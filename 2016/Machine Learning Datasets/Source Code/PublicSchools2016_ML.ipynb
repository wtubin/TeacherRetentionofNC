# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2016

#Location where copies of the raw data files will be read in from csv files.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
inputFileName = 'PublicSchools2016'
#inputFileName = 'PublicHighSchools2016'
#inputFileName = 'PublicMiddleSchools2016'
#inputFileName = 'PublicElementarySchools2016'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2599 entries, 0 to 2598
# Columns: 2158 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2109), int64(3), object(46)
# memory usage: 42.8+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Columns: 2158 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2109), int64(3), object(46)
# memory usage: 40.0+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  1
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Columns: 1967 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1924), object(43)
# memory usage: 36.5+ MB
#
# Columns Deleted:  191

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Columns: 1965 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1924), object(41)
# memory usage: 36.4+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Columns: 1965 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1924), object(41)
# memory usage: 36.4+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print( "Boolean Columns: ", sD_boolean.shape[1])
print( "Nominal Columns: ", sD_nominal.shape[1])
print( "Continuous Columns: ", sD_continuous.shape[1])
print( "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  41
# Continuous Columns:  1924
# Columns Accounted for:  1965

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Columns: 1467 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1426), object(41)
# memory usage: 27.2+ MB
#
# Columns Deleted:  498

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Columns: 1449 entries, closed_ind to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1426), object(23)
# memory usage: 26.9+ MB
#
# Columns Deleted:  18

# %%
#schoolData.info(verbose=True)
print( 'Columns To One-Hot Encode: ', len(sD_nominal.columns))
# Out:
# Columns To One-Hot Encode:  23

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData,columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print( 'Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print( '\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  23
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Columns: 1485 entries, closed_ind to _1_to_1_access_Yes
# dtypes: float64(1426), uint8(59)
# memory usage: 26.6 MB
#
# New Columns Created Via One-Hot Encoding:  36

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 4                                              00_Size                   1149
# 5                                              01_Size                   1153
# 6                                              02_Size                   1153
# 7                                              03_Size                   1155
# 8                                              04_Size                   1140
# 9                                              05_Size                   1168
# 10                                         Math I_Size                   1409
# 20                                           SPG Score                    128
# 21                                   Reading SPG Grade                    604
# 22                                      Math SPG Grade                    604
# 23                                  EVAAS Growth Score                    138
# 24                           Overall Achievement Score                    128
# 25                                       Reading Score                    604
# 26                                          Math Score                    604
# 27                                       Science Score                    690
# 28                                        Math I Score                   1457
# 29                                   EOCMathI_CACR_All                   1423
# 30                                    EOCMathI_GLP_All                   1423
# 31                                EOCSubjects_CACR_All                   1400
# 32                                 EOCSubjects_GLP_All                   1400
# 33                            EOG/EOCSubjects_CACR_All                     45
# 34                             EOG/EOCSubjects_GLP_All                     45
# 35                                     EOGGr3_CACR_All                   1104
# 36                                      EOGGr3_GLP_All                   1104
# 37                                     EOGGr4_CACR_All                   1108
# 38                                      EOGGr4_GLP_All                   1108
# 39                                     EOGGr5_CACR_All                   1133
# 40                                      EOGGr5_GLP_All                   1133
# 41                                 EOGMathGr3_CACR_All                   1114
# 42                                  EOGMathGr3_GLP_All                   1114
# 43                               EOGMathGr3-8_CACR_All                    541
# 44                                EOGMathGr3-8_GLP_All                    541
# 45                                 EOGMathGr4_CACR_All                   1119
# 46                                  EOGMathGr4_GLP_All                   1119
# 47                                 EOGMathGr5_CACR_All                   1147
# 48                                  EOGMathGr5_GLP_All                   1147
# 49                              EOGReadingGr3_CACR_All                   1114
# 50                               EOGReadingGr3_GLP_All                   1114
# 51                            EOGReadingGr3-8_CACR_All                    542
# 52                             EOGReadingGr3-8_GLP_All                    542
# 53                              EOGReadingGr4_CACR_All                   1119
# 54                               EOGReadingGr4_GLP_All                   1119
# 55                              EOGReadingGr5_CACR_All                   1147
# 56                               EOGReadingGr5_GLP_All                   1147
# 57                              EOGScienceGr5_CACR_All                   1147
# 58                               EOGScienceGr5_GLP_All                   1147
# 59                            EOGScienceGr5&8_CACR_All                    650
# 60                             EOGScienceGr5&8_GLP_All                    650
# 61                                EOGSubjects_CACR_All                    536
# 62                                 EOGSubjects_GLP_All                    536
# 63                                EOCMathI_CACR_Female                   1423
# 64                                 EOCMathI_GLP_Female                   1423
# 65                             EOCSubjects_CACR_Female                   1400
# 66                              EOCSubjects_GLP_Female                   1400
# 67                         EOG/EOCSubjects_CACR_Female                     45
# 68                          EOG/EOCSubjects_GLP_Female                     45
# 69                                  EOGGr3_CACR_Female                   1104
# 70                                   EOGGr3_GLP_Female                   1104
# 71                                  EOGGr4_CACR_Female                   1108
# 72                                   EOGGr4_GLP_Female                   1108
# 73                                  EOGGr5_CACR_Female                   1133
# 74                                   EOGGr5_GLP_Female                   1133
# 75                              EOGMathGr3_CACR_Female                   1114
# 76                               EOGMathGr3_GLP_Female                   1114
# 77                            EOGMathGr3-8_CACR_Female                    541
# 78                             EOGMathGr3-8_GLP_Female                    541
# 79                              EOGMathGr4_CACR_Female                   1119
# 80                               EOGMathGr4_GLP_Female                   1119
# 81                              EOGMathGr5_CACR_Female                   1147
# 82                               EOGMathGr5_GLP_Female                   1147
# 83                           EOGReadingGr3_CACR_Female                   1114
# 84                            EOGReadingGr3_GLP_Female                   1114
# 85                         EOGReadingGr3-8_CACR_Female                    542
# 86                          EOGReadingGr3-8_GLP_Female                    542
# 87                           EOGReadingGr4_CACR_Female                   1119
# 88                            EOGReadingGr4_GLP_Female                   1119
# 89                           EOGReadingGr5_CACR_Female                   1147
# 90                            EOGReadingGr5_GLP_Female                   1147
# 91                           EOGScienceGr5_CACR_Female                   1147
# 92                            EOGScienceGr5_GLP_Female                   1147
# 93                         EOGScienceGr5&8_CACR_Female                    650
# 94                          EOGScienceGr5&8_GLP_Female                    650
# 95                             EOGSubjects_CACR_Female                    536
# 96                              EOGSubjects_GLP_Female                    536
# 97                                  EOCMathI_CACR_Male                   1423
# 98                                   EOCMathI_GLP_Male                   1423
# 99                               EOCSubjects_CACR_Male                   1400
# 100                               EOCSubjects_GLP_Male                   1400
# 101                          EOG/EOCSubjects_CACR_Male                     45
# 102                           EOG/EOCSubjects_GLP_Male                     45
# 103                                   EOGGr3_CACR_Male                   1104
# 104                                    EOGGr3_GLP_Male                   1104
# 105                                   EOGGr4_CACR_Male                   1108
# 106                                    EOGGr4_GLP_Male                   1108
# 107                                   EOGGr5_CACR_Male                   1133
# 108                                    EOGGr5_GLP_Male                   1133
# 109                               EOGMathGr3_CACR_Male                   1114
# 110                                EOGMathGr3_GLP_Male                   1114
# 111                             EOGMathGr3-8_CACR_Male                    541
# 112                              EOGMathGr3-8_GLP_Male                    541
# 113                               EOGMathGr4_CACR_Male                   1119
# 114                                EOGMathGr4_GLP_Male                   1119
# 115                               EOGMathGr5_CACR_Male                   1147
# 116                                EOGMathGr5_GLP_Male                   1147
# 117                            EOGReadingGr3_CACR_Male                   1114
# 118                             EOGReadingGr3_GLP_Male                   1114
# 119                          EOGReadingGr3-8_CACR_Male                    542
# 120                           EOGReadingGr3-8_GLP_Male                    542
# 121                            EOGReadingGr4_CACR_Male                   1119
# 122                             EOGReadingGr4_GLP_Male                   1119
# 123                            EOGReadingGr5_CACR_Male                   1147
# 124                             EOGReadingGr5_GLP_Male                   1147
# 125                            EOGScienceGr5_CACR_Male                   1147
# 126                             EOGScienceGr5_GLP_Male                   1147
# 127                          EOGScienceGr5&8_CACR_Male                    650
# 128                           EOGScienceGr5&8_GLP_Male                    650
# 129                              EOGSubjects_CACR_Male                    536
# 130                               EOGSubjects_GLP_Male                    536
# 131                       EOCMathI_CACR_AmericanIndian                   1423
# 132                        EOCMathI_GLP_AmericanIndian                   1423
# 133                    EOCSubjects_CACR_AmericanIndian                   1400
# 134                     EOCSubjects_GLP_AmericanIndian                   1400
# 135                EOG/EOCSubjects_CACR_AmericanIndian                     45
# 136                 EOG/EOCSubjects_GLP_AmericanIndian                     45
# 137                         EOGGr3_CACR_AmericanIndian                   1104
# 138                          EOGGr3_GLP_AmericanIndian                   1104
# 139                         EOGGr4_CACR_AmericanIndian                   1108
# 140                          EOGGr4_GLP_AmericanIndian                   1108
# 141                         EOGGr5_CACR_AmericanIndian                   1133
# 142                          EOGGr5_GLP_AmericanIndian                   1133
# 143                     EOGMathGr3_CACR_AmericanIndian                   1114
# 144                      EOGMathGr3_GLP_AmericanIndian                   1114
# 145                   EOGMathGr3-8_CACR_AmericanIndian                    541
# 146                    EOGMathGr3-8_GLP_AmericanIndian                    541
# 147                     EOGMathGr4_CACR_AmericanIndian                   1119
# 148                      EOGMathGr4_GLP_AmericanIndian                   1119
# 149                     EOGMathGr5_CACR_AmericanIndian                   1147
# 150                      EOGMathGr5_GLP_AmericanIndian                   1147
# 151                  EOGReadingGr3_CACR_AmericanIndian                   1114
# 152                   EOGReadingGr3_GLP_AmericanIndian                   1114
# 153                EOGReadingGr3-8_CACR_AmericanIndian                    542
# 154                 EOGReadingGr3-8_GLP_AmericanIndian                    542
# 155                  EOGReadingGr4_CACR_AmericanIndian                   1119
# 156                   EOGReadingGr4_GLP_AmericanIndian                   1119
# 157                  EOGReadingGr5_CACR_AmericanIndian                   1147
# 158                   EOGReadingGr5_GLP_AmericanIndian                   1147
# 159                  EOGScienceGr5_CACR_AmericanIndian                   1147
# 160                   EOGScienceGr5_GLP_AmericanIndian                   1147
# 161                EOGScienceGr5&8_CACR_AmericanIndian                    650
# 162                 EOGScienceGr5&8_GLP_AmericanIndian                    650
# 163                    EOGSubjects_CACR_AmericanIndian                    536
# 164                     EOGSubjects_GLP_AmericanIndian                    536
# 165                                EOCMathI_CACR_Asian                   1423
# 166                                 EOCMathI_GLP_Asian                   1423
# 167                             EOCSubjects_CACR_Asian                   1400
# 168                              EOCSubjects_GLP_Asian                   1400
# 169                         EOG/EOCSubjects_CACR_Asian                     45
# 170                          EOG/EOCSubjects_GLP_Asian                     45
# 171                                  EOGGr3_CACR_Asian                   1104
# 172                                   EOGGr3_GLP_Asian                   1104
# 173                                  EOGGr4_CACR_Asian                   1108
# 174                                   EOGGr4_GLP_Asian                   1108
# 175                                  EOGGr5_CACR_Asian                   1133
# 176                                   EOGGr5_GLP_Asian                   1133
# 177                              EOGMathGr3_CACR_Asian                   1114
# 178                               EOGMathGr3_GLP_Asian                   1114
# 179                            EOGMathGr3-8_CACR_Asian                    541
# 180                             EOGMathGr3-8_GLP_Asian                    541
# 181                              EOGMathGr4_CACR_Asian                   1119
# 182                               EOGMathGr4_GLP_Asian                   1119
# 183                              EOGMathGr5_CACR_Asian                   1147
# 184                               EOGMathGr5_GLP_Asian                   1147
# 185                           EOGReadingGr3_CACR_Asian                   1114
# 186                            EOGReadingGr3_GLP_Asian                   1114
# 187                         EOGReadingGr3-8_CACR_Asian                    542
# 188                          EOGReadingGr3-8_GLP_Asian                    542
# 189                           EOGReadingGr4_CACR_Asian                   1119
# 190                            EOGReadingGr4_GLP_Asian                   1119
# 191                           EOGReadingGr5_CACR_Asian                   1147
# 192                            EOGReadingGr5_GLP_Asian                   1147
# 193                           EOGScienceGr5_CACR_Asian                   1147
# 194                            EOGScienceGr5_GLP_Asian                   1147
# 195                         EOGScienceGr5&8_CACR_Asian                    650
# 196                          EOGScienceGr5&8_GLP_Asian                    650
# 197                             EOGSubjects_CACR_Asian                    536
# 198                              EOGSubjects_GLP_Asian                    536
# 199                                EOCMathI_CACR_Black                   1423
# 200                                 EOCMathI_GLP_Black                   1423
# 201                             EOCSubjects_CACR_Black                   1400
# 202                              EOCSubjects_GLP_Black                   1400
# 203                         EOG/EOCSubjects_CACR_Black                     45
# 204                          EOG/EOCSubjects_GLP_Black                     45
# 205                                  EOGGr3_CACR_Black                   1104
# 206                                   EOGGr3_GLP_Black                   1104
# 207                                  EOGGr4_CACR_Black                   1108
# 208                                   EOGGr4_GLP_Black                   1108
# 209                                  EOGGr5_CACR_Black                   1133
# 210                                   EOGGr5_GLP_Black                   1133
# 211                              EOGMathGr3_CACR_Black                   1114
# 212                               EOGMathGr3_GLP_Black                   1114
# 213                            EOGMathGr3-8_CACR_Black                    541
# 214                             EOGMathGr3-8_GLP_Black                    541
# 215                              EOGMathGr4_CACR_Black                   1119
# 216                               EOGMathGr4_GLP_Black                   1119
# 217                              EOGMathGr5_CACR_Black                   1147
# 218                               EOGMathGr5_GLP_Black                   1147
# 219                           EOGReadingGr3_CACR_Black                   1114
# 220                            EOGReadingGr3_GLP_Black                   1114
# 221                         EOGReadingGr3-8_CACR_Black                    542
# 222                          EOGReadingGr3-8_GLP_Black                    542
# 223                           EOGReadingGr4_CACR_Black                   1119
# 224                            EOGReadingGr4_GLP_Black                   1119
# 225                           EOGReadingGr5_CACR_Black                   1147
# 226                            EOGReadingGr5_GLP_Black                   1147
# 227                           EOGScienceGr5_CACR_Black                   1147
# 228                            EOGScienceGr5_GLP_Black                   1147
# 229                         EOGScienceGr5&8_CACR_Black                    650
# 230                          EOGScienceGr5&8_GLP_Black                    650
# 231                             EOGSubjects_CACR_Black                    536
# 232                              EOGSubjects_GLP_Black                    536
# 233                             EOCMathI_CACR_Hispanic                   1423
# 234                              EOCMathI_GLP_Hispanic                   1423
# 235                          EOCSubjects_CACR_Hispanic                   1400
# 236                           EOCSubjects_GLP_Hispanic                   1400
# 237                      EOG/EOCSubjects_CACR_Hispanic                     45
# 238                       EOG/EOCSubjects_GLP_Hispanic                     45
# 239                               EOGGr3_CACR_Hispanic                   1104
# 240                                EOGGr3_GLP_Hispanic                   1104
# 241                               EOGGr4_CACR_Hispanic                   1108
# 242                                EOGGr4_GLP_Hispanic                   1108
# 243                               EOGGr5_CACR_Hispanic                   1133
# 244                                EOGGr5_GLP_Hispanic                   1133
# 245                           EOGMathGr3_CACR_Hispanic                   1114
# 246                            EOGMathGr3_GLP_Hispanic                   1114
# 247                         EOGMathGr3-8_CACR_Hispanic                    541
# 248                          EOGMathGr3-8_GLP_Hispanic                    541
# 249                           EOGMathGr4_CACR_Hispanic                   1119
# 250                            EOGMathGr4_GLP_Hispanic                   1119
# 251                           EOGMathGr5_CACR_Hispanic                   1147
# 252                            EOGMathGr5_GLP_Hispanic                   1147
# 253                        EOGReadingGr3_CACR_Hispanic                   1114
# 254                         EOGReadingGr3_GLP_Hispanic                   1114
# 255                      EOGReadingGr3-8_CACR_Hispanic                    542
# 256                       EOGReadingGr3-8_GLP_Hispanic                    542
# 257                        EOGReadingGr4_CACR_Hispanic                   1119
# 258                         EOGReadingGr4_GLP_Hispanic                   1119
# 259                        EOGReadingGr5_CACR_Hispanic                   1147
# 260                         EOGReadingGr5_GLP_Hispanic                   1147
# 261                        EOGScienceGr5_CACR_Hispanic                   1147
# 262                         EOGScienceGr5_GLP_Hispanic                   1147
# 263                      EOGScienceGr5&8_CACR_Hispanic                    650
# 264                       EOGScienceGr5&8_GLP_Hispanic                    650
# 265                          EOGSubjects_CACR_Hispanic                    536
# 266                           EOGSubjects_GLP_Hispanic                    536
# 267                       EOCMathI_CACR_TwoorMoreRaces                   1423
# 268                        EOCMathI_GLP_TwoorMoreRaces                   1423
# 269                    EOCSubjects_CACR_TwoorMoreRaces                   1400
# 270                     EOCSubjects_GLP_TwoorMoreRaces                   1400
# 271                EOG/EOCSubjects_CACR_TwoorMoreRaces                     45
# 272                 EOG/EOCSubjects_GLP_TwoorMoreRaces                     45
# 273                         EOGGr3_CACR_TwoorMoreRaces                   1104
# 274                          EOGGr3_GLP_TwoorMoreRaces                   1104
# 275                         EOGGr4_CACR_TwoorMoreRaces                   1108
# 276                          EOGGr4_GLP_TwoorMoreRaces                   1108
# 277                         EOGGr5_CACR_TwoorMoreRaces                   1133
# 278                          EOGGr5_GLP_TwoorMoreRaces                   1133
# 279                     EOGMathGr3_CACR_TwoorMoreRaces                   1114
# 280                      EOGMathGr3_GLP_TwoorMoreRaces                   1114
# 281                   EOGMathGr3-8_CACR_TwoorMoreRaces                    541
# 282                    EOGMathGr3-8_GLP_TwoorMoreRaces                    541
# 283                     EOGMathGr4_CACR_TwoorMoreRaces                   1119
# 284                      EOGMathGr4_GLP_TwoorMoreRaces                   1119
# 285                     EOGMathGr5_CACR_TwoorMoreRaces                   1147
# 286                      EOGMathGr5_GLP_TwoorMoreRaces                   1147
# 287                  EOGReadingGr3_CACR_TwoorMoreRaces                   1114
# 288                   EOGReadingGr3_GLP_TwoorMoreRaces                   1114
# 289                EOGReadingGr3-8_CACR_TwoorMoreRaces                    542
# 290                 EOGReadingGr3-8_GLP_TwoorMoreRaces                    542
# 291                  EOGReadingGr4_CACR_TwoorMoreRaces                   1119
# 292                   EOGReadingGr4_GLP_TwoorMoreRaces                   1119
# 293                  EOGReadingGr5_CACR_TwoorMoreRaces                   1147
# 294                   EOGReadingGr5_GLP_TwoorMoreRaces                   1147
# 295                  EOGScienceGr5_CACR_TwoorMoreRaces                   1147
# 296                   EOGScienceGr5_GLP_TwoorMoreRaces                   1147
# 297                EOGScienceGr5&8_CACR_TwoorMoreRaces                    650
# 298                 EOGScienceGr5&8_GLP_TwoorMoreRaces                    650
# 299                    EOGSubjects_CACR_TwoorMoreRaces                    536
# 300                     EOGSubjects_GLP_TwoorMoreRaces                    536
# 301                                EOCMathI_CACR_White                   1423
# 302                                 EOCMathI_GLP_White                   1423
# 303                             EOCSubjects_CACR_White                   1400
# 304                              EOCSubjects_GLP_White                   1400
# 305                         EOG/EOCSubjects_CACR_White                     45
# 306                          EOG/EOCSubjects_GLP_White                     45
# 307                                  EOGGr3_CACR_White                   1104
# 308                                   EOGGr3_GLP_White                   1104
# 309                                  EOGGr4_CACR_White                   1108
# 310                                   EOGGr4_GLP_White                   1108
# 311                                  EOGGr5_CACR_White                   1133
# 312                                   EOGGr5_GLP_White                   1133
# 313                              EOGMathGr3_CACR_White                   1114
# 314                               EOGMathGr3_GLP_White                   1114
# 315                            EOGMathGr3-8_CACR_White                    541
# 316                             EOGMathGr3-8_GLP_White                    541
# 317                              EOGMathGr4_CACR_White                   1119
# 318                               EOGMathGr4_GLP_White                   1119
# 319                              EOGMathGr5_CACR_White                   1147
# 320                               EOGMathGr5_GLP_White                   1147
# 321                           EOGReadingGr3_CACR_White                   1114
# 322                            EOGReadingGr3_GLP_White                   1114
# 323                         EOGReadingGr3-8_CACR_White                    542
# 324                          EOGReadingGr3-8_GLP_White                    542
# 325                           EOGReadingGr4_CACR_White                   1119
# 326                            EOGReadingGr4_GLP_White                   1119
# 327                           EOGReadingGr5_CACR_White                   1147
# 328                            EOGReadingGr5_GLP_White                   1147
# 329                           EOGScienceGr5_CACR_White                   1147
# 330                            EOGScienceGr5_GLP_White                   1147
# 331                         EOGScienceGr5&8_CACR_White                    650
# 332                          EOGScienceGr5&8_GLP_White                    650
# 333                             EOGSubjects_CACR_White                    536
# 334                              EOGSubjects_GLP_White                    536
# 335                                  EOCMathI_CACR_EDS                   1423
# 336                                   EOCMathI_GLP_EDS                   1423
# 337                               EOCSubjects_CACR_EDS                   1400
# 338                                EOCSubjects_GLP_EDS                   1400
# 339                           EOG/EOCSubjects_CACR_EDS                     45
# 340                            EOG/EOCSubjects_GLP_EDS                     45
# 341                                    EOGGr3_CACR_EDS                   1104
# 342                                     EOGGr3_GLP_EDS                   1104
# 343                                    EOGGr4_CACR_EDS                   1108
# 344                                     EOGGr4_GLP_EDS                   1108
# 345                                    EOGGr5_CACR_EDS                   1133
# 346                                     EOGGr5_GLP_EDS                   1133
# 347                                EOGMathGr3_CACR_EDS                   1114
# 348                                 EOGMathGr3_GLP_EDS                   1114
# 349                              EOGMathGr3-8_CACR_EDS                    541
# 350                               EOGMathGr3-8_GLP_EDS                    541
# 351                                EOGMathGr4_CACR_EDS                   1119
# 352                                 EOGMathGr4_GLP_EDS                   1119
# 353                                EOGMathGr5_CACR_EDS                   1147
# 354                                 EOGMathGr5_GLP_EDS                   1147
# 355                             EOGReadingGr3_CACR_EDS                   1114
# 356                              EOGReadingGr3_GLP_EDS                   1114
# 357                           EOGReadingGr3-8_CACR_EDS                    542
# 358                            EOGReadingGr3-8_GLP_EDS                    542
# 359                             EOGReadingGr4_CACR_EDS                   1119
# 360                              EOGReadingGr4_GLP_EDS                   1119
# 361                             EOGReadingGr5_CACR_EDS                   1147
# 362                              EOGReadingGr5_GLP_EDS                   1147
# 363                             EOGScienceGr5_CACR_EDS                   1147
# 364                              EOGScienceGr5_GLP_EDS                   1147
# 365                           EOGScienceGr5&8_CACR_EDS                    650
# 366                            EOGScienceGr5&8_GLP_EDS                    650
# 367                               EOGSubjects_CACR_EDS                    536
# 368                                EOGSubjects_GLP_EDS                    536
# 369                                  EOCMathI_CACR_LEP                   1423
# 370                                   EOCMathI_GLP_LEP                   1423
# 371                               EOCSubjects_CACR_LEP                   1400
# 372                                EOCSubjects_GLP_LEP                   1400
# 373                           EOG/EOCSubjects_CACR_LEP                     45
# 374                            EOG/EOCSubjects_GLP_LEP                     45
# 375                                    EOGGr3_CACR_LEP                   1104
# 376                                     EOGGr3_GLP_LEP                   1104
# 377                                    EOGGr4_CACR_LEP                   1108
# 378                                     EOGGr4_GLP_LEP                   1108
# 379                                    EOGGr5_CACR_LEP                   1133
# 380                                     EOGGr5_GLP_LEP                   1133
# 381                                EOGMathGr3_CACR_LEP                   1114
# 382                                 EOGMathGr3_GLP_LEP                   1114
# 383                              EOGMathGr3-8_CACR_LEP                    541
# 384                               EOGMathGr3-8_GLP_LEP                    541
# 385                                EOGMathGr4_CACR_LEP                   1119
# 386                                 EOGMathGr4_GLP_LEP                   1119
# 387                                EOGMathGr5_CACR_LEP                   1147
# 388                                 EOGMathGr5_GLP_LEP                   1147
# 389                             EOGReadingGr3_CACR_LEP                   1114
# 390                              EOGReadingGr3_GLP_LEP                   1114
# 391                           EOGReadingGr3-8_CACR_LEP                    542
# 392                            EOGReadingGr3-8_GLP_LEP                    542
# 393                             EOGReadingGr4_CACR_LEP                   1119
# 394                              EOGReadingGr4_GLP_LEP                   1119
# 395                             EOGReadingGr5_CACR_LEP                   1147
# 396                              EOGReadingGr5_GLP_LEP                   1147
# 397                             EOGScienceGr5_CACR_LEP                   1147
# 398                              EOGScienceGr5_GLP_LEP                   1147
# 399                           EOGScienceGr5&8_CACR_LEP                    650
# 400                            EOGScienceGr5&8_GLP_LEP                    650
# 401                               EOGSubjects_CACR_LEP                    536
# 402                                EOGSubjects_GLP_LEP                    536
# 403                                  EOCMathI_CACR_SWD                   1423
# 404                                   EOCMathI_GLP_SWD                   1423
# 405                               EOCSubjects_CACR_SWD                   1400
# 406                                EOCSubjects_GLP_SWD                   1400
# 407                           EOG/EOCSubjects_CACR_SWD                     45
# 408                            EOG/EOCSubjects_GLP_SWD                     45
# 409                                    EOGGr3_CACR_SWD                   1104
# 410                                     EOGGr3_GLP_SWD                   1104
# 411                                    EOGGr4_CACR_SWD                   1108
# 412                                     EOGGr4_GLP_SWD                   1108
# 413                                    EOGGr5_CACR_SWD                   1133
# 414                                     EOGGr5_GLP_SWD                   1133
# 415                                EOGMathGr3_CACR_SWD                   1114
# 416                                 EOGMathGr3_GLP_SWD                   1114
# 417                              EOGMathGr3-8_CACR_SWD                    541
# 418                               EOGMathGr3-8_GLP_SWD                    541
# 419                                EOGMathGr4_CACR_SWD                   1119
# 420                                 EOGMathGr4_GLP_SWD                   1119
# 421                                EOGMathGr5_CACR_SWD                   1147
# 422                                 EOGMathGr5_GLP_SWD                   1147
# 423                             EOGReadingGr3_CACR_SWD                   1114
# 424                              EOGReadingGr3_GLP_SWD                   1114
# 425                           EOGReadingGr3-8_CACR_SWD                    542
# 426                            EOGReadingGr3-8_GLP_SWD                    542
# 427                             EOGReadingGr4_CACR_SWD                   1119
# 428                              EOGReadingGr4_GLP_SWD                   1119
# 429                             EOGReadingGr5_CACR_SWD                   1147
# 430                              EOGReadingGr5_GLP_SWD                   1147
# 431                             EOGScienceGr5_CACR_SWD                   1147
# 432                              EOGScienceGr5_GLP_SWD                   1147
# 433                           EOGScienceGr5&8_CACR_SWD                    650
# 434                            EOGScienceGr5&8_GLP_SWD                    650
# 435                               EOGSubjects_CACR_SWD                    536
# 436                                EOGSubjects_GLP_SWD                    536
# 437                                  EOCMathI_CACR_AIG                   1423
# 438                                   EOCMathI_GLP_AIG                   1423
# 439                               EOCSubjects_CACR_AIG                   1400
# 440                                EOCSubjects_GLP_AIG                   1400
# 441                           EOG/EOCSubjects_CACR_AIG                     45
# 442                            EOG/EOCSubjects_GLP_AIG                     45
# 443                                    EOGGr3_CACR_AIG                   1104
# 444                                     EOGGr3_GLP_AIG                   1104
# 445                                    EOGGr4_CACR_AIG                   1108
# 446                                     EOGGr4_GLP_AIG                   1108
# 447                                    EOGGr5_CACR_AIG                   1133
# 448                                     EOGGr5_GLP_AIG                   1133
# 449                                EOGMathGr3_CACR_AIG                   1114
# 450                                 EOGMathGr3_GLP_AIG                   1114
# 451                              EOGMathGr3-8_CACR_AIG                    541
# 452                               EOGMathGr3-8_GLP_AIG                    541
# 453                                EOGMathGr4_CACR_AIG                   1119
# 454                                 EOGMathGr4_GLP_AIG                   1119
# 455                                EOGMathGr5_CACR_AIG                   1147
# 456                                 EOGMathGr5_GLP_AIG                   1147
# 457                             EOGReadingGr3_CACR_AIG                   1114
# 458                              EOGReadingGr3_GLP_AIG                   1114
# 459                           EOGReadingGr3-8_CACR_AIG                    542
# 460                            EOGReadingGr3-8_GLP_AIG                    542
# 461                             EOGReadingGr4_CACR_AIG                   1119
# 462                              EOGReadingGr4_GLP_AIG                   1119
# 463                             EOGReadingGr5_CACR_AIG                   1147
# 464                              EOGReadingGr5_GLP_AIG                   1147
# 465                             EOGScienceGr5_CACR_AIG                   1147
# 466                              EOGScienceGr5_GLP_AIG                   1147
# 467                           EOGScienceGr5&8_CACR_AIG                    650
# 468                            EOGScienceGr5&8_GLP_AIG                    650
# 469                               EOGSubjects_CACR_AIG                    536
# 470                                EOGSubjects_GLP_AIG                    536
# 471                                        pct_GCE_ALL                   1086
# 472                                     pct_PASSED_EOG                   1132
# 473                                       pct_PROMOTED                   1114
# 474                           MathGr3-8_pTarget_PctMet                    572
# 475                        ReadingGr3-8_pTarget_PctMet                    572
# 476                            SciGr5&8_pTarget_PctMet                    737
# 477                        TotalTargets_pTarget_PctMet                     60
# 480                           lea_ap_participation_pct                    262
# 481                              lea_ap_pct_3_or_above                     19
# 482                              lea_ib_pct_4_or_above                   1371
# 488                             stud_internet_comp_num                     26
# 499                                  digital_media_pct                    158
# 500                           avg_age_media_collection                    154
# 501                                  books_per_student                    154
# 504                                            wap_num                     17
# 505                                  wap_per_classroom                     17
# 508                                flicensed_teach_pct                      1
# 509                                  tchyrs_0thru3_pct                      1
# 510                                 tchyrs_4thru10_pct                      1
# 511                                  tchyrs_11plus_pct                      1
# 512                                    class_teach_num                      1
# 513                                          nbpts_num                    200
# 514                                    advance_dgr_pct                      1
# 515                               _1yr_tchr_trnovr_pct                     11
# 516                                  lateral_teach_pct                   1122
# 517                                 highqual_class_pct                      9
# 523                                      lea_nbpts_num                     32
# 526                            lea_emer_prov_teach_pct                    984
# 527                              lea_lateral_teach_pct                    227
# 528                             lea_highqual_class_pct                      4
# 529                          lea_highqual_class_hp_pct                     83
# 530                          lea_highqual_class_lp_pct                    239
# 532                      lea_not_highqual_class_hp_pct                     83
# 533                      lea_not_highqual_class_lp_pct                    239
# 546                              0-3 Years_Exp_Pct_Tch                      1
# 547                              10+ Years_Exp_Pct_Tch                      1
# 548                             4-10 Years_Exp_Pct_Tch                      1
# 552                   Accomplished_TCHR_Standard 1_Pct                      7
# 553                   Accomplished_TCHR_Standard 2_Pct                     10
# 554                   Accomplished_TCHR_Standard 3_Pct                     10
# 555                   Accomplished_TCHR_Standard 4_Pct                     15
# 556                   Accomplished_TCHR_Standard 5_Pct                     10
# 557                     Developing_TCHR_Standard 1_Pct                      7
# 558                     Developing_TCHR_Standard 2_Pct                     10
# 559                     Developing_TCHR_Standard 3_Pct                     10
# 560                     Developing_TCHR_Standard 4_Pct                     15
# 561                     Developing_TCHR_Standard 5_Pct                     10
# 562                  Distinguished_TCHR_Standard 1_Pct                      7
# 563                  Distinguished_TCHR_Standard 2_Pct                     10
# 564                  Distinguished_TCHR_Standard 3_Pct                     10
# 565                  Distinguished_TCHR_Standard 4_Pct                     15
# 566                  Distinguished_TCHR_Standard 5_Pct                     10
# 567  Does Not Meet Expected Growth_TCHR_Student Gro...                     41
# 568    Exceeds Expected Growth_TCHR_Student Growth_Pct                     41
# 569      Meets Expected Growth_TCHR_Student Growth_Pct                     41
# 570                Not Demostrated_TCHR_Standard 1_Pct                      7
# 571                Not Demostrated_TCHR_Standard 2_Pct                     10
# 572                Not Demostrated_TCHR_Standard 3_Pct                     10
# 573                Not Demostrated_TCHR_Standard 4_Pct                     15
# 574                Not Demostrated_TCHR_Standard 5_Pct                     10
# 575                     Proficient_TCHR_Standard 1_Pct                      7
# 576                     Proficient_TCHR_Standard 2_Pct                     10
# 577                     Proficient_TCHR_Standard 3_Pct                     10
# 578                     Proficient_TCHR_Standard 4_Pct                     15
# 579                     Proficient_TCHR_Standard 5_Pct                     10
# 604                                               Year                    602
# 605                                       Violent Rate                    648
# 606                                        Murder Rate                    769
# 607                                          Rape Rate                    659
# 608                                       Robbery Rate                    676
# 609                                       Assault Rate                    648
# 610                                           MVT Rate                    664
# 611                                         Arson Rate                    716

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  219594  field correlations > 95%.
#                                                    Field1  \
# 0                                         class_teach_num
# 1                                     lea_class_teach_num
# 2                                      st_class_teach_num
# 3                                      st_advance_dgr_pct
# 4                               Overall Achievement Score
# 5                                          Math SPG Grade
# 6                                           Reading Score
# 7                                              Math Score
# 8                                    EOGMathGr3-8_GLP_All
# 9                                EOGReadingGr3-8_CACR_All
# 10                                EOGReadingGr3-8_GLP_All
# 11                                   EOGSubjects_CACR_All
# 12                                    EOGSubjects_GLP_All
# 13                            EOGReadingGr3-8_CACR_Female
# 14                             EOGReadingGr3-8_GLP_Female
# 15                                EOGSubjects_CACR_Female
# 16                                 EOGSubjects_GLP_Female
# 17                               EOGReadingGr3-8_GLP_Male
# 18                                  EOGSubjects_CACR_Male
# 19                                   EOGSubjects_GLP_Male
# 20                                          Reading Score
# 21                                             Math Score
# 22                                  EOGMathGr3-8_CACR_All
# 23                                   EOGMathGr3-8_GLP_All
# 24                                EOGReadingGr3-8_GLP_All
# 25                                   EOGSubjects_CACR_All
# 26                                    EOGSubjects_GLP_All
# 27                               EOGMathGr3-8_CACR_Female
# 28                                EOGMathGr3-8_GLP_Female
# 29                             EOGReadingGr3-8_GLP_Female
# 30                                EOGSubjects_CACR_Female
# 31                                 EOGSubjects_GLP_Female
# 32                                 EOGMathGr3-8_CACR_Male
# 33                                  EOGMathGr3-8_GLP_Male
# 34                                  EOGSubjects_CACR_Male
# 35                                   EOGSubjects_GLP_Male
# 36                                    EOGSubjects_GLP_EDS
# 37                                             Math Score
# 38                                  EOGMathGr3-8_CACR_All
# 39                                   EOGMathGr3-8_GLP_All
# 40                               EOGReadingGr3-8_CACR_All
# 41                                EOGReadingGr3-8_GLP_All
# 42                                   EOGSubjects_CACR_All
# 43                                    EOGSubjects_GLP_All
# 44                                EOGMathGr3-8_GLP_Female
# 45                            EOGReadingGr3-8_CACR_Female
# 46                             EOGReadingGr3-8_GLP_Female
# 47                                EOGSubjects_CACR_Female
# 48                                 EOGSubjects_GLP_Female
# 49                              EOGReadingGr3-8_CACR_Male
# 50                               EOGReadingGr3-8_GLP_Male
# 51                                  EOGSubjects_CACR_Male
# 52                                   EOGSubjects_GLP_Male
# 53                                  EOGMathGr3-8_CACR_All
# 54                                   EOGMathGr3-8_GLP_All
# 55                                EOGReadingGr3-8_GLP_All
# 56                                   EOGSubjects_CACR_All
# 57                                    EOGSubjects_GLP_All
# 58                               EOGMathGr3-8_CACR_Female
# 59                                EOGMathGr3-8_GLP_Female
# 60                                EOGSubjects_CACR_Female
# 61                                 EOGSubjects_GLP_Female
# 62                                 EOGMathGr3-8_CACR_Male
# 63                                  EOGMathGr3-8_GLP_Male
# 64                                  EOGSubjects_CACR_Male
# 65                                   EOGSubjects_GLP_Male
# 66                                   EOGMathGr3-8_GLP_EDS
# 67                                   EOGSubjects_CACR_EDS
# 68                                    EOGSubjects_GLP_EDS
# 69                               EOGScienceGr5&8_CACR_All
# 70                                EOGScienceGr5&8_GLP_All
# 71                            EOGScienceGr5&8_CACR_Female
# 72                             EOGScienceGr5&8_GLP_Female
# 73                              EOGScienceGr5&8_CACR_Male
# 74                               EOGScienceGr5&8_GLP_Male
# 75                                      EOCMathI_CACR_All
# 76                                       EOCMathI_GLP_All
# 77                                   EOCSubjects_CACR_All
# 78                                    EOCSubjects_GLP_All
# 79                                       EOCMathI_GLP_All
# 80                                   EOCSubjects_CACR_All
# 81                                    EOCSubjects_GLP_All
# 82                                   EOCSubjects_CACR_All
# 83                                    EOCSubjects_GLP_All
# 84                                    EOCSubjects_GLP_All
# 85                                EOG/EOCSubjects_GLP_All
# 86                            EOG/EOCSubjects_CACR_Female
# 87                             EOG/EOCSubjects_GLP_Female
# 88                              EOG/EOCSubjects_CACR_Male
# 89                               EOG/EOCSubjects_GLP_Male
# 90                            EOG/EOCSubjects_CACR_Female
# 91                             EOG/EOCSubjects_GLP_Female
# 92                              EOG/EOCSubjects_CACR_Male
# 93                               EOG/EOCSubjects_GLP_Male
# 94                                         EOGGr3_GLP_All
# 95                                    EOGMathGr3_CACR_All
# 96                                     EOGMathGr3_GLP_All
# 97                                 EOGReadingGr3_CACR_All
# 98                                  EOGReadingGr3_GLP_All
# 99                                     EOGGr3_CACR_Female
# 100                                     EOGGr3_GLP_Female
# 101                                EOGMathGr3_CACR_Female
# 102                                 EOGMathGr3_GLP_Female
# 103                             EOGReadingGr3_CACR_Female
# 104                              EOGReadingGr3_GLP_Female
# 105                                      EOGGr3_CACR_Male
# 106                                       EOGGr3_GLP_Male
# 107                                  EOGMathGr3_CACR_Male
# 108                                   EOGMathGr3_GLP_Male
# 109                               EOGReadingGr3_CACR_Male
# 110                                EOGReadingGr3_GLP_Male
# 111                                        EOGGr3_GLP_EDS
# 112                                        pct_PASSED_EOG
# 113                                   EOGMathGr3_CACR_All
# 114                                    EOGMathGr3_GLP_All
# 115                                EOGReadingGr3_CACR_All
# 116                                 EOGReadingGr3_GLP_All
# 117                                    EOGGr3_CACR_Female
# 118                                     EOGGr3_GLP_Female
# 119                                EOGMathGr3_CACR_Female
# 120                                 EOGMathGr3_GLP_Female
# 121                             EOGReadingGr3_CACR_Female
# 122                              EOGReadingGr3_GLP_Female
# 123                                      EOGGr3_CACR_Male
# 124                                       EOGGr3_GLP_Male
# 125                                  EOGMathGr3_CACR_Male
# 126                                   EOGMathGr3_GLP_Male
# 127                                EOGReadingGr3_GLP_Male
# 128                                       EOGGr3_CACR_EDS
# 129                                        EOGGr3_GLP_EDS
# 130                                        pct_PASSED_EOG
# 131                                          pct_PROMOTED
# 132                                        EOGGr4_GLP_All
# 133                                   EOGMathGr4_CACR_All
# 134                                    EOGMathGr4_GLP_All
# 135                                EOGReadingGr4_CACR_All
# 136                                 EOGReadingGr4_GLP_All
# 137                                    EOGGr4_CACR_Female
# 138                                     EOGGr4_GLP_Female
# 139                                EOGMathGr4_CACR_Female
# 140                                 EOGMathGr4_GLP_Female
# 141                             EOGReadingGr4_CACR_Female
# 142                                      EOGGr4_CACR_Male
# 143                                       EOGGr4_GLP_Male
# 144                                  EOGMathGr4_CACR_Male
# 145                                   EOGMathGr4_GLP_Male
# 146                               EOGReadingGr4_CACR_Male
# 147                                EOGReadingGr4_GLP_Male
# 148                                   EOGMathGr4_CACR_All
# 149                                    EOGMathGr4_GLP_All
# 150                                EOGReadingGr4_CACR_All
# 151                                 EOGReadingGr4_GLP_All
# 152                                    EOGGr4_CACR_Female
# 153                                     EOGGr4_GLP_Female
# 154                                EOGMathGr4_CACR_Female
# 155                                 EOGMathGr4_GLP_Female
# 156                              EOGReadingGr4_GLP_Female
# 157                                      EOGGr4_CACR_Male
# 158                                       EOGGr4_GLP_Male
# 159                                  EOGMathGr4_CACR_Male
# 160                                   EOGMathGr4_GLP_Male
# 161                                EOGReadingGr4_GLP_Male
# 162                                        EOGGr4_GLP_EDS
# 163                                        EOGGr5_GLP_All
# 164                                   EOGMathGr5_CACR_All
# 165                                    EOGMathGr5_GLP_All
# 166                                EOGReadingGr5_CACR_All
# 167                                 EOGReadingGr5_GLP_All
# 168                                EOGScienceGr5_CACR_All
# 169                                 EOGScienceGr5_GLP_All
# 170                                    EOGGr5_CACR_Female
# 171                                     EOGGr5_GLP_Female
# 172                                EOGMathGr5_CACR_Female
# 173                                 EOGMathGr5_GLP_Female
# 174                             EOGReadingGr5_CACR_Female
# 175                              EOGReadingGr5_GLP_Female
# 176                             EOGScienceGr5_CACR_Female
# 177                              EOGScienceGr5_GLP_Female
# 178                                      EOGGr5_CACR_Male
# 179                                       EOGGr5_GLP_Male
# 180                                  EOGMathGr5_CACR_Male
# 181                                   EOGMathGr5_GLP_Male
# 182                                EOGReadingGr5_GLP_Male
# 183                               EOGScienceGr5_CACR_Male
# 184                                EOGScienceGr5_GLP_Male
# 185                                       EOGGr5_CACR_EDS
# 186                                        EOGGr5_GLP_EDS
# 187                                   EOGMathGr5_CACR_All
# 188                                    EOGMathGr5_GLP_All
# 189                                EOGReadingGr5_CACR_All
# 190                                 EOGReadingGr5_GLP_All
# 191                                EOGScienceGr5_CACR_All
# 192                                 EOGScienceGr5_GLP_All
# 193                                    EOGGr5_CACR_Female
# 194                                     EOGGr5_GLP_Female
# 195                                EOGMathGr5_CACR_Female
# 196                                 EOGMathGr5_GLP_Female
# 197                              EOGReadingGr5_GLP_Female
# 198                             EOGScienceGr5_CACR_Female
# 199                              EOGScienceGr5_GLP_Female
# 200                                      EOGGr5_CACR_Male
# 201                                       EOGGr5_GLP_Male
# 202                                  EOGMathGr5_CACR_Male
# 203                                   EOGMathGr5_GLP_Male
# 204                                EOGReadingGr5_GLP_Male
# 205                               EOGScienceGr5_CACR_Male
# 206                                EOGScienceGr5_GLP_Male
# 207                                       EOGGr5_CACR_EDS
# 208                                        EOGGr5_GLP_EDS
# 209                                    EOGMathGr3_GLP_All
# 210                                EOGReadingGr3_CACR_All
# 211                                 EOGReadingGr3_GLP_All
# 212                                    EOGGr3_CACR_Female
# 213                                     EOGGr3_GLP_Female
# 214                                EOGMathGr3_CACR_Female
# 215                                 EOGMathGr3_GLP_Female
# 216                                      EOGGr3_CACR_Male
# 217                                       EOGGr3_GLP_Male
# 218                                  EOGMathGr3_CACR_Male
# 219                                   EOGMathGr3_GLP_Male
# 220                                EOGReadingGr3_GLP_Male
# 221                                       EOGGr3_CACR_EDS
# 222                                        EOGGr3_GLP_EDS
# 223                                        pct_PASSED_EOG
# 224                                EOGReadingGr3_CACR_All
# 225                                 EOGReadingGr3_GLP_All
# 226                                    EOGGr3_CACR_Female
# 227                                     EOGGr3_GLP_Female
# 228                                EOGMathGr3_CACR_Female
# 229                                 EOGMathGr3_GLP_Female
# 230                                      EOGGr3_CACR_Male
# 231                                       EOGGr3_GLP_Male
# 232                                  EOGMathGr3_CACR_Male
# 233                                   EOGMathGr3_GLP_Male
# 234                                EOGReadingGr3_GLP_Male
# 235                                       EOGGr3_CACR_EDS
# 236                                        EOGGr3_GLP_EDS
# 237                                        pct_PASSED_EOG
# 238                                          pct_PROMOTED
# 239                                  EOGMathGr3-8_GLP_All
# 240                              EOGReadingGr3-8_CACR_All
# 241                               EOGReadingGr3-8_GLP_All
# 242                                  EOGSubjects_CACR_All
# 243                                   EOGSubjects_GLP_All
# 244                              EOGMathGr3-8_CACR_Female
# 245                               EOGMathGr3-8_GLP_Female
# 246                               EOGSubjects_CACR_Female
# 247                                EOGSubjects_GLP_Female
# 248                                EOGMathGr3-8_CACR_Male
# 249                                 EOGMathGr3-8_GLP_Male
# 250                                 EOGSubjects_CACR_Male
# 251                                  EOGSubjects_GLP_Male
# 252                              EOGReadingGr3-8_CACR_All
# 253                               EOGReadingGr3-8_GLP_All
# 254                                  EOGSubjects_CACR_All
# 255                                   EOGSubjects_GLP_All
# 256                              EOGMathGr3-8_CACR_Female
# 257                               EOGMathGr3-8_GLP_Female
# 258                               EOGSubjects_CACR_Female
# 259                                EOGSubjects_GLP_Female
# 260                                EOGMathGr3-8_CACR_Male
# 261                                 EOGMathGr3-8_GLP_Male
# 262                              EOGReadingGr3-8_GLP_Male
# 263                                 EOGSubjects_CACR_Male
# 264                                  EOGSubjects_GLP_Male
# 265                                  EOGMathGr3-8_GLP_EDS
# 266                                  EOGSubjects_CACR_EDS
# 267                                   EOGSubjects_GLP_EDS
# 268                                    EOGMathGr4_GLP_All
# 269                                EOGReadingGr4_CACR_All
# 270                                 EOGReadingGr4_GLP_All
# 271                                    EOGGr4_CACR_Female
# 272                                     EOGGr4_GLP_Female
# 273                                EOGMathGr4_CACR_Female
# 274                                 EOGMathGr4_GLP_Female
# 275                                      EOGGr4_CACR_Male
# 276                                       EOGGr4_GLP_Male
# 277                                  EOGMathGr4_CACR_Male
# 278                                   EOGMathGr4_GLP_Male
# 279                                EOGReadingGr4_CACR_All
# 280                                 EOGReadingGr4_GLP_All
# 281                                    EOGGr4_CACR_Female
# 282                                     EOGGr4_GLP_Female
# 283                                EOGMathGr4_CACR_Female
# 284                                 EOGMathGr4_GLP_Female
# 285                                      EOGGr4_CACR_Male
# 286                                       EOGGr4_GLP_Male
# 287                                  EOGMathGr4_CACR_Male
# 288                                   EOGMathGr4_GLP_Male
# 289                                        EOGGr4_GLP_EDS
# 290                                    EOGMathGr5_GLP_All
# 291                                EOGReadingGr5_CACR_All
# 292                                 EOGReadingGr5_GLP_All
# 293                                EOGScienceGr5_CACR_All
# 294                                 EOGScienceGr5_GLP_All
# 295                                    EOGGr5_CACR_Female
# 296                                     EOGGr5_GLP_Female
# 297                                EOGMathGr5_CACR_Female
# 298                                 EOGMathGr5_GLP_Female
# 299                                      EOGGr5_CACR_Male
# 300                                       EOGGr5_GLP_Male
# 301                                  EOGMathGr5_CACR_Male
# 302                                   EOGMathGr5_GLP_Male
# 303                                       EOGGr5_CACR_EDS
# 304                                        EOGGr5_GLP_EDS
# 305                                EOGReadingGr5_CACR_All
# 306                                 EOGReadingGr5_GLP_All
# 307                                EOGScienceGr5_CACR_All
# 308                                 EOGScienceGr5_GLP_All
# 309                                    EOGGr5_CACR_Female
# 310                                     EOGGr5_GLP_Female
# 311                                EOGMathGr5_CACR_Female
# 312                                 EOGMathGr5_GLP_Female
# 313                              EOGReadingGr5_GLP_Female
# 314                                      EOGGr5_CACR_Male
# 315                                       EOGGr5_GLP_Male
# 316                                  EOGMathGr5_CACR_Male
# 317                                   EOGMathGr5_GLP_Male
# 318                               EOGScienceGr5_CACR_Male
# 319                                EOGScienceGr5_GLP_Male
# 320                                       EOGGr5_CACR_EDS
# 321                                        EOGGr5_GLP_EDS
# 322                                 EOGReadingGr3_GLP_All
# 323                                    EOGGr3_CACR_Female
# 324                                     EOGGr3_GLP_Female
# 325                             EOGReadingGr3_CACR_Female
# 326                              EOGReadingGr3_GLP_Female
# 327                                      EOGGr3_CACR_Male
# 328                                       EOGGr3_GLP_Male
# 329                               EOGReadingGr3_CACR_Male
# 330                                EOGReadingGr3_GLP_Male
# 331                                        pct_PASSED_EOG
# 332                                    EOGGr3_CACR_Female
# 333                                     EOGGr3_GLP_Female
# 334                             EOGReadingGr3_CACR_Female
# 335                              EOGReadingGr3_GLP_Female
# 336                                      EOGGr3_CACR_Male
# 337                                       EOGGr3_GLP_Male
# 338                                   EOGMathGr3_GLP_Male
# 339                               EOGReadingGr3_CACR_Male
# 340                                EOGReadingGr3_GLP_Male
# 341                                        EOGGr3_GLP_EDS
# 342                                        pct_PASSED_EOG
# 343                                          pct_PROMOTED
# 344                               EOGReadingGr3-8_GLP_All
# 345                                  EOGSubjects_CACR_All
# 346                                   EOGSubjects_GLP_All
# 347                           EOGReadingGr3-8_CACR_Female
# 348                            EOGReadingGr3-8_GLP_Female
# 349                               EOGSubjects_CACR_Female
# 350                                EOGSubjects_GLP_Female
# 351                             EOGReadingGr3-8_CACR_Male
# 352                              EOGReadingGr3-8_GLP_Male
# 353                                 EOGSubjects_CACR_Male
# 354                                  EOGSubjects_GLP_Male
# 355                                  EOGSubjects_CACR_All
# 356                                   EOGSubjects_GLP_All
# 357                               EOGMathGr3-8_GLP_Female
# 358                           EOGReadingGr3-8_CACR_Female
# 359                            EOGReadingGr3-8_GLP_Female
# 360                               EOGSubjects_CACR_Female
# 361                                EOGSubjects_GLP_Female
# 362                             EOGReadingGr3-8_CACR_Male
# 363                              EOGReadingGr3-8_GLP_Male
# 364                                 EOGSubjects_CACR_Male
# 365                                  EOGSubjects_GLP_Male
# 366                               EOGReadingGr3-8_GLP_EDS
# 367                                 EOGReadingGr4_GLP_All
# 368                                    EOGGr4_CACR_Female
# 369                                     EOGGr4_GLP_Female
# 370                             EOGReadingGr4_CACR_Female
# 371                              EOGReadingGr4_GLP_Female
# 372                                      EOGGr4_CACR_Male
# 373                                       EOGGr4_GLP_Male
# 374                               EOGReadingGr4_CACR_Male
# 375                                EOGReadingGr4_GLP_Male
# 376                                    EOGGr4_CACR_Female
# 377                                     EOGGr4_GLP_Female
# 378                             EOGReadingGr4_CACR_Female
# 379                              EOGReadingGr4_GLP_Female
# 380                                      EOGGr4_CACR_Male
# 381                                       EOGGr4_GLP_Male
# 382                               EOGReadingGr4_CACR_Male
# 383                                EOGReadingGr4_GLP_Male
# 384                                 EOGReadingGr5_GLP_All
# 385                                    EOGGr5_CACR_Female
# 386                                     EOGGr5_GLP_Female
# 387                             EOGReadingGr5_CACR_Female
# 388                              EOGReadingGr5_GLP_Female
# 389                                      EOGGr5_CACR_Male
# 390                                       EOGGr5_GLP_Male
# 391                               EOGReadingGr5_CACR_Male
# 392                                EOGReadingGr5_GLP_Male
# 393                                EOGScienceGr5_CACR_All
# 394                                 EOGScienceGr5_GLP_All
# 395                                    EOGGr5_CACR_Female
# 396                                     EOGGr5_GLP_Female
# 397                             EOGReadingGr5_CACR_Female
# 398                              EOGReadingGr5_GLP_Female
# 399                                      EOGGr5_CACR_Male
# 400                                       EOGGr5_GLP_Male
# 401                                   EOGMathGr5_GLP_Male
# 402                               EOGReadingGr5_CACR_Male
# 403                                EOGReadingGr5_GLP_Male
# 404                                 EOGScienceGr5_GLP_All
# 405                                    EOGGr5_CACR_Female
# 406                                     EOGGr5_GLP_Female
# 407                             EOGScienceGr5_CACR_Female
# 408                              EOGScienceGr5_GLP_Female
# 409                                      EOGGr5_CACR_Male
# 410                                       EOGGr5_GLP_Male
# 411                               EOGScienceGr5_CACR_Male
# 412                                EOGScienceGr5_GLP_Male
# 413                                       EOGGr5_CACR_EDS
# 414                                        EOGGr5_GLP_EDS
# 415                                    EOGGr5_CACR_Female
# 416                                     EOGGr5_GLP_Female
# 417                             EOGScienceGr5_CACR_Female
# 418                              EOGScienceGr5_GLP_Female
# 419                                      EOGGr5_CACR_Male
# 420                                       EOGGr5_GLP_Male
# 421                               EOGScienceGr5_CACR_Male
# 422                                EOGScienceGr5_GLP_Male
# 423                                       EOGGr5_CACR_EDS
# 424                                        EOGGr5_GLP_EDS
# 425                               EOGScienceGr5&8_GLP_All
# 426                           EOGScienceGr5&8_CACR_Female
# 427                            EOGScienceGr5&8_GLP_Female
# 428                             EOGScienceGr5&8_CACR_Male
# 429                              EOGScienceGr5&8_GLP_Male
# 430                           EOGScienceGr5&8_CACR_Female
# 431                            EOGScienceGr5&8_GLP_Female
# 432                             EOGScienceGr5&8_CACR_Male
# 433                              EOGScienceGr5&8_GLP_Male
# 434                                   EOGSubjects_GLP_All
# 435                              EOGMathGr3-8_CACR_Female
# 436                               EOGMathGr3-8_GLP_Female
# 437                           EOGReadingGr3-8_CACR_Female
# 438                            EOGReadingGr3-8_GLP_Female
# 439                               EOGSubjects_CACR_Female
# 440                                EOGSubjects_GLP_Female
# 441                                EOGMathGr3-8_CACR_Male
# 442                                 EOGMathGr3-8_GLP_Male
# 443                             EOGReadingGr3-8_CACR_Male
# 444                              EOGReadingGr3-8_GLP_Male
# 445                                 EOGSubjects_CACR_Male
# 446                                  EOGSubjects_GLP_Male
# 447                                  EOGSubjects_CACR_EDS
# 448                              EOGMathGr3-8_CACR_Female
# 449                               EOGMathGr3-8_GLP_Female
# 450                           EOGReadingGr3-8_CACR_Female
# 451                            EOGReadingGr3-8_GLP_Female
# 452                               EOGSubjects_CACR_Female
# 453                                EOGSubjects_GLP_Female
# 454                                EOGMathGr3-8_CACR_Male
# 455                                 EOGMathGr3-8_GLP_Male
# 456                             EOGReadingGr3-8_CACR_Male
# 457                              EOGReadingGr3-8_GLP_Male
# 458                                 EOGSubjects_CACR_Male
# 459                                  EOGSubjects_GLP_Male
# 460                               EOGReadingGr3-8_GLP_EDS
# 461                                  EOGSubjects_CACR_EDS
# 462                                   EOGSubjects_GLP_EDS
# 463                                   EOCMathI_GLP_Female
# 464                               EOCSubjects_CACR_Female
# 465                                EOCSubjects_GLP_Female
# 466                               EOCSubjects_CACR_Female
# 467                                EOCSubjects_GLP_Female
# 468                                EOCSubjects_GLP_Female
# 469                            EOG/EOCSubjects_GLP_Female
# 470                                     EOGGr3_GLP_Female
# 471                                EOGMathGr3_CACR_Female
# 472                                 EOGMathGr3_GLP_Female
# 473                             EOGReadingGr3_CACR_Female
# 474                              EOGReadingGr3_GLP_Female
# 475                                      EOGGr3_CACR_Male
# 476                                       EOGGr3_GLP_Male
# 477                                        pct_PASSED_EOG
# 478                                EOGMathGr3_CACR_Female
# 479                                 EOGMathGr3_GLP_Female
# 480                             EOGReadingGr3_CACR_Female
# 481                              EOGReadingGr3_GLP_Female
# 482                                      EOGGr3_CACR_Male
# 483                                       EOGGr3_GLP_Male
# 484                                   EOGMathGr3_GLP_Male
# 485                                        EOGGr3_GLP_EDS
# 486                                        pct_PASSED_EOG
# 487                                          pct_PROMOTED
# 488                                     EOGGr4_GLP_Female
# 489                                EOGMathGr4_CACR_Female
# 490                                 EOGMathGr4_GLP_Female
# 491                             EOGReadingGr4_CACR_Female
# 492                              EOGReadingGr4_GLP_Female
# 493                                      EOGGr4_CACR_Male
# 494                                       EOGGr4_GLP_Male
# 495                                EOGMathGr4_CACR_Female
# 496                                 EOGMathGr4_GLP_Female
# 497                             EOGReadingGr4_CACR_Female
# 498                              EOGReadingGr4_GLP_Female
# 499                                      EOGGr4_CACR_Male
# ...                                                   ...
# 219094             Unemployment compensation Amt 25KLT50K
# 219095             Unemployment compensation Amt 50KLT75K
# 219096            Unemployment compensation Amt 75KLT100K
# 219097                  Unemployment compensation Amt All
# 219098                Unemployment compensation Amt LT25K
# 219099            Unemployment compensation Ct 100KLT200K
# 219100              Unemployment compensation Ct 25KLT50K
# 219101              Unemployment compensation Ct 50KLT75K
# 219102             Unemployment compensation Ct 75KLT100K
# 219103                   Unemployment compensation Ct All
# 219104      volunteer prepared w Earned Income Credit All
# 219105    volunteer prepared w Earned Income Credit LT25K
# 219106                           Tot tax payments Amt All
# 219107                        Tot tax payments Amt GE200K
# 219108                     Tot tax payments Ct 100KLT200K
# 219109                       Tot tax payments Ct 25KLT50K
# 219110                       Tot tax payments Ct 50KLT75K
# 219111                      Tot tax payments Ct 75KLT100K
# 219112                            Tot tax payments Ct All
# 219113                         Tot tax payments Ct GE200K
# 219114                          Tot tax payments Ct LT25K
# 219115          Tuition and fees deduction Amt 100KLT200K
# 219116            Tuition and fees deduction Amt 25KLT50K
# 219117            Tuition and fees deduction Amt 50KLT75K
# 219118                 Tuition and fees deduction Amt All
# 219119               Tuition and fees deduction Amt LT25K
# 219120           Tuition and fees deduction Ct 100KLT200K
# 219121             Tuition and fees deduction Ct 25KLT50K
# 219122             Tuition and fees deduction Ct 50KLT75K
# 219123                  Tuition and fees deduction Ct All
# 219124                Tuition and fees deduction Ct LT25K
# 219125           Unemployment compensation Amt 100KLT200K
# 219126             Unemployment compensation Amt 25KLT50K
# 219127             Unemployment compensation Amt 50KLT75K
# 219128            Unemployment compensation Amt 75KLT100K
# 219129                  Unemployment compensation Amt All
# 219130            Unemployment compensation Ct 100KLT200K
# 219131              Unemployment compensation Ct 25KLT50K
# 219132              Unemployment compensation Ct 50KLT75K
# 219133             Unemployment compensation Ct 75KLT100K
# 219134                   Unemployment compensation Ct All
# 219135      volunteer prepared w Earned Income Credit All
# 219136    volunteer prepared w Earned Income Credit LT25K
# 219137                        Tot tax payments Amt GE200K
# 219138                         Tot tax payments Amt LT25K
# 219139                     Tot tax payments Ct 100KLT200K
# 219140                       Tot tax payments Ct 25KLT50K
# 219141                       Tot tax payments Ct 50KLT75K
# 219142                      Tot tax payments Ct 75KLT100K
# 219143                            Tot tax payments Ct All
# 219144                         Tot tax payments Ct GE200K
# 219145                          Tot tax payments Ct LT25K
# 219146            Tuition and fees deduction Amt 25KLT50K
# 219147            Tuition and fees deduction Amt 50KLT75K
# 219148                 Tuition and fees deduction Amt All
# 219149               Tuition and fees deduction Amt LT25K
# 219150             Tuition and fees deduction Ct 25KLT50K
# 219151             Tuition and fees deduction Ct 50KLT75K
# 219152                  Tuition and fees deduction Ct All
# 219153                Tuition and fees deduction Ct LT25K
# 219154           Unemployment compensation Amt 100KLT200K
# 219155             Unemployment compensation Amt 25KLT50K
# 219156             Unemployment compensation Amt 50KLT75K
# 219157            Unemployment compensation Amt 75KLT100K
# 219158                  Unemployment compensation Amt All
# 219159                Unemployment compensation Amt LT25K
# 219160            Unemployment compensation Ct 100KLT200K
# 219161              Unemployment compensation Ct 25KLT50K
# 219162              Unemployment compensation Ct 50KLT75K
# 219163             Unemployment compensation Ct 75KLT100K
# 219164                   Unemployment compensation Ct All
# 219165                       Tot tax payments Ct 25KLT50K
# 219166                       Tot tax payments Ct 50KLT75K
# 219167                            Tot tax payments Ct All
# 219168                         Tot tax payments Ct GE200K
# 219169                          Tot tax payments Ct LT25K
# 219170            Tuition and fees deduction Amt 25KLT50K
# 219171            Tuition and fees deduction Amt 50KLT75K
# 219172                 Tuition and fees deduction Amt All
# 219173             Tuition and fees deduction Ct 50KLT75K
# 219174             Unemployment compensation Amt 25KLT50K
# 219175             Unemployment compensation Amt 50KLT75K
# 219176            Unemployment compensation Amt 75KLT100K
# 219177                  Unemployment compensation Amt All
# 219178                Unemployment compensation Amt LT25K
# 219179            Unemployment compensation Ct 100KLT200K
# 219180              Unemployment compensation Ct 25KLT50K
# 219181              Unemployment compensation Ct 50KLT75K
# 219182             Unemployment compensation Ct 75KLT100K
# 219183                   Unemployment compensation Ct All
# 219184                       Tot tax payments Ct 25KLT50K
# 219185                       Tot tax payments Ct 50KLT75K
# 219186                            Tot tax payments Ct All
# 219187                          Tot tax payments Ct LT25K
# 219188            Tuition and fees deduction Amt 25KLT50K
# 219189             Tuition and fees deduction Ct 25KLT50K
# 219190             Unemployment compensation Amt 25KLT50K
# 219191             Unemployment compensation Amt 50KLT75K
# 219192                  Unemployment compensation Amt All
# 219193                Unemployment compensation Amt LT25K
# 219194              Unemployment compensation Ct 25KLT50K
# 219195              Unemployment compensation Ct 50KLT75K
# 219196                   Unemployment compensation Ct All
# 219197                 Unemployment compensation Ct LT25K
# 219198                       Tot tax payments Ct 25KLT50K
# 219199                       Tot tax payments Ct 50KLT75K
# 219200                      Tot tax payments Ct 75KLT100K
# 219201                            Tot tax payments Ct All
# 219202                         Tot tax payments Ct GE200K
# 219203          Tuition and fees deduction Amt 100KLT200K
# 219204            Tuition and fees deduction Amt 50KLT75K
# 219205                 Tuition and fees deduction Amt All
# 219206               Tuition and fees deduction Amt LT25K
# 219207           Tuition and fees deduction Ct 100KLT200K
# 219208             Tuition and fees deduction Ct 25KLT50K
# 219209             Tuition and fees deduction Ct 50KLT75K
# 219210                  Tuition and fees deduction Ct All
# 219211                Tuition and fees deduction Ct LT25K
# 219212           Unemployment compensation Amt 100KLT200K
# 219213             Unemployment compensation Amt 50KLT75K
# 219214            Unemployment compensation Amt 75KLT100K
# 219215                  Unemployment compensation Amt All
# 219216               Unemployment compensation Amt GE200K
# 219217            Unemployment compensation Ct 100KLT200K
# 219218              Unemployment compensation Ct 50KLT75K
# 219219             Unemployment compensation Ct 75KLT100K
# 219220                   Unemployment compensation Ct All
# 219221                Unemployment compensation Ct GE200K
# 219222  volunteer prepared w Earned Income Credit 25KL...
# 219223      volunteer prepared w Earned Income Credit All
# 219224                       Tot tax payments Ct 50KLT75K
# 219225                      Tot tax payments Ct 75KLT100K
# 219226                            Tot tax payments Ct All
# 219227                         Tot tax payments Ct GE200K
# 219228                          Tot tax payments Ct LT25K
# 219229            Tuition and fees deduction Amt 25KLT50K
# 219230            Tuition and fees deduction Amt 50KLT75K
# 219231                 Tuition and fees deduction Amt All
# 219232               Tuition and fees deduction Amt LT25K
# 219233             Tuition and fees deduction Ct 25KLT50K
# 219234             Tuition and fees deduction Ct 50KLT75K
# 219235                  Tuition and fees deduction Ct All
# 219236                Tuition and fees deduction Ct LT25K
# 219237             Unemployment compensation Amt 25KLT50K
# 219238             Unemployment compensation Amt 50KLT75K
# 219239            Unemployment compensation Amt 75KLT100K
# 219240                  Unemployment compensation Amt All
# 219241                Unemployment compensation Amt LT25K
# 219242              Unemployment compensation Ct 25KLT50K
# 219243              Unemployment compensation Ct 50KLT75K
# 219244             Unemployment compensation Ct 75KLT100K
# 219245                   Unemployment compensation Ct All
# 219246                 Unemployment compensation Ct LT25K
# 219247    volunteer prepared w Earned Income Credit LT25K
# 219248                      Tot tax payments Ct 75KLT100K
# 219249                            Tot tax payments Ct All
# 219250                         Tot tax payments Ct GE200K
# 219251                          Tot tax payments Ct LT25K
# 219252          Tuition and fees deduction Amt 100KLT200K
# 219253            Tuition and fees deduction Amt 25KLT50K
# 219254            Tuition and fees deduction Amt 50KLT75K
# 219255                 Tuition and fees deduction Amt All
# 219256               Tuition and fees deduction Amt LT25K
# 219257             Tuition and fees deduction Ct 25KLT50K
# 219258             Tuition and fees deduction Ct 50KLT75K
# 219259                  Tuition and fees deduction Ct All
# 219260                Tuition and fees deduction Ct LT25K
# 219261           Unemployment compensation Amt 100KLT200K
# 219262             Unemployment compensation Amt 25KLT50K
# 219263             Unemployment compensation Amt 50KLT75K
# 219264            Unemployment compensation Amt 75KLT100K
# 219265                  Unemployment compensation Amt All
# 219266                Unemployment compensation Amt LT25K
# 219267            Unemployment compensation Ct 100KLT200K
# 219268              Unemployment compensation Ct 25KLT50K
# 219269              Unemployment compensation Ct 50KLT75K
# 219270             Unemployment compensation Ct 75KLT100K
# 219271                   Unemployment compensation Ct All
# 219272      volunteer prepared w Earned Income Credit All
# 219273    volunteer prepared w Earned Income Credit LT25K
# 219274                            Tot tax payments Ct All
# 219275                         Tot tax payments Ct GE200K
# 219276                          Tot tax payments Ct LT25K
# 219277          Tuition and fees deduction Amt 100KLT200K
# 219278            Tuition and fees deduction Amt 25KLT50K
# 219279            Tuition and fees deduction Amt 50KLT75K
# 219280                 Tuition and fees deduction Amt All
# 219281               Tuition and fees deduction Amt LT25K
# 219282           Tuition and fees deduction Ct 100KLT200K
# 219283             Tuition and fees deduction Ct 25KLT50K
# 219284             Tuition and fees deduction Ct 50KLT75K
# 219285                  Tuition and fees deduction Ct All
# 219286                Tuition and fees deduction Ct LT25K
# 219287           Unemployment compensation Amt 100KLT200K
# 219288             Unemployment compensation Amt 25KLT50K
# 219289             Unemployment compensation Amt 50KLT75K
# 219290            Unemployment compensation Amt 75KLT100K
# 219291                  Unemployment compensation Amt All
# 219292            Unemployment compensation Ct 100KLT200K
# 219293              Unemployment compensation Ct 25KLT50K
# 219294              Unemployment compensation Ct 50KLT75K
# 219295             Unemployment compensation Ct 75KLT100K
# 219296                   Unemployment compensation Ct All
# 219297      volunteer prepared w Earned Income Credit All
# 219298    volunteer prepared w Earned Income Credit LT25K
# 219299                         Tot tax payments Ct GE200K
# 219300                          Tot tax payments Ct LT25K
# 219301          Tuition and fees deduction Amt 100KLT200K
# 219302            Tuition and fees deduction Amt 25KLT50K
# 219303            Tuition and fees deduction Amt 50KLT75K
# 219304                 Tuition and fees deduction Amt All
# 219305               Tuition and fees deduction Amt LT25K
# 219306             Tuition and fees deduction Ct 25KLT50K
# 219307             Tuition and fees deduction Ct 50KLT75K
# 219308                  Tuition and fees deduction Ct All
# 219309                Tuition and fees deduction Ct LT25K
# 219310           Unemployment compensation Amt 100KLT200K
# 219311             Unemployment compensation Amt 25KLT50K
# 219312             Unemployment compensation Amt 50KLT75K
# 219313            Unemployment compensation Amt 75KLT100K
# 219314                  Unemployment compensation Amt All
# 219315                Unemployment compensation Amt LT25K
# 219316            Unemployment compensation Ct 100KLT200K
# 219317              Unemployment compensation Ct 25KLT50K
# 219318              Unemployment compensation Ct 50KLT75K
# 219319             Unemployment compensation Ct 75KLT100K
# 219320                   Unemployment compensation Ct All
# 219321                 Unemployment compensation Ct LT25K
# 219322      volunteer prepared w Earned Income Credit All
# 219323    volunteer prepared w Earned Income Credit LT25K
# 219324          Tuition and fees deduction Amt 100KLT200K
# 219325            Tuition and fees deduction Amt 25KLT50K
# 219326            Tuition and fees deduction Amt 50KLT75K
# 219327                 Tuition and fees deduction Amt All
# 219328               Tuition and fees deduction Amt LT25K
# 219329           Tuition and fees deduction Ct 100KLT200K
# 219330             Tuition and fees deduction Ct 25KLT50K
# 219331             Tuition and fees deduction Ct 50KLT75K
# 219332                  Tuition and fees deduction Ct All
# 219333                Tuition and fees deduction Ct LT25K
# 219334           Unemployment compensation Amt 100KLT200K
# 219335             Unemployment compensation Amt 25KLT50K
# 219336             Unemployment compensation Amt 50KLT75K
# 219337            Unemployment compensation Amt 75KLT100K
# 219338                  Unemployment compensation Amt All
# 219339               Unemployment compensation Amt GE200K
# 219340            Unemployment compensation Ct 100KLT200K
# 219341              Unemployment compensation Ct 25KLT50K
# 219342              Unemployment compensation Ct 50KLT75K
# 219343             Unemployment compensation Ct 75KLT100K
# 219344                   Unemployment compensation Ct All
# 219345            Tuition and fees deduction Amt 25KLT50K
# 219346            Tuition and fees deduction Amt 50KLT75K
# 219347                 Tuition and fees deduction Amt All
# 219348               Tuition and fees deduction Amt LT25K
# 219349             Tuition and fees deduction Ct 25KLT50K
# 219350             Tuition and fees deduction Ct 50KLT75K
# 219351                  Tuition and fees deduction Ct All
# 219352                Tuition and fees deduction Ct LT25K
# 219353             Unemployment compensation Amt 25KLT50K
# 219354             Unemployment compensation Amt 50KLT75K
# 219355            Unemployment compensation Amt 75KLT100K
# 219356                  Unemployment compensation Amt All
# 219357                Unemployment compensation Amt LT25K
# 219358              Unemployment compensation Ct 25KLT50K
# 219359              Unemployment compensation Ct 50KLT75K
# 219360             Unemployment compensation Ct 75KLT100K
# 219361                   Unemployment compensation Ct All
# 219362                 Unemployment compensation Ct LT25K
# 219363    volunteer prepared w Earned Income Credit LT25K
# 219364            Tuition and fees deduction Amt 50KLT75K
# 219365                 Tuition and fees deduction Amt All
# 219366               Tuition and fees deduction Amt LT25K
# 219367           Tuition and fees deduction Ct 100KLT200K
# 219368             Tuition and fees deduction Ct 50KLT75K
# 219369                  Tuition and fees deduction Ct All
# 219370                Tuition and fees deduction Ct LT25K
# 219371           Unemployment compensation Amt 100KLT200K
# 219372            Unemployment compensation Amt 75KLT100K
# 219373               Unemployment compensation Amt GE200K
# 219374            Unemployment compensation Ct 100KLT200K
# 219375             Unemployment compensation Ct 75KLT100K
# 219376                Unemployment compensation Ct GE200K
# 219377  volunteer prepared w Earned Income Credit 25KL...
# ...
# 219376          Tuition and fees deduction Amt 100KLT200K     0.969534
# 219377          Tuition and fees deduction Amt 100KLT200K     0.958489
# 219378            Tuition and fees deduction Amt 25KLT50K     0.981983
# 219379            Tuition and fees deduction Amt 25KLT50K     0.979731
# 219380            Tuition and fees deduction Amt 25KLT50K     0.976431
# 219381            Tuition and fees deduction Amt 25KLT50K     0.996593
# 219382            Tuition and fees deduction Amt 25KLT50K     0.979089
# 219383            Tuition and fees deduction Amt 25KLT50K     0.976154
# 219384            Tuition and fees deduction Amt 25KLT50K     0.979336
# 219385            Tuition and fees deduction Amt 25KLT50K     0.984015
# 219386            Tuition and fees deduction Amt 25KLT50K     0.981541
# 219387            Tuition and fees deduction Amt 25KLT50K     0.978516
# 219388            Tuition and fees deduction Amt 25KLT50K     0.986310
# 219389            Tuition and fees deduction Amt 25KLT50K     0.976376
# 219390            Tuition and fees deduction Amt 25KLT50K     0.987241
# 219391            Tuition and fees deduction Amt 25KLT50K     0.981543
# 219392            Tuition and fees deduction Amt 25KLT50K     0.978295
# 219393            Tuition and fees deduction Amt 25KLT50K     0.988125
# 219394            Tuition and fees deduction Amt 25KLT50K     0.965361
# 219395            Tuition and fees deduction Amt 25KLT50K     0.950451
# 219396            Tuition and fees deduction Amt 50KLT75K     0.991402
# 219397            Tuition and fees deduction Amt 50KLT75K     0.983128
# 219398            Tuition and fees deduction Amt 50KLT75K     0.978988
# 219399            Tuition and fees deduction Amt 50KLT75K     0.998682
# 219400            Tuition and fees deduction Amt 50KLT75K     0.989036
# 219401            Tuition and fees deduction Amt 50KLT75K     0.984604
# 219402            Tuition and fees deduction Amt 50KLT75K     0.971360
# 219403            Tuition and fees deduction Amt 50KLT75K     0.982134
# 219404            Tuition and fees deduction Amt 50KLT75K     0.986715
# 219405            Tuition and fees deduction Amt 50KLT75K     0.985463
# 219406            Tuition and fees deduction Amt 50KLT75K     0.988122
# 219407            Tuition and fees deduction Amt 50KLT75K     0.956619
# 219408            Tuition and fees deduction Amt 50KLT75K     0.976203
# 219409            Tuition and fees deduction Amt 50KLT75K     0.980779
# 219410            Tuition and fees deduction Amt 50KLT75K     0.984832
# 219411            Tuition and fees deduction Amt 50KLT75K     0.982798
# 219412            Tuition and fees deduction Amt 50KLT75K     0.983982
# 219413           Tuition and fees deduction Amt 75KLT100K     0.992872
# 219414                 Tuition and fees deduction Amt All     0.996151
# 219415                 Tuition and fees deduction Amt All     0.967785
# 219416                 Tuition and fees deduction Amt All     0.980916
# 219417                 Tuition and fees deduction Amt All     0.994669
# 219418                 Tuition and fees deduction Amt All     0.998875
# 219419                 Tuition and fees deduction Amt All     0.996914
# 219420                 Tuition and fees deduction Amt All     0.970547
# 219421                 Tuition and fees deduction Amt All     0.965832
# 219422                 Tuition and fees deduction Amt All     0.977748
# 219423                 Tuition and fees deduction Amt All     0.981696
# 219424                 Tuition and fees deduction Amt All     0.975155
# 219425                 Tuition and fees deduction Amt All     0.972899
# 219426                 Tuition and fees deduction Amt All     0.969041
# 219427                 Tuition and fees deduction Amt All     0.979113
# 219428                 Tuition and fees deduction Amt All     0.982947
# 219429                 Tuition and fees deduction Amt All     0.973439
# 219430                 Tuition and fees deduction Amt All     0.962917
# 219431                 Tuition and fees deduction Amt All     0.961822
# 219432               Tuition and fees deduction Amt LT25K     0.974063
# 219433               Tuition and fees deduction Amt LT25K     0.985604
# 219434               Tuition and fees deduction Amt LT25K     0.992199
# 219435               Tuition and fees deduction Amt LT25K     0.998978
# 219436               Tuition and fees deduction Amt LT25K     0.950216
# 219437               Tuition and fees deduction Amt LT25K     0.957606
# 219438               Tuition and fees deduction Amt LT25K     0.967470
# 219439               Tuition and fees deduction Amt LT25K     0.968081
# 219440               Tuition and fees deduction Amt LT25K     0.965943
# 219441               Tuition and fees deduction Amt LT25K     0.952930
# 219442               Tuition and fees deduction Amt LT25K     0.962846
# 219443               Tuition and fees deduction Amt LT25K     0.969244
# 219444               Tuition and fees deduction Amt LT25K     0.970092
# 219445               Tuition and fees deduction Amt LT25K     0.967069
# 219446               Tuition and fees deduction Amt LT25K     0.965843
# 219447               Tuition and fees deduction Amt LT25K     0.967466
# 219448           Tuition and fees deduction Ct 100KLT200K     0.960865
# 219449           Tuition and fees deduction Ct 100KLT200K     0.976406
# 219450           Tuition and fees deduction Ct 100KLT200K     0.953353
# 219451           Tuition and fees deduction Ct 100KLT200K     0.980518
# 219452           Tuition and fees deduction Ct 100KLT200K     0.953269
# 219453           Tuition and fees deduction Ct 100KLT200K     0.969529
# 219454           Tuition and fees deduction Ct 100KLT200K     0.977001
# 219455           Tuition and fees deduction Ct 100KLT200K     0.957031
# 219456           Tuition and fees deduction Ct 100KLT200K     0.970683
# 219457           Tuition and fees deduction Ct 100KLT200K     0.959578
# 219458             Tuition and fees deduction Ct 25KLT50K     0.979219
# 219459             Tuition and fees deduction Ct 25KLT50K     0.980776
# 219460             Tuition and fees deduction Ct 25KLT50K     0.978772
# 219461             Tuition and fees deduction Ct 25KLT50K     0.979264
# 219462             Tuition and fees deduction Ct 25KLT50K     0.981484
# 219463             Tuition and fees deduction Ct 25KLT50K     0.983089
# 219464             Tuition and fees deduction Ct 25KLT50K     0.983769
# 219465             Tuition and fees deduction Ct 25KLT50K     0.965788
# 219466             Tuition and fees deduction Ct 25KLT50K     0.983119
# 219467             Tuition and fees deduction Ct 25KLT50K     0.982713
# 219468             Tuition and fees deduction Ct 25KLT50K     0.983297
# 219469             Tuition and fees deduction Ct 25KLT50K     0.984443
# 219470             Tuition and fees deduction Ct 25KLT50K     0.952457
# 219471             Tuition and fees deduction Ct 25KLT50K     0.954018
# 219472             Tuition and fees deduction Ct 50KLT75K     0.994096
# 219473             Tuition and fees deduction Ct 50KLT75K     0.987732
# 219474             Tuition and fees deduction Ct 50KLT75K     0.977172
# 219475             Tuition and fees deduction Ct 50KLT75K     0.976895
# 219476             Tuition and fees deduction Ct 50KLT75K     0.985660
# 219477             Tuition and fees deduction Ct 50KLT75K     0.987151
# 219478             Tuition and fees deduction Ct 50KLT75K     0.984840
# 219479             Tuition and fees deduction Ct 50KLT75K     0.980754
# 219480             Tuition and fees deduction Ct 50KLT75K     0.976644
# 219481             Tuition and fees deduction Ct 50KLT75K     0.984974
# 219482             Tuition and fees deduction Ct 50KLT75K     0.985668
# 219483             Tuition and fees deduction Ct 50KLT75K     0.980708
# 219484                  Tuition and fees deduction Ct All     0.994516
# 219485                  Tuition and fees deduction Ct All     0.976211
# 219486                  Tuition and fees deduction Ct All     0.963575
# 219487                  Tuition and fees deduction Ct All     0.978174
# 219488                  Tuition and fees deduction Ct All     0.984633
# 219489                  Tuition and fees deduction Ct All     0.974020
# 219490                  Tuition and fees deduction Ct All     0.977720
# 219491                  Tuition and fees deduction Ct All     0.966828
# 219492                  Tuition and fees deduction Ct All     0.980127
# 219493                  Tuition and fees deduction Ct All     0.986272
# 219494                  Tuition and fees deduction Ct All     0.971555
# 219495                  Tuition and fees deduction Ct All     0.964873
# 219496                  Tuition and fees deduction Ct All     0.962122
# 219497                Tuition and fees deduction Ct LT25K     0.954634
# 219498                Tuition and fees deduction Ct LT25K     0.964139
# 219499                Tuition and fees deduction Ct LT25K     0.974250
# 219500                Tuition and fees deduction Ct LT25K     0.975223
# 219501                Tuition and fees deduction Ct LT25K     0.972220
# 219502                Tuition and fees deduction Ct LT25K     0.957292
# 219503                Tuition and fees deduction Ct LT25K     0.969335
# 219504                Tuition and fees deduction Ct LT25K     0.976301
# 219505                Tuition and fees deduction Ct LT25K     0.977394
# 219506                Tuition and fees deduction Ct LT25K     0.973380
# 219507                Tuition and fees deduction Ct LT25K     0.968876
# 219508                Tuition and fees deduction Ct LT25K     0.970665
# 219509           Unemployment compensation Amt 100KLT200K     0.965579
# 219510           Unemployment compensation Amt 100KLT200K     0.974482
# 219511           Unemployment compensation Amt 100KLT200K     0.955743
# 219512           Unemployment compensation Amt 100KLT200K     0.977453
# 219513           Unemployment compensation Amt 100KLT200K     0.999468
# 219514           Unemployment compensation Amt 100KLT200K     0.963806
# 219515           Unemployment compensation Amt 100KLT200K     0.972921
# 219516           Unemployment compensation Amt 100KLT200K     0.975518
# 219517             Unemployment compensation Amt 25KLT50K     0.994786
# 219518             Unemployment compensation Amt 25KLT50K     0.983634
# 219519             Unemployment compensation Amt 25KLT50K     0.998518
# 219520             Unemployment compensation Amt 25KLT50K     0.986079
# 219521             Unemployment compensation Amt 25KLT50K     0.950972
# 219522             Unemployment compensation Amt 25KLT50K     0.998468
# 219523             Unemployment compensation Amt 25KLT50K     0.992435
# 219524             Unemployment compensation Amt 25KLT50K     0.980583
# 219525             Unemployment compensation Amt 25KLT50K     0.997622
# 219526             Unemployment compensation Amt 25KLT50K     0.972490
# 219527             Unemployment compensation Amt 50KLT75K     0.992733
# 219528             Unemployment compensation Amt 50KLT75K     0.997552
# 219529             Unemployment compensation Amt 50KLT75K     0.970063
# 219530             Unemployment compensation Amt 50KLT75K     0.970540
# 219531             Unemployment compensation Amt 50KLT75K     0.993649
# 219532             Unemployment compensation Amt 50KLT75K     0.998883
# 219533             Unemployment compensation Amt 50KLT75K     0.991286
# 219534             Unemployment compensation Amt 50KLT75K     0.994901
# 219535             Unemployment compensation Amt 50KLT75K     0.953723
# 219536            Unemployment compensation Amt 75KLT100K     0.989894
# 219537            Unemployment compensation Amt 75KLT100K     0.951840
# 219538            Unemployment compensation Amt 75KLT100K     0.977725
# 219539            Unemployment compensation Amt 75KLT100K     0.982603
# 219540            Unemployment compensation Amt 75KLT100K     0.992171
# 219541            Unemployment compensation Amt 75KLT100K     0.998812
# 219542            Unemployment compensation Amt 75KLT100K     0.984894
# 219543                  Unemployment compensation Amt All     0.981968
# 219544                  Unemployment compensation Amt All     0.962096
# 219545                  Unemployment compensation Amt All     0.997178
# 219546                  Unemployment compensation Amt All     0.995436
# 219547                  Unemployment compensation Amt All     0.987158
# 219548                  Unemployment compensation Amt All     0.998252
# 219549                  Unemployment compensation Amt All     0.966935
# 219550               Unemployment compensation Amt GE200K     0.973725
# 219551               Unemployment compensation Amt GE200K     0.999801
# 219552                Unemployment compensation Amt LT25K     0.986859
# 219553                Unemployment compensation Amt LT25K     0.967144
# 219554                Unemployment compensation Amt LT25K     0.986830
# 219555                Unemployment compensation Amt LT25K     0.995542
# 219556            Unemployment compensation Ct 100KLT200K     0.968696
# 219557            Unemployment compensation Ct 100KLT200K     0.975835
# 219558            Unemployment compensation Ct 100KLT200K     0.950716
# 219559            Unemployment compensation Ct 100KLT200K     0.971372
# 219560              Unemployment compensation Ct 25KLT50K     0.993400
# 219561              Unemployment compensation Ct 25KLT50K     0.981245
# 219562              Unemployment compensation Ct 25KLT50K     0.998985
# 219563              Unemployment compensation Ct 25KLT50K     0.976954
# 219564              Unemployment compensation Ct 50KLT75K     0.992262
# 219565              Unemployment compensation Ct 50KLT75K     0.994547
# 219566              Unemployment compensation Ct 50KLT75K     0.953072
# 219567             Unemployment compensation Ct 75KLT100K     0.983688
# 219568                   Unemployment compensation Ct All     0.977162
# 219569  volunteer prepared w Earned Income Credit 25KL...     0.979808
# 219570  volunteer prepared w Earned Income Credit 25KL...     0.964657
# 219571      volunteer prepared w Earned Income Credit All     0.997865
# 219572                                      category_cd_E     1.000000
# 219573                                      category_cd_H     0.997447
# 219574                                      category_cd_I     0.980910
# 219575                                      category_cd_M     0.996073
# 219576                                      category_cd_T     1.000000
# 219577                  calendar_type_txt_Hospital School     1.000000
# 219578                  calendar_type_txt_Hospital School     1.000000
# 219579  calendar_type_txt_Magnet School, Traditional C...     1.000000
# 219580  calendar_type_txt_Magnet School, Traditional C...     0.969176
# 219581  calendar_type_txt_Magnet School, Year-Round Ca...     1.000000
# 219582  calendar_type_txt_Regular School, Traditional ...     1.000000
# 219583  calendar_type_txt_Regular School, Traditional ...     1.000000
# 219584  calendar_type_txt_Regular School, Traditional ...     1.000000
# 219585  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 219586  calendar_type_txt_Regular School, Year-Round C...     0.965283
# 219587  calendar_type_txt_Special Education, Tradition...     1.000000
# 219588  calendar_type_txt_Special Education, Tradition...     1.000000
# 219589                                  sna_pgm_type_cd_H     1.000000
# 219590                                  sna_pgm_type_cd_M     0.969176
# 219591                                  sna_pgm_type_cd_S     1.000000
# 219592                                  sna_pgm_type_cd_X     1.000000
# 219593                                  sna_pgm_type_cd_Y     0.965283
#
# [219594 rows x 3 columns]

# %%
print ('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  1114  highly correlated fields.
# ['Math SPG Grade',
#  'Overall Achievement Score',
#  'Reading Score',
#  'Math Score',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_CACR_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_CACR_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_CACR_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_CACR_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_CACR_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_CACR_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_CACR_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr4_CACR_Female',
#  'EOGReadingGr4_GLP_Female',
#  'EOGReadingGr5_CACR_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_CACR_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_CACR_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_CACR_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_CACR_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_CACR_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr4_CACR_Male',
#  'EOGReadingGr4_GLP_Male',
#  'EOGReadingGr5_CACR_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_CACR_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_CACR_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_CACR_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGReadingGr5_CACR_AmericanIndian',
#  'EOGReadingGr5_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_CACR_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr3_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGReadingGr3_GLP_Black',
#  'EOGReadingGr3-8_GLP_Black',
#  'EOGReadingGr4_GLP_Black',
#  'EOGReadingGr5_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_GLP_Black',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_Hispanic',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGReadingGr3_GLP_Hispanic',
#  'EOGReadingGr3-8_GLP_Hispanic',
#  'EOGReadingGr4_GLP_Hispanic',
#  'EOGReadingGr5_GLP_Hispanic',
#  'EOGScienceGr5_CACR_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_CACR_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr3-8_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_CACR_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_CACR_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_CACR_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_CACR_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_CACR_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_CACR_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_CACR_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_CACR_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_CACR_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_CACR_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_CACR_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGReadingGr4_GLP_EDS',
#  'EOGReadingGr5_GLP_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_LEP',
#  'EOGGr3_GLP_LEP',
#  'EOGGr4_GLP_LEP',
#  'EOGGr5_GLP_LEP',
#  'EOGMathGr3_GLP_LEP',
#  'EOGMathGr3-8_GLP_LEP',
#  'EOGMathGr4_GLP_LEP',
#  'EOGMathGr5_GLP_LEP',
#  'EOGReadingGr3_GLP_LEP',
#  'EOGScienceGr5_GLP_LEP',
#  'EOGScienceGr5&8_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOGSubjects_GLP_LEP',
#  'EOCSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGGr3_GLP_SWD',
#  'EOGGr5_GLP_SWD',
#  'EOGMathGr3-8_GLP_SWD',
#  'EOGMathGr4_GLP_SWD',
#  'EOGMathGr5_GLP_SWD',
#  'EOGReadingGr3_GLP_SWD',
#  'EOGScienceGr5_GLP_SWD',
#  'EOGScienceGr5&8_GLP_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'pct_PROMOTED',
#  'ReadingGr3-8_pTarget_PctMet',
#  'st_short_susp_per_c_num',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'lea_not_highqual_class_all_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_class_teach_num',
#  'st_advance_dgr_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'Not Demostrated_TCHR_Standard 3_Pct',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'HispanicMalePct',
#  'BlackMalePct',
#  'WhiteMalePct',
#  'MinorityMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'HispanicFemalePct',
#  'BlackFemalePct',
#  'WhiteFemalePct',
#  'MinorityFemalePct',
#  'Assault Rate',
#  '(TCE) prepared returns Ct 50KLT75K',
#  '(TCE) prepared returns Ct All',
#  '(TCE) prepared returns Ct LT25K',
#  '(VITA) prepared returns Ct 75KLT100K',
#  '(VITA) prepared returns Ct All',
#  '(VITA) prepared returns Ct LT25K',
#  'Add Medicare tax Amt All',
#  'Add Medicare tax Amt GE200K',
#  'Add Medicare tax Ct 100KLT200K',
#  'Add Medicare tax Ct All',
#  'Add Medicare tax Ct GE200K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt 75KLT100K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Advance premium tax credit Amt 100KLT200K',
#  'Advance premium tax credit Amt 25KLT50K',
#  'Advance premium tax credit Amt 50KLT75K',
#  'Advance premium tax credit Amt 75KLT100K',
#  'Advance premium tax credit Amt All',
#  'Advance premium tax credit Amt LT25K',
#  'Advance premium tax credit Ct 100KLT200K',
#  'Advance premium tax credit Ct 25KLT50K',
#  'Advance premium tax credit Ct 50KLT75K',
#  'Advance premium tax credit Ct 75KLT100K',
#  'Advance premium tax credit Ct All',
#  'Advance premium tax credit Ct LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct 75KLT100K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Alternative minimum tax Ct LT25K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Contributions Amt 100KLT200K',
#  'Contributions Amt 25KLT50K',
#  'Contributions Amt 50KLT75K',
#  'Contributions Amt 75KLT100K',
#  'Contributions Amt All',
#  'Contributions Amt GE200K',
#  'Contributions Amt LT25K',
#  'Contributions Ct 100KLT200K',
#  'Contributions Ct 25KLT50K',
#  'Contributions Ct 50KLT75K',
#  'Contributions Ct 75KLT100K',
#  'Contributions Ct All',
#  'Contributions Ct GE200K',
#  'Contributions Ct LT25K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Ct 100KLT200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Domestic production activities deduction Ct LT25K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct 50KLT75K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess advance premium tax credit repayment Amt 100KLT200K',
#  'Excess advance premium tax credit repayment Amt 25KLT50K',
#  'Excess advance premium tax credit repayment Amt 50KLT75K',
#  'Excess advance premium tax credit repayment Amt 75KLT100K',
#  'Excess advance premium tax credit repayment Amt All',
#  'Excess advance premium tax credit repayment Amt LT25K',
#  'Excess advance premium tax credit repayment Ct 100KLT200K',
#  'Excess advance premium tax credit repayment Ct 25KLT50K',
#  'Excess advance premium tax credit repayment Ct 50KLT75K',
#  'Excess advance premium tax credit repayment Ct 75KLT100K',
#  'Excess advance premium tax credit repayment Ct All',
#  'Excess advance premium tax credit repayment Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct 50KLT75K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'Health care individual responsibility payment Amt 100KLT200K',
#  'Health care individual responsibility payment Amt 25KLT50K',
#  'Health care individual responsibility payment Amt 50KLT75K',
#  'Health care individual responsibility payment Amt 75KLT100K',
#  'Health care individual responsibility payment Amt All',
#  'Health care individual responsibility payment Amt LT25K',
#  'Health care individual responsibility payment Ct 100KLT200K',
#  'Health care individual responsibility payment Ct 25KLT50K',
#  'Health care individual responsibility payment Ct 50KLT75K',
#  'Health care individual responsibility payment Ct 75KLT100K',
#  'Health care individual responsibility payment Ct All',
#  'Health care individual responsibility payment Ct LT25K',
#  'IRA payments Amt 100KLT200K',
#  'IRA payments Amt 25KLT50K',
#  'IRA payments Amt 50KLT75K',
#  'IRA payments Amt 75KLT100K',
#  'IRA payments Amt All',
#  'IRA payments Amt GE200K',
#  'IRA payments Amt LT25K',
#  'IRA payments Ct 100KLT200K',
#  'IRA payments Ct 25KLT50K',
#  'IRA payments Ct 50KLT75K',
#  'IRA payments Ct 75KLT100K',
#  'IRA payments Ct All',
#  'IRA payments Ct GE200K',
#  'IRA payments Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Mortgage interest paid Amt 100KLT200K',
#  'Mortgage interest paid Amt 25KLT50K',
#  'Mortgage interest paid Amt 50KLT75K',
#  'Mortgage interest paid Amt 75KLT100K',
#  'Mortgage interest paid Amt All',
#  'Mortgage interest paid Amt GE200K',
#  'Mortgage interest paid Amt LT25K',
#  'Mortgage interest paid Ct 100KLT200K',
#  'Mortgage interest paid Ct 25KLT50K',
#  'Mortgage interest paid Ct 50KLT75K',
#  'Mortgage interest paid Ct 75KLT100K',
#  'Mortgage interest paid Ct All',
#  'Mortgage interest paid Ct GE200K',
#  'Mortgage interest paid Ct LT25K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct 100KLT200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Net premium tax credit Amt 25KLT50K',
#  'Net premium tax credit Amt 50KLT75K',
#  'Net premium tax credit Amt All',
#  'Net premium tax credit Amt LT25K',
#  'Net premium tax credit Ct 25KLT50K',
#  'Net premium tax credit Ct 50KLT75K',
#  'Net premium tax credit Ct All',
#  'Net premium tax credit Ct LT25K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of elderly returns 100KLT200K',
#  'Number of elderly returns 25KLT50K',
#  'Number of elderly returns 50KLT75K',
#  'Number of elderly returns 75KLT100K',
#  'Number of elderly returns All',
#  'Number of elderly returns GE200K',
#  'Number of elderly returns LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of refund anticipation check returns 100KLT200K',
#  'Number of refund anticipation check returns 25KLT50K',
#  'Number of refund anticipation check returns 50KLT75K',
#  'Number of refund anticipation check returns 75KLT100K',
#  'Number of refund anticipation check returns All',
#  'Number of refund anticipation check returns GE200K',
#  'Number of refund anticipation check returns LT25K',
#  'Number of refund anticipation loan returns 25KLT50K',
#  'Number of refund anticipation loan returns All',
#  'Number of refund anticipation loan returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  'Number of volunteer prepared returns Tot 100KLT200K',
#  'Number of volunteer prepared returns Tot 25KLT50K',
#  'Number of volunteer prepared returns Tot 75KLT100K',
#  'Number of volunteer prepared returns Tot All',
#  'Number of volunteer prepared returns Tot LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Residential energy tax credit Ct LT25K',
#  'Retirement savings contribution credit Amt 25KLT50K',
#  'Retirement savings contribution credit Amt 50KLT75K',
#  'Retirement savings contribution credit Amt All',
#  'Retirement savings contribution credit Amt LT25K',
#  'Retirement savings contribution credit Ct 25KLT50K',
#  'Retirement savings contribution credit Ct 50KLT75K',
#  'Retirement savings contribution credit Ct All',
#  'Retirement savings contribution credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employment health insurance deduction Amt 100KLT200K',
#  'Self-employment health insurance deduction Amt 25KLT50K',
#  'Self-employment health insurance deduction Amt 50KLT75K',
#  'Self-employment health insurance deduction Amt 75KLT100K',
#  'Self-employment health insurance deduction Amt All',
#  'Self-employment health insurance deduction Amt GE200K',
#  'Self-employment health insurance deduction Amt LT25K',
#  'Self-employment health insurance deduction Ct 100KLT200K',
#  'Self-employment health insurance deduction Ct 25KLT50K',
#  'Self-employment health insurance deduction Ct 50KLT75K',
#  'Self-employment health insurance deduction Ct 75KLT100K',
#  'Self-employment health insurance deduction Ct All',
#  'Self-employment health insurance deduction Ct GE200K',
#  'Self-employment health insurance deduction Ct LT25K',
#  'Self-employment retirement plans Amt 100KLT200K',
#  'Self-employment retirement plans Amt 25KLT50K',
#  'Self-employment retirement plans Amt 50KLT75K',
#  'Self-employment retirement plans Amt 75KLT100K',
#  'Self-employment retirement plans Amt All',
#  'Self-employment retirement plans Amt GE200K',
#  'Self-employment retirement plans Amt LT25K',
#  'Self-employment retirement plans Ct 100KLT200K',
#  'Self-employment retirement plans Ct 25KLT50K',
#  'Self-employment retirement plans Ct 50KLT75K',
#  'Self-employment retirement plans Ct 75KLT100K',
#  'Self-employment retirement plans Ct All',
#  'Self-employment retirement plans Ct GE200K',
#  'Self-employment retirement plans Ct LT25K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  'Taxable interest Ct 100KLT200K',
#  'Taxable interest Ct 25KLT50K',
#  'Taxable interest Ct 50KLT75K',
#  'Taxable interest Ct 75KLT100K',
#  'Taxable interest Ct All',
#  'Taxable interest Ct GE200K',
#  'Taxable interest Ct LT25K',
#  'Taxes paid Amt 100KLT200K',
#  'Taxes paid Amt 25KLT50K',
#  'Taxes paid Amt 50KLT75K',
#  'Taxes paid Amt 75KLT100K',
#  'Taxes paid Amt All',
#  'Taxes paid Amt GE200K',
#  'Taxes paid Amt LT25K',
#  'Taxes paid Ct 100KLT200K',
#  'Taxes paid Ct 25KLT50K',
#  'Taxes paid Ct 50KLT75K',
#  'Taxes paid Ct 75KLT100K',
#  'Taxes paid Ct All',
#  'Taxes paid Ct GE200K',
#  'Taxes paid Ct LT25K',
#  'Tot income Amt 100KLT200K',
#  'Tot income Amt 25KLT50K',
#  'Tot income Amt 50KLT75K',
#  'Tot income Amt 75KLT100K',
#  'Tot income Amt All',
#  'Tot income Amt GE200K',
#  'Tot income Amt LT25K',
#  'Tot income Ct 100KLT200K',
#  'Tot income Ct 25KLT50K',
#  'Tot income Ct 50KLT75K',
#  'Tot income Ct 75KLT100K',
#  'Tot income Ct All',
#  'Tot income Ct GE200K',
#  'Tot income Ct LT25K',
#  'Tot itemized deductions Amt 100KLT200K',
#  'Tot itemized deductions Amt 25KLT50K',
#  'Tot itemized deductions Amt 50KLT75K',
#  'Tot itemized deductions Amt 75KLT100K',
#  'Tot itemized deductions Amt All',
#  'Tot itemized deductions Amt GE200K',
#  'Tot itemized deductions Amt LT25K',
#  'Tot itemized deductions Amt of AGI 100KLT200K',
#  'Tot itemized deductions Amt of AGI 25KLT50K',
#  'Tot itemized deductions Amt of AGI 50KLT75K',
#  'Tot itemized deductions Amt of AGI 75KLT100K',
#  'Tot itemized deductions Amt of AGI All',
#  'Tot itemized deductions Amt of AGI GE200K',
#  'Tot itemized deductions Amt of AGI LT25K',
#  'Tot itemized deductions Ct 100KLT200K',
#  'Tot itemized deductions Ct 25KLT50K',
#  'Tot itemized deductions Ct 50KLT75K',
#  'Tot itemized deductions Ct 75KLT100K',
#  'Tot itemized deductions Ct All',
#  ...]

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Columns: 1485 entries, closed_ind to _1_to_1_access_Yes
# dtypes: float64(1426), uint8(59)
# memory usage: 26.6 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Columns: 371 entries, closed_ind to _1_to_1_access_Yes
# dtypes: float64(330), uint8(41)
# memory usage: 6.2 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2430 entries, 2 to 2598
# Data columns (total 372 columns):
# closed_ind                                                                         float64
# student_num                                                                        float64
# lea_avg_student_num                                                                float64
# st_avg_student_num                                                                 float64
# 00_Size                                                                            float64
# 01_Size                                                                            float64
# 02_Size                                                                            float64
# 03_Size                                                                            float64
# 04_Size                                                                            float64
# 05_Size                                                                            float64
# Math I_Size                                                                        float64
# lea_total_expense_num                                                              float64
# lea_salary_expense_pct                                                             float64
# lea_benefits_expense_pct                                                           float64
# lea_services_expense_pct                                                           float64
# lea_supplies_expense_pct                                                           float64
# lea_instruct_equip_exp_pct                                                         float64
# lea_federal_perpupil_num                                                           float64
# lea_local_perpupil_num                                                             float64
# lea_state_perpupil_num                                                             float64
# SPG Score                                                                          float64
# Reading SPG Grade                                                                  float64
# EVAAS Growth Score                                                                 float64
# Science Score                                                                      float64
# Math I Score                                                                       float64
# EOG/EOCSubjects_CACR_All                                                           float64
# EOGGr3_CACR_All                                                                    float64
# EOGGr4_CACR_All                                                                    float64
# EOGGr5_CACR_All                                                                    float64
# EOCMathI_CACR_Female                                                               float64
# EOCMathI_CACR_Male                                                                 float64
# EOCMathI_CACR_AmericanIndian                                                       float64
# EOCSubjects_CACR_AmericanIndian                                                    float64
# EOG/EOCSubjects_CACR_AmericanIndian                                                float64
# EOGGr3_CACR_AmericanIndian                                                         float64
# EOGGr4_CACR_AmericanIndian                                                         float64
# EOGGr5_CACR_AmericanIndian                                                         float64
# EOGMathGr3_CACR_AmericanIndian                                                     float64
# EOGMathGr3-8_CACR_AmericanIndian                                                   float64
# EOGMathGr4_CACR_AmericanIndian                                                     float64
# EOGMathGr5_CACR_AmericanIndian                                                     float64
# EOGReadingGr3-8_CACR_AmericanIndian                                                float64
# EOGScienceGr5_CACR_AmericanIndian                                                  float64
# EOGScienceGr5&8_CACR_AmericanIndian                                                float64
# EOGSubjects_CACR_AmericanIndian                                                    float64
# EOCMathI_CACR_Asian                                                                float64
# EOCSubjects_CACR_Asian                                                             float64
# EOG/EOCSubjects_CACR_Asian                                                         float64
# EOGGr3_CACR_Asian                                                                  float64
# EOGGr4_CACR_Asian                                                                  float64
# EOGGr5_CACR_Asian                                                                  float64
# EOGMathGr3_CACR_Asian                                                              float64
# EOGMathGr3-8_CACR_Asian                                                            float64
# EOGMathGr4_CACR_Asian                                                              float64
# EOGMathGr5_CACR_Asian                                                              float64
# EOGScienceGr5&8_CACR_Asian                                                         float64
# EOGSubjects_CACR_Asian                                                             float64
# EOCMathI_CACR_Black                                                                float64
# EOCSubjects_CACR_Black                                                             float64
# EOG/EOCSubjects_CACR_Black                                                         float64
# EOGGr3_CACR_Black                                                                  float64
# EOGGr4_CACR_Black                                                                  float64
# EOGGr5_CACR_Black                                                                  float64
# EOGMathGr3_CACR_Black                                                              float64
# EOGMathGr3-8_CACR_Black                                                            float64
# EOGMathGr4_CACR_Black                                                              float64
# EOGMathGr5_CACR_Black                                                              float64
# EOGReadingGr3_CACR_Black                                                           float64
# EOGReadingGr3-8_CACR_Black                                                         float64
# EOGReadingGr4_CACR_Black                                                           float64
# EOGReadingGr5_CACR_Black                                                           float64
# EOGScienceGr5_CACR_Black                                                           float64
# EOGScienceGr5&8_CACR_Black                                                         float64
# EOGSubjects_CACR_Black                                                             float64
# EOCMathI_CACR_Hispanic                                                             float64
# EOCSubjects_CACR_Hispanic                                                          float64
# EOG/EOCSubjects_CACR_Hispanic                                                      float64
# EOGGr3_CACR_Hispanic                                                               float64
# EOGGr4_CACR_Hispanic                                                               float64
# EOGGr5_CACR_Hispanic                                                               float64
# EOGMathGr3_CACR_Hispanic                                                           float64
# EOGMathGr3-8_CACR_Hispanic                                                         float64
# EOGMathGr4_CACR_Hispanic                                                           float64
# EOGMathGr5_CACR_Hispanic                                                           float64
# EOGReadingGr3_CACR_Hispanic                                                        float64
# EOGReadingGr3-8_CACR_Hispanic                                                      float64
# EOGReadingGr4_CACR_Hispanic                                                        float64
# EOGReadingGr5_CACR_Hispanic                                                        float64
# EOGScienceGr5&8_CACR_Hispanic                                                      float64
# EOGSubjects_CACR_Hispanic                                                          float64
# EOCMathI_CACR_TwoorMoreRaces                                                       float64
# EOCSubjects_CACR_TwoorMoreRaces                                                    float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                                                float64
# EOGGr3_CACR_TwoorMoreRaces                                                         float64
# EOGGr4_CACR_TwoorMoreRaces                                                         float64
# EOGGr5_CACR_TwoorMoreRaces                                                         float64
# EOGMathGr3_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                                                   float64
# EOGMathGr4_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr5_CACR_TwoorMoreRaces                                                     float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                                                float64
# EOGReadingGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                                                float64
# EOGSubjects_CACR_TwoorMoreRaces                                                    float64
# EOCMathI_CACR_White                                                                float64
# EOG/EOCSubjects_CACR_White                                                         float64
# EOGGr3_CACR_White                                                                  float64
# EOGGr4_CACR_White                                                                  float64
# EOGGr5_CACR_White                                                                  float64
# EOGMathGr3_CACR_White                                                              float64
# EOGMathGr3-8_CACR_White                                                            float64
# EOGMathGr4_CACR_White                                                              float64
# EOGMathGr5_CACR_White                                                              float64
# EOGScienceGr5&8_CACR_White                                                         float64
# EOCMathI_CACR_EDS                                                                  float64
# EOG/EOCSubjects_CACR_EDS                                                           float64
# EOGGr4_CACR_EDS                                                                    float64
# EOGMathGr3_CACR_EDS                                                                float64
# EOGMathGr3-8_CACR_EDS                                                              float64
# EOGMathGr4_CACR_EDS                                                                float64
# EOGMathGr5_CACR_EDS                                                                float64
# EOGReadingGr3_CACR_EDS                                                             float64
# EOGReadingGr3-8_CACR_EDS                                                           float64
# EOGReadingGr4_CACR_EDS                                                             float64
# EOGReadingGr5_CACR_EDS                                                             float64
# EOGScienceGr5_CACR_EDS                                                             float64
# EOGScienceGr5&8_CACR_EDS                                                           float64
# EOCMathI_CACR_LEP                                                                  float64
# EOCMathI_GLP_LEP                                                                   float64
# EOCSubjects_CACR_LEP                                                               float64
# EOCSubjects_GLP_LEP                                                                float64
# EOG/EOCSubjects_CACR_LEP                                                           float64
# EOGGr3_CACR_LEP                                                                    float64
# EOGGr4_CACR_LEP                                                                    float64
# EOGGr5_CACR_LEP                                                                    float64
# EOGMathGr3_CACR_LEP                                                                float64
# EOGMathGr3-8_CACR_LEP                                                              float64
# EOGMathGr4_CACR_LEP                                                                float64
# EOGMathGr5_CACR_LEP                                                                float64
# EOGReadingGr3_CACR_LEP                                                             float64
# EOGReadingGr3-8_CACR_LEP                                                           float64
# EOGReadingGr3-8_GLP_LEP                                                            float64
# EOGReadingGr4_CACR_LEP                                                             float64
# EOGReadingGr4_GLP_LEP                                                              float64
# EOGReadingGr5_CACR_LEP                                                             float64
# EOGReadingGr5_GLP_LEP                                                              float64
# EOGScienceGr5_CACR_LEP                                                             float64
# EOGScienceGr5&8_CACR_LEP                                                           float64
# EOCMathI_CACR_SWD                                                                  float64
# EOCMathI_GLP_SWD                                                                   float64
# EOCSubjects_CACR_SWD                                                               float64
# EOG/EOCSubjects_CACR_SWD                                                           float64
# EOGGr3_CACR_SWD                                                                    float64
# EOGGr4_CACR_SWD                                                                    float64
# EOGGr4_GLP_SWD                                                                     float64
# EOGGr5_CACR_SWD                                                                    float64
# EOGMathGr3_CACR_SWD                                                                float64
# EOGMathGr3_GLP_SWD                                                                 float64
# EOGMathGr3-8_CACR_SWD                                                              float64
# EOGMathGr4_CACR_SWD                                                                float64
# EOGMathGr5_CACR_SWD                                                                float64
# EOGReadingGr3_CACR_SWD                                                             float64
# EOGReadingGr3-8_CACR_SWD                                                           float64
# EOGReadingGr3-8_GLP_SWD                                                            float64
# EOGReadingGr4_CACR_SWD                                                             float64
# EOGReadingGr4_GLP_SWD                                                              float64
# EOGReadingGr5_CACR_SWD                                                             float64
# EOGReadingGr5_GLP_SWD                                                              float64
# EOGScienceGr5_CACR_SWD                                                             float64
# EOGScienceGr5&8_CACR_SWD                                                           float64
# EOGSubjects_CACR_SWD                                                               float64
# EOCMathI_CACR_AIG                                                                  float64
# EOCSubjects_CACR_AIG                                                               float64
# EOG/EOCSubjects_CACR_AIG                                                           float64
# EOGGr3_CACR_AIG                                                                    float64
# EOGGr4_CACR_AIG                                                                    float64
# EOGGr5_CACR_AIG                                                                    float64
# EOGMathGr3_CACR_AIG                                                                float64
# EOGMathGr3-8_CACR_AIG                                                              float64
# EOGMathGr4_CACR_AIG                                                                float64
# EOGMathGr5_CACR_AIG                                                                float64
# EOGScienceGr5&8_CACR_AIG                                                           float64
# EOGSubjects_CACR_AIG                                                               float64
# pct_GCE_ALL                                                                        float64
# MathGr3-8_pTarget_PctMet                                                           float64
# SciGr5&8_pTarget_PctMet                                                            float64
# TotalTargets_pTarget_PctMet                                                        float64
# lea_sat_avg_score_num                                                              float64
# lea_sat_participation_pct                                                          float64
# lea_ap_participation_pct                                                           float64
# lea_ap_pct_3_or_above                                                              float64
# lea_ib_pct_4_or_above                                                              float64
# avg_daily_attend_pct                                                               float64
# crime_per_c_num                                                                    float64
# short_susp_per_c_num                                                               float64
# long_susp_per_c_num                                                                float64
# expelled_per_c_num                                                                 float64
# stud_internet_comp_num                                                             float64
# lea_avg_daily_attend_pct                                                           float64
# lea_crime_per_c_num                                                                float64
# lea_short_susp_per_c_num                                                           float64
# lea_long_susp_per_c_num                                                            float64
# lea_expelled_per_c_num                                                             float64
# lea_stud_internet_comp_num                                                         float64
# st_avg_daily_attend_pct                                                            float64
# st_crime_per_c_num                                                                 float64
# st_long_susp_per_c_num                                                             float64
# digital_media_pct                                                                  float64
# avg_age_media_collection                                                           float64
# books_per_student                                                                  float64
# lea_avg_age_media_collection                                                       float64
# lea_books_per_student                                                              float64
# wap_num                                                                            float64
# wap_per_classroom                                                                  float64
# lea_wap_num                                                                        float64
# lea_wap_per_classroom                                                              float64
# flicensed_teach_pct                                                                float64
# tchyrs_0thru3_pct                                                                  float64
# tchyrs_4thru10_pct                                                                 float64
# tchyrs_11plus_pct                                                                  float64
# nbpts_num                                                                          float64
# advance_dgr_pct                                                                    float64
# _1yr_tchr_trnovr_pct                                                               float64
# lateral_teach_pct                                                                  float64
# highqual_class_pct                                                                 float64
# lea_flicensed_teach_pct                                                            float64
# lea_tchyrs_0thru3_pct                                                              float64
# lea_tchyrs_4thru10_pct                                                             float64
# lea_tchyrs_11plus_pct                                                              float64
# lea_nbpts_num                                                                      float64
# lea_advance_dgr_pct                                                                float64
# lea_1yr_tchr_trnovr_pct                                                            float64
# lea_emer_prov_teach_pct                                                            float64
# lea_highqual_class_pct                                                             float64
# lea_highqual_class_hp_pct                                                          float64
# lea_highqual_class_lp_pct                                                          float64
# lea_highqual_class_all_pct                                                         float64
# lea_not_highqual_class_hp_pct                                                      float64
# lea_not_highqual_class_lp_pct                                                      float64
# st_flicensed_teach_pct                                                             float64
# st_tchyrs_0thru3_pct                                                               float64
# st_tchyrs_11plus_pct                                                               float64
# st_nbpts_num                                                                       float64
# st_1yr_tchr_trnovr_pct                                                             float64
# st_emer_prov_teach_pct                                                             float64
# st_highqual_class_pct                                                              float64
# 0-3 Years_LEA_Exp_Pct_Prin                                                         float64
# 10+ Years_LEA_Exp_Pct_Prin                                                         float64
# 4-10 Years_LEA_Exp_Pct_Prin                                                        float64
# Accomplished_TCHR_Standard 1_Pct                                                   float64
# Accomplished_TCHR_Standard 2_Pct                                                   float64
# Accomplished_TCHR_Standard 3_Pct                                                   float64
# Accomplished_TCHR_Standard 4_Pct                                                   float64
# Accomplished_TCHR_Standard 5_Pct                                                   float64
# Developing_TCHR_Standard 1_Pct                                                     float64
# Developing_TCHR_Standard 2_Pct                                                     float64
# Developing_TCHR_Standard 3_Pct                                                     float64
# Developing_TCHR_Standard 4_Pct                                                     float64
# Developing_TCHR_Standard 5_Pct                                                     float64
# Distinguished_TCHR_Standard 1_Pct                                                  float64
# Distinguished_TCHR_Standard 2_Pct                                                  float64
# Distinguished_TCHR_Standard 3_Pct                                                  float64
# Distinguished_TCHR_Standard 4_Pct                                                  float64
# Distinguished_TCHR_Standard 5_Pct                                                  float64
# Does Not Meet Expected Growth_TCHR_Student Growth_Pct                              float64
# Exceeds Expected Growth_TCHR_Student Growth_Pct                                    float64
# Meets Expected Growth_TCHR_Student Growth_Pct                                      float64
# Not Demostrated_TCHR_Standard 1_Pct                                                float64
# Not Demostrated_TCHR_Standard 2_Pct                                                float64
# Not Demostrated_TCHR_Standard 4_Pct                                                float64
# Not Demostrated_TCHR_Standard 5_Pct                                                float64
# Proficient_TCHR_Standard 1_Pct                                                     float64
# Proficient_TCHR_Standard 2_Pct                                                     float64
# Proficient_TCHR_Standard 3_Pct                                                     float64
# Proficient_TCHR_Standard 4_Pct                                                     float64
# Proficient_TCHR_Standard 5_Pct                                                     float64
# IndianPct                                                                          float64
# AsianPct                                                                           float64
# HispanicPct                                                                        float64
# BlackPct                                                                           float64
# WhitePct                                                                           float64
# PacificIslandPct                                                                   float64
# TwoOrMorePct                                                                       float64
# PacificIslandMalePct                                                               float64
# TwoOrMoreMalePct                                                                   float64
# PacificIslandFemalePct                                                             float64
# TwoOrMoreFemalePct                                                                 float64
# Year                                                                               float64
# Violent Rate                                                                       float64
# Murder Rate                                                                        float64
# Rape Rate                                                                          float64
# Robbery Rate                                                                       float64
# MVT Rate                                                                           float64
# Arson Rate                                                                         float64
# (TCE) prepared returns Ct 100KLT200K                                               float64
# (TCE) prepared returns Ct 25KLT50K                                                 float64
# (TCE) prepared returns Ct 75KLT100K                                                float64
# (VITA) prepared returns Ct 100KLT200K                                              float64
# (VITA) prepared returns Ct 25KLT50K                                                float64
# (VITA) prepared returns Ct 50KLT75K                                                float64
# Add Medicare tax Amt 100KLT200K                                                    float64
# Add child tax credit Amt 25KLT50K                                                  float64
# Alternative minimum tax Amt 25KLT50K                                               float64
# Alternative minimum tax Amt 50KLT75K                                               float64
# Alternative minimum tax Amt 75KLT100K                                              float64
# Alternative minimum tax Amt LT25K                                                  float64
# Alternative minimum tax Ct 50KLT75K                                                float64
# Domestic production activities deduction Amt 100KLT200K                            float64
# Domestic production activities deduction Amt 25KLT50K                              float64
# Domestic production activities deduction Amt 50KLT75K                              float64
# Domestic production activities deduction Amt 75KLT100K                             float64
# Domestic production activities deduction Amt LT25K                                 float64
# Domestic production activities deduction Ct 25KLT50K                               float64
# Domestic production activities deduction Ct 50KLT75K                               float64
# Domestic production activities deduction Ct 75KLT100K                              float64
# Earned income credit Amt 50KLT75K                                                  float64
# Excess earned income credit (refundable) Amt 50KLT75K                              float64
# Net investment income tax Amt 100KLT200K                                           float64
# Number of farm returns 100KLT200K                                                  float64
# Number of farm returns 25KLT50K                                                    float64
# Number of farm returns 50KLT75K                                                    float64
# Number of farm returns 75KLT100K                                                   float64
# Number of farm returns All                                                         float64
# Number of farm returns GE200K                                                      float64
# Number of farm returns LT25K                                                       float64
# Number of volunteer prepared returns Tot 50KLT75K                                  float64
# Partnership/S-corp net income (less loss) Amt LT25K                                float64
# Residential energy tax credit Amt LT25K                                            float64
# State and local general sales taxes Amt GE200K                                     float64
# Tuition and fees deduction Amt 75KLT100K                                           float64
# category_cd_E                                                                      uint8
# category_cd_I                                                                      uint8
# category_cd_M                                                                      uint8
# category_cd_T                                                                      uint8
# calendar_type_txt_Hospital School                                                  uint8
# calendar_type_txt_Magnet School, Traditional Calendar                              uint8
# calendar_type_txt_Magnet School, Year-Round Calendar                               uint8
# calendar_type_txt_Regular School, Traditional Calendar                             uint8
# calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar    uint8
# calendar_type_txt_Regular School, Year-Round Calendar                              uint8
# calendar_type_txt_Special Education, Traditional Calendar                          uint8
# school_type_txt_Regular School                                                     uint8
# esea_status_P                                                                      uint8
# Grad_project_status_Y                                                              uint8
# State Board Region_Northeast Region                                                uint8
# State Board Region_Northwest Region                                                uint8
# State Board Region_Piedmont Triad Region                                           uint8
# State Board Region_SandHills Region                                                uint8
# State Board Region_Southeast Region                                                uint8
# State Board Region_Southwest Region                                                uint8
# State Board Region_Western Region                                                  uint8
# SPG Grade_A+NG                                                                     uint8
# SPG Grade_B                                                                        uint8
# SPG Grade_C                                                                        uint8
# SPG Grade_D                                                                        uint8
# SPG Grade_F                                                                        uint8
# SPG Grade_I                                                                        uint8
# Reading SPG Score_B                                                                uint8
# Reading SPG Score_C                                                                uint8
# Reading SPG Score_D                                                                uint8
# Reading SPG Score_F                                                                uint8
# Math SPG Score_B                                                                   uint8
# Math SPG Score_C                                                                   uint8
# Math SPG Score_D                                                                   uint8
# Math SPG Score_F                                                                   uint8
# EVAAS Growth Status_Met                                                            uint8
# EVAAS Growth Status_NotMet                                                         uint8
# State Gap Compared_Y                                                               uint8
# Byod_No                                                                            uint8
# Byod_Yes                                                                           uint8
# _1_to_1_access_Yes                                                                 uint8
# unit_code                                                                          object
# dtypes: float64(330), object(1), uint8(41)
# memory usage: 6.3+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.1
# Pandas Version: 0.24.2

# %%
print ('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2016/Machine Learning Datasets/PublicSchools2016_ML.csv
