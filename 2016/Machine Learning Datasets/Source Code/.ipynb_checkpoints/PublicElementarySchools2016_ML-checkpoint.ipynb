# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2016

#Location where copies of the raw data files will be read in from csv files.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2016'
#inputFileName = 'PublicHighSchools2016'
#inputFileName = 'PublicMiddleSchools2016'
inputFileName = 'PublicElementarySchools2016'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1291 entries, 0 to 1290
# Columns: 2158 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2112), int64(3), object(43)
# memory usage: 21.3+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Columns: 2158 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2112), int64(3), object(43)
# memory usage: 21.3+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print ('Rows Updated / Imputed: ', rowsUpdated )
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Columns: 1950 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1910), object(40)
# memory usage: 19.2+ MB
#
# Columns Deleted:  208

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Columns: 1947 entries, street_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1910), object(37)
# memory usage: 19.2+ MB
#
# Columns Deleted:  3

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print( '\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Columns: 1947 entries, street_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1910), object(37)
# memory usage: 19.2+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print("Boolean Columns: ", sD_boolean.shape[1])
print( "Nominal Columns: ", sD_nominal.shape[1])
print( "Continuous Columns: ", sD_continuous.shape[1])
print( "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  37
# Continuous Columns:  1910
# Columns Accounted for:  1947

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Columns: 1405 entries, street_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1368), object(37)
# memory usage: 13.8+ MB
#
# Columns Deleted:  542

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Columns: 1389 entries, category_cd to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1368), object(21)
# memory usage: 13.7+ MB
#
# Columns Deleted:  16

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print ('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print ('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  21
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Columns: 1422 entries, student_num to grades_1_to_1_access_PK
# dtypes: float64(1368), uint8(54)
# memory usage: 13.6 MB
#
# New Columns Created Via One-Hot Encoding:  33

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 3                                              00_Size                     83
# 4                                              01_Size                     86
# 5                                              02_Size                     86
# 6                                              03_Size                     85
# 7                                              04_Size                     74
# 8                                              05_Size                    134
# 18                                           SPG Score                     33
# 19                                   Reading SPG Grade                     33
# 20                                      Math SPG Grade                     33
# 21                                  EVAAS Growth Score                     33
# 22                           Overall Achievement Score                     33
# 23                                       Reading Score                     33
# 24                                          Math Score                     33
# 25                                       Science Score                    116
# 26                            EOG/EOCSubjects_CACR_All                     33
# 27                             EOG/EOCSubjects_GLP_All                     33
# 28                                     EOGGr3_CACR_All                     51
# 29                                      EOGGr3_GLP_All                     51
# 30                                     EOGGr4_CACR_All                     55
# 31                                      EOGGr4_GLP_All                     55
# 32                                     EOGGr5_CACR_All                    116
# 33                                      EOGGr5_GLP_All                    116
# 34                                 EOGMathGr3_CACR_All                     52
# 35                                  EOGMathGr3_GLP_All                     52
# 36                               EOGMathGr3-8_CACR_All                     33
# 37                                EOGMathGr3-8_GLP_All                     33
# 38                                 EOGMathGr4_CACR_All                     58
# 39                                  EOGMathGr4_GLP_All                     58
# 40                                 EOGMathGr5_CACR_All                    119
# 41                                  EOGMathGr5_GLP_All                    119
# 42                              EOGReadingGr3_CACR_All                     52
# 43                               EOGReadingGr3_GLP_All                     52
# 44                            EOGReadingGr3-8_CACR_All                     33
# 45                             EOGReadingGr3-8_GLP_All                     33
# 46                              EOGReadingGr4_CACR_All                     58
# 47                               EOGReadingGr4_GLP_All                     58
# 48                              EOGReadingGr5_CACR_All                    119
# 49                               EOGReadingGr5_GLP_All                    119
# 50                              EOGScienceGr5_CACR_All                    119
# 51                               EOGScienceGr5_GLP_All                    119
# 52                            EOGScienceGr5&8_CACR_All                    118
# 53                             EOGScienceGr5&8_GLP_All                    118
# 54                                EOGSubjects_CACR_All                     33
# 55                                 EOGSubjects_GLP_All                     33
# 56                         EOG/EOCSubjects_CACR_Female                     33
# 57                          EOG/EOCSubjects_GLP_Female                     33
# 58                                  EOGGr3_CACR_Female                     51
# 59                                   EOGGr3_GLP_Female                     51
# 60                                  EOGGr4_CACR_Female                     55
# 61                                   EOGGr4_GLP_Female                     55
# 62                                  EOGGr5_CACR_Female                    116
# 63                                   EOGGr5_GLP_Female                    116
# 64                              EOGMathGr3_CACR_Female                     52
# 65                               EOGMathGr3_GLP_Female                     52
# 66                            EOGMathGr3-8_CACR_Female                     33
# 67                             EOGMathGr3-8_GLP_Female                     33
# 68                              EOGMathGr4_CACR_Female                     58
# 69                               EOGMathGr4_GLP_Female                     58
# 70                              EOGMathGr5_CACR_Female                    119
# 71                               EOGMathGr5_GLP_Female                    119
# 72                           EOGReadingGr3_CACR_Female                     52
# 73                            EOGReadingGr3_GLP_Female                     52
# 74                         EOGReadingGr3-8_CACR_Female                     33
# 75                          EOGReadingGr3-8_GLP_Female                     33
# 76                           EOGReadingGr4_CACR_Female                     58
# 77                            EOGReadingGr4_GLP_Female                     58
# 78                           EOGReadingGr5_CACR_Female                    119
# 79                            EOGReadingGr5_GLP_Female                    119
# 80                           EOGScienceGr5_CACR_Female                    119
# 81                            EOGScienceGr5_GLP_Female                    119
# 82                         EOGScienceGr5&8_CACR_Female                    118
# 83                          EOGScienceGr5&8_GLP_Female                    118
# 84                             EOGSubjects_CACR_Female                     33
# 85                              EOGSubjects_GLP_Female                     33
# 86                           EOG/EOCSubjects_CACR_Male                     33
# 87                            EOG/EOCSubjects_GLP_Male                     33
# 88                                    EOGGr3_CACR_Male                     51
# 89                                     EOGGr3_GLP_Male                     51
# 90                                    EOGGr4_CACR_Male                     55
# 91                                     EOGGr4_GLP_Male                     55
# 92                                    EOGGr5_CACR_Male                    116
# 93                                     EOGGr5_GLP_Male                    116
# 94                                EOGMathGr3_CACR_Male                     52
# 95                                 EOGMathGr3_GLP_Male                     52
# 96                              EOGMathGr3-8_CACR_Male                     33
# 97                               EOGMathGr3-8_GLP_Male                     33
# 98                                EOGMathGr4_CACR_Male                     58
# 99                                 EOGMathGr4_GLP_Male                     58
# 100                               EOGMathGr5_CACR_Male                    119
# 101                                EOGMathGr5_GLP_Male                    119
# 102                            EOGReadingGr3_CACR_Male                     52
# 103                             EOGReadingGr3_GLP_Male                     52
# 104                          EOGReadingGr3-8_CACR_Male                     33
# 105                           EOGReadingGr3-8_GLP_Male                     33
# 106                            EOGReadingGr4_CACR_Male                     58
# 107                             EOGReadingGr4_GLP_Male                     58
# 108                            EOGReadingGr5_CACR_Male                    119
# 109                             EOGReadingGr5_GLP_Male                    119
# 110                            EOGScienceGr5_CACR_Male                    119
# 111                             EOGScienceGr5_GLP_Male                    119
# 112                          EOGScienceGr5&8_CACR_Male                    118
# 113                           EOGScienceGr5&8_GLP_Male                    118
# 114                              EOGSubjects_CACR_Male                     33
# 115                               EOGSubjects_GLP_Male                     33
# 116                EOG/EOCSubjects_CACR_AmericanIndian                     33
# 117                 EOG/EOCSubjects_GLP_AmericanIndian                     33
# 118                         EOGGr3_CACR_AmericanIndian                     51
# 119                          EOGGr3_GLP_AmericanIndian                     51
# 120                         EOGGr4_CACR_AmericanIndian                     55
# 121                          EOGGr4_GLP_AmericanIndian                     55
# 122                         EOGGr5_CACR_AmericanIndian                    116
# 123                          EOGGr5_GLP_AmericanIndian                    116
# 124                     EOGMathGr3_CACR_AmericanIndian                     52
# 125                      EOGMathGr3_GLP_AmericanIndian                     52
# 126                   EOGMathGr3-8_CACR_AmericanIndian                     33
# 127                    EOGMathGr3-8_GLP_AmericanIndian                     33
# 128                     EOGMathGr4_CACR_AmericanIndian                     58
# 129                      EOGMathGr4_GLP_AmericanIndian                     58
# 130                     EOGMathGr5_CACR_AmericanIndian                    119
# 131                      EOGMathGr5_GLP_AmericanIndian                    119
# 132                  EOGReadingGr3_CACR_AmericanIndian                     52
# 133                   EOGReadingGr3_GLP_AmericanIndian                     52
# 134                EOGReadingGr3-8_CACR_AmericanIndian                     33
# 135                 EOGReadingGr3-8_GLP_AmericanIndian                     33
# 136                  EOGReadingGr4_CACR_AmericanIndian                     58
# 137                   EOGReadingGr4_GLP_AmericanIndian                     58
# 138                  EOGReadingGr5_CACR_AmericanIndian                    119
# 139                   EOGReadingGr5_GLP_AmericanIndian                    119
# 140                  EOGScienceGr5_CACR_AmericanIndian                    119
# 141                   EOGScienceGr5_GLP_AmericanIndian                    119
# 142                EOGScienceGr5&8_CACR_AmericanIndian                    118
# 143                 EOGScienceGr5&8_GLP_AmericanIndian                    118
# 144                    EOGSubjects_CACR_AmericanIndian                     33
# 145                     EOGSubjects_GLP_AmericanIndian                     33
# 146                         EOG/EOCSubjects_CACR_Asian                     33
# 147                          EOG/EOCSubjects_GLP_Asian                     33
# 148                                  EOGGr3_CACR_Asian                     51
# 149                                   EOGGr3_GLP_Asian                     51
# 150                                  EOGGr4_CACR_Asian                     55
# 151                                   EOGGr4_GLP_Asian                     55
# 152                                  EOGGr5_CACR_Asian                    116
# 153                                   EOGGr5_GLP_Asian                    116
# 154                              EOGMathGr3_CACR_Asian                     52
# 155                               EOGMathGr3_GLP_Asian                     52
# 156                            EOGMathGr3-8_CACR_Asian                     33
# 157                             EOGMathGr3-8_GLP_Asian                     33
# 158                              EOGMathGr4_CACR_Asian                     58
# 159                               EOGMathGr4_GLP_Asian                     58
# 160                              EOGMathGr5_CACR_Asian                    119
# 161                               EOGMathGr5_GLP_Asian                    119
# 162                           EOGReadingGr3_CACR_Asian                     52
# 163                            EOGReadingGr3_GLP_Asian                     52
# 164                         EOGReadingGr3-8_CACR_Asian                     33
# 165                          EOGReadingGr3-8_GLP_Asian                     33
# 166                           EOGReadingGr4_CACR_Asian                     58
# 167                            EOGReadingGr4_GLP_Asian                     58
# 168                           EOGReadingGr5_CACR_Asian                    119
# 169                            EOGReadingGr5_GLP_Asian                    119
# 170                           EOGScienceGr5_CACR_Asian                    119
# 171                            EOGScienceGr5_GLP_Asian                    119
# 172                         EOGScienceGr5&8_CACR_Asian                    118
# 173                          EOGScienceGr5&8_GLP_Asian                    118
# 174                             EOGSubjects_CACR_Asian                     33
# 175                              EOGSubjects_GLP_Asian                     33
# 176                         EOG/EOCSubjects_CACR_Black                     33
# 177                          EOG/EOCSubjects_GLP_Black                     33
# 178                                  EOGGr3_CACR_Black                     51
# 179                                   EOGGr3_GLP_Black                     51
# 180                                  EOGGr4_CACR_Black                     55
# 181                                   EOGGr4_GLP_Black                     55
# 182                                  EOGGr5_CACR_Black                    116
# 183                                   EOGGr5_GLP_Black                    116
# 184                              EOGMathGr3_CACR_Black                     52
# 185                               EOGMathGr3_GLP_Black                     52
# 186                            EOGMathGr3-8_CACR_Black                     33
# 187                             EOGMathGr3-8_GLP_Black                     33
# 188                              EOGMathGr4_CACR_Black                     58
# 189                               EOGMathGr4_GLP_Black                     58
# 190                              EOGMathGr5_CACR_Black                    119
# 191                               EOGMathGr5_GLP_Black                    119
# 192                           EOGReadingGr3_CACR_Black                     52
# 193                            EOGReadingGr3_GLP_Black                     52
# 194                         EOGReadingGr3-8_CACR_Black                     33
# 195                          EOGReadingGr3-8_GLP_Black                     33
# 196                           EOGReadingGr4_CACR_Black                     58
# 197                            EOGReadingGr4_GLP_Black                     58
# 198                           EOGReadingGr5_CACR_Black                    119
# 199                            EOGReadingGr5_GLP_Black                    119
# 200                           EOGScienceGr5_CACR_Black                    119
# 201                            EOGScienceGr5_GLP_Black                    119
# 202                         EOGScienceGr5&8_CACR_Black                    118
# 203                          EOGScienceGr5&8_GLP_Black                    118
# 204                             EOGSubjects_CACR_Black                     33
# 205                              EOGSubjects_GLP_Black                     33
# 206                      EOG/EOCSubjects_CACR_Hispanic                     33
# 207                       EOG/EOCSubjects_GLP_Hispanic                     33
# 208                               EOGGr3_CACR_Hispanic                     51
# 209                                EOGGr3_GLP_Hispanic                     51
# 210                               EOGGr4_CACR_Hispanic                     55
# 211                                EOGGr4_GLP_Hispanic                     55
# 212                               EOGGr5_CACR_Hispanic                    116
# 213                                EOGGr5_GLP_Hispanic                    116
# 214                           EOGMathGr3_CACR_Hispanic                     52
# 215                            EOGMathGr3_GLP_Hispanic                     52
# 216                         EOGMathGr3-8_CACR_Hispanic                     33
# 217                          EOGMathGr3-8_GLP_Hispanic                     33
# 218                           EOGMathGr4_CACR_Hispanic                     58
# 219                            EOGMathGr4_GLP_Hispanic                     58
# 220                           EOGMathGr5_CACR_Hispanic                    119
# 221                            EOGMathGr5_GLP_Hispanic                    119
# 222                        EOGReadingGr3_CACR_Hispanic                     52
# 223                         EOGReadingGr3_GLP_Hispanic                     52
# 224                      EOGReadingGr3-8_CACR_Hispanic                     33
# 225                       EOGReadingGr3-8_GLP_Hispanic                     33
# 226                        EOGReadingGr4_CACR_Hispanic                     58
# 227                         EOGReadingGr4_GLP_Hispanic                     58
# 228                        EOGReadingGr5_CACR_Hispanic                    119
# 229                         EOGReadingGr5_GLP_Hispanic                    119
# 230                        EOGScienceGr5_CACR_Hispanic                    119
# 231                         EOGScienceGr5_GLP_Hispanic                    119
# 232                      EOGScienceGr5&8_CACR_Hispanic                    118
# 233                       EOGScienceGr5&8_GLP_Hispanic                    118
# 234                          EOGSubjects_CACR_Hispanic                     33
# 235                           EOGSubjects_GLP_Hispanic                     33
# 236                EOG/EOCSubjects_CACR_TwoorMoreRaces                     33
# 237                 EOG/EOCSubjects_GLP_TwoorMoreRaces                     33
# 238                         EOGGr3_CACR_TwoorMoreRaces                     51
# 239                          EOGGr3_GLP_TwoorMoreRaces                     51
# 240                         EOGGr4_CACR_TwoorMoreRaces                     55
# 241                          EOGGr4_GLP_TwoorMoreRaces                     55
# 242                         EOGGr5_CACR_TwoorMoreRaces                    116
# 243                          EOGGr5_GLP_TwoorMoreRaces                    116
# 244                     EOGMathGr3_CACR_TwoorMoreRaces                     52
# 245                      EOGMathGr3_GLP_TwoorMoreRaces                     52
# 246                   EOGMathGr3-8_CACR_TwoorMoreRaces                     33
# 247                    EOGMathGr3-8_GLP_TwoorMoreRaces                     33
# 248                     EOGMathGr4_CACR_TwoorMoreRaces                     58
# 249                      EOGMathGr4_GLP_TwoorMoreRaces                     58
# 250                     EOGMathGr5_CACR_TwoorMoreRaces                    119
# 251                      EOGMathGr5_GLP_TwoorMoreRaces                    119
# 252                  EOGReadingGr3_CACR_TwoorMoreRaces                     52
# 253                   EOGReadingGr3_GLP_TwoorMoreRaces                     52
# 254                EOGReadingGr3-8_CACR_TwoorMoreRaces                     33
# 255                 EOGReadingGr3-8_GLP_TwoorMoreRaces                     33
# 256                  EOGReadingGr4_CACR_TwoorMoreRaces                     58
# 257                   EOGReadingGr4_GLP_TwoorMoreRaces                     58
# 258                  EOGReadingGr5_CACR_TwoorMoreRaces                    119
# 259                   EOGReadingGr5_GLP_TwoorMoreRaces                    119
# 260                  EOGScienceGr5_CACR_TwoorMoreRaces                    119
# 261                   EOGScienceGr5_GLP_TwoorMoreRaces                    119
# 262                EOGScienceGr5&8_CACR_TwoorMoreRaces                    118
# 263                 EOGScienceGr5&8_GLP_TwoorMoreRaces                    118
# 264                    EOGSubjects_CACR_TwoorMoreRaces                     33
# 265                     EOGSubjects_GLP_TwoorMoreRaces                     33
# 266                         EOG/EOCSubjects_CACR_White                     33
# 267                          EOG/EOCSubjects_GLP_White                     33
# 268                                  EOGGr3_CACR_White                     51
# 269                                   EOGGr3_GLP_White                     51
# 270                                  EOGGr4_CACR_White                     55
# 271                                   EOGGr4_GLP_White                     55
# 272                                  EOGGr5_CACR_White                    116
# 273                                   EOGGr5_GLP_White                    116
# 274                              EOGMathGr3_CACR_White                     52
# 275                               EOGMathGr3_GLP_White                     52
# 276                            EOGMathGr3-8_CACR_White                     33
# 277                             EOGMathGr3-8_GLP_White                     33
# 278                              EOGMathGr4_CACR_White                     58
# 279                               EOGMathGr4_GLP_White                     58
# 280                              EOGMathGr5_CACR_White                    119
# 281                               EOGMathGr5_GLP_White                    119
# 282                           EOGReadingGr3_CACR_White                     52
# 283                            EOGReadingGr3_GLP_White                     52
# 284                         EOGReadingGr3-8_CACR_White                     33
# 285                          EOGReadingGr3-8_GLP_White                     33
# 286                           EOGReadingGr4_CACR_White                     58
# 287                            EOGReadingGr4_GLP_White                     58
# 288                           EOGReadingGr5_CACR_White                    119
# 289                            EOGReadingGr5_GLP_White                    119
# 290                           EOGScienceGr5_CACR_White                    119
# 291                            EOGScienceGr5_GLP_White                    119
# 292                         EOGScienceGr5&8_CACR_White                    118
# 293                          EOGScienceGr5&8_GLP_White                    118
# 294                             EOGSubjects_CACR_White                     33
# 295                              EOGSubjects_GLP_White                     33
# 296                           EOG/EOCSubjects_CACR_EDS                     33
# 297                            EOG/EOCSubjects_GLP_EDS                     33
# 298                                    EOGGr3_CACR_EDS                     51
# 299                                     EOGGr3_GLP_EDS                     51
# 300                                    EOGGr4_CACR_EDS                     55
# 301                                     EOGGr4_GLP_EDS                     55
# 302                                    EOGGr5_CACR_EDS                    116
# 303                                     EOGGr5_GLP_EDS                    116
# 304                                EOGMathGr3_CACR_EDS                     52
# 305                                 EOGMathGr3_GLP_EDS                     52
# 306                              EOGMathGr3-8_CACR_EDS                     33
# 307                               EOGMathGr3-8_GLP_EDS                     33
# 308                                EOGMathGr4_CACR_EDS                     58
# 309                                 EOGMathGr4_GLP_EDS                     58
# 310                                EOGMathGr5_CACR_EDS                    119
# 311                                 EOGMathGr5_GLP_EDS                    119
# 312                             EOGReadingGr3_CACR_EDS                     52
# 313                              EOGReadingGr3_GLP_EDS                     52
# 314                           EOGReadingGr3-8_CACR_EDS                     33
# 315                            EOGReadingGr3-8_GLP_EDS                     33
# 316                             EOGReadingGr4_CACR_EDS                     58
# 317                              EOGReadingGr4_GLP_EDS                     58
# 318                             EOGReadingGr5_CACR_EDS                    119
# 319                              EOGReadingGr5_GLP_EDS                    119
# 320                             EOGScienceGr5_CACR_EDS                    119
# 321                              EOGScienceGr5_GLP_EDS                    119
# 322                           EOGScienceGr5&8_CACR_EDS                    118
# 323                            EOGScienceGr5&8_GLP_EDS                    118
# 324                               EOGSubjects_CACR_EDS                     33
# 325                                EOGSubjects_GLP_EDS                     33
# 326                           EOG/EOCSubjects_CACR_LEP                     33
# 327                            EOG/EOCSubjects_GLP_LEP                     33
# 328                                    EOGGr3_CACR_LEP                     51
# 329                                     EOGGr3_GLP_LEP                     51
# 330                                    EOGGr4_CACR_LEP                     55
# 331                                     EOGGr4_GLP_LEP                     55
# 332                                    EOGGr5_CACR_LEP                    116
# 333                                     EOGGr5_GLP_LEP                    116
# 334                                EOGMathGr3_CACR_LEP                     52
# 335                                 EOGMathGr3_GLP_LEP                     52
# 336                              EOGMathGr3-8_CACR_LEP                     33
# 337                               EOGMathGr3-8_GLP_LEP                     33
# 338                                EOGMathGr4_CACR_LEP                     58
# 339                                 EOGMathGr4_GLP_LEP                     58
# 340                                EOGMathGr5_CACR_LEP                    119
# 341                                 EOGMathGr5_GLP_LEP                    119
# 342                             EOGReadingGr3_CACR_LEP                     52
# 343                              EOGReadingGr3_GLP_LEP                     52
# 344                           EOGReadingGr3-8_CACR_LEP                     33
# 345                            EOGReadingGr3-8_GLP_LEP                     33
# 346                             EOGReadingGr4_CACR_LEP                     58
# 347                              EOGReadingGr4_GLP_LEP                     58
# 348                             EOGReadingGr5_CACR_LEP                    119
# 349                              EOGReadingGr5_GLP_LEP                    119
# 350                             EOGScienceGr5_CACR_LEP                    119
# 351                              EOGScienceGr5_GLP_LEP                    119
# 352                           EOGScienceGr5&8_CACR_LEP                    118
# 353                            EOGScienceGr5&8_GLP_LEP                    118
# 354                               EOGSubjects_CACR_LEP                     33
# 355                                EOGSubjects_GLP_LEP                     33
# 356                           EOG/EOCSubjects_CACR_SWD                     33
# 357                            EOG/EOCSubjects_GLP_SWD                     33
# 358                                    EOGGr3_CACR_SWD                     51
# 359                                     EOGGr3_GLP_SWD                     51
# 360                                    EOGGr4_CACR_SWD                     55
# 361                                     EOGGr4_GLP_SWD                     55
# 362                                    EOGGr5_CACR_SWD                    116
# 363                                     EOGGr5_GLP_SWD                    116
# 364                                EOGMathGr3_CACR_SWD                     52
# 365                                 EOGMathGr3_GLP_SWD                     52
# 366                              EOGMathGr3-8_CACR_SWD                     33
# 367                               EOGMathGr3-8_GLP_SWD                     33
# 368                                EOGMathGr4_CACR_SWD                     58
# 369                                 EOGMathGr4_GLP_SWD                     58
# 370                                EOGMathGr5_CACR_SWD                    119
# 371                                 EOGMathGr5_GLP_SWD                    119
# 372                             EOGReadingGr3_CACR_SWD                     52
# 373                              EOGReadingGr3_GLP_SWD                     52
# 374                           EOGReadingGr3-8_CACR_SWD                     33
# 375                            EOGReadingGr3-8_GLP_SWD                     33
# 376                             EOGReadingGr4_CACR_SWD                     58
# 377                              EOGReadingGr4_GLP_SWD                     58
# 378                             EOGReadingGr5_CACR_SWD                    119
# 379                              EOGReadingGr5_GLP_SWD                    119
# 380                             EOGScienceGr5_CACR_SWD                    119
# 381                              EOGScienceGr5_GLP_SWD                    119
# 382                           EOGScienceGr5&8_CACR_SWD                    118
# 383                            EOGScienceGr5&8_GLP_SWD                    118
# 384                               EOGSubjects_CACR_SWD                     33
# 385                                EOGSubjects_GLP_SWD                     33
# 386                           EOG/EOCSubjects_CACR_AIG                     33
# 387                            EOG/EOCSubjects_GLP_AIG                     33
# 388                                    EOGGr3_CACR_AIG                     51
# 389                                     EOGGr3_GLP_AIG                     51
# 390                                    EOGGr4_CACR_AIG                     55
# 391                                     EOGGr4_GLP_AIG                     55
# 392                                    EOGGr5_CACR_AIG                    116
# 393                                     EOGGr5_GLP_AIG                    116
# 394                                EOGMathGr3_CACR_AIG                     52
# 395                                 EOGMathGr3_GLP_AIG                     52
# 396                              EOGMathGr3-8_CACR_AIG                     33
# 397                               EOGMathGr3-8_GLP_AIG                     33
# 398                                EOGMathGr4_CACR_AIG                     58
# 399                                 EOGMathGr4_GLP_AIG                     58
# 400                                EOGMathGr5_CACR_AIG                    119
# 401                                 EOGMathGr5_GLP_AIG                    119
# 402                             EOGReadingGr3_CACR_AIG                     52
# 403                              EOGReadingGr3_GLP_AIG                     52
# 404                           EOGReadingGr3-8_CACR_AIG                     33
# 405                            EOGReadingGr3-8_GLP_AIG                     33
# 406                             EOGReadingGr4_CACR_AIG                     58
# 407                              EOGReadingGr4_GLP_AIG                     58
# 408                             EOGReadingGr5_CACR_AIG                    119
# 409                              EOGReadingGr5_GLP_AIG                    119
# 410                             EOGScienceGr5_CACR_AIG                    119
# 411                              EOGScienceGr5_GLP_AIG                    119
# 412                           EOGScienceGr5&8_CACR_AIG                    118
# 413                            EOGScienceGr5&8_GLP_AIG                    118
# 414                               EOGSubjects_CACR_AIG                     33
# 415                                EOGSubjects_GLP_AIG                     33
# 416                                        pct_GCE_ALL                     51
# 417                                     pct_PASSED_EOG                     68
# 418                                       pct_PROMOTED                     54
# 419                                       pct_RETAINED                    716
# 420                           MathGr3-8_pTarget_PctMet                     33
# 421                        ReadingGr3-8_pTarget_PctMet                     33
# 422                            SciGr5&8_pTarget_PctMet                    165
# 423                        TotalTargets_pTarget_PctMet                     33
# 426                           lea_ap_participation_pct                    137
# 427                              lea_ap_pct_3_or_above                      8
# 428                              lea_ib_pct_4_or_above                    745
# 433                             stud_internet_comp_num                     11
# 442                                  digital_media_pct                     11
# 443                           avg_age_media_collection                      9
# 444                                  books_per_student                      9
# 447                                            wap_num                      3
# 448                                  wap_per_classroom                      3
# 456                                          nbpts_num                     91
# 458                               _1yr_tchr_trnovr_pct                      5
# 459                                 highqual_class_pct                      1
# 465                                      lea_nbpts_num                      3
# 468                            lea_emer_prov_teach_pct                    431
# 469                              lea_lateral_teach_pct                    153
# 471                          lea_highqual_class_hp_pct                     47
# 472                          lea_highqual_class_lp_pct                    127
# 474                      lea_not_highqual_class_hp_pct                     47
# 475                      lea_not_highqual_class_lp_pct                    127
# 497                   Accomplished_TCHR_Standard 4_Pct                      5
# 502                     Developing_TCHR_Standard 4_Pct                      5
# 507                  Distinguished_TCHR_Standard 4_Pct                      5
# 509  Does Not Meet Expected Growth_TCHR_Student Gro...                      1
# 510    Exceeds Expected Growth_TCHR_Student Growth_Pct                      1
# 511      Meets Expected Growth_TCHR_Student Growth_Pct                      1
# 515                Not Demostrated_TCHR_Standard 4_Pct                      5
# 520                     Proficient_TCHR_Standard 4_Pct                      5
# 546                                               Year                    315
# 547                                       Violent Rate                    344
# 548                                        Murder Rate                    409
# 549                                          Rape Rate                    349
# 550                                       Robbery Rate                    360
# 551                                       Assault Rate                    344
# 552                                           MVT Rate                    352
# 553                                         Arson Rate                    381

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  219539  field correlations > 95%.
#                                                    Field1  \
# 0                                     lea_class_teach_num
# 1                                    st_tchyrs_0thru3_pct
# 2                                      st_class_teach_num
# 3                                           category_cd_I
# 4                                           Category_Cd_I
# 5                                       Reading SPG Grade
# 6                                          Math SPG Grade
# 7                               Overall Achievement Score
# 8                                           Reading Score
# 9                                              Math Score
# 10                               EOG/EOCSubjects_CACR_All
# 11                                EOG/EOCSubjects_GLP_All
# 12                                   EOGMathGr3-8_GLP_All
# 13                                EOGReadingGr3-8_GLP_All
# 14                                   EOGSubjects_CACR_All
# 15                                    EOGSubjects_GLP_All
# 16                            EOG/EOCSubjects_CACR_Female
# 17                             EOG/EOCSubjects_GLP_Female
# 18                                EOGSubjects_CACR_Female
# 19                                 EOGSubjects_GLP_Female
# 20                               EOG/EOCSubjects_GLP_Male
# 21                                   EOGSubjects_GLP_Male
# 22                              Overall Achievement Score
# 23                                          Reading Score
# 24                               EOG/EOCSubjects_CACR_All
# 25                                EOG/EOCSubjects_GLP_All
# 26                               EOGReadingGr3-8_CACR_All
# 27                                EOGReadingGr3-8_GLP_All
# 28                                   EOGSubjects_CACR_All
# 29                                    EOGSubjects_GLP_All
# 30                             EOG/EOCSubjects_GLP_Female
# 31                             EOGReadingGr3-8_GLP_Female
# 32                                 EOGSubjects_GLP_Female
# 33                               EOG/EOCSubjects_GLP_Male
# 34                               EOGReadingGr3-8_GLP_Male
# 35                                   EOGSubjects_GLP_Male
# 36                              Overall Achievement Score
# 37                                             Math Score
# 38                                EOG/EOCSubjects_GLP_All
# 39                                  EOGMathGr3-8_CACR_All
# 40                                   EOGMathGr3-8_GLP_All
# 41                                    EOGSubjects_GLP_All
# 42                             EOG/EOCSubjects_GLP_Female
# 43                                EOGMathGr3-8_GLP_Female
# 44                                 EOGSubjects_GLP_Female
# 45                                  EOGMathGr3-8_GLP_Male
# 46                                          Reading Score
# 47                                             Math Score
# 48                               EOG/EOCSubjects_CACR_All
# 49                                EOG/EOCSubjects_GLP_All
# 50                                  EOGMathGr3-8_CACR_All
# 51                                   EOGMathGr3-8_GLP_All
# 52                               EOGReadingGr3-8_CACR_All
# 53                                EOGReadingGr3-8_GLP_All
# 54                                   EOGSubjects_CACR_All
# 55                                    EOGSubjects_GLP_All
# 56                            EOG/EOCSubjects_CACR_Female
# 57                             EOG/EOCSubjects_GLP_Female
# 58                                EOGMathGr3-8_GLP_Female
# 59                             EOGReadingGr3-8_GLP_Female
# 60                                EOGSubjects_CACR_Female
# 61                                 EOGSubjects_GLP_Female
# 62                              EOG/EOCSubjects_CACR_Male
# 63                               EOG/EOCSubjects_GLP_Male
# 64                                  EOGMathGr3-8_GLP_Male
# 65                               EOGReadingGr3-8_GLP_Male
# 66                                  EOGSubjects_CACR_Male
# 67                                   EOGSubjects_GLP_Male
# 68                               EOG/EOCSubjects_CACR_All
# 69                                EOG/EOCSubjects_GLP_All
# 70                               EOGReadingGr3-8_CACR_All
# 71                                EOGReadingGr3-8_GLP_All
# 72                                   EOGSubjects_CACR_All
# 73                                    EOGSubjects_GLP_All
# 74                            EOG/EOCSubjects_CACR_Female
# 75                             EOG/EOCSubjects_GLP_Female
# 76                            EOGReadingGr3-8_CACR_Female
# 77                             EOGReadingGr3-8_GLP_Female
# 78                                EOGSubjects_CACR_Female
# 79                                 EOGSubjects_GLP_Female
# 80                              EOG/EOCSubjects_CACR_Male
# 81                               EOG/EOCSubjects_GLP_Male
# 82                              EOGReadingGr3-8_CACR_Male
# 83                               EOGReadingGr3-8_GLP_Male
# 84                                  EOGSubjects_CACR_Male
# 85                                   EOGSubjects_GLP_Male
# 86                               EOG/EOCSubjects_CACR_All
# 87                                EOG/EOCSubjects_GLP_All
# 88                                  EOGMathGr3-8_CACR_All
# 89                                   EOGMathGr3-8_GLP_All
# 90                                   EOGSubjects_CACR_All
# 91                                    EOGSubjects_GLP_All
# 92                            EOG/EOCSubjects_CACR_Female
# 93                             EOG/EOCSubjects_GLP_Female
# 94                               EOGMathGr3-8_CACR_Female
# 95                                EOGMathGr3-8_GLP_Female
# 96                                EOGSubjects_CACR_Female
# 97                                 EOGSubjects_GLP_Female
# 98                              EOG/EOCSubjects_CACR_Male
# 99                               EOG/EOCSubjects_GLP_Male
# 100                                EOGMathGr3-8_CACR_Male
# 101                                 EOGMathGr3-8_GLP_Male
# 102                                 EOGSubjects_CACR_Male
# 103                                  EOGSubjects_GLP_Male
# 104                                        EOGGr5_GLP_All
# 105                                EOGScienceGr5_CACR_All
# 106                                 EOGScienceGr5_GLP_All
# 107                              EOGScienceGr5&8_CACR_All
# 108                               EOGScienceGr5&8_GLP_All
# 109                               EOG/EOCSubjects_GLP_All
# 110                                 EOGMathGr3-8_CACR_All
# 111                                  EOGMathGr3-8_GLP_All
# 112                              EOGReadingGr3-8_CACR_All
# 113                               EOGReadingGr3-8_GLP_All
# 114                                  EOGSubjects_CACR_All
# 115                                   EOGSubjects_GLP_All
# 116                           EOG/EOCSubjects_CACR_Female
# 117                            EOG/EOCSubjects_GLP_Female
# 118                              EOGMathGr3-8_CACR_Female
# 119                               EOGSubjects_CACR_Female
# 120                                EOGSubjects_GLP_Female
# 121                             EOG/EOCSubjects_CACR_Male
# 122                              EOG/EOCSubjects_GLP_Male
# 123                                EOGMathGr3-8_CACR_Male
# 124                                 EOGMathGr3-8_GLP_Male
# 125                             EOGReadingGr3-8_CACR_Male
# 126                                 EOGSubjects_CACR_Male
# 127                                  EOGSubjects_GLP_Male
# 128                                 EOGMathGr3-8_CACR_All
# 129                                  EOGMathGr3-8_GLP_All
# 130                              EOGReadingGr3-8_CACR_All
# 131                               EOGReadingGr3-8_GLP_All
# 132                                  EOGSubjects_CACR_All
# 133                                   EOGSubjects_GLP_All
# 134                           EOG/EOCSubjects_CACR_Female
# 135                            EOG/EOCSubjects_GLP_Female
# 136                               EOGMathGr3-8_GLP_Female
# 137                            EOGReadingGr3-8_GLP_Female
# 138                               EOGSubjects_CACR_Female
# 139                                EOGSubjects_GLP_Female
# 140                             EOG/EOCSubjects_CACR_Male
# 141                              EOG/EOCSubjects_GLP_Male
# 142                                 EOGMathGr3-8_GLP_Male
# 143                              EOGReadingGr3-8_GLP_Male
# 144                                 EOGSubjects_CACR_Male
# 145                                  EOGSubjects_GLP_Male
# 146                                        EOGGr3_GLP_All
# 147                                   EOGMathGr3_CACR_All
# 148                                EOGReadingGr3_CACR_All
# 149                                 EOGReadingGr3_GLP_All
# 150                                    EOGGr3_CACR_Female
# 151                                      EOGGr3_CACR_Male
# 152                                   EOGMathGr3_CACR_All
# 153                                    EOGMathGr3_GLP_All
# 154                                 EOGReadingGr3_GLP_All
# 155                                     EOGGr3_GLP_Female
# 156                                       EOGGr3_GLP_Male
# 157                                        EOGGr4_GLP_All
# 158                                   EOGMathGr4_CACR_All
# 159                                    EOGMathGr4_GLP_All
# 160                                EOGReadingGr4_CACR_All
# 161                                      EOGGr4_CACR_Male
# 162                                    EOGMathGr4_GLP_All
# 163                                 EOGReadingGr4_GLP_All
# 164                                       EOGGr4_GLP_Male
# 165                                        EOGGr5_GLP_All
# 166                                   EOGMathGr5_CACR_All
# 167                                    EOGMathGr5_GLP_All
# 168                                 EOGReadingGr5_GLP_All
# 169                                EOGScienceGr5_CACR_All
# 170                              EOGScienceGr5&8_CACR_All
# 171                                    EOGGr5_CACR_Female
# 172                                     EOGGr5_GLP_Female
# 173                                      EOGGr5_CACR_Male
# 174                                       EOGGr5_GLP_Male
# 175                                    EOGMathGr5_GLP_All
# 176                                 EOGReadingGr5_GLP_All
# 177                                EOGScienceGr5_CACR_All
# 178                                 EOGScienceGr5_GLP_All
# 179                              EOGScienceGr5&8_CACR_All
# 180                               EOGScienceGr5&8_GLP_All
# 181                                    EOGGr5_CACR_Female
# 182                                     EOGGr5_GLP_Female
# 183                                      EOGGr5_CACR_Male
# 184                                       EOGGr5_GLP_Male
# 185                                    EOGMathGr3_GLP_All
# 186                                  EOGMathGr3-8_GLP_All
# 187                                  EOGSubjects_CACR_All
# 188                                   EOGSubjects_GLP_All
# 189                           EOG/EOCSubjects_CACR_Female
# 190                              EOGMathGr3-8_CACR_Female
# 191                               EOGMathGr3-8_GLP_Female
# 192                               EOGSubjects_CACR_Female
# 193                             EOG/EOCSubjects_CACR_Male
# 194                              EOG/EOCSubjects_GLP_Male
# 195                                EOGMathGr3-8_CACR_Male
# 196                                 EOGMathGr3-8_GLP_Male
# 197                                 EOGSubjects_CACR_Male
# 198                                  EOGSubjects_GLP_Male
# 199                                  EOGSubjects_CACR_All
# 200                                   EOGSubjects_GLP_All
# 201                           EOG/EOCSubjects_CACR_Female
# 202                            EOG/EOCSubjects_GLP_Female
# 203                              EOGMathGr3-8_CACR_Female
# 204                               EOGMathGr3-8_GLP_Female
# 205                               EOGSubjects_CACR_Female
# 206                                EOGSubjects_GLP_Female
# 207                             EOG/EOCSubjects_CACR_Male
# 208                              EOG/EOCSubjects_GLP_Male
# 209                                EOGMathGr3-8_CACR_Male
# 210                                 EOGMathGr3-8_GLP_Male
# 211                                 EOGSubjects_CACR_Male
# 212                                  EOGSubjects_GLP_Male
# 213                                    EOGMathGr4_GLP_All
# 214                                    EOGMathGr5_GLP_All
# 215                                 EOGReadingGr3_GLP_All
# 216                                        pct_PASSED_EOG
# 217                                        pct_PASSED_EOG
# 218                               EOGReadingGr3-8_GLP_All
# 219                                  EOGSubjects_CACR_All
# 220                                   EOGSubjects_GLP_All
# 221                           EOG/EOCSubjects_CACR_Female
# 222                           EOGReadingGr3-8_CACR_Female
# 223                            EOGReadingGr3-8_GLP_Female
# 224                               EOGSubjects_CACR_Female
# 225                             EOG/EOCSubjects_CACR_Male
# 226                             EOGReadingGr3-8_CACR_Male
# 227                              EOGReadingGr3-8_GLP_Male
# 228                                 EOGSubjects_CACR_Male
# 229                                  EOGSubjects_CACR_All
# 230                                   EOGSubjects_GLP_All
# 231                           EOG/EOCSubjects_CACR_Female
# 232                            EOG/EOCSubjects_GLP_Female
# 233                           EOGReadingGr3-8_CACR_Female
# 234                            EOGReadingGr3-8_GLP_Female
# 235                               EOGSubjects_CACR_Female
# 236                                EOGSubjects_GLP_Female
# 237                             EOG/EOCSubjects_CACR_Male
# 238                              EOG/EOCSubjects_GLP_Male
# 239                             EOGReadingGr3-8_CACR_Male
# 240                              EOGReadingGr3-8_GLP_Male
# 241                                 EOGSubjects_CACR_Male
# 242                                  EOGSubjects_GLP_Male
# 243                                 EOGReadingGr4_GLP_All
# 244                                 EOGReadingGr5_GLP_All
# 245                                 EOGScienceGr5_GLP_All
# 246                              EOGScienceGr5&8_CACR_All
# 247                               EOGScienceGr5&8_GLP_All
# 248                              EOGScienceGr5&8_CACR_All
# 249                               EOGScienceGr5&8_GLP_All
# 250                               EOGScienceGr5&8_GLP_All
# 251                             EOGScienceGr5&8_CACR_Male
# 252                                   EOGSubjects_GLP_All
# 253                           EOG/EOCSubjects_CACR_Female
# 254                            EOG/EOCSubjects_GLP_Female
# 255                              EOGMathGr3-8_CACR_Female
# 256                               EOGSubjects_CACR_Female
# 257                                EOGSubjects_GLP_Female
# 258                             EOG/EOCSubjects_CACR_Male
# 259                              EOG/EOCSubjects_GLP_Male
# 260                                EOGMathGr3-8_CACR_Male
# 261                                 EOGMathGr3-8_GLP_Male
# 262                             EOGReadingGr3-8_CACR_Male
# 263                                 EOGSubjects_CACR_Male
# 264                                  EOGSubjects_GLP_Male
# 265                           EOG/EOCSubjects_CACR_Female
# 266                            EOG/EOCSubjects_GLP_Female
# 267                               EOGMathGr3-8_GLP_Female
# 268                            EOGReadingGr3-8_GLP_Female
# 269                               EOGSubjects_CACR_Female
# 270                                EOGSubjects_GLP_Female
# 271                             EOG/EOCSubjects_CACR_Male
# 272                              EOG/EOCSubjects_GLP_Male
# 273                                 EOGMathGr3-8_GLP_Male
# 274                              EOGReadingGr3-8_GLP_Male
# 275                                 EOGSubjects_CACR_Male
# 276                                  EOGSubjects_GLP_Male
# 277                            EOG/EOCSubjects_GLP_Female
# 278                              EOGMathGr3-8_CACR_Female
# 279                           EOGReadingGr3-8_CACR_Female
# 280                               EOGSubjects_CACR_Female
# 281                                EOGSubjects_GLP_Female
# 282                              EOGMathGr3-8_CACR_Female
# 283                               EOGMathGr3-8_GLP_Female
# 284                            EOGReadingGr3-8_GLP_Female
# 285                               EOGSubjects_CACR_Female
# 286                                EOGSubjects_GLP_Female
# 287                                     EOGGr3_GLP_Female
# 288                                     EOGGr4_GLP_Female
# 289                                     EOGGr5_GLP_Female
# 290                                 EOGMathGr3_GLP_Female
# 291                               EOGMathGr3-8_GLP_Female
# 292                               EOGSubjects_CACR_Female
# 293                                EOGSubjects_GLP_Female
# 294                                EOGSubjects_GLP_Female
# 295                                 EOGMathGr4_GLP_Female
# 296                                 EOGMathGr5_GLP_Female
# 297                              EOGReadingGr3_GLP_Female
# 298                            EOGReadingGr3-8_GLP_Female
# 299                               EOGSubjects_CACR_Female
# 300                                EOGSubjects_GLP_Female
# 301                              EOGReadingGr5_GLP_Female
# 302                              EOGScienceGr5_GLP_Female
# 303                           EOGScienceGr5&8_CACR_Female
# 304                            EOGScienceGr5&8_GLP_Female
# 305                            EOGScienceGr5&8_GLP_Female
# 306                                EOGSubjects_GLP_Female
# 307                              EOG/EOCSubjects_GLP_Male
# 308                                EOGMathGr3-8_CACR_Male
# 309                                 EOGMathGr3-8_GLP_Male
# 310                             EOGReadingGr3-8_CACR_Male
# 311                              EOGReadingGr3-8_GLP_Male
# 312                                 EOGSubjects_CACR_Male
# 313                                  EOGSubjects_GLP_Male
# 314                                EOGMathGr3-8_CACR_Male
# 315                                 EOGMathGr3-8_GLP_Male
# 316                              EOGReadingGr3-8_GLP_Male
# 317                                 EOGSubjects_CACR_Male
# 318                                  EOGSubjects_GLP_Male
# 319                                       EOGGr3_GLP_Male
# 320                                       EOGGr4_GLP_Male
# 321                                       EOGGr5_GLP_Male
# 322                                   EOGMathGr3_GLP_Male
# 323                                 EOGMathGr3-8_GLP_Male
# 324                                 EOGSubjects_CACR_Male
# 325                                  EOGSubjects_GLP_Male
# 326                                 EOGSubjects_CACR_Male
# 327                                  EOGSubjects_GLP_Male
# 328                                   EOGMathGr4_GLP_Male
# 329                                   EOGMathGr5_GLP_Male
# 330                                EOGReadingGr3_GLP_Male
# 331                              EOGReadingGr3-8_GLP_Male
# 332                                 EOGSubjects_CACR_Male
# 333                                 EOGSubjects_CACR_Male
# 334                                  EOGSubjects_GLP_Male
# 335                                EOGReadingGr5_GLP_Male
# 336                                EOGScienceGr5_GLP_Male
# 337                             EOGScienceGr5&8_CACR_Male
# 338                              EOGScienceGr5&8_GLP_Male
# 339                              EOGScienceGr5&8_GLP_Male
# 340                                  EOGSubjects_GLP_Male
# 341                    EOG/EOCSubjects_GLP_AmericanIndian
# 342                       EOGSubjects_CACR_AmericanIndian
# 343                        EOGSubjects_GLP_AmericanIndian
# 344                       EOGSubjects_CACR_AmericanIndian
# 345                        EOGSubjects_GLP_AmericanIndian
# 346                             EOGGr3_GLP_AmericanIndian
# 347                             EOGGr4_GLP_AmericanIndian
# 348                             EOGGr5_GLP_AmericanIndian
# 349                         EOGMathGr3_GLP_AmericanIndian
# 350                     EOGReadingGr3_CACR_AmericanIndian
# 351                      EOGReadingGr3_GLP_AmericanIndian
# 352                      EOGReadingGr3_GLP_AmericanIndian
# 353                       EOGMathGr3-8_GLP_AmericanIndian
# 354                   EOGReadingGr3-8_CACR_AmericanIndian
# 355                    EOGReadingGr3-8_GLP_AmericanIndian
# 356                   EOGReadingGr3-8_CACR_AmericanIndian
# 357                    EOGReadingGr3-8_GLP_AmericanIndian
# 358                         EOGMathGr4_GLP_AmericanIndian
# 359                     EOGReadingGr4_CACR_AmericanIndian
# 360                      EOGReadingGr4_GLP_AmericanIndian
# 361                     EOGReadingGr4_CACR_AmericanIndian
# 362                      EOGReadingGr4_GLP_AmericanIndian
# 363                         EOGMathGr5_GLP_AmericanIndian
# 364                      EOGReadingGr5_GLP_AmericanIndian
# 365                     EOGReadingGr5_CACR_AmericanIndian
# 366                      EOGReadingGr5_GLP_AmericanIndian
# 367                      EOGReadingGr3_GLP_AmericanIndian
# 368                    EOGReadingGr3-8_GLP_AmericanIndian
# 369                      EOGReadingGr4_GLP_AmericanIndian
# 370                      EOGReadingGr5_GLP_AmericanIndian
# 371                   EOGScienceGr5&8_CACR_AmericanIndian
# 372                      EOGScienceGr5_GLP_AmericanIndian
# 373                   EOGScienceGr5&8_CACR_AmericanIndian
# 374                    EOGScienceGr5&8_GLP_AmericanIndian
# 375                   EOGScienceGr5&8_CACR_AmericanIndian
# 376                    EOGScienceGr5&8_GLP_AmericanIndian
# 377                    EOGScienceGr5&8_GLP_AmericanIndian
# 378                        EOGSubjects_GLP_AmericanIndian
# 379                             EOG/EOCSubjects_GLP_Asian
# 380                                EOGSubjects_CACR_Asian
# 381                                 EOGSubjects_GLP_Asian
# 382                                EOGSubjects_CACR_Asian
# 383                                 EOGSubjects_GLP_Asian
# 384                                      EOGGr3_GLP_Asian
# 385                                      EOGGr4_GLP_Asian
# 386                                      EOGGr5_GLP_Asian
# 387                                  EOGMathGr3_GLP_Asian
# 388                              EOGReadingGr3_CACR_Asian
# 389                               EOGReadingGr3_GLP_Asian
# 390                              EOGReadingGr3_CACR_Asian
# 391                               EOGReadingGr3_GLP_Asian
# 392                                EOGMathGr3-8_GLP_Asian
# 393                            EOGReadingGr3-8_CACR_Asian
# 394                             EOGReadingGr3-8_GLP_Asian
# 395                            EOGReadingGr3-8_CACR_Asian
# 396                             EOGReadingGr3-8_GLP_Asian
# 397                                  EOGMathGr4_GLP_Asian
# 398                              EOGReadingGr4_CACR_Asian
# 399                               EOGReadingGr4_GLP_Asian
# 400                              EOGReadingGr4_CACR_Asian
# 401                               EOGReadingGr4_GLP_Asian
# 402                                  EOGMathGr5_GLP_Asian
# 403                              EOGReadingGr5_CACR_Asian
# 404                               EOGReadingGr5_GLP_Asian
# 405                              EOGScienceGr5_CACR_Asian
# 406                               EOGScienceGr5_GLP_Asian
# 407                            EOGScienceGr5&8_CACR_Asian
# 408                             EOGScienceGr5&8_GLP_Asian
# 409                              EOGReadingGr5_CACR_Asian
# 410                               EOGReadingGr5_GLP_Asian
# 411                              EOGScienceGr5_CACR_Asian
# 412                               EOGScienceGr5_GLP_Asian
# 413                            EOGScienceGr5&8_CACR_Asian
# 414                             EOGScienceGr5&8_GLP_Asian
# 415                               EOGReadingGr3_GLP_Asian
# 416                             EOGReadingGr3-8_GLP_Asian
# 417                               EOGReadingGr4_GLP_Asian
# 418                               EOGReadingGr5_GLP_Asian
# 419                              EOGScienceGr5_CACR_Asian
# 420                               EOGScienceGr5_GLP_Asian
# 421                            EOGScienceGr5&8_CACR_Asian
# 422                             EOGScienceGr5&8_GLP_Asian
# 423                              EOGScienceGr5_CACR_Asian
# 424                               EOGScienceGr5_GLP_Asian
# 425                            EOGScienceGr5&8_CACR_Asian
# 426                             EOGScienceGr5&8_GLP_Asian
# 427                               EOGScienceGr5_GLP_Asian
# 428                            EOGScienceGr5&8_CACR_Asian
# 429                             EOGScienceGr5&8_GLP_Asian
# 430                            EOGScienceGr5&8_CACR_Asian
# 431                             EOGScienceGr5&8_GLP_Asian
# 432                             EOGScienceGr5&8_GLP_Asian
# 433                                 EOGSubjects_GLP_Asian
# 434                             EOG/EOCSubjects_GLP_Black
# 435                                EOGSubjects_CACR_Black
# 436                                 EOGSubjects_GLP_Black
# 437                                EOGSubjects_CACR_Black
# 438                                 EOGSubjects_GLP_Black
# 439                                      EOGGr3_GLP_Black
# 440                                      EOGGr4_GLP_Black
# 441                                      EOGGr5_GLP_Black
# 442                                  EOGMathGr3_GLP_Black
# 443                                EOGMathGr3-8_GLP_Black
# 444                                  EOGMathGr4_GLP_Black
# 445                                  EOGMathGr5_GLP_Black
# 446                               EOGReadingGr3_GLP_Black
# 447                             EOGReadingGr3-8_GLP_Black
# 448                               EOGReadingGr4_GLP_Black
# 449                               EOGScienceGr5_GLP_Black
# 450                            EOGScienceGr5&8_CACR_Black
# 451                             EOGScienceGr5&8_GLP_Black
# 452                            EOGScienceGr5&8_CACR_Black
# 453                             EOGScienceGr5&8_GLP_Black
# 454                             EOGScienceGr5&8_GLP_Black
# 455                                 EOGSubjects_GLP_Black
# 456                          EOG/EOCSubjects_GLP_Hispanic
# 457                             EOGSubjects_CACR_Hispanic
# 458                              EOGSubjects_GLP_Hispanic
# 459                             EOGSubjects_CACR_Hispanic
# 460                              EOGSubjects_GLP_Hispanic
# 461                                   EOGGr3_GLP_Hispanic
# 462                                   EOGGr4_GLP_Hispanic
# 463                                   EOGGr5_GLP_Hispanic
# 464                               EOGMathGr3_GLP_Hispanic
# 465                             EOGMathGr3-8_GLP_Hispanic
# 466                               EOGMathGr4_GLP_Hispanic
# 467                               EOGMathGr5_GLP_Hispanic
# 468                            EOGScienceGr5_GLP_Hispanic
# 469                            EOGReadingGr3_GLP_Hispanic
# 470                          EOGReadingGr3-8_GLP_Hispanic
# 471                            EOGReadingGr4_GLP_Hispanic
# 472                            EOGReadingGr5_GLP_Hispanic
# 473                            EOGScienceGr5_GLP_Hispanic
# 474                         EOGScienceGr5&8_CACR_Hispanic
# 475                          EOGScienceGr5&8_GLP_Hispanic
# 476                         EOGScienceGr5&8_CACR_Hispanic
# 477                          EOGScienceGr5&8_GLP_Hispanic
# 478                          EOGScienceGr5&8_GLP_Hispanic
# 479                              EOGSubjects_GLP_Hispanic
# 480                    EOG/EOCSubjects_GLP_TwoorMoreRaces
# 481                       EOGSubjects_CACR_TwoorMoreRaces
# 482                        EOGSubjects_GLP_TwoorMoreRaces
# 483                       EOGSubjects_CACR_TwoorMoreRaces
# 484                        EOGSubjects_GLP_TwoorMoreRaces
# 485                             EOGGr3_GLP_TwoorMoreRaces
# 486                             EOGGr4_GLP_TwoorMoreRaces
# 487                             EOGGr5_GLP_TwoorMoreRaces
# 488                         EOGMathGr3_GLP_TwoorMoreRaces
# 489                      EOGReadingGr3_GLP_TwoorMoreRaces
# 490                      EOGReadingGr3_GLP_TwoorMoreRaces
# 491                       EOGMathGr3-8_GLP_TwoorMoreRaces
# 492                    EOGReadingGr3-8_GLP_TwoorMoreRaces
# 493                         EOGMathGr4_GLP_TwoorMoreRaces
# 494                     EOGReadingGr4_CACR_TwoorMoreRaces
# 495                      EOGReadingGr4_GLP_TwoorMoreRaces
# 496                     EOGReadingGr4_CACR_TwoorMoreRaces
# 497                      EOGReadingGr4_GLP_TwoorMoreRaces
# 498                         EOGMathGr5_GLP_TwoorMoreRaces
# 499                      EOGReadingGr5_GLP_TwoorMoreRaces
# ...                                                   ...
# 219039                  Tuition and fees deduction Ct All
# 219040                Tuition and fees deduction Ct LT25K
# 219041           Unemployment compensation Amt 100KLT200K
# 219042             Unemployment compensation Amt 25KLT50K
# 219043             Unemployment compensation Amt 50KLT75K
# 219044            Unemployment compensation Amt 75KLT100K
# 219045                  Unemployment compensation Amt All
# 219046                Unemployment compensation Amt LT25K
# 219047            Unemployment compensation Ct 100KLT200K
# 219048              Unemployment compensation Ct 25KLT50K
# 219049              Unemployment compensation Ct 50KLT75K
# 219050             Unemployment compensation Ct 75KLT100K
# 219051                   Unemployment compensation Ct All
# 219052                 Unemployment compensation Ct LT25K
# 219053      volunteer prepared w Earned Income Credit All
# 219054    volunteer prepared w Earned Income Credit LT25K
# 219055                           Tot tax payments Amt All
# 219056                        Tot tax payments Amt GE200K
# 219057                     Tot tax payments Ct 100KLT200K
# 219058                       Tot tax payments Ct 25KLT50K
# 219059                       Tot tax payments Ct 50KLT75K
# 219060                      Tot tax payments Ct 75KLT100K
# 219061                            Tot tax payments Ct All
# 219062                         Tot tax payments Ct GE200K
# 219063                          Tot tax payments Ct LT25K
# 219064          Tuition and fees deduction Amt 100KLT200K
# 219065            Tuition and fees deduction Amt 25KLT50K
# 219066            Tuition and fees deduction Amt 50KLT75K
# 219067                 Tuition and fees deduction Amt All
# 219068               Tuition and fees deduction Amt LT25K
# 219069           Tuition and fees deduction Ct 100KLT200K
# 219070             Tuition and fees deduction Ct 25KLT50K
# 219071             Tuition and fees deduction Ct 50KLT75K
# 219072                  Tuition and fees deduction Ct All
# 219073                Tuition and fees deduction Ct LT25K
# 219074           Unemployment compensation Amt 100KLT200K
# 219075             Unemployment compensation Amt 25KLT50K
# 219076             Unemployment compensation Amt 50KLT75K
# 219077            Unemployment compensation Amt 75KLT100K
# 219078                  Unemployment compensation Amt All
# 219079            Unemployment compensation Ct 100KLT200K
# 219080              Unemployment compensation Ct 25KLT50K
# 219081              Unemployment compensation Ct 50KLT75K
# 219082             Unemployment compensation Ct 75KLT100K
# 219083                   Unemployment compensation Ct All
# 219084      volunteer prepared w Earned Income Credit All
# 219085    volunteer prepared w Earned Income Credit LT25K
# 219086                        Tot tax payments Amt GE200K
# 219087                         Tot tax payments Amt LT25K
# 219088                     Tot tax payments Ct 100KLT200K
# 219089                       Tot tax payments Ct 25KLT50K
# 219090                       Tot tax payments Ct 50KLT75K
# 219091                      Tot tax payments Ct 75KLT100K
# 219092                            Tot tax payments Ct All
# 219093                         Tot tax payments Ct GE200K
# 219094                          Tot tax payments Ct LT25K
# 219095            Tuition and fees deduction Amt 25KLT50K
# 219096            Tuition and fees deduction Amt 50KLT75K
# 219097                 Tuition and fees deduction Amt All
# 219098               Tuition and fees deduction Amt LT25K
# 219099             Tuition and fees deduction Ct 25KLT50K
# 219100             Tuition and fees deduction Ct 50KLT75K
# 219101                  Tuition and fees deduction Ct All
# 219102                Tuition and fees deduction Ct LT25K
# 219103           Unemployment compensation Amt 100KLT200K
# 219104             Unemployment compensation Amt 25KLT50K
# 219105             Unemployment compensation Amt 50KLT75K
# 219106            Unemployment compensation Amt 75KLT100K
# 219107                  Unemployment compensation Amt All
# 219108                Unemployment compensation Amt LT25K
# 219109            Unemployment compensation Ct 100KLT200K
# 219110              Unemployment compensation Ct 25KLT50K
# 219111              Unemployment compensation Ct 50KLT75K
# 219112             Unemployment compensation Ct 75KLT100K
# 219113                   Unemployment compensation Ct All
# 219114                       Tot tax payments Ct 25KLT50K
# 219115                       Tot tax payments Ct 50KLT75K
# 219116                            Tot tax payments Ct All
# 219117                         Tot tax payments Ct GE200K
# 219118                          Tot tax payments Ct LT25K
# 219119            Tuition and fees deduction Amt 25KLT50K
# 219120            Tuition and fees deduction Amt 50KLT75K
# 219121                 Tuition and fees deduction Amt All
# 219122             Tuition and fees deduction Ct 50KLT75K
# 219123             Unemployment compensation Amt 25KLT50K
# 219124             Unemployment compensation Amt 50KLT75K
# 219125            Unemployment compensation Amt 75KLT100K
# 219126                  Unemployment compensation Amt All
# 219127                Unemployment compensation Amt LT25K
# 219128            Unemployment compensation Ct 100KLT200K
# 219129              Unemployment compensation Ct 25KLT50K
# 219130              Unemployment compensation Ct 50KLT75K
# 219131             Unemployment compensation Ct 75KLT100K
# 219132                   Unemployment compensation Ct All
# 219133                       Tot tax payments Ct 25KLT50K
# 219134                       Tot tax payments Ct 50KLT75K
# 219135                            Tot tax payments Ct All
# 219136                          Tot tax payments Ct LT25K
# 219137            Tuition and fees deduction Amt 25KLT50K
# 219138            Tuition and fees deduction Amt 50KLT75K
# 219139             Tuition and fees deduction Ct 25KLT50K
# 219140             Unemployment compensation Amt 25KLT50K
# 219141             Unemployment compensation Amt 50KLT75K
# 219142            Unemployment compensation Amt 75KLT100K
# 219143                  Unemployment compensation Amt All
# 219144                Unemployment compensation Amt LT25K
# 219145              Unemployment compensation Ct 25KLT50K
# 219146              Unemployment compensation Ct 50KLT75K
# 219147                   Unemployment compensation Ct All
# 219148                 Unemployment compensation Ct LT25K
# 219149                       Tot tax payments Ct 25KLT50K
# 219150                       Tot tax payments Ct 50KLT75K
# 219151                      Tot tax payments Ct 75KLT100K
# 219152                            Tot tax payments Ct All
# 219153                         Tot tax payments Ct GE200K
# 219154          Tuition and fees deduction Amt 100KLT200K
# 219155            Tuition and fees deduction Amt 50KLT75K
# 219156                 Tuition and fees deduction Amt All
# 219157               Tuition and fees deduction Amt LT25K
# 219158           Tuition and fees deduction Ct 100KLT200K
# 219159             Tuition and fees deduction Ct 25KLT50K
# 219160             Tuition and fees deduction Ct 50KLT75K
# 219161                  Tuition and fees deduction Ct All
# 219162                Tuition and fees deduction Ct LT25K
# 219163           Unemployment compensation Amt 100KLT200K
# 219164             Unemployment compensation Amt 50KLT75K
# 219165            Unemployment compensation Amt 75KLT100K
# 219166                  Unemployment compensation Amt All
# 219167               Unemployment compensation Amt GE200K
# 219168            Unemployment compensation Ct 100KLT200K
# 219169              Unemployment compensation Ct 50KLT75K
# 219170             Unemployment compensation Ct 75KLT100K
# 219171                   Unemployment compensation Ct All
# 219172                Unemployment compensation Ct GE200K
# 219173  volunteer prepared w Earned Income Credit 25KL...
# 219174      volunteer prepared w Earned Income Credit All
# 219175                       Tot tax payments Ct 50KLT75K
# 219176                      Tot tax payments Ct 75KLT100K
# 219177                            Tot tax payments Ct All
# 219178                         Tot tax payments Ct GE200K
# 219179                          Tot tax payments Ct LT25K
# 219180            Tuition and fees deduction Amt 25KLT50K
# 219181            Tuition and fees deduction Amt 50KLT75K
# 219182                 Tuition and fees deduction Amt All
# 219183               Tuition and fees deduction Amt LT25K
# 219184             Tuition and fees deduction Ct 25KLT50K
# 219185             Tuition and fees deduction Ct 50KLT75K
# 219186                  Tuition and fees deduction Ct All
# 219187                Tuition and fees deduction Ct LT25K
# 219188             Unemployment compensation Amt 25KLT50K
# 219189             Unemployment compensation Amt 50KLT75K
# 219190            Unemployment compensation Amt 75KLT100K
# 219191                  Unemployment compensation Amt All
# 219192                Unemployment compensation Amt LT25K
# 219193              Unemployment compensation Ct 25KLT50K
# 219194              Unemployment compensation Ct 50KLT75K
# 219195             Unemployment compensation Ct 75KLT100K
# 219196                   Unemployment compensation Ct All
# 219197                 Unemployment compensation Ct LT25K
# 219198    volunteer prepared w Earned Income Credit LT25K
# 219199                      Tot tax payments Ct 75KLT100K
# 219200                            Tot tax payments Ct All
# 219201                         Tot tax payments Ct GE200K
# 219202                          Tot tax payments Ct LT25K
# 219203          Tuition and fees deduction Amt 100KLT200K
# 219204            Tuition and fees deduction Amt 25KLT50K
# 219205            Tuition and fees deduction Amt 50KLT75K
# 219206                 Tuition and fees deduction Amt All
# 219207               Tuition and fees deduction Amt LT25K
# 219208             Tuition and fees deduction Ct 25KLT50K
# 219209             Tuition and fees deduction Ct 50KLT75K
# 219210                  Tuition and fees deduction Ct All
# 219211                Tuition and fees deduction Ct LT25K
# 219212           Unemployment compensation Amt 100KLT200K
# 219213             Unemployment compensation Amt 25KLT50K
# 219214             Unemployment compensation Amt 50KLT75K
# 219215            Unemployment compensation Amt 75KLT100K
# 219216                  Unemployment compensation Amt All
# 219217                Unemployment compensation Amt LT25K
# 219218            Unemployment compensation Ct 100KLT200K
# 219219              Unemployment compensation Ct 25KLT50K
# 219220              Unemployment compensation Ct 50KLT75K
# 219221             Unemployment compensation Ct 75KLT100K
# 219222                   Unemployment compensation Ct All
# 219223                 Unemployment compensation Ct LT25K
# 219224      volunteer prepared w Earned Income Credit All
# 219225    volunteer prepared w Earned Income Credit LT25K
# 219226                            Tot tax payments Ct All
# 219227                         Tot tax payments Ct GE200K
# 219228                          Tot tax payments Ct LT25K
# 219229          Tuition and fees deduction Amt 100KLT200K
# 219230            Tuition and fees deduction Amt 25KLT50K
# 219231            Tuition and fees deduction Amt 50KLT75K
# 219232                 Tuition and fees deduction Amt All
# 219233               Tuition and fees deduction Amt LT25K
# 219234           Tuition and fees deduction Ct 100KLT200K
# 219235             Tuition and fees deduction Ct 25KLT50K
# 219236             Tuition and fees deduction Ct 50KLT75K
# 219237                  Tuition and fees deduction Ct All
# 219238                Tuition and fees deduction Ct LT25K
# 219239           Unemployment compensation Amt 100KLT200K
# 219240             Unemployment compensation Amt 25KLT50K
# 219241             Unemployment compensation Amt 50KLT75K
# 219242            Unemployment compensation Amt 75KLT100K
# 219243                  Unemployment compensation Amt All
# 219244            Unemployment compensation Ct 100KLT200K
# 219245              Unemployment compensation Ct 25KLT50K
# 219246              Unemployment compensation Ct 50KLT75K
# 219247             Unemployment compensation Ct 75KLT100K
# 219248                   Unemployment compensation Ct All
# 219249      volunteer prepared w Earned Income Credit All
# 219250    volunteer prepared w Earned Income Credit LT25K
# 219251                         Tot tax payments Ct GE200K
# 219252                          Tot tax payments Ct LT25K
# 219253          Tuition and fees deduction Amt 100KLT200K
# 219254            Tuition and fees deduction Amt 25KLT50K
# 219255            Tuition and fees deduction Amt 50KLT75K
# 219256                 Tuition and fees deduction Amt All
# 219257               Tuition and fees deduction Amt LT25K
# 219258             Tuition and fees deduction Ct 25KLT50K
# 219259             Tuition and fees deduction Ct 50KLT75K
# 219260                  Tuition and fees deduction Ct All
# 219261                Tuition and fees deduction Ct LT25K
# 219262           Unemployment compensation Amt 100KLT200K
# 219263             Unemployment compensation Amt 25KLT50K
# 219264             Unemployment compensation Amt 50KLT75K
# 219265            Unemployment compensation Amt 75KLT100K
# 219266                  Unemployment compensation Amt All
# 219267                Unemployment compensation Amt LT25K
# 219268            Unemployment compensation Ct 100KLT200K
# 219269              Unemployment compensation Ct 25KLT50K
# 219270              Unemployment compensation Ct 50KLT75K
# 219271             Unemployment compensation Ct 75KLT100K
# 219272                   Unemployment compensation Ct All
# 219273                 Unemployment compensation Ct LT25K
# 219274      volunteer prepared w Earned Income Credit All
# 219275    volunteer prepared w Earned Income Credit LT25K
# 219276                          Tot tax payments Ct LT25K
# 219277          Tuition and fees deduction Amt 100KLT200K
# 219278            Tuition and fees deduction Amt 25KLT50K
# 219279            Tuition and fees deduction Amt 50KLT75K
# 219280                 Tuition and fees deduction Amt All
# 219281               Tuition and fees deduction Amt LT25K
# 219282           Tuition and fees deduction Ct 100KLT200K
# 219283             Tuition and fees deduction Ct 25KLT50K
# 219284             Tuition and fees deduction Ct 50KLT75K
# 219285                  Tuition and fees deduction Ct All
# 219286                Tuition and fees deduction Ct LT25K
# 219287           Unemployment compensation Amt 100KLT200K
# 219288             Unemployment compensation Amt 25KLT50K
# 219289             Unemployment compensation Amt 50KLT75K
# 219290            Unemployment compensation Amt 75KLT100K
# 219291                  Unemployment compensation Amt All
# 219292               Unemployment compensation Amt GE200K
# 219293            Unemployment compensation Ct 100KLT200K
# 219294              Unemployment compensation Ct 25KLT50K
# 219295              Unemployment compensation Ct 50KLT75K
# 219296             Unemployment compensation Ct 75KLT100K
# 219297                   Unemployment compensation Ct All
# 219298            Tuition and fees deduction Amt 25KLT50K
# 219299            Tuition and fees deduction Amt 50KLT75K
# 219300                 Tuition and fees deduction Amt All
# 219301               Tuition and fees deduction Amt LT25K
# 219302             Tuition and fees deduction Ct 25KLT50K
# 219303             Tuition and fees deduction Ct 50KLT75K
# 219304                  Tuition and fees deduction Ct All
# 219305                Tuition and fees deduction Ct LT25K
# 219306             Unemployment compensation Amt 25KLT50K
# 219307             Unemployment compensation Amt 50KLT75K
# 219308            Unemployment compensation Amt 75KLT100K
# 219309                  Unemployment compensation Amt All
# 219310                Unemployment compensation Amt LT25K
# 219311              Unemployment compensation Ct 25KLT50K
# 219312              Unemployment compensation Ct 50KLT75K
# 219313             Unemployment compensation Ct 75KLT100K
# 219314                   Unemployment compensation Ct All
# 219315                 Unemployment compensation Ct LT25K
# 219316    volunteer prepared w Earned Income Credit LT25K
# 219317            Tuition and fees deduction Amt 50KLT75K
# 219318                 Tuition and fees deduction Amt All
# 219319               Tuition and fees deduction Amt LT25K
# 219320           Tuition and fees deduction Ct 100KLT200K
# 219321             Tuition and fees deduction Ct 50KLT75K
# 219322                  Tuition and fees deduction Ct All
# ...
# 219321          Tuition and fees deduction Amt 100KLT200K     0.966401
# 219322          Tuition and fees deduction Amt 100KLT200K     0.980991
# 219323          Tuition and fees deduction Amt 100KLT200K     0.960951
# 219324          Tuition and fees deduction Amt 100KLT200K     0.982677
# 219325          Tuition and fees deduction Amt 100KLT200K     0.957184
# 219326          Tuition and fees deduction Amt 100KLT200K     0.969667
# 219327          Tuition and fees deduction Amt 100KLT200K     0.979647
# 219328          Tuition and fees deduction Amt 100KLT200K     0.960831
# 219329          Tuition and fees deduction Amt 100KLT200K     0.970481
# 219330          Tuition and fees deduction Amt 100KLT200K     0.957417
# 219331            Tuition and fees deduction Amt 25KLT50K     0.981966
# 219332            Tuition and fees deduction Amt 25KLT50K     0.979599
# 219333            Tuition and fees deduction Amt 25KLT50K     0.976040
# 219334            Tuition and fees deduction Amt 25KLT50K     0.996702
# 219335            Tuition and fees deduction Amt 25KLT50K     0.979226
# 219336            Tuition and fees deduction Amt 25KLT50K     0.976294
# 219337            Tuition and fees deduction Amt 25KLT50K     0.978918
# 219338            Tuition and fees deduction Amt 25KLT50K     0.984118
# 219339            Tuition and fees deduction Amt 25KLT50K     0.981676
# 219340            Tuition and fees deduction Amt 25KLT50K     0.979558
# 219341            Tuition and fees deduction Amt 25KLT50K     0.986643
# 219342            Tuition and fees deduction Amt 25KLT50K     0.977347
# 219343            Tuition and fees deduction Amt 25KLT50K     0.987219
# 219344            Tuition and fees deduction Amt 25KLT50K     0.981517
# 219345            Tuition and fees deduction Amt 25KLT50K     0.978878
# 219346            Tuition and fees deduction Amt 25KLT50K     0.988315
# 219347            Tuition and fees deduction Amt 25KLT50K     0.967917
# 219348            Tuition and fees deduction Amt 50KLT75K     0.991378
# 219349            Tuition and fees deduction Amt 50KLT75K     0.983662
# 219350            Tuition and fees deduction Amt 50KLT75K     0.978000
# 219351            Tuition and fees deduction Amt 50KLT75K     0.998683
# 219352            Tuition and fees deduction Amt 50KLT75K     0.988850
# 219353            Tuition and fees deduction Amt 50KLT75K     0.984905
# 219354            Tuition and fees deduction Amt 50KLT75K     0.972525
# 219355            Tuition and fees deduction Amt 50KLT75K     0.982613
# 219356            Tuition and fees deduction Amt 50KLT75K     0.986782
# 219357            Tuition and fees deduction Amt 50KLT75K     0.985611
# 219358            Tuition and fees deduction Amt 50KLT75K     0.988389
# 219359            Tuition and fees deduction Amt 50KLT75K     0.958634
# 219360            Tuition and fees deduction Amt 50KLT75K     0.977227
# 219361            Tuition and fees deduction Amt 50KLT75K     0.981420
# 219362            Tuition and fees deduction Amt 50KLT75K     0.984992
# 219363            Tuition and fees deduction Amt 50KLT75K     0.982761
# 219364            Tuition and fees deduction Amt 50KLT75K     0.984722
# 219365           Tuition and fees deduction Amt 75KLT100K     0.992872
# 219366                 Tuition and fees deduction Amt All     0.996417
# 219367                 Tuition and fees deduction Amt All     0.968391
# 219368                 Tuition and fees deduction Amt All     0.980143
# 219369                 Tuition and fees deduction Amt All     0.994707
# 219370                 Tuition and fees deduction Amt All     0.998927
# 219371                 Tuition and fees deduction Amt All     0.997049
# 219372                 Tuition and fees deduction Amt All     0.972694
# 219373                 Tuition and fees deduction Amt All     0.966400
# 219374                 Tuition and fees deduction Amt All     0.978028
# 219375                 Tuition and fees deduction Amt All     0.982334
# 219376                 Tuition and fees deduction Amt All     0.975577
# 219377                 Tuition and fees deduction Amt All     0.974755
# 219378                 Tuition and fees deduction Amt All     0.969532
# 219379                 Tuition and fees deduction Amt All     0.979356
# 219380                 Tuition and fees deduction Amt All     0.983327
# 219381                 Tuition and fees deduction Amt All     0.974016
# 219382                 Tuition and fees deduction Amt All     0.961806
# 219383                 Tuition and fees deduction Amt All     0.961318
# 219384               Tuition and fees deduction Amt LT25K     0.952028
# 219385               Tuition and fees deduction Amt LT25K     0.973491
# 219386               Tuition and fees deduction Amt LT25K     0.986292
# 219387               Tuition and fees deduction Amt LT25K     0.992790
# 219388               Tuition and fees deduction Amt LT25K     0.999009
# 219389               Tuition and fees deduction Amt LT25K     0.954426
# 219390               Tuition and fees deduction Amt LT25K     0.958588
# 219391               Tuition and fees deduction Amt LT25K     0.968467
# 219392               Tuition and fees deduction Amt LT25K     0.969882
# 219393               Tuition and fees deduction Amt LT25K     0.966913
# 219394               Tuition and fees deduction Amt LT25K     0.956728
# 219395               Tuition and fees deduction Amt LT25K     0.963403
# 219396               Tuition and fees deduction Amt LT25K     0.970054
# 219397               Tuition and fees deduction Amt LT25K     0.971449
# 219398               Tuition and fees deduction Amt LT25K     0.967689
# 219399               Tuition and fees deduction Amt LT25K     0.964519
# 219400               Tuition and fees deduction Amt LT25K     0.966491
# 219401           Tuition and fees deduction Ct 100KLT200K     0.960215
# 219402           Tuition and fees deduction Ct 100KLT200K     0.976603
# 219403           Tuition and fees deduction Ct 100KLT200K     0.955000
# 219404           Tuition and fees deduction Ct 100KLT200K     0.979423
# 219405           Tuition and fees deduction Ct 100KLT200K     0.952135
# 219406           Tuition and fees deduction Ct 100KLT200K     0.969958
# 219407           Tuition and fees deduction Ct 100KLT200K     0.975687
# 219408           Tuition and fees deduction Ct 100KLT200K     0.956223
# 219409           Tuition and fees deduction Ct 100KLT200K     0.971155
# 219410           Tuition and fees deduction Ct 100KLT200K     0.958930
# 219411             Tuition and fees deduction Ct 25KLT50K     0.978316
# 219412             Tuition and fees deduction Ct 25KLT50K     0.980107
# 219413             Tuition and fees deduction Ct 25KLT50K     0.978071
# 219414             Tuition and fees deduction Ct 25KLT50K     0.978624
# 219415             Tuition and fees deduction Ct 25KLT50K     0.980537
# 219416             Tuition and fees deduction Ct 25KLT50K     0.982807
# 219417             Tuition and fees deduction Ct 25KLT50K     0.983250
# 219418             Tuition and fees deduction Ct 25KLT50K     0.967152
# 219419             Tuition and fees deduction Ct 25KLT50K     0.982605
# 219420             Tuition and fees deduction Ct 25KLT50K     0.981682
# 219421             Tuition and fees deduction Ct 25KLT50K     0.982646
# 219422             Tuition and fees deduction Ct 25KLT50K     0.984121
# 219423             Tuition and fees deduction Ct 25KLT50K     0.955891
# 219424             Tuition and fees deduction Ct 25KLT50K     0.952749
# 219425             Tuition and fees deduction Ct 50KLT75K     0.993950
# 219426             Tuition and fees deduction Ct 50KLT75K     0.988152
# 219427             Tuition and fees deduction Ct 50KLT75K     0.978083
# 219428             Tuition and fees deduction Ct 50KLT75K     0.977378
# 219429             Tuition and fees deduction Ct 50KLT75K     0.985666
# 219430             Tuition and fees deduction Ct 50KLT75K     0.987255
# 219431             Tuition and fees deduction Ct 50KLT75K     0.985092
# 219432             Tuition and fees deduction Ct 50KLT75K     0.981504
# 219433             Tuition and fees deduction Ct 50KLT75K     0.977295
# 219434             Tuition and fees deduction Ct 50KLT75K     0.985069
# 219435             Tuition and fees deduction Ct 50KLT75K     0.985599
# 219436             Tuition and fees deduction Ct 50KLT75K     0.981453
# 219437                  Tuition and fees deduction Ct All     0.994900
# 219438                  Tuition and fees deduction Ct All     0.977475
# 219439                  Tuition and fees deduction Ct All     0.963966
# 219440                  Tuition and fees deduction Ct All     0.978160
# 219441                  Tuition and fees deduction Ct All     0.984867
# 219442                  Tuition and fees deduction Ct All     0.974229
# 219443                  Tuition and fees deduction Ct All     0.978708
# 219444                  Tuition and fees deduction Ct All     0.967275
# 219445                  Tuition and fees deduction Ct All     0.980118
# 219446                  Tuition and fees deduction Ct All     0.986323
# 219447                  Tuition and fees deduction Ct All     0.972091
# 219448                  Tuition and fees deduction Ct All     0.964195
# 219449                  Tuition and fees deduction Ct All     0.962142
# 219450                Tuition and fees deduction Ct LT25K     0.958199
# 219451                Tuition and fees deduction Ct LT25K     0.964761
# 219452                Tuition and fees deduction Ct LT25K     0.974843
# 219453                Tuition and fees deduction Ct LT25K     0.976607
# 219454                Tuition and fees deduction Ct LT25K     0.972828
# 219455                Tuition and fees deduction Ct LT25K     0.960436
# 219456                Tuition and fees deduction Ct LT25K     0.969575
# 219457                Tuition and fees deduction Ct LT25K     0.976685
# 219458                Tuition and fees deduction Ct LT25K     0.978347
# 219459                Tuition and fees deduction Ct LT25K     0.973667
# 219460                Tuition and fees deduction Ct LT25K     0.967487
# 219461                Tuition and fees deduction Ct LT25K     0.969706
# 219462           Unemployment compensation Amt 100KLT200K     0.966988
# 219463           Unemployment compensation Amt 100KLT200K     0.974452
# 219464           Unemployment compensation Amt 100KLT200K     0.957306
# 219465           Unemployment compensation Amt 100KLT200K     0.977307
# 219466           Unemployment compensation Amt 100KLT200K     0.999460
# 219467           Unemployment compensation Amt 100KLT200K     0.965520
# 219468           Unemployment compensation Amt 100KLT200K     0.973296
# 219469           Unemployment compensation Amt 100KLT200K     0.975243
# 219470             Unemployment compensation Amt 25KLT50K     0.994832
# 219471             Unemployment compensation Amt 25KLT50K     0.983887
# 219472             Unemployment compensation Amt 25KLT50K     0.998526
# 219473             Unemployment compensation Amt 25KLT50K     0.986636
# 219474             Unemployment compensation Amt 25KLT50K     0.952955
# 219475             Unemployment compensation Amt 25KLT50K     0.998543
# 219476             Unemployment compensation Amt 25KLT50K     0.992443
# 219477             Unemployment compensation Amt 25KLT50K     0.980589
# 219478             Unemployment compensation Amt 25KLT50K     0.997720
# 219479             Unemployment compensation Amt 25KLT50K     0.975067
# 219480             Unemployment compensation Amt 50KLT75K     0.992686
# 219481             Unemployment compensation Amt 50KLT75K     0.997479
# 219482             Unemployment compensation Amt 50KLT75K     0.971244
# 219483             Unemployment compensation Amt 50KLT75K     0.971678
# 219484             Unemployment compensation Amt 50KLT75K     0.993801
# 219485             Unemployment compensation Amt 50KLT75K     0.998870
# 219486             Unemployment compensation Amt 50KLT75K     0.991090
# 219487             Unemployment compensation Amt 50KLT75K     0.995082
# 219488             Unemployment compensation Amt 50KLT75K     0.957169
# 219489            Unemployment compensation Amt 75KLT100K     0.990032
# 219490            Unemployment compensation Amt 75KLT100K     0.954531
# 219491            Unemployment compensation Amt 75KLT100K     0.977507
# 219492            Unemployment compensation Amt 75KLT100K     0.983225
# 219493            Unemployment compensation Amt 75KLT100K     0.992225
# 219494            Unemployment compensation Amt 75KLT100K     0.998817
# 219495            Unemployment compensation Amt 75KLT100K     0.985731
# 219496                  Unemployment compensation Amt All     0.983115
# 219497                  Unemployment compensation Amt All     0.963401
# 219498                  Unemployment compensation Amt All     0.997304
# 219499                  Unemployment compensation Amt All     0.995324
# 219500                  Unemployment compensation Amt All     0.987074
# 219501                  Unemployment compensation Amt All     0.998462
# 219502                  Unemployment compensation Amt All     0.970281
# 219503               Unemployment compensation Amt GE200K     0.973761
# 219504               Unemployment compensation Amt GE200K     0.999786
# 219505                Unemployment compensation Amt LT25K     0.987112
# 219506                Unemployment compensation Amt LT25K     0.968050
# 219507                Unemployment compensation Amt LT25K     0.987281
# 219508                Unemployment compensation Amt LT25K     0.996186
# 219509            Unemployment compensation Ct 100KLT200K     0.970124
# 219510            Unemployment compensation Ct 100KLT200K     0.975968
# 219511            Unemployment compensation Ct 100KLT200K     0.953391
# 219512            Unemployment compensation Ct 100KLT200K     0.971259
# 219513              Unemployment compensation Ct 25KLT50K     0.993455
# 219514              Unemployment compensation Ct 25KLT50K     0.981500
# 219515              Unemployment compensation Ct 25KLT50K     0.998950
# 219516              Unemployment compensation Ct 25KLT50K     0.978760
# 219517              Unemployment compensation Ct 50KLT75K     0.992121
# 219518              Unemployment compensation Ct 50KLT75K     0.994581
# 219519              Unemployment compensation Ct 50KLT75K     0.956019
# 219520             Unemployment compensation Ct 75KLT100K     0.984127
# 219521                   Unemployment compensation Ct All     0.979082
# 219522  volunteer prepared w Earned Income Credit 25KL...     0.979433
# 219523  volunteer prepared w Earned Income Credit 25KL...     0.964165
# 219524      volunteer prepared w Earned Income Credit All     0.997865
# 219525                                      category_cd_E     0.970235
# 219526                                      category_cd_E     1.000000
# 219527                                      category_cd_E     0.970235
# 219528                                      category_cd_I     0.970235
# 219529                                      category_cd_I     1.000000
# 219530  calendar_type_txt_Regular School, Traditional ...     1.000000
# 219531  calendar_type_txt_Regular School, Traditional ...     1.000000
# 219532  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 219533  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 219534                                  sna_pgm_type_cd_X     1.000000
# 219535                                  sna_pgm_type_cd_Y     1.000000
# 219536                                     SPG Grade_A+NG     0.964148
# 219537                                      Category_Cd_E     0.970235
# 219538                                            Byod_No     0.978269
#
# [219539 rows x 3 columns]

# %%
print ('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  1067  highly correlated fields.
# ['Reading SPG Grade',
#  'Math SPG Grade',
#  'Overall Achievement Score',
#  'Reading Score',
#  'Math Score',
#  'EOG/EOCSubjects_CACR_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_CACR_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_CACR_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_CACR_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGReadingGr5_CACR_AmericanIndian',
#  'EOGReadingGr5_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_CACR_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_CACR_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_CACR_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_CACR_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_CACR_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr3_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGReadingGr3_GLP_Black',
#  'EOGReadingGr3-8_GLP_Black',
#  'EOGReadingGr4_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_CACR_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_CACR_Black',
#  'EOGSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_Hispanic',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGReadingGr3_GLP_Hispanic',
#  'EOGReadingGr3-8_GLP_Hispanic',
#  'EOGReadingGr4_GLP_Hispanic',
#  'EOGReadingGr5_GLP_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_CACR_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_CACR_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr3-8_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_CACR_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_CACR_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_CACR_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_CACR_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_CACR_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_CACR_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_CACR_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_LEP',
#  'EOGGr3_GLP_LEP',
#  'EOGGr4_GLP_LEP',
#  'EOGGr5_GLP_LEP',
#  'EOGMathGr3_GLP_LEP',
#  'EOGMathGr3-8_GLP_LEP',
#  'EOGMathGr4_GLP_LEP',
#  'EOGMathGr5_GLP_LEP',
#  'EOGReadingGr3_GLP_LEP',
#  'EOGScienceGr5_GLP_LEP',
#  'EOGScienceGr5&8_CACR_LEP',
#  'EOGScienceGr5&8_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOGSubjects_GLP_LEP',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGMathGr4_GLP_SWD',
#  'EOGScienceGr5&8_CACR_SWD',
#  'EOGScienceGr5&8_GLP_SWD',
#  'EOGSubjects_CACR_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_CACR_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_CACR_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'ReadingGr3-8_pTarget_PctMet',
#  'TotalTargets_pTarget_PctMet',
#  'st_short_susp_per_c_num',
#  'lea_class_teach_num',
#  'lea_not_highqual_class_all_pct',
#  'st_flicensed_teach_pct',
#  'st_tchyrs_0thru3_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_class_teach_num',
#  'st_nbpts_num',
#  'st_advance_dgr_pct',
#  'st_1yr_tchr_trnovr_pct',
#  'st_emer_prov_teach_pct',
#  'st_lateral_teach_pct',
#  'st_highqual_class_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'Not Demostrated_TCHR_Standard 3_Pct',
#  'Not Demostrated_TCHR_Standard 5_Pct',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'HispanicMalePct',
#  'BlackMalePct',
#  'WhiteMalePct',
#  'MinorityMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'HispanicFemalePct',
#  'BlackFemalePct',
#  'WhiteFemalePct',
#  'MinorityFemalePct',
#  'Assault Rate',
#  '(TCE) prepared returns Ct 50KLT75K',
#  '(TCE) prepared returns Ct All',
#  '(TCE) prepared returns Ct LT25K',
#  '(VITA) prepared returns Ct 75KLT100K',
#  '(VITA) prepared returns Ct All',
#  '(VITA) prepared returns Ct LT25K',
#  'Add Medicare tax Amt 100KLT200K',
#  'Add Medicare tax Amt All',
#  'Add Medicare tax Amt GE200K',
#  'Add Medicare tax Ct 100KLT200K',
#  'Add Medicare tax Ct All',
#  'Add Medicare tax Ct GE200K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt 75KLT100K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Advance premium tax credit Amt 100KLT200K',
#  'Advance premium tax credit Amt 25KLT50K',
#  'Advance premium tax credit Amt 50KLT75K',
#  'Advance premium tax credit Amt 75KLT100K',
#  'Advance premium tax credit Amt All',
#  'Advance premium tax credit Amt LT25K',
#  'Advance premium tax credit Ct 100KLT200K',
#  'Advance premium tax credit Ct 25KLT50K',
#  'Advance premium tax credit Ct 50KLT75K',
#  'Advance premium tax credit Ct 75KLT100K',
#  'Advance premium tax credit Ct All',
#  'Advance premium tax credit Ct LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct 75KLT100K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Alternative minimum tax Ct LT25K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Contributions Amt 100KLT200K',
#  'Contributions Amt 25KLT50K',
#  'Contributions Amt 50KLT75K',
#  'Contributions Amt 75KLT100K',
#  'Contributions Amt All',
#  'Contributions Amt GE200K',
#  'Contributions Amt LT25K',
#  'Contributions Ct 100KLT200K',
#  'Contributions Ct 25KLT50K',
#  'Contributions Ct 50KLT75K',
#  'Contributions Ct 75KLT100K',
#  'Contributions Ct All',
#  'Contributions Ct GE200K',
#  'Contributions Ct LT25K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Amt LT25K',
#  'Domestic production activities deduction Ct 100KLT200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Domestic production activities deduction Ct LT25K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct 50KLT75K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess advance premium tax credit repayment Amt 100KLT200K',
#  'Excess advance premium tax credit repayment Amt 25KLT50K',
#  'Excess advance premium tax credit repayment Amt 50KLT75K',
#  'Excess advance premium tax credit repayment Amt 75KLT100K',
#  'Excess advance premium tax credit repayment Amt All',
#  'Excess advance premium tax credit repayment Amt LT25K',
#  'Excess advance premium tax credit repayment Ct 100KLT200K',
#  'Excess advance premium tax credit repayment Ct 25KLT50K',
#  'Excess advance premium tax credit repayment Ct 50KLT75K',
#  'Excess advance premium tax credit repayment Ct 75KLT100K',
#  'Excess advance premium tax credit repayment Ct All',
#  'Excess advance premium tax credit repayment Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct 50KLT75K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'Health care individual responsibility payment Amt 100KLT200K',
#  'Health care individual responsibility payment Amt 25KLT50K',
#  'Health care individual responsibility payment Amt 50KLT75K',
#  'Health care individual responsibility payment Amt 75KLT100K',
#  'Health care individual responsibility payment Amt All',
#  'Health care individual responsibility payment Amt LT25K',
#  'Health care individual responsibility payment Ct 100KLT200K',
#  'Health care individual responsibility payment Ct 25KLT50K',
#  'Health care individual responsibility payment Ct 50KLT75K',
#  'Health care individual responsibility payment Ct 75KLT100K',
#  'Health care individual responsibility payment Ct All',
#  'Health care individual responsibility payment Ct LT25K',
#  'IRA payments Amt 100KLT200K',
#  'IRA payments Amt 25KLT50K',
#  'IRA payments Amt 50KLT75K',
#  'IRA payments Amt 75KLT100K',
#  'IRA payments Amt All',
#  'IRA payments Amt GE200K',
#  'IRA payments Amt LT25K',
#  'IRA payments Ct 100KLT200K',
#  'IRA payments Ct 25KLT50K',
#  'IRA payments Ct 50KLT75K',
#  'IRA payments Ct 75KLT100K',
#  'IRA payments Ct All',
#  'IRA payments Ct GE200K',
#  'IRA payments Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Mortgage interest paid Amt 100KLT200K',
#  'Mortgage interest paid Amt 25KLT50K',
#  'Mortgage interest paid Amt 50KLT75K',
#  'Mortgage interest paid Amt 75KLT100K',
#  'Mortgage interest paid Amt All',
#  'Mortgage interest paid Amt GE200K',
#  'Mortgage interest paid Amt LT25K',
#  'Mortgage interest paid Ct 100KLT200K',
#  'Mortgage interest paid Ct 25KLT50K',
#  'Mortgage interest paid Ct 50KLT75K',
#  'Mortgage interest paid Ct 75KLT100K',
#  'Mortgage interest paid Ct All',
#  'Mortgage interest paid Ct GE200K',
#  'Mortgage interest paid Ct LT25K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct 100KLT200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Net premium tax credit Amt 25KLT50K',
#  'Net premium tax credit Amt 50KLT75K',
#  'Net premium tax credit Amt All',
#  'Net premium tax credit Amt LT25K',
#  'Net premium tax credit Ct 25KLT50K',
#  'Net premium tax credit Ct 50KLT75K',
#  'Net premium tax credit Ct All',
#  'Net premium tax credit Ct LT25K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of elderly returns 100KLT200K',
#  'Number of elderly returns 25KLT50K',
#  'Number of elderly returns 50KLT75K',
#  'Number of elderly returns 75KLT100K',
#  'Number of elderly returns All',
#  'Number of elderly returns GE200K',
#  'Number of elderly returns LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of refund anticipation check returns 100KLT200K',
#  'Number of refund anticipation check returns 25KLT50K',
#  'Number of refund anticipation check returns 50KLT75K',
#  'Number of refund anticipation check returns 75KLT100K',
#  'Number of refund anticipation check returns All',
#  'Number of refund anticipation check returns GE200K',
#  'Number of refund anticipation check returns LT25K',
#  'Number of refund anticipation loan returns 25KLT50K',
#  'Number of refund anticipation loan returns All',
#  'Number of refund anticipation loan returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  'Number of volunteer prepared returns Tot 100KLT200K',
#  'Number of volunteer prepared returns Tot 25KLT50K',
#  'Number of volunteer prepared returns Tot 75KLT100K',
#  'Number of volunteer prepared returns Tot All',
#  'Number of volunteer prepared returns Tot LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Residential energy tax credit Ct LT25K',
#  'Retirement savings contribution credit Amt 25KLT50K',
#  'Retirement savings contribution credit Amt 50KLT75K',
#  'Retirement savings contribution credit Amt All',
#  'Retirement savings contribution credit Amt LT25K',
#  'Retirement savings contribution credit Ct 25KLT50K',
#  'Retirement savings contribution credit Ct 50KLT75K',
#  'Retirement savings contribution credit Ct All',
#  'Retirement savings contribution credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employment health insurance deduction Amt 100KLT200K',
#  'Self-employment health insurance deduction Amt 25KLT50K',
#  'Self-employment health insurance deduction Amt 50KLT75K',
#  'Self-employment health insurance deduction Amt 75KLT100K',
#  'Self-employment health insurance deduction Amt All',
#  'Self-employment health insurance deduction Amt GE200K',
#  'Self-employment health insurance deduction Amt LT25K',
#  'Self-employment health insurance deduction Ct 100KLT200K',
#  'Self-employment health insurance deduction Ct 25KLT50K',
#  'Self-employment health insurance deduction Ct 50KLT75K',
#  'Self-employment health insurance deduction Ct 75KLT100K',
#  'Self-employment health insurance deduction Ct All',
#  'Self-employment health insurance deduction Ct GE200K',
#  'Self-employment health insurance deduction Ct LT25K',
#  'Self-employment retirement plans Amt 100KLT200K',
#  'Self-employment retirement plans Amt 25KLT50K',
#  'Self-employment retirement plans Amt 50KLT75K',
#  'Self-employment retirement plans Amt All',
#  'Self-employment retirement plans Amt GE200K',
#  'Self-employment retirement plans Amt LT25K',
#  'Self-employment retirement plans Ct 100KLT200K',
#  'Self-employment retirement plans Ct 25KLT50K',
#  'Self-employment retirement plans Ct 50KLT75K',
#  'Self-employment retirement plans Ct 75KLT100K',
#  'Self-employment retirement plans Ct All',
#  'Self-employment retirement plans Ct GE200K',
#  'Self-employment retirement plans Ct LT25K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  'Taxable interest Ct 100KLT200K',
#  'Taxable interest Ct 25KLT50K',
#  'Taxable interest Ct 50KLT75K',
#  'Taxable interest Ct 75KLT100K',
#  'Taxable interest Ct All',
#  'Taxable interest Ct GE200K',
#  'Taxable interest Ct LT25K',
#  'Taxes paid Amt 100KLT200K',
#  'Taxes paid Amt 25KLT50K',
#  'Taxes paid Amt 50KLT75K',
#  'Taxes paid Amt 75KLT100K',
#  'Taxes paid Amt All',
#  'Taxes paid Amt GE200K',
#  'Taxes paid Amt LT25K',
#  'Taxes paid Ct 100KLT200K',
#  'Taxes paid Ct 25KLT50K',
#  'Taxes paid Ct 50KLT75K',
#  'Taxes paid Ct 75KLT100K',
#  'Taxes paid Ct All',
#  'Taxes paid Ct GE200K',
#  'Taxes paid Ct LT25K',
#  'Tot income Amt 100KLT200K',
#  'Tot income Amt 25KLT50K',
#  'Tot income Amt 50KLT75K',
#  'Tot income Amt 75KLT100K',
#  'Tot income Amt All',
#  'Tot income Amt GE200K',
#  'Tot income Amt LT25K',
#  'Tot income Ct 100KLT200K',
#  'Tot income Ct 25KLT50K',
#  'Tot income Ct 50KLT75K',
#  'Tot income Ct 75KLT100K',
#  'Tot income Ct All',
#  'Tot income Ct GE200K',
#  'Tot income Ct LT25K',
#  'Tot itemized deductions Amt 100KLT200K',
#  'Tot itemized deductions Amt 25KLT50K',
#  'Tot itemized deductions Amt 50KLT75K',
#  'Tot itemized deductions Amt 75KLT100K',
#  'Tot itemized deductions Amt All',
#  'Tot itemized deductions Amt GE200K',
#  'Tot itemized deductions Amt LT25K',
#  'Tot itemized deductions Amt of AGI 100KLT200K',
#  'Tot itemized deductions Amt of AGI 25KLT50K',
#  'Tot itemized deductions Amt of AGI 50KLT75K',
#  'Tot itemized deductions Amt of AGI 75KLT100K',
#  'Tot itemized deductions Amt of AGI All',
#  'Tot itemized deductions Amt of AGI GE200K',
#  'Tot itemized deductions Amt of AGI LT25K',
#  'Tot itemized deductions Ct 100KLT200K',
#  'Tot itemized deductions Ct 25KLT50K',
#  'Tot itemized deductions Ct 50KLT75K',
#  'Tot itemized deductions Ct 75KLT100K',
#  'Tot itemized deductions Ct All',
#  'Tot itemized deductions Ct GE200K',
#  'Tot itemized deductions Ct LT25K',
#  'Tot premium tax credit Amt 25KLT50K',
#  'Tot premium tax credit Amt 50KLT75K',
#  'Tot premium tax credit Amt 75KLT100K',
#  'Tot premium tax credit Amt All',
#  'Tot premium tax credit Amt LT25K',
#  'Tot premium tax credit Ct 25KLT50K',
#  'Tot premium tax credit Ct 50KLT75K',
#  'Tot premium tax credit Ct 75KLT100K',
#  'Tot premium tax credit Ct All',
#  'Tot premium tax credit Ct LT25K',
#  'Tot statuory adjustments Amt 100KLT200K',
#  'Tot statuory adjustments Amt 25KLT50K',
#  'Tot statuory adjustments Amt 50KLT75K',
#  'Tot statuory adjustments Amt 75KLT100K',
#  'Tot statuory adjustments Amt All',
#  'Tot statuory adjustments Amt GE200K',
#  'Tot statuory adjustments Amt LT25K',
#  'Tot statuory adjustments Ct 100KLT200K',
#  'Tot statuory adjustments Ct 25KLT50K',
#  'Tot statuory adjustments Ct 50KLT75K',
#  'Tot statuory adjustments Ct 75KLT100K',
#  'Tot statuory adjustments Ct All',
#  'Tot statuory adjustments Ct GE200K',
#  'Tot statuory adjustments Ct LT25K',
#  'Tot tax credits Amt 100KLT200K',
#  'Tot tax credits Amt 25KLT50K',
#  'Tot tax credits Amt 50KLT75K',
#  'Tot tax credits Amt 75KLT100K',
#  'Tot tax credits Amt All',
#  'Tot tax credits Amt GE200K',
#  'Tot tax credits Amt LT25K',
#  'Tot tax credits Ct 100KLT200K',
#  'Tot tax credits Ct 25KLT50K',
#  'Tot tax credits Ct 50KLT75K',
#  'Tot tax credits Ct 75KLT100K',
#  'Tot tax credits Ct All',
#  'Tot tax credits Ct GE200K',
#  'Tot tax credits Ct LT25K',
#  ...]

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Columns: 1422 entries, student_num to grades_1_to_1_access_PK
# dtypes: float64(1368), uint8(54)
# memory usage: 13.6 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Columns: 355 entries, student_num to grades_1_to_1_access_PK
# dtypes: float64(312), uint8(43)
# memory usage: 3.1 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 0 to 1290
# Data columns (total 356 columns):
# student_num                                                                        float64
# lea_avg_student_num                                                                float64
# st_avg_student_num                                                                 float64
# 00_Size                                                                            float64
# 01_Size                                                                            float64
# 02_Size                                                                            float64
# 03_Size                                                                            float64
# 04_Size                                                                            float64
# 05_Size                                                                            float64
# lea_total_expense_num                                                              float64
# lea_salary_expense_pct                                                             float64
# lea_benefits_expense_pct                                                           float64
# lea_services_expense_pct                                                           float64
# lea_supplies_expense_pct                                                           float64
# lea_instruct_equip_exp_pct                                                         float64
# lea_federal_perpupil_num                                                           float64
# lea_local_perpupil_num                                                             float64
# lea_state_perpupil_num                                                             float64
# SPG Score                                                                          float64
# EVAAS Growth Score                                                                 float64
# Science Score                                                                      float64
# EOGGr3_CACR_All                                                                    float64
# EOGGr4_CACR_All                                                                    float64
# EOGGr5_CACR_All                                                                    float64
# EOGReadingGr5_CACR_All                                                             float64
# EOGGr4_CACR_Female                                                                 float64
# EOGMathGr3_CACR_Female                                                             float64
# EOGMathGr4_CACR_Female                                                             float64
# EOGMathGr5_CACR_Female                                                             float64
# EOGReadingGr3_CACR_Female                                                          float64
# EOGReadingGr4_CACR_Female                                                          float64
# EOGReadingGr4_GLP_Female                                                           float64
# EOGReadingGr5_CACR_Female                                                          float64
# EOGScienceGr5_CACR_Female                                                          float64
# EOGMathGr3_CACR_Male                                                               float64
# EOGMathGr4_CACR_Male                                                               float64
# EOGMathGr5_CACR_Male                                                               float64
# EOGReadingGr3_CACR_Male                                                            float64
# EOGReadingGr4_CACR_Male                                                            float64
# EOGReadingGr4_GLP_Male                                                             float64
# EOGReadingGr5_CACR_Male                                                            float64
# EOGScienceGr5_CACR_Male                                                            float64
# EOG/EOCSubjects_CACR_AmericanIndian                                                float64
# EOGGr3_CACR_AmericanIndian                                                         float64
# EOGGr4_CACR_AmericanIndian                                                         float64
# EOGGr5_CACR_AmericanIndian                                                         float64
# EOGMathGr3_CACR_AmericanIndian                                                     float64
# EOGMathGr3-8_CACR_AmericanIndian                                                   float64
# EOGMathGr4_CACR_AmericanIndian                                                     float64
# EOGMathGr5_CACR_AmericanIndian                                                     float64
# EOGScienceGr5_CACR_AmericanIndian                                                  float64
# EOG/EOCSubjects_CACR_Asian                                                         float64
# EOGGr3_CACR_Asian                                                                  float64
# EOGGr4_CACR_Asian                                                                  float64
# EOGGr5_CACR_Asian                                                                  float64
# EOGMathGr3_CACR_Asian                                                              float64
# EOGMathGr3-8_CACR_Asian                                                            float64
# EOGMathGr4_CACR_Asian                                                              float64
# EOGMathGr5_CACR_Asian                                                              float64
# EOG/EOCSubjects_CACR_Black                                                         float64
# EOGGr3_CACR_Black                                                                  float64
# EOGGr4_CACR_Black                                                                  float64
# EOGGr5_CACR_Black                                                                  float64
# EOGMathGr3_CACR_Black                                                              float64
# EOGMathGr3-8_CACR_Black                                                            float64
# EOGMathGr4_CACR_Black                                                              float64
# EOGMathGr5_CACR_Black                                                              float64
# EOGReadingGr3_CACR_Black                                                           float64
# EOGReadingGr3-8_CACR_Black                                                         float64
# EOGReadingGr4_CACR_Black                                                           float64
# EOGReadingGr5_CACR_Black                                                           float64
# EOGReadingGr5_GLP_Black                                                            float64
# EOGScienceGr5_CACR_Black                                                           float64
# EOG/EOCSubjects_CACR_Hispanic                                                      float64
# EOGGr3_CACR_Hispanic                                                               float64
# EOGGr4_CACR_Hispanic                                                               float64
# EOGGr5_CACR_Hispanic                                                               float64
# EOGMathGr3_CACR_Hispanic                                                           float64
# EOGMathGr3-8_CACR_Hispanic                                                         float64
# EOGMathGr4_CACR_Hispanic                                                           float64
# EOGMathGr5_CACR_Hispanic                                                           float64
# EOGReadingGr3_CACR_Hispanic                                                        float64
# EOGReadingGr3-8_CACR_Hispanic                                                      float64
# EOGReadingGr4_CACR_Hispanic                                                        float64
# EOGReadingGr5_CACR_Hispanic                                                        float64
# EOGScienceGr5_CACR_Hispanic                                                        float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                                                float64
# EOGGr3_CACR_TwoorMoreRaces                                                         float64
# EOGGr4_CACR_TwoorMoreRaces                                                         float64
# EOGGr5_CACR_TwoorMoreRaces                                                         float64
# EOGMathGr3_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                                                   float64
# EOGMathGr4_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr5_CACR_TwoorMoreRaces                                                     float64
# EOGReadingGr3_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                                                float64
# EOGReadingGr5_CACR_TwoorMoreRaces                                                  float64
# EOG/EOCSubjects_CACR_White                                                         float64
# EOGGr3_CACR_White                                                                  float64
# EOGGr4_CACR_White                                                                  float64
# EOGGr5_CACR_White                                                                  float64
# EOGMathGr3_CACR_White                                                              float64
# EOGMathGr3-8_CACR_White                                                            float64
# EOGMathGr4_CACR_White                                                              float64
# EOGMathGr5_CACR_White                                                              float64
# EOGReadingGr3_CACR_White                                                           float64
# EOGReadingGr3-8_CACR_White                                                         float64
# EOGReadingGr4_CACR_White                                                           float64
# EOGReadingGr5_CACR_White                                                           float64
# EOG/EOCSubjects_CACR_EDS                                                           float64
# EOGGr3_CACR_EDS                                                                    float64
# EOGGr4_CACR_EDS                                                                    float64
# EOGGr5_CACR_EDS                                                                    float64
# EOGMathGr3_CACR_EDS                                                                float64
# EOGMathGr3_GLP_EDS                                                                 float64
# EOGMathGr3-8_CACR_EDS                                                              float64
# EOGMathGr4_CACR_EDS                                                                float64
# EOGMathGr5_CACR_EDS                                                                float64
# EOGReadingGr3_CACR_EDS                                                             float64
# EOGReadingGr3_GLP_EDS                                                              float64
# EOGReadingGr3-8_CACR_EDS                                                           float64
# EOGReadingGr4_CACR_EDS                                                             float64
# EOGReadingGr4_GLP_EDS                                                              float64
# EOGReadingGr5_CACR_EDS                                                             float64
# EOGReadingGr5_GLP_EDS                                                              float64
# EOGScienceGr5_CACR_EDS                                                             float64
# EOG/EOCSubjects_CACR_LEP                                                           float64
# EOGGr3_CACR_LEP                                                                    float64
# EOGGr4_CACR_LEP                                                                    float64
# EOGGr5_CACR_LEP                                                                    float64
# EOGMathGr3_CACR_LEP                                                                float64
# EOGMathGr3-8_CACR_LEP                                                              float64
# EOGMathGr4_CACR_LEP                                                                float64
# EOGMathGr5_CACR_LEP                                                                float64
# EOGReadingGr3_CACR_LEP                                                             float64
# EOGReadingGr3-8_CACR_LEP                                                           float64
# EOGReadingGr3-8_GLP_LEP                                                            float64
# EOGReadingGr4_CACR_LEP                                                             float64
# EOGReadingGr4_GLP_LEP                                                              float64
# EOGReadingGr5_CACR_LEP                                                             float64
# EOGReadingGr5_GLP_LEP                                                              float64
# EOGScienceGr5_CACR_LEP                                                             float64
# EOG/EOCSubjects_CACR_SWD                                                           float64
# EOGGr3_CACR_SWD                                                                    float64
# EOGGr3_GLP_SWD                                                                     float64
# EOGGr4_CACR_SWD                                                                    float64
# EOGGr4_GLP_SWD                                                                     float64
# EOGGr5_CACR_SWD                                                                    float64
# EOGGr5_GLP_SWD                                                                     float64
# EOGMathGr3_CACR_SWD                                                                float64
# EOGMathGr3_GLP_SWD                                                                 float64
# EOGMathGr3-8_CACR_SWD                                                              float64
# EOGMathGr3-8_GLP_SWD                                                               float64
# EOGMathGr4_CACR_SWD                                                                float64
# EOGMathGr5_CACR_SWD                                                                float64
# EOGMathGr5_GLP_SWD                                                                 float64
# EOGReadingGr3_CACR_SWD                                                             float64
# EOGReadingGr3_GLP_SWD                                                              float64
# EOGReadingGr3-8_CACR_SWD                                                           float64
# EOGReadingGr3-8_GLP_SWD                                                            float64
# EOGReadingGr4_CACR_SWD                                                             float64
# EOGReadingGr4_GLP_SWD                                                              float64
# EOGReadingGr5_CACR_SWD                                                             float64
# EOGReadingGr5_GLP_SWD                                                              float64
# EOGScienceGr5_CACR_SWD                                                             float64
# EOGScienceGr5_GLP_SWD                                                              float64
# EOG/EOCSubjects_CACR_AIG                                                           float64
# EOGGr3_CACR_AIG                                                                    float64
# EOGGr4_CACR_AIG                                                                    float64
# EOGGr5_CACR_AIG                                                                    float64
# EOGMathGr3_CACR_AIG                                                                float64
# EOGMathGr3-8_CACR_AIG                                                              float64
# EOGMathGr4_CACR_AIG                                                                float64
# EOGMathGr5_CACR_AIG                                                                float64
# pct_GCE_ALL                                                                        float64
# pct_PROMOTED                                                                       float64
# pct_RETAINED                                                                       float64
# MathGr3-8_pTarget_PctMet                                                           float64
# SciGr5&8_pTarget_PctMet                                                            float64
# lea_sat_avg_score_num                                                              float64
# lea_sat_participation_pct                                                          float64
# lea_ap_participation_pct                                                           float64
# lea_ap_pct_3_or_above                                                              float64
# lea_ib_pct_4_or_above                                                              float64
# avg_daily_attend_pct                                                               float64
# crime_per_c_num                                                                    float64
# short_susp_per_c_num                                                               float64
# long_susp_per_c_num                                                                float64
# stud_internet_comp_num                                                             float64
# lea_avg_daily_attend_pct                                                           float64
# lea_crime_per_c_num                                                                float64
# lea_short_susp_per_c_num                                                           float64
# lea_long_susp_per_c_num                                                            float64
# lea_stud_internet_comp_num                                                         float64
# st_avg_daily_attend_pct                                                            float64
# st_crime_per_c_num                                                                 float64
# digital_media_pct                                                                  float64
# avg_age_media_collection                                                           float64
# books_per_student                                                                  float64
# lea_avg_age_media_collection                                                       float64
# lea_books_per_student                                                              float64
# wap_num                                                                            float64
# wap_per_classroom                                                                  float64
# lea_wap_num                                                                        float64
# lea_wap_per_classroom                                                              float64
# flicensed_teach_pct                                                                float64
# tchyrs_0thru3_pct                                                                  float64
# tchyrs_4thru10_pct                                                                 float64
# tchyrs_11plus_pct                                                                  float64
# class_teach_num                                                                    float64
# nbpts_num                                                                          float64
# advance_dgr_pct                                                                    float64
# _1yr_tchr_trnovr_pct                                                               float64
# highqual_class_pct                                                                 float64
# lea_flicensed_teach_pct                                                            float64
# lea_tchyrs_0thru3_pct                                                              float64
# lea_tchyrs_4thru10_pct                                                             float64
# lea_tchyrs_11plus_pct                                                              float64
# lea_nbpts_num                                                                      float64
# lea_advance_dgr_pct                                                                float64
# lea_1yr_tchr_trnovr_pct                                                            float64
# lea_emer_prov_teach_pct                                                            float64
# lea_lateral_teach_pct                                                              float64
# lea_highqual_class_pct                                                             float64
# lea_highqual_class_hp_pct                                                          float64
# lea_highqual_class_lp_pct                                                          float64
# lea_highqual_class_all_pct                                                         float64
# lea_not_highqual_class_hp_pct                                                      float64
# lea_not_highqual_class_lp_pct                                                      float64
# st_tchyrs_11plus_pct                                                               float64
# 0-3 Years_LEA_Exp_Pct_Prin                                                         float64
# 10+ Years_LEA_Exp_Pct_Prin                                                         float64
# 4-10 Years_LEA_Exp_Pct_Prin                                                        float64
# Accomplished_TCHR_Standard 1_Pct                                                   float64
# Accomplished_TCHR_Standard 2_Pct                                                   float64
# Accomplished_TCHR_Standard 3_Pct                                                   float64
# Accomplished_TCHR_Standard 4_Pct                                                   float64
# Accomplished_TCHR_Standard 5_Pct                                                   float64
# Developing_TCHR_Standard 1_Pct                                                     float64
# Developing_TCHR_Standard 2_Pct                                                     float64
# Developing_TCHR_Standard 3_Pct                                                     float64
# Developing_TCHR_Standard 4_Pct                                                     float64
# Developing_TCHR_Standard 5_Pct                                                     float64
# Distinguished_TCHR_Standard 1_Pct                                                  float64
# Distinguished_TCHR_Standard 2_Pct                                                  float64
# Distinguished_TCHR_Standard 3_Pct                                                  float64
# Distinguished_TCHR_Standard 4_Pct                                                  float64
# Distinguished_TCHR_Standard 5_Pct                                                  float64
# Does Not Meet Expected Growth_TCHR_Student Growth_Pct                              float64
# Exceeds Expected Growth_TCHR_Student Growth_Pct                                    float64
# Meets Expected Growth_TCHR_Student Growth_Pct                                      float64
# Not Demostrated_TCHR_Standard 1_Pct                                                float64
# Not Demostrated_TCHR_Standard 2_Pct                                                float64
# Not Demostrated_TCHR_Standard 4_Pct                                                float64
# Proficient_TCHR_Standard 1_Pct                                                     float64
# Proficient_TCHR_Standard 2_Pct                                                     float64
# Proficient_TCHR_Standard 3_Pct                                                     float64
# Proficient_TCHR_Standard 4_Pct                                                     float64
# Proficient_TCHR_Standard 5_Pct                                                     float64
# IndianPct                                                                          float64
# AsianPct                                                                           float64
# HispanicPct                                                                        float64
# BlackPct                                                                           float64
# WhitePct                                                                           float64
# PacificIslandPct                                                                   float64
# TwoOrMorePct                                                                       float64
# PacificIslandMalePct                                                               float64
# TwoOrMoreMalePct                                                                   float64
# PacificIslandFemalePct                                                             float64
# TwoOrMoreFemalePct                                                                 float64
# Year                                                                               float64
# Violent Rate                                                                       float64
# Murder Rate                                                                        float64
# Rape Rate                                                                          float64
# Robbery Rate                                                                       float64
# MVT Rate                                                                           float64
# Arson Rate                                                                         float64
# (TCE) prepared returns Ct 100KLT200K                                               float64
# (TCE) prepared returns Ct 25KLT50K                                                 float64
# (TCE) prepared returns Ct 75KLT100K                                                float64
# (VITA) prepared returns Ct 100KLT200K                                              float64
# (VITA) prepared returns Ct 25KLT50K                                                float64
# (VITA) prepared returns Ct 50KLT75K                                                float64
# Add child tax credit Amt 25KLT50K                                                  float64
# Alternative minimum tax Amt 25KLT50K                                               float64
# Alternative minimum tax Amt 50KLT75K                                               float64
# Alternative minimum tax Amt 75KLT100K                                              float64
# Alternative minimum tax Amt LT25K                                                  float64
# Alternative minimum tax Ct 50KLT75K                                                float64
# Domestic production activities deduction Amt 100KLT200K                            float64
# Domestic production activities deduction Amt 25KLT50K                              float64
# Domestic production activities deduction Amt 50KLT75K                              float64
# Domestic production activities deduction Amt 75KLT100K                             float64
# Domestic production activities deduction Ct 25KLT50K                               float64
# Domestic production activities deduction Ct 50KLT75K                               float64
# Domestic production activities deduction Ct 75KLT100K                              float64
# Earned income credit Amt 50KLT75K                                                  float64
# Excess earned income credit (refundable) Amt 50KLT75K                              float64
# Net investment income tax Amt 100KLT200K                                           float64
# Number of farm returns 100KLT200K                                                  float64
# Number of farm returns 25KLT50K                                                    float64
# Number of farm returns 50KLT75K                                                    float64
# Number of farm returns 75KLT100K                                                   float64
# Number of farm returns All                                                         float64
# Number of farm returns GE200K                                                      float64
# Number of farm returns LT25K                                                       float64
# Number of volunteer prepared returns Tot 50KLT75K                                  float64
# Partnership/S-corp net income (less loss) Amt LT25K                                float64
# Residential energy tax credit Amt LT25K                                            float64
# Self-employment retirement plans Amt 75KLT100K                                     float64
# State and local general sales taxes Amt GE200K                                     float64
# Tuition and fees deduction Amt 75KLT100K                                           float64
# calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar    uint8
# calendar_type_txt_Regular School, Year-Round Calendar                              uint8
# esea_status_P                                                                      uint8
# Grad_project_status_Y                                                              uint8
# State Board Region_Northeast Region                                                uint8
# State Board Region_Northwest Region                                                uint8
# State Board Region_Piedmont Triad Region                                           uint8
# State Board Region_SandHills Region                                                uint8
# State Board Region_Southeast Region                                                uint8
# State Board Region_Southwest Region                                                uint8
# State Board Region_Western Region                                                  uint8
# SPG Grade_A+NG                                                                     uint8
# SPG Grade_B                                                                        uint8
# SPG Grade_C                                                                        uint8
# SPG Grade_D                                                                        uint8
# SPG Grade_F                                                                        uint8
# Reading SPG Score_B                                                                uint8
# Reading SPG Score_C                                                                uint8
# Reading SPG Score_D                                                                uint8
# Reading SPG Score_F                                                                uint8
# Math SPG Score_B                                                                   uint8
# Math SPG Score_C                                                                   uint8
# Math SPG Score_D                                                                   uint8
# Math SPG Score_F                                                                   uint8
# EVAAS Growth Status_Met                                                            uint8
# EVAAS Growth Status_NotMet                                                         uint8
# Byod_No                                                                            uint8
# _1_to_1_access_Yes                                                                 uint8
# grades_1_to_1_access_3                                                             uint8
# grades_1_to_1_access_3:04:05                                                       uint8
# grades_1_to_1_access_4                                                             uint8
# grades_1_to_1_access_4:05                                                          uint8
# grades_1_to_1_access_4:05:06                                                       uint8
# grades_1_to_1_access_5                                                             uint8
# grades_1_to_1_access_6:07:08                                                       uint8
# grades_1_to_1_access_7                                                             uint8
# grades_1_to_1_access_8                                                             uint8
# grades_1_to_1_access_9:10:11:12                                                    uint8
# grades_1_to_1_access_9:10:11:12:13                                                 uint8
# grades_1_to_1_access_K:1:2:3                                                       uint8
# grades_1_to_1_access_K:1:2:3:4:5                                                   uint8
# grades_1_to_1_access_K:1:2:3:4:5:6:7:8                                             uint8
# grades_1_to_1_access_PK                                                            uint8
# unit_code                                                                          object
# dtypes: float64(312), object(1), uint8(43)
# memory usage: 3.1+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.3
# Pandas Version: 0.24.2

# %%
print( 'Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2016/Machine Learning Datasets/PublicElementarySchools2016_ML.csv
