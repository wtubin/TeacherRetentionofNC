# %% [markdown]
# # NC Teacher Attrition Data 2016-2017

# %%
import PyPDF2
import requests 
from tabula import read_pdf
import tabula
import pandas as pd
import urllib

# %%
PDFfilename = "2016-17-state-teaching-profession.pdf"

url = 'http://www.ncpublicschools.org/docs/district-humanresources/surveys/leaving/' + PDFfilename
r = requests.get(url)
# downlaod the file
with open(url, 'wb') as f:  
    f.write(r.content)

pfr = PyPDF2.PdfFileReader(open(PDFfilename,"rb"))
NewPDFfilename = "TeacherAttrition_ByReasonsCategories"

files = [] 
for i in range(27,31):
    pg = pfr.getPage(i-1)
    writer = PyPDF2.PdfFileWriter() 
    writer.addPage(pg)
    PDF = NewPDFfilename + "_"+str(i) +".pdf"
    files.append(PDF)
    with open(PDF,"wb") as outputStream:
        writer.write(outputStream)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-ec8e0e9475fb> in <module>()
#       4 r = requests.get(url)
#       5 # downlaod the file
# ----> 6 with open(url, 'wb') as f:
#       7     f.write(r.content)
#       8
#
# OSError: [Errno 22] Invalid argument: 'http://www.ncpublicschools.org/docs/district-humanresources/surveys/leaving/2016-17-state-teaching-profession.pdf'

# %%
# read pdf multiple files into one data frame
df=pd.DataFrame([])
df_combine=pd.DataFrame([])
for file in files:
            df = tabula.read_pdf(file,multiple_tables=False)
            #If you want to change the table by editing the columns you can do that here.
            #print(df)
            df_combine=pd.concat([df,df_combine],axis=0,sort=False) #again you can choose between merge or concat as per your need

            
df_combine.columns = ['LEACode', 'LEAName', 'TotalTeachers', 'TeachersLeaving', 'PersonalReasons'
                            ,'PersonalPerct','InitiatedbyLEA','InitiatedPerct','BeyondControlofLEA','BeyondControlPerct'
                           ,'OtherReasons','OtherReasonsPerct']
# Remove header

exclude = ['LEA','Code']

df = df_combine[~df_combine['LEACode'].isin(exclude) & ~ df_combine['LEACode'].isna()] # remove LEA code NaN as well as some 
# fix the name cross multiple line
df.loc[df['LEACode']=='700','LEAName']='Elizabeth City-Pasquotank Public Schools'
df.loc[df['LEACode']=='94Z','LEAName']='Northeast Regional School - Biotech/Agri'
df.loc[df['LEACode']=='340','LEAName']='Winston Salem/Forsyth County Schools'

# save to csv file
csv = "../NCTeacherAttrition_ByReasonsCategories.csv"
df_sorted=df.sort_values(by='LEACode', ascending=True)

df_sorted.to_csv(csv,index=False)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy [indexing.py:190]
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy [ipykernel_launcher.py:20]
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy [ipykernel_launcher.py:21]
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy [ipykernel_launcher.py:22]

# %%
df_sorted
# Out:
#    LEACode                                   LEAName TotalTeachers  \
# 2      010               Alamance-Burlington Schools         1,504
# 3      020                  Alexander County Schools           327
# 4      030                  Alleghany County Schools           118
# 5      040                      Anson County Schools           214
# 6      050                       Ashe County Schools           233
# 9      060                      Avery County Schools           169
# 10     070                   Beaufort County Schools           482
# 11     080                     Bertie County Schools           141
# 12     090                     Bladen County Schools           306
# 13     100                  Brunswick County Schools           819
# 14     110                   Buncombe County Schools         1,639
# 8      111                    Asheville City Schools           331
# 15     120                      Burke County Schools           769
# 16     130                   Cabarrus County Schools         1,949
# 2      132                   Kannapolis City Schools           358
# 17     140                   Caldwell County Schools           833
# 18     150                     Camden County Schools           129
# 19     160            Carteret County Public Schools           615
# 20     170                    Caswell County Schools           188
# 21     180                    Catawba County Schools         1,007
# 27     181                      Hickory City Schools           289
# 18     182               Newton Conover City Schools           205
# 24     190                    Chatham County Schools           623
# 25     200                   Cherokee County Schools           271
# 10     210                    Edenton-Chowan Schools           138
# 26     220                       Clay County Schools            95
# 27     230                  Cleveland County Schools         1,057
# 29     240                   Columbus County Schools           398
# 22     241                   Whiteville City Schools           155
# 2      250                     Craven County Schools           895
# ..     ...                                       ...           ...
# 7      761                     Asheboro City Schools           330
# 32     770                   Richmond County Schools           485
# 30     780          Public Schools of Robeson County         1,483
# 2      790                 Rockingham County Schools           788
# 29     790                 Rockingham County Schools           788
# 3      800                   Rowan-Salisbury Schools         1,295
# 4      810                 Rutherford County Schools           543
# 5      820                    Sampson County Schools           553
# 28     821                      Clinton City Schools           200
# 6      830                   Scotland County Schools           428
# 7      840                     Stanly County Schools           583
# 8      850                     Stokes County Schools           437
# 9      860                      Surry County Schools           538
# 14     861                        Elkin City Schools            89
# 15     862                   Mount Airy City Schools           111
# 10     870                      Swain County Schools           141
# 12     880               Transylvania County Schools           275
# 13     890                    Tyrrell County Schools            49
# 14     900               Union County Public Schools         2,528
# 15     910                      Vance County Schools           445
# 16     920                       Wake County Schools        10,275
# 17     930                     Warren County Schools           154
# 18     940                 Washington County Schools           108
# 21     94Z  Northeast Regional School - Biotech/Agri            11
# 19     950                    Watauga County Schools           358
# 20     960               Wayne County Public Schools         1,234
# 23     970                     Wilkes County Schools           625
# 24     980                     Wilson County Schools           734
# 27     990                     Yadkin County Schools           386
# 28     995                     Yancey County Schools           174
#
#    TeachersLeaving PersonalReasons PersonalPerct InitiatedbyLEA  \
# 2              129              73         56.6%          17.00
# 3               15               1          6.7%            NaN
# 4               10               2         20.0%            NaN
# 5               25              14         56.0%           3.00
# 6                8               2         25.0%           1.00
# 9               18               6         33.3%            NaN
# 10              44              18         40.9%           3.00
# 11              20               6         30.0%           3.00
# 12              28              10         35.7%           2.00
# 13              79              47         59.5%           4.00
# 14             121              76         62.8%            NaN
# 8               22              17         77.3%            NaN
# 15              47              28         59.6%           2.00
# 16             128              97         75.8%           3.00
# 2               29              14         48.3%           1.00
# 17              28              14         50.0%           1.00
# 18               4             NaN          0.0%            NaN
# 19              51              24         47.1%            NaN
# 20              25               5         20.0%           6.00
# 21              58              29         50.0%           3.00
# 27              32              15         46.9%           7.00
# 18              16               5         31.3%           3.00
# 24              44              23         52.3%           4.00
# 25              16               5         31.3%            NaN
# 10               9               5         55.6%            NaN
# 26               7               3         42.9%            NaN
# 27              55              31         56.4%            NaN
# 29              38              11         28.9%           4.00
# 22               9               6         66.7%            NaN
# 2               94              26         27.7%            NaN
# ..             ...             ...           ...            ...
# 7               25              14         56.0%           1.00
# 32              51              15         29.4%           5.00
# 30             108              55         50.9%          18.00
# 2               74              46         62.2%           2.00
# 29              74              46         62.2%           2.00
# 3              105              47         44.8%            NaN
# 4               41              26         63.4%            NaN
# 5               42              15         35.7%            NaN
# 28              11               7         63.6%           1.00
# 6               41              12         29.3%           7.00
# 7               29              12         41.4%           1.00
# 8               28               8         28.6%           7.00
# 9               25               8         32.0%            NaN
# 14               4               2         50.0%            NaN
# 15              16               3         18.8%           2.00
# 10               9               5         55.6%            NaN
# 12              18              11         61.1%            NaN
# 13               3               1         33.3%           2.00
# 14             187              97         51.9%           4.00
# 15              57              15         26.3%           6.00
# 16             750             456         60.8%          44.00
# 17              34              18         52.9%           4.00
# 18              12             NaN          0.0%           7.00
# 21               2               1         50.0%            NaN
# 19              29              15         51.7%           3.00
# 20              92              42         45.7%           4.00
# 23              40              21         52.5%            NaN
# 24              68              33         48.5%           1.00
# 27              22              19         86.4%            NaN
# 28               8               2         25.0%           2.00
#
#    InitiatedPerct BeyondControlofLEA BeyondControlPerct OtherReasons  \
# 2           13.2%              25.00              19.4%        14.00
# 3            0.0%              11.00              73.3%         3.00
# 4            0.0%               7.00              70.0%         1.00
# 5           12.0%               8.00              32.0%          NaN
# 6           12.5%               4.00              50.0%         1.00
# 9            0.0%              12.00              66.7%          NaN
# 10           6.8%              18.00              40.9%         5.00
# 11          15.0%               7.00              35.0%         4.00
# 12           7.1%              14.00              50.0%         2.00
# 13           5.1%              17.00              21.5%        11.00
# 14           0.0%              27.00              22.3%        18.00
# 8            0.0%                NaN               0.0%         5.00
# 15           4.3%              15.00              31.9%         2.00
# 16           2.3%              18.00              14.1%        10.00
# 2            3.4%               8.00              27.6%         6.00
# 17           3.6%              12.00              42.9%         1.00
# 18           0.0%               3.00              75.0%         1.00
# 19           0.0%              22.00              43.1%         5.00
# 20          24.0%               9.00              36.0%         5.00
# 21           5.2%              21.00              36.2%         5.00
# 27          21.9%               8.00              25.0%         2.00
# 18          18.8%               6.00              37.5%         2.00
# 24           9.1%              11.00              25.0%         6.00
# 25           0.0%               8.00              50.0%         3.00
# 10           0.0%               2.00              22.2%         2.00
# 26           0.0%               3.00              42.9%         1.00
# 27           0.0%              17.00              30.9%         7.00
# 29          10.5%              11.00              28.9%        12.00
# 22           0.0%               2.00              22.2%         1.00
# 2            0.0%              30.00              31.9%        38.00
# ..            ...                ...                ...          ...
# 7            4.0%               7.00              28.0%         3.00
# 32           9.8%              16.00              31.4%        15.00
# 30          16.7%              31.00              28.7%         4.00
# 2            2.7%              14.00              18.9%        12.00
# 29           2.7%              14.00              18.9%        12.00
# 3            0.0%              26.00              24.8%        32.00
# 4            0.0%              12.00              29.3%         3.00
# 5            0.0%              25.00              59.5%         2.00
# 28           9.1%               2.00              18.2%         1.00
# 6           17.1%              14.00              34.1%         8.00
# 7            3.4%              10.00              34.5%         6.00
# 8           25.0%               9.00              32.1%         4.00
# 9            0.0%              15.00              60.0%         2.00
# 14           0.0%               1.00              25.0%         1.00
# 15          12.5%               8.00              50.0%         3.00
# 10           0.0%               1.00              11.1%         3.00
# 12           0.0%               4.00              22.2%         3.00
# 13          66.7%                NaN               0.0%          NaN
# 14           2.1%              43.00              23.0%        43.00
# 15          10.5%              19.00              33.3%        17.00
# 16           5.9%             134.00              17.9%       116.00
# 17          11.8%              10.00              29.4%         2.00
# 18          58.3%               1.00               8.3%         4.00
# 21           0.0%                NaN               0.0%         1.00
# 19          10.3%               8.00              27.6%         3.00
# 20           4.3%              34.00              37.0%        12.00
# 23           0.0%              14.00              35.0%         5.00
# 24           1.5%              18.00              26.5%        16.00
# 27           0.0%               2.00               9.1%         1.00
# 28          25.0%               4.00              50.0%          NaN
#
#    OtherReasonsPerct
# 2              10.9%
# 3              20.0%
# 4              10.0%
# 5               0.0%
# 6              12.5%
# 9               0.0%
# 10             11.4%
# 11             20.0%
# 12              7.1%
# 13             13.9%
# 14             14.9%
# 8              22.7%
# 15              4.3%
# 16              7.8%
# 2              20.7%
# 17              3.6%
# 18             25.0%
# 19              9.8%
# 20             20.0%
# 21              8.6%
# 27              6.3%
# 18             12.5%
# 24             13.6%
# 25             18.8%
# 10             22.2%
# 26             14.3%
# 27             12.7%
# 29             31.6%
# 22             11.1%
# 2              40.4%
# ..               ...
# 7              12.0%
# 32             29.4%
# 30              3.7%
# 2              16.2%
# 29             16.2%
# 3              30.5%
# 4               7.3%
# 5               4.8%
# 28              9.1%
# 6              19.5%
# 7              20.7%
# 8              14.3%
# 9               8.0%
# 14             25.0%
# 15             18.8%
# 10             33.3%
# 12             16.7%
# 13              0.0%
# 14             23.0%
# 15             29.8%
# 16             15.5%
# 17              5.9%
# 18             33.3%
# 21             50.0%
# 19             10.3%
# 20             13.0%
# 23             12.5%
# 24             23.5%
# 27              4.5%
# 28              0.0%
#
# [117 rows x 12 columns]
