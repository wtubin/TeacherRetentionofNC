# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2014

#Location where copies of the raw data files will be read in from csv files.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools' + str(schoolYear)
#inputFileName = 'PublicHighSchools' + str(schoolYear)
inputFileName = 'PublicMiddleSchools' + str(schoolYear)
#inputFileName = 'PublicElementarySchools' + str(schoolYear)

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
#Rename Lea_Name to District Name
schoolData.rename(columns={'Lea_Name': 'District Name'}, inplace=True)
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 538 entries, 0 to 537
# Columns: 2055 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(2015), int64(3), object(37)
# memory usage: 8.4+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 2055 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(2015), int64(3), object(37)
# memory usage: 8.4+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Data columns (total 2055 columns):
# vphone_ad                                                                object
# year                                                                     int64
# unit_code                                                                object
# street_ad                                                                object
# scity_ad                                                                 object
# state_ad                                                                 object
# szip_ad                                                                  object
# type_cd                                                                  object
# closed_ind                                                               float64
# new_ind                                                                  float64
# super_nm                                                                 float64
# category_cd                                                              object
# url_ad                                                                   object
# grade_range_cd                                                           object
# calendar_type_txt                                                        object
# sna_pgm_type_cd                                                          object
# cover_letter_ad                                                          float64
# school_type_txt                                                          object
# calendar_only_txt                                                        object
# title1_type_cd                                                           object
# clp_ind                                                                  float64
# focus_clp_ind                                                            float64
# summer_program_ind                                                       float64
# asm_no_spg_ind                                                           float64
# no_data_spg_ind                                                          float64
# District Name                                                            object
# School_Name                                                              object
# State_Name                                                               object
# esea_status                                                              object
# student_num                                                              float64
# lea_avg_student_num                                                      float64
# st_avg_student_num                                                       float64
# Grad_project_status                                                      object
# stem                                                                     object
# url                                                                      object
# Biology_Size                                                             float64
# English II_Size                                                          float64
# Math I_Size                                                              float64
# total_expense_num                                                        float64
# salary_expense_pct                                                       float64
# benefits_expense_pct                                                     float64
# services_expense_pct                                                     float64
# supplies_expense_pct                                                     float64
# instruct_equip_exp_pct                                                   float64
# other_expense_pct                                                        float64
# federal_perpupil_num                                                     float64
# local_perpupil_num                                                       float64
# state_perpupil_num                                                       float64
# lea_total_expense_num                                                    float64
# lea_salary_expense_pct                                                   float64
# lea_benefits_expense_pct                                                 float64
# lea_services_expense_pct                                                 float64
# lea_supplies_expense_pct                                                 float64
# lea_instruct_equip_exp_pct                                               float64
# lea_other_expense_pct                                                    float64
# lea_federal_perpupil_num                                                 float64
# lea_local_perpupil_num                                                   float64
# lea_state_perpupil_num                                                   float64
# st_total_expense_num                                                     float64
# st_salary_expense_pct                                                    float64
# st_benefits_expense_pct                                                  float64
# st_services_expense_pct                                                  float64
# st_supplies_expense_pct                                                  float64
# st_instruct_equip_exp_pct                                                float64
# st_other_expense_pct                                                     float64
# st_federal_perpupil_num                                                  float64
# st_local_perpupil_num                                                    float64
# st_state_perpupil_num                                                    float64
# building_expense_pct                                                     float64
# lea_building_expense_pct                                                 float64
# st_building_expense_pct                                                  float64
# LEA Name                                                                 object
# School Name                                                              object
# SBE Region                                                               float64
# SPG Grade                                                                object
# SPG Score                                                                float64
# Reading SPG Grade                                                        object
# Reading  SPG Score                                                       float64
# Math SPG Grade                                                           object
# Math SPG Score                                                           float64
# EVAAS Growth Status                                                      object
# EVAAS Growth Score                                                       float64
# Overall Achievement Score                                                float64
# Read Score                                                               float64
# Math Score                                                               float64
# Science Score                                                            float64
# Math I Score                                                             float64
# English II Score                                                         float64
# Biology Score                                                            float64
# The ACT Score                                                            float64
# ACT WorkKeys Score                                                       float64
# Math Course Rigor Score                                                  float64
# Cohort Graduation Rate Standard Score                                    float64
# ACTCompositeScore_UNCMin_All                                             float64
# ACTEnglish_ACTBenchmark_All                                              float64
# ACTMath_ACTBenchmark_All                                                 float64
# ACTReading_ACTBenchmark_All                                              float64
# ACTScience_ACTBenchmark_All                                              float64
# ACTSubtests_BenchmarksMet_All                                            float64
# ACTWorkKeys_SilverPlus_All                                               float64
# ACTWriting_ACTBenchmark_All                                              float64
# EOCBiology_CACR_All                                                      float64
# EOCBiology_GLP_All                                                       float64
# EOCEnglish2_CACR_All                                                     float64
# EOCEnglish2_GLP_All                                                      float64
# EOCMathI_CACR_All                                                        float64
# EOCMathI_GLP_All                                                         float64
# EOCSubjects_CACR_All                                                     float64
# EOCSubjects_GLP_All                                                      float64
# EOG/EOCSubjects_CACR_All                                                 float64
# EOG/EOCSubjects_GLP_All                                                  float64
# EOGGr3_CACR_All                                                          float64
# EOGGr3_GLP_All                                                           float64
# EOGGr4_CACR_All                                                          float64
# EOGGr4_GLP_All                                                           float64
# EOGGr5_CACR_All                                                          float64
# EOGGr5_GLP_All                                                           float64
# EOGGr6_CACR_All                                                          float64
# EOGGr6_GLP_All                                                           float64
# EOGGr7_CACR_All                                                          float64
# EOGGr7_GLP_All                                                           float64
# EOGGr8_CACR_All                                                          float64
# EOGGr8_GLP_All                                                           float64
# EOGMathGr3_CACR_All                                                      float64
# EOGMathGr3_GLP_All                                                       float64
# EOGMathGr3-8_CACR_All                                                    float64
# EOGMathGr3-8_GLP_All                                                     float64
# EOGMathGr4_CACR_All                                                      float64
# EOGMathGr4_GLP_All                                                       float64
# EOGMathGr5_CACR_All                                                      float64
# EOGMathGr5_GLP_All                                                       float64
# EOGMathGr6_CACR_All                                                      float64
# EOGMathGr6_GLP_All                                                       float64
# EOGMathGr7_CACR_All                                                      float64
# EOGMathGr7_GLP_All                                                       float64
# EOGMathGr8_CACR_All                                                      float64
# EOGMathGr8_GLP_All                                                       float64
# EOGReadingGr3_CACR_All                                                   float64
# EOGReadingGr3_GLP_All                                                    float64
# EOGReadingGr3-8_CACR_All                                                 float64
# EOGReadingGr3-8_GLP_All                                                  float64
# EOGReadingGr4_CACR_All                                                   float64
# EOGReadingGr4_GLP_All                                                    float64
# EOGReadingGr5_CACR_All                                                   float64
# EOGReadingGr5_GLP_All                                                    float64
# EOGReadingGr6_CACR_All                                                   float64
# EOGReadingGr6_GLP_All                                                    float64
# EOGReadingGr7_CACR_All                                                   float64
# EOGReadingGr7_GLP_All                                                    float64
# EOGReadingGr8_CACR_All                                                   float64
# EOGReadingGr8_GLP_All                                                    float64
# EOGScienceGr5_CACR_All                                                   float64
# EOGScienceGr5_GLP_All                                                    float64
# EOGScienceGr5&8_CACR_All                                                 float64
# EOGScienceGr5&8_GLP_All                                                  float64
# EOGScienceGr8_CACR_All                                                   float64
# EOGScienceGr8_GLP_All                                                    float64
# EOGSubjects_CACR_All                                                     float64
# EOGSubjects_GLP_All                                                      float64
# GraduationRate_4yr_All                                                   float64
# GraduationRate_5yr_All                                                   float64
# ACTCompositeScore_UNCMin_Female                                          float64
# ACTEnglish_ACTBenchmark_Female                                           float64
# ACTMath_ACTBenchmark_Female                                              float64
# ACTReading_ACTBenchmark_Female                                           float64
# ACTScience_ACTBenchmark_Female                                           float64
# ACTSubtests_BenchmarksMet_Female                                         float64
# ACTWorkKeys_SilverPlus_Female                                            float64
# ACTWriting_ACTBenchmark_Female                                           float64
# EOCBiology_CACR_Female                                                   float64
# EOCBiology_GLP_Female                                                    float64
# EOCEnglish2_CACR_Female                                                  float64
# EOCEnglish2_GLP_Female                                                   float64
# EOCMathI_CACR_Female                                                     float64
# EOCMathI_GLP_Female                                                      float64
# EOCSubjects_CACR_Female                                                  float64
# EOCSubjects_GLP_Female                                                   float64
# EOG/EOCSubjects_CACR_Female                                              float64
# EOG/EOCSubjects_GLP_Female                                               float64
# EOGGr3_CACR_Female                                                       float64
# EOGGr3_GLP_Female                                                        float64
# EOGGr4_CACR_Female                                                       float64
# EOGGr4_GLP_Female                                                        float64
# EOGGr5_CACR_Female                                                       float64
# EOGGr5_GLP_Female                                                        float64
# EOGGr6_CACR_Female                                                       float64
# EOGGr6_GLP_Female                                                        float64
# EOGGr7_CACR_Female                                                       float64
# EOGGr7_GLP_Female                                                        float64
# EOGGr8_CACR_Female                                                       float64
# EOGGr8_GLP_Female                                                        float64
# EOGMathGr3_CACR_Female                                                   float64
# EOGMathGr3_GLP_Female                                                    float64
# EOGMathGr3-8_CACR_Female                                                 float64
# EOGMathGr3-8_GLP_Female                                                  float64
# EOGMathGr4_CACR_Female                                                   float64
# EOGMathGr4_GLP_Female                                                    float64
# EOGMathGr5_CACR_Female                                                   float64
# EOGMathGr5_GLP_Female                                                    float64
# EOGMathGr6_CACR_Female                                                   float64
# EOGMathGr6_GLP_Female                                                    float64
# EOGMathGr7_CACR_Female                                                   float64
# EOGMathGr7_GLP_Female                                                    float64
# EOGMathGr8_CACR_Female                                                   float64
# EOGMathGr8_GLP_Female                                                    float64
# EOGReadingGr3_CACR_Female                                                float64
# EOGReadingGr3_GLP_Female                                                 float64
# EOGReadingGr3-8_CACR_Female                                              float64
# EOGReadingGr3-8_GLP_Female                                               float64
# EOGReadingGr4_CACR_Female                                                float64
# EOGReadingGr4_GLP_Female                                                 float64
# EOGReadingGr5_CACR_Female                                                float64
# EOGReadingGr5_GLP_Female                                                 float64
# EOGReadingGr6_CACR_Female                                                float64
# EOGReadingGr6_GLP_Female                                                 float64
# EOGReadingGr7_CACR_Female                                                float64
# EOGReadingGr7_GLP_Female                                                 float64
# EOGReadingGr8_CACR_Female                                                float64
# EOGReadingGr8_GLP_Female                                                 float64
# EOGScienceGr5_CACR_Female                                                float64
# EOGScienceGr5_GLP_Female                                                 float64
# EOGScienceGr5&8_CACR_Female                                              float64
# EOGScienceGr5&8_GLP_Female                                               float64
# EOGScienceGr8_CACR_Female                                                float64
# EOGScienceGr8_GLP_Female                                                 float64
# EOGSubjects_CACR_Female                                                  float64
# EOGSubjects_GLP_Female                                                   float64
# GraduationRate_4yr_Female                                                float64
# GraduationRate_5yr_Female                                                float64
# ACTCompositeScore_UNCMin_Male                                            float64
# ACTEnglish_ACTBenchmark_Male                                             float64
# ACTMath_ACTBenchmark_Male                                                float64
# ACTReading_ACTBenchmark_Male                                             float64
# ACTScience_ACTBenchmark_Male                                             float64
# ACTSubtests_BenchmarksMet_Male                                           float64
# ACTWorkKeys_SilverPlus_Male                                              float64
# ACTWriting_ACTBenchmark_Male                                             float64
# EOCBiology_CACR_Male                                                     float64
# EOCBiology_GLP_Male                                                      float64
# EOCEnglish2_CACR_Male                                                    float64
# EOCEnglish2_GLP_Male                                                     float64
# EOCMathI_CACR_Male                                                       float64
# EOCMathI_GLP_Male                                                        float64
# EOCSubjects_CACR_Male                                                    float64
# EOCSubjects_GLP_Male                                                     float64
# EOG/EOCSubjects_CACR_Male                                                float64
# EOG/EOCSubjects_GLP_Male                                                 float64
# EOGGr3_CACR_Male                                                         float64
# EOGGr3_GLP_Male                                                          float64
# EOGGr4_CACR_Male                                                         float64
# EOGGr4_GLP_Male                                                          float64
# EOGGr5_CACR_Male                                                         float64
# EOGGr5_GLP_Male                                                          float64
# EOGGr6_CACR_Male                                                         float64
# EOGGr6_GLP_Male                                                          float64
# EOGGr7_CACR_Male                                                         float64
# EOGGr7_GLP_Male                                                          float64
# EOGGr8_CACR_Male                                                         float64
# EOGGr8_GLP_Male                                                          float64
# EOGMathGr3_CACR_Male                                                     float64
# EOGMathGr3_GLP_Male                                                      float64
# EOGMathGr3-8_CACR_Male                                                   float64
# EOGMathGr3-8_GLP_Male                                                    float64
# EOGMathGr4_CACR_Male                                                     float64
# EOGMathGr4_GLP_Male                                                      float64
# EOGMathGr5_CACR_Male                                                     float64
# EOGMathGr5_GLP_Male                                                      float64
# EOGMathGr6_CACR_Male                                                     float64
# EOGMathGr6_GLP_Male                                                      float64
# EOGMathGr7_CACR_Male                                                     float64
# EOGMathGr7_GLP_Male                                                      float64
# EOGMathGr8_CACR_Male                                                     float64
# EOGMathGr8_GLP_Male                                                      float64
# EOGReadingGr3_CACR_Male                                                  float64
# EOGReadingGr3_GLP_Male                                                   float64
# EOGReadingGr3-8_CACR_Male                                                float64
# EOGReadingGr3-8_GLP_Male                                                 float64
# EOGReadingGr4_CACR_Male                                                  float64
# EOGReadingGr4_GLP_Male                                                   float64
# EOGReadingGr5_CACR_Male                                                  float64
# EOGReadingGr5_GLP_Male                                                   float64
# EOGReadingGr6_CACR_Male                                                  float64
# EOGReadingGr6_GLP_Male                                                   float64
# EOGReadingGr7_CACR_Male                                                  float64
# EOGReadingGr7_GLP_Male                                                   float64
# EOGReadingGr8_CACR_Male                                                  float64
# EOGReadingGr8_GLP_Male                                                   float64
# EOGScienceGr5_CACR_Male                                                  float64
# EOGScienceGr5_GLP_Male                                                   float64
# EOGScienceGr5&8_CACR_Male                                                float64
# EOGScienceGr5&8_GLP_Male                                                 float64
# EOGScienceGr8_CACR_Male                                                  float64
# EOGScienceGr8_GLP_Male                                                   float64
# EOGSubjects_CACR_Male                                                    float64
# EOGSubjects_GLP_Male                                                     float64
# GraduationRate_4yr_Male                                                  float64
# GraduationRate_5yr_Male                                                  float64
# ACTCompositeScore_UNCMin_AmericanIndian                                  float64
# ACTEnglish_ACTBenchmark_AmericanIndian                                   float64
# ACTMath_ACTBenchmark_AmericanIndian                                      float64
# ACTReading_ACTBenchmark_AmericanIndian                                   float64
# ACTScience_ACTBenchmark_AmericanIndian                                   float64
# ACTSubtests_BenchmarksMet_AmericanIndian                                 float64
# ACTWorkKeys_SilverPlus_AmericanIndian                                    float64
# ACTWriting_ACTBenchmark_AmericanIndian                                   float64
# EOCBiology_CACR_AmericanIndian                                           float64
# EOCBiology_GLP_AmericanIndian                                            float64
# EOCEnglish2_CACR_AmericanIndian                                          float64
# EOCEnglish2_GLP_AmericanIndian                                           float64
# EOCMathI_CACR_AmericanIndian                                             float64
# EOCMathI_GLP_AmericanIndian                                              float64
# EOCSubjects_CACR_AmericanIndian                                          float64
# EOCSubjects_GLP_AmericanIndian                                           float64
# EOG/EOCSubjects_CACR_AmericanIndian                                      float64
# EOG/EOCSubjects_GLP_AmericanIndian                                       float64
# EOGGr3_CACR_AmericanIndian                                               float64
# EOGGr3_GLP_AmericanIndian                                                float64
# EOGGr4_CACR_AmericanIndian                                               float64
# EOGGr4_GLP_AmericanIndian                                                float64
# EOGGr5_CACR_AmericanIndian                                               float64
# EOGGr5_GLP_AmericanIndian                                                float64
# EOGGr6_CACR_AmericanIndian                                               float64
# EOGGr6_GLP_AmericanIndian                                                float64
# EOGGr7_CACR_AmericanIndian                                               float64
# EOGGr7_GLP_AmericanIndian                                                float64
# EOGGr8_CACR_AmericanIndian                                               float64
# EOGGr8_GLP_AmericanIndian                                                float64
# EOGMathGr3_CACR_AmericanIndian                                           float64
# EOGMathGr3_GLP_AmericanIndian                                            float64
# EOGMathGr3-8_CACR_AmericanIndian                                         float64
# EOGMathGr3-8_GLP_AmericanIndian                                          float64
# EOGMathGr4_CACR_AmericanIndian                                           float64
# EOGMathGr4_GLP_AmericanIndian                                            float64
# EOGMathGr5_CACR_AmericanIndian                                           float64
# EOGMathGr5_GLP_AmericanIndian                                            float64
# EOGMathGr6_CACR_AmericanIndian                                           float64
# EOGMathGr6_GLP_AmericanIndian                                            float64
# EOGMathGr7_CACR_AmericanIndian                                           float64
# EOGMathGr7_GLP_AmericanIndian                                            float64
# EOGMathGr8_CACR_AmericanIndian                                           float64
# EOGMathGr8_GLP_AmericanIndian                                            float64
# EOGReadingGr3_CACR_AmericanIndian                                        float64
# EOGReadingGr3_GLP_AmericanIndian                                         float64
# EOGReadingGr3-8_CACR_AmericanIndian                                      float64
# EOGReadingGr3-8_GLP_AmericanIndian                                       float64
# EOGReadingGr4_CACR_AmericanIndian                                        float64
# EOGReadingGr4_GLP_AmericanIndian                                         float64
# EOGReadingGr5_CACR_AmericanIndian                                        float64
# EOGReadingGr5_GLP_AmericanIndian                                         float64
# EOGReadingGr6_CACR_AmericanIndian                                        float64
# EOGReadingGr6_GLP_AmericanIndian                                         float64
# EOGReadingGr7_CACR_AmericanIndian                                        float64
# EOGReadingGr7_GLP_AmericanIndian                                         float64
# EOGReadingGr8_CACR_AmericanIndian                                        float64
# EOGReadingGr8_GLP_AmericanIndian                                         float64
# EOGScienceGr5_CACR_AmericanIndian                                        float64
# EOGScienceGr5_GLP_AmericanIndian                                         float64
# EOGScienceGr5&8_CACR_AmericanIndian                                      float64
# EOGScienceGr5&8_GLP_AmericanIndian                                       float64
# EOGScienceGr8_CACR_AmericanIndian                                        float64
# EOGScienceGr8_GLP_AmericanIndian                                         float64
# EOGSubjects_CACR_AmericanIndian                                          float64
# EOGSubjects_GLP_AmericanIndian                                           float64
# GraduationRate_4yr_AmericanIndian                                        float64
# GraduationRate_5yr_AmericanIndian                                        float64
# ACTCompositeScore_UNCMin_Asian                                           float64
# ACTEnglish_ACTBenchmark_Asian                                            float64
# ACTMath_ACTBenchmark_Asian                                               float64
# ACTReading_ACTBenchmark_Asian                                            float64
# ACTScience_ACTBenchmark_Asian                                            float64
# ACTSubtests_BenchmarksMet_Asian                                          float64
# ACTWorkKeys_SilverPlus_Asian                                             float64
# ACTWriting_ACTBenchmark_Asian                                            float64
# EOCBiology_CACR_Asian                                                    float64
# EOCBiology_GLP_Asian                                                     float64
# EOCEnglish2_CACR_Asian                                                   float64
# EOCEnglish2_GLP_Asian                                                    float64
# EOCMathI_CACR_Asian                                                      float64
# EOCMathI_GLP_Asian                                                       float64
# EOCSubjects_CACR_Asian                                                   float64
# EOCSubjects_GLP_Asian                                                    float64
# EOG/EOCSubjects_CACR_Asian                                               float64
# EOG/EOCSubjects_GLP_Asian                                                float64
# EOGGr3_CACR_Asian                                                        float64
# EOGGr3_GLP_Asian                                                         float64
# EOGGr4_CACR_Asian                                                        float64
# EOGGr4_GLP_Asian                                                         float64
# EOGGr5_CACR_Asian                                                        float64
# EOGGr5_GLP_Asian                                                         float64
# EOGGr6_CACR_Asian                                                        float64
# EOGGr6_GLP_Asian                                                         float64
# EOGGr7_CACR_Asian                                                        float64
# EOGGr7_GLP_Asian                                                         float64
# EOGGr8_CACR_Asian                                                        float64
# EOGGr8_GLP_Asian                                                         float64
# EOGMathGr3_CACR_Asian                                                    float64
# EOGMathGr3_GLP_Asian                                                     float64
# EOGMathGr3-8_CACR_Asian                                                  float64
# EOGMathGr3-8_GLP_Asian                                                   float64
# EOGMathGr4_CACR_Asian                                                    float64
# EOGMathGr4_GLP_Asian                                                     float64
# EOGMathGr5_CACR_Asian                                                    float64
# EOGMathGr5_GLP_Asian                                                     float64
# EOGMathGr6_CACR_Asian                                                    float64
# EOGMathGr6_GLP_Asian                                                     float64
# EOGMathGr7_CACR_Asian                                                    float64
# EOGMathGr7_GLP_Asian                                                     float64
# EOGMathGr8_CACR_Asian                                                    float64
# EOGMathGr8_GLP_Asian                                                     float64
# EOGReadingGr3_CACR_Asian                                                 float64
# EOGReadingGr3_GLP_Asian                                                  float64
# EOGReadingGr3-8_CACR_Asian                                               float64
# EOGReadingGr3-8_GLP_Asian                                                float64
# EOGReadingGr4_CACR_Asian                                                 float64
# EOGReadingGr4_GLP_Asian                                                  float64
# EOGReadingGr5_CACR_Asian                                                 float64
# EOGReadingGr5_GLP_Asian                                                  float64
# EOGReadingGr6_CACR_Asian                                                 float64
# EOGReadingGr6_GLP_Asian                                                  float64
# EOGReadingGr7_CACR_Asian                                                 float64
# EOGReadingGr7_GLP_Asian                                                  float64
# EOGReadingGr8_CACR_Asian                                                 float64
# EOGReadingGr8_GLP_Asian                                                  float64
# EOGScienceGr5_CACR_Asian                                                 float64
# EOGScienceGr5_GLP_Asian                                                  float64
# EOGScienceGr5&8_CACR_Asian                                               float64
# EOGScienceGr5&8_GLP_Asian                                                float64
# EOGScienceGr8_CACR_Asian                                                 float64
# EOGScienceGr8_GLP_Asian                                                  float64
# EOGSubjects_CACR_Asian                                                   float64
# EOGSubjects_GLP_Asian                                                    float64
# GraduationRate_4yr_Asian                                                 float64
# GraduationRate_5yr_Asian                                                 float64
# ACTCompositeScore_UNCMin_Black                                           float64
# ACTEnglish_ACTBenchmark_Black                                            float64
# ACTMath_ACTBenchmark_Black                                               float64
# ACTReading_ACTBenchmark_Black                                            float64
# ACTScience_ACTBenchmark_Black                                            float64
# ACTSubtests_BenchmarksMet_Black                                          float64
# ACTWorkKeys_SilverPlus_Black                                             float64
# ACTWriting_ACTBenchmark_Black                                            float64
# EOCBiology_CACR_Black                                                    float64
# EOCBiology_GLP_Black                                                     float64
# EOCEnglish2_CACR_Black                                                   float64
# EOCEnglish2_GLP_Black                                                    float64
# EOCMathI_CACR_Black                                                      float64
# EOCMathI_GLP_Black                                                       float64
# EOCSubjects_CACR_Black                                                   float64
# EOCSubjects_GLP_Black                                                    float64
# EOG/EOCSubjects_CACR_Black                                               float64
# EOG/EOCSubjects_GLP_Black                                                float64
# EOGGr3_CACR_Black                                                        float64
# EOGGr3_GLP_Black                                                         float64
# EOGGr4_CACR_Black                                                        float64
# EOGGr4_GLP_Black                                                         float64
# EOGGr5_CACR_Black                                                        float64
# EOGGr5_GLP_Black                                                         float64
# EOGGr6_CACR_Black                                                        float64
# EOGGr6_GLP_Black                                                         float64
# EOGGr7_CACR_Black                                                        float64
# EOGGr7_GLP_Black                                                         float64
# EOGGr8_CACR_Black                                                        float64
# EOGGr8_GLP_Black                                                         float64
# EOGMathGr3_CACR_Black                                                    float64
# EOGMathGr3_GLP_Black                                                     float64
# EOGMathGr3-8_CACR_Black                                                  float64
# EOGMathGr3-8_GLP_Black                                                   float64
# EOGMathGr4_CACR_Black                                                    float64
# EOGMathGr4_GLP_Black                                                     float64
# EOGMathGr5_CACR_Black                                                    float64
# EOGMathGr5_GLP_Black                                                     float64
# EOGMathGr6_CACR_Black                                                    float64
# EOGMathGr6_GLP_Black                                                     float64
# EOGMathGr7_CACR_Black                                                    float64
# EOGMathGr7_GLP_Black                                                     float64
# EOGMathGr8_CACR_Black                                                    float64
# EOGMathGr8_GLP_Black                                                     float64
# EOGReadingGr3_CACR_Black                                                 float64
# EOGReadingGr3_GLP_Black                                                  float64
# EOGReadingGr3-8_CACR_Black                                               float64
# EOGReadingGr3-8_GLP_Black                                                float64
# EOGReadingGr4_CACR_Black                                                 float64
# EOGReadingGr4_GLP_Black                                                  float64
# EOGReadingGr5_CACR_Black                                                 float64
# EOGReadingGr5_GLP_Black                                                  float64
# EOGReadingGr6_CACR_Black                                                 float64
# EOGReadingGr6_GLP_Black                                                  float64
# EOGReadingGr7_CACR_Black                                                 float64
# EOGReadingGr7_GLP_Black                                                  float64
# EOGReadingGr8_CACR_Black                                                 float64
# EOGReadingGr8_GLP_Black                                                  float64
# EOGScienceGr5_CACR_Black                                                 float64
# EOGScienceGr5_GLP_Black                                                  float64
# EOGScienceGr5&8_CACR_Black                                               float64
# EOGScienceGr5&8_GLP_Black                                                float64
# EOGScienceGr8_CACR_Black                                                 float64
# EOGScienceGr8_GLP_Black                                                  float64
# EOGSubjects_CACR_Black                                                   float64
# EOGSubjects_GLP_Black                                                    float64
# GraduationRate_4yr_Black                                                 float64
# GraduationRate_5yr_Black                                                 float64
# ACTCompositeScore_UNCMin_Hispanic                                        float64
# ACTEnglish_ACTBenchmark_Hispanic                                         float64
# ACTMath_ACTBenchmark_Hispanic                                            float64
# ACTReading_ACTBenchmark_Hispanic                                         float64
# ACTScience_ACTBenchmark_Hispanic                                         float64
# ACTSubtests_BenchmarksMet_Hispanic                                       float64
# ACTWorkKeys_SilverPlus_Hispanic                                          float64
# ACTWriting_ACTBenchmark_Hispanic                                         float64
# EOCBiology_CACR_Hispanic                                                 float64
# EOCBiology_GLP_Hispanic                                                  float64
# EOCEnglish2_CACR_Hispanic                                                float64
# EOCEnglish2_GLP_Hispanic                                                 float64
# EOCMathI_CACR_Hispanic                                                   float64
# EOCMathI_GLP_Hispanic                                                    float64
# EOCSubjects_CACR_Hispanic                                                float64
# EOCSubjects_GLP_Hispanic                                                 float64
# EOG/EOCSubjects_CACR_Hispanic                                            float64
# EOG/EOCSubjects_GLP_Hispanic                                             float64
# EOGGr3_CACR_Hispanic                                                     float64
# EOGGr3_GLP_Hispanic                                                      float64
# EOGGr4_CACR_Hispanic                                                     float64
# EOGGr4_GLP_Hispanic                                                      float64
# EOGGr5_CACR_Hispanic                                                     float64
# EOGGr5_GLP_Hispanic                                                      float64
# EOGGr6_CACR_Hispanic                                                     float64
# EOGGr6_GLP_Hispanic                                                      float64
# EOGGr7_CACR_Hispanic                                                     float64
# EOGGr7_GLP_Hispanic                                                      float64
# EOGGr8_CACR_Hispanic                                                     float64
# EOGGr8_GLP_Hispanic                                                      float64
# EOGMathGr3_CACR_Hispanic                                                 float64
# EOGMathGr3_GLP_Hispanic                                                  float64
# EOGMathGr3-8_CACR_Hispanic                                               float64
# EOGMathGr3-8_GLP_Hispanic                                                float64
# EOGMathGr4_CACR_Hispanic                                                 float64
# EOGMathGr4_GLP_Hispanic                                                  float64
# EOGMathGr5_CACR_Hispanic                                                 float64
# EOGMathGr5_GLP_Hispanic                                                  float64
# EOGMathGr6_CACR_Hispanic                                                 float64
# EOGMathGr6_GLP_Hispanic                                                  float64
# EOGMathGr7_CACR_Hispanic                                                 float64
# EOGMathGr7_GLP_Hispanic                                                  float64
# EOGMathGr8_CACR_Hispanic                                                 float64
# EOGMathGr8_GLP_Hispanic                                                  float64
# EOGReadingGr3_CACR_Hispanic                                              float64
# EOGReadingGr3_GLP_Hispanic                                               float64
# EOGReadingGr3-8_CACR_Hispanic                                            float64
# EOGReadingGr3-8_GLP_Hispanic                                             float64
# EOGReadingGr4_CACR_Hispanic                                              float64
# EOGReadingGr4_GLP_Hispanic                                               float64
# EOGReadingGr5_CACR_Hispanic                                              float64
# EOGReadingGr5_GLP_Hispanic                                               float64
# EOGReadingGr6_CACR_Hispanic                                              float64
# EOGReadingGr6_GLP_Hispanic                                               float64
# EOGReadingGr7_CACR_Hispanic                                              float64
# EOGReadingGr7_GLP_Hispanic                                               float64
# EOGReadingGr8_CACR_Hispanic                                              float64
# EOGReadingGr8_GLP_Hispanic                                               float64
# EOGScienceGr5_CACR_Hispanic                                              float64
# EOGScienceGr5_GLP_Hispanic                                               float64
# EOGScienceGr5&8_CACR_Hispanic                                            float64
# EOGScienceGr5&8_GLP_Hispanic                                             float64
# EOGScienceGr8_CACR_Hispanic                                              float64
# EOGScienceGr8_GLP_Hispanic                                               float64
# EOGSubjects_CACR_Hispanic                                                float64
# EOGSubjects_GLP_Hispanic                                                 float64
# GraduationRate_4yr_Hispanic                                              float64
# GraduationRate_5yr_Hispanic                                              float64
# ACTCompositeScore_UNCMin_TwoorMoreRaces                                  float64
# ACTEnglish_ACTBenchmark_TwoorMoreRaces                                   float64
# ACTMath_ACTBenchmark_TwoorMoreRaces                                      float64
# ACTReading_ACTBenchmark_TwoorMoreRaces                                   float64
# ACTScience_ACTBenchmark_TwoorMoreRaces                                   float64
# ACTSubtests_BenchmarksMet_TwoorMoreRaces                                 float64
# ACTWorkKeys_SilverPlus_TwoorMoreRaces                                    float64
# ACTWriting_ACTBenchmark_TwoorMoreRaces                                   float64
# EOCBiology_CACR_TwoorMoreRaces                                           float64
# EOCBiology_GLP_TwoorMoreRaces                                            float64
# EOCEnglish2_CACR_TwoorMoreRaces                                          float64
# EOCEnglish2_GLP_TwoorMoreRaces                                           float64
# EOCMathI_CACR_TwoorMoreRaces                                             float64
# EOCMathI_GLP_TwoorMoreRaces                                              float64
# EOCSubjects_CACR_TwoorMoreRaces                                          float64
# EOCSubjects_GLP_TwoorMoreRaces                                           float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                                      float64
# EOG/EOCSubjects_GLP_TwoorMoreRaces                                       float64
# EOGGr3_CACR_TwoorMoreRaces                                               float64
# EOGGr3_GLP_TwoorMoreRaces                                                float64
# EOGGr4_CACR_TwoorMoreRaces                                               float64
# EOGGr4_GLP_TwoorMoreRaces                                                float64
# ...
# Taxable Social Security benefits Amt LT25K                               float64
# Taxable Social Security benefits Ct 100KLT200K                           float64
# Taxable Social Security benefits Ct 25KLT50K                             float64
# Taxable Social Security benefits Ct 50KLT75K                             float64
# Taxable Social Security benefits Ct 75KLT100K                            float64
# Taxable Social Security benefits Ct All                                  float64
# Taxable Social Security benefits Ct GE200K                               float64
# Taxable Social Security benefits Ct LT25K                                float64
# Taxable income Amt 100KLT200K                                            float64
# Taxable income Amt 25KLT50K                                              float64
# Taxable income Amt 50KLT75K                                              float64
# Taxable income Amt 75KLT100K                                             float64
# Taxable income Amt All                                                   float64
# Taxable income Amt GE200K                                                float64
# Taxable income Amt LT25K                                                 float64
# Taxable income Ct 100KLT200K                                             float64
# Taxable income Ct 25KLT50K                                               float64
# Taxable income Ct 50KLT75K                                               float64
# Taxable income Ct 75KLT100K                                              float64
# Taxable income Ct All                                                    float64
# Taxable income Ct GE200K                                                 float64
# Taxable income Ct LT25K                                                  float64
# Taxable individual retirementarrangement distributions Amt 100KLT200K    float64
# Taxable individual retirementarrangement distributions Amt 25KLT50K      float64
# Taxable individual retirementarrangement distributions Amt 50KLT75K      float64
# Taxable individual retirementarrangement distributions Amt 75KLT100K     float64
# Taxable individual retirementarrangement distributions Amt All           float64
# Taxable individual retirementarrangement distributions Amt GE200K        float64
# Taxable individual retirementarrangement distributions Amt LT25K         float64
# Taxable individual retirementarrangement distributions Ct 100KLT200K     float64
# Taxable individual retirementarrangement distributions Ct 25KLT50K       float64
# Taxable individual retirementarrangement distributions Ct 50KLT75K       float64
# Taxable individual retirementarrangement distributions Ct 75KLT100K      float64
# Taxable individual retirementarrangement distributions Ct All            float64
# Taxable individual retirementarrangement distributions Ct GE200K         float64
# Taxable individual retirementarrangement distributions Ct LT25K          float64
# Taxable interest Amt 100KLT200K                                          float64
# Taxable interest Amt 25KLT50K                                            float64
# Taxable interest Amt 50KLT75K                                            float64
# Taxable interest Amt 75KLT100K                                           float64
# Taxable interest Amt All                                                 float64
# Taxable interest Amt GE200K                                              float64
# Taxable interest Amt LT25K                                               float64
# Taxable interest Ct 100KLT200K                                           float64
# Taxable interest Ct 25KLT50K                                             float64
# Taxable interest Ct 50KLT75K                                             float64
# Taxable interest Ct 75KLT100K                                            float64
# Taxable interest Ct All                                                  float64
# Taxable interest Ct GE200K                                               float64
# Taxable interest Ct LT25K                                                float64
# Taxes paid Amt 100KLT200K                                                float64
# Taxes paid Amt 25KLT50K                                                  float64
# Taxes paid Amt 50KLT75K                                                  float64
# Taxes paid Amt 75KLT100K                                                 float64
# Taxes paid Amt All                                                       float64
# Taxes paid Amt GE200K                                                    float64
# Taxes paid Amt LT25K                                                     float64
# Taxes paid Ct 100KLT200K                                                 float64
# Taxes paid Ct 25KLT50K                                                   float64
# Taxes paid Ct 50KLT75K                                                   float64
# Taxes paid Ct 75KLT100K                                                  float64
# Taxes paid Ct All                                                        float64
# Taxes paid Ct GE200K                                                     float64
# Taxes paid Ct LT25K                                                      float64
# Tot income Amt 100KLT200K                                                float64
# Tot income Amt 25KLT50K                                                  float64
# Tot income Amt 50KLT75K                                                  float64
# Tot income Amt 75KLT100K                                                 float64
# Tot income Amt All                                                       float64
# Tot income Amt GE200K                                                    float64
# Tot income Amt LT25K                                                     float64
# Tot income Ct 100KLT200K                                                 float64
# Tot income Ct 25KLT50K                                                   float64
# Tot income Ct 50KLT75K                                                   float64
# Tot income Ct 75KLT100K                                                  float64
# Tot income Ct All                                                        float64
# Tot income Ct GE200K                                                     float64
# Tot income Ct LT25K                                                      float64
# Tot itemized deductions Amt 100KLT200K                                   float64
# Tot itemized deductions Amt 25KLT50K                                     float64
# Tot itemized deductions Amt 50KLT75K                                     float64
# Tot itemized deductions Amt 75KLT100K                                    float64
# Tot itemized deductions Amt All                                          float64
# Tot itemized deductions Amt GE200K                                       float64
# Tot itemized deductions Amt LT25K                                        float64
# Tot itemized deductions Amt of AGI 100KLT200K                            float64
# Tot itemized deductions Amt of AGI 25KLT50K                              float64
# Tot itemized deductions Amt of AGI 50KLT75K                              float64
# Tot itemized deductions Amt of AGI 75KLT100K                             float64
# Tot itemized deductions Amt of AGI All                                   float64
# Tot itemized deductions Amt of AGI GE200K                                float64
# Tot itemized deductions Amt of AGI LT25K                                 float64
# Tot itemized deductions Ct 100KLT200K                                    float64
# Tot itemized deductions Ct 25KLT50K                                      float64
# Tot itemized deductions Ct 50KLT75K                                      float64
# Tot itemized deductions Ct 75KLT100K                                     float64
# Tot itemized deductions Ct All                                           float64
# Tot itemized deductions Ct GE200K                                        float64
# Tot itemized deductions Ct LT25K                                         float64
# Tot statuory adjustments Amt 100KLT200K                                  float64
# Tot statuory adjustments Amt 25KLT50K                                    float64
# Tot statuory adjustments Amt 50KLT75K                                    float64
# Tot statuory adjustments Amt 75KLT100K                                   float64
# Tot statuory adjustments Amt All                                         float64
# Tot statuory adjustments Amt GE200K                                      float64
# Tot statuory adjustments Amt LT25K                                       float64
# Tot statuory adjustments Ct 100KLT200K                                   float64
# Tot statuory adjustments Ct 25KLT50K                                     float64
# Tot statuory adjustments Ct 50KLT75K                                     float64
# Tot statuory adjustments Ct 75KLT100K                                    float64
# Tot statuory adjustments Ct All                                          float64
# Tot statuory adjustments Ct GE200K                                       float64
# Tot statuory adjustments Ct LT25K                                        float64
# Tot tax credits Amt 100KLT200K                                           float64
# Tot tax credits Amt 25KLT50K                                             float64
# Tot tax credits Amt 50KLT75K                                             float64
# Tot tax credits Amt 75KLT100K                                            float64
# Tot tax credits Amt All                                                  float64
# Tot tax credits Amt GE200K                                               float64
# Tot tax credits Amt LT25K                                                float64
# Tot tax credits Ct 100KLT200K                                            float64
# Tot tax credits Ct 25KLT50K                                              float64
# Tot tax credits Ct 50KLT75K                                              float64
# Tot tax credits Ct 75KLT100K                                             float64
# Tot tax credits Ct All                                                   float64
# Tot tax credits Ct GE200K                                                float64
# Tot tax credits Ct LT25K                                                 float64
# Tot tax liability Amt 100KLT200K                                         float64
# Tot tax liability Amt 25KLT50K                                           float64
# Tot tax liability Amt 50KLT75K                                           float64
# Tot tax liability Amt 75KLT100K                                          float64
# Tot tax liability Amt All                                                float64
# Tot tax liability Amt GE200K                                             float64
# Tot tax liability Amt LT25K                                              float64
# Tot tax liability Ct 100KLT200K                                          float64
# Tot tax liability Ct 25KLT50K                                            float64
# Tot tax liability Ct 50KLT75K                                            float64
# Tot tax liability Ct 75KLT100K                                           float64
# Tot tax liability Ct All                                                 float64
# Tot tax liability Ct GE200K                                              float64
# Tot tax liability Ct LT25K                                               float64
# Tot tax payments Amt 100KLT200K                                          float64
# Tot tax payments Amt 25KLT50K                                            float64
# Tot tax payments Amt 50KLT75K                                            float64
# Tot tax payments Amt 75KLT100K                                           float64
# Tot tax payments Amt All                                                 float64
# Tot tax payments Amt GE200K                                              float64
# Tot tax payments Amt LT25K                                               float64
# Tot tax payments Ct 100KLT200K                                           float64
# Tot tax payments Ct 25KLT50K                                             float64
# Tot tax payments Ct 50KLT75K                                             float64
# Tot tax payments Ct 75KLT100K                                            float64
# Tot tax payments Ct All                                                  float64
# Tot tax payments Ct GE200K                                               float64
# Tot tax payments Ct LT25K                                                float64
# Tuition and fees deduction Amt 100KLT200K                                float64
# Tuition and fees deduction Amt 25KLT50K                                  float64
# Tuition and fees deduction Amt 50KLT75K                                  float64
# Tuition and fees deduction Amt 75KLT100K                                 float64
# Tuition and fees deduction Amt All                                       float64
# Tuition and fees deduction Amt GE200K                                    float64
# Tuition and fees deduction Amt LT25K                                     float64
# Tuition and fees deduction Ct 100KLT200K                                 float64
# Tuition and fees deduction Ct 25KLT50K                                   float64
# Tuition and fees deduction Ct 50KLT75K                                   float64
# Tuition and fees deduction Ct 75KLT100K                                  float64
# Tuition and fees deduction Ct All                                        float64
# Tuition and fees deduction Ct GE200K                                     float64
# Tuition and fees deduction Ct LT25K                                      float64
# Unemployment compensation Amt 100KLT200K                                 float64
# Unemployment compensation Amt 25KLT50K                                   float64
# Unemployment compensation Amt 50KLT75K                                   float64
# Unemployment compensation Amt 75KLT100K                                  float64
# Unemployment compensation Amt All                                        float64
# Unemployment compensation Amt GE200K                                     float64
# Unemployment compensation Amt LT25K                                      float64
# Unemployment compensation Ct 100KLT200K                                  float64
# Unemployment compensation Ct 25KLT50K                                    float64
# Unemployment compensation Ct 50KLT75K                                    float64
# Unemployment compensation Ct 75KLT100K                                   float64
# Unemployment compensation Ct All                                         float64
# Unemployment compensation Ct GE200K                                      float64
# Unemployment compensation Ct LT25K                                       float64
# LEACode                                                                  float64
# TotalTeachers                                                            object
# TeachersLeaving                                                          object
# RemainedinEducation                                                      float64
# RemainedinEducationPerct                                                 float64
# PersonalReasons                                                          float64
# PersonalPerct                                                            float64
# InitiatedbyLEA                                                           float64
# InitiatedPerct                                                           float64
# BeyondControlofLEA                                                       float64
# BeyondControlPerct                                                       float64
# OtherReasons                                                             float64
# OtherReasonsPerct                                                        float64
# dtypes: float64(2014), int64(3), object(38)
# memory usage: 8.4+ MB

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print( 'Rows Updated / Imputed: ', rowsUpdated )
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print( '\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1850 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(1817), object(33)
# memory usage: 7.6+ MB
#
# Columns Deleted:  205

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print( '\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1847 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(1817), object(30)
# memory usage: 7.6+ MB
#
# Columns Deleted:  3

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1847 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(1817), object(30)
# memory usage: 7.6+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  30
# Continuous Columns:  1817
# Columns Accounted for:  1847

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1340 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(1310), object(30)
# memory usage: 5.5+ MB
#
# Columns Deleted:  507

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1325 entries, category_cd to OtherReasonsPerct
# dtypes: float64(1310), object(15)
# memory usage: 5.4+ MB
#
# Columns Deleted:  15

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print ('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print ('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  15
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1358 entries, student_num to esea_attendance_Met
# dtypes: float64(1310), uint8(48)
# memory usage: 5.4 MB
#
# New Columns Created Via One-Hot Encoding:  33

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                           Variable Name  Number Missing Values
# 3                                           Math I_Size                     53
# 15                                   Reading  SPG Score                      2
# 16                                       Math SPG Score                      2
# 19                                           Read Score                      2
# 20                                           Math Score                      2
# 21                                        Science Score                      7
# 22                                         Math I Score                     52
# 23                                    EOCMathI_CACR_All                     52
# 24                                     EOCMathI_GLP_All                     52
# 25                                 EOCSubjects_CACR_All                     52
# 26                                  EOCSubjects_GLP_All                     52
# 29                                      EOGGr6_CACR_All                     35
# 30                                       EOGGr6_GLP_All                     35
# 31                                      EOGGr7_CACR_All                     18
# 32                                       EOGGr7_GLP_All                     18
# 33                                      EOGGr8_CACR_All                     20
# 34                                       EOGGr8_GLP_All                     20
# 35                                EOGMathGr3-8_CACR_All                      2
# 36                                 EOGMathGr3-8_GLP_All                      2
# 37                                  EOGMathGr6_CACR_All                     36
# 38                                   EOGMathGr6_GLP_All                     36
# 39                                  EOGMathGr7_CACR_All                     19
# 40                                   EOGMathGr7_GLP_All                     19
# 41                                  EOGMathGr8_CACR_All                     20
# 42                                   EOGMathGr8_GLP_All                     20
# 43                             EOGReadingGr3-8_CACR_All                      2
# 44                              EOGReadingGr3-8_GLP_All                      2
# 45                               EOGReadingGr6_CACR_All                     36
# 46                                EOGReadingGr6_GLP_All                     36
# 47                               EOGReadingGr7_CACR_All                     19
# 48                                EOGReadingGr7_GLP_All                     19
# 49                               EOGReadingGr8_CACR_All                     20
# 50                                EOGReadingGr8_GLP_All                     20
# 51                             EOGScienceGr5&8_CACR_All                      7
# 52                              EOGScienceGr5&8_GLP_All                      7
# 53                               EOGScienceGr8_CACR_All                     20
# 54                                EOGScienceGr8_GLP_All                     20
# 55                                 EOGSubjects_CACR_All                      2
# 56                                  EOGSubjects_GLP_All                      2
# 57                                 EOCMathI_CACR_Female                     52
# 58                                  EOCMathI_GLP_Female                     52
# 59                              EOCSubjects_CACR_Female                     52
# 60                               EOCSubjects_GLP_Female                     52
# 63                                   EOGGr6_CACR_Female                     35
# 64                                    EOGGr6_GLP_Female                     35
# 65                                   EOGGr7_CACR_Female                     18
# 66                                    EOGGr7_GLP_Female                     18
# 67                                   EOGGr8_CACR_Female                     20
# 68                                    EOGGr8_GLP_Female                     20
# 69                             EOGMathGr3-8_CACR_Female                      2
# 70                              EOGMathGr3-8_GLP_Female                      2
# 71                               EOGMathGr6_CACR_Female                     36
# 72                                EOGMathGr6_GLP_Female                     36
# 73                               EOGMathGr7_CACR_Female                     19
# 74                                EOGMathGr7_GLP_Female                     19
# 75                               EOGMathGr8_CACR_Female                     20
# 76                                EOGMathGr8_GLP_Female                     20
# 77                          EOGReadingGr3-8_CACR_Female                      2
# 78                           EOGReadingGr3-8_GLP_Female                      2
# 79                            EOGReadingGr6_CACR_Female                     36
# 80                             EOGReadingGr6_GLP_Female                     36
# 81                            EOGReadingGr7_CACR_Female                     19
# 82                             EOGReadingGr7_GLP_Female                     19
# 83                            EOGReadingGr8_CACR_Female                     20
# 84                             EOGReadingGr8_GLP_Female                     20
# 85                          EOGScienceGr5&8_CACR_Female                      7
# 86                           EOGScienceGr5&8_GLP_Female                      7
# 87                            EOGScienceGr8_CACR_Female                     20
# 88                             EOGScienceGr8_GLP_Female                     20
# 89                              EOGSubjects_CACR_Female                      2
# 90                               EOGSubjects_GLP_Female                      2
# 91                                   EOCMathI_CACR_Male                     52
# 92                                    EOCMathI_GLP_Male                     52
# 93                                EOCSubjects_CACR_Male                     52
# 94                                 EOCSubjects_GLP_Male                     52
# 97                                     EOGGr6_CACR_Male                     35
# 98                                      EOGGr6_GLP_Male                     35
# 99                                     EOGGr7_CACR_Male                     18
# 100                                     EOGGr7_GLP_Male                     18
# 101                                    EOGGr8_CACR_Male                     20
# 102                                     EOGGr8_GLP_Male                     20
# 103                              EOGMathGr3-8_CACR_Male                      2
# 104                               EOGMathGr3-8_GLP_Male                      2
# 105                                EOGMathGr6_CACR_Male                     36
# 106                                 EOGMathGr6_GLP_Male                     36
# 107                                EOGMathGr7_CACR_Male                     19
# 108                                 EOGMathGr7_GLP_Male                     19
# 109                                EOGMathGr8_CACR_Male                     20
# 110                                 EOGMathGr8_GLP_Male                     20
# 111                           EOGReadingGr3-8_CACR_Male                      2
# 112                            EOGReadingGr3-8_GLP_Male                      2
# 113                             EOGReadingGr6_CACR_Male                     36
# 114                              EOGReadingGr6_GLP_Male                     36
# 115                             EOGReadingGr7_CACR_Male                     19
# 116                              EOGReadingGr7_GLP_Male                     19
# 117                             EOGReadingGr8_CACR_Male                     20
# 118                              EOGReadingGr8_GLP_Male                     20
# 119                           EOGScienceGr5&8_CACR_Male                      7
# 120                            EOGScienceGr5&8_GLP_Male                      7
# 121                             EOGScienceGr8_CACR_Male                     20
# 122                              EOGScienceGr8_GLP_Male                     20
# 123                               EOGSubjects_CACR_Male                      2
# 124                                EOGSubjects_GLP_Male                      2
# 125                        EOCMathI_CACR_AmericanIndian                     52
# 126                         EOCMathI_GLP_AmericanIndian                     52
# 127                     EOCSubjects_CACR_AmericanIndian                     52
# 128                      EOCSubjects_GLP_AmericanIndian                     52
# 131                          EOGGr6_CACR_AmericanIndian                     35
# 132                           EOGGr6_GLP_AmericanIndian                     35
# 133                          EOGGr7_CACR_AmericanIndian                     18
# 134                           EOGGr7_GLP_AmericanIndian                     18
# 135                          EOGGr8_CACR_AmericanIndian                     20
# 136                           EOGGr8_GLP_AmericanIndian                     20
# 137                    EOGMathGr3-8_CACR_AmericanIndian                      2
# 138                     EOGMathGr3-8_GLP_AmericanIndian                      2
# 139                      EOGMathGr6_CACR_AmericanIndian                     36
# 140                       EOGMathGr6_GLP_AmericanIndian                     36
# 141                      EOGMathGr7_CACR_AmericanIndian                     19
# 142                       EOGMathGr7_GLP_AmericanIndian                     19
# 143                      EOGMathGr8_CACR_AmericanIndian                     20
# 144                       EOGMathGr8_GLP_AmericanIndian                     20
# 145                 EOGReadingGr3-8_CACR_AmericanIndian                      2
# 146                  EOGReadingGr3-8_GLP_AmericanIndian                      2
# 147                   EOGReadingGr6_CACR_AmericanIndian                     36
# 148                    EOGReadingGr6_GLP_AmericanIndian                     36
# 149                   EOGReadingGr7_CACR_AmericanIndian                     19
# 150                    EOGReadingGr7_GLP_AmericanIndian                     19
# 151                   EOGReadingGr8_CACR_AmericanIndian                     20
# 152                    EOGReadingGr8_GLP_AmericanIndian                     20
# 153                 EOGScienceGr5&8_CACR_AmericanIndian                      7
# 154                  EOGScienceGr5&8_GLP_AmericanIndian                      7
# 155                   EOGScienceGr8_CACR_AmericanIndian                     20
# 156                    EOGScienceGr8_GLP_AmericanIndian                     20
# 157                     EOGSubjects_CACR_AmericanIndian                      2
# 158                      EOGSubjects_GLP_AmericanIndian                      2
# 159                                 EOCMathI_CACR_Asian                     52
# 160                                  EOCMathI_GLP_Asian                     52
# 161                              EOCSubjects_CACR_Asian                     52
# 162                               EOCSubjects_GLP_Asian                     52
# 165                                   EOGGr6_CACR_Asian                     35
# 166                                    EOGGr6_GLP_Asian                     35
# 167                                   EOGGr7_CACR_Asian                     18
# 168                                    EOGGr7_GLP_Asian                     18
# 169                                   EOGGr8_CACR_Asian                     20
# 170                                    EOGGr8_GLP_Asian                     20
# 171                             EOGMathGr3-8_CACR_Asian                      2
# 172                              EOGMathGr3-8_GLP_Asian                      2
# 173                               EOGMathGr6_CACR_Asian                     36
# 174                                EOGMathGr6_GLP_Asian                     36
# 175                               EOGMathGr7_CACR_Asian                     19
# 176                                EOGMathGr7_GLP_Asian                     19
# 177                               EOGMathGr8_CACR_Asian                     20
# 178                                EOGMathGr8_GLP_Asian                     20
# 179                          EOGReadingGr3-8_CACR_Asian                      2
# 180                           EOGReadingGr3-8_GLP_Asian                      2
# 181                            EOGReadingGr6_CACR_Asian                     36
# 182                             EOGReadingGr6_GLP_Asian                     36
# 183                            EOGReadingGr7_CACR_Asian                     19
# 184                             EOGReadingGr7_GLP_Asian                     19
# 185                            EOGReadingGr8_CACR_Asian                     20
# 186                             EOGReadingGr8_GLP_Asian                     20
# 187                          EOGScienceGr5&8_CACR_Asian                      7
# 188                           EOGScienceGr5&8_GLP_Asian                      7
# 189                            EOGScienceGr8_CACR_Asian                     20
# 190                             EOGScienceGr8_GLP_Asian                     20
# 191                              EOGSubjects_CACR_Asian                      2
# 192                               EOGSubjects_GLP_Asian                      2
# 193                                 EOCMathI_CACR_Black                     52
# 194                                  EOCMathI_GLP_Black                     52
# 195                              EOCSubjects_CACR_Black                     52
# 196                               EOCSubjects_GLP_Black                     52
# 199                                   EOGGr6_CACR_Black                     35
# 200                                    EOGGr6_GLP_Black                     35
# 201                                   EOGGr7_CACR_Black                     18
# 202                                    EOGGr7_GLP_Black                     18
# 203                                   EOGGr8_CACR_Black                     20
# 204                                    EOGGr8_GLP_Black                     20
# 205                             EOGMathGr3-8_CACR_Black                      2
# 206                              EOGMathGr3-8_GLP_Black                      2
# 207                               EOGMathGr6_CACR_Black                     36
# 208                                EOGMathGr6_GLP_Black                     36
# 209                               EOGMathGr7_CACR_Black                     19
# 210                                EOGMathGr7_GLP_Black                     19
# 211                               EOGMathGr8_CACR_Black                     20
# 212                                EOGMathGr8_GLP_Black                     20
# 213                          EOGReadingGr3-8_CACR_Black                      2
# 214                           EOGReadingGr3-8_GLP_Black                      2
# 215                            EOGReadingGr6_CACR_Black                     36
# 216                             EOGReadingGr6_GLP_Black                     36
# 217                            EOGReadingGr7_CACR_Black                     19
# 218                             EOGReadingGr7_GLP_Black                     19
# 219                            EOGReadingGr8_CACR_Black                     20
# 220                             EOGReadingGr8_GLP_Black                     20
# 221                          EOGScienceGr5&8_CACR_Black                      7
# 222                           EOGScienceGr5&8_GLP_Black                      7
# 223                            EOGScienceGr8_CACR_Black                     20
# 224                             EOGScienceGr8_GLP_Black                     20
# 225                              EOGSubjects_CACR_Black                      2
# 226                               EOGSubjects_GLP_Black                      2
# 227                              EOCMathI_CACR_Hispanic                     52
# 228                               EOCMathI_GLP_Hispanic                     52
# 229                           EOCSubjects_CACR_Hispanic                     52
# 230                            EOCSubjects_GLP_Hispanic                     52
# 233                                EOGGr6_CACR_Hispanic                     35
# 234                                 EOGGr6_GLP_Hispanic                     35
# 235                                EOGGr7_CACR_Hispanic                     18
# 236                                 EOGGr7_GLP_Hispanic                     18
# 237                                EOGGr8_CACR_Hispanic                     20
# 238                                 EOGGr8_GLP_Hispanic                     20
# 239                          EOGMathGr3-8_CACR_Hispanic                      2
# 240                           EOGMathGr3-8_GLP_Hispanic                      2
# 241                            EOGMathGr6_CACR_Hispanic                     36
# 242                             EOGMathGr6_GLP_Hispanic                     36
# 243                            EOGMathGr7_CACR_Hispanic                     19
# 244                             EOGMathGr7_GLP_Hispanic                     19
# 245                            EOGMathGr8_CACR_Hispanic                     20
# 246                             EOGMathGr8_GLP_Hispanic                     20
# 247                       EOGReadingGr3-8_CACR_Hispanic                      2
# 248                        EOGReadingGr3-8_GLP_Hispanic                      2
# 249                         EOGReadingGr6_CACR_Hispanic                     36
# 250                          EOGReadingGr6_GLP_Hispanic                     36
# 251                         EOGReadingGr7_CACR_Hispanic                     19
# 252                          EOGReadingGr7_GLP_Hispanic                     19
# 253                         EOGReadingGr8_CACR_Hispanic                     20
# 254                          EOGReadingGr8_GLP_Hispanic                     20
# 255                       EOGScienceGr5&8_CACR_Hispanic                      7
# 256                        EOGScienceGr5&8_GLP_Hispanic                      7
# 257                         EOGScienceGr8_CACR_Hispanic                     20
# 258                          EOGScienceGr8_GLP_Hispanic                     20
# 259                           EOGSubjects_CACR_Hispanic                      2
# 260                            EOGSubjects_GLP_Hispanic                      2
# 261                        EOCMathI_CACR_TwoorMoreRaces                     52
# 262                         EOCMathI_GLP_TwoorMoreRaces                     52
# 263                     EOCSubjects_CACR_TwoorMoreRaces                     52
# 264                      EOCSubjects_GLP_TwoorMoreRaces                     52
# 267                          EOGGr6_CACR_TwoorMoreRaces                     35
# 268                           EOGGr6_GLP_TwoorMoreRaces                     35
# 269                          EOGGr7_CACR_TwoorMoreRaces                     18
# 270                           EOGGr7_GLP_TwoorMoreRaces                     18
# 271                          EOGGr8_CACR_TwoorMoreRaces                     20
# 272                           EOGGr8_GLP_TwoorMoreRaces                     20
# 273                    EOGMathGr3-8_CACR_TwoorMoreRaces                      2
# 274                     EOGMathGr3-8_GLP_TwoorMoreRaces                      2
# 275                      EOGMathGr6_CACR_TwoorMoreRaces                     36
# 276                       EOGMathGr6_GLP_TwoorMoreRaces                     36
# 277                      EOGMathGr7_CACR_TwoorMoreRaces                     19
# 278                       EOGMathGr7_GLP_TwoorMoreRaces                     19
# 279                      EOGMathGr8_CACR_TwoorMoreRaces                     20
# 280                       EOGMathGr8_GLP_TwoorMoreRaces                     20
# 281                 EOGReadingGr3-8_CACR_TwoorMoreRaces                      2
# 282                  EOGReadingGr3-8_GLP_TwoorMoreRaces                      2
# 283                   EOGReadingGr6_CACR_TwoorMoreRaces                     36
# 284                    EOGReadingGr6_GLP_TwoorMoreRaces                     36
# 285                   EOGReadingGr7_CACR_TwoorMoreRaces                     19
# 286                    EOGReadingGr7_GLP_TwoorMoreRaces                     19
# 287                   EOGReadingGr8_CACR_TwoorMoreRaces                     20
# 288                    EOGReadingGr8_GLP_TwoorMoreRaces                     20
# 289                 EOGScienceGr5&8_CACR_TwoorMoreRaces                      7
# 290                  EOGScienceGr5&8_GLP_TwoorMoreRaces                      7
# 291                   EOGScienceGr8_CACR_TwoorMoreRaces                     20
# 292                    EOGScienceGr8_GLP_TwoorMoreRaces                     20
# 293                     EOGSubjects_CACR_TwoorMoreRaces                      2
# 294                      EOGSubjects_GLP_TwoorMoreRaces                      2
# 295                                 EOCMathI_CACR_White                     52
# 296                                  EOCMathI_GLP_White                     52
# 297                              EOCSubjects_CACR_White                     52
# 298                               EOCSubjects_GLP_White                     52
# 301                                   EOGGr6_CACR_White                     35
# 302                                    EOGGr6_GLP_White                     35
# 303                                   EOGGr7_CACR_White                     18
# 304                                    EOGGr7_GLP_White                     18
# 305                                   EOGGr8_CACR_White                     20
# 306                                    EOGGr8_GLP_White                     20
# 307                             EOGMathGr3-8_CACR_White                      2
# 308                              EOGMathGr3-8_GLP_White                      2
# 309                               EOGMathGr6_CACR_White                     36
# 310                                EOGMathGr6_GLP_White                     36
# 311                               EOGMathGr7_CACR_White                     19
# 312                                EOGMathGr7_GLP_White                     19
# 313                               EOGMathGr8_CACR_White                     20
# 314                                EOGMathGr8_GLP_White                     20
# 315                          EOGReadingGr3-8_CACR_White                      2
# 316                           EOGReadingGr3-8_GLP_White                      2
# 317                            EOGReadingGr6_CACR_White                     36
# 318                             EOGReadingGr6_GLP_White                     36
# 319                            EOGReadingGr7_CACR_White                     19
# 320                             EOGReadingGr7_GLP_White                     19
# 321                            EOGReadingGr8_CACR_White                     20
# 322                             EOGReadingGr8_GLP_White                     20
# 323                          EOGScienceGr5&8_CACR_White                      7
# 324                           EOGScienceGr5&8_GLP_White                      7
# 325                            EOGScienceGr8_CACR_White                     20
# 326                             EOGScienceGr8_GLP_White                     20
# 327                              EOGSubjects_CACR_White                      2
# 328                               EOGSubjects_GLP_White                      2
# 329                                   EOCMathI_CACR_EDS                     52
# 330                                    EOCMathI_GLP_EDS                     52
# 331                                EOCSubjects_CACR_EDS                     52
# 332                                 EOCSubjects_GLP_EDS                     52
# 335                                     EOGGr6_CACR_EDS                     35
# 336                                      EOGGr6_GLP_EDS                     35
# 337                                     EOGGr7_CACR_EDS                     18
# 338                                      EOGGr7_GLP_EDS                     18
# 339                                     EOGGr8_CACR_EDS                     20
# 340                                      EOGGr8_GLP_EDS                     20
# 341                               EOGMathGr3-8_CACR_EDS                      2
# 342                                EOGMathGr3-8_GLP_EDS                      2
# 343                                 EOGMathGr6_CACR_EDS                     36
# 344                                  EOGMathGr6_GLP_EDS                     36
# 345                                 EOGMathGr7_CACR_EDS                     19
# 346                                  EOGMathGr7_GLP_EDS                     19
# 347                                 EOGMathGr8_CACR_EDS                     20
# 348                                  EOGMathGr8_GLP_EDS                     20
# 349                            EOGReadingGr3-8_CACR_EDS                      2
# 350                             EOGReadingGr3-8_GLP_EDS                      2
# 351                              EOGReadingGr6_CACR_EDS                     36
# 352                               EOGReadingGr6_GLP_EDS                     36
# 353                              EOGReadingGr7_CACR_EDS                     19
# 354                               EOGReadingGr7_GLP_EDS                     19
# 355                              EOGReadingGr8_CACR_EDS                     20
# 356                               EOGReadingGr8_GLP_EDS                     20
# 357                            EOGScienceGr5&8_CACR_EDS                      7
# 358                             EOGScienceGr5&8_GLP_EDS                      7
# 359                              EOGScienceGr8_CACR_EDS                     20
# 360                               EOGScienceGr8_GLP_EDS                     20
# 361                                EOGSubjects_CACR_EDS                      2
# 362                                 EOGSubjects_GLP_EDS                      2
# 363                                   EOCMathI_CACR_LEP                     52
# 364                                    EOCMathI_GLP_LEP                     52
# 365                                EOCSubjects_CACR_LEP                     52
# 366                                 EOCSubjects_GLP_LEP                     52
# 369                                     EOGGr6_CACR_LEP                     35
# 370                                      EOGGr6_GLP_LEP                     35
# 371                                     EOGGr7_CACR_LEP                     18
# 372                                      EOGGr7_GLP_LEP                     18
# 373                                     EOGGr8_CACR_LEP                     20
# 374                                      EOGGr8_GLP_LEP                     20
# 375                               EOGMathGr3-8_CACR_LEP                      2
# 376                                EOGMathGr3-8_GLP_LEP                      2
# 377                                 EOGMathGr6_CACR_LEP                     36
# 378                                  EOGMathGr6_GLP_LEP                     36
# 379                                 EOGMathGr7_CACR_LEP                     19
# 380                                  EOGMathGr7_GLP_LEP                     19
# 381                                 EOGMathGr8_CACR_LEP                     20
# 382                                  EOGMathGr8_GLP_LEP                     20
# 383                            EOGReadingGr3-8_CACR_LEP                      2
# 384                             EOGReadingGr3-8_GLP_LEP                      2
# 385                              EOGReadingGr6_CACR_LEP                     36
# 386                               EOGReadingGr6_GLP_LEP                     36
# 387                              EOGReadingGr7_CACR_LEP                     19
# 388                               EOGReadingGr7_GLP_LEP                     19
# 389                              EOGReadingGr8_CACR_LEP                     20
# 390                               EOGReadingGr8_GLP_LEP                     20
# 391                            EOGScienceGr5&8_CACR_LEP                      7
# 392                             EOGScienceGr5&8_GLP_LEP                      7
# 393                              EOGScienceGr8_CACR_LEP                     20
# 394                               EOGScienceGr8_GLP_LEP                     20
# 395                                EOGSubjects_CACR_LEP                      2
# 396                                 EOGSubjects_GLP_LEP                      2
# 397                                   EOCMathI_CACR_SWD                     52
# 398                                    EOCMathI_GLP_SWD                     52
# 399                                EOCSubjects_CACR_SWD                     52
# 400                                 EOCSubjects_GLP_SWD                     52
# 403                                     EOGGr6_CACR_SWD                     35
# 404                                      EOGGr6_GLP_SWD                     35
# 405                                     EOGGr7_CACR_SWD                     18
# 406                                      EOGGr7_GLP_SWD                     18
# 407                                     EOGGr8_CACR_SWD                     20
# 408                                      EOGGr8_GLP_SWD                     20
# 409                               EOGMathGr3-8_CACR_SWD                      2
# 410                                EOGMathGr3-8_GLP_SWD                      2
# 411                                 EOGMathGr6_CACR_SWD                     36
# 412                                  EOGMathGr6_GLP_SWD                     36
# 413                                 EOGMathGr7_CACR_SWD                     19
# 414                                  EOGMathGr7_GLP_SWD                     19
# 415                                 EOGMathGr8_CACR_SWD                     20
# 416                                  EOGMathGr8_GLP_SWD                     20
# 417                            EOGReadingGr3-8_CACR_SWD                      2
# 418                             EOGReadingGr3-8_GLP_SWD                      2
# 419                              EOGReadingGr6_CACR_SWD                     36
# 420                               EOGReadingGr6_GLP_SWD                     36
# 421                              EOGReadingGr7_CACR_SWD                     19
# 422                               EOGReadingGr7_GLP_SWD                     19
# 423                              EOGReadingGr8_CACR_SWD                     20
# 424                               EOGReadingGr8_GLP_SWD                     20
# 425                            EOGScienceGr5&8_CACR_SWD                      7
# 426                             EOGScienceGr5&8_GLP_SWD                      7
# 427                              EOGScienceGr8_CACR_SWD                     20
# 428                               EOGScienceGr8_GLP_SWD                     20
# 429                                EOGSubjects_CACR_SWD                      2
# 430                                 EOGSubjects_GLP_SWD                      2
# 431                                   EOCMathI_CACR_AIG                     52
# 432                                    EOCMathI_GLP_AIG                     52
# 433                                EOCSubjects_CACR_AIG                     52
# 434                                 EOCSubjects_GLP_AIG                     52
# 437                                     EOGGr6_CACR_AIG                     35
# 438                                      EOGGr6_GLP_AIG                     35
# 439                                     EOGGr7_CACR_AIG                     18
# 440                                      EOGGr7_GLP_AIG                     18
# 441                                     EOGGr8_CACR_AIG                     20
# 442                                      EOGGr8_GLP_AIG                     20
# 443                               EOGMathGr3-8_CACR_AIG                      2
# 444                                EOGMathGr3-8_GLP_AIG                      2
# 445                                 EOGMathGr6_CACR_AIG                     36
# 446                                  EOGMathGr6_GLP_AIG                     36
# 447                                 EOGMathGr7_CACR_AIG                     19
# 448                                  EOGMathGr7_GLP_AIG                     19
# 449                                 EOGMathGr8_CACR_AIG                     20
# 450                                  EOGMathGr8_GLP_AIG                     20
# 451                            EOGReadingGr3-8_CACR_AIG                      2
# 452                             EOGReadingGr3-8_GLP_AIG                      2
# 453                              EOGReadingGr6_CACR_AIG                     36
# 454                               EOGReadingGr6_GLP_AIG                     36
# 455                              EOGReadingGr7_CACR_AIG                     19
# 456                               EOGReadingGr7_GLP_AIG                     19
# 457                              EOGReadingGr8_CACR_AIG                     20
# 458                               EOGReadingGr8_GLP_AIG                     20
# 459                            EOGScienceGr5&8_CACR_AIG                      7
# 460                             EOGScienceGr5&8_GLP_AIG                      7
# 461                              EOGScienceGr8_CACR_AIG                     20
# 462                               EOGScienceGr8_GLP_AIG                     20
# 463                                EOGSubjects_CACR_AIG                      2
# 464                                 EOGSubjects_GLP_AIG                      2
# 465                       CurrentYearEOC_pTarget_PctMet                    201
# 466                            MathGr3-8_pTarget_PctMet                      4
# 467                         ReadingGr3-8_pTarget_PctMet                      4
# 468                             SciGr5&8_pTarget_PctMet                     14
# 472                            lea_ap_participation_pct                    114
# 473                               lea_ap_pct_3_or_above                      4
# 488                                 flicensed_teach_pct                      1
# 489                                   tchyrs_0thru3_pct                      1
# 490                                  tchyrs_4thru10_pct                      1
# 491                                   tchyrs_11plus_pct                      1
# 492                                     class_teach_num                      1
# 493                                           nbpts_num                     32
# 494                                     advance_dgr_pct                      1
# 495                                _1yr_tchr_trnovr_pct                      4
# 496                                   lateral_teach_pct                    204
# 502                                       lea_nbpts_num                      7
# 505                             lea_emer_prov_teach_pct                    276
# 506                               lea_lateral_teach_pct                     70
# 517                               0-3 Years_Exp_Pct_Tch                      1
# 518                               10+ Years_Exp_Pct_Tch                      1
# 519                              4-10 Years_Exp_Pct_Tch                      1
# 523                    Accomplished_TCHR_Standard 1_Pct                      2
# 524                    Accomplished_TCHR_Standard 2_Pct                      2
# 525                    Accomplished_TCHR_Standard 3_Pct                      2
# 526                    Accomplished_TCHR_Standard 4_Pct                      2
# 527                    Accomplished_TCHR_Standard 5_Pct                      2
# 528                      Developing_TCHR_Standard 1_Pct                      2
# 529                      Developing_TCHR_Standard 2_Pct                      2
# 530                      Developing_TCHR_Standard 3_Pct                      2
# 531                      Developing_TCHR_Standard 4_Pct                      2
# 532                      Developing_TCHR_Standard 5_Pct                      2
# 533                   Distinguished_TCHR_Standard 1_Pct                      2
# 534                   Distinguished_TCHR_Standard 2_Pct                      2
# 535                   Distinguished_TCHR_Standard 3_Pct                      2
# 536                   Distinguished_TCHR_Standard 4_Pct                      2
# 537                   Distinguished_TCHR_Standard 5_Pct                      2
# 538   Does Not Meet Expected Growth_TCHR_Standard 6_Pct                      2
# 539         Exceeds Expected Growth_TCHR_Standard 6_Pct                      2
# 540           Meets Expected Growth_TCHR_Standard 6_Pct                      2
# 541                 Not Demostrated_TCHR_Standard 1_Pct                      2
# 542                 Not Demostrated_TCHR_Standard 2_Pct                      2
# 543                 Not Demostrated_TCHR_Standard 3_Pct                      2
# 544                 Not Demostrated_TCHR_Standard 4_Pct                      2
# 545                 Not Demostrated_TCHR_Standard 5_Pct                      2
# 546                      Proficient_TCHR_Standard 1_Pct                      2
# 547                      Proficient_TCHR_Standard 2_Pct                      2
# 548                      Proficient_TCHR_Standard 3_Pct                      2
# 549                      Proficient_TCHR_Standard 4_Pct                      2
# 550                      Proficient_TCHR_Standard 5_Pct                      2
# 575                                                Year                    135
# 576                                        Violent Rate                    185
# 577                                         Murder Rate                    223
# 578                                           Rape Rate                    192
# 579                                        Robbery Rate                    192
# 580                                        Assault Rate                    185
# 581                                            MVT Rate                    186
# 582                                          Arson Rate                    200
# 1299                                            LEACode                     47
# 1300                                RemainedinEducation                     47
# 1301                           RemainedinEducationPerct                     47
# 1302                                    PersonalReasons                     47
# 1303                                      PersonalPerct                     47
# 1304                                     InitiatedbyLEA                     47
# 1305                                     InitiatedPerct                     47
# 1306                                 BeyondControlofLEA                     47
# 1307                                 BeyondControlPerct                     47
# 1308                                       OtherReasons                     47
# 1309                                  OtherReasonsPerct                     47

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  186012  field correlations > 95%.
#                                            Field1  \
# 0                                 class_teach_num
# 1                             lea_class_teach_num
# 2                              st_class_teach_num
# 3                              st_advance_dgr_pct
# 4                                   category_cd_M
# 5                                   Category_Cd_M
# 6                       Overall Achievement Score
# 7                        EOG/EOCSubjects_CACR_All
# 8                         EOG/EOCSubjects_GLP_All
# 9                      EOG/EOCSubjects_GLP_Female
# 10                                     Read Score
# 11                       EOGReadingGr3-8_CACR_All
# 12                        EOGReadingGr3-8_GLP_All
# 13                            EOGSubjects_GLP_All
# 14                                     Math Score
# 15                          EOGMathGr3-8_CACR_All
# 16                           EOGMathGr3-8_GLP_All
# 17                            EOGSubjects_GLP_All
# 18                       EOGMathGr3-8_CACR_Female
# 19                        EOGMathGr3-8_GLP_Female
# 20                         EOGMathGr3-8_CACR_Male
# 21                          EOGMathGr3-8_GLP_Male
# 22                       EOG/EOCSubjects_CACR_All
# 23                        EOG/EOCSubjects_GLP_All
# 24                    EOG/EOCSubjects_CACR_Female
# 25                     EOG/EOCSubjects_GLP_Female
# 26                      EOG/EOCSubjects_CACR_Male
# 27                       EOG/EOCSubjects_GLP_Male
# 28                       EOGReadingGr3-8_CACR_All
# 29                        EOGReadingGr3-8_GLP_All
# 30                           EOGSubjects_CACR_All
# 31                            EOGSubjects_GLP_All
# 32                    EOGReadingGr3-8_CACR_Female
# 33                     EOGReadingGr3-8_GLP_Female
# 34                      EOGReadingGr3-8_CACR_Male
# 35                       EOGReadingGr3-8_GLP_Male
# 36                          EOGMathGr3-8_CACR_All
# 37                           EOGMathGr3-8_GLP_All
# 38                           EOGSubjects_CACR_All
# 39                            EOGSubjects_GLP_All
# 40                       EOGMathGr3-8_CACR_Female
# 41                        EOGMathGr3-8_GLP_Female
# 42                         EOGMathGr3-8_CACR_Male
# 43                          EOGMathGr3-8_GLP_Male
# 44                       EOGScienceGr5&8_CACR_All
# 45                        EOGScienceGr5&8_GLP_All
# 46                       EOGScienceGr5&8_GLP_Male
# 47                              EOCMathI_CACR_All
# 48                               EOCMathI_GLP_All
# 49                           EOCSubjects_CACR_All
# 50                            EOCSubjects_GLP_All
# 51                               EOCMathI_GLP_All
# 52                           EOCSubjects_CACR_All
# 53                            EOCSubjects_GLP_All
# 54                           EOCSubjects_CACR_All
# 55                            EOCSubjects_GLP_All
# 56                            EOCSubjects_GLP_All
# 57                        EOG/EOCSubjects_GLP_All
# 58                           EOGSubjects_CACR_All
# 59                            EOGSubjects_GLP_All
# 60                    EOG/EOCSubjects_CACR_Female
# 61                     EOG/EOCSubjects_GLP_Female
# 62                      EOG/EOCSubjects_CACR_Male
# 63                       EOG/EOCSubjects_GLP_Male
# 64                           EOGSubjects_CACR_All
# 65                            EOGSubjects_GLP_All
# 66                    EOG/EOCSubjects_CACR_Female
# 67                     EOG/EOCSubjects_GLP_Female
# 68                      EOG/EOCSubjects_CACR_Male
# 69                       EOG/EOCSubjects_GLP_Male
# 70                                 EOGGr6_GLP_All
# 71                            EOGMathGr6_CACR_All
# 72                             EOGMathGr6_GLP_All
# 73                         EOGReadingGr6_CACR_All
# 74                          EOGReadingGr6_GLP_All
# 75                             EOGGr6_CACR_Female
# 76                              EOGGr6_GLP_Female
# 77                               EOGGr6_CACR_Male
# 78                                EOGGr6_GLP_Male
# 79                            EOGMathGr6_CACR_All
# 80                             EOGMathGr6_GLP_All
# 81                         EOGReadingGr6_CACR_All
# 82                          EOGReadingGr6_GLP_All
# 83                             EOGGr6_CACR_Female
# 84                              EOGGr6_GLP_Female
# 85                               EOGGr6_CACR_Male
# 86                                EOGGr6_GLP_Male
# 87                                 EOGGr7_GLP_All
# 88                            EOGMathGr7_CACR_All
# 89                             EOGMathGr7_GLP_All
# 90                         EOGReadingGr7_CACR_All
# 91                             EOGGr7_CACR_Female
# 92                              EOGGr7_GLP_Female
# 93                               EOGGr7_CACR_Male
# 94                            EOGMathGr7_CACR_All
# 95                             EOGMathGr7_GLP_All
# 96                         EOGReadingGr7_CACR_All
# 97                          EOGReadingGr7_GLP_All
# 98                             EOGGr7_CACR_Female
# 99                              EOGGr7_GLP_Female
# 100                               EOGGr7_GLP_Male
# 101                                EOGGr8_GLP_All
# 102                        EOGReadingGr8_CACR_All
# 103                         EOGReadingGr8_GLP_All
# 104                            EOGGr8_CACR_Female
# 105                              EOGGr8_CACR_Male
# 106                               EOGGr8_GLP_Male
# 107                         EOGReadingGr8_GLP_All
# 108                             EOGGr8_GLP_Female
# 109                               EOGGr8_GLP_Male
# 110                          EOGMathGr3-8_GLP_All
# 111                          EOGSubjects_CACR_All
# 112                           EOGSubjects_GLP_All
# 113                      EOGMathGr3-8_CACR_Female
# 114                       EOGMathGr3-8_GLP_Female
# 115                        EOGMathGr3-8_CACR_Male
# 116                         EOGMathGr3-8_GLP_Male
# 117                          EOGSubjects_CACR_All
# 118                           EOGSubjects_GLP_All
# 119                      EOGMathGr3-8_CACR_Female
# 120                       EOGMathGr3-8_GLP_Female
# 121                        EOGMathGr3-8_CACR_Male
# 122                         EOGMathGr3-8_GLP_Male
# 123                            EOGMathGr6_GLP_All
# 124                          EOGMathGr6_CACR_Male
# 125                          EOGMathGr6_CACR_Male
# 126                           EOGMathGr6_GLP_Male
# 127                            EOGMathGr7_GLP_All
# 128                        EOGMathGr7_CACR_Female
# 129                         EOGMathGr7_GLP_Female
# 130                          EOGMathGr7_CACR_Male
# 131                        EOGMathGr7_CACR_Female
# 132                         EOGMathGr7_GLP_Female
# 133                           EOGMathGr7_GLP_Male
# 134                            EOGMathGr8_GLP_All
# 135                        EOGMathGr8_CACR_Female
# 136                       EOGReadingGr3-8_GLP_All
# 137                          EOGSubjects_CACR_All
# 138                           EOGSubjects_GLP_All
# 139                   EOGReadingGr3-8_CACR_Female
# 140                       EOGSubjects_CACR_Female
# 141                     EOGReadingGr3-8_CACR_Male
# 142                      EOGReadingGr3-8_GLP_Male
# 143                         EOGSubjects_CACR_Male
# 144                          EOGSubjects_CACR_All
# 145                           EOGSubjects_GLP_All
# 146                   EOGReadingGr3-8_CACR_Female
# 147                    EOGReadingGr3-8_GLP_Female
# 148                     EOGReadingGr3-8_CACR_Male
# 149                      EOGReadingGr3-8_GLP_Male
# 150                         EOGReadingGr6_GLP_All
# 151                       EOGReadingGr6_CACR_Male
# 152                        EOGReadingGr6_GLP_Male
# 153                         EOGReadingGr7_GLP_All
# 154                     EOGReadingGr7_CACR_Female
# 155                      EOGReadingGr7_GLP_Female
# 156                         EOGReadingGr8_GLP_All
# 157                       EOGScienceGr5&8_GLP_All
# 158                   EOGScienceGr5&8_CACR_Female
# 159                     EOGScienceGr5&8_CACR_Male
# 160                      EOGScienceGr5&8_GLP_Male
# 161                         EOGScienceGr8_GLP_All
# 162                           EOGSubjects_GLP_All
# 163                       EOGSubjects_CACR_Female
# 164                        EOGSubjects_GLP_Female
# 165                     EOGReadingGr3-8_CACR_Male
# 166                         EOGSubjects_CACR_Male
# 167                          EOGSubjects_GLP_Male
# 168                       EOGSubjects_CACR_Female
# 169                        EOGSubjects_GLP_Female
# 170                         EOGSubjects_CACR_Male
# 171                          EOGSubjects_GLP_Male
# 172                           EOCMathI_GLP_Female
# 173                       EOCSubjects_CACR_Female
# 174                        EOCSubjects_GLP_Female
# 175                        EOCSubjects_GLP_Female
# 176                    EOG/EOCSubjects_GLP_Female
# 177                       EOGSubjects_CACR_Female
# 178                       EOGSubjects_CACR_Female
# 179                        EOGSubjects_GLP_Female
# 180                             EOGGr6_GLP_Female
# 181                        EOGMathGr6_CACR_Female
# 182                             EOGGr7_GLP_Female
# 183                        EOGMathGr7_CACR_Female
# 184                         EOGMathGr7_GLP_Female
# 185                     EOGReadingGr7_CACR_Female
# 186                         EOGMathGr7_GLP_Female
# 187                     EOGReadingGr7_CACR_Female
# 188                      EOGReadingGr7_GLP_Female
# 189                             EOGGr8_GLP_Female
# 190                     EOGReadingGr8_CACR_Female
# 191                      EOGReadingGr8_GLP_Female
# 192                       EOGMathGr3-8_GLP_Female
# 193                       EOGSubjects_CACR_Female
# 194                       EOGSubjects_CACR_Female
# 195                        EOGSubjects_GLP_Female
# 196                         EOGMathGr6_GLP_Female
# 197                         EOGMathGr7_GLP_Female
# 198                         EOGMathGr8_GLP_Female
# 199                    EOGReadingGr3-8_GLP_Female
# 200                       EOGSubjects_CACR_Female
# 201                        EOGSubjects_GLP_Female
# 202                       EOGSubjects_CACR_Female
# 203                        EOGSubjects_GLP_Female
# 204                      EOGReadingGr6_GLP_Female
# 205                      EOGReadingGr7_GLP_Female
# 206                      EOGReadingGr8_GLP_Female
# 207                    EOGScienceGr5&8_GLP_Female
# 208                      EOGScienceGr8_GLP_Female
# 209                        EOGSubjects_GLP_Female
# 210                             EOCMathI_GLP_Male
# 211                         EOCSubjects_CACR_Male
# 212                          EOCSubjects_GLP_Male
# 213                         EOCSubjects_CACR_Male
# 214                          EOCSubjects_GLP_Male
# 215                          EOCSubjects_GLP_Male
# 216                      EOG/EOCSubjects_GLP_Male
# 217                     EOGReadingGr3-8_CACR_Male
# 218                         EOGSubjects_CACR_Male
# 219                          EOGSubjects_GLP_Male
# 220                         EOGSubjects_CACR_Male
# 221                          EOGSubjects_GLP_Male
# 222                               EOGGr6_GLP_Male
# 223                          EOGMathGr6_CACR_Male
# 224                           EOGMathGr6_GLP_Male
# 225                       EOGReadingGr6_CACR_Male
# 226                          EOGMathGr6_CACR_Male
# 227                           EOGMathGr6_GLP_Male
# 228                       EOGReadingGr6_CACR_Male
# 229                        EOGReadingGr6_GLP_Male
# 230                               EOGGr7_GLP_Male
# 231                          EOGMathGr7_CACR_Male
# 232                           EOGMathGr7_GLP_Male
# 233                       EOGReadingGr7_CACR_Male
# 234                           EOGMathGr7_GLP_Male
# 235                       EOGReadingGr7_CACR_Male
# 236                        EOGReadingGr7_GLP_Male
# 237                               EOGGr8_GLP_Male
# 238                         EOGMathGr3-8_GLP_Male
# 239                         EOGSubjects_CACR_Male
# 240                          EOGSubjects_GLP_Male
# 241                         EOGSubjects_CACR_Male
# 242                          EOGSubjects_GLP_Male
# 243                           EOGMathGr6_GLP_Male
# 244                           EOGMathGr7_GLP_Male
# 245                           EOGMathGr8_GLP_Male
# 246                      EOGReadingGr3-8_GLP_Male
# 247                         EOGSubjects_CACR_Male
# 248                          EOGSubjects_GLP_Male
# 249                         EOGSubjects_CACR_Male
# 250                          EOGSubjects_GLP_Male
# 251                        EOGReadingGr6_GLP_Male
# 252                        EOGReadingGr7_GLP_Male
# 253                        EOGReadingGr8_GLP_Male
# 254                      EOGScienceGr5&8_GLP_Male
# 255                        EOGScienceGr8_GLP_Male
# 256                          EOGSubjects_GLP_Male
# 257                   EOCMathI_GLP_AmericanIndian
# 258                EOCSubjects_GLP_AmericanIndian
# 259            EOG/EOCSubjects_GLP_AmericanIndian
# 260               EOGSubjects_CACR_AmericanIndian
# 261                EOGSubjects_GLP_AmericanIndian
# 262                     EOGGr6_GLP_AmericanIndian
# 263                     EOGGr7_GLP_AmericanIndian
# 264                     EOGGr8_GLP_AmericanIndian
# 265               EOGMathGr3-8_GLP_AmericanIndian
# 266                 EOGMathGr6_GLP_AmericanIndian
# 267            EOGReadingGr3-8_GLP_AmericanIndian
# 268              EOGReadingGr7_GLP_AmericanIndian
# 269            EOGScienceGr5&8_GLP_AmericanIndian
# 270             EOGScienceGr8_CACR_AmericanIndian
# 271              EOGScienceGr8_GLP_AmericanIndian
# 272              EOGScienceGr8_GLP_AmericanIndian
# 273              EOGScienceGr8_GLP_AmericanIndian
# 274                EOGSubjects_GLP_AmericanIndian
# 275                            EOCMathI_GLP_Asian
# 276                        EOCSubjects_CACR_Asian
# 277                         EOCSubjects_GLP_Asian
# 278                        EOCSubjects_CACR_Asian
# 279                         EOCSubjects_GLP_Asian
# 280                         EOCSubjects_GLP_Asian
# 281                     EOG/EOCSubjects_GLP_Asian
# 282                        EOGSubjects_CACR_Asian
# 283                         EOGSubjects_GLP_Asian
# 284                        EOGSubjects_CACR_Asian
# 285                         EOGSubjects_GLP_Asian
# 286                              EOGGr6_GLP_Asian
# 287                              EOGGr7_GLP_Asian
# 288                              EOGGr8_GLP_Asian
# 289                        EOGMathGr3-8_GLP_Asian
# 290                     EOGReadingGr3-8_GLP_Asian
# 291                          EOGMathGr6_GLP_Asian
# 292                      EOGReadingGr6_CACR_Asian
# 293                       EOGReadingGr6_GLP_Asian
# 294                      EOGReadingGr6_CACR_Asian
# 295                       EOGReadingGr6_GLP_Asian
# 296                          EOGMathGr7_GLP_Asian
# 297                      EOGReadingGr7_CACR_Asian
# 298                       EOGReadingGr7_GLP_Asian
# 299                      EOGReadingGr7_CACR_Asian
# 300                       EOGReadingGr7_GLP_Asian
# 301                          EOGMathGr8_GLP_Asian
# 302                      EOGScienceGr8_CACR_Asian
# 303                       EOGReadingGr8_GLP_Asian
# 304                      EOGScienceGr8_CACR_Asian
# 305                       EOGScienceGr8_GLP_Asian
# 306                     EOGReadingGr3-8_GLP_Asian
# 307                       EOGReadingGr6_GLP_Asian
# 308                       EOGReadingGr7_GLP_Asian
# 309                       EOGReadingGr8_GLP_Asian
# 310                      EOGScienceGr8_CACR_Asian
# 311                       EOGScienceGr8_GLP_Asian
# 312                     EOGScienceGr5&8_GLP_Asian
# 313                      EOGScienceGr8_CACR_Asian
# 314                       EOGScienceGr8_GLP_Asian
# 315                      EOGScienceGr8_CACR_Asian
# 316                       EOGScienceGr8_GLP_Asian
# 317                       EOGScienceGr8_GLP_Asian
# 318                         EOGSubjects_GLP_Asian
# 319                            EOCMathI_GLP_Black
# 320                        EOCSubjects_CACR_Black
# 321                         EOCSubjects_GLP_Black
# 322                        EOCSubjects_CACR_Black
# 323                         EOCSubjects_GLP_Black
# 324                         EOCSubjects_GLP_Black
# 325                     EOG/EOCSubjects_GLP_Black
# 326                        EOGSubjects_CACR_Black
# 327                         EOGSubjects_GLP_Black
# 328                              EOGGr7_GLP_Black
# 329                              EOGGr8_GLP_Black
# 330                        EOGMathGr3-8_GLP_Black
# 331                          EOGMathGr7_GLP_Black
# 332                     EOGScienceGr5&8_GLP_Black
# 333                      EOGScienceGr8_CACR_Black
# 334                       EOGScienceGr8_GLP_Black
# 335                         EOGSubjects_GLP_Black
# 336                         EOCMathI_GLP_Hispanic
# 337                     EOCSubjects_CACR_Hispanic
# 338                      EOCSubjects_GLP_Hispanic
# 339                     EOCSubjects_CACR_Hispanic
# 340                      EOCSubjects_GLP_Hispanic
# 341                      EOCSubjects_GLP_Hispanic
# 342                  EOG/EOCSubjects_GLP_Hispanic
# 343                     EOGSubjects_CACR_Hispanic
# 344                      EOGSubjects_GLP_Hispanic
# 345                           EOGGr7_GLP_Hispanic
# 346                           EOGGr8_GLP_Hispanic
# 347                       EOGMathGr6_GLP_Hispanic
# 348                  EOGScienceGr5&8_GLP_Hispanic
# 349                    EOGScienceGr8_GLP_Hispanic
# 350                      EOGSubjects_GLP_Hispanic
# 351                   EOCMathI_GLP_TwoorMoreRaces
# 352               EOCSubjects_CACR_TwoorMoreRaces
# 353                EOCSubjects_GLP_TwoorMoreRaces
# 354                EOCSubjects_GLP_TwoorMoreRaces
# 355               EOGSubjects_CACR_TwoorMoreRaces
# 356                EOGSubjects_GLP_TwoorMoreRaces
# 357                     EOGGr6_GLP_TwoorMoreRaces
# 358                     EOGGr7_GLP_TwoorMoreRaces
# 359                     EOGGr8_GLP_TwoorMoreRaces
# 360               EOGMathGr3-8_GLP_TwoorMoreRaces
# 361                 EOGMathGr6_GLP_TwoorMoreRaces
# 362                 EOGMathGr7_GLP_TwoorMoreRaces
# 363                 EOGMathGr8_GLP_TwoorMoreRaces
# 364              EOGReadingGr6_GLP_TwoorMoreRaces
# 365              EOGReadingGr7_GLP_TwoorMoreRaces
# 366            EOGScienceGr5&8_GLP_TwoorMoreRaces
# 367             EOGScienceGr8_CACR_TwoorMoreRaces
# 368              EOGScienceGr8_GLP_TwoorMoreRaces
# 369                            EOCMathI_GLP_White
# 370                        EOCSubjects_CACR_White
# 371                         EOCSubjects_GLP_White
# 372                        EOCSubjects_CACR_White
# 373                         EOCSubjects_GLP_White
# 374                         EOCSubjects_GLP_White
# 375                     EOG/EOCSubjects_GLP_White
# 376                        EOGSubjects_CACR_White
# 377                              EOGGr6_GLP_White
# 378                         EOGMathGr6_CACR_White
# 379                          EOGMathGr6_GLP_White
# 380                          EOGMathGr6_GLP_White
# 381                              EOGGr7_GLP_White
# 382                         EOGMathGr7_CACR_White
# 383                          EOGMathGr7_GLP_White
# 384                      EOGReadingGr7_CACR_White
# 385                          EOGMathGr7_GLP_White
# 386                      EOGReadingGr7_CACR_White
# 387                       EOGReadingGr7_GLP_White
# 388                              EOGGr8_GLP_White
# 389                        EOGMathGr3-8_GLP_White
# 390                        EOGSubjects_CACR_White
# 391                         EOGSubjects_GLP_White
# 392                          EOGMathGr6_GLP_White
# 393                          EOGMathGr7_GLP_White
# 394                          EOGMathGr8_GLP_White
# 395                     EOGReadingGr3-8_GLP_White
# 396                       EOGReadingGr6_GLP_White
# 397                       EOGReadingGr7_GLP_White
# 398                       EOGReadingGr8_GLP_White
# 399                     EOGScienceGr5&8_GLP_White
# 400                       EOGScienceGr8_GLP_White
# 401                         EOGSubjects_GLP_White
# 402                              EOCMathI_GLP_EDS
# 403                          EOCSubjects_CACR_EDS
# 404                           EOCSubjects_GLP_EDS
# 405                          EOCSubjects_CACR_EDS
# 406                           EOCSubjects_GLP_EDS
# 407                           EOCSubjects_GLP_EDS
# 408                       EOG/EOCSubjects_GLP_EDS
# 409                          EOGSubjects_CACR_EDS
# 410                                EOGGr6_GLP_EDS
# 411                                EOGGr7_GLP_EDS
# 412                                EOGGr8_GLP_EDS
# 413                          EOGMathGr3-8_GLP_EDS
# 414                            EOGMathGr6_GLP_EDS
# 415                            EOGMathGr7_GLP_EDS
# 416                            EOGMathGr8_GLP_EDS
# 417                       EOGReadingGr3-8_GLP_EDS
# 418                          EOGSubjects_CACR_EDS
# 419                           EOGSubjects_GLP_EDS
# 420                         EOGReadingGr6_GLP_EDS
# 421                         EOGReadingGr7_GLP_EDS
# 422                       EOGScienceGr5&8_GLP_EDS
# 423                         EOGScienceGr8_GLP_EDS
# 424                           EOGSubjects_GLP_EDS
# 425                          EOCSubjects_CACR_LEP
# 426                           EOCSubjects_GLP_LEP
# 427                           EOCSubjects_GLP_LEP
# 428                           EOCSubjects_GLP_LEP
# 429                          EOGSubjects_CACR_LEP
# 430                           EOGSubjects_GLP_LEP
# 431                        EOGScienceGr8_CACR_LEP
# 432                         EOGScienceGr8_GLP_LEP
# 433                              EOCMathI_GLP_SWD
# 434                           EOCSubjects_GLP_SWD
# 435                       EOG/EOCSubjects_GLP_SWD
# 436                           EOGSubjects_GLP_SWD
# 437                              EOCMathI_GLP_AIG
# 438                          EOCSubjects_CACR_AIG
# 439                           EOCSubjects_GLP_AIG
# 440                           EOCSubjects_GLP_AIG
# 441                                EOGGr6_GLP_AIG
# 442                                EOGGr7_GLP_AIG
# 443                                EOGGr8_GLP_AIG
# 444                          EOGMathGr3-8_GLP_AIG
# 445                            EOGMathGr6_GLP_AIG
# 446                        EOGReadingGr6_CACR_AIG
# 447                         EOGReadingGr6_GLP_AIG
# 448                        EOGReadingGr6_CACR_AIG
# 449                         EOGReadingGr6_GLP_AIG
# 450                            EOGMathGr7_GLP_AIG
# 451                        EOGReadingGr7_CACR_AIG
# 452                         EOGReadingGr7_GLP_AIG
# 453                            EOGMathGr8_GLP_AIG
# 454                         EOGReadingGr8_GLP_AIG
# 455                       EOGReadingGr3-8_GLP_AIG
# 456                         EOGReadingGr6_GLP_AIG
# 457                         EOGReadingGr7_GLP_AIG
# 458                         EOGReadingGr8_GLP_AIG
# 459                        EOGScienceGr8_CACR_AIG
# 460                        EOGScienceGr8_CACR_AIG
# 461                         EOGScienceGr8_GLP_AIG
# 462                       EOGScienceGr5&8_GLP_AIG
# 463                         EOGScienceGr8_GLP_AIG
# 464                           EOGSubjects_GLP_AIG
# 465                       st_short_susp_per_c_num
# 466                                 category_cd_I
# 467                                 Category_Cd_I
# 468                        st_emer_prov_teach_pct
# 469                          st_lateral_teach_pct
# 470                                 category_cd_I
# 471                                 Category_Cd_I
# 472                         0-3 Years_Exp_Pct_Tch
# 473                        4-10 Years_Exp_Pct_Tch
# 474                         10+ Years_Exp_Pct_Tch
# 475                         lea_lateral_teach_pct
# 476                            st_advance_dgr_pct
# 477                                 category_cd_M
# 478                                 Category_Cd_M
# 479                                 category_cd_M
# 480                                 Category_Cd_M
# 481                                 IndianMalePct
# 482                               IndianFemalePct
# 483                                  AsianMalePct
# 484                                AsianFemalePct
# 485                               HispanicMalePct
# 486                             HispanicFemalePct
# 487                                  BlackMalePct
# 488                                BlackFemalePct
# 489                                   MinorityPct
# 490                                  WhiteMalePct
# 491                               MinorityMalePct
# 492                                WhiteFemalePct
# 493                             MinorityFemalePct
# 494                                  WhiteMalePct
# 495                               MinorityMalePct
# 496                                WhiteFemalePct
# 497                             MinorityFemalePct
# 498                               IndianFemalePct
# 499                                BlackFemalePct
# ...                                           ...
# 185512                 Tot tax payments Amt LT25K
# 185513             Tot tax payments Ct 100KLT200K
# 185514               Tot tax payments Ct 25KLT50K
# 185515               Tot tax payments Ct 50KLT75K
# 185516              Tot tax payments Ct 75KLT100K
# 185517                    Tot tax payments Ct All
# 185518                 Tot tax payments Ct GE200K
# 185519                  Tot tax payments Ct LT25K
# 185520  Tuition and fees deduction Amt 100KLT200K
# 185521    Tuition and fees deduction Amt 25KLT50K
# 185522    Tuition and fees deduction Amt 50KLT75K
# 185523         Tuition and fees deduction Amt All
# 185524       Tuition and fees deduction Amt LT25K
# 185525   Tuition and fees deduction Ct 100KLT200K
# 185526     Tuition and fees deduction Ct 25KLT50K
# 185527     Tuition and fees deduction Ct 50KLT75K
# 185528          Tuition and fees deduction Ct All
# 185529        Tuition and fees deduction Ct LT25K
# 185530   Unemployment compensation Amt 100KLT200K
# 185531     Unemployment compensation Amt 25KLT50K
# 185532     Unemployment compensation Amt 50KLT75K
# 185533    Unemployment compensation Amt 75KLT100K
# 185534          Unemployment compensation Amt All
# 185535       Unemployment compensation Amt GE200K
# 185536        Unemployment compensation Amt LT25K
# 185537    Unemployment compensation Ct 100KLT200K
# 185538      Unemployment compensation Ct 25KLT50K
# 185539      Unemployment compensation Ct 50KLT75K
# 185540     Unemployment compensation Ct 75KLT100K
# 185541           Unemployment compensation Ct All
# 185542        Unemployment compensation Ct GE200K
# 185543                             InitiatedbyLEA
# 185544               Tot tax payments Ct 25KLT50K
# 185545               Tot tax payments Ct 50KLT75K
# 185546              Tot tax payments Ct 75KLT100K
# 185547                    Tot tax payments Ct All
# 185548                 Tot tax payments Ct GE200K
# 185549                  Tot tax payments Ct LT25K
# 185550    Tuition and fees deduction Amt 25KLT50K
# 185551    Tuition and fees deduction Amt 50KLT75K
# 185552         Tuition and fees deduction Amt All
# 185553       Tuition and fees deduction Amt LT25K
# 185554     Tuition and fees deduction Ct 25KLT50K
# 185555     Tuition and fees deduction Ct 50KLT75K
# 185556          Tuition and fees deduction Ct All
# 185557        Tuition and fees deduction Ct LT25K
# 185558   Unemployment compensation Amt 100KLT200K
# 185559     Unemployment compensation Amt 25KLT50K
# 185560     Unemployment compensation Amt 50KLT75K
# 185561    Unemployment compensation Amt 75KLT100K
# 185562          Unemployment compensation Amt All
# 185563       Unemployment compensation Amt GE200K
# 185564        Unemployment compensation Amt LT25K
# 185565    Unemployment compensation Ct 100KLT200K
# 185566      Unemployment compensation Ct 25KLT50K
# 185567      Unemployment compensation Ct 50KLT75K
# 185568     Unemployment compensation Ct 75KLT100K
# 185569           Unemployment compensation Ct All
# 185570        Unemployment compensation Ct GE200K
# 185571                             InitiatedbyLEA
# 185572               Tot tax payments Ct 25KLT50K
# 185573               Tot tax payments Ct 50KLT75K
# 185574                    Tot tax payments Ct All
# 185575                  Tot tax payments Ct LT25K
# 185576    Tuition and fees deduction Amt 25KLT50K
# 185577    Tuition and fees deduction Amt 50KLT75K
# 185578         Tuition and fees deduction Amt All
# 185579       Tuition and fees deduction Amt LT25K
# 185580     Tuition and fees deduction Ct 25KLT50K
# 185581     Tuition and fees deduction Ct 50KLT75K
# 185582        Tuition and fees deduction Ct LT25K
# 185583     Unemployment compensation Amt 25KLT50K
# 185584     Unemployment compensation Amt 50KLT75K
# 185585    Unemployment compensation Amt 75KLT100K
# 185586          Unemployment compensation Amt All
# 185587        Unemployment compensation Amt LT25K
# 185588      Unemployment compensation Ct 25KLT50K
# 185589      Unemployment compensation Ct 50KLT75K
# 185590     Unemployment compensation Ct 75KLT100K
# 185591           Unemployment compensation Ct All
# 185592         Unemployment compensation Ct LT25K
# 185593                             InitiatedbyLEA
# 185594               Tot tax payments Ct 25KLT50K
# 185595               Tot tax payments Ct 50KLT75K
# 185596              Tot tax payments Ct 75KLT100K
# 185597                    Tot tax payments Ct All
# 185598                 Tot tax payments Ct GE200K
# 185599  Tuition and fees deduction Amt 100KLT200K
# 185600    Tuition and fees deduction Amt 50KLT75K
# 185601         Tuition and fees deduction Amt All
# 185602       Tuition and fees deduction Amt LT25K
# 185603   Tuition and fees deduction Ct 100KLT200K
# 185604     Tuition and fees deduction Ct 25KLT50K
# 185605     Tuition and fees deduction Ct 50KLT75K
# 185606          Tuition and fees deduction Ct All
# 185607        Tuition and fees deduction Ct LT25K
# 185608   Unemployment compensation Amt 100KLT200K
# 185609     Unemployment compensation Amt 50KLT75K
# 185610    Unemployment compensation Amt 75KLT100K
# 185611          Unemployment compensation Amt All
# 185612       Unemployment compensation Amt GE200K
# 185613    Unemployment compensation Ct 100KLT200K
# 185614      Unemployment compensation Ct 50KLT75K
# 185615     Unemployment compensation Ct 75KLT100K
# 185616        Unemployment compensation Ct GE200K
# 185617               Tot tax payments Ct 50KLT75K
# 185618              Tot tax payments Ct 75KLT100K
# 185619                    Tot tax payments Ct All
# 185620                 Tot tax payments Ct GE200K
# 185621                  Tot tax payments Ct LT25K
# 185622    Tuition and fees deduction Amt 25KLT50K
# 185623    Tuition and fees deduction Amt 50KLT75K
# 185624         Tuition and fees deduction Amt All
# 185625       Tuition and fees deduction Amt LT25K
# 185626     Tuition and fees deduction Ct 25KLT50K
# 185627     Tuition and fees deduction Ct 50KLT75K
# 185628          Tuition and fees deduction Ct All
# 185629        Tuition and fees deduction Ct LT25K
# 185630   Unemployment compensation Amt 100KLT200K
# 185631     Unemployment compensation Amt 25KLT50K
# 185632     Unemployment compensation Amt 50KLT75K
# 185633    Unemployment compensation Amt 75KLT100K
# 185634          Unemployment compensation Amt All
# 185635        Unemployment compensation Amt LT25K
# 185636    Unemployment compensation Ct 100KLT200K
# 185637      Unemployment compensation Ct 25KLT50K
# 185638      Unemployment compensation Ct 50KLT75K
# 185639     Unemployment compensation Ct 75KLT100K
# 185640           Unemployment compensation Ct All
# 185641         Unemployment compensation Ct LT25K
# 185642                             InitiatedbyLEA
# 185643              Tot tax payments Ct 75KLT100K
# 185644                    Tot tax payments Ct All
# 185645                 Tot tax payments Ct GE200K
# 185646                  Tot tax payments Ct LT25K
# 185647  Tuition and fees deduction Amt 100KLT200K
# 185648    Tuition and fees deduction Amt 25KLT50K
# 185649    Tuition and fees deduction Amt 50KLT75K
# 185650         Tuition and fees deduction Amt All
# 185651       Tuition and fees deduction Amt LT25K
# 185652   Tuition and fees deduction Ct 100KLT200K
# 185653     Tuition and fees deduction Ct 25KLT50K
# 185654     Tuition and fees deduction Ct 50KLT75K
# 185655          Tuition and fees deduction Ct All
# 185656        Tuition and fees deduction Ct LT25K
# 185657   Unemployment compensation Amt 100KLT200K
# 185658     Unemployment compensation Amt 25KLT50K
# 185659     Unemployment compensation Amt 50KLT75K
# 185660    Unemployment compensation Amt 75KLT100K
# 185661          Unemployment compensation Amt All
# 185662        Unemployment compensation Amt LT25K
# 185663    Unemployment compensation Ct 100KLT200K
# 185664      Unemployment compensation Ct 25KLT50K
# 185665      Unemployment compensation Ct 50KLT75K
# 185666     Unemployment compensation Ct 75KLT100K
# 185667           Unemployment compensation Ct All
# 185668         Unemployment compensation Ct LT25K
# 185669                             InitiatedbyLEA
# 185670                    Tot tax payments Ct All
# 185671                 Tot tax payments Ct GE200K
# 185672                  Tot tax payments Ct LT25K
# 185673  Tuition and fees deduction Amt 100KLT200K
# 185674    Tuition and fees deduction Amt 25KLT50K
# 185675    Tuition and fees deduction Amt 50KLT75K
# 185676         Tuition and fees deduction Amt All
# 185677       Tuition and fees deduction Amt LT25K
# 185678   Tuition and fees deduction Ct 100KLT200K
# 185679     Tuition and fees deduction Ct 25KLT50K
# 185680     Tuition and fees deduction Ct 50KLT75K
# 185681          Tuition and fees deduction Ct All
# 185682        Tuition and fees deduction Ct LT25K
# 185683   Unemployment compensation Amt 100KLT200K
# 185684     Unemployment compensation Amt 25KLT50K
# 185685     Unemployment compensation Amt 50KLT75K
# 185686    Unemployment compensation Amt 75KLT100K
# 185687          Unemployment compensation Amt All
# 185688    Unemployment compensation Ct 100KLT200K
# 185689      Unemployment compensation Ct 25KLT50K
# 185690      Unemployment compensation Ct 50KLT75K
# 185691     Unemployment compensation Ct 75KLT100K
# 185692           Unemployment compensation Ct All
# 185693                             InitiatedbyLEA
# 185694                 Tot tax payments Ct GE200K
# 185695                  Tot tax payments Ct LT25K
# 185696  Tuition and fees deduction Amt 100KLT200K
# 185697    Tuition and fees deduction Amt 25KLT50K
# 185698    Tuition and fees deduction Amt 50KLT75K
# 185699         Tuition and fees deduction Amt All
# 185700       Tuition and fees deduction Amt LT25K
# 185701   Tuition and fees deduction Ct 100KLT200K
# 185702     Tuition and fees deduction Ct 25KLT50K
# 185703     Tuition and fees deduction Ct 50KLT75K
# 185704          Tuition and fees deduction Ct All
# 185705        Tuition and fees deduction Ct LT25K
# 185706   Unemployment compensation Amt 100KLT200K
# 185707     Unemployment compensation Amt 25KLT50K
# 185708     Unemployment compensation Amt 50KLT75K
# 185709    Unemployment compensation Amt 75KLT100K
# 185710          Unemployment compensation Amt All
# 185711        Unemployment compensation Amt LT25K
# 185712    Unemployment compensation Ct 100KLT200K
# 185713      Unemployment compensation Ct 25KLT50K
# 185714      Unemployment compensation Ct 50KLT75K
# 185715     Unemployment compensation Ct 75KLT100K
# 185716           Unemployment compensation Ct All
# 185717         Unemployment compensation Ct LT25K
# 185718                             InitiatedbyLEA
# 185719                  Tot tax payments Ct LT25K
# 185720  Tuition and fees deduction Amt 100KLT200K
# 185721    Tuition and fees deduction Amt 25KLT50K
# 185722    Tuition and fees deduction Amt 50KLT75K
# 185723         Tuition and fees deduction Amt All
# 185724       Tuition and fees deduction Amt LT25K
# 185725   Tuition and fees deduction Ct 100KLT200K
# 185726     Tuition and fees deduction Ct 25KLT50K
# 185727     Tuition and fees deduction Ct 50KLT75K
# 185728          Tuition and fees deduction Ct All
# 185729        Tuition and fees deduction Ct LT25K
# 185730   Unemployment compensation Amt 100KLT200K
# 185731     Unemployment compensation Amt 25KLT50K
# 185732     Unemployment compensation Amt 50KLT75K
# 185733    Unemployment compensation Amt 75KLT100K
# 185734          Unemployment compensation Amt All
# 185735       Unemployment compensation Amt GE200K
# 185736    Unemployment compensation Ct 100KLT200K
# 185737      Unemployment compensation Ct 25KLT50K
# 185738      Unemployment compensation Ct 50KLT75K
# 185739     Unemployment compensation Ct 75KLT100K
# 185740           Unemployment compensation Ct All
# 185741        Unemployment compensation Ct GE200K
# 185742                             InitiatedbyLEA
# 185743    Tuition and fees deduction Amt 25KLT50K
# 185744    Tuition and fees deduction Amt 50KLT75K
# 185745         Tuition and fees deduction Amt All
# 185746       Tuition and fees deduction Amt LT25K
# 185747     Tuition and fees deduction Ct 25KLT50K
# 185748     Tuition and fees deduction Ct 50KLT75K
# 185749          Tuition and fees deduction Ct All
# 185750        Tuition and fees deduction Ct LT25K
# 185751   Unemployment compensation Amt 100KLT200K
# 185752     Unemployment compensation Amt 25KLT50K
# 185753     Unemployment compensation Amt 50KLT75K
# 185754    Unemployment compensation Amt 75KLT100K
# 185755          Unemployment compensation Amt All
# 185756        Unemployment compensation Amt LT25K
# 185757      Unemployment compensation Ct 25KLT50K
# 185758      Unemployment compensation Ct 50KLT75K
# 185759     Unemployment compensation Ct 75KLT100K
# 185760           Unemployment compensation Ct All
# 185761         Unemployment compensation Ct LT25K
# 185762                             InitiatedbyLEA
# 185763    Tuition and fees deduction Amt 50KLT75K
# 185764         Tuition and fees deduction Amt All
# 185765       Tuition and fees deduction Amt LT25K
# 185766   Tuition and fees deduction Ct 100KLT200K
# 185767     Tuition and fees deduction Ct 50KLT75K
# 185768          Tuition and fees deduction Ct All
# 185769        Tuition and fees deduction Ct LT25K
# 185770   Unemployment compensation Amt 100KLT200K
# 185771    Unemployment compensation Amt 75KLT100K
# 185772       Unemployment compensation Amt GE200K
# 185773    Unemployment compensation Ct 100KLT200K
# 185774     Unemployment compensation Ct 75KLT100K
# 185775        Unemployment compensation Ct GE200K
# 185776    Tuition and fees deduction Amt 50KLT75K
# 185777         Tuition and fees deduction Amt All
# 185778       Tuition and fees deduction Amt LT25K
# 185779     Tuition and fees deduction Ct 25KLT50K
# 185780     Tuition and fees deduction Ct 50KLT75K
# 185781          Tuition and fees deduction Ct All
# 185782        Tuition and fees deduction Ct LT25K
# 185783   Unemployment compensation Amt 100KLT200K
# 185784     Unemployment compensation Amt 25KLT50K
# 185785     Unemployment compensation Amt 50KLT75K
# 185786    Unemployment compensation Amt 75KLT100K
# 185787          Unemployment compensation Amt All
# 185788        Unemployment compensation Amt LT25K
# 185789      Unemployment compensation Ct 25KLT50K
# 185790      Unemployment compensation Ct 50KLT75K
# 185791     Unemployment compensation Ct 75KLT100K
# 185792           Unemployment compensation Ct All
# 185793         Unemployment compensation Ct LT25K
# 185794                        RemainedinEducation
# 185795                            PersonalReasons
# 185796                             InitiatedbyLEA
# 185797         Tuition and fees deduction Amt All
# 185798       Tuition and fees deduction Amt LT25K
# 185799   Tuition and fees deduction Ct 100KLT200K
# 185800     Tuition and fees deduction Ct 25KLT50K
# 185801     Tuition and fees deduction Ct 50KLT75K
# 185802          Tuition and fees deduction Ct All
# 185803        Tuition and fees deduction Ct LT25K
# 185804   Unemployment compensation Amt 100KLT200K
# 185805     Unemployment compensation Amt 25KLT50K
# 185806     Unemployment compensation Amt 50KLT75K
# 185807    Unemployment compensation Amt 75KLT100K
# 185808          Unemployment compensation Amt All
# 185809       Unemployment compensation Amt GE200K
# 185810    Unemployment compensation Ct 100KLT200K
# 185811      Unemployment compensation Ct 25KLT50K
# 185812      Unemployment compensation Ct 50KLT75K
# 185813     Unemployment compensation Ct 75KLT100K
# 185814           Unemployment compensation Ct All
# 185815        Unemployment compensation Ct GE200K
# 185816                             InitiatedbyLEA
# 185817    Tuition and fees deduction Ct 75KLT100K
# 185818       Tuition and fees deduction Amt LT25K
# 185819   Tuition and fees deduction Ct 100KLT200K
# 185820     Tuition and fees deduction Ct 25KLT50K
# 185821     Tuition and fees deduction Ct 50KLT75K
# 185822          Tuition and fees deduction Ct All
# 185823        Tuition and fees deduction Ct LT25K
# 185824   Unemployment compensation Amt 100KLT200K
# 185825     Unemployment compensation Amt 25KLT50K
# 185826     Unemployment compensation Amt 50KLT75K
# 185827    Unemployment compensation Amt 75KLT100K
# 185828          Unemployment compensation Amt All
# 185829       Unemployment compensation Amt GE200K
# 185830    Unemployment compensation Ct 100KLT200K
# 185831      Unemployment compensation Ct 25KLT50K
# 185832      Unemployment compensation Ct 50KLT75K
# 185833     Unemployment compensation Ct 75KLT100K
# 185834           Unemployment compensation Ct All
# 185835        Unemployment compensation Ct GE200K
# 185836                             InitiatedbyLEA
# 185837   Tuition and fees deduction Ct 100KLT200K
# 185838     Tuition and fees deduction Ct 25KLT50K
# 185839     Tuition and fees deduction Ct 50KLT75K
# 185840          Tuition and fees deduction Ct All
# 185841        Tuition and fees deduction Ct LT25K
# 185842   Unemployment compensation Amt 100KLT200K
# 185843     Unemployment compensation Amt 25KLT50K
# 185844     Unemployment compensation Amt 50KLT75K
# 185845    Unemployment compensation Amt 75KLT100K
# 185846          Unemployment compensation Amt All
# 185847        Unemployment compensation Amt LT25K
# 185848    Unemployment compensation Ct 100KLT200K
# 185849      Unemployment compensation Ct 25KLT50K
# 185850      Unemployment compensation Ct 50KLT75K
# 185851     Unemployment compensation Ct 75KLT100K
# 185852           Unemployment compensation Ct All
# 185853                             InitiatedbyLEA
# 185854     Tuition and fees deduction Ct 50KLT75K
# 185855          Tuition and fees deduction Ct All
# 185856        Tuition and fees deduction Ct LT25K
# 185857   Unemployment compensation Amt 100KLT200K
# 185858    Unemployment compensation Amt 75KLT100K
# 185859       Unemployment compensation Amt GE200K
# 185860    Unemployment compensation Ct 100KLT200K
# 185861     Unemployment compensation Ct 75KLT100K
# 185862        Unemployment compensation Ct GE200K
# 185863     Tuition and fees deduction Ct 50KLT75K
# 185864          Tuition and fees deduction Ct All
# 185865        Tuition and fees deduction Ct LT25K
# 185866   Unemployment compensation Amt 100KLT200K
# 185867     Unemployment compensation Amt 25KLT50K
# 185868     Unemployment compensation Amt 50KLT75K
# 185869    Unemployment compensation Amt 75KLT100K
# 185870          Unemployment compensation Amt All
# 185871        Unemployment compensation Amt LT25K
# 185872    Unemployment compensation Ct 100KLT200K
# 185873      Unemployment compensation Ct 25KLT50K
# 185874      Unemployment compensation Ct 50KLT75K
# 185875     Unemployment compensation Ct 75KLT100K
# 185876           Unemployment compensation Ct All
# 185877         Unemployment compensation Ct LT25K
# 185878                            PersonalReasons
# 185879                             InitiatedbyLEA
# 185880          Tuition and fees deduction Ct All
# 185881        Tuition and fees deduction Ct LT25K
# 185882   Unemployment compensation Amt 100KLT200K
# 185883     Unemployment compensation Amt 25KLT50K
# 185884     Unemployment compensation Amt 50KLT75K
# 185885    Unemployment compensation Amt 75KLT100K
# 185886          Unemployment compensation Amt All
# 185887       Unemployment compensation Amt GE200K
# 185888    Unemployment compensation Ct 100KLT200K
# 185889      Unemployment compensation Ct 25KLT50K
# 185890      Unemployment compensation Ct 50KLT75K
# 185891     Unemployment compensation Ct 75KLT100K
# 185892           Unemployment compensation Ct All
# 185893        Unemployment compensation Ct GE200K
# 185894                             InitiatedbyLEA
# 185895        Tuition and fees deduction Ct LT25K
# 185896   Unemployment compensation Amt 100KLT200K
# 185897     Unemployment compensation Amt 25KLT50K
# 185898     Unemployment compensation Amt 50KLT75K
# 185899    Unemployment compensation Amt 75KLT100K
# 185900          Unemployment compensation Amt All
# 185901       Unemployment compensation Amt GE200K
# 185902    Unemployment compensation Ct 100KLT200K
# 185903      Unemployment compensation Ct 25KLT50K
# 185904      Unemployment compensation Ct 50KLT75K
# 185905     Unemployment compensation Ct 75KLT100K
# 185906           Unemployment compensation Ct All
# 185907        Unemployment compensation Ct GE200K
# 185908                             InitiatedbyLEA
# 185909   Unemployment compensation Amt 100KLT200K
# 185910     Unemployment compensation Amt 25KLT50K
# 185911     Unemployment compensation Amt 50KLT75K
# 185912    Unemployment compensation Amt 75KLT100K
# 185913          Unemployment compensation Amt All
# ...
# 185794            Tuition and fees deduction Amt 25KLT50K     0.951030
# 185795            Tuition and fees deduction Amt 25KLT50K     0.960908
# 185796            Tuition and fees deduction Amt 25KLT50K     0.982953
# 185797            Tuition and fees deduction Amt 50KLT75K     0.997499
# 185798            Tuition and fees deduction Amt 50KLT75K     0.992699
# 185799            Tuition and fees deduction Amt 50KLT75K     0.967183
# 185800            Tuition and fees deduction Amt 50KLT75K     0.984517
# 185801            Tuition and fees deduction Amt 50KLT75K     0.999311
# 185802            Tuition and fees deduction Amt 50KLT75K     0.995767
# 185803            Tuition and fees deduction Amt 50KLT75K     0.991087
# 185804            Tuition and fees deduction Amt 50KLT75K     0.987910
# 185805            Tuition and fees deduction Amt 50KLT75K     0.976401
# 185806            Tuition and fees deduction Amt 50KLT75K     0.982106
# 185807            Tuition and fees deduction Amt 50KLT75K     0.987276
# 185808            Tuition and fees deduction Amt 50KLT75K     0.979067
# 185809            Tuition and fees deduction Amt 50KLT75K     0.959422
# 185810            Tuition and fees deduction Amt 50KLT75K     0.986420
# 185811            Tuition and fees deduction Amt 50KLT75K     0.970635
# 185812            Tuition and fees deduction Amt 50KLT75K     0.973286
# 185813            Tuition and fees deduction Amt 50KLT75K     0.981291
# 185814            Tuition and fees deduction Amt 50KLT75K     0.970563
# 185815            Tuition and fees deduction Amt 50KLT75K     0.958960
# 185816            Tuition and fees deduction Amt 50KLT75K     0.970272
# 185817           Tuition and fees deduction Amt 75KLT100K     0.996953
# 185818                 Tuition and fees deduction Amt All     0.996049
# 185819                 Tuition and fees deduction Amt All     0.972845
# 185820                 Tuition and fees deduction Amt All     0.986753
# 185821                 Tuition and fees deduction Amt All     0.997941
# 185822                 Tuition and fees deduction Amt All     0.999306
# 185823                 Tuition and fees deduction Amt All     0.995562
# 185824                 Tuition and fees deduction Amt All     0.988419
# 185825                 Tuition and fees deduction Amt All     0.975193
# 185826                 Tuition and fees deduction Amt All     0.983225
# 185827                 Tuition and fees deduction Amt All     0.987756
# 185828                 Tuition and fees deduction Amt All     0.978574
# 185829                 Tuition and fees deduction Amt All     0.951864
# 185830                 Tuition and fees deduction Amt All     0.987191
# 185831                 Tuition and fees deduction Amt All     0.970363
# 185832                 Tuition and fees deduction Amt All     0.975936
# 185833                 Tuition and fees deduction Amt All     0.983205
# 185834                 Tuition and fees deduction Amt All     0.971305
# 185835                 Tuition and fees deduction Amt All     0.952212
# 185836                 Tuition and fees deduction Amt All     0.969230
# 185837               Tuition and fees deduction Amt LT25K     0.951795
# 185838               Tuition and fees deduction Amt LT25K     0.986750
# 185839               Tuition and fees deduction Amt LT25K     0.992060
# 185840               Tuition and fees deduction Amt LT25K     0.993235
# 185841               Tuition and fees deduction Amt LT25K     0.999100
# 185842               Tuition and fees deduction Amt LT25K     0.976140
# 185843               Tuition and fees deduction Amt LT25K     0.977156
# 185844               Tuition and fees deduction Amt LT25K     0.979283
# 185845               Tuition and fees deduction Amt LT25K     0.983068
# 185846               Tuition and fees deduction Amt LT25K     0.980390
# 185847               Tuition and fees deduction Amt LT25K     0.957370
# 185848               Tuition and fees deduction Amt LT25K     0.973963
# 185849               Tuition and fees deduction Amt LT25K     0.972791
# 185850               Tuition and fees deduction Amt LT25K     0.971204
# 185851               Tuition and fees deduction Amt LT25K     0.976458
# 185852               Tuition and fees deduction Amt LT25K     0.974830
# 185853               Tuition and fees deduction Amt LT25K     0.965081
# 185854           Tuition and fees deduction Ct 100KLT200K     0.971347
# 185855           Tuition and fees deduction Ct 100KLT200K     0.978660
# 185856           Tuition and fees deduction Ct 100KLT200K     0.952771
# 185857           Tuition and fees deduction Ct 100KLT200K     0.984703
# 185858           Tuition and fees deduction Ct 100KLT200K     0.956843
# 185859           Tuition and fees deduction Ct 100KLT200K     0.957026
# 185860           Tuition and fees deduction Ct 100KLT200K     0.986012
# 185861           Tuition and fees deduction Ct 100KLT200K     0.960900
# 185862           Tuition and fees deduction Ct 100KLT200K     0.961948
# 185863             Tuition and fees deduction Ct 25KLT50K     0.985096
# 185864             Tuition and fees deduction Ct 25KLT50K     0.984848
# 185865             Tuition and fees deduction Ct 25KLT50K     0.987870
# 185866             Tuition and fees deduction Ct 25KLT50K     0.962488
# 185867             Tuition and fees deduction Ct 25KLT50K     0.988498
# 185868             Tuition and fees deduction Ct 25KLT50K     0.987032
# 185869             Tuition and fees deduction Ct 25KLT50K     0.982522
# 185870             Tuition and fees deduction Ct 25KLT50K     0.989092
# 185871             Tuition and fees deduction Ct 25KLT50K     0.974888
# 185872             Tuition and fees deduction Ct 25KLT50K     0.960742
# 185873             Tuition and fees deduction Ct 25KLT50K     0.983668
# 185874             Tuition and fees deduction Ct 25KLT50K     0.977098
# 185875             Tuition and fees deduction Ct 25KLT50K     0.973987
# 185876             Tuition and fees deduction Ct 25KLT50K     0.984245
# 185877             Tuition and fees deduction Ct 25KLT50K     0.963786
# 185878             Tuition and fees deduction Ct 25KLT50K     0.956361
# 185879             Tuition and fees deduction Ct 25KLT50K     0.983769
# 185880             Tuition and fees deduction Ct 50KLT75K     0.997306
# 185881             Tuition and fees deduction Ct 50KLT75K     0.991384
# 185882             Tuition and fees deduction Ct 50KLT75K     0.988451
# 185883             Tuition and fees deduction Ct 50KLT75K     0.976180
# 185884             Tuition and fees deduction Ct 50KLT75K     0.983931
# 185885             Tuition and fees deduction Ct 50KLT75K     0.988476
# 185886             Tuition and fees deduction Ct 50KLT75K     0.979105
# 185887             Tuition and fees deduction Ct 50KLT75K     0.956378
# 185888             Tuition and fees deduction Ct 50KLT75K     0.987178
# 185889             Tuition and fees deduction Ct 50KLT75K     0.970845
# 185890             Tuition and fees deduction Ct 50KLT75K     0.975923
# 185891             Tuition and fees deduction Ct 50KLT75K     0.983458
# 185892             Tuition and fees deduction Ct 50KLT75K     0.971064
# 185893             Tuition and fees deduction Ct 50KLT75K     0.956347
# 185894             Tuition and fees deduction Ct 50KLT75K     0.969192
# 185895                  Tuition and fees deduction Ct All     0.993872
# 185896                  Tuition and fees deduction Ct All     0.990296
# 185897                  Tuition and fees deduction Ct All     0.973158
# 185898                  Tuition and fees deduction Ct All     0.983952
# 185899                  Tuition and fees deduction Ct All     0.988304
# 185900                  Tuition and fees deduction Ct All     0.976835
# 185901                  Tuition and fees deduction Ct All     0.952268
# 185902                  Tuition and fees deduction Ct All     0.989428
# 185903                  Tuition and fees deduction Ct All     0.968873
# 185904                  Tuition and fees deduction Ct All     0.977935
# 185905                  Tuition and fees deduction Ct All     0.985200
# 185906                  Tuition and fees deduction Ct All     0.969846
# 185907                  Tuition and fees deduction Ct All     0.953294
# 185908                  Tuition and fees deduction Ct All     0.966790
# 185909                Tuition and fees deduction Ct LT25K     0.976645
# 185910                Tuition and fees deduction Ct LT25K     0.980335
# 185911                Tuition and fees deduction Ct LT25K     0.983364
# 185912                Tuition and fees deduction Ct LT25K     0.985890
# 185913                Tuition and fees deduction Ct LT25K     0.983623
# 185914                Tuition and fees deduction Ct LT25K     0.961460
# 185915                Tuition and fees deduction Ct LT25K     0.974625
# 185916                Tuition and fees deduction Ct LT25K     0.976690
# 185917                Tuition and fees deduction Ct LT25K     0.976372
# 185918                Tuition and fees deduction Ct LT25K     0.980149
# 185919                Tuition and fees deduction Ct LT25K     0.978978
# 185920                Tuition and fees deduction Ct LT25K     0.950600
# 185921                Tuition and fees deduction Ct LT25K     0.965308
# 185922           Unemployment compensation Amt 100KLT200K     0.960959
# 185923           Unemployment compensation Amt 100KLT200K     0.977287
# 185924           Unemployment compensation Amt 100KLT200K     0.986676
# 185925           Unemployment compensation Amt 100KLT200K     0.965007
# 185926           Unemployment compensation Amt 100KLT200K     0.977237
# 185927           Unemployment compensation Amt 100KLT200K     0.999813
# 185928           Unemployment compensation Amt 100KLT200K     0.956488
# 185929           Unemployment compensation Amt 100KLT200K     0.973608
# 185930           Unemployment compensation Amt 100KLT200K     0.986278
# 185931           Unemployment compensation Amt 100KLT200K     0.955875
# 185932           Unemployment compensation Amt 100KLT200K     0.978424
# 185933           Unemployment compensation Amt 100KLT200K     0.951699
# 185934             Unemployment compensation Amt 25KLT50K     0.995067
# 185935             Unemployment compensation Amt 25KLT50K     0.990117
# 185936             Unemployment compensation Amt 25KLT50K     0.999545
# 185937             Unemployment compensation Amt 25KLT50K     0.990232
# 185938             Unemployment compensation Amt 25KLT50K     0.959144
# 185939             Unemployment compensation Amt 25KLT50K     0.998283
# 185940             Unemployment compensation Amt 25KLT50K     0.989415
# 185941             Unemployment compensation Amt 25KLT50K     0.983930
# 185942             Unemployment compensation Amt 25KLT50K     0.997927
# 185943             Unemployment compensation Amt 25KLT50K     0.981993
# 185944             Unemployment compensation Amt 25KLT50K     0.950510
# 185945             Unemployment compensation Amt 25KLT50K     0.954050
# 185946             Unemployment compensation Amt 25KLT50K     0.977037
# 185947             Unemployment compensation Amt 50KLT75K     0.996955
# 185948             Unemployment compensation Amt 50KLT75K     0.996128
# 185949             Unemployment compensation Amt 50KLT75K     0.975105
# 185950             Unemployment compensation Amt 50KLT75K     0.976336
# 185951             Unemployment compensation Amt 50KLT75K     0.993479
# 185952             Unemployment compensation Amt 50KLT75K     0.996712
# 185953             Unemployment compensation Amt 50KLT75K     0.994322
# 185954             Unemployment compensation Amt 50KLT75K     0.993368
# 185955             Unemployment compensation Amt 50KLT75K     0.965041
# 185956             Unemployment compensation Amt 50KLT75K     0.974525
# 185957            Unemployment compensation Amt 75KLT100K     0.992289
# 185958            Unemployment compensation Amt 75KLT100K     0.965136
# 185959            Unemployment compensation Amt 75KLT100K     0.985638
# 185960            Unemployment compensation Amt 75KLT100K     0.988234
# 185961            Unemployment compensation Amt 75KLT100K     0.994100
# 185962            Unemployment compensation Amt 75KLT100K     0.997707
# 185963            Unemployment compensation Amt 75KLT100K     0.988400
# 185964            Unemployment compensation Amt 75KLT100K     0.953803
# 185965            Unemployment compensation Amt 75KLT100K     0.970666
# 185966                  Unemployment compensation Amt All     0.989391
# 185967                  Unemployment compensation Amt All     0.963151
# 185968                  Unemployment compensation Amt All     0.997877
# 185969                  Unemployment compensation Amt All     0.990581
# 185970                  Unemployment compensation Amt All     0.986346
# 185971                  Unemployment compensation Amt All     0.998365
# 185972                  Unemployment compensation Amt All     0.981305
# 185973                  Unemployment compensation Amt All     0.950739
# 185974                  Unemployment compensation Amt All     0.950902
# 185975                  Unemployment compensation Amt All     0.976432
# 185976               Unemployment compensation Amt GE200K     0.976514
# 185977               Unemployment compensation Amt GE200K     0.999578
# 185978                Unemployment compensation Amt LT25K     0.989941
# 185979                Unemployment compensation Amt LT25K     0.967851
# 185980                Unemployment compensation Amt LT25K     0.955513
# 185981                Unemployment compensation Amt LT25K     0.991854
# 185982                Unemployment compensation Amt LT25K     0.997795
# 185983                Unemployment compensation Amt LT25K     0.951621
# 185984                Unemployment compensation Amt LT25K     0.960266
# 185985            Unemployment compensation Ct 100KLT200K     0.954944
# 185986            Unemployment compensation Ct 100KLT200K     0.973348
# 185987            Unemployment compensation Ct 100KLT200K     0.986044
# 185988            Unemployment compensation Ct 100KLT200K     0.954123
# 185989            Unemployment compensation Ct 100KLT200K     0.978006
# 185990            Unemployment compensation Ct 100KLT200K     0.950341
# 185991              Unemployment compensation Ct 25KLT50K     0.991866
# 185992              Unemployment compensation Ct 25KLT50K     0.984779
# 185993              Unemployment compensation Ct 25KLT50K     0.999266
# 185994              Unemployment compensation Ct 25KLT50K     0.984612
# 185995              Unemployment compensation Ct 25KLT50K     0.970437
# 185996              Unemployment compensation Ct 50KLT75K     0.996381
# 185997              Unemployment compensation Ct 50KLT75K     0.991222
# 185998              Unemployment compensation Ct 50KLT75K     0.960677
# 185999              Unemployment compensation Ct 50KLT75K     0.962511
# 186000             Unemployment compensation Ct 75KLT100K     0.984447
# 186001             Unemployment compensation Ct 75KLT100K     0.961692
# 186002                   Unemployment compensation Ct All     0.987351
# 186003                   Unemployment compensation Ct All     0.969163
# 186004                                RemainedinEducation     0.977054
# 186005                                    PersonalReasons     0.972111
# 186006                                      category_cd_I     1.000000
# 186007                                      category_cd_M     1.000000
# 186008                                      category_cd_T     1.000000
# 186009  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 186010  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 186011                                  sna_pgm_type_cd_Y     1.000000
#
# [186012 rows x 3 columns]

# %%
print ('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  962  highly correlated fields.
# ['Overall Achievement Score',
#  'Read Score',
#  'Math Score',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_CACR_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_CACR_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr6_GLP_All',
#  'EOGGr7_GLP_All',
#  'EOGGr8_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr6_CACR_All',
#  'EOGMathGr6_GLP_All',
#  'EOGMathGr7_CACR_All',
#  'EOGMathGr7_GLP_All',
#  'EOGMathGr8_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr6_CACR_All',
#  'EOGReadingGr6_GLP_All',
#  'EOGReadingGr7_CACR_All',
#  'EOGReadingGr7_GLP_All',
#  'EOGReadingGr8_CACR_All',
#  'EOGReadingGr8_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGScienceGr8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr6_CACR_Female',
#  'EOGGr6_GLP_Female',
#  'EOGGr7_CACR_Female',
#  'EOGGr7_GLP_Female',
#  'EOGGr8_CACR_Female',
#  'EOGGr8_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr6_CACR_Female',
#  'EOGMathGr6_GLP_Female',
#  'EOGMathGr7_CACR_Female',
#  'EOGMathGr7_GLP_Female',
#  'EOGMathGr8_CACR_Female',
#  'EOGMathGr8_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr6_GLP_Female',
#  'EOGReadingGr7_CACR_Female',
#  'EOGReadingGr7_GLP_Female',
#  'EOGReadingGr8_CACR_Female',
#  'EOGReadingGr8_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGScienceGr8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr6_CACR_Male',
#  'EOGGr6_GLP_Male',
#  'EOGGr7_CACR_Male',
#  'EOGGr7_GLP_Male',
#  'EOGGr8_CACR_Male',
#  'EOGGr8_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr6_CACR_Male',
#  'EOGMathGr6_GLP_Male',
#  'EOGMathGr7_CACR_Male',
#  'EOGMathGr7_GLP_Male',
#  'EOGMathGr8_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr6_CACR_Male',
#  'EOGReadingGr6_GLP_Male',
#  'EOGReadingGr7_CACR_Male',
#  'EOGReadingGr7_GLP_Male',
#  'EOGReadingGr8_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGScienceGr8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr6_GLP_AmericanIndian',
#  'EOGGr7_GLP_AmericanIndian',
#  'EOGGr8_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr6_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr7_GLP_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGScienceGr8_CACR_AmericanIndian',
#  'EOGScienceGr8_GLP_AmericanIndian',
#  'EOGSubjects_CACR_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_CACR_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr6_GLP_Asian',
#  'EOGGr7_GLP_Asian',
#  'EOGGr8_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr6_GLP_Asian',
#  'EOGMathGr7_GLP_Asian',
#  'EOGMathGr8_GLP_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr6_CACR_Asian',
#  'EOGReadingGr6_GLP_Asian',
#  'EOGReadingGr7_CACR_Asian',
#  'EOGReadingGr7_GLP_Asian',
#  'EOGReadingGr8_GLP_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGScienceGr8_CACR_Asian',
#  'EOGScienceGr8_GLP_Asian',
#  'EOGSubjects_CACR_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_CACR_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr7_GLP_Black',
#  'EOGGr8_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr7_GLP_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGScienceGr8_CACR_Black',
#  'EOGScienceGr8_GLP_Black',
#  'EOGSubjects_CACR_Black',
#  'EOGSubjects_GLP_Black',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_CACR_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'EOGGr7_GLP_Hispanic',
#  'EOGGr8_GLP_Hispanic',
#  'EOGMathGr6_GLP_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGScienceGr8_GLP_Hispanic',
#  'EOGSubjects_CACR_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_CACR_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr6_GLP_TwoorMoreRaces',
#  'EOGGr7_GLP_TwoorMoreRaces',
#  'EOGGr8_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr6_GLP_TwoorMoreRaces',
#  'EOGMathGr7_GLP_TwoorMoreRaces',
#  'EOGMathGr8_GLP_TwoorMoreRaces',
#  'EOGReadingGr6_GLP_TwoorMoreRaces',
#  'EOGReadingGr7_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGScienceGr8_CACR_TwoorMoreRaces',
#  'EOGScienceGr8_GLP_TwoorMoreRaces',
#  'EOGSubjects_CACR_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_CACR_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr6_GLP_White',
#  'EOGGr7_GLP_White',
#  'EOGGr8_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr6_CACR_White',
#  'EOGMathGr6_GLP_White',
#  'EOGMathGr7_CACR_White',
#  'EOGMathGr7_GLP_White',
#  'EOGMathGr8_GLP_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr6_GLP_White',
#  'EOGReadingGr7_CACR_White',
#  'EOGReadingGr7_GLP_White',
#  'EOGReadingGr8_GLP_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGScienceGr8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_CACR_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr6_GLP_EDS',
#  'EOGGr7_GLP_EDS',
#  'EOGGr8_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr6_GLP_EDS',
#  'EOGMathGr7_GLP_EDS',
#  'EOGMathGr8_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGReadingGr6_GLP_EDS',
#  'EOGReadingGr7_GLP_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGScienceGr8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOCSubjects_CACR_LEP',
#  'EOCSubjects_GLP_LEP',
#  'EOGScienceGr8_CACR_LEP',
#  'EOGScienceGr8_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOGSubjects_GLP_LEP',
#  'EOCMathI_GLP_SWD',
#  'EOCSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_CACR_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOGGr6_GLP_AIG',
#  'EOGGr7_GLP_AIG',
#  'EOGGr8_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr6_GLP_AIG',
#  'EOGMathGr7_GLP_AIG',
#  'EOGMathGr8_GLP_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr6_CACR_AIG',
#  'EOGReadingGr6_GLP_AIG',
#  'EOGReadingGr7_CACR_AIG',
#  'EOGReadingGr7_GLP_AIG',
#  'EOGReadingGr8_GLP_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGScienceGr8_CACR_AIG',
#  'EOGScienceGr8_GLP_AIG',
#  'EOGSubjects_GLP_AIG',
#  'st_short_susp_per_c_num',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'st_class_teach_num',
#  'st_advance_dgr_pct',
#  'st_emer_prov_teach_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'HispanicMalePct',
#  'BlackMalePct',
#  'WhiteMalePct',
#  'MinorityMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'HispanicFemalePct',
#  'BlackFemalePct',
#  'WhiteFemalePct',
#  'MinorityFemalePct',
#  'Assault Rate',
#  'Add Medicare tax Amt All',
#  'Add Medicare tax Amt GE200K',
#  'Add Medicare tax Ct 100KLT200K',
#  'Add Medicare tax Ct All',
#  'Add Medicare tax Ct GE200K',
#  'Add child tax credit Amt 25KLT50K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct 50KLT75K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Contributions Amt 100KLT200K',
#  'Contributions Amt 25KLT50K',
#  'Contributions Amt 50KLT75K',
#  'Contributions Amt 75KLT100K',
#  'Contributions Amt All',
#  'Contributions Amt GE200K',
#  'Contributions Amt LT25K',
#  'Contributions Ct 100KLT200K',
#  'Contributions Ct 25KLT50K',
#  'Contributions Ct 50KLT75K',
#  'Contributions Ct 75KLT100K',
#  'Contributions Ct All',
#  'Contributions Ct GE200K',
#  'Contributions Ct LT25K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Ct 100KLT200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'IRA payments Amt 100KLT200K',
#  'IRA payments Amt 25KLT50K',
#  'IRA payments Amt 50KLT75K',
#  'IRA payments Amt 75KLT100K',
#  'IRA payments Amt All',
#  'IRA payments Amt GE200K',
#  'IRA payments Amt LT25K',
#  'IRA payments Ct 100KLT200K',
#  'IRA payments Ct 25KLT50K',
#  'IRA payments Ct 50KLT75K',
#  'IRA payments Ct 75KLT100K',
#  'IRA payments Ct All',
#  'IRA payments Ct GE200K',
#  'IRA payments Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Mortgage interest paid Amt 100KLT200K',
#  'Mortgage interest paid Amt 25KLT50K',
#  'Mortgage interest paid Amt 50KLT75K',
#  'Mortgage interest paid Amt 75KLT100K',
#  'Mortgage interest paid Amt All',
#  'Mortgage interest paid Amt GE200K',
#  'Mortgage interest paid Amt LT25K',
#  'Mortgage interest paid Ct 100KLT200K',
#  'Mortgage interest paid Ct 25KLT50K',
#  'Mortgage interest paid Ct 50KLT75K',
#  'Mortgage interest paid Ct 75KLT100K',
#  'Mortgage interest paid Ct All',
#  'Mortgage interest paid Ct GE200K',
#  'Mortgage interest paid Ct LT25K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Retirement savings contribution credit Amt 25KLT50K',
#  'Retirement savings contribution credit Amt 50KLT75K',
#  'Retirement savings contribution credit Amt All',
#  'Retirement savings contribution credit Amt LT25K',
#  'Retirement savings contribution credit Ct 25KLT50K',
#  'Retirement savings contribution credit Ct 50KLT75K',
#  'Retirement savings contribution credit Ct All',
#  'Retirement savings contribution credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employment health insurance deduction Amt 100KLT200K',
#  'Self-employment health insurance deduction Amt 25KLT50K',
#  'Self-employment health insurance deduction Amt 50KLT75K',
#  'Self-employment health insurance deduction Amt 75KLT100K',
#  'Self-employment health insurance deduction Amt All',
#  'Self-employment health insurance deduction Amt GE200K',
#  'Self-employment health insurance deduction Amt LT25K',
#  'Self-employment health insurance deduction Ct 100KLT200K',
#  'Self-employment health insurance deduction Ct 25KLT50K',
#  'Self-employment health insurance deduction Ct 50KLT75K',
#  'Self-employment health insurance deduction Ct 75KLT100K',
#  'Self-employment health insurance deduction Ct All',
#  'Self-employment health insurance deduction Ct GE200K',
#  'Self-employment health insurance deduction Ct LT25K',
#  'Self-employment retirement plans Amt 100KLT200K',
#  'Self-employment retirement plans Amt 50KLT75K',
#  'Self-employment retirement plans Amt 75KLT100K',
#  'Self-employment retirement plans Amt All',
#  'Self-employment retirement plans Amt GE200K',
#  'Self-employment retirement plans Ct 100KLT200K',
#  'Self-employment retirement plans Ct 25KLT50K',
#  'Self-employment retirement plans Ct 50KLT75K',
#  'Self-employment retirement plans Ct 75KLT100K',
#  'Self-employment retirement plans Ct All',
#  'Self-employment retirement plans Ct GE200K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt GE200K',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  'Taxable interest Ct 100KLT200K',
#  'Taxable interest Ct 25KLT50K',
#  'Taxable interest Ct 50KLT75K',
#  'Taxable interest Ct 75KLT100K',
#  'Taxable interest Ct All',
#  'Taxable interest Ct GE200K',
#  'Taxable interest Ct LT25K',
#  'Taxes paid Amt 100KLT200K',
#  'Taxes paid Amt 25KLT50K',
#  'Taxes paid Amt 50KLT75K',
#  'Taxes paid Amt 75KLT100K',
#  'Taxes paid Amt All',
#  'Taxes paid Amt GE200K',
#  'Taxes paid Amt LT25K',
#  'Taxes paid Ct 100KLT200K',
#  'Taxes paid Ct 25KLT50K',
#  'Taxes paid Ct 50KLT75K',
#  'Taxes paid Ct 75KLT100K',
#  'Taxes paid Ct All',
#  'Taxes paid Ct GE200K',
#  'Taxes paid Ct LT25K',
#  'Tot income Amt 100KLT200K',
#  'Tot income Amt 25KLT50K',
#  'Tot income Amt 50KLT75K',
#  'Tot income Amt 75KLT100K',
#  'Tot income Amt All',
#  'Tot income Amt GE200K',
#  'Tot income Amt LT25K',
#  'Tot income Ct 100KLT200K',
#  'Tot income Ct 25KLT50K',
#  'Tot income Ct 50KLT75K',
#  'Tot income Ct 75KLT100K',
#  'Tot income Ct All',
#  'Tot income Ct GE200K',
#  'Tot income Ct LT25K',
#  'Tot itemized deductions Amt 100KLT200K',
#  'Tot itemized deductions Amt 25KLT50K',
#  'Tot itemized deductions Amt 50KLT75K',
#  'Tot itemized deductions Amt 75KLT100K',
#  'Tot itemized deductions Amt All',
#  'Tot itemized deductions Amt GE200K',
#  'Tot itemized deductions Amt LT25K',
#  'Tot itemized deductions Amt of AGI 100KLT200K',
#  'Tot itemized deductions Amt of AGI 25KLT50K',
#  'Tot itemized deductions Amt of AGI 50KLT75K',
#  'Tot itemized deductions Amt of AGI 75KLT100K',
#  'Tot itemized deductions Amt of AGI All',
#  'Tot itemized deductions Amt of AGI GE200K',
#  'Tot itemized deductions Amt of AGI LT25K',
#  'Tot itemized deductions Ct 100KLT200K',
#  'Tot itemized deductions Ct 25KLT50K',
#  'Tot itemized deductions Ct 50KLT75K',
#  'Tot itemized deductions Ct 75KLT100K',
#  'Tot itemized deductions Ct All',
#  'Tot itemized deductions Ct GE200K',
#  'Tot itemized deductions Ct LT25K',
#  'Tot statuory adjustments Amt 100KLT200K',
#  'Tot statuory adjustments Amt 25KLT50K',
#  'Tot statuory adjustments Amt 50KLT75K',
#  'Tot statuory adjustments Amt 75KLT100K',
#  'Tot statuory adjustments Amt All',
#  'Tot statuory adjustments Amt GE200K',
#  'Tot statuory adjustments Amt LT25K',
#  'Tot statuory adjustments Ct 100KLT200K',
#  'Tot statuory adjustments Ct 25KLT50K',
#  'Tot statuory adjustments Ct 50KLT75K',
#  'Tot statuory adjustments Ct 75KLT100K',
#  'Tot statuory adjustments Ct All',
#  'Tot statuory adjustments Ct GE200K',
#  'Tot statuory adjustments Ct LT25K',
#  'Tot tax credits Amt 100KLT200K',
#  'Tot tax credits Amt 25KLT50K',
#  'Tot tax credits Amt 50KLT75K',
#  'Tot tax credits Amt 75KLT100K',
#  'Tot tax credits Amt All',
#  'Tot tax credits Amt GE200K',
#  'Tot tax credits Amt LT25K',
#  'Tot tax credits Ct 100KLT200K',
#  'Tot tax credits Ct 25KLT50K',
#  'Tot tax credits Ct 50KLT75K',
#  'Tot tax credits Ct 75KLT100K',
#  'Tot tax credits Ct All',
#  'Tot tax credits Ct GE200K',
#  'Tot tax credits Ct LT25K',
#  'Tot tax liability Amt 100KLT200K',
#  'Tot tax liability Amt 25KLT50K',
#  'Tot tax liability Amt 50KLT75K',
#  'Tot tax liability Amt 75KLT100K',
#  'Tot tax liability Amt All',
#  'Tot tax liability Amt GE200K',
#  'Tot tax liability Amt LT25K',
#  'Tot tax liability Ct 100KLT200K',
#  'Tot tax liability Ct 25KLT50K',
#  'Tot tax liability Ct 50KLT75K',
#  'Tot tax liability Ct 75KLT100K',
#  'Tot tax liability Ct All',
#  'Tot tax liability Ct GE200K',
#  'Tot tax liability Ct LT25K',
#  'Tot tax payments Amt 100KLT200K',
#  'Tot tax payments Amt 25KLT50K',
#  'Tot tax payments Amt 50KLT75K',
#  'Tot tax payments Amt 75KLT100K',
#  'Tot tax payments Amt All',
#  'Tot tax payments Amt GE200K',
#  'Tot tax payments Amt LT25K',
#  'Tot tax payments Ct 100KLT200K',
#  'Tot tax payments Ct 25KLT50K',
#  'Tot tax payments Ct 50KLT75K',
#  'Tot tax payments Ct 75KLT100K',
#  'Tot tax payments Ct All',
#  'Tot tax payments Ct GE200K',
#  'Tot tax payments Ct LT25K',
#  'Tuition and fees deduction Amt 100KLT200K',
#  'Tuition and fees deduction Amt 25KLT50K',
#  'Tuition and fees deduction Amt 50KLT75K',
#  'Tuition and fees deduction Amt 75KLT100K',
#  'Tuition and fees deduction Amt All',
#  'Tuition and fees deduction Amt LT25K',
#  'Tuition and fees deduction Ct 100KLT200K',
#  'Tuition and fees deduction Ct 25KLT50K',
#  'Tuition and fees deduction Ct 50KLT75K',
#  'Tuition and fees deduction Ct 75KLT100K',
#  'Tuition and fees deduction Ct All',
#  'Tuition and fees deduction Ct LT25K',
#  'Unemployment compensation Amt 100KLT200K',
#  'Unemployment compensation Amt 25KLT50K',
#  'Unemployment compensation Amt 50KLT75K',
#  'Unemployment compensation Amt 75KLT100K',
#  'Unemployment compensation Amt All',
#  'Unemployment compensation Amt GE200K',
#  'Unemployment compensation Amt LT25K',
#  'Unemployment compensation Ct 100KLT200K',
#  'Unemployment compensation Ct 25KLT50K',
#  'Unemployment compensation Ct 50KLT75K',
#  'Unemployment compensation Ct 75KLT100K',
#  'Unemployment compensation Ct All',
#  'Unemployment compensation Ct GE200K',
#  'Unemployment compensation Ct LT25K',
#  'RemainedinEducation',
#  'PersonalReasons',
#  'InitiatedbyLEA',
#  'category_cd_I',
#  'category_cd_M',
#  'sna_pgm_type_cd_Y',
#  'calendar_only_txt_Year-Round Calendar',
#  'Category_Cd_I',
#  'Category_Cd_M',
#  'Category_Cd_T']

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1358 entries, student_num to esea_attendance_Met
# dtypes: float64(1310), uint8(48)
# memory usage: 5.4 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 396 entries, student_num to esea_attendance_Met
# dtypes: float64(355), uint8(41)
# memory usage: 1.5 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Data columns (total 397 columns):
# student_num                                                float64
# lea_avg_student_num                                        float64
# st_avg_student_num                                         float64
# Math I_Size                                                float64
# lea_total_expense_num                                      float64
# lea_salary_expense_pct                                     float64
# lea_benefits_expense_pct                                   float64
# lea_services_expense_pct                                   float64
# lea_supplies_expense_pct                                   float64
# lea_instruct_equip_exp_pct                                 float64
# lea_federal_perpupil_num                                   float64
# lea_local_perpupil_num                                     float64
# lea_state_perpupil_num                                     float64
# SBE Region                                                 float64
# SPG Score                                                  float64
# Reading  SPG Score                                         float64
# Math SPG Score                                             float64
# EVAAS Growth Score                                         float64
# Science Score                                              float64
# Math I Score                                               float64
# EOGGr6_CACR_All                                            float64
# EOGGr7_CACR_All                                            float64
# EOGGr8_CACR_All                                            float64
# EOGMathGr8_CACR_All                                        float64
# EOGScienceGr8_CACR_All                                     float64
# EOCMathI_CACR_Female                                       float64
# EOGReadingGr6_CACR_Female                                  float64
# EOGScienceGr8_CACR_Female                                  float64
# EOCMathI_CACR_Male                                         float64
# EOGMathGr8_CACR_Male                                       float64
# EOGReadingGr8_CACR_Male                                    float64
# EOGScienceGr8_CACR_Male                                    float64
# EOCMathI_CACR_AmericanIndian                               float64
# EOCSubjects_CACR_AmericanIndian                            float64
# EOG/EOCSubjects_CACR_AmericanIndian                        float64
# EOGGr6_CACR_AmericanIndian                                 float64
# EOGGr7_CACR_AmericanIndian                                 float64
# EOGGr8_CACR_AmericanIndian                                 float64
# EOGMathGr3-8_CACR_AmericanIndian                           float64
# EOGMathGr6_CACR_AmericanIndian                             float64
# EOGMathGr7_CACR_AmericanIndian                             float64
# EOGMathGr7_GLP_AmericanIndian                              float64
# EOGMathGr8_CACR_AmericanIndian                             float64
# EOGMathGr8_GLP_AmericanIndian                              float64
# EOGReadingGr3-8_CACR_AmericanIndian                        float64
# EOGReadingGr6_CACR_AmericanIndian                          float64
# EOGReadingGr6_GLP_AmericanIndian                           float64
# EOGReadingGr7_CACR_AmericanIndian                          float64
# EOGReadingGr8_CACR_AmericanIndian                          float64
# EOGReadingGr8_GLP_AmericanIndian                           float64
# EOGScienceGr5&8_CACR_AmericanIndian                        float64
# EOCMathI_CACR_Asian                                        float64
# EOG/EOCSubjects_CACR_Asian                                 float64
# EOGGr6_CACR_Asian                                          float64
# EOGGr7_CACR_Asian                                          float64
# EOGGr8_CACR_Asian                                          float64
# EOGMathGr3-8_CACR_Asian                                    float64
# EOGMathGr6_CACR_Asian                                      float64
# EOGMathGr7_CACR_Asian                                      float64
# EOGMathGr8_CACR_Asian                                      float64
# EOGReadingGr3-8_CACR_Asian                                 float64
# EOGReadingGr8_CACR_Asian                                   float64
# EOGScienceGr5&8_CACR_Asian                                 float64
# EOCMathI_CACR_Black                                        float64
# EOG/EOCSubjects_CACR_Black                                 float64
# EOGGr6_CACR_Black                                          float64
# EOGGr6_GLP_Black                                           float64
# EOGGr7_CACR_Black                                          float64
# EOGGr8_CACR_Black                                          float64
# EOGMathGr3-8_CACR_Black                                    float64
# EOGMathGr6_CACR_Black                                      float64
# EOGMathGr6_GLP_Black                                       float64
# EOGMathGr7_CACR_Black                                      float64
# EOGMathGr8_CACR_Black                                      float64
# EOGMathGr8_GLP_Black                                       float64
# EOGReadingGr3-8_CACR_Black                                 float64
# EOGReadingGr3-8_GLP_Black                                  float64
# EOGReadingGr6_CACR_Black                                   float64
# EOGReadingGr6_GLP_Black                                    float64
# EOGReadingGr7_CACR_Black                                   float64
# EOGReadingGr7_GLP_Black                                    float64
# EOGReadingGr8_CACR_Black                                   float64
# EOGReadingGr8_GLP_Black                                    float64
# EOGScienceGr5&8_CACR_Black                                 float64
# EOCMathI_CACR_Hispanic                                     float64
# EOG/EOCSubjects_CACR_Hispanic                              float64
# EOGGr6_CACR_Hispanic                                       float64
# EOGGr6_GLP_Hispanic                                        float64
# EOGGr7_CACR_Hispanic                                       float64
# EOGGr8_CACR_Hispanic                                       float64
# EOGMathGr3-8_CACR_Hispanic                                 float64
# EOGMathGr3-8_GLP_Hispanic                                  float64
# EOGMathGr6_CACR_Hispanic                                   float64
# EOGMathGr7_CACR_Hispanic                                   float64
# EOGMathGr7_GLP_Hispanic                                    float64
# EOGMathGr8_CACR_Hispanic                                   float64
# EOGMathGr8_GLP_Hispanic                                    float64
# EOGReadingGr3-8_CACR_Hispanic                              float64
# EOGReadingGr3-8_GLP_Hispanic                               float64
# EOGReadingGr6_CACR_Hispanic                                float64
# EOGReadingGr6_GLP_Hispanic                                 float64
# EOGReadingGr7_CACR_Hispanic                                float64
# EOGReadingGr7_GLP_Hispanic                                 float64
# EOGReadingGr8_CACR_Hispanic                                float64
# EOGReadingGr8_GLP_Hispanic                                 float64
# EOGScienceGr5&8_CACR_Hispanic                              float64
# EOGScienceGr8_CACR_Hispanic                                float64
# EOCMathI_CACR_TwoorMoreRaces                               float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                        float64
# EOG/EOCSubjects_GLP_TwoorMoreRaces                         float64
# EOGGr6_CACR_TwoorMoreRaces                                 float64
# EOGGr7_CACR_TwoorMoreRaces                                 float64
# EOGGr8_CACR_TwoorMoreRaces                                 float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                           float64
# EOGMathGr6_CACR_TwoorMoreRaces                             float64
# EOGMathGr7_CACR_TwoorMoreRaces                             float64
# EOGMathGr8_CACR_TwoorMoreRaces                             float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                        float64
# EOGReadingGr3-8_GLP_TwoorMoreRaces                         float64
# EOGReadingGr6_CACR_TwoorMoreRaces                          float64
# EOGReadingGr7_CACR_TwoorMoreRaces                          float64
# EOGReadingGr8_CACR_TwoorMoreRaces                          float64
# EOGReadingGr8_GLP_TwoorMoreRaces                           float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                        float64
# EOCMathI_CACR_White                                        float64
# EOG/EOCSubjects_CACR_White                                 float64
# EOGGr6_CACR_White                                          float64
# EOGGr7_CACR_White                                          float64
# EOGGr8_CACR_White                                          float64
# EOGMathGr3-8_CACR_White                                    float64
# EOGMathGr8_CACR_White                                      float64
# EOGReadingGr3-8_CACR_White                                 float64
# EOGReadingGr6_CACR_White                                   float64
# EOGReadingGr8_CACR_White                                   float64
# EOGScienceGr5&8_CACR_White                                 float64
# EOGScienceGr8_CACR_White                                   float64
# EOCMathI_CACR_EDS                                          float64
# EOG/EOCSubjects_CACR_EDS                                   float64
# EOGGr6_CACR_EDS                                            float64
# EOGGr7_CACR_EDS                                            float64
# EOGGr8_CACR_EDS                                            float64
# EOGMathGr3-8_CACR_EDS                                      float64
# EOGMathGr6_CACR_EDS                                        float64
# EOGMathGr7_CACR_EDS                                        float64
# EOGMathGr8_CACR_EDS                                        float64
# EOGReadingGr3-8_CACR_EDS                                   float64
# EOGReadingGr6_CACR_EDS                                     float64
# EOGReadingGr7_CACR_EDS                                     float64
# EOGReadingGr8_CACR_EDS                                     float64
# EOGReadingGr8_GLP_EDS                                      float64
# EOGScienceGr5&8_CACR_EDS                                   float64
# EOGScienceGr8_CACR_EDS                                     float64
# EOCMathI_CACR_LEP                                          float64
# EOCMathI_GLP_LEP                                           float64
# EOG/EOCSubjects_CACR_LEP                                   float64
# EOG/EOCSubjects_GLP_LEP                                    float64
# EOGGr6_CACR_LEP                                            float64
# EOGGr6_GLP_LEP                                             float64
# EOGGr7_CACR_LEP                                            float64
# EOGGr7_GLP_LEP                                             float64
# EOGGr8_CACR_LEP                                            float64
# EOGGr8_GLP_LEP                                             float64
# EOGMathGr3-8_CACR_LEP                                      float64
# EOGMathGr3-8_GLP_LEP                                       float64
# EOGMathGr6_CACR_LEP                                        float64
# EOGMathGr6_GLP_LEP                                         float64
# EOGMathGr7_CACR_LEP                                        float64
# EOGMathGr7_GLP_LEP                                         float64
# EOGMathGr8_CACR_LEP                                        float64
# EOGMathGr8_GLP_LEP                                         float64
# EOGReadingGr3-8_CACR_LEP                                   float64
# EOGReadingGr3-8_GLP_LEP                                    float64
# EOGReadingGr6_CACR_LEP                                     float64
# EOGReadingGr6_GLP_LEP                                      float64
# EOGReadingGr7_CACR_LEP                                     float64
# EOGReadingGr7_GLP_LEP                                      float64
# EOGReadingGr8_CACR_LEP                                     float64
# EOGReadingGr8_GLP_LEP                                      float64
# EOGScienceGr5&8_CACR_LEP                                   float64
# EOGScienceGr5&8_GLP_LEP                                    float64
# EOCMathI_CACR_SWD                                          float64
# EOCSubjects_CACR_SWD                                       float64
# EOG/EOCSubjects_CACR_SWD                                   float64
# EOGGr6_CACR_SWD                                            float64
# EOGGr6_GLP_SWD                                             float64
# EOGGr7_CACR_SWD                                            float64
# EOGGr7_GLP_SWD                                             float64
# EOGGr8_CACR_SWD                                            float64
# EOGGr8_GLP_SWD                                             float64
# EOGMathGr3-8_CACR_SWD                                      float64
# EOGMathGr3-8_GLP_SWD                                       float64
# EOGMathGr6_CACR_SWD                                        float64
# EOGMathGr6_GLP_SWD                                         float64
# EOGMathGr7_CACR_SWD                                        float64
# EOGMathGr7_GLP_SWD                                         float64
# EOGMathGr8_CACR_SWD                                        float64
# EOGMathGr8_GLP_SWD                                         float64
# EOGReadingGr3-8_CACR_SWD                                   float64
# EOGReadingGr3-8_GLP_SWD                                    float64
# EOGReadingGr6_CACR_SWD                                     float64
# EOGReadingGr6_GLP_SWD                                      float64
# EOGReadingGr7_CACR_SWD                                     float64
# EOGReadingGr7_GLP_SWD                                      float64
# EOGReadingGr8_CACR_SWD                                     float64
# EOGReadingGr8_GLP_SWD                                      float64
# EOGScienceGr5&8_CACR_SWD                                   float64
# EOGScienceGr5&8_GLP_SWD                                    float64
# EOGScienceGr8_CACR_SWD                                     float64
# EOGScienceGr8_GLP_SWD                                      float64
# EOGSubjects_CACR_SWD                                       float64
# EOCMathI_CACR_AIG                                          float64
# EOG/EOCSubjects_CACR_AIG                                   float64
# EOG/EOCSubjects_GLP_AIG                                    float64
# EOGGr6_CACR_AIG                                            float64
# EOGGr7_CACR_AIG                                            float64
# EOGGr8_CACR_AIG                                            float64
# EOGMathGr3-8_CACR_AIG                                      float64
# EOGMathGr6_CACR_AIG                                        float64
# EOGMathGr7_CACR_AIG                                        float64
# EOGMathGr8_CACR_AIG                                        float64
# EOGReadingGr3-8_CACR_AIG                                   float64
# EOGReadingGr8_CACR_AIG                                     float64
# EOGScienceGr5&8_CACR_AIG                                   float64
# EOGSubjects_CACR_AIG                                       float64
# CurrentYearEOC_pTarget_PctMet                              float64
# MathGr3-8_pTarget_PctMet                                   float64
# ReadingGr3-8_pTarget_PctMet                                float64
# SciGr5&8_pTarget_PctMet                                    float64
# TotalTargets_pTarget_PctMet                                float64
# lea_sat_avg_score_num                                      float64
# lea_sat_participation_pct                                  float64
# lea_ap_participation_pct                                   float64
# lea_ap_pct_3_or_above                                      float64
# avg_daily_attend_pct                                       float64
# crime_per_c_num                                            float64
# short_susp_per_c_num                                       float64
# long_susp_per_c_num                                        float64
# stud_internet_comp_num                                     float64
# lea_avg_daily_attend_pct                                   float64
# lea_crime_per_c_num                                        float64
# lea_short_susp_per_c_num                                   float64
# lea_long_susp_per_c_num                                    float64
# lea_expelled_per_c_num                                     float64
# lea_stud_internet_comp_num                                 float64
# st_avg_daily_attend_pct                                    float64
# st_crime_per_c_num                                         float64
# flicensed_teach_pct                                        float64
# tchyrs_0thru3_pct                                          float64
# tchyrs_4thru10_pct                                         float64
# tchyrs_11plus_pct                                          float64
# nbpts_num                                                  float64
# advance_dgr_pct                                            float64
# _1yr_tchr_trnovr_pct                                       float64
# lateral_teach_pct                                          float64
# lea_flicensed_teach_pct                                    float64
# lea_tchyrs_0thru3_pct                                      float64
# lea_tchyrs_4thru10_pct                                     float64
# lea_tchyrs_11plus_pct                                      float64
# lea_nbpts_num                                              float64
# lea_advance_dgr_pct                                        float64
# lea_1yr_tchr_trnovr_pct                                    float64
# lea_emer_prov_teach_pct                                    float64
# st_flicensed_teach_pct                                     float64
# st_tchyrs_0thru3_pct                                       float64
# st_tchyrs_4thru10_pct                                      float64
# st_tchyrs_11plus_pct                                       float64
# st_nbpts_num                                               float64
# st_1yr_tchr_trnovr_pct                                     float64
# 0-3 Years_LEA_Exp_Pct_Prin                                 float64
# 10+ Years_LEA_Exp_Pct_Prin                                 float64
# 4-10 Years_LEA_Exp_Pct_Prin                                float64
# Accomplished_TCHR_Standard 1_Pct                           float64
# Accomplished_TCHR_Standard 2_Pct                           float64
# Accomplished_TCHR_Standard 3_Pct                           float64
# Accomplished_TCHR_Standard 4_Pct                           float64
# Accomplished_TCHR_Standard 5_Pct                           float64
# Developing_TCHR_Standard 1_Pct                             float64
# Developing_TCHR_Standard 2_Pct                             float64
# Developing_TCHR_Standard 3_Pct                             float64
# Developing_TCHR_Standard 4_Pct                             float64
# Developing_TCHR_Standard 5_Pct                             float64
# Distinguished_TCHR_Standard 1_Pct                          float64
# Distinguished_TCHR_Standard 2_Pct                          float64
# Distinguished_TCHR_Standard 3_Pct                          float64
# Distinguished_TCHR_Standard 4_Pct                          float64
# Distinguished_TCHR_Standard 5_Pct                          float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct          float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct                float64
# Meets Expected Growth_TCHR_Standard 6_Pct                  float64
# Not Demostrated_TCHR_Standard 1_Pct                        float64
# Not Demostrated_TCHR_Standard 2_Pct                        float64
# Not Demostrated_TCHR_Standard 3_Pct                        float64
# Not Demostrated_TCHR_Standard 4_Pct                        float64
# Not Demostrated_TCHR_Standard 5_Pct                        float64
# Proficient_TCHR_Standard 1_Pct                             float64
# Proficient_TCHR_Standard 2_Pct                             float64
# Proficient_TCHR_Standard 3_Pct                             float64
# Proficient_TCHR_Standard 4_Pct                             float64
# Proficient_TCHR_Standard 5_Pct                             float64
# IndianPct                                                  float64
# AsianPct                                                   float64
# HispanicPct                                                float64
# BlackPct                                                   float64
# WhitePct                                                   float64
# PacificIslandPct                                           float64
# TwoOrMorePct                                               float64
# PacificIslandMalePct                                       float64
# TwoOrMoreMalePct                                           float64
# PacificIslandFemalePct                                     float64
# TwoOrMoreFemalePct                                         float64
# Year                                                       float64
# Violent Rate                                               float64
# Murder Rate                                                float64
# Rape Rate                                                  float64
# Robbery Rate                                               float64
# MVT Rate                                                   float64
# Arson Rate                                                 float64
# Add Medicare tax Amt 100KLT200K                            float64
# Add child tax credit Amt 75KLT100K                         float64
# Alternative minimum tax Amt 25KLT50K                       float64
# Alternative minimum tax Amt 50KLT75K                       float64
# Alternative minimum tax Amt 75KLT100K                      float64
# Alternative minimum tax Amt LT25K                          float64
# Alternative minimum tax Ct 75KLT100K                       float64
# Alternative minimum tax Ct LT25K                           float64
# Domestic production activities deduction Amt 100KLT200K    float64
# Domestic production activities deduction Amt 25KLT50K      float64
# Domestic production activities deduction Amt 50KLT75K      float64
# Domestic production activities deduction Amt 75KLT100K     float64
# Domestic production activities deduction Amt LT25K         float64
# Domestic production activities deduction Ct 25KLT50K       float64
# Domestic production activities deduction Ct 50KLT75K       float64
# Domestic production activities deduction Ct 75KLT100K      float64
# Domestic production activities deduction Ct LT25K          float64
# Number of farm returns 100KLT200K                          float64
# Number of farm returns 25KLT50K                            float64
# Number of farm returns 50KLT75K                            float64
# Number of farm returns 75KLT100K                           float64
# Number of farm returns All                                 float64
# Number of farm returns GE200K                              float64
# Number of farm returns LT25K                               float64
# Partnership/S-corp net income (less loss) Amt LT25K        float64
# Residential energy tax credit Amt LT25K                    float64
# Residential energy tax credit Ct LT25K                     float64
# Self-employment retirement plans Amt 25KLT50K              float64
# Self-employment retirement plans Amt LT25K                 float64
# Self-employment retirement plans Ct LT25K                  float64
# LEACode                                                    float64
# RemainedinEducationPerct                                   float64
# PersonalPerct                                              float64
# InitiatedPerct                                             float64
# BeyondControlofLEA                                         float64
# BeyondControlPerct                                         float64
# OtherReasons                                               float64
# OtherReasonsPerct                                          float64
# category_cd_T                                              uint8
# grade_range_cd_5-6                                         uint8
# grade_range_cd_5-8                                         uint8
# grade_range_cd_6-11                                        uint8
# grade_range_cd_6-12                                        uint8
# grade_range_cd_6-13                                        uint8
# grade_range_cd_6-6                                         uint8
# grade_range_cd_6-7                                         uint8
# grade_range_cd_6-8                                         uint8
# grade_range_cd_6-9                                         uint8
# grade_range_cd_7-12                                        uint8
# grade_range_cd_7-13                                        uint8
# grade_range_cd_7-8                                         uint8
# grade_range_cd_7-9                                         uint8
# grade_range_cd_8-8                                         uint8
# grade_range_cd_K-12                                        uint8
# grade_range_cd_K-8                                         uint8
# grade_range_cd_PK-12                                       uint8
# grade_range_cd_PK-7                                        uint8
# grade_range_cd_PK-8                                        uint8
# calendar_type_txt_Regular School, Year-Round Calendar      uint8
# esea_status_P                                              uint8
# esea_status_R                                              uint8
# esea_status_RF                                             uint8
# esea_status_RP                                             uint8
# Grad_project_status_Y                                      uint8
# SPG Grade_B                                                uint8
# SPG Grade_C                                                uint8
# SPG Grade_D                                                uint8
# SPG Grade_F                                                uint8
# Reading SPG Grade_B                                        uint8
# Reading SPG Grade_C                                        uint8
# Reading SPG Grade_D                                        uint8
# Reading SPG Grade_F                                        uint8
# Math SPG Grade_B                                           uint8
# Math SPG Grade_C                                           uint8
# Math SPG Grade_D                                           uint8
# Math SPG Grade_F                                           uint8
# EVAAS Growth Status_Met                                    uint8
# EVAAS Growth Status_NotMet                                 uint8
# esea_attendance_Met                                        uint8
# unit_code                                                  object
# dtypes: float64(355), object(1), uint8(41)
# memory usage: 1.5+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.1
# Pandas Version: 0.24.2

# %%
print ('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2014/Machine Learning Datasets/PublicMiddleSchools2014_ML.csv
