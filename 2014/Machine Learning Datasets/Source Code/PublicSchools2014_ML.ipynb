# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2014

#Location where copies of the raw data files will be read in from csv files.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
inputFileName = 'PublicSchools' + str(schoolYear)
#inputFileName = 'PublicHighSchools' + str(schoolYear)
#inputFileName = 'PublicMiddleSchools' + str(schoolYear)
#inputFileName = 'PublicElementarySchools' + str(schoolYear)

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
#Rename Lea_Name to District Name
schoolData.rename(columns={'Lea_Name': 'District Name'}, inplace=True)
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2561 entries, 0 to 2560
# Columns: 2055 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(2018), int64(3), object(34)
# memory usage: 40.2+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 2055 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(2018), int64(3), object(34)
# memory usage: 38.1+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#schoolData.info(verbose=True)

# %%
schoolData[['unit_code','LEA Name','School Name','_1yr_tchr_trnovr_pct','lea_1yr_tchr_trnovr_pct','st_1yr_tchr_trnovr_pct']].head(20)
# Out:
#    unit_code                     LEA Name                         School Name  \
# 0     010303  Alamance-Burlington Schools  Alamance-Burlington Middle College
# 1     010304  Alamance-Burlington Schools         Alexander Wilson Elementary
# 2     010308  Alamance-Burlington Schools              Altamahaw Ossipee Elem
# 3     010310  Alamance-Burlington Schools                    Broadview Middle
# 5     010312  Alamance-Burlington Schools                 Highland Elementary
# 6     010320  Alamance-Burlington Schools                E M Yoder Elementary
# 7     010324  Alamance-Burlington Schools               Eastern Alamance High
# 8     010326  Alamance-Burlington Schools                 Eastlawn Elementary
# 9     010328  Alamance-Burlington Schools             Edwin M Holt Elementary
# 10    010340  Alamance-Burlington Schools                     Elon Elementary
# 11    010346  Alamance-Burlington Schools               B Everett Jordan Elem
# 12    010347  Alamance-Burlington Schools                  Garrett Elementary
# 13    010348  Alamance-Burlington Schools                         Graham High
# 14    010350  Alamance-Burlington Schools                       Graham Middle
# 15    010351  Alamance-Burlington Schools               Grove Park Elementary
# 16    010353  Alamance-Burlington Schools                    Hawfields Middle
# 17    010354  Alamance-Burlington Schools          Harvey R Newlin Elementary
# 18    010357  Alamance-Burlington Schools                Haw River Elementary
# 19    010358  Alamance-Burlington Schools                Hillcrest Elementary
# 20    010360  Alamance-Burlington Schools                Hugh M Cummings High
#
#     _1yr_tchr_trnovr_pct  lea_1yr_tchr_trnovr_pct  st_1yr_tchr_trnovr_pct
# 0                  0.000                    0.137                   0.156
# 1                  0.264                    0.148                   0.128
# 2                  0.085                    0.148                   0.128
# 3                  0.296                    0.185                   0.153
# 5                  0.247                    0.148                   0.128
# 6                  0.112                    0.148                   0.128
# 7                  0.109                    0.137                   0.156
# 8                  0.302                    0.148                   0.128
# 9                  0.100                    0.148                   0.128
# 10                 0.075                    0.148                   0.128
# 11                 0.108                    0.148                   0.128
# 12                 0.091                    0.148                   0.128
# 13                 0.255                    0.137                   0.156
# 14                 0.173                    0.185                   0.153
# 15                 0.132                    0.148                   0.128
# 16                 0.289                    0.185                   0.153
# 17                 0.154                    0.148                   0.128
# 18                 0.098                    0.148                   0.128
# 19                 0.195                    0.148                   0.128
# 20                 0.125                    0.137                   0.156

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print ('Rows Updated / Imputed: ', rowsUpdated )
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1870 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1840), object(30)
# memory usage: 34.6+ MB
#
# Columns Deleted:  185

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1868 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1840), object(28)
# memory usage: 34.6+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1868 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1840), object(28)
# memory usage: 34.6+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print( "Boolean Columns: ", sD_boolean.shape[1])
print( "Nominal Columns: ", sD_nominal.shape[1])
print( "Continuous Columns: ", sD_continuous.shape[1])
print( "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  28
# Continuous Columns:  1840
# Columns Accounted for:  1868

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1360 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1332), object(28)
# memory usage: 25.2+ MB
#
# Columns Deleted:  508

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1347 entries, closed_ind to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1332), object(15)
# memory usage: 25.0+ MB
#
# Columns Deleted:  13

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print ('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print ('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  15
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1383 entries, closed_ind to esea_attendance_Met
# dtypes: float64(1332), uint8(51)
# memory usage: 24.8 MB
#
# New Columns Created Via One-Hot Encoding:  36

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                           Variable Name  Number Missing Values
# 2                                   lea_avg_student_num                      3
# 3                                    st_avg_student_num                      3
# 4                                           Math I_Size                   1396
# 15                                            SPG Score                    128
# 16                                   Reading  SPG Score                    599
# 17                                       Math SPG Score                    599
# 18                                   EVAAS Growth Score                    141
# 19                            Overall Achievement Score                    128
# 20                                           Read Score                    599
# 21                                           Math Score                    599
# 22                                        Science Score                    688
# 23                                         Math I Score                   1445
# 24                                    EOCMathI_CACR_All                   1371
# 25                                     EOCMathI_GLP_All                   1371
# 26                                 EOCSubjects_CACR_All                   1360
# 27                                  EOCSubjects_GLP_All                   1360
# 28                             EOG/EOCSubjects_CACR_All                     43
# 29                              EOG/EOCSubjects_GLP_All                     43
# 30                                      EOGGr3_CACR_All                   1096
# 31                                       EOGGr3_GLP_All                   1096
# 32                                      EOGGr4_CACR_All                   1099
# 33                                       EOGGr4_GLP_All                   1099
# 34                                      EOGGr5_CACR_All                   1122
# 35                                       EOGGr5_GLP_All                   1122
# 36                                  EOGMathGr3_CACR_All                   1103
# 37                                   EOGMathGr3_GLP_All                   1103
# 38                                EOGMathGr3-8_CACR_All                    528
# 39                                 EOGMathGr3-8_GLP_All                    528
# 40                                  EOGMathGr4_CACR_All                   1108
# 41                                   EOGMathGr4_GLP_All                   1108
# 42                                  EOGMathGr5_CACR_All                   1134
# 43                                   EOGMathGr5_GLP_All                   1134
# 44                               EOGReadingGr3_CACR_All                   1103
# 45                                EOGReadingGr3_GLP_All                   1103
# 46                             EOGReadingGr3-8_CACR_All                    528
# 47                              EOGReadingGr3-8_GLP_All                    528
# 48                               EOGReadingGr4_CACR_All                   1108
# 49                                EOGReadingGr4_GLP_All                   1108
# 50                               EOGReadingGr5_CACR_All                   1134
# 51                                EOGReadingGr5_GLP_All                   1134
# 52                               EOGScienceGr5_CACR_All                   1134
# 53                                EOGScienceGr5_GLP_All                   1134
# 54                             EOGScienceGr5&8_CACR_All                    626
# 55                              EOGScienceGr5&8_GLP_All                    626
# 56                                 EOGSubjects_CACR_All                    523
# 57                                  EOGSubjects_GLP_All                    523
# 58                                 EOCMathI_CACR_Female                   1371
# 59                                  EOCMathI_GLP_Female                   1371
# 60                              EOCSubjects_CACR_Female                   1360
# 61                               EOCSubjects_GLP_Female                   1360
# 62                          EOG/EOCSubjects_CACR_Female                     43
# 63                           EOG/EOCSubjects_GLP_Female                     43
# 64                                   EOGGr3_CACR_Female                   1096
# 65                                    EOGGr3_GLP_Female                   1096
# 66                                   EOGGr4_CACR_Female                   1099
# 67                                    EOGGr4_GLP_Female                   1099
# 68                                   EOGGr5_CACR_Female                   1122
# 69                                    EOGGr5_GLP_Female                   1122
# 70                               EOGMathGr3_CACR_Female                   1103
# 71                                EOGMathGr3_GLP_Female                   1103
# 72                             EOGMathGr3-8_CACR_Female                    528
# 73                              EOGMathGr3-8_GLP_Female                    528
# 74                               EOGMathGr4_CACR_Female                   1108
# 75                                EOGMathGr4_GLP_Female                   1108
# 76                               EOGMathGr5_CACR_Female                   1134
# 77                                EOGMathGr5_GLP_Female                   1134
# 78                            EOGReadingGr3_CACR_Female                   1103
# 79                             EOGReadingGr3_GLP_Female                   1103
# 80                          EOGReadingGr3-8_CACR_Female                    528
# 81                           EOGReadingGr3-8_GLP_Female                    528
# 82                            EOGReadingGr4_CACR_Female                   1108
# 83                             EOGReadingGr4_GLP_Female                   1108
# 84                            EOGReadingGr5_CACR_Female                   1134
# 85                             EOGReadingGr5_GLP_Female                   1134
# 86                            EOGScienceGr5_CACR_Female                   1134
# 87                             EOGScienceGr5_GLP_Female                   1134
# 88                          EOGScienceGr5&8_CACR_Female                    626
# 89                           EOGScienceGr5&8_GLP_Female                    626
# 90                              EOGSubjects_CACR_Female                    523
# 91                               EOGSubjects_GLP_Female                    523
# 92                                   EOCMathI_CACR_Male                   1371
# 93                                    EOCMathI_GLP_Male                   1371
# 94                                EOCSubjects_CACR_Male                   1360
# 95                                 EOCSubjects_GLP_Male                   1360
# 96                            EOG/EOCSubjects_CACR_Male                     43
# 97                             EOG/EOCSubjects_GLP_Male                     43
# 98                                     EOGGr3_CACR_Male                   1096
# 99                                      EOGGr3_GLP_Male                   1096
# 100                                    EOGGr4_CACR_Male                   1099
# 101                                     EOGGr4_GLP_Male                   1099
# 102                                    EOGGr5_CACR_Male                   1122
# 103                                     EOGGr5_GLP_Male                   1122
# 104                                EOGMathGr3_CACR_Male                   1103
# 105                                 EOGMathGr3_GLP_Male                   1103
# 106                              EOGMathGr3-8_CACR_Male                    528
# 107                               EOGMathGr3-8_GLP_Male                    528
# 108                                EOGMathGr4_CACR_Male                   1108
# 109                                 EOGMathGr4_GLP_Male                   1108
# 110                                EOGMathGr5_CACR_Male                   1134
# 111                                 EOGMathGr5_GLP_Male                   1134
# 112                             EOGReadingGr3_CACR_Male                   1103
# 113                              EOGReadingGr3_GLP_Male                   1103
# 114                           EOGReadingGr3-8_CACR_Male                    528
# 115                            EOGReadingGr3-8_GLP_Male                    528
# 116                             EOGReadingGr4_CACR_Male                   1108
# 117                              EOGReadingGr4_GLP_Male                   1108
# 118                             EOGReadingGr5_CACR_Male                   1134
# 119                              EOGReadingGr5_GLP_Male                   1134
# 120                             EOGScienceGr5_CACR_Male                   1134
# 121                              EOGScienceGr5_GLP_Male                   1134
# 122                           EOGScienceGr5&8_CACR_Male                    626
# 123                            EOGScienceGr5&8_GLP_Male                    626
# 124                               EOGSubjects_CACR_Male                    523
# 125                                EOGSubjects_GLP_Male                    523
# 126                        EOCMathI_CACR_AmericanIndian                   1371
# 127                         EOCMathI_GLP_AmericanIndian                   1371
# 128                     EOCSubjects_CACR_AmericanIndian                   1360
# 129                      EOCSubjects_GLP_AmericanIndian                   1360
# 130                 EOG/EOCSubjects_CACR_AmericanIndian                     43
# 131                  EOG/EOCSubjects_GLP_AmericanIndian                     43
# 132                          EOGGr3_CACR_AmericanIndian                   1096
# 133                           EOGGr3_GLP_AmericanIndian                   1096
# 134                          EOGGr4_CACR_AmericanIndian                   1099
# 135                           EOGGr4_GLP_AmericanIndian                   1099
# 136                          EOGGr5_CACR_AmericanIndian                   1122
# 137                           EOGGr5_GLP_AmericanIndian                   1122
# 138                      EOGMathGr3_CACR_AmericanIndian                   1103
# 139                       EOGMathGr3_GLP_AmericanIndian                   1103
# 140                    EOGMathGr3-8_CACR_AmericanIndian                    528
# 141                     EOGMathGr3-8_GLP_AmericanIndian                    528
# 142                      EOGMathGr4_CACR_AmericanIndian                   1108
# 143                       EOGMathGr4_GLP_AmericanIndian                   1108
# 144                      EOGMathGr5_CACR_AmericanIndian                   1134
# 145                       EOGMathGr5_GLP_AmericanIndian                   1134
# 146                   EOGReadingGr3_CACR_AmericanIndian                   1103
# 147                    EOGReadingGr3_GLP_AmericanIndian                   1103
# 148                 EOGReadingGr3-8_CACR_AmericanIndian                    528
# 149                  EOGReadingGr3-8_GLP_AmericanIndian                    528
# 150                   EOGReadingGr4_CACR_AmericanIndian                   1108
# 151                    EOGReadingGr4_GLP_AmericanIndian                   1108
# 152                   EOGReadingGr5_CACR_AmericanIndian                   1134
# 153                    EOGReadingGr5_GLP_AmericanIndian                   1134
# 154                   EOGScienceGr5_CACR_AmericanIndian                   1134
# 155                    EOGScienceGr5_GLP_AmericanIndian                   1134
# 156                 EOGScienceGr5&8_CACR_AmericanIndian                    626
# 157                  EOGScienceGr5&8_GLP_AmericanIndian                    626
# 158                     EOGSubjects_CACR_AmericanIndian                    523
# 159                      EOGSubjects_GLP_AmericanIndian                    523
# 160                                 EOCMathI_CACR_Asian                   1371
# 161                                  EOCMathI_GLP_Asian                   1371
# 162                              EOCSubjects_CACR_Asian                   1360
# 163                               EOCSubjects_GLP_Asian                   1360
# 164                          EOG/EOCSubjects_CACR_Asian                     43
# 165                           EOG/EOCSubjects_GLP_Asian                     43
# 166                                   EOGGr3_CACR_Asian                   1096
# 167                                    EOGGr3_GLP_Asian                   1096
# 168                                   EOGGr4_CACR_Asian                   1099
# 169                                    EOGGr4_GLP_Asian                   1099
# 170                                   EOGGr5_CACR_Asian                   1122
# 171                                    EOGGr5_GLP_Asian                   1122
# 172                               EOGMathGr3_CACR_Asian                   1103
# 173                                EOGMathGr3_GLP_Asian                   1103
# 174                             EOGMathGr3-8_CACR_Asian                    528
# 175                              EOGMathGr3-8_GLP_Asian                    528
# 176                               EOGMathGr4_CACR_Asian                   1108
# 177                                EOGMathGr4_GLP_Asian                   1108
# 178                               EOGMathGr5_CACR_Asian                   1134
# 179                                EOGMathGr5_GLP_Asian                   1134
# 180                            EOGReadingGr3_CACR_Asian                   1103
# 181                             EOGReadingGr3_GLP_Asian                   1103
# 182                          EOGReadingGr3-8_CACR_Asian                    528
# 183                           EOGReadingGr3-8_GLP_Asian                    528
# 184                            EOGReadingGr4_CACR_Asian                   1108
# 185                             EOGReadingGr4_GLP_Asian                   1108
# 186                            EOGReadingGr5_CACR_Asian                   1134
# 187                             EOGReadingGr5_GLP_Asian                   1134
# 188                            EOGScienceGr5_CACR_Asian                   1134
# 189                             EOGScienceGr5_GLP_Asian                   1134
# 190                          EOGScienceGr5&8_CACR_Asian                    626
# 191                           EOGScienceGr5&8_GLP_Asian                    626
# 192                              EOGSubjects_CACR_Asian                    523
# 193                               EOGSubjects_GLP_Asian                    523
# 194                                 EOCMathI_CACR_Black                   1371
# 195                                  EOCMathI_GLP_Black                   1371
# 196                              EOCSubjects_CACR_Black                   1360
# 197                               EOCSubjects_GLP_Black                   1360
# 198                          EOG/EOCSubjects_CACR_Black                     43
# 199                           EOG/EOCSubjects_GLP_Black                     43
# 200                                   EOGGr3_CACR_Black                   1096
# 201                                    EOGGr3_GLP_Black                   1096
# 202                                   EOGGr4_CACR_Black                   1099
# 203                                    EOGGr4_GLP_Black                   1099
# 204                                   EOGGr5_CACR_Black                   1122
# 205                                    EOGGr5_GLP_Black                   1122
# 206                               EOGMathGr3_CACR_Black                   1103
# 207                                EOGMathGr3_GLP_Black                   1103
# 208                             EOGMathGr3-8_CACR_Black                    528
# 209                              EOGMathGr3-8_GLP_Black                    528
# 210                               EOGMathGr4_CACR_Black                   1108
# 211                                EOGMathGr4_GLP_Black                   1108
# 212                               EOGMathGr5_CACR_Black                   1134
# 213                                EOGMathGr5_GLP_Black                   1134
# 214                            EOGReadingGr3_CACR_Black                   1103
# 215                             EOGReadingGr3_GLP_Black                   1103
# 216                          EOGReadingGr3-8_CACR_Black                    528
# 217                           EOGReadingGr3-8_GLP_Black                    528
# 218                            EOGReadingGr4_CACR_Black                   1108
# 219                             EOGReadingGr4_GLP_Black                   1108
# 220                            EOGReadingGr5_CACR_Black                   1134
# 221                             EOGReadingGr5_GLP_Black                   1134
# 222                            EOGScienceGr5_CACR_Black                   1134
# 223                             EOGScienceGr5_GLP_Black                   1134
# 224                          EOGScienceGr5&8_CACR_Black                    626
# 225                           EOGScienceGr5&8_GLP_Black                    626
# 226                              EOGSubjects_CACR_Black                    523
# 227                               EOGSubjects_GLP_Black                    523
# 228                              EOCMathI_CACR_Hispanic                   1371
# 229                               EOCMathI_GLP_Hispanic                   1371
# 230                           EOCSubjects_CACR_Hispanic                   1360
# 231                            EOCSubjects_GLP_Hispanic                   1360
# 232                       EOG/EOCSubjects_CACR_Hispanic                     43
# 233                        EOG/EOCSubjects_GLP_Hispanic                     43
# 234                                EOGGr3_CACR_Hispanic                   1096
# 235                                 EOGGr3_GLP_Hispanic                   1096
# 236                                EOGGr4_CACR_Hispanic                   1099
# 237                                 EOGGr4_GLP_Hispanic                   1099
# 238                                EOGGr5_CACR_Hispanic                   1122
# 239                                 EOGGr5_GLP_Hispanic                   1122
# 240                            EOGMathGr3_CACR_Hispanic                   1103
# 241                             EOGMathGr3_GLP_Hispanic                   1103
# 242                          EOGMathGr3-8_CACR_Hispanic                    528
# 243                           EOGMathGr3-8_GLP_Hispanic                    528
# 244                            EOGMathGr4_CACR_Hispanic                   1108
# 245                             EOGMathGr4_GLP_Hispanic                   1108
# 246                            EOGMathGr5_CACR_Hispanic                   1134
# 247                             EOGMathGr5_GLP_Hispanic                   1134
# 248                         EOGReadingGr3_CACR_Hispanic                   1103
# 249                          EOGReadingGr3_GLP_Hispanic                   1103
# 250                       EOGReadingGr3-8_CACR_Hispanic                    528
# 251                        EOGReadingGr3-8_GLP_Hispanic                    528
# 252                         EOGReadingGr4_CACR_Hispanic                   1108
# 253                          EOGReadingGr4_GLP_Hispanic                   1108
# 254                         EOGReadingGr5_CACR_Hispanic                   1134
# 255                          EOGReadingGr5_GLP_Hispanic                   1134
# 256                         EOGScienceGr5_CACR_Hispanic                   1134
# 257                          EOGScienceGr5_GLP_Hispanic                   1134
# 258                       EOGScienceGr5&8_CACR_Hispanic                    626
# 259                        EOGScienceGr5&8_GLP_Hispanic                    626
# 260                           EOGSubjects_CACR_Hispanic                    523
# 261                            EOGSubjects_GLP_Hispanic                    523
# 262                        EOCMathI_CACR_TwoorMoreRaces                   1371
# 263                         EOCMathI_GLP_TwoorMoreRaces                   1371
# 264                     EOCSubjects_CACR_TwoorMoreRaces                   1360
# 265                      EOCSubjects_GLP_TwoorMoreRaces                   1360
# 266                 EOG/EOCSubjects_CACR_TwoorMoreRaces                     43
# 267                  EOG/EOCSubjects_GLP_TwoorMoreRaces                     43
# 268                          EOGGr3_CACR_TwoorMoreRaces                   1096
# 269                           EOGGr3_GLP_TwoorMoreRaces                   1096
# 270                          EOGGr4_CACR_TwoorMoreRaces                   1099
# 271                           EOGGr4_GLP_TwoorMoreRaces                   1099
# 272                          EOGGr5_CACR_TwoorMoreRaces                   1122
# 273                           EOGGr5_GLP_TwoorMoreRaces                   1122
# 274                      EOGMathGr3_CACR_TwoorMoreRaces                   1103
# 275                       EOGMathGr3_GLP_TwoorMoreRaces                   1103
# 276                    EOGMathGr3-8_CACR_TwoorMoreRaces                    528
# 277                     EOGMathGr3-8_GLP_TwoorMoreRaces                    528
# 278                      EOGMathGr4_CACR_TwoorMoreRaces                   1108
# 279                       EOGMathGr4_GLP_TwoorMoreRaces                   1108
# 280                      EOGMathGr5_CACR_TwoorMoreRaces                   1134
# 281                       EOGMathGr5_GLP_TwoorMoreRaces                   1134
# 282                   EOGReadingGr3_CACR_TwoorMoreRaces                   1103
# 283                    EOGReadingGr3_GLP_TwoorMoreRaces                   1103
# 284                 EOGReadingGr3-8_CACR_TwoorMoreRaces                    528
# 285                  EOGReadingGr3-8_GLP_TwoorMoreRaces                    528
# 286                   EOGReadingGr4_CACR_TwoorMoreRaces                   1108
# 287                    EOGReadingGr4_GLP_TwoorMoreRaces                   1108
# 288                   EOGReadingGr5_CACR_TwoorMoreRaces                   1134
# 289                    EOGReadingGr5_GLP_TwoorMoreRaces                   1134
# 290                   EOGScienceGr5_CACR_TwoorMoreRaces                   1134
# 291                    EOGScienceGr5_GLP_TwoorMoreRaces                   1134
# 292                 EOGScienceGr5&8_CACR_TwoorMoreRaces                    626
# 293                  EOGScienceGr5&8_GLP_TwoorMoreRaces                    626
# 294                     EOGSubjects_CACR_TwoorMoreRaces                    523
# 295                      EOGSubjects_GLP_TwoorMoreRaces                    523
# 296                                 EOCMathI_CACR_White                   1371
# 297                                  EOCMathI_GLP_White                   1371
# 298                              EOCSubjects_CACR_White                   1360
# 299                               EOCSubjects_GLP_White                   1360
# 300                          EOG/EOCSubjects_CACR_White                     43
# 301                           EOG/EOCSubjects_GLP_White                     43
# 302                                   EOGGr3_CACR_White                   1096
# 303                                    EOGGr3_GLP_White                   1096
# 304                                   EOGGr4_CACR_White                   1099
# 305                                    EOGGr4_GLP_White                   1099
# 306                                   EOGGr5_CACR_White                   1122
# 307                                    EOGGr5_GLP_White                   1122
# 308                               EOGMathGr3_CACR_White                   1103
# 309                                EOGMathGr3_GLP_White                   1103
# 310                             EOGMathGr3-8_CACR_White                    528
# 311                              EOGMathGr3-8_GLP_White                    528
# 312                               EOGMathGr4_CACR_White                   1108
# 313                                EOGMathGr4_GLP_White                   1108
# 314                               EOGMathGr5_CACR_White                   1134
# 315                                EOGMathGr5_GLP_White                   1134
# 316                            EOGReadingGr3_CACR_White                   1103
# 317                             EOGReadingGr3_GLP_White                   1103
# 318                          EOGReadingGr3-8_CACR_White                    528
# 319                           EOGReadingGr3-8_GLP_White                    528
# 320                            EOGReadingGr4_CACR_White                   1108
# 321                             EOGReadingGr4_GLP_White                   1108
# 322                            EOGReadingGr5_CACR_White                   1134
# 323                             EOGReadingGr5_GLP_White                   1134
# 324                            EOGScienceGr5_CACR_White                   1134
# 325                             EOGScienceGr5_GLP_White                   1134
# 326                          EOGScienceGr5&8_CACR_White                    626
# 327                           EOGScienceGr5&8_GLP_White                    626
# 328                              EOGSubjects_CACR_White                    523
# 329                               EOGSubjects_GLP_White                    523
# 330                                   EOCMathI_CACR_EDS                   1371
# 331                                    EOCMathI_GLP_EDS                   1371
# 332                                EOCSubjects_CACR_EDS                   1360
# 333                                 EOCSubjects_GLP_EDS                   1360
# 334                            EOG/EOCSubjects_CACR_EDS                     43
# 335                             EOG/EOCSubjects_GLP_EDS                     43
# 336                                     EOGGr3_CACR_EDS                   1096
# 337                                      EOGGr3_GLP_EDS                   1096
# 338                                     EOGGr4_CACR_EDS                   1099
# 339                                      EOGGr4_GLP_EDS                   1099
# 340                                     EOGGr5_CACR_EDS                   1122
# 341                                      EOGGr5_GLP_EDS                   1122
# 342                                 EOGMathGr3_CACR_EDS                   1103
# 343                                  EOGMathGr3_GLP_EDS                   1103
# 344                               EOGMathGr3-8_CACR_EDS                    528
# 345                                EOGMathGr3-8_GLP_EDS                    528
# 346                                 EOGMathGr4_CACR_EDS                   1108
# 347                                  EOGMathGr4_GLP_EDS                   1108
# 348                                 EOGMathGr5_CACR_EDS                   1134
# 349                                  EOGMathGr5_GLP_EDS                   1134
# 350                              EOGReadingGr3_CACR_EDS                   1103
# 351                               EOGReadingGr3_GLP_EDS                   1103
# 352                            EOGReadingGr3-8_CACR_EDS                    528
# 353                             EOGReadingGr3-8_GLP_EDS                    528
# 354                              EOGReadingGr4_CACR_EDS                   1108
# 355                               EOGReadingGr4_GLP_EDS                   1108
# 356                              EOGReadingGr5_CACR_EDS                   1134
# 357                               EOGReadingGr5_GLP_EDS                   1134
# 358                              EOGScienceGr5_CACR_EDS                   1134
# 359                               EOGScienceGr5_GLP_EDS                   1134
# 360                            EOGScienceGr5&8_CACR_EDS                    626
# 361                             EOGScienceGr5&8_GLP_EDS                    626
# 362                                EOGSubjects_CACR_EDS                    523
# 363                                 EOGSubjects_GLP_EDS                    523
# 364                                   EOCMathI_CACR_LEP                   1371
# 365                                    EOCMathI_GLP_LEP                   1371
# 366                                EOCSubjects_CACR_LEP                   1360
# 367                                 EOCSubjects_GLP_LEP                   1360
# 368                            EOG/EOCSubjects_CACR_LEP                     43
# 369                             EOG/EOCSubjects_GLP_LEP                     43
# 370                                     EOGGr3_CACR_LEP                   1096
# 371                                      EOGGr3_GLP_LEP                   1096
# 372                                     EOGGr4_CACR_LEP                   1099
# 373                                      EOGGr4_GLP_LEP                   1099
# 374                                     EOGGr5_CACR_LEP                   1122
# 375                                      EOGGr5_GLP_LEP                   1122
# 376                                 EOGMathGr3_CACR_LEP                   1103
# 377                                  EOGMathGr3_GLP_LEP                   1103
# 378                               EOGMathGr3-8_CACR_LEP                    528
# 379                                EOGMathGr3-8_GLP_LEP                    528
# 380                                 EOGMathGr4_CACR_LEP                   1108
# 381                                  EOGMathGr4_GLP_LEP                   1108
# 382                                 EOGMathGr5_CACR_LEP                   1134
# 383                                  EOGMathGr5_GLP_LEP                   1134
# 384                              EOGReadingGr3_CACR_LEP                   1103
# 385                               EOGReadingGr3_GLP_LEP                   1103
# 386                            EOGReadingGr3-8_CACR_LEP                    528
# 387                             EOGReadingGr3-8_GLP_LEP                    528
# 388                              EOGReadingGr4_CACR_LEP                   1108
# 389                               EOGReadingGr4_GLP_LEP                   1108
# 390                              EOGReadingGr5_CACR_LEP                   1134
# 391                               EOGReadingGr5_GLP_LEP                   1134
# 392                              EOGScienceGr5_CACR_LEP                   1134
# 393                               EOGScienceGr5_GLP_LEP                   1134
# 394                            EOGScienceGr5&8_CACR_LEP                    626
# 395                             EOGScienceGr5&8_GLP_LEP                    626
# 396                                EOGSubjects_CACR_LEP                    523
# 397                                 EOGSubjects_GLP_LEP                    523
# 398                                   EOCMathI_CACR_SWD                   1371
# 399                                    EOCMathI_GLP_SWD                   1371
# 400                                EOCSubjects_CACR_SWD                   1360
# 401                                 EOCSubjects_GLP_SWD                   1360
# 402                            EOG/EOCSubjects_CACR_SWD                     43
# 403                             EOG/EOCSubjects_GLP_SWD                     43
# 404                                     EOGGr3_CACR_SWD                   1096
# 405                                      EOGGr3_GLP_SWD                   1096
# 406                                     EOGGr4_CACR_SWD                   1099
# 407                                      EOGGr4_GLP_SWD                   1099
# 408                                     EOGGr5_CACR_SWD                   1122
# 409                                      EOGGr5_GLP_SWD                   1122
# 410                                 EOGMathGr3_CACR_SWD                   1103
# 411                                  EOGMathGr3_GLP_SWD                   1103
# 412                               EOGMathGr3-8_CACR_SWD                    528
# 413                                EOGMathGr3-8_GLP_SWD                    528
# 414                                 EOGMathGr4_CACR_SWD                   1108
# 415                                  EOGMathGr4_GLP_SWD                   1108
# 416                                 EOGMathGr5_CACR_SWD                   1134
# 417                                  EOGMathGr5_GLP_SWD                   1134
# 418                              EOGReadingGr3_CACR_SWD                   1103
# 419                               EOGReadingGr3_GLP_SWD                   1103
# 420                            EOGReadingGr3-8_CACR_SWD                    528
# 421                             EOGReadingGr3-8_GLP_SWD                    528
# 422                              EOGReadingGr4_CACR_SWD                   1108
# 423                               EOGReadingGr4_GLP_SWD                   1108
# 424                              EOGReadingGr5_CACR_SWD                   1134
# 425                               EOGReadingGr5_GLP_SWD                   1134
# 426                              EOGScienceGr5_CACR_SWD                   1134
# 427                               EOGScienceGr5_GLP_SWD                   1134
# 428                            EOGScienceGr5&8_CACR_SWD                    626
# 429                             EOGScienceGr5&8_GLP_SWD                    626
# 430                                EOGSubjects_CACR_SWD                    523
# 431                                 EOGSubjects_GLP_SWD                    523
# 432                                   EOCMathI_CACR_AIG                   1371
# 433                                    EOCMathI_GLP_AIG                   1371
# 434                                EOCSubjects_CACR_AIG                   1360
# 435                                 EOCSubjects_GLP_AIG                   1360
# 436                            EOG/EOCSubjects_CACR_AIG                     43
# 437                             EOG/EOCSubjects_GLP_AIG                     43
# 438                                     EOGGr3_CACR_AIG                   1096
# 439                                      EOGGr3_GLP_AIG                   1096
# 440                                     EOGGr4_CACR_AIG                   1099
# 441                                      EOGGr4_GLP_AIG                   1099
# 442                                     EOGGr5_CACR_AIG                   1122
# 443                                      EOGGr5_GLP_AIG                   1122
# 444                                 EOGMathGr3_CACR_AIG                   1103
# 445                                  EOGMathGr3_GLP_AIG                   1103
# 446                               EOGMathGr3-8_CACR_AIG                    528
# 447                                EOGMathGr3-8_GLP_AIG                    528
# 448                                 EOGMathGr4_CACR_AIG                   1108
# 449                                  EOGMathGr4_GLP_AIG                   1108
# 450                                 EOGMathGr5_CACR_AIG                   1134
# 451                                  EOGMathGr5_GLP_AIG                   1134
# 452                              EOGReadingGr3_CACR_AIG                   1103
# 453                               EOGReadingGr3_GLP_AIG                   1103
# 454                            EOGReadingGr3-8_CACR_AIG                    528
# 455                             EOGReadingGr3-8_GLP_AIG                    528
# 456                              EOGReadingGr4_CACR_AIG                   1108
# 457                               EOGReadingGr4_GLP_AIG                   1108
# 458                              EOGReadingGr5_CACR_AIG                   1134
# 459                               EOGReadingGr5_GLP_AIG                   1134
# 460                              EOGScienceGr5_CACR_AIG                   1134
# 461                               EOGScienceGr5_GLP_AIG                   1134
# 462                            EOGScienceGr5&8_CACR_AIG                    626
# 463                             EOGScienceGr5&8_GLP_AIG                    626
# 464                                EOGSubjects_CACR_AIG                    523
# 465                                 EOGSubjects_GLP_AIG                    523
# 466                                         pct_GCE_ALL                   1085
# 467                                      pct_PASSED_EOG                   1115
# 468                                        pct_PROMOTED                   1106
# 469                            MathGr3-8_pTarget_PctMet                    574
# 470                         ReadingGr3-8_pTarget_PctMet                    574
# 471                             SciGr5&8_pTarget_PctMet                    727
# 472                         TotalTargets_pTarget_PctMet                     62
# 475                            lea_ap_participation_pct                    473
# 476                               lea_ap_pct_3_or_above                     24
# 477                               lea_ib_pct_4_or_above                   1452
# 483                              stud_internet_comp_num                      4
# 484                            lea_avg_daily_attend_pct                      3
# 485                                 lea_crime_per_c_num                      3
# 486                            lea_short_susp_per_c_num                      3
# 487                             lea_long_susp_per_c_num                      3
# 488                              lea_expelled_per_c_num                      3
# 489                          lea_stud_internet_comp_num                      3
# 490                             st_avg_daily_attend_pct                      3
# 491                                  st_crime_per_c_num                      3
# 492                             st_short_susp_per_c_num                      3
# 493                              st_long_susp_per_c_num                      3
# 494                               st_expelled_per_c_num                      3
# 495                           st_stud_internet_comp_num                      3
# 496                                 flicensed_teach_pct                      1
# 497                                   tchyrs_0thru3_pct                      1
# 498                                  tchyrs_4thru10_pct                      1
# 499                                   tchyrs_11plus_pct                      1
# 500                                     class_teach_num                      1
# 501                                           nbpts_num                    167
# 502                                     advance_dgr_pct                      1
# 503                                _1yr_tchr_trnovr_pct                     16
# 504                                   lateral_teach_pct                   1357
# 505                             lea_flicensed_teach_pct                      3
# 506                               lea_tchyrs_0thru3_pct                      3
# 507                              lea_tchyrs_4thru10_pct                      3
# 508                               lea_tchyrs_11plus_pct                      3
# 509                                 lea_class_teach_num                      3
# 510                                       lea_nbpts_num                     36
# 511                                 lea_advance_dgr_pct                      3
# 512                             lea_1yr_tchr_trnovr_pct                      6
# 513                             lea_emer_prov_teach_pct                    819
# 514                               lea_lateral_teach_pct                    264
# 515                              st_flicensed_teach_pct                      3
# 516                                st_tchyrs_0thru3_pct                      3
# 517                               st_tchyrs_4thru10_pct                      3
# 518                                st_tchyrs_11plus_pct                      3
# 519                                  st_class_teach_num                      3
# 520                                        st_nbpts_num                      3
# 521                                  st_advance_dgr_pct                      3
# 522                              st_1yr_tchr_trnovr_pct                      3
# 523                              st_emer_prov_teach_pct                      3
# 524                                st_lateral_teach_pct                      3
# 525                               st_prinyrs_0thru3_pct                      3
# 526                              st_prinyrs_4thru10_pct                      3
# 527                               st_prinyrs_11plus_pct                      3
# 528                             st_prin_advance_dgr_pct                      3
# 529                              st_1yr_prin_trnovr_pct                      3
# 530                                    st_prin_male_pct                      3
# 531                                  st_prin_female_pct                      3
# 532                                   st_prin_black_pct                      3
# 533                                   st_prin_white_pct                      3
# 534                                   st_prin_other_pct                      3
# 535                               0-3 Years_Exp_Pct_Tch                      1
# 536                               10+ Years_Exp_Pct_Tch                      1
# 537                              4-10 Years_Exp_Pct_Tch                      1
# 538                          0-3 Years_LEA_Exp_Pct_Prin                      3
# 539                          10+ Years_LEA_Exp_Pct_Prin                      3
# 540                         4-10 Years_LEA_Exp_Pct_Prin                      3
# 541                    Accomplished_TCHR_Standard 1_Pct                     81
# 542                    Accomplished_TCHR_Standard 2_Pct                     81
# 543                    Accomplished_TCHR_Standard 3_Pct                     81
# 544                    Accomplished_TCHR_Standard 4_Pct                     81
# 545                    Accomplished_TCHR_Standard 5_Pct                     81
# 546                      Developing_TCHR_Standard 1_Pct                     81
# 547                      Developing_TCHR_Standard 2_Pct                     81
# 548                      Developing_TCHR_Standard 3_Pct                     81
# 549                      Developing_TCHR_Standard 4_Pct                     81
# 550                      Developing_TCHR_Standard 5_Pct                     81
# 551                   Distinguished_TCHR_Standard 1_Pct                     81
# 552                   Distinguished_TCHR_Standard 2_Pct                     81
# 553                   Distinguished_TCHR_Standard 3_Pct                     81
# 554                   Distinguished_TCHR_Standard 4_Pct                     81
# 555                   Distinguished_TCHR_Standard 5_Pct                     81
# 556   Does Not Meet Expected Growth_TCHR_Standard 6_Pct                     81
# 557         Exceeds Expected Growth_TCHR_Standard 6_Pct                     81
# 558           Meets Expected Growth_TCHR_Standard 6_Pct                     81
# 559                 Not Demostrated_TCHR_Standard 1_Pct                     81
# 560                 Not Demostrated_TCHR_Standard 2_Pct                     81
# 561                 Not Demostrated_TCHR_Standard 3_Pct                     81
# 562                 Not Demostrated_TCHR_Standard 4_Pct                     81
# 563                 Not Demostrated_TCHR_Standard 5_Pct                     81
# 564                      Proficient_TCHR_Standard 1_Pct                     81
# 565                      Proficient_TCHR_Standard 2_Pct                     81
# 566                      Proficient_TCHR_Standard 3_Pct                     81
# 567                      Proficient_TCHR_Standard 4_Pct                     81
# 568                      Proficient_TCHR_Standard 5_Pct                     81
# 593                                                Year                     11
# 594                               Crime_Rate_Index_Rate                     73
# 595                             Crime_Rate_Violent_Rate                     73
# 596                            Crime_Rate_Property_Rate                     73
# 597                              Crime_Rate_Murder_Rate                    187
# 598                                Crime_Rate_Rape_Rate                    100
# 599                             Crime_Rate_Robbery_Rate                     96
# 600                             Crime_Rate_Assault_Rate                     73
# 601                            Crime_Rate_Burglary_Rate                     73
# 602                             Crime_Rate_Larceny_Rate                     73
# 603                                 Crime_Rate_MVT_Rate                     73
# 604                               Crime_Rate_Arson_Rate                    124
# 1321                                            LEACode                    225
# 1322                Attrtion_Reason_RemainedinEducation                    225
# 1323           Attrtion_Reason_RemainedinEducationPerct                    225
# 1324                    Attrtion_Reason_PersonalReasons                    225
# 1325                      Attrtion_Reason_PersonalPerct                    225
# 1326                     Attrtion_Reason_InitiatedbyLEA                    225
# 1327                     Attrtion_Reason_InitiatedPerct                    225
# 1328                 Attrtion_Reason_BeyondControlofLEA                    225
# 1329                 Attrtion_Reason_BeyondControlPerct                    225
# 1330                       Attrtion_Reason_OtherReasons                    225
# 1331                  Attrtion_Reason_OtherReasonsPerct                    225

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  184577  field correlations > 95%.
#                                                    Field1  \
# 0                                         class_teach_num
# 1                                     lea_class_teach_num
# 2                                      st_class_teach_num
# 3                               Overall Achievement Score
# 4                                          Math SPG Score
# 5                                              Read Score
# 6                                              Math Score
# 7                                EOGReadingGr3-8_CACR_All
# 8                                 EOGReadingGr3-8_GLP_All
# 9                                    EOGSubjects_CACR_All
# 10                                    EOGSubjects_GLP_All
# 11                            EOGReadingGr3-8_CACR_Female
# 12                             EOGReadingGr3-8_GLP_Female
# 13                                EOGSubjects_CACR_Female
# 14                                 EOGSubjects_GLP_Female
# 15                               EOGReadingGr3-8_GLP_Male
# 16                                   EOGSubjects_GLP_Male
# 17                                             Read Score
# 18                                             Math Score
# 19                                  EOGMathGr3-8_CACR_All
# 20                                   EOGMathGr3-8_GLP_All
# 21                                EOGReadingGr3-8_GLP_All
# 22                                   EOGSubjects_CACR_All
# 23                                    EOGSubjects_GLP_All
# 24                               EOGMathGr3-8_CACR_Female
# 25                                EOGMathGr3-8_GLP_Female
# 26                                EOGSubjects_CACR_Female
# 27                                 EOGSubjects_GLP_Female
# 28                                 EOGMathGr3-8_CACR_Male
# 29                                  EOGMathGr3-8_GLP_Male
# 30                                  EOGSubjects_CACR_Male
# 31                                   EOGSubjects_GLP_Male
# 32                                             Math Score
# 33                                   EOGMathGr3-8_GLP_All
# 34                               EOGReadingGr3-8_CACR_All
# 35                                EOGReadingGr3-8_GLP_All
# 36                                   EOGSubjects_CACR_All
# 37                                    EOGSubjects_GLP_All
# 38                            EOGReadingGr3-8_CACR_Female
# 39                             EOGReadingGr3-8_GLP_Female
# 40                                EOGSubjects_CACR_Female
# 41                                 EOGSubjects_GLP_Female
# 42                              EOGReadingGr3-8_CACR_Male
# 43                               EOGReadingGr3-8_GLP_Male
# 44                                  EOGSubjects_CACR_Male
# 45                                   EOGSubjects_GLP_Male
# 46                                  EOGMathGr3-8_CACR_All
# 47                                   EOGMathGr3-8_GLP_All
# 48                                   EOGSubjects_CACR_All
# 49                                    EOGSubjects_GLP_All
# 50                               EOGMathGr3-8_CACR_Female
# 51                                EOGMathGr3-8_GLP_Female
# 52                                EOGSubjects_CACR_Female
# 53                                 EOGSubjects_GLP_Female
# 54                                 EOGMathGr3-8_CACR_Male
# 55                                  EOGMathGr3-8_GLP_Male
# 56                                  EOGSubjects_CACR_Male
# 57                                   EOGSubjects_GLP_Male
# 58                               EOGScienceGr5&8_CACR_All
# 59                                EOGScienceGr5&8_GLP_All
# 60                            EOGScienceGr5&8_CACR_Female
# 61                             EOGScienceGr5&8_GLP_Female
# 62                              EOGScienceGr5&8_CACR_Male
# 63                               EOGScienceGr5&8_GLP_Male
# 64                                EOGScienceGr5&8_GLP_EDS
# 65                                      EOCMathI_CACR_All
# 66                                       EOCMathI_GLP_All
# 67                                   EOCSubjects_CACR_All
# 68                                    EOCSubjects_GLP_All
# 69                                   EOCMathI_CACR_Female
# 70                                    EOCMathI_GLP_Female
# 71                                EOCSubjects_CACR_Female
# 72                                 EOCSubjects_GLP_Female
# 73                                     EOCMathI_CACR_Male
# 74                                      EOCMathI_GLP_Male
# 75                                  EOCSubjects_CACR_Male
# 76                                   EOCSubjects_GLP_Male
# 77                                       EOCMathI_GLP_All
# 78                                   EOCSubjects_CACR_All
# 79                                    EOCSubjects_GLP_All
# 80                                   EOCMathI_CACR_Female
# 81                                    EOCMathI_GLP_Female
# 82                                EOCSubjects_CACR_Female
# 83                                 EOCSubjects_GLP_Female
# 84                                     EOCMathI_CACR_Male
# 85                                  EOCSubjects_CACR_Male
# 86                                    EOCMathI_CACR_White
# 87                                   EOCSubjects_CACR_All
# 88                                    EOCSubjects_GLP_All
# 89                                   EOCMathI_CACR_Female
# 90                                    EOCMathI_GLP_Female
# 91                                EOCSubjects_CACR_Female
# 92                                 EOCSubjects_GLP_Female
# 93                                     EOCMathI_CACR_Male
# 94                                      EOCMathI_GLP_Male
# 95                                  EOCSubjects_CACR_Male
# 96                                   EOCSubjects_GLP_Male
# 97                                    EOCSubjects_GLP_All
# 98                                   EOCMathI_CACR_Female
# 99                                    EOCMathI_GLP_Female
# 100                               EOCSubjects_CACR_Female
# 101                                EOCSubjects_GLP_Female
# 102                                    EOCMathI_CACR_Male
# 103                                 EOCSubjects_CACR_Male
# 104                                  EOCSubjects_GLP_Male
# 105                                   EOCMathI_CACR_White
# 106                                EOCSubjects_CACR_White
# 107                                   EOCMathI_GLP_Female
# 108                               EOCSubjects_CACR_Female
# 109                                EOCSubjects_GLP_Female
# 110                                     EOCMathI_GLP_Male
# 111                                 EOCSubjects_CACR_Male
# 112                                  EOCSubjects_GLP_Male
# 113                                 EOCSubjects_GLP_White
# 114                               EOG/EOCSubjects_GLP_All
# 115                           EOG/EOCSubjects_CACR_Female
# 116                            EOG/EOCSubjects_GLP_Female
# 117                             EOG/EOCSubjects_CACR_Male
# 118                              EOG/EOCSubjects_GLP_Male
# 119                           EOG/EOCSubjects_CACR_Female
# 120                            EOG/EOCSubjects_GLP_Female
# 121                             EOG/EOCSubjects_CACR_Male
# 122                              EOG/EOCSubjects_GLP_Male
# 123                                        EOGGr3_GLP_All
# 124                                   EOGMathGr3_CACR_All
# 125                                    EOGMathGr3_GLP_All
# 126                                EOGReadingGr3_CACR_All
# 127                                 EOGReadingGr3_GLP_All
# 128                                    EOGGr3_CACR_Female
# 129                                     EOGGr3_GLP_Female
# 130                                EOGMathGr3_CACR_Female
# 131                                 EOGMathGr3_GLP_Female
# 132                             EOGReadingGr3_CACR_Female
# 133                              EOGReadingGr3_GLP_Female
# 134                                      EOGGr3_CACR_Male
# 135                                       EOGGr3_GLP_Male
# 136                                  EOGMathGr3_CACR_Male
# 137                                   EOGMathGr3_GLP_Male
# 138                               EOGReadingGr3_CACR_Male
# 139                                EOGReadingGr3_GLP_Male
# 140                                       EOGGr3_CACR_EDS
# 141                                        pct_PASSED_EOG
# 142                                   EOGMathGr3_CACR_All
# 143                                    EOGMathGr3_GLP_All
# 144                                EOGReadingGr3_CACR_All
# 145                                 EOGReadingGr3_GLP_All
# 146                                    EOGGr3_CACR_Female
# 147                                     EOGGr3_GLP_Female
# 148                                EOGMathGr3_CACR_Female
# 149                                 EOGMathGr3_GLP_Female
# 150                             EOGReadingGr3_CACR_Female
# 151                              EOGReadingGr3_GLP_Female
# 152                                      EOGGr3_CACR_Male
# 153                                       EOGGr3_GLP_Male
# 154                                  EOGMathGr3_CACR_Male
# 155                                   EOGMathGr3_GLP_Male
# 156                               EOGReadingGr3_CACR_Male
# 157                                EOGReadingGr3_GLP_Male
# 158                                      EOGGr3_GLP_White
# 159                                       EOGGr3_CACR_EDS
# 160                                        EOGGr3_GLP_EDS
# 161                                    EOGMathGr3_GLP_EDS
# 162                                 EOGReadingGr3_GLP_EDS
# 163                                        pct_PASSED_EOG
# 164                                        EOGGr4_GLP_All
# 165                                   EOGMathGr4_CACR_All
# 166                                    EOGMathGr4_GLP_All
# 167                                EOGReadingGr4_CACR_All
# 168                                 EOGReadingGr4_GLP_All
# 169                                    EOGGr4_CACR_Female
# 170                                     EOGGr4_GLP_Female
# 171                                EOGMathGr4_CACR_Female
# 172                                 EOGMathGr4_GLP_Female
# 173                             EOGReadingGr4_CACR_Female
# 174                              EOGReadingGr4_GLP_Female
# 175                                      EOGGr4_CACR_Male
# 176                                       EOGGr4_GLP_Male
# 177                                  EOGMathGr4_CACR_Male
# 178                                   EOGMathGr4_GLP_Male
# 179                               EOGReadingGr4_CACR_Male
# 180                                EOGReadingGr4_GLP_Male
# 181                                   EOGMathGr4_CACR_All
# 182                                    EOGMathGr4_GLP_All
# 183                                EOGReadingGr4_CACR_All
# 184                                 EOGReadingGr4_GLP_All
# 185                                    EOGGr4_CACR_Female
# 186                                     EOGGr4_GLP_Female
# 187                                EOGMathGr4_CACR_Female
# 188                                 EOGMathGr4_GLP_Female
# 189                             EOGReadingGr4_CACR_Female
# 190                              EOGReadingGr4_GLP_Female
# 191                                      EOGGr4_CACR_Male
# 192                                       EOGGr4_GLP_Male
# 193                                  EOGMathGr4_CACR_Male
# 194                                   EOGMathGr4_GLP_Male
# 195                               EOGReadingGr4_CACR_Male
# 196                                EOGReadingGr4_GLP_Male
# 197                                        EOGGr4_GLP_EDS
# 198                                        EOGGr5_GLP_All
# 199                                   EOGMathGr5_CACR_All
# 200                                    EOGMathGr5_GLP_All
# 201                                EOGReadingGr5_CACR_All
# 202                                 EOGReadingGr5_GLP_All
# 203                                EOGScienceGr5_CACR_All
# 204                                 EOGScienceGr5_GLP_All
# 205                                    EOGGr5_CACR_Female
# 206                                     EOGGr5_GLP_Female
# 207                                EOGMathGr5_CACR_Female
# 208                                 EOGMathGr5_GLP_Female
# 209                             EOGReadingGr5_CACR_Female
# 210                              EOGReadingGr5_GLP_Female
# 211                             EOGScienceGr5_CACR_Female
# 212                              EOGScienceGr5_GLP_Female
# 213                                      EOGGr5_CACR_Male
# 214                                       EOGGr5_GLP_Male
# 215                                  EOGMathGr5_CACR_Male
# 216                                   EOGMathGr5_GLP_Male
# 217                               EOGReadingGr5_CACR_Male
# 218                                EOGReadingGr5_GLP_Male
# 219                               EOGScienceGr5_CACR_Male
# 220                                EOGScienceGr5_GLP_Male
# 221                                     EOGGr5_CACR_White
# 222                                       EOGGr5_CACR_EDS
# 223                                        EOGGr5_GLP_EDS
# 224                                   EOGMathGr5_CACR_All
# 225                                    EOGMathGr5_GLP_All
# 226                                EOGReadingGr5_CACR_All
# 227                                 EOGReadingGr5_GLP_All
# 228                                EOGScienceGr5_CACR_All
# 229                                 EOGScienceGr5_GLP_All
# 230                                    EOGGr5_CACR_Female
# 231                                     EOGGr5_GLP_Female
# 232                                EOGMathGr5_CACR_Female
# 233                                 EOGMathGr5_GLP_Female
# 234                              EOGReadingGr5_GLP_Female
# 235                             EOGScienceGr5_CACR_Female
# 236                              EOGScienceGr5_GLP_Female
# 237                                      EOGGr5_CACR_Male
# 238                                       EOGGr5_GLP_Male
# 239                                  EOGMathGr5_CACR_Male
# 240                                   EOGMathGr5_GLP_Male
# 241                                EOGReadingGr5_GLP_Male
# 242                               EOGScienceGr5_CACR_Male
# 243                                EOGScienceGr5_GLP_Male
# 244                                     EOGGr5_CACR_White
# 245                                      EOGGr5_GLP_White
# 246                                       EOGGr5_CACR_EDS
# 247                                        EOGGr5_GLP_EDS
# 248                                    EOGMathGr3_GLP_All
# 249                                EOGReadingGr3_CACR_All
# 250                                 EOGReadingGr3_GLP_All
# 251                                    EOGGr3_CACR_Female
# 252                                     EOGGr3_GLP_Female
# 253                                EOGMathGr3_CACR_Female
# 254                                 EOGMathGr3_GLP_Female
# 255                                      EOGGr3_CACR_Male
# 256                                       EOGGr3_GLP_Male
# 257                                  EOGMathGr3_CACR_Male
# 258                                   EOGMathGr3_GLP_Male
# 259                                EOGReadingGr3_GLP_Male
# 260                                        pct_PASSED_EOG
# 261                                EOGReadingGr3_CACR_All
# 262                                 EOGReadingGr3_GLP_All
# 263                                    EOGGr3_CACR_Female
# 264                                     EOGGr3_GLP_Female
# 265                                EOGMathGr3_CACR_Female
# 266                                 EOGMathGr3_GLP_Female
# 267                             EOGReadingGr3_CACR_Female
# 268                              EOGReadingGr3_GLP_Female
# 269                                      EOGGr3_CACR_Male
# 270                                       EOGGr3_GLP_Male
# 271                                  EOGMathGr3_CACR_Male
# 272                                   EOGMathGr3_GLP_Male
# 273                                EOGReadingGr3_GLP_Male
# 274                                       EOGGr3_CACR_EDS
# 275                                        EOGGr3_GLP_EDS
# 276                                    EOGMathGr3_GLP_EDS
# 277                                        pct_PASSED_EOG
# 278                                  EOGMathGr3-8_GLP_All
# 279                                  EOGSubjects_CACR_All
# 280                                   EOGSubjects_GLP_All
# 281                              EOGMathGr3-8_CACR_Female
# 282                               EOGMathGr3-8_GLP_Female
# 283                               EOGSubjects_CACR_Female
# 284                                EOGSubjects_GLP_Female
# 285                                EOGMathGr3-8_CACR_Male
# 286                                 EOGMathGr3-8_GLP_Male
# 287                                 EOGSubjects_CACR_Male
# 288                                  EOGSubjects_GLP_Male
# 289                               EOGReadingGr3-8_GLP_All
# 290                                  EOGSubjects_CACR_All
# 291                                   EOGSubjects_GLP_All
# 292                              EOGMathGr3-8_CACR_Female
# 293                               EOGMathGr3-8_GLP_Female
# 294                               EOGSubjects_CACR_Female
# 295                                EOGSubjects_GLP_Female
# 296                                EOGMathGr3-8_CACR_Male
# 297                                 EOGMathGr3-8_GLP_Male
# 298                                 EOGSubjects_CACR_Male
# 299                                  EOGSubjects_GLP_Male
# 300                                  EOGMathGr3-8_GLP_EDS
# 301                                    EOGMathGr4_GLP_All
# 302                                EOGReadingGr4_CACR_All
# 303                                 EOGReadingGr4_GLP_All
# 304                                    EOGGr4_CACR_Female
# 305                                     EOGGr4_GLP_Female
# 306                                EOGMathGr4_CACR_Female
# 307                                 EOGMathGr4_GLP_Female
# 308                                      EOGGr4_CACR_Male
# 309                                       EOGGr4_GLP_Male
# 310                                  EOGMathGr4_CACR_Male
# 311                                   EOGMathGr4_GLP_Male
# 312                                EOGReadingGr4_CACR_All
# 313                                 EOGReadingGr4_GLP_All
# 314                                    EOGGr4_CACR_Female
# 315                                     EOGGr4_GLP_Female
# 316                                EOGMathGr4_CACR_Female
# 317                                 EOGMathGr4_GLP_Female
# 318                                      EOGGr4_CACR_Male
# 319                                       EOGGr4_GLP_Male
# 320                                  EOGMathGr4_CACR_Male
# 321                                   EOGMathGr4_GLP_Male
# 322                                EOGReadingGr4_GLP_Male
# 323                                    EOGMathGr5_GLP_All
# 324                                EOGReadingGr5_CACR_All
# 325                                 EOGReadingGr5_GLP_All
# 326                                EOGScienceGr5_CACR_All
# 327                                 EOGScienceGr5_GLP_All
# 328                                    EOGGr5_CACR_Female
# 329                                     EOGGr5_GLP_Female
# 330                                EOGMathGr5_CACR_Female
# 331                                 EOGMathGr5_GLP_Female
# 332                              EOGReadingGr5_GLP_Female
# 333                                      EOGGr5_CACR_Male
# 334                                       EOGGr5_GLP_Male
# 335                                  EOGMathGr5_CACR_Male
# 336                                   EOGMathGr5_GLP_Male
# 337                                EOGReadingGr5_GLP_Male
# 338                                EOGScienceGr5_GLP_Male
# 339                                EOGReadingGr5_CACR_All
# 340                                 EOGReadingGr5_GLP_All
# 341                                EOGScienceGr5_CACR_All
# 342                                 EOGScienceGr5_GLP_All
# 343                                    EOGGr5_CACR_Female
# 344                                     EOGGr5_GLP_Female
# 345                                EOGMathGr5_CACR_Female
# 346                                 EOGMathGr5_GLP_Female
# 347                              EOGReadingGr5_GLP_Female
# 348                              EOGScienceGr5_GLP_Female
# 349                                      EOGGr5_CACR_Male
# 350                                       EOGGr5_GLP_Male
# 351                                  EOGMathGr5_CACR_Male
# 352                                   EOGMathGr5_GLP_Male
# 353                                EOGReadingGr5_GLP_Male
# 354                               EOGScienceGr5_CACR_Male
# 355                                EOGScienceGr5_GLP_Male
# 356                                        EOGGr5_GLP_EDS
# 357                                    EOGMathGr5_GLP_EDS
# 358                                 EOGReadingGr3_GLP_All
# 359                                    EOGGr3_CACR_Female
# 360                                     EOGGr3_GLP_Female
# 361                                 EOGMathGr3_GLP_Female
# 362                             EOGReadingGr3_CACR_Female
# 363                              EOGReadingGr3_GLP_Female
# 364                                      EOGGr3_CACR_Male
# 365                                       EOGGr3_GLP_Male
# 366                                   EOGMathGr3_GLP_Male
# 367                               EOGReadingGr3_CACR_Male
# 368                                EOGReadingGr3_GLP_Male
# 369                                        pct_PASSED_EOG
# 370                                    EOGGr3_CACR_Female
# 371                                     EOGGr3_GLP_Female
# 372                                 EOGMathGr3_GLP_Female
# 373                             EOGReadingGr3_CACR_Female
# 374                              EOGReadingGr3_GLP_Female
# 375                                      EOGGr3_CACR_Male
# 376                                       EOGGr3_GLP_Male
# 377                                   EOGMathGr3_GLP_Male
# 378                               EOGReadingGr3_CACR_Male
# 379                                EOGReadingGr3_GLP_Male
# 380                                        EOGGr3_GLP_EDS
# 381                                 EOGReadingGr3_GLP_EDS
# 382                                        pct_PASSED_EOG
# 383                               EOGReadingGr3-8_GLP_All
# 384                                  EOGSubjects_CACR_All
# 385                                   EOGSubjects_GLP_All
# 386                           EOGReadingGr3-8_CACR_Female
# 387                            EOGReadingGr3-8_GLP_Female
# 388                               EOGSubjects_CACR_Female
# 389                                EOGSubjects_GLP_Female
# 390                             EOGReadingGr3-8_CACR_Male
# 391                              EOGReadingGr3-8_GLP_Male
# 392                                 EOGSubjects_CACR_Male
# 393                                  EOGSubjects_GLP_Male
# 394                                  EOGSubjects_CACR_All
# 395                                   EOGSubjects_GLP_All
# 396                           EOGReadingGr3-8_CACR_Female
# 397                            EOGReadingGr3-8_GLP_Female
# 398                               EOGSubjects_CACR_Female
# 399                                EOGSubjects_GLP_Female
# 400                             EOGReadingGr3-8_CACR_Male
# 401                              EOGReadingGr3-8_GLP_Male
# 402                                 EOGSubjects_CACR_Male
# 403                                  EOGSubjects_GLP_Male
# 404                               EOGReadingGr3-8_GLP_EDS
# 405                                 EOGReadingGr4_GLP_All
# 406                                    EOGGr4_CACR_Female
# 407                                     EOGGr4_GLP_Female
# 408                             EOGReadingGr4_CACR_Female
# 409                              EOGReadingGr4_GLP_Female
# 410                                      EOGGr4_CACR_Male
# 411                                       EOGGr4_GLP_Male
# 412                                   EOGMathGr4_GLP_Male
# 413                               EOGReadingGr4_CACR_Male
# 414                                EOGReadingGr4_GLP_Male
# 415                                    EOGGr4_CACR_Female
# 416                                     EOGGr4_GLP_Female
# 417                             EOGReadingGr4_CACR_Female
# 418                              EOGReadingGr4_GLP_Female
# 419                                      EOGGr4_CACR_Male
# 420                                       EOGGr4_GLP_Male
# 421                                   EOGMathGr4_GLP_Male
# 422                               EOGReadingGr4_CACR_Male
# 423                                EOGReadingGr4_GLP_Male
# 424                                 EOGReadingGr5_GLP_All
# 425                                    EOGGr5_CACR_Female
# 426                                     EOGGr5_GLP_Female
# 427                             EOGReadingGr5_CACR_Female
# 428                              EOGReadingGr5_GLP_Female
# 429                                      EOGGr5_CACR_Male
# 430                                       EOGGr5_GLP_Male
# 431                               EOGReadingGr5_CACR_Male
# 432                                EOGReadingGr5_GLP_Male
# 433                                EOGScienceGr5_CACR_All
# 434                                 EOGScienceGr5_GLP_All
# 435                                    EOGGr5_CACR_Female
# 436                                     EOGGr5_GLP_Female
# 437                             EOGReadingGr5_CACR_Female
# 438                              EOGReadingGr5_GLP_Female
# 439                              EOGScienceGr5_GLP_Female
# 440                                      EOGGr5_CACR_Male
# 441                                       EOGGr5_GLP_Male
# 442                                   EOGMathGr5_GLP_Male
# 443                               EOGReadingGr5_CACR_Male
# 444                                EOGReadingGr5_GLP_Male
# 445                               EOGScienceGr5_CACR_Male
# 446                                EOGScienceGr5_GLP_Male
# 447                                      EOGGr5_GLP_White
# 448                                 EOGReadingGr5_GLP_EDS
# 449                                 EOGScienceGr5_GLP_All
# 450                                    EOGGr5_CACR_Female
# 451                                     EOGGr5_GLP_Female
# 452                             EOGScienceGr5_CACR_Female
# 453                              EOGScienceGr5_GLP_Female
# 454                                      EOGGr5_CACR_Male
# 455                                       EOGGr5_GLP_Male
# 456                               EOGScienceGr5_CACR_Male
# 457                                EOGScienceGr5_GLP_Male
# 458                                EOGScienceGr5_CACR_EDS
# 459                                 EOGScienceGr5_GLP_EDS
# 460                                    EOGGr5_CACR_Female
# 461                                     EOGGr5_GLP_Female
# 462                              EOGReadingGr5_GLP_Female
# 463                             EOGScienceGr5_CACR_Female
# 464                              EOGScienceGr5_GLP_Female
# 465                                      EOGGr5_CACR_Male
# 466                                       EOGGr5_GLP_Male
# 467                                   EOGMathGr5_GLP_Male
# 468                                EOGReadingGr5_GLP_Male
# 469                               EOGScienceGr5_CACR_Male
# 470                                EOGScienceGr5_GLP_Male
# 471                                        EOGGr5_GLP_EDS
# 472                                 EOGScienceGr5_GLP_EDS
# 473                               EOGScienceGr5&8_GLP_All
# 474                           EOGScienceGr5&8_CACR_Female
# 475                            EOGScienceGr5&8_GLP_Female
# 476                             EOGScienceGr5&8_CACR_Male
# 477                              EOGScienceGr5&8_GLP_Male
# 478                           EOGScienceGr5&8_CACR_Female
# 479                            EOGScienceGr5&8_GLP_Female
# 480                             EOGScienceGr5&8_CACR_Male
# 481                              EOGScienceGr5&8_GLP_Male
# 482                               EOGScienceGr5&8_GLP_EDS
# 483                                   EOGSubjects_GLP_All
# 484                              EOGMathGr3-8_CACR_Female
# 485                               EOGMathGr3-8_GLP_Female
# 486                           EOGReadingGr3-8_CACR_Female
# 487                            EOGReadingGr3-8_GLP_Female
# 488                               EOGSubjects_CACR_Female
# 489                                EOGSubjects_GLP_Female
# 490                                EOGMathGr3-8_CACR_Male
# 491                                 EOGMathGr3-8_GLP_Male
# 492                             EOGReadingGr3-8_CACR_Male
# 493                              EOGReadingGr3-8_GLP_Male
# 494                                 EOGSubjects_CACR_Male
# 495                                  EOGSubjects_GLP_Male
# 496                              EOGMathGr3-8_CACR_Female
# 497                               EOGMathGr3-8_GLP_Female
# 498                           EOGReadingGr3-8_CACR_Female
# 499                            EOGReadingGr3-8_GLP_Female
# ...                                                   ...
# 184077                  Tuition and fees deduction Ct All
# 184078                Tuition and fees deduction Ct LT25K
# 184079           Unemployment compensation Amt 100KLT200K
# 184080             Unemployment compensation Amt 25KLT50K
# 184081             Unemployment compensation Amt 50KLT75K
# 184082            Unemployment compensation Amt 75KLT100K
# 184083                  Unemployment compensation Amt All
# 184084            Unemployment compensation Ct 100KLT200K
# 184085              Unemployment compensation Ct 25KLT50K
# 184086              Unemployment compensation Ct 50KLT75K
# 184087             Unemployment compensation Ct 75KLT100K
# 184088                   Unemployment compensation Ct All
# 184089                     Attrtion_Reason_InitiatedbyLEA
# 184090                        Tot tax payments Amt GE200K
# 184091                         Tot tax payments Amt LT25K
# 184092                     Tot tax payments Ct 100KLT200K
# 184093                       Tot tax payments Ct 25KLT50K
# 184094                       Tot tax payments Ct 50KLT75K
# 184095                      Tot tax payments Ct 75KLT100K
# 184096                            Tot tax payments Ct All
# 184097                         Tot tax payments Ct GE200K
# 184098                          Tot tax payments Ct LT25K
# 184099          Tuition and fees deduction Amt 100KLT200K
# 184100            Tuition and fees deduction Amt 25KLT50K
# 184101            Tuition and fees deduction Amt 50KLT75K
# 184102                 Tuition and fees deduction Amt All
# 184103               Tuition and fees deduction Amt LT25K
# 184104           Tuition and fees deduction Ct 100KLT200K
# 184105             Tuition and fees deduction Ct 25KLT50K
# 184106             Tuition and fees deduction Ct 50KLT75K
# 184107                  Tuition and fees deduction Ct All
# 184108                Tuition and fees deduction Ct LT25K
# 184109           Unemployment compensation Amt 100KLT200K
# 184110             Unemployment compensation Amt 25KLT50K
# 184111             Unemployment compensation Amt 50KLT75K
# 184112            Unemployment compensation Amt 75KLT100K
# 184113                  Unemployment compensation Amt All
# 184114               Unemployment compensation Amt GE200K
# 184115                Unemployment compensation Amt LT25K
# 184116            Unemployment compensation Ct 100KLT200K
# 184117              Unemployment compensation Ct 25KLT50K
# 184118              Unemployment compensation Ct 50KLT75K
# 184119             Unemployment compensation Ct 75KLT100K
# 184120                   Unemployment compensation Ct All
# 184121                Unemployment compensation Ct GE200K
# 184122                     Attrtion_Reason_InitiatedbyLEA
# 184123                       Tot tax payments Ct 25KLT50K
# 184124                       Tot tax payments Ct 50KLT75K
# 184125                      Tot tax payments Ct 75KLT100K
# 184126                            Tot tax payments Ct All
# 184127                         Tot tax payments Ct GE200K
# 184128                          Tot tax payments Ct LT25K
# 184129            Tuition and fees deduction Amt 25KLT50K
# 184130            Tuition and fees deduction Amt 50KLT75K
# 184131                 Tuition and fees deduction Amt All
# 184132               Tuition and fees deduction Amt LT25K
# 184133             Tuition and fees deduction Ct 25KLT50K
# 184134             Tuition and fees deduction Ct 50KLT75K
# 184135                  Tuition and fees deduction Ct All
# 184136                Tuition and fees deduction Ct LT25K
# 184137           Unemployment compensation Amt 100KLT200K
# 184138             Unemployment compensation Amt 25KLT50K
# 184139             Unemployment compensation Amt 50KLT75K
# 184140            Unemployment compensation Amt 75KLT100K
# 184141                  Unemployment compensation Amt All
# 184142            Unemployment compensation Ct 100KLT200K
# 184143              Unemployment compensation Ct 25KLT50K
# 184144              Unemployment compensation Ct 50KLT75K
# 184145             Unemployment compensation Ct 75KLT100K
# 184146                   Unemployment compensation Ct All
# 184147                     Attrtion_Reason_InitiatedbyLEA
# 184148                       Tot tax payments Ct 25KLT50K
# 184149                       Tot tax payments Ct 50KLT75K
# 184150                            Tot tax payments Ct All
# 184151                          Tot tax payments Ct LT25K
# 184152            Tuition and fees deduction Amt 25KLT50K
# 184153               Tuition and fees deduction Amt LT25K
# 184154             Tuition and fees deduction Ct 25KLT50K
# 184155                Tuition and fees deduction Ct LT25K
# 184156             Unemployment compensation Amt 25KLT50K
# 184157             Unemployment compensation Amt 50KLT75K
# 184158            Unemployment compensation Amt 75KLT100K
# 184159                  Unemployment compensation Amt All
# 184160                Unemployment compensation Amt LT25K
# 184161              Unemployment compensation Ct 25KLT50K
# 184162              Unemployment compensation Ct 50KLT75K
# 184163             Unemployment compensation Ct 75KLT100K
# 184164                   Unemployment compensation Ct All
# 184165                 Unemployment compensation Ct LT25K
# 184166                     Attrtion_Reason_InitiatedbyLEA
# 184167                       Tot tax payments Ct 25KLT50K
# 184168                       Tot tax payments Ct 50KLT75K
# 184169                      Tot tax payments Ct 75KLT100K
# 184170                            Tot tax payments Ct All
# 184171                         Tot tax payments Ct GE200K
# 184172          Tuition and fees deduction Amt 100KLT200K
# 184173            Tuition and fees deduction Amt 50KLT75K
# 184174                 Tuition and fees deduction Amt All
# 184175               Tuition and fees deduction Amt LT25K
# 184176           Tuition and fees deduction Ct 100KLT200K
# 184177             Tuition and fees deduction Ct 25KLT50K
# 184178             Tuition and fees deduction Ct 50KLT75K
# 184179                  Tuition and fees deduction Ct All
# 184180                Tuition and fees deduction Ct LT25K
# 184181           Unemployment compensation Amt 100KLT200K
# 184182             Unemployment compensation Amt 50KLT75K
# 184183            Unemployment compensation Amt 75KLT100K
# 184184               Unemployment compensation Amt GE200K
# 184185            Unemployment compensation Ct 100KLT200K
# 184186              Unemployment compensation Ct 50KLT75K
# 184187             Unemployment compensation Ct 75KLT100K
# 184188                Unemployment compensation Ct GE200K
# 184189                       Tot tax payments Ct 50KLT75K
# 184190                      Tot tax payments Ct 75KLT100K
# 184191                            Tot tax payments Ct All
# 184192                         Tot tax payments Ct GE200K
# 184193                          Tot tax payments Ct LT25K
# 184194            Tuition and fees deduction Amt 25KLT50K
# 184195            Tuition and fees deduction Amt 50KLT75K
# 184196                 Tuition and fees deduction Amt All
# 184197               Tuition and fees deduction Amt LT25K
# 184198             Tuition and fees deduction Ct 25KLT50K
# 184199             Tuition and fees deduction Ct 50KLT75K
# 184200                  Tuition and fees deduction Ct All
# 184201                Tuition and fees deduction Ct LT25K
# 184202           Unemployment compensation Amt 100KLT200K
# 184203             Unemployment compensation Amt 25KLT50K
# 184204             Unemployment compensation Amt 50KLT75K
# 184205            Unemployment compensation Amt 75KLT100K
# 184206                  Unemployment compensation Amt All
# 184207                Unemployment compensation Amt LT25K
# 184208            Unemployment compensation Ct 100KLT200K
# 184209              Unemployment compensation Ct 25KLT50K
# 184210              Unemployment compensation Ct 50KLT75K
# 184211             Unemployment compensation Ct 75KLT100K
# 184212                   Unemployment compensation Ct All
# 184213                 Unemployment compensation Ct LT25K
# 184214                     Attrtion_Reason_InitiatedbyLEA
# 184215                      Tot tax payments Ct 75KLT100K
# 184216                            Tot tax payments Ct All
# 184217                         Tot tax payments Ct GE200K
# 184218                          Tot tax payments Ct LT25K
# 184219          Tuition and fees deduction Amt 100KLT200K
# 184220            Tuition and fees deduction Amt 25KLT50K
# 184221            Tuition and fees deduction Amt 50KLT75K
# 184222                 Tuition and fees deduction Amt All
# 184223               Tuition and fees deduction Amt LT25K
# 184224           Tuition and fees deduction Ct 100KLT200K
# 184225             Tuition and fees deduction Ct 25KLT50K
# 184226             Tuition and fees deduction Ct 50KLT75K
# 184227                  Tuition and fees deduction Ct All
# 184228                Tuition and fees deduction Ct LT25K
# 184229           Unemployment compensation Amt 100KLT200K
# 184230             Unemployment compensation Amt 25KLT50K
# 184231             Unemployment compensation Amt 50KLT75K
# 184232            Unemployment compensation Amt 75KLT100K
# 184233                  Unemployment compensation Amt All
# 184234                Unemployment compensation Amt LT25K
# 184235            Unemployment compensation Ct 100KLT200K
# 184236              Unemployment compensation Ct 25KLT50K
# 184237              Unemployment compensation Ct 50KLT75K
# 184238             Unemployment compensation Ct 75KLT100K
# 184239                   Unemployment compensation Ct All
# 184240                     Attrtion_Reason_InitiatedbyLEA
# 184241                            Tot tax payments Ct All
# 184242                         Tot tax payments Ct GE200K
# 184243                          Tot tax payments Ct LT25K
# 184244          Tuition and fees deduction Amt 100KLT200K
# 184245            Tuition and fees deduction Amt 25KLT50K
# 184246            Tuition and fees deduction Amt 50KLT75K
# 184247                 Tuition and fees deduction Amt All
# 184248               Tuition and fees deduction Amt LT25K
# 184249           Tuition and fees deduction Ct 100KLT200K
# 184250             Tuition and fees deduction Ct 25KLT50K
# 184251             Tuition and fees deduction Ct 50KLT75K
# 184252                  Tuition and fees deduction Ct All
# 184253                Tuition and fees deduction Ct LT25K
# 184254           Unemployment compensation Amt 100KLT200K
# 184255             Unemployment compensation Amt 25KLT50K
# 184256             Unemployment compensation Amt 50KLT75K
# 184257            Unemployment compensation Amt 75KLT100K
# 184258                  Unemployment compensation Amt All
# 184259            Unemployment compensation Ct 100KLT200K
# 184260              Unemployment compensation Ct 25KLT50K
# 184261              Unemployment compensation Ct 50KLT75K
# 184262             Unemployment compensation Ct 75KLT100K
# 184263                   Unemployment compensation Ct All
# 184264                     Attrtion_Reason_InitiatedbyLEA
# 184265                         Tot tax payments Ct GE200K
# 184266                          Tot tax payments Ct LT25K
# 184267          Tuition and fees deduction Amt 100KLT200K
# 184268            Tuition and fees deduction Amt 25KLT50K
# 184269            Tuition and fees deduction Amt 50KLT75K
# 184270                 Tuition and fees deduction Amt All
# 184271               Tuition and fees deduction Amt LT25K
# 184272           Tuition and fees deduction Ct 100KLT200K
# 184273             Tuition and fees deduction Ct 25KLT50K
# 184274             Tuition and fees deduction Ct 50KLT75K
# 184275                  Tuition and fees deduction Ct All
# 184276                Tuition and fees deduction Ct LT25K
# 184277           Unemployment compensation Amt 100KLT200K
# 184278             Unemployment compensation Amt 25KLT50K
# 184279             Unemployment compensation Amt 50KLT75K
# 184280            Unemployment compensation Amt 75KLT100K
# 184281                  Unemployment compensation Amt All
# 184282                Unemployment compensation Amt LT25K
# 184283            Unemployment compensation Ct 100KLT200K
# 184284              Unemployment compensation Ct 25KLT50K
# 184285              Unemployment compensation Ct 50KLT75K
# 184286             Unemployment compensation Ct 75KLT100K
# 184287                   Unemployment compensation Ct All
# 184288                 Unemployment compensation Ct LT25K
# 184289                     Attrtion_Reason_InitiatedbyLEA
# 184290          Tuition and fees deduction Amt 100KLT200K
# 184291            Tuition and fees deduction Amt 25KLT50K
# 184292            Tuition and fees deduction Amt 50KLT75K
# 184293                 Tuition and fees deduction Amt All
# 184294               Tuition and fees deduction Amt LT25K
# 184295           Tuition and fees deduction Ct 100KLT200K
# 184296             Tuition and fees deduction Ct 25KLT50K
# 184297             Tuition and fees deduction Ct 50KLT75K
# 184298                  Tuition and fees deduction Ct All
# 184299                Tuition and fees deduction Ct LT25K
# 184300           Unemployment compensation Amt 100KLT200K
# 184301             Unemployment compensation Amt 25KLT50K
# 184302             Unemployment compensation Amt 50KLT75K
# 184303            Unemployment compensation Amt 75KLT100K
# 184304                  Unemployment compensation Amt All
# 184305               Unemployment compensation Amt GE200K
# 184306            Unemployment compensation Ct 100KLT200K
# 184307              Unemployment compensation Ct 25KLT50K
# 184308              Unemployment compensation Ct 50KLT75K
# 184309             Unemployment compensation Ct 75KLT100K
# 184310                   Unemployment compensation Ct All
# 184311                Unemployment compensation Ct GE200K
# 184312            Tuition and fees deduction Amt 25KLT50K
# 184313            Tuition and fees deduction Amt 50KLT75K
# 184314                 Tuition and fees deduction Amt All
# 184315               Tuition and fees deduction Amt LT25K
# 184316             Tuition and fees deduction Ct 25KLT50K
# 184317             Tuition and fees deduction Ct 50KLT75K
# 184318                  Tuition and fees deduction Ct All
# 184319                Tuition and fees deduction Ct LT25K
# 184320             Unemployment compensation Amt 25KLT50K
# 184321             Unemployment compensation Amt 50KLT75K
# 184322            Unemployment compensation Amt 75KLT100K
# 184323                  Unemployment compensation Amt All
# 184324                Unemployment compensation Amt LT25K
# 184325              Unemployment compensation Ct 25KLT50K
# 184326              Unemployment compensation Ct 50KLT75K
# 184327             Unemployment compensation Ct 75KLT100K
# 184328                   Unemployment compensation Ct All
# 184329                 Unemployment compensation Ct LT25K
# 184330                     Attrtion_Reason_InitiatedbyLEA
# 184331            Tuition and fees deduction Amt 50KLT75K
# 184332                 Tuition and fees deduction Amt All
# 184333               Tuition and fees deduction Amt LT25K
# 184334           Tuition and fees deduction Ct 100KLT200K
# 184335             Tuition and fees deduction Ct 50KLT75K
# 184336                  Tuition and fees deduction Ct All
# 184337                Tuition and fees deduction Ct LT25K
# 184338           Unemployment compensation Amt 100KLT200K
# 184339            Unemployment compensation Amt 75KLT100K
# 184340               Unemployment compensation Amt GE200K
# 184341            Unemployment compensation Ct 100KLT200K
# 184342             Unemployment compensation Ct 75KLT100K
# 184343                Unemployment compensation Ct GE200K
# 184344            Tuition and fees deduction Amt 50KLT75K
# 184345                 Tuition and fees deduction Amt All
# 184346               Tuition and fees deduction Amt LT25K
# 184347             Tuition and fees deduction Ct 25KLT50K
# 184348             Tuition and fees deduction Ct 50KLT75K
# 184349                  Tuition and fees deduction Ct All
# 184350                Tuition and fees deduction Ct LT25K
# 184351             Unemployment compensation Amt 25KLT50K
# 184352             Unemployment compensation Amt 50KLT75K
# 184353            Unemployment compensation Amt 75KLT100K
# 184354                  Unemployment compensation Amt All
# 184355                Unemployment compensation Amt LT25K
# 184356              Unemployment compensation Ct 25KLT50K
# 184357              Unemployment compensation Ct 50KLT75K
# 184358             Unemployment compensation Ct 75KLT100K
# 184359                   Unemployment compensation Ct All
# 184360                 Unemployment compensation Ct LT25K
# ...
# 184359            Tuition and fees deduction Amt 25KLT50K     0.982876
# 184360            Tuition and fees deduction Amt 25KLT50K     0.964277
# 184361            Tuition and fees deduction Amt 25KLT50K     0.950047
# 184362            Tuition and fees deduction Amt 25KLT50K     0.958834
# 184363            Tuition and fees deduction Amt 25KLT50K     0.981098
# 184364            Tuition and fees deduction Amt 50KLT75K     0.997592
# 184365            Tuition and fees deduction Amt 50KLT75K     0.992200
# 184366            Tuition and fees deduction Amt 50KLT75K     0.967361
# 184367            Tuition and fees deduction Amt 50KLT75K     0.984369
# 184368            Tuition and fees deduction Amt 50KLT75K     0.999350
# 184369            Tuition and fees deduction Amt 50KLT75K     0.995919
# 184370            Tuition and fees deduction Amt 50KLT75K     0.990636
# 184371            Tuition and fees deduction Amt 50KLT75K     0.987640
# 184372            Tuition and fees deduction Amt 50KLT75K     0.974502
# 184373            Tuition and fees deduction Amt 50KLT75K     0.981968
# 184374            Tuition and fees deduction Amt 50KLT75K     0.986702
# 184375            Tuition and fees deduction Amt 50KLT75K     0.976963
# 184376            Tuition and fees deduction Amt 50KLT75K     0.950816
# 184377            Tuition and fees deduction Amt 50KLT75K     0.986126
# 184378            Tuition and fees deduction Amt 50KLT75K     0.967489
# 184379            Tuition and fees deduction Amt 50KLT75K     0.973278
# 184380            Tuition and fees deduction Amt 50KLT75K     0.981010
# 184381            Tuition and fees deduction Amt 50KLT75K     0.966493
# 184382            Tuition and fees deduction Amt 50KLT75K     0.950516
# 184383            Tuition and fees deduction Amt 50KLT75K     0.966037
# 184384           Tuition and fees deduction Amt 75KLT100K     0.997182
# 184385                 Tuition and fees deduction Amt All     0.995632
# 184386                 Tuition and fees deduction Amt All     0.972242
# 184387                 Tuition and fees deduction Amt All     0.986836
# 184388                 Tuition and fees deduction Amt All     0.998168
# 184389                 Tuition and fees deduction Amt All     0.999321
# 184390                 Tuition and fees deduction Amt All     0.995143
# 184391                 Tuition and fees deduction Amt All     0.987884
# 184392                 Tuition and fees deduction Amt All     0.974222
# 184393                 Tuition and fees deduction Amt All     0.983842
# 184394                 Tuition and fees deduction Amt All     0.988317
# 184395                 Tuition and fees deduction Amt All     0.977488
# 184396                 Tuition and fees deduction Amt All     0.986614
# 184397                 Tuition and fees deduction Amt All     0.968604
# 184398                 Tuition and fees deduction Amt All     0.977032
# 184399                 Tuition and fees deduction Amt All     0.984168
# 184400                 Tuition and fees deduction Amt All     0.968781
# 184401                 Tuition and fees deduction Amt All     0.965981
# 184402               Tuition and fees deduction Amt LT25K     0.987710
# 184403               Tuition and fees deduction Amt LT25K     0.991866
# 184404               Tuition and fees deduction Amt LT25K     0.992733
# 184405               Tuition and fees deduction Amt LT25K     0.999128
# 184406               Tuition and fees deduction Amt LT25K     0.973918
# 184407               Tuition and fees deduction Amt LT25K     0.977550
# 184408               Tuition and fees deduction Amt LT25K     0.980528
# 184409               Tuition and fees deduction Amt LT25K     0.984345
# 184410               Tuition and fees deduction Amt LT25K     0.980720
# 184411               Tuition and fees deduction Amt LT25K     0.953817
# 184412               Tuition and fees deduction Amt LT25K     0.971636
# 184413               Tuition and fees deduction Amt LT25K     0.972942
# 184414               Tuition and fees deduction Amt LT25K     0.973281
# 184415               Tuition and fees deduction Amt LT25K     0.978141
# 184416               Tuition and fees deduction Amt LT25K     0.974563
# 184417               Tuition and fees deduction Amt LT25K     0.962311
# 184418           Tuition and fees deduction Ct 100KLT200K     0.971440
# 184419           Tuition and fees deduction Ct 100KLT200K     0.978247
# 184420           Tuition and fees deduction Ct 100KLT200K     0.950316
# 184421           Tuition and fees deduction Ct 100KLT200K     0.985860
# 184422           Tuition and fees deduction Ct 100KLT200K     0.955843
# 184423           Tuition and fees deduction Ct 100KLT200K     0.954396
# 184424           Tuition and fees deduction Ct 100KLT200K     0.987140
# 184425           Tuition and fees deduction Ct 100KLT200K     0.960090
# 184426           Tuition and fees deduction Ct 100KLT200K     0.959308
# 184427             Tuition and fees deduction Ct 25KLT50K     0.984771
# 184428             Tuition and fees deduction Ct 25KLT50K     0.984474
# 184429             Tuition and fees deduction Ct 25KLT50K     0.988514
# 184430             Tuition and fees deduction Ct 25KLT50K     0.960696
# 184431             Tuition and fees deduction Ct 25KLT50K     0.988645
# 184432             Tuition and fees deduction Ct 25KLT50K     0.987479
# 184433             Tuition and fees deduction Ct 25KLT50K     0.983135
# 184434             Tuition and fees deduction Ct 25KLT50K     0.989071
# 184435             Tuition and fees deduction Ct 25KLT50K     0.971086
# 184436             Tuition and fees deduction Ct 25KLT50K     0.958848
# 184437             Tuition and fees deduction Ct 25KLT50K     0.983457
# 184438             Tuition and fees deduction Ct 25KLT50K     0.978105
# 184439             Tuition and fees deduction Ct 25KLT50K     0.974938
# 184440             Tuition and fees deduction Ct 25KLT50K     0.983382
# 184441             Tuition and fees deduction Ct 25KLT50K     0.956431
# 184442             Tuition and fees deduction Ct 25KLT50K     0.954284
# 184443             Tuition and fees deduction Ct 25KLT50K     0.982476
# 184444             Tuition and fees deduction Ct 50KLT75K     0.997526
# 184445             Tuition and fees deduction Ct 50KLT75K     0.991207
# 184446             Tuition and fees deduction Ct 50KLT75K     0.988305
# 184447             Tuition and fees deduction Ct 50KLT75K     0.974238
# 184448             Tuition and fees deduction Ct 50KLT75K     0.983716
# 184449             Tuition and fees deduction Ct 50KLT75K     0.988001
# 184450             Tuition and fees deduction Ct 50KLT75K     0.977042
# 184451             Tuition and fees deduction Ct 50KLT75K     0.986954
# 184452             Tuition and fees deduction Ct 50KLT75K     0.967677
# 184453             Tuition and fees deduction Ct 50KLT75K     0.975811
# 184454             Tuition and fees deduction Ct 50KLT75K     0.983227
# 184455             Tuition and fees deduction Ct 50KLT75K     0.967083
# 184456             Tuition and fees deduction Ct 50KLT75K     0.964614
# 184457                  Tuition and fees deduction Ct All     0.993323
# 184458                  Tuition and fees deduction Ct All     0.990129
# 184459                  Tuition and fees deduction Ct All     0.971889
# 184460                  Tuition and fees deduction Ct All     0.984392
# 184461                  Tuition and fees deduction Ct All     0.988843
# 184462                  Tuition and fees deduction Ct All     0.975486
# 184463                  Tuition and fees deduction Ct All     0.989198
# 184464                  Tuition and fees deduction Ct All     0.966748
# 184465                  Tuition and fees deduction Ct All     0.978771
# 184466                  Tuition and fees deduction Ct All     0.986103
# 184467                  Tuition and fees deduction Ct All     0.966936
# 184468                  Tuition and fees deduction Ct All     0.963139
# 184469                Tuition and fees deduction Ct LT25K     0.974718
# 184470                Tuition and fees deduction Ct LT25K     0.980876
# 184471                Tuition and fees deduction Ct LT25K     0.984725
# 184472                Tuition and fees deduction Ct LT25K     0.987536
# 184473                Tuition and fees deduction Ct LT25K     0.984134
# 184474                Tuition and fees deduction Ct LT25K     0.958056
# 184475                Tuition and fees deduction Ct LT25K     0.972554
# 184476                Tuition and fees deduction Ct LT25K     0.977030
# 184477                Tuition and fees deduction Ct LT25K     0.978523
# 184478                Tuition and fees deduction Ct LT25K     0.982140
# 184479                Tuition and fees deduction Ct LT25K     0.978904
# 184480                Tuition and fees deduction Ct LT25K     0.962232
# 184481           Unemployment compensation Amt 100KLT200K     0.957071
# 184482           Unemployment compensation Amt 100KLT200K     0.975978
# 184483           Unemployment compensation Amt 100KLT200K     0.984795
# 184484           Unemployment compensation Amt 100KLT200K     0.961023
# 184485           Unemployment compensation Amt 100KLT200K     0.972235
# 184486           Unemployment compensation Amt 100KLT200K     0.999826
# 184487           Unemployment compensation Amt 100KLT200K     0.950962
# 184488           Unemployment compensation Amt 100KLT200K     0.972050
# 184489           Unemployment compensation Amt 100KLT200K     0.984584
# 184490           Unemployment compensation Amt 100KLT200K     0.973552
# 184491             Unemployment compensation Amt 25KLT50K     0.994720
# 184492             Unemployment compensation Amt 25KLT50K     0.989703
# 184493             Unemployment compensation Amt 25KLT50K     0.999527
# 184494             Unemployment compensation Amt 25KLT50K     0.988048
# 184495             Unemployment compensation Amt 25KLT50K     0.954991
# 184496             Unemployment compensation Amt 25KLT50K     0.998061
# 184497             Unemployment compensation Amt 25KLT50K     0.989327
# 184498             Unemployment compensation Amt 25KLT50K     0.983377
# 184499             Unemployment compensation Amt 25KLT50K     0.997388
# 184500             Unemployment compensation Amt 25KLT50K     0.976782
# 184501             Unemployment compensation Amt 25KLT50K     0.953352
# 184502             Unemployment compensation Amt 25KLT50K     0.975080
# 184503             Unemployment compensation Amt 50KLT75K     0.997260
# 184504             Unemployment compensation Amt 50KLT75K     0.995856
# 184505             Unemployment compensation Amt 50KLT75K     0.970765
# 184506             Unemployment compensation Amt 50KLT75K     0.974795
# 184507             Unemployment compensation Amt 50KLT75K     0.992522
# 184508             Unemployment compensation Amt 50KLT75K     0.996762
# 184509             Unemployment compensation Amt 50KLT75K     0.994455
# 184510             Unemployment compensation Amt 50KLT75K     0.991980
# 184511             Unemployment compensation Amt 50KLT75K     0.956985
# 184512             Unemployment compensation Amt 50KLT75K     0.972352
# 184513            Unemployment compensation Amt 75KLT100K     0.992080
# 184514            Unemployment compensation Amt 75KLT100K     0.961052
# 184515            Unemployment compensation Amt 75KLT100K     0.983565
# 184516            Unemployment compensation Amt 75KLT100K     0.987385
# 184517            Unemployment compensation Amt 75KLT100K     0.994668
# 184518            Unemployment compensation Amt 75KLT100K     0.997809
# 184519            Unemployment compensation Amt 75KLT100K     0.987326
# 184520            Unemployment compensation Amt 75KLT100K     0.968241
# 184521                  Unemployment compensation Amt All     0.987199
# 184522                  Unemployment compensation Amt All     0.958898
# 184523                  Unemployment compensation Amt All     0.997771
# 184524                  Unemployment compensation Amt All     0.990734
# 184525                  Unemployment compensation Amt All     0.986102
# 184526                  Unemployment compensation Amt All     0.997981
# 184527                  Unemployment compensation Amt All     0.976267
# 184528                  Unemployment compensation Amt All     0.974207
# 184529               Unemployment compensation Amt GE200K     0.971873
# 184530               Unemployment compensation Amt GE200K     0.999590
# 184531                Unemployment compensation Amt LT25K     0.988793
# 184532                Unemployment compensation Amt LT25K     0.964526
# 184533                Unemployment compensation Amt LT25K     0.951334
# 184534                Unemployment compensation Amt LT25K     0.990895
# 184535                Unemployment compensation Amt LT25K     0.997081
# 184536                Unemployment compensation Amt LT25K     0.955053
# 184537            Unemployment compensation Ct 100KLT200K     0.971479
# 184538            Unemployment compensation Ct 100KLT200K     0.984095
# 184539            Unemployment compensation Ct 100KLT200K     0.973487
# 184540              Unemployment compensation Ct 25KLT50K     0.991366
# 184541              Unemployment compensation Ct 25KLT50K     0.983807
# 184542              Unemployment compensation Ct 25KLT50K     0.999222
# 184543              Unemployment compensation Ct 25KLT50K     0.981259
# 184544              Unemployment compensation Ct 25KLT50K     0.968525
# 184545              Unemployment compensation Ct 50KLT75K     0.996628
# 184546              Unemployment compensation Ct 50KLT75K     0.990544
# 184547              Unemployment compensation Ct 50KLT75K     0.954135
# 184548              Unemployment compensation Ct 50KLT75K     0.961067
# 184549             Unemployment compensation Ct 75KLT100K     0.983355
# 184550             Unemployment compensation Ct 75KLT100K     0.959620
# 184551                   Unemployment compensation Ct All     0.984597
# 184552                   Unemployment compensation Ct All     0.966498
# 184553                Attrtion_Reason_RemainedinEducation     0.978794
# 184554                    Attrtion_Reason_PersonalReasons     0.972273
# 184555                                      category_cd_E     1.000000
# 184556                                      category_cd_H     1.000000
# 184557                                      category_cd_I     1.000000
# 184558                                      category_cd_M     1.000000
# 184559                                      category_cd_T     1.000000
# 184560                  calendar_type_txt_Hospital School     1.000000
# 184561                  calendar_type_txt_Hospital School     1.000000
# 184562  calendar_type_txt_Magnet School, Traditional C...     1.000000
# 184563  calendar_type_txt_Magnet School, Traditional C...     0.985376
# 184564  calendar_type_txt_Magnet School, Year-Round Ca...     1.000000
# 184565  calendar_type_txt_Regular School, Traditional ...     1.000000
# 184566  calendar_type_txt_Regular School, Traditional ...     1.000000
# 184567  calendar_type_txt_Regular School, Traditional ...     1.000000
# 184568  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 184569  calendar_type_txt_Regular School, Year-Round C...     0.984549
# 184570  calendar_type_txt_Special Education, Tradition...     1.000000
# 184571  calendar_type_txt_Special Education, Tradition...     1.000000
# 184572                                  sna_pgm_type_cd_H     1.000000
# 184573                                  sna_pgm_type_cd_M     0.985376
# 184574                                  sna_pgm_type_cd_S     1.000000
# 184575                                  sna_pgm_type_cd_X     1.000000
# 184576                                  sna_pgm_type_cd_Y     0.984549
#
# [184577 rows x 3 columns]

# %%
print ('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  1018  highly correlated fields.
# ['Math SPG Score',
#  'Overall Achievement Score',
#  'Read Score',
#  'Math Score',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_CACR_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_CACR_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOCMathI_CACR_Female',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_CACR_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_CACR_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_CACR_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_CACR_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_CACR_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr4_CACR_Female',
#  'EOGReadingGr4_GLP_Female',
#  'EOGReadingGr5_CACR_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_CACR_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOCMathI_CACR_Male',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_CACR_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_CACR_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_CACR_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_CACR_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr4_CACR_Male',
#  'EOGReadingGr4_GLP_Male',
#  'EOGReadingGr5_CACR_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_CACR_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGReadingGr5_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_CACR_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr3_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGReadingGr3_GLP_Black',
#  'EOGReadingGr3-8_GLP_Black',
#  'EOGReadingGr4_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_GLP_Black',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_Hispanic',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGReadingGr3_GLP_Hispanic',
#  'EOGReadingGr4_GLP_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr3-8_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOCMathI_CACR_White',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_CACR_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_CACR_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_CACR_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_CACR_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_CACR_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_CACR_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_CACR_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_CACR_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_CACR_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_CACR_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_CACR_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_CACR_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3_CACR_EDS',
#  'EOGMathGr3_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_CACR_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_CACR_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3_CACR_EDS',
#  'EOGReadingGr3_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGReadingGr4_CACR_EDS',
#  'EOGReadingGr4_GLP_EDS',
#  'EOGReadingGr5_GLP_EDS',
#  'EOGScienceGr5_CACR_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOGGr3_GLP_LEP',
#  'EOGMathGr3_GLP_LEP',
#  'EOGGr5_GLP_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_CACR_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'st_avg_daily_attend_pct',
#  'st_stud_internet_comp_num',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'st_tchyrs_11plus_pct',
#  'st_class_teach_num',
#  'st_prinyrs_0thru3_pct',
#  'st_prinyrs_4thru10_pct',
#  'st_prinyrs_11plus_pct',
#  'st_prin_advance_dgr_pct',
#  'st_1yr_prin_trnovr_pct',
#  'st_prin_male_pct',
#  'st_prin_female_pct',
#  'st_prin_black_pct',
#  'st_prin_white_pct',
#  'st_prin_other_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'Not Demostrated_TCHR_Standard 3_Pct',
#  'Not Demostrated_TCHR_Standard 5_Pct',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'HispanicMalePct',
#  'BlackMalePct',
#  'WhiteMalePct',
#  'MinorityMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'HispanicFemalePct',
#  'BlackFemalePct',
#  'WhiteFemalePct',
#  'MinorityFemalePct',
#  'Crime_Rate_Property_Rate',
#  'Crime_Rate_Assault_Rate',
#  'Crime_Rate_Larceny_Rate',
#  'Add Medicare tax Amt All',
#  'Add Medicare tax Amt GE200K',
#  'Add Medicare tax Ct 100KLT200K',
#  'Add Medicare tax Ct All',
#  'Add Medicare tax Ct GE200K',
#  'Add child tax credit Amt 25KLT50K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct 50KLT75K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Contributions Amt 100KLT200K',
#  'Contributions Amt 25KLT50K',
#  'Contributions Amt 50KLT75K',
#  'Contributions Amt 75KLT100K',
#  'Contributions Amt All',
#  'Contributions Amt GE200K',
#  'Contributions Amt LT25K',
#  'Contributions Ct 100KLT200K',
#  'Contributions Ct 25KLT50K',
#  'Contributions Ct 50KLT75K',
#  'Contributions Ct 75KLT100K',
#  'Contributions Ct All',
#  'Contributions Ct GE200K',
#  'Contributions Ct LT25K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Ct 100KLT200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'IRA payments Amt 100KLT200K',
#  'IRA payments Amt 25KLT50K',
#  'IRA payments Amt 50KLT75K',
#  'IRA payments Amt 75KLT100K',
#  'IRA payments Amt All',
#  'IRA payments Amt GE200K',
#  'IRA payments Amt LT25K',
#  'IRA payments Ct 100KLT200K',
#  'IRA payments Ct 25KLT50K',
#  'IRA payments Ct 50KLT75K',
#  'IRA payments Ct 75KLT100K',
#  'IRA payments Ct All',
#  'IRA payments Ct GE200K',
#  'IRA payments Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Mortgage interest paid Amt 100KLT200K',
#  'Mortgage interest paid Amt 25KLT50K',
#  'Mortgage interest paid Amt 50KLT75K',
#  'Mortgage interest paid Amt 75KLT100K',
#  'Mortgage interest paid Amt All',
#  'Mortgage interest paid Amt GE200K',
#  'Mortgage interest paid Amt LT25K',
#  'Mortgage interest paid Ct 100KLT200K',
#  'Mortgage interest paid Ct 25KLT50K',
#  'Mortgage interest paid Ct 50KLT75K',
#  'Mortgage interest paid Ct 75KLT100K',
#  'Mortgage interest paid Ct All',
#  'Mortgage interest paid Ct GE200K',
#  'Mortgage interest paid Ct LT25K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Residential energy tax credit Ct LT25K',
#  'Retirement savings contribution credit Amt 25KLT50K',
#  'Retirement savings contribution credit Amt 50KLT75K',
#  'Retirement savings contribution credit Amt All',
#  'Retirement savings contribution credit Amt LT25K',
#  'Retirement savings contribution credit Ct 25KLT50K',
#  'Retirement savings contribution credit Ct 50KLT75K',
#  'Retirement savings contribution credit Ct All',
#  'Retirement savings contribution credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employment health insurance deduction Amt 100KLT200K',
#  'Self-employment health insurance deduction Amt 25KLT50K',
#  'Self-employment health insurance deduction Amt 50KLT75K',
#  'Self-employment health insurance deduction Amt 75KLT100K',
#  'Self-employment health insurance deduction Amt All',
#  'Self-employment health insurance deduction Amt GE200K',
#  'Self-employment health insurance deduction Amt LT25K',
#  'Self-employment health insurance deduction Ct 100KLT200K',
#  'Self-employment health insurance deduction Ct 25KLT50K',
#  'Self-employment health insurance deduction Ct 50KLT75K',
#  'Self-employment health insurance deduction Ct 75KLT100K',
#  'Self-employment health insurance deduction Ct All',
#  'Self-employment health insurance deduction Ct GE200K',
#  'Self-employment health insurance deduction Ct LT25K',
#  'Self-employment retirement plans Amt 100KLT200K',
#  'Self-employment retirement plans Amt 50KLT75K',
#  'Self-employment retirement plans Amt 75KLT100K',
#  'Self-employment retirement plans Amt All',
#  'Self-employment retirement plans Amt GE200K',
#  'Self-employment retirement plans Amt LT25K',
#  'Self-employment retirement plans Ct 100KLT200K',
#  'Self-employment retirement plans Ct 25KLT50K',
#  'Self-employment retirement plans Ct 50KLT75K',
#  'Self-employment retirement plans Ct 75KLT100K',
#  'Self-employment retirement plans Ct All',
#  'Self-employment retirement plans Ct GE200K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt GE200K',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  'Taxable interest Ct 100KLT200K',
#  'Taxable interest Ct 25KLT50K',
#  'Taxable interest Ct 50KLT75K',
#  'Taxable interest Ct 75KLT100K',
#  'Taxable interest Ct All',
#  'Taxable interest Ct GE200K',
#  'Taxable interest Ct LT25K',
#  'Taxes paid Amt 100KLT200K',
#  'Taxes paid Amt 25KLT50K',
#  'Taxes paid Amt 50KLT75K',
#  'Taxes paid Amt 75KLT100K',
#  'Taxes paid Amt All',
#  'Taxes paid Amt GE200K',
#  'Taxes paid Amt LT25K',
#  'Taxes paid Ct 100KLT200K',
#  'Taxes paid Ct 25KLT50K',
#  'Taxes paid Ct 50KLT75K',
#  'Taxes paid Ct 75KLT100K',
#  'Taxes paid Ct All',
#  'Taxes paid Ct GE200K',
#  'Taxes paid Ct LT25K',
#  'Tot income Amt 100KLT200K',
#  'Tot income Amt 25KLT50K',
#  'Tot income Amt 50KLT75K',
#  'Tot income Amt 75KLT100K',
#  'Tot income Amt All',
#  'Tot income Amt GE200K',
#  'Tot income Amt LT25K',
#  'Tot income Ct 100KLT200K',
#  'Tot income Ct 25KLT50K',
#  'Tot income Ct 50KLT75K',
#  'Tot income Ct 75KLT100K',
#  'Tot income Ct All',
#  'Tot income Ct GE200K',
#  'Tot income Ct LT25K',
#  'Tot itemized deductions Amt 100KLT200K',
#  'Tot itemized deductions Amt 25KLT50K',
#  'Tot itemized deductions Amt 50KLT75K',
#  'Tot itemized deductions Amt 75KLT100K',
#  'Tot itemized deductions Amt All',
#  'Tot itemized deductions Amt GE200K',
#  'Tot itemized deductions Amt LT25K',
#  'Tot itemized deductions Amt of AGI 100KLT200K',
#  'Tot itemized deductions Amt of AGI 25KLT50K',
#  'Tot itemized deductions Amt of AGI 50KLT75K',
#  'Tot itemized deductions Amt of AGI 75KLT100K',
#  'Tot itemized deductions Amt of AGI All',
#  'Tot itemized deductions Amt of AGI GE200K',
#  'Tot itemized deductions Amt of AGI LT25K',
#  'Tot itemized deductions Ct 100KLT200K',
#  'Tot itemized deductions Ct 25KLT50K',
#  'Tot itemized deductions Ct 50KLT75K',
#  'Tot itemized deductions Ct 75KLT100K',
#  'Tot itemized deductions Ct All',
#  'Tot itemized deductions Ct GE200K',
#  'Tot itemized deductions Ct LT25K',
#  'Tot statuory adjustments Amt 100KLT200K',
#  'Tot statuory adjustments Amt 25KLT50K',
#  'Tot statuory adjustments Amt 50KLT75K',
#  'Tot statuory adjustments Amt 75KLT100K',
#  'Tot statuory adjustments Amt All',
#  'Tot statuory adjustments Amt GE200K',
#  'Tot statuory adjustments Amt LT25K',
#  'Tot statuory adjustments Ct 100KLT200K',
#  'Tot statuory adjustments Ct 25KLT50K',
#  'Tot statuory adjustments Ct 50KLT75K',
#  'Tot statuory adjustments Ct 75KLT100K',
#  'Tot statuory adjustments Ct All',
#  'Tot statuory adjustments Ct GE200K',
#  'Tot statuory adjustments Ct LT25K',
#  'Tot tax credits Amt 100KLT200K',
#  'Tot tax credits Amt 25KLT50K',
#  'Tot tax credits Amt 50KLT75K',
#  'Tot tax credits Amt 75KLT100K',
#  'Tot tax credits Amt All',
#  'Tot tax credits Amt GE200K',
#  'Tot tax credits Amt LT25K',
#  'Tot tax credits Ct 100KLT200K',
#  'Tot tax credits Ct 25KLT50K',
#  'Tot tax credits Ct 50KLT75K',
#  'Tot tax credits Ct 75KLT100K',
#  'Tot tax credits Ct All',
#  'Tot tax credits Ct GE200K',
#  'Tot tax credits Ct LT25K',
#  'Tot tax liability Amt 100KLT200K',
#  'Tot tax liability Amt 25KLT50K',
#  'Tot tax liability Amt 50KLT75K',
#  'Tot tax liability Amt 75KLT100K',
#  'Tot tax liability Amt All',
#  'Tot tax liability Amt GE200K',
#  'Tot tax liability Amt LT25K',
#  'Tot tax liability Ct 100KLT200K',
#  'Tot tax liability Ct 25KLT50K',
#  'Tot tax liability Ct 50KLT75K',
#  'Tot tax liability Ct 75KLT100K',
#  'Tot tax liability Ct All',
#  'Tot tax liability Ct GE200K',
#  'Tot tax liability Ct LT25K',
#  'Tot tax payments Amt 100KLT200K',
#  'Tot tax payments Amt 25KLT50K',
#  'Tot tax payments Amt 50KLT75K',
#  'Tot tax payments Amt 75KLT100K',
#  'Tot tax payments Amt All',
#  'Tot tax payments Amt GE200K',
#  'Tot tax payments Amt LT25K',
#  'Tot tax payments Ct 100KLT200K',
#  'Tot tax payments Ct 25KLT50K',
#  'Tot tax payments Ct 50KLT75K',
#  'Tot tax payments Ct 75KLT100K',
#  'Tot tax payments Ct All',
#  'Tot tax payments Ct GE200K',
#  'Tot tax payments Ct LT25K',
#  'Tuition and fees deduction Amt 100KLT200K',
#  'Tuition and fees deduction Amt 25KLT50K',
#  'Tuition and fees deduction Amt 50KLT75K',
#  'Tuition and fees deduction Amt 75KLT100K',
#  'Tuition and fees deduction Amt All',
#  'Tuition and fees deduction Amt LT25K',
#  'Tuition and fees deduction Ct 100KLT200K',
#  'Tuition and fees deduction Ct 25KLT50K',
#  'Tuition and fees deduction Ct 50KLT75K',
#  'Tuition and fees deduction Ct 75KLT100K',
#  'Tuition and fees deduction Ct All',
#  'Tuition and fees deduction Ct LT25K',
#  'Unemployment compensation Amt 100KLT200K',
#  'Unemployment compensation Amt 25KLT50K',
#  'Unemployment compensation Amt 50KLT75K',
#  'Unemployment compensation Amt 75KLT100K',
#  'Unemployment compensation Amt All',
#  'Unemployment compensation Amt GE200K',
#  'Unemployment compensation Amt LT25K',
#  'Unemployment compensation Ct 100KLT200K',
#  'Unemployment compensation Ct 25KLT50K',
#  'Unemployment compensation Ct 50KLT75K',
#  'Unemployment compensation Ct 75KLT100K',
#  'Unemployment compensation Ct All',
#  'Unemployment compensation Ct GE200K',
#  'Unemployment compensation Ct LT25K',
#  'Attrtion_Reason_RemainedinEducation',
#  'Attrtion_Reason_PersonalReasons',
#  'Attrtion_Reason_InitiatedbyLEA',
#  'category_cd_E',
#  ...]

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1383 entries, closed_ind to esea_attendance_Met
# dtypes: float64(1332), uint8(51)
# memory usage: 24.8 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 365 entries, closed_ind to esea_attendance_Met
# dtypes: float64(333), uint8(32)
# memory usage: 6.3 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Data columns (total 366 columns):
# closed_ind                                                                         float64
# student_num                                                                        float64
# lea_avg_student_num                                                                float64
# st_avg_student_num                                                                 float64
# Math I_Size                                                                        float64
# lea_total_expense_num                                                              float64
# lea_salary_expense_pct                                                             float64
# lea_benefits_expense_pct                                                           float64
# lea_services_expense_pct                                                           float64
# lea_supplies_expense_pct                                                           float64
# lea_instruct_equip_exp_pct                                                         float64
# lea_federal_perpupil_num                                                           float64
# lea_local_perpupil_num                                                             float64
# lea_state_perpupil_num                                                             float64
# SBE Region                                                                         float64
# SPG Score                                                                          float64
# Reading  SPG Score                                                                 float64
# EVAAS Growth Score                                                                 float64
# Science Score                                                                      float64
# Math I Score                                                                       float64
# EOG/EOCSubjects_CACR_All                                                           float64
# EOGGr3_CACR_All                                                                    float64
# EOGGr4_CACR_All                                                                    float64
# EOGGr5_CACR_All                                                                    float64
# EOCMathI_CACR_AmericanIndian                                                       float64
# EOCSubjects_CACR_AmericanIndian                                                    float64
# EOG/EOCSubjects_CACR_AmericanIndian                                                float64
# EOGGr3_CACR_AmericanIndian                                                         float64
# EOGGr4_CACR_AmericanIndian                                                         float64
# EOGGr5_CACR_AmericanIndian                                                         float64
# EOGMathGr3_CACR_AmericanIndian                                                     float64
# EOGMathGr3-8_CACR_AmericanIndian                                                   float64
# EOGMathGr4_CACR_AmericanIndian                                                     float64
# EOGMathGr5_CACR_AmericanIndian                                                     float64
# EOGReadingGr3_CACR_AmericanIndian                                                  float64
# EOGReadingGr3-8_CACR_AmericanIndian                                                float64
# EOGReadingGr4_CACR_AmericanIndian                                                  float64
# EOGReadingGr5_CACR_AmericanIndian                                                  float64
# EOGScienceGr5_CACR_AmericanIndian                                                  float64
# EOGScienceGr5&8_CACR_AmericanIndian                                                float64
# EOGSubjects_CACR_AmericanIndian                                                    float64
# EOCMathI_CACR_Asian                                                                float64
# EOCSubjects_CACR_Asian                                                             float64
# EOG/EOCSubjects_CACR_Asian                                                         float64
# EOGGr3_CACR_Asian                                                                  float64
# EOGGr4_CACR_Asian                                                                  float64
# EOGGr5_CACR_Asian                                                                  float64
# EOGMathGr3_CACR_Asian                                                              float64
# EOGMathGr3-8_CACR_Asian                                                            float64
# EOGMathGr4_CACR_Asian                                                              float64
# EOGMathGr5_CACR_Asian                                                              float64
# EOGReadingGr5_CACR_Asian                                                           float64
# EOGScienceGr5&8_CACR_Asian                                                         float64
# EOGSubjects_CACR_Asian                                                             float64
# EOCMathI_CACR_Black                                                                float64
# EOG/EOCSubjects_CACR_Black                                                         float64
# EOGGr3_CACR_Black                                                                  float64
# EOGGr4_CACR_Black                                                                  float64
# EOGGr5_CACR_Black                                                                  float64
# EOGMathGr3_CACR_Black                                                              float64
# EOGMathGr3-8_CACR_Black                                                            float64
# EOGMathGr4_CACR_Black                                                              float64
# EOGMathGr5_CACR_Black                                                              float64
# EOGReadingGr3_CACR_Black                                                           float64
# EOGReadingGr3-8_CACR_Black                                                         float64
# EOGReadingGr4_CACR_Black                                                           float64
# EOGReadingGr5_CACR_Black                                                           float64
# EOGReadingGr5_GLP_Black                                                            float64
# EOGScienceGr5_CACR_Black                                                           float64
# EOGScienceGr5&8_CACR_Black                                                         float64
# EOGSubjects_CACR_Black                                                             float64
# EOCMathI_CACR_Hispanic                                                             float64
# EOCSubjects_CACR_Hispanic                                                          float64
# EOG/EOCSubjects_CACR_Hispanic                                                      float64
# EOG/EOCSubjects_GLP_Hispanic                                                       float64
# EOGGr3_CACR_Hispanic                                                               float64
# EOGGr4_CACR_Hispanic                                                               float64
# EOGGr5_CACR_Hispanic                                                               float64
# EOGMathGr3_CACR_Hispanic                                                           float64
# EOGMathGr3-8_CACR_Hispanic                                                         float64
# EOGMathGr4_CACR_Hispanic                                                           float64
# EOGMathGr5_CACR_Hispanic                                                           float64
# EOGReadingGr3_CACR_Hispanic                                                        float64
# EOGReadingGr3-8_CACR_Hispanic                                                      float64
# EOGReadingGr3-8_GLP_Hispanic                                                       float64
# EOGReadingGr4_CACR_Hispanic                                                        float64
# EOGReadingGr5_CACR_Hispanic                                                        float64
# EOGReadingGr5_GLP_Hispanic                                                         float64
# EOGScienceGr5_CACR_Hispanic                                                        float64
# EOGScienceGr5&8_CACR_Hispanic                                                      float64
# EOGSubjects_CACR_Hispanic                                                          float64
# EOCMathI_CACR_TwoorMoreRaces                                                       float64
# EOCSubjects_CACR_TwoorMoreRaces                                                    float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                                                float64
# EOGGr3_CACR_TwoorMoreRaces                                                         float64
# EOGGr4_CACR_TwoorMoreRaces                                                         float64
# EOGGr5_CACR_TwoorMoreRaces                                                         float64
# EOGMathGr3_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                                                   float64
# EOGMathGr4_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr5_CACR_TwoorMoreRaces                                                     float64
# EOGReadingGr3_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                                                float64
# EOGReadingGr4_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                                                float64
# EOGSubjects_CACR_TwoorMoreRaces                                                    float64
# EOG/EOCSubjects_CACR_White                                                         float64
# EOGGr3_CACR_White                                                                  float64
# EOGGr4_CACR_White                                                                  float64
# EOGMathGr3-8_CACR_White                                                            float64
# EOGReadingGr3-8_CACR_White                                                         float64
# EOGScienceGr5&8_CACR_White                                                         float64
# EOCMathI_CACR_EDS                                                                  float64
# EOG/EOCSubjects_CACR_EDS                                                           float64
# EOGGr4_CACR_EDS                                                                    float64
# EOGMathGr3-8_CACR_EDS                                                              float64
# EOGReadingGr3-8_CACR_EDS                                                           float64
# EOGReadingGr5_CACR_EDS                                                             float64
# EOGScienceGr5&8_CACR_EDS                                                           float64
# EOCMathI_CACR_LEP                                                                  float64
# EOCMathI_GLP_LEP                                                                   float64
# EOCSubjects_CACR_LEP                                                               float64
# EOCSubjects_GLP_LEP                                                                float64
# EOG/EOCSubjects_CACR_LEP                                                           float64
# EOG/EOCSubjects_GLP_LEP                                                            float64
# EOGGr3_CACR_LEP                                                                    float64
# EOGGr4_CACR_LEP                                                                    float64
# EOGGr4_GLP_LEP                                                                     float64
# EOGGr5_CACR_LEP                                                                    float64
# EOGGr5_GLP_LEP                                                                     float64
# EOGMathGr3_CACR_LEP                                                                float64
# EOGMathGr3-8_CACR_LEP                                                              float64
# EOGMathGr3-8_GLP_LEP                                                               float64
# EOGMathGr4_CACR_LEP                                                                float64
# EOGMathGr4_GLP_LEP                                                                 float64
# EOGMathGr5_CACR_LEP                                                                float64
# EOGMathGr5_GLP_LEP                                                                 float64
# EOGReadingGr3_CACR_LEP                                                             float64
# EOGReadingGr3_GLP_LEP                                                              float64
# EOGReadingGr3-8_CACR_LEP                                                           float64
# EOGReadingGr3-8_GLP_LEP                                                            float64
# EOGReadingGr4_CACR_LEP                                                             float64
# EOGReadingGr4_GLP_LEP                                                              float64
# EOGReadingGr5_CACR_LEP                                                             float64
# EOGReadingGr5_GLP_LEP                                                              float64
# EOGScienceGr5_CACR_LEP                                                             float64
# EOGScienceGr5_GLP_LEP                                                              float64
# EOGScienceGr5&8_CACR_LEP                                                           float64
# EOGScienceGr5&8_GLP_LEP                                                            float64
# EOGSubjects_CACR_LEP                                                               float64
# EOGSubjects_GLP_LEP                                                                float64
# EOCMathI_CACR_SWD                                                                  float64
# EOCMathI_GLP_SWD                                                                   float64
# EOCSubjects_CACR_SWD                                                               float64
# EOCSubjects_GLP_SWD                                                                float64
# EOG/EOCSubjects_CACR_SWD                                                           float64
# EOG/EOCSubjects_GLP_SWD                                                            float64
# EOGGr3_CACR_SWD                                                                    float64
# EOGGr3_GLP_SWD                                                                     float64
# EOGGr4_CACR_SWD                                                                    float64
# EOGGr4_GLP_SWD                                                                     float64
# EOGGr5_CACR_SWD                                                                    float64
# EOGMathGr3_CACR_SWD                                                                float64
# EOGMathGr3_GLP_SWD                                                                 float64
# EOGMathGr3-8_CACR_SWD                                                              float64
# EOGMathGr3-8_GLP_SWD                                                               float64
# EOGMathGr4_CACR_SWD                                                                float64
# EOGMathGr4_GLP_SWD                                                                 float64
# EOGMathGr5_CACR_SWD                                                                float64
# EOGMathGr5_GLP_SWD                                                                 float64
# EOGReadingGr3_CACR_SWD                                                             float64
# EOGReadingGr3_GLP_SWD                                                              float64
# EOGReadingGr3-8_CACR_SWD                                                           float64
# EOGReadingGr3-8_GLP_SWD                                                            float64
# EOGReadingGr4_CACR_SWD                                                             float64
# EOGReadingGr4_GLP_SWD                                                              float64
# EOGReadingGr5_CACR_SWD                                                             float64
# EOGReadingGr5_GLP_SWD                                                              float64
# EOGScienceGr5_CACR_SWD                                                             float64
# EOGScienceGr5_GLP_SWD                                                              float64
# EOGScienceGr5&8_CACR_SWD                                                           float64
# EOGScienceGr5&8_GLP_SWD                                                            float64
# EOGSubjects_CACR_SWD                                                               float64
# EOCMathI_CACR_AIG                                                                  float64
# EOG/EOCSubjects_CACR_AIG                                                           float64
# EOGGr3_CACR_AIG                                                                    float64
# EOGGr4_CACR_AIG                                                                    float64
# EOGGr5_CACR_AIG                                                                    float64
# EOGMathGr3_CACR_AIG                                                                float64
# EOGMathGr3-8_CACR_AIG                                                              float64
# EOGMathGr4_CACR_AIG                                                                float64
# EOGMathGr5_CACR_AIG                                                                float64
# EOGScienceGr5&8_CACR_AIG                                                           float64
# EOGSubjects_CACR_AIG                                                               float64
# pct_GCE_ALL                                                                        float64
# pct_PROMOTED                                                                       float64
# MathGr3-8_pTarget_PctMet                                                           float64
# ReadingGr3-8_pTarget_PctMet                                                        float64
# SciGr5&8_pTarget_PctMet                                                            float64
# TotalTargets_pTarget_PctMet                                                        float64
# lea_sat_avg_score_num                                                              float64
# lea_sat_participation_pct                                                          float64
# lea_ap_participation_pct                                                           float64
# lea_ap_pct_3_or_above                                                              float64
# lea_ib_pct_4_or_above                                                              float64
# avg_daily_attend_pct                                                               float64
# crime_per_c_num                                                                    float64
# short_susp_per_c_num                                                               float64
# long_susp_per_c_num                                                                float64
# expelled_per_c_num                                                                 float64
# stud_internet_comp_num                                                             float64
# lea_avg_daily_attend_pct                                                           float64
# lea_crime_per_c_num                                                                float64
# lea_short_susp_per_c_num                                                           float64
# lea_long_susp_per_c_num                                                            float64
# lea_expelled_per_c_num                                                             float64
# lea_stud_internet_comp_num                                                         float64
# st_crime_per_c_num                                                                 float64
# st_short_susp_per_c_num                                                            float64
# st_long_susp_per_c_num                                                             float64
# st_expelled_per_c_num                                                              float64
# flicensed_teach_pct                                                                float64
# tchyrs_0thru3_pct                                                                  float64
# tchyrs_4thru10_pct                                                                 float64
# tchyrs_11plus_pct                                                                  float64
# nbpts_num                                                                          float64
# advance_dgr_pct                                                                    float64
# _1yr_tchr_trnovr_pct                                                               float64
# lateral_teach_pct                                                                  float64
# lea_flicensed_teach_pct                                                            float64
# lea_tchyrs_0thru3_pct                                                              float64
# lea_tchyrs_4thru10_pct                                                             float64
# lea_tchyrs_11plus_pct                                                              float64
# lea_nbpts_num                                                                      float64
# lea_advance_dgr_pct                                                                float64
# lea_1yr_tchr_trnovr_pct                                                            float64
# lea_emer_prov_teach_pct                                                            float64
# lea_lateral_teach_pct                                                              float64
# st_flicensed_teach_pct                                                             float64
# st_tchyrs_0thru3_pct                                                               float64
# st_tchyrs_4thru10_pct                                                              float64
# st_nbpts_num                                                                       float64
# st_advance_dgr_pct                                                                 float64
# st_1yr_tchr_trnovr_pct                                                             float64
# st_emer_prov_teach_pct                                                             float64
# st_lateral_teach_pct                                                               float64
# 0-3 Years_LEA_Exp_Pct_Prin                                                         float64
# 10+ Years_LEA_Exp_Pct_Prin                                                         float64
# 4-10 Years_LEA_Exp_Pct_Prin                                                        float64
# Accomplished_TCHR_Standard 1_Pct                                                   float64
# Accomplished_TCHR_Standard 2_Pct                                                   float64
# Accomplished_TCHR_Standard 3_Pct                                                   float64
# Accomplished_TCHR_Standard 4_Pct                                                   float64
# Accomplished_TCHR_Standard 5_Pct                                                   float64
# Developing_TCHR_Standard 1_Pct                                                     float64
# Developing_TCHR_Standard 2_Pct                                                     float64
# Developing_TCHR_Standard 3_Pct                                                     float64
# Developing_TCHR_Standard 4_Pct                                                     float64
# Developing_TCHR_Standard 5_Pct                                                     float64
# Distinguished_TCHR_Standard 1_Pct                                                  float64
# Distinguished_TCHR_Standard 2_Pct                                                  float64
# Distinguished_TCHR_Standard 3_Pct                                                  float64
# Distinguished_TCHR_Standard 4_Pct                                                  float64
# Distinguished_TCHR_Standard 5_Pct                                                  float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct                                  float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct                                        float64
# Meets Expected Growth_TCHR_Standard 6_Pct                                          float64
# Not Demostrated_TCHR_Standard 1_Pct                                                float64
# Not Demostrated_TCHR_Standard 2_Pct                                                float64
# Not Demostrated_TCHR_Standard 4_Pct                                                float64
# Proficient_TCHR_Standard 1_Pct                                                     float64
# Proficient_TCHR_Standard 2_Pct                                                     float64
# Proficient_TCHR_Standard 3_Pct                                                     float64
# Proficient_TCHR_Standard 4_Pct                                                     float64
# Proficient_TCHR_Standard 5_Pct                                                     float64
# IndianPct                                                                          float64
# AsianPct                                                                           float64
# HispanicPct                                                                        float64
# BlackPct                                                                           float64
# WhitePct                                                                           float64
# PacificIslandPct                                                                   float64
# TwoOrMorePct                                                                       float64
# PacificIslandMalePct                                                               float64
# TwoOrMoreMalePct                                                                   float64
# PacificIslandFemalePct                                                             float64
# TwoOrMoreFemalePct                                                                 float64
# Year                                                                               float64
# Crime_Rate_Index_Rate                                                              float64
# Crime_Rate_Violent_Rate                                                            float64
# Crime_Rate_Murder_Rate                                                             float64
# Crime_Rate_Rape_Rate                                                               float64
# Crime_Rate_Robbery_Rate                                                            float64
# Crime_Rate_Burglary_Rate                                                           float64
# Crime_Rate_MVT_Rate                                                                float64
# Crime_Rate_Arson_Rate                                                              float64
# Add Medicare tax Amt 100KLT200K                                                    float64
# Add child tax credit Amt 75KLT100K                                                 float64
# Alternative minimum tax Amt 25KLT50K                                               float64
# Alternative minimum tax Amt 50KLT75K                                               float64
# Alternative minimum tax Amt 75KLT100K                                              float64
# Alternative minimum tax Amt LT25K                                                  float64
# Alternative minimum tax Ct 75KLT100K                                               float64
# Alternative minimum tax Ct LT25K                                                   float64
# Domestic production activities deduction Amt 100KLT200K                            float64
# Domestic production activities deduction Amt 25KLT50K                              float64
# Domestic production activities deduction Amt 50KLT75K                              float64
# Domestic production activities deduction Amt 75KLT100K                             float64
# Domestic production activities deduction Amt LT25K                                 float64
# Domestic production activities deduction Ct 25KLT50K                               float64
# Domestic production activities deduction Ct 50KLT75K                               float64
# Domestic production activities deduction Ct 75KLT100K                              float64
# Domestic production activities deduction Ct LT25K                                  float64
# Number of farm returns 100KLT200K                                                  float64
# Number of farm returns 25KLT50K                                                    float64
# Number of farm returns 50KLT75K                                                    float64
# Number of farm returns 75KLT100K                                                   float64
# Number of farm returns All                                                         float64
# Number of farm returns GE200K                                                      float64
# Number of farm returns LT25K                                                       float64
# Partnership/S-corp net income (less loss) Amt LT25K                                float64
# Residential energy tax credit Amt LT25K                                            float64
# Self-employment retirement plans Amt 25KLT50K                                      float64
# Self-employment retirement plans Ct LT25K                                          float64
# LEACode                                                                            float64
# Attrtion_Reason_RemainedinEducationPerct                                           float64
# Attrtion_Reason_PersonalPerct                                                      float64
# Attrtion_Reason_InitiatedPerct                                                     float64
# Attrtion_Reason_BeyondControlofLEA                                                 float64
# Attrtion_Reason_BeyondControlPerct                                                 float64
# Attrtion_Reason_OtherReasons                                                       float64
# Attrtion_Reason_OtherReasonsPerct                                                  float64
# category_cd_I                                                                      uint8
# category_cd_M                                                                      uint8
# category_cd_T                                                                      uint8
# calendar_type_txt_Hospital School                                                  uint8
# calendar_type_txt_Magnet School, Traditional Calendar                              uint8
# calendar_type_txt_Magnet School, Year-Round Calendar                               uint8
# calendar_type_txt_Regular School, Traditional Calendar                             uint8
# calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar    uint8
# calendar_type_txt_Regular School, Year-Round Calendar                              uint8
# calendar_type_txt_Special Education, Traditional Calendar                          uint8
# school_type_txt_Regular School                                                     uint8
# esea_status_P                                                                      uint8
# esea_status_R                                                                      uint8
# esea_status_RF                                                                     uint8
# esea_status_RP                                                                     uint8
# Grad_project_status_Y                                                              uint8
# SPG Grade_B                                                                        uint8
# SPG Grade_C                                                                        uint8
# SPG Grade_D                                                                        uint8
# SPG Grade_F                                                                        uint8
# SPG Grade_I                                                                        uint8
# Reading SPG Grade_B                                                                uint8
# Reading SPG Grade_C                                                                uint8
# Reading SPG Grade_D                                                                uint8
# Reading SPG Grade_F                                                                uint8
# Math SPG Grade_B                                                                   uint8
# Math SPG Grade_C                                                                   uint8
# Math SPG Grade_D                                                                   uint8
# Math SPG Grade_F                                                                   uint8
# EVAAS Growth Status_Met                                                            uint8
# EVAAS Growth Status_NotMet                                                         uint8
# esea_attendance_Met                                                                uint8
# unit_code                                                                          object
# dtypes: float64(333), object(1), uint8(32)
# memory usage: 6.3+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.1
# Pandas Version: 0.24.2

# %%
print ('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2014/Machine Learning Datasets/PublicSchools2014_ML.csv
