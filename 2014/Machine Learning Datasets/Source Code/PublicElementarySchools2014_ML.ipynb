# %% [markdown]
# # Create Public School Machine Learning Datasets for Teacher Retention
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
# * Added Criminal data set and teacher attrition by reason data set.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2014

#Location where copies of the raw data files will be read in from csv files.
#use relative path then don't have to make the changes for the user every time as long
# as it follow the same structure.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools' + str(schoolYear)
#inputFileName = 'PublicHighSchools' + str(schoolYear)
#inputFileName = 'PublicMiddleSchools' + str(schoolYear)
inputFileName = 'PublicElementarySchools' + str(schoolYear)

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
#use relative path then don't have to make the changes for the user every time as long
# as it follow the same structure.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.80

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 10

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
#Rename Lea_Name to District Name
schoolData.rename(columns={'Lea_Name': 'District Name'}, inplace=True)
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Columns: 2055 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(2015), int64(3), object(37)
# memory usage: 20.4+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Columns: 2055 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(2015), int64(3), object(37)
# memory usage: 20.4+ MB

# %%
#schoolData

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#schoolData.info(verbose=True)

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print ('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Columns: 1843 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(1810), object(33)
# memory usage: 18.3+ MB
#
# Columns Deleted:  212

# %%
for it in SingleValueCols:
    print(it)
# Out:
# year
# state_ad
# type_cd
# closed_ind
# new_ind
# super_nm
# cover_letter_ad
# school_type_txt
# clp_ind
# focus_clp_ind
# summer_program_ind
# asm_no_spg_ind
# no_data_spg_ind
# State_Name
# total_expense_num
# salary_expense_pct
# benefits_expense_pct
# services_expense_pct
# supplies_expense_pct
# instruct_equip_exp_pct
# other_expense_pct
# federal_perpupil_num
# local_perpupil_num
# state_perpupil_num
# lea_other_expense_pct
# st_total_expense_num
# st_salary_expense_pct
# st_benefits_expense_pct
# st_services_expense_pct
# st_supplies_expense_pct
# st_instruct_equip_exp_pct
# st_other_expense_pct
# st_federal_perpupil_num
# st_local_perpupil_num
# st_state_perpupil_num
# building_expense_pct
# lea_building_expense_pct
# st_building_expense_pct
# ACT_pTarget_PctMet
# ACTWorkKeys_pTarget_PctMet
# SciGr11_pTarget_PctMet
# st_sat_avg_score_num
# nat_sat_avg_score_num
# st_sat_participation_pct
# nat_sat_participation_pct
# lea_esea_attendance
# st_ap_participation_pct
# st_ap_pct_3_or_above
# ib_participation_pct
# lea_ib_participation_pct
# st_ib_participation_pct
# ib_pct_4_or_above
# st_ib_pct_4_or_above
# AS7_Asian_ENROLL_sch_pct
# AS7_Asian_NOENROLL_sch_pct
# LEP_Limited English Proficiency_ENROLL_sch_pct
# LEP_Limited English Proficiency_NOENROLL_sch_pct
# PI7_Pacific Islander_ENROLL_sch_pct
# PI7_Pacific Islander_NOENROLL_sch_pct
# ttl_crimes_num
# st_long_susp_per_c_num
# st_expelled_per_c_num
# st_stud_internet_comp_num
# digital_media_pct
# Byod
# grades_BYOD
# avg_age_media_collection
# _1_to_1_access
# books_per_student
# grades_1_to_1_access
# lea_avg_age_media_collection
# lea_books_per_student
# st_avg_age_media_collection
# st_books_per_student
# wap_num
# wap_per_classroom
# lea_wap_num
# lea_wap_per_classroom
# st_wap_num
# st_wap_per_classroom
# SRC_devices_sent_home
# SRC_Grades_Devices_Sent_Home
# total_class_teacher_num
# total_nbpts_num
# prin_other_pct
# prinyrs_0thru3_pct
# prinyrs_4thru10_pct
# prinyrs_11plus_pct
# prin_advance_dgr_pct
# _1yr_prin_trnovr_pct
# prin_male_pct
# prin_female_pct
# prin_black_pct
# prin_white_pct
# highqual_class_pct
# lea_highqual_class_pct
# lea_highqual_class_hp_pct
# lea_highqual_class_lp_pct
# lea_highqual_class_all_pct
# lea_not_highqual_class_hp_pct
# lea_not_highqual_class_lp_pct
# lea_not_highqual_class_all_pct
# st_emer_prov_teach_pct
# st_highqual_class_pct
# st_highqual_class_hp_pct
# st_highqual_class_lp_pct
# st_highqual_class_all_pct
# st_not_highqual_class_hp_pct
# st_not_highqual_class_lp_pct
# st_not_highqual_class_all_pct
# st_prinyrs_0thru3_pct
# st_prinyrs_4thru10_pct
# st_prinyrs_11plus_pct
# st_prin_advance_dgr_pct
# st_1yr_prin_trnovr_pct
# st_prin_male_pct
# st_prin_female_pct
# st_prin_black_pct
# st_prin_white_pct
# st_prin_other_pct
# Accomplished_PRIN_Standard 1_Pct
# Accomplished_PRIN_Standard 2_Pct
# Accomplished_PRIN_Standard 3_Pct
# Accomplished_PRIN_Standard 4_Pct
# Accomplished_PRIN_Standard 5_Pct
# Accomplished_PRIN_Standard 6_Pct
# Accomplished_PRIN_Standard 7_Pct
# Developing_PRIN_Standard 1_Pct
# Developing_PRIN_Standard 2_Pct
# Developing_PRIN_Standard 3_Pct
# Developing_PRIN_Standard 4_Pct
# Developing_PRIN_Standard 5_Pct
# Developing_PRIN_Standard 6_Pct
# Developing_PRIN_Standard 7_Pct
# Distinguished_PRIN_Standard 1_Pct
# Distinguished_PRIN_Standard 2_Pct
# Distinguished_PRIN_Standard 3_Pct
# Distinguished_PRIN_Standard 4_Pct
# Distinguished_PRIN_Standard 5_Pct
# Distinguished_PRIN_Standard 6_Pct
# Distinguished_PRIN_Standard 7_Pct
# Does Not Meet Expected Growth_PRIN_Standard 8_Pct
# Exceeds Expected Growth_PRIN_Standard 8_Pct
# Meets Expected Growth_PRIN_Standard 8_Pct
# Not Demostrated_PRIN_Standard 1_Pct
# Not Demostrated_PRIN_Standard 2_Pct
# Not Demostrated_PRIN_Standard 3_Pct
# Not Demostrated_PRIN_Standard 4_Pct
# Not Demostrated_PRIN_Standard 5_Pct
# Not Demostrated_PRIN_Standard 6_Pct
# Not Demostrated_PRIN_Standard 7_Pct
# Proficient_PRIN_Standard 1_Pct
# Proficient_PRIN_Standard 2_Pct
# Proficient_PRIN_Standard 3_Pct
# Proficient_PRIN_Standard 4_Pct
# Proficient_PRIN_Standard 5_Pct
# Proficient_PRIN_Standard 6_Pct
# Proficient_PRIN_Standard 7_Pct
# Add Medicare tax Amt 25KLT50K
# Add Medicare tax Amt 50KLT75K
# Add Medicare tax Amt 75KLT100K
# Add Medicare tax Amt LT25K
# Add Medicare tax Ct 25KLT50K
# Add Medicare tax Ct 50KLT75K
# Add Medicare tax Ct 75KLT100K
# Add Medicare tax Ct LT25K
# Add child tax credit Amt 100KLT200K
# Add child tax credit Amt GE200K
# Add child tax credit Ct 100KLT200K
# Add child tax credit Ct GE200K
# Child tax credit Amt GE200K
# Child tax credit Ct GE200K
# Earned income credit Amt 100KLT200K
# Earned income credit Amt 50KLT75K
# Earned income credit Amt 75KLT100K
# Earned income credit Amt GE200K
# Earned income credit Ct 100KLT200K
# Earned income credit Ct 50KLT75K
# Earned income credit Ct 75KLT100K
# Earned income credit Ct GE200K
# Excess earned income credit (refundable) Amt 100KLT200K
# Excess earned income credit (refundable) Amt 50KLT75K
# Excess earned income credit (refundable) Amt 75KLT100K
# Excess earned income credit (refundable) Amt GE200K
# Excess earned income credit (refundable) Ct 100KLT200K
# Excess earned income credit (refundable) Ct 50KLT75K
# Excess earned income credit (refundable) Ct 75KLT100K
# Excess earned income credit (refundable) Ct GE200K
# Net investment income tax Amt 100KLT200K
# Net investment income tax Amt 25KLT50K
# Net investment income tax Amt 50KLT75K
# Net investment income tax Amt 75KLT100K
# Net investment income tax Amt LT25K
# Net investment income tax Ct 100KLT200K
# Net investment income tax Ct 25KLT50K
# Net investment income tax Ct 50KLT75K
# Net investment income tax Ct 75KLT100K
# Net investment income tax Ct LT25K
# Nonrefundable edu credit Amt GE200K
# Nonrefundable edu credit Ct GE200K
# Refundable edu credit Amt GE200K
# Refundable edu credit Ct GE200K
# Retirement savings contribution credit Amt 100KLT200K
# Retirement savings contribution credit Amt 75KLT100K
# Retirement savings contribution credit Amt GE200K
# Retirement savings contribution credit Ct 100KLT200K
# Retirement savings contribution credit Ct 75KLT100K
# Retirement savings contribution credit Ct GE200K
# Student loan interest deduction Amt GE200K
# Student loan interest deduction Ct GE200K
# Tuition and fees deduction Amt GE200K
# Tuition and fees deduction Ct GE200K

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Columns: 1841 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(1810), object(31)
# memory usage: 18.3+ MB
#
# Columns Deleted:  2

# %%
for it in AllUniqueValueCols:
    print(it)
# Out:
# unit_code
# School_Name

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Columns: 1841 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(1810), object(31)
# memory usage: 18.3+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print( "Boolean Columns: ", sD_boolean.shape[1])
print( "Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  31
# Continuous Columns:  1810
# Columns Accounted for:  1841

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Columns: 1293 entries, vphone_ad to OtherReasonsPerct
# dtypes: float64(1262), object(31)
# memory usage: 12.8+ MB
#
# Columns Deleted:  548

# %%
for it in NullValueCols:
    print(it)
# Out:
# Biology_Size
# English II_Size
# Math I_Size
# Math I Score
# English II Score
# Biology Score
# The ACT Score
# ACT WorkKeys Score
# Math Course Rigor Score
# Cohort Graduation Rate Standard Score
# ACTCompositeScore_UNCMin_All
# ACTEnglish_ACTBenchmark_All
# ACTMath_ACTBenchmark_All
# ACTReading_ACTBenchmark_All
# ACTScience_ACTBenchmark_All
# ACTSubtests_BenchmarksMet_All
# ACTWorkKeys_SilverPlus_All
# ACTWriting_ACTBenchmark_All
# EOCBiology_CACR_All
# EOCBiology_GLP_All
# EOCEnglish2_CACR_All
# EOCEnglish2_GLP_All
# EOCMathI_CACR_All
# EOCMathI_GLP_All
# EOCSubjects_CACR_All
# EOCSubjects_GLP_All
# EOGGr6_CACR_All
# EOGGr6_GLP_All
# EOGGr7_CACR_All
# EOGGr7_GLP_All
# EOGGr8_CACR_All
# EOGGr8_GLP_All
# EOGMathGr6_CACR_All
# EOGMathGr6_GLP_All
# EOGMathGr7_CACR_All
# EOGMathGr7_GLP_All
# EOGMathGr8_CACR_All
# EOGMathGr8_GLP_All
# EOGReadingGr6_CACR_All
# EOGReadingGr6_GLP_All
# EOGReadingGr7_CACR_All
# EOGReadingGr7_GLP_All
# EOGReadingGr8_CACR_All
# EOGReadingGr8_GLP_All
# EOGScienceGr8_CACR_All
# EOGScienceGr8_GLP_All
# GraduationRate_4yr_All
# GraduationRate_5yr_All
# ACTCompositeScore_UNCMin_Female
# ACTEnglish_ACTBenchmark_Female
# ACTMath_ACTBenchmark_Female
# ACTReading_ACTBenchmark_Female
# ACTScience_ACTBenchmark_Female
# ACTSubtests_BenchmarksMet_Female
# ACTWorkKeys_SilverPlus_Female
# ACTWriting_ACTBenchmark_Female
# EOCBiology_CACR_Female
# EOCBiology_GLP_Female
# EOCEnglish2_CACR_Female
# EOCEnglish2_GLP_Female
# EOCMathI_CACR_Female
# EOCMathI_GLP_Female
# EOCSubjects_CACR_Female
# EOCSubjects_GLP_Female
# EOGGr6_CACR_Female
# EOGGr6_GLP_Female
# EOGGr7_CACR_Female
# EOGGr7_GLP_Female
# EOGGr8_CACR_Female
# EOGGr8_GLP_Female
# EOGMathGr6_CACR_Female
# EOGMathGr6_GLP_Female
# EOGMathGr7_CACR_Female
# EOGMathGr7_GLP_Female
# EOGMathGr8_CACR_Female
# EOGMathGr8_GLP_Female
# EOGReadingGr6_CACR_Female
# EOGReadingGr6_GLP_Female
# EOGReadingGr7_CACR_Female
# EOGReadingGr7_GLP_Female
# EOGReadingGr8_CACR_Female
# EOGReadingGr8_GLP_Female
# EOGScienceGr8_CACR_Female
# EOGScienceGr8_GLP_Female
# GraduationRate_4yr_Female
# GraduationRate_5yr_Female
# ACTCompositeScore_UNCMin_Male
# ACTEnglish_ACTBenchmark_Male
# ACTMath_ACTBenchmark_Male
# ACTReading_ACTBenchmark_Male
# ACTScience_ACTBenchmark_Male
# ACTSubtests_BenchmarksMet_Male
# ACTWorkKeys_SilverPlus_Male
# ACTWriting_ACTBenchmark_Male
# EOCBiology_CACR_Male
# EOCBiology_GLP_Male
# EOCEnglish2_CACR_Male
# EOCEnglish2_GLP_Male
# EOCMathI_CACR_Male
# EOCMathI_GLP_Male
# EOCSubjects_CACR_Male
# EOCSubjects_GLP_Male
# EOGGr6_CACR_Male
# EOGGr6_GLP_Male
# EOGGr7_CACR_Male
# EOGGr7_GLP_Male
# EOGGr8_CACR_Male
# EOGGr8_GLP_Male
# EOGMathGr6_CACR_Male
# EOGMathGr6_GLP_Male
# EOGMathGr7_CACR_Male
# EOGMathGr7_GLP_Male
# EOGMathGr8_CACR_Male
# EOGMathGr8_GLP_Male
# EOGReadingGr6_CACR_Male
# EOGReadingGr6_GLP_Male
# EOGReadingGr7_CACR_Male
# EOGReadingGr7_GLP_Male
# EOGReadingGr8_CACR_Male
# EOGReadingGr8_GLP_Male
# EOGScienceGr8_CACR_Male
# EOGScienceGr8_GLP_Male
# GraduationRate_4yr_Male
# GraduationRate_5yr_Male
# ACTCompositeScore_UNCMin_AmericanIndian
# ACTEnglish_ACTBenchmark_AmericanIndian
# ACTMath_ACTBenchmark_AmericanIndian
# ACTReading_ACTBenchmark_AmericanIndian
# ACTScience_ACTBenchmark_AmericanIndian
# ACTSubtests_BenchmarksMet_AmericanIndian
# ACTWorkKeys_SilverPlus_AmericanIndian
# ACTWriting_ACTBenchmark_AmericanIndian
# EOCBiology_CACR_AmericanIndian
# EOCBiology_GLP_AmericanIndian
# EOCEnglish2_CACR_AmericanIndian
# EOCEnglish2_GLP_AmericanIndian
# EOCMathI_CACR_AmericanIndian
# EOCMathI_GLP_AmericanIndian
# EOCSubjects_CACR_AmericanIndian
# EOCSubjects_GLP_AmericanIndian
# EOGGr6_CACR_AmericanIndian
# EOGGr6_GLP_AmericanIndian
# EOGGr7_CACR_AmericanIndian
# EOGGr7_GLP_AmericanIndian
# EOGGr8_CACR_AmericanIndian
# EOGGr8_GLP_AmericanIndian
# EOGMathGr6_CACR_AmericanIndian
# EOGMathGr6_GLP_AmericanIndian
# EOGMathGr7_CACR_AmericanIndian
# EOGMathGr7_GLP_AmericanIndian
# EOGMathGr8_CACR_AmericanIndian
# EOGMathGr8_GLP_AmericanIndian
# EOGReadingGr6_CACR_AmericanIndian
# EOGReadingGr6_GLP_AmericanIndian
# EOGReadingGr7_CACR_AmericanIndian
# EOGReadingGr7_GLP_AmericanIndian
# EOGReadingGr8_CACR_AmericanIndian
# EOGReadingGr8_GLP_AmericanIndian
# EOGScienceGr8_CACR_AmericanIndian
# EOGScienceGr8_GLP_AmericanIndian
# GraduationRate_4yr_AmericanIndian
# GraduationRate_5yr_AmericanIndian
# ACTCompositeScore_UNCMin_Asian
# ACTEnglish_ACTBenchmark_Asian
# ACTMath_ACTBenchmark_Asian
# ACTReading_ACTBenchmark_Asian
# ACTScience_ACTBenchmark_Asian
# ACTSubtests_BenchmarksMet_Asian
# ACTWorkKeys_SilverPlus_Asian
# ACTWriting_ACTBenchmark_Asian
# EOCBiology_CACR_Asian
# EOCBiology_GLP_Asian
# EOCEnglish2_CACR_Asian
# EOCEnglish2_GLP_Asian
# EOCMathI_CACR_Asian
# EOCMathI_GLP_Asian
# EOCSubjects_CACR_Asian
# EOCSubjects_GLP_Asian
# EOGGr6_CACR_Asian
# EOGGr6_GLP_Asian
# EOGGr7_CACR_Asian
# EOGGr7_GLP_Asian
# EOGGr8_CACR_Asian
# EOGGr8_GLP_Asian
# EOGMathGr6_CACR_Asian
# EOGMathGr6_GLP_Asian
# EOGMathGr7_CACR_Asian
# EOGMathGr7_GLP_Asian
# EOGMathGr8_CACR_Asian
# EOGMathGr8_GLP_Asian
# EOGReadingGr6_CACR_Asian
# EOGReadingGr6_GLP_Asian
# EOGReadingGr7_CACR_Asian
# EOGReadingGr7_GLP_Asian
# EOGReadingGr8_CACR_Asian
# EOGReadingGr8_GLP_Asian
# EOGScienceGr8_CACR_Asian
# EOGScienceGr8_GLP_Asian
# GraduationRate_4yr_Asian
# GraduationRate_5yr_Asian
# ACTCompositeScore_UNCMin_Black
# ACTEnglish_ACTBenchmark_Black
# ACTMath_ACTBenchmark_Black
# ACTReading_ACTBenchmark_Black
# ACTScience_ACTBenchmark_Black
# ACTSubtests_BenchmarksMet_Black
# ACTWorkKeys_SilverPlus_Black
# ACTWriting_ACTBenchmark_Black
# EOCBiology_CACR_Black
# EOCBiology_GLP_Black
# EOCEnglish2_CACR_Black
# EOCEnglish2_GLP_Black
# EOCMathI_CACR_Black
# EOCMathI_GLP_Black
# EOCSubjects_CACR_Black
# EOCSubjects_GLP_Black
# EOGGr6_CACR_Black
# EOGGr6_GLP_Black
# EOGGr7_CACR_Black
# EOGGr7_GLP_Black
# EOGGr8_CACR_Black
# EOGGr8_GLP_Black
# EOGMathGr6_CACR_Black
# EOGMathGr6_GLP_Black
# EOGMathGr7_CACR_Black
# EOGMathGr7_GLP_Black
# EOGMathGr8_CACR_Black
# EOGMathGr8_GLP_Black
# EOGReadingGr6_CACR_Black
# EOGReadingGr6_GLP_Black
# EOGReadingGr7_CACR_Black
# EOGReadingGr7_GLP_Black
# EOGReadingGr8_CACR_Black
# EOGReadingGr8_GLP_Black
# EOGScienceGr8_CACR_Black
# EOGScienceGr8_GLP_Black
# GraduationRate_4yr_Black
# GraduationRate_5yr_Black
# ACTCompositeScore_UNCMin_Hispanic
# ACTEnglish_ACTBenchmark_Hispanic
# ACTMath_ACTBenchmark_Hispanic
# ACTReading_ACTBenchmark_Hispanic
# ACTScience_ACTBenchmark_Hispanic
# ACTSubtests_BenchmarksMet_Hispanic
# ACTWorkKeys_SilverPlus_Hispanic
# ACTWriting_ACTBenchmark_Hispanic
# EOCBiology_CACR_Hispanic
# EOCBiology_GLP_Hispanic
# EOCEnglish2_CACR_Hispanic
# EOCEnglish2_GLP_Hispanic
# EOCMathI_CACR_Hispanic
# EOCMathI_GLP_Hispanic
# EOCSubjects_CACR_Hispanic
# EOCSubjects_GLP_Hispanic
# EOGGr6_CACR_Hispanic
# EOGGr6_GLP_Hispanic
# EOGGr7_CACR_Hispanic
# EOGGr7_GLP_Hispanic
# EOGGr8_CACR_Hispanic
# EOGGr8_GLP_Hispanic
# EOGMathGr6_CACR_Hispanic
# EOGMathGr6_GLP_Hispanic
# EOGMathGr7_CACR_Hispanic
# EOGMathGr7_GLP_Hispanic
# EOGMathGr8_CACR_Hispanic
# EOGMathGr8_GLP_Hispanic
# EOGReadingGr6_CACR_Hispanic
# EOGReadingGr6_GLP_Hispanic
# EOGReadingGr7_CACR_Hispanic
# EOGReadingGr7_GLP_Hispanic
# EOGReadingGr8_CACR_Hispanic
# EOGReadingGr8_GLP_Hispanic
# EOGScienceGr8_CACR_Hispanic
# EOGScienceGr8_GLP_Hispanic
# GraduationRate_4yr_Hispanic
# GraduationRate_5yr_Hispanic
# ACTCompositeScore_UNCMin_TwoorMoreRaces
# ACTEnglish_ACTBenchmark_TwoorMoreRaces
# ACTMath_ACTBenchmark_TwoorMoreRaces
# ACTReading_ACTBenchmark_TwoorMoreRaces
# ACTScience_ACTBenchmark_TwoorMoreRaces
# ACTSubtests_BenchmarksMet_TwoorMoreRaces
# ACTWorkKeys_SilverPlus_TwoorMoreRaces
# ACTWriting_ACTBenchmark_TwoorMoreRaces
# EOCBiology_CACR_TwoorMoreRaces
# EOCBiology_GLP_TwoorMoreRaces
# EOCEnglish2_CACR_TwoorMoreRaces
# EOCEnglish2_GLP_TwoorMoreRaces
# EOCMathI_CACR_TwoorMoreRaces
# EOCMathI_GLP_TwoorMoreRaces
# EOCSubjects_CACR_TwoorMoreRaces
# EOCSubjects_GLP_TwoorMoreRaces
# EOGGr6_CACR_TwoorMoreRaces
# EOGGr6_GLP_TwoorMoreRaces
# EOGGr7_CACR_TwoorMoreRaces
# EOGGr7_GLP_TwoorMoreRaces
# EOGGr8_CACR_TwoorMoreRaces
# EOGGr8_GLP_TwoorMoreRaces
# EOGMathGr6_CACR_TwoorMoreRaces
# EOGMathGr6_GLP_TwoorMoreRaces
# EOGMathGr7_CACR_TwoorMoreRaces
# EOGMathGr7_GLP_TwoorMoreRaces
# EOGMathGr8_CACR_TwoorMoreRaces
# EOGMathGr8_GLP_TwoorMoreRaces
# EOGReadingGr6_CACR_TwoorMoreRaces
# EOGReadingGr6_GLP_TwoorMoreRaces
# EOGReadingGr7_CACR_TwoorMoreRaces
# EOGReadingGr7_GLP_TwoorMoreRaces
# EOGReadingGr8_CACR_TwoorMoreRaces
# EOGReadingGr8_GLP_TwoorMoreRaces
# EOGScienceGr8_CACR_TwoorMoreRaces
# EOGScienceGr8_GLP_TwoorMoreRaces
# GraduationRate_4yr_TwoorMoreRaces
# GraduationRate_5yr_TwoorMoreRaces
# ACTCompositeScore_UNCMin_White
# ACTEnglish_ACTBenchmark_White
# ACTMath_ACTBenchmark_White
# ACTReading_ACTBenchmark_White
# ACTScience_ACTBenchmark_White
# ACTSubtests_BenchmarksMet_White
# ACTWorkKeys_SilverPlus_White
# ACTWriting_ACTBenchmark_White
# EOCBiology_CACR_White
# EOCBiology_GLP_White
# EOCEnglish2_CACR_White
# EOCEnglish2_GLP_White
# EOCMathI_CACR_White
# EOCMathI_GLP_White
# EOCSubjects_CACR_White
# EOCSubjects_GLP_White
# EOGGr6_CACR_White
# EOGGr6_GLP_White
# EOGGr7_CACR_White
# EOGGr7_GLP_White
# EOGGr8_CACR_White
# EOGGr8_GLP_White
# EOGMathGr6_CACR_White
# EOGMathGr6_GLP_White
# EOGMathGr7_CACR_White
# EOGMathGr7_GLP_White
# EOGMathGr8_CACR_White
# EOGMathGr8_GLP_White
# EOGReadingGr6_CACR_White
# EOGReadingGr6_GLP_White
# EOGReadingGr7_CACR_White
# EOGReadingGr7_GLP_White
# EOGReadingGr8_CACR_White
# EOGReadingGr8_GLP_White
# EOGScienceGr8_CACR_White
# EOGScienceGr8_GLP_White
# GraduationRate_4yr_White
# GraduationRate_5yr_White
# ACTCompositeScore_UNCMin_EDS
# ACTEnglish_ACTBenchmark_EDS
# ACTMath_ACTBenchmark_EDS
# ACTReading_ACTBenchmark_EDS
# ACTScience_ACTBenchmark_EDS
# ACTSubtests_BenchmarksMet_EDS
# ACTWorkKeys_SilverPlus_EDS
# ACTWriting_ACTBenchmark_EDS
# EOCBiology_CACR_EDS
# EOCBiology_GLP_EDS
# EOCEnglish2_CACR_EDS
# EOCEnglish2_GLP_EDS
# EOCMathI_CACR_EDS
# EOCMathI_GLP_EDS
# EOCSubjects_CACR_EDS
# EOCSubjects_GLP_EDS
# EOGGr6_CACR_EDS
# EOGGr6_GLP_EDS
# EOGGr7_CACR_EDS
# EOGGr7_GLP_EDS
# EOGGr8_CACR_EDS
# EOGGr8_GLP_EDS
# EOGMathGr6_CACR_EDS
# EOGMathGr6_GLP_EDS
# EOGMathGr7_CACR_EDS
# EOGMathGr7_GLP_EDS
# EOGMathGr8_CACR_EDS
# EOGMathGr8_GLP_EDS
# EOGReadingGr6_CACR_EDS
# EOGReadingGr6_GLP_EDS
# EOGReadingGr7_CACR_EDS
# EOGReadingGr7_GLP_EDS
# EOGReadingGr8_CACR_EDS
# EOGReadingGr8_GLP_EDS
# EOGScienceGr8_CACR_EDS
# EOGScienceGr8_GLP_EDS
# GraduationRate_4yr_EDS
# GraduationRate_5yr_EDS
# ACTCompositeScore_UNCMin_LEP
# ACTEnglish_ACTBenchmark_LEP
# ACTMath_ACTBenchmark_LEP
# ACTReading_ACTBenchmark_LEP
# ACTScience_ACTBenchmark_LEP
# ACTSubtests_BenchmarksMet_LEP
# ACTWorkKeys_SilverPlus_LEP
# ACTWriting_ACTBenchmark_LEP
# EOCBiology_CACR_LEP
# EOCBiology_GLP_LEP
# EOCEnglish2_CACR_LEP
# EOCEnglish2_GLP_LEP
# EOCMathI_CACR_LEP
# EOCMathI_GLP_LEP
# EOCSubjects_CACR_LEP
# EOCSubjects_GLP_LEP
# EOGGr6_CACR_LEP
# EOGGr6_GLP_LEP
# EOGGr7_CACR_LEP
# EOGGr7_GLP_LEP
# EOGGr8_CACR_LEP
# EOGGr8_GLP_LEP
# EOGMathGr6_CACR_LEP
# EOGMathGr6_GLP_LEP
# EOGMathGr7_CACR_LEP
# EOGMathGr7_GLP_LEP
# EOGMathGr8_CACR_LEP
# EOGMathGr8_GLP_LEP
# EOGReadingGr6_CACR_LEP
# EOGReadingGr6_GLP_LEP
# EOGReadingGr7_CACR_LEP
# EOGReadingGr7_GLP_LEP
# EOGReadingGr8_CACR_LEP
# EOGReadingGr8_GLP_LEP
# EOGScienceGr8_CACR_LEP
# EOGScienceGr8_GLP_LEP
# GraduationRate_4yr_LEP
# GraduationRate_5yr_LEP
# ACTCompositeScore_UNCMin_SWD
# ACTEnglish_ACTBenchmark_SWD
# ACTMath_ACTBenchmark_SWD
# ACTReading_ACTBenchmark_SWD
# ACTScience_ACTBenchmark_SWD
# ACTSubtests_BenchmarksMet_SWD
# ACTWorkKeys_SilverPlus_SWD
# ACTWriting_ACTBenchmark_SWD
# EOCBiology_CACR_SWD
# EOCBiology_GLP_SWD
# EOCEnglish2_CACR_SWD
# EOCEnglish2_GLP_SWD
# EOCMathI_CACR_SWD
# EOCMathI_GLP_SWD
# EOCSubjects_CACR_SWD
# EOCSubjects_GLP_SWD
# EOGGr6_CACR_SWD
# EOGGr6_GLP_SWD
# EOGGr7_CACR_SWD
# EOGGr7_GLP_SWD
# EOGGr8_CACR_SWD
# EOGGr8_GLP_SWD
# EOGMathGr6_CACR_SWD
# EOGMathGr6_GLP_SWD
# EOGMathGr7_CACR_SWD
# EOGMathGr7_GLP_SWD
# EOGMathGr8_CACR_SWD
# EOGMathGr8_GLP_SWD
# EOGReadingGr6_CACR_SWD
# EOGReadingGr6_GLP_SWD
# EOGReadingGr7_CACR_SWD
# EOGReadingGr7_GLP_SWD
# EOGReadingGr8_CACR_SWD
# EOGReadingGr8_GLP_SWD
# EOGScienceGr8_CACR_SWD
# EOGScienceGr8_GLP_SWD
# GraduationRate_4yr_SWD
# GraduationRate_5yr_SWD
# ACTCompositeScore_UNCMin_AIG
# ACTEnglish_ACTBenchmark_AIG
# ACTMath_ACTBenchmark_AIG
# ACTReading_ACTBenchmark_AIG
# ACTScience_ACTBenchmark_AIG
# ACTSubtests_BenchmarksMet_AIG
# ACTWorkKeys_SilverPlus_AIG
# ACTWriting_ACTBenchmark_AIG
# EOCBiology_CACR_AIG
# EOCBiology_GLP_AIG
# EOCEnglish2_CACR_AIG
# EOCEnglish2_GLP_AIG
# EOCMathI_CACR_AIG
# EOCMathI_GLP_AIG
# EOCSubjects_CACR_AIG
# EOCSubjects_GLP_AIG
# EOGGr6_CACR_AIG
# EOGGr6_GLP_AIG
# EOGGr7_CACR_AIG
# EOGGr7_GLP_AIG
# EOGGr8_CACR_AIG
# EOGGr8_GLP_AIG
# EOGMathGr6_CACR_AIG
# EOGMathGr6_GLP_AIG
# EOGMathGr7_CACR_AIG
# EOGMathGr7_GLP_AIG
# EOGMathGr8_CACR_AIG
# EOGMathGr8_GLP_AIG
# EOGReadingGr6_CACR_AIG
# EOGReadingGr6_GLP_AIG
# EOGReadingGr7_CACR_AIG
# EOGReadingGr7_GLP_AIG
# EOGReadingGr8_CACR_AIG
# EOGReadingGr8_GLP_AIG
# EOGScienceGr8_CACR_AIG
# EOGScienceGr8_GLP_AIG
# GraduationRate_4yr_AIG
# GraduationRate_5yr_AIG
# pct_GCE_LEP
# pct_GCE_PRM
# pct_GCE_RPF
# pct_PASSED_RTA
# CurrentYearEOC_pTarget_PctMet
# MathGr10_pTarget_PctMet
# ReadingGr10_pTarget_PctMet
# sat_avg_score_num
# sat_participation_pct
# ap_participation_pct
# ap_pct_3_or_above
# total_specialized_courses
# ap_ib_courses
# cte_courses
# univ_college_courses
# lea_total_specialized_courses
# lea_ap_ib_courses
# lea_cte_courses
# lea_univ_college_courses
# st_total_specialized_courses
# st_ap_ib_courses
# st_cte_courses
# st_univ_college_courses
# AM7_American Indian_ENROLL_sch_pct
# AM7_American Indian_NOENROLL_sch_pct
# All_All Student (Total or subtotal)_ENROLL_sch_pct
# All_All Student (Total or subtotal)_NOENROLL_sch_pct
# BL7_Black_ENROLL_sch_pct
# BL7_Black_NOENROLL_sch_pct
# ECODIS_Economically Disadvantaged_ENROLL_sch_pct
# ECODIS_Economically Disadvantaged_NOENROLL_sch_pct
# F_Female_ENROLL_sch_pct
# F_Female_NOENROLL_sch_pct
# HI7_Hispanic_ENROLL_sch_pct
# HI7_Hispanic_NOENROLL_sch_pct
# M_Male_ENROLL_sch_pct
# M_Male_NOENROLL_sch_pct
# MU7_Multiracial_ENROLL_sch_pct
# MU7_Multiracial_NOENROLL_sch_pct
# WDIS_Students with Disabilities_ENROLL_sch_pct
# WDIS_Students with Disabilities_NOENROLL_sch_pct
# WH7_White_ENROLL_sch_pct
# WH7_White_NOENROLL_sch_pct
# emer_prov_teach_pct

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Columns: 1276 entries, category_cd to OtherReasonsPerct
# dtypes: float64(1262), object(14)
# memory usage: 12.7+ MB
#
# Columns Deleted:  17

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

# %%
#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, columns=sD_nominal.columns, drop_first=True)

# %%
#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print ('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print ('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  14
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Columns: 1293 entries, student_num to esea_attendance_Met
# dtypes: float64(1262), uint8(31)
# memory usage: 12.6 MB
#
# New Columns Created Via One-Hot Encoding:  17

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                           Variable Name  Number Missing Values
# 13                                            SPG Score                     33
# 14                                   Reading  SPG Score                     34
# 15                                       Math SPG Score                     34
# 16                                   EVAAS Growth Score                     33
# 17                            Overall Achievement Score                     33
# 18                                           Read Score                     34
# 19                                           Math Score                     34
# 20                                        Science Score                    116
# 21                             EOG/EOCSubjects_CACR_All                     33
# 22                              EOG/EOCSubjects_GLP_All                     33
# 23                                      EOGGr3_CACR_All                     57
# 24                                       EOGGr3_GLP_All                     57
# 25                                      EOGGr4_CACR_All                     62
# 26                                       EOGGr4_GLP_All                     62
# 27                                      EOGGr5_CACR_All                    119
# 28                                       EOGGr5_GLP_All                    119
# 29                                  EOGMathGr3_CACR_All                     57
# 30                                   EOGMathGr3_GLP_All                     57
# 31                                EOGMathGr3-8_CACR_All                     34
# 32                                 EOGMathGr3-8_GLP_All                     34
# 33                                  EOGMathGr4_CACR_All                     62
# 34                                   EOGMathGr4_GLP_All                     62
# 35                                  EOGMathGr5_CACR_All                    119
# 36                                   EOGMathGr5_GLP_All                    119
# 37                               EOGReadingGr3_CACR_All                     57
# 38                                EOGReadingGr3_GLP_All                     57
# 39                             EOGReadingGr3-8_CACR_All                     34
# 40                              EOGReadingGr3-8_GLP_All                     34
# 41                               EOGReadingGr4_CACR_All                     62
# 42                                EOGReadingGr4_GLP_All                     62
# 43                               EOGReadingGr5_CACR_All                    119
# 44                                EOGReadingGr5_GLP_All                    119
# 45                               EOGScienceGr5_CACR_All                    119
# 46                                EOGScienceGr5_GLP_All                    119
# 47                             EOGScienceGr5&8_CACR_All                    116
# 48                              EOGScienceGr5&8_GLP_All                    116
# 49                                 EOGSubjects_CACR_All                     34
# 50                                  EOGSubjects_GLP_All                     34
# 51                          EOG/EOCSubjects_CACR_Female                     33
# 52                           EOG/EOCSubjects_GLP_Female                     33
# 53                                   EOGGr3_CACR_Female                     57
# 54                                    EOGGr3_GLP_Female                     57
# 55                                   EOGGr4_CACR_Female                     62
# 56                                    EOGGr4_GLP_Female                     62
# 57                                   EOGGr5_CACR_Female                    119
# 58                                    EOGGr5_GLP_Female                    119
# 59                               EOGMathGr3_CACR_Female                     57
# 60                                EOGMathGr3_GLP_Female                     57
# 61                             EOGMathGr3-8_CACR_Female                     34
# 62                              EOGMathGr3-8_GLP_Female                     34
# 63                               EOGMathGr4_CACR_Female                     62
# 64                                EOGMathGr4_GLP_Female                     62
# 65                               EOGMathGr5_CACR_Female                    119
# 66                                EOGMathGr5_GLP_Female                    119
# 67                            EOGReadingGr3_CACR_Female                     57
# 68                             EOGReadingGr3_GLP_Female                     57
# 69                          EOGReadingGr3-8_CACR_Female                     34
# 70                           EOGReadingGr3-8_GLP_Female                     34
# 71                            EOGReadingGr4_CACR_Female                     62
# 72                             EOGReadingGr4_GLP_Female                     62
# 73                            EOGReadingGr5_CACR_Female                    119
# 74                             EOGReadingGr5_GLP_Female                    119
# 75                            EOGScienceGr5_CACR_Female                    119
# 76                             EOGScienceGr5_GLP_Female                    119
# 77                          EOGScienceGr5&8_CACR_Female                    116
# 78                           EOGScienceGr5&8_GLP_Female                    116
# 79                              EOGSubjects_CACR_Female                     34
# 80                               EOGSubjects_GLP_Female                     34
# 81                            EOG/EOCSubjects_CACR_Male                     33
# 82                             EOG/EOCSubjects_GLP_Male                     33
# 83                                     EOGGr3_CACR_Male                     57
# 84                                      EOGGr3_GLP_Male                     57
# 85                                     EOGGr4_CACR_Male                     62
# 86                                      EOGGr4_GLP_Male                     62
# 87                                     EOGGr5_CACR_Male                    119
# 88                                      EOGGr5_GLP_Male                    119
# 89                                 EOGMathGr3_CACR_Male                     57
# 90                                  EOGMathGr3_GLP_Male                     57
# 91                               EOGMathGr3-8_CACR_Male                     34
# 92                                EOGMathGr3-8_GLP_Male                     34
# 93                                 EOGMathGr4_CACR_Male                     62
# 94                                  EOGMathGr4_GLP_Male                     62
# 95                                 EOGMathGr5_CACR_Male                    119
# 96                                  EOGMathGr5_GLP_Male                    119
# 97                              EOGReadingGr3_CACR_Male                     57
# 98                               EOGReadingGr3_GLP_Male                     57
# 99                            EOGReadingGr3-8_CACR_Male                     34
# 100                            EOGReadingGr3-8_GLP_Male                     34
# 101                             EOGReadingGr4_CACR_Male                     62
# 102                              EOGReadingGr4_GLP_Male                     62
# 103                             EOGReadingGr5_CACR_Male                    119
# 104                              EOGReadingGr5_GLP_Male                    119
# 105                             EOGScienceGr5_CACR_Male                    119
# 106                              EOGScienceGr5_GLP_Male                    119
# 107                           EOGScienceGr5&8_CACR_Male                    116
# 108                            EOGScienceGr5&8_GLP_Male                    116
# 109                               EOGSubjects_CACR_Male                     34
# 110                                EOGSubjects_GLP_Male                     34
# 111                 EOG/EOCSubjects_CACR_AmericanIndian                     33
# 112                  EOG/EOCSubjects_GLP_AmericanIndian                     33
# 113                          EOGGr3_CACR_AmericanIndian                     57
# 114                           EOGGr3_GLP_AmericanIndian                     57
# 115                          EOGGr4_CACR_AmericanIndian                     62
# 116                           EOGGr4_GLP_AmericanIndian                     62
# 117                          EOGGr5_CACR_AmericanIndian                    119
# 118                           EOGGr5_GLP_AmericanIndian                    119
# 119                      EOGMathGr3_CACR_AmericanIndian                     57
# 120                       EOGMathGr3_GLP_AmericanIndian                     57
# 121                    EOGMathGr3-8_CACR_AmericanIndian                     34
# 122                     EOGMathGr3-8_GLP_AmericanIndian                     34
# 123                      EOGMathGr4_CACR_AmericanIndian                     62
# 124                       EOGMathGr4_GLP_AmericanIndian                     62
# 125                      EOGMathGr5_CACR_AmericanIndian                    119
# 126                       EOGMathGr5_GLP_AmericanIndian                    119
# 127                   EOGReadingGr3_CACR_AmericanIndian                     57
# 128                    EOGReadingGr3_GLP_AmericanIndian                     57
# 129                 EOGReadingGr3-8_CACR_AmericanIndian                     34
# 130                  EOGReadingGr3-8_GLP_AmericanIndian                     34
# 131                   EOGReadingGr4_CACR_AmericanIndian                     62
# 132                    EOGReadingGr4_GLP_AmericanIndian                     62
# 133                   EOGReadingGr5_CACR_AmericanIndian                    119
# 134                    EOGReadingGr5_GLP_AmericanIndian                    119
# 135                   EOGScienceGr5_CACR_AmericanIndian                    119
# 136                    EOGScienceGr5_GLP_AmericanIndian                    119
# 137                 EOGScienceGr5&8_CACR_AmericanIndian                    116
# 138                  EOGScienceGr5&8_GLP_AmericanIndian                    116
# 139                     EOGSubjects_CACR_AmericanIndian                     34
# 140                      EOGSubjects_GLP_AmericanIndian                     34
# 141                          EOG/EOCSubjects_CACR_Asian                     33
# 142                           EOG/EOCSubjects_GLP_Asian                     33
# 143                                   EOGGr3_CACR_Asian                     57
# 144                                    EOGGr3_GLP_Asian                     57
# 145                                   EOGGr4_CACR_Asian                     62
# 146                                    EOGGr4_GLP_Asian                     62
# 147                                   EOGGr5_CACR_Asian                    119
# 148                                    EOGGr5_GLP_Asian                    119
# 149                               EOGMathGr3_CACR_Asian                     57
# 150                                EOGMathGr3_GLP_Asian                     57
# 151                             EOGMathGr3-8_CACR_Asian                     34
# 152                              EOGMathGr3-8_GLP_Asian                     34
# 153                               EOGMathGr4_CACR_Asian                     62
# 154                                EOGMathGr4_GLP_Asian                     62
# 155                               EOGMathGr5_CACR_Asian                    119
# 156                                EOGMathGr5_GLP_Asian                    119
# 157                            EOGReadingGr3_CACR_Asian                     57
# 158                             EOGReadingGr3_GLP_Asian                     57
# 159                          EOGReadingGr3-8_CACR_Asian                     34
# 160                           EOGReadingGr3-8_GLP_Asian                     34
# 161                            EOGReadingGr4_CACR_Asian                     62
# 162                             EOGReadingGr4_GLP_Asian                     62
# 163                            EOGReadingGr5_CACR_Asian                    119
# 164                             EOGReadingGr5_GLP_Asian                    119
# 165                            EOGScienceGr5_CACR_Asian                    119
# 166                             EOGScienceGr5_GLP_Asian                    119
# 167                          EOGScienceGr5&8_CACR_Asian                    116
# 168                           EOGScienceGr5&8_GLP_Asian                    116
# 169                              EOGSubjects_CACR_Asian                     34
# 170                               EOGSubjects_GLP_Asian                     34
# 171                          EOG/EOCSubjects_CACR_Black                     33
# 172                           EOG/EOCSubjects_GLP_Black                     33
# 173                                   EOGGr3_CACR_Black                     57
# 174                                    EOGGr3_GLP_Black                     57
# 175                                   EOGGr4_CACR_Black                     62
# 176                                    EOGGr4_GLP_Black                     62
# 177                                   EOGGr5_CACR_Black                    119
# 178                                    EOGGr5_GLP_Black                    119
# 179                               EOGMathGr3_CACR_Black                     57
# 180                                EOGMathGr3_GLP_Black                     57
# 181                             EOGMathGr3-8_CACR_Black                     34
# 182                              EOGMathGr3-8_GLP_Black                     34
# 183                               EOGMathGr4_CACR_Black                     62
# 184                                EOGMathGr4_GLP_Black                     62
# 185                               EOGMathGr5_CACR_Black                    119
# 186                                EOGMathGr5_GLP_Black                    119
# 187                            EOGReadingGr3_CACR_Black                     57
# 188                             EOGReadingGr3_GLP_Black                     57
# 189                          EOGReadingGr3-8_CACR_Black                     34
# 190                           EOGReadingGr3-8_GLP_Black                     34
# 191                            EOGReadingGr4_CACR_Black                     62
# 192                             EOGReadingGr4_GLP_Black                     62
# 193                            EOGReadingGr5_CACR_Black                    119
# 194                             EOGReadingGr5_GLP_Black                    119
# 195                            EOGScienceGr5_CACR_Black                    119
# 196                             EOGScienceGr5_GLP_Black                    119
# 197                          EOGScienceGr5&8_CACR_Black                    116
# 198                           EOGScienceGr5&8_GLP_Black                    116
# 199                              EOGSubjects_CACR_Black                     34
# 200                               EOGSubjects_GLP_Black                     34
# 201                       EOG/EOCSubjects_CACR_Hispanic                     33
# 202                        EOG/EOCSubjects_GLP_Hispanic                     33
# 203                                EOGGr3_CACR_Hispanic                     57
# 204                                 EOGGr3_GLP_Hispanic                     57
# 205                                EOGGr4_CACR_Hispanic                     62
# 206                                 EOGGr4_GLP_Hispanic                     62
# 207                                EOGGr5_CACR_Hispanic                    119
# 208                                 EOGGr5_GLP_Hispanic                    119
# 209                            EOGMathGr3_CACR_Hispanic                     57
# 210                             EOGMathGr3_GLP_Hispanic                     57
# 211                          EOGMathGr3-8_CACR_Hispanic                     34
# 212                           EOGMathGr3-8_GLP_Hispanic                     34
# 213                            EOGMathGr4_CACR_Hispanic                     62
# 214                             EOGMathGr4_GLP_Hispanic                     62
# 215                            EOGMathGr5_CACR_Hispanic                    119
# 216                             EOGMathGr5_GLP_Hispanic                    119
# 217                         EOGReadingGr3_CACR_Hispanic                     57
# 218                          EOGReadingGr3_GLP_Hispanic                     57
# 219                       EOGReadingGr3-8_CACR_Hispanic                     34
# 220                        EOGReadingGr3-8_GLP_Hispanic                     34
# 221                         EOGReadingGr4_CACR_Hispanic                     62
# 222                          EOGReadingGr4_GLP_Hispanic                     62
# 223                         EOGReadingGr5_CACR_Hispanic                    119
# 224                          EOGReadingGr5_GLP_Hispanic                    119
# 225                         EOGScienceGr5_CACR_Hispanic                    119
# 226                          EOGScienceGr5_GLP_Hispanic                    119
# 227                       EOGScienceGr5&8_CACR_Hispanic                    116
# 228                        EOGScienceGr5&8_GLP_Hispanic                    116
# 229                           EOGSubjects_CACR_Hispanic                     34
# 230                            EOGSubjects_GLP_Hispanic                     34
# 231                 EOG/EOCSubjects_CACR_TwoorMoreRaces                     33
# 232                  EOG/EOCSubjects_GLP_TwoorMoreRaces                     33
# 233                          EOGGr3_CACR_TwoorMoreRaces                     57
# 234                           EOGGr3_GLP_TwoorMoreRaces                     57
# 235                          EOGGr4_CACR_TwoorMoreRaces                     62
# 236                           EOGGr4_GLP_TwoorMoreRaces                     62
# 237                          EOGGr5_CACR_TwoorMoreRaces                    119
# 238                           EOGGr5_GLP_TwoorMoreRaces                    119
# 239                      EOGMathGr3_CACR_TwoorMoreRaces                     57
# 240                       EOGMathGr3_GLP_TwoorMoreRaces                     57
# 241                    EOGMathGr3-8_CACR_TwoorMoreRaces                     34
# 242                     EOGMathGr3-8_GLP_TwoorMoreRaces                     34
# 243                      EOGMathGr4_CACR_TwoorMoreRaces                     62
# 244                       EOGMathGr4_GLP_TwoorMoreRaces                     62
# 245                      EOGMathGr5_CACR_TwoorMoreRaces                    119
# 246                       EOGMathGr5_GLP_TwoorMoreRaces                    119
# 247                   EOGReadingGr3_CACR_TwoorMoreRaces                     57
# 248                    EOGReadingGr3_GLP_TwoorMoreRaces                     57
# 249                 EOGReadingGr3-8_CACR_TwoorMoreRaces                     34
# 250                  EOGReadingGr3-8_GLP_TwoorMoreRaces                     34
# 251                   EOGReadingGr4_CACR_TwoorMoreRaces                     62
# 252                    EOGReadingGr4_GLP_TwoorMoreRaces                     62
# 253                   EOGReadingGr5_CACR_TwoorMoreRaces                    119
# 254                    EOGReadingGr5_GLP_TwoorMoreRaces                    119
# 255                   EOGScienceGr5_CACR_TwoorMoreRaces                    119
# 256                    EOGScienceGr5_GLP_TwoorMoreRaces                    119
# 257                 EOGScienceGr5&8_CACR_TwoorMoreRaces                    116
# 258                  EOGScienceGr5&8_GLP_TwoorMoreRaces                    116
# 259                     EOGSubjects_CACR_TwoorMoreRaces                     34
# 260                      EOGSubjects_GLP_TwoorMoreRaces                     34
# 261                          EOG/EOCSubjects_CACR_White                     33
# 262                           EOG/EOCSubjects_GLP_White                     33
# 263                                   EOGGr3_CACR_White                     57
# 264                                    EOGGr3_GLP_White                     57
# 265                                   EOGGr4_CACR_White                     62
# 266                                    EOGGr4_GLP_White                     62
# 267                                   EOGGr5_CACR_White                    119
# 268                                    EOGGr5_GLP_White                    119
# 269                               EOGMathGr3_CACR_White                     57
# 270                                EOGMathGr3_GLP_White                     57
# 271                             EOGMathGr3-8_CACR_White                     34
# 272                              EOGMathGr3-8_GLP_White                     34
# 273                               EOGMathGr4_CACR_White                     62
# 274                                EOGMathGr4_GLP_White                     62
# 275                               EOGMathGr5_CACR_White                    119
# 276                                EOGMathGr5_GLP_White                    119
# 277                            EOGReadingGr3_CACR_White                     57
# 278                             EOGReadingGr3_GLP_White                     57
# 279                          EOGReadingGr3-8_CACR_White                     34
# 280                           EOGReadingGr3-8_GLP_White                     34
# 281                            EOGReadingGr4_CACR_White                     62
# 282                             EOGReadingGr4_GLP_White                     62
# 283                            EOGReadingGr5_CACR_White                    119
# 284                             EOGReadingGr5_GLP_White                    119
# 285                            EOGScienceGr5_CACR_White                    119
# 286                             EOGScienceGr5_GLP_White                    119
# 287                          EOGScienceGr5&8_CACR_White                    116
# 288                           EOGScienceGr5&8_GLP_White                    116
# 289                              EOGSubjects_CACR_White                     34
# 290                               EOGSubjects_GLP_White                     34
# 291                            EOG/EOCSubjects_CACR_EDS                     33
# 292                             EOG/EOCSubjects_GLP_EDS                     33
# 293                                     EOGGr3_CACR_EDS                     57
# 294                                      EOGGr3_GLP_EDS                     57
# 295                                     EOGGr4_CACR_EDS                     62
# 296                                      EOGGr4_GLP_EDS                     62
# 297                                     EOGGr5_CACR_EDS                    119
# 298                                      EOGGr5_GLP_EDS                    119
# 299                                 EOGMathGr3_CACR_EDS                     57
# 300                                  EOGMathGr3_GLP_EDS                     57
# 301                               EOGMathGr3-8_CACR_EDS                     34
# 302                                EOGMathGr3-8_GLP_EDS                     34
# 303                                 EOGMathGr4_CACR_EDS                     62
# 304                                  EOGMathGr4_GLP_EDS                     62
# 305                                 EOGMathGr5_CACR_EDS                    119
# 306                                  EOGMathGr5_GLP_EDS                    119
# 307                              EOGReadingGr3_CACR_EDS                     57
# 308                               EOGReadingGr3_GLP_EDS                     57
# 309                            EOGReadingGr3-8_CACR_EDS                     34
# 310                             EOGReadingGr3-8_GLP_EDS                     34
# 311                              EOGReadingGr4_CACR_EDS                     62
# 312                               EOGReadingGr4_GLP_EDS                     62
# 313                              EOGReadingGr5_CACR_EDS                    119
# 314                               EOGReadingGr5_GLP_EDS                    119
# 315                              EOGScienceGr5_CACR_EDS                    119
# 316                               EOGScienceGr5_GLP_EDS                    119
# 317                            EOGScienceGr5&8_CACR_EDS                    116
# 318                             EOGScienceGr5&8_GLP_EDS                    116
# 319                                EOGSubjects_CACR_EDS                     34
# 320                                 EOGSubjects_GLP_EDS                     34
# 321                            EOG/EOCSubjects_CACR_LEP                     33
# 322                             EOG/EOCSubjects_GLP_LEP                     33
# 323                                     EOGGr3_CACR_LEP                     57
# 324                                      EOGGr3_GLP_LEP                     57
# 325                                     EOGGr4_CACR_LEP                     62
# 326                                      EOGGr4_GLP_LEP                     62
# 327                                     EOGGr5_CACR_LEP                    119
# 328                                      EOGGr5_GLP_LEP                    119
# 329                                 EOGMathGr3_CACR_LEP                     57
# 330                                  EOGMathGr3_GLP_LEP                     57
# 331                               EOGMathGr3-8_CACR_LEP                     34
# 332                                EOGMathGr3-8_GLP_LEP                     34
# 333                                 EOGMathGr4_CACR_LEP                     62
# 334                                  EOGMathGr4_GLP_LEP                     62
# 335                                 EOGMathGr5_CACR_LEP                    119
# 336                                  EOGMathGr5_GLP_LEP                    119
# 337                              EOGReadingGr3_CACR_LEP                     57
# 338                               EOGReadingGr3_GLP_LEP                     57
# 339                            EOGReadingGr3-8_CACR_LEP                     34
# 340                             EOGReadingGr3-8_GLP_LEP                     34
# 341                              EOGReadingGr4_CACR_LEP                     62
# 342                               EOGReadingGr4_GLP_LEP                     62
# 343                              EOGReadingGr5_CACR_LEP                    119
# 344                               EOGReadingGr5_GLP_LEP                    119
# 345                              EOGScienceGr5_CACR_LEP                    119
# 346                               EOGScienceGr5_GLP_LEP                    119
# 347                            EOGScienceGr5&8_CACR_LEP                    116
# 348                             EOGScienceGr5&8_GLP_LEP                    116
# 349                                EOGSubjects_CACR_LEP                     34
# 350                                 EOGSubjects_GLP_LEP                     34
# 351                            EOG/EOCSubjects_CACR_SWD                     33
# 352                             EOG/EOCSubjects_GLP_SWD                     33
# 353                                     EOGGr3_CACR_SWD                     57
# 354                                      EOGGr3_GLP_SWD                     57
# 355                                     EOGGr4_CACR_SWD                     62
# 356                                      EOGGr4_GLP_SWD                     62
# 357                                     EOGGr5_CACR_SWD                    119
# 358                                      EOGGr5_GLP_SWD                    119
# 359                                 EOGMathGr3_CACR_SWD                     57
# 360                                  EOGMathGr3_GLP_SWD                     57
# 361                               EOGMathGr3-8_CACR_SWD                     34
# 362                                EOGMathGr3-8_GLP_SWD                     34
# 363                                 EOGMathGr4_CACR_SWD                     62
# 364                                  EOGMathGr4_GLP_SWD                     62
# 365                                 EOGMathGr5_CACR_SWD                    119
# 366                                  EOGMathGr5_GLP_SWD                    119
# 367                              EOGReadingGr3_CACR_SWD                     57
# 368                               EOGReadingGr3_GLP_SWD                     57
# 369                            EOGReadingGr3-8_CACR_SWD                     34
# 370                             EOGReadingGr3-8_GLP_SWD                     34
# 371                              EOGReadingGr4_CACR_SWD                     62
# 372                               EOGReadingGr4_GLP_SWD                     62
# 373                              EOGReadingGr5_CACR_SWD                    119
# 374                               EOGReadingGr5_GLP_SWD                    119
# 375                              EOGScienceGr5_CACR_SWD                    119
# 376                               EOGScienceGr5_GLP_SWD                    119
# 377                            EOGScienceGr5&8_CACR_SWD                    116
# 378                             EOGScienceGr5&8_GLP_SWD                    116
# 379                                EOGSubjects_CACR_SWD                     34
# 380                                 EOGSubjects_GLP_SWD                     34
# 381                            EOG/EOCSubjects_CACR_AIG                     33
# 382                             EOG/EOCSubjects_GLP_AIG                     33
# 383                                     EOGGr3_CACR_AIG                     57
# 384                                      EOGGr3_GLP_AIG                     57
# 385                                     EOGGr4_CACR_AIG                     62
# 386                                      EOGGr4_GLP_AIG                     62
# 387                                     EOGGr5_CACR_AIG                    119
# 388                                      EOGGr5_GLP_AIG                    119
# 389                                 EOGMathGr3_CACR_AIG                     57
# 390                                  EOGMathGr3_GLP_AIG                     57
# 391                               EOGMathGr3-8_CACR_AIG                     34
# 392                                EOGMathGr3-8_GLP_AIG                     34
# 393                                 EOGMathGr4_CACR_AIG                     62
# 394                                  EOGMathGr4_GLP_AIG                     62
# 395                                 EOGMathGr5_CACR_AIG                    119
# 396                                  EOGMathGr5_GLP_AIG                    119
# 397                              EOGReadingGr3_CACR_AIG                     57
# 398                               EOGReadingGr3_GLP_AIG                     57
# 399                            EOGReadingGr3-8_CACR_AIG                     34
# 400                             EOGReadingGr3-8_GLP_AIG                     34
# 401                              EOGReadingGr4_CACR_AIG                     62
# 402                               EOGReadingGr4_GLP_AIG                     62
# 403                              EOGReadingGr5_CACR_AIG                    119
# 404                               EOGReadingGr5_GLP_AIG                    119
# 405                              EOGScienceGr5_CACR_AIG                    119
# 406                               EOGScienceGr5_GLP_AIG                    119
# 407                            EOGScienceGr5&8_CACR_AIG                    116
# 408                             EOGScienceGr5&8_GLP_AIG                    116
# 409                                EOGSubjects_CACR_AIG                     34
# 410                                 EOGSubjects_GLP_AIG                     34
# 411                                         pct_GCE_ALL                     56
# 412                                         pct_GCE_SWD                    845
# 413                                      pct_PASSED_EOG                     60
# 414                                      pct_PASSED_LAA                    487
# 415                                        pct_PROMOTED                     57
# 416                                        pct_RETAINED                    472
# 417                            MathGr3-8_pTarget_PctMet                     35
# 418                         ReadingGr3-8_pTarget_PctMet                     35
# 419                             SciGr5&8_pTarget_PctMet                    161
# 420                         TotalTargets_pTarget_PctMet                     34
# 423                            lea_ap_participation_pct                    258
# 424                               lea_ap_pct_3_or_above                     12
# 425                               lea_ib_pct_4_or_above                    793
# 446                                           nbpts_num                     64
# 448                                _1yr_tchr_trnovr_pct                      4
# 449                                   lateral_teach_pct                    982
# 455                                       lea_nbpts_num                      2
# 458                             lea_emer_prov_teach_pct                    465
# 459                               lea_lateral_teach_pct                    173
# 475                    Accomplished_TCHR_Standard 1_Pct                     36
# 476                    Accomplished_TCHR_Standard 2_Pct                     36
# 477                    Accomplished_TCHR_Standard 3_Pct                     36
# 478                    Accomplished_TCHR_Standard 4_Pct                     36
# 479                    Accomplished_TCHR_Standard 5_Pct                     36
# 480                      Developing_TCHR_Standard 1_Pct                     36
# 481                      Developing_TCHR_Standard 2_Pct                     36
# 482                      Developing_TCHR_Standard 3_Pct                     36
# 483                      Developing_TCHR_Standard 4_Pct                     36
# 484                      Developing_TCHR_Standard 5_Pct                     36
# 485                   Distinguished_TCHR_Standard 1_Pct                     36
# 486                   Distinguished_TCHR_Standard 2_Pct                     36
# 487                   Distinguished_TCHR_Standard 3_Pct                     36
# 488                   Distinguished_TCHR_Standard 4_Pct                     36
# 489                   Distinguished_TCHR_Standard 5_Pct                     36
# 490   Does Not Meet Expected Growth_TCHR_Standard 6_Pct                     36
# 491         Exceeds Expected Growth_TCHR_Standard 6_Pct                     36
# 492           Meets Expected Growth_TCHR_Standard 6_Pct                     36
# 493                 Not Demostrated_TCHR_Standard 1_Pct                     36
# 494                 Not Demostrated_TCHR_Standard 2_Pct                     36
# 495                 Not Demostrated_TCHR_Standard 3_Pct                     36
# 496                 Not Demostrated_TCHR_Standard 4_Pct                     36
# 497                 Not Demostrated_TCHR_Standard 5_Pct                     36
# 498                      Proficient_TCHR_Standard 1_Pct                     36
# 499                      Proficient_TCHR_Standard 2_Pct                     36
# 500                      Proficient_TCHR_Standard 3_Pct                     36
# 501                      Proficient_TCHR_Standard 4_Pct                     36
# 502                      Proficient_TCHR_Standard 5_Pct                     36
# 527                                                Year                    313
# 528                                        Violent Rate                    438
# 529                                         Murder Rate                    512
# 530                                           Rape Rate                    456
# 531                                        Robbery Rate                    461
# 532                                        Assault Rate                    438
# 533                                            MVT Rate                    441
# 534                                          Arson Rate                    472
# 1251                                            LEACode                    125
# 1252                                RemainedinEducation                    125
# 1253                           RemainedinEducationPerct                    125
# 1254                                    PersonalReasons                    125
# 1255                                      PersonalPerct                    125
# 1256                                     InitiatedbyLEA                    125
# 1257                                     InitiatedPerct                    125
# 1258                                 BeyondControlofLEA                    125
# 1259                                 BeyondControlPerct                    125
# 1260                                       OtherReasons                    125
# 1261                                  OtherReasonsPerct                    125

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  184719  field correlations > 95%.
#                                                    Field1  \
# 0                                 st_avg_daily_attend_pct
# 1                                 st_short_susp_per_c_num
# 2                                  st_flicensed_teach_pct
# 3                                    st_lateral_teach_pct
# 4                                           category_cd_E
# 5                                           Category_Cd_E
# 6                                      Reading  SPG Score
# 7                                          Math SPG Score
# 8                               Overall Achievement Score
# 9                                              Read Score
# 10                                             Math Score
# 11                               EOG/EOCSubjects_CACR_All
# 12                                EOG/EOCSubjects_GLP_All
# 13                                   EOGMathGr3-8_GLP_All
# 14                                EOGReadingGr3-8_GLP_All
# 15                                   EOGSubjects_CACR_All
# 16                                    EOGSubjects_GLP_All
# 17                            EOG/EOCSubjects_CACR_Female
# 18                             EOG/EOCSubjects_GLP_Female
# 19                                 EOGSubjects_GLP_Female
# 20                               EOG/EOCSubjects_GLP_Male
# 21                                   EOGSubjects_GLP_Male
# 22                              Overall Achievement Score
# 23                                             Read Score
# 24                                EOG/EOCSubjects_GLP_All
# 25                               EOGReadingGr3-8_CACR_All
# 26                                EOGReadingGr3-8_GLP_All
# 27                                    EOGSubjects_GLP_All
# 28                             EOGReadingGr3-8_GLP_Female
# 29                                 EOGSubjects_GLP_Female
# 30                               EOGReadingGr3-8_GLP_Male
# 31                                   EOGSubjects_GLP_Male
# 32                              Overall Achievement Score
# 33                                             Math Score
# 34                                EOG/EOCSubjects_GLP_All
# 35                                  EOGMathGr3-8_CACR_All
# 36                                   EOGMathGr3-8_GLP_All
# 37                                    EOGSubjects_GLP_All
# 38                                EOGMathGr3-8_GLP_Female
# 39                                 EOGSubjects_GLP_Female
# 40                                  EOGMathGr3-8_GLP_Male
# 41                                   EOGSubjects_GLP_Male
# 42                                             Read Score
# 43                                             Math Score
# 44                               EOG/EOCSubjects_CACR_All
# 45                                EOG/EOCSubjects_GLP_All
# 46                                  EOGMathGr3-8_CACR_All
# 47                                   EOGMathGr3-8_GLP_All
# 48                               EOGReadingGr3-8_CACR_All
# 49                                EOGReadingGr3-8_GLP_All
# 50                                   EOGSubjects_CACR_All
# 51                                    EOGSubjects_GLP_All
# 52                            EOG/EOCSubjects_CACR_Female
# 53                             EOG/EOCSubjects_GLP_Female
# 54                                EOGMathGr3-8_GLP_Female
# 55                                EOGSubjects_CACR_Female
# 56                                 EOGSubjects_GLP_Female
# 57                              EOG/EOCSubjects_CACR_Male
# 58                               EOG/EOCSubjects_GLP_Male
# 59                                  EOGMathGr3-8_GLP_Male
# 60                               EOGReadingGr3-8_GLP_Male
# 61                                  EOGSubjects_CACR_Male
# 62                                   EOGSubjects_GLP_Male
# 63                               EOG/EOCSubjects_CACR_All
# 64                                EOG/EOCSubjects_GLP_All
# 65                               EOGReadingGr3-8_CACR_All
# 66                                EOGReadingGr3-8_GLP_All
# 67                                   EOGSubjects_CACR_All
# 68                                    EOGSubjects_GLP_All
# 69                             EOG/EOCSubjects_GLP_Female
# 70                            EOGReadingGr3-8_CACR_Female
# 71                             EOGReadingGr3-8_GLP_Female
# 72                                EOGSubjects_CACR_Female
# 73                                 EOGSubjects_GLP_Female
# 74                               EOG/EOCSubjects_GLP_Male
# 75                              EOGReadingGr3-8_CACR_Male
# 76                               EOGReadingGr3-8_GLP_Male
# 77                                  EOGSubjects_CACR_Male
# 78                                   EOGSubjects_GLP_Male
# 79                               EOG/EOCSubjects_CACR_All
# 80                                EOG/EOCSubjects_GLP_All
# 81                                  EOGMathGr3-8_CACR_All
# 82                                   EOGMathGr3-8_GLP_All
# 83                                   EOGSubjects_CACR_All
# 84                                    EOGSubjects_GLP_All
# 85                             EOG/EOCSubjects_GLP_Female
# 86                               EOGMathGr3-8_CACR_Female
# 87                                EOGMathGr3-8_GLP_Female
# 88                                EOGSubjects_CACR_Female
# 89                                 EOGSubjects_GLP_Female
# 90                               EOG/EOCSubjects_GLP_Male
# 91                                 EOGMathGr3-8_CACR_Male
# 92                                  EOGMathGr3-8_GLP_Male
# 93                                  EOGSubjects_CACR_Male
# 94                                   EOGSubjects_GLP_Male
# 95                                         EOGGr5_GLP_All
# 96                                 EOGScienceGr5_CACR_All
# 97                                  EOGScienceGr5_GLP_All
# 98                               EOGScienceGr5&8_CACR_All
# 99                                EOGScienceGr5&8_GLP_All
# 100                            EOGScienceGr5&8_GLP_Female
# 101                                EOGScienceGr5_GLP_Male
# 102                             EOGScienceGr5&8_CACR_Male
# 103                              EOGScienceGr5&8_GLP_Male
# 104                               EOG/EOCSubjects_GLP_All
# 105                                 EOGMathGr3-8_CACR_All
# 106                                  EOGMathGr3-8_GLP_All
# 107                              EOGReadingGr3-8_CACR_All
# 108                               EOGReadingGr3-8_GLP_All
# 109                                  EOGSubjects_CACR_All
# 110                                   EOGSubjects_GLP_All
# 111                           EOG/EOCSubjects_CACR_Female
# 112                            EOG/EOCSubjects_GLP_Female
# 113                              EOGMathGr3-8_CACR_Female
# 114                               EOGSubjects_CACR_Female
# 115                                EOGSubjects_GLP_Female
# 116                             EOG/EOCSubjects_CACR_Male
# 117                              EOG/EOCSubjects_GLP_Male
# 118                                EOGMathGr3-8_CACR_Male
# 119                                 EOGSubjects_CACR_Male
# 120                                  EOGSubjects_GLP_Male
# 121                                 EOGMathGr3-8_CACR_All
# 122                                  EOGMathGr3-8_GLP_All
# 123                              EOGReadingGr3-8_CACR_All
# 124                               EOGReadingGr3-8_GLP_All
# 125                                  EOGSubjects_CACR_All
# 126                                   EOGSubjects_GLP_All
# 127                           EOG/EOCSubjects_CACR_Female
# 128                            EOG/EOCSubjects_GLP_Female
# 129                               EOGMathGr3-8_GLP_Female
# 130                            EOGReadingGr3-8_GLP_Female
# 131                               EOGSubjects_CACR_Female
# 132                                EOGSubjects_GLP_Female
# 133                             EOG/EOCSubjects_CACR_Male
# 134                              EOG/EOCSubjects_GLP_Male
# 135                                 EOGMathGr3-8_GLP_Male
# 136                              EOGReadingGr3-8_GLP_Male
# 137                                 EOGSubjects_CACR_Male
# 138                                  EOGSubjects_GLP_Male
# 139                                        EOGGr3_GLP_All
# 140                                   EOGMathGr3_CACR_All
# 141                                    EOGMathGr3_GLP_All
# 142                                EOGReadingGr3_CACR_All
# 143                                    EOGGr3_CACR_Female
# 144                                      EOGGr3_CACR_Male
# 145                                    EOGMathGr3_GLP_All
# 146                                 EOGReadingGr3_GLP_All
# 147                                     EOGGr3_GLP_Female
# 148                                       EOGGr3_GLP_Male
# 149                                        pct_PASSED_EOG
# 150                                        EOGGr4_GLP_All
# 151                                   EOGMathGr4_CACR_All
# 152                                    EOGMathGr4_GLP_All
# 153                                EOGReadingGr4_CACR_All
# 154                                 EOGReadingGr4_GLP_All
# 155                                      EOGGr4_CACR_Male
# 156                                   EOGMathGr4_CACR_All
# 157                                    EOGMathGr4_GLP_All
# 158                                EOGReadingGr4_CACR_All
# 159                                 EOGReadingGr4_GLP_All
# 160                                     EOGGr4_GLP_Female
# 161                                       EOGGr4_GLP_Male
# 162                                        EOGGr5_GLP_All
# 163                                   EOGMathGr5_CACR_All
# 164                                    EOGMathGr5_GLP_All
# 165                                EOGReadingGr5_CACR_All
# 166                                 EOGReadingGr5_GLP_All
# 167                                EOGScienceGr5_CACR_All
# 168                                 EOGScienceGr5_GLP_All
# 169                              EOGScienceGr5&8_CACR_All
# 170                                    EOGGr5_CACR_Female
# 171                                     EOGGr5_GLP_Female
# 172                                      EOGGr5_CACR_Male
# 173                                       EOGGr5_GLP_Male
# 174                                   EOGMathGr5_CACR_All
# 175                                    EOGMathGr5_GLP_All
# 176                                 EOGReadingGr5_GLP_All
# 177                                EOGScienceGr5_CACR_All
# 178                                 EOGScienceGr5_GLP_All
# 179                               EOGScienceGr5&8_GLP_All
# 180                                    EOGGr5_CACR_Female
# 181                                     EOGGr5_GLP_Female
# 182                                      EOGGr5_CACR_Male
# 183                                       EOGGr5_GLP_Male
# 184                                EOGScienceGr5_GLP_Male
# 185                                    EOGMathGr3_GLP_All
# 186                                EOGMathGr3_CACR_Female
# 187                                  EOGMathGr3_CACR_Male
# 188                                 EOGMathGr3_GLP_Female
# 189                                   EOGMathGr3_GLP_Male
# 190                                  EOGMathGr3-8_GLP_All
# 191                                  EOGSubjects_CACR_All
# 192                                   EOGSubjects_GLP_All
# 193                           EOG/EOCSubjects_CACR_Female
# 194                              EOGMathGr3-8_CACR_Female
# 195                               EOGMathGr3-8_GLP_Female
# 196                               EOGSubjects_CACR_Female
# 197                             EOG/EOCSubjects_CACR_Male
# 198                                EOGMathGr3-8_CACR_Male
# 199                                 EOGMathGr3-8_GLP_Male
# 200                                 EOGSubjects_CACR_Male
# 201                                  EOGSubjects_GLP_Male
# 202                                  EOGSubjects_CACR_All
# 203                                   EOGSubjects_GLP_All
# 204                            EOG/EOCSubjects_GLP_Female
# 205                              EOGMathGr3-8_CACR_Female
# 206                               EOGMathGr3-8_GLP_Female
# 207                               EOGSubjects_CACR_Female
# 208                                EOGSubjects_GLP_Female
# 209                              EOG/EOCSubjects_GLP_Male
# 210                                EOGMathGr3-8_CACR_Male
# 211                                 EOGMathGr3-8_GLP_Male
# 212                                 EOGSubjects_CACR_Male
# 213                                  EOGSubjects_GLP_Male
# 214                                    EOGMathGr4_GLP_All
# 215                                    EOGMathGr5_GLP_All
# 216                                  EOGMathGr5_CACR_Male
# 217                                   EOGMathGr5_GLP_Male
# 218                                 EOGMathGr5_GLP_Female
# 219                                  EOGMathGr5_CACR_Male
# 220                                   EOGMathGr5_GLP_Male
# 221                                 EOGReadingGr3_GLP_All
# 222                                        pct_PASSED_EOG
# 223                              EOGReadingGr3_GLP_Female
# 224                                EOGReadingGr3_GLP_Male
# 225                                        pct_PASSED_EOG
# 226                               EOGReadingGr3-8_GLP_All
# 227                                  EOGSubjects_CACR_All
# 228                                   EOGSubjects_GLP_All
# 229                           EOG/EOCSubjects_CACR_Female
# 230                           EOGReadingGr3-8_CACR_Female
# 231                            EOGReadingGr3-8_GLP_Female
# 232                               EOGSubjects_CACR_Female
# 233                             EOG/EOCSubjects_CACR_Male
# 234                             EOGReadingGr3-8_CACR_Male
# 235                              EOGReadingGr3-8_GLP_Male
# 236                                 EOGSubjects_CACR_Male
# 237                                  EOGSubjects_CACR_All
# 238                                   EOGSubjects_GLP_All
# 239                            EOG/EOCSubjects_GLP_Female
# 240                           EOGReadingGr3-8_CACR_Female
# 241                            EOGReadingGr3-8_GLP_Female
# 242                               EOGSubjects_CACR_Female
# 243                                EOGSubjects_GLP_Female
# 244                              EOG/EOCSubjects_GLP_Male
# 245                             EOGReadingGr3-8_CACR_Male
# 246                              EOGReadingGr3-8_GLP_Male
# 247                                 EOGSubjects_CACR_Male
# 248                                  EOGSubjects_GLP_Male
# 249                                 EOGReadingGr4_GLP_All
# 250                                 EOGReadingGr5_GLP_All
# 251                               EOGReadingGr5_CACR_Male
# 252                                       EOGGr5_GLP_Male
# 253                                EOGReadingGr5_GLP_Male
# 254                                 EOGScienceGr5_GLP_All
# 255                              EOGScienceGr5&8_CACR_All
# 256                               EOGScienceGr5&8_GLP_All
# 257                             EOGScienceGr5_CACR_Female
# 258                           EOGScienceGr5&8_CACR_Female
# 259                               EOGScienceGr5_CACR_Male
# 260                                EOGScienceGr5_GLP_Male
# 261                             EOGScienceGr5&8_CACR_Male
# 262                              EOGScienceGr5&8_CACR_All
# 263                               EOGScienceGr5&8_GLP_All
# 264                              EOGScienceGr5_GLP_Female
# 265                            EOGScienceGr5&8_GLP_Female
# 266                                       EOGGr5_GLP_Male
# 267                               EOGScienceGr5_CACR_Male
# 268                                EOGScienceGr5_GLP_Male
# 269                              EOGScienceGr5&8_GLP_Male
# 270                               EOGScienceGr5&8_GLP_All
# 271                           EOGScienceGr5&8_CACR_Female
# 272                            EOGScienceGr5&8_GLP_Female
# 273                               EOGScienceGr5_CACR_Male
# 274                             EOGScienceGr5&8_CACR_Male
# 275                              EOGScienceGr5&8_GLP_Male
# 276                            EOGScienceGr5&8_GLP_Female
# 277                                EOGScienceGr5_GLP_Male
# 278                             EOGScienceGr5&8_CACR_Male
# 279                              EOGScienceGr5&8_GLP_Male
# 280                                   EOGSubjects_GLP_All
# 281                           EOG/EOCSubjects_CACR_Female
# 282                            EOG/EOCSubjects_GLP_Female
# 283                              EOGMathGr3-8_CACR_Female
# 284                           EOGReadingGr3-8_CACR_Female
# 285                               EOGSubjects_CACR_Female
# 286                                EOGSubjects_GLP_Female
# 287                             EOG/EOCSubjects_CACR_Male
# 288                              EOG/EOCSubjects_GLP_Male
# 289                                EOGMathGr3-8_CACR_Male
# 290                                 EOGMathGr3-8_GLP_Male
# 291                             EOGReadingGr3-8_CACR_Male
# 292                                 EOGSubjects_CACR_Male
# 293                                  EOGSubjects_GLP_Male
# 294                           EOG/EOCSubjects_CACR_Female
# 295                            EOG/EOCSubjects_GLP_Female
# 296                               EOGMathGr3-8_GLP_Female
# 297                            EOGReadingGr3-8_GLP_Female
# 298                               EOGSubjects_CACR_Female
# 299                                EOGSubjects_GLP_Female
# 300                             EOG/EOCSubjects_CACR_Male
# 301                              EOG/EOCSubjects_GLP_Male
# 302                                 EOGMathGr3-8_GLP_Male
# 303                              EOGReadingGr3-8_GLP_Male
# 304                                 EOGSubjects_CACR_Male
# 305                                  EOGSubjects_GLP_Male
# 306                            EOG/EOCSubjects_GLP_Female
# 307                              EOGMathGr3-8_CACR_Female
# 308                               EOGMathGr3-8_GLP_Female
# 309                           EOGReadingGr3-8_CACR_Female
# 310                               EOGSubjects_CACR_Female
# 311                                EOGSubjects_GLP_Female
# 312                              EOGMathGr3-8_CACR_Female
# 313                               EOGMathGr3-8_GLP_Female
# 314                            EOGReadingGr3-8_GLP_Female
# 315                               EOGSubjects_CACR_Female
# 316                                EOGSubjects_GLP_Female
# 317                                     EOGGr3_GLP_Female
# 318                                EOGMathGr3_CACR_Female
# 319                             EOGReadingGr3_CACR_Female
# 320                                 EOGMathGr3_GLP_Female
# 321                              EOGReadingGr3_GLP_Female
# 322                                     EOGGr4_GLP_Female
# 323                                EOGMathGr4_CACR_Female
# 324                                 EOGMathGr4_GLP_Female
# 325                                     EOGGr5_GLP_Female
# 326                               EOGMathGr3-8_GLP_Female
# 327                               EOGSubjects_CACR_Female
# 328                                EOGSubjects_GLP_Female
# 329                               EOGSubjects_CACR_Female
# 330                                EOGSubjects_GLP_Female
# 331                                 EOGMathGr4_GLP_Female
# 332                                 EOGMathGr5_GLP_Female
# 333                            EOGReadingGr3-8_GLP_Female
# 334                               EOGSubjects_CACR_Female
# 335                               EOGSubjects_CACR_Female
# 336                                EOGSubjects_GLP_Female
# 337                              EOGReadingGr4_GLP_Female
# 338                              EOGReadingGr5_GLP_Female
# 339                              EOGScienceGr5_GLP_Female
# 340                           EOGScienceGr5&8_CACR_Female
# 341                            EOGScienceGr5&8_GLP_Female
# 342                            EOGScienceGr5&8_GLP_Female
# 343                                EOGSubjects_GLP_Female
# 344                              EOG/EOCSubjects_GLP_Male
# 345                                EOGMathGr3-8_CACR_Male
# 346                                 EOGMathGr3-8_GLP_Male
# 347                             EOGReadingGr3-8_CACR_Male
# 348                              EOGReadingGr3-8_GLP_Male
# 349                                 EOGSubjects_CACR_Male
# 350                                  EOGSubjects_GLP_Male
# 351                                EOGMathGr3-8_CACR_Male
# 352                                 EOGMathGr3-8_GLP_Male
# 353                              EOGReadingGr3-8_GLP_Male
# 354                                 EOGSubjects_CACR_Male
# 355                                  EOGSubjects_GLP_Male
# 356                                       EOGGr3_GLP_Male
# 357                                  EOGMathGr3_CACR_Male
# 358                               EOGReadingGr3_CACR_Male
# 359                                   EOGMathGr3_GLP_Male
# 360                                EOGReadingGr3_GLP_Male
# 361                                       EOGGr4_GLP_Male
# 362                                  EOGMathGr4_CACR_Male
# 363                                   EOGMathGr4_GLP_Male
# 364                                EOGReadingGr4_GLP_Male
# 365                                       EOGGr5_GLP_Male
# 366                                  EOGMathGr5_CACR_Male
# 367                                   EOGMathGr5_GLP_Male
# 368                               EOGScienceGr5_CACR_Male
# 369                             EOGScienceGr5&8_CACR_Male
# 370                                   EOGMathGr5_GLP_Male
# 371                                EOGReadingGr5_GLP_Male
# 372                               EOGScienceGr5_CACR_Male
# 373                                EOGScienceGr5_GLP_Male
# 374                              EOGScienceGr5&8_GLP_Male
# 375                                 EOGMathGr3-8_GLP_Male
# 376                                 EOGSubjects_CACR_Male
# 377                                  EOGSubjects_GLP_Male
# 378                                 EOGSubjects_CACR_Male
# 379                                  EOGSubjects_GLP_Male
# 380                                   EOGMathGr4_GLP_Male
# 381                                   EOGMathGr5_GLP_Male
# 382                              EOGReadingGr3-8_GLP_Male
# 383                                 EOGSubjects_CACR_Male
# 384                                 EOGSubjects_CACR_Male
# 385                                  EOGSubjects_GLP_Male
# 386                                EOGReadingGr4_GLP_Male
# 387                                EOGScienceGr5_GLP_Male
# 388                             EOGScienceGr5&8_CACR_Male
# 389                              EOGScienceGr5&8_GLP_Male
# 390                             EOGScienceGr5&8_CACR_Male
# 391                              EOGScienceGr5&8_GLP_Male
# 392                              EOGScienceGr5&8_GLP_Male
# 393                                  EOGSubjects_GLP_Male
# 394                    EOG/EOCSubjects_GLP_AmericanIndian
# 395                       EOGSubjects_CACR_AmericanIndian
# 396                        EOGSubjects_GLP_AmericanIndian
# 397                       EOGSubjects_CACR_AmericanIndian
# 398                        EOGSubjects_GLP_AmericanIndian
# 399                             EOGGr3_GLP_AmericanIndian
# 400                             EOGGr4_GLP_AmericanIndian
# 401                             EOGGr5_GLP_AmericanIndian
# 402                         EOGMathGr3_GLP_AmericanIndian
# 403                       EOGMathGr3-8_GLP_AmericanIndian
# 404                         EOGMathGr4_GLP_AmericanIndian
# 405                         EOGMathGr5_GLP_AmericanIndian
# 406                      EOGReadingGr3_GLP_AmericanIndian
# 407                    EOGReadingGr3-8_GLP_AmericanIndian
# 408                      EOGReadingGr4_GLP_AmericanIndian
# 409                      EOGReadingGr5_GLP_AmericanIndian
# 410                      EOGScienceGr5_GLP_AmericanIndian
# 411                   EOGScienceGr5&8_CACR_AmericanIndian
# 412                    EOGScienceGr5&8_GLP_AmericanIndian
# 413                        EOGSubjects_GLP_AmericanIndian
# 414                             EOG/EOCSubjects_GLP_Asian
# 415                                EOGSubjects_CACR_Asian
# 416                                 EOGSubjects_GLP_Asian
# 417                                EOGSubjects_CACR_Asian
# 418                                 EOGSubjects_GLP_Asian
# 419                                      EOGGr3_GLP_Asian
# 420                                      EOGGr4_GLP_Asian
# 421                                      EOGGr5_GLP_Asian
# 422                                  EOGMathGr3_GLP_Asian
# 423                              EOGReadingGr3_CACR_Asian
# 424                               EOGReadingGr3_GLP_Asian
# 425                              EOGReadingGr3_CACR_Asian
# 426                               EOGReadingGr3_GLP_Asian
# 427                                EOGMathGr3-8_GLP_Asian
# 428                             EOGReadingGr3-8_GLP_Asian
# 429                             EOGReadingGr3-8_GLP_Asian
# 430                                  EOGMathGr4_GLP_Asian
# 431                              EOGReadingGr4_CACR_Asian
# 432                               EOGReadingGr4_GLP_Asian
# 433                              EOGReadingGr4_CACR_Asian
# 434                               EOGReadingGr4_GLP_Asian
# 435                                  EOGMathGr5_GLP_Asian
# 436                               EOGReadingGr5_GLP_Asian
# 437                              EOGScienceGr5_CACR_Asian
# 438                               EOGScienceGr5_GLP_Asian
# 439                            EOGScienceGr5&8_CACR_Asian
# 440                             EOGScienceGr5&8_GLP_Asian
# 441                               EOGReadingGr5_GLP_Asian
# 442                              EOGScienceGr5_CACR_Asian
# 443                               EOGScienceGr5_GLP_Asian
# 444                            EOGScienceGr5&8_CACR_Asian
# 445                             EOGScienceGr5&8_GLP_Asian
# 446                               EOGReadingGr3_GLP_Asian
# 447                             EOGReadingGr3-8_GLP_Asian
# 448                               EOGReadingGr4_GLP_Asian
# 449                               EOGReadingGr5_GLP_Asian
# 450                              EOGScienceGr5_CACR_Asian
# 451                               EOGScienceGr5_GLP_Asian
# 452                            EOGScienceGr5&8_CACR_Asian
# 453                             EOGScienceGr5&8_GLP_Asian
# 454                               EOGScienceGr5_GLP_Asian
# 455                            EOGScienceGr5&8_CACR_Asian
# 456                             EOGScienceGr5&8_GLP_Asian
# 457                            EOGScienceGr5&8_CACR_Asian
# 458                             EOGScienceGr5&8_GLP_Asian
# 459                             EOGScienceGr5&8_GLP_Asian
# 460                                 EOGSubjects_GLP_Asian
# 461                             EOG/EOCSubjects_GLP_Black
# 462                                EOGSubjects_CACR_Black
# 463                                 EOGSubjects_GLP_Black
# 464                                EOGSubjects_CACR_Black
# 465                                 EOGSubjects_GLP_Black
# 466                                      EOGGr4_GLP_Black
# 467                                      EOGGr5_GLP_Black
# 468                                EOGMathGr3-8_GLP_Black
# 469                                  EOGMathGr4_GLP_Black
# 470                                  EOGMathGr5_GLP_Black
# 471                               EOGScienceGr5_GLP_Black
# 472                            EOGScienceGr5&8_CACR_Black
# 473                             EOGScienceGr5&8_GLP_Black
# 474                             EOGScienceGr5&8_GLP_Black
# 475                                 EOGSubjects_GLP_Black
# 476                             EOGSubjects_CACR_Hispanic
# 477                              EOGSubjects_GLP_Hispanic
# 478                                   EOGGr4_GLP_Hispanic
# 479                                   EOGGr5_GLP_Hispanic
# 480                             EOGMathGr3-8_GLP_Hispanic
# 481                               EOGMathGr4_GLP_Hispanic
# 482                               EOGMathGr5_GLP_Hispanic
# 483                            EOGScienceGr5_GLP_Hispanic
# 484                         EOGScienceGr5&8_CACR_Hispanic
# 485                          EOGScienceGr5&8_GLP_Hispanic
# 486                          EOGScienceGr5&8_GLP_Hispanic
# 487                       EOGSubjects_CACR_TwoorMoreRaces
# 488                        EOGSubjects_GLP_TwoorMoreRaces
# 489                             EOGGr3_GLP_TwoorMoreRaces
# 490                             EOGGr4_GLP_TwoorMoreRaces
# 491                             EOGGr5_GLP_TwoorMoreRaces
# 492                         EOGMathGr3_GLP_TwoorMoreRaces
# 493                       EOGMathGr3-8_GLP_TwoorMoreRaces
# 494                         EOGMathGr4_GLP_TwoorMoreRaces
# 495                         EOGMathGr5_GLP_TwoorMoreRaces
# 496                      EOGReadingGr3_GLP_TwoorMoreRaces
# 497                      EOGReadingGr4_GLP_TwoorMoreRaces
# 498                      EOGReadingGr5_GLP_TwoorMoreRaces
# 499                      EOGScienceGr5_GLP_TwoorMoreRaces
# ...                                                   ...
# 184219               Tuition and fees deduction Amt LT25K
# 184220           Tuition and fees deduction Ct 100KLT200K
# 184221             Tuition and fees deduction Ct 25KLT50K
# 184222             Tuition and fees deduction Ct 50KLT75K
# 184223                  Tuition and fees deduction Ct All
# 184224                Tuition and fees deduction Ct LT25K
# 184225           Unemployment compensation Amt 100KLT200K
# 184226             Unemployment compensation Amt 25KLT50K
# 184227             Unemployment compensation Amt 50KLT75K
# 184228            Unemployment compensation Amt 75KLT100K
# 184229                  Unemployment compensation Amt All
# 184230            Unemployment compensation Ct 100KLT200K
# 184231              Unemployment compensation Ct 25KLT50K
# 184232              Unemployment compensation Ct 50KLT75K
# 184233             Unemployment compensation Ct 75KLT100K
# 184234                   Unemployment compensation Ct All
# 184235                Unemployment compensation Ct GE200K
# 184236                                     InitiatedbyLEA
# 184237                        Tot tax payments Amt GE200K
# 184238                         Tot tax payments Amt LT25K
# 184239                     Tot tax payments Ct 100KLT200K
# 184240                       Tot tax payments Ct 25KLT50K
# 184241                       Tot tax payments Ct 50KLT75K
# 184242                      Tot tax payments Ct 75KLT100K
# 184243                            Tot tax payments Ct All
# 184244                         Tot tax payments Ct GE200K
# 184245                          Tot tax payments Ct LT25K
# 184246          Tuition and fees deduction Amt 100KLT200K
# 184247            Tuition and fees deduction Amt 25KLT50K
# 184248            Tuition and fees deduction Amt 50KLT75K
# 184249                 Tuition and fees deduction Amt All
# 184250               Tuition and fees deduction Amt LT25K
# 184251           Tuition and fees deduction Ct 100KLT200K
# 184252             Tuition and fees deduction Ct 25KLT50K
# 184253             Tuition and fees deduction Ct 50KLT75K
# 184254                  Tuition and fees deduction Ct All
# 184255                Tuition and fees deduction Ct LT25K
# 184256           Unemployment compensation Amt 100KLT200K
# 184257             Unemployment compensation Amt 25KLT50K
# 184258             Unemployment compensation Amt 50KLT75K
# 184259            Unemployment compensation Amt 75KLT100K
# 184260                  Unemployment compensation Amt All
# 184261               Unemployment compensation Amt GE200K
# 184262                Unemployment compensation Amt LT25K
# 184263            Unemployment compensation Ct 100KLT200K
# 184264              Unemployment compensation Ct 25KLT50K
# 184265              Unemployment compensation Ct 50KLT75K
# 184266             Unemployment compensation Ct 75KLT100K
# 184267                   Unemployment compensation Ct All
# 184268                Unemployment compensation Ct GE200K
# 184269                                     InitiatedbyLEA
# 184270                       Tot tax payments Ct 25KLT50K
# 184271                       Tot tax payments Ct 50KLT75K
# 184272                      Tot tax payments Ct 75KLT100K
# 184273                            Tot tax payments Ct All
# 184274                         Tot tax payments Ct GE200K
# 184275                          Tot tax payments Ct LT25K
# 184276            Tuition and fees deduction Amt 25KLT50K
# 184277            Tuition and fees deduction Amt 50KLT75K
# 184278                 Tuition and fees deduction Amt All
# 184279               Tuition and fees deduction Amt LT25K
# 184280             Tuition and fees deduction Ct 25KLT50K
# 184281             Tuition and fees deduction Ct 50KLT75K
# 184282                  Tuition and fees deduction Ct All
# 184283                Tuition and fees deduction Ct LT25K
# 184284           Unemployment compensation Amt 100KLT200K
# 184285             Unemployment compensation Amt 25KLT50K
# 184286             Unemployment compensation Amt 50KLT75K
# 184287            Unemployment compensation Amt 75KLT100K
# 184288                  Unemployment compensation Amt All
# 184289               Unemployment compensation Amt GE200K
# 184290            Unemployment compensation Ct 100KLT200K
# 184291              Unemployment compensation Ct 25KLT50K
# 184292              Unemployment compensation Ct 50KLT75K
# 184293             Unemployment compensation Ct 75KLT100K
# 184294                   Unemployment compensation Ct All
# 184295                                     InitiatedbyLEA
# 184296                       Tot tax payments Ct 25KLT50K
# 184297                       Tot tax payments Ct 50KLT75K
# 184298                            Tot tax payments Ct All
# 184299                          Tot tax payments Ct LT25K
# 184300            Tuition and fees deduction Amt 25KLT50K
# 184301               Tuition and fees deduction Amt LT25K
# 184302             Tuition and fees deduction Ct 25KLT50K
# 184303                Tuition and fees deduction Ct LT25K
# 184304             Unemployment compensation Amt 25KLT50K
# 184305             Unemployment compensation Amt 50KLT75K
# 184306            Unemployment compensation Amt 75KLT100K
# 184307                  Unemployment compensation Amt All
# 184308                Unemployment compensation Amt LT25K
# 184309              Unemployment compensation Ct 25KLT50K
# 184310              Unemployment compensation Ct 50KLT75K
# 184311             Unemployment compensation Ct 75KLT100K
# 184312                   Unemployment compensation Ct All
# 184313                 Unemployment compensation Ct LT25K
# 184314                                     InitiatedbyLEA
# 184315                       Tot tax payments Ct 25KLT50K
# 184316                       Tot tax payments Ct 50KLT75K
# 184317                      Tot tax payments Ct 75KLT100K
# 184318                            Tot tax payments Ct All
# 184319                         Tot tax payments Ct GE200K
# 184320          Tuition and fees deduction Amt 100KLT200K
# 184321            Tuition and fees deduction Amt 50KLT75K
# 184322                 Tuition and fees deduction Amt All
# 184323               Tuition and fees deduction Amt LT25K
# 184324           Tuition and fees deduction Ct 100KLT200K
# 184325             Tuition and fees deduction Ct 25KLT50K
# 184326             Tuition and fees deduction Ct 50KLT75K
# 184327                  Tuition and fees deduction Ct All
# 184328                Tuition and fees deduction Ct LT25K
# 184329           Unemployment compensation Amt 100KLT200K
# 184330             Unemployment compensation Amt 50KLT75K
# 184331            Unemployment compensation Amt 75KLT100K
# 184332               Unemployment compensation Amt GE200K
# 184333            Unemployment compensation Ct 100KLT200K
# 184334              Unemployment compensation Ct 50KLT75K
# 184335             Unemployment compensation Ct 75KLT100K
# 184336                Unemployment compensation Ct GE200K
# 184337                       Tot tax payments Ct 50KLT75K
# 184338                      Tot tax payments Ct 75KLT100K
# 184339                            Tot tax payments Ct All
# 184340                         Tot tax payments Ct GE200K
# 184341                          Tot tax payments Ct LT25K
# 184342            Tuition and fees deduction Amt 25KLT50K
# 184343            Tuition and fees deduction Amt 50KLT75K
# 184344                 Tuition and fees deduction Amt All
# 184345               Tuition and fees deduction Amt LT25K
# 184346             Tuition and fees deduction Ct 25KLT50K
# 184347             Tuition and fees deduction Ct 50KLT75K
# 184348                  Tuition and fees deduction Ct All
# 184349                Tuition and fees deduction Ct LT25K
# 184350           Unemployment compensation Amt 100KLT200K
# 184351             Unemployment compensation Amt 25KLT50K
# 184352             Unemployment compensation Amt 50KLT75K
# 184353            Unemployment compensation Amt 75KLT100K
# 184354                  Unemployment compensation Amt All
# 184355                Unemployment compensation Amt LT25K
# 184356            Unemployment compensation Ct 100KLT200K
# 184357              Unemployment compensation Ct 25KLT50K
# 184358              Unemployment compensation Ct 50KLT75K
# 184359             Unemployment compensation Ct 75KLT100K
# 184360                   Unemployment compensation Ct All
# 184361                 Unemployment compensation Ct LT25K
# 184362                                     InitiatedbyLEA
# 184363                      Tot tax payments Ct 75KLT100K
# 184364                            Tot tax payments Ct All
# 184365                         Tot tax payments Ct GE200K
# 184366                          Tot tax payments Ct LT25K
# 184367          Tuition and fees deduction Amt 100KLT200K
# 184368            Tuition and fees deduction Amt 25KLT50K
# 184369            Tuition and fees deduction Amt 50KLT75K
# 184370                 Tuition and fees deduction Amt All
# 184371               Tuition and fees deduction Amt LT25K
# 184372           Tuition and fees deduction Ct 100KLT200K
# 184373             Tuition and fees deduction Ct 25KLT50K
# 184374             Tuition and fees deduction Ct 50KLT75K
# 184375                  Tuition and fees deduction Ct All
# 184376                Tuition and fees deduction Ct LT25K
# 184377           Unemployment compensation Amt 100KLT200K
# 184378             Unemployment compensation Amt 25KLT50K
# 184379             Unemployment compensation Amt 50KLT75K
# 184380            Unemployment compensation Amt 75KLT100K
# 184381                  Unemployment compensation Amt All
# 184382                Unemployment compensation Amt LT25K
# 184383            Unemployment compensation Ct 100KLT200K
# 184384              Unemployment compensation Ct 25KLT50K
# 184385              Unemployment compensation Ct 50KLT75K
# 184386             Unemployment compensation Ct 75KLT100K
# 184387                   Unemployment compensation Ct All
# 184388                                     InitiatedbyLEA
# 184389                            Tot tax payments Ct All
# 184390                         Tot tax payments Ct GE200K
# 184391                          Tot tax payments Ct LT25K
# 184392          Tuition and fees deduction Amt 100KLT200K
# 184393            Tuition and fees deduction Amt 25KLT50K
# 184394            Tuition and fees deduction Amt 50KLT75K
# 184395                 Tuition and fees deduction Amt All
# 184396               Tuition and fees deduction Amt LT25K
# 184397           Tuition and fees deduction Ct 100KLT200K
# 184398             Tuition and fees deduction Ct 25KLT50K
# 184399             Tuition and fees deduction Ct 50KLT75K
# 184400                  Tuition and fees deduction Ct All
# 184401                Tuition and fees deduction Ct LT25K
# 184402           Unemployment compensation Amt 100KLT200K
# 184403             Unemployment compensation Amt 25KLT50K
# 184404             Unemployment compensation Amt 50KLT75K
# 184405            Unemployment compensation Amt 75KLT100K
# 184406                  Unemployment compensation Amt All
# 184407            Unemployment compensation Ct 100KLT200K
# 184408              Unemployment compensation Ct 25KLT50K
# 184409              Unemployment compensation Ct 50KLT75K
# 184410             Unemployment compensation Ct 75KLT100K
# 184411                   Unemployment compensation Ct All
# 184412                                     InitiatedbyLEA
# 184413                         Tot tax payments Ct GE200K
# 184414                          Tot tax payments Ct LT25K
# 184415          Tuition and fees deduction Amt 100KLT200K
# 184416            Tuition and fees deduction Amt 25KLT50K
# 184417            Tuition and fees deduction Amt 50KLT75K
# 184418                 Tuition and fees deduction Amt All
# 184419               Tuition and fees deduction Amt LT25K
# 184420           Tuition and fees deduction Ct 100KLT200K
# 184421             Tuition and fees deduction Ct 25KLT50K
# 184422             Tuition and fees deduction Ct 50KLT75K
# 184423                  Tuition and fees deduction Ct All
# 184424                Tuition and fees deduction Ct LT25K
# 184425           Unemployment compensation Amt 100KLT200K
# 184426             Unemployment compensation Amt 25KLT50K
# 184427             Unemployment compensation Amt 50KLT75K
# 184428            Unemployment compensation Amt 75KLT100K
# 184429                  Unemployment compensation Amt All
# 184430                Unemployment compensation Amt LT25K
# 184431            Unemployment compensation Ct 100KLT200K
# 184432              Unemployment compensation Ct 25KLT50K
# 184433              Unemployment compensation Ct 50KLT75K
# 184434             Unemployment compensation Ct 75KLT100K
# 184435                   Unemployment compensation Ct All
# 184436                 Unemployment compensation Ct LT25K
# 184437                                     InitiatedbyLEA
# 184438          Tuition and fees deduction Amt 100KLT200K
# 184439            Tuition and fees deduction Amt 25KLT50K
# 184440            Tuition and fees deduction Amt 50KLT75K
# 184441                 Tuition and fees deduction Amt All
# 184442               Tuition and fees deduction Amt LT25K
# 184443           Tuition and fees deduction Ct 100KLT200K
# 184444             Tuition and fees deduction Ct 25KLT50K
# 184445             Tuition and fees deduction Ct 50KLT75K
# 184446                  Tuition and fees deduction Ct All
# 184447                Tuition and fees deduction Ct LT25K
# 184448           Unemployment compensation Amt 100KLT200K
# 184449             Unemployment compensation Amt 25KLT50K
# 184450             Unemployment compensation Amt 50KLT75K
# 184451            Unemployment compensation Amt 75KLT100K
# 184452                  Unemployment compensation Amt All
# 184453               Unemployment compensation Amt GE200K
# 184454            Unemployment compensation Ct 100KLT200K
# 184455              Unemployment compensation Ct 25KLT50K
# 184456              Unemployment compensation Ct 50KLT75K
# 184457             Unemployment compensation Ct 75KLT100K
# 184458                   Unemployment compensation Ct All
# 184459                Unemployment compensation Ct GE200K
# 184460            Tuition and fees deduction Amt 25KLT50K
# 184461            Tuition and fees deduction Amt 50KLT75K
# 184462                 Tuition and fees deduction Amt All
# 184463               Tuition and fees deduction Amt LT25K
# 184464             Tuition and fees deduction Ct 25KLT50K
# 184465             Tuition and fees deduction Ct 50KLT75K
# 184466                  Tuition and fees deduction Ct All
# 184467                Tuition and fees deduction Ct LT25K
# 184468             Unemployment compensation Amt 25KLT50K
# 184469             Unemployment compensation Amt 50KLT75K
# 184470            Unemployment compensation Amt 75KLT100K
# 184471                  Unemployment compensation Amt All
# 184472                Unemployment compensation Amt LT25K
# 184473              Unemployment compensation Ct 25KLT50K
# 184474              Unemployment compensation Ct 50KLT75K
# 184475             Unemployment compensation Ct 75KLT100K
# 184476                   Unemployment compensation Ct All
# 184477                 Unemployment compensation Ct LT25K
# 184478                                     InitiatedbyLEA
# 184479            Tuition and fees deduction Amt 50KLT75K
# 184480                 Tuition and fees deduction Amt All
# 184481               Tuition and fees deduction Amt LT25K
# 184482           Tuition and fees deduction Ct 100KLT200K
# 184483             Tuition and fees deduction Ct 50KLT75K
# 184484                  Tuition and fees deduction Ct All
# 184485                Tuition and fees deduction Ct LT25K
# 184486           Unemployment compensation Amt 100KLT200K
# 184487            Unemployment compensation Amt 75KLT100K
# 184488               Unemployment compensation Amt GE200K
# 184489            Unemployment compensation Ct 100KLT200K
# 184490             Unemployment compensation Ct 75KLT100K
# 184491                Unemployment compensation Ct GE200K
# 184492            Tuition and fees deduction Amt 50KLT75K
# 184493                 Tuition and fees deduction Amt All
# 184494               Tuition and fees deduction Amt LT25K
# 184495             Tuition and fees deduction Ct 25KLT50K
# 184496             Tuition and fees deduction Ct 50KLT75K
# 184497                  Tuition and fees deduction Ct All
# 184498                Tuition and fees deduction Ct LT25K
# 184499             Unemployment compensation Amt 25KLT50K
# 184500             Unemployment compensation Amt 50KLT75K
# 184501            Unemployment compensation Amt 75KLT100K
# 184502                  Unemployment compensation Amt All
# ...
# 184501            Tuition and fees deduction Amt 25KLT50K     0.976308
# 184502            Tuition and fees deduction Amt 25KLT50K     0.988915
# 184503            Tuition and fees deduction Amt 25KLT50K     0.980035
# 184504            Tuition and fees deduction Amt 25KLT50K     0.983220
# 184505            Tuition and fees deduction Amt 25KLT50K     0.970677
# 184506            Tuition and fees deduction Amt 25KLT50K     0.965253
# 184507            Tuition and fees deduction Amt 25KLT50K     0.983760
# 184508            Tuition and fees deduction Amt 25KLT50K     0.967582
# 184509            Tuition and fees deduction Amt 25KLT50K     0.959512
# 184510            Tuition and fees deduction Amt 25KLT50K     0.981238
# 184511            Tuition and fees deduction Amt 50KLT75K     0.997642
# 184512            Tuition and fees deduction Amt 50KLT75K     0.992724
# 184513            Tuition and fees deduction Amt 50KLT75K     0.967023
# 184514            Tuition and fees deduction Amt 50KLT75K     0.984313
# 184515            Tuition and fees deduction Amt 50KLT75K     0.999331
# 184516            Tuition and fees deduction Amt 50KLT75K     0.995936
# 184517            Tuition and fees deduction Amt 50KLT75K     0.991165
# 184518            Tuition and fees deduction Amt 50KLT75K     0.987865
# 184519            Tuition and fees deduction Amt 50KLT75K     0.975813
# 184520            Tuition and fees deduction Amt 50KLT75K     0.982898
# 184521            Tuition and fees deduction Amt 50KLT75K     0.987709
# 184522            Tuition and fees deduction Amt 50KLT75K     0.978458
# 184523            Tuition and fees deduction Amt 50KLT75K     0.955278
# 184524            Tuition and fees deduction Amt 50KLT75K     0.986389
# 184525            Tuition and fees deduction Amt 50KLT75K     0.969810
# 184526            Tuition and fees deduction Amt 50KLT75K     0.974722
# 184527            Tuition and fees deduction Amt 50KLT75K     0.982202
# 184528            Tuition and fees deduction Amt 50KLT75K     0.969231
# 184529            Tuition and fees deduction Amt 50KLT75K     0.954996
# 184530            Tuition and fees deduction Amt 50KLT75K     0.966736
# 184531           Tuition and fees deduction Amt 75KLT100K     0.997084
# 184532                 Tuition and fees deduction Amt All     0.995846
# 184533                 Tuition and fees deduction Amt All     0.972426
# 184534                 Tuition and fees deduction Amt All     0.986526
# 184535                 Tuition and fees deduction Amt All     0.998179
# 184536                 Tuition and fees deduction Amt All     0.999331
# 184537                 Tuition and fees deduction Amt All     0.995360
# 184538                 Tuition and fees deduction Amt All     0.988353
# 184539                 Tuition and fees deduction Amt All     0.974960
# 184540                 Tuition and fees deduction Amt All     0.984383
# 184541                 Tuition and fees deduction Amt All     0.988810
# 184542                 Tuition and fees deduction Amt All     0.978379
# 184543                 Tuition and fees deduction Amt All     0.987141
# 184544                 Tuition and fees deduction Amt All     0.970032
# 184545                 Tuition and fees deduction Amt All     0.977840
# 184546                 Tuition and fees deduction Amt All     0.984752
# 184547                 Tuition and fees deduction Amt All     0.970568
# 184548                 Tuition and fees deduction Amt All     0.966186
# 184549               Tuition and fees deduction Amt LT25K     0.950386
# 184550               Tuition and fees deduction Amt LT25K     0.987080
# 184551               Tuition and fees deduction Amt LT25K     0.992252
# 184552               Tuition and fees deduction Amt LT25K     0.993019
# 184553               Tuition and fees deduction Amt LT25K     0.999168
# 184554               Tuition and fees deduction Amt LT25K     0.975512
# 184555               Tuition and fees deduction Amt LT25K     0.978087
# 184556               Tuition and fees deduction Amt LT25K     0.981163
# 184557               Tuition and fees deduction Amt LT25K     0.984933
# 184558               Tuition and fees deduction Amt LT25K     0.981375
# 184559               Tuition and fees deduction Amt LT25K     0.955496
# 184560               Tuition and fees deduction Amt LT25K     0.973318
# 184561               Tuition and fees deduction Amt LT25K     0.973919
# 184562               Tuition and fees deduction Amt LT25K     0.973998
# 184563               Tuition and fees deduction Amt LT25K     0.978783
# 184564               Tuition and fees deduction Amt LT25K     0.975731
# 184565               Tuition and fees deduction Amt LT25K     0.962117
# 184566           Tuition and fees deduction Ct 100KLT200K     0.971159
# 184567           Tuition and fees deduction Ct 100KLT200K     0.978359
# 184568           Tuition and fees deduction Ct 100KLT200K     0.951289
# 184569           Tuition and fees deduction Ct 100KLT200K     0.985314
# 184570           Tuition and fees deduction Ct 100KLT200K     0.956404
# 184571           Tuition and fees deduction Ct 100KLT200K     0.956088
# 184572           Tuition and fees deduction Ct 100KLT200K     0.986627
# 184573           Tuition and fees deduction Ct 100KLT200K     0.960938
# 184574           Tuition and fees deduction Ct 100KLT200K     0.961126
# 184575             Tuition and fees deduction Ct 25KLT50K     0.984836
# 184576             Tuition and fees deduction Ct 25KLT50K     0.984284
# 184577             Tuition and fees deduction Ct 25KLT50K     0.987970
# 184578             Tuition and fees deduction Ct 25KLT50K     0.960783
# 184579             Tuition and fees deduction Ct 25KLT50K     0.989161
# 184580             Tuition and fees deduction Ct 25KLT50K     0.988033
# 184581             Tuition and fees deduction Ct 25KLT50K     0.983049
# 184582             Tuition and fees deduction Ct 25KLT50K     0.989578
# 184583             Tuition and fees deduction Ct 25KLT50K     0.973113
# 184584             Tuition and fees deduction Ct 25KLT50K     0.959017
# 184585             Tuition and fees deduction Ct 25KLT50K     0.984226
# 184586             Tuition and fees deduction Ct 25KLT50K     0.978510
# 184587             Tuition and fees deduction Ct 25KLT50K     0.974729
# 184588             Tuition and fees deduction Ct 25KLT50K     0.984380
# 184589             Tuition and fees deduction Ct 25KLT50K     0.960111
# 184590             Tuition and fees deduction Ct 25KLT50K     0.954552
# 184591             Tuition and fees deduction Ct 25KLT50K     0.982518
# 184592             Tuition and fees deduction Ct 50KLT75K     0.997517
# 184593             Tuition and fees deduction Ct 50KLT75K     0.991588
# 184594             Tuition and fees deduction Ct 50KLT75K     0.988378
# 184595             Tuition and fees deduction Ct 50KLT75K     0.975466
# 184596             Tuition and fees deduction Ct 50KLT75K     0.984608
# 184597             Tuition and fees deduction Ct 50KLT75K     0.988877
# 184598             Tuition and fees deduction Ct 50KLT75K     0.978422
# 184599             Tuition and fees deduction Ct 50KLT75K     0.952286
# 184600             Tuition and fees deduction Ct 50KLT75K     0.987072
# 184601             Tuition and fees deduction Ct 50KLT75K     0.969819
# 184602             Tuition and fees deduction Ct 50KLT75K     0.977133
# 184603             Tuition and fees deduction Ct 50KLT75K     0.984242
# 184604             Tuition and fees deduction Ct 50KLT75K     0.969628
# 184605             Tuition and fees deduction Ct 50KLT75K     0.952418
# 184606             Tuition and fees deduction Ct 50KLT75K     0.965514
# 184607                  Tuition and fees deduction Ct All     0.993569
# 184608                  Tuition and fees deduction Ct All     0.990346
# 184609                  Tuition and fees deduction Ct All     0.972507
# 184610                  Tuition and fees deduction Ct All     0.984790
# 184611                  Tuition and fees deduction Ct All     0.989171
# 184612                  Tuition and fees deduction Ct All     0.976250
# 184613                  Tuition and fees deduction Ct All     0.989472
# 184614                  Tuition and fees deduction Ct All     0.968030
# 184615                  Tuition and fees deduction Ct All     0.979427
# 184616                  Tuition and fees deduction Ct All     0.986504
# 184617                  Tuition and fees deduction Ct All     0.968604
# 184618                  Tuition and fees deduction Ct All     0.963475
# 184619                Tuition and fees deduction Ct LT25K     0.975989
# 184620                Tuition and fees deduction Ct LT25K     0.981033
# 184621                Tuition and fees deduction Ct LT25K     0.984986
# 184622                Tuition and fees deduction Ct LT25K     0.987692
# 184623                Tuition and fees deduction Ct LT25K     0.984391
# 184624                Tuition and fees deduction Ct LT25K     0.959309
# 184625                Tuition and fees deduction Ct LT25K     0.973912
# 184626                Tuition and fees deduction Ct LT25K     0.977503
# 184627                Tuition and fees deduction Ct LT25K     0.978756
# 184628                Tuition and fees deduction Ct LT25K     0.982275
# 184629                Tuition and fees deduction Ct LT25K     0.979583
# 184630                Tuition and fees deduction Ct LT25K     0.962082
# 184631           Unemployment compensation Amt 100KLT200K     0.957923
# 184632           Unemployment compensation Amt 100KLT200K     0.976225
# 184633           Unemployment compensation Amt 100KLT200K     0.985602
# 184634           Unemployment compensation Amt 100KLT200K     0.962186
# 184635           Unemployment compensation Amt 100KLT200K     0.975113
# 184636           Unemployment compensation Amt 100KLT200K     0.999827
# 184637           Unemployment compensation Amt 100KLT200K     0.952988
# 184638           Unemployment compensation Amt 100KLT200K     0.973069
# 184639           Unemployment compensation Amt 100KLT200K     0.985641
# 184640           Unemployment compensation Amt 100KLT200K     0.951937
# 184641           Unemployment compensation Amt 100KLT200K     0.976477
# 184642             Unemployment compensation Amt 25KLT50K     0.994799
# 184643             Unemployment compensation Amt 25KLT50K     0.989507
# 184644             Unemployment compensation Amt 25KLT50K     0.999518
# 184645             Unemployment compensation Amt 25KLT50K     0.988927
# 184646             Unemployment compensation Amt 25KLT50K     0.955905
# 184647             Unemployment compensation Amt 25KLT50K     0.998159
# 184648             Unemployment compensation Amt 25KLT50K     0.989202
# 184649             Unemployment compensation Amt 25KLT50K     0.982992
# 184650             Unemployment compensation Amt 25KLT50K     0.997658
# 184651             Unemployment compensation Amt 25KLT50K     0.979111
# 184652             Unemployment compensation Amt 25KLT50K     0.952012
# 184653             Unemployment compensation Amt 25KLT50K     0.975494
# 184654             Unemployment compensation Amt 50KLT75K     0.997065
# 184655             Unemployment compensation Amt 50KLT75K     0.995968
# 184656             Unemployment compensation Amt 50KLT75K     0.972306
# 184657             Unemployment compensation Amt 50KLT75K     0.975085
# 184658             Unemployment compensation Amt 50KLT75K     0.992832
# 184659             Unemployment compensation Amt 50KLT75K     0.996701
# 184660             Unemployment compensation Amt 50KLT75K     0.994112
# 184661             Unemployment compensation Amt 50KLT75K     0.992595
# 184662             Unemployment compensation Amt 50KLT75K     0.960235
# 184663             Unemployment compensation Amt 50KLT75K     0.973085
# 184664            Unemployment compensation Amt 75KLT100K     0.991970
# 184665            Unemployment compensation Amt 75KLT100K     0.962024
# 184666            Unemployment compensation Amt 75KLT100K     0.984414
# 184667            Unemployment compensation Amt 75KLT100K     0.987480
# 184668            Unemployment compensation Amt 75KLT100K     0.994535
# 184669            Unemployment compensation Amt 75KLT100K     0.997744
# 184670            Unemployment compensation Amt 75KLT100K     0.987682
# 184671            Unemployment compensation Amt 75KLT100K     0.968524
# 184672                  Unemployment compensation Amt All     0.987954
# 184673                  Unemployment compensation Amt All     0.960125
# 184674                  Unemployment compensation Amt All     0.997798
# 184675                  Unemployment compensation Amt All     0.990602
# 184676                  Unemployment compensation Amt All     0.985785
# 184677                  Unemployment compensation Amt All     0.998182
# 184678                  Unemployment compensation Amt All     0.978369
# 184679                  Unemployment compensation Amt All     0.974652
# 184680               Unemployment compensation Amt GE200K     0.974636
# 184681               Unemployment compensation Amt GE200K     0.999574
# 184682                Unemployment compensation Amt LT25K     0.989014
# 184683                Unemployment compensation Amt LT25K     0.965225
# 184684                Unemployment compensation Amt LT25K     0.951866
# 184685                Unemployment compensation Amt LT25K     0.991011
# 184686                Unemployment compensation Amt LT25K     0.997427
# 184687                Unemployment compensation Amt LT25K     0.956493
# 184688            Unemployment compensation Ct 100KLT200K     0.951187
# 184689            Unemployment compensation Ct 100KLT200K     0.972559
# 184690            Unemployment compensation Ct 100KLT200K     0.985205
# 184691            Unemployment compensation Ct 100KLT200K     0.976304
# 184692              Unemployment compensation Ct 25KLT50K     0.991399
# 184693              Unemployment compensation Ct 25KLT50K     0.983713
# 184694              Unemployment compensation Ct 25KLT50K     0.999227
# 184695              Unemployment compensation Ct 25KLT50K     0.982513
# 184696              Unemployment compensation Ct 25KLT50K     0.968905
# 184697              Unemployment compensation Ct 50KLT75K     0.996484
# 184698              Unemployment compensation Ct 50KLT75K     0.990747
# 184699              Unemployment compensation Ct 50KLT75K     0.956262
# 184700              Unemployment compensation Ct 50KLT75K     0.961490
# 184701             Unemployment compensation Ct 75KLT100K     0.983472
# 184702             Unemployment compensation Ct 75KLT100K     0.959705
# 184703                   Unemployment compensation Ct All     0.985534
# 184704                   Unemployment compensation Ct All     0.967119
# 184705                                RemainedinEducation     0.978730
# 184706                                    PersonalReasons     0.972028
# 184707                                      category_cd_E     0.965446
# 184708                                      category_cd_E     1.000000
# 184709                                      category_cd_E     0.965446
# 184710                                      category_cd_I     0.965446
# 184711                                      category_cd_I     1.000000
# 184712  calendar_type_txt_Regular School, Traditional ...     1.000000
# 184713  calendar_type_txt_Regular School, Traditional ...     1.000000
# 184714  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 184715  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 184716                                  sna_pgm_type_cd_X     1.000000
# 184717                                  sna_pgm_type_cd_Y     1.000000
# 184718                                      Category_Cd_E     0.965446
#
# [184719 rows x 3 columns]

# %%
print ('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  949  highly correlated fields.
# ['Reading  SPG Score',
#  'Math SPG Score',
#  'Overall Achievement Score',
#  'Read Score',
#  'Math Score',
#  'EOG/EOCSubjects_CACR_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_CACR_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_CACR_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_CACR_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_CACR_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr4_GLP_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_CACR_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_CACR_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_CACR_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_CACR_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_CACR_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr4_GLP_Male',
#  'EOGReadingGr5_CACR_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_CACR_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGReadingGr5_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_CACR_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_CACR_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_CACR_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_CACR_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_CACR_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_CACR_Black',
#  'EOGSubjects_GLP_Black',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_CACR_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_CACR_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_CACR_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_CACR_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_CACR_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_CACR_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOGMathGr5_GLP_LEP',
#  'EOGScienceGr5&8_CACR_LEP',
#  'EOGScienceGr5&8_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOGSubjects_GLP_LEP',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGScienceGr5&8_CACR_SWD',
#  'EOGScienceGr5&8_GLP_SWD',
#  'EOGSubjects_CACR_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_CACR_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_CACR_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'st_avg_daily_attend_pct',
#  'st_short_susp_per_c_num',
#  'st_flicensed_teach_pct',
#  'st_tchyrs_0thru3_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_class_teach_num',
#  'st_advance_dgr_pct',
#  'st_1yr_tchr_trnovr_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'Not Demostrated_TCHR_Standard 3_Pct',
#  'Not Demostrated_TCHR_Standard 5_Pct',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'HispanicMalePct',
#  'BlackMalePct',
#  'WhiteMalePct',
#  'MinorityMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'HispanicFemalePct',
#  'BlackFemalePct',
#  'WhiteFemalePct',
#  'MinorityFemalePct',
#  'Assault Rate',
#  'Add Medicare tax Amt All',
#  'Add Medicare tax Amt GE200K',
#  'Add Medicare tax Ct 100KLT200K',
#  'Add Medicare tax Ct All',
#  'Add Medicare tax Ct GE200K',
#  'Add child tax credit Amt 25KLT50K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct 50KLT75K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Contributions Amt 100KLT200K',
#  'Contributions Amt 25KLT50K',
#  'Contributions Amt 50KLT75K',
#  'Contributions Amt 75KLT100K',
#  'Contributions Amt All',
#  'Contributions Amt GE200K',
#  'Contributions Amt LT25K',
#  'Contributions Ct 100KLT200K',
#  'Contributions Ct 25KLT50K',
#  'Contributions Ct 50KLT75K',
#  'Contributions Ct 75KLT100K',
#  'Contributions Ct All',
#  'Contributions Ct GE200K',
#  'Contributions Ct LT25K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Ct 100KLT200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'IRA payments Amt 100KLT200K',
#  'IRA payments Amt 25KLT50K',
#  'IRA payments Amt 50KLT75K',
#  'IRA payments Amt 75KLT100K',
#  'IRA payments Amt All',
#  'IRA payments Amt GE200K',
#  'IRA payments Amt LT25K',
#  'IRA payments Ct 100KLT200K',
#  'IRA payments Ct 25KLT50K',
#  'IRA payments Ct 50KLT75K',
#  'IRA payments Ct 75KLT100K',
#  'IRA payments Ct All',
#  'IRA payments Ct GE200K',
#  'IRA payments Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Mortgage interest paid Amt 100KLT200K',
#  'Mortgage interest paid Amt 25KLT50K',
#  'Mortgage interest paid Amt 50KLT75K',
#  'Mortgage interest paid Amt 75KLT100K',
#  'Mortgage interest paid Amt All',
#  'Mortgage interest paid Amt GE200K',
#  'Mortgage interest paid Amt LT25K',
#  'Mortgage interest paid Ct 100KLT200K',
#  'Mortgage interest paid Ct 25KLT50K',
#  'Mortgage interest paid Ct 50KLT75K',
#  'Mortgage interest paid Ct 75KLT100K',
#  'Mortgage interest paid Ct All',
#  'Mortgage interest paid Ct GE200K',
#  'Mortgage interest paid Ct LT25K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Residential energy tax credit Ct LT25K',
#  'Retirement savings contribution credit Amt 25KLT50K',
#  'Retirement savings contribution credit Amt 50KLT75K',
#  'Retirement savings contribution credit Amt All',
#  'Retirement savings contribution credit Amt LT25K',
#  'Retirement savings contribution credit Ct 25KLT50K',
#  'Retirement savings contribution credit Ct 50KLT75K',
#  'Retirement savings contribution credit Ct All',
#  'Retirement savings contribution credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employment health insurance deduction Amt 100KLT200K',
#  'Self-employment health insurance deduction Amt 25KLT50K',
#  'Self-employment health insurance deduction Amt 50KLT75K',
#  'Self-employment health insurance deduction Amt 75KLT100K',
#  'Self-employment health insurance deduction Amt All',
#  'Self-employment health insurance deduction Amt GE200K',
#  'Self-employment health insurance deduction Amt LT25K',
#  'Self-employment health insurance deduction Ct 100KLT200K',
#  'Self-employment health insurance deduction Ct 25KLT50K',
#  'Self-employment health insurance deduction Ct 50KLT75K',
#  'Self-employment health insurance deduction Ct 75KLT100K',
#  'Self-employment health insurance deduction Ct All',
#  'Self-employment health insurance deduction Ct GE200K',
#  'Self-employment health insurance deduction Ct LT25K',
#  'Self-employment retirement plans Amt 100KLT200K',
#  'Self-employment retirement plans Amt 50KLT75K',
#  'Self-employment retirement plans Amt 75KLT100K',
#  'Self-employment retirement plans Amt All',
#  'Self-employment retirement plans Amt GE200K',
#  'Self-employment retirement plans Ct 100KLT200K',
#  'Self-employment retirement plans Ct 25KLT50K',
#  'Self-employment retirement plans Ct 50KLT75K',
#  'Self-employment retirement plans Ct 75KLT100K',
#  'Self-employment retirement plans Ct All',
#  'Self-employment retirement plans Ct GE200K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt GE200K',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  'Taxable interest Ct 100KLT200K',
#  'Taxable interest Ct 25KLT50K',
#  'Taxable interest Ct 50KLT75K',
#  'Taxable interest Ct 75KLT100K',
#  'Taxable interest Ct All',
#  'Taxable interest Ct GE200K',
#  'Taxable interest Ct LT25K',
#  'Taxes paid Amt 100KLT200K',
#  'Taxes paid Amt 25KLT50K',
#  'Taxes paid Amt 50KLT75K',
#  'Taxes paid Amt 75KLT100K',
#  'Taxes paid Amt All',
#  'Taxes paid Amt GE200K',
#  'Taxes paid Amt LT25K',
#  'Taxes paid Ct 100KLT200K',
#  'Taxes paid Ct 25KLT50K',
#  'Taxes paid Ct 50KLT75K',
#  'Taxes paid Ct 75KLT100K',
#  'Taxes paid Ct All',
#  'Taxes paid Ct GE200K',
#  'Taxes paid Ct LT25K',
#  'Tot income Amt 100KLT200K',
#  'Tot income Amt 25KLT50K',
#  'Tot income Amt 50KLT75K',
#  'Tot income Amt 75KLT100K',
#  'Tot income Amt All',
#  'Tot income Amt GE200K',
#  'Tot income Amt LT25K',
#  'Tot income Ct 100KLT200K',
#  'Tot income Ct 25KLT50K',
#  'Tot income Ct 50KLT75K',
#  'Tot income Ct 75KLT100K',
#  'Tot income Ct All',
#  'Tot income Ct GE200K',
#  'Tot income Ct LT25K',
#  'Tot itemized deductions Amt 100KLT200K',
#  'Tot itemized deductions Amt 25KLT50K',
#  'Tot itemized deductions Amt 50KLT75K',
#  'Tot itemized deductions Amt 75KLT100K',
#  'Tot itemized deductions Amt All',
#  'Tot itemized deductions Amt GE200K',
#  'Tot itemized deductions Amt LT25K',
#  'Tot itemized deductions Amt of AGI 100KLT200K',
#  'Tot itemized deductions Amt of AGI 25KLT50K',
#  'Tot itemized deductions Amt of AGI 50KLT75K',
#  'Tot itemized deductions Amt of AGI 75KLT100K',
#  'Tot itemized deductions Amt of AGI All',
#  'Tot itemized deductions Amt of AGI GE200K',
#  'Tot itemized deductions Amt of AGI LT25K',
#  'Tot itemized deductions Ct 100KLT200K',
#  'Tot itemized deductions Ct 25KLT50K',
#  'Tot itemized deductions Ct 50KLT75K',
#  'Tot itemized deductions Ct 75KLT100K',
#  'Tot itemized deductions Ct All',
#  'Tot itemized deductions Ct GE200K',
#  'Tot itemized deductions Ct LT25K',
#  'Tot statuory adjustments Amt 100KLT200K',
#  'Tot statuory adjustments Amt 25KLT50K',
#  'Tot statuory adjustments Amt 50KLT75K',
#  'Tot statuory adjustments Amt 75KLT100K',
#  'Tot statuory adjustments Amt All',
#  'Tot statuory adjustments Amt GE200K',
#  'Tot statuory adjustments Amt LT25K',
#  'Tot statuory adjustments Ct 100KLT200K',
#  'Tot statuory adjustments Ct 25KLT50K',
#  'Tot statuory adjustments Ct 50KLT75K',
#  'Tot statuory adjustments Ct 75KLT100K',
#  'Tot statuory adjustments Ct All',
#  'Tot statuory adjustments Ct GE200K',
#  'Tot statuory adjustments Ct LT25K',
#  'Tot tax credits Amt 100KLT200K',
#  'Tot tax credits Amt 25KLT50K',
#  'Tot tax credits Amt 50KLT75K',
#  'Tot tax credits Amt 75KLT100K',
#  'Tot tax credits Amt All',
#  'Tot tax credits Amt GE200K',
#  'Tot tax credits Amt LT25K',
#  'Tot tax credits Ct 100KLT200K',
#  'Tot tax credits Ct 25KLT50K',
#  'Tot tax credits Ct 50KLT75K',
#  'Tot tax credits Ct 75KLT100K',
#  'Tot tax credits Ct All',
#  'Tot tax credits Ct GE200K',
#  'Tot tax credits Ct LT25K',
#  'Tot tax liability Amt 100KLT200K',
#  'Tot tax liability Amt 25KLT50K',
#  'Tot tax liability Amt 50KLT75K',
#  'Tot tax liability Amt 75KLT100K',
#  'Tot tax liability Amt All',
#  'Tot tax liability Amt GE200K',
#  'Tot tax liability Amt LT25K',
#  'Tot tax liability Ct 100KLT200K',
#  'Tot tax liability Ct 25KLT50K',
#  'Tot tax liability Ct 50KLT75K',
#  'Tot tax liability Ct 75KLT100K',
#  'Tot tax liability Ct All',
#  'Tot tax liability Ct GE200K',
#  'Tot tax liability Ct LT25K',
#  'Tot tax payments Amt 100KLT200K',
#  'Tot tax payments Amt 25KLT50K',
#  'Tot tax payments Amt 50KLT75K',
#  'Tot tax payments Amt 75KLT100K',
#  'Tot tax payments Amt All',
#  'Tot tax payments Amt GE200K',
#  'Tot tax payments Amt LT25K',
#  'Tot tax payments Ct 100KLT200K',
#  'Tot tax payments Ct 25KLT50K',
#  'Tot tax payments Ct 50KLT75K',
#  'Tot tax payments Ct 75KLT100K',
#  'Tot tax payments Ct All',
#  'Tot tax payments Ct GE200K',
#  'Tot tax payments Ct LT25K',
#  'Tuition and fees deduction Amt 100KLT200K',
#  'Tuition and fees deduction Amt 25KLT50K',
#  'Tuition and fees deduction Amt 50KLT75K',
#  'Tuition and fees deduction Amt 75KLT100K',
#  'Tuition and fees deduction Amt All',
#  'Tuition and fees deduction Amt LT25K',
#  'Tuition and fees deduction Ct 100KLT200K',
#  'Tuition and fees deduction Ct 25KLT50K',
#  'Tuition and fees deduction Ct 50KLT75K',
#  'Tuition and fees deduction Ct 75KLT100K',
#  'Tuition and fees deduction Ct All',
#  'Tuition and fees deduction Ct LT25K',
#  'Unemployment compensation Amt 100KLT200K',
#  'Unemployment compensation Amt 25KLT50K',
#  'Unemployment compensation Amt 50KLT75K',
#  'Unemployment compensation Amt 75KLT100K',
#  'Unemployment compensation Amt All',
#  'Unemployment compensation Amt GE200K',
#  'Unemployment compensation Amt LT25K',
#  'Unemployment compensation Ct 100KLT200K',
#  'Unemployment compensation Ct 25KLT50K',
#  'Unemployment compensation Ct 50KLT75K',
#  'Unemployment compensation Ct 75KLT100K',
#  'Unemployment compensation Ct All',
#  'Unemployment compensation Ct GE200K',
#  'Unemployment compensation Ct LT25K',
#  'RemainedinEducation',
#  'PersonalReasons',
#  'InitiatedbyLEA',
#  'category_cd_E',
#  'category_cd_I',
#  'sna_pgm_type_cd_X',
#  'sna_pgm_type_cd_Y',
#  'calendar_only_txt_Traditional Calendar plus Year-Round Calendar',
#  'calendar_only_txt_Year-Round Calendar',
#  'Category_Cd_E',
#  'Category_Cd_I']

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Columns: 1293 entries, student_num to esea_attendance_Met
# dtypes: float64(1262), uint8(31)
# memory usage: 12.6 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Columns: 344 entries, student_num to esea_attendance_Met
# dtypes: float64(321), uint8(23)
# memory usage: 3.2 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 1300
# Data columns (total 345 columns):
# student_num                                                                        float64
# lea_avg_student_num                                                                float64
# st_avg_student_num                                                                 float64
# lea_total_expense_num                                                              float64
# lea_salary_expense_pct                                                             float64
# lea_benefits_expense_pct                                                           float64
# lea_services_expense_pct                                                           float64
# lea_supplies_expense_pct                                                           float64
# lea_instruct_equip_exp_pct                                                         float64
# lea_federal_perpupil_num                                                           float64
# lea_local_perpupil_num                                                             float64
# lea_state_perpupil_num                                                             float64
# SBE Region                                                                         float64
# SPG Score                                                                          float64
# EVAAS Growth Score                                                                 float64
# Science Score                                                                      float64
# EOGGr3_CACR_All                                                                    float64
# EOGGr4_CACR_All                                                                    float64
# EOGGr5_CACR_All                                                                    float64
# EOGGr4_CACR_Female                                                                 float64
# EOGMathGr5_CACR_Female                                                             float64
# EOGReadingGr4_CACR_Female                                                          float64
# EOGReadingGr5_CACR_Female                                                          float64
# EOGReadingGr4_CACR_Male                                                            float64
# EOG/EOCSubjects_CACR_AmericanIndian                                                float64
# EOGGr3_CACR_AmericanIndian                                                         float64
# EOGGr4_CACR_AmericanIndian                                                         float64
# EOGGr5_CACR_AmericanIndian                                                         float64
# EOGMathGr3_CACR_AmericanIndian                                                     float64
# EOGMathGr3-8_CACR_AmericanIndian                                                   float64
# EOGMathGr4_CACR_AmericanIndian                                                     float64
# EOGMathGr5_CACR_AmericanIndian                                                     float64
# EOGReadingGr3_CACR_AmericanIndian                                                  float64
# EOGReadingGr3-8_CACR_AmericanIndian                                                float64
# EOGReadingGr4_CACR_AmericanIndian                                                  float64
# EOGReadingGr5_CACR_AmericanIndian                                                  float64
# EOGScienceGr5_CACR_AmericanIndian                                                  float64
# EOG/EOCSubjects_CACR_Asian                                                         float64
# EOGGr3_CACR_Asian                                                                  float64
# EOGGr4_CACR_Asian                                                                  float64
# EOGGr5_CACR_Asian                                                                  float64
# EOGMathGr3_CACR_Asian                                                              float64
# EOGMathGr3-8_CACR_Asian                                                            float64
# EOGMathGr4_CACR_Asian                                                              float64
# EOGMathGr5_CACR_Asian                                                              float64
# EOGReadingGr3-8_CACR_Asian                                                         float64
# EOGReadingGr5_CACR_Asian                                                           float64
# EOG/EOCSubjects_CACR_Black                                                         float64
# EOGGr3_CACR_Black                                                                  float64
# EOGGr3_GLP_Black                                                                   float64
# EOGGr4_CACR_Black                                                                  float64
# EOGGr5_CACR_Black                                                                  float64
# EOGMathGr3_CACR_Black                                                              float64
# EOGMathGr3_GLP_Black                                                               float64
# EOGMathGr3-8_CACR_Black                                                            float64
# EOGMathGr4_CACR_Black                                                              float64
# EOGMathGr5_CACR_Black                                                              float64
# EOGReadingGr3_CACR_Black                                                           float64
# EOGReadingGr3_GLP_Black                                                            float64
# EOGReadingGr3-8_CACR_Black                                                         float64
# EOGReadingGr3-8_GLP_Black                                                          float64
# EOGReadingGr4_CACR_Black                                                           float64
# EOGReadingGr4_GLP_Black                                                            float64
# EOGReadingGr5_CACR_Black                                                           float64
# EOGReadingGr5_GLP_Black                                                            float64
# EOGScienceGr5_CACR_Black                                                           float64
# EOG/EOCSubjects_CACR_Hispanic                                                      float64
# EOG/EOCSubjects_GLP_Hispanic                                                       float64
# EOGGr3_CACR_Hispanic                                                               float64
# EOGGr3_GLP_Hispanic                                                                float64
# EOGGr4_CACR_Hispanic                                                               float64
# EOGGr5_CACR_Hispanic                                                               float64
# EOGMathGr3_CACR_Hispanic                                                           float64
# EOGMathGr3_GLP_Hispanic                                                            float64
# EOGMathGr3-8_CACR_Hispanic                                                         float64
# EOGMathGr4_CACR_Hispanic                                                           float64
# EOGMathGr5_CACR_Hispanic                                                           float64
# EOGReadingGr3_CACR_Hispanic                                                        float64
# EOGReadingGr3_GLP_Hispanic                                                         float64
# EOGReadingGr3-8_CACR_Hispanic                                                      float64
# EOGReadingGr3-8_GLP_Hispanic                                                       float64
# EOGReadingGr4_CACR_Hispanic                                                        float64
# EOGReadingGr4_GLP_Hispanic                                                         float64
# EOGReadingGr5_CACR_Hispanic                                                        float64
# EOGReadingGr5_GLP_Hispanic                                                         float64
# EOGScienceGr5_CACR_Hispanic                                                        float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                                                float64
# EOG/EOCSubjects_GLP_TwoorMoreRaces                                                 float64
# EOGGr3_CACR_TwoorMoreRaces                                                         float64
# EOGGr4_CACR_TwoorMoreRaces                                                         float64
# EOGGr5_CACR_TwoorMoreRaces                                                         float64
# EOGMathGr3_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                                                   float64
# EOGMathGr4_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr5_CACR_TwoorMoreRaces                                                     float64
# EOGReadingGr3_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                                                float64
# EOGReadingGr3-8_GLP_TwoorMoreRaces                                                 float64
# EOGReadingGr4_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5_CACR_TwoorMoreRaces                                                  float64
# EOG/EOCSubjects_CACR_White                                                         float64
# EOGGr3_CACR_White                                                                  float64
# EOGGr4_CACR_White                                                                  float64
# EOGGr5_CACR_White                                                                  float64
# EOGMathGr3_CACR_White                                                              float64
# EOGMathGr3-8_CACR_White                                                            float64
# EOGMathGr4_CACR_White                                                              float64
# EOGMathGr5_CACR_White                                                              float64
# EOGReadingGr3_CACR_White                                                           float64
# EOGReadingGr3-8_CACR_White                                                         float64
# EOGReadingGr4_CACR_White                                                           float64
# EOGReadingGr5_CACR_White                                                           float64
# EOGScienceGr5_CACR_White                                                           float64
# EOG/EOCSubjects_CACR_EDS                                                           float64
# EOGGr3_CACR_EDS                                                                    float64
# EOGGr4_CACR_EDS                                                                    float64
# EOGGr5_CACR_EDS                                                                    float64
# EOGMathGr3_CACR_EDS                                                                float64
# EOGMathGr3_GLP_EDS                                                                 float64
# EOGMathGr3-8_CACR_EDS                                                              float64
# EOGMathGr4_CACR_EDS                                                                float64
# EOGMathGr5_CACR_EDS                                                                float64
# EOGReadingGr3_CACR_EDS                                                             float64
# EOGReadingGr3_GLP_EDS                                                              float64
# EOGReadingGr3-8_CACR_EDS                                                           float64
# EOGReadingGr4_CACR_EDS                                                             float64
# EOGReadingGr4_GLP_EDS                                                              float64
# EOGReadingGr5_CACR_EDS                                                             float64
# EOGReadingGr5_GLP_EDS                                                              float64
# EOGScienceGr5_CACR_EDS                                                             float64
# EOG/EOCSubjects_CACR_LEP                                                           float64
# EOG/EOCSubjects_GLP_LEP                                                            float64
# EOGGr3_CACR_LEP                                                                    float64
# EOGGr3_GLP_LEP                                                                     float64
# EOGGr4_CACR_LEP                                                                    float64
# EOGGr4_GLP_LEP                                                                     float64
# EOGGr5_CACR_LEP                                                                    float64
# EOGGr5_GLP_LEP                                                                     float64
# EOGMathGr3_CACR_LEP                                                                float64
# EOGMathGr3_GLP_LEP                                                                 float64
# EOGMathGr3-8_CACR_LEP                                                              float64
# EOGMathGr3-8_GLP_LEP                                                               float64
# EOGMathGr4_CACR_LEP                                                                float64
# EOGMathGr4_GLP_LEP                                                                 float64
# EOGMathGr5_CACR_LEP                                                                float64
# EOGReadingGr3_CACR_LEP                                                             float64
# EOGReadingGr3_GLP_LEP                                                              float64
# EOGReadingGr3-8_CACR_LEP                                                           float64
# EOGReadingGr3-8_GLP_LEP                                                            float64
# EOGReadingGr4_CACR_LEP                                                             float64
# EOGReadingGr4_GLP_LEP                                                              float64
# EOGReadingGr5_CACR_LEP                                                             float64
# EOGReadingGr5_GLP_LEP                                                              float64
# EOGScienceGr5_CACR_LEP                                                             float64
# EOGScienceGr5_GLP_LEP                                                              float64
# EOG/EOCSubjects_CACR_SWD                                                           float64
# EOGGr3_CACR_SWD                                                                    float64
# EOGGr3_GLP_SWD                                                                     float64
# EOGGr4_CACR_SWD                                                                    float64
# EOGGr4_GLP_SWD                                                                     float64
# EOGGr5_CACR_SWD                                                                    float64
# EOGGr5_GLP_SWD                                                                     float64
# EOGMathGr3_CACR_SWD                                                                float64
# EOGMathGr3_GLP_SWD                                                                 float64
# EOGMathGr3-8_CACR_SWD                                                              float64
# EOGMathGr3-8_GLP_SWD                                                               float64
# EOGMathGr4_CACR_SWD                                                                float64
# EOGMathGr4_GLP_SWD                                                                 float64
# EOGMathGr5_CACR_SWD                                                                float64
# EOGMathGr5_GLP_SWD                                                                 float64
# EOGReadingGr3_CACR_SWD                                                             float64
# EOGReadingGr3_GLP_SWD                                                              float64
# EOGReadingGr3-8_CACR_SWD                                                           float64
# EOGReadingGr3-8_GLP_SWD                                                            float64
# EOGReadingGr4_CACR_SWD                                                             float64
# EOGReadingGr4_GLP_SWD                                                              float64
# EOGReadingGr5_CACR_SWD                                                             float64
# EOGReadingGr5_GLP_SWD                                                              float64
# EOGScienceGr5_CACR_SWD                                                             float64
# EOGScienceGr5_GLP_SWD                                                              float64
# EOG/EOCSubjects_CACR_AIG                                                           float64
# EOGGr3_CACR_AIG                                                                    float64
# EOGGr4_CACR_AIG                                                                    float64
# EOGGr5_CACR_AIG                                                                    float64
# EOGMathGr3_CACR_AIG                                                                float64
# EOGMathGr3-8_CACR_AIG                                                              float64
# EOGMathGr4_CACR_AIG                                                                float64
# EOGMathGr5_CACR_AIG                                                                float64
# pct_GCE_ALL                                                                        float64
# pct_GCE_SWD                                                                        float64
# pct_PASSED_LAA                                                                     float64
# pct_PROMOTED                                                                       float64
# pct_RETAINED                                                                       float64
# MathGr3-8_pTarget_PctMet                                                           float64
# ReadingGr3-8_pTarget_PctMet                                                        float64
# SciGr5&8_pTarget_PctMet                                                            float64
# TotalTargets_pTarget_PctMet                                                        float64
# lea_sat_avg_score_num                                                              float64
# lea_sat_participation_pct                                                          float64
# lea_ap_participation_pct                                                           float64
# lea_ap_pct_3_or_above                                                              float64
# lea_ib_pct_4_or_above                                                              float64
# avg_daily_attend_pct                                                               float64
# crime_per_c_num                                                                    float64
# short_susp_per_c_num                                                               float64
# long_susp_per_c_num                                                                float64
# expelled_per_c_num                                                                 float64
# stud_internet_comp_num                                                             float64
# lea_avg_daily_attend_pct                                                           float64
# lea_crime_per_c_num                                                                float64
# lea_short_susp_per_c_num                                                           float64
# lea_long_susp_per_c_num                                                            float64
# lea_expelled_per_c_num                                                             float64
# lea_stud_internet_comp_num                                                         float64
# st_crime_per_c_num                                                                 float64
# flicensed_teach_pct                                                                float64
# tchyrs_0thru3_pct                                                                  float64
# tchyrs_4thru10_pct                                                                 float64
# tchyrs_11plus_pct                                                                  float64
# class_teach_num                                                                    float64
# nbpts_num                                                                          float64
# advance_dgr_pct                                                                    float64
# _1yr_tchr_trnovr_pct                                                               float64
# lateral_teach_pct                                                                  float64
# lea_flicensed_teach_pct                                                            float64
# lea_tchyrs_0thru3_pct                                                              float64
# lea_tchyrs_4thru10_pct                                                             float64
# lea_tchyrs_11plus_pct                                                              float64
# lea_class_teach_num                                                                float64
# lea_nbpts_num                                                                      float64
# lea_advance_dgr_pct                                                                float64
# lea_1yr_tchr_trnovr_pct                                                            float64
# lea_emer_prov_teach_pct                                                            float64
# lea_lateral_teach_pct                                                              float64
# st_tchyrs_11plus_pct                                                               float64
# st_nbpts_num                                                                       float64
# 0-3 Years_LEA_Exp_Pct_Prin                                                         float64
# 10+ Years_LEA_Exp_Pct_Prin                                                         float64
# 4-10 Years_LEA_Exp_Pct_Prin                                                        float64
# Accomplished_TCHR_Standard 1_Pct                                                   float64
# Accomplished_TCHR_Standard 2_Pct                                                   float64
# Accomplished_TCHR_Standard 3_Pct                                                   float64
# Accomplished_TCHR_Standard 4_Pct                                                   float64
# Accomplished_TCHR_Standard 5_Pct                                                   float64
# Developing_TCHR_Standard 1_Pct                                                     float64
# Developing_TCHR_Standard 2_Pct                                                     float64
# Developing_TCHR_Standard 3_Pct                                                     float64
# Developing_TCHR_Standard 4_Pct                                                     float64
# Developing_TCHR_Standard 5_Pct                                                     float64
# Distinguished_TCHR_Standard 1_Pct                                                  float64
# Distinguished_TCHR_Standard 2_Pct                                                  float64
# Distinguished_TCHR_Standard 3_Pct                                                  float64
# Distinguished_TCHR_Standard 4_Pct                                                  float64
# Distinguished_TCHR_Standard 5_Pct                                                  float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct                                  float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct                                        float64
# Meets Expected Growth_TCHR_Standard 6_Pct                                          float64
# Not Demostrated_TCHR_Standard 1_Pct                                                float64
# Not Demostrated_TCHR_Standard 2_Pct                                                float64
# Not Demostrated_TCHR_Standard 4_Pct                                                float64
# Proficient_TCHR_Standard 1_Pct                                                     float64
# Proficient_TCHR_Standard 2_Pct                                                     float64
# Proficient_TCHR_Standard 3_Pct                                                     float64
# Proficient_TCHR_Standard 4_Pct                                                     float64
# Proficient_TCHR_Standard 5_Pct                                                     float64
# IndianPct                                                                          float64
# AsianPct                                                                           float64
# HispanicPct                                                                        float64
# BlackPct                                                                           float64
# WhitePct                                                                           float64
# PacificIslandPct                                                                   float64
# TwoOrMorePct                                                                       float64
# PacificIslandMalePct                                                               float64
# TwoOrMoreMalePct                                                                   float64
# PacificIslandFemalePct                                                             float64
# TwoOrMoreFemalePct                                                                 float64
# Year                                                                               float64
# Violent Rate                                                                       float64
# Murder Rate                                                                        float64
# Rape Rate                                                                          float64
# Robbery Rate                                                                       float64
# MVT Rate                                                                           float64
# Arson Rate                                                                         float64
# Add Medicare tax Amt 100KLT200K                                                    float64
# Add child tax credit Amt 75KLT100K                                                 float64
# Alternative minimum tax Amt 25KLT50K                                               float64
# Alternative minimum tax Amt 50KLT75K                                               float64
# Alternative minimum tax Amt 75KLT100K                                              float64
# Alternative minimum tax Amt LT25K                                                  float64
# Alternative minimum tax Ct 75KLT100K                                               float64
# Alternative minimum tax Ct LT25K                                                   float64
# Domestic production activities deduction Amt 100KLT200K                            float64
# Domestic production activities deduction Amt 25KLT50K                              float64
# Domestic production activities deduction Amt 50KLT75K                              float64
# Domestic production activities deduction Amt 75KLT100K                             float64
# Domestic production activities deduction Amt LT25K                                 float64
# Domestic production activities deduction Ct 25KLT50K                               float64
# Domestic production activities deduction Ct 50KLT75K                               float64
# Domestic production activities deduction Ct 75KLT100K                              float64
# Domestic production activities deduction Ct LT25K                                  float64
# Number of farm returns 100KLT200K                                                  float64
# Number of farm returns 25KLT50K                                                    float64
# Number of farm returns 50KLT75K                                                    float64
# Number of farm returns 75KLT100K                                                   float64
# Number of farm returns All                                                         float64
# Number of farm returns GE200K                                                      float64
# Number of farm returns LT25K                                                       float64
# Partnership/S-corp net income (less loss) Amt LT25K                                float64
# Residential energy tax credit Amt LT25K                                            float64
# Self-employment retirement plans Amt 25KLT50K                                      float64
# Self-employment retirement plans Amt LT25K                                         float64
# Self-employment retirement plans Ct LT25K                                          float64
# LEACode                                                                            float64
# RemainedinEducationPerct                                                           float64
# PersonalPerct                                                                      float64
# InitiatedPerct                                                                     float64
# BeyondControlofLEA                                                                 float64
# BeyondControlPerct                                                                 float64
# OtherReasons                                                                       float64
# OtherReasonsPerct                                                                  float64
# calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar    uint8
# calendar_type_txt_Regular School, Year-Round Calendar                              uint8
# esea_status_P                                                                      uint8
# esea_status_R                                                                      uint8
# esea_status_RF                                                                     uint8
# esea_status_RP                                                                     uint8
# Grad_project_status_Y                                                              uint8
# SPG Grade_B                                                                        uint8
# SPG Grade_C                                                                        uint8
# SPG Grade_D                                                                        uint8
# SPG Grade_F                                                                        uint8
# SPG Grade_I                                                                        uint8
# Reading SPG Grade_B                                                                uint8
# Reading SPG Grade_C                                                                uint8
# Reading SPG Grade_D                                                                uint8
# Reading SPG Grade_F                                                                uint8
# Math SPG Grade_B                                                                   uint8
# Math SPG Grade_C                                                                   uint8
# Math SPG Grade_D                                                                   uint8
# Math SPG Grade_F                                                                   uint8
# EVAAS Growth Status_Met                                                            uint8
# EVAAS Growth Status_NotMet                                                         uint8
# esea_attendance_Met                                                                uint8
# unit_code                                                                          object
# dtypes: float64(321), object(1), uint8(23)
# memory usage: 3.2+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.1
# Pandas Version: 0.24.2

# %%
print ('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2014/Machine Learning Datasets/PublicElementarySchools2014_ML.csv
