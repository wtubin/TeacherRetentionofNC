# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2015

#Location where copies of the raw data files will be read in from csv files.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools' + str(schoolYear)
#inputFileName = 'PublicHighSchools' + str(schoolYear)
#inputFileName = 'PublicMiddleSchools' + str(schoolYear)
inputFileName = 'PublicElementarySchools' + str(schoolYear)

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
#Rename Lea_Name to District Name
schoolData.rename(columns={'Lea_Name': 'District Name'}, inplace=True)
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1298 entries, 0 to 1297
# Columns: 2130 entries, vphone_ad to Unemployment compensation Ct LT25K
# dtypes: float64(2082), int64(3), object(45)
# memory usage: 21.1+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Columns: 2130 entries, vphone_ad to Unemployment compensation Ct LT25K
# dtypes: float64(2082), int64(3), object(45)
# memory usage: 21.1+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#schoolData.info(verbose=True)

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print ('Rows Updated / Imputed: ', rowsUpdated )
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print( '\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Columns: 1926 entries, vphone_ad to Unemployment compensation Ct LT25K
# dtypes: float64(1885), object(41)
# memory usage: 19.1+ MB
#
# Columns Deleted:  204

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print( '\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Columns: 1924 entries, vphone_ad to Unemployment compensation Ct LT25K
# dtypes: float64(1885), object(39)
# memory usage: 19.1+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print( '\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Columns: 1924 entries, vphone_ad to Unemployment compensation Ct LT25K
# dtypes: float64(1885), object(39)
# memory usage: 19.1+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  39
# Continuous Columns:  1885
# Columns Accounted for:  1924

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Columns: 1382 entries, vphone_ad to Unemployment compensation Ct LT25K
# dtypes: float64(1343), object(39)
# memory usage: 13.7+ MB
#
# Columns Deleted:  542

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Columns: 1363 entries, category_cd to Unemployment compensation Ct LT25K
# dtypes: float64(1343), object(20)
# memory usage: 13.5+ MB
#
# Columns Deleted:  19

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print ('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print( '\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  20
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Columns: 1403 entries, student_num to lea_avg_age_media_collection_2010
# dtypes: float64(1343), uint8(60)
# memory usage: 13.4 MB
#
# New Columns Created Via One-Hot Encoding:  40

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 3                                              00_Size                    111
# 4                                              01_Size                    127
# 5                                              02_Size                    126
# 6                                              03_Size                    125
# 7                                              04_Size                    102
# 8                                              05_Size                    156
# 18                                           SPG Score                     34
# 19                                  Reading  SPG Score                     36
# 20                                      Math SPG Score                     36
# 21                                  EVAAS Growth Score                     34
# 22                           Overall Achievement Score                     34
# 23                                          Read Score                     36
# 24                                          Math Score                     36
# 25                                       Science Score                    118
# 26                            EOG/EOCSubjects_CACR_All                     34
# 27                             EOG/EOCSubjects_GLP_All                     34
# 28                                     EOGGr3_CACR_All                     57
# 29                                      EOGGr3_GLP_All                     57
# 30                                     EOGGr4_CACR_All                     62
# 31                                      EOGGr4_GLP_All                     62
# 32                                     EOGGr5_CACR_All                    120
# 33                                      EOGGr5_GLP_All                    120
# 34                                 EOGMathGr3_CACR_All                     57
# 35                                  EOGMathGr3_GLP_All                     57
# 36                               EOGMathGr3-8_CACR_All                     36
# 37                                EOGMathGr3-8_GLP_All                     36
# 38                                 EOGMathGr4_CACR_All                     63
# 39                                  EOGMathGr4_GLP_All                     63
# 40                                 EOGMathGr5_CACR_All                    121
# 41                                  EOGMathGr5_GLP_All                    121
# 42                              EOGReadingGr3_CACR_All                     57
# 43                               EOGReadingGr3_GLP_All                     57
# 44                            EOGReadingGr3-8_CACR_All                     36
# 45                             EOGReadingGr3-8_GLP_All                     36
# 46                              EOGReadingGr4_CACR_All                     63
# 47                               EOGReadingGr4_GLP_All                     63
# 48                              EOGReadingGr5_CACR_All                    121
# 49                               EOGReadingGr5_GLP_All                    121
# 50                              EOGScienceGr5_CACR_All                    121
# 51                               EOGScienceGr5_GLP_All                    121
# 52                            EOGScienceGr5&8_CACR_All                    118
# 53                             EOGScienceGr5&8_GLP_All                    118
# 54                                EOGSubjects_CACR_All                     36
# 55                                 EOGSubjects_GLP_All                     36
# 56                         EOG/EOCSubjects_CACR_Female                     34
# 57                          EOG/EOCSubjects_GLP_Female                     34
# 58                                  EOGGr3_CACR_Female                     57
# 59                                   EOGGr3_GLP_Female                     57
# 60                                  EOGGr4_CACR_Female                     62
# 61                                   EOGGr4_GLP_Female                     62
# 62                                  EOGGr5_CACR_Female                    120
# 63                                   EOGGr5_GLP_Female                    120
# 64                              EOGMathGr3_CACR_Female                     57
# 65                               EOGMathGr3_GLP_Female                     57
# 66                            EOGMathGr3-8_CACR_Female                     36
# 67                             EOGMathGr3-8_GLP_Female                     36
# 68                              EOGMathGr4_CACR_Female                     63
# 69                               EOGMathGr4_GLP_Female                     63
# 70                              EOGMathGr5_CACR_Female                    121
# 71                               EOGMathGr5_GLP_Female                    121
# 72                           EOGReadingGr3_CACR_Female                     57
# 73                            EOGReadingGr3_GLP_Female                     57
# 74                         EOGReadingGr3-8_CACR_Female                     36
# 75                          EOGReadingGr3-8_GLP_Female                     36
# 76                           EOGReadingGr4_CACR_Female                     63
# 77                            EOGReadingGr4_GLP_Female                     63
# 78                           EOGReadingGr5_CACR_Female                    121
# 79                            EOGReadingGr5_GLP_Female                    121
# 80                           EOGScienceGr5_CACR_Female                    121
# 81                            EOGScienceGr5_GLP_Female                    121
# 82                         EOGScienceGr5&8_CACR_Female                    118
# 83                          EOGScienceGr5&8_GLP_Female                    118
# 84                             EOGSubjects_CACR_Female                     36
# 85                              EOGSubjects_GLP_Female                     36
# 86                           EOG/EOCSubjects_CACR_Male                     34
# 87                            EOG/EOCSubjects_GLP_Male                     34
# 88                                    EOGGr3_CACR_Male                     57
# 89                                     EOGGr3_GLP_Male                     57
# 90                                    EOGGr4_CACR_Male                     62
# 91                                     EOGGr4_GLP_Male                     62
# 92                                    EOGGr5_CACR_Male                    120
# 93                                     EOGGr5_GLP_Male                    120
# 94                                EOGMathGr3_CACR_Male                     57
# 95                                 EOGMathGr3_GLP_Male                     57
# 96                              EOGMathGr3-8_CACR_Male                     36
# 97                               EOGMathGr3-8_GLP_Male                     36
# 98                                EOGMathGr4_CACR_Male                     63
# 99                                 EOGMathGr4_GLP_Male                     63
# 100                               EOGMathGr5_CACR_Male                    121
# 101                                EOGMathGr5_GLP_Male                    121
# 102                            EOGReadingGr3_CACR_Male                     57
# 103                             EOGReadingGr3_GLP_Male                     57
# 104                          EOGReadingGr3-8_CACR_Male                     36
# 105                           EOGReadingGr3-8_GLP_Male                     36
# 106                            EOGReadingGr4_CACR_Male                     63
# 107                             EOGReadingGr4_GLP_Male                     63
# 108                            EOGReadingGr5_CACR_Male                    121
# 109                             EOGReadingGr5_GLP_Male                    121
# 110                            EOGScienceGr5_CACR_Male                    121
# 111                             EOGScienceGr5_GLP_Male                    121
# 112                          EOGScienceGr5&8_CACR_Male                    118
# 113                           EOGScienceGr5&8_GLP_Male                    118
# 114                              EOGSubjects_CACR_Male                     36
# 115                               EOGSubjects_GLP_Male                     36
# 116                EOG/EOCSubjects_CACR_AmericanIndian                     34
# 117                 EOG/EOCSubjects_GLP_AmericanIndian                     34
# 118                         EOGGr3_CACR_AmericanIndian                     57
# 119                          EOGGr3_GLP_AmericanIndian                     57
# 120                         EOGGr4_CACR_AmericanIndian                     62
# 121                          EOGGr4_GLP_AmericanIndian                     62
# 122                         EOGGr5_CACR_AmericanIndian                    120
# 123                          EOGGr5_GLP_AmericanIndian                    120
# 124                     EOGMathGr3_CACR_AmericanIndian                     57
# 125                      EOGMathGr3_GLP_AmericanIndian                     57
# 126                   EOGMathGr3-8_CACR_AmericanIndian                     36
# 127                    EOGMathGr3-8_GLP_AmericanIndian                     36
# 128                     EOGMathGr4_CACR_AmericanIndian                     63
# 129                      EOGMathGr4_GLP_AmericanIndian                     63
# 130                     EOGMathGr5_CACR_AmericanIndian                    121
# 131                      EOGMathGr5_GLP_AmericanIndian                    121
# 132                  EOGReadingGr3_CACR_AmericanIndian                     57
# 133                   EOGReadingGr3_GLP_AmericanIndian                     57
# 134                EOGReadingGr3-8_CACR_AmericanIndian                     36
# 135                 EOGReadingGr3-8_GLP_AmericanIndian                     36
# 136                  EOGReadingGr4_CACR_AmericanIndian                     63
# 137                   EOGReadingGr4_GLP_AmericanIndian                     63
# 138                  EOGReadingGr5_CACR_AmericanIndian                    121
# 139                   EOGReadingGr5_GLP_AmericanIndian                    121
# 140                  EOGScienceGr5_CACR_AmericanIndian                    121
# 141                   EOGScienceGr5_GLP_AmericanIndian                    121
# 142                EOGScienceGr5&8_CACR_AmericanIndian                    118
# 143                 EOGScienceGr5&8_GLP_AmericanIndian                    118
# 144                    EOGSubjects_CACR_AmericanIndian                     36
# 145                     EOGSubjects_GLP_AmericanIndian                     36
# 146                         EOG/EOCSubjects_CACR_Asian                     34
# 147                          EOG/EOCSubjects_GLP_Asian                     34
# 148                                  EOGGr3_CACR_Asian                     57
# 149                                   EOGGr3_GLP_Asian                     57
# 150                                  EOGGr4_CACR_Asian                     62
# 151                                   EOGGr4_GLP_Asian                     62
# 152                                  EOGGr5_CACR_Asian                    120
# 153                                   EOGGr5_GLP_Asian                    120
# 154                              EOGMathGr3_CACR_Asian                     57
# 155                               EOGMathGr3_GLP_Asian                     57
# 156                            EOGMathGr3-8_CACR_Asian                     36
# 157                             EOGMathGr3-8_GLP_Asian                     36
# 158                              EOGMathGr4_CACR_Asian                     63
# 159                               EOGMathGr4_GLP_Asian                     63
# 160                              EOGMathGr5_CACR_Asian                    121
# 161                               EOGMathGr5_GLP_Asian                    121
# 162                           EOGReadingGr3_CACR_Asian                     57
# 163                            EOGReadingGr3_GLP_Asian                     57
# 164                         EOGReadingGr3-8_CACR_Asian                     36
# 165                          EOGReadingGr3-8_GLP_Asian                     36
# 166                           EOGReadingGr4_CACR_Asian                     63
# 167                            EOGReadingGr4_GLP_Asian                     63
# 168                           EOGReadingGr5_CACR_Asian                    121
# 169                            EOGReadingGr5_GLP_Asian                    121
# 170                           EOGScienceGr5_CACR_Asian                    121
# 171                            EOGScienceGr5_GLP_Asian                    121
# 172                         EOGScienceGr5&8_CACR_Asian                    118
# 173                          EOGScienceGr5&8_GLP_Asian                    118
# 174                             EOGSubjects_CACR_Asian                     36
# 175                              EOGSubjects_GLP_Asian                     36
# 176                         EOG/EOCSubjects_CACR_Black                     34
# 177                          EOG/EOCSubjects_GLP_Black                     34
# 178                                  EOGGr3_CACR_Black                     57
# 179                                   EOGGr3_GLP_Black                     57
# 180                                  EOGGr4_CACR_Black                     62
# 181                                   EOGGr4_GLP_Black                     62
# 182                                  EOGGr5_CACR_Black                    120
# 183                                   EOGGr5_GLP_Black                    120
# 184                              EOGMathGr3_CACR_Black                     57
# 185                               EOGMathGr3_GLP_Black                     57
# 186                            EOGMathGr3-8_CACR_Black                     36
# 187                             EOGMathGr3-8_GLP_Black                     36
# 188                              EOGMathGr4_CACR_Black                     63
# 189                               EOGMathGr4_GLP_Black                     63
# 190                              EOGMathGr5_CACR_Black                    121
# 191                               EOGMathGr5_GLP_Black                    121
# 192                           EOGReadingGr3_CACR_Black                     57
# 193                            EOGReadingGr3_GLP_Black                     57
# 194                         EOGReadingGr3-8_CACR_Black                     36
# 195                          EOGReadingGr3-8_GLP_Black                     36
# 196                           EOGReadingGr4_CACR_Black                     63
# 197                            EOGReadingGr4_GLP_Black                     63
# 198                           EOGReadingGr5_CACR_Black                    121
# 199                            EOGReadingGr5_GLP_Black                    121
# 200                           EOGScienceGr5_CACR_Black                    121
# 201                            EOGScienceGr5_GLP_Black                    121
# 202                         EOGScienceGr5&8_CACR_Black                    118
# 203                          EOGScienceGr5&8_GLP_Black                    118
# 204                             EOGSubjects_CACR_Black                     36
# 205                              EOGSubjects_GLP_Black                     36
# 206                      EOG/EOCSubjects_CACR_Hispanic                     34
# 207                       EOG/EOCSubjects_GLP_Hispanic                     34
# 208                               EOGGr3_CACR_Hispanic                     57
# 209                                EOGGr3_GLP_Hispanic                     57
# 210                               EOGGr4_CACR_Hispanic                     62
# 211                                EOGGr4_GLP_Hispanic                     62
# 212                               EOGGr5_CACR_Hispanic                    120
# 213                                EOGGr5_GLP_Hispanic                    120
# 214                           EOGMathGr3_CACR_Hispanic                     57
# 215                            EOGMathGr3_GLP_Hispanic                     57
# 216                         EOGMathGr3-8_CACR_Hispanic                     36
# 217                          EOGMathGr3-8_GLP_Hispanic                     36
# 218                           EOGMathGr4_CACR_Hispanic                     63
# 219                            EOGMathGr4_GLP_Hispanic                     63
# 220                           EOGMathGr5_CACR_Hispanic                    121
# 221                            EOGMathGr5_GLP_Hispanic                    121
# 222                        EOGReadingGr3_CACR_Hispanic                     57
# 223                         EOGReadingGr3_GLP_Hispanic                     57
# 224                      EOGReadingGr3-8_CACR_Hispanic                     36
# 225                       EOGReadingGr3-8_GLP_Hispanic                     36
# 226                        EOGReadingGr4_CACR_Hispanic                     63
# 227                         EOGReadingGr4_GLP_Hispanic                     63
# 228                        EOGReadingGr5_CACR_Hispanic                    121
# 229                         EOGReadingGr5_GLP_Hispanic                    121
# 230                        EOGScienceGr5_CACR_Hispanic                    121
# 231                         EOGScienceGr5_GLP_Hispanic                    121
# 232                      EOGScienceGr5&8_CACR_Hispanic                    118
# 233                       EOGScienceGr5&8_GLP_Hispanic                    118
# 234                          EOGSubjects_CACR_Hispanic                     36
# 235                           EOGSubjects_GLP_Hispanic                     36
# 236                EOG/EOCSubjects_CACR_TwoorMoreRaces                     34
# 237                 EOG/EOCSubjects_GLP_TwoorMoreRaces                     34
# 238                         EOGGr3_CACR_TwoorMoreRaces                     57
# 239                          EOGGr3_GLP_TwoorMoreRaces                     57
# 240                         EOGGr4_CACR_TwoorMoreRaces                     62
# 241                          EOGGr4_GLP_TwoorMoreRaces                     62
# 242                         EOGGr5_CACR_TwoorMoreRaces                    120
# 243                          EOGGr5_GLP_TwoorMoreRaces                    120
# 244                     EOGMathGr3_CACR_TwoorMoreRaces                     57
# 245                      EOGMathGr3_GLP_TwoorMoreRaces                     57
# 246                   EOGMathGr3-8_CACR_TwoorMoreRaces                     36
# 247                    EOGMathGr3-8_GLP_TwoorMoreRaces                     36
# 248                     EOGMathGr4_CACR_TwoorMoreRaces                     63
# 249                      EOGMathGr4_GLP_TwoorMoreRaces                     63
# 250                     EOGMathGr5_CACR_TwoorMoreRaces                    121
# 251                      EOGMathGr5_GLP_TwoorMoreRaces                    121
# 252                  EOGReadingGr3_CACR_TwoorMoreRaces                     57
# 253                   EOGReadingGr3_GLP_TwoorMoreRaces                     57
# 254                EOGReadingGr3-8_CACR_TwoorMoreRaces                     36
# 255                 EOGReadingGr3-8_GLP_TwoorMoreRaces                     36
# 256                  EOGReadingGr4_CACR_TwoorMoreRaces                     63
# 257                   EOGReadingGr4_GLP_TwoorMoreRaces                     63
# 258                  EOGReadingGr5_CACR_TwoorMoreRaces                    121
# 259                   EOGReadingGr5_GLP_TwoorMoreRaces                    121
# 260                  EOGScienceGr5_CACR_TwoorMoreRaces                    121
# 261                   EOGScienceGr5_GLP_TwoorMoreRaces                    121
# 262                EOGScienceGr5&8_CACR_TwoorMoreRaces                    118
# 263                 EOGScienceGr5&8_GLP_TwoorMoreRaces                    118
# 264                    EOGSubjects_CACR_TwoorMoreRaces                     36
# 265                     EOGSubjects_GLP_TwoorMoreRaces                     36
# 266                         EOG/EOCSubjects_CACR_White                     34
# 267                          EOG/EOCSubjects_GLP_White                     34
# 268                                  EOGGr3_CACR_White                     57
# 269                                   EOGGr3_GLP_White                     57
# 270                                  EOGGr4_CACR_White                     62
# 271                                   EOGGr4_GLP_White                     62
# 272                                  EOGGr5_CACR_White                    120
# 273                                   EOGGr5_GLP_White                    120
# 274                              EOGMathGr3_CACR_White                     57
# 275                               EOGMathGr3_GLP_White                     57
# 276                            EOGMathGr3-8_CACR_White                     36
# 277                             EOGMathGr3-8_GLP_White                     36
# 278                              EOGMathGr4_CACR_White                     63
# 279                               EOGMathGr4_GLP_White                     63
# 280                              EOGMathGr5_CACR_White                    121
# 281                               EOGMathGr5_GLP_White                    121
# 282                           EOGReadingGr3_CACR_White                     57
# 283                            EOGReadingGr3_GLP_White                     57
# 284                         EOGReadingGr3-8_CACR_White                     36
# 285                          EOGReadingGr3-8_GLP_White                     36
# 286                           EOGReadingGr4_CACR_White                     63
# 287                            EOGReadingGr4_GLP_White                     63
# 288                           EOGReadingGr5_CACR_White                    121
# 289                            EOGReadingGr5_GLP_White                    121
# 290                           EOGScienceGr5_CACR_White                    121
# 291                            EOGScienceGr5_GLP_White                    121
# 292                         EOGScienceGr5&8_CACR_White                    118
# 293                          EOGScienceGr5&8_GLP_White                    118
# 294                             EOGSubjects_CACR_White                     36
# 295                              EOGSubjects_GLP_White                     36
# 296                           EOG/EOCSubjects_CACR_EDS                     34
# 297                            EOG/EOCSubjects_GLP_EDS                     34
# 298                                    EOGGr3_CACR_EDS                     57
# 299                                     EOGGr3_GLP_EDS                     57
# 300                                    EOGGr4_CACR_EDS                     62
# 301                                     EOGGr4_GLP_EDS                     62
# 302                                    EOGGr5_CACR_EDS                    120
# 303                                     EOGGr5_GLP_EDS                    120
# 304                                EOGMathGr3_CACR_EDS                     57
# 305                                 EOGMathGr3_GLP_EDS                     57
# 306                              EOGMathGr3-8_CACR_EDS                     36
# 307                               EOGMathGr3-8_GLP_EDS                     36
# 308                                EOGMathGr4_CACR_EDS                     63
# 309                                 EOGMathGr4_GLP_EDS                     63
# 310                                EOGMathGr5_CACR_EDS                    121
# 311                                 EOGMathGr5_GLP_EDS                    121
# 312                             EOGReadingGr3_CACR_EDS                     57
# 313                              EOGReadingGr3_GLP_EDS                     57
# 314                           EOGReadingGr3-8_CACR_EDS                     36
# 315                            EOGReadingGr3-8_GLP_EDS                     36
# 316                             EOGReadingGr4_CACR_EDS                     63
# 317                              EOGReadingGr4_GLP_EDS                     63
# 318                             EOGReadingGr5_CACR_EDS                    121
# 319                              EOGReadingGr5_GLP_EDS                    121
# 320                             EOGScienceGr5_CACR_EDS                    121
# 321                              EOGScienceGr5_GLP_EDS                    121
# 322                           EOGScienceGr5&8_CACR_EDS                    118
# 323                            EOGScienceGr5&8_GLP_EDS                    118
# 324                               EOGSubjects_CACR_EDS                     36
# 325                                EOGSubjects_GLP_EDS                     36
# 326                           EOG/EOCSubjects_CACR_LEP                     34
# 327                            EOG/EOCSubjects_GLP_LEP                     34
# 328                                    EOGGr3_CACR_LEP                     57
# 329                                     EOGGr3_GLP_LEP                     57
# 330                                    EOGGr4_CACR_LEP                     62
# 331                                     EOGGr4_GLP_LEP                     62
# 332                                    EOGGr5_CACR_LEP                    120
# 333                                     EOGGr5_GLP_LEP                    120
# 334                                EOGMathGr3_CACR_LEP                     57
# 335                                 EOGMathGr3_GLP_LEP                     57
# 336                              EOGMathGr3-8_CACR_LEP                     36
# 337                               EOGMathGr3-8_GLP_LEP                     36
# 338                                EOGMathGr4_CACR_LEP                     63
# 339                                 EOGMathGr4_GLP_LEP                     63
# 340                                EOGMathGr5_CACR_LEP                    121
# 341                                 EOGMathGr5_GLP_LEP                    121
# 342                             EOGReadingGr3_CACR_LEP                     57
# 343                              EOGReadingGr3_GLP_LEP                     57
# 344                           EOGReadingGr3-8_CACR_LEP                     36
# 345                            EOGReadingGr3-8_GLP_LEP                     36
# 346                             EOGReadingGr4_CACR_LEP                     63
# 347                              EOGReadingGr4_GLP_LEP                     63
# 348                             EOGReadingGr5_CACR_LEP                    121
# 349                              EOGReadingGr5_GLP_LEP                    121
# 350                             EOGScienceGr5_CACR_LEP                    121
# 351                              EOGScienceGr5_GLP_LEP                    121
# 352                           EOGScienceGr5&8_CACR_LEP                    118
# 353                            EOGScienceGr5&8_GLP_LEP                    118
# 354                               EOGSubjects_CACR_LEP                     36
# 355                                EOGSubjects_GLP_LEP                     36
# 356                           EOG/EOCSubjects_CACR_SWD                     34
# 357                            EOG/EOCSubjects_GLP_SWD                     34
# 358                                    EOGGr3_CACR_SWD                     57
# 359                                     EOGGr3_GLP_SWD                     57
# 360                                    EOGGr4_CACR_SWD                     62
# 361                                     EOGGr4_GLP_SWD                     62
# 362                                    EOGGr5_CACR_SWD                    120
# 363                                     EOGGr5_GLP_SWD                    120
# 364                                EOGMathGr3_CACR_SWD                     57
# 365                                 EOGMathGr3_GLP_SWD                     57
# 366                              EOGMathGr3-8_CACR_SWD                     36
# 367                               EOGMathGr3-8_GLP_SWD                     36
# 368                                EOGMathGr4_CACR_SWD                     63
# 369                                 EOGMathGr4_GLP_SWD                     63
# 370                                EOGMathGr5_CACR_SWD                    121
# 371                                 EOGMathGr5_GLP_SWD                    121
# 372                             EOGReadingGr3_CACR_SWD                     57
# 373                              EOGReadingGr3_GLP_SWD                     57
# 374                           EOGReadingGr3-8_CACR_SWD                     36
# 375                            EOGReadingGr3-8_GLP_SWD                     36
# 376                             EOGReadingGr4_CACR_SWD                     63
# 377                              EOGReadingGr4_GLP_SWD                     63
# 378                             EOGReadingGr5_CACR_SWD                    121
# 379                              EOGReadingGr5_GLP_SWD                    121
# 380                             EOGScienceGr5_CACR_SWD                    121
# 381                              EOGScienceGr5_GLP_SWD                    121
# 382                           EOGScienceGr5&8_CACR_SWD                    118
# 383                            EOGScienceGr5&8_GLP_SWD                    118
# 384                               EOGSubjects_CACR_SWD                     36
# 385                                EOGSubjects_GLP_SWD                     36
# 386                           EOG/EOCSubjects_CACR_AIG                     34
# 387                            EOG/EOCSubjects_GLP_AIG                     34
# 388                                    EOGGr3_CACR_AIG                     57
# 389                                     EOGGr3_GLP_AIG                     57
# 390                                    EOGGr4_CACR_AIG                     62
# 391                                     EOGGr4_GLP_AIG                     62
# 392                                    EOGGr5_CACR_AIG                    120
# 393                                     EOGGr5_GLP_AIG                    120
# 394                                EOGMathGr3_CACR_AIG                     57
# 395                                 EOGMathGr3_GLP_AIG                     57
# 396                              EOGMathGr3-8_CACR_AIG                     36
# 397                               EOGMathGr3-8_GLP_AIG                     36
# 398                                EOGMathGr4_CACR_AIG                     63
# 399                                 EOGMathGr4_GLP_AIG                     63
# 400                                EOGMathGr5_CACR_AIG                    121
# 401                                 EOGMathGr5_GLP_AIG                    121
# 402                             EOGReadingGr3_CACR_AIG                     57
# 403                              EOGReadingGr3_GLP_AIG                     57
# 404                           EOGReadingGr3-8_CACR_AIG                     36
# 405                            EOGReadingGr3-8_GLP_AIG                     36
# 406                             EOGReadingGr4_CACR_AIG                     63
# 407                              EOGReadingGr4_GLP_AIG                     63
# 408                             EOGReadingGr5_CACR_AIG                    121
# 409                              EOGReadingGr5_GLP_AIG                    121
# 410                             EOGScienceGr5_CACR_AIG                    121
# 411                              EOGScienceGr5_GLP_AIG                    121
# 412                           EOGScienceGr5&8_CACR_AIG                    118
# 413                            EOGScienceGr5&8_GLP_AIG                    118
# 414                               EOGSubjects_CACR_AIG                     36
# 415                                EOGSubjects_GLP_AIG                     36
# 416                                        pct_GCE_ALL                     57
# 417                                        pct_GCE_SWD                    681
# 418                                     pct_PASSED_EOG                     59
# 419                                     pct_PASSED_LAA                    531
# 420                                       pct_PROMOTED                     57
# 421                                       pct_RETAINED                    438
# 422                           MathGr3-8_pTarget_PctMet                     37
# 423                        ReadingGr3-8_pTarget_PctMet                     37
# 424                            SciGr5&8_pTarget_PctMet                    179
# 425                        TotalTargets_pTarget_PctMet                     35
# 428                           lea_ap_participation_pct                    119
# 429                              lea_ap_pct_3_or_above                     12
# 430                              lea_ib_pct_4_or_above                    772
# 435                             stud_internet_comp_num                      1
# 440                         lea_stud_internet_comp_num                      1
# 444                                  digital_media_pct                      3
# 445                                  books_per_student                      2
# 446                              lea_books_per_student                      2
# 447                        st_avg_age_media_collection                      2
# 448                               st_books_per_student                      2
# 454                                          nbpts_num                     69
# 456                               _1yr_tchr_trnovr_pct                      3
# 457                                 highqual_class_pct                      2
# 463                                      lea_nbpts_num                      2
# 466                            lea_emer_prov_teach_pct                    417
# 467                              lea_lateral_teach_pct                    172
# 469                          lea_highqual_class_hp_pct                    159
# 470                          lea_highqual_class_lp_pct                    263
# 472                      lea_not_highqual_class_hp_pct                    159
# 473                      lea_not_highqual_class_lp_pct                    263
# 492                   Accomplished_TCHR_Standard 1_Pct                     10
# 493                   Accomplished_TCHR_Standard 2_Pct                     10
# 494                   Accomplished_TCHR_Standard 3_Pct                     10
# 495                   Accomplished_TCHR_Standard 4_Pct                     10
# 496                   Accomplished_TCHR_Standard 5_Pct                     10
# 497                     Developing_TCHR_Standard 1_Pct                     10
# 498                     Developing_TCHR_Standard 2_Pct                     10
# 499                     Developing_TCHR_Standard 3_Pct                     10
# 500                     Developing_TCHR_Standard 4_Pct                     10
# 501                     Developing_TCHR_Standard 5_Pct                     10
# 502                  Distinguished_TCHR_Standard 1_Pct                     10
# 503                  Distinguished_TCHR_Standard 2_Pct                     10
# 504                  Distinguished_TCHR_Standard 3_Pct                     10
# 505                  Distinguished_TCHR_Standard 4_Pct                     10
# 506                  Distinguished_TCHR_Standard 5_Pct                     10
# 507  Does Not Meet Expected Growth_TCHR_Standard 6_Pct                     10
# 508        Exceeds Expected Growth_TCHR_Standard 6_Pct                     10
# 509          Meets Expected Growth_TCHR_Standard 6_Pct                     10
# 510                Not Demostrated_TCHR_Standard 1_Pct                     10
# 511                Not Demostrated_TCHR_Standard 2_Pct                     10
# 512                Not Demostrated_TCHR_Standard 3_Pct                     10
# 513                Not Demostrated_TCHR_Standard 4_Pct                     10
# 514                Not Demostrated_TCHR_Standard 5_Pct                     10
# 515                     Proficient_TCHR_Standard 1_Pct                     10
# 516                     Proficient_TCHR_Standard 2_Pct                     10
# 517                     Proficient_TCHR_Standard 3_Pct                     10
# 518                     Proficient_TCHR_Standard 4_Pct                     10
# 519                     Proficient_TCHR_Standard 5_Pct                     10
# 544                                               Year                    309
# 545                                       Violent Rate                    322
# 546                                        Murder Rate                    419
# 547                                          Rape Rate                    333
# 548                                       Robbery Rate                    335
# 549                                       Assault Rate                    326
# 550                                           MVT Rate                    324
# 551                                         Arson Rate                    350

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  212785  field correlations > 95%.
#                                                    Field1  \
# 0                                     lea_class_teach_num
# 1                                 st_avg_daily_attend_pct
# 2                                 st_short_susp_per_c_num
# 3                                  st_flicensed_teach_pct
# 4                                   st_tchyrs_4thru10_pct
# 5                                    st_lateral_teach_pct
# 6                                   st_highqual_class_pct
# 7                                           category_cd_E
# 8                                           Category_Cd_E
# 9                                      Reading  SPG Score
# 10                                         Math SPG Score
# 11                              Overall Achievement Score
# 12                               EOG/EOCSubjects_CACR_All
# 13                                EOG/EOCSubjects_GLP_All
# 14                                    EOGSubjects_GLP_All
# 15                             EOG/EOCSubjects_GLP_Female
# 16                                 EOGSubjects_GLP_Female
# 17                               EOG/EOCSubjects_GLP_Male
# 18                                   EOGSubjects_GLP_Male
# 19                                             Read Score
# 20                               EOGReadingGr3-8_CACR_All
# 21                                EOGReadingGr3-8_GLP_All
# 22                                    EOGSubjects_GLP_All
# 23                             EOGReadingGr3-8_GLP_Female
# 24                                 EOGSubjects_GLP_Female
# 25                               EOGReadingGr3-8_GLP_Male
# 26                                   EOGSubjects_GLP_Male
# 27                                             Math Score
# 28                                  EOGMathGr3-8_CACR_All
# 29                                   EOGMathGr3-8_GLP_All
# 30                                    EOGSubjects_GLP_All
# 31                                EOGMathGr3-8_GLP_Female
# 32                                 EOGSubjects_GLP_Female
# 33                                  EOGMathGr3-8_GLP_Male
# 34                                             Read Score
# 35                                             Math Score
# 36                               EOG/EOCSubjects_CACR_All
# 37                                EOG/EOCSubjects_GLP_All
# 38                                  EOGMathGr3-8_CACR_All
# 39                                   EOGMathGr3-8_GLP_All
# 40                                EOGReadingGr3-8_GLP_All
# 41                                   EOGSubjects_CACR_All
# 42                                    EOGSubjects_GLP_All
# 43                            EOG/EOCSubjects_CACR_Female
# 44                             EOG/EOCSubjects_GLP_Female
# 45                                EOGSubjects_CACR_Female
# 46                                 EOGSubjects_GLP_Female
# 47                              EOG/EOCSubjects_CACR_Male
# 48                               EOG/EOCSubjects_GLP_Male
# 49                                  EOGSubjects_CACR_Male
# 50                                   EOGSubjects_GLP_Male
# 51                                EOG/EOCSubjects_GLP_All
# 52                               EOGReadingGr3-8_CACR_All
# 53                                EOGReadingGr3-8_GLP_All
# 54                                   EOGSubjects_CACR_All
# 55                                    EOGSubjects_GLP_All
# 56                            EOGReadingGr3-8_CACR_Female
# 57                             EOGReadingGr3-8_GLP_Female
# 58                                 EOGSubjects_GLP_Female
# 59                              EOGReadingGr3-8_CACR_Male
# 60                               EOGReadingGr3-8_GLP_Male
# 61                                  EOGSubjects_CACR_Male
# 62                                   EOGSubjects_GLP_Male
# 63                               EOG/EOCSubjects_CACR_All
# 64                                EOG/EOCSubjects_GLP_All
# 65                                  EOGMathGr3-8_CACR_All
# 66                                   EOGMathGr3-8_GLP_All
# 67                                   EOGSubjects_CACR_All
# 68                                    EOGSubjects_GLP_All
# 69                               EOGMathGr3-8_CACR_Female
# 70                                EOGMathGr3-8_GLP_Female
# 71                                EOGSubjects_CACR_Female
# 72                                 EOGSubjects_GLP_Female
# 73                                 EOGMathGr3-8_CACR_Male
# 74                                  EOGMathGr3-8_GLP_Male
# 75                                  EOGSubjects_CACR_Male
# 76                                   EOGSubjects_GLP_Male
# 77                                         EOGGr5_GLP_All
# 78                                 EOGScienceGr5_CACR_All
# 79                                  EOGScienceGr5_GLP_All
# 80                               EOGScienceGr5&8_CACR_All
# 81                                EOGScienceGr5&8_GLP_All
# 82                             EOGScienceGr5&8_GLP_Female
# 83                               EOGScienceGr5&8_GLP_Male
# 84                                EOG/EOCSubjects_GLP_All
# 85                                  EOGMathGr3-8_CACR_All
# 86                                   EOGMathGr3-8_GLP_All
# 87                               EOGReadingGr3-8_CACR_All
# 88                                   EOGSubjects_CACR_All
# 89                                    EOGSubjects_GLP_All
# 90                            EOG/EOCSubjects_CACR_Female
# 91                             EOG/EOCSubjects_GLP_Female
# 92                                EOGSubjects_CACR_Female
# 93                                 EOGSubjects_GLP_Female
# 94                              EOG/EOCSubjects_CACR_Male
# 95                               EOG/EOCSubjects_GLP_Male
# 96                                  EOGSubjects_CACR_Male
# 97                                   EOGSubjects_GLP_Male
# 98                                  EOGMathGr3-8_CACR_All
# 99                                   EOGMathGr3-8_GLP_All
# 100                               EOGReadingGr3-8_GLP_All
# 101                                  EOGSubjects_CACR_All
# 102                                   EOGSubjects_GLP_All
# 103                           EOG/EOCSubjects_CACR_Female
# 104                            EOG/EOCSubjects_GLP_Female
# 105                               EOGSubjects_CACR_Female
# 106                                EOGSubjects_GLP_Female
# 107                             EOG/EOCSubjects_CACR_Male
# 108                              EOG/EOCSubjects_GLP_Male
# 109                                 EOGSubjects_CACR_Male
# 110                                  EOGSubjects_GLP_Male
# 111                                        EOGGr3_GLP_All
# 112                                   EOGMathGr3_CACR_All
# 113                                    EOGMathGr3_GLP_All
# 114                                EOGReadingGr3_CACR_All
# 115                                    EOGGr3_CACR_Female
# 116                                      EOGGr3_CACR_Male
# 117                                    EOGMathGr3_GLP_All
# 118                                 EOGReadingGr3_GLP_All
# 119                                     EOGGr3_GLP_Female
# 120                                       EOGGr3_GLP_Male
# 121                                        pct_PASSED_EOG
# 122                                        EOGGr4_GLP_All
# 123                                   EOGMathGr4_CACR_All
# 124                                    EOGMathGr4_GLP_All
# 125                                EOGReadingGr4_CACR_All
# 126                                 EOGReadingGr4_GLP_All
# 127                                    EOGGr4_CACR_Female
# 128                                      EOGGr4_CACR_Male
# 129                                       EOGGr4_GLP_Male
# 130                                   EOGMathGr4_CACR_All
# 131                                    EOGMathGr4_GLP_All
# 132                                EOGReadingGr4_CACR_All
# 133                                 EOGReadingGr4_GLP_All
# 134                                     EOGGr4_GLP_Female
# 135                                       EOGGr4_GLP_Male
# 136                                        EOGGr5_GLP_All
# 137                                   EOGMathGr5_CACR_All
# 138                                    EOGMathGr5_GLP_All
# 139                                EOGReadingGr5_CACR_All
# 140                                 EOGReadingGr5_GLP_All
# 141                                EOGScienceGr5_CACR_All
# 142                              EOGScienceGr5&8_CACR_All
# 143                                    EOGGr5_CACR_Female
# 144                                     EOGGr5_GLP_Female
# 145                                      EOGGr5_CACR_Male
# 146                                       EOGGr5_GLP_Male
# 147                                   EOGMathGr5_CACR_All
# 148                                    EOGMathGr5_GLP_All
# 149                                 EOGReadingGr5_GLP_All
# 150                                 EOGScienceGr5_GLP_All
# 151                               EOGScienceGr5&8_GLP_All
# 152                                     EOGGr5_GLP_Female
# 153                                      EOGGr5_CACR_Male
# 154                                       EOGGr5_GLP_Male
# 155                                    EOGMathGr3_GLP_All
# 156                                  EOGMathGr3_CACR_Male
# 157                                   EOGMathGr3_GLP_Male
# 158                                  EOGMathGr3-8_GLP_All
# 159                                  EOGSubjects_CACR_All
# 160                                   EOGSubjects_GLP_All
# 161                              EOGMathGr3-8_CACR_Female
# 162                               EOGMathGr3-8_GLP_Female
# 163                               EOGSubjects_CACR_Female
# 164                                EOGSubjects_GLP_Female
# 165                                EOGMathGr3-8_CACR_Male
# 166                                 EOGMathGr3-8_GLP_Male
# 167                                 EOGSubjects_CACR_Male
# 168                                  EOGSubjects_GLP_Male
# 169                                  EOGSubjects_CACR_All
# 170                                   EOGSubjects_GLP_All
# 171                              EOGMathGr3-8_CACR_Female
# 172                               EOGMathGr3-8_GLP_Female
# 173                               EOGSubjects_CACR_Female
# 174                                EOGSubjects_GLP_Female
# 175                                EOGMathGr3-8_CACR_Male
# 176                                 EOGMathGr3-8_GLP_Male
# 177                                 EOGSubjects_CACR_Male
# 178                                  EOGSubjects_GLP_Male
# 179                                    EOGMathGr4_GLP_All
# 180                                EOGMathGr4_CACR_Female
# 181                                  EOGMathGr4_CACR_Male
# 182                                 EOGMathGr4_GLP_Female
# 183                                   EOGMathGr4_GLP_Male
# 184                                    EOGMathGr5_GLP_All
# 185                                  EOGMathGr5_CACR_Male
# 186                                   EOGMathGr5_GLP_Male
# 187                                 EOGReadingGr3_GLP_All
# 188                                        pct_PASSED_EOG
# 189                                EOGReadingGr3_GLP_Male
# 190                                        pct_PASSED_EOG
# 191                               EOGReadingGr3-8_GLP_All
# 192                                  EOGSubjects_CACR_All
# 193                                   EOGSubjects_GLP_All
# 194                           EOGReadingGr3-8_CACR_Female
# 195                            EOGReadingGr3-8_GLP_Female
# 196                               EOGSubjects_CACR_Female
# 197                             EOGReadingGr3-8_CACR_Male
# 198                              EOGReadingGr3-8_GLP_Male
# 199                                 EOGSubjects_CACR_Male
# 200                                  EOGSubjects_GLP_Male
# 201                                  EOGSubjects_CACR_All
# 202                                   EOGSubjects_GLP_All
# 203                           EOGReadingGr3-8_CACR_Female
# 204                            EOGReadingGr3-8_GLP_Female
# 205                                EOGSubjects_GLP_Female
# 206                             EOGReadingGr3-8_CACR_Male
# 207                              EOGReadingGr3-8_GLP_Male
# 208                                 EOGSubjects_CACR_Male
# 209                                  EOGSubjects_GLP_Male
# 210                                 EOGReadingGr4_GLP_All
# 211                                 EOGReadingGr5_GLP_All
# 212                                 EOGScienceGr5_GLP_All
# 213                              EOGScienceGr5&8_CACR_All
# 214                               EOGScienceGr5&8_GLP_All
# 215                           EOGScienceGr5&8_CACR_Female
# 216                               EOGScienceGr5_CACR_Male
# 217                             EOGScienceGr5&8_CACR_Male
# 218                              EOGScienceGr5&8_CACR_All
# 219                               EOGScienceGr5&8_GLP_All
# 220                            EOGScienceGr5&8_GLP_Female
# 221                                EOGScienceGr5_GLP_Male
# 222                              EOGScienceGr5&8_GLP_Male
# 223                               EOGScienceGr5&8_GLP_All
# 224                           EOGScienceGr5&8_CACR_Female
# 225                             EOGScienceGr5&8_CACR_Male
# 226                            EOGScienceGr5&8_GLP_Female
# 227                              EOGScienceGr5&8_GLP_Male
# 228                                   EOGSubjects_GLP_All
# 229                           EOG/EOCSubjects_CACR_Female
# 230                            EOG/EOCSubjects_GLP_Female
# 231                              EOGMathGr3-8_CACR_Female
# 232                           EOGReadingGr3-8_CACR_Female
# 233                               EOGSubjects_CACR_Female
# 234                                EOGSubjects_GLP_Female
# 235                             EOG/EOCSubjects_CACR_Male
# 236                              EOG/EOCSubjects_GLP_Male
# 237                                EOGMathGr3-8_CACR_Male
# 238                                 EOGMathGr3-8_GLP_Male
# 239                             EOGReadingGr3-8_CACR_Male
# 240                                 EOGSubjects_CACR_Male
# 241                                  EOGSubjects_GLP_Male
# 242                           EOG/EOCSubjects_CACR_Female
# 243                            EOG/EOCSubjects_GLP_Female
# 244                               EOGMathGr3-8_GLP_Female
# 245                            EOGReadingGr3-8_GLP_Female
# 246                               EOGSubjects_CACR_Female
# 247                                EOGSubjects_GLP_Female
# 248                             EOG/EOCSubjects_CACR_Male
# 249                              EOG/EOCSubjects_GLP_Male
# 250                                EOGMathGr3-8_CACR_Male
# 251                                 EOGMathGr3-8_GLP_Male
# 252                              EOGReadingGr3-8_GLP_Male
# 253                                 EOGSubjects_CACR_Male
# 254                                  EOGSubjects_GLP_Male
# 255                            EOG/EOCSubjects_GLP_Female
# 256                              EOGMathGr3-8_CACR_Female
# 257                           EOGReadingGr3-8_CACR_Female
# 258                               EOGSubjects_CACR_Female
# 259                                EOGSubjects_GLP_Female
# 260                               EOGMathGr3-8_GLP_Female
# 261                            EOGReadingGr3-8_GLP_Female
# 262                               EOGSubjects_CACR_Female
# 263                                EOGSubjects_GLP_Female
# 264                                     EOGGr3_GLP_Female
# 265                                     EOGGr4_GLP_Female
# 266                                EOGMathGr4_CACR_Female
# 267                             EOGReadingGr4_CACR_Female
# 268                                 EOGMathGr4_GLP_Female
# 269                              EOGReadingGr4_GLP_Female
# 270                                     EOGGr5_GLP_Female
# 271                                 EOGMathGr5_GLP_Female
# 272                               EOGMathGr3-8_GLP_Female
# 273                               EOGSubjects_CACR_Female
# 274                                EOGSubjects_GLP_Female
# 275                               EOGSubjects_CACR_Female
# 276                                EOGSubjects_GLP_Female
# 277                                 EOGMathGr4_GLP_Female
# 278                                 EOGMathGr5_GLP_Female
# 279                            EOGReadingGr3-8_GLP_Female
# 280                               EOGSubjects_CACR_Female
# 281                               EOGSubjects_CACR_Female
# 282                                EOGSubjects_GLP_Female
# 283                              EOGReadingGr4_GLP_Female
# 284                              EOGReadingGr5_GLP_Female
# 285                              EOGScienceGr5_GLP_Female
# 286                           EOGScienceGr5&8_CACR_Female
# 287                            EOGScienceGr5&8_GLP_Female
# 288                            EOGScienceGr5&8_GLP_Female
# 289                                EOGSubjects_GLP_Female
# 290                              EOG/EOCSubjects_GLP_Male
# 291                                EOGMathGr3-8_CACR_Male
# 292                             EOGReadingGr3-8_CACR_Male
# 293                                 EOGSubjects_CACR_Male
# 294                                  EOGSubjects_GLP_Male
# 295                                 EOGMathGr3-8_GLP_Male
# 296                              EOGReadingGr3-8_GLP_Male
# 297                                 EOGSubjects_CACR_Male
# 298                                  EOGSubjects_GLP_Male
# 299                                       EOGGr3_GLP_Male
# 300                                  EOGMathGr3_CACR_Male
# 301                               EOGReadingGr3_CACR_Male
# 302                                   EOGMathGr3_GLP_Male
# 303                                EOGReadingGr3_GLP_Male
# 304                                       EOGGr4_GLP_Male
# 305                                  EOGMathGr4_CACR_Male
# 306                                   EOGMathGr4_GLP_Male
# 307                               EOGReadingGr4_CACR_Male
# 308                                   EOGMathGr4_GLP_Male
# 309                                EOGReadingGr4_GLP_Male
# 310                                       EOGGr5_GLP_Male
# 311                                   EOGMathGr3_GLP_Male
# 312                                 EOGMathGr3-8_GLP_Male
# 313                                 EOGSubjects_CACR_Male
# 314                                  EOGSubjects_GLP_Male
# 315                                 EOGSubjects_CACR_Male
# 316                                  EOGSubjects_GLP_Male
# 317                                   EOGMathGr4_GLP_Male
# 318                                   EOGMathGr5_GLP_Male
# 319                                        pct_PASSED_EOG
# 320                              EOGReadingGr3-8_GLP_Male
# 321                                 EOGSubjects_CACR_Male
# 322                                  EOGSubjects_GLP_Male
# 323                                 EOGSubjects_CACR_Male
# 324                                  EOGSubjects_GLP_Male
# 325                                EOGReadingGr4_GLP_Male
# 326                                EOGReadingGr5_GLP_Male
# 327                                EOGScienceGr5_GLP_Male
# 328                             EOGScienceGr5&8_CACR_Male
# 329                              EOGScienceGr5&8_GLP_Male
# 330                             EOGScienceGr5&8_CACR_Male
# 331                              EOGScienceGr5&8_GLP_Male
# 332                              EOGScienceGr5&8_GLP_Male
# 333                                  EOGSubjects_GLP_Male
# 334                    EOG/EOCSubjects_GLP_AmericanIndian
# 335                       EOGSubjects_CACR_AmericanIndian
# 336                        EOGSubjects_GLP_AmericanIndian
# 337                       EOGSubjects_CACR_AmericanIndian
# 338                        EOGSubjects_GLP_AmericanIndian
# 339                             EOGGr3_GLP_AmericanIndian
# 340                             EOGGr4_GLP_AmericanIndian
# 341                             EOGGr5_GLP_AmericanIndian
# 342                         EOGMathGr3_GLP_AmericanIndian
# 343                       EOGMathGr3-8_GLP_AmericanIndian
# 344                         EOGMathGr4_GLP_AmericanIndian
# 345                     EOGReadingGr4_CACR_AmericanIndian
# 346                      EOGReadingGr4_GLP_AmericanIndian
# 347                         EOGMathGr5_GLP_AmericanIndian
# 348                      EOGReadingGr3_GLP_AmericanIndian
# 349                    EOGReadingGr3-8_GLP_AmericanIndian
# 350                      EOGReadingGr4_GLP_AmericanIndian
# 351                      EOGScienceGr5_GLP_AmericanIndian
# 352                   EOGScienceGr5&8_CACR_AmericanIndian
# 353                    EOGScienceGr5&8_GLP_AmericanIndian
# 354                   EOGScienceGr5&8_CACR_AmericanIndian
# 355                    EOGScienceGr5&8_GLP_AmericanIndian
# 356                    EOGScienceGr5&8_GLP_AmericanIndian
# 357                        EOGSubjects_GLP_AmericanIndian
# 358                             EOG/EOCSubjects_GLP_Asian
# 359                                EOGSubjects_CACR_Asian
# 360                                 EOGSubjects_GLP_Asian
# 361                                EOGSubjects_CACR_Asian
# 362                                 EOGSubjects_GLP_Asian
# 363                                      EOGGr3_GLP_Asian
# 364                                      EOGGr4_GLP_Asian
# 365                                      EOGGr5_GLP_Asian
# 366                                  EOGMathGr3_GLP_Asian
# 367                              EOGReadingGr3_CACR_Asian
# 368                               EOGReadingGr3_GLP_Asian
# 369                              EOGReadingGr3_CACR_Asian
# 370                               EOGReadingGr3_GLP_Asian
# 371                                EOGMathGr3-8_GLP_Asian
# 372                            EOGReadingGr3-8_CACR_Asian
# 373                             EOGReadingGr3-8_GLP_Asian
# 374                             EOGReadingGr3-8_GLP_Asian
# 375                                  EOGMathGr4_GLP_Asian
# 376                              EOGReadingGr4_CACR_Asian
# 377                               EOGReadingGr4_GLP_Asian
# 378                              EOGReadingGr4_CACR_Asian
# 379                               EOGReadingGr4_GLP_Asian
# 380                                  EOGMathGr5_GLP_Asian
# 381                              EOGReadingGr5_CACR_Asian
# 382                               EOGReadingGr5_GLP_Asian
# 383                              EOGScienceGr5_CACR_Asian
# 384                               EOGScienceGr5_GLP_Asian
# 385                            EOGScienceGr5&8_CACR_Asian
# 386                             EOGScienceGr5&8_GLP_Asian
# 387                               EOGReadingGr5_GLP_Asian
# 388                              EOGScienceGr5_CACR_Asian
# 389                               EOGScienceGr5_GLP_Asian
# 390                            EOGScienceGr5&8_CACR_Asian
# 391                             EOGScienceGr5&8_GLP_Asian
# 392                               EOGReadingGr3_GLP_Asian
# 393                             EOGReadingGr3-8_GLP_Asian
# 394                               EOGReadingGr4_GLP_Asian
# 395                               EOGReadingGr5_GLP_Asian
# 396                              EOGScienceGr5_CACR_Asian
# 397                              EOGScienceGr5_CACR_Asian
# 398                               EOGScienceGr5_GLP_Asian
# 399                            EOGScienceGr5&8_CACR_Asian
# 400                             EOGScienceGr5&8_GLP_Asian
# 401                               EOGScienceGr5_GLP_Asian
# 402                            EOGScienceGr5&8_CACR_Asian
# 403                             EOGScienceGr5&8_GLP_Asian
# 404                            EOGScienceGr5&8_CACR_Asian
# 405                             EOGScienceGr5&8_GLP_Asian
# 406                             EOGScienceGr5&8_GLP_Asian
# 407                                 EOGSubjects_GLP_Asian
# 408                             EOG/EOCSubjects_GLP_Black
# 409                                EOGSubjects_CACR_Black
# 410                                 EOGSubjects_GLP_Black
# 411                                EOGSubjects_CACR_Black
# 412                                 EOGSubjects_GLP_Black
# 413                                      EOGGr4_GLP_Black
# 414                                      EOGGr5_GLP_Black
# 415                                EOGMathGr3-8_GLP_Black
# 416                                  EOGMathGr4_GLP_Black
# 417                                  EOGMathGr5_GLP_Black
# 418                               EOGScienceGr5_GLP_Black
# 419                            EOGScienceGr5&8_CACR_Black
# 420                             EOGScienceGr5&8_GLP_Black
# 421                             EOGScienceGr5&8_GLP_Black
# 422                                 EOGSubjects_GLP_Black
# 423                             EOGSubjects_CACR_Hispanic
# 424                              EOGSubjects_GLP_Hispanic
# 425                                   EOGGr4_GLP_Hispanic
# 426                                   EOGGr5_GLP_Hispanic
# 427                               EOGMathGr4_GLP_Hispanic
# 428                               EOGMathGr5_GLP_Hispanic
# 429                            EOGScienceGr5_GLP_Hispanic
# 430                         EOGScienceGr5&8_CACR_Hispanic
# 431                          EOGScienceGr5&8_GLP_Hispanic
# 432                          EOGScienceGr5&8_GLP_Hispanic
# 433                    EOG/EOCSubjects_GLP_TwoorMoreRaces
# 434                       EOGSubjects_CACR_TwoorMoreRaces
# 435                        EOGSubjects_GLP_TwoorMoreRaces
# 436                             EOGGr3_GLP_TwoorMoreRaces
# 437                             EOGGr4_GLP_TwoorMoreRaces
# 438                             EOGGr5_GLP_TwoorMoreRaces
# 439                         EOGMathGr3_GLP_TwoorMoreRaces
# 440                      EOGReadingGr3_GLP_TwoorMoreRaces
# 441                       EOGMathGr3-8_GLP_TwoorMoreRaces
# 442                         EOGMathGr4_GLP_TwoorMoreRaces
# 443                         EOGMathGr5_GLP_TwoorMoreRaces
# 444                      EOGReadingGr3_GLP_TwoorMoreRaces
# 445                      EOGReadingGr4_GLP_TwoorMoreRaces
# 446                      EOGReadingGr5_GLP_TwoorMoreRaces
# 447                      EOGScienceGr5_GLP_TwoorMoreRaces
# 448                   EOGScienceGr5&8_CACR_TwoorMoreRaces
# 449                    EOGScienceGr5&8_GLP_TwoorMoreRaces
# 450                   EOGScienceGr5&8_CACR_TwoorMoreRaces
# 451                    EOGScienceGr5&8_GLP_TwoorMoreRaces
# 452                    EOGScienceGr5&8_GLP_TwoorMoreRaces
# 453                        EOGSubjects_GLP_TwoorMoreRaces
# 454                             EOG/EOCSubjects_GLP_White
# 455                                EOGSubjects_CACR_White
# 456                                 EOGSubjects_GLP_White
# 457                                EOGSubjects_CACR_White
# 458                                 EOGSubjects_GLP_White
# 459                                      EOGGr3_GLP_White
# 460                                      EOGGr4_GLP_White
# 461                                      EOGGr5_GLP_White
# 462                                  EOGMathGr3_GLP_White
# 463                                EOGMathGr3-8_GLP_White
# 464                                  EOGMathGr4_GLP_White
# 465                                  EOGMathGr5_GLP_White
# 466                               EOGReadingGr3_GLP_White
# 467                             EOGReadingGr3-8_GLP_White
# 468                               EOGReadingGr4_GLP_White
# 469                               EOGReadingGr5_GLP_White
# 470                               EOGScienceGr5_GLP_White
# 471                            EOGScienceGr5&8_CACR_White
# 472                             EOGScienceGr5&8_GLP_White
# 473                            EOGScienceGr5&8_CACR_White
# 474                             EOGScienceGr5&8_GLP_White
# 475                             EOGScienceGr5&8_GLP_White
# 476                                 EOGSubjects_GLP_White
# 477                               EOG/EOCSubjects_GLP_EDS
# 478                                  EOGSubjects_CACR_EDS
# 479                                   EOGSubjects_GLP_EDS
# 480                                  EOGSubjects_CACR_EDS
# 481                                   EOGSubjects_GLP_EDS
# 482                                        EOGGr3_GLP_EDS
# 483                                        EOGGr4_GLP_EDS
# 484                                    EOGMathGr4_GLP_EDS
# 485                                        EOGGr5_GLP_EDS
# 486                                  EOGMathGr3-8_GLP_EDS
# 487                                  EOGSubjects_CACR_EDS
# 488                                   EOGSubjects_GLP_EDS
# 489                                    EOGMathGr4_GLP_EDS
# 490                                    EOGMathGr5_GLP_EDS
# 491                               EOGReadingGr3-8_GLP_EDS
# 492                                   EOGSubjects_GLP_EDS
# 493                                 EOGScienceGr5_GLP_EDS
# 494                              EOGScienceGr5&8_CACR_EDS
# 495                               EOGScienceGr5&8_GLP_EDS
# 496                               EOGScienceGr5&8_GLP_EDS
# 497                                   EOGSubjects_GLP_EDS
# 498                                  EOGSubjects_CACR_LEP
# 499                                   EOGSubjects_GLP_LEP
# ...                                                   ...
# 212285                Unemployment compensation Amt LT25K
# 212286            Unemployment compensation Ct 100KLT200K
# 212287              Unemployment compensation Ct 25KLT50K
# 212288              Unemployment compensation Ct 50KLT75K
# 212289             Unemployment compensation Ct 75KLT100K
# 212290                   Unemployment compensation Ct All
# 212291                 Unemployment compensation Ct LT25K
# 212292                     Tot tax payments Amt 75KLT100K
# 212293                           Tot tax payments Amt All
# 212294                        Tot tax payments Amt GE200K
# 212295                         Tot tax payments Amt LT25K
# 212296                     Tot tax payments Ct 100KLT200K
# 212297                       Tot tax payments Ct 25KLT50K
# 212298                       Tot tax payments Ct 50KLT75K
# 212299                      Tot tax payments Ct 75KLT100K
# 212300                            Tot tax payments Ct All
# 212301                         Tot tax payments Ct GE200K
# 212302                          Tot tax payments Ct LT25K
# 212303          Tuition and fees deduction Amt 100KLT200K
# 212304            Tuition and fees deduction Amt 25KLT50K
# 212305            Tuition and fees deduction Amt 50KLT75K
# 212306                 Tuition and fees deduction Amt All
# 212307               Tuition and fees deduction Amt LT25K
# 212308           Tuition and fees deduction Ct 100KLT200K
# 212309             Tuition and fees deduction Ct 25KLT50K
# 212310             Tuition and fees deduction Ct 50KLT75K
# 212311                  Tuition and fees deduction Ct All
# 212312                Tuition and fees deduction Ct LT25K
# 212313           Unemployment compensation Amt 100KLT200K
# 212314             Unemployment compensation Amt 25KLT50K
# 212315             Unemployment compensation Amt 50KLT75K
# 212316            Unemployment compensation Amt 75KLT100K
# 212317                  Unemployment compensation Amt All
# 212318                Unemployment compensation Amt LT25K
# 212319            Unemployment compensation Ct 100KLT200K
# 212320              Unemployment compensation Ct 25KLT50K
# 212321              Unemployment compensation Ct 50KLT75K
# 212322             Unemployment compensation Ct 75KLT100K
# 212323                   Unemployment compensation Ct All
# 212324                 Unemployment compensation Ct LT25K
# 212325                           Tot tax payments Amt All
# 212326                        Tot tax payments Amt GE200K
# 212327                     Tot tax payments Ct 100KLT200K
# 212328                       Tot tax payments Ct 25KLT50K
# 212329                       Tot tax payments Ct 50KLT75K
# 212330                      Tot tax payments Ct 75KLT100K
# 212331                            Tot tax payments Ct All
# 212332                         Tot tax payments Ct GE200K
# 212333                          Tot tax payments Ct LT25K
# 212334          Tuition and fees deduction Amt 100KLT200K
# 212335            Tuition and fees deduction Amt 25KLT50K
# 212336            Tuition and fees deduction Amt 50KLT75K
# 212337                 Tuition and fees deduction Amt All
# 212338               Tuition and fees deduction Amt LT25K
# 212339           Tuition and fees deduction Ct 100KLT200K
# 212340             Tuition and fees deduction Ct 25KLT50K
# 212341             Tuition and fees deduction Ct 50KLT75K
# 212342                  Tuition and fees deduction Ct All
# 212343                Tuition and fees deduction Ct LT25K
# 212344           Unemployment compensation Amt 100KLT200K
# 212345             Unemployment compensation Amt 25KLT50K
# 212346             Unemployment compensation Amt 50KLT75K
# 212347            Unemployment compensation Amt 75KLT100K
# 212348                  Unemployment compensation Amt All
# 212349            Unemployment compensation Ct 100KLT200K
# 212350              Unemployment compensation Ct 25KLT50K
# 212351              Unemployment compensation Ct 50KLT75K
# 212352             Unemployment compensation Ct 75KLT100K
# 212353                   Unemployment compensation Ct All
# 212354                        Tot tax payments Amt GE200K
# 212355                         Tot tax payments Amt LT25K
# 212356                     Tot tax payments Ct 100KLT200K
# 212357                       Tot tax payments Ct 25KLT50K
# 212358                       Tot tax payments Ct 50KLT75K
# 212359                      Tot tax payments Ct 75KLT100K
# 212360                            Tot tax payments Ct All
# 212361                         Tot tax payments Ct GE200K
# 212362                          Tot tax payments Ct LT25K
# 212363          Tuition and fees deduction Amt 100KLT200K
# 212364            Tuition and fees deduction Amt 25KLT50K
# 212365            Tuition and fees deduction Amt 50KLT75K
# 212366                 Tuition and fees deduction Amt All
# 212367               Tuition and fees deduction Amt LT25K
# 212368             Tuition and fees deduction Ct 25KLT50K
# 212369             Tuition and fees deduction Ct 50KLT75K
# 212370                  Tuition and fees deduction Ct All
# 212371                Tuition and fees deduction Ct LT25K
# 212372           Unemployment compensation Amt 100KLT200K
# 212373             Unemployment compensation Amt 25KLT50K
# 212374             Unemployment compensation Amt 50KLT75K
# 212375            Unemployment compensation Amt 75KLT100K
# 212376                  Unemployment compensation Amt All
# 212377                Unemployment compensation Amt LT25K
# 212378            Unemployment compensation Ct 100KLT200K
# 212379              Unemployment compensation Ct 25KLT50K
# 212380              Unemployment compensation Ct 50KLT75K
# 212381             Unemployment compensation Ct 75KLT100K
# 212382                   Unemployment compensation Ct All
# 212383                       Tot tax payments Ct 25KLT50K
# 212384                       Tot tax payments Ct 50KLT75K
# 212385                      Tot tax payments Ct 75KLT100K
# 212386                            Tot tax payments Ct All
# 212387                         Tot tax payments Ct GE200K
# 212388                          Tot tax payments Ct LT25K
# 212389            Tuition and fees deduction Amt 25KLT50K
# 212390            Tuition and fees deduction Amt 50KLT75K
# 212391                 Tuition and fees deduction Amt All
# 212392               Tuition and fees deduction Amt LT25K
# 212393             Tuition and fees deduction Ct 25KLT50K
# 212394             Tuition and fees deduction Ct 50KLT75K
# 212395                  Tuition and fees deduction Ct All
# 212396                Tuition and fees deduction Ct LT25K
# 212397           Unemployment compensation Amt 100KLT200K
# 212398             Unemployment compensation Amt 25KLT50K
# 212399             Unemployment compensation Amt 50KLT75K
# 212400            Unemployment compensation Amt 75KLT100K
# 212401                  Unemployment compensation Amt All
# 212402                Unemployment compensation Amt LT25K
# 212403            Unemployment compensation Ct 100KLT200K
# 212404              Unemployment compensation Ct 25KLT50K
# 212405              Unemployment compensation Ct 50KLT75K
# 212406             Unemployment compensation Ct 75KLT100K
# 212407                   Unemployment compensation Ct All
# 212408                       Tot tax payments Ct 25KLT50K
# 212409                       Tot tax payments Ct 50KLT75K
# 212410                            Tot tax payments Ct All
# 212411                          Tot tax payments Ct LT25K
# 212412            Tuition and fees deduction Amt 25KLT50K
# 212413            Tuition and fees deduction Amt 50KLT75K
# 212414             Tuition and fees deduction Ct 25KLT50K
# 212415             Tuition and fees deduction Ct 50KLT75K
# 212416                Tuition and fees deduction Ct LT25K
# 212417             Unemployment compensation Amt 25KLT50K
# 212418             Unemployment compensation Amt 50KLT75K
# 212419                  Unemployment compensation Amt All
# 212420                Unemployment compensation Amt LT25K
# 212421              Unemployment compensation Ct 25KLT50K
# 212422              Unemployment compensation Ct 50KLT75K
# 212423                   Unemployment compensation Ct All
# 212424                 Unemployment compensation Ct LT25K
# 212425                       Tot tax payments Ct 25KLT50K
# 212426                       Tot tax payments Ct 50KLT75K
# 212427                      Tot tax payments Ct 75KLT100K
# 212428                            Tot tax payments Ct All
# 212429                         Tot tax payments Ct GE200K
# 212430          Tuition and fees deduction Amt 100KLT200K
# 212431            Tuition and fees deduction Amt 50KLT75K
# 212432                 Tuition and fees deduction Amt All
# 212433               Tuition and fees deduction Amt LT25K
# 212434           Tuition and fees deduction Ct 100KLT200K
# 212435             Tuition and fees deduction Ct 50KLT75K
# 212436                  Tuition and fees deduction Ct All
# 212437                Tuition and fees deduction Ct LT25K
# 212438           Unemployment compensation Amt 100KLT200K
# 212439             Unemployment compensation Amt 50KLT75K
# 212440            Unemployment compensation Amt 75KLT100K
# 212441               Unemployment compensation Amt GE200K
# 212442            Unemployment compensation Ct 100KLT200K
# 212443              Unemployment compensation Ct 50KLT75K
# 212444             Unemployment compensation Ct 75KLT100K
# 212445                Unemployment compensation Ct GE200K
# 212446                       Tot tax payments Ct 50KLT75K
# 212447                      Tot tax payments Ct 75KLT100K
# 212448                            Tot tax payments Ct All
# 212449                         Tot tax payments Ct GE200K
# 212450                          Tot tax payments Ct LT25K
# 212451            Tuition and fees deduction Amt 25KLT50K
# 212452            Tuition and fees deduction Amt 50KLT75K
# 212453                 Tuition and fees deduction Amt All
# 212454               Tuition and fees deduction Amt LT25K
# 212455             Tuition and fees deduction Ct 25KLT50K
# 212456             Tuition and fees deduction Ct 50KLT75K
# 212457                  Tuition and fees deduction Ct All
# 212458                Tuition and fees deduction Ct LT25K
# 212459           Unemployment compensation Amt 100KLT200K
# 212460             Unemployment compensation Amt 25KLT50K
# 212461             Unemployment compensation Amt 50KLT75K
# 212462            Unemployment compensation Amt 75KLT100K
# 212463                  Unemployment compensation Amt All
# 212464                Unemployment compensation Amt LT25K
# 212465            Unemployment compensation Ct 100KLT200K
# 212466              Unemployment compensation Ct 25KLT50K
# 212467              Unemployment compensation Ct 50KLT75K
# 212468             Unemployment compensation Ct 75KLT100K
# 212469                   Unemployment compensation Ct All
# 212470                 Unemployment compensation Ct LT25K
# 212471                      Tot tax payments Ct 75KLT100K
# 212472                            Tot tax payments Ct All
# 212473                         Tot tax payments Ct GE200K
# 212474                          Tot tax payments Ct LT25K
# 212475          Tuition and fees deduction Amt 100KLT200K
# 212476            Tuition and fees deduction Amt 25KLT50K
# 212477            Tuition and fees deduction Amt 50KLT75K
# 212478                 Tuition and fees deduction Amt All
# 212479               Tuition and fees deduction Amt LT25K
# 212480           Tuition and fees deduction Ct 100KLT200K
# 212481             Tuition and fees deduction Ct 25KLT50K
# 212482             Tuition and fees deduction Ct 50KLT75K
# 212483                  Tuition and fees deduction Ct All
# 212484                Tuition and fees deduction Ct LT25K
# 212485           Unemployment compensation Amt 100KLT200K
# 212486             Unemployment compensation Amt 25KLT50K
# 212487             Unemployment compensation Amt 50KLT75K
# 212488            Unemployment compensation Amt 75KLT100K
# 212489                  Unemployment compensation Amt All
# 212490                Unemployment compensation Amt LT25K
# 212491            Unemployment compensation Ct 100KLT200K
# 212492              Unemployment compensation Ct 25KLT50K
# 212493              Unemployment compensation Ct 50KLT75K
# 212494             Unemployment compensation Ct 75KLT100K
# 212495                   Unemployment compensation Ct All
# 212496                 Unemployment compensation Ct LT25K
# 212497                            Tot tax payments Ct All
# 212498                         Tot tax payments Ct GE200K
# 212499                          Tot tax payments Ct LT25K
# 212500          Tuition and fees deduction Amt 100KLT200K
# 212501            Tuition and fees deduction Amt 25KLT50K
# 212502            Tuition and fees deduction Amt 50KLT75K
# 212503                 Tuition and fees deduction Amt All
# 212504               Tuition and fees deduction Amt LT25K
# 212505           Tuition and fees deduction Ct 100KLT200K
# 212506             Tuition and fees deduction Ct 25KLT50K
# 212507             Tuition and fees deduction Ct 50KLT75K
# 212508                  Tuition and fees deduction Ct All
# 212509                Tuition and fees deduction Ct LT25K
# 212510           Unemployment compensation Amt 100KLT200K
# 212511             Unemployment compensation Amt 25KLT50K
# 212512             Unemployment compensation Amt 50KLT75K
# 212513            Unemployment compensation Amt 75KLT100K
# 212514                  Unemployment compensation Amt All
# 212515            Unemployment compensation Ct 100KLT200K
# 212516              Unemployment compensation Ct 25KLT50K
# 212517              Unemployment compensation Ct 50KLT75K
# 212518             Unemployment compensation Ct 75KLT100K
# 212519                   Unemployment compensation Ct All
# 212520                         Tot tax payments Ct GE200K
# 212521                          Tot tax payments Ct LT25K
# 212522          Tuition and fees deduction Amt 100KLT200K
# 212523            Tuition and fees deduction Amt 25KLT50K
# 212524            Tuition and fees deduction Amt 50KLT75K
# 212525                 Tuition and fees deduction Amt All
# 212526               Tuition and fees deduction Amt LT25K
# 212527             Tuition and fees deduction Ct 25KLT50K
# 212528             Tuition and fees deduction Ct 50KLT75K
# 212529                  Tuition and fees deduction Ct All
# 212530                Tuition and fees deduction Ct LT25K
# 212531           Unemployment compensation Amt 100KLT200K
# 212532             Unemployment compensation Amt 25KLT50K
# 212533             Unemployment compensation Amt 50KLT75K
# 212534            Unemployment compensation Amt 75KLT100K
# 212535                  Unemployment compensation Amt All
# 212536                Unemployment compensation Amt LT25K
# 212537            Unemployment compensation Ct 100KLT200K
# 212538              Unemployment compensation Ct 25KLT50K
# 212539              Unemployment compensation Ct 50KLT75K
# 212540             Unemployment compensation Ct 75KLT100K
# 212541                   Unemployment compensation Ct All
# 212542                 Unemployment compensation Ct LT25K
# 212543                          Tot tax payments Ct LT25K
# 212544          Tuition and fees deduction Amt 100KLT200K
# 212545            Tuition and fees deduction Amt 50KLT75K
# 212546                 Tuition and fees deduction Amt All
# 212547               Tuition and fees deduction Amt LT25K
# 212548           Tuition and fees deduction Ct 100KLT200K
# 212549             Tuition and fees deduction Ct 50KLT75K
# 212550                  Tuition and fees deduction Ct All
# 212551                Tuition and fees deduction Ct LT25K
# 212552           Unemployment compensation Amt 100KLT200K
# 212553             Unemployment compensation Amt 25KLT50K
# 212554             Unemployment compensation Amt 50KLT75K
# 212555            Unemployment compensation Amt 75KLT100K
# 212556                  Unemployment compensation Amt All
# 212557               Unemployment compensation Amt GE200K
# 212558            Unemployment compensation Ct 100KLT200K
# 212559              Unemployment compensation Ct 25KLT50K
# 212560              Unemployment compensation Ct 50KLT75K
# 212561             Unemployment compensation Ct 75KLT100K
# 212562                   Unemployment compensation Ct All
# 212563                Unemployment compensation Ct GE200K
# 212564            Tuition and fees deduction Amt 25KLT50K
# 212565            Tuition and fees deduction Amt 50KLT75K
# 212566                 Tuition and fees deduction Amt All
# 212567               Tuition and fees deduction Amt LT25K
# 212568             Tuition and fees deduction Ct 25KLT50K
# ...
# 212567                          Tot tax payments Ct LT25K     0.972863
# 212568                          Tot tax payments Ct LT25K     0.984341
# 212569                          Tot tax payments Ct LT25K     0.971409
# 212570                          Tot tax payments Ct LT25K     0.970448
# 212571                          Tot tax payments Ct LT25K     0.978658
# 212572                          Tot tax payments Ct LT25K     0.989265
# 212573                          Tot tax payments Ct LT25K     0.988638
# 212574                          Tot tax payments Ct LT25K     0.958342
# 212575                          Tot tax payments Ct LT25K     0.991332
# 212576                          Tot tax payments Ct LT25K     0.986801
# 212577                          Tot tax payments Ct LT25K     0.992468
# 212578                          Tot tax payments Ct LT25K     0.988849
# 212579                          Tot tax payments Ct LT25K     0.962011
# 212580                          Tot tax payments Ct LT25K     0.994984
# 212581                          Tot tax payments Ct LT25K     0.987286
# 212582          Tuition and fees deduction Amt 100KLT200K     0.972336
# 212583          Tuition and fees deduction Amt 100KLT200K     0.961433
# 212584          Tuition and fees deduction Amt 100KLT200K     0.999775
# 212585          Tuition and fees deduction Amt 100KLT200K     0.977295
# 212586          Tuition and fees deduction Amt 100KLT200K     0.960445
# 212587          Tuition and fees deduction Amt 100KLT200K     0.974742
# 212588          Tuition and fees deduction Amt 100KLT200K     0.975727
# 212589          Tuition and fees deduction Amt 100KLT200K     0.951132
# 212590          Tuition and fees deduction Amt 100KLT200K     0.979627
# 212591          Tuition and fees deduction Amt 100KLT200K     0.974817
# 212592            Tuition and fees deduction Amt 25KLT50K     0.976360
# 212593            Tuition and fees deduction Amt 25KLT50K     0.968712
# 212594            Tuition and fees deduction Amt 25KLT50K     0.967226
# 212595            Tuition and fees deduction Amt 25KLT50K     0.996874
# 212596            Tuition and fees deduction Amt 25KLT50K     0.973833
# 212597            Tuition and fees deduction Amt 25KLT50K     0.964774
# 212598            Tuition and fees deduction Amt 25KLT50K     0.968767
# 212599            Tuition and fees deduction Amt 25KLT50K     0.986570
# 212600            Tuition and fees deduction Amt 25KLT50K     0.973448
# 212601            Tuition and fees deduction Amt 25KLT50K     0.984801
# 212602            Tuition and fees deduction Amt 25KLT50K     0.982666
# 212603            Tuition and fees deduction Amt 25KLT50K     0.986726
# 212604            Tuition and fees deduction Amt 25KLT50K     0.970643
# 212605            Tuition and fees deduction Amt 25KLT50K     0.985246
# 212606            Tuition and fees deduction Amt 25KLT50K     0.978811
# 212607            Tuition and fees deduction Amt 50KLT75K     0.985367
# 212608            Tuition and fees deduction Amt 50KLT75K     0.977576
# 212609            Tuition and fees deduction Amt 50KLT75K     0.977022
# 212610            Tuition and fees deduction Amt 50KLT75K     0.999250
# 212611            Tuition and fees deduction Amt 50KLT75K     0.982703
# 212612            Tuition and fees deduction Amt 50KLT75K     0.976630
# 212613            Tuition and fees deduction Amt 50KLT75K     0.978947
# 212614            Tuition and fees deduction Amt 50KLT75K     0.982747
# 212615            Tuition and fees deduction Amt 50KLT75K     0.983706
# 212616            Tuition and fees deduction Amt 50KLT75K     0.974401
# 212617            Tuition and fees deduction Amt 50KLT75K     0.986471
# 212618            Tuition and fees deduction Amt 50KLT75K     0.961997
# 212619            Tuition and fees deduction Amt 50KLT75K     0.975475
# 212620            Tuition and fees deduction Amt 50KLT75K     0.979661
# 212621            Tuition and fees deduction Amt 50KLT75K     0.979285
# 212622            Tuition and fees deduction Amt 50KLT75K     0.974895
# 212623            Tuition and fees deduction Amt 50KLT75K     0.981881
# 212624            Tuition and fees deduction Amt 50KLT75K     0.950695
# 212625           Tuition and fees deduction Amt 75KLT100K     0.992789
# 212626                 Tuition and fees deduction Amt All     0.997273
# 212627                 Tuition and fees deduction Amt All     0.969287
# 212628                 Tuition and fees deduction Amt All     0.975702
# 212629                 Tuition and fees deduction Amt All     0.989239
# 212630                 Tuition and fees deduction Amt All     0.999338
# 212631                 Tuition and fees deduction Amt All     0.996652
# 212632                 Tuition and fees deduction Amt All     0.982200
# 212633                 Tuition and fees deduction Amt All     0.965264
# 212634                 Tuition and fees deduction Amt All     0.980886
# 212635                 Tuition and fees deduction Amt All     0.983000
# 212636                 Tuition and fees deduction Amt All     0.974146
# 212637                 Tuition and fees deduction Amt All     0.982599
# 212638                 Tuition and fees deduction Amt All     0.965150
# 212639                 Tuition and fees deduction Amt All     0.980979
# 212640                 Tuition and fees deduction Amt All     0.984267
# 212641                 Tuition and fees deduction Amt All     0.973421
# 212642               Tuition and fees deduction Amt LT25K     0.958087
# 212643               Tuition and fees deduction Amt LT25K     0.972094
# 212644               Tuition and fees deduction Amt LT25K     0.981122
# 212645               Tuition and fees deduction Amt LT25K     0.995329
# 212646               Tuition and fees deduction Amt LT25K     0.999109
# 212647               Tuition and fees deduction Amt LT25K     0.970053
# 212648               Tuition and fees deduction Amt LT25K     0.959983
# 212649               Tuition and fees deduction Amt LT25K     0.974911
# 212650               Tuition and fees deduction Amt LT25K     0.970425
# 212651               Tuition and fees deduction Amt LT25K     0.968703
# 212652               Tuition and fees deduction Amt LT25K     0.970559
# 212653               Tuition and fees deduction Amt LT25K     0.961004
# 212654               Tuition and fees deduction Amt LT25K     0.975739
# 212655               Tuition and fees deduction Amt LT25K     0.972590
# 212656               Tuition and fees deduction Amt LT25K     0.969904
# 212657           Tuition and fees deduction Ct 100KLT200K     0.974828
# 212658           Tuition and fees deduction Ct 100KLT200K     0.957379
# 212659           Tuition and fees deduction Ct 100KLT200K     0.971793
# 212660           Tuition and fees deduction Ct 100KLT200K     0.974032
# 212661           Tuition and fees deduction Ct 100KLT200K     0.976953
# 212662           Tuition and fees deduction Ct 100KLT200K     0.972967
# 212663             Tuition and fees deduction Ct 25KLT50K     0.976979
# 212664             Tuition and fees deduction Ct 25KLT50K     0.974232
# 212665             Tuition and fees deduction Ct 25KLT50K     0.974681
# 212666             Tuition and fees deduction Ct 25KLT50K     0.983433
# 212667             Tuition and fees deduction Ct 25KLT50K     0.977537
# 212668             Tuition and fees deduction Ct 25KLT50K     0.958471
# 212669             Tuition and fees deduction Ct 25KLT50K     0.983879
# 212670             Tuition and fees deduction Ct 25KLT50K     0.974487
# 212671             Tuition and fees deduction Ct 25KLT50K     0.984152
# 212672             Tuition and fees deduction Ct 25KLT50K     0.975752
# 212673             Tuition and fees deduction Ct 25KLT50K     0.960641
# 212674             Tuition and fees deduction Ct 25KLT50K     0.984314
# 212675             Tuition and fees deduction Ct 25KLT50K     0.970287
# 212676             Tuition and fees deduction Ct 50KLT75K     0.987658
# 212677             Tuition and fees deduction Ct 50KLT75K     0.980605
# 212678             Tuition and fees deduction Ct 50KLT75K     0.982791
# 212679             Tuition and fees deduction Ct 50KLT75K     0.980059
# 212680             Tuition and fees deduction Ct 50KLT75K     0.984964
# 212681             Tuition and fees deduction Ct 50KLT75K     0.980299
# 212682             Tuition and fees deduction Ct 50KLT75K     0.985133
# 212683             Tuition and fees deduction Ct 50KLT75K     0.957101
# 212684             Tuition and fees deduction Ct 50KLT75K     0.980151
# 212685             Tuition and fees deduction Ct 50KLT75K     0.977380
# 212686             Tuition and fees deduction Ct 50KLT75K     0.981287
# 212687             Tuition and fees deduction Ct 50KLT75K     0.980606
# 212688             Tuition and fees deduction Ct 50KLT75K     0.980883
# 212689                  Tuition and fees deduction Ct All     0.995722
# 212690                  Tuition and fees deduction Ct All     0.983594
# 212691                  Tuition and fees deduction Ct All     0.962911
# 212692                  Tuition and fees deduction Ct All     0.981379
# 212693                  Tuition and fees deduction Ct All     0.986904
# 212694                  Tuition and fees deduction Ct All     0.972658
# 212695                  Tuition and fees deduction Ct All     0.984473
# 212696                  Tuition and fees deduction Ct All     0.963110
# 212697                  Tuition and fees deduction Ct All     0.981933
# 212698                  Tuition and fees deduction Ct All     0.987906
# 212699                  Tuition and fees deduction Ct All     0.972015
# 212700                Tuition and fees deduction Ct LT25K     0.970154
# 212701                Tuition and fees deduction Ct LT25K     0.964064
# 212702                Tuition and fees deduction Ct LT25K     0.979615
# 212703                Tuition and fees deduction Ct LT25K     0.973530
# 212704                Tuition and fees deduction Ct LT25K     0.972823
# 212705                Tuition and fees deduction Ct LT25K     0.970695
# 212706                Tuition and fees deduction Ct LT25K     0.965794
# 212707                Tuition and fees deduction Ct LT25K     0.980831
# 212708                Tuition and fees deduction Ct LT25K     0.975775
# 212709                Tuition and fees deduction Ct LT25K     0.974666
# 212710           Unemployment compensation Amt 100KLT200K     0.954481
# 212711           Unemployment compensation Amt 100KLT200K     0.977437
# 212712           Unemployment compensation Amt 100KLT200K     0.990637
# 212713           Unemployment compensation Amt 100KLT200K     0.965856
# 212714           Unemployment compensation Amt 100KLT200K     0.970714
# 212715           Unemployment compensation Amt 100KLT200K     0.999555
# 212716           Unemployment compensation Amt 100KLT200K     0.951173
# 212717           Unemployment compensation Amt 100KLT200K     0.976197
# 212718           Unemployment compensation Amt 100KLT200K     0.989977
# 212719           Unemployment compensation Amt 100KLT200K     0.960381
# 212720           Unemployment compensation Amt 100KLT200K     0.966572
# 212721             Unemployment compensation Amt 25KLT50K     0.990329
# 212722             Unemployment compensation Amt 25KLT50K     0.960878
# 212723             Unemployment compensation Amt 25KLT50K     0.998664
# 212724             Unemployment compensation Amt 25KLT50K     0.992660
# 212725             Unemployment compensation Amt 25KLT50K     0.999271
# 212726             Unemployment compensation Amt 25KLT50K     0.987052
# 212727             Unemployment compensation Amt 25KLT50K     0.963140
# 212728             Unemployment compensation Amt 25KLT50K     0.997648
# 212729             Unemployment compensation Amt 25KLT50K     0.986491
# 212730             Unemployment compensation Amt 50KLT75K     0.983887
# 212731             Unemployment compensation Amt 50KLT75K     0.995394
# 212732             Unemployment compensation Amt 50KLT75K     0.973344
# 212733             Unemployment compensation Amt 50KLT75K     0.975461
# 212734             Unemployment compensation Amt 50KLT75K     0.990579
# 212735             Unemployment compensation Amt 50KLT75K     0.999126
# 212736             Unemployment compensation Amt 50KLT75K     0.985964
# 212737             Unemployment compensation Amt 50KLT75K     0.994768
# 212738             Unemployment compensation Amt 50KLT75K     0.967374
# 212739            Unemployment compensation Amt 75KLT100K     0.971217
# 212740            Unemployment compensation Amt 75KLT100K     0.953575
# 212741            Unemployment compensation Amt 75KLT100K     0.991045
# 212742            Unemployment compensation Amt 75KLT100K     0.959433
# 212743            Unemployment compensation Amt 75KLT100K     0.984046
# 212744            Unemployment compensation Amt 75KLT100K     0.999373
# 212745            Unemployment compensation Amt 75KLT100K     0.967902
# 212746                  Unemployment compensation Amt All     0.988611
# 212747                  Unemployment compensation Amt All     0.962159
# 212748                  Unemployment compensation Amt All     0.998203
# 212749                  Unemployment compensation Amt All     0.992847
# 212750                  Unemployment compensation Amt All     0.973226
# 212751                  Unemployment compensation Amt All     0.999117
# 212752                  Unemployment compensation Amt All     0.982584
# 212753               Unemployment compensation Amt GE200K     0.970319
# 212754               Unemployment compensation Amt GE200K     0.999520
# 212755                Unemployment compensation Amt LT25K     0.993613
# 212756                Unemployment compensation Amt LT25K     0.969767
# 212757                Unemployment compensation Amt LT25K     0.990314
# 212758                Unemployment compensation Amt LT25K     0.998088
# 212759            Unemployment compensation Ct 100KLT200K     0.974941
# 212760            Unemployment compensation Ct 100KLT200K     0.990629
# 212761            Unemployment compensation Ct 100KLT200K     0.957208
# 212762            Unemployment compensation Ct 100KLT200K     0.966240
# 212763              Unemployment compensation Ct 25KLT50K     0.988487
# 212764              Unemployment compensation Ct 25KLT50K     0.962375
# 212765              Unemployment compensation Ct 25KLT50K     0.998577
# 212766              Unemployment compensation Ct 25KLT50K     0.989133
# 212767              Unemployment compensation Ct 50KLT75K     0.986638
# 212768              Unemployment compensation Ct 50KLT75K     0.993440
# 212769              Unemployment compensation Ct 50KLT75K     0.965248
# 212770             Unemployment compensation Ct 75KLT100K     0.970740
# 212771                   Unemployment compensation Ct All     0.986776
# 212772                                      category_cd_E     0.958918
# 212773                                      category_cd_E     1.000000
# 212774                                      category_cd_E     0.958918
# 212775                                      category_cd_I     0.958918
# 212776                                      category_cd_I     1.000000
# 212777  calendar_type_txt_Regular School, Traditional ...     1.000000
# 212778  calendar_type_txt_Regular School, Traditional ...     1.000000
# 212779  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 212780  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 212781                                  sna_pgm_type_cd_X     1.000000
# 212782                                  sna_pgm_type_cd_Y     1.000000
# 212783                                     SPG Grade_A+NG     1.000000
# 212784                                      Category_Cd_E     0.958918
#
# [212785 rows x 3 columns]

# %%
print( 'Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  1009  highly correlated fields.
# ['Reading  SPG Score',
#  'Math SPG Score',
#  'Overall Achievement Score',
#  'Read Score',
#  'Math Score',
#  'EOG/EOCSubjects_CACR_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_CACR_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_CACR_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_CACR_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr4_CACR_Female',
#  'EOGReadingGr4_GLP_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_CACR_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_CACR_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_CACR_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_CACR_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr4_CACR_Male',
#  'EOGReadingGr4_GLP_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_CACR_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_CACR_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_CACR_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_CACR_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_CACR_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_CACR_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_CACR_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_CACR_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_CACR_Black',
#  'EOGSubjects_GLP_Black',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_CACR_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_CACR_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_CACR_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_CACR_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_CACR_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_CACR_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOGMathGr5_GLP_LEP',
#  'EOGScienceGr5&8_CACR_LEP',
#  'EOGScienceGr5&8_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOGSubjects_GLP_LEP',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGSubjects_CACR_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_CACR_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_CACR_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'st_avg_daily_attend_pct',
#  'st_short_susp_per_c_num',
#  'st_books_per_student',
#  'lea_class_teach_num',
#  'lea_not_highqual_class_all_pct',
#  'st_flicensed_teach_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_class_teach_num',
#  'st_1yr_tchr_trnovr_pct',
#  'st_emer_prov_teach_pct',
#  'st_lateral_teach_pct',
#  'st_highqual_class_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'HispanicMalePct',
#  'BlackMalePct',
#  'WhiteMalePct',
#  'MinorityMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'HispanicFemalePct',
#  'BlackFemalePct',
#  'WhiteFemalePct',
#  'MinorityFemalePct',
#  'Assault Rate',
#  '(TCE) prepared returns Ct 50KLT75K',
#  '(TCE) prepared returns Ct All',
#  '(TCE) prepared returns Ct LT25K',
#  '(VITA) prepared returns Ct 75KLT100K',
#  '(VITA) prepared returns Ct All',
#  '(VITA) prepared returns Ct LT25K',
#  'Add Medicare tax Amt 100KLT200K',
#  'Add Medicare tax Amt All',
#  'Add Medicare tax Amt GE200K',
#  'Add Medicare tax Ct 100KLT200K',
#  'Add Medicare tax Ct All',
#  'Add Medicare tax Ct GE200K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Advance premium tax credit Amt 100KLT200K',
#  'Advance premium tax credit Amt 25KLT50K',
#  'Advance premium tax credit Amt 50KLT75K',
#  'Advance premium tax credit Amt 75KLT100K',
#  'Advance premium tax credit Amt All',
#  'Advance premium tax credit Amt LT25K',
#  'Advance premium tax credit Ct 100KLT200K',
#  'Advance premium tax credit Ct 25KLT50K',
#  'Advance premium tax credit Ct 50KLT75K',
#  'Advance premium tax credit Ct 75KLT100K',
#  'Advance premium tax credit Ct All',
#  'Advance premium tax credit Ct LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct 75KLT100K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Alternative minimum tax Ct LT25K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Contributions Amt 100KLT200K',
#  'Contributions Amt 25KLT50K',
#  'Contributions Amt 50KLT75K',
#  'Contributions Amt 75KLT100K',
#  'Contributions Amt All',
#  'Contributions Amt GE200K',
#  'Contributions Amt LT25K',
#  'Contributions Ct 100KLT200K',
#  'Contributions Ct 25KLT50K',
#  'Contributions Ct 50KLT75K',
#  'Contributions Ct 75KLT100K',
#  'Contributions Ct All',
#  'Contributions Ct GE200K',
#  'Contributions Ct LT25K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct 50KLT75K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess advance premium tax credit repayment Amt 100KLT200K',
#  'Excess advance premium tax credit repayment Amt 25KLT50K',
#  'Excess advance premium tax credit repayment Amt 50KLT75K',
#  'Excess advance premium tax credit repayment Amt 75KLT100K',
#  'Excess advance premium tax credit repayment Amt All',
#  'Excess advance premium tax credit repayment Amt LT25K',
#  'Excess advance premium tax credit repayment Ct 100KLT200K',
#  'Excess advance premium tax credit repayment Ct 25KLT50K',
#  'Excess advance premium tax credit repayment Ct 50KLT75K',
#  'Excess advance premium tax credit repayment Ct 75KLT100K',
#  'Excess advance premium tax credit repayment Ct All',
#  'Excess advance premium tax credit repayment Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct 50KLT75K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'Health care individual responsibility payment Amt 100KLT200K',
#  'Health care individual responsibility payment Amt 25KLT50K',
#  'Health care individual responsibility payment Amt 50KLT75K',
#  'Health care individual responsibility payment Amt 75KLT100K',
#  'Health care individual responsibility payment Amt All',
#  'Health care individual responsibility payment Amt LT25K',
#  'Health care individual responsibility payment Ct 100KLT200K',
#  'Health care individual responsibility payment Ct 25KLT50K',
#  'Health care individual responsibility payment Ct 50KLT75K',
#  'Health care individual responsibility payment Ct 75KLT100K',
#  'Health care individual responsibility payment Ct All',
#  'Health care individual responsibility payment Ct LT25K',
#  'IRA payments Amt 100KLT200K',
#  'IRA payments Amt 25KLT50K',
#  'IRA payments Amt 50KLT75K',
#  'IRA payments Amt 75KLT100K',
#  'IRA payments Amt All',
#  'IRA payments Amt GE200K',
#  'IRA payments Amt LT25K',
#  'IRA payments Ct 100KLT200K',
#  'IRA payments Ct 25KLT50K',
#  'IRA payments Ct 50KLT75K',
#  'IRA payments Ct 75KLT100K',
#  'IRA payments Ct All',
#  'IRA payments Ct GE200K',
#  'IRA payments Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Mortgage interest paid Amt 100KLT200K',
#  'Mortgage interest paid Amt 25KLT50K',
#  'Mortgage interest paid Amt 50KLT75K',
#  'Mortgage interest paid Amt 75KLT100K',
#  'Mortgage interest paid Amt All',
#  'Mortgage interest paid Amt GE200K',
#  'Mortgage interest paid Amt LT25K',
#  'Mortgage interest paid Ct 100KLT200K',
#  'Mortgage interest paid Ct 25KLT50K',
#  'Mortgage interest paid Ct 50KLT75K',
#  'Mortgage interest paid Ct 75KLT100K',
#  'Mortgage interest paid Ct All',
#  'Mortgage interest paid Ct GE200K',
#  'Mortgage interest paid Ct LT25K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Net premium tax credit Amt 25KLT50K',
#  'Net premium tax credit Amt All',
#  'Net premium tax credit Amt LT25K',
#  'Net premium tax credit Ct 25KLT50K',
#  'Net premium tax credit Ct 50KLT75K',
#  'Net premium tax credit Ct All',
#  'Net premium tax credit Ct LT25K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  'Number of volunteer prepared returns Tot 100KLT200K',
#  'Number of volunteer prepared returns Tot 25KLT50K',
#  'Number of volunteer prepared returns Tot 75KLT100K',
#  'Number of volunteer prepared returns Tot All',
#  'Number of volunteer prepared returns Tot LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Amt LT25K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Residential energy tax credit Ct LT25K',
#  'Retirement savings contribution credit Amt 25KLT50K',
#  'Retirement savings contribution credit Amt 50KLT75K',
#  'Retirement savings contribution credit Amt All',
#  'Retirement savings contribution credit Amt LT25K',
#  'Retirement savings contribution credit Ct 25KLT50K',
#  'Retirement savings contribution credit Ct 50KLT75K',
#  'Retirement savings contribution credit Ct All',
#  'Retirement savings contribution credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employment health insurance deduction Amt 100KLT200K',
#  'Self-employment health insurance deduction Amt 25KLT50K',
#  'Self-employment health insurance deduction Amt 50KLT75K',
#  'Self-employment health insurance deduction Amt 75KLT100K',
#  'Self-employment health insurance deduction Amt All',
#  'Self-employment health insurance deduction Amt GE200K',
#  'Self-employment health insurance deduction Amt LT25K',
#  'Self-employment health insurance deduction Ct 100KLT200K',
#  'Self-employment health insurance deduction Ct 25KLT50K',
#  'Self-employment health insurance deduction Ct 50KLT75K',
#  'Self-employment health insurance deduction Ct 75KLT100K',
#  'Self-employment health insurance deduction Ct All',
#  'Self-employment health insurance deduction Ct GE200K',
#  'Self-employment health insurance deduction Ct LT25K',
#  'Self-employment retirement plans Amt 100KLT200K',
#  'Self-employment retirement plans Amt 50KLT75K',
#  'Self-employment retirement plans Amt All',
#  'Self-employment retirement plans Amt GE200K',
#  'Self-employment retirement plans Ct 100KLT200K',
#  'Self-employment retirement plans Ct 25KLT50K',
#  'Self-employment retirement plans Ct 50KLT75K',
#  'Self-employment retirement plans Ct 75KLT100K',
#  'Self-employment retirement plans Ct All',
#  'Self-employment retirement plans Ct GE200K',
#  'Self-employment retirement plans Ct LT25K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  'Taxable interest Ct 100KLT200K',
#  'Taxable interest Ct 25KLT50K',
#  'Taxable interest Ct 50KLT75K',
#  'Taxable interest Ct 75KLT100K',
#  'Taxable interest Ct All',
#  'Taxable interest Ct GE200K',
#  'Taxable interest Ct LT25K',
#  'Taxes paid Amt 100KLT200K',
#  'Taxes paid Amt 25KLT50K',
#  'Taxes paid Amt 50KLT75K',
#  'Taxes paid Amt 75KLT100K',
#  'Taxes paid Amt All',
#  'Taxes paid Amt GE200K',
#  'Taxes paid Amt LT25K',
#  'Taxes paid Ct 100KLT200K',
#  'Taxes paid Ct 25KLT50K',
#  'Taxes paid Ct 50KLT75K',
#  'Taxes paid Ct 75KLT100K',
#  'Taxes paid Ct All',
#  'Taxes paid Ct GE200K',
#  'Taxes paid Ct LT25K',
#  'Tot income Amt 100KLT200K',
#  'Tot income Amt 25KLT50K',
#  'Tot income Amt 50KLT75K',
#  'Tot income Amt 75KLT100K',
#  'Tot income Amt All',
#  'Tot income Amt GE200K',
#  'Tot income Amt LT25K',
#  'Tot income Ct 100KLT200K',
#  'Tot income Ct 25KLT50K',
#  'Tot income Ct 50KLT75K',
#  'Tot income Ct 75KLT100K',
#  'Tot income Ct All',
#  'Tot income Ct GE200K',
#  'Tot income Ct LT25K',
#  'Tot itemized deductions Amt 100KLT200K',
#  'Tot itemized deductions Amt 25KLT50K',
#  'Tot itemized deductions Amt 50KLT75K',
#  'Tot itemized deductions Amt 75KLT100K',
#  'Tot itemized deductions Amt All',
#  'Tot itemized deductions Amt GE200K',
#  'Tot itemized deductions Amt LT25K',
#  'Tot itemized deductions Amt of AGI 100KLT200K',
#  'Tot itemized deductions Amt of AGI 25KLT50K',
#  'Tot itemized deductions Amt of AGI 50KLT75K',
#  'Tot itemized deductions Amt of AGI 75KLT100K',
#  'Tot itemized deductions Amt of AGI All',
#  'Tot itemized deductions Amt of AGI GE200K',
#  'Tot itemized deductions Amt of AGI LT25K',
#  'Tot itemized deductions Ct 100KLT200K',
#  'Tot itemized deductions Ct 25KLT50K',
#  'Tot itemized deductions Ct 50KLT75K',
#  'Tot itemized deductions Ct 75KLT100K',
#  'Tot itemized deductions Ct All',
#  'Tot itemized deductions Ct GE200K',
#  'Tot itemized deductions Ct LT25K',
#  'Tot premium tax credit Amt 25KLT50K',
#  'Tot premium tax credit Amt 50KLT75K',
#  'Tot premium tax credit Amt All',
#  'Tot premium tax credit Amt LT25K',
#  'Tot premium tax credit Ct 25KLT50K',
#  'Tot premium tax credit Ct 50KLT75K',
#  'Tot premium tax credit Ct 75KLT100K',
#  'Tot premium tax credit Ct All',
#  'Tot premium tax credit Ct LT25K',
#  'Tot statuory adjustments Amt 100KLT200K',
#  'Tot statuory adjustments Amt 25KLT50K',
#  'Tot statuory adjustments Amt 50KLT75K',
#  'Tot statuory adjustments Amt 75KLT100K',
#  'Tot statuory adjustments Amt All',
#  'Tot statuory adjustments Amt GE200K',
#  'Tot statuory adjustments Amt LT25K',
#  'Tot statuory adjustments Ct 100KLT200K',
#  'Tot statuory adjustments Ct 25KLT50K',
#  'Tot statuory adjustments Ct 50KLT75K',
#  'Tot statuory adjustments Ct 75KLT100K',
#  'Tot statuory adjustments Ct All',
#  'Tot statuory adjustments Ct GE200K',
#  'Tot statuory adjustments Ct LT25K',
#  'Tot tax credits Amt 100KLT200K',
#  'Tot tax credits Amt 25KLT50K',
#  'Tot tax credits Amt 50KLT75K',
#  'Tot tax credits Amt 75KLT100K',
#  'Tot tax credits Amt All',
#  'Tot tax credits Amt GE200K',
#  'Tot tax credits Amt LT25K',
#  'Tot tax credits Ct 100KLT200K',
#  'Tot tax credits Ct 25KLT50K',
#  'Tot tax credits Ct 50KLT75K',
#  'Tot tax credits Ct 75KLT100K',
#  'Tot tax credits Ct All',
#  'Tot tax credits Ct GE200K',
#  'Tot tax credits Ct LT25K',
#  'Tot tax liability Amt 100KLT200K',
#  'Tot tax liability Amt 25KLT50K',
#  'Tot tax liability Amt 50KLT75K',
#  'Tot tax liability Amt 75KLT100K',
#  'Tot tax liability Amt All',
#  'Tot tax liability Amt GE200K',
#  'Tot tax liability Amt LT25K',
#  'Tot tax liability Ct 100KLT200K',
#  'Tot tax liability Ct 25KLT50K',
#  'Tot tax liability Ct 50KLT75K',
#  'Tot tax liability Ct 75KLT100K',
#  'Tot tax liability Ct All',
#  'Tot tax liability Ct GE200K',
#  'Tot tax liability Ct LT25K',
#  'Tot tax payments Amt 100KLT200K',
#  'Tot tax payments Amt 25KLT50K',
#  'Tot tax payments Amt 50KLT75K',
#  'Tot tax payments Amt 75KLT100K',
#  'Tot tax payments Amt All',
#  'Tot tax payments Amt GE200K',
#  'Tot tax payments Amt LT25K',
#  'Tot tax payments Ct 100KLT200K',
#  'Tot tax payments Ct 25KLT50K',
#  'Tot tax payments Ct 50KLT75K',
#  'Tot tax payments Ct 75KLT100K',
#  'Tot tax payments Ct All',
#  'Tot tax payments Ct GE200K',
#  'Tot tax payments Ct LT25K',
#  'Tuition and fees deduction Amt 100KLT200K',
#  'Tuition and fees deduction Amt 25KLT50K',
#  'Tuition and fees deduction Amt 50KLT75K',
#  'Tuition and fees deduction Amt All',
#  'Tuition and fees deduction Amt LT25K',
#  'Tuition and fees deduction Ct 100KLT200K',
#  'Tuition and fees deduction Ct 25KLT50K',
#  'Tuition and fees deduction Ct 50KLT75K',
#  'Tuition and fees deduction Ct 75KLT100K',
#  'Tuition and fees deduction Ct All',
#  'Tuition and fees deduction Ct LT25K',
#  'Unemployment compensation Amt 100KLT200K',
#  'Unemployment compensation Amt 25KLT50K',
#  'Unemployment compensation Amt 50KLT75K',
#  'Unemployment compensation Amt 75KLT100K',
#  'Unemployment compensation Amt All',
#  'Unemployment compensation Amt GE200K',
#  'Unemployment compensation Amt LT25K',
#  'Unemployment compensation Ct 100KLT200K',
#  'Unemployment compensation Ct 25KLT50K',
#  'Unemployment compensation Ct 50KLT75K',
#  'Unemployment compensation Ct 75KLT100K',
#  'Unemployment compensation Ct All',
#  'Unemployment compensation Ct GE200K',
#  'Unemployment compensation Ct LT25K',
#  ...]

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Columns: 1403 entries, student_num to lea_avg_age_media_collection_2010
# dtypes: float64(1343), uint8(60)
# memory usage: 13.4 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Columns: 394 entries, student_num to lea_avg_age_media_collection_2010
# dtypes: float64(343), uint8(51)
# memory usage: 3.5 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 1297
# Data columns (total 395 columns):
# student_num                                                                        float64
# lea_avg_student_num                                                                float64
# st_avg_student_num                                                                 float64
# 00_Size                                                                            float64
# 01_Size                                                                            float64
# 02_Size                                                                            float64
# 03_Size                                                                            float64
# 04_Size                                                                            float64
# 05_Size                                                                            float64
# lea_total_expense_num                                                              float64
# lea_salary_expense_pct                                                             float64
# lea_benefits_expense_pct                                                           float64
# lea_services_expense_pct                                                           float64
# lea_supplies_expense_pct                                                           float64
# lea_instruct_equip_exp_pct                                                         float64
# lea_federal_perpupil_num                                                           float64
# lea_local_perpupil_num                                                             float64
# lea_state_perpupil_num                                                             float64
# SPG Score                                                                          float64
# EVAAS Growth Score                                                                 float64
# Science Score                                                                      float64
# EOGGr3_CACR_All                                                                    float64
# EOGGr4_CACR_All                                                                    float64
# EOGGr5_CACR_All                                                                    float64
# EOGMathGr3_CACR_Female                                                             float64
# EOGMathGr3_GLP_Female                                                              float64
# EOGMathGr5_CACR_Female                                                             float64
# EOGReadingGr3_CACR_Female                                                          float64
# EOGReadingGr3_GLP_Female                                                           float64
# EOGReadingGr5_CACR_Female                                                          float64
# EOGScienceGr5_CACR_Female                                                          float64
# EOGReadingGr5_CACR_Male                                                            float64
# EOG/EOCSubjects_CACR_AmericanIndian                                                float64
# EOGGr3_CACR_AmericanIndian                                                         float64
# EOGGr4_CACR_AmericanIndian                                                         float64
# EOGGr5_CACR_AmericanIndian                                                         float64
# EOGMathGr3_CACR_AmericanIndian                                                     float64
# EOGMathGr3-8_CACR_AmericanIndian                                                   float64
# EOGMathGr4_CACR_AmericanIndian                                                     float64
# EOGMathGr5_CACR_AmericanIndian                                                     float64
# EOGReadingGr3_CACR_AmericanIndian                                                  float64
# EOGReadingGr3-8_CACR_AmericanIndian                                                float64
# EOGReadingGr5_CACR_AmericanIndian                                                  float64
# EOGReadingGr5_GLP_AmericanIndian                                                   float64
# EOGScienceGr5_CACR_AmericanIndian                                                  float64
# EOG/EOCSubjects_CACR_Asian                                                         float64
# EOGGr3_CACR_Asian                                                                  float64
# EOGGr4_CACR_Asian                                                                  float64
# EOGGr5_CACR_Asian                                                                  float64
# EOGMathGr3_CACR_Asian                                                              float64
# EOGMathGr3-8_CACR_Asian                                                            float64
# EOGMathGr4_CACR_Asian                                                              float64
# EOGMathGr5_CACR_Asian                                                              float64
# EOG/EOCSubjects_CACR_Black                                                         float64
# EOGGr3_CACR_Black                                                                  float64
# EOGGr3_GLP_Black                                                                   float64
# EOGGr4_CACR_Black                                                                  float64
# EOGGr5_CACR_Black                                                                  float64
# EOGMathGr3_CACR_Black                                                              float64
# EOGMathGr3_GLP_Black                                                               float64
# EOGMathGr3-8_CACR_Black                                                            float64
# EOGMathGr4_CACR_Black                                                              float64
# EOGMathGr5_CACR_Black                                                              float64
# EOGReadingGr3_CACR_Black                                                           float64
# EOGReadingGr3_GLP_Black                                                            float64
# EOGReadingGr3-8_CACR_Black                                                         float64
# EOGReadingGr3-8_GLP_Black                                                          float64
# EOGReadingGr4_CACR_Black                                                           float64
# EOGReadingGr4_GLP_Black                                                            float64
# EOGReadingGr5_CACR_Black                                                           float64
# EOGReadingGr5_GLP_Black                                                            float64
# EOGScienceGr5_CACR_Black                                                           float64
# EOG/EOCSubjects_CACR_Hispanic                                                      float64
# EOG/EOCSubjects_GLP_Hispanic                                                       float64
# EOGGr3_CACR_Hispanic                                                               float64
# EOGGr3_GLP_Hispanic                                                                float64
# EOGGr4_CACR_Hispanic                                                               float64
# EOGGr5_CACR_Hispanic                                                               float64
# EOGMathGr3_CACR_Hispanic                                                           float64
# EOGMathGr3_GLP_Hispanic                                                            float64
# EOGMathGr3-8_CACR_Hispanic                                                         float64
# EOGMathGr3-8_GLP_Hispanic                                                          float64
# EOGMathGr4_CACR_Hispanic                                                           float64
# EOGMathGr5_CACR_Hispanic                                                           float64
# EOGReadingGr3_CACR_Hispanic                                                        float64
# EOGReadingGr3_GLP_Hispanic                                                         float64
# EOGReadingGr3-8_CACR_Hispanic                                                      float64
# EOGReadingGr3-8_GLP_Hispanic                                                       float64
# EOGReadingGr4_CACR_Hispanic                                                        float64
# EOGReadingGr4_GLP_Hispanic                                                         float64
# EOGReadingGr5_CACR_Hispanic                                                        float64
# EOGReadingGr5_GLP_Hispanic                                                         float64
# EOGScienceGr5_CACR_Hispanic                                                        float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                                                float64
# EOGGr3_CACR_TwoorMoreRaces                                                         float64
# EOGGr4_CACR_TwoorMoreRaces                                                         float64
# EOGGr5_CACR_TwoorMoreRaces                                                         float64
# EOGMathGr3_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                                                   float64
# EOGMathGr4_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr5_CACR_TwoorMoreRaces                                                     float64
# EOGReadingGr3_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                                                float64
# EOGReadingGr3-8_GLP_TwoorMoreRaces                                                 float64
# EOGReadingGr4_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5_CACR_TwoorMoreRaces                                                  float64
# EOG/EOCSubjects_CACR_White                                                         float64
# EOGGr3_CACR_White                                                                  float64
# EOGGr4_CACR_White                                                                  float64
# EOGGr5_CACR_White                                                                  float64
# EOGMathGr3_CACR_White                                                              float64
# EOGMathGr3-8_CACR_White                                                            float64
# EOGMathGr4_CACR_White                                                              float64
# EOGMathGr5_CACR_White                                                              float64
# EOGReadingGr3_CACR_White                                                           float64
# EOGReadingGr3-8_CACR_White                                                         float64
# EOGReadingGr4_CACR_White                                                           float64
# EOGReadingGr5_CACR_White                                                           float64
# EOGScienceGr5_CACR_White                                                           float64
# EOG/EOCSubjects_CACR_EDS                                                           float64
# EOGGr3_CACR_EDS                                                                    float64
# EOGGr4_CACR_EDS                                                                    float64
# EOGGr5_CACR_EDS                                                                    float64
# EOGMathGr3_CACR_EDS                                                                float64
# EOGMathGr3_GLP_EDS                                                                 float64
# EOGMathGr3-8_CACR_EDS                                                              float64
# EOGMathGr4_CACR_EDS                                                                float64
# EOGMathGr5_CACR_EDS                                                                float64
# EOGReadingGr3_CACR_EDS                                                             float64
# EOGReadingGr3_GLP_EDS                                                              float64
# EOGReadingGr3-8_CACR_EDS                                                           float64
# EOGReadingGr4_CACR_EDS                                                             float64
# EOGReadingGr4_GLP_EDS                                                              float64
# EOGReadingGr5_CACR_EDS                                                             float64
# EOGReadingGr5_GLP_EDS                                                              float64
# EOGScienceGr5_CACR_EDS                                                             float64
# EOG/EOCSubjects_CACR_LEP                                                           float64
# EOG/EOCSubjects_GLP_LEP                                                            float64
# EOGGr3_CACR_LEP                                                                    float64
# EOGGr3_GLP_LEP                                                                     float64
# EOGGr4_CACR_LEP                                                                    float64
# EOGGr4_GLP_LEP                                                                     float64
# EOGGr5_CACR_LEP                                                                    float64
# EOGGr5_GLP_LEP                                                                     float64
# EOGMathGr3_CACR_LEP                                                                float64
# EOGMathGr3_GLP_LEP                                                                 float64
# EOGMathGr3-8_CACR_LEP                                                              float64
# EOGMathGr3-8_GLP_LEP                                                               float64
# EOGMathGr4_CACR_LEP                                                                float64
# EOGMathGr4_GLP_LEP                                                                 float64
# EOGMathGr5_CACR_LEP                                                                float64
# EOGReadingGr3_CACR_LEP                                                             float64
# EOGReadingGr3_GLP_LEP                                                              float64
# EOGReadingGr3-8_CACR_LEP                                                           float64
# EOGReadingGr3-8_GLP_LEP                                                            float64
# EOGReadingGr4_CACR_LEP                                                             float64
# EOGReadingGr4_GLP_LEP                                                              float64
# EOGReadingGr5_CACR_LEP                                                             float64
# EOGReadingGr5_GLP_LEP                                                              float64
# EOGScienceGr5_CACR_LEP                                                             float64
# EOGScienceGr5_GLP_LEP                                                              float64
# EOG/EOCSubjects_CACR_SWD                                                           float64
# EOGGr3_CACR_SWD                                                                    float64
# EOGGr3_GLP_SWD                                                                     float64
# EOGGr4_CACR_SWD                                                                    float64
# EOGGr4_GLP_SWD                                                                     float64
# EOGGr5_CACR_SWD                                                                    float64
# EOGGr5_GLP_SWD                                                                     float64
# EOGMathGr3_CACR_SWD                                                                float64
# EOGMathGr3_GLP_SWD                                                                 float64
# EOGMathGr3-8_CACR_SWD                                                              float64
# EOGMathGr3-8_GLP_SWD                                                               float64
# EOGMathGr4_CACR_SWD                                                                float64
# EOGMathGr4_GLP_SWD                                                                 float64
# EOGMathGr5_CACR_SWD                                                                float64
# EOGMathGr5_GLP_SWD                                                                 float64
# EOGReadingGr3_CACR_SWD                                                             float64
# EOGReadingGr3_GLP_SWD                                                              float64
# EOGReadingGr3-8_CACR_SWD                                                           float64
# EOGReadingGr3-8_GLP_SWD                                                            float64
# EOGReadingGr4_CACR_SWD                                                             float64
# EOGReadingGr4_GLP_SWD                                                              float64
# EOGReadingGr5_CACR_SWD                                                             float64
# EOGReadingGr5_GLP_SWD                                                              float64
# EOGScienceGr5_CACR_SWD                                                             float64
# EOGScienceGr5_GLP_SWD                                                              float64
# EOGScienceGr5&8_CACR_SWD                                                           float64
# EOGScienceGr5&8_GLP_SWD                                                            float64
# EOG/EOCSubjects_CACR_AIG                                                           float64
# EOGGr3_CACR_AIG                                                                    float64
# EOGGr4_CACR_AIG                                                                    float64
# EOGGr5_CACR_AIG                                                                    float64
# EOGMathGr3_CACR_AIG                                                                float64
# EOGMathGr3-8_CACR_AIG                                                              float64
# EOGMathGr4_CACR_AIG                                                                float64
# EOGMathGr5_CACR_AIG                                                                float64
# pct_GCE_ALL                                                                        float64
# pct_GCE_SWD                                                                        float64
# pct_PASSED_LAA                                                                     float64
# pct_PROMOTED                                                                       float64
# pct_RETAINED                                                                       float64
# MathGr3-8_pTarget_PctMet                                                           float64
# ReadingGr3-8_pTarget_PctMet                                                        float64
# SciGr5&8_pTarget_PctMet                                                            float64
# TotalTargets_pTarget_PctMet                                                        float64
# lea_sat_avg_score_num                                                              float64
# lea_sat_participation_pct                                                          float64
# lea_ap_participation_pct                                                           float64
# lea_ap_pct_3_or_above                                                              float64
# lea_ib_pct_4_or_above                                                              float64
# avg_daily_attend_pct                                                               float64
# crime_per_c_num                                                                    float64
# short_susp_per_c_num                                                               float64
# long_susp_per_c_num                                                                float64
# stud_internet_comp_num                                                             float64
# lea_avg_daily_attend_pct                                                           float64
# lea_crime_per_c_num                                                                float64
# lea_short_susp_per_c_num                                                           float64
# lea_long_susp_per_c_num                                                            float64
# lea_stud_internet_comp_num                                                         float64
# st_crime_per_c_num                                                                 float64
# digital_media_pct                                                                  float64
# books_per_student                                                                  float64
# lea_books_per_student                                                              float64
# st_avg_age_media_collection                                                        float64
# flicensed_teach_pct                                                                float64
# tchyrs_0thru3_pct                                                                  float64
# tchyrs_4thru10_pct                                                                 float64
# tchyrs_11plus_pct                                                                  float64
# class_teach_num                                                                    float64
# nbpts_num                                                                          float64
# advance_dgr_pct                                                                    float64
# _1yr_tchr_trnovr_pct                                                               float64
# highqual_class_pct                                                                 float64
# lea_flicensed_teach_pct                                                            float64
# lea_tchyrs_0thru3_pct                                                              float64
# lea_tchyrs_4thru10_pct                                                             float64
# lea_tchyrs_11plus_pct                                                              float64
# lea_nbpts_num                                                                      float64
# lea_advance_dgr_pct                                                                float64
# lea_1yr_tchr_trnovr_pct                                                            float64
# lea_emer_prov_teach_pct                                                            float64
# lea_lateral_teach_pct                                                              float64
# lea_highqual_class_pct                                                             float64
# lea_highqual_class_hp_pct                                                          float64
# lea_highqual_class_lp_pct                                                          float64
# lea_highqual_class_all_pct                                                         float64
# lea_not_highqual_class_hp_pct                                                      float64
# lea_not_highqual_class_lp_pct                                                      float64
# st_tchyrs_0thru3_pct                                                               float64
# st_tchyrs_11plus_pct                                                               float64
# st_nbpts_num                                                                       float64
# st_advance_dgr_pct                                                                 float64
# 0-3 Years_LEA_Exp_Pct_Prin                                                         float64
# 10+ Years_LEA_Exp_Pct_Prin                                                         float64
# 4-10 Years_LEA_Exp_Pct_Prin                                                        float64
# Accomplished_TCHR_Standard 1_Pct                                                   float64
# Accomplished_TCHR_Standard 2_Pct                                                   float64
# Accomplished_TCHR_Standard 3_Pct                                                   float64
# Accomplished_TCHR_Standard 4_Pct                                                   float64
# Accomplished_TCHR_Standard 5_Pct                                                   float64
# Developing_TCHR_Standard 1_Pct                                                     float64
# Developing_TCHR_Standard 2_Pct                                                     float64
# Developing_TCHR_Standard 3_Pct                                                     float64
# Developing_TCHR_Standard 4_Pct                                                     float64
# Developing_TCHR_Standard 5_Pct                                                     float64
# Distinguished_TCHR_Standard 1_Pct                                                  float64
# Distinguished_TCHR_Standard 2_Pct                                                  float64
# Distinguished_TCHR_Standard 3_Pct                                                  float64
# Distinguished_TCHR_Standard 4_Pct                                                  float64
# Distinguished_TCHR_Standard 5_Pct                                                  float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct                                  float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct                                        float64
# Meets Expected Growth_TCHR_Standard 6_Pct                                          float64
# Not Demostrated_TCHR_Standard 1_Pct                                                float64
# Not Demostrated_TCHR_Standard 2_Pct                                                float64
# Not Demostrated_TCHR_Standard 3_Pct                                                float64
# Not Demostrated_TCHR_Standard 4_Pct                                                float64
# Not Demostrated_TCHR_Standard 5_Pct                                                float64
# Proficient_TCHR_Standard 1_Pct                                                     float64
# Proficient_TCHR_Standard 2_Pct                                                     float64
# Proficient_TCHR_Standard 3_Pct                                                     float64
# Proficient_TCHR_Standard 4_Pct                                                     float64
# Proficient_TCHR_Standard 5_Pct                                                     float64
# IndianPct                                                                          float64
# AsianPct                                                                           float64
# HispanicPct                                                                        float64
# BlackPct                                                                           float64
# WhitePct                                                                           float64
# PacificIslandPct                                                                   float64
# TwoOrMorePct                                                                       float64
# PacificIslandMalePct                                                               float64
# TwoOrMoreMalePct                                                                   float64
# PacificIslandFemalePct                                                             float64
# TwoOrMoreFemalePct                                                                 float64
# Year                                                                               float64
# Violent Rate                                                                       float64
# Murder Rate                                                                        float64
# Rape Rate                                                                          float64
# Robbery Rate                                                                       float64
# MVT Rate                                                                           float64
# Arson Rate                                                                         float64
# (TCE) prepared returns Ct 25KLT50K                                                 float64
# (TCE) prepared returns Ct 75KLT100K                                                float64
# (VITA) prepared returns Ct 100KLT200K                                              float64
# (VITA) prepared returns Ct 25KLT50K                                                float64
# (VITA) prepared returns Ct 50KLT75K                                                float64
# Add child tax credit Amt 25KLT50K                                                  float64
# Add child tax credit Amt 75KLT100K                                                 float64
# Alternative minimum tax Amt 25KLT50K                                               float64
# Alternative minimum tax Amt 50KLT75K                                               float64
# Alternative minimum tax Amt 75KLT100K                                              float64
# Alternative minimum tax Amt LT25K                                                  float64
# Alternative minimum tax Ct 50KLT75K                                                float64
# Domestic production activities deduction Amt 100KLT200K                            float64
# Domestic production activities deduction Amt 25KLT50K                              float64
# Domestic production activities deduction Amt 50KLT75K                              float64
# Domestic production activities deduction Amt 75KLT100K                             float64
# Domestic production activities deduction Amt LT25K                                 float64
# Domestic production activities deduction Ct 100KLT200K                             float64
# Domestic production activities deduction Ct 25KLT50K                               float64
# Domestic production activities deduction Ct 50KLT75K                               float64
# Domestic production activities deduction Ct 75KLT100K                              float64
# Domestic production activities deduction Ct LT25K                                  float64
# Earned income credit Amt 50KLT75K                                                  float64
# Excess earned income credit (refundable) Amt 50KLT75K                              float64
# Net premium tax credit Amt 50KLT75K                                                float64
# Number of farm returns 100KLT200K                                                  float64
# Number of farm returns 25KLT50K                                                    float64
# Number of farm returns 50KLT75K                                                    float64
# Number of farm returns 75KLT100K                                                   float64
# Number of farm returns All                                                         float64
# Number of farm returns GE200K                                                      float64
# Number of farm returns LT25K                                                       float64
# Number of volunteer prepared returns Tot 50KLT75K                                  float64
# Residential energy tax credit Amt LT25K                                            float64
# Self-employment retirement plans Amt 25KLT50K                                      float64
# Self-employment retirement plans Amt 75KLT100K                                     float64
# Self-employment retirement plans Amt LT25K                                         float64
# State and local general sales taxes Amt GE200K                                     float64
# Tot premium tax credit Amt 75KLT100K                                               float64
# Tuition and fees deduction Amt 75KLT100K                                           float64
# calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar    uint8
# calendar_type_txt_Regular School, Year-Round Calendar                              uint8
# esea_status_P                                                                      uint8
# esea_status_R                                                                      uint8
# esea_status_RF                                                                     uint8
# Grad_project_status_Y                                                              uint8
# SBE District_Northeast                                                             uint8
# SBE District_Northwest                                                             uint8
# SBE District_Piedmont-Triad                                                        uint8
# SBE District_Sandhills                                                             uint8
# SBE District_Southeast                                                             uint8
# SBE District_Southwest                                                             uint8
# SBE District_Western                                                               uint8
# SPG Grade_A+NG                                                                     uint8
# SPG Grade_B                                                                        uint8
# SPG Grade_C                                                                        uint8
# SPG Grade_D                                                                        uint8
# SPG Grade_F                                                                        uint8
# SPG Grade_I                                                                        uint8
# Reading SPG Grade_B                                                                uint8
# Reading SPG Grade_C                                                                uint8
# Reading SPG Grade_D                                                                uint8
# Reading SPG Grade_F                                                                uint8
# Math SPG Grade_B                                                                   uint8
# Math SPG Grade_C                                                                   uint8
# Math SPG Grade_D                                                                   uint8
# Math SPG Grade_F                                                                   uint8
# EVAAS Growth Status_Met                                                            uint8
# EVAAS Growth Status_NotMet                                                         uint8
# State Gap Compared_Insufficient Data                                               uint8
# esea_attendance_Met                                                                uint8
# Byod_YES                                                                           uint8
# _1_to_1_access_YES                                                                 uint8
# lea_avg_age_media_collection_1936                                                  uint8
# lea_avg_age_media_collection_1988                                                  uint8
# lea_avg_age_media_collection_1991                                                  uint8
# lea_avg_age_media_collection_1993                                                  uint8
# lea_avg_age_media_collection_1994                                                  uint8
# lea_avg_age_media_collection_1995                                                  uint8
# lea_avg_age_media_collection_1996                                                  uint8
# lea_avg_age_media_collection_1997                                                  uint8
# lea_avg_age_media_collection_1998                                                  uint8
# lea_avg_age_media_collection_1999                                                  uint8
# lea_avg_age_media_collection_2000                                                  uint8
# lea_avg_age_media_collection_2001                                                  uint8
# lea_avg_age_media_collection_2002                                                  uint8
# lea_avg_age_media_collection_2003                                                  uint8
# lea_avg_age_media_collection_2005                                                  uint8
# lea_avg_age_media_collection_2006                                                  uint8
# lea_avg_age_media_collection_2007                                                  uint8
# lea_avg_age_media_collection_2010                                                  uint8
# unit_code                                                                          object
# dtypes: float64(343), object(1), uint8(51)
# memory usage: 3.5+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.3
# Pandas Version: 0.24.2

# %%
print( 'Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2015/Machine Learning Datasets/PublicElementarySchools2015_ML.csv
