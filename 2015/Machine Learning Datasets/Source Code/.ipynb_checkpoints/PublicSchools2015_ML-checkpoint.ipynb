# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2015

#Location where copies of the raw data files will be read in from csv files.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
inputFileName = 'PublicSchools' + str(schoolYear)
#inputFileName = 'PublicHighSchools' + str(schoolYear)
#inputFileName = 'PublicMiddleSchools' + str(schoolYear)
#inputFileName = 'PublicElementarySchools' + str(schoolYear)

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
#Rename Lea_Name to District Name
schoolData.rename(columns={'Lea_Name': 'District Name'}, inplace=True)
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2585 entries, 0 to 2584
# Columns: 2143 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(2090), int64(3), object(50)
# memory usage: 42.3+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 2143 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(2090), int64(3), object(50)
# memory usage: 39.8+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#schoolData.info(verbose=True)

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print ('Rows Updated / Imputed: ', rowsUpdated )
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1954 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1908), object(46)
# memory usage: 36.3+ MB
#
# Columns Deleted:  189

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print( '\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1952 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1908), object(44)
# memory usage: 36.2+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1952 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1908), object(44)
# memory usage: 36.2+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print( "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  44
# Continuous Columns:  1908
# Columns Accounted for:  1952

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1454 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1410), object(44)
# memory usage: 27.0+ MB
#
# Columns Deleted:  498

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1434 entries, closed_ind to Attrtion_Reason_OtherReasons
# dtypes: float64(1410), object(24)
# memory usage: 26.6+ MB
#
# Columns Deleted:  20

# %%
sD_nominal.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Data columns (total 44 columns):
# vphone_ad                                   2432 non-null object
# street_ad                                   2432 non-null object
# scity_ad                                    2432 non-null object
# szip_ad                                     2432 non-null object
# category_cd                                 2432 non-null object
# url_ad                                      2358 non-null object
# grade_range_cd                              2432 non-null object
# calendar_type_txt                           2429 non-null object
# sna_pgm_type_cd                             2429 non-null object
# cover_letter_ad                             1784 non-null object
# school_type_txt                             2429 non-null object
# calendar_only_txt                           2426 non-null object
# title1_type_cd                              1322 non-null object
# clp_ind                                     117 non-null object
# focus_clp_ind                               90 non-null object
# summer_program_ind                          411 non-null object
# asm_no_spg_ind                              93 non-null object
# no_data_spg_ind                             36 non-null object
# District Name                               2432 non-null object
# esea_status                                 243 non-null object
# Grad_project_status                         580 non-null object
# url                                         1411 non-null object
# LEA Name                                    2432 non-null object
# School Name                                 2432 non-null object
# SBE District                                2432 non-null object
# SPG Grade                                   2339 non-null object
# Reading SPG Grade                           1828 non-null object
# Math SPG Grade                              1828 non-null object
# EVAAS Growth Status                         2291 non-null object
# State Gap Compared                          139 non-null object
# Category_Cd                                 2432 non-null object
# esea_attendance                             2432 non-null object
# Byod                                        2398 non-null object
# grades_BYOD                                 573 non-null object
# avg_age_media_collection                    2419 non-null object
# _1_to_1_access                              2401 non-null object
# grades_1_to_1_access                        658 non-null object
# lea_avg_age_media_collection                2419 non-null object
# County                                      2432 non-null object
# Attrtion_Reason_RemainedinEducationPerct    2259 non-null object
# Attrtion_Reason_PersonalPerct               2259 non-null object
# Attrtion_Reason_InitiatedPerct              2259 non-null object
# Attrtion_Reason_BeyondControlPerct          2259 non-null object
# Attrtion_Reason_OtherReasonsPerct           2259 non-null object
# dtypes: object(44)
# memory usage: 855.0+ KB

# %%
sD_nominal.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Data columns (total 44 columns):
# vphone_ad                                   2432 non-null object
# street_ad                                   2432 non-null object
# scity_ad                                    2432 non-null object
# szip_ad                                     2432 non-null object
# category_cd                                 2432 non-null object
# url_ad                                      2358 non-null object
# grade_range_cd                              2432 non-null object
# calendar_type_txt                           2429 non-null object
# sna_pgm_type_cd                             2429 non-null object
# cover_letter_ad                             1784 non-null object
# school_type_txt                             2429 non-null object
# calendar_only_txt                           2426 non-null object
# title1_type_cd                              1322 non-null object
# clp_ind                                     117 non-null object
# focus_clp_ind                               90 non-null object
# summer_program_ind                          411 non-null object
# asm_no_spg_ind                              93 non-null object
# no_data_spg_ind                             36 non-null object
# District Name                               2432 non-null object
# esea_status                                 243 non-null object
# Grad_project_status                         580 non-null object
# url                                         1411 non-null object
# LEA Name                                    2432 non-null object
# School Name                                 2432 non-null object
# SBE District                                2432 non-null object
# SPG Grade                                   2339 non-null object
# Reading SPG Grade                           1828 non-null object
# Math SPG Grade                              1828 non-null object
# EVAAS Growth Status                         2291 non-null object
# State Gap Compared                          139 non-null object
# Category_Cd                                 2432 non-null object
# esea_attendance                             2432 non-null object
# Byod                                        2398 non-null object
# grades_BYOD                                 573 non-null object
# avg_age_media_collection                    2419 non-null object
# _1_to_1_access                              2401 non-null object
# grades_1_to_1_access                        658 non-null object
# lea_avg_age_media_collection                2419 non-null object
# County                                      2432 non-null object
# Attrtion_Reason_RemainedinEducationPerct    2259 non-null object
# Attrtion_Reason_PersonalPerct               2259 non-null object
# Attrtion_Reason_InitiatedPerct              2259 non-null object
# Attrtion_Reason_BeyondControlPerct          2259 non-null object
# Attrtion_Reason_OtherReasonsPerct           2259 non-null object
# dtypes: object(44)
# memory usage: 855.0+ KB

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print ('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print( '\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  24
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1490 entries, closed_ind to lea_avg_age_media_collection_2010
# dtypes: float64(1410), uint8(80)
# memory usage: 26.4 MB
#
# New Columns Created Via One-Hot Encoding:  56

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                           Variable Name  Number Missing Values
# 4                                               00_Size                   1179
# 5                                               01_Size                   1195
# 6                                               02_Size                   1195
# 7                                               03_Size                   1194
# 8                                               04_Size                   1168
# 9                                               05_Size                   1192
# 10                                          Math I_Size                   1397
# 20                                            SPG Score                    129
# 21                                   Reading  SPG Score                    604
# 22                                       Math SPG Score                    604
# 23                                   EVAAS Growth Score                    141
# 24                            Overall Achievement Score                    129
# 25                                           Read Score                    604
# 26                                           Math Score                    604
# 27                                        Science Score                    693
# 28                                         Math I Score                   1447
# 29                                    EOCMathI_CACR_All                   1377
# 30                                     EOCMathI_GLP_All                   1377
# 31                                 EOCSubjects_CACR_All                   1366
# 32                                  EOCSubjects_GLP_All                   1366
# 33                             EOG/EOCSubjects_CACR_All                     45
# 34                              EOG/EOCSubjects_GLP_All                     45
# 35                                      EOGGr3_CACR_All                   1101
# 36                                       EOGGr3_GLP_All                   1101
# 37                                      EOGGr4_CACR_All                   1106
# 38                                       EOGGr4_GLP_All                   1106
# 39                                      EOGGr5_CACR_All                   1122
# 40                                       EOGGr5_GLP_All                   1122
# 41                                  EOGMathGr3_CACR_All                   1105
# 42                                   EOGMathGr3_GLP_All                   1105
# 43                                EOGMathGr3-8_CACR_All                    535
# 44                                 EOGMathGr3-8_GLP_All                    535
# 45                                  EOGMathGr4_CACR_All                   1112
# 46                                   EOGMathGr4_GLP_All                   1112
# 47                                  EOGMathGr5_CACR_All                   1138
# 48                                   EOGMathGr5_GLP_All                   1138
# 49                               EOGReadingGr3_CACR_All                   1105
# 50                                EOGReadingGr3_GLP_All                   1105
# 51                             EOGReadingGr3-8_CACR_All                    535
# 52                              EOGReadingGr3-8_GLP_All                    535
# 53                               EOGReadingGr4_CACR_All                   1112
# 54                                EOGReadingGr4_GLP_All                   1112
# 55                               EOGReadingGr5_CACR_All                   1138
# 56                                EOGReadingGr5_GLP_All                   1138
# 57                               EOGScienceGr5_CACR_All                   1138
# 58                                EOGScienceGr5_GLP_All                   1138
# 59                             EOGScienceGr5&8_CACR_All                    631
# 60                              EOGScienceGr5&8_GLP_All                    631
# 61                                 EOGSubjects_CACR_All                    532
# 62                                  EOGSubjects_GLP_All                    532
# 63                                 EOCMathI_CACR_Female                   1377
# 64                                  EOCMathI_GLP_Female                   1377
# 65                              EOCSubjects_CACR_Female                   1366
# 66                               EOCSubjects_GLP_Female                   1366
# 67                          EOG/EOCSubjects_CACR_Female                     45
# 68                           EOG/EOCSubjects_GLP_Female                     45
# 69                                   EOGGr3_CACR_Female                   1101
# 70                                    EOGGr3_GLP_Female                   1101
# 71                                   EOGGr4_CACR_Female                   1106
# 72                                    EOGGr4_GLP_Female                   1106
# 73                                   EOGGr5_CACR_Female                   1122
# 74                                    EOGGr5_GLP_Female                   1122
# 75                               EOGMathGr3_CACR_Female                   1105
# 76                                EOGMathGr3_GLP_Female                   1105
# 77                             EOGMathGr3-8_CACR_Female                    535
# 78                              EOGMathGr3-8_GLP_Female                    535
# 79                               EOGMathGr4_CACR_Female                   1112
# 80                                EOGMathGr4_GLP_Female                   1112
# 81                               EOGMathGr5_CACR_Female                   1138
# 82                                EOGMathGr5_GLP_Female                   1138
# 83                            EOGReadingGr3_CACR_Female                   1105
# 84                             EOGReadingGr3_GLP_Female                   1105
# 85                          EOGReadingGr3-8_CACR_Female                    535
# 86                           EOGReadingGr3-8_GLP_Female                    535
# 87                            EOGReadingGr4_CACR_Female                   1112
# 88                             EOGReadingGr4_GLP_Female                   1112
# 89                            EOGReadingGr5_CACR_Female                   1138
# 90                             EOGReadingGr5_GLP_Female                   1138
# 91                            EOGScienceGr5_CACR_Female                   1138
# 92                             EOGScienceGr5_GLP_Female                   1138
# 93                          EOGScienceGr5&8_CACR_Female                    631
# 94                           EOGScienceGr5&8_GLP_Female                    631
# 95                              EOGSubjects_CACR_Female                    532
# 96                               EOGSubjects_GLP_Female                    532
# 97                                   EOCMathI_CACR_Male                   1377
# 98                                    EOCMathI_GLP_Male                   1377
# 99                                EOCSubjects_CACR_Male                   1366
# 100                                EOCSubjects_GLP_Male                   1366
# 101                           EOG/EOCSubjects_CACR_Male                     45
# 102                            EOG/EOCSubjects_GLP_Male                     45
# 103                                    EOGGr3_CACR_Male                   1101
# 104                                     EOGGr3_GLP_Male                   1101
# 105                                    EOGGr4_CACR_Male                   1106
# 106                                     EOGGr4_GLP_Male                   1106
# 107                                    EOGGr5_CACR_Male                   1122
# 108                                     EOGGr5_GLP_Male                   1122
# 109                                EOGMathGr3_CACR_Male                   1105
# 110                                 EOGMathGr3_GLP_Male                   1105
# 111                              EOGMathGr3-8_CACR_Male                    535
# 112                               EOGMathGr3-8_GLP_Male                    535
# 113                                EOGMathGr4_CACR_Male                   1112
# 114                                 EOGMathGr4_GLP_Male                   1112
# 115                                EOGMathGr5_CACR_Male                   1138
# 116                                 EOGMathGr5_GLP_Male                   1138
# 117                             EOGReadingGr3_CACR_Male                   1105
# 118                              EOGReadingGr3_GLP_Male                   1105
# 119                           EOGReadingGr3-8_CACR_Male                    535
# 120                            EOGReadingGr3-8_GLP_Male                    535
# 121                             EOGReadingGr4_CACR_Male                   1112
# 122                              EOGReadingGr4_GLP_Male                   1112
# 123                             EOGReadingGr5_CACR_Male                   1138
# 124                              EOGReadingGr5_GLP_Male                   1138
# 125                             EOGScienceGr5_CACR_Male                   1138
# 126                              EOGScienceGr5_GLP_Male                   1138
# 127                           EOGScienceGr5&8_CACR_Male                    631
# 128                            EOGScienceGr5&8_GLP_Male                    631
# 129                               EOGSubjects_CACR_Male                    532
# 130                                EOGSubjects_GLP_Male                    532
# 131                        EOCMathI_CACR_AmericanIndian                   1377
# 132                         EOCMathI_GLP_AmericanIndian                   1377
# 133                     EOCSubjects_CACR_AmericanIndian                   1366
# 134                      EOCSubjects_GLP_AmericanIndian                   1366
# 135                 EOG/EOCSubjects_CACR_AmericanIndian                     45
# 136                  EOG/EOCSubjects_GLP_AmericanIndian                     45
# 137                          EOGGr3_CACR_AmericanIndian                   1101
# 138                           EOGGr3_GLP_AmericanIndian                   1101
# 139                          EOGGr4_CACR_AmericanIndian                   1106
# 140                           EOGGr4_GLP_AmericanIndian                   1106
# 141                          EOGGr5_CACR_AmericanIndian                   1122
# 142                           EOGGr5_GLP_AmericanIndian                   1122
# 143                      EOGMathGr3_CACR_AmericanIndian                   1105
# 144                       EOGMathGr3_GLP_AmericanIndian                   1105
# 145                    EOGMathGr3-8_CACR_AmericanIndian                    535
# 146                     EOGMathGr3-8_GLP_AmericanIndian                    535
# 147                      EOGMathGr4_CACR_AmericanIndian                   1112
# 148                       EOGMathGr4_GLP_AmericanIndian                   1112
# 149                      EOGMathGr5_CACR_AmericanIndian                   1138
# 150                       EOGMathGr5_GLP_AmericanIndian                   1138
# 151                   EOGReadingGr3_CACR_AmericanIndian                   1105
# 152                    EOGReadingGr3_GLP_AmericanIndian                   1105
# 153                 EOGReadingGr3-8_CACR_AmericanIndian                    535
# 154                  EOGReadingGr3-8_GLP_AmericanIndian                    535
# 155                   EOGReadingGr4_CACR_AmericanIndian                   1112
# 156                    EOGReadingGr4_GLP_AmericanIndian                   1112
# 157                   EOGReadingGr5_CACR_AmericanIndian                   1138
# 158                    EOGReadingGr5_GLP_AmericanIndian                   1138
# 159                   EOGScienceGr5_CACR_AmericanIndian                   1138
# 160                    EOGScienceGr5_GLP_AmericanIndian                   1138
# 161                 EOGScienceGr5&8_CACR_AmericanIndian                    631
# 162                  EOGScienceGr5&8_GLP_AmericanIndian                    631
# 163                     EOGSubjects_CACR_AmericanIndian                    532
# 164                      EOGSubjects_GLP_AmericanIndian                    532
# 165                                 EOCMathI_CACR_Asian                   1377
# 166                                  EOCMathI_GLP_Asian                   1377
# 167                              EOCSubjects_CACR_Asian                   1366
# 168                               EOCSubjects_GLP_Asian                   1366
# 169                          EOG/EOCSubjects_CACR_Asian                     45
# 170                           EOG/EOCSubjects_GLP_Asian                     45
# 171                                   EOGGr3_CACR_Asian                   1101
# 172                                    EOGGr3_GLP_Asian                   1101
# 173                                   EOGGr4_CACR_Asian                   1106
# 174                                    EOGGr4_GLP_Asian                   1106
# 175                                   EOGGr5_CACR_Asian                   1122
# 176                                    EOGGr5_GLP_Asian                   1122
# 177                               EOGMathGr3_CACR_Asian                   1105
# 178                                EOGMathGr3_GLP_Asian                   1105
# 179                             EOGMathGr3-8_CACR_Asian                    535
# 180                              EOGMathGr3-8_GLP_Asian                    535
# 181                               EOGMathGr4_CACR_Asian                   1112
# 182                                EOGMathGr4_GLP_Asian                   1112
# 183                               EOGMathGr5_CACR_Asian                   1138
# 184                                EOGMathGr5_GLP_Asian                   1138
# 185                            EOGReadingGr3_CACR_Asian                   1105
# 186                             EOGReadingGr3_GLP_Asian                   1105
# 187                          EOGReadingGr3-8_CACR_Asian                    535
# 188                           EOGReadingGr3-8_GLP_Asian                    535
# 189                            EOGReadingGr4_CACR_Asian                   1112
# 190                             EOGReadingGr4_GLP_Asian                   1112
# 191                            EOGReadingGr5_CACR_Asian                   1138
# 192                             EOGReadingGr5_GLP_Asian                   1138
# 193                            EOGScienceGr5_CACR_Asian                   1138
# 194                             EOGScienceGr5_GLP_Asian                   1138
# 195                          EOGScienceGr5&8_CACR_Asian                    631
# 196                           EOGScienceGr5&8_GLP_Asian                    631
# 197                              EOGSubjects_CACR_Asian                    532
# 198                               EOGSubjects_GLP_Asian                    532
# 199                                 EOCMathI_CACR_Black                   1377
# 200                                  EOCMathI_GLP_Black                   1377
# 201                              EOCSubjects_CACR_Black                   1366
# 202                               EOCSubjects_GLP_Black                   1366
# 203                          EOG/EOCSubjects_CACR_Black                     45
# 204                           EOG/EOCSubjects_GLP_Black                     45
# 205                                   EOGGr3_CACR_Black                   1101
# 206                                    EOGGr3_GLP_Black                   1101
# 207                                   EOGGr4_CACR_Black                   1106
# 208                                    EOGGr4_GLP_Black                   1106
# 209                                   EOGGr5_CACR_Black                   1122
# 210                                    EOGGr5_GLP_Black                   1122
# 211                               EOGMathGr3_CACR_Black                   1105
# 212                                EOGMathGr3_GLP_Black                   1105
# 213                             EOGMathGr3-8_CACR_Black                    535
# 214                              EOGMathGr3-8_GLP_Black                    535
# 215                               EOGMathGr4_CACR_Black                   1112
# 216                                EOGMathGr4_GLP_Black                   1112
# 217                               EOGMathGr5_CACR_Black                   1138
# 218                                EOGMathGr5_GLP_Black                   1138
# 219                            EOGReadingGr3_CACR_Black                   1105
# 220                             EOGReadingGr3_GLP_Black                   1105
# 221                          EOGReadingGr3-8_CACR_Black                    535
# 222                           EOGReadingGr3-8_GLP_Black                    535
# 223                            EOGReadingGr4_CACR_Black                   1112
# 224                             EOGReadingGr4_GLP_Black                   1112
# 225                            EOGReadingGr5_CACR_Black                   1138
# 226                             EOGReadingGr5_GLP_Black                   1138
# 227                            EOGScienceGr5_CACR_Black                   1138
# 228                             EOGScienceGr5_GLP_Black                   1138
# 229                          EOGScienceGr5&8_CACR_Black                    631
# 230                           EOGScienceGr5&8_GLP_Black                    631
# 231                              EOGSubjects_CACR_Black                    532
# 232                               EOGSubjects_GLP_Black                    532
# 233                              EOCMathI_CACR_Hispanic                   1377
# 234                               EOCMathI_GLP_Hispanic                   1377
# 235                           EOCSubjects_CACR_Hispanic                   1366
# 236                            EOCSubjects_GLP_Hispanic                   1366
# 237                       EOG/EOCSubjects_CACR_Hispanic                     45
# 238                        EOG/EOCSubjects_GLP_Hispanic                     45
# 239                                EOGGr3_CACR_Hispanic                   1101
# 240                                 EOGGr3_GLP_Hispanic                   1101
# 241                                EOGGr4_CACR_Hispanic                   1106
# 242                                 EOGGr4_GLP_Hispanic                   1106
# 243                                EOGGr5_CACR_Hispanic                   1122
# 244                                 EOGGr5_GLP_Hispanic                   1122
# 245                            EOGMathGr3_CACR_Hispanic                   1105
# 246                             EOGMathGr3_GLP_Hispanic                   1105
# 247                          EOGMathGr3-8_CACR_Hispanic                    535
# 248                           EOGMathGr3-8_GLP_Hispanic                    535
# 249                            EOGMathGr4_CACR_Hispanic                   1112
# 250                             EOGMathGr4_GLP_Hispanic                   1112
# 251                            EOGMathGr5_CACR_Hispanic                   1138
# 252                             EOGMathGr5_GLP_Hispanic                   1138
# 253                         EOGReadingGr3_CACR_Hispanic                   1105
# 254                          EOGReadingGr3_GLP_Hispanic                   1105
# 255                       EOGReadingGr3-8_CACR_Hispanic                    535
# 256                        EOGReadingGr3-8_GLP_Hispanic                    535
# 257                         EOGReadingGr4_CACR_Hispanic                   1112
# 258                          EOGReadingGr4_GLP_Hispanic                   1112
# 259                         EOGReadingGr5_CACR_Hispanic                   1138
# 260                          EOGReadingGr5_GLP_Hispanic                   1138
# 261                         EOGScienceGr5_CACR_Hispanic                   1138
# 262                          EOGScienceGr5_GLP_Hispanic                   1138
# 263                       EOGScienceGr5&8_CACR_Hispanic                    631
# 264                        EOGScienceGr5&8_GLP_Hispanic                    631
# 265                           EOGSubjects_CACR_Hispanic                    532
# 266                            EOGSubjects_GLP_Hispanic                    532
# 267                        EOCMathI_CACR_TwoorMoreRaces                   1377
# 268                         EOCMathI_GLP_TwoorMoreRaces                   1377
# 269                     EOCSubjects_CACR_TwoorMoreRaces                   1366
# 270                      EOCSubjects_GLP_TwoorMoreRaces                   1366
# 271                 EOG/EOCSubjects_CACR_TwoorMoreRaces                     45
# 272                  EOG/EOCSubjects_GLP_TwoorMoreRaces                     45
# 273                          EOGGr3_CACR_TwoorMoreRaces                   1101
# 274                           EOGGr3_GLP_TwoorMoreRaces                   1101
# 275                          EOGGr4_CACR_TwoorMoreRaces                   1106
# 276                           EOGGr4_GLP_TwoorMoreRaces                   1106
# 277                          EOGGr5_CACR_TwoorMoreRaces                   1122
# 278                           EOGGr5_GLP_TwoorMoreRaces                   1122
# 279                      EOGMathGr3_CACR_TwoorMoreRaces                   1105
# 280                       EOGMathGr3_GLP_TwoorMoreRaces                   1105
# 281                    EOGMathGr3-8_CACR_TwoorMoreRaces                    535
# 282                     EOGMathGr3-8_GLP_TwoorMoreRaces                    535
# 283                      EOGMathGr4_CACR_TwoorMoreRaces                   1112
# 284                       EOGMathGr4_GLP_TwoorMoreRaces                   1112
# 285                      EOGMathGr5_CACR_TwoorMoreRaces                   1138
# 286                       EOGMathGr5_GLP_TwoorMoreRaces                   1138
# 287                   EOGReadingGr3_CACR_TwoorMoreRaces                   1105
# 288                    EOGReadingGr3_GLP_TwoorMoreRaces                   1105
# 289                 EOGReadingGr3-8_CACR_TwoorMoreRaces                    535
# 290                  EOGReadingGr3-8_GLP_TwoorMoreRaces                    535
# 291                   EOGReadingGr4_CACR_TwoorMoreRaces                   1112
# 292                    EOGReadingGr4_GLP_TwoorMoreRaces                   1112
# 293                   EOGReadingGr5_CACR_TwoorMoreRaces                   1138
# 294                    EOGReadingGr5_GLP_TwoorMoreRaces                   1138
# 295                   EOGScienceGr5_CACR_TwoorMoreRaces                   1138
# 296                    EOGScienceGr5_GLP_TwoorMoreRaces                   1138
# 297                 EOGScienceGr5&8_CACR_TwoorMoreRaces                    631
# 298                  EOGScienceGr5&8_GLP_TwoorMoreRaces                    631
# 299                     EOGSubjects_CACR_TwoorMoreRaces                    532
# 300                      EOGSubjects_GLP_TwoorMoreRaces                    532
# 301                                 EOCMathI_CACR_White                   1377
# 302                                  EOCMathI_GLP_White                   1377
# 303                              EOCSubjects_CACR_White                   1366
# 304                               EOCSubjects_GLP_White                   1366
# 305                          EOG/EOCSubjects_CACR_White                     45
# 306                           EOG/EOCSubjects_GLP_White                     45
# 307                                   EOGGr3_CACR_White                   1101
# 308                                    EOGGr3_GLP_White                   1101
# 309                                   EOGGr4_CACR_White                   1106
# 310                                    EOGGr4_GLP_White                   1106
# 311                                   EOGGr5_CACR_White                   1122
# 312                                    EOGGr5_GLP_White                   1122
# 313                               EOGMathGr3_CACR_White                   1105
# 314                                EOGMathGr3_GLP_White                   1105
# 315                             EOGMathGr3-8_CACR_White                    535
# 316                              EOGMathGr3-8_GLP_White                    535
# 317                               EOGMathGr4_CACR_White                   1112
# 318                                EOGMathGr4_GLP_White                   1112
# 319                               EOGMathGr5_CACR_White                   1138
# 320                                EOGMathGr5_GLP_White                   1138
# 321                            EOGReadingGr3_CACR_White                   1105
# 322                             EOGReadingGr3_GLP_White                   1105
# 323                          EOGReadingGr3-8_CACR_White                    535
# 324                           EOGReadingGr3-8_GLP_White                    535
# 325                            EOGReadingGr4_CACR_White                   1112
# 326                             EOGReadingGr4_GLP_White                   1112
# 327                            EOGReadingGr5_CACR_White                   1138
# 328                             EOGReadingGr5_GLP_White                   1138
# 329                            EOGScienceGr5_CACR_White                   1138
# 330                             EOGScienceGr5_GLP_White                   1138
# 331                          EOGScienceGr5&8_CACR_White                    631
# 332                           EOGScienceGr5&8_GLP_White                    631
# 333                              EOGSubjects_CACR_White                    532
# 334                               EOGSubjects_GLP_White                    532
# 335                                   EOCMathI_CACR_EDS                   1377
# 336                                    EOCMathI_GLP_EDS                   1377
# 337                                EOCSubjects_CACR_EDS                   1366
# 338                                 EOCSubjects_GLP_EDS                   1366
# 339                            EOG/EOCSubjects_CACR_EDS                     45
# 340                             EOG/EOCSubjects_GLP_EDS                     45
# 341                                     EOGGr3_CACR_EDS                   1101
# 342                                      EOGGr3_GLP_EDS                   1101
# 343                                     EOGGr4_CACR_EDS                   1106
# 344                                      EOGGr4_GLP_EDS                   1106
# 345                                     EOGGr5_CACR_EDS                   1122
# 346                                      EOGGr5_GLP_EDS                   1122
# 347                                 EOGMathGr3_CACR_EDS                   1105
# 348                                  EOGMathGr3_GLP_EDS                   1105
# 349                               EOGMathGr3-8_CACR_EDS                    535
# 350                                EOGMathGr3-8_GLP_EDS                    535
# 351                                 EOGMathGr4_CACR_EDS                   1112
# 352                                  EOGMathGr4_GLP_EDS                   1112
# 353                                 EOGMathGr5_CACR_EDS                   1138
# 354                                  EOGMathGr5_GLP_EDS                   1138
# 355                              EOGReadingGr3_CACR_EDS                   1105
# 356                               EOGReadingGr3_GLP_EDS                   1105
# 357                            EOGReadingGr3-8_CACR_EDS                    535
# 358                             EOGReadingGr3-8_GLP_EDS                    535
# 359                              EOGReadingGr4_CACR_EDS                   1112
# 360                               EOGReadingGr4_GLP_EDS                   1112
# 361                              EOGReadingGr5_CACR_EDS                   1138
# 362                               EOGReadingGr5_GLP_EDS                   1138
# 363                              EOGScienceGr5_CACR_EDS                   1138
# 364                               EOGScienceGr5_GLP_EDS                   1138
# 365                            EOGScienceGr5&8_CACR_EDS                    631
# 366                             EOGScienceGr5&8_GLP_EDS                    631
# 367                                EOGSubjects_CACR_EDS                    532
# 368                                 EOGSubjects_GLP_EDS                    532
# 369                                   EOCMathI_CACR_LEP                   1377
# 370                                    EOCMathI_GLP_LEP                   1377
# 371                                EOCSubjects_CACR_LEP                   1366
# 372                                 EOCSubjects_GLP_LEP                   1366
# 373                            EOG/EOCSubjects_CACR_LEP                     45
# 374                             EOG/EOCSubjects_GLP_LEP                     45
# 375                                     EOGGr3_CACR_LEP                   1101
# 376                                      EOGGr3_GLP_LEP                   1101
# 377                                     EOGGr4_CACR_LEP                   1106
# 378                                      EOGGr4_GLP_LEP                   1106
# 379                                     EOGGr5_CACR_LEP                   1122
# 380                                      EOGGr5_GLP_LEP                   1122
# 381                                 EOGMathGr3_CACR_LEP                   1105
# 382                                  EOGMathGr3_GLP_LEP                   1105
# 383                               EOGMathGr3-8_CACR_LEP                    535
# 384                                EOGMathGr3-8_GLP_LEP                    535
# 385                                 EOGMathGr4_CACR_LEP                   1112
# 386                                  EOGMathGr4_GLP_LEP                   1112
# 387                                 EOGMathGr5_CACR_LEP                   1138
# 388                                  EOGMathGr5_GLP_LEP                   1138
# 389                              EOGReadingGr3_CACR_LEP                   1105
# 390                               EOGReadingGr3_GLP_LEP                   1105
# 391                            EOGReadingGr3-8_CACR_LEP                    535
# 392                             EOGReadingGr3-8_GLP_LEP                    535
# 393                              EOGReadingGr4_CACR_LEP                   1112
# 394                               EOGReadingGr4_GLP_LEP                   1112
# 395                              EOGReadingGr5_CACR_LEP                   1138
# 396                               EOGReadingGr5_GLP_LEP                   1138
# 397                              EOGScienceGr5_CACR_LEP                   1138
# 398                               EOGScienceGr5_GLP_LEP                   1138
# 399                            EOGScienceGr5&8_CACR_LEP                    631
# 400                             EOGScienceGr5&8_GLP_LEP                    631
# 401                                EOGSubjects_CACR_LEP                    532
# 402                                 EOGSubjects_GLP_LEP                    532
# 403                                   EOCMathI_CACR_SWD                   1377
# 404                                    EOCMathI_GLP_SWD                   1377
# 405                                EOCSubjects_CACR_SWD                   1366
# 406                                 EOCSubjects_GLP_SWD                   1366
# 407                            EOG/EOCSubjects_CACR_SWD                     45
# 408                             EOG/EOCSubjects_GLP_SWD                     45
# 409                                     EOGGr3_CACR_SWD                   1101
# 410                                      EOGGr3_GLP_SWD                   1101
# 411                                     EOGGr4_CACR_SWD                   1106
# 412                                      EOGGr4_GLP_SWD                   1106
# 413                                     EOGGr5_CACR_SWD                   1122
# 414                                      EOGGr5_GLP_SWD                   1122
# 415                                 EOGMathGr3_CACR_SWD                   1105
# 416                                  EOGMathGr3_GLP_SWD                   1105
# 417                               EOGMathGr3-8_CACR_SWD                    535
# 418                                EOGMathGr3-8_GLP_SWD                    535
# 419                                 EOGMathGr4_CACR_SWD                   1112
# 420                                  EOGMathGr4_GLP_SWD                   1112
# 421                                 EOGMathGr5_CACR_SWD                   1138
# 422                                  EOGMathGr5_GLP_SWD                   1138
# 423                              EOGReadingGr3_CACR_SWD                   1105
# 424                               EOGReadingGr3_GLP_SWD                   1105
# 425                            EOGReadingGr3-8_CACR_SWD                    535
# 426                             EOGReadingGr3-8_GLP_SWD                    535
# 427                              EOGReadingGr4_CACR_SWD                   1112
# 428                               EOGReadingGr4_GLP_SWD                   1112
# 429                              EOGReadingGr5_CACR_SWD                   1138
# 430                               EOGReadingGr5_GLP_SWD                   1138
# 431                              EOGScienceGr5_CACR_SWD                   1138
# 432                               EOGScienceGr5_GLP_SWD                   1138
# 433                            EOGScienceGr5&8_CACR_SWD                    631
# 434                             EOGScienceGr5&8_GLP_SWD                    631
# 435                                EOGSubjects_CACR_SWD                    532
# 436                                 EOGSubjects_GLP_SWD                    532
# 437                                   EOCMathI_CACR_AIG                   1377
# 438                                    EOCMathI_GLP_AIG                   1377
# 439                                EOCSubjects_CACR_AIG                   1366
# 440                                 EOCSubjects_GLP_AIG                   1366
# 441                            EOG/EOCSubjects_CACR_AIG                     45
# 442                             EOG/EOCSubjects_GLP_AIG                     45
# 443                                     EOGGr3_CACR_AIG                   1101
# 444                                      EOGGr3_GLP_AIG                   1101
# 445                                     EOGGr4_CACR_AIG                   1106
# 446                                      EOGGr4_GLP_AIG                   1106
# 447                                     EOGGr5_CACR_AIG                   1122
# 448                                      EOGGr5_GLP_AIG                   1122
# 449                                 EOGMathGr3_CACR_AIG                   1105
# 450                                  EOGMathGr3_GLP_AIG                   1105
# 451                               EOGMathGr3-8_CACR_AIG                    535
# 452                                EOGMathGr3-8_GLP_AIG                    535
# 453                                 EOGMathGr4_CACR_AIG                   1112
# 454                                  EOGMathGr4_GLP_AIG                   1112
# 455                                 EOGMathGr5_CACR_AIG                   1138
# 456                                  EOGMathGr5_GLP_AIG                   1138
# 457                              EOGReadingGr3_CACR_AIG                   1105
# 458                               EOGReadingGr3_GLP_AIG                   1105
# 459                            EOGReadingGr3-8_CACR_AIG                    535
# 460                             EOGReadingGr3-8_GLP_AIG                    535
# 461                              EOGReadingGr4_CACR_AIG                   1112
# 462                               EOGReadingGr4_GLP_AIG                   1112
# 463                              EOGReadingGr5_CACR_AIG                   1138
# 464                               EOGReadingGr5_GLP_AIG                   1138
# 465                              EOGScienceGr5_CACR_AIG                   1138
# 466                               EOGScienceGr5_GLP_AIG                   1138
# 467                            EOGScienceGr5&8_CACR_AIG                    631
# 468                             EOGScienceGr5&8_GLP_AIG                    631
# 469                                EOGSubjects_CACR_AIG                    532
# 470                                 EOGSubjects_GLP_AIG                    532
# 471                                         pct_GCE_ALL                   1089
# 472                                      pct_PASSED_EOG                   1118
# 473                                        pct_PROMOTED                   1105
# 474                            MathGr3-8_pTarget_PctMet                    578
# 475                         ReadingGr3-8_pTarget_PctMet                    578
# 476                             SciGr5&8_pTarget_PctMet                    750
# 477                         TotalTargets_pTarget_PctMet                     68
# 480                            lea_ap_participation_pct                    229
# 481                               lea_ap_pct_3_or_above                     24
# 482                               lea_ib_pct_4_or_above                   1412
# 488                              stud_internet_comp_num                     11
# 494                          lea_stud_internet_comp_num                      4
# 498                                   digital_media_pct                     16
# 499                                   books_per_student                     13
# 500                               lea_books_per_student                     13
# 501                         st_avg_age_media_collection                     13
# 502                                st_books_per_student                     13
# 503                                 flicensed_teach_pct                      1
# 504                                   tchyrs_0thru3_pct                      1
# 505                                  tchyrs_4thru10_pct                      1
# 506                                   tchyrs_11plus_pct                      1
# 507                                     class_teach_num                      1
# 508                                           nbpts_num                    157
# 509                                     advance_dgr_pct                      1
# 510                                _1yr_tchr_trnovr_pct                     14
# 511                                   lateral_teach_pct                   1199
# 512                                  highqual_class_pct                      7
# 518                                       lea_nbpts_num                     23
# 520                             lea_1yr_tchr_trnovr_pct                      2
# 521                             lea_emer_prov_teach_pct                    944
# 522                               lea_lateral_teach_pct                    231
# 523                              lea_highqual_class_pct                      2
# 524                           lea_highqual_class_hp_pct                    287
# 525                           lea_highqual_class_lp_pct                    482
# 527                       lea_not_highqual_class_hp_pct                    287
# 528                       lea_not_highqual_class_lp_pct                    482
# 541                               0-3 Years_Exp_Pct_Tch                      1
# 542                               10+ Years_Exp_Pct_Tch                      1
# 543                              4-10 Years_Exp_Pct_Tch                      1
# 547                    Accomplished_TCHR_Standard 1_Pct                     34
# 548                    Accomplished_TCHR_Standard 2_Pct                     34
# 549                    Accomplished_TCHR_Standard 3_Pct                     34
# 550                    Accomplished_TCHR_Standard 4_Pct                     34
# 551                    Accomplished_TCHR_Standard 5_Pct                     34
# 552                      Developing_TCHR_Standard 1_Pct                     34
# 553                      Developing_TCHR_Standard 2_Pct                     34
# 554                      Developing_TCHR_Standard 3_Pct                     34
# 555                      Developing_TCHR_Standard 4_Pct                     34
# 556                      Developing_TCHR_Standard 5_Pct                     34
# 557                   Distinguished_TCHR_Standard 1_Pct                     34
# 558                   Distinguished_TCHR_Standard 2_Pct                     34
# 559                   Distinguished_TCHR_Standard 3_Pct                     34
# 560                   Distinguished_TCHR_Standard 4_Pct                     34
# 561                   Distinguished_TCHR_Standard 5_Pct                     34
# 562   Does Not Meet Expected Growth_TCHR_Standard 6_Pct                     34
# 563         Exceeds Expected Growth_TCHR_Standard 6_Pct                     34
# 564           Meets Expected Growth_TCHR_Standard 6_Pct                     34
# 565                 Not Demostrated_TCHR_Standard 1_Pct                     34
# 566                 Not Demostrated_TCHR_Standard 2_Pct                     34
# 567                 Not Demostrated_TCHR_Standard 3_Pct                     34
# 568                 Not Demostrated_TCHR_Standard 4_Pct                     34
# 569                 Not Demostrated_TCHR_Standard 5_Pct                     34
# 570                      Proficient_TCHR_Standard 1_Pct                     34
# 571                      Proficient_TCHR_Standard 2_Pct                     34
# 572                      Proficient_TCHR_Standard 3_Pct                     34
# 573                      Proficient_TCHR_Standard 4_Pct                     34
# 574                      Proficient_TCHR_Standard 5_Pct                     34
# 599                                                Year                      3
# 600                               Crime_Rate_Index_Rate                     27
# 601                             Crime_Rate_Violent_Rate                     27
# 602                            Crime_Rate_Property_Rate                     27
# 603                              Crime_Rate_Murder_Rate                    215
# 604                                Crime_Rate_Rape_Rate                     46
# 605                             Crime_Rate_Robbery_Rate                     50
# 606                             Crime_Rate_Assault_Rate                     33
# 607                            Crime_Rate_Burglary_Rate                     27
# 608                             Crime_Rate_Larceny_Rate                     27
# 609                                 Crime_Rate_MVT_Rate                     32
# 610                               Crime_Rate_Arson_Rate                     77
# 1402                                            LEACode                    173
# 1403                      Attrtion_Reason_TotalTeachers                    173
# 1404                    Attrtion_Reason_TeachersLeaving                    173
# 1405                Attrtion_Reason_RemainedinEducation                    173
# 1406                    Attrtion_Reason_PersonalReasons                    173
# 1407                     Attrtion_Reason_InitiatedbyLEA                    173
# 1408                 Attrtion_Reason_BeyondControlofLEA                    173
# 1409                       Attrtion_Reason_OtherReasons                    173

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print( 'There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  215192  field correlations > 95%.
#                                                    Field1  \
# 0                                         class_teach_num
# 1                                     lea_class_teach_num
# 2                                      st_class_teach_num
# 3                                            st_nbpts_num
# 4                                      st_advance_dgr_pct
# 5                               Overall Achievement Score
# 6                                          Math SPG Score
# 7                                              Read Score
# 8                                              Math Score
# 9                                    EOGMathGr3-8_GLP_All
# 10                               EOGReadingGr3-8_CACR_All
# 11                                EOGReadingGr3-8_GLP_All
# 12                                   EOGSubjects_CACR_All
# 13                                    EOGSubjects_GLP_All
# 14                            EOGReadingGr3-8_CACR_Female
# 15                             EOGReadingGr3-8_GLP_Female
# 16                                EOGSubjects_CACR_Female
# 17                                 EOGSubjects_GLP_Female
# 18                               EOGReadingGr3-8_GLP_Male
# 19                                  EOGSubjects_CACR_Male
# 20                                   EOGSubjects_GLP_Male
# 21                                             Read Score
# 22                                             Math Score
# 23                                  EOGMathGr3-8_CACR_All
# 24                                   EOGMathGr3-8_GLP_All
# 25                                EOGReadingGr3-8_GLP_All
# 26                                   EOGSubjects_CACR_All
# 27                                    EOGSubjects_GLP_All
# 28                               EOGMathGr3-8_CACR_Female
# 29                                EOGMathGr3-8_GLP_Female
# 30                             EOGReadingGr3-8_GLP_Female
# 31                                EOGSubjects_CACR_Female
# 32                                 EOGSubjects_GLP_Female
# 33                                 EOGMathGr3-8_CACR_Male
# 34                                  EOGMathGr3-8_GLP_Male
# 35                                  EOGSubjects_CACR_Male
# 36                                   EOGSubjects_GLP_Male
# 37                                             Math Score
# 38                                  EOGMathGr3-8_CACR_All
# 39                                   EOGMathGr3-8_GLP_All
# 40                               EOGReadingGr3-8_CACR_All
# 41                                EOGReadingGr3-8_GLP_All
# 42                                   EOGSubjects_CACR_All
# 43                                    EOGSubjects_GLP_All
# 44                                EOGMathGr3-8_GLP_Female
# 45                            EOGReadingGr3-8_CACR_Female
# 46                             EOGReadingGr3-8_GLP_Female
# 47                                EOGSubjects_CACR_Female
# 48                                 EOGSubjects_GLP_Female
# 49                                  EOGMathGr3-8_GLP_Male
# 50                              EOGReadingGr3-8_CACR_Male
# 51                               EOGReadingGr3-8_GLP_Male
# 52                                  EOGSubjects_CACR_Male
# 53                                   EOGSubjects_GLP_Male
# 54                                  EOGMathGr3-8_CACR_All
# 55                                   EOGMathGr3-8_GLP_All
# 56                                   EOGSubjects_CACR_All
# 57                                    EOGSubjects_GLP_All
# 58                               EOGMathGr3-8_CACR_Female
# 59                                EOGMathGr3-8_GLP_Female
# 60                                EOGSubjects_CACR_Female
# 61                                 EOGSubjects_GLP_Female
# 62                                 EOGMathGr3-8_CACR_Male
# 63                                  EOGMathGr3-8_GLP_Male
# 64                                  EOGSubjects_CACR_Male
# 65                                   EOGSubjects_GLP_Male
# 66                                   EOGMathGr3-8_GLP_EDS
# 67                               EOGScienceGr5&8_CACR_All
# 68                                EOGScienceGr5&8_GLP_All
# 69                            EOGScienceGr5&8_CACR_Female
# 70                             EOGScienceGr5&8_GLP_Female
# 71                              EOGScienceGr5&8_CACR_Male
# 72                               EOGScienceGr5&8_GLP_Male
# 73                                      EOCMathI_CACR_All
# 74                                       EOCMathI_GLP_All
# 75                                   EOCSubjects_CACR_All
# 76                                    EOCSubjects_GLP_All
# 77                                   EOCMathI_CACR_Female
# 78                                    EOCMathI_GLP_Female
# 79                                EOCSubjects_CACR_Female
# 80                                 EOCSubjects_GLP_Female
# 81                                      EOCMathI_GLP_Male
# 82                                   EOCSubjects_GLP_Male
# 83                                       EOCMathI_GLP_All
# 84                                   EOCSubjects_CACR_All
# 85                                    EOCSubjects_GLP_All
# 86                                   EOCMathI_CACR_Female
# 87                                    EOCMathI_GLP_Female
# 88                                EOCSubjects_CACR_Female
# 89                                 EOCSubjects_GLP_Female
# 90                                     EOCMathI_CACR_Male
# 91                                  EOCSubjects_CACR_Male
# 92                                   EOCSubjects_CACR_All
# 93                                    EOCSubjects_GLP_All
# 94                                   EOCMathI_CACR_Female
# 95                                    EOCMathI_GLP_Female
# 96                                EOCSubjects_CACR_Female
# 97                                 EOCSubjects_GLP_Female
# 98                                      EOCMathI_GLP_Male
# 99                                  EOCSubjects_CACR_Male
# 100                                  EOCSubjects_GLP_Male
# 101                                   EOCSubjects_GLP_All
# 102                                  EOCMathI_CACR_Female
# 103                                   EOCMathI_GLP_Female
# 104                               EOCSubjects_CACR_Female
# 105                                EOCSubjects_GLP_Female
# 106                                    EOCMathI_CACR_Male
# 107                                 EOCSubjects_CACR_Male
# 108                                  EOCSubjects_GLP_Male
# 109                                  EOCMathI_CACR_Female
# 110                                   EOCMathI_GLP_Female
# 111                               EOCSubjects_CACR_Female
# 112                                EOCSubjects_GLP_Female
# 113                                     EOCMathI_GLP_Male
# 114                                 EOCSubjects_CACR_Male
# 115                                  EOCSubjects_GLP_Male
# 116                               EOG/EOCSubjects_GLP_All
# 117                           EOG/EOCSubjects_CACR_Female
# 118                            EOG/EOCSubjects_GLP_Female
# 119                             EOG/EOCSubjects_CACR_Male
# 120                              EOG/EOCSubjects_GLP_Male
# 121                           EOG/EOCSubjects_CACR_Female
# 122                            EOG/EOCSubjects_GLP_Female
# 123                             EOG/EOCSubjects_CACR_Male
# 124                              EOG/EOCSubjects_GLP_Male
# 125                                        EOGGr3_GLP_All
# 126                                   EOGMathGr3_CACR_All
# 127                                    EOGMathGr3_GLP_All
# 128                                EOGReadingGr3_CACR_All
# 129                                 EOGReadingGr3_GLP_All
# 130                                    EOGGr3_CACR_Female
# 131                                     EOGGr3_GLP_Female
# 132                                EOGMathGr3_CACR_Female
# 133                                 EOGMathGr3_GLP_Female
# 134                             EOGReadingGr3_CACR_Female
# 135                              EOGReadingGr3_GLP_Female
# 136                                      EOGGr3_CACR_Male
# 137                                       EOGGr3_GLP_Male
# 138                                  EOGMathGr3_CACR_Male
# 139                                   EOGMathGr3_GLP_Male
# 140                               EOGReadingGr3_CACR_Male
# 141                                EOGReadingGr3_GLP_Male
# 142                                     EOGGr3_CACR_White
# 143                                        pct_PASSED_EOG
# 144                                   EOGMathGr3_CACR_All
# 145                                    EOGMathGr3_GLP_All
# 146                                EOGReadingGr3_CACR_All
# 147                                 EOGReadingGr3_GLP_All
# 148                                    EOGGr3_CACR_Female
# 149                                     EOGGr3_GLP_Female
# 150                                EOGMathGr3_CACR_Female
# 151                                 EOGMathGr3_GLP_Female
# 152                             EOGReadingGr3_CACR_Female
# 153                              EOGReadingGr3_GLP_Female
# 154                                      EOGGr3_CACR_Male
# 155                                       EOGGr3_GLP_Male
# 156                                  EOGMathGr3_CACR_Male
# 157                                   EOGMathGr3_GLP_Male
# 158                               EOGReadingGr3_CACR_Male
# 159                                EOGReadingGr3_GLP_Male
# 160                                      EOGGr3_GLP_White
# 161                                       EOGGr3_CACR_EDS
# 162                                        EOGGr3_GLP_EDS
# 163                                 EOGReadingGr3_GLP_EDS
# 164                                        pct_PASSED_EOG
# 165                                          pct_PROMOTED
# 166                                        EOGGr4_GLP_All
# 167                                   EOGMathGr4_CACR_All
# 168                                    EOGMathGr4_GLP_All
# 169                                EOGReadingGr4_CACR_All
# 170                                 EOGReadingGr4_GLP_All
# 171                                    EOGGr4_CACR_Female
# 172                                     EOGGr4_GLP_Female
# 173                                EOGMathGr4_CACR_Female
# 174                                 EOGMathGr4_GLP_Female
# 175                             EOGReadingGr4_CACR_Female
# 176                              EOGReadingGr4_GLP_Female
# 177                                      EOGGr4_CACR_Male
# 178                                       EOGGr4_GLP_Male
# 179                                  EOGMathGr4_CACR_Male
# 180                                   EOGMathGr4_GLP_Male
# 181                               EOGReadingGr4_CACR_Male
# 182                                EOGReadingGr4_GLP_Male
# 183                                        EOGGr4_GLP_EDS
# 184                                   EOGMathGr4_CACR_All
# 185                                    EOGMathGr4_GLP_All
# 186                                EOGReadingGr4_CACR_All
# 187                                 EOGReadingGr4_GLP_All
# 188                                    EOGGr4_CACR_Female
# 189                                     EOGGr4_GLP_Female
# 190                                EOGMathGr4_CACR_Female
# 191                                 EOGMathGr4_GLP_Female
# 192                             EOGReadingGr4_CACR_Female
# 193                              EOGReadingGr4_GLP_Female
# 194                                      EOGGr4_CACR_Male
# 195                                       EOGGr4_GLP_Male
# 196                                  EOGMathGr4_CACR_Male
# 197                                   EOGMathGr4_GLP_Male
# 198                               EOGReadingGr4_CACR_Male
# 199                                EOGReadingGr4_GLP_Male
# 200                                       EOGGr4_CACR_EDS
# 201                                        EOGGr4_GLP_EDS
# 202                                 EOGReadingGr4_GLP_EDS
# 203                                        EOGGr5_GLP_All
# 204                                   EOGMathGr5_CACR_All
# 205                                    EOGMathGr5_GLP_All
# 206                                EOGReadingGr5_CACR_All
# 207                                 EOGReadingGr5_GLP_All
# 208                                EOGScienceGr5_CACR_All
# 209                                 EOGScienceGr5_GLP_All
# 210                                    EOGGr5_CACR_Female
# 211                                     EOGGr5_GLP_Female
# 212                                EOGMathGr5_CACR_Female
# 213                                 EOGMathGr5_GLP_Female
# 214                             EOGReadingGr5_CACR_Female
# 215                              EOGReadingGr5_GLP_Female
# 216                             EOGScienceGr5_CACR_Female
# 217                              EOGScienceGr5_GLP_Female
# 218                                      EOGGr5_CACR_Male
# 219                                       EOGGr5_GLP_Male
# 220                                  EOGMathGr5_CACR_Male
# 221                                   EOGMathGr5_GLP_Male
# 222                               EOGReadingGr5_CACR_Male
# 223                                EOGReadingGr5_GLP_Male
# 224                               EOGScienceGr5_CACR_Male
# 225                                EOGScienceGr5_GLP_Male
# 226                                   EOGMathGr5_CACR_All
# 227                                    EOGMathGr5_GLP_All
# 228                                EOGReadingGr5_CACR_All
# 229                                 EOGReadingGr5_GLP_All
# 230                                EOGScienceGr5_CACR_All
# 231                                 EOGScienceGr5_GLP_All
# 232                                    EOGGr5_CACR_Female
# 233                                     EOGGr5_GLP_Female
# 234                                EOGMathGr5_CACR_Female
# 235                                 EOGMathGr5_GLP_Female
# 236                              EOGReadingGr5_GLP_Female
# 237                              EOGScienceGr5_GLP_Female
# 238                                      EOGGr5_CACR_Male
# 239                                       EOGGr5_GLP_Male
# 240                                  EOGMathGr5_CACR_Male
# 241                                   EOGMathGr5_GLP_Male
# 242                                EOGReadingGr5_GLP_Male
# 243                               EOGScienceGr5_CACR_Male
# 244                                EOGScienceGr5_GLP_Male
# 245                                        EOGGr5_GLP_EDS
# 246                                    EOGMathGr3_GLP_All
# 247                                EOGReadingGr3_CACR_All
# 248                                 EOGReadingGr3_GLP_All
# 249                                    EOGGr3_CACR_Female
# 250                                     EOGGr3_GLP_Female
# 251                                EOGMathGr3_CACR_Female
# 252                                 EOGMathGr3_GLP_Female
# 253                                      EOGGr3_CACR_Male
# 254                                       EOGGr3_GLP_Male
# 255                                  EOGMathGr3_CACR_Male
# 256                                   EOGMathGr3_GLP_Male
# 257                                EOGReadingGr3_GLP_Male
# 258                                        pct_PASSED_EOG
# 259                                EOGReadingGr3_CACR_All
# 260                                 EOGReadingGr3_GLP_All
# 261                                    EOGGr3_CACR_Female
# 262                                     EOGGr3_GLP_Female
# 263                                EOGMathGr3_CACR_Female
# 264                                 EOGMathGr3_GLP_Female
# 265                              EOGReadingGr3_GLP_Female
# 266                                      EOGGr3_CACR_Male
# 267                                       EOGGr3_GLP_Male
# 268                                  EOGMathGr3_CACR_Male
# 269                                   EOGMathGr3_GLP_Male
# 270                                EOGReadingGr3_GLP_Male
# 271                                       EOGGr3_CACR_EDS
# 272                                        EOGGr3_GLP_EDS
# 273                                    EOGMathGr3_GLP_EDS
# 274                                        pct_PASSED_EOG
# 275                                  EOGMathGr3-8_GLP_All
# 276                              EOGReadingGr3-8_CACR_All
# 277                                  EOGSubjects_CACR_All
# 278                                   EOGSubjects_GLP_All
# 279                              EOGMathGr3-8_CACR_Female
# 280                               EOGMathGr3-8_GLP_Female
# 281                               EOGSubjects_CACR_Female
# 282                                EOGSubjects_GLP_Female
# 283                                EOGMathGr3-8_CACR_Male
# 284                                 EOGMathGr3-8_GLP_Male
# 285                                 EOGSubjects_CACR_Male
# 286                                  EOGSubjects_GLP_Male
# 287                              EOGReadingGr3-8_CACR_All
# 288                               EOGReadingGr3-8_GLP_All
# 289                                  EOGSubjects_CACR_All
# 290                                   EOGSubjects_GLP_All
# 291                              EOGMathGr3-8_CACR_Female
# 292                               EOGMathGr3-8_GLP_Female
# 293                            EOGReadingGr3-8_GLP_Female
# 294                               EOGSubjects_CACR_Female
# 295                                EOGSubjects_GLP_Female
# 296                                EOGMathGr3-8_CACR_Male
# 297                                 EOGMathGr3-8_GLP_Male
# 298                              EOGReadingGr3-8_GLP_Male
# 299                                 EOGSubjects_CACR_Male
# 300                                  EOGSubjects_GLP_Male
# 301                                  EOGMathGr3-8_GLP_EDS
# 302                                    EOGMathGr4_GLP_All
# 303                                EOGReadingGr4_CACR_All
# 304                                 EOGReadingGr4_GLP_All
# 305                                    EOGGr4_CACR_Female
# 306                                     EOGGr4_GLP_Female
# 307                                EOGMathGr4_CACR_Female
# 308                                 EOGMathGr4_GLP_Female
# 309                             EOGReadingGr4_CACR_Female
# 310                                      EOGGr4_CACR_Male
# 311                                       EOGGr4_GLP_Male
# 312                                  EOGMathGr4_CACR_Male
# 313                                   EOGMathGr4_GLP_Male
# 314                               EOGReadingGr4_CACR_Male
# 315                                EOGReadingGr4_GLP_Male
# 316                                EOGReadingGr4_CACR_All
# 317                                 EOGReadingGr4_GLP_All
# 318                                    EOGGr4_CACR_Female
# 319                                     EOGGr4_GLP_Female
# 320                                EOGMathGr4_CACR_Female
# 321                                 EOGMathGr4_GLP_Female
# 322                             EOGReadingGr4_CACR_Female
# 323                              EOGReadingGr4_GLP_Female
# 324                                      EOGGr4_CACR_Male
# 325                                       EOGGr4_GLP_Male
# 326                                  EOGMathGr4_CACR_Male
# 327                                   EOGMathGr4_GLP_Male
# 328                               EOGReadingGr4_CACR_Male
# 329                                EOGReadingGr4_GLP_Male
# 330                                        EOGGr4_GLP_EDS
# 331                                    EOGMathGr4_GLP_EDS
# 332                                    EOGMathGr5_GLP_All
# 333                                EOGReadingGr5_CACR_All
# 334                                 EOGReadingGr5_GLP_All
# 335                                EOGScienceGr5_CACR_All
# 336                                 EOGScienceGr5_GLP_All
# 337                                    EOGGr5_CACR_Female
# 338                                     EOGGr5_GLP_Female
# 339                                EOGMathGr5_CACR_Female
# 340                                 EOGMathGr5_GLP_Female
# 341                                      EOGGr5_CACR_Male
# 342                                       EOGGr5_GLP_Male
# 343                                  EOGMathGr5_CACR_Male
# 344                                   EOGMathGr5_GLP_Male
# 345                                EOGReadingGr5_CACR_All
# 346                                 EOGReadingGr5_GLP_All
# 347                                EOGScienceGr5_CACR_All
# 348                                 EOGScienceGr5_GLP_All
# 349                                    EOGGr5_CACR_Female
# 350                                     EOGGr5_GLP_Female
# 351                                EOGMathGr5_CACR_Female
# 352                                 EOGMathGr5_GLP_Female
# 353                              EOGScienceGr5_GLP_Female
# 354                                      EOGGr5_CACR_Male
# 355                                       EOGGr5_GLP_Male
# 356                                  EOGMathGr5_CACR_Male
# 357                                   EOGMathGr5_GLP_Male
# 358                                EOGScienceGr5_GLP_Male
# 359                                 EOGReadingGr3_GLP_All
# 360                                    EOGGr3_CACR_Female
# 361                                     EOGGr3_GLP_Female
# 362                             EOGReadingGr3_CACR_Female
# 363                              EOGReadingGr3_GLP_Female
# 364                                      EOGGr3_CACR_Male
# 365                                       EOGGr3_GLP_Male
# 366                                   EOGMathGr3_GLP_Male
# 367                               EOGReadingGr3_CACR_Male
# 368                                EOGReadingGr3_GLP_Male
# 369                                        pct_PASSED_EOG
# 370                                    EOGGr3_CACR_Female
# 371                                     EOGGr3_GLP_Female
# 372                                 EOGMathGr3_GLP_Female
# 373                             EOGReadingGr3_CACR_Female
# 374                              EOGReadingGr3_GLP_Female
# 375                                      EOGGr3_CACR_Male
# 376                                       EOGGr3_GLP_Male
# 377                                   EOGMathGr3_GLP_Male
# 378                               EOGReadingGr3_CACR_Male
# 379                                EOGReadingGr3_GLP_Male
# 380                                        EOGGr3_GLP_EDS
# 381                                 EOGReadingGr3_GLP_EDS
# 382                                        pct_PASSED_EOG
# 383                                          pct_PROMOTED
# 384                               EOGReadingGr3-8_GLP_All
# 385                                  EOGSubjects_CACR_All
# 386                                   EOGSubjects_GLP_All
# 387                           EOGReadingGr3-8_CACR_Female
# 388                            EOGReadingGr3-8_GLP_Female
# 389                               EOGSubjects_CACR_Female
# 390                                EOGSubjects_GLP_Female
# 391                             EOGReadingGr3-8_CACR_Male
# 392                              EOGReadingGr3-8_GLP_Male
# 393                                 EOGSubjects_CACR_Male
# 394                                  EOGSubjects_GLP_Male
# 395                                  EOGSubjects_CACR_All
# 396                                   EOGSubjects_GLP_All
# 397                           EOGReadingGr3-8_CACR_Female
# 398                            EOGReadingGr3-8_GLP_Female
# 399                               EOGSubjects_CACR_Female
# 400                                EOGSubjects_GLP_Female
# 401                                 EOGMathGr3-8_GLP_Male
# 402                             EOGReadingGr3-8_CACR_Male
# 403                              EOGReadingGr3-8_GLP_Male
# 404                                 EOGSubjects_CACR_Male
# 405                                  EOGSubjects_GLP_Male
# 406                               EOGReadingGr3-8_GLP_EDS
# 407                                 EOGReadingGr4_GLP_All
# 408                                    EOGGr4_CACR_Female
# 409                                     EOGGr4_GLP_Female
# 410                                 EOGMathGr4_GLP_Female
# 411                             EOGReadingGr4_CACR_Female
# 412                              EOGReadingGr4_GLP_Female
# 413                                      EOGGr4_CACR_Male
# 414                                       EOGGr4_GLP_Male
# 415                                  EOGMathGr4_CACR_Male
# 416                                   EOGMathGr4_GLP_Male
# 417                               EOGReadingGr4_CACR_Male
# 418                                EOGReadingGr4_GLP_Male
# 419                                    EOGGr4_CACR_Female
# 420                                     EOGGr4_GLP_Female
# 421                                 EOGMathGr4_GLP_Female
# 422                             EOGReadingGr4_CACR_Female
# 423                              EOGReadingGr4_GLP_Female
# 424                                      EOGGr4_CACR_Male
# 425                                       EOGGr4_GLP_Male
# 426                                  EOGMathGr4_CACR_Male
# 427                                   EOGMathGr4_GLP_Male
# 428                               EOGReadingGr4_CACR_Male
# 429                                EOGReadingGr4_GLP_Male
# 430                                        EOGGr4_GLP_EDS
# 431                                 EOGReadingGr4_GLP_EDS
# 432                                 EOGReadingGr5_GLP_All
# 433                                    EOGGr5_CACR_Female
# 434                                     EOGGr5_GLP_Female
# 435                             EOGReadingGr5_CACR_Female
# 436                              EOGReadingGr5_GLP_Female
# 437                                      EOGGr5_CACR_Male
# 438                                       EOGGr5_GLP_Male
# 439                               EOGReadingGr5_CACR_Male
# 440                                EOGReadingGr5_GLP_Male
# 441                                EOGScienceGr5_CACR_All
# 442                                 EOGScienceGr5_GLP_All
# 443                                    EOGGr5_CACR_Female
# 444                                     EOGGr5_GLP_Female
# 445                             EOGReadingGr5_CACR_Female
# 446                              EOGReadingGr5_GLP_Female
# 447                                      EOGGr5_CACR_Male
# 448                                       EOGGr5_GLP_Male
# 449                               EOGReadingGr5_CACR_Male
# 450                                EOGReadingGr5_GLP_Male
# 451                                 EOGScienceGr5_GLP_All
# 452                                    EOGGr5_CACR_Female
# 453                                     EOGGr5_GLP_Female
# 454                             EOGScienceGr5_CACR_Female
# 455                              EOGScienceGr5_GLP_Female
# 456                                      EOGGr5_CACR_Male
# 457                                       EOGGr5_GLP_Male
# 458                               EOGScienceGr5_CACR_Male
# 459                                EOGScienceGr5_GLP_Male
# 460                                    EOGGr5_CACR_Female
# 461                                     EOGGr5_GLP_Female
# 462                                 EOGMathGr5_GLP_Female
# 463                             EOGScienceGr5_CACR_Female
# 464                              EOGScienceGr5_GLP_Female
# 465                                      EOGGr5_CACR_Male
# 466                                       EOGGr5_GLP_Male
# 467                               EOGScienceGr5_CACR_Male
# 468                                EOGScienceGr5_GLP_Male
# 469                                        EOGGr5_GLP_EDS
# 470                                 EOGScienceGr5_GLP_EDS
# 471                               EOGScienceGr5&8_GLP_All
# 472                           EOGScienceGr5&8_CACR_Female
# 473                            EOGScienceGr5&8_GLP_Female
# 474                             EOGScienceGr5&8_CACR_Male
# 475                              EOGScienceGr5&8_GLP_Male
# 476                           EOGScienceGr5&8_CACR_Female
# 477                            EOGScienceGr5&8_GLP_Female
# 478                             EOGScienceGr5&8_CACR_Male
# 479                              EOGScienceGr5&8_GLP_Male
# 480                               EOGScienceGr5&8_GLP_EDS
# 481                                   EOGSubjects_GLP_All
# 482                              EOGMathGr3-8_CACR_Female
# 483                               EOGMathGr3-8_GLP_Female
# 484                           EOGReadingGr3-8_CACR_Female
# 485                            EOGReadingGr3-8_GLP_Female
# 486                               EOGSubjects_CACR_Female
# 487                                EOGSubjects_GLP_Female
# 488                                EOGMathGr3-8_CACR_Male
# 489                                 EOGMathGr3-8_GLP_Male
# 490                             EOGReadingGr3-8_CACR_Male
# 491                              EOGReadingGr3-8_GLP_Male
# 492                                 EOGSubjects_CACR_Male
# 493                                  EOGSubjects_GLP_Male
# 494                              EOGMathGr3-8_CACR_Female
# 495                               EOGMathGr3-8_GLP_Female
# 496                           EOGReadingGr3-8_CACR_Female
# 497                            EOGReadingGr3-8_GLP_Female
# 498                               EOGSubjects_CACR_Female
# 499                                EOGSubjects_GLP_Female
# ...                                                   ...
# 214692                       Tot tax payments Ct 50KLT75K
# 214693                      Tot tax payments Ct 75KLT100K
# 214694                            Tot tax payments Ct All
# 214695                         Tot tax payments Ct GE200K
# 214696                          Tot tax payments Ct LT25K
# 214697            Tuition and fees deduction Amt 25KLT50K
# 214698            Tuition and fees deduction Amt 50KLT75K
# 214699                 Tuition and fees deduction Amt All
# 214700               Tuition and fees deduction Amt LT25K
# 214701             Tuition and fees deduction Ct 25KLT50K
# 214702             Tuition and fees deduction Ct 50KLT75K
# 214703                  Tuition and fees deduction Ct All
# 214704                Tuition and fees deduction Ct LT25K
# 214705           Unemployment compensation Amt 100KLT200K
# 214706             Unemployment compensation Amt 25KLT50K
# 214707             Unemployment compensation Amt 50KLT75K
# 214708            Unemployment compensation Amt 75KLT100K
# 214709                  Unemployment compensation Amt All
# 214710                Unemployment compensation Amt LT25K
# 214711            Unemployment compensation Ct 100KLT200K
# 214712              Unemployment compensation Ct 25KLT50K
# 214713              Unemployment compensation Ct 50KLT75K
# 214714             Unemployment compensation Ct 75KLT100K
# 214715                   Unemployment compensation Ct All
# 214716                    Attrtion_Reason_PersonalReasons
# 214717                       Tot tax payments Ct 25KLT50K
# 214718                       Tot tax payments Ct 50KLT75K
# 214719                            Tot tax payments Ct All
# 214720                          Tot tax payments Ct LT25K
# 214721            Tuition and fees deduction Amt 25KLT50K
# 214722            Tuition and fees deduction Amt 50KLT75K
# 214723             Tuition and fees deduction Ct 25KLT50K
# 214724                Tuition and fees deduction Ct LT25K
# 214725             Unemployment compensation Amt 25KLT50K
# 214726             Unemployment compensation Amt 50KLT75K
# 214727                  Unemployment compensation Amt All
# 214728                Unemployment compensation Amt LT25K
# 214729              Unemployment compensation Ct 25KLT50K
# 214730              Unemployment compensation Ct 50KLT75K
# 214731                   Unemployment compensation Ct All
# 214732                 Unemployment compensation Ct LT25K
# 214733                    Attrtion_Reason_PersonalReasons
# 214734                       Tot tax payments Ct 25KLT50K
# 214735                       Tot tax payments Ct 50KLT75K
# 214736                      Tot tax payments Ct 75KLT100K
# 214737                            Tot tax payments Ct All
# 214738                         Tot tax payments Ct GE200K
# 214739          Tuition and fees deduction Amt 100KLT200K
# 214740            Tuition and fees deduction Amt 50KLT75K
# 214741                 Tuition and fees deduction Amt All
# 214742               Tuition and fees deduction Amt LT25K
# 214743           Tuition and fees deduction Ct 100KLT200K
# 214744             Tuition and fees deduction Ct 50KLT75K
# 214745                  Tuition and fees deduction Ct All
# 214746                Tuition and fees deduction Ct LT25K
# 214747           Unemployment compensation Amt 100KLT200K
# 214748             Unemployment compensation Amt 50KLT75K
# 214749            Unemployment compensation Amt 75KLT100K
# 214750               Unemployment compensation Amt GE200K
# 214751            Unemployment compensation Ct 100KLT200K
# 214752              Unemployment compensation Ct 50KLT75K
# 214753             Unemployment compensation Ct 75KLT100K
# 214754                Unemployment compensation Ct GE200K
# 214755                      Attrtion_Reason_TotalTeachers
# 214756                     Attrtion_Reason_InitiatedbyLEA
# 214757                       Tot tax payments Ct 50KLT75K
# 214758                      Tot tax payments Ct 75KLT100K
# 214759                            Tot tax payments Ct All
# 214760                         Tot tax payments Ct GE200K
# 214761                          Tot tax payments Ct LT25K
# 214762            Tuition and fees deduction Amt 25KLT50K
# 214763            Tuition and fees deduction Amt 50KLT75K
# 214764                 Tuition and fees deduction Amt All
# 214765               Tuition and fees deduction Amt LT25K
# 214766             Tuition and fees deduction Ct 25KLT50K
# 214767             Tuition and fees deduction Ct 50KLT75K
# 214768                  Tuition and fees deduction Ct All
# 214769                Tuition and fees deduction Ct LT25K
# 214770           Unemployment compensation Amt 100KLT200K
# 214771             Unemployment compensation Amt 25KLT50K
# 214772             Unemployment compensation Amt 50KLT75K
# 214773            Unemployment compensation Amt 75KLT100K
# 214774                  Unemployment compensation Amt All
# 214775                Unemployment compensation Amt LT25K
# 214776            Unemployment compensation Ct 100KLT200K
# 214777              Unemployment compensation Ct 25KLT50K
# 214778              Unemployment compensation Ct 50KLT75K
# 214779             Unemployment compensation Ct 75KLT100K
# 214780                   Unemployment compensation Ct All
# 214781                 Unemployment compensation Ct LT25K
# 214782                      Attrtion_Reason_TotalTeachers
# 214783                    Attrtion_Reason_TeachersLeaving
# 214784                    Attrtion_Reason_PersonalReasons
# 214785                 Attrtion_Reason_BeyondControlofLEA
# 214786                      Tot tax payments Ct 75KLT100K
# 214787                            Tot tax payments Ct All
# 214788                         Tot tax payments Ct GE200K
# 214789                          Tot tax payments Ct LT25K
# 214790          Tuition and fees deduction Amt 100KLT200K
# 214791            Tuition and fees deduction Amt 25KLT50K
# 214792            Tuition and fees deduction Amt 50KLT75K
# 214793                 Tuition and fees deduction Amt All
# 214794               Tuition and fees deduction Amt LT25K
# 214795           Tuition and fees deduction Ct 100KLT200K
# 214796             Tuition and fees deduction Ct 25KLT50K
# 214797             Tuition and fees deduction Ct 50KLT75K
# 214798                  Tuition and fees deduction Ct All
# 214799                Tuition and fees deduction Ct LT25K
# 214800           Unemployment compensation Amt 100KLT200K
# 214801             Unemployment compensation Amt 25KLT50K
# 214802             Unemployment compensation Amt 50KLT75K
# 214803            Unemployment compensation Amt 75KLT100K
# 214804                  Unemployment compensation Amt All
# 214805                Unemployment compensation Amt LT25K
# 214806            Unemployment compensation Ct 100KLT200K
# 214807              Unemployment compensation Ct 25KLT50K
# 214808              Unemployment compensation Ct 50KLT75K
# 214809             Unemployment compensation Ct 75KLT100K
# 214810                   Unemployment compensation Ct All
# 214811                 Unemployment compensation Ct LT25K
# 214812                      Attrtion_Reason_TotalTeachers
# 214813                    Attrtion_Reason_TeachersLeaving
# 214814                    Attrtion_Reason_PersonalReasons
# 214815                            Tot tax payments Ct All
# 214816                         Tot tax payments Ct GE200K
# 214817                          Tot tax payments Ct LT25K
# 214818          Tuition and fees deduction Amt 100KLT200K
# 214819            Tuition and fees deduction Amt 50KLT75K
# 214820                 Tuition and fees deduction Amt All
# 214821               Tuition and fees deduction Amt LT25K
# 214822           Tuition and fees deduction Ct 100KLT200K
# 214823             Tuition and fees deduction Ct 25KLT50K
# 214824             Tuition and fees deduction Ct 50KLT75K
# 214825                  Tuition and fees deduction Ct All
# 214826                Tuition and fees deduction Ct LT25K
# 214827           Unemployment compensation Amt 100KLT200K
# 214828             Unemployment compensation Amt 25KLT50K
# 214829             Unemployment compensation Amt 50KLT75K
# 214830            Unemployment compensation Amt 75KLT100K
# 214831                  Unemployment compensation Amt All
# 214832            Unemployment compensation Ct 100KLT200K
# 214833              Unemployment compensation Ct 25KLT50K
# 214834              Unemployment compensation Ct 50KLT75K
# 214835             Unemployment compensation Ct 75KLT100K
# 214836                   Unemployment compensation Ct All
# 214837                      Attrtion_Reason_TotalTeachers
# 214838                    Attrtion_Reason_TeachersLeaving
# 214839                         Tot tax payments Ct GE200K
# 214840                          Tot tax payments Ct LT25K
# 214841          Tuition and fees deduction Amt 100KLT200K
# 214842            Tuition and fees deduction Amt 25KLT50K
# 214843            Tuition and fees deduction Amt 50KLT75K
# 214844                 Tuition and fees deduction Amt All
# 214845               Tuition and fees deduction Amt LT25K
# 214846             Tuition and fees deduction Ct 25KLT50K
# 214847             Tuition and fees deduction Ct 50KLT75K
# 214848                  Tuition and fees deduction Ct All
# 214849                Tuition and fees deduction Ct LT25K
# 214850           Unemployment compensation Amt 100KLT200K
# 214851             Unemployment compensation Amt 25KLT50K
# 214852             Unemployment compensation Amt 50KLT75K
# 214853            Unemployment compensation Amt 75KLT100K
# 214854                  Unemployment compensation Amt All
# 214855                Unemployment compensation Amt LT25K
# 214856            Unemployment compensation Ct 100KLT200K
# 214857              Unemployment compensation Ct 25KLT50K
# 214858              Unemployment compensation Ct 50KLT75K
# 214859             Unemployment compensation Ct 75KLT100K
# 214860                   Unemployment compensation Ct All
# 214861                 Unemployment compensation Ct LT25K
# 214862                      Attrtion_Reason_TotalTeachers
# 214863                    Attrtion_Reason_TeachersLeaving
# 214864                    Attrtion_Reason_PersonalReasons
# 214865          Tuition and fees deduction Amt 100KLT200K
# 214866            Tuition and fees deduction Amt 50KLT75K
# 214867                 Tuition and fees deduction Amt All
# 214868               Tuition and fees deduction Amt LT25K
# 214869           Tuition and fees deduction Ct 100KLT200K
# 214870             Tuition and fees deduction Ct 25KLT50K
# 214871             Tuition and fees deduction Ct 50KLT75K
# 214872                  Tuition and fees deduction Ct All
# 214873                Tuition and fees deduction Ct LT25K
# 214874           Unemployment compensation Amt 100KLT200K
# 214875             Unemployment compensation Amt 25KLT50K
# 214876             Unemployment compensation Amt 50KLT75K
# 214877            Unemployment compensation Amt 75KLT100K
# 214878                  Unemployment compensation Amt All
# 214879               Unemployment compensation Amt GE200K
# 214880            Unemployment compensation Ct 100KLT200K
# 214881              Unemployment compensation Ct 25KLT50K
# 214882              Unemployment compensation Ct 50KLT75K
# 214883             Unemployment compensation Ct 75KLT100K
# 214884                   Unemployment compensation Ct All
# 214885                Unemployment compensation Ct GE200K
# 214886                      Attrtion_Reason_TotalTeachers
# 214887            Tuition and fees deduction Amt 25KLT50K
# 214888            Tuition and fees deduction Amt 50KLT75K
# 214889                 Tuition and fees deduction Amt All
# 214890               Tuition and fees deduction Amt LT25K
# 214891             Tuition and fees deduction Ct 25KLT50K
# 214892             Tuition and fees deduction Ct 50KLT75K
# 214893                  Tuition and fees deduction Ct All
# 214894                Tuition and fees deduction Ct LT25K
# 214895             Unemployment compensation Amt 25KLT50K
# 214896             Unemployment compensation Amt 50KLT75K
# 214897            Unemployment compensation Amt 75KLT100K
# 214898                  Unemployment compensation Amt All
# 214899                Unemployment compensation Amt LT25K
# 214900              Unemployment compensation Ct 25KLT50K
# 214901              Unemployment compensation Ct 50KLT75K
# 214902             Unemployment compensation Ct 75KLT100K
# 214903                   Unemployment compensation Ct All
# 214904                 Unemployment compensation Ct LT25K
# 214905                      Attrtion_Reason_TotalTeachers
# 214906                    Attrtion_Reason_TeachersLeaving
# 214907                    Attrtion_Reason_PersonalReasons
# 214908                 Tuition and fees deduction Amt All
# 214909               Tuition and fees deduction Amt LT25K
# 214910           Tuition and fees deduction Ct 100KLT200K
# 214911             Tuition and fees deduction Ct 50KLT75K
# 214912                  Tuition and fees deduction Ct All
# 214913                Tuition and fees deduction Ct LT25K
# 214914           Unemployment compensation Amt 100KLT200K
# 214915            Unemployment compensation Amt 75KLT100K
# 214916               Unemployment compensation Amt GE200K
# 214917            Unemployment compensation Ct 100KLT200K
# 214918             Unemployment compensation Ct 75KLT100K
# 214919                      Attrtion_Reason_TotalTeachers
# 214920                     Attrtion_Reason_InitiatedbyLEA
# 214921            Tuition and fees deduction Amt 50KLT75K
# 214922                 Tuition and fees deduction Amt All
# 214923               Tuition and fees deduction Amt LT25K
# 214924             Tuition and fees deduction Ct 25KLT50K
# 214925             Tuition and fees deduction Ct 50KLT75K
# 214926                  Tuition and fees deduction Ct All
# 214927                Tuition and fees deduction Ct LT25K
# 214928             Unemployment compensation Amt 25KLT50K
# 214929             Unemployment compensation Amt 50KLT75K
# 214930                  Unemployment compensation Amt All
# 214931                Unemployment compensation Amt LT25K
# 214932              Unemployment compensation Ct 25KLT50K
# 214933              Unemployment compensation Ct 50KLT75K
# 214934                   Unemployment compensation Ct All
# 214935                 Unemployment compensation Ct LT25K
# 214936                    Attrtion_Reason_TeachersLeaving
# 214937                    Attrtion_Reason_PersonalReasons
# 214938                 Tuition and fees deduction Amt All
# 214939               Tuition and fees deduction Amt LT25K
# 214940             Tuition and fees deduction Ct 25KLT50K
# 214941             Tuition and fees deduction Ct 50KLT75K
# 214942                  Tuition and fees deduction Ct All
# 214943                Tuition and fees deduction Ct LT25K
# 214944           Unemployment compensation Amt 100KLT200K
# 214945             Unemployment compensation Amt 25KLT50K
# 214946             Unemployment compensation Amt 50KLT75K
# 214947            Unemployment compensation Amt 75KLT100K
# 214948                  Unemployment compensation Amt All
# 214949                Unemployment compensation Amt LT25K
# 214950            Unemployment compensation Ct 100KLT200K
# 214951              Unemployment compensation Ct 25KLT50K
# 214952              Unemployment compensation Ct 50KLT75K
# 214953             Unemployment compensation Ct 75KLT100K
# 214954                   Unemployment compensation Ct All
# 214955                      Attrtion_Reason_TotalTeachers
# 214956                    Attrtion_Reason_TeachersLeaving
# 214957                    Attrtion_Reason_PersonalReasons
# 214958            Tuition and fees deduction Ct 75KLT100K
# 214959               Tuition and fees deduction Amt LT25K
# 214960           Tuition and fees deduction Ct 100KLT200K
# 214961             Tuition and fees deduction Ct 25KLT50K
# 214962             Tuition and fees deduction Ct 50KLT75K
# 214963                  Tuition and fees deduction Ct All
# 214964                Tuition and fees deduction Ct LT25K
# 214965           Unemployment compensation Amt 100KLT200K
# 214966             Unemployment compensation Amt 25KLT50K
# 214967             Unemployment compensation Amt 50KLT75K
# 214968            Unemployment compensation Amt 75KLT100K
# 214969                  Unemployment compensation Amt All
# 214970            Unemployment compensation Ct 100KLT200K
# 214971              Unemployment compensation Ct 25KLT50K
# 214972              Unemployment compensation Ct 50KLT75K
# 214973             Unemployment compensation Ct 75KLT100K
# 214974                   Unemployment compensation Ct All
# 214975                      Attrtion_Reason_TotalTeachers
# ...
# 214974                 Tuition and fees deduction Amt All     0.972737
# 214975                 Tuition and fees deduction Amt All     0.972508
# 214976                 Tuition and fees deduction Amt All     0.964367
# 214977                 Tuition and fees deduction Amt All     0.958952
# 214978                 Tuition and fees deduction Amt All     0.950577
# 214979               Tuition and fees deduction Amt LT25K     0.956567
# 214980               Tuition and fees deduction Amt LT25K     0.973355
# 214981               Tuition and fees deduction Amt LT25K     0.979322
# 214982               Tuition and fees deduction Amt LT25K     0.994969
# 214983               Tuition and fees deduction Amt LT25K     0.999103
# 214984               Tuition and fees deduction Amt LT25K     0.967906
# 214985               Tuition and fees deduction Amt LT25K     0.959536
# 214986               Tuition and fees deduction Amt LT25K     0.974421
# 214987               Tuition and fees deduction Amt LT25K     0.968635
# 214988               Tuition and fees deduction Amt LT25K     0.968252
# 214989               Tuition and fees deduction Amt LT25K     0.968638
# 214990               Tuition and fees deduction Amt LT25K     0.960644
# 214991               Tuition and fees deduction Amt LT25K     0.975415
# 214992               Tuition and fees deduction Amt LT25K     0.971145
# 214993               Tuition and fees deduction Amt LT25K     0.969542
# 214994               Tuition and fees deduction Amt LT25K     0.963769
# 214995               Tuition and fees deduction Amt LT25K     0.955743
# 214996           Tuition and fees deduction Ct 100KLT200K     0.974850
# 214997           Tuition and fees deduction Ct 100KLT200K     0.955930
# 214998           Tuition and fees deduction Ct 100KLT200K     0.973173
# 214999           Tuition and fees deduction Ct 100KLT200K     0.975228
# 215000           Tuition and fees deduction Ct 100KLT200K     0.978225
# 215001           Tuition and fees deduction Ct 100KLT200K     0.974090
# 215002           Tuition and fees deduction Ct 100KLT200K     0.951382
# 215003             Tuition and fees deduction Ct 25KLT50K     0.976071
# 215004             Tuition and fees deduction Ct 25KLT50K     0.974477
# 215005             Tuition and fees deduction Ct 25KLT50K     0.975692
# 215006             Tuition and fees deduction Ct 25KLT50K     0.983717
# 215007             Tuition and fees deduction Ct 25KLT50K     0.978087
# 215008             Tuition and fees deduction Ct 25KLT50K     0.957197
# 215009             Tuition and fees deduction Ct 25KLT50K     0.984261
# 215010             Tuition and fees deduction Ct 25KLT50K     0.973740
# 215011             Tuition and fees deduction Ct 25KLT50K     0.984365
# 215012             Tuition and fees deduction Ct 25KLT50K     0.976450
# 215013             Tuition and fees deduction Ct 25KLT50K     0.959908
# 215014             Tuition and fees deduction Ct 25KLT50K     0.984695
# 215015             Tuition and fees deduction Ct 25KLT50K     0.968780
# 215016             Tuition and fees deduction Ct 25KLT50K     0.958519
# 215017             Tuition and fees deduction Ct 25KLT50K     0.970585
# 215018             Tuition and fees deduction Ct 25KLT50K     0.973723
# 215019             Tuition and fees deduction Ct 25KLT50K     0.953459
# 215020             Tuition and fees deduction Ct 50KLT75K     0.987083
# 215021             Tuition and fees deduction Ct 50KLT75K     0.978661
# 215022             Tuition and fees deduction Ct 50KLT75K     0.983066
# 215023             Tuition and fees deduction Ct 50KLT75K     0.978419
# 215024             Tuition and fees deduction Ct 50KLT75K     0.983986
# 215025             Tuition and fees deduction Ct 50KLT75K     0.980451
# 215026             Tuition and fees deduction Ct 50KLT75K     0.983721
# 215027             Tuition and fees deduction Ct 50KLT75K     0.952564
# 215028             Tuition and fees deduction Ct 50KLT75K     0.980459
# 215029             Tuition and fees deduction Ct 50KLT75K     0.975203
# 215030             Tuition and fees deduction Ct 50KLT75K     0.979925
# 215031             Tuition and fees deduction Ct 50KLT75K     0.980719
# 215032             Tuition and fees deduction Ct 50KLT75K     0.978627
# 215033             Tuition and fees deduction Ct 50KLT75K     0.957925
# 215034             Tuition and fees deduction Ct 50KLT75K     0.962690
# 215035             Tuition and fees deduction Ct 50KLT75K     0.966375
# 215036                  Tuition and fees deduction Ct All     0.995322
# 215037                  Tuition and fees deduction Ct All     0.983421
# 215038                  Tuition and fees deduction Ct All     0.962234
# 215039                  Tuition and fees deduction Ct All     0.981310
# 215040                  Tuition and fees deduction Ct All     0.986533
# 215041                  Tuition and fees deduction Ct All     0.972227
# 215042                  Tuition and fees deduction Ct All     0.984451
# 215043                  Tuition and fees deduction Ct All     0.962273
# 215044                  Tuition and fees deduction Ct All     0.981831
# 215045                  Tuition and fees deduction Ct All     0.987740
# 215046                  Tuition and fees deduction Ct All     0.971282
# 215047                  Tuition and fees deduction Ct All     0.974725
# 215048                  Tuition and fees deduction Ct All     0.964662
# 215049                  Tuition and fees deduction Ct All     0.957185
# 215050                  Tuition and fees deduction Ct All     0.955805
# 215051                Tuition and fees deduction Ct LT25K     0.968217
# 215052                Tuition and fees deduction Ct LT25K     0.963687
# 215053                Tuition and fees deduction Ct LT25K     0.979262
# 215054                Tuition and fees deduction Ct LT25K     0.971696
# 215055                Tuition and fees deduction Ct LT25K     0.972479
# 215056                Tuition and fees deduction Ct LT25K     0.969018
# 215057                Tuition and fees deduction Ct LT25K     0.965540
# 215058                Tuition and fees deduction Ct LT25K     0.980697
# 215059                Tuition and fees deduction Ct LT25K     0.974322
# 215060                Tuition and fees deduction Ct LT25K     0.974458
# 215061                Tuition and fees deduction Ct LT25K     0.966814
# 215062                Tuition and fees deduction Ct LT25K     0.958907
# 215063                Tuition and fees deduction Ct LT25K     0.952204
# 215064           Unemployment compensation Amt 100KLT200K     0.953093
# 215065           Unemployment compensation Amt 100KLT200K     0.976884
# 215066           Unemployment compensation Amt 100KLT200K     0.991563
# 215067           Unemployment compensation Amt 100KLT200K     0.964796
# 215068           Unemployment compensation Amt 100KLT200K     0.970377
# 215069           Unemployment compensation Amt 100KLT200K     0.999558
# 215070           Unemployment compensation Amt 100KLT200K     0.975283
# 215071           Unemployment compensation Amt 100KLT200K     0.990727
# 215072           Unemployment compensation Amt 100KLT200K     0.958550
# 215073           Unemployment compensation Amt 100KLT200K     0.966709
# 215074           Unemployment compensation Amt 100KLT200K     0.961634
# 215075             Unemployment compensation Amt 25KLT50K     0.990144
# 215076             Unemployment compensation Amt 25KLT50K     0.959057
# 215077             Unemployment compensation Amt 25KLT50K     0.998636
# 215078             Unemployment compensation Amt 25KLT50K     0.992004
# 215079             Unemployment compensation Amt 25KLT50K     0.999235
# 215080             Unemployment compensation Amt 25KLT50K     0.986887
# 215081             Unemployment compensation Amt 25KLT50K     0.961665
# 215082             Unemployment compensation Amt 25KLT50K     0.997559
# 215083             Unemployment compensation Amt 25KLT50K     0.984948
# 215084             Unemployment compensation Amt 25KLT50K     0.950858
# 215085             Unemployment compensation Amt 25KLT50K     0.965183
# 215086             Unemployment compensation Amt 25KLT50K     0.975930
# 215087             Unemployment compensation Amt 25KLT50K     0.955159
# 215088             Unemployment compensation Amt 50KLT75K     0.983190
# 215089             Unemployment compensation Amt 50KLT75K     0.995371
# 215090             Unemployment compensation Amt 50KLT75K     0.971825
# 215091             Unemployment compensation Amt 50KLT75K     0.975087
# 215092             Unemployment compensation Amt 50KLT75K     0.990342
# 215093             Unemployment compensation Amt 50KLT75K     0.999117
# 215094             Unemployment compensation Amt 50KLT75K     0.985461
# 215095             Unemployment compensation Amt 50KLT75K     0.994561
# 215096             Unemployment compensation Amt 50KLT75K     0.964810
# 215097             Unemployment compensation Amt 50KLT75K     0.963575
# 215098             Unemployment compensation Amt 50KLT75K     0.962763
# 215099             Unemployment compensation Amt 50KLT75K     0.965722
# 215100            Unemployment compensation Amt 75KLT100K     0.969887
# 215101            Unemployment compensation Amt 75KLT100K     0.954203
# 215102            Unemployment compensation Amt 75KLT100K     0.992016
# 215103            Unemployment compensation Amt 75KLT100K     0.957204
# 215104            Unemployment compensation Amt 75KLT100K     0.983006
# 215105            Unemployment compensation Amt 75KLT100K     0.999376
# 215106            Unemployment compensation Amt 75KLT100K     0.965801
# 215107            Unemployment compensation Amt 75KLT100K     0.950782
# 215108            Unemployment compensation Amt 75KLT100K     0.972671
# 215109            Unemployment compensation Amt 75KLT100K     0.960337
# 215110            Unemployment compensation Amt 75KLT100K     0.954073
# 215111            Unemployment compensation Amt 75KLT100K     0.961701
# 215112                  Unemployment compensation Amt All     0.987614
# 215113                  Unemployment compensation Amt All     0.961295
# 215114                  Unemployment compensation Amt All     0.998141
# 215115                  Unemployment compensation Amt All     0.992851
# 215116                  Unemployment compensation Amt All     0.972201
# 215117                  Unemployment compensation Amt All     0.999015
# 215118                  Unemployment compensation Amt All     0.980642
# 215119                  Unemployment compensation Amt All     0.957757
# 215120                  Unemployment compensation Amt All     0.966832
# 215121                  Unemployment compensation Amt All     0.974603
# 215122                  Unemployment compensation Amt All     0.953712
# 215123               Unemployment compensation Amt GE200K     0.969744
# 215124               Unemployment compensation Amt GE200K     0.999579
# 215125                Unemployment compensation Amt LT25K     0.993198
# 215126                Unemployment compensation Amt LT25K     0.968531
# 215127                Unemployment compensation Amt LT25K     0.989717
# 215128                Unemployment compensation Amt LT25K     0.997861
# 215129                Unemployment compensation Amt LT25K     0.957563
# 215130            Unemployment compensation Ct 100KLT200K     0.974225
# 215131            Unemployment compensation Ct 100KLT200K     0.991434
# 215132            Unemployment compensation Ct 100KLT200K     0.955625
# 215133            Unemployment compensation Ct 100KLT200K     0.966139
# 215134            Unemployment compensation Ct 100KLT200K     0.962792
# 215135              Unemployment compensation Ct 25KLT50K     0.988335
# 215136              Unemployment compensation Ct 25KLT50K     0.960548
# 215137              Unemployment compensation Ct 25KLT50K     0.998584
# 215138              Unemployment compensation Ct 25KLT50K     0.988040
# 215139              Unemployment compensation Ct 25KLT50K     0.951770
# 215140              Unemployment compensation Ct 25KLT50K     0.964383
# 215141              Unemployment compensation Ct 25KLT50K     0.973894
# 215142              Unemployment compensation Ct 25KLT50K     0.954609
# 215143              Unemployment compensation Ct 50KLT75K     0.985828
# 215144              Unemployment compensation Ct 50KLT75K     0.993370
# 215145              Unemployment compensation Ct 50KLT75K     0.963159
# 215146              Unemployment compensation Ct 50KLT75K     0.965873
# 215147              Unemployment compensation Ct 50KLT75K     0.961018
# 215148              Unemployment compensation Ct 50KLT75K     0.962182
# 215149             Unemployment compensation Ct 75KLT100K     0.969033
# 215150             Unemployment compensation Ct 75KLT100K     0.974420
# 215151             Unemployment compensation Ct 75KLT100K     0.961026
# 215152             Unemployment compensation Ct 75KLT100K     0.955273
# 215153             Unemployment compensation Ct 75KLT100K     0.958453
# 215154                   Unemployment compensation Ct All     0.985541
# 215155                   Unemployment compensation Ct All     0.957750
# 215156                   Unemployment compensation Ct All     0.965006
# 215157                   Unemployment compensation Ct All     0.971705
# 215158                   Unemployment compensation Ct All     0.950834
# 215159                      Attrtion_Reason_TotalTeachers     0.989828
# 215160                      Attrtion_Reason_TotalTeachers     0.979535
# 215161                      Attrtion_Reason_TotalTeachers     0.971736
# 215162                      Attrtion_Reason_TotalTeachers     0.962051
# 215163                    Attrtion_Reason_TeachersLeaving     0.995150
# 215164                    Attrtion_Reason_TeachersLeaving     0.973073
# 215165                    Attrtion_Reason_TeachersLeaving     0.985494
# 215166                    Attrtion_Reason_PersonalReasons     0.955700
# 215167                    Attrtion_Reason_PersonalReasons     0.980402
# 215168                     Attrtion_Reason_InitiatedbyLEA     0.955267
# 215169                                      category_cd_E     1.000000
# 215170                                      category_cd_H     1.000000
# 215171                                      category_cd_I     1.000000
# 215172                                      category_cd_M     1.000000
# 215173                                      category_cd_T     1.000000
# 215174                  calendar_type_txt_Hospital School     1.000000
# 215175                  calendar_type_txt_Hospital School     1.000000
# 215176  calendar_type_txt_Magnet School, Traditional C...     1.000000
# 215177  calendar_type_txt_Magnet School, Traditional C...     0.981760
# 215178  calendar_type_txt_Magnet School, Year-Round Ca...     1.000000
# 215179  calendar_type_txt_Regular School, Traditional ...     1.000000
# 215180  calendar_type_txt_Regular School, Traditional ...     1.000000
# 215181  calendar_type_txt_Regular School, Traditional ...     1.000000
# 215182  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 215183  calendar_type_txt_Regular School, Year-Round C...     0.979158
# 215184  calendar_type_txt_Special Education, Tradition...     1.000000
# 215185  calendar_type_txt_Special Education, Tradition...     1.000000
# 215186                                  sna_pgm_type_cd_H     1.000000
# 215187                                  sna_pgm_type_cd_M     0.981760
# 215188                                  sna_pgm_type_cd_S     1.000000
# 215189                                  sna_pgm_type_cd_X     1.000000
# 215190                                  sna_pgm_type_cd_Y     0.979158
# 215191                                     SPG Grade_A+NG     1.000000
#
# [215192 rows x 3 columns]

# %%
print( 'Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  1086  highly correlated fields.
# ['Math SPG Score',
#  'Overall Achievement Score',
#  'Read Score',
#  'Math Score',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_CACR_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_CACR_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOCMathI_CACR_Female',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_CACR_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_CACR_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_CACR_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_CACR_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_CACR_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr4_CACR_Female',
#  'EOGReadingGr4_GLP_Female',
#  'EOGReadingGr5_CACR_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_CACR_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOCMathI_CACR_Male',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_CACR_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_CACR_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_CACR_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_CACR_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr4_CACR_Male',
#  'EOGReadingGr4_GLP_Male',
#  'EOGReadingGr5_CACR_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_CACR_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_CACR_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_CACR_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_CACR_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr3_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGReadingGr3_GLP_Black',
#  'EOGReadingGr3-8_GLP_Black',
#  'EOGReadingGr4_GLP_Black',
#  'EOGReadingGr5_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_GLP_Black',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_CACR_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_Hispanic',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGReadingGr3_GLP_Hispanic',
#  'EOGReadingGr3-8_GLP_Hispanic',
#  'EOGReadingGr4_GLP_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr3-8_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_CACR_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_CACR_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_CACR_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_CACR_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_CACR_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_CACR_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_CACR_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_CACR_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_CACR_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_CACR_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_CACR_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_CACR_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3_CACR_EDS',
#  'EOGMathGr3_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_CACR_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_CACR_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3_CACR_EDS',
#  'EOGReadingGr3_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGReadingGr4_CACR_EDS',
#  'EOGReadingGr4_GLP_EDS',
#  'EOGReadingGr5_GLP_EDS',
#  'EOGScienceGr5_CACR_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOGGr5_GLP_LEP',
#  'EOGMathGr3_GLP_LEP',
#  'EOGMathGr5_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOCSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGGr4_GLP_SWD',
#  'EOGGr5_GLP_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_CACR_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'pct_PROMOTED',
#  'st_books_per_student',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'lea_not_highqual_class_all_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_class_teach_num',
#  'st_nbpts_num',
#  'st_advance_dgr_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'HispanicMalePct',
#  'BlackMalePct',
#  'WhiteMalePct',
#  'MinorityMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'HispanicFemalePct',
#  'BlackFemalePct',
#  'WhiteFemalePct',
#  'MinorityFemalePct',
#  'Crime_Rate_Property_Rate',
#  'Crime_Rate_Assault_Rate',
#  'Crime_Rate_Larceny_Rate',
#  '(TCE) prepared returns Ct 50KLT75K',
#  '(TCE) prepared returns Ct All',
#  '(TCE) prepared returns Ct LT25K',
#  '(VITA) prepared returns Ct 75KLT100K',
#  '(VITA) prepared returns Ct All',
#  '(VITA) prepared returns Ct LT25K',
#  'Add Medicare tax Amt 100KLT200K',
#  'Add Medicare tax Amt All',
#  'Add Medicare tax Amt GE200K',
#  'Add Medicare tax Ct 100KLT200K',
#  'Add Medicare tax Ct All',
#  'Add Medicare tax Ct GE200K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Advance premium tax credit Amt 100KLT200K',
#  'Advance premium tax credit Amt 25KLT50K',
#  'Advance premium tax credit Amt 50KLT75K',
#  'Advance premium tax credit Amt 75KLT100K',
#  'Advance premium tax credit Amt All',
#  'Advance premium tax credit Amt LT25K',
#  'Advance premium tax credit Ct 100KLT200K',
#  'Advance premium tax credit Ct 25KLT50K',
#  'Advance premium tax credit Ct 50KLT75K',
#  'Advance premium tax credit Ct 75KLT100K',
#  'Advance premium tax credit Ct All',
#  'Advance premium tax credit Ct LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct 75KLT100K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Alternative minimum tax Ct LT25K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Contributions Amt 100KLT200K',
#  'Contributions Amt 25KLT50K',
#  'Contributions Amt 50KLT75K',
#  'Contributions Amt 75KLT100K',
#  'Contributions Amt All',
#  'Contributions Amt GE200K',
#  'Contributions Amt LT25K',
#  'Contributions Ct 100KLT200K',
#  'Contributions Ct 25KLT50K',
#  'Contributions Ct 50KLT75K',
#  'Contributions Ct 75KLT100K',
#  'Contributions Ct All',
#  'Contributions Ct GE200K',
#  'Contributions Ct LT25K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct 50KLT75K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess advance premium tax credit repayment Amt 100KLT200K',
#  'Excess advance premium tax credit repayment Amt 25KLT50K',
#  'Excess advance premium tax credit repayment Amt 50KLT75K',
#  'Excess advance premium tax credit repayment Amt 75KLT100K',
#  'Excess advance premium tax credit repayment Amt All',
#  'Excess advance premium tax credit repayment Amt LT25K',
#  'Excess advance premium tax credit repayment Ct 100KLT200K',
#  'Excess advance premium tax credit repayment Ct 25KLT50K',
#  'Excess advance premium tax credit repayment Ct 50KLT75K',
#  'Excess advance premium tax credit repayment Ct 75KLT100K',
#  'Excess advance premium tax credit repayment Ct All',
#  'Excess advance premium tax credit repayment Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct 50KLT75K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'Health care individual responsibility payment Amt 100KLT200K',
#  'Health care individual responsibility payment Amt 25KLT50K',
#  'Health care individual responsibility payment Amt 50KLT75K',
#  'Health care individual responsibility payment Amt 75KLT100K',
#  'Health care individual responsibility payment Amt All',
#  'Health care individual responsibility payment Amt LT25K',
#  'Health care individual responsibility payment Ct 100KLT200K',
#  'Health care individual responsibility payment Ct 25KLT50K',
#  'Health care individual responsibility payment Ct 50KLT75K',
#  'Health care individual responsibility payment Ct 75KLT100K',
#  'Health care individual responsibility payment Ct All',
#  'Health care individual responsibility payment Ct LT25K',
#  'IRA payments Amt 100KLT200K',
#  'IRA payments Amt 25KLT50K',
#  'IRA payments Amt 50KLT75K',
#  'IRA payments Amt 75KLT100K',
#  'IRA payments Amt All',
#  'IRA payments Amt GE200K',
#  'IRA payments Amt LT25K',
#  'IRA payments Ct 100KLT200K',
#  'IRA payments Ct 25KLT50K',
#  'IRA payments Ct 50KLT75K',
#  'IRA payments Ct 75KLT100K',
#  'IRA payments Ct All',
#  'IRA payments Ct GE200K',
#  'IRA payments Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Mortgage interest paid Amt 100KLT200K',
#  'Mortgage interest paid Amt 25KLT50K',
#  'Mortgage interest paid Amt 50KLT75K',
#  'Mortgage interest paid Amt 75KLT100K',
#  'Mortgage interest paid Amt All',
#  'Mortgage interest paid Amt GE200K',
#  'Mortgage interest paid Amt LT25K',
#  'Mortgage interest paid Ct 100KLT200K',
#  'Mortgage interest paid Ct 25KLT50K',
#  'Mortgage interest paid Ct 50KLT75K',
#  'Mortgage interest paid Ct 75KLT100K',
#  'Mortgage interest paid Ct All',
#  'Mortgage interest paid Ct GE200K',
#  'Mortgage interest paid Ct LT25K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Net premium tax credit Amt 25KLT50K',
#  'Net premium tax credit Amt All',
#  'Net premium tax credit Amt LT25K',
#  'Net premium tax credit Ct 25KLT50K',
#  'Net premium tax credit Ct 50KLT75K',
#  'Net premium tax credit Ct All',
#  'Net premium tax credit Ct LT25K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  'Number of volunteer prepared returns Tot 100KLT200K',
#  'Number of volunteer prepared returns Tot 25KLT50K',
#  'Number of volunteer prepared returns Tot 75KLT100K',
#  'Number of volunteer prepared returns Tot All',
#  'Number of volunteer prepared returns Tot LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Amt LT25K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Residential energy tax credit Ct LT25K',
#  'Retirement savings contribution credit Amt 25KLT50K',
#  'Retirement savings contribution credit Amt 50KLT75K',
#  'Retirement savings contribution credit Amt All',
#  'Retirement savings contribution credit Amt LT25K',
#  'Retirement savings contribution credit Ct 25KLT50K',
#  'Retirement savings contribution credit Ct 50KLT75K',
#  'Retirement savings contribution credit Ct All',
#  'Retirement savings contribution credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employment health insurance deduction Amt 100KLT200K',
#  'Self-employment health insurance deduction Amt 25KLT50K',
#  'Self-employment health insurance deduction Amt 50KLT75K',
#  'Self-employment health insurance deduction Amt 75KLT100K',
#  'Self-employment health insurance deduction Amt All',
#  'Self-employment health insurance deduction Amt GE200K',
#  'Self-employment health insurance deduction Amt LT25K',
#  'Self-employment health insurance deduction Ct 100KLT200K',
#  'Self-employment health insurance deduction Ct 25KLT50K',
#  'Self-employment health insurance deduction Ct 50KLT75K',
#  'Self-employment health insurance deduction Ct 75KLT100K',
#  'Self-employment health insurance deduction Ct All',
#  'Self-employment health insurance deduction Ct GE200K',
#  'Self-employment health insurance deduction Ct LT25K',
#  'Self-employment retirement plans Amt 100KLT200K',
#  'Self-employment retirement plans Amt 50KLT75K',
#  'Self-employment retirement plans Amt All',
#  'Self-employment retirement plans Amt GE200K',
#  'Self-employment retirement plans Ct 100KLT200K',
#  'Self-employment retirement plans Ct 25KLT50K',
#  'Self-employment retirement plans Ct 50KLT75K',
#  'Self-employment retirement plans Ct 75KLT100K',
#  'Self-employment retirement plans Ct All',
#  'Self-employment retirement plans Ct GE200K',
#  'Self-employment retirement plans Ct LT25K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  'Taxable interest Ct 100KLT200K',
#  'Taxable interest Ct 25KLT50K',
#  'Taxable interest Ct 50KLT75K',
#  'Taxable interest Ct 75KLT100K',
#  'Taxable interest Ct All',
#  'Taxable interest Ct GE200K',
#  'Taxable interest Ct LT25K',
#  'Taxes paid Amt 100KLT200K',
#  'Taxes paid Amt 25KLT50K',
#  'Taxes paid Amt 50KLT75K',
#  'Taxes paid Amt 75KLT100K',
#  'Taxes paid Amt All',
#  'Taxes paid Amt GE200K',
#  'Taxes paid Amt LT25K',
#  'Taxes paid Ct 100KLT200K',
#  'Taxes paid Ct 25KLT50K',
#  'Taxes paid Ct 50KLT75K',
#  'Taxes paid Ct 75KLT100K',
#  'Taxes paid Ct All',
#  'Taxes paid Ct GE200K',
#  'Taxes paid Ct LT25K',
#  'Tot income Amt 100KLT200K',
#  'Tot income Amt 25KLT50K',
#  'Tot income Amt 50KLT75K',
#  'Tot income Amt 75KLT100K',
#  'Tot income Amt All',
#  'Tot income Amt GE200K',
#  'Tot income Amt LT25K',
#  'Tot income Ct 100KLT200K',
#  'Tot income Ct 25KLT50K',
#  'Tot income Ct 50KLT75K',
#  'Tot income Ct 75KLT100K',
#  'Tot income Ct All',
#  'Tot income Ct GE200K',
#  'Tot income Ct LT25K',
#  'Tot itemized deductions Amt 100KLT200K',
#  'Tot itemized deductions Amt 25KLT50K',
#  'Tot itemized deductions Amt 50KLT75K',
#  'Tot itemized deductions Amt 75KLT100K',
#  'Tot itemized deductions Amt All',
#  'Tot itemized deductions Amt GE200K',
#  'Tot itemized deductions Amt LT25K',
#  'Tot itemized deductions Amt of AGI 100KLT200K',
#  'Tot itemized deductions Amt of AGI 25KLT50K',
#  'Tot itemized deductions Amt of AGI 50KLT75K',
#  'Tot itemized deductions Amt of AGI 75KLT100K',
#  'Tot itemized deductions Amt of AGI All',
#  'Tot itemized deductions Amt of AGI GE200K',
#  'Tot itemized deductions Amt of AGI LT25K',
#  'Tot itemized deductions Ct 100KLT200K',
#  'Tot itemized deductions Ct 25KLT50K',
#  'Tot itemized deductions Ct 50KLT75K',
#  'Tot itemized deductions Ct 75KLT100K',
#  'Tot itemized deductions Ct All',
#  'Tot itemized deductions Ct GE200K',
#  'Tot itemized deductions Ct LT25K',
#  'Tot premium tax credit Amt 25KLT50K',
#  'Tot premium tax credit Amt 50KLT75K',
#  'Tot premium tax credit Amt All',
#  'Tot premium tax credit Amt LT25K',
#  'Tot premium tax credit Ct 25KLT50K',
#  'Tot premium tax credit Ct 50KLT75K',
#  'Tot premium tax credit Ct 75KLT100K',
#  'Tot premium tax credit Ct All',
#  'Tot premium tax credit Ct LT25K',
#  'Tot statuory adjustments Amt 100KLT200K',
#  'Tot statuory adjustments Amt 25KLT50K',
#  'Tot statuory adjustments Amt 50KLT75K',
#  'Tot statuory adjustments Amt 75KLT100K',
#  'Tot statuory adjustments Amt All',
#  'Tot statuory adjustments Amt GE200K',
#  'Tot statuory adjustments Amt LT25K',
#  'Tot statuory adjustments Ct 100KLT200K',
#  'Tot statuory adjustments Ct 25KLT50K',
#  'Tot statuory adjustments Ct 50KLT75K',
#  'Tot statuory adjustments Ct 75KLT100K',
#  'Tot statuory adjustments Ct All',
#  'Tot statuory adjustments Ct GE200K',
#  'Tot statuory adjustments Ct LT25K',
#  'Tot tax credits Amt 100KLT200K',
#  'Tot tax credits Amt 25KLT50K',
#  'Tot tax credits Amt 50KLT75K',
#  'Tot tax credits Amt 75KLT100K',
#  'Tot tax credits Amt All',
#  'Tot tax credits Amt GE200K',
#  ...]

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1490 entries, closed_ind to lea_avg_age_media_collection_2010
# dtypes: float64(1410), uint8(80)
# memory usage: 26.4 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 404 entries, closed_ind to lea_avg_age_media_collection_2010
# dtypes: float64(344), uint8(60)
# memory usage: 6.5 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Data columns (total 405 columns):
# closed_ind                                                                         float64
# student_num                                                                        float64
# lea_avg_student_num                                                                float64
# st_avg_student_num                                                                 float64
# 00_Size                                                                            float64
# 01_Size                                                                            float64
# 02_Size                                                                            float64
# 03_Size                                                                            float64
# 04_Size                                                                            float64
# 05_Size                                                                            float64
# Math I_Size                                                                        float64
# lea_total_expense_num                                                              float64
# lea_salary_expense_pct                                                             float64
# lea_benefits_expense_pct                                                           float64
# lea_services_expense_pct                                                           float64
# lea_supplies_expense_pct                                                           float64
# lea_instruct_equip_exp_pct                                                         float64
# lea_federal_perpupil_num                                                           float64
# lea_local_perpupil_num                                                             float64
# lea_state_perpupil_num                                                             float64
# SPG Score                                                                          float64
# Reading  SPG Score                                                                 float64
# EVAAS Growth Score                                                                 float64
# Science Score                                                                      float64
# Math I Score                                                                       float64
# EOG/EOCSubjects_CACR_All                                                           float64
# EOGGr3_CACR_All                                                                    float64
# EOGGr4_CACR_All                                                                    float64
# EOGGr5_CACR_All                                                                    float64
# EOCMathI_CACR_AmericanIndian                                                       float64
# EOCSubjects_CACR_AmericanIndian                                                    float64
# EOG/EOCSubjects_CACR_AmericanIndian                                                float64
# EOGGr3_CACR_AmericanIndian                                                         float64
# EOGGr4_CACR_AmericanIndian                                                         float64
# EOGGr5_CACR_AmericanIndian                                                         float64
# EOGMathGr3_CACR_AmericanIndian                                                     float64
# EOGMathGr3-8_CACR_AmericanIndian                                                   float64
# EOGMathGr4_CACR_AmericanIndian                                                     float64
# EOGMathGr5_CACR_AmericanIndian                                                     float64
# EOGReadingGr3_CACR_AmericanIndian                                                  float64
# EOGReadingGr3-8_CACR_AmericanIndian                                                float64
# EOGReadingGr5_CACR_AmericanIndian                                                  float64
# EOGReadingGr5_GLP_AmericanIndian                                                   float64
# EOGScienceGr5_CACR_AmericanIndian                                                  float64
# EOGScienceGr5&8_CACR_AmericanIndian                                                float64
# EOGSubjects_CACR_AmericanIndian                                                    float64
# EOCMathI_CACR_Asian                                                                float64
# EOCSubjects_CACR_Asian                                                             float64
# EOG/EOCSubjects_CACR_Asian                                                         float64
# EOGGr3_CACR_Asian                                                                  float64
# EOGGr4_CACR_Asian                                                                  float64
# EOGGr5_CACR_Asian                                                                  float64
# EOGMathGr3_CACR_Asian                                                              float64
# EOGMathGr3-8_CACR_Asian                                                            float64
# EOGMathGr4_CACR_Asian                                                              float64
# EOGMathGr5_CACR_Asian                                                              float64
# EOGScienceGr5&8_CACR_Asian                                                         float64
# EOGSubjects_CACR_Asian                                                             float64
# EOCMathI_CACR_Black                                                                float64
# EOG/EOCSubjects_CACR_Black                                                         float64
# EOGGr3_CACR_Black                                                                  float64
# EOGGr4_CACR_Black                                                                  float64
# EOGGr5_CACR_Black                                                                  float64
# EOGMathGr3_CACR_Black                                                              float64
# EOGMathGr3-8_CACR_Black                                                            float64
# EOGMathGr4_CACR_Black                                                              float64
# EOGMathGr5_CACR_Black                                                              float64
# EOGReadingGr3_CACR_Black                                                           float64
# EOGReadingGr3-8_CACR_Black                                                         float64
# EOGReadingGr4_CACR_Black                                                           float64
# EOGReadingGr5_CACR_Black                                                           float64
# EOGScienceGr5_CACR_Black                                                           float64
# EOGScienceGr5&8_CACR_Black                                                         float64
# EOGSubjects_CACR_Black                                                             float64
# EOCMathI_CACR_Hispanic                                                             float64
# EOG/EOCSubjects_CACR_Hispanic                                                      float64
# EOGGr3_CACR_Hispanic                                                               float64
# EOGGr4_CACR_Hispanic                                                               float64
# EOGGr5_CACR_Hispanic                                                               float64
# EOGMathGr3_CACR_Hispanic                                                           float64
# EOGMathGr3-8_CACR_Hispanic                                                         float64
# EOGMathGr4_CACR_Hispanic                                                           float64
# EOGMathGr5_CACR_Hispanic                                                           float64
# EOGReadingGr3_CACR_Hispanic                                                        float64
# EOGReadingGr3-8_CACR_Hispanic                                                      float64
# EOGReadingGr4_CACR_Hispanic                                                        float64
# EOGReadingGr5_CACR_Hispanic                                                        float64
# EOGReadingGr5_GLP_Hispanic                                                         float64
# EOGScienceGr5_CACR_Hispanic                                                        float64
# EOGScienceGr5&8_CACR_Hispanic                                                      float64
# EOGSubjects_CACR_Hispanic                                                          float64
# EOCMathI_CACR_TwoorMoreRaces                                                       float64
# EOCSubjects_CACR_TwoorMoreRaces                                                    float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                                                float64
# EOGGr3_CACR_TwoorMoreRaces                                                         float64
# EOGGr4_CACR_TwoorMoreRaces                                                         float64
# EOGGr5_CACR_TwoorMoreRaces                                                         float64
# EOGMathGr3_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                                                   float64
# EOGMathGr4_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr5_CACR_TwoorMoreRaces                                                     float64
# EOGReadingGr3_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                                                float64
# EOGReadingGr4_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                                                float64
# EOGSubjects_CACR_TwoorMoreRaces                                                    float64
# EOCMathI_CACR_White                                                                float64
# EOG/EOCSubjects_CACR_White                                                         float64
# EOGGr4_CACR_White                                                                  float64
# EOGGr5_CACR_White                                                                  float64
# EOGMathGr3-8_CACR_White                                                            float64
# EOGMathGr5_CACR_White                                                              float64
# EOGScienceGr5&8_CACR_White                                                         float64
# EOCMathI_CACR_EDS                                                                  float64
# EOG/EOCSubjects_CACR_EDS                                                           float64
# EOGGr5_CACR_EDS                                                                    float64
# EOGMathGr3-8_CACR_EDS                                                              float64
# EOGReadingGr3-8_CACR_EDS                                                           float64
# EOGReadingGr5_CACR_EDS                                                             float64
# EOGScienceGr5&8_CACR_EDS                                                           float64
# EOCMathI_CACR_LEP                                                                  float64
# EOCMathI_GLP_LEP                                                                   float64
# EOCSubjects_CACR_LEP                                                               float64
# EOCSubjects_GLP_LEP                                                                float64
# EOG/EOCSubjects_CACR_LEP                                                           float64
# EOG/EOCSubjects_GLP_LEP                                                            float64
# EOGGr3_CACR_LEP                                                                    float64
# EOGGr3_GLP_LEP                                                                     float64
# EOGGr4_CACR_LEP                                                                    float64
# EOGGr4_GLP_LEP                                                                     float64
# EOGGr5_CACR_LEP                                                                    float64
# EOGMathGr3_CACR_LEP                                                                float64
# EOGMathGr3-8_CACR_LEP                                                              float64
# EOGMathGr3-8_GLP_LEP                                                               float64
# EOGMathGr4_CACR_LEP                                                                float64
# EOGMathGr4_GLP_LEP                                                                 float64
# EOGMathGr5_CACR_LEP                                                                float64
# EOGReadingGr3_CACR_LEP                                                             float64
# EOGReadingGr3_GLP_LEP                                                              float64
# EOGReadingGr3-8_CACR_LEP                                                           float64
# EOGReadingGr3-8_GLP_LEP                                                            float64
# EOGReadingGr4_CACR_LEP                                                             float64
# EOGReadingGr4_GLP_LEP                                                              float64
# EOGReadingGr5_CACR_LEP                                                             float64
# EOGReadingGr5_GLP_LEP                                                              float64
# EOGScienceGr5_CACR_LEP                                                             float64
# EOGScienceGr5_GLP_LEP                                                              float64
# EOGScienceGr5&8_CACR_LEP                                                           float64
# EOGScienceGr5&8_GLP_LEP                                                            float64
# EOGSubjects_GLP_LEP                                                                float64
# EOCMathI_CACR_SWD                                                                  float64
# EOCMathI_GLP_SWD                                                                   float64
# EOCSubjects_CACR_SWD                                                               float64
# EOG/EOCSubjects_CACR_SWD                                                           float64
# EOGGr3_CACR_SWD                                                                    float64
# EOGGr3_GLP_SWD                                                                     float64
# EOGGr4_CACR_SWD                                                                    float64
# EOGGr5_CACR_SWD                                                                    float64
# EOGMathGr3_CACR_SWD                                                                float64
# EOGMathGr3_GLP_SWD                                                                 float64
# EOGMathGr3-8_CACR_SWD                                                              float64
# EOGMathGr3-8_GLP_SWD                                                               float64
# EOGMathGr4_CACR_SWD                                                                float64
# EOGMathGr4_GLP_SWD                                                                 float64
# EOGMathGr5_CACR_SWD                                                                float64
# EOGMathGr5_GLP_SWD                                                                 float64
# EOGReadingGr3_CACR_SWD                                                             float64
# EOGReadingGr3_GLP_SWD                                                              float64
# EOGReadingGr3-8_CACR_SWD                                                           float64
# EOGReadingGr3-8_GLP_SWD                                                            float64
# EOGReadingGr4_CACR_SWD                                                             float64
# EOGReadingGr4_GLP_SWD                                                              float64
# EOGReadingGr5_CACR_SWD                                                             float64
# EOGReadingGr5_GLP_SWD                                                              float64
# EOGScienceGr5_CACR_SWD                                                             float64
# EOGScienceGr5_GLP_SWD                                                              float64
# EOGScienceGr5&8_CACR_SWD                                                           float64
# EOGScienceGr5&8_GLP_SWD                                                            float64
# EOGSubjects_CACR_SWD                                                               float64
# EOCMathI_CACR_AIG                                                                  float64
# EOG/EOCSubjects_CACR_AIG                                                           float64
# EOGGr3_CACR_AIG                                                                    float64
# EOGGr4_CACR_AIG                                                                    float64
# EOGGr5_CACR_AIG                                                                    float64
# EOGMathGr3_CACR_AIG                                                                float64
# EOGMathGr3-8_CACR_AIG                                                              float64
# EOGMathGr4_CACR_AIG                                                                float64
# EOGMathGr5_CACR_AIG                                                                float64
# EOGScienceGr5&8_CACR_AIG                                                           float64
# EOGSubjects_CACR_AIG                                                               float64
# pct_GCE_ALL                                                                        float64
# MathGr3-8_pTarget_PctMet                                                           float64
# ReadingGr3-8_pTarget_PctMet                                                        float64
# SciGr5&8_pTarget_PctMet                                                            float64
# TotalTargets_pTarget_PctMet                                                        float64
# lea_sat_avg_score_num                                                              float64
# lea_sat_participation_pct                                                          float64
# lea_ap_participation_pct                                                           float64
# lea_ap_pct_3_or_above                                                              float64
# lea_ib_pct_4_or_above                                                              float64
# avg_daily_attend_pct                                                               float64
# crime_per_c_num                                                                    float64
# short_susp_per_c_num                                                               float64
# long_susp_per_c_num                                                                float64
# expelled_per_c_num                                                                 float64
# stud_internet_comp_num                                                             float64
# lea_avg_daily_attend_pct                                                           float64
# lea_crime_per_c_num                                                                float64
# lea_short_susp_per_c_num                                                           float64
# lea_long_susp_per_c_num                                                            float64
# lea_expelled_per_c_num                                                             float64
# lea_stud_internet_comp_num                                                         float64
# st_avg_daily_attend_pct                                                            float64
# st_crime_per_c_num                                                                 float64
# st_short_susp_per_c_num                                                            float64
# digital_media_pct                                                                  float64
# books_per_student                                                                  float64
# lea_books_per_student                                                              float64
# st_avg_age_media_collection                                                        float64
# flicensed_teach_pct                                                                float64
# tchyrs_0thru3_pct                                                                  float64
# tchyrs_4thru10_pct                                                                 float64
# tchyrs_11plus_pct                                                                  float64
# nbpts_num                                                                          float64
# advance_dgr_pct                                                                    float64
# _1yr_tchr_trnovr_pct                                                               float64
# lateral_teach_pct                                                                  float64
# highqual_class_pct                                                                 float64
# lea_flicensed_teach_pct                                                            float64
# lea_tchyrs_0thru3_pct                                                              float64
# lea_tchyrs_4thru10_pct                                                             float64
# lea_tchyrs_11plus_pct                                                              float64
# lea_nbpts_num                                                                      float64
# lea_advance_dgr_pct                                                                float64
# lea_1yr_tchr_trnovr_pct                                                            float64
# lea_emer_prov_teach_pct                                                            float64
# lea_highqual_class_pct                                                             float64
# lea_highqual_class_hp_pct                                                          float64
# lea_highqual_class_lp_pct                                                          float64
# lea_highqual_class_all_pct                                                         float64
# lea_not_highqual_class_hp_pct                                                      float64
# lea_not_highqual_class_lp_pct                                                      float64
# st_flicensed_teach_pct                                                             float64
# st_tchyrs_0thru3_pct                                                               float64
# st_tchyrs_11plus_pct                                                               float64
# st_1yr_tchr_trnovr_pct                                                             float64
# st_emer_prov_teach_pct                                                             float64
# st_highqual_class_pct                                                              float64
# 0-3 Years_LEA_Exp_Pct_Prin                                                         float64
# 10+ Years_LEA_Exp_Pct_Prin                                                         float64
# 4-10 Years_LEA_Exp_Pct_Prin                                                        float64
# Accomplished_TCHR_Standard 1_Pct                                                   float64
# Accomplished_TCHR_Standard 2_Pct                                                   float64
# Accomplished_TCHR_Standard 3_Pct                                                   float64
# Accomplished_TCHR_Standard 4_Pct                                                   float64
# Accomplished_TCHR_Standard 5_Pct                                                   float64
# Developing_TCHR_Standard 1_Pct                                                     float64
# Developing_TCHR_Standard 2_Pct                                                     float64
# Developing_TCHR_Standard 3_Pct                                                     float64
# Developing_TCHR_Standard 4_Pct                                                     float64
# Developing_TCHR_Standard 5_Pct                                                     float64
# Distinguished_TCHR_Standard 1_Pct                                                  float64
# Distinguished_TCHR_Standard 2_Pct                                                  float64
# Distinguished_TCHR_Standard 3_Pct                                                  float64
# Distinguished_TCHR_Standard 4_Pct                                                  float64
# Distinguished_TCHR_Standard 5_Pct                                                  float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct                                  float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct                                        float64
# Meets Expected Growth_TCHR_Standard 6_Pct                                          float64
# Not Demostrated_TCHR_Standard 1_Pct                                                float64
# Not Demostrated_TCHR_Standard 2_Pct                                                float64
# Not Demostrated_TCHR_Standard 3_Pct                                                float64
# Not Demostrated_TCHR_Standard 4_Pct                                                float64
# Not Demostrated_TCHR_Standard 5_Pct                                                float64
# Proficient_TCHR_Standard 1_Pct                                                     float64
# Proficient_TCHR_Standard 2_Pct                                                     float64
# Proficient_TCHR_Standard 3_Pct                                                     float64
# Proficient_TCHR_Standard 4_Pct                                                     float64
# Proficient_TCHR_Standard 5_Pct                                                     float64
# IndianPct                                                                          float64
# AsianPct                                                                           float64
# HispanicPct                                                                        float64
# BlackPct                                                                           float64
# WhitePct                                                                           float64
# PacificIslandPct                                                                   float64
# TwoOrMorePct                                                                       float64
# PacificIslandMalePct                                                               float64
# TwoOrMoreMalePct                                                                   float64
# PacificIslandFemalePct                                                             float64
# TwoOrMoreFemalePct                                                                 float64
# Year                                                                               float64
# Crime_Rate_Index_Rate                                                              float64
# Crime_Rate_Violent_Rate                                                            float64
# Crime_Rate_Murder_Rate                                                             float64
# Crime_Rate_Rape_Rate                                                               float64
# Crime_Rate_Robbery_Rate                                                            float64
# Crime_Rate_Burglary_Rate                                                           float64
# Crime_Rate_MVT_Rate                                                                float64
# Crime_Rate_Arson_Rate                                                              float64
# (TCE) prepared returns Ct 25KLT50K                                                 float64
# (TCE) prepared returns Ct 75KLT100K                                                float64
# (VITA) prepared returns Ct 100KLT200K                                              float64
# (VITA) prepared returns Ct 25KLT50K                                                float64
# (VITA) prepared returns Ct 50KLT75K                                                float64
# Add child tax credit Amt 25KLT50K                                                  float64
# Add child tax credit Amt 75KLT100K                                                 float64
# Alternative minimum tax Amt 25KLT50K                                               float64
# Alternative minimum tax Amt 50KLT75K                                               float64
# Alternative minimum tax Amt 75KLT100K                                              float64
# Alternative minimum tax Amt LT25K                                                  float64
# Alternative minimum tax Ct 50KLT75K                                                float64
# Domestic production activities deduction Amt 100KLT200K                            float64
# Domestic production activities deduction Amt 25KLT50K                              float64
# Domestic production activities deduction Amt 50KLT75K                              float64
# Domestic production activities deduction Amt 75KLT100K                             float64
# Domestic production activities deduction Amt LT25K                                 float64
# Domestic production activities deduction Ct 100KLT200K                             float64
# Domestic production activities deduction Ct 25KLT50K                               float64
# Domestic production activities deduction Ct 50KLT75K                               float64
# Domestic production activities deduction Ct 75KLT100K                              float64
# Domestic production activities deduction Ct LT25K                                  float64
# Earned income credit Amt 50KLT75K                                                  float64
# Excess earned income credit (refundable) Amt 50KLT75K                              float64
# Net premium tax credit Amt 50KLT75K                                                float64
# Number of farm returns 100KLT200K                                                  float64
# Number of farm returns 25KLT50K                                                    float64
# Number of farm returns 50KLT75K                                                    float64
# Number of farm returns 75KLT100K                                                   float64
# Number of farm returns All                                                         float64
# Number of farm returns GE200K                                                      float64
# Number of farm returns LT25K                                                       float64
# Number of volunteer prepared returns Tot 50KLT75K                                  float64
# Residential energy tax credit Amt LT25K                                            float64
# Self-employment retirement plans Amt 25KLT50K                                      float64
# Self-employment retirement plans Amt 75KLT100K                                     float64
# Self-employment retirement plans Amt LT25K                                         float64
# State and local general sales taxes Amt GE200K                                     float64
# Tot premium tax credit Amt 75KLT100K                                               float64
# Tuition and fees deduction Amt 75KLT100K                                           float64
# LEACode                                                                            float64
# Attrtion_Reason_RemainedinEducation                                                float64
# Attrtion_Reason_OtherReasons                                                       float64
# category_cd_E                                                                      uint8
# category_cd_I                                                                      uint8
# category_cd_T                                                                      uint8
# calendar_type_txt_Hospital School                                                  uint8
# calendar_type_txt_Magnet School, Traditional Calendar                              uint8
# calendar_type_txt_Magnet School, Year-Round Calendar                               uint8
# calendar_type_txt_Regular School, Traditional Calendar                             uint8
# calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar    uint8
# calendar_type_txt_Regular School, Year-Round Calendar                              uint8
# calendar_type_txt_Special Education, Traditional Calendar                          uint8
# school_type_txt_Regular School                                                     uint8
# esea_status_P                                                                      uint8
# esea_status_R                                                                      uint8
# esea_status_RF                                                                     uint8
# Grad_project_status_Y                                                              uint8
# SBE District_Northeast                                                             uint8
# SBE District_Northwest                                                             uint8
# SBE District_Piedmont-Triad                                                        uint8
# SBE District_Sandhills                                                             uint8
# SBE District_Southeast                                                             uint8
# SBE District_Southwest                                                             uint8
# SBE District_Western                                                               uint8
# SPG Grade_A+NG                                                                     uint8
# SPG Grade_B                                                                        uint8
# SPG Grade_C                                                                        uint8
# SPG Grade_D                                                                        uint8
# SPG Grade_F                                                                        uint8
# SPG Grade_I                                                                        uint8
# Reading SPG Grade_B                                                                uint8
# Reading SPG Grade_C                                                                uint8
# Reading SPG Grade_D                                                                uint8
# Reading SPG Grade_F                                                                uint8
# Math SPG Grade_B                                                                   uint8
# Math SPG Grade_C                                                                   uint8
# Math SPG Grade_D                                                                   uint8
# Math SPG Grade_F                                                                   uint8
# EVAAS Growth Status_Met                                                            uint8
# EVAAS Growth Status_NotMet                                                         uint8
# State Gap Compared_Insufficient Data                                               uint8
# esea_attendance_Met                                                                uint8
# Byod_YES                                                                           uint8
# _1_to_1_access_YES                                                                 uint8
# lea_avg_age_media_collection_1936                                                  uint8
# lea_avg_age_media_collection_1988                                                  uint8
# lea_avg_age_media_collection_1991                                                  uint8
# lea_avg_age_media_collection_1993                                                  uint8
# lea_avg_age_media_collection_1994                                                  uint8
# lea_avg_age_media_collection_1995                                                  uint8
# lea_avg_age_media_collection_1996                                                  uint8
# lea_avg_age_media_collection_1997                                                  uint8
# lea_avg_age_media_collection_1998                                                  uint8
# lea_avg_age_media_collection_1999                                                  uint8
# lea_avg_age_media_collection_2000                                                  uint8
# lea_avg_age_media_collection_2001                                                  uint8
# lea_avg_age_media_collection_2002                                                  uint8
# lea_avg_age_media_collection_2003                                                  uint8
# lea_avg_age_media_collection_2005                                                  uint8
# lea_avg_age_media_collection_2006                                                  uint8
# lea_avg_age_media_collection_2007                                                  uint8
# lea_avg_age_media_collection_2010                                                  uint8
# unit_code                                                                          object
# dtypes: float64(344), object(1), uint8(60)
# memory usage: 6.6+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.1
# Pandas Version: 0.24.2

# %%
print ('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2015/Machine Learning Datasets/PublicSchools2015_ML.csv
