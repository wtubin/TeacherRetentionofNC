# %% [markdown]
# ## Predicting Teacher Attrition Rates for Public Schools
# **This notebook explores predicting teacher attrition rates for public schools in North Carolina.**
# * Public school racial compositions are also considered when making predictions in this notebook.
# * The North Carolina Educational Attainment Data Repository for Machine Learning is located on Github at: https://github.com/wtubin/TeacherRetentionofNC
#
# **For documentation on various Generalized Linear Models in Sklearn see:**
# * http://scikit-learn.org/stable/modules/linear_model.html
# * https://stackoverflow.com/questions/33845539/modelling-probabilities-in-a-regularized-logistic-regression-model-in-python

# %%
# !pip install xgboost

# %%
#import required Libraries
from __future__ import division
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV    
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn import metrics as mt
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from sklearn.model_selection import cross_validate
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost
import math

from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
#from sklearn import cross_validation, tree, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-67-e5959cd0919e> in <module>
#      20 import pandas as pd
#      21 import matplotlib.pyplot as plt
# ---> 22 import xgboost
#      23 import math
#      24
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
#Read in the high schools dataset - NC EA Public High Schools Dataset Feb 2018

#The 'path' variable may also be a URL pointing to the proper raw file path on github: 
#path="https://raw.githubusercontent.com/jakemdrew/EducationDataNC/master/2017/Machine%20Learning%20Datasets/PublicHighSchools2017_ML.csv"

ML2017 = '../Machine Learning Datasets/PublicSchools2017_ML.csv'
ML2016 = '../../2016/Machine Learning Datasets/PublicSchools2016_ML.csv'
ML2015 =  '../../2015/Machine Learning Datasets/PublicSchools2015_ML.csv'
ML2014 =  '../../2014/Machine Learning Datasets/PublicSchools2014_ML.csv'

schData2017=pd.read_csv(ML2017, low_memory=False)
print('*********************************2017 ML Data*************************************')
schData2017.info()
schData2016=pd.read_csv(ML2016, low_memory=False)
print('*********************************2016 ML Data*************************************')
schData2016.info()

schData2015=pd.read_csv(ML2015, low_memory=False)
print('*********************************2015 ML Data*************************************')
schData2015.info()

schData2014=pd.read_csv(ML2014, low_memory=False)
print('*********************************2014 ML Data*************************************')
schData2014.info()
# Out:
# *********************************2017 ML Data*************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2468 entries, 0 to 2467
# Columns: 394 entries, student_num to unit_code
# dtypes: float64(350), int64(44)
# memory usage: 7.4 MB
# *********************************2016 ML Data*************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Columns: 374 entries, closed_ind to unit_code
# dtypes: float64(296), int64(78)
# memory usage: 6.9 MB
# *********************************2015 ML Data*************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2432 entries, 0 to 2431
# Columns: 403 entries, closed_ind to unit_code
# dtypes: float64(342), int64(61)
# memory usage: 7.5 MB
# *********************************2014 ML Data*************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2426 entries, 0 to 2425
# Columns: 364 entries, closed_ind to unit_code
# dtypes: float64(331), int64(33)
# memory usage: 6.7 MB

# %%
# Combine the data set
schData = pd.concat([schData2017,schData2016,schData2015,schData2014], axis=0, ignore_index=True, sort = True)

# %%
#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25


#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = schData.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = schData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schData = schData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Columns: 410 entries, (TCE) prepared returns Ct 100KLT200K to wap_per_classroom
# dtypes: float64(392), int64(18)
# memory usage: 30.5 MB
#
# Columns Deleted:  101

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 0                 (TCE) prepared returns Ct 100KLT200K                   4858
# 1                   (TCE) prepared returns Ct 25KLT50K                   2426
# 2                  (TCE) prepared returns Ct 75KLT100K                   2426
# 3                (VITA) prepared returns Ct 100KLT200K                   2426
# 4                  (VITA) prepared returns Ct 25KLT50K                   2426
# 5                  (VITA) prepared returns Ct 50KLT75K                   2426
# 7                                              00_Size                   2426
# 8                                              01_Size                   4894
# 9                                              02_Size                   2426
# 10                                             03_Size                   2426
# 11                                             04_Size                   2426
# 12                                             05_Size                   2426
# 20                     Add Medicare tax Amt 100KLT200K                   4900
# 21                   Add child tax credit Amt 25KLT50K                   2426
# 22                  Add child tax credit Amt 75KLT100K                   2430
# 26                   Alternative minimum tax Amt LT25K                   2468
# 27                 Alternative minimum tax Ct 50KLT75K                   2426
# 28                Alternative minimum tax Ct 75KLT100K                   4862
# 32                                            Byod_Yes                   4858
# 49   Does Not Meet Expected Growth_TCHR_Standard 6_Pct                   4898
# 50   Does Not Meet Expected Growth_TCHR_Student Gro...                   4858
# 59   Domestic production activities deduction Ct LT25K                   2430
# 65                                EOCMathI_CACR_Female                   4858
# 68                                  EOCMathI_CACR_Male                   4858
# 71                                 EOCMathI_CACR_White                   2426
# 74                                EOCSubjects_CACR_AIG                   4858
# 77                              EOCSubjects_CACR_Black                   4858
# 78                           EOCSubjects_CACR_Hispanic                   2432
# 94                             EOG/EOCSubjects_GLP_LEP                   2430
# 104                                  EOGGr3_CACR_White                   2432
# 105                                     EOGGr3_GLP_SWD                   4898
# 111                                    EOGGr4_CACR_EDS                   2432
# 117                                     EOGGr4_GLP_LEP                   2430
# 118                                     EOGGr4_GLP_SWD                   4900
# 128                                  EOGGr5_CACR_White                   2426
# 139                               EOGMathGr3-8_GLP_LEP                   4898
# 140                               EOGMathGr3-8_GLP_SWD                   4898
# 145                                EOGMathGr3_CACR_EDS                   4858
# 150                              EOGMathGr3_CACR_White                   4858
# 156                                EOGMathGr4_CACR_EDS                   4858
# 161                              EOGMathGr4_CACR_White                   4858
# 162                                 EOGMathGr4_GLP_LEP                   4898
# 163                                 EOGMathGr4_GLP_SWD                   4898
# 168                                EOGMathGr5_CACR_EDS                   4858
# 173                              EOGMathGr5_CACR_White                   2426
# 174                                 EOGMathGr5_GLP_SWD                   4898
# 184                  EOGReadingGr3_CACR_AmericanIndian                   2430
# 186                             EOGReadingGr3_CACR_EDS                   4858
# 190                  EOGReadingGr3_CACR_TwoorMoreRaces                   4898
# 191                              EOGReadingGr3_GLP_LEP                   2430
# 192                              EOGReadingGr3_GLP_SWD                   4898
# 193                  EOGReadingGr4_CACR_AmericanIndian                   4862
# 195                             EOGReadingGr4_CACR_EDS                   4858
# 199                  EOGReadingGr4_CACR_TwoorMoreRaces                   4898
# 202                  EOGReadingGr5_CACR_AmericanIndian                   2430
# 208                  EOGReadingGr5_CACR_TwoorMoreRaces                   2468
# 209                   EOGReadingGr5_GLP_AmericanIndian                   4856
# 210                         EOGReadingGr5_GLP_Hispanic                   4898
# 223                            EOGScienceGr5&8_GLP_LEP                   2430
# 224                            EOGScienceGr5&8_GLP_SWD                   4898
# 227                             EOGScienceGr5_CACR_EDS                   4858
# 228                        EOGScienceGr5_CACR_Hispanic                   4898
# 231                  EOGScienceGr5_CACR_TwoorMoreRaces                   4898
# 232                              EOGScienceGr5_GLP_LEP                   2430
# 233                              EOGScienceGr5_GLP_SWD                   4898
# 239                               EOGSubjects_CACR_LEP                   4862
# 242                                EOGSubjects_GLP_LEP                   4898
# 246                  Earned income credit Amt 50KLT75K                   2426
# 247        Exceeds Expected Growth_TCHR_Standard 6_Pct                   4898
# 248    Exceeds Expected Growth_TCHR_Student Growth_Pct                   4858
# 249  Excess earned income credit (refundable) Amt 5...                   2426
# 254                                       Math I Score                   2468
# 256                                   Math SPG Grade_B                   2430
# 257                                   Math SPG Grade_C                   2430
# 258                                   Math SPG Grade_D                   2430
# 259                                   Math SPG Grade_F                   2430
# 261          Meets Expected Growth_TCHR_Standard 6_Pct                   4898
# 262      Meets Expected Growth_TCHR_Student Growth_Pct                   4858
# 263           Net investment income tax Amt 100KLT200K                   4858
# 267                Not Demostrated_TCHR_Standard 5_Pct                   4894
# 275  Number of volunteer prepared returns Tot 50KLT75K                   2426
# 279  Partnership/S-corp net income (less loss) Amt ...                   2432
# 285                                 Reading  SPG Score                   4898
# 286                                Reading SPG Grade_B                   2430
# 287                                Reading SPG Grade_C                   2430
# 288                                Reading SPG Grade_D                   2430
# 289                                Reading SPG Grade_F                   2430
# 290                        ReadingGr3-8_pTarget_PctMet                   4898
# 292                             SBE District_Northeast                   4856
# 293                             SBE District_Northwest                   4856
# 294                        SBE District_Piedmont-Triad                   4856
# 295                             SBE District_Sandhills                   4856
# 296                             SBE District_Southeast                   4856
# 297                             SBE District_Southwest                   4856
# 298                               SBE District_Western                   4856
# 299                                     SPG Grade_A+NG                   2426
# 308      Self-employment retirement plans Amt 25KLT50K                   4898
# 309                               State Gap Compared_Y                   4858
# 310     State and local general sales taxes Amt GE200K                   4894
# 312           Tuition and fees deduction Amt 75KLT100K                   2426
# 318                                 _1_to_1_access_Yes                   4858
# 321                           avg_age_media_collection                   4858
# 323                                  books_per_student                   2426
# 328  calendar_type_txt_Regular School, Traditional ...                   2468
# 331                                      category_cd_E                   2426
# 333                                      category_cd_M                   2432
# 334                                      category_cd_T                   2468
# 335                                         closed_ind                   2468
# 337                                  digital_media_pct                   2426
# 338                                esea_attendance_Met                   4898
# 340                                      esea_status_R                   4898
# 341                                     esea_status_RF                   4898
# 344                                 highqual_class_pct                   4894
# 352                           lea_benefits_expense_pct                   2468
# 353                              lea_books_per_student                   2426
# 359                         lea_highqual_class_all_pct                   4894
# 360                          lea_highqual_class_hp_pct                   4894
# 361                          lea_highqual_class_lp_pct                   4894
# 362                             lea_highqual_class_pct                   4894
# 368                      lea_not_highqual_class_hp_pct                   4894
# 369                      lea_not_highqual_class_lp_pct                   4894
# 382                                        lea_wap_num                   4858
# 383                              lea_wap_per_classroom                   4858
# 390                            st_avg_daily_attend_pct                   2426
# 394                              st_expelled_per_c_num                   4862
# 396                              st_highqual_class_pct                   4894
# 397                             st_long_susp_per_c_num                   2432
# 398                                       st_nbpts_num                   2432
# 399                            st_short_susp_per_c_num                   2430
# 401                               st_tchyrs_11plus_pct                   2426
# 408                                            wap_num                   4858
# 409                                  wap_per_classroom                   4858

# %%
#Replace all remaining NaN with 0
schData = schData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ### we are not remove the 0 1 year percentage for now.

# %%
zeroAttrition = schData[schData['_1yr_tchr_trnovr_pct']==0.0].index
schData = schData.drop(zeroAttrition,axis=0)
print('*********After: Removing rows with first year turn over percentage =0.00******')
schData.info(verbose=False)
print ('\r\nRows Deleted: ', len(zeroAttrition))
# Out:
# *********After: Removing rows with first year turn over percentage =0.00******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9253 entries, 1 to 9755
# Columns: 410 entries, (TCE) prepared returns Ct 100KLT200K to wap_per_classroom
# dtypes: float64(392), int64(18)
# memory usage: 29.0 MB
#
# Rows Deleted:  503

# %%
plt.figure(figsize=(13,10))
_1yr_tchr_trnovr_pct = schData["_1yr_tchr_trnovr_pct"]
ax = sns.distplot(_1yr_tchr_trnovr_pct);
plt.title("Figure 1. North Carolina Public School First Year Teacher Turnover Percentage (2014-2017)")
plt.show()

# %%
schData['lea_salary'] = schData['lea_total_expense_num']*schData['lea_salary_expense_pct']

plt.figure(figsize=(13,10))
lea_salary_expense_pct=schData.lea_salary_expense_pct
ax = sns.distplot(schData['lea_salary']);
plt.title("Figure 2. North Carolina Public School Lea Salary Expense (2014-2017)")
plt.show()

# %%
schData['_1yr_tchr_trnovr_pct'].describe()
# Out:
# count    9253.000000
# mean        0.148518
# std         0.083152
# min         0.005000
# 25%         0.090000
# 50%         0.135000
# 75%         0.189000
# max         0.818000
# Name: _1yr_tchr_trnovr_pct, dtype: float64

# %%
sns.lmplot(x="lea_salary", y="_1yr_tchr_trnovr_pct", data=schData,height=8.27, aspect=11.7/8.27)
sns.despine()

plt.title("Figure 3. North Carolina Public School One Year Teacher Attrition Rate vs. LEA Salary Expenditure (2014-2017)")
plt.ylabel('1st Year Attrition Rate')
plt.xlabel('LEA Salary Expenditure')

# plt.show()
# Out:
# Text(0.5, 6.799999999999976, 'LEA Salary Expenditure')

# %%
sns.lmplot(x="lea_total_expense_num", y="_1yr_tchr_trnovr_pct", data=schData,height=8.27, aspect=11.7/8.27)
sns.despine()

plt.title("Figure 4. North Coralina Public School One Year Teacher Attrition Rate vs. LEA Total School Expenditure (2014-2017)")
plt.ylabel('1st Year Attrition Rate')
plt.xlabel('LEA Total School Expenditure')
# Out:
# Text(0.5, 6.799999999999976, 'LEA Total School Expenditure')

# %%
#schData.select_dtypes(exclude=['object']).describe()

# %%
#schData.info(verbose=True)

# %% [markdown]
# ## Feature Selection
# * set max features we want to select

# %%
max_features =200

# %%
schData_bak = schData
#schData = schData_bak

# %%
#schData = schData_bak

# %%
y= schData['_1yr_tchr_trnovr_pct']
X = schData.drop(['_1yr_tchr_trnovr_pct'],axis=1)

# %%
#X.info(verbose=True)

# %% [markdown]
# ### Manually remove columns
#
# * there columns is not what we are interested in, so we remove them manaually from data set

# %%
X = X.drop(['st_1yr_tchr_trnovr_pct','lea_1yr_tchr_trnovr_pct'],axis=1)

# %%
# Feature Selection 
X_fs = X
y_fs = y

# %% [markdown]
# ## Pearson Correlation

# %%
# Pearson Correlation
feature_name = X_fs.columns.tolist()
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
        # replace NaN with 0
        cor_list = [0 if np.isnan(i) else i for i in cor_list]
        # feature name
        cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-max_features:]].columns.tolist()
        # feature selection? 0 for not select, 1 for select
        cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature
cor_support, cor_feature = cor_selector(X_fs, y_fs)
print(str(len(cor_feature)), 'selected features')
print(pd.DataFrame( cor_feature))
# Out:
# 200 selected features
#                                                      0
# 0                                    EOGGr4_CACR_Asian
# 1                                   Reading  SPG Score
# 2                               EOGReadingGr3_CACR_LEP
# 3                                  EOGMathGr3_CACR_LEP
# 4                       school_type_txt_Regular School
# 5                              EOGScienceGr5&8_GLP_SWD
# 6                               stud_internet_comp_num
# 7                           EVAAS Growth Status_NotMet
# 8                                  EOCMathI_CACR_Black
# 9                                   tchyrs_4thru10_pct
# 10                          lea_stud_internet_comp_num
# 11   Domestic production activities deduction Ct 25...
# 12                                  st_avg_student_num
# 13                                         SPG Grade_C
# 14                                   EOGGr5_CACR_Asian
# 15                            lea_ap_participation_pct
# 16   Partnership/S-corp net income (less loss) Amt ...
# 17                            EOGMathGr5_CACR_Hispanic
# 18                               Grad_project_status_Y
# 19                                   EOGGr4_CACR_Black
# 20                          EOGGr4_CACR_TwoorMoreRaces
# 21                   Distinguished_TCHR_Standard 5_Pct
# 22                         EOGReadingGr5_CACR_Hispanic
# 23                          EOGGr3_CACR_TwoorMoreRaces
# 24                             EOGMathGr3-8_CACR_Asian
# 25                   Distinguished_TCHR_Standard 3_Pct
# 26                              Crime_Rate_Murder_Rate
# 27   Domestic production activities deduction Ct 50...
# 28                                       category_cd_T
# 29                                  EOGMathGr5_GLP_SWD
# 30                          EOGGr5_CACR_TwoorMoreRaces
# 31                                       category_cd_E
# 32                                         student_num
# 33                         4-10 Years_LEA_Exp_Pct_Prin
# 34                                  EOGMathGr4_GLP_SWD
# 35                                   EOGGr3_CACR_Black
# 36                          EOG/EOCSubjects_CACR_Black
# 37                               EOGScienceGr5_GLP_SWD
# 38                   Distinguished_TCHR_Standard 4_Pct
# 39                             EOG/EOCSubjects_GLP_LEP
# 40                                EOGSubjects_CACR_LEP
# 41                                   EOGGr5_CACR_Black
# 42                               EOGReadingGr3_GLP_SWD
# 43                            EOGReadingGr3-8_CACR_LEP
# 44                         EOGReadingGr4_CACR_Hispanic
# 45                               EOGMathGr3-8_CACR_LEP
# 46                                      EOGGr3_GLP_SWD
# 47                          EOGReadingGr3-8_CACR_Black
# 48                                             05_Size
# 49   Domestic production activities deduction Amt 1...
# 50                                    Math SPG Grade_C
# 51                          EOG/EOCSubjects_CACR_Asian
# 52                            EOGMathGr4_CACR_Hispanic
# 53                                 EOGMathGr5_CACR_EDS
# 54                   Distinguished_TCHR_Standard 2_Pct
# 55                         EOGReadingGr3_CACR_Hispanic
# 56                                             04_Size
# 57                             EOGReadingGr3-8_GLP_LEP
# 58                            EOGMathGr3_CACR_Hispanic
# 59                                 EOGMathGr3_CACR_AIG
# 60                                EOGMathGr3-8_GLP_SWD
# 61                                      EOGGr4_GLP_SWD
# 62                                     EOGGr3_CACR_LEP
# 63                              EOGScienceGr5_CACR_EDS
# 64                              EOGReadingGr5_CACR_SWD
# 65                                             02_Size
# 66                             EOGMathGr3-8_CACR_Black
# 67                                             00_Size
# 68                              EOGSubjects_CACR_Asian
# 69                                     EOGGr3_CACR_AIG
# 70                              lea_state_perpupil_num
# 71                                 Reading SPG Grade_D
# 72                                 EOGMathGr4_CACR_EDS
# 73                   Distinguished_TCHR_Standard 1_Pct
# 74                            lea_supplies_expense_pct
# 75                                             03_Size
# 76                              EOGReadingGr4_CACR_EDS
# 77                 EOGReadingGr3-8_CACR_TwoorMoreRaces
# 78                    Number of farm returns 75KLT100K
# 79                     Number of farm returns 25KLT50K
# 80                                 EOGMathGr3_CACR_EDS
# 81   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 82                              EOGReadingGr3_CACR_EDS
# 83                                 Reading SPG Grade_C
# 84                              st_flicensed_teach_pct
# 85                            EOG/EOCSubjects_CACR_LEP
# 86                                 Reading SPG Grade_F
# 87                          0-3 Years_LEA_Exp_Pct_Prin
# 88                                EOGGr4_CACR_Hispanic
# 89                                       lea_nbpts_num
# 90                               EOGReadingGr5_GLP_SWD
# 91                   Number of farm returns 100KLT200K
# 92                              EOGReadingGr4_CACR_SWD
# 93                     Number of farm returns 50KLT75K
# 94                                 lea_crime_per_c_num
# 95                                  EVAAS Growth Score
# 96                              EOGSubjects_CACR_Black
# 97                    EOGMathGr3-8_CACR_TwoorMoreRaces
# 98                             SciGr5&8_pTarget_PctMet
# 99                                EOGGr5_CACR_Hispanic
# 100                              lea_total_expense_num
# 101                        TotalTargets_pTarget_PctMet
# 102                                EOGMathGr5_CACR_SWD
# 103                                Reading SPG Grade_B
# 104                                  EOGGr5_CACR_White
# 105                              EOGMathGr4_CACR_White
# 106                                      esea_status_P
# 107                                   Math SPG Grade_B
# 108                      EOGReadingGr3-8_CACR_Hispanic
# 109                       Number of farm returns LT25K
# 110                              EOGMathGr3_CACR_White
# 111                                EOGMathGr4_CACR_SWD
# 112                              EOGReadingGr4_GLP_SWD
# 113                           EOGScienceGr5&8_CACR_AIG
# 114                             EOGReadingGr3_CACR_SWD
# 115                             EOGScienceGr5_CACR_SWD
# 116                           EOGScienceGr5&8_CACR_SWD
# 117                             lea_tchyrs_4thru10_pct
# 118                               EOGGr3_CACR_Hispanic
# 119                           MathGr3-8_pTarget_PctMet
# 120                                EOGMathGr3_CACR_SWD
# 121                                        SPG Grade_F
# 122                                        SPG Grade_D
# 123                         Number of farm returns All
# 124                                        SPG Grade_B
# 125                              EOGMathGr5_CACR_White
# 126                               avg_daily_attend_pct
# 127                                   Math SPG Grade_F
# 128                                 EOGMathGr3_GLP_SWD
# 129                                    EOGGr4_CACR_SWD
# 130                    EOGSubjects_CACR_TwoorMoreRaces
# 131                                    EOGGr5_CACR_SWD
# 132                     Developing_TCHR_Standard 3_Pct
# 133                         EOGMathGr3-8_CACR_Hispanic
# 134                                    EOGGr3_CACR_SWD
# 135                               EOGSubjects_CACR_AIG
# 136                           EOGScienceGr5&8_CACR_EDS
# 137                                 st_crime_per_c_num
# 138                EOG/EOCSubjects_CACR_TwoorMoreRaces
# 139                      EOG/EOCSubjects_CACR_Hispanic
# 140                                EOGMathGr4_CACR_AIG
# 141                     Developing_TCHR_Standard 5_Pct
# 142                                EOGMathGr5_CACR_AIG
# 143                           lea_services_expense_pct
# 144                     Proficient_TCHR_Standard 3_Pct
# 145                          EOGSubjects_CACR_Hispanic
# 146                                    EOGGr4_CACR_EDS
# 147                                    advance_dgr_pct
# 148                                    EOGGr5_CACR_AIG
# 149                     Proficient_TCHR_Standard 5_Pct
# 150                           EOGReadingGr3-8_CACR_SWD
# 151                                      Science Score
# 152                              EOGMathGr3-8_CACR_AIG
# 153                                  EOGGr3_CACR_White
# 154                              lea_ap_pct_3_or_above
# 155                                lea_advance_dgr_pct
# 156                           lea_short_susp_per_c_num
# 157                           EOG/EOCSubjects_CACR_AIG
# 158                         EOGScienceGr5&8_CACR_White
# 159                                    EOGGr4_CACR_AIG
# 160                             EOGReadingGr5_CACR_EDS
# 161                            EOGReadingGr3-8_GLP_SWD
# 162                              lea_tchyrs_11plus_pct
# 163                     Developing_TCHR_Standard 2_Pct
# 164                              EOGMathGr3-8_CACR_SWD
# 165                                  EOGGr4_CACR_White
# 166                                    EOGGr5_CACR_All
# 167                               EOGSubjects_CACR_SWD
# 168                           EOG/EOCSubjects_CACR_SWD
# 169                   Accomplished_TCHR_Standard 3_Pct
# 170                               short_susp_per_c_num
# 171                                          nbpts_num
# 172                              lea_sat_avg_score_num
# 173                   Accomplished_TCHR_Standard 5_Pct
# 174                         EOG/EOCSubjects_CACR_White
# 175                     Proficient_TCHR_Standard 2_Pct
# 176                                    EOGGr4_CACR_All
# 177                           lea_federal_perpupil_num
# 178                           EOGReadingGr3-8_CACR_EDS
# 179                                    EOGGr3_CACR_All
# 180                            EOGMathGr3-8_CACR_White
# 181                     Developing_TCHR_Standard 1_Pct
# 182                                          SPG Score
# 183                           EOG/EOCSubjects_CACR_EDS
# 184                   Accomplished_TCHR_Standard 2_Pct
# 185                              EOGMathGr3-8_CACR_EDS
# 186                     Developing_TCHR_Standard 4_Pct
# 187                     Proficient_TCHR_Standard 1_Pct
# 188                     Proficient_TCHR_Standard 4_Pct
# 189                   Accomplished_TCHR_Standard 1_Pct
# 190                           EOG/EOCSubjects_CACR_All
# 191                   Accomplished_TCHR_Standard 4_Pct
# 192                                           WhitePct
# 193                              lea_tchyrs_0thru3_pct
# 194                            lea_flicensed_teach_pct
# 195                                  tchyrs_11plus_pct
# 196                                           BlackPct
# 197                                  lateral_teach_pct
# 198                                flicensed_teach_pct
# 199                                  tchyrs_0thru3_pct

# %% [markdown]
# ## Linear Reggesion RFE

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
rfe_selector = RFE(estimator=LinearRegression(), n_features_to_select=max_features, step=10, verbose=5)
rfe_selector.fit(X_fs, y_fs)
rfe_support = rfe_selector.get_support()
rfe_feature = X_fs.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
print(pd.DataFrame(rfe_feature))
# Out:
# Fitting estimator with 408 features.
# Fitting estimator with 398 features.
# Fitting estimator with 388 features.
# Fitting estimator with 378 features.
# Fitting estimator with 368 features.
# Fitting estimator with 358 features.
# Fitting estimator with 348 features.
# Fitting estimator with 338 features.
# Fitting estimator with 328 features.
# Fitting estimator with 318 features.
# Fitting estimator with 308 features.
# Fitting estimator with 298 features.
# Fitting estimator with 288 features.
# Fitting estimator with 278 features.
# Fitting estimator with 268 features.
# Fitting estimator with 258 features.
# Fitting estimator with 248 features.
# Fitting estimator with 238 features.
# Fitting estimator with 228 features.
# Fitting estimator with 218 features.
# Fitting estimator with 208 features.
# 200 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                           0-3 Years_LEA_Exp_Pct_Prin
# 2                                              00_Size
# 3                                              01_Size
# 4                                              02_Size
# 5                                              03_Size
# 6                                              04_Size
# 7                                              05_Size
# 8                           10+ Years_LEA_Exp_Pct_Prin
# 9                          4-10 Years_LEA_Exp_Pct_Prin
# 10                    Accomplished_TCHR_Standard 1_Pct
# 11                    Accomplished_TCHR_Standard 2_Pct
# 12                    Accomplished_TCHR_Standard 3_Pct
# 13                    Accomplished_TCHR_Standard 4_Pct
# 14                    Accomplished_TCHR_Standard 5_Pct
# 15                Alternative minimum tax Amt 25KLT50K
# 16                Alternative minimum tax Amt 50KLT75K
# 17                   Alternative minimum tax Amt LT25K
# 18                 Alternative minimum tax Ct 50KLT75K
# 19                                            AsianPct
# 20                                            BlackPct
# 21                                            Byod_Yes
# 22                               Crime_Rate_Arson_Rate
# 23                              Crime_Rate_Murder_Rate
# 24                                Crime_Rate_Rape_Rate
# 25                      Developing_TCHR_Standard 1_Pct
# 26                      Developing_TCHR_Standard 2_Pct
# 27                      Developing_TCHR_Standard 3_Pct
# 28                      Developing_TCHR_Standard 4_Pct
# 29                      Developing_TCHR_Standard 5_Pct
# 30                   Distinguished_TCHR_Standard 1_Pct
# 31                   Distinguished_TCHR_Standard 2_Pct
# 32                   Distinguished_TCHR_Standard 3_Pct
# 33                   Distinguished_TCHR_Standard 5_Pct
# 34   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 35   Does Not Meet Expected Growth_TCHR_Student Gro...
# 36                        EOCMathI_CACR_AmericanIndian
# 37                                EOCMathI_CACR_Female
# 38                                   EOCMathI_CACR_SWD
# 39                                    EOCMathI_GLP_LEP
# 40                                    EOCMathI_GLP_SWD
# 41                                EOCSubjects_CACR_LEP
# 42                                EOCSubjects_CACR_SWD
# 43                                 EOCSubjects_GLP_LEP
# 44                            EOG/EOCSubjects_CACR_All
# 45                            EOG/EOCSubjects_CACR_EDS
# 46                       EOG/EOCSubjects_CACR_Hispanic
# 47                            EOG/EOCSubjects_CACR_SWD
# 48                                     EOGGr3_CACR_All
# 49                          EOGGr3_CACR_AmericanIndian
# 50                                     EOGGr3_CACR_SWD
# 51                                     EOGGr4_CACR_LEP
# 52                                     EOGGr5_CACR_LEP
# 53                               EOGMathGr3-8_CACR_EDS
# 54                               EOGMathGr3-8_CACR_SWD
# 55                      EOGMathGr3_CACR_AmericanIndian
# 56                                 EOGMathGr3_CACR_SWD
# 57                                  EOGMathGr4_GLP_LEP
# 58                                 EOGMathGr5_CACR_EDS
# 59                          EOGReadingGr3-8_CACR_Black
# 60                            EOGReadingGr3-8_CACR_SWD
# 61                             EOGReadingGr3-8_GLP_SWD
# 62                   EOGReadingGr3_CACR_AmericanIndian
# 63                   EOGReadingGr4_CACR_AmericanIndian
# 64                              EOGReadingGr4_CACR_SWD
# 65                               EOGReadingGr4_GLP_SWD
# 66                   EOGReadingGr5_CACR_AmericanIndian
# 67                              EOGReadingGr5_CACR_SWD
# 68                    EOGReadingGr5_GLP_AmericanIndian
# 69                               EOGReadingGr5_GLP_SWD
# 70                 EOGScienceGr5&8_CACR_AmericanIndian
# 71                             EOGScienceGr5&8_GLP_SWD
# 72                   EOGScienceGr5_CACR_AmericanIndian
# 73                              EOGScienceGr5_CACR_EDS
# 74                               EOGScienceGr5_GLP_SWD
# 75                                EOGSubjects_CACR_LEP
# 76                                  EVAAS Growth Score
# 77                             EVAAS Growth Status_Met
# 78                          EVAAS Growth Status_NotMet
# 79         Exceeds Expected Growth_TCHR_Standard 6_Pct
# 80     Exceeds Expected Growth_TCHR_Student Growth_Pct
# 81                               Grad_project_status_Y
# 82                                         HispanicPct
# 83                                           IndianPct
# 84                                         Math I_Size
# 85                                    Math SPG Grade_B
# 86                                    Math SPG Grade_C
# 87                                    Math SPG Grade_D
# 88                                    Math SPG Grade_F
# 89           Meets Expected Growth_TCHR_Standard 6_Pct
# 90       Meets Expected Growth_TCHR_Student Growth_Pct
# 91                 Not Demostrated_TCHR_Standard 1_Pct
# 92                 Not Demostrated_TCHR_Standard 2_Pct
# 93                 Not Demostrated_TCHR_Standard 4_Pct
# 94                 Not Demostrated_TCHR_Standard 5_Pct
# 95                              PacificIslandFemalePct
# 96                                PacificIslandMalePct
# 97                                    PacificIslandPct
# 98                      Proficient_TCHR_Standard 1_Pct
# 99                      Proficient_TCHR_Standard 2_Pct
# 100                     Proficient_TCHR_Standard 3_Pct
# 101                     Proficient_TCHR_Standard 4_Pct
# 102                     Proficient_TCHR_Standard 5_Pct
# 103                                Reading SPG Grade_B
# 104                                Reading SPG Grade_D
# 105                                Reading SPG Grade_F
# 106                        ReadingGr3-8_pTarget_PctMet
# 107            Residential energy tax credit Amt LT25K
# 108                             SBE District_Northeast
# 109                             SBE District_Northwest
# 110                        SBE District_Piedmont-Triad
# 111                             SBE District_Sandhills
# 112                             SBE District_Southeast
# 113                             SBE District_Southwest
# 114                                     SPG Grade_A+NG
# 115                                        SPG Grade_B
# 116                                        SPG Grade_C
# 117                                        SPG Grade_D
# 118                                        SPG Grade_F
# 119                                        SPG Grade_I
# 120                                          SPG Score
# 121                            SciGr5&8_pTarget_PctMet
# 122                               State Gap Compared_Y
# 123                        TotalTargets_pTarget_PctMet
# 124                                 TwoOrMoreFemalePct
# 125                                   TwoOrMoreMalePct
# 126                                       TwoOrMorePct
# 127                                           WhitePct
# 128                                    advance_dgr_pct
# 129                               avg_daily_attend_pct
# 130                  calendar_type_txt_Hospital School
# 131  calendar_type_txt_Magnet School, Traditional C...
# 132  calendar_type_txt_Magnet School, Year-Round Ca...
# 133  calendar_type_txt_Regular School, Traditional ...
# 134  calendar_type_txt_Regular School, Traditional ...
# 135  calendar_type_txt_Regular School, Year-Round C...
# 136  calendar_type_txt_Special Education, Tradition...
# 137                                      category_cd_E
# 138                                      category_cd_I
# 139                                      category_cd_M
# 140                                      category_cd_T
# 141                                         closed_ind
# 142                                  digital_media_pct
# 143                                esea_attendance_Met
# 144                                      esea_status_P
# 145                                      esea_status_R
# 146                                     esea_status_RF
# 147                                 expelled_per_c_num
# 148                                flicensed_teach_pct
# 149                                 highqual_class_pct
# 150                                  lateral_teach_pct
# 151                                lea_advance_dgr_pct
# 152                           lea_ap_participation_pct
# 153                              lea_ap_pct_3_or_above
# 154                           lea_avg_daily_attend_pct
# 155                           lea_benefits_expense_pct
# 156                              lea_books_per_student
# 157                                lea_crime_per_c_num
# 158                            lea_emer_prov_teach_pct
# 159                             lea_expelled_per_c_num
# 160                            lea_flicensed_teach_pct
# 161                         lea_highqual_class_all_pct
# 162                          lea_highqual_class_hp_pct
# 163                          lea_highqual_class_lp_pct
# 164                             lea_highqual_class_pct
# 165                              lea_ib_pct_4_or_above
# 166                         lea_instruct_equip_exp_pct
# 167                            lea_long_susp_per_c_num
# 168                                      lea_nbpts_num
# 169                      lea_not_highqual_class_hp_pct
# 170                      lea_not_highqual_class_lp_pct
# 171                             lea_salary_expense_pct
# 172                          lea_sat_participation_pct
# 173                           lea_services_expense_pct
# 174                         lea_stud_internet_comp_num
# 175                           lea_supplies_expense_pct
# 176                              lea_tchyrs_0thru3_pct
# 177                              lea_tchyrs_11plus_pct
# 178                             lea_tchyrs_4thru10_pct
# 179                              lea_wap_per_classroom
# 180                                long_susp_per_c_num
# 181                                          nbpts_num
# 182                                        pct_GCE_ALL
# 183                     school_type_txt_Regular School
# 184                            st_avg_daily_attend_pct
# 185                                 st_crime_per_c_num
# 186                             st_emer_prov_teach_pct
# 187                              st_expelled_per_c_num
# 188                             st_flicensed_teach_pct
# 189                              st_highqual_class_pct
# 190                             st_long_susp_per_c_num
# 191                            st_short_susp_per_c_num
# 192                               st_tchyrs_0thru3_pct
# 193                               st_tchyrs_11plus_pct
# 194                             stud_internet_comp_num
# 195                                  tchyrs_0thru3_pct
# 196                                  tchyrs_11plus_pct
# 197                                 tchyrs_4thru10_pct
# 198                                            wap_num
# 199                                  wap_per_classroom

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC
from sklearn.linear_model import LinearRegression

Linear = LinearRegression()

Linear_selector = SelectFromModel(Linear, threshold='1.25*median', max_features=max_features)
Linear_selector.fit(X_fs, y_fs)
Linear_support = Linear_selector.get_support()
Linear_feature = X_fs.loc[:,Linear_support].columns.tolist()
print(str(len(Linear_feature)), 'selected features')
print(pd.DataFrame(Linear_feature))
# Out:
# 189 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                           0-3 Years_LEA_Exp_Pct_Prin
# 2                                              00_Size
# 3                                              01_Size
# 4                                              03_Size
# 5                                              04_Size
# 6                           10+ Years_LEA_Exp_Pct_Prin
# 7                          4-10 Years_LEA_Exp_Pct_Prin
# 8                     Accomplished_TCHR_Standard 1_Pct
# 9                     Accomplished_TCHR_Standard 2_Pct
# 10                    Accomplished_TCHR_Standard 3_Pct
# 11                    Accomplished_TCHR_Standard 4_Pct
# 12                    Accomplished_TCHR_Standard 5_Pct
# 13                Alternative minimum tax Amt 25KLT50K
# 14                Alternative minimum tax Amt 50KLT75K
# 15                 Alternative minimum tax Ct 50KLT75K
# 16                                            AsianPct
# 17                                            BlackPct
# 18                                            Byod_Yes
# 19                               Crime_Rate_Arson_Rate
# 20                              Crime_Rate_Murder_Rate
# 21                                Crime_Rate_Rape_Rate
# 22                      Developing_TCHR_Standard 1_Pct
# 23                      Developing_TCHR_Standard 2_Pct
# 24                      Developing_TCHR_Standard 3_Pct
# 25                      Developing_TCHR_Standard 4_Pct
# 26                      Developing_TCHR_Standard 5_Pct
# 27                   Distinguished_TCHR_Standard 1_Pct
# 28                   Distinguished_TCHR_Standard 2_Pct
# 29                   Distinguished_TCHR_Standard 3_Pct
# 30                   Distinguished_TCHR_Standard 4_Pct
# 31                   Distinguished_TCHR_Standard 5_Pct
# 32   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 33   Does Not Meet Expected Growth_TCHR_Student Gro...
# 34                                EOCMathI_CACR_Female
# 35                                    EOCMathI_GLP_SWD
# 36                                EOCSubjects_CACR_LEP
# 37                                EOCSubjects_CACR_SWD
# 38                                 EOCSubjects_GLP_LEP
# 39                            EOG/EOCSubjects_CACR_All
# 40                            EOG/EOCSubjects_CACR_EDS
# 41                       EOG/EOCSubjects_CACR_Hispanic
# 42                          EOGGr3_CACR_AmericanIndian
# 43                                     EOGGr3_CACR_SWD
# 44                                     EOGGr4_CACR_LEP
# 45                                      EOGGr4_GLP_LEP
# 46                               EOGMathGr3-8_CACR_SWD
# 47                      EOGMathGr3_CACR_AmericanIndian
# 48                                  EOGMathGr4_GLP_LEP
# 49                            EOGMathGr5_CACR_Hispanic
# 50                          EOGReadingGr3-8_CACR_Black
# 51                            EOGReadingGr3-8_CACR_SWD
# 52                   EOGReadingGr3_CACR_AmericanIndian
# 53                   EOGReadingGr4_CACR_AmericanIndian
# 54                              EOGReadingGr4_CACR_SWD
# 55                               EOGReadingGr4_GLP_SWD
# 56                   EOGReadingGr5_CACR_AmericanIndian
# 57                              EOGReadingGr5_CACR_LEP
# 58                    EOGReadingGr5_GLP_AmericanIndian
# 59                   EOGScienceGr5_CACR_AmericanIndian
# 60                              EOGScienceGr5_CACR_EDS
# 61                               EOGScienceGr5_GLP_SWD
# 62                                  EVAAS Growth Score
# 63                             EVAAS Growth Status_Met
# 64                          EVAAS Growth Status_NotMet
# 65                   Earned income credit Amt 50KLT75K
# 66         Exceeds Expected Growth_TCHR_Standard 6_Pct
# 67     Exceeds Expected Growth_TCHR_Student Growth_Pct
# 68   Excess earned income credit (refundable) Amt 5...
# 69                               Grad_project_status_Y
# 70                                         HispanicPct
# 71                                           IndianPct
# 72                                    Math SPG Grade_B
# 73                                    Math SPG Grade_C
# 74                                    Math SPG Grade_D
# 75                                    Math SPG Grade_F
# 76                            MathGr3-8_pTarget_PctMet
# 77           Meets Expected Growth_TCHR_Standard 6_Pct
# 78       Meets Expected Growth_TCHR_Student Growth_Pct
# 79                 Not Demostrated_TCHR_Standard 1_Pct
# 80                 Not Demostrated_TCHR_Standard 2_Pct
# 81                 Not Demostrated_TCHR_Standard 4_Pct
# 82                 Not Demostrated_TCHR_Standard 5_Pct
# 83                              PacificIslandFemalePct
# 84                                PacificIslandMalePct
# 85                                    PacificIslandPct
# 86                      Proficient_TCHR_Standard 1_Pct
# 87                      Proficient_TCHR_Standard 2_Pct
# 88                      Proficient_TCHR_Standard 3_Pct
# 89                      Proficient_TCHR_Standard 4_Pct
# 90                      Proficient_TCHR_Standard 5_Pct
# 91                                 Reading SPG Grade_B
# 92                                 Reading SPG Grade_C
# 93                                 Reading SPG Grade_D
# 94                                 Reading SPG Grade_F
# 95                         ReadingGr3-8_pTarget_PctMet
# 96             Residential energy tax credit Amt LT25K
# 97                              SBE District_Northeast
# 98                              SBE District_Northwest
# 99                         SBE District_Piedmont-Triad
# 100                             SBE District_Sandhills
# 101                             SBE District_Southeast
# 102                             SBE District_Southwest
# 103                               SBE District_Western
# 104                                     SPG Grade_A+NG
# 105                                        SPG Grade_B
# 106                                        SPG Grade_C
# 107                                        SPG Grade_D
# 108                                        SPG Grade_F
# 109                                        SPG Grade_I
# 110                            SciGr5&8_pTarget_PctMet
# 111                               State Gap Compared_Y
# 112                        TotalTargets_pTarget_PctMet
# 113                                 TwoOrMoreFemalePct
# 114                                   TwoOrMoreMalePct
# 115                                       TwoOrMorePct
# 116                                           WhitePct
# 117                                 _1_to_1_access_Yes
# 118                                    advance_dgr_pct
# 119                               avg_daily_attend_pct
# 120                  calendar_type_txt_Hospital School
# 121  calendar_type_txt_Magnet School, Traditional C...
# 122  calendar_type_txt_Magnet School, Year-Round Ca...
# 123  calendar_type_txt_Regular School, Traditional ...
# 124  calendar_type_txt_Regular School, Traditional ...
# 125  calendar_type_txt_Regular School, Year-Round C...
# 126  calendar_type_txt_Special Education, Tradition...
# 127                                      category_cd_E
# 128                                      category_cd_I
# 129                                      category_cd_M
# 130                                      category_cd_T
# 131                                         closed_ind
# 132                                  digital_media_pct
# 133                                esea_attendance_Met
# 134                                      esea_status_P
# 135                                      esea_status_R
# 136                                     esea_status_RF
# 137                                 expelled_per_c_num
# 138                                flicensed_teach_pct
# 139                                 highqual_class_pct
# 140                                  lateral_teach_pct
# 141                                lea_advance_dgr_pct
# 142                           lea_ap_participation_pct
# 143                              lea_ap_pct_3_or_above
# 144                           lea_avg_daily_attend_pct
# 145                           lea_benefits_expense_pct
# 146                              lea_books_per_student
# 147                                lea_crime_per_c_num
# 148                            lea_emer_prov_teach_pct
# 149                             lea_expelled_per_c_num
# 150                            lea_flicensed_teach_pct
# 151                         lea_highqual_class_all_pct
# 152                          lea_highqual_class_hp_pct
# 153                          lea_highqual_class_lp_pct
# 154                             lea_highqual_class_pct
# 155                              lea_ib_pct_4_or_above
# 156                         lea_instruct_equip_exp_pct
# 157                            lea_long_susp_per_c_num
# 158                                      lea_nbpts_num
# 159                      lea_not_highqual_class_hp_pct
# 160                      lea_not_highqual_class_lp_pct
# 161                             lea_salary_expense_pct
# 162                          lea_sat_participation_pct
# 163                           lea_services_expense_pct
# 164                         lea_stud_internet_comp_num
# 165                           lea_supplies_expense_pct
# 166                              lea_tchyrs_0thru3_pct
# 167                              lea_tchyrs_11plus_pct
# 168                             lea_tchyrs_4thru10_pct
# 169                              lea_wap_per_classroom
# 170                                long_susp_per_c_num
# 171                                          nbpts_num
# 172                                        pct_GCE_ALL
# 173                     school_type_txt_Regular School
# 174                            st_avg_daily_attend_pct
# 175                                 st_crime_per_c_num
# 176                             st_emer_prov_teach_pct
# 177                              st_expelled_per_c_num
# 178                             st_flicensed_teach_pct
# 179                              st_highqual_class_pct
# 180                             st_long_susp_per_c_num
# 181                                       st_nbpts_num
# 182                            st_short_susp_per_c_num
# 183                               st_tchyrs_0thru3_pct
# 184                               st_tchyrs_11plus_pct
# 185                                  tchyrs_0thru3_pct
# 186                                  tchyrs_11plus_pct
# 187                                 tchyrs_4thru10_pct
# 188                                  wap_per_classroom

# %% [markdown]
# ## Lasso

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV

from sklearn.linear_model import Ridge

Lasso = LassoCV(cv = 5)

LassoCV_selector = SelectFromModel(Lasso, threshold='1.25*median', max_features=max_features)
LassoCV_selector.fit(X_fs, y_fs)
LassoCV_support = LassoCV_selector.get_support()
LassoCV_feature = X_fs.loc[:,LassoCV_support].columns.tolist()
print(str(len(LassoCV_feature)), 'selected features')
print(pd.DataFrame(LassoCV_feature))
# Out:
# 200 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                   (TCE) prepared returns Ct 25KLT50K
# 2                  (TCE) prepared returns Ct 75KLT100K
# 3                (VITA) prepared returns Ct 100KLT200K
# 4                  (VITA) prepared returns Ct 25KLT50K
# 5                  (VITA) prepared returns Ct 50KLT75K
# 6                           0-3 Years_LEA_Exp_Pct_Prin
# 7                                              00_Size
# 8                                              01_Size
# 9                                              02_Size
# 10                                             03_Size
# 11                                             04_Size
# 12                                             05_Size
# 13                          10+ Years_LEA_Exp_Pct_Prin
# 14                         4-10 Years_LEA_Exp_Pct_Prin
# 15                    Accomplished_TCHR_Standard 1_Pct
# 16                    Accomplished_TCHR_Standard 2_Pct
# 17                    Accomplished_TCHR_Standard 3_Pct
# 18                    Accomplished_TCHR_Standard 4_Pct
# 19                    Accomplished_TCHR_Standard 5_Pct
# 20                     Add Medicare tax Amt 100KLT200K
# 21                   Add child tax credit Amt 25KLT50K
# 22                  Add child tax credit Amt 75KLT100K
# 23                Alternative minimum tax Amt 25KLT50K
# 24                Alternative minimum tax Amt 50KLT75K
# 25               Alternative minimum tax Amt 75KLT100K
# 26                   Alternative minimum tax Amt LT25K
# 27                 Alternative minimum tax Ct 50KLT75K
# 28                Alternative minimum tax Ct 75KLT100K
# 29                                            AsianPct
# 30                        Attrtion_Reason_OtherReasons
# 31                                            BlackPct
# 32                                            Byod_Yes
# 33                               Crime_Rate_Arson_Rate
# 34                                 Crime_Rate_MVT_Rate
# 35                              Crime_Rate_Murder_Rate
# 36                                Crime_Rate_Rape_Rate
# 37                             Crime_Rate_Robbery_Rate
# 38                             Crime_Rate_Violent_Rate
# 39                      Developing_TCHR_Standard 1_Pct
# 40                      Developing_TCHR_Standard 2_Pct
# 41                      Developing_TCHR_Standard 3_Pct
# 42                      Developing_TCHR_Standard 4_Pct
# 43                      Developing_TCHR_Standard 5_Pct
# 44                   Distinguished_TCHR_Standard 1_Pct
# 45                   Distinguished_TCHR_Standard 2_Pct
# 46                   Distinguished_TCHR_Standard 3_Pct
# 47                   Distinguished_TCHR_Standard 4_Pct
# 48                   Distinguished_TCHR_Standard 5_Pct
# 49   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 50   Does Not Meet Expected Growth_TCHR_Student Gro...
# 51   Domestic production activities deduction Amt 1...
# 52   Domestic production activities deduction Amt 2...
# 53   Domestic production activities deduction Amt 5...
# 54   Domestic production activities deduction Amt 7...
# 55   Domestic production activities deduction Amt L...
# 56   Domestic production activities deduction Ct 25...
# 57   Domestic production activities deduction Ct 50...
# 58   Domestic production activities deduction Ct 75...
# 59   Domestic production activities deduction Ct LT25K
# 60                                   EOCMathI_CACR_AIG
# 61                        EOCMathI_CACR_AmericanIndian
# 62                                 EOCMathI_CACR_Asian
# 63                                 EOCMathI_CACR_Black
# 64                                   EOCMathI_CACR_EDS
# 65                                EOCMathI_CACR_Female
# 66                              EOCMathI_CACR_Hispanic
# 67                                   EOCMathI_CACR_LEP
# 68                                  EOCMathI_CACR_Male
# 69                                   EOCMathI_CACR_SWD
# 70                        EOCMathI_CACR_TwoorMoreRaces
# 71                                 EOCMathI_CACR_White
# 72                                    EOCMathI_GLP_LEP
# 73                                    EOCMathI_GLP_SWD
# 74                                EOCSubjects_CACR_AIG
# 75                     EOCSubjects_CACR_AmericanIndian
# 76                              EOCSubjects_CACR_Asian
# 77                              EOCSubjects_CACR_Black
# 78                           EOCSubjects_CACR_Hispanic
# 79                                EOCSubjects_CACR_LEP
# 80                                EOCSubjects_CACR_SWD
# 81                     EOCSubjects_CACR_TwoorMoreRaces
# 82                                 EOCSubjects_GLP_LEP
# 83                            EOG/EOCSubjects_CACR_AIG
# 84                            EOG/EOCSubjects_CACR_All
# 85                 EOG/EOCSubjects_CACR_AmericanIndian
# 86                          EOG/EOCSubjects_CACR_Asian
# 87                          EOG/EOCSubjects_CACR_Black
# 88                            EOG/EOCSubjects_CACR_EDS
# 89                       EOG/EOCSubjects_CACR_Hispanic
# 90                            EOG/EOCSubjects_CACR_LEP
# 91                            EOG/EOCSubjects_CACR_SWD
# 92                 EOG/EOCSubjects_CACR_TwoorMoreRaces
# 93                          EOG/EOCSubjects_CACR_White
# 94                             EOG/EOCSubjects_GLP_LEP
# 95                                     EOGGr3_CACR_AIG
# 96                                     EOGGr3_CACR_All
# 97                          EOGGr3_CACR_AmericanIndian
# 98                                   EOGGr3_CACR_Asian
# 99                                   EOGGr3_CACR_Black
# 100                               EOGGr3_CACR_Hispanic
# 101                                    EOGGr3_CACR_LEP
# 102                                    EOGGr3_CACR_SWD
# 103                         EOGGr3_CACR_TwoorMoreRaces
# 104                                  EOGGr3_CACR_White
# 105                                     EOGGr3_GLP_SWD
# 106                                    EOGGr4_CACR_AIG
# 107                                    EOGGr4_CACR_All
# 108                         EOGGr4_CACR_AmericanIndian
# 109                                  EOGGr4_CACR_Asian
# 110                                  EOGGr4_CACR_Black
# 111                                    EOGGr4_CACR_EDS
# 112                               EOGGr4_CACR_Hispanic
# 113                                    EOGGr4_CACR_LEP
# 114                                    EOGGr4_CACR_SWD
# 115                         EOGGr4_CACR_TwoorMoreRaces
# 116                                  EOGGr4_CACR_White
# 117                                     EOGGr4_GLP_LEP
# 118                                     EOGGr4_GLP_SWD
# 119                                    EOGGr5_CACR_AIG
# 120                                    EOGGr5_CACR_All
# 121                         EOGGr5_CACR_AmericanIndian
# 122                                  EOGGr5_CACR_Asian
# 123                                  EOGGr5_CACR_Black
# 124                               EOGGr5_CACR_Hispanic
# 125                                    EOGGr5_CACR_LEP
# 126                                    EOGGr5_CACR_SWD
# 127                         EOGGr5_CACR_TwoorMoreRaces
# 128                                  EOGGr5_CACR_White
# 129                              EOGMathGr3-8_CACR_AIG
# 130                   EOGMathGr3-8_CACR_AmericanIndian
# 131                            EOGMathGr3-8_CACR_Asian
# 132                            EOGMathGr3-8_CACR_Black
# 133                              EOGMathGr3-8_CACR_EDS
# 134                         EOGMathGr3-8_CACR_Hispanic
# 135                              EOGMathGr3-8_CACR_LEP
# 136                              EOGMathGr3-8_CACR_SWD
# 137                   EOGMathGr3-8_CACR_TwoorMoreRaces
# 138                            EOGMathGr3-8_CACR_White
# 139                               EOGMathGr3-8_GLP_LEP
# 140                               EOGMathGr3-8_GLP_SWD
# 141                                EOGMathGr3_CACR_AIG
# 142                     EOGMathGr3_CACR_AmericanIndian
# 143                              EOGMathGr3_CACR_Asian
# 144                              EOGMathGr3_CACR_Black
# 145                                EOGMathGr3_CACR_EDS
# 146                           EOGMathGr3_CACR_Hispanic
# 147                                EOGMathGr3_CACR_LEP
# 148                                EOGMathGr3_CACR_SWD
# 149                     EOGMathGr3_CACR_TwoorMoreRaces
# 150                              EOGMathGr3_CACR_White
# 151                                 EOGMathGr3_GLP_SWD
# 152                                EOGMathGr4_CACR_AIG
# 153                     EOGMathGr4_CACR_AmericanIndian
# 154                              EOGMathGr4_CACR_Asian
# 155                              EOGMathGr4_CACR_Black
# 156                                EOGMathGr4_CACR_EDS
# 157                           EOGMathGr4_CACR_Hispanic
# 158                                EOGMathGr4_CACR_LEP
# 159                                EOGMathGr4_CACR_SWD
# 160                     EOGMathGr4_CACR_TwoorMoreRaces
# 161                              EOGMathGr4_CACR_White
# 162                                 EOGMathGr4_GLP_LEP
# 163                                 EOGMathGr4_GLP_SWD
# 164                                EOGMathGr5_CACR_AIG
# 165                     EOGMathGr5_CACR_AmericanIndian
# 166                              EOGMathGr5_CACR_Asian
# 167                              EOGMathGr5_CACR_Black
# 168                                EOGMathGr5_CACR_EDS
# 169                           EOGMathGr5_CACR_Hispanic
# 170                                EOGMathGr5_CACR_LEP
# 171                                EOGMathGr5_CACR_SWD
# 172                     EOGMathGr5_CACR_TwoorMoreRaces
# 173                              EOGMathGr5_CACR_White
# 174                                 EOGMathGr5_GLP_SWD
# 175                EOGReadingGr3-8_CACR_AmericanIndian
# 176                         EOGReadingGr3-8_CACR_Black
# 177                           EOGReadingGr3-8_CACR_EDS
# 178                      EOGReadingGr3-8_CACR_Hispanic
# 179                           EOGReadingGr3-8_CACR_LEP
# 180                           EOGReadingGr3-8_CACR_SWD
# 181                EOGReadingGr3-8_CACR_TwoorMoreRaces
# 182                            EOGReadingGr3-8_GLP_LEP
# 183                            EOGReadingGr3-8_GLP_SWD
# 184                  EOGReadingGr3_CACR_AmericanIndian
# 185                           EOGReadingGr3_CACR_Black
# 186                             EOGReadingGr3_CACR_EDS
# 187                        EOGReadingGr3_CACR_Hispanic
# 188                             EOGReadingGr3_CACR_LEP
# 189                             EOGReadingGr3_CACR_SWD
# 190                         Number of farm returns All
# 191  Partnership/S-corp net income (less loss) Amt ...
# 192                                               Year
# 193                           avg_age_media_collection
# 194                           lea_federal_perpupil_num
# 195                              lea_total_expense_num
# 196                                        lea_wap_num
# 197                                 st_avg_student_num
# 198                                        student_num
# 199                                          unit_code

# %% [markdown]
# ## Ridge

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Ridge

reg = Ridge()

reg_selector = SelectFromModel(reg, threshold='1.25*median', max_features=max_features)
reg_selector.fit(X_fs, y_fs)
reg_support = reg_selector.get_support()
reg_feature = X_fs.loc[:,reg_support].columns.tolist()
print(str(len(reg_feature)), 'selected features')
print(pd.DataFrame(reg_feature))
# Out:
# 188 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                           0-3 Years_LEA_Exp_Pct_Prin
# 2                                              00_Size
# 3                                              01_Size
# 4                                              03_Size
# 5                                              04_Size
# 6                           10+ Years_LEA_Exp_Pct_Prin
# 7                          4-10 Years_LEA_Exp_Pct_Prin
# 8                     Accomplished_TCHR_Standard 1_Pct
# 9                     Accomplished_TCHR_Standard 2_Pct
# 10                    Accomplished_TCHR_Standard 3_Pct
# 11                    Accomplished_TCHR_Standard 4_Pct
# 12                    Accomplished_TCHR_Standard 5_Pct
# 13                Alternative minimum tax Amt 25KLT50K
# 14                Alternative minimum tax Amt 50KLT75K
# 15                 Alternative minimum tax Ct 50KLT75K
# 16                                            AsianPct
# 17                                            BlackPct
# 18                                            Byod_Yes
# 19                               Crime_Rate_Arson_Rate
# 20                              Crime_Rate_Murder_Rate
# 21                                Crime_Rate_Rape_Rate
# 22                      Developing_TCHR_Standard 1_Pct
# 23                      Developing_TCHR_Standard 2_Pct
# 24                      Developing_TCHR_Standard 3_Pct
# 25                      Developing_TCHR_Standard 4_Pct
# 26                      Developing_TCHR_Standard 5_Pct
# 27                   Distinguished_TCHR_Standard 1_Pct
# 28                   Distinguished_TCHR_Standard 2_Pct
# 29                   Distinguished_TCHR_Standard 3_Pct
# 30                   Distinguished_TCHR_Standard 4_Pct
# 31                   Distinguished_TCHR_Standard 5_Pct
# 32   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 33   Does Not Meet Expected Growth_TCHR_Student Gro...
# 34                                EOCMathI_CACR_Female
# 35                                    EOCMathI_GLP_SWD
# 36                                 EOCSubjects_GLP_LEP
# 37                            EOG/EOCSubjects_CACR_All
# 38                            EOG/EOCSubjects_CACR_EDS
# 39                       EOG/EOCSubjects_CACR_Hispanic
# 40                                     EOGGr3_CACR_All
# 41                          EOGGr3_CACR_AmericanIndian
# 42                                     EOGGr3_CACR_SWD
# 43                                     EOGGr4_CACR_LEP
# 44                                      EOGGr4_GLP_LEP
# 45                               EOGMathGr3-8_CACR_SWD
# 46                      EOGMathGr3_CACR_AmericanIndian
# 47                                  EOGMathGr4_GLP_LEP
# 48                            EOGMathGr5_CACR_Hispanic
# 49                          EOGReadingGr3-8_CACR_Black
# 50                            EOGReadingGr3-8_CACR_SWD
# 51                   EOGReadingGr3_CACR_AmericanIndian
# 52                   EOGReadingGr4_CACR_AmericanIndian
# 53                              EOGReadingGr4_CACR_SWD
# 54                               EOGReadingGr4_GLP_SWD
# 55                   EOGReadingGr5_CACR_AmericanIndian
# 56                              EOGReadingGr5_CACR_LEP
# 57                    EOGReadingGr5_GLP_AmericanIndian
# 58                   EOGScienceGr5_CACR_AmericanIndian
# 59                              EOGScienceGr5_CACR_EDS
# 60                     EOGSubjects_CACR_TwoorMoreRaces
# 61                                  EVAAS Growth Score
# 62                             EVAAS Growth Status_Met
# 63                          EVAAS Growth Status_NotMet
# 64         Exceeds Expected Growth_TCHR_Standard 6_Pct
# 65     Exceeds Expected Growth_TCHR_Student Growth_Pct
# 66   Excess earned income credit (refundable) Amt 5...
# 67                               Grad_project_status_Y
# 68                                         HispanicPct
# 69                                           IndianPct
# 70                                    Math SPG Grade_B
# 71                                    Math SPG Grade_C
# 72                                    Math SPG Grade_D
# 73                                    Math SPG Grade_F
# 74                            MathGr3-8_pTarget_PctMet
# 75           Meets Expected Growth_TCHR_Standard 6_Pct
# 76       Meets Expected Growth_TCHR_Student Growth_Pct
# 77                 Not Demostrated_TCHR_Standard 1_Pct
# 78                 Not Demostrated_TCHR_Standard 2_Pct
# 79                 Not Demostrated_TCHR_Standard 4_Pct
# 80                 Not Demostrated_TCHR_Standard 5_Pct
# 81                              PacificIslandFemalePct
# 82                                PacificIslandMalePct
# 83                                    PacificIslandPct
# 84                      Proficient_TCHR_Standard 1_Pct
# 85                      Proficient_TCHR_Standard 2_Pct
# 86                      Proficient_TCHR_Standard 3_Pct
# 87                      Proficient_TCHR_Standard 4_Pct
# 88                      Proficient_TCHR_Standard 5_Pct
# 89                                 Reading SPG Grade_B
# 90                                 Reading SPG Grade_C
# 91                                 Reading SPG Grade_D
# 92                                 Reading SPG Grade_F
# 93                         ReadingGr3-8_pTarget_PctMet
# 94             Residential energy tax credit Amt LT25K
# 95                              SBE District_Northeast
# 96                              SBE District_Northwest
# 97                         SBE District_Piedmont-Triad
# 98                              SBE District_Sandhills
# 99                              SBE District_Southeast
# 100                             SBE District_Southwest
# 101                               SBE District_Western
# 102                                     SPG Grade_A+NG
# 103                                        SPG Grade_B
# 104                                        SPG Grade_C
# 105                                        SPG Grade_D
# 106                                        SPG Grade_F
# 107                                        SPG Grade_I
# 108                            SciGr5&8_pTarget_PctMet
# 109                               State Gap Compared_Y
# 110                        TotalTargets_pTarget_PctMet
# 111                                 TwoOrMoreFemalePct
# 112                                   TwoOrMoreMalePct
# 113                                       TwoOrMorePct
# 114                                           WhitePct
# 115                                 _1_to_1_access_Yes
# 116                                    advance_dgr_pct
# 117                               avg_daily_attend_pct
# 118                  calendar_type_txt_Hospital School
# 119  calendar_type_txt_Magnet School, Traditional C...
# 120  calendar_type_txt_Magnet School, Year-Round Ca...
# 121  calendar_type_txt_Regular School, Traditional ...
# 122  calendar_type_txt_Regular School, Traditional ...
# 123  calendar_type_txt_Regular School, Year-Round C...
# 124  calendar_type_txt_Special Education, Tradition...
# 125                                      category_cd_E
# 126                                      category_cd_I
# 127                                      category_cd_M
# 128                                      category_cd_T
# 129                                         closed_ind
# 130                                  digital_media_pct
# 131                                esea_attendance_Met
# 132                                      esea_status_P
# 133                                      esea_status_R
# 134                                     esea_status_RF
# 135                                 expelled_per_c_num
# 136                                flicensed_teach_pct
# 137                                 highqual_class_pct
# 138                                  lateral_teach_pct
# 139                                lea_advance_dgr_pct
# 140                           lea_ap_participation_pct
# 141                              lea_ap_pct_3_or_above
# 142                           lea_avg_daily_attend_pct
# 143                           lea_benefits_expense_pct
# 144                              lea_books_per_student
# 145                                lea_crime_per_c_num
# 146                            lea_emer_prov_teach_pct
# 147                             lea_expelled_per_c_num
# 148                            lea_flicensed_teach_pct
# 149                         lea_highqual_class_all_pct
# 150                          lea_highqual_class_hp_pct
# 151                          lea_highqual_class_lp_pct
# 152                             lea_highqual_class_pct
# 153                              lea_ib_pct_4_or_above
# 154                         lea_instruct_equip_exp_pct
# 155                            lea_long_susp_per_c_num
# 156                                      lea_nbpts_num
# 157                      lea_not_highqual_class_hp_pct
# 158                      lea_not_highqual_class_lp_pct
# 159                             lea_salary_expense_pct
# 160                          lea_sat_participation_pct
# 161                           lea_services_expense_pct
# 162                         lea_stud_internet_comp_num
# 163                           lea_supplies_expense_pct
# 164                              lea_tchyrs_0thru3_pct
# 165                              lea_tchyrs_11plus_pct
# 166                             lea_tchyrs_4thru10_pct
# 167                              lea_wap_per_classroom
# 168                                long_susp_per_c_num
# 169                                          nbpts_num
# 170                                        pct_GCE_ALL
# 171                     school_type_txt_Regular School
# 172                            st_avg_daily_attend_pct
# 173                                 st_crime_per_c_num
# 174                             st_emer_prov_teach_pct
# 175                              st_expelled_per_c_num
# 176                             st_flicensed_teach_pct
# 177                              st_highqual_class_pct
# 178                             st_long_susp_per_c_num
# 179                                       st_nbpts_num
# 180                            st_short_susp_per_c_num
# 181                               st_tchyrs_0thru3_pct
# 182                               st_tchyrs_11plus_pct
# 183                             stud_internet_comp_num
# 184                                  tchyrs_0thru3_pct
# 185                                  tchyrs_11plus_pct
# 186                                 tchyrs_4thru10_pct
# 187                                  wap_per_classroom

# %% [markdown]
# ## Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet

ELN = ElasticNet()

ELN_selector = SelectFromModel(ELN, threshold='1.25*median', max_features=max_features)
ELN_selector.fit(X_fs, y_fs)
ELN_support = ELN_selector.get_support()
ELN_feature = X_fs.loc[:,ELN_support].columns.tolist()
print(str(len(ELN_feature)), 'selected features')
print(pd.DataFrame(ELN_feature))
# Out:
# 200 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                   (TCE) prepared returns Ct 25KLT50K
# 2                  (TCE) prepared returns Ct 75KLT100K
# 3                (VITA) prepared returns Ct 100KLT200K
# 4                  (VITA) prepared returns Ct 25KLT50K
# 5                  (VITA) prepared returns Ct 50KLT75K
# 6                           0-3 Years_LEA_Exp_Pct_Prin
# 7                                              00_Size
# 8                                              01_Size
# 9                                              02_Size
# 10                                             03_Size
# 11                                             04_Size
# 12                                             05_Size
# 13                          10+ Years_LEA_Exp_Pct_Prin
# 14                         4-10 Years_LEA_Exp_Pct_Prin
# 15                    Accomplished_TCHR_Standard 1_Pct
# 16                    Accomplished_TCHR_Standard 2_Pct
# 17                    Accomplished_TCHR_Standard 3_Pct
# 18                    Accomplished_TCHR_Standard 4_Pct
# 19                    Accomplished_TCHR_Standard 5_Pct
# 20                     Add Medicare tax Amt 100KLT200K
# 21                   Add child tax credit Amt 25KLT50K
# 22                  Add child tax credit Amt 75KLT100K
# 23                Alternative minimum tax Amt 25KLT50K
# 24                Alternative minimum tax Amt 50KLT75K
# 25               Alternative minimum tax Amt 75KLT100K
# 26                   Alternative minimum tax Amt LT25K
# 27                 Alternative minimum tax Ct 50KLT75K
# 28                Alternative minimum tax Ct 75KLT100K
# 29                                            AsianPct
# 30                        Attrtion_Reason_OtherReasons
# 31                                            BlackPct
# 32                                            Byod_Yes
# 33                               Crime_Rate_Arson_Rate
# 34                                 Crime_Rate_MVT_Rate
# 35                              Crime_Rate_Murder_Rate
# 36                                Crime_Rate_Rape_Rate
# 37                             Crime_Rate_Robbery_Rate
# 38                             Crime_Rate_Violent_Rate
# 39                      Developing_TCHR_Standard 1_Pct
# 40                      Developing_TCHR_Standard 2_Pct
# 41                      Developing_TCHR_Standard 3_Pct
# 42                      Developing_TCHR_Standard 4_Pct
# 43                      Developing_TCHR_Standard 5_Pct
# 44                   Distinguished_TCHR_Standard 1_Pct
# 45                   Distinguished_TCHR_Standard 2_Pct
# 46                   Distinguished_TCHR_Standard 3_Pct
# 47                   Distinguished_TCHR_Standard 4_Pct
# 48                   Distinguished_TCHR_Standard 5_Pct
# 49   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 50   Does Not Meet Expected Growth_TCHR_Student Gro...
# 51   Domestic production activities deduction Amt 1...
# 52   Domestic production activities deduction Amt 2...
# 53   Domestic production activities deduction Amt 5...
# 54   Domestic production activities deduction Amt 7...
# 55   Domestic production activities deduction Amt L...
# 56   Domestic production activities deduction Ct 25...
# 57   Domestic production activities deduction Ct 50...
# 58   Domestic production activities deduction Ct 75...
# 59   Domestic production activities deduction Ct LT25K
# 60                                   EOCMathI_CACR_AIG
# 61                        EOCMathI_CACR_AmericanIndian
# 62                                 EOCMathI_CACR_Asian
# 63                                 EOCMathI_CACR_Black
# 64                                   EOCMathI_CACR_EDS
# 65                                EOCMathI_CACR_Female
# 66                              EOCMathI_CACR_Hispanic
# 67                                   EOCMathI_CACR_LEP
# 68                                  EOCMathI_CACR_Male
# 69                                   EOCMathI_CACR_SWD
# 70                        EOCMathI_CACR_TwoorMoreRaces
# 71                                 EOCMathI_CACR_White
# 72                                    EOCMathI_GLP_LEP
# 73                                    EOCMathI_GLP_SWD
# 74                                EOCSubjects_CACR_AIG
# 75                     EOCSubjects_CACR_AmericanIndian
# 76                              EOCSubjects_CACR_Asian
# 77                              EOCSubjects_CACR_Black
# 78                           EOCSubjects_CACR_Hispanic
# 79                                EOCSubjects_CACR_LEP
# 80                                EOCSubjects_CACR_SWD
# 81                     EOCSubjects_CACR_TwoorMoreRaces
# 82                                 EOCSubjects_GLP_LEP
# 83                            EOG/EOCSubjects_CACR_AIG
# 84                            EOG/EOCSubjects_CACR_All
# 85                 EOG/EOCSubjects_CACR_AmericanIndian
# 86                          EOG/EOCSubjects_CACR_Asian
# 87                          EOG/EOCSubjects_CACR_Black
# 88                            EOG/EOCSubjects_CACR_EDS
# 89                       EOG/EOCSubjects_CACR_Hispanic
# 90                            EOG/EOCSubjects_CACR_LEP
# 91                            EOG/EOCSubjects_CACR_SWD
# 92                 EOG/EOCSubjects_CACR_TwoorMoreRaces
# 93                          EOG/EOCSubjects_CACR_White
# 94                             EOG/EOCSubjects_GLP_LEP
# 95                                     EOGGr3_CACR_AIG
# 96                                     EOGGr3_CACR_All
# 97                          EOGGr3_CACR_AmericanIndian
# 98                                   EOGGr3_CACR_Asian
# 99                                   EOGGr3_CACR_Black
# 100                               EOGGr3_CACR_Hispanic
# 101                                    EOGGr3_CACR_LEP
# 102                                    EOGGr3_CACR_SWD
# 103                         EOGGr3_CACR_TwoorMoreRaces
# 104                                  EOGGr3_CACR_White
# 105                                     EOGGr3_GLP_SWD
# 106                                    EOGGr4_CACR_AIG
# 107                                    EOGGr4_CACR_All
# 108                         EOGGr4_CACR_AmericanIndian
# 109                                  EOGGr4_CACR_Asian
# 110                                  EOGGr4_CACR_Black
# 111                                    EOGGr4_CACR_EDS
# 112                               EOGGr4_CACR_Hispanic
# 113                                    EOGGr4_CACR_LEP
# 114                                    EOGGr4_CACR_SWD
# 115                         EOGGr4_CACR_TwoorMoreRaces
# 116                                  EOGGr4_CACR_White
# 117                                     EOGGr4_GLP_LEP
# 118                                     EOGGr4_GLP_SWD
# 119                                    EOGGr5_CACR_AIG
# 120                                    EOGGr5_CACR_All
# 121                         EOGGr5_CACR_AmericanIndian
# 122                                  EOGGr5_CACR_Asian
# 123                                  EOGGr5_CACR_Black
# 124                               EOGGr5_CACR_Hispanic
# 125                                    EOGGr5_CACR_LEP
# 126                                    EOGGr5_CACR_SWD
# 127                         EOGGr5_CACR_TwoorMoreRaces
# 128                                  EOGGr5_CACR_White
# 129                              EOGMathGr3-8_CACR_AIG
# 130                   EOGMathGr3-8_CACR_AmericanIndian
# 131                            EOGMathGr3-8_CACR_Asian
# 132                            EOGMathGr3-8_CACR_Black
# 133                              EOGMathGr3-8_CACR_EDS
# 134                         EOGMathGr3-8_CACR_Hispanic
# 135                              EOGMathGr3-8_CACR_LEP
# 136                              EOGMathGr3-8_CACR_SWD
# 137                   EOGMathGr3-8_CACR_TwoorMoreRaces
# 138                            EOGMathGr3-8_CACR_White
# 139                               EOGMathGr3-8_GLP_LEP
# 140                               EOGMathGr3-8_GLP_SWD
# 141                                EOGMathGr3_CACR_AIG
# 142                     EOGMathGr3_CACR_AmericanIndian
# 143                              EOGMathGr3_CACR_Asian
# 144                              EOGMathGr3_CACR_Black
# 145                                EOGMathGr3_CACR_EDS
# 146                           EOGMathGr3_CACR_Hispanic
# 147                                EOGMathGr3_CACR_LEP
# 148                                EOGMathGr3_CACR_SWD
# 149                     EOGMathGr3_CACR_TwoorMoreRaces
# 150                              EOGMathGr3_CACR_White
# 151                                 EOGMathGr3_GLP_SWD
# 152                                EOGMathGr4_CACR_AIG
# 153                     EOGMathGr4_CACR_AmericanIndian
# 154                              EOGMathGr4_CACR_Asian
# 155                              EOGMathGr4_CACR_Black
# 156                                EOGMathGr4_CACR_EDS
# 157                           EOGMathGr4_CACR_Hispanic
# 158                                EOGMathGr4_CACR_LEP
# 159                                EOGMathGr4_CACR_SWD
# 160                     EOGMathGr4_CACR_TwoorMoreRaces
# 161                              EOGMathGr4_CACR_White
# 162                                 EOGMathGr4_GLP_LEP
# 163                                 EOGMathGr4_GLP_SWD
# 164                                EOGMathGr5_CACR_AIG
# 165                     EOGMathGr5_CACR_AmericanIndian
# 166                              EOGMathGr5_CACR_Asian
# 167                              EOGMathGr5_CACR_Black
# 168                                EOGMathGr5_CACR_EDS
# 169                           EOGMathGr5_CACR_Hispanic
# 170                                EOGMathGr5_CACR_LEP
# 171                                EOGMathGr5_CACR_SWD
# 172                     EOGMathGr5_CACR_TwoorMoreRaces
# 173                              EOGMathGr5_CACR_White
# 174                                 EOGMathGr5_GLP_SWD
# 175                EOGReadingGr3-8_CACR_AmericanIndian
# 176                         EOGReadingGr3-8_CACR_Black
# 177                           EOGReadingGr3-8_CACR_EDS
# 178                      EOGReadingGr3-8_CACR_Hispanic
# 179                           EOGReadingGr3-8_CACR_LEP
# 180                           EOGReadingGr3-8_CACR_SWD
# 181                EOGReadingGr3-8_CACR_TwoorMoreRaces
# 182                            EOGReadingGr3-8_GLP_LEP
# 183                            EOGReadingGr3-8_GLP_SWD
# 184                  EOGReadingGr3_CACR_AmericanIndian
# 185                           EOGReadingGr3_CACR_Black
# 186                         Number of farm returns All
# 187  Partnership/S-corp net income (less loss) Amt ...
# 188                                               Year
# 189                           avg_age_media_collection
# 190                                lea_avg_student_num
# 191                           lea_federal_perpupil_num
# 192                             lea_local_perpupil_num
# 193                              lea_total_expense_num
# 194                                        lea_wap_num
# 195                               short_susp_per_c_num
# 196                                 st_avg_student_num
# 197                                        student_num
# 198                                          unit_code
# 199                                         lea_salary

# %%
## Summary
pd.set_option('display.max_rows', None)
# put all selection together
feature_selection_df = pd.DataFrame({'Feature':feature_name
                                     , 'Pearson':cor_support
                                     , 'Linear Regression':Linear_support
                                     , 'RFE':rfe_support
                                     , 'Lasso':LassoCV_support
                                     ,'Ridge':reg_support
                                     , 'Elastic Net':ELN_support
                                     
                                    })
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] ,
ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df
# Out:
#                                                Feature  Pearson  \
# 1                             EOGReadingGr3-8_CACR_SWD     True
# 2                           EOGReadingGr3-8_CACR_Black     True
# 3                                EOGMathGr3-8_CACR_SWD     True
# 4                                      EOGGr3_CACR_SWD     True
# 5                        EOG/EOCSubjects_CACR_Hispanic     True
# 6                             EOG/EOCSubjects_CACR_EDS     True
# 7                             EOG/EOCSubjects_CACR_All     True
# 8    Does Not Meet Expected Growth_TCHR_Standard 6_Pct     True
# 9                    Distinguished_TCHR_Standard 5_Pct     True
# 10                   Distinguished_TCHR_Standard 3_Pct     True
# 11                   Distinguished_TCHR_Standard 2_Pct     True
# 12                   Distinguished_TCHR_Standard 1_Pct     True
# 13                      Developing_TCHR_Standard 5_Pct     True
# 14                      Developing_TCHR_Standard 4_Pct     True
# 15                      Developing_TCHR_Standard 3_Pct     True
# 16                      Developing_TCHR_Standard 2_Pct     True
# 17                      Developing_TCHR_Standard 1_Pct     True
# 18                              Crime_Rate_Murder_Rate     True
# 19                                            BlackPct     True
# 20                    Accomplished_TCHR_Standard 5_Pct     True
# 21                    Accomplished_TCHR_Standard 4_Pct     True
# 22                    Accomplished_TCHR_Standard 3_Pct     True
# 23                    Accomplished_TCHR_Standard 2_Pct     True
# 24                    Accomplished_TCHR_Standard 1_Pct     True
# 25                         4-10 Years_LEA_Exp_Pct_Prin     True
# 26                                             04_Size     True
# 27                                             03_Size     True
# 28                                             00_Size     True
# 29                          0-3 Years_LEA_Exp_Pct_Prin     True
# 30                   EOGReadingGr3_CACR_AmericanIndian    False
# 31                            EOGMathGr5_CACR_Hispanic     True
# 32                                  EOGMathGr4_GLP_LEP    False
# 33                      EOGMathGr3_CACR_AmericanIndian    False
# 34                                     EOGGr4_CACR_LEP    False
# 35                          EOGGr3_CACR_AmericanIndian    False
# 36                                     EOGGr3_CACR_All     True
# 37                                 EOCSubjects_GLP_LEP    False
# 38                                    EOCMathI_GLP_SWD    False
# 39                                EOCMathI_CACR_Female    False
# 40   Does Not Meet Expected Growth_TCHR_Student Gro...    False
# 41                   Distinguished_TCHR_Standard 4_Pct     True
# 42                                Crime_Rate_Rape_Rate    False
# 43                               Crime_Rate_Arson_Rate    False
# 44                                            Byod_Yes    False
# 45                                            AsianPct    False
# 46                 Alternative minimum tax Ct 50KLT75K    False
# 47                Alternative minimum tax Amt 50KLT75K    False
# 48                Alternative minimum tax Amt 25KLT50K    False
# 49                          10+ Years_LEA_Exp_Pct_Prin    False
# 50                                             01_Size    False
# 51                (TCE) prepared returns Ct 100KLT200K    False
# 52                                  tchyrs_4thru10_pct     True
# 53                                   tchyrs_11plus_pct     True
# 54                                   tchyrs_0thru3_pct     True
# 55                              st_flicensed_teach_pct     True
# 56                                  st_crime_per_c_num     True
# 57                      school_type_txt_Regular School     True
# 58                                           nbpts_num     True
# 59                              lea_tchyrs_4thru10_pct     True
# 60                               lea_tchyrs_11plus_pct     True
# 61                               lea_tchyrs_0thru3_pct     True
# 62                            lea_supplies_expense_pct     True
# 63                          lea_stud_internet_comp_num     True
# 64                            lea_services_expense_pct     True
# 65                                       lea_nbpts_num     True
# 66                             lea_flicensed_teach_pct     True
# 67                                 lea_crime_per_c_num     True
# 68                               lea_ap_pct_3_or_above     True
# 69                            lea_ap_participation_pct     True
# 70                                 lea_advance_dgr_pct     True
# 71                                   lateral_teach_pct     True
# 72                                 flicensed_teach_pct     True
# 73                                       esea_status_P     True
# 74                                       category_cd_T     True
# 75                                       category_cd_E     True
# 76                                avg_daily_attend_pct     True
# 77                                     advance_dgr_pct     True
# 78                                            WhitePct     True
# 79                         TotalTargets_pTarget_PctMet     True
# 80                             SciGr5&8_pTarget_PctMet     True
# 81                                         SPG Grade_F     True
# 82                                         SPG Grade_D     True
# 83                                         SPG Grade_C     True
# 84                                         SPG Grade_B     True
# 85                                 Reading SPG Grade_F     True
# 86                                 Reading SPG Grade_D     True
# 87                                 Reading SPG Grade_B     True
# 88                      Proficient_TCHR_Standard 5_Pct     True
# 89                      Proficient_TCHR_Standard 4_Pct     True
# 90                      Proficient_TCHR_Standard 3_Pct     True
# 91                      Proficient_TCHR_Standard 2_Pct     True
# 92                      Proficient_TCHR_Standard 1_Pct     True
# 93                                    Math SPG Grade_F     True
# 94                                    Math SPG Grade_C     True
# 95                                    Math SPG Grade_B     True
# 96                               Grad_project_status_Y     True
# 97                          EVAAS Growth Status_NotMet     True
# 98                                  EVAAS Growth Score     True
# 99                              EOGScienceGr5_CACR_EDS     True
# 100                              EOGReadingGr4_GLP_SWD     True
# 101                             EOGReadingGr4_CACR_SWD     True
# 102                            EOGReadingGr3-8_GLP_SWD     True
# 103                                EOGMathGr5_CACR_EDS     True
# 104                                EOGMathGr3_CACR_SWD     True
# 105                              EOGMathGr3-8_CACR_EDS     True
# 106                                     EOGGr4_GLP_LEP    False
# 107                           EOG/EOCSubjects_CACR_SWD     True
# 108                               EOCSubjects_CACR_SWD    False
# 109                               EOCSubjects_CACR_LEP    False
# 110                                            05_Size     True
# 111                                            02_Size     True
# 112                                  wap_per_classroom    False
# 113                                        student_num     True
# 114                             stud_internet_comp_num     True
# 115                               st_tchyrs_11plus_pct    False
# 116                               st_tchyrs_0thru3_pct    False
# 117                            st_short_susp_per_c_num    False
# 118                             st_long_susp_per_c_num    False
# 119                              st_highqual_class_pct    False
# 120                              st_expelled_per_c_num    False
# 121                             st_emer_prov_teach_pct    False
# 122                                 st_avg_student_num     True
# 123                            st_avg_daily_attend_pct    False
# 124                                        pct_GCE_ALL    False
# 125                                long_susp_per_c_num    False
# 126                              lea_wap_per_classroom    False
# 127                              lea_total_expense_num     True
# 128                          lea_sat_participation_pct    False
# 129                             lea_salary_expense_pct    False
# 130                      lea_not_highqual_class_lp_pct    False
# 131                      lea_not_highqual_class_hp_pct    False
# 132                            lea_long_susp_per_c_num    False
# 133                         lea_instruct_equip_exp_pct    False
# 134                              lea_ib_pct_4_or_above    False
# 135                             lea_highqual_class_pct    False
# 136                          lea_highqual_class_lp_pct    False
# 137                          lea_highqual_class_hp_pct    False
# 138                         lea_highqual_class_all_pct    False
# 139                           lea_federal_perpupil_num     True
# 140                             lea_expelled_per_c_num    False
# 141                            lea_emer_prov_teach_pct    False
# 142                              lea_books_per_student    False
# 143                           lea_benefits_expense_pct    False
# 144                           lea_avg_daily_attend_pct    False
# 145                                 highqual_class_pct    False
# 146                                 expelled_per_c_num    False
# 147                                     esea_status_RF    False
# 148                                      esea_status_R    False
# 149                                esea_attendance_Met    False
# 150                                  digital_media_pct    False
# 151                                         closed_ind    False
# 152                                      category_cd_M    False
# 153                                      category_cd_I    False
# 154  calendar_type_txt_Special Education, Tradition...    False
# 155  calendar_type_txt_Regular School, Year-Round C...    False
# 156  calendar_type_txt_Regular School, Traditional ...    False
# 157  calendar_type_txt_Regular School, Traditional ...    False
# 158  calendar_type_txt_Magnet School, Year-Round Ca...    False
# 159  calendar_type_txt_Magnet School, Traditional C...    False
# 160                  calendar_type_txt_Hospital School    False
# 161                                       TwoOrMorePct    False
# 162                                   TwoOrMoreMalePct    False
# 163                                 TwoOrMoreFemalePct    False
# 164                               State Gap Compared_Y    False
# 165                                        SPG Grade_I    False
# 166                                     SPG Grade_A+NG    False
# 167                             SBE District_Southwest    False
# 168                             SBE District_Southeast    False
# 169                             SBE District_Sandhills    False
# 170                        SBE District_Piedmont-Triad    False
# 171                             SBE District_Northwest    False
# 172                             SBE District_Northeast    False
# 173            Residential energy tax credit Amt LT25K    False
# 174                        ReadingGr3-8_pTarget_PctMet    False
# 175                                Reading SPG Grade_C     True
# 176  Partnership/S-corp net income (less loss) Amt ...     True
# 177                                   PacificIslandPct    False
# 178                               PacificIslandMalePct    False
# 179                             PacificIslandFemalePct    False
# 180                         Number of farm returns All     True
# 181                Not Demostrated_TCHR_Standard 5_Pct    False
# 182                Not Demostrated_TCHR_Standard 4_Pct    False
# 183                Not Demostrated_TCHR_Standard 2_Pct    False
# 184                Not Demostrated_TCHR_Standard 1_Pct    False
# 185      Meets Expected Growth_TCHR_Student Growth_Pct    False
# 186          Meets Expected Growth_TCHR_Standard 6_Pct    False
# 187                           MathGr3-8_pTarget_PctMet     True
# 188                                   Math SPG Grade_D    False
# 189                                          IndianPct    False
# 190                                        HispanicPct    False
# 191    Exceeds Expected Growth_TCHR_Student Growth_Pct    False
# 192        Exceeds Expected Growth_TCHR_Standard 6_Pct    False
# 193                            EVAAS Growth Status_Met    False
# 194                              EOGScienceGr5_GLP_SWD     True
# 195                  EOGScienceGr5_CACR_AmericanIndian    False
# 196                   EOGReadingGr5_GLP_AmericanIndian    False
# 197                  EOGReadingGr5_CACR_AmericanIndian    False
# 198                  EOGReadingGr4_CACR_AmericanIndian    False
# 199                            EOGReadingGr3-8_GLP_LEP     True
# 200                EOGReadingGr3-8_CACR_TwoorMoreRaces     True
# 201                           EOGReadingGr3-8_CACR_LEP     True
# 202                      EOGReadingGr3-8_CACR_Hispanic     True
# 203                           EOGReadingGr3-8_CACR_EDS     True
# 204                                 EOGMathGr5_GLP_SWD     True
# 205                              EOGMathGr5_CACR_White     True
# 206                                EOGMathGr5_CACR_SWD     True
# 207                                EOGMathGr5_CACR_AIG     True
# 208                                 EOGMathGr4_GLP_SWD     True
# 209                              EOGMathGr4_CACR_White     True
# 210                                EOGMathGr4_CACR_SWD     True
# 211                           EOGMathGr4_CACR_Hispanic     True
# 212                                EOGMathGr4_CACR_EDS     True
# 213                                EOGMathGr4_CACR_AIG     True
# 214                                 EOGMathGr3_GLP_SWD     True
# 215                              EOGMathGr3_CACR_White     True
# 216                                EOGMathGr3_CACR_LEP     True
# 217                           EOGMathGr3_CACR_Hispanic     True
# 218                                EOGMathGr3_CACR_EDS     True
# 219                                EOGMathGr3_CACR_AIG     True
# 220                               EOGMathGr3-8_GLP_SWD     True
# 221                            EOGMathGr3-8_CACR_White     True
# 222                   EOGMathGr3-8_CACR_TwoorMoreRaces     True
# 223                              EOGMathGr3-8_CACR_LEP     True
# 224                         EOGMathGr3-8_CACR_Hispanic     True
# 225                            EOGMathGr3-8_CACR_Black     True
# 226                            EOGMathGr3-8_CACR_Asian     True
# 227                              EOGMathGr3-8_CACR_AIG     True
# 228                                  EOGGr5_CACR_White     True
# 229                         EOGGr5_CACR_TwoorMoreRaces     True
# 230                                    EOGGr5_CACR_SWD     True
# 231                                    EOGGr5_CACR_LEP    False
# 232                               EOGGr5_CACR_Hispanic     True
# 233                                  EOGGr5_CACR_Black     True
# 234                                  EOGGr5_CACR_Asian     True
# 235                                    EOGGr5_CACR_All     True
# 236                                    EOGGr5_CACR_AIG     True
# 237                                     EOGGr4_GLP_SWD     True
# 238                                  EOGGr4_CACR_White     True
# 239                         EOGGr4_CACR_TwoorMoreRaces     True
# 240                                    EOGGr4_CACR_SWD     True
# 241                               EOGGr4_CACR_Hispanic     True
# 242                                    EOGGr4_CACR_EDS     True
# 243                                  EOGGr4_CACR_Black     True
# 244                                  EOGGr4_CACR_Asian     True
# 245                                    EOGGr4_CACR_All     True
# 246                                    EOGGr4_CACR_AIG     True
# 247                                     EOGGr3_GLP_SWD     True
# 248                                  EOGGr3_CACR_White     True
# 249                         EOGGr3_CACR_TwoorMoreRaces     True
# 250                                    EOGGr3_CACR_LEP     True
# 251                               EOGGr3_CACR_Hispanic     True
# 252                                  EOGGr3_CACR_Black     True
# 253                                    EOGGr3_CACR_AIG     True
# 254                            EOG/EOCSubjects_GLP_LEP     True
# 255                         EOG/EOCSubjects_CACR_White     True
# 256                EOG/EOCSubjects_CACR_TwoorMoreRaces     True
# 257                           EOG/EOCSubjects_CACR_LEP     True
# 258                         EOG/EOCSubjects_CACR_Black     True
# 259                         EOG/EOCSubjects_CACR_Asian     True
# 260                           EOG/EOCSubjects_CACR_AIG     True
# 261                                   EOCMathI_GLP_LEP    False
# 262                                  EOCMathI_CACR_SWD    False
# 263                                EOCMathI_CACR_Black     True
# 264                       EOCMathI_CACR_AmericanIndian    False
# 265  Domestic production activities deduction Ct 50...     True
# 266  Domestic production activities deduction Ct 25...     True
# 267  Domestic production activities deduction Amt 1...     True
# 268                  Alternative minimum tax Amt LT25K    False
# 269                                          unit_code    False
# 270                                       st_nbpts_num    False
# 271                               short_susp_per_c_num     True
# 272                                        lea_wap_num    False
# 273                           avg_age_media_collection    False
# 274                                 _1_to_1_access_Yes    False
# 275                                               Year    False
# 276                                          SPG Score     True
# 277                               SBE District_Western    False
# 278  Excess earned income credit (refundable) Amt 5...    False
# 279                    EOGSubjects_CACR_TwoorMoreRaces     True
# 280                               EOGSubjects_CACR_LEP     True
# 281                            EOGScienceGr5&8_GLP_SWD     True
# 282                              EOGReadingGr5_GLP_SWD     True
# 283                             EOGReadingGr5_CACR_SWD     True
# 284                             EOGReadingGr5_CACR_LEP    False
# 285                             EOGReadingGr3_CACR_SWD     True
# 286                             EOGReadingGr3_CACR_LEP     True
# 287                        EOGReadingGr3_CACR_Hispanic     True
# 288                             EOGReadingGr3_CACR_EDS     True
# 289                           EOGReadingGr3_CACR_Black    False
# 290                EOGReadingGr3-8_CACR_AmericanIndian    False
# 291                     EOGMathGr5_CACR_TwoorMoreRaces    False
# 292                                EOGMathGr5_CACR_LEP    False
# 293                              EOGMathGr5_CACR_Black    False
# 294                              EOGMathGr5_CACR_Asian    False
# 295                     EOGMathGr5_CACR_AmericanIndian    False
# 296                     EOGMathGr4_CACR_TwoorMoreRaces    False
# 297                                EOGMathGr4_CACR_LEP    False
# 298                              EOGMathGr4_CACR_Black    False
# 299                              EOGMathGr4_CACR_Asian    False
# 300                     EOGMathGr4_CACR_AmericanIndian    False
# 301                     EOGMathGr3_CACR_TwoorMoreRaces    False
# 302                              EOGMathGr3_CACR_Black    False
# 303                              EOGMathGr3_CACR_Asian    False
# 304                               EOGMathGr3-8_GLP_LEP    False
# 305                   EOGMathGr3-8_CACR_AmericanIndian    False
# 306                         EOGGr5_CACR_AmericanIndian    False
# 307                         EOGGr4_CACR_AmericanIndian    False
# 308                                  EOGGr3_CACR_Asian    False
# 309                EOG/EOCSubjects_CACR_AmericanIndian    False
# 310                    EOCSubjects_CACR_TwoorMoreRaces    False
# 311                          EOCSubjects_CACR_Hispanic    False
# 312                             EOCSubjects_CACR_Black    False
# 313                             EOCSubjects_CACR_Asian    False
# 314                    EOCSubjects_CACR_AmericanIndian    False
# 315                               EOCSubjects_CACR_AIG    False
# 316                                EOCMathI_CACR_White    False
# 317                       EOCMathI_CACR_TwoorMoreRaces    False
# 318                                 EOCMathI_CACR_Male    False
# 319                                  EOCMathI_CACR_LEP    False
# 320                             EOCMathI_CACR_Hispanic    False
# 321                                  EOCMathI_CACR_EDS    False
# 322                                EOCMathI_CACR_Asian    False
# 323                                  EOCMathI_CACR_AIG    False
# 324  Domestic production activities deduction Ct LT25K    False
# 325  Domestic production activities deduction Ct 75...    False
# 326  Domestic production activities deduction Amt L...    False
# 327  Domestic production activities deduction Amt 7...    False
# 328  Domestic production activities deduction Amt 5...    False
# 329  Domestic production activities deduction Amt 2...    False
# 330                            Crime_Rate_Violent_Rate    False
# 331                            Crime_Rate_Robbery_Rate    False
# 332                                Crime_Rate_MVT_Rate    False
# 333                       Attrtion_Reason_OtherReasons    False
# 334               Alternative minimum tax Ct 75KLT100K    False
# 335              Alternative minimum tax Amt 75KLT100K    False
# 336                 Add child tax credit Amt 75KLT100K    False
# 337                  Add child tax credit Amt 25KLT50K    False
# 338                    Add Medicare tax Amt 100KLT200K    False
# 339                (VITA) prepared returns Ct 50KLT75K    False
# 340                (VITA) prepared returns Ct 25KLT50K    False
# 341              (VITA) prepared returns Ct 100KLT200K    False
# 342                (TCE) prepared returns Ct 75KLT100K    False
# 343                 (TCE) prepared returns Ct 25KLT50K    False
# 344                                            wap_num    False
# 345                             lea_state_perpupil_num     True
# 346                           lea_short_susp_per_c_num     True
# 347                              lea_sat_avg_score_num     True
# 348                                         lea_salary    False
# 349                             lea_local_perpupil_num    False
# 350                                lea_avg_student_num    False
# 351                                      Science Score     True
# 352                                 Reading  SPG Score     True
# 353                       Number of farm returns LT25K     True
# 354                   Number of farm returns 75KLT100K     True
# 355                    Number of farm returns 50KLT75K     True
# 356                    Number of farm returns 25KLT50K     True
# 357                  Number of farm returns 100KLT200K     True
# 358                                        Math I_Size    False
# 359                  Earned income credit Amt 50KLT75K    False
# 360                               EOGSubjects_CACR_SWD     True
# 361                          EOGSubjects_CACR_Hispanic     True
# 362                             EOGSubjects_CACR_Black     True
# 363                             EOGSubjects_CACR_Asian     True
# 364                               EOGSubjects_CACR_AIG     True
# 365                             EOGScienceGr5_CACR_SWD     True
# 366                         EOGScienceGr5&8_CACR_White     True
# 367                           EOGScienceGr5&8_CACR_SWD     True
# 368                           EOGScienceGr5&8_CACR_EDS     True
# 369                EOGScienceGr5&8_CACR_AmericanIndian    False
# 370                           EOGScienceGr5&8_CACR_AIG     True
# 371                        EOGReadingGr5_CACR_Hispanic     True
# 372                             EOGReadingGr5_CACR_EDS     True
# 373                        EOGReadingGr4_CACR_Hispanic     True
# 374                             EOGReadingGr4_CACR_EDS     True
# 375                              EOGReadingGr3_GLP_SWD     True
# 376                                    crime_per_c_num    False
# 377                                  books_per_student    False
# 378           Tuition and fees deduction Amt 75KLT100K    False
# 379     State and local general sales taxes Amt GE200K    False
# 380      Self-employment retirement plans Amt 25KLT50K    False
# 381  Number of volunteer prepared returns Tot 50KLT75K    False
# 382                      Number of farm returns GE200K    False
# 383           Net investment income tax Amt 100KLT200K    False
# 384                                       Math I Score    False
# 385                                            LEACode    False
# 386                                EOGSubjects_GLP_LEP    False
# 387                    EOGSubjects_CACR_AmericanIndian    False
# 388                              EOGScienceGr5_GLP_LEP    False
# 389                  EOGScienceGr5_CACR_TwoorMoreRaces    False
# 390                             EOGScienceGr5_CACR_LEP    False
# 391                        EOGScienceGr5_CACR_Hispanic    False
# 392                           EOGScienceGr5_CACR_Black    False
# 393                            EOGScienceGr5&8_GLP_LEP    False
# 394                EOGScienceGr5&8_CACR_TwoorMoreRaces    False
# 395                           EOGScienceGr5&8_CACR_LEP    False
# 396                      EOGScienceGr5&8_CACR_Hispanic    False
# 397                         EOGScienceGr5&8_CACR_Black    False
# 398                         EOGScienceGr5&8_CACR_Asian    False
# 399                              EOGReadingGr5_GLP_LEP    False
# 400                         EOGReadingGr5_GLP_Hispanic    False
# 401                  EOGReadingGr5_CACR_TwoorMoreRaces    False
# 402                           EOGReadingGr5_CACR_Black    False
# 403                              EOGReadingGr4_GLP_LEP    False
# 404                  EOGReadingGr4_CACR_TwoorMoreRaces    False
# 405                             EOGReadingGr4_CACR_LEP    False
# 406                           EOGReadingGr4_CACR_Black    False
# 407                              EOGReadingGr3_GLP_LEP    False
# 408                  EOGReadingGr3_CACR_TwoorMoreRaces    False
#
#      Linear Regression    RFE  Lasso  Ridge  Elastic Net  Total
# 1                 True   True   True   True         True      6
# 2                 True   True   True   True         True      6
# 3                 True   True   True   True         True      6
# 4                 True   True   True   True         True      6
# 5                 True   True   True   True         True      6
# 6                 True   True   True   True         True      6
# 7                 True   True   True   True         True      6
# 8                 True   True   True   True         True      6
# 9                 True   True   True   True         True      6
# 10                True   True   True   True         True      6
# 11                True   True   True   True         True      6
# 12                True   True   True   True         True      6
# 13                True   True   True   True         True      6
# 14                True   True   True   True         True      6
# 15                True   True   True   True         True      6
# 16                True   True   True   True         True      6
# 17                True   True   True   True         True      6
# 18                True   True   True   True         True      6
# 19                True   True   True   True         True      6
# 20                True   True   True   True         True      6
# 21                True   True   True   True         True      6
# 22                True   True   True   True         True      6
# 23                True   True   True   True         True      6
# 24                True   True   True   True         True      6
# 25                True   True   True   True         True      6
# 26                True   True   True   True         True      6
# 27                True   True   True   True         True      6
# 28                True   True   True   True         True      6
# 29                True   True   True   True         True      6
# 30                True   True   True   True         True      5
# 31                True  False   True   True         True      5
# 32                True   True   True   True         True      5
# 33                True   True   True   True         True      5
# 34                True   True   True   True         True      5
# 35                True   True   True   True         True      5
# 36               False   True   True   True         True      5
# 37                True   True   True   True         True      5
# 38                True   True   True   True         True      5
# 39                True   True   True   True         True      5
# 40                True   True   True   True         True      5
# 41                True  False   True   True         True      5
# 42                True   True   True   True         True      5
# 43                True   True   True   True         True      5
# 44                True   True   True   True         True      5
# 45                True   True   True   True         True      5
# 46                True   True   True   True         True      5
# 47                True   True   True   True         True      5
# 48                True   True   True   True         True      5
# 49                True   True   True   True         True      5
# 50                True   True   True   True         True      5
# 51                True   True   True   True         True      5
# 52                True   True  False   True        False      4
# 53                True   True  False   True        False      4
# 54                True   True  False   True        False      4
# 55                True   True  False   True        False      4
# 56                True   True  False   True        False      4
# 57                True   True  False   True        False      4
# 58                True   True  False   True        False      4
# 59                True   True  False   True        False      4
# 60                True   True  False   True        False      4
# 61                True   True  False   True        False      4
# 62                True   True  False   True        False      4
# 63                True   True  False   True        False      4
# 64                True   True  False   True        False      4
# 65                True   True  False   True        False      4
# 66                True   True  False   True        False      4
# 67                True   True  False   True        False      4
# 68                True   True  False   True        False      4
# 69                True   True  False   True        False      4
# 70                True   True  False   True        False      4
# 71                True   True  False   True        False      4
# 72                True   True  False   True        False      4
# 73                True   True  False   True        False      4
# 74                True   True  False   True        False      4
# 75                True   True  False   True        False      4
# 76                True   True  False   True        False      4
# 77                True   True  False   True        False      4
# 78                True   True  False   True        False      4
# 79                True   True  False   True        False      4
# 80                True   True  False   True        False      4
# 81                True   True  False   True        False      4
# 82                True   True  False   True        False      4
# 83                True   True  False   True        False      4
# 84                True   True  False   True        False      4
# 85                True   True  False   True        False      4
# 86                True   True  False   True        False      4
# 87                True   True  False   True        False      4
# 88                True   True  False   True        False      4
# 89                True   True  False   True        False      4
# 90                True   True  False   True        False      4
# 91                True   True  False   True        False      4
# 92                True   True  False   True        False      4
# 93                True   True  False   True        False      4
# 94                True   True  False   True        False      4
# 95                True   True  False   True        False      4
# 96                True   True  False   True        False      4
# 97                True   True  False   True        False      4
# 98                True   True  False   True        False      4
# 99                True   True  False   True        False      4
# 100               True   True  False   True        False      4
# 101               True   True  False   True        False      4
# 102              False   True   True  False         True      4
# 103              False   True   True  False         True      4
# 104              False   True   True  False         True      4
# 105              False   True   True  False         True      4
# 106               True  False   True   True         True      4
# 107              False   True   True  False         True      4
# 108               True   True   True  False         True      4
# 109               True   True   True  False         True      4
# 110              False   True   True  False         True      4
# 111              False   True   True  False         True      4
# 112               True   True  False   True        False      3
# 113              False  False   True  False         True      3
# 114              False   True  False   True        False      3
# 115               True   True  False   True        False      3
# 116               True   True  False   True        False      3
# 117               True   True  False   True        False      3
# 118               True   True  False   True        False      3
# 119               True   True  False   True        False      3
# 120               True   True  False   True        False      3
# 121               True   True  False   True        False      3
# 122              False  False   True  False         True      3
# 123               True   True  False   True        False      3
# 124               True   True  False   True        False      3
# 125               True   True  False   True        False      3
# 126               True   True  False   True        False      3
# 127              False  False   True  False         True      3
# 128               True   True  False   True        False      3
# 129               True   True  False   True        False      3
# 130               True   True  False   True        False      3
# 131               True   True  False   True        False      3
# 132               True   True  False   True        False      3
# 133               True   True  False   True        False      3
# 134               True   True  False   True        False      3
# 135               True   True  False   True        False      3
# 136               True   True  False   True        False      3
# 137               True   True  False   True        False      3
# 138               True   True  False   True        False      3
# 139              False  False   True  False         True      3
# 140               True   True  False   True        False      3
# 141               True   True  False   True        False      3
# 142               True   True  False   True        False      3
# 143               True   True  False   True        False      3
# 144               True   True  False   True        False      3
# 145               True   True  False   True        False      3
# 146               True   True  False   True        False      3
# 147               True   True  False   True        False      3
# 148               True   True  False   True        False      3
# 149               True   True  False   True        False      3
# 150               True   True  False   True        False      3
# 151               True   True  False   True        False      3
# 152               True   True  False   True        False      3
# 153               True   True  False   True        False      3
# 154               True   True  False   True        False      3
# 155               True   True  False   True        False      3
# 156               True   True  False   True        False      3
# 157               True   True  False   True        False      3
# 158               True   True  False   True        False      3
# 159               True   True  False   True        False      3
# 160               True   True  False   True        False      3
# 161               True   True  False   True        False      3
# 162               True   True  False   True        False      3
# 163               True   True  False   True        False      3
# 164               True   True  False   True        False      3
# 165               True   True  False   True        False      3
# 166               True   True  False   True        False      3
# 167               True   True  False   True        False      3
# 168               True   True  False   True        False      3
# 169               True   True  False   True        False      3
# 170               True   True  False   True        False      3
# 171               True   True  False   True        False      3
# 172               True   True  False   True        False      3
# 173               True   True  False   True        False      3
# 174               True   True  False   True        False      3
# 175               True  False  False   True        False      3
# 176              False  False   True  False         True      3
# 177               True   True  False   True        False      3
# 178               True   True  False   True        False      3
# 179               True   True  False   True        False      3
# 180              False  False   True  False         True      3
# 181               True   True  False   True        False      3
# 182               True   True  False   True        False      3
# 183               True   True  False   True        False      3
# 184               True   True  False   True        False      3
# 185               True   True  False   True        False      3
# 186               True   True  False   True        False      3
# 187               True  False  False   True        False      3
# 188               True   True  False   True        False      3
# 189               True   True  False   True        False      3
# 190               True   True  False   True        False      3
# 191               True   True  False   True        False      3
# 192               True   True  False   True        False      3
# 193               True   True  False   True        False      3
# 194               True   True  False  False        False      3
# 195               True   True  False   True        False      3
# 196               True   True  False   True        False      3
# 197               True   True  False   True        False      3
# 198               True   True  False   True        False      3
# 199              False  False   True  False         True      3
# 200              False  False   True  False         True      3
# 201              False  False   True  False         True      3
# 202              False  False   True  False         True      3
# 203              False  False   True  False         True      3
# 204              False  False   True  False         True      3
# 205              False  False   True  False         True      3
# 206              False  False   True  False         True      3
# 207              False  False   True  False         True      3
# 208              False  False   True  False         True      3
# 209              False  False   True  False         True      3
# 210              False  False   True  False         True      3
# 211              False  False   True  False         True      3
# 212              False  False   True  False         True      3
# 213              False  False   True  False         True      3
# 214              False  False   True  False         True      3
# 215              False  False   True  False         True      3
# 216              False  False   True  False         True      3
# 217              False  False   True  False         True      3
# 218              False  False   True  False         True      3
# 219              False  False   True  False         True      3
# 220              False  False   True  False         True      3
# 221              False  False   True  False         True      3
# 222              False  False   True  False         True      3
# 223              False  False   True  False         True      3
# 224              False  False   True  False         True      3
# 225              False  False   True  False         True      3
# 226              False  False   True  False         True      3
# 227              False  False   True  False         True      3
# 228              False  False   True  False         True      3
# 229              False  False   True  False         True      3
# 230              False  False   True  False         True      3
# 231              False   True   True  False         True      3
# 232              False  False   True  False         True      3
# 233              False  False   True  False         True      3
# 234              False  False   True  False         True      3
# 235              False  False   True  False         True      3
# 236              False  False   True  False         True      3
# 237              False  False   True  False         True      3
# 238              False  False   True  False         True      3
# 239              False  False   True  False         True      3
# 240              False  False   True  False         True      3
# 241              False  False   True  False         True      3
# 242              False  False   True  False         True      3
# 243              False  False   True  False         True      3
# 244              False  False   True  False         True      3
# 245              False  False   True  False         True      3
# 246              False  False   True  False         True      3
# 247              False  False   True  False         True      3
# 248              False  False   True  False         True      3
# 249              False  False   True  False         True      3
# 250              False  False   True  False         True      3
# 251              False  False   True  False         True      3
# 252              False  False   True  False         True      3
# 253              False  False   True  False         True      3
# 254              False  False   True  False         True      3
# 255              False  False   True  False         True      3
# 256              False  False   True  False         True      3
# 257              False  False   True  False         True      3
# 258              False  False   True  False         True      3
# 259              False  False   True  False         True      3
# 260              False  False   True  False         True      3
# 261              False   True   True  False         True      3
# 262              False   True   True  False         True      3
# 263              False  False   True  False         True      3
# 264              False   True   True  False         True      3
# 265              False  False   True  False         True      3
# 266              False  False   True  False         True      3
# 267              False  False   True  False         True      3
# 268              False   True   True  False         True      3
# 269              False  False   True  False         True      2
# 270               True  False  False   True        False      2
# 271              False  False  False  False         True      2
# 272              False  False   True  False         True      2
# 273              False  False   True  False         True      2
# 274               True  False  False   True        False      2
# 275              False  False   True  False         True      2
# 276              False   True  False  False        False      2
# 277               True  False  False   True        False      2
# 278               True  False  False   True        False      2
# 279              False  False  False   True        False      2
# 280              False   True  False  False        False      2
# 281              False   True  False  False        False      2
# 282              False   True  False  False        False      2
# 283              False   True  False  False        False      2
# 284               True  False  False   True        False      2
# 285              False  False   True  False        False      2
# 286              False  False   True  False        False      2
# 287              False  False   True  False        False      2
# 288              False  False   True  False        False      2
# 289              False  False   True  False         True      2
# 290              False  False   True  False         True      2
# 291              False  False   True  False         True      2
# 292              False  False   True  False         True      2
# 293              False  False   True  False         True      2
# 294              False  False   True  False         True      2
# 295              False  False   True  False         True      2
# 296              False  False   True  False         True      2
# 297              False  False   True  False         True      2
# 298              False  False   True  False         True      2
# 299              False  False   True  False         True      2
# 300              False  False   True  False         True      2
# 301              False  False   True  False         True      2
# 302              False  False   True  False         True      2
# 303              False  False   True  False         True      2
# 304              False  False   True  False         True      2
# 305              False  False   True  False         True      2
# 306              False  False   True  False         True      2
# 307              False  False   True  False         True      2
# 308              False  False   True  False         True      2
# 309              False  False   True  False         True      2
# 310              False  False   True  False         True      2
# 311              False  False   True  False         True      2
# 312              False  False   True  False         True      2
# 313              False  False   True  False         True      2
# 314              False  False   True  False         True      2
# 315              False  False   True  False         True      2
# 316              False  False   True  False         True      2
# 317              False  False   True  False         True      2
# 318              False  False   True  False         True      2
# 319              False  False   True  False         True      2
# 320              False  False   True  False         True      2
# 321              False  False   True  False         True      2
# 322              False  False   True  False         True      2
# 323              False  False   True  False         True      2
# 324              False  False   True  False         True      2
# 325              False  False   True  False         True      2
# 326              False  False   True  False         True      2
# 327              False  False   True  False         True      2
# 328              False  False   True  False         True      2
# 329              False  False   True  False         True      2
# 330              False  False   True  False         True      2
# 331              False  False   True  False         True      2
# 332              False  False   True  False         True      2
# 333              False  False   True  False         True      2
# 334              False  False   True  False         True      2
# 335              False  False   True  False         True      2
# 336              False  False   True  False         True      2
# 337              False  False   True  False         True      2
# 338              False  False   True  False         True      2
# 339              False  False   True  False         True      2
# 340              False  False   True  False         True      2
# 341              False  False   True  False         True      2
# 342              False  False   True  False         True      2
# 343              False  False   True  False         True      2
# 344              False   True  False  False        False      1
# 345              False  False  False  False        False      1
# 346              False  False  False  False        False      1
# 347              False  False  False  False        False      1
# 348              False  False  False  False         True      1
# 349              False  False  False  False         True      1
# 350              False  False  False  False         True      1
# 351              False  False  False  False        False      1
# 352              False  False  False  False        False      1
# 353              False  False  False  False        False      1
# 354              False  False  False  False        False      1
# 355              False  False  False  False        False      1
# 356              False  False  False  False        False      1
# 357              False  False  False  False        False      1
# 358              False   True  False  False        False      1
# 359               True  False  False  False        False      1
# 360              False  False  False  False        False      1
# 361              False  False  False  False        False      1
# 362              False  False  False  False        False      1
# 363              False  False  False  False        False      1
# 364              False  False  False  False        False      1
# 365              False  False  False  False        False      1
# 366              False  False  False  False        False      1
# 367              False  False  False  False        False      1
# 368              False  False  False  False        False      1
# 369              False   True  False  False        False      1
# 370              False  False  False  False        False      1
# 371              False  False  False  False        False      1
# 372              False  False  False  False        False      1
# 373              False  False  False  False        False      1
# 374              False  False  False  False        False      1
# 375              False  False  False  False        False      1
# 376              False  False  False  False        False      0
# 377              False  False  False  False        False      0
# 378              False  False  False  False        False      0
# 379              False  False  False  False        False      0
# 380              False  False  False  False        False      0
# 381              False  False  False  False        False      0
# 382              False  False  False  False        False      0
# 383              False  False  False  False        False      0
# 384              False  False  False  False        False      0
# 385              False  False  False  False        False      0
# 386              False  False  False  False        False      0
# 387              False  False  False  False        False      0
# 388              False  False  False  False        False      0
# 389              False  False  False  False        False      0
# 390              False  False  False  False        False      0
# 391              False  False  False  False        False      0
# 392              False  False  False  False        False      0
# 393              False  False  False  False        False      0
# 394              False  False  False  False        False      0
# 395              False  False  False  False        False      0
# 396              False  False  False  False        False      0
# 397              False  False  False  False        False      0
# 398              False  False  False  False        False      0
# 399              False  False  False  False        False      0
# 400              False  False  False  False        False      0
# 401              False  False  False  False        False      0
# 402              False  False  False  False        False      0
# 403              False  False  False  False        False      0
# 404              False  False  False  False        False      0
# 405              False  False  False  False        False      0
# 406              False  False  False  False        False      0
# 407              False  False  False  False        False      0
# 408              False  False  False  False        False      0

# %%
# export feature selection to csv file
feature_selection_df.to_csv('Feature_Selection_Results.csv', sep=',', index=False)

# %%
feature_to_remove = feature_selection_df[feature_selection_df['Total']<3]['Feature']

#feature_to_remove

# %%
X = X.drop(feature_to_remove, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns not Selected by Feature Selection******')
X.info(verbose=False)
print ('\r\nColumns Deleted: ', len(feature_to_remove))
# Out:
# *********After: Removing columns not Selected by Feature Selection******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9253 entries, 1 to 9755
# Columns: 268 entries, (TCE) prepared returns Ct 100KLT200K to wap_per_classroom
# dtypes: float64(251), int64(17)
# memory usage: 19.0 MB
#
# Columns Deleted:  140

# %% [markdown]
# ## Transformation

# %%
# Transform

saved_cols = X.columns

scaler = StandardScaler()
X = scaler.fit_transform(X)
#Save as data frames
X = pd.DataFrame(X)
X.columns = saved_cols

# %%
# %%time

# df2_vif = pd.DataFrame()
# df2_vif["VIF Factor"] = [vif(X.values, i) for i in range(X.shape[1])]
# df2_vif["ABSVIFFactor"] = abs(df2_vif["VIF Factor"])
# df2_vif["features"] = X.columns
# df2_vif["indexes"] = range(0, len(X.columns))

# %%
# df2_vif = df2_vif.sort_values('ABSVIFFactor', ascending=True)
# df2_vif.to_csv('VIF_Result_ML.csv', sep=',', index=False)

# %%
# Create Cross Validation Object with 10 folds with 80/20 train - test split
# cv = ShuffleSplit(n_splits = 10, test_size=0.20, random_state=0)

# %%
# %%time



# X_train, X_test, y_train, y_test = train_test_split(X, y, 
#     test_size=0.3,random_state =1 )

# #print("RFE CV Linear Regression 1st Pass")
# rfecvEstimator = LinearRegression()

# parameters = { 'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}

# #Create a grid search object  

# grid = GridSearchCV(estimator=rfecvEstimator
#                    #, n_jobs=8 # jobs to run in parallel
#                    #, verbose=0 # low verbosity
#                    , param_grid=parameters
#                   )

# #Perform hyperparameter search to find the best combination of parameters for our data using RFECV
# grid.fit(X_train, y_train)
# print("r2 / variance : ", grid.best_score_)
# print("Residual sum of squares: %.2f"
#               % np.mean((grid.predict(X_test) - y_test) ** 2))

# %%
# %%time


# #print("RFE CV Linear Regression 1st Pass")
# rfecvEstimator = LinearRegression()

# parameters = { 'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]
#              }

# #Create a grid search object  
# from sklearn.model_selection import GridSearchCV
# rfecvGridSearch = GridSearchCV(estimator=rfecvEstimator
# #                    , n_jobs=8 # jobs to run in parallel
# #                    , verbose=0 # low verbosity
#                    , param_grid=parameters
#                    , cv=cv # KFolds = 10
#                    )

# #Perform hyperparameter search to find the best combination of parameters for our data using RFECV
# rfecvGridSearch.fit(X, y)

# #Use the best parameters for our RFECV Linear Regression object
# rfecvClassifierEst = rfecvGridSearch.best_estimator_

# #Recursive Feature Elimination
# rfecv = RFECV(estimator=rfecvClassifierEst, step=1, cv=cv,  verbose=1)
# X_BestFeatures = rfecv.fit_transform(X, y)

# #Print RFECV Details
# print("Ranking", rfecv.ranking_)
# print("Support", rfecv.support_)
# print("Number of Features:", rfecv.n_features_)

# #print("Linear Regression Second Pass")
# # #create a pipeline to scale all of the data and perform logistic regression during each grid search step.
# # pipe = make_pipeline(StandardScaler(), LinearRegression())

# # #Define a range of hyper parameters for grid search
# # parameters = { 'linearregression__fit_intercept':[True,False], 'LinearRegression__normalize':[True,False]
# #               , 'LinearRegression__copy_X':[True, False]
# #               , 'linearregression__n_jobs':[None]
# #              }

# # #Perform the grid search using accuracy as a metric during cross validation.
# # grid = GridSearchCV(estimator=pipe, param_grid=parameters, cv=cv)

# # #Use the best features from recursive feature elimination during the grid search
# # grid.fit(X, y)

# %% [markdown]
# ## Cross Validation
# **Cross validation is performed using repeated holdout using ShuffleSplit()**
# * Ten folds are used
# * The split is: 90% training data and 10% test data
# * A random seed is set so the same random test and training splits are used each time cross validation is performed.

# %%
#Divide data into test and training splits
from sklearn.model_selection import ShuffleSplit
cv = ShuffleSplit(n_splits=10, test_size=0.10, random_state=0)

# %% [markdown]
# ## Custom Scorers for Evaluating Regression Models
#
# **All regression models created in this notebook are validated using the following metrics:**
# * Mean Absolute Error (MAE)
# * Root Mean Squared Error (RMSE) - https://stackoverflow.com/questions/17197492/root-mean-square-error-in-python
# * Mean Absolute Percentage Error (MAPE) - https://stackoverflow.com/questions/42250958/how-to-optimize-mape-code-in-python
#
# **For details on making scorers to return multiple mean error scores see:**
# * http://scikit-learn.org/stable/auto_examples/model_selection/plot_multi_metric_evaluation.html
# * https://github.com/scikit-learn/scikit-learn/pull/7388
# * https://github.com/drorata/multiscorer

# %%
# it may not make sense to use MAPE in our project based on below articles:
# http://www.catchbull.com/catchblogs/why-mape-doesnt-work

# %%
#Use mean absolute error (MAE) to score the regression models created 
#(the scale of MAE is identical to the response variable)
from sklearn.metrics import mean_absolute_error, make_scorer, mean_squared_error, r2_score 
#from sklearn.metrics import mean_absolute_error, make_scorer, mean_squared_error, r2_scorer 

#Function for Root mean squared error
#https://stackoverflow.com/questions/17197492/root-mean-square-error-in-python
def rmse(y_actual, y_predicted):
    return np.sqrt(mean_squared_error(y_actual, y_predicted))

#Function for Mean Absolute Percentage Error (MAPE) - Untested
#Adapted from - https://stackoverflow.com/questions/42250958/how-to-optimize-mape-code-in-python
# revised from - https://stats.stackexchange.com/questions/58391/mean-absolute-percentage-error-mape-in-scikit-learn
# still not working
def mape(y_actual, y_predicted): 
    mask = y_actual != 0           
    return (np.fabs(y_actual - y_predicted)/y_actual)[mask].mean() * 100
# Credit: https://alex.miller.im/posts/linear-model-custom-loss-function-regularization-python/
def mean_absolute_percentage_error(y_true, y_pred, sample_weights=None):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    assert len(y_true) == len(y_pred)
    
    if np.any(y_true==0):
        print("Found zeroes in y_true. MAPE undefined. Removing from set...")
        idx = np.where(y_true==0)
        y_true = np.delete(y_true, idx)
        y_pred = np.delete(y_pred, idx)
        if type(sample_weights) != type(None):
            sample_weights = np.array(sample_weights)
            sample_weights = np.delete(sample_weights, idx)
        
    if type(sample_weights) == type(None):
        return(np.mean(np.abs((y_true - y_pred) / y_true)))
    else:
        sample_weights = np.array(sample_weights)
        assert len(sample_weights) == len(y_true)
        return(100/sum(sample_weights)*np.dot(
                sample_weights, (np.abs((y_true - y_pred) / y_true))
        ))
    
#Create scorers for rmse and mape functions
mae_scorer = make_scorer(score_func=mean_absolute_error, greater_is_better=False)
mse_scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
rmse_scorer = make_scorer(score_func=rmse, greater_is_better=False)
#mape_scorer = make_scorer(score_func=mape, greater_is_better=False)
r2_scorer = make_scorer(score_func=r2_score, greater_is_better=True) 

#Make scorer array to pass into cross_validate() function for producing mutiple scores for each cv fold.
errorScoring = {'MAE':  mae_scorer, 
                'MSE':  mse_scorer, 
                'RMSE': rmse_scorer,
                #'MAPE': mape_scorer,
                'R2': r2_scorer       
               }

# %% [markdown]
# ## Regression Model Evaluation
# ** All regression models are evaluated using the regression model evaluation function below: **
# * The following regression evaluation function uses the cross validation object and the custom scorers in the two cells above in combination with sklearn.model_selection's cross_validate function to perform cross validation for regression estimators.
# * The cross validation object above uses a random seed to ensure that all regression estimators are tested on the same randomly selected records for each cross validation fold.
# * Custom scorers are created using the three chosen mean error scores and passed into cross_validate(), so all three scores are calcualted using a single call to cross_validate().
# * All of this functionality is wrapped within the custom EvaluateRegressionEstimator() function below so multiple regression models may be tested using the same test / train cv data and evaluation scores producing a consistent output for each model without the need to re-write the same code over and over.

# %%
from sklearn.model_selection import cross_validate

def EvaluateRegressionEstimator(regEstimator, X, y, cv):
    
    scores = cross_validate(regEstimator, X, y, scoring=errorScoring, cv=cv, return_train_score=True)

    #cross val score sign-flips the outputs of MAE
    # https://github.com/scikit-learn/scikit-learn/issues/2439
    scores['test_MAE'] = scores['test_MAE'] * -1
    scores['test_MSE'] = scores['test_MSE'] * -1
    #scores['test_MAPE'] = scores['test_MAPE'] * -1
    scores['test_RMSE'] = scores['test_RMSE'] * -1

    #print mean MAE for all folds 
    maeAvg = scores['test_MAE'].mean()
    print_str = "The average MAE for all cv folds is: \t\t\t {maeAvg:.5}"
    print(print_str.format(maeAvg=maeAvg))

     #print mean MAE for all folds 
    mseAvg = scores['test_MSE'].mean()
    print_str = "The average MSE for all cv folds is: \t\t\t {mseAvg:.5}"
    print(print_str.format(mseAvg=mseAvg))
    
    #print mean test_MAPE for all folds
#     scores['test_MAPE'] = scores['test_MAPE']
#     mape_avg = scores['test_MAPE'].mean()
#     print_str = "The average MAE percentage (MAPE) for all cv folds is: \t {mape_avg:.5}"
#     print(print_str.format(mape_avg=mape_avg))

    #print mean MAE for all folds 
    RMSEavg = scores['test_RMSE'].mean()
    print_str = "The average RMSE for all cv folds is: \t\t\t {RMSEavg:.5}"
    print(print_str.format(RMSEavg=RMSEavg))
    print('*********************************************************')
    
    #print mean R-squared for all folds 
    R2avg = scores['test_R2'].mean()
    print_str = "The average R-Squared for all cv folds is: \t\t {R2avg:.5}"
    print(print_str.format(R2avg=R2avg))
    print('*********************************************************')


    print('Cross Validation Fold Mean Error Scores')
    scoresResults = pd.DataFrame()
    scoresResults['MAE'] = scores['test_MAE']
    scoresResults['MSE'] = scores['test_MSE']
   # scoresResults['MAPE'] = scores['test_MAPE']
    scoresResults['RMSE'] = scores['test_RMSE']
    scoresResults['R2'] = scores['test_R2']
    return scoresResults

# %% [markdown]
# ## Baseline Regression Model
#
# **Linear Regression is used to create a baseline model.  Since linear regression may predict response variable values outside the range of the training data's response variable, we create a linear regression estimator with graduation rate predictions clipped 0% and 100%. For details see:**
# * http://scikit-learn.org/stable/developers/contributing.html#rolling-your-own-estimator
# * https://github.com/scikit-learn/scikit-learn/issues/6950
# * http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
# * https://github.com/scikit-learn-contrib/project-template/blob/master/skltemplate/template.py
# * https://stackoverflow.com/questions/44234682/how-to-use-sklearn-when-target-variable-is-a-proportion

# %%
#Make new estimator compatible for use with GridSearchCV() and cross_validate()
# -  Cap predict function for LinearRegression between 0 and 100
# -  See: Roll your own estimator links above for details. 
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.linear_model import LinearRegression

class CappedLinearRegression(LinearRegression):

    def predict(self, X):
        return np.clip(super(CappedLinearRegression, self).predict(X), 0, 100)

# %% [markdown]
# ### Linear Regression Grid Search
# ** Here we perform a grid search testing 40 models to find the best parameters for our Linear Regression model based on Mean Absolute Error.  See more on parameter tuning with grid search here:**
# * http://scikit-learn.org/stable/modules/grid_search.html

# %%
#Create a Linear Regression object and perform a grid search to find the best parameters
linreg = CappedLinearRegression()
parameters = {'normalize':(True,False), 'fit_intercept':(True,False),'normalize': (True, False),}

#Create a grid search object using the  
regGridSearch = GridSearchCV(estimator=linreg
                   , verbose=1 # low verbosity
                   , param_grid=parameters
                   , cv=cv # KFolds = 10
                   , scoring=mae_scorer)

#Perform hyperparameter search to find the best combination of parameters for our data
regGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.8s finished
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=0, test_size=0.1, train_size=None),
#              error_score='raise-deprecating',
#              estimator=CappedLinearRegression(copy_X=True, fit_intercept=True,
#                                               n_jobs=None, normalize=False),
#              iid='warn', n_jobs=None,
#              param_grid={'fit_intercept': (True, False),
#                          'normalize': (True, False)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(mean_absolute_error, greater_is_better=False),
#              verbose=1)

# %%
#Print the parameterization of the best estimator
regGridSearch.best_estimator_
# Out:
# CappedLinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                        normalize=True)

# %% [markdown]
# ## Baseline Regression Model - Cross Validation
# **Perform tenfold cross validation using the grid search "best" parameters and our Capped Linear Regression estimator**
# * 10-fold cross-validation using the parameters for the top performing model
# * CAP predictions between 0 and 100%
# * Evaluate cross-validation results using MAE, MAPE, and RMSE

# %%
#Create CappedLinearRegression predictions between 0 and 100% using the best parameters for our Linear Regression object
regEstimator = regGridSearch.best_estimator_

#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics. 
baseLine_Results = EvaluateRegressionEstimator(regEstimator, X, y, cv)
# Out:
# The average MAE for all cv folds is: 			 0.051182
# The average MSE for all cv folds is: 			 0.004608
# The average RMSE for all cv folds is: 			 0.067843
# *********************************************************
# The average R-Squared for all cv folds is: 		 0.32475
# *********************************************************
# Cross Validation Fold Mean Error Scores

# %%
baseLine_Results
# Out:
#         MAE       MSE      RMSE        R2
# 0  0.048308  0.003956  0.062894  0.362522
# 1  0.051672  0.004821  0.069434  0.277755
# 2  0.051367  0.004686  0.068457  0.326571
# 3  0.050653  0.004443  0.066653  0.332163
# 4  0.051996  0.004754  0.068950  0.397550
# 5  0.049650  0.004431  0.066568  0.347038
# 6  0.052880  0.005142  0.071710  0.321294
# 7  0.050366  0.004366  0.066073  0.286042
# 8  0.051899  0.004628  0.068030  0.352893
# 9  0.053032  0.004853  0.069666  0.243649

# %% [markdown]
# ## Support Vector Regression
# **This model uses Support Vector Machines for regression of continuous variables (SVR). Please see documentation here:"**
# * http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html
# * http://scikit-learn.org/stable/modules/svm.html

# %%
# #Create a Linear regression object and perform a grid search to find the best parameters
# from sklearn.svm import SVR
# reg = SVR()

# #Set up SVR parameters to test (WARNING: Creates 320 models!!!) 
# costs = [0.001, 0.1]
# defGamma = 1 / X.shape[1]  #This is the default value for the gamma parameter
# gammas = [defGamma, 0.1]
# kernels = ['rbf','linear']
# parameters = {'C': costs, 'gamma' : gammas, 'kernel': kernels}

# #Create a grid search object using the parameters above
# from sklearn.model_selection import GridSearchCV
# regGridSearch = GridSearchCV(estimator=reg
#                    , n_jobs=8 # jobs to run in parallel
#                    , verbose=1 # low verbosity
#                    , param_grid=parameters
#                    , cv=cv # KFolds = 10
#                    , scoring=mae_scorer)

# #Perform hyperparameter search to find the best combination of parameters for our data
# regGridSearch.fit(X, y)

# %%
#Display the best estimator parameters
regGridSearch.best_estimator_
# Out:
# CappedLinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                        normalize=True)

# %%
# from sklearn.svm import SVR

# #Create a regression estimator with best parameters for cross validation
# regEstimator = SVR(C=0.001, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# #Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics.
# EvaluateRegressionEstimator(regEstimator, X_highSchools, Y, cv)

# %%
#Do we predict graduation rates greater than 100%?
# regEstimator = SVR(C=0.001, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# regEstimator.fit(X_highSchools, Y)
# yhat = regEstimator.predict(X_highSchools)
# print("Yhat Max: ", yhat.max())

# %% [markdown]
# ## Graduation Rate - Lasso Regression
# **This model uses Lasso regression (L1 Norm). Please see documentation here:"**
# * **Caution!** - See documentation for fit_intercept, normalize, and copy_X. Lasso can over-write your X data!
# * Lasso may also perform scaling as well.  Please see docs!
# * http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html

# %%
#Create a regression object and perform a grid search to find the best parameters
from sklearn.linear_model import Lasso

reg = Lasso(fit_intercept=True, normalize=True,copy_X=True
          , max_iter=10000, precompute=True, tol=0.0001, random_state=0)

#Test parameters 
alpha = [0.001, 0.1, 1, 10, 20]
selection = ['cyclic','random']
warm_start = [True, False]
parameters = {'alpha': alpha, 'selection': selection, 'warm_start': warm_start}

#Create a grid search object using the parameters above
regGridSearch = GridSearchCV(estimator=reg
                   , n_jobs=8 # jobs to run in parallel
                   , verbose=1 # low verbosity
                   , param_grid=parameters
                   , cv=cv # KFolds = 10
                   , scoring=mae_scorer)

#Perform hyperparameter search to find the best combination of parameters for our data
regGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    6.2s finished
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=0, test_size=0.1, train_size=None),
#              error_score='raise-deprecating',
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=10000, normalize=True, positive=False,
#                              precompute=True, random_state=0,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='warn', n_jobs=8,
#              param_grid={'alpha': [0.001, 0.1, 1, 10, 20],
#                          'selection': ['cyclic', 'random'],
#                          'warm_start': [True, False]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(mean_absolute_error, greater_is_better=False),
#              verbose=1)

# %%
#Display the best estimator parameters
regGridSearch.best_estimator_
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=10000,
#       normalize=True, positive=False, precompute=True, random_state=0,
#       selection='cyclic', tol=0.0001, warm_start=True)

# %%
#Create a regression estimator with best parameters for cross validation
regEstimator = regGridSearch.best_estimator_

#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics.
Lasso_Results = EvaluateRegressionEstimator(regEstimator, X, y, cv)
# Out:
# The average MAE for all cv folds is: 			 0.062496
# The average MSE for all cv folds is: 			 0.0068469
# The average RMSE for all cv folds is: 			 0.082683
# *********************************************************
# The average R-Squared for all cv folds is: 		 -0.00059349
# *********************************************************
# Cross Validation Fold Mean Error Scores

# %%
#Do we predict graduation rates greater than 100%?
regEstimator = Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=10000,
   normalize=True, positive=False, precompute=True, random_state=0,
   selection='cyclic', tol=0.0001, warm_start=True)

regEstimator.fit(X, y)
yhat = regEstimator.predict(X)
print("Yhat Max: ", yhat.max())
# Out:
# Yhat Max:  0.14851810223711226

# %% [markdown]
# ## Ridge Regression
# **This model uses Ridge regression (L2 Norm). Please see documentation here:"**
# * http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html

# %%
#Create a regression object and perform a grid search to find the best parameters
from sklearn.linear_model import Ridge

reg = Ridge(fit_intercept=True, normalize=True,copy_X=True
          , max_iter=10000, tol=0.0001, random_state=0)

#Test parameters 
alpha = [0.001, 0.1, 1, 5, 10, 20]
solver = [ 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']
parameters = {'alpha': alpha, 'solver': solver}

#Create a grid search object using the parameters above
from sklearn.model_selection import GridSearchCV
regGridSearch = GridSearchCV(estimator=reg
                   , n_jobs=6 # jobs to run in parallel
                   , verbose=1 # low verbosity
                   , param_grid=parameters
                   , cv=cv # KFolds = 10
                   , scoring=mae_scorer)

#Perform hyperparameter search to find the best combination of parameters for our data
regGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:    5.3s
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\joblib\externals\loky\process_executor.py", line 418, in _process_worker
#     r = call_item()
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\joblib\externals\loky\process_executor.py", line 272, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\joblib\_parallel_backends.py", line 567, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\joblib\parallel.py", line 225, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\joblib\parallel.py", line 225, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\model_selection\_validation.py", line 514, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\ridge.py", line 747, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\ridge.py", line 580, in fit
#     return_intercept=False, check_input=False, **params)
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\ridge.py", line 492, in _ridge_regression
#     is_saga=solver == 'saga')
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\sag.py", line 306, in sag_solver
#     dataset, intercept_decay = make_dataset(X, y, sample_weight, random_state)
#   File "C:\Users\bin.yu\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\base.py", line 95, in make_dataset
#     dataset = ArrayData(X, y, sample_weight, seed=seed)
#   File "sklearn\utils\seq_dataset.pyx", line 200, in sklearn.utils.seq_dataset.ArrayDataset64.__cinit__
# ValueError: ndarray is not C-contiguous
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-a10af570d8fa> in <module>
#      20
#      21 #Perform hyperparameter search to find the best combination of parameters for our data
# ---> 22 regGridSearch.fit(X, y)
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     685                 return results
#     686
# --> 687             self._run_search(evaluate_candidates)
#     688
#     689         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1146     def _run_search(self, evaluate_candidates):
#    1147         """Search all candidates in param_grid"""
# -> 1148         evaluate_candidates(ParameterGrid(self.param_grid))
#    1149
#    1150
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     664                                for parameters, (train, test)
#     665                                in product(candidate_params,
# --> 666                                           cv.split(X, y, groups)))
#     667
#     668                 if len(out) < 1:
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\concurrent\futures\_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ValueError: ndarray is not C-contiguous

# %%
#Display the best estimator parameters
regGridSearch.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-6936b776f391> in <module>
#       1 #Display the best estimator parameters
# ----> 2 regGridSearch.best_estimator_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
# %%time
#Create a regression estimator with best parameters for cross validation
regEstimator = regGridSearch.best_estimator_

#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics.
Ridge_Results = EvaluateRegressionEstimator(regEstimator, X, y, cv)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
#Do we predict graduation rates greater than 100%?
regEstimator = Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
   normalize=True, random_state=0, solver='saga', tol=0.0001)

regEstimator.fit(X, y)
yhat = regEstimator.predict(X)
print("Yhat Max: ", yhat.max())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-b66c51f0c776> in <module>
#       3    normalize=True, random_state=0, solver='saga', tol=0.0001)
#       4
# ----> 5 regEstimator.fit(X, y)
#       6 yhat = regEstimator.predict(X)
#       7 print("Yhat Max: ", yhat.max())
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\ridge.py in fit(self, X, y, sample_weight)
#     745         self : returns an instance of self.
#     746         """
# --> 747         return super().fit(X, y, sample_weight=sample_weight)
#     748
#     749
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\ridge.py in fit(self, X, y, sample_weight)
#     578                 max_iter=self.max_iter, tol=self.tol, solver=self.solver,
#     579                 random_state=self.random_state, return_n_iter=True,
# --> 580                 return_intercept=False, check_input=False, **params)
#     581             self._set_intercept(X_offset, y_offset, X_scale)
#     582
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\ridge.py in _ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, random_state, return_n_iter, return_intercept, X_scale, X_offset, check_input)
#     490                 max_iter, tol, verbose, random_state, False, max_squared_sum,
#     491                 init,
# --> 492                 is_saga=solver == 'saga')
#     493             if return_intercept:
#     494                 coef[i] = coef_[:-1]
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\sag.py in sag_solver(X, y, sample_weight, loss, alpha, beta, max_iter, tol, verbose, random_state, check_input, max_squared_sum, warm_start_mem, is_saga)
#     304         num_seen_init = 0
#     305
# --> 306     dataset, intercept_decay = make_dataset(X, y, sample_weight, random_state)
#     307
#     308     if max_squared_sum is None:
#
# ~\AppData\Local\Continuum\anaconda3\envs\ML\lib\site-packages\sklearn\linear_model\base.py in make_dataset(X, y, sample_weight, random_state)
#      93         intercept_decay = SPARSE_INTERCEPT_DECAY
#      94     else:
# ---> 95         dataset = ArrayData(X, y, sample_weight, seed=seed)
#      96         intercept_decay = 1.0
#      97
#
# sklearn\utils\seq_dataset.pyx in sklearn.utils.seq_dataset.ArrayDataset64.__cinit__()
#
# ValueError: ndarray is not C-contiguous

# %% [markdown]
# ## Elastic Net Regression
# **This model uses Elastic Net Regression (L1 and L2 Norm mixing). Please see documentation here:"**
# * http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html

# %%
#Create a regression object and perform a grid search to find the best parameters
from sklearn.linear_model import ElasticNet

reg = ElasticNet(fit_intercept=True, normalize=True, precompute=True, copy_X=True
          , max_iter=10000, tol=0.0001, random_state=0)
 
#Test parameters
l1_ratio = [0.001, 0.01, 0.1, 0.5, 0.75, 1]
alpha = [0.001, 0.1, 1, 10]
selection = ['cyclic','random']
warm_start = [True, False]
parameters = {'l1_ratio': l1_ratio, 'alpha': alpha, 'selection': selection, 'warm_start': warm_start}

#Create a grid search object using the parameters above
from sklearn.model_selection import GridSearchCV
regGridSearch = GridSearchCV(estimator=reg
                   , n_jobs=8 # jobs to run in parallel
                   , verbose=1 # low verbosity
                   , param_grid=parameters
                   , cv=cv # KFolds = 10
                   , scoring=mae_scorer)

#Perform hyperparameter search to find the best combination of parameters for our data
regGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 96 candidates, totalling 960 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=8)]: Done 960 out of 960 | elapsed:   22.8s finished
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=0, test_size=0.1, train_size=None),
#              error_score='raise-deprecating',
#              estimator=ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True,
#                                   l1_ratio=0.5, max_iter=10000, normalize=True,
#                                   positive=False, precompute=True,
#                                   random_state=0, selection='cyclic',
#                                   tol=0.0001, warm_start=False),
#              iid='warn', n_jobs=8,
#              param_grid={'alpha': [0.001, 0.1, 1, 10],
#                          'l1_ratio': [0.001, 0.01, 0.1, 0.5, 0.75, 1],
#                          'selection': ['cyclic', 'random'],
#                          'warm_start': [True, False]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(mean_absolute_error, greater_is_better=False),
#              verbose=1)

# %%
#Display the best estimator parameters
regGridSearch.best_estimator_
# Out:
# ElasticNet(alpha=0.001, copy_X=True, fit_intercept=True, l1_ratio=0.001,
#            max_iter=10000, normalize=True, positive=False, precompute=True,
#            random_state=0, selection='cyclic', tol=0.0001, warm_start=True)

# %%
#Create a regression estimator with best parameters for cross validation
regEstimator = regGridSearch.best_estimator_

#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics.
elastic_Results = EvaluateRegressionEstimator(regEstimator, X, y, cv)
# Out:
# The average MAE for all cv folds is: 			 0.054355
# The average MSE for all cv folds is: 			 0.0051755
# The average RMSE for all cv folds is: 			 0.071892
# *********************************************************
# The average R-Squared for all cv folds is: 		 0.24326
# *********************************************************
# Cross Validation Fold Mean Error Scores

# %%
#Do we predict graduation rates greater than 100%?
regEstimator =  regGridSearch.best_estimator_

regEstimator.fit(X, y)
yhat = regEstimator.predict(X)
print("Yhat Max: ", yhat.max())
# Out:
# Yhat Max:  0.28130985024883437

# %% [markdown]
# ## XGBoost

# %%
# credit: https://www.kaggle.com/mburakergenc/predictions-with-xgboost-and-linear-regression
# Out:
#   File "<ipython-input-64-a2fed50ee2d7>", line 10
#     #from sklearn import cross_validation, tree, linear_model
#            ^
# SyntaxError: from __future__ imports must occur at the beginning of the file

# %%
regr = LinearRegression()

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state =1 )

# %%
# Let's try XGboost algorithm to see if we can get better results
xgb = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)

# %%
traindf, testdf = train_test_split(X_train, test_size = 0.3)
xgb.fit(X_train,y_train)

# %%
predictions = xgb.predict(X_test)
print(explained_variance_score(y_test,predictions))
