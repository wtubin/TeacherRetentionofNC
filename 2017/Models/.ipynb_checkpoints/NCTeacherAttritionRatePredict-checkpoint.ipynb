# %% [markdown]
# ## Predicting Teacher Attrition Rates for Public Schools
# **This notebook explores predicting teacher attrition rates for public schools in North Carolina.**
# * Public school racial compositions are also considered when making predictions in this notebook.
# * The North Carolina Educational Attainment Data Repository for Machine Learning is located on Github at: https://github.com/wtubin/TeacherRetentionofNC
#
# **For documentation on various Generalized Linear Models in Sklearn see:**
# * http://scikit-learn.org/stable/modules/linear_model.html
# * https://stackoverflow.com/questions/33845539/modelling-probabilities-in-a-regularized-logistic-regression-model-in-python

# %%
#!pip install xgboost

# %%
#import required Libraries
from __future__ import division
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV    
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn import metrics as mt
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from sklearn.model_selection import cross_validate
from scipy.stats import pearsonr
from sklearn.metrics import explained_variance_score

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost
import math

# %%
#The 'path' variable may also be a URL pointing to the proper raw file path on github: 

ML2017 = '../Machine Learning Datasets/PublicSchools2017_ML.csv'
ML2016 = '../../2016/Machine Learning Datasets/PublicSchools2016_ML.csv'
ML2015 =  '../../2015/Machine Learning Datasets/PublicSchools2015_ML.csv'
ML2014 =  '../../2014/Machine Learning Datasets/PublicSchools2014_ML.csv'

schData2017=pd.read_csv(ML2017, low_memory=False)
print('*********************************2017 ML Data*************************************')
schData2017.info()
schData2016=pd.read_csv(ML2016, low_memory=False)
print('*********************************2016 ML Data*************************************')
schData2016.info()

schData2015=pd.read_csv(ML2015, low_memory=False)
print('*********************************2015 ML Data*************************************')
schData2015.info()

schData2014=pd.read_csv(ML2014, low_memory=False)
print('*********************************2014 ML Data*************************************')
schData2014.info()
# Out:
# *********************************2017 ML Data*************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2468 entries, 0 to 2467
# Columns: 394 entries, student_num to unit_code
# dtypes: float64(350), int64(44)
# memory usage: 7.4 MB
# *********************************2016 ML Data*************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Columns: 374 entries, closed_ind to unit_code
# dtypes: float64(296), int64(78)
# memory usage: 6.9 MB
# *********************************2015 ML Data*************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2432 entries, 0 to 2431
# Columns: 403 entries, closed_ind to unit_code
# dtypes: float64(342), int64(61)
# memory usage: 7.5 MB
# *********************************2014 ML Data*************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2426 entries, 0 to 2425
# Columns: 364 entries, closed_ind to unit_code
# dtypes: float64(331), int64(33)
# memory usage: 6.7 MB

# %% [markdown]
# ## Fix Year

# %%
schData2014["Year"]=2014
schData2015["Year"]=2015
schData2016["Year"]=2016
schData2017["Year"]=2017

# %%
# Combine the data set
schData = pd.concat([schData2017,schData2016,schData2015,schData2014], axis=0, ignore_index=True, sort = True)

# %%
#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25


#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = schData.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = schData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schData = schData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Columns: 410 entries, (TCE) prepared returns Ct 100KLT200K to wap_per_classroom
# dtypes: float64(391), int64(19)
# memory usage: 30.5 MB
#
# Columns Deleted:  101

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 0                 (TCE) prepared returns Ct 100KLT200K                   4858
# 1                   (TCE) prepared returns Ct 25KLT50K                   2426
# 2                  (TCE) prepared returns Ct 75KLT100K                   2426
# 3                (VITA) prepared returns Ct 100KLT200K                   2426
# 4                  (VITA) prepared returns Ct 25KLT50K                   2426
# 5                  (VITA) prepared returns Ct 50KLT75K                   2426
# 7                                              00_Size                   2426
# 8                                              01_Size                   4894
# 9                                              02_Size                   2426
# 10                                             03_Size                   2426
# 11                                             04_Size                   2426
# 12                                             05_Size                   2426
# 20                     Add Medicare tax Amt 100KLT200K                   4900
# 21                   Add child tax credit Amt 25KLT50K                   2426
# 22                  Add child tax credit Amt 75KLT100K                   2430
# 26                   Alternative minimum tax Amt LT25K                   2468
# 27                 Alternative minimum tax Ct 50KLT75K                   2426
# 28                Alternative minimum tax Ct 75KLT100K                   4862
# 32                                            Byod_Yes                   4858
# 49   Does Not Meet Expected Growth_TCHR_Standard 6_Pct                   4898
# 50   Does Not Meet Expected Growth_TCHR_Student Gro...                   4858
# 59   Domestic production activities deduction Ct LT25K                   2430
# 65                                EOCMathI_CACR_Female                   4858
# 68                                  EOCMathI_CACR_Male                   4858
# 71                                 EOCMathI_CACR_White                   2426
# 74                                EOCSubjects_CACR_AIG                   4858
# 77                              EOCSubjects_CACR_Black                   4858
# 78                           EOCSubjects_CACR_Hispanic                   2432
# 94                             EOG/EOCSubjects_GLP_LEP                   2430
# 104                                  EOGGr3_CACR_White                   2432
# 105                                     EOGGr3_GLP_SWD                   4898
# 111                                    EOGGr4_CACR_EDS                   2432
# 117                                     EOGGr4_GLP_LEP                   2430
# 118                                     EOGGr4_GLP_SWD                   4900
# 128                                  EOGGr5_CACR_White                   2426
# 139                               EOGMathGr3-8_GLP_LEP                   4898
# 140                               EOGMathGr3-8_GLP_SWD                   4898
# 145                                EOGMathGr3_CACR_EDS                   4858
# 150                              EOGMathGr3_CACR_White                   4858
# 156                                EOGMathGr4_CACR_EDS                   4858
# 161                              EOGMathGr4_CACR_White                   4858
# 162                                 EOGMathGr4_GLP_LEP                   4898
# 163                                 EOGMathGr4_GLP_SWD                   4898
# 168                                EOGMathGr5_CACR_EDS                   4858
# 173                              EOGMathGr5_CACR_White                   2426
# 174                                 EOGMathGr5_GLP_SWD                   4898
# 184                  EOGReadingGr3_CACR_AmericanIndian                   2430
# 186                             EOGReadingGr3_CACR_EDS                   4858
# 190                  EOGReadingGr3_CACR_TwoorMoreRaces                   4898
# 191                              EOGReadingGr3_GLP_LEP                   2430
# 192                              EOGReadingGr3_GLP_SWD                   4898
# 193                  EOGReadingGr4_CACR_AmericanIndian                   4862
# 195                             EOGReadingGr4_CACR_EDS                   4858
# 199                  EOGReadingGr4_CACR_TwoorMoreRaces                   4898
# 202                  EOGReadingGr5_CACR_AmericanIndian                   2430
# 208                  EOGReadingGr5_CACR_TwoorMoreRaces                   2468
# 209                   EOGReadingGr5_GLP_AmericanIndian                   4856
# 210                         EOGReadingGr5_GLP_Hispanic                   4898
# 223                            EOGScienceGr5&8_GLP_LEP                   2430
# 224                            EOGScienceGr5&8_GLP_SWD                   4898
# 227                             EOGScienceGr5_CACR_EDS                   4858
# 228                        EOGScienceGr5_CACR_Hispanic                   4898
# 231                  EOGScienceGr5_CACR_TwoorMoreRaces                   4898
# 232                              EOGScienceGr5_GLP_LEP                   2430
# 233                              EOGScienceGr5_GLP_SWD                   4898
# 239                               EOGSubjects_CACR_LEP                   4862
# 242                                EOGSubjects_GLP_LEP                   4898
# 246                  Earned income credit Amt 50KLT75K                   2426
# 247        Exceeds Expected Growth_TCHR_Standard 6_Pct                   4898
# 248    Exceeds Expected Growth_TCHR_Student Growth_Pct                   4858
# 249  Excess earned income credit (refundable) Amt 5...                   2426
# 254                                       Math I Score                   2468
# 256                                   Math SPG Grade_B                   2430
# 257                                   Math SPG Grade_C                   2430
# 258                                   Math SPG Grade_D                   2430
# 259                                   Math SPG Grade_F                   2430
# 261          Meets Expected Growth_TCHR_Standard 6_Pct                   4898
# 262      Meets Expected Growth_TCHR_Student Growth_Pct                   4858
# 263           Net investment income tax Amt 100KLT200K                   4858
# 267                Not Demostrated_TCHR_Standard 5_Pct                   4894
# 275  Number of volunteer prepared returns Tot 50KLT75K                   2426
# 279  Partnership/S-corp net income (less loss) Amt ...                   2432
# 285                                 Reading  SPG Score                   4898
# 286                                Reading SPG Grade_B                   2430
# 287                                Reading SPG Grade_C                   2430
# 288                                Reading SPG Grade_D                   2430
# 289                                Reading SPG Grade_F                   2430
# 290                        ReadingGr3-8_pTarget_PctMet                   4898
# 292                             SBE District_Northeast                   4856
# 293                             SBE District_Northwest                   4856
# 294                        SBE District_Piedmont-Triad                   4856
# 295                             SBE District_Sandhills                   4856
# 296                             SBE District_Southeast                   4856
# 297                             SBE District_Southwest                   4856
# 298                               SBE District_Western                   4856
# 299                                     SPG Grade_A+NG                   2426
# 308      Self-employment retirement plans Amt 25KLT50K                   4898
# 309                               State Gap Compared_Y                   4858
# 310     State and local general sales taxes Amt GE200K                   4894
# 312           Tuition and fees deduction Amt 75KLT100K                   2426
# 318                                 _1_to_1_access_Yes                   4858
# 321                           avg_age_media_collection                   4858
# 323                                  books_per_student                   2426
# 328  calendar_type_txt_Regular School, Traditional ...                   2468
# 331                                      category_cd_E                   2426
# 333                                      category_cd_M                   2432
# 334                                      category_cd_T                   2468
# 335                                         closed_ind                   2468
# 337                                  digital_media_pct                   2426
# 338                                esea_attendance_Met                   4898
# 340                                      esea_status_R                   4898
# 341                                     esea_status_RF                   4898
# 344                                 highqual_class_pct                   4894
# 352                           lea_benefits_expense_pct                   2468
# 353                              lea_books_per_student                   2426
# 359                         lea_highqual_class_all_pct                   4894
# 360                          lea_highqual_class_hp_pct                   4894
# 361                          lea_highqual_class_lp_pct                   4894
# 362                             lea_highqual_class_pct                   4894
# 368                      lea_not_highqual_class_hp_pct                   4894
# 369                      lea_not_highqual_class_lp_pct                   4894
# 382                                        lea_wap_num                   4858
# 383                              lea_wap_per_classroom                   4858
# 390                            st_avg_daily_attend_pct                   2426
# 394                              st_expelled_per_c_num                   4862
# 396                              st_highqual_class_pct                   4894
# 397                             st_long_susp_per_c_num                   2432
# 398                                       st_nbpts_num                   2432
# 399                            st_short_susp_per_c_num                   2430
# 401                               st_tchyrs_11plus_pct                   2426
# 408                                            wap_num                   4858
# 409                                  wap_per_classroom                   4858

# %%
#Replace all remaining NaN with 0
schData = schData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ### we are not remove the 0 1 year percentage for now.

# %%
# zeroAttrition = schData[schData['_1yr_tchr_trnovr_pct']==0.0].index
# schData = schData.drop(zeroAttrition,axis=0)
# print('*********After: Removing rows with first year turn over percentage =0.00******')
# schData.info(verbose=False)
# print ('\r\nRows Deleted: ', len(zeroAttrition))

# %% [markdown]
# ## Visulization

# %%
plt.figure(figsize=(13,10))
_1yr_tchr_trnovr_pct = schData["_1yr_tchr_trnovr_pct"]
ax = sns.distplot(_1yr_tchr_trnovr_pct);
plt.title("Figure 1. North Carolina Public School First Year Teacher Turnover Percentage (2014-2017)")
plt.show()

# %%
schData['lea_salary'] = schData['lea_total_expense_num']*schData['lea_salary_expense_pct']

plt.figure(figsize=(13,10))
lea_salary_expense_pct=schData.lea_salary_expense_pct
ax = sns.distplot(schData['lea_salary']);
plt.title("Figure 2. North Carolina Public School Lea Salary Expense (2014-2017)")
plt.show()

# %%
# responseible variabl distribution
schData['_1yr_tchr_trnovr_pct'].describe()
# Out:
# count    9756.000000
# mean        0.140861
# std         0.087387
# min         0.000000
# 25%         0.082000
# 50%         0.130000
# 75%         0.185250
# max         0.818000
# Name: _1yr_tchr_trnovr_pct, dtype: float64

# %%
sns.lmplot(x="Crime_Rate_Murder_Rate", y="_1yr_tchr_trnovr_pct", hue = "Year", data=schData,height=8.27, aspect=11.7/8.27)
sns.despine()

plt.title("Figure 3. North Carolina Public School One Year Teacher Attrition Rate vs. LEA Salary Expenditure (2014-2017)")
plt.ylabel('1st Year Teacher Attrition Rate')
plt.xlabel('Crime Rate Murder Rate')

# plt.show()
# Out:
# Text(0.5,20.8,'Crime Rate Murder Rate')

# %%
#------------------------------------------------------------
# Get the highest frequency offense and do violin plot
#------------------------------------------------------------
plt.figure(figsize=(16,10))


sns.set(style="whitegrid")
ax = sns.violinplot(x= 'Year'
                   ,y='Crime_Rate_Murder_Rate'
                   #,hue='Arrest_status'
                   ,order=['2014','2015','2016','2017']
                   ,palette='Set2'
                   ,split=True
                   ,inner='quartile'
                   ,data = schData)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
ax.axes.set_title("Arrests by Response Time and Day of Week",fontsize=15)
ax.set_xlabel("Day of Week",fontsize=10)
ax.set_ylabel("Response Time",fontsize=10)
ax.tick_params(labelsize=10)

# %%
sns.lmplot(x="lea_total_expense_num", y="_1yr_tchr_trnovr_pct", hue="Year", data=schData,height=8.27, aspect=11.7/8.27)
sns.despine()

plt.title("Figure 4. North Coralina Public School One Year Teacher Attrition Rate vs. LEA Total School Expenditure (2014-2017)")
plt.ylabel('1st Year Attrition Rate')
plt.xlabel('LEA Total School Expenditure')
# Out:
# Text(0.5,23.0069,'LEA Total School Expenditure')

# %%
sns.lmplot(x="lea_total_expense_num", y="_1yr_tchr_trnovr_pct", hue="Year", data=schData,height=8.27, aspect=11.7/8.27)
sns.despine()

plt.title("Figure 4. North Coralina Public School One Year Teacher Attrition Rate vs. LEA Total School Expenditure (2014-2017)")
plt.ylabel('1st Year Attrition Rate')
plt.xlabel('LEA Total School Expenditure')
# Out:
# Text(0.5,23.0069,'LEA Total School Expenditure')

# %%
#schData.info(verbose=True)

# %% [markdown]
# ## Feature Selection
# * set max features we want to select

# %% [markdown]
# ### Manually remove columns
#
# * there columns is not what we are interested in, so we remove them manaually from data set

# %%
# manually remove the columns

ManualDropFeatures = ['st_1yr_tchr_trnovr_pct','lea_1yr_tchr_trnovr_pct','PacificIslandPct','PacificIslandMalePct','PacificIslandFemalePct','HispanicPct'
                      ,'BlackPct','AsianPct','IndianPct','lea_supplies_expense_pct'
                      ,'lea_services_expense_pct','lea_salary_expense_pct']

schData = schData.drop(ManualDropFeatures,axis=1)
print('*********After: Removing fetures we are not interested in ******')
schData.info(verbose=False)
print ('\r\nFeatures Deleted: ', len(ManualDropFeatures))
# Out:
# *********After: Removing fetures we are not interested in ******
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Columns: 399 entries, (TCE) prepared returns Ct 100KLT200K to lea_salary
# dtypes: float64(380), int64(19)
# memory usage: 29.7 MB
#
# Features Deleted:  12

# %%
# threthold for the feature selection
max_features =350
# backup the data set
schData_bak = schData
#schData = schData_bak

# %%
# Get the X and y
y= schData['_1yr_tchr_trnovr_pct']
X = schData.drop(['_1yr_tchr_trnovr_pct'],axis=1)

# %%
# Feature Selection 
X_fs = X
y_fs = y

# %% [markdown]
# ## Pearson Correlation

# %%
# Pearson Correlation
feature_name = X_fs.columns.tolist()
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
        # replace NaN with 0
        cor_list = [0 if np.isnan(i) else i for i in cor_list]
        # feature name
        cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-max_features:]].columns.tolist()
        # feature selection? 0 for not select, 1 for select
        cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature
cor_support, cor_feature = cor_selector(X_fs, y_fs)
print(str(len(cor_feature)), 'selected features')
print(pd.DataFrame( cor_feature))
# Out:
# 350 selected features
#                                                      0
# 0                               SBE District_Southeast
# 1                               EOGReadingGr5_CACR_LEP
# 2                  Not Demostrated_TCHR_Standard 1_Pct
# 3                                lea_wap_per_classroom
# 4                                     TwoOrMoreMalePct
# 5                         EOCMathI_CACR_AmericanIndian
# 6                                   _1_to_1_access_Yes
# 7                                         st_nbpts_num
# 8                            lea_highqual_class_lp_pct
# 9                     EOGReadingGr5_GLP_AmericanIndian
# 10                                          lea_salary
# 11                                   wap_per_classroom
# 12                   EOGReadingGr4_CACR_AmericanIndian
# 13                Alternative minimum tax Amt 50KLT75K
# 14   calendar_type_txt_Regular School, Traditional ...
# 15                     EOCSubjects_CACR_TwoorMoreRaces
# 16                   EOGReadingGr5_CACR_TwoorMoreRaces
# 17                       Number of farm returns GE200K
# 18                                  EOCMathI_CACR_Male
# 19                              lea_expelled_per_c_num
# 20                                   EOCMathI_CACR_LEP
# 21   calendar_type_txt_Magnet School, Traditional C...
# 22                      EOGMathGr5_CACR_TwoorMoreRaces
# 23                           EOCSubjects_CACR_Hispanic
# 24                                EOCSubjects_CACR_LEP
# 25                 Alternative minimum tax Ct 50KLT75K
# 26                Alternative minimum tax Amt 25KLT50K
# 27                   Alternative minimum tax Amt LT25K
# 28            Tuition and fees deduction Amt 75KLT100K
# 29                              lea_local_perpupil_num
# 30                        Attrtion_Reason_OtherReasons
# 31   calendar_type_txt_Magnet School, Year-Round Ca...
# 32                              st_long_susp_per_c_num
# 33                                 esea_attendance_Met
# 34                                         student_num
# 35                   EOGScienceGr5_CACR_TwoorMoreRaces
# 36                   Add child tax credit Amt 25KLT50K
# 37                            lea_benefits_expense_pct
# 38                            EOGScienceGr5&8_CACR_LEP
# 39                      EOGMathGr4_CACR_TwoorMoreRaces
# 40                 Not Demostrated_TCHR_Standard 4_Pct
# 41                                  highqual_class_pct
# 42                   EOGReadingGr3_CACR_TwoorMoreRaces
# 43                      EOGMathGr3_CACR_TwoorMoreRaces
# 44       Self-employment retirement plans Amt 25KLT50K
# 45                              SBE District_Southwest
# 46   Domestic production activities deduction Amt L...
# 47                               EOGMathGr5_CACR_Black
# 48                     EOGSubjects_CACR_AmericanIndian
# 49                            EOGScienceGr5_CACR_Black
# 50                                    EOCMathI_GLP_LEP
# 51                              lea_highqual_class_pct
# 52                                EOCMathI_CACR_Female
# 53                             Crime_Rate_Violent_Rate
# 54                                             LEACode
# 55                                 EOGMathGr4_CACR_LEP
# 56                              EOCSubjects_CACR_Black
# 57                   EOGReadingGr4_CACR_TwoorMoreRaces
# 58                                                Year
# 59                              EOGReadingGr4_CACR_LEP
# 60                                  EOGMathGr4_GLP_LEP
# 61                                         SPG Grade_I
# 62                             EOGScienceGr5&8_GLP_LEP
# 63                                 EOCSubjects_GLP_LEP
# 64                                     EOGGr5_CACR_LEP
# 65                       EOGScienceGr5&8_CACR_Hispanic
# 66                                            Byod_Yes
# 67             Residential energy tax credit Amt LT25K
# 68                          lea_highqual_class_all_pct
# 69                                     crime_per_c_num
# 70                     Add Medicare tax Amt 100KLT200K
# 71                               EOGMathGr3_CACR_Black
# 72                 EOGScienceGr5&8_CACR_AmericanIndian
# 73                                           unit_code
# 74                               EOGReadingGr4_GLP_LEP
# 75                             Crime_Rate_Robbery_Rate
# 76                            EOGReadingGr4_CACR_Black
# 77                     EOCSubjects_CACR_AmericanIndian
# 78                          EOGScienceGr5&8_CACR_Black
# 79                 (VITA) prepared returns Ct 50KLT75K
# 80                               st_highqual_class_pct
# 81         Exceeds Expected Growth_TCHR_Standard 6_Pct
# 82                 (VITA) prepared returns Ct 25KLT50K
# 83                                      SPG Grade_A+NG
# 84   calendar_type_txt_Regular School, Traditional ...
# 85                            avg_age_media_collection
# 86                               EOGMathGr4_CACR_Black
# 87                                   EOCMathI_CACR_EDS
# 88                                   EOCMathI_CACR_AIG
# 89                               st_expelled_per_c_num
# 90                 EOG/EOCSubjects_CACR_AmericanIndian
# 91                            EOGReadingGr5_CACR_Black
# 92                           lea_highqual_class_hp_pct
# 93   Domestic production activities deduction Amt 2...
# 94                                       category_cd_I
# 95                             st_short_susp_per_c_num
# 96                            EOGReadingGr3_CACR_Black
# 97                    EOGMathGr3-8_CACR_AmericanIndian
# 98            Net investment income tax Amt 100KLT200K
# 99                          EOGScienceGr5&8_CACR_Asian
# 100                                long_susp_per_c_num
# 101                              lea_books_per_student
# 102                              EOGMathGr5_CACR_Asian
# 103  Excess earned income credit (refundable) Amt 5...
# 104                            EVAAS Growth Status_Met
# 105                              EOGMathGr3_CACR_Asian
# 106                                        lea_wap_num
# 107                             EOCMathI_CACR_Hispanic
# 108                            lea_long_susp_per_c_num
# 109                EOGReadingGr3-8_CACR_AmericanIndian
# 110                               EOGMathGr3-8_GLP_LEP
# 111                         EOGReadingGr5_GLP_Hispanic
# 112                              EOGMathGr4_CACR_Asian
# 113                               SBE District_Western
# 114  calendar_type_txt_Regular School, Year-Round C...
# 115                                     EOGGr4_GLP_LEP
# 116                 Add child tax credit Amt 75KLT100K
# 117                        SBE District_Piedmont-Triad
# 118                        EOGScienceGr5_CACR_Hispanic
# 119  Domestic production activities deduction Ct LT25K
# 120                      lea_not_highqual_class_lp_pct
# 121                               State Gap Compared_Y
# 122      Meets Expected Growth_TCHR_Student Growth_Pct
# 123  Domestic production activities deduction Amt 7...
# 124                (TCE) prepared returns Ct 75KLT100K
# 125  Domestic production activities deduction Ct 75...
# 126                 (TCE) prepared returns Ct 25KLT50K
# 127                          lea_sat_participation_pct
# 128                                EOGSubjects_GLP_LEP
# 129                                    EOGGr4_CACR_LEP
# 130                           lea_avg_daily_attend_pct
# 131                               st_tchyrs_0thru3_pct
# 132                                EOGMathGr3_CACR_LEP
# 133                                      esea_status_R
# 134                              EOGReadingGr3_GLP_LEP
# 135                                Crime_Rate_MVT_Rate
# 136                         EOGReadingGr3-8_CACR_Black
# 137  Domestic production activities deduction Amt 5...
# 138                                       Math I Score
# 139                             SBE District_Sandhills
# 140                                  EOGGr4_CACR_Black
# 141                            lea_emer_prov_teach_pct
# 142                                      category_cd_M
# 143                             EOGReadingGr3_CACR_LEP
# 144                            EOGMathGr3-8_CACR_Asian
# 145                                            01_Size
# 146                         EOG/EOCSubjects_CACR_Black
# 147                             st_emer_prov_teach_pct
# 148  Domestic production activities deduction Ct 25...
# 149                           EOGMathGr5_CACR_Hispanic
# 150                                  EOGGr3_CACR_Asian
# 151                        ReadingGr3-8_pTarget_PctMet
# 152                         EOGGr4_CACR_TwoorMoreRaces
# 153                        EOGReadingGr5_CACR_Hispanic
# 154                           lea_ap_participation_pct
# 155                                  EOGGr4_CACR_Asian
# 156                     school_type_txt_Regular School
# 157                                  EOGGr3_CACR_Black
# 158                         EOG/EOCSubjects_CACR_Asian
# 159                                  EOGGr5_CACR_Asian
# 160                                        SPG Grade_C
# 161                            EOGScienceGr5&8_GLP_SWD
# 162                                 Reading  SPG Score
# 163                         10+ Years_LEA_Exp_Pct_Prin
# 164                                   Math SPG Grade_D
# 165                            EOGMathGr3-8_CACR_Black
# 166                         EOGGr3_CACR_TwoorMoreRaces
# 167                      lea_not_highqual_class_hp_pct
# 168  Partnership/S-corp net income (less loss) Amt ...
# 169                         lea_stud_internet_comp_num
# 170  Domestic production activities deduction Ct 50...
# 171                            EOG/EOCSubjects_GLP_LEP
# 172                         EOGGr5_CACR_TwoorMoreRaces
# 173                EOGReadingGr3-8_CACR_TwoorMoreRaces
# 174                             stud_internet_comp_num
# 175                             SBE District_Northeast
# 176                                 st_avg_student_num
# 177                              EOGMathGr3-8_CACR_LEP
# 178                                  EOGGr5_CACR_Black
# 179                              Grad_project_status_Y
# 180                        EOGReadingGr4_CACR_Hispanic
# 181    Exceeds Expected Growth_TCHR_Student Growth_Pct
# 182                             EOGSubjects_CACR_Asian
# 183                           EOGReadingGr3-8_CACR_LEP
# 184                           EOGMathGr4_CACR_Hispanic
# 185              (VITA) prepared returns Ct 100KLT200K
# 186                                      category_cd_T
# 187                            EOGReadingGr3-8_GLP_LEP
# 188                        EOGReadingGr3_CACR_Hispanic
# 189                                 tchyrs_4thru10_pct
# 190                           EOGMathGr3_CACR_Hispanic
# 191                             lea_state_perpupil_num
# 192  Domestic production activities deduction Amt 1...
# 193                                        pct_GCE_ALL
# 194                               EOGSubjects_CACR_LEP
# 195                             SBE District_Northwest
# 196  Does Not Meet Expected Growth_TCHR_Student Gro...
# 197                             EOGSubjects_CACR_Black
# 198                                    EOGGr3_CACR_LEP
# 199                        4-10 Years_LEA_Exp_Pct_Prin
# 200                                 EOGMathGr5_GLP_SWD
# 201                                 EOGMathGr4_GLP_SWD
# 202                                      category_cd_E
# 203                   EOGMathGr3-8_CACR_TwoorMoreRaces
# 204                              EOGScienceGr5_GLP_SWD
# 205                                EOCMathI_CACR_Black
# 206                            SciGr5&8_pTarget_PctMet
# 207                                 EVAAS Growth Score
# 208                              EOGReadingGr3_GLP_SWD
# 209                                            05_Size
# 210                           EOG/EOCSubjects_CACR_LEP
# 211                                            04_Size
# 212                                        Math I_Size
# 213                                EOGMathGr3_CACR_AIG
# 214                             Crime_Rate_Murder_Rate
# 215                             EOGReadingGr5_CACR_SWD
# 216                                    EOGGr3_CACR_AIG
# 217                         EVAAS Growth Status_NotMet
# 218                                   Math SPG Grade_C
# 219                  Distinguished_TCHR_Standard 5_Pct
# 220                                     EOGGr3_GLP_SWD
# 221                               EOGGr4_CACR_Hispanic
# 222                                            02_Size
# 223                                EOGMathGr5_CACR_EDS
# 224                      EOGReadingGr3-8_CACR_Hispanic
# 225                                            03_Size
# 226                   Number of farm returns 75KLT100K
# 227                                            00_Size
# 228                             EOGScienceGr5_CACR_EDS
# 229                                     EOGGr4_GLP_SWD
# 230                                EOGMathGr4_CACR_EDS
# 231                           EOGScienceGr5&8_CACR_AIG
# 232                  Number of farm returns 100KLT200K
# 233                                lea_crime_per_c_num
# 234                             st_flicensed_teach_pct
# 235                               EOGMathGr3-8_GLP_SWD
# 236                  Distinguished_TCHR_Standard 3_Pct
# 237                    Number of farm returns 25KLT50K
# 238                             EOGReadingGr4_CACR_EDS
# 239                              lea_total_expense_num
# 240                                EOGMathGr3_CACR_EDS
# 241                EOG/EOCSubjects_CACR_TwoorMoreRaces
# 242                              EOGReadingGr5_GLP_SWD
# 243                    Number of farm returns 50KLT75K
# 244                           EOGScienceGr5&8_CACR_SWD
# 245                               EOGGr5_CACR_Hispanic
# 246                                      lea_nbpts_num
# 247                             EOGReadingGr3_CACR_EDS
# 248                             EOGReadingGr4_CACR_SWD
# 249                           MathGr3-8_pTarget_PctMet
# 250                                Reading SPG Grade_C
# 251                    EOGSubjects_CACR_TwoorMoreRaces
# 252                         0-3 Years_LEA_Exp_Pct_Prin
# 253                  Distinguished_TCHR_Standard 4_Pct
# 254                                EOGMathGr5_CACR_SWD
# 255                               EOGGr3_CACR_Hispanic
# 256                             lea_tchyrs_4thru10_pct
# 257                               EOGSubjects_CACR_AIG
# 258                         EOGMathGr3-8_CACR_Hispanic
# 259                  Distinguished_TCHR_Standard 2_Pct
# 260                             EOGScienceGr5_CACR_SWD
# 261                                EOGMathGr4_CACR_SWD
# 262                              EOGReadingGr4_GLP_SWD
# 263                        TotalTargets_pTarget_PctMet
# 264                                Reading SPG Grade_F
# 265                              EOGMathGr4_CACR_White
# 266                                  EOGGr5_CACR_White
# 267                             EOGReadingGr3_CACR_SWD
# 268                                      esea_status_P
# 269                           EOG/EOCSubjects_CACR_AIG
# 270                          EOGSubjects_CACR_Hispanic
# 271                         Number of farm returns All
# 272                       Number of farm returns LT25K
# 273                              EOGMathGr3_CACR_White
# 274                              EOGMathGr3-8_CACR_AIG
# 275                  Distinguished_TCHR_Standard 1_Pct
# 276  Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 277                                EOGMathGr3_CACR_SWD
# 278                                   Math SPG Grade_B
# 279                                Reading SPG Grade_D
# 280                                Reading SPG Grade_B
# 281                           EOGScienceGr5&8_CACR_EDS
# 282                                EOGMathGr4_CACR_AIG
# 283                                 EOGMathGr3_GLP_SWD
# 284                                 st_crime_per_c_num
# 285                               avg_daily_attend_pct
# 286                      EOG/EOCSubjects_CACR_Hispanic
# 287                              EOGMathGr5_CACR_White
# 288                                      Science Score
# 289                                EOGMathGr5_CACR_AIG
# 290                                        SPG Grade_B
# 291                                    EOGGr3_CACR_SWD
# 292                                    EOGGr4_CACR_SWD
# 293                                    EOGGr5_CACR_SWD
# 294                                    EOGGr5_CACR_AIG
# 295                         EOGScienceGr5&8_CACR_White
# 296                                        SPG Grade_F
# 297                                    EOGGr4_CACR_AIG
# 298                                    EOGGr4_CACR_EDS
# 299                              lea_ap_pct_3_or_above
# 300                                  EOGGr3_CACR_White
# 301                                          nbpts_num
# 302                           EOGReadingGr3-8_CACR_SWD
# 303                           lea_short_susp_per_c_num
# 304                                   Math SPG Grade_F
# 305                                lea_advance_dgr_pct
# 306                            EOGReadingGr3-8_GLP_SWD
# 307                                        SPG Grade_D
# 308                     Developing_TCHR_Standard 5_Pct
# 309                     Developing_TCHR_Standard 3_Pct
# 310                             EOGReadingGr5_CACR_EDS
# 311                                    advance_dgr_pct
# 312                            EOGMathGr3-8_CACR_White
# 313                                  EOGGr4_CACR_White
# 314                   Accomplished_TCHR_Standard 3_Pct
# 315                         EOG/EOCSubjects_CACR_White
# 316                               short_susp_per_c_num
# 317                           EOG/EOCSubjects_CACR_SWD
# 318                   Accomplished_TCHR_Standard 2_Pct
# 319                              EOGMathGr3-8_CACR_SWD
# 320                               EOGSubjects_CACR_SWD
# 321                   Accomplished_TCHR_Standard 5_Pct
# 322                           lea_federal_perpupil_num
# 323                           EOGReadingGr3-8_CACR_EDS
# 324                                    EOGGr5_CACR_All
# 325                                    EOGGr4_CACR_All
# 326                              lea_sat_avg_score_num
# 327                              EOGMathGr3-8_CACR_EDS
# 328                     Developing_TCHR_Standard 2_Pct
# 329                                    EOGGr3_CACR_All
# 330                     Proficient_TCHR_Standard 3_Pct
# 331                                          SPG Score
# 332                              lea_tchyrs_11plus_pct
# 333                     Proficient_TCHR_Standard 5_Pct
# 334                     Developing_TCHR_Standard 1_Pct
# 335                           EOG/EOCSubjects_CACR_EDS
# 336                   Accomplished_TCHR_Standard 1_Pct
# 337                     Proficient_TCHR_Standard 2_Pct
# 338                     Developing_TCHR_Standard 4_Pct
# 339                   Accomplished_TCHR_Standard 4_Pct
# 340                           EOG/EOCSubjects_CACR_All
# 341                     Proficient_TCHR_Standard 4_Pct
# 342                     Proficient_TCHR_Standard 1_Pct
# 343                            lea_flicensed_teach_pct
# 344                                  tchyrs_11plus_pct
# 345                                           WhitePct
# 346                              lea_tchyrs_0thru3_pct
# 347                                flicensed_teach_pct
# 348                                  lateral_teach_pct
# 349                                  tchyrs_0thru3_pct

# %% [markdown]
# ## Linear Reggesion RFE

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
rfe_selector = RFE(estimator=LinearRegression(), n_features_to_select=max_features, step=10, verbose=5)
rfe_selector.fit(X_fs, y_fs)
rfe_support = rfe_selector.get_support()
rfe_feature = X_fs.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
print(pd.DataFrame(rfe_feature))
# Out:
# Fitting estimator with 398 features.
# Fitting estimator with 388 features.
# Fitting estimator with 378 features.
# Fitting estimator with 368 features.
# Fitting estimator with 358 features.
# 350 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                  (TCE) prepared returns Ct 75KLT100K
# 2                (VITA) prepared returns Ct 100KLT200K
# 3                           0-3 Years_LEA_Exp_Pct_Prin
# 4                                              00_Size
# 5                                              01_Size
# 6                                              02_Size
# 7                                              03_Size
# 8                                              04_Size
# 9                                              05_Size
# 10                          10+ Years_LEA_Exp_Pct_Prin
# 11                         4-10 Years_LEA_Exp_Pct_Prin
# 12                    Accomplished_TCHR_Standard 1_Pct
# 13                    Accomplished_TCHR_Standard 2_Pct
# 14                    Accomplished_TCHR_Standard 3_Pct
# 15                    Accomplished_TCHR_Standard 4_Pct
# 16                    Accomplished_TCHR_Standard 5_Pct
# 17                     Add Medicare tax Amt 100KLT200K
# 18                  Add child tax credit Amt 75KLT100K
# 19                Alternative minimum tax Amt 25KLT50K
# 20                Alternative minimum tax Amt 50KLT75K
# 21               Alternative minimum tax Amt 75KLT100K
# 22                   Alternative minimum tax Amt LT25K
# 23                 Alternative minimum tax Ct 50KLT75K
# 24                Alternative minimum tax Ct 75KLT100K
# 25                        Attrtion_Reason_OtherReasons
# 26                                            Byod_Yes
# 27                               Crime_Rate_Arson_Rate
# 28                                 Crime_Rate_MVT_Rate
# 29                              Crime_Rate_Murder_Rate
# 30                                Crime_Rate_Rape_Rate
# 31                             Crime_Rate_Robbery_Rate
# 32                             Crime_Rate_Violent_Rate
# 33                      Developing_TCHR_Standard 1_Pct
# 34                      Developing_TCHR_Standard 2_Pct
# 35                      Developing_TCHR_Standard 3_Pct
# 36                      Developing_TCHR_Standard 4_Pct
# 37                      Developing_TCHR_Standard 5_Pct
# 38                   Distinguished_TCHR_Standard 1_Pct
# 39                   Distinguished_TCHR_Standard 2_Pct
# 40                   Distinguished_TCHR_Standard 3_Pct
# 41                   Distinguished_TCHR_Standard 4_Pct
# 42                   Distinguished_TCHR_Standard 5_Pct
# 43   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 44   Does Not Meet Expected Growth_TCHR_Student Gro...
# 45   Domestic production activities deduction Amt 2...
# 46   Domestic production activities deduction Amt 7...
# 47   Domestic production activities deduction Amt L...
# 48   Domestic production activities deduction Ct 25...
# 49   Domestic production activities deduction Ct 50...
# 50   Domestic production activities deduction Ct 75...
# 51   Domestic production activities deduction Ct LT25K
# 52                        EOCMathI_CACR_AmericanIndian
# 53                                 EOCMathI_CACR_Asian
# 54                                 EOCMathI_CACR_Black
# 55                                   EOCMathI_CACR_EDS
# 56                                EOCMathI_CACR_Female
# 57                              EOCMathI_CACR_Hispanic
# 58                                   EOCMathI_CACR_LEP
# 59                                  EOCMathI_CACR_Male
# 60                                   EOCMathI_CACR_SWD
# 61                        EOCMathI_CACR_TwoorMoreRaces
# 62                                 EOCMathI_CACR_White
# 63                                    EOCMathI_GLP_LEP
# 64                                    EOCMathI_GLP_SWD
# 65                     EOCSubjects_CACR_AmericanIndian
# 66                              EOCSubjects_CACR_Asian
# 67                              EOCSubjects_CACR_Black
# 68                                EOCSubjects_CACR_LEP
# 69                                EOCSubjects_CACR_SWD
# 70                     EOCSubjects_CACR_TwoorMoreRaces
# 71                                 EOCSubjects_GLP_LEP
# 72                            EOG/EOCSubjects_CACR_AIG
# 73                            EOG/EOCSubjects_CACR_All
# 74                 EOG/EOCSubjects_CACR_AmericanIndian
# 75                          EOG/EOCSubjects_CACR_Asian
# 76                          EOG/EOCSubjects_CACR_Black
# 77                            EOG/EOCSubjects_CACR_EDS
# 78                       EOG/EOCSubjects_CACR_Hispanic
# 79                            EOG/EOCSubjects_CACR_LEP
# 80                            EOG/EOCSubjects_CACR_SWD
# 81                 EOG/EOCSubjects_CACR_TwoorMoreRaces
# 82                          EOG/EOCSubjects_CACR_White
# 83                             EOG/EOCSubjects_GLP_LEP
# 84                                     EOGGr3_CACR_All
# 85                          EOGGr3_CACR_AmericanIndian
# 86                                   EOGGr3_CACR_Asian
# 87                                   EOGGr3_CACR_Black
# 88                                EOGGr3_CACR_Hispanic
# 89                                     EOGGr3_CACR_LEP
# 90                                     EOGGr3_CACR_SWD
# 91                          EOGGr3_CACR_TwoorMoreRaces
# 92                                   EOGGr3_CACR_White
# 93                                      EOGGr3_GLP_SWD
# 94                          EOGGr4_CACR_AmericanIndian
# 95                                   EOGGr4_CACR_Asian
# 96                                   EOGGr4_CACR_Black
# 97                                     EOGGr4_CACR_EDS
# 98                                EOGGr4_CACR_Hispanic
# 99                                     EOGGr4_CACR_LEP
# 100                                    EOGGr4_CACR_SWD
# 101                         EOGGr4_CACR_TwoorMoreRaces
# 102                                  EOGGr4_CACR_White
# 103                                     EOGGr4_GLP_LEP
# 104                                     EOGGr4_GLP_SWD
# 105                                    EOGGr5_CACR_All
# 106                         EOGGr5_CACR_AmericanIndian
# 107                                  EOGGr5_CACR_Black
# 108                                    EOGGr5_CACR_LEP
# 109                                    EOGGr5_CACR_SWD
# 110                         EOGGr5_CACR_TwoorMoreRaces
# 111                                  EOGGr5_CACR_White
# 112                              EOGMathGr3-8_CACR_AIG
# 113                   EOGMathGr3-8_CACR_AmericanIndian
# 114                            EOGMathGr3-8_CACR_Asian
# 115                            EOGMathGr3-8_CACR_Black
# 116                              EOGMathGr3-8_CACR_EDS
# 117                         EOGMathGr3-8_CACR_Hispanic
# 118                              EOGMathGr3-8_CACR_LEP
# 119                              EOGMathGr3-8_CACR_SWD
# 120                   EOGMathGr3-8_CACR_TwoorMoreRaces
# 121                            EOGMathGr3-8_CACR_White
# 122                               EOGMathGr3-8_GLP_LEP
# 123                               EOGMathGr3-8_GLP_SWD
# 124                     EOGMathGr3_CACR_AmericanIndian
# 125                                EOGMathGr3_CACR_EDS
# 126                           EOGMathGr3_CACR_Hispanic
# 127                                EOGMathGr3_CACR_LEP
# 128                                EOGMathGr3_CACR_SWD
# 129                     EOGMathGr3_CACR_TwoorMoreRaces
# 130                              EOGMathGr3_CACR_White
# 131                                 EOGMathGr3_GLP_SWD
# 132                                EOGMathGr4_CACR_AIG
# 133                     EOGMathGr4_CACR_AmericanIndian
# 134                              EOGMathGr4_CACR_Asian
# 135                              EOGMathGr4_CACR_Black
# 136                                EOGMathGr4_CACR_EDS
# 137                           EOGMathGr4_CACR_Hispanic
# 138                                EOGMathGr4_CACR_SWD
# 139                     EOGMathGr4_CACR_TwoorMoreRaces
# 140                                 EOGMathGr4_GLP_LEP
# 141                                 EOGMathGr4_GLP_SWD
# 142                                EOGMathGr5_CACR_AIG
# 143                     EOGMathGr5_CACR_AmericanIndian
# 144                              EOGMathGr5_CACR_Black
# 145                                EOGMathGr5_CACR_EDS
# 146                           EOGMathGr5_CACR_Hispanic
# 147                                EOGMathGr5_CACR_LEP
# 148                                EOGMathGr5_CACR_SWD
# 149                              EOGMathGr5_CACR_White
# 150                                 EOGMathGr5_GLP_SWD
# 151                EOGReadingGr3-8_CACR_AmericanIndian
# 152                         EOGReadingGr3-8_CACR_Black
# 153                           EOGReadingGr3-8_CACR_EDS
# 154                      EOGReadingGr3-8_CACR_Hispanic
# 155                           EOGReadingGr3-8_CACR_LEP
# 156                           EOGReadingGr3-8_CACR_SWD
# 157                EOGReadingGr3-8_CACR_TwoorMoreRaces
# 158                            EOGReadingGr3-8_GLP_LEP
# 159                            EOGReadingGr3-8_GLP_SWD
# 160                  EOGReadingGr3_CACR_AmericanIndian
# 161                           EOGReadingGr3_CACR_Black
# 162                             EOGReadingGr3_CACR_EDS
# 163                        EOGReadingGr3_CACR_Hispanic
# 164                             EOGReadingGr3_CACR_LEP
# 165                             EOGReadingGr3_CACR_SWD
# 166                  EOGReadingGr3_CACR_TwoorMoreRaces
# 167                              EOGReadingGr3_GLP_LEP
# 168                              EOGReadingGr3_GLP_SWD
# 169                  EOGReadingGr4_CACR_AmericanIndian
# 170                           EOGReadingGr4_CACR_Black
# 171                             EOGReadingGr4_CACR_EDS
# 172                        EOGReadingGr4_CACR_Hispanic
# 173                             EOGReadingGr4_CACR_LEP
# 174                             EOGReadingGr4_CACR_SWD
# 175                  EOGReadingGr4_CACR_TwoorMoreRaces
# 176                              EOGReadingGr4_GLP_LEP
# 177                              EOGReadingGr4_GLP_SWD
# 178                  EOGReadingGr5_CACR_AmericanIndian
# 179                           EOGReadingGr5_CACR_Black
# 180                             EOGReadingGr5_CACR_EDS
# 181                             EOGReadingGr5_CACR_LEP
# 182                             EOGReadingGr5_CACR_SWD
# 183                  EOGReadingGr5_CACR_TwoorMoreRaces
# 184                   EOGReadingGr5_GLP_AmericanIndian
# 185                         EOGReadingGr5_GLP_Hispanic
# 186                              EOGReadingGr5_GLP_SWD
# 187                           EOGScienceGr5&8_CACR_AIG
# 188                EOGScienceGr5&8_CACR_AmericanIndian
# 189                         EOGScienceGr5&8_CACR_Black
# 190                           EOGScienceGr5&8_CACR_EDS
# 191                      EOGScienceGr5&8_CACR_Hispanic
# 192                           EOGScienceGr5&8_CACR_LEP
# 193                           EOGScienceGr5&8_CACR_SWD
# 194                         EOGScienceGr5&8_CACR_White
# 195                            EOGScienceGr5&8_GLP_LEP
# 196                            EOGScienceGr5&8_GLP_SWD
# 197                  EOGScienceGr5_CACR_AmericanIndian
# 198                           EOGScienceGr5_CACR_Black
# 199                             EOGScienceGr5_CACR_EDS
# 200                             EOGScienceGr5_CACR_LEP
# 201                  EOGScienceGr5_CACR_TwoorMoreRaces
# 202                              EOGScienceGr5_GLP_SWD
# 203                               EOGSubjects_CACR_AIG
# 204                    EOGSubjects_CACR_AmericanIndian
# 205                             EOGSubjects_CACR_Asian
# 206                             EOGSubjects_CACR_Black
# 207                          EOGSubjects_CACR_Hispanic
# 208                               EOGSubjects_CACR_LEP
# 209                               EOGSubjects_CACR_SWD
# 210                    EOGSubjects_CACR_TwoorMoreRaces
# 211                                EOGSubjects_GLP_LEP
# 212                                 EVAAS Growth Score
# 213                            EVAAS Growth Status_Met
# 214                         EVAAS Growth Status_NotMet
# 215                  Earned income credit Amt 50KLT75K
# 216        Exceeds Expected Growth_TCHR_Standard 6_Pct
# 217    Exceeds Expected Growth_TCHR_Student Growth_Pct
# 218  Excess earned income credit (refundable) Amt 5...
# 219                              Grad_project_status_Y
# 220                                       Math I Score
# 221                                        Math I_Size
# 222                                   Math SPG Grade_B
# 223                                   Math SPG Grade_C
# 224                                   Math SPG Grade_D
# 225                                   Math SPG Grade_F
# 226                           MathGr3-8_pTarget_PctMet
# 227          Meets Expected Growth_TCHR_Standard 6_Pct
# 228      Meets Expected Growth_TCHR_Student Growth_Pct
# 229           Net investment income tax Amt 100KLT200K
# 230                Not Demostrated_TCHR_Standard 1_Pct
# 231                Not Demostrated_TCHR_Standard 2_Pct
# 232                Not Demostrated_TCHR_Standard 4_Pct
# 233                Not Demostrated_TCHR_Standard 5_Pct
# 234                  Number of farm returns 100KLT200K
# 235                    Number of farm returns 25KLT50K
# 236                    Number of farm returns 50KLT75K
# 237                         Number of farm returns All
# 238                      Number of farm returns GE200K
# 239                       Number of farm returns LT25K
# 240                     Proficient_TCHR_Standard 1_Pct
# 241                     Proficient_TCHR_Standard 2_Pct
# 242                     Proficient_TCHR_Standard 3_Pct
# 243                     Proficient_TCHR_Standard 4_Pct
# 244                     Proficient_TCHR_Standard 5_Pct
# 245                                 Reading  SPG Score
# 246                                Reading SPG Grade_B
# 247                                Reading SPG Grade_C
# 248                                Reading SPG Grade_D
# 249                                Reading SPG Grade_F
# 250                        ReadingGr3-8_pTarget_PctMet
# 251            Residential energy tax credit Amt LT25K
# 252                             SBE District_Northeast
# 253                             SBE District_Northwest
# 254                        SBE District_Piedmont-Triad
# 255                             SBE District_Sandhills
# 256                             SBE District_Southeast
# 257                             SBE District_Southwest
# 258                               SBE District_Western
# 259                                     SPG Grade_A+NG
# 260                                        SPG Grade_B
# 261                                        SPG Grade_C
# 262                                        SPG Grade_D
# 263                                        SPG Grade_F
# 264                                        SPG Grade_I
# 265                                          SPG Score
# 266                            SciGr5&8_pTarget_PctMet
# 267                                      Science Score
# 268                               State Gap Compared_Y
# 269     State and local general sales taxes Amt GE200K
# 270                        TotalTargets_pTarget_PctMet
# 271           Tuition and fees deduction Amt 75KLT100K
# 272                                 TwoOrMoreFemalePct
# 273                                   TwoOrMoreMalePct
# 274                                       TwoOrMorePct
# 275                                           WhitePct
# 276                                               Year
# 277                                 _1_to_1_access_Yes
# 278                                    advance_dgr_pct
# 279                               avg_daily_attend_pct
# 280                  calendar_type_txt_Hospital School
# 281  calendar_type_txt_Magnet School, Traditional C...
# 282  calendar_type_txt_Magnet School, Year-Round Ca...
# 283  calendar_type_txt_Regular School, Traditional ...
# 284  calendar_type_txt_Regular School, Traditional ...
# 285  calendar_type_txt_Regular School, Year-Round C...
# 286  calendar_type_txt_Special Education, Tradition...
# 287                                      category_cd_E
# 288                                      category_cd_I
# 289                                      category_cd_M
# 290                                      category_cd_T
# 291                                         closed_ind
# 292                                    crime_per_c_num
# 293                                  digital_media_pct
# 294                                esea_attendance_Met
# 295                                      esea_status_P
# 296                                      esea_status_R
# 297                                     esea_status_RF
# 298                                 expelled_per_c_num
# 299                                flicensed_teach_pct
# 300                                 highqual_class_pct
# 301                                  lateral_teach_pct
# 302                                lea_advance_dgr_pct
# 303                           lea_ap_participation_pct
# 304                              lea_ap_pct_3_or_above
# 305                           lea_avg_daily_attend_pct
# 306                                lea_avg_student_num
# 307                           lea_benefits_expense_pct
# 308                              lea_books_per_student
# 309                                lea_crime_per_c_num
# 310                            lea_emer_prov_teach_pct
# 311                             lea_expelled_per_c_num
# 312                            lea_flicensed_teach_pct
# 313                         lea_highqual_class_all_pct
# 314                          lea_highqual_class_hp_pct
# 315                          lea_highqual_class_lp_pct
# 316                             lea_highqual_class_pct
# 317                              lea_ib_pct_4_or_above
# 318                         lea_instruct_equip_exp_pct
# 319                            lea_long_susp_per_c_num
# 320                      lea_not_highqual_class_hp_pct
# 321                      lea_not_highqual_class_lp_pct
# 322                              lea_sat_avg_score_num
# 323                          lea_sat_participation_pct
# 324                         lea_stud_internet_comp_num
# 325                              lea_tchyrs_0thru3_pct
# 326                              lea_tchyrs_11plus_pct
# 327                             lea_tchyrs_4thru10_pct
# 328                              lea_wap_per_classroom
# 329                                long_susp_per_c_num
# 330                                          nbpts_num
# 331                                        pct_GCE_ALL
# 332                     school_type_txt_Regular School
# 333                            st_avg_daily_attend_pct
# 334                                 st_avg_student_num
# 335                                 st_crime_per_c_num
# 336                             st_emer_prov_teach_pct
# 337                              st_expelled_per_c_num
# 338                             st_flicensed_teach_pct
# 339                              st_highqual_class_pct
# 340                             st_long_susp_per_c_num
# 341                                       st_nbpts_num
# 342                            st_short_susp_per_c_num
# 343                               st_tchyrs_0thru3_pct
# 344                               st_tchyrs_11plus_pct
# 345                             stud_internet_comp_num
# 346                                  tchyrs_0thru3_pct
# 347                                  tchyrs_11plus_pct
# 348                                 tchyrs_4thru10_pct
# 349                                  wap_per_classroom

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC
from sklearn.linear_model import LinearRegression

Linear = LinearRegression()

Linear_selector = SelectFromModel(Linear, threshold='1.25*median', max_features=max_features)
Linear_selector.fit(X_fs, y_fs)
Linear_support = Linear_selector.get_support()
Linear_feature = X_fs.loc[:,Linear_support].columns.tolist()
print(str(len(Linear_feature)), 'selected features')
print(pd.DataFrame(Linear_feature))
# Out:
# 184 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                           0-3 Years_LEA_Exp_Pct_Prin
# 2                                              00_Size
# 3                                              01_Size
# 4                                              03_Size
# 5                                              04_Size
# 6                                              05_Size
# 7                           10+ Years_LEA_Exp_Pct_Prin
# 8                          4-10 Years_LEA_Exp_Pct_Prin
# 9                     Accomplished_TCHR_Standard 1_Pct
# 10                    Accomplished_TCHR_Standard 2_Pct
# 11                    Accomplished_TCHR_Standard 3_Pct
# 12                    Accomplished_TCHR_Standard 4_Pct
# 13                    Accomplished_TCHR_Standard 5_Pct
# 14                Alternative minimum tax Amt 25KLT50K
# 15                   Alternative minimum tax Amt LT25K
# 16                 Alternative minimum tax Ct 50KLT75K
# 17                                            Byod_Yes
# 18                               Crime_Rate_Arson_Rate
# 19                              Crime_Rate_Murder_Rate
# 20                                Crime_Rate_Rape_Rate
# 21                      Developing_TCHR_Standard 1_Pct
# 22                      Developing_TCHR_Standard 2_Pct
# 23                      Developing_TCHR_Standard 3_Pct
# 24                      Developing_TCHR_Standard 4_Pct
# 25                      Developing_TCHR_Standard 5_Pct
# 26                   Distinguished_TCHR_Standard 1_Pct
# 27                   Distinguished_TCHR_Standard 2_Pct
# 28                   Distinguished_TCHR_Standard 3_Pct
# 29                   Distinguished_TCHR_Standard 4_Pct
# 30                   Distinguished_TCHR_Standard 5_Pct
# 31   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 32   Does Not Meet Expected Growth_TCHR_Student Gro...
# 33                        EOCMathI_CACR_AmericanIndian
# 34                                EOCMathI_CACR_Female
# 35                                EOCSubjects_CACR_LEP
# 36                                 EOCSubjects_GLP_LEP
# 37                            EOG/EOCSubjects_CACR_All
# 38                            EOG/EOCSubjects_CACR_EDS
# 39                       EOG/EOCSubjects_CACR_Hispanic
# 40                            EOG/EOCSubjects_CACR_SWD
# 41                 EOG/EOCSubjects_CACR_TwoorMoreRaces
# 42                                     EOGGr3_CACR_SWD
# 43                                     EOGGr4_CACR_LEP
# 44                                     EOGGr5_CACR_All
# 45                      EOGMathGr3_CACR_AmericanIndian
# 46                                 EOGMathGr4_CACR_EDS
# 47                            EOGReadingGr3-8_CACR_SWD
# 48                             EOGReadingGr3-8_GLP_SWD
# 49                   EOGReadingGr3_CACR_AmericanIndian
# 50                   EOGReadingGr4_CACR_AmericanIndian
# 51                              EOGReadingGr4_CACR_EDS
# 52                              EOGReadingGr4_CACR_LEP
# 53                              EOGReadingGr4_CACR_SWD
# 54                               EOGReadingGr4_GLP_LEP
# 55                               EOGReadingGr4_GLP_SWD
# 56                   EOGReadingGr5_CACR_AmericanIndian
# 57                    EOGReadingGr5_GLP_AmericanIndian
# 58                 EOGScienceGr5&8_CACR_AmericanIndian
# 59                   EOGScienceGr5_CACR_AmericanIndian
# 60                               EOGScienceGr5_GLP_SWD
# 61                           EOGSubjects_CACR_Hispanic
# 62                                EOGSubjects_CACR_LEP
# 63                     EOGSubjects_CACR_TwoorMoreRaces
# 64                             EVAAS Growth Status_Met
# 65                          EVAAS Growth Status_NotMet
# 66                   Earned income credit Amt 50KLT75K
# 67         Exceeds Expected Growth_TCHR_Standard 6_Pct
# 68     Exceeds Expected Growth_TCHR_Student Growth_Pct
# 69   Excess earned income credit (refundable) Amt 5...
# 70                               Grad_project_status_Y
# 71                                    Math SPG Grade_B
# 72                                    Math SPG Grade_C
# 73                                    Math SPG Grade_D
# 74                                    Math SPG Grade_F
# 75                            MathGr3-8_pTarget_PctMet
# 76           Meets Expected Growth_TCHR_Standard 6_Pct
# 77       Meets Expected Growth_TCHR_Student Growth_Pct
# 78            Net investment income tax Amt 100KLT200K
# 79                 Not Demostrated_TCHR_Standard 1_Pct
# 80                 Not Demostrated_TCHR_Standard 2_Pct
# 81                 Not Demostrated_TCHR_Standard 4_Pct
# 82                 Not Demostrated_TCHR_Standard 5_Pct
# 83                      Proficient_TCHR_Standard 1_Pct
# 84                      Proficient_TCHR_Standard 2_Pct
# 85                      Proficient_TCHR_Standard 3_Pct
# 86                      Proficient_TCHR_Standard 4_Pct
# 87                      Proficient_TCHR_Standard 5_Pct
# 88                                 Reading SPG Grade_B
# 89                                 Reading SPG Grade_C
# 90                                 Reading SPG Grade_D
# 91                                 Reading SPG Grade_F
# 92                         ReadingGr3-8_pTarget_PctMet
# 93                              SBE District_Northeast
# 94                              SBE District_Northwest
# 95                         SBE District_Piedmont-Triad
# 96                              SBE District_Sandhills
# 97                              SBE District_Southeast
# 98                              SBE District_Southwest
# 99                                SBE District_Western
# 100                                     SPG Grade_A+NG
# 101                                        SPG Grade_B
# 102                                        SPG Grade_C
# 103                                        SPG Grade_D
# 104                                        SPG Grade_F
# 105                                        SPG Grade_I
# 106                                          SPG Score
# 107                            SciGr5&8_pTarget_PctMet
# 108                               State Gap Compared_Y
# 109                        TotalTargets_pTarget_PctMet
# 110                                 TwoOrMoreFemalePct
# 111                                   TwoOrMoreMalePct
# 112                                       TwoOrMorePct
# 113                                           WhitePct
# 114                                               Year
# 115                                 _1_to_1_access_Yes
# 116                                    advance_dgr_pct
# 117                               avg_daily_attend_pct
# 118                  calendar_type_txt_Hospital School
# 119  calendar_type_txt_Magnet School, Traditional C...
# 120  calendar_type_txt_Magnet School, Year-Round Ca...
# 121  calendar_type_txt_Regular School, Traditional ...
# 122  calendar_type_txt_Regular School, Traditional ...
# 123  calendar_type_txt_Regular School, Year-Round C...
# 124  calendar_type_txt_Special Education, Tradition...
# 125                                      category_cd_E
# 126                                      category_cd_I
# 127                                      category_cd_M
# 128                                      category_cd_T
# 129                                         closed_ind
# 130                                  digital_media_pct
# 131                                esea_attendance_Met
# 132                                      esea_status_P
# 133                                      esea_status_R
# 134                                     esea_status_RF
# 135                                 expelled_per_c_num
# 136                                flicensed_teach_pct
# 137                                 highqual_class_pct
# 138                                  lateral_teach_pct
# 139                                lea_advance_dgr_pct
# 140                           lea_ap_participation_pct
# 141                              lea_ap_pct_3_or_above
# 142                           lea_avg_daily_attend_pct
# 143                           lea_benefits_expense_pct
# 144                              lea_books_per_student
# 145                                lea_crime_per_c_num
# 146                            lea_emer_prov_teach_pct
# 147                             lea_expelled_per_c_num
# 148                            lea_flicensed_teach_pct
# 149                         lea_highqual_class_all_pct
# 150                          lea_highqual_class_hp_pct
# 151                          lea_highqual_class_lp_pct
# 152                             lea_highqual_class_pct
# 153                              lea_ib_pct_4_or_above
# 154                         lea_instruct_equip_exp_pct
# 155                            lea_long_susp_per_c_num
# 156                                      lea_nbpts_num
# 157                      lea_not_highqual_class_hp_pct
# 158                      lea_not_highqual_class_lp_pct
# 159                          lea_sat_participation_pct
# 160                         lea_stud_internet_comp_num
# 161                              lea_tchyrs_0thru3_pct
# 162                              lea_tchyrs_11plus_pct
# 163                             lea_tchyrs_4thru10_pct
# 164                              lea_wap_per_classroom
# 165                                long_susp_per_c_num
# 166                                        pct_GCE_ALL
# 167                     school_type_txt_Regular School
# 168                            st_avg_daily_attend_pct
# 169                                 st_crime_per_c_num
# 170                             st_emer_prov_teach_pct
# 171                              st_expelled_per_c_num
# 172                             st_flicensed_teach_pct
# 173                              st_highqual_class_pct
# 174                             st_long_susp_per_c_num
# 175                                       st_nbpts_num
# 176                            st_short_susp_per_c_num
# 177                               st_tchyrs_0thru3_pct
# 178                               st_tchyrs_11plus_pct
# 179                             stud_internet_comp_num
# 180                                  tchyrs_0thru3_pct
# 181                                  tchyrs_11plus_pct
# 182                                 tchyrs_4thru10_pct
# 183                                  wap_per_classroom

# %% [markdown]
# ## Lasso

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV

from sklearn.linear_model import Ridge

Lasso = LassoCV(cv = 5)

LassoCV_selector = SelectFromModel(Lasso, threshold='1.25*median', max_features=max_features)
LassoCV_selector.fit(X_fs, y_fs)
LassoCV_support = LassoCV_selector.get_support()
LassoCV_feature = X_fs.loc[:,LassoCV_support].columns.tolist()
print(str(len(LassoCV_feature)), 'selected features')
print(pd.DataFrame(LassoCV_feature))
# Out:
# 350 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                   (TCE) prepared returns Ct 25KLT50K
# 2                  (TCE) prepared returns Ct 75KLT100K
# 3                (VITA) prepared returns Ct 100KLT200K
# 4                  (VITA) prepared returns Ct 25KLT50K
# 5                  (VITA) prepared returns Ct 50KLT75K
# 6                           0-3 Years_LEA_Exp_Pct_Prin
# 7                                              00_Size
# 8                                              01_Size
# 9                                              02_Size
# 10                                             03_Size
# 11                                             04_Size
# 12                                             05_Size
# 13                          10+ Years_LEA_Exp_Pct_Prin
# 14                         4-10 Years_LEA_Exp_Pct_Prin
# 15                    Accomplished_TCHR_Standard 1_Pct
# 16                    Accomplished_TCHR_Standard 2_Pct
# 17                    Accomplished_TCHR_Standard 3_Pct
# 18                    Accomplished_TCHR_Standard 4_Pct
# 19                    Accomplished_TCHR_Standard 5_Pct
# 20                     Add Medicare tax Amt 100KLT200K
# 21                   Add child tax credit Amt 25KLT50K
# 22                  Add child tax credit Amt 75KLT100K
# 23                Alternative minimum tax Amt 25KLT50K
# 24                Alternative minimum tax Amt 50KLT75K
# 25               Alternative minimum tax Amt 75KLT100K
# 26                   Alternative minimum tax Amt LT25K
# 27                 Alternative minimum tax Ct 50KLT75K
# 28                Alternative minimum tax Ct 75KLT100K
# 29                        Attrtion_Reason_OtherReasons
# 30                                            Byod_Yes
# 31                               Crime_Rate_Arson_Rate
# 32                                 Crime_Rate_MVT_Rate
# 33                              Crime_Rate_Murder_Rate
# 34                                Crime_Rate_Rape_Rate
# 35                             Crime_Rate_Robbery_Rate
# 36                             Crime_Rate_Violent_Rate
# 37                      Developing_TCHR_Standard 1_Pct
# 38                      Developing_TCHR_Standard 2_Pct
# 39                      Developing_TCHR_Standard 3_Pct
# 40                      Developing_TCHR_Standard 4_Pct
# 41                      Developing_TCHR_Standard 5_Pct
# 42                   Distinguished_TCHR_Standard 1_Pct
# 43                   Distinguished_TCHR_Standard 2_Pct
# 44                   Distinguished_TCHR_Standard 3_Pct
# 45                   Distinguished_TCHR_Standard 4_Pct
# 46                   Distinguished_TCHR_Standard 5_Pct
# 47   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 48   Does Not Meet Expected Growth_TCHR_Student Gro...
# 49   Domestic production activities deduction Amt 1...
# 50   Domestic production activities deduction Amt 2...
# 51   Domestic production activities deduction Amt 5...
# 52   Domestic production activities deduction Amt 7...
# 53   Domestic production activities deduction Amt L...
# 54   Domestic production activities deduction Ct 25...
# 55   Domestic production activities deduction Ct 50...
# 56   Domestic production activities deduction Ct 75...
# 57   Domestic production activities deduction Ct LT25K
# 58                                   EOCMathI_CACR_AIG
# 59                        EOCMathI_CACR_AmericanIndian
# 60                                 EOCMathI_CACR_Asian
# 61                                 EOCMathI_CACR_Black
# 62                                   EOCMathI_CACR_EDS
# 63                                EOCMathI_CACR_Female
# 64                              EOCMathI_CACR_Hispanic
# 65                                   EOCMathI_CACR_LEP
# 66                                  EOCMathI_CACR_Male
# 67                                   EOCMathI_CACR_SWD
# 68                        EOCMathI_CACR_TwoorMoreRaces
# 69                                 EOCMathI_CACR_White
# 70                                    EOCMathI_GLP_LEP
# 71                                    EOCMathI_GLP_SWD
# 72                                EOCSubjects_CACR_AIG
# 73                     EOCSubjects_CACR_AmericanIndian
# 74                              EOCSubjects_CACR_Asian
# 75                              EOCSubjects_CACR_Black
# 76                           EOCSubjects_CACR_Hispanic
# 77                                EOCSubjects_CACR_LEP
# 78                                EOCSubjects_CACR_SWD
# 79                     EOCSubjects_CACR_TwoorMoreRaces
# 80                                 EOCSubjects_GLP_LEP
# 81                            EOG/EOCSubjects_CACR_AIG
# 82                            EOG/EOCSubjects_CACR_All
# 83                 EOG/EOCSubjects_CACR_AmericanIndian
# 84                          EOG/EOCSubjects_CACR_Asian
# 85                          EOG/EOCSubjects_CACR_Black
# 86                            EOG/EOCSubjects_CACR_EDS
# 87                       EOG/EOCSubjects_CACR_Hispanic
# 88                            EOG/EOCSubjects_CACR_LEP
# 89                            EOG/EOCSubjects_CACR_SWD
# 90                 EOG/EOCSubjects_CACR_TwoorMoreRaces
# 91                          EOG/EOCSubjects_CACR_White
# 92                             EOG/EOCSubjects_GLP_LEP
# 93                                     EOGGr3_CACR_AIG
# 94                                     EOGGr3_CACR_All
# 95                          EOGGr3_CACR_AmericanIndian
# 96                                   EOGGr3_CACR_Asian
# 97                                   EOGGr3_CACR_Black
# 98                                EOGGr3_CACR_Hispanic
# 99                                     EOGGr3_CACR_LEP
# 100                                    EOGGr3_CACR_SWD
# 101                         EOGGr3_CACR_TwoorMoreRaces
# 102                                  EOGGr3_CACR_White
# 103                                     EOGGr3_GLP_SWD
# 104                                    EOGGr4_CACR_AIG
# 105                                    EOGGr4_CACR_All
# 106                         EOGGr4_CACR_AmericanIndian
# 107                                  EOGGr4_CACR_Asian
# 108                                  EOGGr4_CACR_Black
# 109                                    EOGGr4_CACR_EDS
# 110                               EOGGr4_CACR_Hispanic
# 111                                    EOGGr4_CACR_LEP
# 112                                    EOGGr4_CACR_SWD
# 113                         EOGGr4_CACR_TwoorMoreRaces
# 114                                  EOGGr4_CACR_White
# 115                                     EOGGr4_GLP_LEP
# 116                                     EOGGr4_GLP_SWD
# 117                                    EOGGr5_CACR_AIG
# 118                                    EOGGr5_CACR_All
# 119                         EOGGr5_CACR_AmericanIndian
# 120                                  EOGGr5_CACR_Asian
# 121                                  EOGGr5_CACR_Black
# 122                               EOGGr5_CACR_Hispanic
# 123                                    EOGGr5_CACR_LEP
# 124                                    EOGGr5_CACR_SWD
# 125                         EOGGr5_CACR_TwoorMoreRaces
# 126                                  EOGGr5_CACR_White
# 127                              EOGMathGr3-8_CACR_AIG
# 128                   EOGMathGr3-8_CACR_AmericanIndian
# 129                            EOGMathGr3-8_CACR_Asian
# 130                            EOGMathGr3-8_CACR_Black
# 131                              EOGMathGr3-8_CACR_EDS
# 132                         EOGMathGr3-8_CACR_Hispanic
# 133                              EOGMathGr3-8_CACR_LEP
# 134                              EOGMathGr3-8_CACR_SWD
# 135                   EOGMathGr3-8_CACR_TwoorMoreRaces
# 136                            EOGMathGr3-8_CACR_White
# 137                               EOGMathGr3-8_GLP_LEP
# 138                               EOGMathGr3-8_GLP_SWD
# 139                                EOGMathGr3_CACR_AIG
# 140                     EOGMathGr3_CACR_AmericanIndian
# 141                              EOGMathGr3_CACR_Asian
# 142                              EOGMathGr3_CACR_Black
# 143                                EOGMathGr3_CACR_EDS
# 144                           EOGMathGr3_CACR_Hispanic
# 145                                EOGMathGr3_CACR_LEP
# 146                                EOGMathGr3_CACR_SWD
# 147                     EOGMathGr3_CACR_TwoorMoreRaces
# 148                              EOGMathGr3_CACR_White
# 149                                 EOGMathGr3_GLP_SWD
# 150                                EOGMathGr4_CACR_AIG
# 151                     EOGMathGr4_CACR_AmericanIndian
# 152                              EOGMathGr4_CACR_Asian
# 153                              EOGMathGr4_CACR_Black
# 154                                EOGMathGr4_CACR_EDS
# 155                           EOGMathGr4_CACR_Hispanic
# 156                                EOGMathGr4_CACR_LEP
# 157                                EOGMathGr4_CACR_SWD
# 158                     EOGMathGr4_CACR_TwoorMoreRaces
# 159                              EOGMathGr4_CACR_White
# 160                                 EOGMathGr4_GLP_LEP
# 161                                 EOGMathGr4_GLP_SWD
# 162                                EOGMathGr5_CACR_AIG
# 163                     EOGMathGr5_CACR_AmericanIndian
# 164                              EOGMathGr5_CACR_Asian
# 165                              EOGMathGr5_CACR_Black
# 166                                EOGMathGr5_CACR_EDS
# 167                           EOGMathGr5_CACR_Hispanic
# 168                                EOGMathGr5_CACR_LEP
# 169                                EOGMathGr5_CACR_SWD
# 170                     EOGMathGr5_CACR_TwoorMoreRaces
# 171                              EOGMathGr5_CACR_White
# 172                                 EOGMathGr5_GLP_SWD
# 173                EOGReadingGr3-8_CACR_AmericanIndian
# 174                         EOGReadingGr3-8_CACR_Black
# 175                           EOGReadingGr3-8_CACR_EDS
# 176                      EOGReadingGr3-8_CACR_Hispanic
# 177                           EOGReadingGr3-8_CACR_LEP
# 178                           EOGReadingGr3-8_CACR_SWD
# 179                EOGReadingGr3-8_CACR_TwoorMoreRaces
# 180                            EOGReadingGr3-8_GLP_LEP
# 181                            EOGReadingGr3-8_GLP_SWD
# 182                  EOGReadingGr3_CACR_AmericanIndian
# 183                           EOGReadingGr3_CACR_Black
# 184                             EOGReadingGr3_CACR_EDS
# 185                        EOGReadingGr3_CACR_Hispanic
# 186                             EOGReadingGr3_CACR_LEP
# 187                             EOGReadingGr3_CACR_SWD
# 188                  EOGReadingGr3_CACR_TwoorMoreRaces
# 189                              EOGReadingGr3_GLP_LEP
# 190                              EOGReadingGr3_GLP_SWD
# 191                  EOGReadingGr4_CACR_AmericanIndian
# 192                           EOGReadingGr4_CACR_Black
# 193                             EOGReadingGr4_CACR_EDS
# 194                        EOGReadingGr4_CACR_Hispanic
# 195                             EOGReadingGr4_CACR_LEP
# 196                             EOGReadingGr4_CACR_SWD
# 197                  EOGReadingGr4_CACR_TwoorMoreRaces
# 198                              EOGReadingGr4_GLP_LEP
# 199                              EOGReadingGr4_GLP_SWD
# 200                  EOGReadingGr5_CACR_AmericanIndian
# 201                           EOGReadingGr5_CACR_Black
# 202                             EOGReadingGr5_CACR_EDS
# 203                        EOGReadingGr5_CACR_Hispanic
# 204                             EOGReadingGr5_CACR_LEP
# 205                             EOGReadingGr5_CACR_SWD
# 206                  EOGReadingGr5_CACR_TwoorMoreRaces
# 207                   EOGReadingGr5_GLP_AmericanIndian
# 208                         EOGReadingGr5_GLP_Hispanic
# 209                              EOGReadingGr5_GLP_LEP
# 210                              EOGReadingGr5_GLP_SWD
# 211                           EOGScienceGr5&8_CACR_AIG
# 212                EOGScienceGr5&8_CACR_AmericanIndian
# 213                         EOGScienceGr5&8_CACR_Asian
# 214                         EOGScienceGr5&8_CACR_Black
# 215                           EOGScienceGr5&8_CACR_EDS
# 216                      EOGScienceGr5&8_CACR_Hispanic
# 217                           EOGScienceGr5&8_CACR_LEP
# 218                           EOGScienceGr5&8_CACR_SWD
# 219                EOGScienceGr5&8_CACR_TwoorMoreRaces
# 220                         EOGScienceGr5&8_CACR_White
# 221                            EOGScienceGr5&8_GLP_LEP
# 222                            EOGScienceGr5&8_GLP_SWD
# 223                  EOGScienceGr5_CACR_AmericanIndian
# 224                           EOGScienceGr5_CACR_Black
# 225                             EOGScienceGr5_CACR_EDS
# 226                        EOGScienceGr5_CACR_Hispanic
# 227                             EOGScienceGr5_CACR_LEP
# 228                             EOGScienceGr5_CACR_SWD
# 229                  EOGScienceGr5_CACR_TwoorMoreRaces
# 230                              EOGScienceGr5_GLP_LEP
# 231                              EOGScienceGr5_GLP_SWD
# 232                               EOGSubjects_CACR_AIG
# 233                    EOGSubjects_CACR_AmericanIndian
# 234                             EOGSubjects_CACR_Asian
# 235                             EOGSubjects_CACR_Black
# 236                          EOGSubjects_CACR_Hispanic
# 237                               EOGSubjects_CACR_LEP
# 238                               EOGSubjects_CACR_SWD
# 239                    EOGSubjects_CACR_TwoorMoreRaces
# 240                                EOGSubjects_GLP_LEP
# 241                                 EVAAS Growth Score
# 242                            EVAAS Growth Status_Met
# 243                         EVAAS Growth Status_NotMet
# 244                  Earned income credit Amt 50KLT75K
# 245        Exceeds Expected Growth_TCHR_Standard 6_Pct
# 246    Exceeds Expected Growth_TCHR_Student Growth_Pct
# 247  Excess earned income credit (refundable) Amt 5...
# 248                              Grad_project_status_Y
# 249                                            LEACode
# 250                                       Math I Score
# 251                                        Math I_Size
# 252                                   Math SPG Grade_B
# 253                                   Math SPG Grade_C
# 254                                   Math SPG Grade_D
# 255                                   Math SPG Grade_F
# 256                           MathGr3-8_pTarget_PctMet
# 257          Meets Expected Growth_TCHR_Standard 6_Pct
# 258      Meets Expected Growth_TCHR_Student Growth_Pct
# 259           Net investment income tax Amt 100KLT200K
# 260                Not Demostrated_TCHR_Standard 1_Pct
# 261                Not Demostrated_TCHR_Standard 2_Pct
# 262                Not Demostrated_TCHR_Standard 4_Pct
# 263                Not Demostrated_TCHR_Standard 5_Pct
# 264                  Number of farm returns 100KLT200K
# 265                    Number of farm returns 25KLT50K
# 266                    Number of farm returns 50KLT75K
# 267                   Number of farm returns 75KLT100K
# 268                         Number of farm returns All
# 269                      Number of farm returns GE200K
# 270                       Number of farm returns LT25K
# 271  Number of volunteer prepared returns Tot 50KLT75K
# 272  Partnership/S-corp net income (less loss) Amt ...
# 273                     Proficient_TCHR_Standard 1_Pct
# 274                     Proficient_TCHR_Standard 2_Pct
# 275                     Proficient_TCHR_Standard 3_Pct
# 276                     Proficient_TCHR_Standard 4_Pct
# 277                     Proficient_TCHR_Standard 5_Pct
# 278                                 Reading  SPG Score
# 279                                Reading SPG Grade_B
# 280                                Reading SPG Grade_C
# 281                                Reading SPG Grade_D
# 282                                Reading SPG Grade_F
# 283                        ReadingGr3-8_pTarget_PctMet
# 284            Residential energy tax credit Amt LT25K
# 285                             SBE District_Northeast
# 286                             SBE District_Northwest
# 287                        SBE District_Piedmont-Triad
# 288                             SBE District_Sandhills
# 289                             SBE District_Southeast
# 290                             SBE District_Southwest
# 291                               SBE District_Western
# 292                                     SPG Grade_A+NG
# 293                                        SPG Grade_B
# 294                                        SPG Grade_C
# 295                                        SPG Grade_D
# 296                                        SPG Grade_F
# 297                                        SPG Grade_I
# 298                                          SPG Score
# 299                            SciGr5&8_pTarget_PctMet
# 300                                      Science Score
# 301      Self-employment retirement plans Amt 25KLT50K
# 302                               State Gap Compared_Y
# 303     State and local general sales taxes Amt GE200K
# 304                        TotalTargets_pTarget_PctMet
# 305           Tuition and fees deduction Amt 75KLT100K
# 306                                 TwoOrMoreFemalePct
# 307                                   TwoOrMoreMalePct
# 308                                       TwoOrMorePct
# 309                                           WhitePct
# 310                                               Year
# 311                                 _1_to_1_access_Yes
# 312                                    advance_dgr_pct
# 313                           avg_age_media_collection
# 314                               avg_daily_attend_pct
# 315                                  books_per_student
# 316                  calendar_type_txt_Hospital School
# 317  calendar_type_txt_Magnet School, Traditional C...
# 318  calendar_type_txt_Magnet School, Year-Round Ca...
# 319  calendar_type_txt_Regular School, Traditional ...
# 320  calendar_type_txt_Regular School, Traditional ...
# 321  calendar_type_txt_Regular School, Year-Round C...
# 322  calendar_type_txt_Special Education, Tradition...
# 323                                      category_cd_E
# 324                                      category_cd_I
# 325                                      category_cd_M
# 326                                      category_cd_T
# 327                                         closed_ind
# 328                                    crime_per_c_num
# 329                                  digital_media_pct
# 330                                esea_attendance_Met
# 331                                      esea_status_P
# 332                                      esea_status_R
# 333                                     esea_status_RF
# 334                                 expelled_per_c_num
# 335                                flicensed_teach_pct
# 336                                 highqual_class_pct
# 337                                  lateral_teach_pct
# 338                                lea_advance_dgr_pct
# 339                           lea_ap_participation_pct
# 340                              lea_ap_pct_3_or_above
# 341                                lea_avg_student_num
# 342                           lea_federal_perpupil_num
# 343                             lea_local_perpupil_num
# 344                             lea_state_perpupil_num
# 345                              lea_total_expense_num
# 346                                        lea_wap_num
# 347                                 st_avg_student_num
# 348                                          unit_code
# 349                                         lea_salary

# %% [markdown]
# ## Ridge

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Ridge

reg = Ridge()

reg_selector = SelectFromModel(reg, threshold='1.25*median', max_features=max_features)
reg_selector.fit(X_fs, y_fs)
reg_support = reg_selector.get_support()
reg_feature = X_fs.loc[:,reg_support].columns.tolist()
print(str(len(reg_feature)), 'selected features')
print(pd.DataFrame(reg_feature))
# Out:
# 186 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                           0-3 Years_LEA_Exp_Pct_Prin
# 2                                              00_Size
# 3                                              01_Size
# 4                                              02_Size
# 5                                              03_Size
# 6                                              04_Size
# 7                                              05_Size
# 8                           10+ Years_LEA_Exp_Pct_Prin
# 9                          4-10 Years_LEA_Exp_Pct_Prin
# 10                    Accomplished_TCHR_Standard 1_Pct
# 11                    Accomplished_TCHR_Standard 2_Pct
# 12                    Accomplished_TCHR_Standard 3_Pct
# 13                    Accomplished_TCHR_Standard 4_Pct
# 14                    Accomplished_TCHR_Standard 5_Pct
# 15                Alternative minimum tax Amt 25KLT50K
# 16                Alternative minimum tax Amt 50KLT75K
# 17                   Alternative minimum tax Amt LT25K
# 18                 Alternative minimum tax Ct 50KLT75K
# 19                                            Byod_Yes
# 20                               Crime_Rate_Arson_Rate
# 21                              Crime_Rate_Murder_Rate
# 22                                Crime_Rate_Rape_Rate
# 23                      Developing_TCHR_Standard 1_Pct
# 24                      Developing_TCHR_Standard 2_Pct
# 25                      Developing_TCHR_Standard 3_Pct
# 26                      Developing_TCHR_Standard 4_Pct
# 27                      Developing_TCHR_Standard 5_Pct
# 28                   Distinguished_TCHR_Standard 1_Pct
# 29                   Distinguished_TCHR_Standard 2_Pct
# 30                   Distinguished_TCHR_Standard 3_Pct
# 31                   Distinguished_TCHR_Standard 4_Pct
# 32                   Distinguished_TCHR_Standard 5_Pct
# 33   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 34   Does Not Meet Expected Growth_TCHR_Student Gro...
# 35                        EOCMathI_CACR_AmericanIndian
# 36                                EOCMathI_CACR_Female
# 37                                    EOCMathI_GLP_SWD
# 38                                EOCSubjects_CACR_LEP
# 39                                 EOCSubjects_GLP_LEP
# 40                            EOG/EOCSubjects_CACR_All
# 41                            EOG/EOCSubjects_CACR_EDS
# 42                       EOG/EOCSubjects_CACR_Hispanic
# 43                            EOG/EOCSubjects_CACR_SWD
# 44                 EOG/EOCSubjects_CACR_TwoorMoreRaces
# 45                                     EOGGr3_CACR_All
# 46                                     EOGGr3_CACR_SWD
# 47                                     EOGGr4_CACR_LEP
# 48                                     EOGGr5_CACR_All
# 49                      EOGMathGr3_CACR_AmericanIndian
# 50                                 EOGMathGr4_CACR_EDS
# 51                            EOGReadingGr3-8_CACR_SWD
# 52                             EOGReadingGr3-8_GLP_SWD
# 53                   EOGReadingGr3_CACR_AmericanIndian
# 54                   EOGReadingGr4_CACR_AmericanIndian
# 55                              EOGReadingGr4_CACR_EDS
# 56                              EOGReadingGr4_CACR_LEP
# 57                              EOGReadingGr4_CACR_SWD
# 58                               EOGReadingGr4_GLP_LEP
# 59                               EOGReadingGr4_GLP_SWD
# 60                   EOGReadingGr5_CACR_AmericanIndian
# 61                              EOGReadingGr5_CACR_SWD
# 62                    EOGReadingGr5_GLP_AmericanIndian
# 63                 EOGScienceGr5&8_CACR_AmericanIndian
# 64                   EOGScienceGr5_CACR_AmericanIndian
# 65                           EOGSubjects_CACR_Hispanic
# 66                                EOGSubjects_CACR_LEP
# 67                     EOGSubjects_CACR_TwoorMoreRaces
# 68                             EVAAS Growth Status_Met
# 69                          EVAAS Growth Status_NotMet
# 70                   Earned income credit Amt 50KLT75K
# 71         Exceeds Expected Growth_TCHR_Standard 6_Pct
# 72     Exceeds Expected Growth_TCHR_Student Growth_Pct
# 73   Excess earned income credit (refundable) Amt 5...
# 74                               Grad_project_status_Y
# 75                                    Math SPG Grade_B
# 76                                    Math SPG Grade_C
# 77                                    Math SPG Grade_D
# 78                                    Math SPG Grade_F
# 79                            MathGr3-8_pTarget_PctMet
# 80           Meets Expected Growth_TCHR_Standard 6_Pct
# 81       Meets Expected Growth_TCHR_Student Growth_Pct
# 82                 Not Demostrated_TCHR_Standard 1_Pct
# 83                 Not Demostrated_TCHR_Standard 2_Pct
# 84                 Not Demostrated_TCHR_Standard 4_Pct
# 85                 Not Demostrated_TCHR_Standard 5_Pct
# 86                      Proficient_TCHR_Standard 1_Pct
# 87                      Proficient_TCHR_Standard 2_Pct
# 88                      Proficient_TCHR_Standard 3_Pct
# 89                      Proficient_TCHR_Standard 4_Pct
# 90                      Proficient_TCHR_Standard 5_Pct
# 91                                 Reading SPG Grade_B
# 92                                 Reading SPG Grade_C
# 93                                 Reading SPG Grade_D
# 94                                 Reading SPG Grade_F
# 95                         ReadingGr3-8_pTarget_PctMet
# 96                              SBE District_Northwest
# 97                         SBE District_Piedmont-Triad
# 98                              SBE District_Sandhills
# 99                              SBE District_Southeast
# 100                             SBE District_Southwest
# 101                               SBE District_Western
# 102                                     SPG Grade_A+NG
# 103                                        SPG Grade_B
# 104                                        SPG Grade_C
# 105                                        SPG Grade_D
# 106                                        SPG Grade_F
# 107                                        SPG Grade_I
# 108                                          SPG Score
# 109                            SciGr5&8_pTarget_PctMet
# 110                               State Gap Compared_Y
# 111                        TotalTargets_pTarget_PctMet
# 112                                 TwoOrMoreFemalePct
# 113                                   TwoOrMoreMalePct
# 114                                       TwoOrMorePct
# 115                                           WhitePct
# 116                                               Year
# 117                                 _1_to_1_access_Yes
# 118                                    advance_dgr_pct
# 119                               avg_daily_attend_pct
# 120                  calendar_type_txt_Hospital School
# 121  calendar_type_txt_Magnet School, Traditional C...
# 122  calendar_type_txt_Magnet School, Year-Round Ca...
# 123  calendar_type_txt_Regular School, Traditional ...
# 124  calendar_type_txt_Regular School, Traditional ...
# 125  calendar_type_txt_Regular School, Year-Round C...
# 126  calendar_type_txt_Special Education, Tradition...
# 127                                      category_cd_E
# 128                                      category_cd_I
# 129                                      category_cd_M
# 130                                      category_cd_T
# 131                                         closed_ind
# 132                                  digital_media_pct
# 133                                esea_attendance_Met
# 134                                      esea_status_P
# 135                                      esea_status_R
# 136                                     esea_status_RF
# 137                                 expelled_per_c_num
# 138                                flicensed_teach_pct
# 139                                 highqual_class_pct
# 140                                  lateral_teach_pct
# 141                                lea_advance_dgr_pct
# 142                           lea_ap_participation_pct
# 143                              lea_ap_pct_3_or_above
# 144                           lea_avg_daily_attend_pct
# 145                           lea_benefits_expense_pct
# 146                              lea_books_per_student
# 147                                lea_crime_per_c_num
# 148                            lea_emer_prov_teach_pct
# 149                             lea_expelled_per_c_num
# 150                            lea_flicensed_teach_pct
# 151                         lea_highqual_class_all_pct
# 152                          lea_highqual_class_hp_pct
# 153                          lea_highqual_class_lp_pct
# 154                             lea_highqual_class_pct
# 155                              lea_ib_pct_4_or_above
# 156                         lea_instruct_equip_exp_pct
# 157                            lea_long_susp_per_c_num
# 158                                      lea_nbpts_num
# 159                      lea_not_highqual_class_hp_pct
# 160                      lea_not_highqual_class_lp_pct
# 161                          lea_sat_participation_pct
# 162                         lea_stud_internet_comp_num
# 163                              lea_tchyrs_0thru3_pct
# 164                              lea_tchyrs_11plus_pct
# 165                             lea_tchyrs_4thru10_pct
# 166                              lea_wap_per_classroom
# 167                                long_susp_per_c_num
# 168                                        pct_GCE_ALL
# 169                     school_type_txt_Regular School
# 170                            st_avg_daily_attend_pct
# 171                                 st_crime_per_c_num
# 172                             st_emer_prov_teach_pct
# 173                              st_expelled_per_c_num
# 174                             st_flicensed_teach_pct
# 175                              st_highqual_class_pct
# 176                             st_long_susp_per_c_num
# 177                                       st_nbpts_num
# 178                            st_short_susp_per_c_num
# 179                               st_tchyrs_0thru3_pct
# 180                               st_tchyrs_11plus_pct
# 181                             stud_internet_comp_num
# 182                                  tchyrs_0thru3_pct
# 183                                  tchyrs_11plus_pct
# 184                                 tchyrs_4thru10_pct
# 185                                  wap_per_classroom

# %% [markdown]
# ## Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet

ELN = ElasticNet()

ELN_selector = SelectFromModel(ELN, threshold='1.25*median', max_features=max_features)
ELN_selector.fit(X_fs, y_fs)
ELN_support = ELN_selector.get_support()
ELN_feature = X_fs.loc[:,ELN_support].columns.tolist()
print(str(len(ELN_feature)), 'selected features')
print(pd.DataFrame(ELN_feature))
# Out:
# 350 selected features
#                                                      0
# 0                 (TCE) prepared returns Ct 100KLT200K
# 1                   (TCE) prepared returns Ct 25KLT50K
# 2                  (TCE) prepared returns Ct 75KLT100K
# 3                (VITA) prepared returns Ct 100KLT200K
# 4                  (VITA) prepared returns Ct 25KLT50K
# 5                  (VITA) prepared returns Ct 50KLT75K
# 6                           0-3 Years_LEA_Exp_Pct_Prin
# 7                                              00_Size
# 8                                              01_Size
# 9                                              02_Size
# 10                                             03_Size
# 11                                             04_Size
# 12                                             05_Size
# 13                          10+ Years_LEA_Exp_Pct_Prin
# 14                         4-10 Years_LEA_Exp_Pct_Prin
# 15                    Accomplished_TCHR_Standard 1_Pct
# 16                    Accomplished_TCHR_Standard 2_Pct
# 17                    Accomplished_TCHR_Standard 3_Pct
# 18                    Accomplished_TCHR_Standard 4_Pct
# 19                    Accomplished_TCHR_Standard 5_Pct
# 20                     Add Medicare tax Amt 100KLT200K
# 21                   Add child tax credit Amt 25KLT50K
# 22                  Add child tax credit Amt 75KLT100K
# 23                Alternative minimum tax Amt 25KLT50K
# 24                Alternative minimum tax Amt 50KLT75K
# 25               Alternative minimum tax Amt 75KLT100K
# 26                   Alternative minimum tax Amt LT25K
# 27                 Alternative minimum tax Ct 50KLT75K
# 28                Alternative minimum tax Ct 75KLT100K
# 29                        Attrtion_Reason_OtherReasons
# 30                                            Byod_Yes
# 31                               Crime_Rate_Arson_Rate
# 32                                 Crime_Rate_MVT_Rate
# 33                              Crime_Rate_Murder_Rate
# 34                                Crime_Rate_Rape_Rate
# 35                             Crime_Rate_Robbery_Rate
# 36                             Crime_Rate_Violent_Rate
# 37                      Developing_TCHR_Standard 1_Pct
# 38                      Developing_TCHR_Standard 2_Pct
# 39                      Developing_TCHR_Standard 3_Pct
# 40                      Developing_TCHR_Standard 4_Pct
# 41                      Developing_TCHR_Standard 5_Pct
# 42                   Distinguished_TCHR_Standard 1_Pct
# 43                   Distinguished_TCHR_Standard 2_Pct
# 44                   Distinguished_TCHR_Standard 3_Pct
# 45                   Distinguished_TCHR_Standard 4_Pct
# 46                   Distinguished_TCHR_Standard 5_Pct
# 47   Does Not Meet Expected Growth_TCHR_Standard 6_Pct
# 48   Does Not Meet Expected Growth_TCHR_Student Gro...
# 49   Domestic production activities deduction Amt 1...
# 50   Domestic production activities deduction Amt 2...
# 51   Domestic production activities deduction Amt 5...
# 52   Domestic production activities deduction Amt 7...
# 53   Domestic production activities deduction Amt L...
# 54   Domestic production activities deduction Ct 25...
# 55   Domestic production activities deduction Ct 50...
# 56   Domestic production activities deduction Ct 75...
# 57   Domestic production activities deduction Ct LT25K
# 58                                   EOCMathI_CACR_AIG
# 59                        EOCMathI_CACR_AmericanIndian
# 60                                 EOCMathI_CACR_Asian
# 61                                 EOCMathI_CACR_Black
# 62                                   EOCMathI_CACR_EDS
# 63                                EOCMathI_CACR_Female
# 64                              EOCMathI_CACR_Hispanic
# 65                                   EOCMathI_CACR_LEP
# 66                                  EOCMathI_CACR_Male
# 67                                   EOCMathI_CACR_SWD
# 68                        EOCMathI_CACR_TwoorMoreRaces
# 69                                 EOCMathI_CACR_White
# 70                                    EOCMathI_GLP_LEP
# 71                                    EOCMathI_GLP_SWD
# 72                                EOCSubjects_CACR_AIG
# 73                     EOCSubjects_CACR_AmericanIndian
# 74                              EOCSubjects_CACR_Asian
# 75                              EOCSubjects_CACR_Black
# 76                           EOCSubjects_CACR_Hispanic
# 77                                EOCSubjects_CACR_LEP
# 78                                EOCSubjects_CACR_SWD
# 79                     EOCSubjects_CACR_TwoorMoreRaces
# 80                                 EOCSubjects_GLP_LEP
# 81                            EOG/EOCSubjects_CACR_AIG
# 82                            EOG/EOCSubjects_CACR_All
# 83                 EOG/EOCSubjects_CACR_AmericanIndian
# 84                          EOG/EOCSubjects_CACR_Asian
# 85                          EOG/EOCSubjects_CACR_Black
# 86                            EOG/EOCSubjects_CACR_EDS
# 87                       EOG/EOCSubjects_CACR_Hispanic
# 88                            EOG/EOCSubjects_CACR_LEP
# 89                            EOG/EOCSubjects_CACR_SWD
# 90                 EOG/EOCSubjects_CACR_TwoorMoreRaces
# 91                          EOG/EOCSubjects_CACR_White
# 92                             EOG/EOCSubjects_GLP_LEP
# 93                                     EOGGr3_CACR_AIG
# 94                                     EOGGr3_CACR_All
# 95                          EOGGr3_CACR_AmericanIndian
# 96                                   EOGGr3_CACR_Asian
# 97                                   EOGGr3_CACR_Black
# 98                                EOGGr3_CACR_Hispanic
# 99                                     EOGGr3_CACR_LEP
# 100                                    EOGGr3_CACR_SWD
# 101                         EOGGr3_CACR_TwoorMoreRaces
# 102                                  EOGGr3_CACR_White
# 103                                     EOGGr3_GLP_SWD
# 104                                    EOGGr4_CACR_AIG
# 105                                    EOGGr4_CACR_All
# 106                         EOGGr4_CACR_AmericanIndian
# 107                                  EOGGr4_CACR_Asian
# 108                                  EOGGr4_CACR_Black
# 109                                    EOGGr4_CACR_EDS
# 110                               EOGGr4_CACR_Hispanic
# 111                                    EOGGr4_CACR_LEP
# 112                                    EOGGr4_CACR_SWD
# 113                         EOGGr4_CACR_TwoorMoreRaces
# 114                                  EOGGr4_CACR_White
# 115                                     EOGGr4_GLP_LEP
# 116                                     EOGGr4_GLP_SWD
# 117                                    EOGGr5_CACR_AIG
# 118                                    EOGGr5_CACR_All
# 119                         EOGGr5_CACR_AmericanIndian
# 120                                  EOGGr5_CACR_Asian
# 121                                  EOGGr5_CACR_Black
# 122                               EOGGr5_CACR_Hispanic
# 123                                    EOGGr5_CACR_LEP
# 124                                    EOGGr5_CACR_SWD
# 125                         EOGGr5_CACR_TwoorMoreRaces
# 126                                  EOGGr5_CACR_White
# 127                              EOGMathGr3-8_CACR_AIG
# 128                   EOGMathGr3-8_CACR_AmericanIndian
# 129                            EOGMathGr3-8_CACR_Asian
# 130                            EOGMathGr3-8_CACR_Black
# 131                              EOGMathGr3-8_CACR_EDS
# 132                         EOGMathGr3-8_CACR_Hispanic
# 133                              EOGMathGr3-8_CACR_LEP
# 134                              EOGMathGr3-8_CACR_SWD
# 135                   EOGMathGr3-8_CACR_TwoorMoreRaces
# 136                            EOGMathGr3-8_CACR_White
# 137                               EOGMathGr3-8_GLP_LEP
# 138                               EOGMathGr3-8_GLP_SWD
# 139                                EOGMathGr3_CACR_AIG
# 140                     EOGMathGr3_CACR_AmericanIndian
# 141                              EOGMathGr3_CACR_Asian
# 142                              EOGMathGr3_CACR_Black
# 143                                EOGMathGr3_CACR_EDS
# 144                           EOGMathGr3_CACR_Hispanic
# 145                                EOGMathGr3_CACR_LEP
# 146                                EOGMathGr3_CACR_SWD
# 147                     EOGMathGr3_CACR_TwoorMoreRaces
# 148                              EOGMathGr3_CACR_White
# 149                                 EOGMathGr3_GLP_SWD
# 150                                EOGMathGr4_CACR_AIG
# 151                     EOGMathGr4_CACR_AmericanIndian
# 152                              EOGMathGr4_CACR_Asian
# 153                              EOGMathGr4_CACR_Black
# 154                                EOGMathGr4_CACR_EDS
# 155                           EOGMathGr4_CACR_Hispanic
# 156                                EOGMathGr4_CACR_LEP
# 157                                EOGMathGr4_CACR_SWD
# 158                     EOGMathGr4_CACR_TwoorMoreRaces
# 159                              EOGMathGr4_CACR_White
# 160                                 EOGMathGr4_GLP_LEP
# 161                                 EOGMathGr4_GLP_SWD
# 162                                EOGMathGr5_CACR_AIG
# 163                     EOGMathGr5_CACR_AmericanIndian
# 164                              EOGMathGr5_CACR_Asian
# 165                              EOGMathGr5_CACR_Black
# 166                                EOGMathGr5_CACR_EDS
# 167                           EOGMathGr5_CACR_Hispanic
# 168                                EOGMathGr5_CACR_LEP
# 169                                EOGMathGr5_CACR_SWD
# 170                     EOGMathGr5_CACR_TwoorMoreRaces
# 171                              EOGMathGr5_CACR_White
# 172                                 EOGMathGr5_GLP_SWD
# 173                EOGReadingGr3-8_CACR_AmericanIndian
# 174                         EOGReadingGr3-8_CACR_Black
# 175                           EOGReadingGr3-8_CACR_EDS
# 176                      EOGReadingGr3-8_CACR_Hispanic
# 177                           EOGReadingGr3-8_CACR_LEP
# 178                           EOGReadingGr3-8_CACR_SWD
# 179                EOGReadingGr3-8_CACR_TwoorMoreRaces
# 180                            EOGReadingGr3-8_GLP_LEP
# 181                            EOGReadingGr3-8_GLP_SWD
# 182                  EOGReadingGr3_CACR_AmericanIndian
# 183                           EOGReadingGr3_CACR_Black
# 184                             EOGReadingGr3_CACR_EDS
# 185                        EOGReadingGr3_CACR_Hispanic
# 186                             EOGReadingGr3_CACR_LEP
# 187                             EOGReadingGr3_CACR_SWD
# 188                  EOGReadingGr3_CACR_TwoorMoreRaces
# 189                              EOGReadingGr3_GLP_LEP
# 190                              EOGReadingGr3_GLP_SWD
# 191                  EOGReadingGr4_CACR_AmericanIndian
# 192                           EOGReadingGr4_CACR_Black
# 193                             EOGReadingGr4_CACR_EDS
# 194                        EOGReadingGr4_CACR_Hispanic
# 195                             EOGReadingGr4_CACR_LEP
# 196                             EOGReadingGr4_CACR_SWD
# 197                  EOGReadingGr4_CACR_TwoorMoreRaces
# 198                              EOGReadingGr4_GLP_LEP
# 199                              EOGReadingGr4_GLP_SWD
# 200                  EOGReadingGr5_CACR_AmericanIndian
# 201                           EOGReadingGr5_CACR_Black
# 202                             EOGReadingGr5_CACR_EDS
# 203                        EOGReadingGr5_CACR_Hispanic
# 204                             EOGReadingGr5_CACR_LEP
# 205                             EOGReadingGr5_CACR_SWD
# 206                  EOGReadingGr5_CACR_TwoorMoreRaces
# 207                   EOGReadingGr5_GLP_AmericanIndian
# 208                         EOGReadingGr5_GLP_Hispanic
# 209                              EOGReadingGr5_GLP_LEP
# 210                              EOGReadingGr5_GLP_SWD
# 211                           EOGScienceGr5&8_CACR_AIG
# 212                EOGScienceGr5&8_CACR_AmericanIndian
# 213                         EOGScienceGr5&8_CACR_Asian
# 214                         EOGScienceGr5&8_CACR_Black
# 215                           EOGScienceGr5&8_CACR_EDS
# 216                      EOGScienceGr5&8_CACR_Hispanic
# 217                           EOGScienceGr5&8_CACR_LEP
# 218                           EOGScienceGr5&8_CACR_SWD
# 219                EOGScienceGr5&8_CACR_TwoorMoreRaces
# 220                         EOGScienceGr5&8_CACR_White
# 221                            EOGScienceGr5&8_GLP_LEP
# 222                            EOGScienceGr5&8_GLP_SWD
# 223                  EOGScienceGr5_CACR_AmericanIndian
# 224                           EOGScienceGr5_CACR_Black
# 225                             EOGScienceGr5_CACR_EDS
# 226                        EOGScienceGr5_CACR_Hispanic
# 227                             EOGScienceGr5_CACR_LEP
# 228                             EOGScienceGr5_CACR_SWD
# 229                  EOGScienceGr5_CACR_TwoorMoreRaces
# 230                              EOGScienceGr5_GLP_LEP
# 231                              EOGScienceGr5_GLP_SWD
# 232                               EOGSubjects_CACR_AIG
# 233                    EOGSubjects_CACR_AmericanIndian
# 234                             EOGSubjects_CACR_Asian
# 235                             EOGSubjects_CACR_Black
# 236                          EOGSubjects_CACR_Hispanic
# 237                               EOGSubjects_CACR_LEP
# 238                               EOGSubjects_CACR_SWD
# 239                    EOGSubjects_CACR_TwoorMoreRaces
# 240                                EOGSubjects_GLP_LEP
# 241                                 EVAAS Growth Score
# 242                            EVAAS Growth Status_Met
# 243                         EVAAS Growth Status_NotMet
# 244                  Earned income credit Amt 50KLT75K
# 245        Exceeds Expected Growth_TCHR_Standard 6_Pct
# 246    Exceeds Expected Growth_TCHR_Student Growth_Pct
# 247  Excess earned income credit (refundable) Amt 5...
# 248                              Grad_project_status_Y
# 249                                            LEACode
# 250                                       Math I Score
# 251                                        Math I_Size
# 252                                   Math SPG Grade_B
# 253                                   Math SPG Grade_C
# 254                                   Math SPG Grade_D
# 255                                   Math SPG Grade_F
# 256                           MathGr3-8_pTarget_PctMet
# 257          Meets Expected Growth_TCHR_Standard 6_Pct
# 258      Meets Expected Growth_TCHR_Student Growth_Pct
# 259           Net investment income tax Amt 100KLT200K
# 260                Not Demostrated_TCHR_Standard 1_Pct
# 261                Not Demostrated_TCHR_Standard 2_Pct
# 262                Not Demostrated_TCHR_Standard 4_Pct
# 263                Not Demostrated_TCHR_Standard 5_Pct
# 264                  Number of farm returns 100KLT200K
# 265                    Number of farm returns 25KLT50K
# 266                    Number of farm returns 50KLT75K
# 267                   Number of farm returns 75KLT100K
# 268                         Number of farm returns All
# 269                      Number of farm returns GE200K
# 270                       Number of farm returns LT25K
# 271  Number of volunteer prepared returns Tot 50KLT75K
# 272  Partnership/S-corp net income (less loss) Amt ...
# 273                     Proficient_TCHR_Standard 1_Pct
# 274                     Proficient_TCHR_Standard 2_Pct
# 275                     Proficient_TCHR_Standard 3_Pct
# 276                     Proficient_TCHR_Standard 4_Pct
# 277                     Proficient_TCHR_Standard 5_Pct
# 278                                 Reading  SPG Score
# 279                                Reading SPG Grade_B
# 280                                Reading SPG Grade_C
# 281                                Reading SPG Grade_D
# 282                                Reading SPG Grade_F
# 283                        ReadingGr3-8_pTarget_PctMet
# 284            Residential energy tax credit Amt LT25K
# 285                             SBE District_Northeast
# 286                             SBE District_Northwest
# 287                        SBE District_Piedmont-Triad
# 288                             SBE District_Sandhills
# 289                             SBE District_Southeast
# 290                             SBE District_Southwest
# 291                               SBE District_Western
# 292                                     SPG Grade_A+NG
# 293                                        SPG Grade_B
# 294                                        SPG Grade_C
# 295                                        SPG Grade_D
# 296                                        SPG Grade_F
# 297                                        SPG Grade_I
# 298                                          SPG Score
# 299                            SciGr5&8_pTarget_PctMet
# 300                                      Science Score
# 301      Self-employment retirement plans Amt 25KLT50K
# 302                               State Gap Compared_Y
# 303     State and local general sales taxes Amt GE200K
# 304                        TotalTargets_pTarget_PctMet
# 305           Tuition and fees deduction Amt 75KLT100K
# 306                                 TwoOrMoreFemalePct
# 307                                   TwoOrMoreMalePct
# 308                                       TwoOrMorePct
# 309                                           WhitePct
# 310                                               Year
# 311                                 _1_to_1_access_Yes
# 312                                    advance_dgr_pct
# 313                           avg_age_media_collection
# 314                               avg_daily_attend_pct
# 315                                  books_per_student
# 316                  calendar_type_txt_Hospital School
# 317  calendar_type_txt_Magnet School, Traditional C...
# 318  calendar_type_txt_Magnet School, Year-Round Ca...
# 319  calendar_type_txt_Regular School, Traditional ...
# 320  calendar_type_txt_Regular School, Traditional ...
# 321  calendar_type_txt_Regular School, Year-Round C...
# 322  calendar_type_txt_Special Education, Tradition...
# 323                                      category_cd_E
# 324                                      category_cd_I
# 325                                      category_cd_M
# 326                                      category_cd_T
# 327                                         closed_ind
# 328                                    crime_per_c_num
# 329                                  digital_media_pct
# 330                                esea_attendance_Met
# 331                                      esea_status_P
# 332                                      esea_status_R
# 333                                     esea_status_RF
# 334                                 expelled_per_c_num
# 335                                flicensed_teach_pct
# 336                                 highqual_class_pct
# 337                                  lateral_teach_pct
# 338                                lea_advance_dgr_pct
# 339                                lea_avg_student_num
# 340                           lea_federal_perpupil_num
# 341                             lea_local_perpupil_num
# 342                              lea_sat_avg_score_num
# 343                             lea_state_perpupil_num
# 344                              lea_total_expense_num
# 345                                        lea_wap_num
# 346                               short_susp_per_c_num
# 347                                 st_avg_student_num
# 348                                          unit_code
# 349                                         lea_salary

# %%
## Summary
pd.set_option('display.max_rows', None)
# put all selection together
feature_selection_df = pd.DataFrame({'Feature':feature_name
                                     , 'Pearson':cor_support
                                     , 'Linear Regression':Linear_support
                                     , 'RFE':rfe_support
                                     , 'Lasso':LassoCV_support
                                     ,'Ridge':reg_support
                                     , 'Elastic Net':ELN_support
                                     
                                    })
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] ,
ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df
# Out:
#                                                Feature  Pearson  \
# 1                                  lea_advance_dgr_pct     True
# 2                                    lateral_teach_pct     True
# 3                                   highqual_class_pct     True
# 4                                  flicensed_teach_pct     True
# 5                                        esea_status_R     True
# 6                                        esea_status_P     True
# 7                                  esea_attendance_Met     True
# 8                                        category_cd_T     True
# 9                                        category_cd_M     True
# 10                                       category_cd_I     True
# 11                                       category_cd_E     True
# 12   calendar_type_txt_Regular School, Year-Round C...     True
# 13   calendar_type_txt_Regular School, Traditional ...     True
# 14   calendar_type_txt_Regular School, Traditional ...     True
# 15   calendar_type_txt_Magnet School, Year-Round Ca...     True
# 16   calendar_type_txt_Magnet School, Traditional C...     True
# 17                                avg_daily_attend_pct     True
# 18                                     advance_dgr_pct     True
# 19                                  _1_to_1_access_Yes     True
# 20                                                Year     True
# 21                                            WhitePct     True
# 22                                    TwoOrMoreMalePct     True
# 23                         TotalTargets_pTarget_PctMet     True
# 24                                State Gap Compared_Y     True
# 25                             SciGr5&8_pTarget_PctMet     True
# 26                                           SPG Score     True
# 27                                         SPG Grade_I     True
# 28                                         SPG Grade_F     True
# 29                                         SPG Grade_D     True
# 30                                         SPG Grade_C     True
# 31                                         SPG Grade_B     True
# 32                                      SPG Grade_A+NG     True
# 33                                SBE District_Western     True
# 34                              SBE District_Southwest     True
# 35                              SBE District_Southeast     True
# 36                              SBE District_Sandhills     True
# 37                         SBE District_Piedmont-Triad     True
# 38                              SBE District_Northwest     True
# 39                         ReadingGr3-8_pTarget_PctMet     True
# 40                                 Reading SPG Grade_F     True
# 41                                 Reading SPG Grade_D     True
# 42                                 Reading SPG Grade_C     True
# 43                                 Reading SPG Grade_B     True
# 44                      Proficient_TCHR_Standard 5_Pct     True
# 45                      Proficient_TCHR_Standard 4_Pct     True
# 46                      Proficient_TCHR_Standard 3_Pct     True
# 47                      Proficient_TCHR_Standard 2_Pct     True
# 48                      Proficient_TCHR_Standard 1_Pct     True
# 49                 Not Demostrated_TCHR_Standard 4_Pct     True
# 50                 Not Demostrated_TCHR_Standard 1_Pct     True
# 51       Meets Expected Growth_TCHR_Student Growth_Pct     True
# 52                            MathGr3-8_pTarget_PctMet     True
# 53                                    Math SPG Grade_F     True
# 54                                    Math SPG Grade_D     True
# 55                                    Math SPG Grade_C     True
# 56                                    Math SPG Grade_B     True
# 57                               Grad_project_status_Y     True
# 58   Excess earned income credit (refundable) Amt 5...     True
# 59     Exceeds Expected Growth_TCHR_Student Growth_Pct     True
# 60         Exceeds Expected Growth_TCHR_Standard 6_Pct     True
# 61                          EVAAS Growth Status_NotMet     True
# 62                             EVAAS Growth Status_Met     True
# 63                     EOGSubjects_CACR_TwoorMoreRaces     True
# 64                                EOGSubjects_CACR_LEP     True
# 65                           EOGSubjects_CACR_Hispanic     True
# 66                 EOGScienceGr5&8_CACR_AmericanIndian     True
# 67                    EOGReadingGr5_GLP_AmericanIndian     True
# 68                               EOGReadingGr4_GLP_SWD     True
# 69                               EOGReadingGr4_GLP_LEP     True
# 70                              EOGReadingGr4_CACR_SWD     True
# 71                              EOGReadingGr4_CACR_LEP     True
# 72                              EOGReadingGr4_CACR_EDS     True
# 73                   EOGReadingGr4_CACR_AmericanIndian     True
# 74                             EOGReadingGr3-8_GLP_SWD     True
# 75                            EOGReadingGr3-8_CACR_SWD     True
# 76                                 EOGMathGr4_CACR_EDS     True
# 77                                     EOGGr5_CACR_All     True
# 78                                     EOGGr4_CACR_LEP     True
# 79                                     EOGGr3_CACR_SWD     True
# 80                 EOG/EOCSubjects_CACR_TwoorMoreRaces     True
# 81                            EOG/EOCSubjects_CACR_SWD     True
# 82                       EOG/EOCSubjects_CACR_Hispanic     True
# 83                            EOG/EOCSubjects_CACR_EDS     True
# 84                            EOG/EOCSubjects_CACR_All     True
# 85                                 EOCSubjects_GLP_LEP     True
# 86                                EOCSubjects_CACR_LEP     True
# 87                                EOCMathI_CACR_Female     True
# 88                        EOCMathI_CACR_AmericanIndian     True
# 89   Does Not Meet Expected Growth_TCHR_Student Gro...     True
# 90   Does Not Meet Expected Growth_TCHR_Standard 6_Pct     True
# 91                   Distinguished_TCHR_Standard 5_Pct     True
# 92                   Distinguished_TCHR_Standard 4_Pct     True
# 93                   Distinguished_TCHR_Standard 3_Pct     True
# 94                   Distinguished_TCHR_Standard 2_Pct     True
# 95                   Distinguished_TCHR_Standard 1_Pct     True
# 96                      Developing_TCHR_Standard 5_Pct     True
# 97                      Developing_TCHR_Standard 4_Pct     True
# 98                      Developing_TCHR_Standard 3_Pct     True
# 99                      Developing_TCHR_Standard 2_Pct     True
# 100                     Developing_TCHR_Standard 1_Pct     True
# 101                             Crime_Rate_Murder_Rate     True
# 102                                           Byod_Yes     True
# 103                Alternative minimum tax Ct 50KLT75K     True
# 104                  Alternative minimum tax Amt LT25K     True
# 105               Alternative minimum tax Amt 25KLT50K     True
# 106                   Accomplished_TCHR_Standard 5_Pct     True
# 107                   Accomplished_TCHR_Standard 4_Pct     True
# 108                   Accomplished_TCHR_Standard 3_Pct     True
# 109                   Accomplished_TCHR_Standard 2_Pct     True
# 110                   Accomplished_TCHR_Standard 1_Pct     True
# 111                        4-10 Years_LEA_Exp_Pct_Prin     True
# 112                         10+ Years_LEA_Exp_Pct_Prin     True
# 113                                            05_Size     True
# 114                                            04_Size     True
# 115                                            03_Size     True
# 116                                            01_Size     True
# 117                                            00_Size     True
# 118                         0-3 Years_LEA_Exp_Pct_Prin     True
# 119                              lea_ap_pct_3_or_above     True
# 120                           lea_ap_participation_pct     True
# 121                                 expelled_per_c_num    False
# 122                                     esea_status_RF    False
# 123                                  digital_media_pct    False
# 124                                         closed_ind    False
# 125  calendar_type_txt_Special Education, Tradition...    False
# 126                  calendar_type_txt_Hospital School    False
# 127                                       TwoOrMorePct    False
# 128                                 TwoOrMoreFemalePct    False
# 129                             SBE District_Northeast     True
# 130                Not Demostrated_TCHR_Standard 5_Pct    False
# 131                Not Demostrated_TCHR_Standard 2_Pct    False
# 132           Net investment income tax Amt 100KLT200K     True
# 133          Meets Expected Growth_TCHR_Standard 6_Pct    False
# 134                  Earned income credit Amt 50KLT75K    False
# 135                              EOGScienceGr5_GLP_SWD     True
# 136                  EOGScienceGr5_CACR_AmericanIndian    False
# 137                             EOGReadingGr5_CACR_SWD     True
# 138                  EOGReadingGr5_CACR_AmericanIndian    False
# 139                  EOGReadingGr3_CACR_AmericanIndian    False
# 140                     EOGMathGr3_CACR_AmericanIndian    False
# 141                                    EOGGr3_CACR_All     True
# 142                               Crime_Rate_Rape_Rate    False
# 143                              Crime_Rate_Arson_Rate    False
# 144               Alternative minimum tax Amt 50KLT75K     True
# 145                                            02_Size     True
# 146               (TCE) prepared returns Ct 100KLT200K    False
# 147                                  wap_per_classroom     True
# 148                                 tchyrs_4thru10_pct     True
# 149                                  tchyrs_11plus_pct     True
# 150                                  tchyrs_0thru3_pct     True
# 151                             stud_internet_comp_num     True
# 152                               st_tchyrs_0thru3_pct     True
# 153                            st_short_susp_per_c_num     True
# 154                                       st_nbpts_num     True
# 155                             st_long_susp_per_c_num     True
# 156                              st_highqual_class_pct     True
# 157                             st_flicensed_teach_pct     True
# 158                              st_expelled_per_c_num     True
# 159                             st_emer_prov_teach_pct     True
# 160                                 st_crime_per_c_num     True
# 161                                 st_avg_student_num     True
# 162                     school_type_txt_Regular School     True
# 163                                        pct_GCE_ALL     True
# 164                                long_susp_per_c_num     True
# 165                              lea_wap_per_classroom     True
# 166                             lea_tchyrs_4thru10_pct     True
# 167                              lea_tchyrs_11plus_pct     True
# 168                              lea_tchyrs_0thru3_pct     True
# 169                         lea_stud_internet_comp_num     True
# 170                          lea_sat_participation_pct     True
# 171                      lea_not_highqual_class_lp_pct     True
# 172                      lea_not_highqual_class_hp_pct     True
# 173                            lea_long_susp_per_c_num     True
# 174                             lea_highqual_class_pct     True
# 175                          lea_highqual_class_lp_pct     True
# 176                          lea_highqual_class_hp_pct     True
# 177                         lea_highqual_class_all_pct     True
# 178                            lea_flicensed_teach_pct     True
# 179                             lea_expelled_per_c_num     True
# 180                            lea_emer_prov_teach_pct     True
# 181                                lea_crime_per_c_num     True
# 182                              lea_books_per_student     True
# 183                           lea_benefits_expense_pct     True
# 184                           lea_avg_daily_attend_pct     True
# 185                                    crime_per_c_num     True
# 186           Tuition and fees deduction Amt 75KLT100K     True
# 187                                      Science Score     True
# 188            Residential energy tax credit Amt LT25K     True
# 189                                 Reading  SPG Score     True
# 190                       Number of farm returns LT25K     True
# 191                      Number of farm returns GE200K     True
# 192                         Number of farm returns All     True
# 193                    Number of farm returns 50KLT75K     True
# 194                    Number of farm returns 25KLT50K     True
# 195                  Number of farm returns 100KLT200K     True
# 196                                        Math I_Size     True
# 197                                       Math I Score     True
# 198                                 EVAAS Growth Score     True
# 199                                EOGSubjects_GLP_LEP     True
# 200                               EOGSubjects_CACR_SWD     True
# 201                             EOGSubjects_CACR_Black     True
# 202                             EOGSubjects_CACR_Asian     True
# 203                    EOGSubjects_CACR_AmericanIndian     True
# 204                               EOGSubjects_CACR_AIG     True
# 205                  EOGScienceGr5_CACR_TwoorMoreRaces     True
# 206                             EOGScienceGr5_CACR_EDS     True
# 207                           EOGScienceGr5_CACR_Black     True
# 208                            EOGScienceGr5&8_GLP_SWD     True
# 209                            EOGScienceGr5&8_GLP_LEP     True
# 210                         EOGScienceGr5&8_CACR_White     True
# 211                           EOGScienceGr5&8_CACR_SWD     True
# 212                           EOGScienceGr5&8_CACR_LEP     True
# 213                      EOGScienceGr5&8_CACR_Hispanic     True
# 214                           EOGScienceGr5&8_CACR_EDS     True
# 215                         EOGScienceGr5&8_CACR_Black     True
# 216                           EOGScienceGr5&8_CACR_AIG     True
# 217                              EOGReadingGr5_GLP_SWD     True
# 218                         EOGReadingGr5_GLP_Hispanic     True
# 219                  EOGReadingGr5_CACR_TwoorMoreRaces     True
# 220                             EOGReadingGr5_CACR_LEP     True
# 221                             EOGReadingGr5_CACR_EDS     True
# 222                           EOGReadingGr5_CACR_Black     True
# 223                  EOGReadingGr4_CACR_TwoorMoreRaces     True
# 224                        EOGReadingGr4_CACR_Hispanic     True
# 225                           EOGReadingGr4_CACR_Black     True
# 226                              EOGReadingGr3_GLP_SWD     True
# 227                              EOGReadingGr3_GLP_LEP     True
# 228                  EOGReadingGr3_CACR_TwoorMoreRaces     True
# 229                             EOGReadingGr3_CACR_SWD     True
# 230                             EOGReadingGr3_CACR_LEP     True
# 231                        EOGReadingGr3_CACR_Hispanic     True
# 232                             EOGReadingGr3_CACR_EDS     True
# 233                           EOGReadingGr3_CACR_Black     True
# 234                            EOGReadingGr3-8_GLP_LEP     True
# 235                EOGReadingGr3-8_CACR_TwoorMoreRaces     True
# 236                           EOGReadingGr3-8_CACR_LEP     True
# 237                      EOGReadingGr3-8_CACR_Hispanic     True
# 238                           EOGReadingGr3-8_CACR_EDS     True
# 239                         EOGReadingGr3-8_CACR_Black     True
# 240                EOGReadingGr3-8_CACR_AmericanIndian     True
# 241                                 EOGMathGr5_GLP_SWD     True
# 242                              EOGMathGr5_CACR_White     True
# 243                                EOGMathGr5_CACR_SWD     True
# 244                           EOGMathGr5_CACR_Hispanic     True
# 245                                EOGMathGr5_CACR_EDS     True
# 246                              EOGMathGr5_CACR_Black     True
# 247                                EOGMathGr5_CACR_AIG     True
# 248                                 EOGMathGr4_GLP_SWD     True
# 249                                 EOGMathGr4_GLP_LEP     True
# 250                     EOGMathGr4_CACR_TwoorMoreRaces     True
# 251                                EOGMathGr4_CACR_SWD     True
# 252                           EOGMathGr4_CACR_Hispanic     True
# 253                              EOGMathGr4_CACR_Black     True
# 254                              EOGMathGr4_CACR_Asian     True
# 255                                EOGMathGr4_CACR_AIG     True
# 256                                 EOGMathGr3_GLP_SWD     True
# 257                              EOGMathGr3_CACR_White     True
# 258                     EOGMathGr3_CACR_TwoorMoreRaces     True
# 259                                EOGMathGr3_CACR_SWD     True
# 260                                EOGMathGr3_CACR_LEP     True
# 261                           EOGMathGr3_CACR_Hispanic     True
# 262                                EOGMathGr3_CACR_EDS     True
# 263                               EOGMathGr3-8_GLP_SWD     True
# 264                               EOGMathGr3-8_GLP_LEP     True
# 265                            EOGMathGr3-8_CACR_White     True
# 266                   EOGMathGr3-8_CACR_TwoorMoreRaces     True
# 267                              EOGMathGr3-8_CACR_SWD     True
# 268                              EOGMathGr3-8_CACR_LEP     True
# 269                         EOGMathGr3-8_CACR_Hispanic     True
# 270                              EOGMathGr3-8_CACR_EDS     True
# 271                            EOGMathGr3-8_CACR_Black     True
# 272                            EOGMathGr3-8_CACR_Asian     True
# 273                   EOGMathGr3-8_CACR_AmericanIndian     True
# 274                              EOGMathGr3-8_CACR_AIG     True
# 275                                  EOGGr5_CACR_White     True
# 276                         EOGGr5_CACR_TwoorMoreRaces     True
# 277                                    EOGGr5_CACR_SWD     True
# 278                                    EOGGr5_CACR_LEP     True
# 279                                  EOGGr5_CACR_Black     True
# 280                                     EOGGr4_GLP_SWD     True
# 281                                     EOGGr4_GLP_LEP     True
# 282                                  EOGGr4_CACR_White     True
# 283                         EOGGr4_CACR_TwoorMoreRaces     True
# 284                                    EOGGr4_CACR_SWD     True
# 285                               EOGGr4_CACR_Hispanic     True
# 286                                    EOGGr4_CACR_EDS     True
# 287                                  EOGGr4_CACR_Black     True
# 288                                  EOGGr4_CACR_Asian     True
# 289                                     EOGGr3_GLP_SWD     True
# 290                                  EOGGr3_CACR_White     True
# 291                         EOGGr3_CACR_TwoorMoreRaces     True
# 292                                    EOGGr3_CACR_LEP     True
# 293                               EOGGr3_CACR_Hispanic     True
# 294                                  EOGGr3_CACR_Black     True
# 295                                  EOGGr3_CACR_Asian     True
# 296                            EOG/EOCSubjects_GLP_LEP     True
# 297                         EOG/EOCSubjects_CACR_White     True
# 298                           EOG/EOCSubjects_CACR_LEP     True
# 299                         EOG/EOCSubjects_CACR_Black     True
# 300                         EOG/EOCSubjects_CACR_Asian     True
# 301                EOG/EOCSubjects_CACR_AmericanIndian     True
# 302                           EOG/EOCSubjects_CACR_AIG     True
# 303                    EOCSubjects_CACR_TwoorMoreRaces     True
# 304                             EOCSubjects_CACR_Black     True
# 305                    EOCSubjects_CACR_AmericanIndian     True
# 306                                   EOCMathI_GLP_SWD    False
# 307                                   EOCMathI_GLP_LEP     True
# 308                                 EOCMathI_CACR_Male     True
# 309                                  EOCMathI_CACR_LEP     True
# 310                             EOCMathI_CACR_Hispanic     True
# 311                                  EOCMathI_CACR_EDS     True
# 312                                EOCMathI_CACR_Black     True
# 313  Domestic production activities deduction Ct LT25K     True
# 314  Domestic production activities deduction Ct 75...     True
# 315  Domestic production activities deduction Ct 50...     True
# 316  Domestic production activities deduction Ct 25...     True
# 317  Domestic production activities deduction Amt L...     True
# 318  Domestic production activities deduction Amt 7...     True
# 319  Domestic production activities deduction Amt 2...     True
# 320                            Crime_Rate_Violent_Rate     True
# 321                            Crime_Rate_Robbery_Rate     True
# 322                                Crime_Rate_MVT_Rate     True
# 323                       Attrtion_Reason_OtherReasons     True
# 324                 Add child tax credit Amt 75KLT100K     True
# 325                    Add Medicare tax Amt 100KLT200K     True
# 326              (VITA) prepared returns Ct 100KLT200K     True
# 327                (TCE) prepared returns Ct 75KLT100K     True
# 328                                          unit_code     True
# 329                               st_tchyrs_11plus_pct    False
# 330                            st_avg_daily_attend_pct    False
# 331                                        lea_wap_num     True
# 332                              lea_total_expense_num     True
# 333                             lea_state_perpupil_num     True
# 334                              lea_sat_avg_score_num     True
# 335                                         lea_salary     True
# 336                                      lea_nbpts_num     True
# 337                             lea_local_perpupil_num     True
# 338                         lea_instruct_equip_exp_pct    False
# 339                              lea_ib_pct_4_or_above    False
# 340                           lea_federal_perpupil_num     True
# 341                                lea_avg_student_num    False
# 342                           avg_age_media_collection     True
# 343     State and local general sales taxes Amt GE200K    False
# 344      Self-employment retirement plans Amt 25KLT50K     True
# 345  Partnership/S-corp net income (less loss) Amt ...     True
# 346                   Number of farm returns 75KLT100K     True
# 347                                            LEACode     True
# 348                             EOGScienceGr5_CACR_SWD     True
# 349                             EOGScienceGr5_CACR_LEP    False
# 350                        EOGScienceGr5_CACR_Hispanic     True
# 351                         EOGScienceGr5&8_CACR_Asian     True
# 352                        EOGReadingGr5_CACR_Hispanic     True
# 353                     EOGMathGr5_CACR_TwoorMoreRaces     True
# 354                                EOGMathGr5_CACR_LEP    False
# 355                              EOGMathGr5_CACR_Asian     True
# 356                     EOGMathGr5_CACR_AmericanIndian    False
# 357                              EOGMathGr4_CACR_White     True
# 358                                EOGMathGr4_CACR_LEP     True
# 359                     EOGMathGr4_CACR_AmericanIndian    False
# 360                              EOGMathGr3_CACR_Black     True
# 361                              EOGMathGr3_CACR_Asian     True
# 362                                EOGMathGr3_CACR_AIG     True
# 363                               EOGGr5_CACR_Hispanic     True
# 364                                  EOGGr5_CACR_Asian     True
# 365                         EOGGr5_CACR_AmericanIndian    False
# 366                                    EOGGr5_CACR_AIG     True
# 367                         EOGGr4_CACR_AmericanIndian    False
# 368                                    EOGGr4_CACR_All     True
# 369                                    EOGGr4_CACR_AIG     True
# 370                         EOGGr3_CACR_AmericanIndian    False
# 371                                    EOGGr3_CACR_AIG     True
# 372                               EOCSubjects_CACR_SWD    False
# 373                          EOCSubjects_CACR_Hispanic     True
# 374                             EOCSubjects_CACR_Asian    False
# 375                                EOCMathI_CACR_White    False
# 376                       EOCMathI_CACR_TwoorMoreRaces    False
# 377                                  EOCMathI_CACR_SWD    False
# 378                                EOCMathI_CACR_Asian    False
# 379                                  EOCMathI_CACR_AIG     True
# 380  Domestic production activities deduction Amt 5...     True
# 381  Domestic production activities deduction Amt 1...     True
# 382               Alternative minimum tax Ct 75KLT100K    False
# 383              Alternative minimum tax Amt 75KLT100K    False
# 384                  Add child tax credit Amt 25KLT50K     True
# 385                (VITA) prepared returns Ct 50KLT75K     True
# 386                (VITA) prepared returns Ct 25KLT50K     True
# 387                 (TCE) prepared returns Ct 25KLT50K     True
# 388                               short_susp_per_c_num     True
# 389                                          nbpts_num     True
# 390                                  books_per_student    False
# 391  Number of volunteer prepared returns Tot 50KLT75K    False
# 392                              EOGScienceGr5_GLP_LEP    False
# 393                EOGScienceGr5&8_CACR_TwoorMoreRaces    False
# 394                              EOGReadingGr5_GLP_LEP    False
# 395                               EOCSubjects_CACR_AIG    False
# 396                                        student_num     True
# 397                           lea_short_susp_per_c_num     True
# 398                                            wap_num    False
#
#      Linear Regression    RFE  Lasso  Ridge  Elastic Net  Total
# 1                 True   True   True   True         True      6
# 2                 True   True   True   True         True      6
# 3                 True   True   True   True         True      6
# 4                 True   True   True   True         True      6
# 5                 True   True   True   True         True      6
# 6                 True   True   True   True         True      6
# 7                 True   True   True   True         True      6
# 8                 True   True   True   True         True      6
# 9                 True   True   True   True         True      6
# 10                True   True   True   True         True      6
# 11                True   True   True   True         True      6
# 12                True   True   True   True         True      6
# 13                True   True   True   True         True      6
# 14                True   True   True   True         True      6
# 15                True   True   True   True         True      6
# 16                True   True   True   True         True      6
# 17                True   True   True   True         True      6
# 18                True   True   True   True         True      6
# 19                True   True   True   True         True      6
# 20                True   True   True   True         True      6
# 21                True   True   True   True         True      6
# 22                True   True   True   True         True      6
# 23                True   True   True   True         True      6
# 24                True   True   True   True         True      6
# 25                True   True   True   True         True      6
# 26                True   True   True   True         True      6
# 27                True   True   True   True         True      6
# 28                True   True   True   True         True      6
# 29                True   True   True   True         True      6
# 30                True   True   True   True         True      6
# 31                True   True   True   True         True      6
# 32                True   True   True   True         True      6
# 33                True   True   True   True         True      6
# 34                True   True   True   True         True      6
# 35                True   True   True   True         True      6
# 36                True   True   True   True         True      6
# 37                True   True   True   True         True      6
# 38                True   True   True   True         True      6
# 39                True   True   True   True         True      6
# 40                True   True   True   True         True      6
# 41                True   True   True   True         True      6
# 42                True   True   True   True         True      6
# 43                True   True   True   True         True      6
# 44                True   True   True   True         True      6
# 45                True   True   True   True         True      6
# 46                True   True   True   True         True      6
# 47                True   True   True   True         True      6
# 48                True   True   True   True         True      6
# 49                True   True   True   True         True      6
# 50                True   True   True   True         True      6
# 51                True   True   True   True         True      6
# 52                True   True   True   True         True      6
# 53                True   True   True   True         True      6
# 54                True   True   True   True         True      6
# 55                True   True   True   True         True      6
# 56                True   True   True   True         True      6
# 57                True   True   True   True         True      6
# 58                True   True   True   True         True      6
# 59                True   True   True   True         True      6
# 60                True   True   True   True         True      6
# 61                True   True   True   True         True      6
# 62                True   True   True   True         True      6
# 63                True   True   True   True         True      6
# 64                True   True   True   True         True      6
# 65                True   True   True   True         True      6
# 66                True   True   True   True         True      6
# 67                True   True   True   True         True      6
# 68                True   True   True   True         True      6
# 69                True   True   True   True         True      6
# 70                True   True   True   True         True      6
# 71                True   True   True   True         True      6
# 72                True   True   True   True         True      6
# 73                True   True   True   True         True      6
# 74                True   True   True   True         True      6
# 75                True   True   True   True         True      6
# 76                True   True   True   True         True      6
# 77                True   True   True   True         True      6
# 78                True   True   True   True         True      6
# 79                True   True   True   True         True      6
# 80                True   True   True   True         True      6
# 81                True   True   True   True         True      6
# 82                True   True   True   True         True      6
# 83                True   True   True   True         True      6
# 84                True   True   True   True         True      6
# 85                True   True   True   True         True      6
# 86                True   True   True   True         True      6
# 87                True   True   True   True         True      6
# 88                True   True   True   True         True      6
# 89                True   True   True   True         True      6
# 90                True   True   True   True         True      6
# 91                True   True   True   True         True      6
# 92                True   True   True   True         True      6
# 93                True   True   True   True         True      6
# 94                True   True   True   True         True      6
# 95                True   True   True   True         True      6
# 96                True   True   True   True         True      6
# 97                True   True   True   True         True      6
# 98                True   True   True   True         True      6
# 99                True   True   True   True         True      6
# 100               True   True   True   True         True      6
# 101               True   True   True   True         True      6
# 102               True   True   True   True         True      6
# 103               True   True   True   True         True      6
# 104               True   True   True   True         True      6
# 105               True   True   True   True         True      6
# 106               True   True   True   True         True      6
# 107               True   True   True   True         True      6
# 108               True   True   True   True         True      6
# 109               True   True   True   True         True      6
# 110               True   True   True   True         True      6
# 111               True   True   True   True         True      6
# 112               True   True   True   True         True      6
# 113               True   True   True   True         True      6
# 114               True   True   True   True         True      6
# 115               True   True   True   True         True      6
# 116               True   True   True   True         True      6
# 117               True   True   True   True         True      6
# 118               True   True   True   True         True      6
# 119               True   True   True   True        False      5
# 120               True   True   True   True        False      5
# 121               True   True   True   True         True      5
# 122               True   True   True   True         True      5
# 123               True   True   True   True         True      5
# 124               True   True   True   True         True      5
# 125               True   True   True   True         True      5
# 126               True   True   True   True         True      5
# 127               True   True   True   True         True      5
# 128               True   True   True   True         True      5
# 129               True   True   True  False         True      5
# 130               True   True   True   True         True      5
# 131               True   True   True   True         True      5
# 132               True   True   True  False         True      5
# 133               True   True   True   True         True      5
# 134               True   True   True   True         True      5
# 135               True   True   True  False         True      5
# 136               True   True   True   True         True      5
# 137              False   True   True   True         True      5
# 138               True   True   True   True         True      5
# 139               True   True   True   True         True      5
# 140               True   True   True   True         True      5
# 141              False   True   True   True         True      5
# 142               True   True   True   True         True      5
# 143               True   True   True   True         True      5
# 144              False   True   True   True         True      5
# 145              False   True   True   True         True      5
# 146               True   True   True   True         True      5
# 147               True   True  False   True        False      4
# 148               True   True  False   True        False      4
# 149               True   True  False   True        False      4
# 150               True   True  False   True        False      4
# 151               True   True  False   True        False      4
# 152               True   True  False   True        False      4
# 153               True   True  False   True        False      4
# 154               True   True  False   True        False      4
# 155               True   True  False   True        False      4
# 156               True   True  False   True        False      4
# 157               True   True  False   True        False      4
# 158               True   True  False   True        False      4
# 159               True   True  False   True        False      4
# 160               True   True  False   True        False      4
# 161              False   True   True  False         True      4
# 162               True   True  False   True        False      4
# 163               True   True  False   True        False      4
# 164               True   True  False   True        False      4
# 165               True   True  False   True        False      4
# 166               True   True  False   True        False      4
# 167               True   True  False   True        False      4
# 168               True   True  False   True        False      4
# 169               True   True  False   True        False      4
# 170               True   True  False   True        False      4
# 171               True   True  False   True        False      4
# 172               True   True  False   True        False      4
# 173               True   True  False   True        False      4
# 174               True   True  False   True        False      4
# 175               True   True  False   True        False      4
# 176               True   True  False   True        False      4
# 177               True   True  False   True        False      4
# 178               True   True  False   True        False      4
# 179               True   True  False   True        False      4
# 180               True   True  False   True        False      4
# 181               True   True  False   True        False      4
# 182               True   True  False   True        False      4
# 183               True   True  False   True        False      4
# 184               True   True  False   True        False      4
# 185              False   True   True  False         True      4
# 186              False   True   True  False         True      4
# 187              False   True   True  False         True      4
# 188              False   True   True  False         True      4
# 189              False   True   True  False         True      4
# 190              False   True   True  False         True      4
# 191              False   True   True  False         True      4
# 192              False   True   True  False         True      4
# 193              False   True   True  False         True      4
# 194              False   True   True  False         True      4
# 195              False   True   True  False         True      4
# 196              False   True   True  False         True      4
# 197              False   True   True  False         True      4
# 198              False   True   True  False         True      4
# 199              False   True   True  False         True      4
# 200              False   True   True  False         True      4
# 201              False   True   True  False         True      4
# 202              False   True   True  False         True      4
# 203              False   True   True  False         True      4
# 204              False   True   True  False         True      4
# 205              False   True   True  False         True      4
# 206              False   True   True  False         True      4
# 207              False   True   True  False         True      4
# 208              False   True   True  False         True      4
# 209              False   True   True  False         True      4
# 210              False   True   True  False         True      4
# 211              False   True   True  False         True      4
# 212              False   True   True  False         True      4
# 213              False   True   True  False         True      4
# 214              False   True   True  False         True      4
# 215              False   True   True  False         True      4
# 216              False   True   True  False         True      4
# 217              False   True   True  False         True      4
# 218              False   True   True  False         True      4
# 219              False   True   True  False         True      4
# 220              False   True   True  False         True      4
# 221              False   True   True  False         True      4
# 222              False   True   True  False         True      4
# 223              False   True   True  False         True      4
# 224              False   True   True  False         True      4
# 225              False   True   True  False         True      4
# 226              False   True   True  False         True      4
# 227              False   True   True  False         True      4
# 228              False   True   True  False         True      4
# 229              False   True   True  False         True      4
# 230              False   True   True  False         True      4
# 231              False   True   True  False         True      4
# 232              False   True   True  False         True      4
# 233              False   True   True  False         True      4
# 234              False   True   True  False         True      4
# 235              False   True   True  False         True      4
# 236              False   True   True  False         True      4
# 237              False   True   True  False         True      4
# 238              False   True   True  False         True      4
# 239              False   True   True  False         True      4
# 240              False   True   True  False         True      4
# 241              False   True   True  False         True      4
# 242              False   True   True  False         True      4
# 243              False   True   True  False         True      4
# 244              False   True   True  False         True      4
# 245              False   True   True  False         True      4
# 246              False   True   True  False         True      4
# 247              False   True   True  False         True      4
# 248              False   True   True  False         True      4
# 249              False   True   True  False         True      4
# 250              False   True   True  False         True      4
# 251              False   True   True  False         True      4
# 252              False   True   True  False         True      4
# 253              False   True   True  False         True      4
# 254              False   True   True  False         True      4
# 255              False   True   True  False         True      4
# 256              False   True   True  False         True      4
# 257              False   True   True  False         True      4
# 258              False   True   True  False         True      4
# 259              False   True   True  False         True      4
# 260              False   True   True  False         True      4
# 261              False   True   True  False         True      4
# 262              False   True   True  False         True      4
# 263              False   True   True  False         True      4
# 264              False   True   True  False         True      4
# 265              False   True   True  False         True      4
# 266              False   True   True  False         True      4
# 267              False   True   True  False         True      4
# 268              False   True   True  False         True      4
# 269              False   True   True  False         True      4
# 270              False   True   True  False         True      4
# 271              False   True   True  False         True      4
# 272              False   True   True  False         True      4
# 273              False   True   True  False         True      4
# 274              False   True   True  False         True      4
# 275              False   True   True  False         True      4
# 276              False   True   True  False         True      4
# 277              False   True   True  False         True      4
# 278              False   True   True  False         True      4
# 279              False   True   True  False         True      4
# 280              False   True   True  False         True      4
# 281              False   True   True  False         True      4
# 282              False   True   True  False         True      4
# 283              False   True   True  False         True      4
# 284              False   True   True  False         True      4
# 285              False   True   True  False         True      4
# 286              False   True   True  False         True      4
# 287              False   True   True  False         True      4
# 288              False   True   True  False         True      4
# 289              False   True   True  False         True      4
# 290              False   True   True  False         True      4
# 291              False   True   True  False         True      4
# 292              False   True   True  False         True      4
# 293              False   True   True  False         True      4
# 294              False   True   True  False         True      4
# 295              False   True   True  False         True      4
# 296              False   True   True  False         True      4
# 297              False   True   True  False         True      4
# 298              False   True   True  False         True      4
# 299              False   True   True  False         True      4
# 300              False   True   True  False         True      4
# 301              False   True   True  False         True      4
# 302              False   True   True  False         True      4
# 303              False   True   True  False         True      4
# 304              False   True   True  False         True      4
# 305              False   True   True  False         True      4
# 306              False   True   True   True         True      4
# 307              False   True   True  False         True      4
# 308              False   True   True  False         True      4
# 309              False   True   True  False         True      4
# 310              False   True   True  False         True      4
# 311              False   True   True  False         True      4
# 312              False   True   True  False         True      4
# 313              False   True   True  False         True      4
# 314              False   True   True  False         True      4
# 315              False   True   True  False         True      4
# 316              False   True   True  False         True      4
# 317              False   True   True  False         True      4
# 318              False   True   True  False         True      4
# 319              False   True   True  False         True      4
# 320              False   True   True  False         True      4
# 321              False   True   True  False         True      4
# 322              False   True   True  False         True      4
# 323              False   True   True  False         True      4
# 324              False   True   True  False         True      4
# 325              False   True   True  False         True      4
# 326              False   True   True  False         True      4
# 327              False   True   True  False         True      4
# 328              False  False   True  False         True      3
# 329               True   True  False   True        False      3
# 330               True   True  False   True        False      3
# 331              False  False   True  False         True      3
# 332              False  False   True  False         True      3
# 333              False  False   True  False         True      3
# 334              False   True  False  False         True      3
# 335              False  False   True  False         True      3
# 336               True  False  False   True        False      3
# 337              False  False   True  False         True      3
# 338               True   True  False   True        False      3
# 339               True   True  False   True        False      3
# 340              False  False   True  False         True      3
# 341              False   True   True  False         True      3
# 342              False  False   True  False         True      3
# 343              False   True   True  False         True      3
# 344              False  False   True  False         True      3
# 345              False  False   True  False         True      3
# 346              False  False   True  False         True      3
# 347              False  False   True  False         True      3
# 348              False  False   True  False         True      3
# 349              False   True   True  False         True      3
# 350              False  False   True  False         True      3
# 351              False  False   True  False         True      3
# 352              False  False   True  False         True      3
# 353              False  False   True  False         True      3
# 354              False   True   True  False         True      3
# 355              False  False   True  False         True      3
# 356              False   True   True  False         True      3
# 357              False  False   True  False         True      3
# 358              False  False   True  False         True      3
# 359              False   True   True  False         True      3
# 360              False  False   True  False         True      3
# 361              False  False   True  False         True      3
# 362              False  False   True  False         True      3
# 363              False  False   True  False         True      3
# 364              False  False   True  False         True      3
# 365              False   True   True  False         True      3
# 366              False  False   True  False         True      3
# 367              False   True   True  False         True      3
# 368              False  False   True  False         True      3
# 369              False  False   True  False         True      3
# 370              False   True   True  False         True      3
# 371              False  False   True  False         True      3
# 372              False   True   True  False         True      3
# 373              False  False   True  False         True      3
# 374              False   True   True  False         True      3
# 375              False   True   True  False         True      3
# 376              False   True   True  False         True      3
# 377              False   True   True  False         True      3
# 378              False   True   True  False         True      3
# 379              False  False   True  False         True      3
# 380              False  False   True  False         True      3
# 381              False  False   True  False         True      3
# 382              False   True   True  False         True      3
# 383              False   True   True  False         True      3
# 384              False  False   True  False         True      3
# 385              False  False   True  False         True      3
# 386              False  False   True  False         True      3
# 387              False  False   True  False         True      3
# 388              False  False  False  False         True      2
# 389              False   True  False  False        False      2
# 390              False  False   True  False         True      2
# 391              False  False   True  False         True      2
# 392              False  False   True  False         True      2
# 393              False  False   True  False         True      2
# 394              False  False   True  False         True      2
# 395              False  False   True  False         True      2
# 396              False  False  False  False        False      1
# 397              False  False  False  False        False      1
# 398              False  False  False  False        False      0

# %%
# export feature selection to csv file
feature_selection_df.to_csv('Feature_Selection_Results.csv', sep=',', index=False)

# %%
feature_to_remove = feature_selection_df[feature_selection_df['Total']<3]['Feature']

#feature_to_remove
print ('\r\nFeatures Deleted: ', len(feature_to_remove))
# Out:
# Features Deleted:  11

# %%
X = X.drop(feature_to_remove, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns not Selected by Feature Selection******')
X.info(verbose=False)
print ('\r\nColumns Deleted: ', len(feature_to_remove))
# Out:
# *********After: Removing columns not Selected by Feature Selection******
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Columns: 387 entries, (TCE) prepared returns Ct 100KLT200K to lea_salary
# dtypes: float64(368), int64(19)
# memory usage: 28.8 MB
#
# Columns Deleted:  11

# %% [markdown]
# ## Transformation

# %%
# Transform

saved_cols = X.columns

scaler = StandardScaler()
X = scaler.fit_transform(X)
#Save as data frames
X = pd.DataFrame(X)
X.columns = saved_cols
# Out:
# C:\Users\yubin\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\yubin\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# %%time

# df2_vif = pd.DataFrame()
# df2_vif["VIF Factor"] = [vif(X.values, i) for i in range(X.shape[1])]
# df2_vif["ABSVIFFactor"] = abs(df2_vif["VIF Factor"])
# df2_vif["features"] = X.columns
# df2_vif["indexes"] = range(0, len(X.columns))

# %%
# df2_vif = df2_vif.sort_values('ABSVIFFactor', ascending=True)
# df2_vif.to_csv('VIF_Result_ML.csv', sep=',', index=False)

# %%
# Create Cross Validation Object with 10 folds with 80/20 train - test split
# cv = ShuffleSplit(n_splits = 10, test_size=0.20, random_state=0)

# %%
# %%time



# X_train, X_test, y_train, y_test = train_test_split(X, y, 
#     test_size=0.3,random_state =1 )

# #print("RFE CV Linear Regression 1st Pass")
# rfecvEstimator = LinearRegression()

# parameters = { 'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}

# #Create a grid search object  

# grid = GridSearchCV(estimator=rfecvEstimator
#                    #, n_jobs=8 # jobs to run in parallel
#                    #, verbose=0 # low verbosity
#                    , param_grid=parameters
#                   )

# #Perform hyperparameter search to find the best combination of parameters for our data using RFECV
# grid.fit(X_train, y_train)
# print("r2 / variance : ", grid.best_score_)
# print("Residual sum of squares: %.2f"
#               % np.mean((grid.predict(X_test) - y_test) ** 2))

# %%
# %%time


# #print("RFE CV Linear Regression 1st Pass")
# rfecvEstimator = LinearRegression()

# parameters = { 'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]
#              }

# #Create a grid search object  
# from sklearn.model_selection import GridSearchCV
# rfecvGridSearch = GridSearchCV(estimator=rfecvEstimator
# #                    , n_jobs=8 # jobs to run in parallel
# #                    , verbose=0 # low verbosity
#                    , param_grid=parameters
#                    , cv=cv # KFolds = 10
#                    )

# #Perform hyperparameter search to find the best combination of parameters for our data using RFECV
# rfecvGridSearch.fit(X, y)

# #Use the best parameters for our RFECV Linear Regression object
# rfecvClassifierEst = rfecvGridSearch.best_estimator_

# #Recursive Feature Elimination
# rfecv = RFECV(estimator=rfecvClassifierEst, step=1, cv=cv,  verbose=1)
# X_BestFeatures = rfecv.fit_transform(X, y)

# #Print RFECV Details
# print("Ranking", rfecv.ranking_)
# print("Support", rfecv.support_)
# print("Number of Features:", rfecv.n_features_)

# #print("Linear Regression Second Pass")
# # #create a pipeline to scale all of the data and perform logistic regression during each grid search step.
# # pipe = make_pipeline(StandardScaler(), LinearRegression())

# # #Define a range of hyper parameters for grid search
# # parameters = { 'linearregression__fit_intercept':[True,False], 'LinearRegression__normalize':[True,False]
# #               , 'LinearRegression__copy_X':[True, False]
# #               , 'linearregression__n_jobs':[None]
# #              }

# # #Perform the grid search using accuracy as a metric during cross validation.
# # grid = GridSearchCV(estimator=pipe, param_grid=parameters, cv=cv)

# # #Use the best features from recursive feature elimination during the grid search
# # grid.fit(X, y)

# %% [markdown]
# ## Cross Validation
# **Cross validation is performed using repeated holdout using ShuffleSplit()**
# * Ten folds are used
# * The split is: 90% training data and 10% test data
# * A random seed is set so the same random test and training splits are used each time cross validation is performed.

# %%
#Divide data into test and training splits
from sklearn.model_selection import ShuffleSplit
cv = ShuffleSplit(n_splits=10, test_size=0.10, random_state=0)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state =1 )

# %% [markdown]
# ## Custom Scorers for Evaluating Regression Models
#
# **All regression models created in this notebook are validated using the following metrics:**
# * Mean Absolute Error (MAE)
# * Root Mean Squared Error (RMSE) - https://stackoverflow.com/questions/17197492/root-mean-square-error-in-python
# * Mean Absolute Percentage Error (MAPE) - https://stackoverflow.com/questions/42250958/how-to-optimize-mape-code-in-python
#
# **For details on making scorers to return multiple mean error scores see:**
# * http://scikit-learn.org/stable/auto_examples/model_selection/plot_multi_metric_evaluation.html
# * https://github.com/scikit-learn/scikit-learn/pull/7388
# * https://github.com/drorata/multiscorer

# %%
# it may not make sense to use MAPE in our project based on below articles:
# http://www.catchbull.com/catchblogs/why-mape-doesnt-work

# %%
#Use mean absolute error (MAE) to score the regression models created 
#(the scale of MAE is identical to the response variable)
from sklearn.metrics import mean_absolute_error, make_scorer, mean_squared_error, r2_score 
#from sklearn.metrics import mean_absolute_error, make_scorer, mean_squared_error, r2_scorer 

#Function for Root mean squared error
#https://stackoverflow.com/questions/17197492/root-mean-square-error-in-python
def rmse(y_actual, y_predicted):
    return np.sqrt(mean_squared_error(y_actual, y_predicted))

#Function for Mean Absolute Percentage Error (MAPE) - Untested
#Adapted from - https://stackoverflow.com/questions/42250958/how-to-optimize-mape-code-in-python
# revised from - https://stats.stackexchange.com/questions/58391/mean-absolute-percentage-error-mape-in-scikit-learn
# still not working
def mape(y_actual, y_predicted): 
    mask = y_actual != 0           
    return (np.fabs(y_actual - y_predicted)/y_actual)[mask].mean() * 100
# Credit: https://alex.miller.im/posts/linear-model-custom-loss-function-regularization-python/
def mean_absolute_percentage_error(y_true, y_pred, sample_weights=None):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    assert len(y_true) == len(y_pred)
    
    if np.any(y_true==0):
        print("Found zeroes in y_true. MAPE undefined. Removing from set...")
        idx = np.where(y_true==0)
        y_true = np.delete(y_true, idx)
        y_pred = np.delete(y_pred, idx)
        if type(sample_weights) != type(None):
            sample_weights = np.array(sample_weights)
            sample_weights = np.delete(sample_weights, idx)
        
    if type(sample_weights) == type(None):
        return(np.mean(np.abs((y_true - y_pred) / y_true)))
    else:
        sample_weights = np.array(sample_weights)
        assert len(sample_weights) == len(y_true)
        return(100/sum(sample_weights)*np.dot(
                sample_weights, (np.abs((y_true - y_pred) / y_true))
        ))
    
#Create scorers for rmse and mape functions
mae_scorer = make_scorer(score_func=mean_absolute_error, greater_is_better=False)
mse_scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
rmse_scorer = make_scorer(score_func=rmse, greater_is_better=False)
#mape_scorer = make_scorer(score_func=mape, greater_is_better=False)
r2_scorer = make_scorer(score_func=r2_score, greater_is_better=True) 

#Make scorer array to pass into cross_validate() function for producing mutiple scores for each cv fold.
errorScoring = {'MAE':  mae_scorer, 
                'MSE':  mse_scorer, 
                'RMSE': rmse_scorer,
                #'MAPE': mape_scorer,
                'R2': r2_scorer       
               }

# %% [markdown]
# ## Regression Model Evaluation
# ** All regression models are evaluated using the regression model evaluation function below: **
# * The following regression evaluation function uses the cross validation object and the custom scorers in the two cells above in combination with sklearn.model_selection's cross_validate function to perform cross validation for regression estimators.
# * The cross validation object above uses a random seed to ensure that all regression estimators are tested on the same randomly selected records for each cross validation fold.
# * Custom scorers are created using the three chosen mean error scores and passed into cross_validate(), so all three scores are calcualted using a single call to cross_validate().
# * All of this functionality is wrapped within the custom EvaluateRegressionEstimator() function below so multiple regression models may be tested using the same test / train cv data and evaluation scores producing a consistent output for each model without the need to re-write the same code over and over.

# %%
from sklearn.model_selection import cross_validate

def EvaluateRegressionEstimator(regEstimator, X, y, cv):
    
    scores = cross_validate(regEstimator, X, y, scoring=errorScoring, cv=cv, return_train_score=True)

    #cross val score sign-flips the outputs of MAE
    # https://github.com/scikit-learn/scikit-learn/issues/2439
    scores['test_MAE'] = scores['test_MAE'] * -1
    scores['test_MSE'] = scores['test_MSE'] * -1
    #scores['test_MAPE'] = scores['test_MAPE'] * -1
    scores['test_RMSE'] = scores['test_RMSE'] * -1

    #print mean MAE for all folds 
    maeAvg = scores['test_MAE'].mean()
    print_str = "The average MAE for all cv folds is: \t\t\t {maeAvg:.5}"
    print(print_str.format(maeAvg=maeAvg))

     #print mean MAE for all folds 
    mseAvg = scores['test_MSE'].mean()
    print_str = "The average MSE for all cv folds is: \t\t\t {mseAvg:.5}"
    print(print_str.format(mseAvg=mseAvg))
    
    #print mean test_MAPE for all folds
#     scores['test_MAPE'] = scores['test_MAPE']
#     mape_avg = scores['test_MAPE'].mean()
#     print_str = "The average MAE percentage (MAPE) for all cv folds is: \t {mape_avg:.5}"
#     print(print_str.format(mape_avg=mape_avg))

    #print mean MAE for all folds 
    RMSEavg = scores['test_RMSE'].mean()
    print_str = "The average RMSE for all cv folds is: \t\t\t {RMSEavg:.5}"
    print(print_str.format(RMSEavg=RMSEavg))
    print('*********************************************************')
    
    #print mean R-squared for all folds 
    R2avg = scores['test_R2'].mean()
    print_str = "The average R-Squared for all cv folds is: \t\t {R2avg:.5}"
    print(print_str.format(R2avg=R2avg))
    print('*********************************************************')


    print('Cross Validation Fold Mean Error Scores')
    scoresResults = pd.DataFrame()
    scoresResults['MAE'] = scores['test_MAE']
    scoresResults['MSE'] = scores['test_MSE']
   # scoresResults['MAPE'] = scores['test_MAPE']
    scoresResults['RMSE'] = scores['test_RMSE']
    scoresResults['R2'] = scores['test_R2']
    return scoresResults

# %% [markdown]
# ## Baseline Regression Model
#
# **Linear Regression is used to create a baseline model.  Since linear regression may predict response variable values outside the range of the training data's response variable, we create a linear regression estimator with graduation rate predictions clipped 0% and 100%. For details see:**
# * http://scikit-learn.org/stable/developers/contributing.html#rolling-your-own-estimator
# * https://github.com/scikit-learn/scikit-learn/issues/6950
# * http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
# * https://github.com/scikit-learn-contrib/project-template/blob/master/skltemplate/template.py
# * https://stackoverflow.com/questions/44234682/how-to-use-sklearn-when-target-variable-is-a-proportion

# %%
#Make new estimator compatible for use with GridSearchCV() and cross_validate()
# -  Cap predict function for LinearRegression between 0 and 100
# -  See: Roll your own estimator links above for details. 
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.linear_model import LinearRegression

class CappedLinearRegression(LinearRegression):

    def predict(self, X):
        return np.clip(super(CappedLinearRegression, self).predict(X), 0, 100)

# %% [markdown]
# ### Linear Regression Grid Search
# ** Here we perform a grid search testing 40 models to find the best parameters for our Linear Regression model based on Mean Absolute Error.  See more on parameter tuning with grid search here:**
# * http://scikit-learn.org/stable/modules/grid_search.html

# %%
#Create a Linear Regression object and perform a grid search to find the best parameters
linreg = CappedLinearRegression()
parameters = {'normalize':(True,False), 'fit_intercept':(True,False),'normalize': (True, False),}

#Create a grid search object using the  
regGridSearch = GridSearchCV(estimator=linreg
                   , verbose=1 # low verbosity
                   , param_grid=parameters
                   , cv=cv # KFolds = 10
                   , scoring=mae_scorer)

#Perform hyperparameter search to find the best combination of parameters for our data
regGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    7.6s finished
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=0, test_size=0.1, train_size=None),
#        error_score='raise-deprecating',
#        estimator=CappedLinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#             normalize=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'normalize': (True, False), 'fit_intercept': (True, False)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_absolute_error, greater_is_better=False),
#        verbose=1)

# %%
#Print the parameterization of the best estimator
regEstimator = regGridSearch.best_estimator_
#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics. 
CappedLinear_Results = EvaluateRegressionEstimator(regEstimator, X, y, cv)
# Out:
# The average MAE for all cv folds is: 			 0.054257
# The average MSE for all cv folds is: 			 0.0052399
# The average RMSE for all cv folds is: 			 0.072357
# *********************************************************
# The average R-Squared for all cv folds is: 		 0.2813
# *********************************************************
# Cross Validation Fold Mean Error Scores

# %%
regEstimator = regGridSearch.best_estimator_

regEstimator.fit(X_train, y_train)
yhat = regEstimator.predict(X_test)
print("Yhat Max: ", yhat.max())
# Out:
# Yhat Max:  0.5902988135826024

# %% [markdown]
# ## Support Vector Regression
# **This model uses Support Vector Machines for regression of continuous variables (SVR). Please see documentation here:"**
# * http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html
# * http://scikit-learn.org/stable/modules/svm.html

# %%
#Create a Linear regression object and perform a grid search to find the best parameters
from sklearn.svm import SVR
reg = SVR()

#Set up SVR parameters to test (WARNING: Creates 320 models!!!) 
costs = [0.001, 0.1]
defGamma = 1 / X.shape[1]  #This is the default value for the gamma parameter
gammas = [defGamma, 0.1]
kernels = ['rbf','linear']
parameters = {'C': costs, 'gamma' : gammas, 'kernel': kernels}

#Create a grid search object using the parameters above
from sklearn.model_selection import GridSearchCV
regGridSearch = GridSearchCV(estimator=reg
                   , n_jobs=8 # jobs to run in parallel
                   , verbose=1 # low verbosity
                   , param_grid=parameters
                   , cv=cv # KFolds = 10
                   , scoring=mae_scorer)

#Perform hyperparameter search to find the best combination of parameters for our data
regGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=8)]: Done  80 out of  80 | elapsed:  8.8min finished
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=0, test_size=0.1, train_size=None),
#        error_score='raise-deprecating',
#        estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=8,
#        param_grid={'C': [0.001, 0.1], 'gamma': [0.002583979328165375, 0.1], 'kernel': ['rbf', 'linear']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_absolute_error, greater_is_better=False),
#        verbose=1)

# %%
#Display the best estimator parameters
regGridSearch.best_estimator_
# Out:
# SVR(C=0.001, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma=0.002583979328165375, kernel='linear', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# from sklearn.svm import SVR

#Create a regression estimator with best parameters for cross validation
# regEstimator = SVR(C=0.001, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
regEstimator = regGridSearch.best_estimator_

#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics.
SVR_Results=EvaluateRegressionEstimator(regEstimator, X, y, cv)
# Out:
# The average MAE for all cv folds is: 			 0.053452
# The average MSE for all cv folds is: 			 0.005087
# The average RMSE for all cv folds is: 			 0.071273
# *********************************************************
# The average R-Squared for all cv folds is: 		 0.30301
# *********************************************************
# Cross Validation Fold Mean Error Scores

# %%
#Do we predict graduation rates greater than 100%?
# regEstimator = SVR(C=0.001, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

regEstimator.fit(X_train, y_train)
yhat = regEstimator.predict(X_test)
print("Yhat Max: ", yhat.max())
# Out:
# Yhat Max:  0.42791930066261924

# %% [markdown]
# ## Graduation Rate - Lasso Regression
# **This model uses Lasso regression (L1 Norm). Please see documentation here:"**
# * **Caution!** - See documentation for fit_intercept, normalize, and copy_X. Lasso can over-write your X data!
# * Lasso may also perform scaling as well.  Please see docs!
# * http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html

# %%
#Create a regression object and perform a grid search to find the best parameters
from sklearn.linear_model import Lasso

reg = Lasso(fit_intercept=True, normalize=True,copy_X=True
          , max_iter=10000, precompute=True, tol=0.0001, random_state=0)

#Test parameters 
alpha = [0.001, 0.1, 1, 10, 20]
selection = ['cyclic','random']
warm_start = [True, False]
parameters = {'alpha': alpha, 'selection': selection, 'warm_start': warm_start}

#Create a grid search object using the parameters above
regGridSearch = GridSearchCV(estimator=reg
                   , n_jobs=8 # jobs to run in parallel
                   , verbose=1 # low verbosity
                   , param_grid=parameters
                   , cv=cv # KFolds = 10
                   , scoring=mae_scorer)

#Perform hyperparameter search to find the best combination of parameters for our data
regGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   14.0s finished
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=0, test_size=0.1, train_size=None),
#        error_score='raise-deprecating',
#        estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=True, positive=False, precompute=True, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=8,
#        param_grid={'alpha': [0.001, 0.1, 1, 10, 20], 'selection': ['cyclic', 'random'], 'warm_start': [True, False]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_absolute_error, greater_is_better=False),
#        verbose=1)

# %%
#Display the best estimator parameters
regGridSearch.best_estimator_
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=True, positive=False, precompute=True, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=True)

# %%
#Create a regression estimator with best parameters for cross validation
regEstimator = regGridSearch.best_estimator_

#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics.
Lasso_Results = EvaluateRegressionEstimator(regEstimator, X, y, cv)
# Out:
# The average MAE for all cv folds is: 			 0.064694
# The average MSE for all cv folds is: 			 0.0073217
# The average RMSE for all cv folds is: 			 0.085483
# *********************************************************
# The average R-Squared for all cv folds is: 		 -0.00042389
# *********************************************************
# Cross Validation Fold Mean Error Scores

# %%
#Do we predict graduation rates greater than 100%?
# regEstimator = Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=True, positive=False, precompute=True, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=True)
regEstimator = regGridSearch.best_estimator_

regEstimator.fit(X_train, y_train)
yhat = regEstimator.predict(X_test)
print("Yhat Max: ", yhat.max())
# Out:
# Yhat Max:  0.14120325084199736

# %% [markdown]
# ## Ridge Regression
# **This model uses Ridge regression (L2 Norm). Please see documentation here:"**
# * http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html

# %%
#Create a regression object and perform a grid search to find the best parameters
from sklearn.linear_model import Ridge

reg = Ridge(fit_intercept=True, normalize=True,copy_X=True
          , max_iter=10000, tol=0.0001, random_state=0)

#Test parameters 
alpha = [0.001, 0.1, 1, 5, 10, 20]
solver = [ 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']
parameters = {'alpha': alpha, 'solver': solver}

#Create a grid search object using the parameters above
from sklearn.model_selection import GridSearchCV
regGridSearch = GridSearchCV(estimator=reg
                   , n_jobs=10 # jobs to run in parallel
                   , verbose=1 # low verbosity
                   , param_grid=parameters
                   , cv=cv # KFolds = 10
                   , scoring=mae_scorer)

#Perform hyperparameter search to find the best combination of parameters for our data
regGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=10)]: Done 360 out of 360 | elapsed:  5.2min finished
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=0, test_size=0.1, train_size=None),
#        error_score='raise-deprecating',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=True, random_state=0, solver='auto', tol=0.0001),
#        fit_params=None, iid='warn', n_jobs=10,
#        param_grid={'alpha': [0.001, 0.1, 1, 5, 10, 20], 'solver': ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_absolute_error, greater_is_better=False),
#        verbose=1)

# %%
#Display the best estimator parameters
regGridSearch.best_estimator_
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=True, random_state=0, solver='sparse_cg', tol=0.0001)

# %%
# %%time
#Create a regression estimator with best parameters for cross validation
regEstimator = regGridSearch.best_estimator_

#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics.
Ridge_Results = EvaluateRegressionEstimator(regEstimator, X, y, cv)
# Out:
# The average MAE for all cv folds is: 			 0.053452
# The average MSE for all cv folds is: 			 0.005087
# The average RMSE for all cv folds is: 			 0.071273
# *********************************************************
# The average R-Squared for all cv folds is: 		 0.30301
# *********************************************************
# Cross Validation Fold Mean Error Scores
# Wall time: 2.26 s

# %%
#Do we predict graduation rates greater than 100%?
# regEstimator = Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=True, random_state=0, solver='saga', tol=0.0001)
regEstimator = regGridSearch.best_estimator_

regEstimator.fit(X_train, y_train)
yhat = regEstimator.predict(X_test)
print("Yhat Max: ", yhat.max())
# Out:
# Yhat Max:  0.4318838190805139

# %% [markdown]
# ## Elastic Net Regression
# **This model uses Elastic Net Regression (L1 and L2 Norm mixing). Please see documentation here:"**
# * http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html

# %%
#Create a regression object and perform a grid search to find the best parameters
from sklearn.linear_model import ElasticNet

elasticNet = ElasticNet(fit_intercept=True, normalize=True, precompute=True, copy_X=True
          , max_iter=10000, tol=0.0001, random_state=0)
 
#Test parameters
l1_ratio = [0.001, 0.01, 0.1, 0.5, 0.75, 1]
alpha = [0.001, 0.1, 1, 10]
selection = ['cyclic','random']
warm_start = [True, False]
parameters = {'l1_ratio': l1_ratio, 'alpha': alpha, 'selection': selection, 'warm_start': warm_start}

#Create a grid search object using the parameters above
from sklearn.model_selection import GridSearchCV
elasticNetGridSearch = GridSearchCV(estimator=elasticNet
                   , n_jobs=8 # jobs to run in parallel
                   , verbose=1 # low verbosity
                   , param_grid=parameters
                   , cv=cv # KFolds = 10
                   , scoring=mae_scorer)

#Perform hyperparameter search to find the best combination of parameters for our data
elasticNetGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 96 candidates, totalling 960 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=8)]: Done 960 out of 960 | elapsed:   42.5s finished
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=0, test_size=0.1, train_size=None),
#        error_score='raise-deprecating',
#        estimator=ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=True, positive=False, precompute=True,
#       random_state=0, selection='cyclic', tol=0.0001, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=8,
#        param_grid={'l1_ratio': [0.001, 0.01, 0.1, 0.5, 0.75, 1], 'alpha': [0.001, 0.1, 1, 10], 'selection': ['cyclic', 'random'], 'warm_start': [True, False]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_absolute_error, greater_is_better=False),
#        verbose=1)

# %%
#Display the best estimator parameters
elasticNetGridSearch.best_estimator_
# Out:
# ElasticNet(alpha=0.001, copy_X=True, fit_intercept=True, l1_ratio=0.001,
#       max_iter=10000, normalize=True, positive=False, precompute=True,
#       random_state=0, selection='random', tol=0.0001, warm_start=True)

# %%
#Create a regression estimator with best parameters for cross validation
elasticNetEstimator = elasticNetGridSearch.best_estimator_

#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics.
elastic_Results = EvaluateRegressionEstimator(elasticNetEstimator, X, y, cv)
# Out:
# The average MAE for all cv folds is: 			 0.05674
# The average MSE for all cv folds is: 			 0.0057062
# The average RMSE for all cv folds is: 			 0.075476
# *********************************************************
# The average R-Squared for all cv folds is: 		 0.21964
# *********************************************************
# Cross Validation Fold Mean Error Scores

# %%
#Do we predict graduation rates greater than 100%?
elasticNetEstimator =  elasticNetGridSearch.best_estimator_

elasticNetEstimator.fit(X_train, y_train)
yhat = elasticNetEstimator.predict(X_test)
print("Yhat Max: ", yhat.max())
# Out:
# Yhat Max:  0.269424137495597

# %% [markdown]
# ## XGBoost

# %%
# credit: https://www.kaggle.com/mburakergenc/predictions-with-xgboost-and-linear-regression

# %%
regr = LinearRegression()

# %%
 #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state =1 )

# %%
# Let's try XGboost algorithm to see if we can get better results
xgb = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)

# %%
traindf, testdf = train_test_split(X_train, test_size = 0.3)
xgb.fit(X_train,y_train)
# Out:
# C:\Users\yubin\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, importance_type='gain',
#        learning_rate=0.08, max_delta_step=0, max_depth=7,
#        min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#        nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=0.75)

# %%
predictions = xgb.predict(X_test)
print(explained_variance_score(predictions,y_test))
# Out:
# -0.6289762377577575
