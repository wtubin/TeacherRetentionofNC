# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2017

#Location where copies of the raw data files will be read in from csv files.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2017'
inputFileName = 'PublicHighSchools2017'
#inputFileName = 'PublicMiddleSchools2017'
#inputFileName = 'PublicElementarySchools2017'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Columns: 2293 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2246), int64(3), object(44)
# memory usage: 8.2+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 2293 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2246), int64(3), object(44)
# memory usage: 8.2+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print ('Rows Updated / Imputed: ', rowsUpdated )
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(SingleValueCols)
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 1145 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1109), object(36)
# memory usage: 4.1+ MB
#
# Columns Deleted:  134

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print( '\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 2291 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2245), int64(3), object(43)
# memory usage: 8.2+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 2198 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2152), int64(3), object(43)
# memory usage: 7.9+ MB
#
# Columns Deleted:  93

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  43
# Continuous Columns:  2155
# Columns Accounted for:  2198

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 1537 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1491), int64(3), object(43)
# memory usage: 5.5+ MB
#
# Columns Deleted:  661

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 1522 entries, year to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1491), int64(3), object(28)
# memory usage: 5.5+ MB
#
# Columns Deleted:  15

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print( 'Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print ('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  28
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 1586 entries, year to SRC_Grades_Devices_Sent_Home_9:10:12
# dtypes: float64(1491), int64(3), uint8(92)
# memory usage: 5.4 MB
#
# New Columns Created Via One-Hot Encoding:  64

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 6                                              09_Size                     54
# 7                                              10_Size                     75
# 8                                              11_Size                     81
# 9                                              12_Size                    103
# 10                                        Biology_Size                     15
# 11                                     English II_Size                     17
# 12                                         Math I_Size                     16
# 32                                  EVAAS Growth Score                     11
# 34                                     NC Math 1 Score                     12
# 35                                    English II Score                     17
# 36                                       Biology Score                     17
# 37                                           ACT Score                     11
# 38                                  ACT WorkKeys Score                     89
# 39                                   Passing NC Math 3                     14
# 40                 4-Year Cohort Graduation Rate Score                     13
# 41                        ACTCompositeScore_UNCMin_All                     13
# 42                         ACTEnglish_ACTBenchmark_All                     13
# 43                            ACTMath_ACTBenchmark_All                     13
# 44                         ACTReading_ACTBenchmark_All                     13
# 45                         ACTScience_ACTBenchmark_All                     13
# 46                       ACTSubtests_BenchmarksMet_All                      9
# 47                          ACTWorkKeys_SilverPlus_All                    108
# 48                         ACTWriting_ACTBenchmark_All                     13
# 49                                 EOCBiology_CACR_All                     19
# 50                                  EOCBiology_GLP_All                     19
# 51                                EOCEnglish2_CACR_All                     19
# 52                                 EOCEnglish2_GLP_All                     19
# 53                                   EOCMathI_CACR_All                     13
# 54                                    EOCMathI_GLP_All                     13
# 55                                EOCSubjects_CACR_All                     10
# 56                                 EOCSubjects_GLP_All                     10
# 57                            EOG/EOCSubjects_CACR_All                      9
# 58                             EOG/EOCSubjects_GLP_All                      9
# 59                              GraduationRate_4yr_All                     14
# 60                              GraduationRate_5yr_All                     24
# 61                     ACTCompositeScore_UNCMin_Female                     13
# 62                      ACTEnglish_ACTBenchmark_Female                     13
# 63                         ACTMath_ACTBenchmark_Female                     13
# 64                      ACTReading_ACTBenchmark_Female                     13
# 65                      ACTScience_ACTBenchmark_Female                     13
# 66                    ACTSubtests_BenchmarksMet_Female                      9
# 67                       ACTWorkKeys_SilverPlus_Female                    108
# 68                      ACTWriting_ACTBenchmark_Female                     13
# 69                              EOCBiology_CACR_Female                     19
# 70                               EOCBiology_GLP_Female                     19
# 71                             EOCEnglish2_CACR_Female                     19
# 72                              EOCEnglish2_GLP_Female                     19
# 73                                EOCMathI_CACR_Female                     13
# 74                                 EOCMathI_GLP_Female                     13
# 75                             EOCSubjects_CACR_Female                     10
# 76                              EOCSubjects_GLP_Female                     10
# 77                         EOG/EOCSubjects_CACR_Female                      9
# 78                          EOG/EOCSubjects_GLP_Female                      9
# 79                           GraduationRate_4yr_Female                     14
# 80                           GraduationRate_5yr_Female                     24
# 81                       ACTCompositeScore_UNCMin_Male                     13
# 82                        ACTEnglish_ACTBenchmark_Male                     13
# 83                           ACTMath_ACTBenchmark_Male                     13
# 84                        ACTReading_ACTBenchmark_Male                     13
# 85                        ACTScience_ACTBenchmark_Male                     13
# 86                      ACTSubtests_BenchmarksMet_Male                      9
# 87                         ACTWorkKeys_SilverPlus_Male                    108
# 88                        ACTWriting_ACTBenchmark_Male                     13
# 89                                EOCBiology_CACR_Male                     19
# 90                                 EOCBiology_GLP_Male                     19
# 91                               EOCEnglish2_CACR_Male                     19
# 92                                EOCEnglish2_GLP_Male                     19
# 93                                  EOCMathI_CACR_Male                     13
# 94                                   EOCMathI_GLP_Male                     13
# 95                               EOCSubjects_CACR_Male                     10
# 96                                EOCSubjects_GLP_Male                     10
# 97                           EOG/EOCSubjects_CACR_Male                      9
# 98                            EOG/EOCSubjects_GLP_Male                      9
# 99                             GraduationRate_4yr_Male                     14
# 100                            GraduationRate_5yr_Male                     24
# 101            ACTCompositeScore_UNCMin_AmericanIndian                     13
# 102             ACTEnglish_ACTBenchmark_AmericanIndian                     13
# 103                ACTMath_ACTBenchmark_AmericanIndian                     13
# 104             ACTReading_ACTBenchmark_AmericanIndian                     13
# 105             ACTScience_ACTBenchmark_AmericanIndian                     13
# 106           ACTSubtests_BenchmarksMet_AmericanIndian                      9
# 107              ACTWorkKeys_SilverPlus_AmericanIndian                    108
# 108             ACTWriting_ACTBenchmark_AmericanIndian                     13
# 109                     EOCBiology_CACR_AmericanIndian                     19
# 110                      EOCBiology_GLP_AmericanIndian                     19
# 111                    EOCEnglish2_CACR_AmericanIndian                     19
# 112                     EOCEnglish2_GLP_AmericanIndian                     19
# 113                       EOCMathI_CACR_AmericanIndian                     13
# 114                        EOCMathI_GLP_AmericanIndian                     13
# 115                    EOCSubjects_CACR_AmericanIndian                     10
# 116                     EOCSubjects_GLP_AmericanIndian                     10
# 117                EOG/EOCSubjects_CACR_AmericanIndian                      9
# 118                 EOG/EOCSubjects_GLP_AmericanIndian                      9
# 119                  GraduationRate_4yr_AmericanIndian                     14
# 120                  GraduationRate_5yr_AmericanIndian                     24
# 121                     ACTCompositeScore_UNCMin_Asian                     13
# 122                      ACTEnglish_ACTBenchmark_Asian                     13
# 123                         ACTMath_ACTBenchmark_Asian                     13
# 124                      ACTReading_ACTBenchmark_Asian                     13
# 125                      ACTScience_ACTBenchmark_Asian                     13
# 126                    ACTSubtests_BenchmarksMet_Asian                      9
# 127                       ACTWorkKeys_SilverPlus_Asian                    108
# 128                      ACTWriting_ACTBenchmark_Asian                     13
# 129                              EOCBiology_CACR_Asian                     19
# 130                               EOCBiology_GLP_Asian                     19
# 131                             EOCEnglish2_CACR_Asian                     19
# 132                              EOCEnglish2_GLP_Asian                     19
# 133                                EOCMathI_CACR_Asian                     13
# 134                                 EOCMathI_GLP_Asian                     13
# 135                             EOCSubjects_CACR_Asian                     10
# 136                              EOCSubjects_GLP_Asian                     10
# 137                         EOG/EOCSubjects_CACR_Asian                      9
# 138                          EOG/EOCSubjects_GLP_Asian                      9
# 139                           GraduationRate_4yr_Asian                     14
# 140                           GraduationRate_5yr_Asian                     24
# 141                     ACTCompositeScore_UNCMin_Black                     13
# 142                      ACTEnglish_ACTBenchmark_Black                     13
# 143                         ACTMath_ACTBenchmark_Black                     13
# 144                      ACTReading_ACTBenchmark_Black                     13
# 145                      ACTScience_ACTBenchmark_Black                     13
# 146                    ACTSubtests_BenchmarksMet_Black                      9
# 147                       ACTWorkKeys_SilverPlus_Black                    108
# 148                      ACTWriting_ACTBenchmark_Black                     13
# 149                              EOCBiology_CACR_Black                     19
# 150                               EOCBiology_GLP_Black                     19
# 151                             EOCEnglish2_CACR_Black                     19
# 152                              EOCEnglish2_GLP_Black                     19
# 153                                EOCMathI_CACR_Black                     13
# 154                                 EOCMathI_GLP_Black                     13
# 155                             EOCSubjects_CACR_Black                     10
# 156                              EOCSubjects_GLP_Black                     10
# 157                         EOG/EOCSubjects_CACR_Black                      9
# 158                          EOG/EOCSubjects_GLP_Black                      9
# 159                           GraduationRate_4yr_Black                     14
# 160                           GraduationRate_5yr_Black                     24
# 161                  ACTCompositeScore_UNCMin_Hispanic                     13
# 162                   ACTEnglish_ACTBenchmark_Hispanic                     13
# 163                      ACTMath_ACTBenchmark_Hispanic                     13
# 164                   ACTReading_ACTBenchmark_Hispanic                     13
# 165                   ACTScience_ACTBenchmark_Hispanic                     13
# 166                 ACTSubtests_BenchmarksMet_Hispanic                      9
# 167                    ACTWorkKeys_SilverPlus_Hispanic                    108
# 168                   ACTWriting_ACTBenchmark_Hispanic                     13
# 169                           EOCBiology_CACR_Hispanic                     19
# 170                            EOCBiology_GLP_Hispanic                     19
# 171                          EOCEnglish2_CACR_Hispanic                     19
# 172                           EOCEnglish2_GLP_Hispanic                     19
# 173                             EOCMathI_CACR_Hispanic                     13
# 174                              EOCMathI_GLP_Hispanic                     13
# 175                          EOCSubjects_CACR_Hispanic                     10
# 176                           EOCSubjects_GLP_Hispanic                     10
# 177                      EOG/EOCSubjects_CACR_Hispanic                      9
# 178                       EOG/EOCSubjects_GLP_Hispanic                      9
# 179                        GraduationRate_4yr_Hispanic                     14
# 180                        GraduationRate_5yr_Hispanic                     24
# 181            ACTCompositeScore_UNCMin_TwoorMoreRaces                     13
# 182             ACTEnglish_ACTBenchmark_TwoorMoreRaces                     13
# 183                ACTMath_ACTBenchmark_TwoorMoreRaces                     13
# 184             ACTReading_ACTBenchmark_TwoorMoreRaces                     13
# 185             ACTScience_ACTBenchmark_TwoorMoreRaces                     13
# 186           ACTSubtests_BenchmarksMet_TwoorMoreRaces                      9
# 187              ACTWorkKeys_SilverPlus_TwoorMoreRaces                    108
# 188             ACTWriting_ACTBenchmark_TwoorMoreRaces                     13
# 189                     EOCBiology_CACR_TwoorMoreRaces                     19
# 190                      EOCBiology_GLP_TwoorMoreRaces                     19
# 191                    EOCEnglish2_CACR_TwoorMoreRaces                     19
# 192                     EOCEnglish2_GLP_TwoorMoreRaces                     19
# 193                       EOCMathI_CACR_TwoorMoreRaces                     13
# 194                        EOCMathI_GLP_TwoorMoreRaces                     13
# 195                    EOCSubjects_CACR_TwoorMoreRaces                     10
# 196                     EOCSubjects_GLP_TwoorMoreRaces                     10
# 197                EOG/EOCSubjects_CACR_TwoorMoreRaces                      9
# 198                 EOG/EOCSubjects_GLP_TwoorMoreRaces                      9
# 199                  GraduationRate_4yr_TwoorMoreRaces                     14
# 200                  GraduationRate_5yr_TwoorMoreRaces                     24
# 201                     ACTCompositeScore_UNCMin_White                     13
# 202                      ACTEnglish_ACTBenchmark_White                     13
# 203                         ACTMath_ACTBenchmark_White                     13
# 204                      ACTReading_ACTBenchmark_White                     13
# 205                      ACTScience_ACTBenchmark_White                     13
# 206                    ACTSubtests_BenchmarksMet_White                      9
# 207                       ACTWorkKeys_SilverPlus_White                    108
# 208                      ACTWriting_ACTBenchmark_White                     13
# 209                              EOCBiology_CACR_White                     19
# 210                               EOCBiology_GLP_White                     19
# 211                             EOCEnglish2_CACR_White                     19
# 212                              EOCEnglish2_GLP_White                     19
# 213                                EOCMathI_CACR_White                     13
# 214                                 EOCMathI_GLP_White                     13
# 215                             EOCSubjects_CACR_White                     10
# 216                              EOCSubjects_GLP_White                     10
# 217                         EOG/EOCSubjects_CACR_White                      9
# 218                          EOG/EOCSubjects_GLP_White                      9
# 219                           GraduationRate_4yr_White                     14
# 220                           GraduationRate_5yr_White                     24
# 221                       ACTCompositeScore_UNCMin_EDS                     13
# 222                        ACTEnglish_ACTBenchmark_EDS                     13
# 223                           ACTMath_ACTBenchmark_EDS                     13
# 224                        ACTReading_ACTBenchmark_EDS                     13
# 225                        ACTScience_ACTBenchmark_EDS                     13
# 226                      ACTSubtests_BenchmarksMet_EDS                      9
# 227                         ACTWorkKeys_SilverPlus_EDS                    108
# 228                        ACTWriting_ACTBenchmark_EDS                     13
# 229                                EOCBiology_CACR_EDS                     19
# 230                                 EOCBiology_GLP_EDS                     19
# 231                               EOCEnglish2_CACR_EDS                     19
# 232                                EOCEnglish2_GLP_EDS                     19
# 233                                  EOCMathI_CACR_EDS                     13
# 234                                   EOCMathI_GLP_EDS                     13
# 235                               EOCSubjects_CACR_EDS                     10
# 236                                EOCSubjects_GLP_EDS                     10
# 237                           EOG/EOCSubjects_CACR_EDS                      9
# 238                            EOG/EOCSubjects_GLP_EDS                      9
# 239                             GraduationRate_4yr_EDS                     14
# 240                             GraduationRate_5yr_EDS                     24
# 241                       ACTCompositeScore_UNCMin_LEP                     13
# 242                        ACTEnglish_ACTBenchmark_LEP                     13
# 243                           ACTMath_ACTBenchmark_LEP                     13
# 244                        ACTReading_ACTBenchmark_LEP                     13
# 245                        ACTScience_ACTBenchmark_LEP                     13
# 246                      ACTSubtests_BenchmarksMet_LEP                      9
# 247                         ACTWorkKeys_SilverPlus_LEP                    108
# 248                        ACTWriting_ACTBenchmark_LEP                     13
# 249                                EOCBiology_CACR_LEP                     19
# 250                                 EOCBiology_GLP_LEP                     19
# 251                               EOCEnglish2_CACR_LEP                     19
# 252                                EOCEnglish2_GLP_LEP                     19
# 253                                  EOCMathI_CACR_LEP                     13
# 254                                   EOCMathI_GLP_LEP                     13
# 255                               EOCSubjects_CACR_LEP                     10
# 256                                EOCSubjects_GLP_LEP                     10
# 257                           EOG/EOCSubjects_CACR_LEP                      9
# 258                            EOG/EOCSubjects_GLP_LEP                      9
# 259                             GraduationRate_4yr_LEP                     14
# 260                             GraduationRate_5yr_LEP                     24
# 261                       ACTCompositeScore_UNCMin_SWD                     13
# 262                        ACTEnglish_ACTBenchmark_SWD                     13
# 263                           ACTMath_ACTBenchmark_SWD                     13
# 264                        ACTReading_ACTBenchmark_SWD                     13
# 265                        ACTScience_ACTBenchmark_SWD                     13
# 266                      ACTSubtests_BenchmarksMet_SWD                      9
# 267                         ACTWorkKeys_SilverPlus_SWD                    108
# 268                        ACTWriting_ACTBenchmark_SWD                     13
# 269                                EOCBiology_CACR_SWD                     19
# 270                                 EOCBiology_GLP_SWD                     19
# 271                               EOCEnglish2_CACR_SWD                     19
# 272                                EOCEnglish2_GLP_SWD                     19
# 273                                  EOCMathI_CACR_SWD                     13
# 274                                   EOCMathI_GLP_SWD                     13
# 275                               EOCSubjects_CACR_SWD                     10
# 276                                EOCSubjects_GLP_SWD                     10
# 277                           EOG/EOCSubjects_CACR_SWD                      9
# 278                            EOG/EOCSubjects_GLP_SWD                      9
# 279                             GraduationRate_4yr_SWD                     14
# 280                             GraduationRate_5yr_SWD                     24
# 281                       ACTCompositeScore_UNCMin_AIG                     13
# 282                        ACTEnglish_ACTBenchmark_AIG                     13
# 283                           ACTMath_ACTBenchmark_AIG                     13
# 284                        ACTReading_ACTBenchmark_AIG                     13
# 285                        ACTScience_ACTBenchmark_AIG                     13
# 286                      ACTSubtests_BenchmarksMet_AIG                      9
# 287                         ACTWorkKeys_SilverPlus_AIG                    108
# 288                        ACTWriting_ACTBenchmark_AIG                     13
# 289                                EOCBiology_CACR_AIG                     19
# 290                                 EOCBiology_GLP_AIG                     19
# 291                               EOCEnglish2_CACR_AIG                     19
# 292                                EOCEnglish2_GLP_AIG                     19
# 293                                  EOCMathI_CACR_AIG                     13
# 294                                   EOCMathI_GLP_AIG                     13
# 295                               EOCSubjects_CACR_AIG                     10
# 296                                EOCSubjects_GLP_AIG                     10
# 297                           EOG/EOCSubjects_CACR_AIG                      9
# 298                            EOG/EOCSubjects_GLP_AIG                      9
# 299                             GraduationRate_4yr_AIG                     14
# 300                             GraduationRate_5yr_AIG                     24
# 301                                 ACT_pTarget_PctMet                     30
# 302                         ACTWorkKeys_pTarget_PctMet                    140
# 303                      CurrentYearEOC_pTarget_PctMet                     13
# 304                            MathGr10_pTarget_PctMet                     31
# 305                         ReadingGr10_pTarget_PctMet                     31
# 306                             SciGr11_pTarget_PctMet                     33
# 307                        TotalTargets_pTarget_PctMet                      1
# 308                                  sat_avg_score_num                     49
# 309                              lea_sat_avg_score_num                      1
# 312                              sat_participation_pct                     49
# 313                          lea_sat_participation_pct                      1
# 316                               ap_participation_pct                    161
# 317                           lea_ap_participation_pct                     71
# 319                                  ap_pct_3_or_above                    121
# 320                              lea_ap_pct_3_or_above                     18
# 323                          total_specialized_courses                      6
# 324                                      ap_ib_courses                    111
# 325                                        cte_courses                     13
# 326                               univ_college_courses                     61
# 327                      lea_total_specialized_courses                      6
# 328                                  lea_ap_ib_courses                     15
# 329                                    lea_cte_courses                      6
# 330                           lea_univ_college_courses                      9
# 331                       st_total_specialized_courses                      6
# 332                                   st_ap_ib_courses                      6
# 333                                     st_cte_courses                      6
# 334                            st_univ_college_courses                      6
# 335  ALL_All Students (Total or Subtotal_ENROLL_sch...                     29
# 336   ECODIS_Economically Disadvantaged_ENROLL_sch_pct                    112
# 337                            F_Female_ENROLL_sch_pct                     30
# 338                              M_Male_ENROLL_sch_pct                     31
# 339                            MB_Black_ENROLL_sch_pct                    165
# 340                            MW_White_ENROLL_sch_pct                     58
# 346                             stud_internet_comp_num                      4
# 359                                  digital_media_pct                     91
# 360                           avg_age_media_collection                     85
# 361                                  books_per_student                     94
# 362                       lea_avg_age_media_collection                     85
# 363                              lea_books_per_student                     94
# 366                                            wap_num                     11
# 367                                  wap_per_classroom                     11
# 374                                flicensed_teach_pct                      2
# 375                                  tchyrs_0thru3_pct                      2
# 376                                 tchyrs_4thru10_pct                      2
# 377                                  tchyrs_11plus_pct                      2
# 378                                    class_teach_num                      2
# 379                                          nbpts_num                      2
# 380                                    advance_dgr_pct                      2
# 381                               _1yr_tchr_trnovr_pct                     12
# 382                                  lateral_teach_pct                     82
# 391                            lea_emer_prov_teach_pct                    263
# 392                              lea_lateral_teach_pct                      5
# 413                              0-3 Years_Exp_Pct_Tch                      2
# 414                              10+ Years_Exp_Pct_Tch                      2
# 415                             4-10 Years_Exp_Pct_Tch                      2
# 419                   Accomplished_TCHR_Standard 1_Pct                      3
# 420                   Accomplished_TCHR_Standard 2_Pct                      3
# 421                   Accomplished_TCHR_Standard 3_Pct                      3
# 422                   Accomplished_TCHR_Standard 4_Pct                      3
# 423                   Accomplished_TCHR_Standard 5_Pct                      3
# 424                     Developing_TCHR_Standard 1_Pct                      3
# 425                     Developing_TCHR_Standard 2_Pct                      3
# 426                     Developing_TCHR_Standard 3_Pct                      3
# 427                     Developing_TCHR_Standard 4_Pct                      3
# 428                     Developing_TCHR_Standard 5_Pct                      3
# 429                  Distinguished_TCHR_Standard 1_Pct                      3
# 430                  Distinguished_TCHR_Standard 2_Pct                      3
# 431                  Distinguished_TCHR_Standard 3_Pct                      3
# 432                  Distinguished_TCHR_Standard 4_Pct                      3
# 433                  Distinguished_TCHR_Standard 5_Pct                      3
# 434  Does Not Meet Expected Growth_TCHR_Student Gro...                     11
# 435    Exceeds Expected Growth_TCHR_Student Growth_Pct                     11
# 436      Meets Expected Growth_TCHR_Student Growth_Pct                     11
# 437                Not Demostrated_TCHR_Standard 1_Pct                      3
# 438                Not Demostrated_TCHR_Standard 2_Pct                      3
# 439                Not Demostrated_TCHR_Standard 3_Pct                      3
# 440                Not Demostrated_TCHR_Standard 4_Pct                      3
# 441                Not Demostrated_TCHR_Standard 5_Pct                      3
# 442                     Proficient_TCHR_Standard 1_Pct                      3
# 443                     Proficient_TCHR_Standard 2_Pct                      3
# 444                     Proficient_TCHR_Standard 3_Pct                      3
# 445                     Proficient_TCHR_Standard 4_Pct                      3
# 446                     Proficient_TCHR_Standard 5_Pct                      3
# 471                                      Gr_9_Pct_Prof                     13
# 473                               AAVC_Concentrator_Ct                    247
# 474                               AGNR_Concentrator_Ct                    147
# 475                               ARCH_Concentrator_Ct                    164
# 476                                BMA_Concentrator_Ct                    150
# 477                               HLTH_Concentrator_Ct                    148
# 478                               HOSP_Concentrator_Ct                    140
# 479                               INFO_Concentrator_Ct                    143
# 480                               MANU_Concentrator_Ct                    228
# 481                               MRKT_Concentrator_Ct                    269
# 482                               STEM_Concentrator_Ct                    259
# 483                               TRAN_Concentrator_Ct                    268
# 484                   Number_Industry_Recognized_Crede                     57
# 485                                               Year                    116
# 486                                       Violent Rate                    117
# 487                                        Murder Rate                    154
# 488                                          Rape Rate                    124
# 489                                       Robbery Rate                    130
# 490                                       Assault Rate                    119
# 491                                           MVT Rate                    116
# 492                                         Arson Rate                    128

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  272454  field correlations > 95%.
#                                                    Field1  \
# 0                                         class_teach_num
# 1                                     lea_class_teach_num
# 2                                      st_class_teach_num
# 3                                            st_nbpts_num
# 4                                      st_advance_dgr_pct
# 5                                           category_cd_H
# 6                                           Category_Cd_H
# 7                                   st_salary_expense_pct
# 8                                 st_services_expense_pct
# 9                                 st_supplies_expense_pct
# 10                              st_instruct_equip_exp_pct
# 11                                st_federal_perpupil_num
# 12                                  st_local_perpupil_num
# 13                                  st_state_perpupil_num
# 14                               st_sat_participation_pct
# 15                                st_ap_participation_pct
# 16                                   st_ap_pct_3_or_above
# 17                                   st_ib_pct_4_or_above
# 18                              st_stud_internet_comp_num
# 19                                   st_books_per_student
# 20                                   st_wap_per_classroom
# 21                                  st_prinyrs_0thru3_pct
# 22                                 st_prinyrs_4thru10_pct
# 23                                  st_prinyrs_11plus_pct
# 24                                st_prin_advance_dgr_pct
# 25                                 st_1yr_prin_trnovr_pct
# 26                                       st_prin_male_pct
# 27                                      st_prin_black_pct
# 28                                      st_prin_white_pct
# 29                                      st_prin_other_pct
# 30                                st_services_expense_pct
# 31                                st_supplies_expense_pct
# 32                              st_instruct_equip_exp_pct
# 33                                st_federal_perpupil_num
# 34                                  st_local_perpupil_num
# 35                                  st_state_perpupil_num
# 36                               st_sat_participation_pct
# 37                                st_ap_participation_pct
# 38                                   st_ap_pct_3_or_above
# 39                                   st_ib_pct_4_or_above
# 40                              st_stud_internet_comp_num
# 41                                   st_books_per_student
# 42                                   st_wap_per_classroom
# 43                                  st_prinyrs_0thru3_pct
# 44                                 st_prinyrs_4thru10_pct
# 45                                  st_prinyrs_11plus_pct
# 46                                st_prin_advance_dgr_pct
# 47                                 st_1yr_prin_trnovr_pct
# 48                                       st_prin_male_pct
# 49                                      st_prin_black_pct
# 50                                      st_prin_white_pct
# 51                                      st_prin_other_pct
# 52                                st_supplies_expense_pct
# 53                              st_instruct_equip_exp_pct
# 54                                st_federal_perpupil_num
# 55                                  st_local_perpupil_num
# 56                                  st_state_perpupil_num
# 57                               st_sat_participation_pct
# 58                                st_ap_participation_pct
# 59                                   st_ap_pct_3_or_above
# 60                                   st_ib_pct_4_or_above
# 61                              st_stud_internet_comp_num
# 62                                   st_books_per_student
# 63                                   st_wap_per_classroom
# 64                                  st_prinyrs_0thru3_pct
# 65                                 st_prinyrs_4thru10_pct
# 66                                  st_prinyrs_11plus_pct
# 67                                st_prin_advance_dgr_pct
# 68                                 st_1yr_prin_trnovr_pct
# 69                                       st_prin_male_pct
# 70                                      st_prin_black_pct
# 71                                      st_prin_white_pct
# 72                                      st_prin_other_pct
# 73                              st_instruct_equip_exp_pct
# 74                                st_federal_perpupil_num
# 75                                  st_local_perpupil_num
# 76                                  st_state_perpupil_num
# 77                               st_sat_participation_pct
# 78                                st_ap_participation_pct
# 79                                   st_ap_pct_3_or_above
# 80                                   st_ib_pct_4_or_above
# 81                              st_stud_internet_comp_num
# 82                                   st_books_per_student
# 83                                   st_wap_per_classroom
# 84                                  st_prinyrs_0thru3_pct
# 85                                 st_prinyrs_4thru10_pct
# 86                                  st_prinyrs_11plus_pct
# 87                                st_prin_advance_dgr_pct
# 88                                 st_1yr_prin_trnovr_pct
# 89                                       st_prin_male_pct
# 90                                      st_prin_black_pct
# 91                                      st_prin_white_pct
# 92                                      st_prin_other_pct
# 93                                st_federal_perpupil_num
# 94                                  st_local_perpupil_num
# 95                                  st_state_perpupil_num
# 96                               st_sat_participation_pct
# 97                                st_ap_participation_pct
# 98                                   st_ap_pct_3_or_above
# 99                                   st_ib_pct_4_or_above
# 100                             st_stud_internet_comp_num
# 101                                  st_books_per_student
# 102                                  st_wap_per_classroom
# 103                                 st_prinyrs_0thru3_pct
# 104                                st_prinyrs_4thru10_pct
# 105                                 st_prinyrs_11plus_pct
# 106                               st_prin_advance_dgr_pct
# 107                                st_1yr_prin_trnovr_pct
# 108                                      st_prin_male_pct
# 109                                     st_prin_black_pct
# 110                                     st_prin_white_pct
# 111                                     st_prin_other_pct
# 112                                 st_local_perpupil_num
# 113                                 st_state_perpupil_num
# 114                              st_sat_participation_pct
# 115                               st_ap_participation_pct
# 116                                  st_ap_pct_3_or_above
# 117                                  st_ib_pct_4_or_above
# 118                             st_stud_internet_comp_num
# 119                                  st_books_per_student
# 120                                  st_wap_per_classroom
# 121                                 st_prinyrs_0thru3_pct
# 122                                st_prinyrs_4thru10_pct
# 123                                 st_prinyrs_11plus_pct
# 124                               st_prin_advance_dgr_pct
# 125                                st_1yr_prin_trnovr_pct
# 126                                      st_prin_male_pct
# 127                                     st_prin_black_pct
# 128                                     st_prin_white_pct
# 129                                     st_prin_other_pct
# 130                                 st_state_perpupil_num
# 131                              st_sat_participation_pct
# 132                               st_ap_participation_pct
# 133                                  st_ap_pct_3_or_above
# 134                                  st_ib_pct_4_or_above
# 135                             st_stud_internet_comp_num
# 136                                  st_books_per_student
# 137                                  st_wap_per_classroom
# 138                                 st_prinyrs_0thru3_pct
# 139                                st_prinyrs_4thru10_pct
# 140                                 st_prinyrs_11plus_pct
# 141                               st_prin_advance_dgr_pct
# 142                                st_1yr_prin_trnovr_pct
# 143                                      st_prin_male_pct
# 144                                     st_prin_black_pct
# 145                                     st_prin_white_pct
# 146                                     st_prin_other_pct
# 147                              st_sat_participation_pct
# 148                               st_ap_participation_pct
# 149                                  st_ap_pct_3_or_above
# 150                                  st_ib_pct_4_or_above
# 151                             st_stud_internet_comp_num
# 152                                  st_books_per_student
# 153                                  st_wap_per_classroom
# 154                                 st_prinyrs_0thru3_pct
# 155                                st_prinyrs_4thru10_pct
# 156                                 st_prinyrs_11plus_pct
# 157                               st_prin_advance_dgr_pct
# 158                                st_1yr_prin_trnovr_pct
# 159                                      st_prin_male_pct
# 160                                     st_prin_black_pct
# 161                                     st_prin_white_pct
# 162                                     st_prin_other_pct
# 163                             Overall Achievement Score
# 164                                     EOCMathI_CACR_All
# 165                                      EOCMathI_GLP_All
# 166                                  EOCEnglish2_CACR_All
# 167                                   EOCEnglish2_GLP_All
# 168                                   EOCBiology_CACR_All
# 169                                    EOCBiology_GLP_All
# 170                          ACTCompositeScore_UNCMin_All
# 171                           ACTEnglish_ACTBenchmark_All
# 172                                GraduationRate_4yr_All
# 173                           ACTEnglish_ACTBenchmark_All
# 174                           ACTReading_ACTBenchmark_All
# 175                         ACTSubtests_BenchmarksMet_All
# 176                         ACTSubtests_BenchmarksMet_All
# 177                         ACTSubtests_BenchmarksMet_All
# 178                         ACTSubtests_BenchmarksMet_All
# 179                      ACTSubtests_BenchmarksMet_Female
# 180                        ACTSubtests_BenchmarksMet_Male
# 181                        ACTWriting_ACTBenchmark_Female
# 182                                    EOCBiology_GLP_All
# 183                                   EOCEnglish2_GLP_All
# 184                                      EOCMathI_GLP_All
# 185                                  EOCMathI_CACR_Female
# 186                                   EOCSubjects_GLP_All
# 187                              EOG/EOCSubjects_CACR_All
# 188                               EOG/EOCSubjects_GLP_All
# 189                               EOCSubjects_CACR_Female
# 190                                 EOCSubjects_CACR_Male
# 191                              EOG/EOCSubjects_CACR_All
# 192                               EOG/EOCSubjects_GLP_All
# 193                               EOG/EOCSubjects_GLP_All
# 194                           EOG/EOCSubjects_CACR_Female
# 195                             EOG/EOCSubjects_CACR_Male
# 196                      ACTSubtests_BenchmarksMet_Female
# 197                                 EOCBiology_GLP_Female
# 198                                EOCEnglish2_GLP_Female
# 199                                   EOCMathI_GLP_Female
# 200                                EOCSubjects_GLP_Female
# 201                           EOG/EOCSubjects_CACR_Female
# 202                            EOG/EOCSubjects_GLP_Female
# 203                           EOG/EOCSubjects_CACR_Female
# 204                            EOG/EOCSubjects_GLP_Female
# 205                            EOG/EOCSubjects_GLP_Female
# 206                          ACTEnglish_ACTBenchmark_Male
# 207                          ACTReading_ACTBenchmark_Male
# 208                                   EOCBiology_GLP_Male
# 209                                  EOCEnglish2_GLP_Male
# 210                                     EOCMathI_GLP_Male
# 211                                  EOCSubjects_GLP_Male
# 212                             EOG/EOCSubjects_CACR_Male
# 213                              EOG/EOCSubjects_GLP_Male
# 214                             EOG/EOCSubjects_CACR_Male
# 215                              EOG/EOCSubjects_GLP_Male
# 216                              EOG/EOCSubjects_GLP_Male
# 217                ACTEnglish_ACTBenchmark_AmericanIndian
# 218                ACTReading_ACTBenchmark_AmericanIndian
# 219                ACTScience_ACTBenchmark_AmericanIndian
# 220                         EOCBiology_GLP_AmericanIndian
# 221                        EOCEnglish2_GLP_AmericanIndian
# 222                           EOCMathI_GLP_AmericanIndian
# 223                        EOCSubjects_GLP_AmericanIndian
# 224                   EOG/EOCSubjects_CACR_AmericanIndian
# 225                    EOG/EOCSubjects_GLP_AmericanIndian
# 226                   EOG/EOCSubjects_CACR_AmericanIndian
# 227                    EOG/EOCSubjects_GLP_AmericanIndian
# 228                    EOG/EOCSubjects_GLP_AmericanIndian
# 229                         ACTEnglish_ACTBenchmark_Asian
# 230                            ACTMath_ACTBenchmark_Asian
# 231                         ACTReading_ACTBenchmark_Asian
# 232                            ACTMath_ACTBenchmark_Asian
# 233                         ACTReading_ACTBenchmark_Asian
# 234                         ACTScience_ACTBenchmark_Asian
# 235                         ACTReading_ACTBenchmark_Asian
# 236                         ACTScience_ACTBenchmark_Asian
# 237                         ACTScience_ACTBenchmark_Asian
# 238                                  EOCBiology_GLP_Asian
# 239                                 EOCEnglish2_GLP_Asian
# 240                                    EOCMathI_GLP_Asian
# 241                                 EOCSubjects_GLP_Asian
# 242                            EOG/EOCSubjects_CACR_Asian
# 243                             EOG/EOCSubjects_GLP_Asian
# 244                            EOG/EOCSubjects_CACR_Asian
# 245                             EOG/EOCSubjects_GLP_Asian
# 246                             EOG/EOCSubjects_GLP_Asian
# 247                                  EOCBiology_GLP_Black
# 248                                 EOCEnglish2_GLP_Black
# 249                                    EOCMathI_GLP_Black
# 250                                 EOCSubjects_GLP_Black
# 251                            EOG/EOCSubjects_CACR_Black
# 252                             EOG/EOCSubjects_GLP_Black
# 253                            EOG/EOCSubjects_CACR_Black
# 254                             EOG/EOCSubjects_GLP_Black
# 255                             EOG/EOCSubjects_GLP_Black
# 256                               EOCBiology_GLP_Hispanic
# 257                              EOCEnglish2_GLP_Hispanic
# 258                                 EOCMathI_GLP_Hispanic
# 259                              EOCSubjects_GLP_Hispanic
# 260                         EOG/EOCSubjects_CACR_Hispanic
# 261                          EOG/EOCSubjects_GLP_Hispanic
# 262                         EOG/EOCSubjects_CACR_Hispanic
# 263                          EOG/EOCSubjects_GLP_Hispanic
# 264                          EOG/EOCSubjects_GLP_Hispanic
# 265                ACTEnglish_ACTBenchmark_TwoorMoreRaces
# 266                         EOCBiology_GLP_TwoorMoreRaces
# 267                        EOCEnglish2_GLP_TwoorMoreRaces
# 268                           EOCMathI_GLP_TwoorMoreRaces
# 269                        EOCSubjects_GLP_TwoorMoreRaces
# 270                   EOG/EOCSubjects_CACR_TwoorMoreRaces
# 271                    EOG/EOCSubjects_GLP_TwoorMoreRaces
# 272                    EOG/EOCSubjects_GLP_TwoorMoreRaces
# 273                         ACTEnglish_ACTBenchmark_White
# 274                         ACTReading_ACTBenchmark_White
# 275                                  EOCBiology_GLP_White
# 276                                 EOCEnglish2_GLP_White
# 277                                    EOCMathI_GLP_White
# 278                                 EOCSubjects_GLP_White
# 279                            EOG/EOCSubjects_CACR_White
# 280                             EOG/EOCSubjects_GLP_White
# 281                            EOG/EOCSubjects_CACR_White
# 282                             EOG/EOCSubjects_GLP_White
# 283                             EOG/EOCSubjects_GLP_White
# 284                                    EOCBiology_GLP_EDS
# 285                                   EOCEnglish2_GLP_EDS
# 286                                      EOCMathI_GLP_EDS
# 287                                   EOCSubjects_GLP_EDS
# 288                              EOG/EOCSubjects_CACR_EDS
# 289                               EOG/EOCSubjects_GLP_EDS
# 290                              EOG/EOCSubjects_CACR_EDS
# 291                               EOG/EOCSubjects_GLP_EDS
# 292                               EOG/EOCSubjects_GLP_EDS
# 293                              EOG/EOCSubjects_CACR_LEP
# 294                           ACTEnglish_ACTBenchmark_AIG
# 295                           ACTReading_ACTBenchmark_AIG
# 296                           ACTReading_ACTBenchmark_AIG
# 297                                    EOCBiology_GLP_AIG
# 298                                   EOCEnglish2_GLP_AIG
# 299                                      EOCMathI_GLP_AIG
# 300                                   EOCSubjects_GLP_AIG
# 301                              EOG/EOCSubjects_CACR_AIG
# 302                               EOG/EOCSubjects_GLP_AIG
# 303                               EOG/EOCSubjects_GLP_AIG
# 304                               st_ap_participation_pct
# 305                                  st_ap_pct_3_or_above
# 306                                  st_ib_pct_4_or_above
# 307                             st_stud_internet_comp_num
# 308                                  st_books_per_student
# 309                                  st_wap_per_classroom
# 310                                 st_prinyrs_0thru3_pct
# 311                                st_prinyrs_4thru10_pct
# 312                                 st_prinyrs_11plus_pct
# 313                               st_prin_advance_dgr_pct
# 314                                st_1yr_prin_trnovr_pct
# 315                                      st_prin_male_pct
# 316                                     st_prin_black_pct
# 317                                     st_prin_white_pct
# 318                                     st_prin_other_pct
# 319                                         ap_ib_courses
# 320                                     lea_ap_ib_courses
# 321                                  st_ap_pct_3_or_above
# 322                                  st_ib_pct_4_or_above
# 323                             st_stud_internet_comp_num
# 324                                  st_books_per_student
# 325                                  st_wap_per_classroom
# 326                                 st_prinyrs_0thru3_pct
# 327                                st_prinyrs_4thru10_pct
# 328                                 st_prinyrs_11plus_pct
# 329                               st_prin_advance_dgr_pct
# 330                                st_1yr_prin_trnovr_pct
# 331                                      st_prin_male_pct
# 332                                     st_prin_black_pct
# 333                                     st_prin_white_pct
# 334                                     st_prin_other_pct
# 335                                  st_ib_pct_4_or_above
# 336                             st_stud_internet_comp_num
# 337                                  st_books_per_student
# 338                                  st_wap_per_classroom
# 339                                 st_prinyrs_0thru3_pct
# 340                                st_prinyrs_4thru10_pct
# 341                                 st_prinyrs_11plus_pct
# 342                               st_prin_advance_dgr_pct
# 343                                st_1yr_prin_trnovr_pct
# 344                                      st_prin_male_pct
# 345                                     st_prin_black_pct
# 346                                     st_prin_white_pct
# 347                                     st_prin_other_pct
# 348                             st_stud_internet_comp_num
# 349                                  st_books_per_student
# 350                                  st_wap_per_classroom
# 351                                 st_prinyrs_0thru3_pct
# 352                                st_prinyrs_4thru10_pct
# 353                                 st_prinyrs_11plus_pct
# 354                               st_prin_advance_dgr_pct
# 355                                st_1yr_prin_trnovr_pct
# 356                                      st_prin_male_pct
# 357                                     st_prin_black_pct
# 358                                     st_prin_white_pct
# 359                                     st_prin_other_pct
# 360                                      st_ap_ib_courses
# 361                                        st_cte_courses
# 362                               st_univ_college_courses
# 363                                        st_cte_courses
# 364                               st_univ_college_courses
# 365                               st_univ_college_courses
# 366                                st_flicensed_teach_pct
# 367                                  st_tchyrs_11plus_pct
# 368                                  st_tchyrs_0thru3_pct
# 369                                 st_tchyrs_4thru10_pct
# 370                                st_long_susp_per_c_num
# 371                                 st_expelled_per_c_num
# 372                                st_1yr_tchr_trnovr_pct
# 373                                st_emer_prov_teach_pct
# 374                                         category_cd_T
# 375                                         Category_Cd_T
# 376                                 st_expelled_per_c_num
# 377                                st_emer_prov_teach_pct
# 378                                         category_cd_T
# 379                                         Category_Cd_T
# 380                                st_emer_prov_teach_pct
# 381                                         category_cd_T
# 382                                         Category_Cd_T
# 383                                  st_books_per_student
# 384                                  st_wap_per_classroom
# 385                                 st_prinyrs_0thru3_pct
# 386                                st_prinyrs_4thru10_pct
# 387                                 st_prinyrs_11plus_pct
# 388                               st_prin_advance_dgr_pct
# 389                                st_1yr_prin_trnovr_pct
# 390                                      st_prin_male_pct
# 391                                     st_prin_black_pct
# 392                                     st_prin_white_pct
# 393                                     st_prin_other_pct
# 394                          lea_avg_age_media_collection
# 395                                  st_wap_per_classroom
# 396                                 st_prinyrs_0thru3_pct
# 397                                st_prinyrs_4thru10_pct
# 398                                 st_prinyrs_11plus_pct
# 399                               st_prin_advance_dgr_pct
# 400                                st_1yr_prin_trnovr_pct
# 401                                      st_prin_male_pct
# 402                                     st_prin_black_pct
# 403                                     st_prin_white_pct
# 404                                     st_prin_other_pct
# 405                     Add child tax credit Amt 25KLT50K
# 406                          Add child tax credit Amt All
# 407                        Add child tax credit Amt LT25K
# 408                      Add child tax credit Ct 25KLT50K
# 409                           Add child tax credit Ct All
# 410                         Add child tax credit Ct LT25K
# 411                     Adjusted gross income (AGI) LT25K
# 412               Advance premium tax credit Amt 25KLT50K
# 413                    Advance premium tax credit Amt All
# 414                  Advance premium tax credit Amt LT25K
# 415                   Advance premium tax credit Ct LT25K
# 416     Business or professionnet income (less loss) A...
# 417     Business or professionnet income (less loss) C...
# 418          Child and dependent care credit Amt 25KLT50K
# 419             Child and dependent care credit Amt LT25K
# 420           Child and dependent care credit Ct 25KLT50K
# 421              Child and dependent care credit Ct LT25K
# 422                            Child tax credit Amt LT25K
# 423                             Child tax credit Ct LT25K
# 424                     Earned income credit Amt 25KLT50K
# 425                          Earned income credit Amt All
# 426                        Earned income credit Amt LT25K
# 427                      Earned income credit Ct 25KLT50K
# 428                           Earned income credit Ct All
# 429                         Earned income credit Ct LT25K
# 430                        Educator expenses Amt 25KLT50K
# 431     Excess earned income credit (refundable) Amt 2...
# 432      Excess earned income credit (refundable) Amt All
# 433     Excess earned income credit (refundable) Amt L...
# 434     Excess earned income credit (refundable) Ct 25...
# 435       Excess earned income credit (refundable) Ct All
# 436     Excess earned income credit (refundable) Ct LT25K
# 437               Net limited misc deduction Amt 25KLT50K
# 438               Net limited misc deduction Amt 50KLT75K
# 439              Net limited misc deduction Amt 75KLT100K
# 440                  Net limited misc deduction Amt LT25K
# 441                Net limited misc deduction Ct 25KLT50K
# 442                Net limited misc deduction Ct 50KLT75K
# 443                   Net limited misc deduction Ct LT25K
# 444                         Number of dependents 25KLT50K
# 445                            Number of dependents LT25K
# 446                            Number of exemptions LT25K
# 447          Number of head of household returns 25KLT50K
# 448               Number of head of household returns All
# 449             Number of head of household returns LT25K
# 450     Number of refund anticipation check returns 25...
# 451       Number of refund anticipation check returns All
# 452     Number of refund anticipation check returns LT25K
# 453     Number of refund anticipation loan returns 25K...
# 454        Number of refund anticipation loan returns All
# 455      Number of refund anticipation loan returns LT25K
# 456        Number with paid preparer's signature 25KLT50K
# 457             Number with paid preparer's signature All
# 458           Number with paid preparer's signature LT25K
# 459              Other non-limited misc deduction Amt All
# 460           Other non-limited misc deduction Amt GE200K
# 461            Other non-limited misc deduction Ct GE200K
# 462                       Overpayments refunded Amt LT25K
# 463                  Personal property taxes Amt 25KLT50K
# 464                  Personal property taxes Amt 50KLT75K
# 465                     Personal property taxes Amt LT25K
# 466                   Personal property taxes Ct 25KLT50K
# 467                      Personal property taxes Ct LT25K
# 468     Qualified mortgage insurance premiums Amt 25KL...
# 469     Qualified mortgage insurance premiums Ct 25KLT50K
# 470        Qualified mortgage insurance premiums Ct LT25K
# 471                    Refundable edu credit Amt 25KLT50K
# 472                       Refundable edu credit Amt LT25K
# 473                     Refundable edu credit Ct 25KLT50K
# 474                        Refundable edu credit Ct LT25K
# 475     Retirement savings contributions credit Amt 25...
# 476       Retirement savings contributions credit Amt All
# 477     Retirement savings contributions credit Amt LT25K
# 478     Retirement savings contributions credit Ct 25K...
# 479        Retirement savings contributions credit Ct All
# 480      Retirement savings contributions credit Ct LT25K
# 481                   Salaries and wages in AGI Amt LT25K
# 482                         Self-employment tax Amt LT25K
# 483                          Self-employment tax Ct LT25K
# 484       State and local income tax refunds Amt 25KLT50K
# 485              State and local income taxes Ct 25KLT50K
# 486                 State and local income taxes Ct LT25K
# 487                Tax due at time of filing Amt 25KLT50K
# 488                   Tax due at time of filing Amt LT25K
# 489             Tot charitable contributions Amt 25KLT50K
# 490                Tot charitable contributions Amt LT25K
# 491              Tot charitable contributions Ct 25KLT50K
# 492                 Tot charitable contributions Ct LT25K
# 493                                  Tot income Amt LT25K
# 494              Tot itemized deductions Amt of AGI LT25K
# 495                   Tot premium tax credit Amt 25KLT50K
# 496                        Tot premium tax credit Amt All
# 497                      Tot premium tax credit Amt LT25K
# 498                         Tot premium tax credit Ct All
# 499                       Tot premium tax credit Ct LT25K
# ...                                                   ...
# 271954                Unemployment compensation Amt LT25K
# 271955            Unemployment compensation Ct 100KLT200K
# 271956              Unemployment compensation Ct 25KLT50K
# 271957              Unemployment compensation Ct 50KLT75K
# 271958             Unemployment compensation Ct 75KLT100K
# 271959                   Unemployment compensation Ct All
# 271960                 Unemployment compensation Ct LT25K
# 271961                       Tot taxes paid Amt 75KLT100K
# 271962                             Tot taxes paid Amt All
# 271963                          Tot taxes paid Amt GE200K
# 271964                           Tot taxes paid Amt LT25K
# 271965                       Tot taxes paid Ct 100KLT200K
# 271966                         Tot taxes paid Ct 25KLT50K
# 271967                         Tot taxes paid Ct 50KLT75K
# 271968                        Tot taxes paid Ct 75KLT100K
# 271969                              Tot taxes paid Ct All
# 271970                           Tot taxes paid Ct GE200K
# 271971                            Tot taxes paid Ct LT25K
# 271972            Tuition and fees deduction Amt 25KLT50K
# 271973            Tuition and fees deduction Amt 50KLT75K
# 271974                 Tuition and fees deduction Amt All
# 271975               Tuition and fees deduction Amt LT25K
# 271976             Tuition and fees deduction Ct 25KLT50K
# 271977             Tuition and fees deduction Ct 50KLT75K
# 271978                  Tuition and fees deduction Ct All
# 271979                Tuition and fees deduction Ct LT25K
# 271980           Unemployment compensation Amt 100KLT200K
# 271981             Unemployment compensation Amt 25KLT50K
# 271982             Unemployment compensation Amt 50KLT75K
# 271983            Unemployment compensation Amt 75KLT100K
# 271984                  Unemployment compensation Amt All
# 271985                Unemployment compensation Amt LT25K
# 271986            Unemployment compensation Ct 100KLT200K
# 271987              Unemployment compensation Ct 25KLT50K
# 271988              Unemployment compensation Ct 50KLT75K
# 271989             Unemployment compensation Ct 75KLT100K
# 271990                   Unemployment compensation Ct All
# 271991                             Tot taxes paid Amt All
# 271992                          Tot taxes paid Amt GE200K
# 271993                           Tot taxes paid Amt LT25K
# 271994                       Tot taxes paid Ct 100KLT200K
# 271995                         Tot taxes paid Ct 25KLT50K
# 271996                         Tot taxes paid Ct 50KLT75K
# 271997                        Tot taxes paid Ct 75KLT100K
# 271998                              Tot taxes paid Ct All
# 271999                           Tot taxes paid Ct GE200K
# 272000                            Tot taxes paid Ct LT25K
# 272001          Tuition and fees deduction Amt 100KLT200K
# 272002            Tuition and fees deduction Amt 25KLT50K
# 272003            Tuition and fees deduction Amt 50KLT75K
# 272004                 Tuition and fees deduction Amt All
# 272005               Tuition and fees deduction Amt LT25K
# 272006           Tuition and fees deduction Ct 100KLT200K
# 272007             Tuition and fees deduction Ct 25KLT50K
# 272008             Tuition and fees deduction Ct 50KLT75K
# 272009                  Tuition and fees deduction Ct All
# 272010                Tuition and fees deduction Ct LT25K
# 272011           Unemployment compensation Amt 100KLT200K
# 272012             Unemployment compensation Amt 25KLT50K
# 272013             Unemployment compensation Amt 50KLT75K
# 272014            Unemployment compensation Amt 75KLT100K
# 272015                  Unemployment compensation Amt All
# 272016            Unemployment compensation Ct 100KLT200K
# 272017              Unemployment compensation Ct 25KLT50K
# 272018              Unemployment compensation Ct 50KLT75K
# 272019             Unemployment compensation Ct 75KLT100K
# 272020                   Unemployment compensation Ct All
# 272021                          Tot taxes paid Amt GE200K
# 272022                           Tot taxes paid Amt LT25K
# 272023                       Tot taxes paid Ct 100KLT200K
# 272024                         Tot taxes paid Ct 25KLT50K
# 272025                         Tot taxes paid Ct 50KLT75K
# 272026                        Tot taxes paid Ct 75KLT100K
# 272027                              Tot taxes paid Ct All
# 272028                           Tot taxes paid Ct GE200K
# 272029                            Tot taxes paid Ct LT25K
# 272030            Tuition and fees deduction Amt 25KLT50K
# 272031            Tuition and fees deduction Amt 50KLT75K
# 272032                 Tuition and fees deduction Amt All
# 272033               Tuition and fees deduction Amt LT25K
# 272034             Tuition and fees deduction Ct 25KLT50K
# 272035             Tuition and fees deduction Ct 50KLT75K
# 272036                  Tuition and fees deduction Ct All
# 272037                Tuition and fees deduction Ct LT25K
# 272038           Unemployment compensation Amt 100KLT200K
# 272039             Unemployment compensation Amt 25KLT50K
# 272040             Unemployment compensation Amt 50KLT75K
# 272041            Unemployment compensation Amt 75KLT100K
# 272042                  Unemployment compensation Amt All
# 272043               Unemployment compensation Amt GE200K
# 272044            Unemployment compensation Ct 100KLT200K
# 272045              Unemployment compensation Ct 25KLT50K
# 272046              Unemployment compensation Ct 50KLT75K
# 272047             Unemployment compensation Ct 75KLT100K
# 272048                   Unemployment compensation Ct All
# 272049                Unemployment compensation Ct GE200K
# 272050                           Tot taxes paid Amt LT25K
# 272051                       Tot taxes paid Ct 100KLT200K
# 272052                         Tot taxes paid Ct 25KLT50K
# 272053                         Tot taxes paid Ct 50KLT75K
# 272054                        Tot taxes paid Ct 75KLT100K
# 272055                              Tot taxes paid Ct All
# 272056                           Tot taxes paid Ct GE200K
# 272057                            Tot taxes paid Ct LT25K
# 272058            Tuition and fees deduction Amt 25KLT50K
# 272059            Tuition and fees deduction Amt 50KLT75K
# 272060                 Tuition and fees deduction Amt All
# 272061               Tuition and fees deduction Amt LT25K
# 272062             Tuition and fees deduction Ct 25KLT50K
# 272063             Tuition and fees deduction Ct 50KLT75K
# 272064                  Tuition and fees deduction Ct All
# 272065                Tuition and fees deduction Ct LT25K
# 272066           Unemployment compensation Amt 100KLT200K
# 272067             Unemployment compensation Amt 25KLT50K
# 272068             Unemployment compensation Amt 50KLT75K
# 272069            Unemployment compensation Amt 75KLT100K
# 272070                  Unemployment compensation Amt All
# 272071            Unemployment compensation Ct 100KLT200K
# 272072              Unemployment compensation Ct 25KLT50K
# 272073              Unemployment compensation Ct 50KLT75K
# 272074                   Unemployment compensation Ct All
# 272075                Unemployment compensation Ct GE200K
# 272076                       Tot taxes paid Ct 100KLT200K
# 272077                         Tot taxes paid Ct 25KLT50K
# 272078                         Tot taxes paid Ct 50KLT75K
# 272079                        Tot taxes paid Ct 75KLT100K
# 272080                              Tot taxes paid Ct All
# 272081                           Tot taxes paid Ct GE200K
# 272082                            Tot taxes paid Ct LT25K
# 272083            Tuition and fees deduction Amt 25KLT50K
# 272084            Tuition and fees deduction Amt 50KLT75K
# 272085                 Tuition and fees deduction Amt All
# 272086               Tuition and fees deduction Amt LT25K
# 272087             Tuition and fees deduction Ct 25KLT50K
# 272088             Tuition and fees deduction Ct 50KLT75K
# 272089                  Tuition and fees deduction Ct All
# 272090                Tuition and fees deduction Ct LT25K
# 272091             Unemployment compensation Amt 25KLT50K
# 272092             Unemployment compensation Amt 50KLT75K
# 272093            Unemployment compensation Amt 75KLT100K
# 272094                  Unemployment compensation Amt All
# 272095                Unemployment compensation Amt LT25K
# 272096            Unemployment compensation Ct 100KLT200K
# 272097              Unemployment compensation Ct 25KLT50K
# 272098              Unemployment compensation Ct 50KLT75K
# 272099             Unemployment compensation Ct 75KLT100K
# 272100                   Unemployment compensation Ct All
# 272101                 Unemployment compensation Ct LT25K
# 272102                         Tot taxes paid Ct 25KLT50K
# 272103                         Tot taxes paid Ct 50KLT75K
# 272104                        Tot taxes paid Ct 75KLT100K
# 272105                              Tot taxes paid Ct All
# 272106                           Tot taxes paid Ct GE200K
# 272107                            Tot taxes paid Ct LT25K
# 272108          Tuition and fees deduction Amt 100KLT200K
# 272109            Tuition and fees deduction Amt 25KLT50K
# 272110            Tuition and fees deduction Amt 50KLT75K
# 272111                 Tuition and fees deduction Amt All
# 272112               Tuition and fees deduction Amt LT25K
# 272113           Tuition and fees deduction Ct 100KLT200K
# 272114             Tuition and fees deduction Ct 25KLT50K
# 272115             Tuition and fees deduction Ct 50KLT75K
# 272116                  Tuition and fees deduction Ct All
# 272117                Tuition and fees deduction Ct LT25K
# 272118           Unemployment compensation Amt 100KLT200K
# 272119            Unemployment compensation Amt 75KLT100K
# 272120                  Unemployment compensation Amt All
# 272121            Unemployment compensation Ct 100KLT200K
# 272122             Unemployment compensation Ct 75KLT100K
# 272123                   Unemployment compensation Ct All
# 272124                Unemployment compensation Ct GE200K
# 272125                         Tot taxes paid Ct 50KLT75K
# 272126                        Tot taxes paid Ct 75KLT100K
# 272127                              Tot taxes paid Ct All
# 272128                           Tot taxes paid Ct GE200K
# 272129                            Tot taxes paid Ct LT25K
# 272130            Tuition and fees deduction Amt 25KLT50K
# 272131            Tuition and fees deduction Amt 50KLT75K
# 272132                 Tuition and fees deduction Amt All
# 272133               Tuition and fees deduction Amt LT25K
# 272134             Tuition and fees deduction Ct 25KLT50K
# 272135             Tuition and fees deduction Ct 50KLT75K
# 272136                  Tuition and fees deduction Ct All
# 272137                Tuition and fees deduction Ct LT25K
# 272138             Unemployment compensation Amt 25KLT50K
# 272139             Unemployment compensation Amt 50KLT75K
# 272140            Unemployment compensation Amt 75KLT100K
# 272141                  Unemployment compensation Amt All
# 272142                Unemployment compensation Amt LT25K
# 272143              Unemployment compensation Ct 25KLT50K
# 272144              Unemployment compensation Ct 50KLT75K
# 272145             Unemployment compensation Ct 75KLT100K
# 272146                   Unemployment compensation Ct All
# 272147                 Unemployment compensation Ct LT25K
# 272148                        Tot taxes paid Ct 75KLT100K
# 272149                              Tot taxes paid Ct All
# 272150                           Tot taxes paid Ct GE200K
# 272151                            Tot taxes paid Ct LT25K
# 272152            Tuition and fees deduction Amt 25KLT50K
# 272153            Tuition and fees deduction Amt 50KLT75K
# 272154                 Tuition and fees deduction Amt All
# 272155               Tuition and fees deduction Amt LT25K
# 272156             Tuition and fees deduction Ct 25KLT50K
# 272157             Tuition and fees deduction Ct 50KLT75K
# 272158                  Tuition and fees deduction Ct All
# 272159                Tuition and fees deduction Ct LT25K
# 272160           Unemployment compensation Amt 100KLT200K
# 272161             Unemployment compensation Amt 25KLT50K
# 272162             Unemployment compensation Amt 50KLT75K
# 272163            Unemployment compensation Amt 75KLT100K
# 272164                  Unemployment compensation Amt All
# 272165                Unemployment compensation Amt LT25K
# 272166            Unemployment compensation Ct 100KLT200K
# 272167              Unemployment compensation Ct 25KLT50K
# 272168              Unemployment compensation Ct 50KLT75K
# 272169             Unemployment compensation Ct 75KLT100K
# 272170                   Unemployment compensation Ct All
# 272171                              Tot taxes paid Ct All
# 272172                           Tot taxes paid Ct GE200K
# 272173                            Tot taxes paid Ct LT25K
# 272174          Tuition and fees deduction Amt 100KLT200K
# 272175            Tuition and fees deduction Amt 25KLT50K
# 272176            Tuition and fees deduction Amt 50KLT75K
# 272177                 Tuition and fees deduction Amt All
# 272178               Tuition and fees deduction Amt LT25K
# 272179           Tuition and fees deduction Ct 100KLT200K
# 272180             Tuition and fees deduction Ct 25KLT50K
# 272181             Tuition and fees deduction Ct 50KLT75K
# 272182                  Tuition and fees deduction Ct All
# 272183                Tuition and fees deduction Ct LT25K
# 272184           Unemployment compensation Amt 100KLT200K
# 272185             Unemployment compensation Amt 25KLT50K
# 272186             Unemployment compensation Amt 50KLT75K
# 272187            Unemployment compensation Amt 75KLT100K
# 272188                  Unemployment compensation Amt All
# 272189            Unemployment compensation Ct 100KLT200K
# 272190              Unemployment compensation Ct 25KLT50K
# 272191              Unemployment compensation Ct 50KLT75K
# 272192             Unemployment compensation Ct 75KLT100K
# 272193                   Unemployment compensation Ct All
# 272194    volunteer prepared w Earned Income Credit LT25K
# 272195                           Tot taxes paid Ct GE200K
# 272196                            Tot taxes paid Ct LT25K
# 272197          Tuition and fees deduction Amt 100KLT200K
# 272198            Tuition and fees deduction Amt 25KLT50K
# 272199            Tuition and fees deduction Amt 50KLT75K
# 272200                 Tuition and fees deduction Amt All
# 272201               Tuition and fees deduction Amt LT25K
# 272202           Tuition and fees deduction Ct 100KLT200K
# 272203             Tuition and fees deduction Ct 25KLT50K
# 272204             Tuition and fees deduction Ct 50KLT75K
# 272205                  Tuition and fees deduction Ct All
# 272206                Tuition and fees deduction Ct LT25K
# 272207           Unemployment compensation Amt 100KLT200K
# 272208             Unemployment compensation Amt 25KLT50K
# 272209             Unemployment compensation Amt 50KLT75K
# 272210            Unemployment compensation Amt 75KLT100K
# 272211                  Unemployment compensation Amt All
# 272212            Unemployment compensation Ct 100KLT200K
# 272213              Unemployment compensation Ct 25KLT50K
# 272214              Unemployment compensation Ct 50KLT75K
# 272215             Unemployment compensation Ct 75KLT100K
# 272216                   Unemployment compensation Ct All
# 272217                Unemployment compensation Ct GE200K
# 272218                            Tot taxes paid Ct LT25K
# 272219          Tuition and fees deduction Amt 100KLT200K
# 272220            Tuition and fees deduction Amt 25KLT50K
# 272221            Tuition and fees deduction Amt 50KLT75K
# 272222                 Tuition and fees deduction Amt All
# 272223               Tuition and fees deduction Amt LT25K
# 272224           Tuition and fees deduction Ct 100KLT200K
# 272225             Tuition and fees deduction Ct 25KLT50K
# 272226             Tuition and fees deduction Ct 50KLT75K
# 272227                  Tuition and fees deduction Ct All
# 272228                Tuition and fees deduction Ct LT25K
# 272229           Unemployment compensation Amt 100KLT200K
# 272230             Unemployment compensation Amt 25KLT50K
# 272231             Unemployment compensation Amt 50KLT75K
# 272232            Unemployment compensation Amt 75KLT100K
# 272233                  Unemployment compensation Amt All
# 272234               Unemployment compensation Amt GE200K
# 272235            Unemployment compensation Ct 100KLT200K
# 272236              Unemployment compensation Ct 25KLT50K
# 272237              Unemployment compensation Ct 50KLT75K
# ...
# 272236                           Tot taxes paid Ct GE200K     0.961127
# 272237                           Tot taxes paid Ct GE200K     0.965585
# 272238                           Tot taxes paid Ct GE200K     0.973087
# 272239                           Tot taxes paid Ct GE200K     0.967083
# 272240                           Tot taxes paid Ct GE200K     0.973524
# 272241                            Tot taxes paid Ct LT25K     0.981422
# 272242                            Tot taxes paid Ct LT25K     0.982553
# 272243                            Tot taxes paid Ct LT25K     0.972820
# 272244                            Tot taxes paid Ct LT25K     0.977899
# 272245                            Tot taxes paid Ct LT25K     0.978904
# 272246                            Tot taxes paid Ct LT25K     0.979230
# 272247                            Tot taxes paid Ct LT25K     0.971163
# 272248                            Tot taxes paid Ct LT25K     0.981994
# 272249                            Tot taxes paid Ct LT25K     0.991448
# 272250                            Tot taxes paid Ct LT25K     0.991764
# 272251                            Tot taxes paid Ct LT25K     0.973255
# 272252                            Tot taxes paid Ct LT25K     0.993178
# 272253                            Tot taxes paid Ct LT25K     0.978312
# 272254                            Tot taxes paid Ct LT25K     0.992341
# 272255                            Tot taxes paid Ct LT25K     0.991085
# 272256                            Tot taxes paid Ct LT25K     0.969580
# 272257                            Tot taxes paid Ct LT25K     0.993171
# 272258                            Tot taxes paid Ct LT25K     0.967162
# 272259          Tuition and fees deduction Amt 100KLT200K     0.968093
# 272260          Tuition and fees deduction Amt 100KLT200K     0.999761
# 272261          Tuition and fees deduction Amt 100KLT200K     0.973140
# 272262          Tuition and fees deduction Amt 100KLT200K     0.967926
# 272263          Tuition and fees deduction Amt 100KLT200K     0.955906
# 272264          Tuition and fees deduction Amt 100KLT200K     0.965977
# 272265          Tuition and fees deduction Amt 100KLT200K     0.961519
# 272266            Tuition and fees deduction Amt 25KLT50K     0.985605
# 272267            Tuition and fees deduction Amt 25KLT50K     0.989381
# 272268            Tuition and fees deduction Amt 25KLT50K     0.988950
# 272269            Tuition and fees deduction Amt 25KLT50K     0.999198
# 272270            Tuition and fees deduction Amt 25KLT50K     0.984662
# 272271            Tuition and fees deduction Amt 25KLT50K     0.987421
# 272272            Tuition and fees deduction Amt 25KLT50K     0.989585
# 272273            Tuition and fees deduction Amt 25KLT50K     0.967442
# 272274            Tuition and fees deduction Amt 25KLT50K     0.970142
# 272275            Tuition and fees deduction Amt 25KLT50K     0.967379
# 272276            Tuition and fees deduction Amt 25KLT50K     0.975630
# 272277            Tuition and fees deduction Amt 25KLT50K     0.951348
# 272278            Tuition and fees deduction Amt 25KLT50K     0.970407
# 272279            Tuition and fees deduction Amt 25KLT50K     0.968096
# 272280            Tuition and fees deduction Amt 25KLT50K     0.966931
# 272281            Tuition and fees deduction Amt 25KLT50K     0.977418
# 272282            Tuition and fees deduction Amt 25KLT50K     0.950328
# 272283            Tuition and fees deduction Amt 50KLT75K     0.990786
# 272284            Tuition and fees deduction Amt 50KLT75K     0.988401
# 272285            Tuition and fees deduction Amt 50KLT75K     0.983602
# 272286            Tuition and fees deduction Amt 50KLT75K     0.999196
# 272287            Tuition and fees deduction Amt 50KLT75K     0.989629
# 272288            Tuition and fees deduction Amt 50KLT75K     0.989254
# 272289            Tuition and fees deduction Amt 50KLT75K     0.962229
# 272290            Tuition and fees deduction Amt 50KLT75K     0.979834
# 272291            Tuition and fees deduction Amt 50KLT75K     0.978381
# 272292            Tuition and fees deduction Amt 50KLT75K     0.972515
# 272293            Tuition and fees deduction Amt 50KLT75K     0.985479
# 272294            Tuition and fees deduction Amt 50KLT75K     0.952489
# 272295            Tuition and fees deduction Amt 50KLT75K     0.966674
# 272296            Tuition and fees deduction Amt 50KLT75K     0.978902
# 272297            Tuition and fees deduction Amt 50KLT75K     0.976053
# 272298            Tuition and fees deduction Amt 50KLT75K     0.970297
# 272299            Tuition and fees deduction Amt 50KLT75K     0.982038
# 272300           Tuition and fees deduction Amt 75KLT100K     0.992782
# 272301                 Tuition and fees deduction Amt All     0.995758
# 272302                 Tuition and fees deduction Amt All     0.970122
# 272303                 Tuition and fees deduction Amt All     0.988763
# 272304                 Tuition and fees deduction Amt All     0.993002
# 272305                 Tuition and fees deduction Amt All     0.999400
# 272306                 Tuition and fees deduction Amt All     0.995933
# 272307                 Tuition and fees deduction Amt All     0.964982
# 272308                 Tuition and fees deduction Amt All     0.959536
# 272309                 Tuition and fees deduction Amt All     0.962839
# 272310                 Tuition and fees deduction Amt All     0.979364
# 272311                 Tuition and fees deduction Amt All     0.970341
# 272312                 Tuition and fees deduction Amt All     0.967709
# 272313                 Tuition and fees deduction Amt All     0.962811
# 272314                 Tuition and fees deduction Amt All     0.960549
# 272315                 Tuition and fees deduction Amt All     0.980292
# 272316                 Tuition and fees deduction Amt All     0.969008
# 272317                 Tuition and fees deduction Amt All     0.952285
# 272318                 Tuition and fees deduction Amt All     0.954927
# 272319               Tuition and fees deduction Amt LT25K     0.986796
# 272320               Tuition and fees deduction Amt LT25K     0.988659
# 272321               Tuition and fees deduction Amt LT25K     0.992785
# 272322               Tuition and fees deduction Amt LT25K     0.999125
# 272323               Tuition and fees deduction Amt LT25K     0.961290
# 272324               Tuition and fees deduction Amt LT25K     0.963436
# 272325               Tuition and fees deduction Amt LT25K     0.970398
# 272326               Tuition and fees deduction Amt LT25K     0.969250
# 272327               Tuition and fees deduction Amt LT25K     0.964985
# 272328               Tuition and fees deduction Amt LT25K     0.961588
# 272329               Tuition and fees deduction Amt LT25K     0.970408
# 272330               Tuition and fees deduction Amt LT25K     0.969919
# 272331               Tuition and fees deduction Amt LT25K     0.955158
# 272332           Tuition and fees deduction Ct 100KLT200K     0.952329
# 272333           Tuition and fees deduction Ct 100KLT200K     0.975322
# 272334           Tuition and fees deduction Ct 100KLT200K     0.970445
# 272335           Tuition and fees deduction Ct 100KLT200K     0.959038
# 272336           Tuition and fees deduction Ct 100KLT200K     0.968699
# 272337           Tuition and fees deduction Ct 100KLT200K     0.964166
# 272338             Tuition and fees deduction Ct 25KLT50K     0.983451
# 272339             Tuition and fees deduction Ct 25KLT50K     0.987779
# 272340             Tuition and fees deduction Ct 25KLT50K     0.988263
# 272341             Tuition and fees deduction Ct 25KLT50K     0.965492
# 272342             Tuition and fees deduction Ct 25KLT50K     0.967874
# 272343             Tuition and fees deduction Ct 25KLT50K     0.969483
# 272344             Tuition and fees deduction Ct 25KLT50K     0.973918
# 272345             Tuition and fees deduction Ct 25KLT50K     0.968627
# 272346             Tuition and fees deduction Ct 25KLT50K     0.965745
# 272347             Tuition and fees deduction Ct 25KLT50K     0.968681
# 272348             Tuition and fees deduction Ct 25KLT50K     0.975723
# 272349             Tuition and fees deduction Ct 25KLT50K     0.951672
# 272350             Tuition and fees deduction Ct 50KLT75K     0.992755
# 272351             Tuition and fees deduction Ct 50KLT75K     0.989927
# 272352             Tuition and fees deduction Ct 50KLT75K     0.965967
# 272353             Tuition and fees deduction Ct 50KLT75K     0.975877
# 272354             Tuition and fees deduction Ct 50KLT75K     0.975497
# 272355             Tuition and fees deduction Ct 50KLT75K     0.975706
# 272356             Tuition and fees deduction Ct 50KLT75K     0.982703
# 272357             Tuition and fees deduction Ct 50KLT75K     0.969786
# 272358             Tuition and fees deduction Ct 50KLT75K     0.975941
# 272359             Tuition and fees deduction Ct 50KLT75K     0.973286
# 272360             Tuition and fees deduction Ct 50KLT75K     0.974340
# 272361             Tuition and fees deduction Ct 50KLT75K     0.979464
# 272362                  Tuition and fees deduction Ct All     0.994075
# 272363                  Tuition and fees deduction Ct All     0.969016
# 272364                  Tuition and fees deduction Ct All     0.959068
# 272365                  Tuition and fees deduction Ct All     0.962690
# 272366                  Tuition and fees deduction Ct All     0.982686
# 272367                  Tuition and fees deduction Ct All     0.970391
# 272368                  Tuition and fees deduction Ct All     0.971267
# 272369                  Tuition and fees deduction Ct All     0.962427
# 272370                  Tuition and fees deduction Ct All     0.960435
# 272371                  Tuition and fees deduction Ct All     0.983628
# 272372                  Tuition and fees deduction Ct All     0.968713
# 272373                  Tuition and fees deduction Ct All     0.952709
# 272374                  Tuition and fees deduction Ct All     0.954385
# 272375                Tuition and fees deduction Ct LT25K     0.966687
# 272376                Tuition and fees deduction Ct LT25K     0.969075
# 272377                Tuition and fees deduction Ct LT25K     0.976378
# 272378                Tuition and fees deduction Ct LT25K     0.974357
# 272379                Tuition and fees deduction Ct LT25K     0.950385
# 272380                Tuition and fees deduction Ct LT25K     0.970467
# 272381                Tuition and fees deduction Ct LT25K     0.967444
# 272382                Tuition and fees deduction Ct LT25K     0.975955
# 272383                Tuition and fees deduction Ct LT25K     0.975083
# 272384                Tuition and fees deduction Ct LT25K     0.955498
# 272385           Unemployment compensation Amt 100KLT200K     0.967114
# 272386           Unemployment compensation Amt 100KLT200K     0.954366
# 272387           Unemployment compensation Amt 100KLT200K     0.979332
# 272388           Unemployment compensation Amt 100KLT200K     0.999547
# 272389           Unemployment compensation Amt 100KLT200K     0.966244
# 272390           Unemployment compensation Amt 100KLT200K     0.985529
# 272391             Unemployment compensation Amt 25KLT50K     0.993416
# 272392             Unemployment compensation Amt 25KLT50K     0.967504
# 272393             Unemployment compensation Amt 25KLT50K     0.997807
# 272394             Unemployment compensation Amt 25KLT50K     0.984038
# 272395             Unemployment compensation Amt 25KLT50K     0.997484
# 272396             Unemployment compensation Amt 25KLT50K     0.993635
# 272397             Unemployment compensation Amt 25KLT50K     0.962258
# 272398             Unemployment compensation Amt 25KLT50K     0.995700
# 272399             Unemployment compensation Amt 25KLT50K     0.969043
# 272400             Unemployment compensation Amt 50KLT75K     0.970136
# 272401             Unemployment compensation Amt 50KLT75K     0.996416
# 272402             Unemployment compensation Amt 50KLT75K     0.977229
# 272403             Unemployment compensation Amt 50KLT75K     0.950256
# 272404             Unemployment compensation Amt 50KLT75K     0.991725
# 272405             Unemployment compensation Amt 50KLT75K     0.998256
# 272406             Unemployment compensation Amt 50KLT75K     0.965515
# 272407             Unemployment compensation Amt 50KLT75K     0.993943
# 272408             Unemployment compensation Amt 50KLT75K     0.962583
# 272409            Unemployment compensation Amt 75KLT100K     0.976402
# 272410            Unemployment compensation Amt 75KLT100K     0.967870
# 272411            Unemployment compensation Amt 75KLT100K     0.971270
# 272412            Unemployment compensation Amt 75KLT100K     0.968294
# 272413            Unemployment compensation Amt 75KLT100K     0.998315
# 272414            Unemployment compensation Amt 75KLT100K     0.973939
# 272415                  Unemployment compensation Amt All     0.978920
# 272416                  Unemployment compensation Amt All     0.959164
# 272417                  Unemployment compensation Amt All     0.996143
# 272418                  Unemployment compensation Amt All     0.995805
# 272419                  Unemployment compensation Amt All     0.972175
# 272420                  Unemployment compensation Amt All     0.997711
# 272421                  Unemployment compensation Amt All     0.964652
# 272422               Unemployment compensation Amt GE200K     0.978748
# 272423               Unemployment compensation Amt GE200K     0.997457
# 272424                Unemployment compensation Amt LT25K     0.982483
# 272425                Unemployment compensation Amt LT25K     0.979416
# 272426                Unemployment compensation Amt LT25K     0.982846
# 272427                Unemployment compensation Amt LT25K     0.993479
# 272428            Unemployment compensation Ct 100KLT200K     0.967223
# 272429            Unemployment compensation Ct 100KLT200K     0.985359
# 272430              Unemployment compensation Ct 25KLT50K     0.994430
# 272431              Unemployment compensation Ct 25KLT50K     0.968550
# 272432              Unemployment compensation Ct 25KLT50K     0.997936
# 272433              Unemployment compensation Ct 25KLT50K     0.973243
# 272434              Unemployment compensation Ct 50KLT75K     0.965370
# 272435              Unemployment compensation Ct 50KLT75K     0.996195
# 272436              Unemployment compensation Ct 50KLT75K     0.968634
# 272437             Unemployment compensation Ct 75KLT100K     0.971692
# 272438                   Unemployment compensation Ct All     0.975798
# 272439  volunteer prepared w Earned Income Credit 25KL...     0.975318
# 272440  volunteer prepared w Earned Income Credit 25KL...     0.957010
# 272441      volunteer prepared w Earned Income Credit All     0.997435
# 272442                                      category_cd_H     1.000000
# 272443                                      category_cd_T     1.000000
# 272444                                grade_range_cd_3-12     1.000000
# 272445                                grade_range_cd_7-12     1.000000
# 272446                                grade_range_cd_7-13     1.000000
# 272447                                grade_range_cd_7-13     1.000000
# 272448  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 272449  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 272450                                  sna_pgm_type_cd_Y     1.000000
# 272451                         grades_1_to_1_access_11:12     1.000000
# 272452             grades_1_to_1_access_7:8:9:10:11:12:13     1.000000
# 272453                             grades_1_to_1_access_9     0.959719
#
# [272454 rows x 3 columns]

# %%
print ('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  1039  highly correlated fields.
# ['st_salary_expense_pct',
#  'st_services_expense_pct',
#  'st_supplies_expense_pct',
#  'st_instruct_equip_exp_pct',
#  'st_federal_perpupil_num',
#  'st_local_perpupil_num',
#  'st_state_perpupil_num',
#  'Overall Achievement Score',
#  'ACTCompositeScore_UNCMin_All',
#  'ACTEnglish_ACTBenchmark_All',
#  'ACTReading_ACTBenchmark_All',
#  'ACTSubtests_BenchmarksMet_All',
#  'EOCBiology_CACR_All',
#  'EOCBiology_GLP_All',
#  'EOCEnglish2_CACR_All',
#  'EOCEnglish2_GLP_All',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_CACR_All',
#  'EOG/EOCSubjects_GLP_All',
#  'GraduationRate_4yr_All',
#  'ACTSubtests_BenchmarksMet_Female',
#  'ACTWriting_ACTBenchmark_Female',
#  'EOCBiology_GLP_Female',
#  'EOCEnglish2_GLP_Female',
#  'EOCMathI_CACR_Female',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'ACTEnglish_ACTBenchmark_Male',
#  'ACTReading_ACTBenchmark_Male',
#  'ACTSubtests_BenchmarksMet_Male',
#  'EOCBiology_GLP_Male',
#  'EOCEnglish2_GLP_Male',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'ACTEnglish_ACTBenchmark_AmericanIndian',
#  'ACTReading_ACTBenchmark_AmericanIndian',
#  'ACTScience_ACTBenchmark_AmericanIndian',
#  'EOCBiology_GLP_AmericanIndian',
#  'EOCEnglish2_GLP_AmericanIndian',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_CACR_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'ACTEnglish_ACTBenchmark_Asian',
#  'ACTMath_ACTBenchmark_Asian',
#  'ACTReading_ACTBenchmark_Asian',
#  'ACTScience_ACTBenchmark_Asian',
#  'EOCBiology_GLP_Asian',
#  'EOCEnglish2_GLP_Asian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_CACR_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOCBiology_GLP_Black',
#  'EOCEnglish2_GLP_Black',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_CACR_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOCBiology_GLP_Hispanic',
#  'EOCEnglish2_GLP_Hispanic',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_CACR_Hispanic',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'ACTEnglish_ACTBenchmark_TwoorMoreRaces',
#  'EOCBiology_GLP_TwoorMoreRaces',
#  'EOCEnglish2_GLP_TwoorMoreRaces',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_CACR_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'ACTEnglish_ACTBenchmark_White',
#  'ACTReading_ACTBenchmark_White',
#  'EOCBiology_GLP_White',
#  'EOCEnglish2_GLP_White',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_CACR_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOCBiology_GLP_EDS',
#  'EOCEnglish2_GLP_EDS',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_CACR_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_CACR_LEP',
#  'ACTEnglish_ACTBenchmark_AIG',
#  'ACTReading_ACTBenchmark_AIG',
#  'EOCBiology_GLP_AIG',
#  'EOCEnglish2_GLP_AIG',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOG/EOCSubjects_CACR_AIG',
#  'EOG/EOCSubjects_GLP_AIG',
#  'st_sat_participation_pct',
#  'st_ap_participation_pct',
#  'st_ap_pct_3_or_above',
#  'st_ib_pct_4_or_above',
#  'ap_ib_courses',
#  'lea_ap_ib_courses',
#  'st_ap_ib_courses',
#  'st_cte_courses',
#  'st_univ_college_courses',
#  'st_long_susp_per_c_num',
#  'st_expelled_per_c_num',
#  'st_stud_internet_comp_num',
#  'lea_avg_age_media_collection',
#  'st_books_per_student',
#  'st_wap_per_classroom',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'st_flicensed_teach_pct',
#  'st_tchyrs_0thru3_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_tchyrs_11plus_pct',
#  'st_class_teach_num',
#  'st_nbpts_num',
#  'st_advance_dgr_pct',
#  'st_1yr_tchr_trnovr_pct',
#  'st_emer_prov_teach_pct',
#  'st_lateral_teach_pct',
#  'st_prinyrs_0thru3_pct',
#  'st_prinyrs_4thru10_pct',
#  'st_prinyrs_11plus_pct',
#  'st_prin_advance_dgr_pct',
#  'st_1yr_prin_trnovr_pct',
#  'st_prin_male_pct',
#  'st_prin_black_pct',
#  'st_prin_white_pct',
#  'st_prin_other_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'WhiteMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'WhiteFemalePct',
#  'Assault Rate',
#  '(TCE) prepared returns Ct 50KLT75K',
#  '(TCE) prepared returns Ct All',
#  '(TCE) prepared returns Ct LT25K',
#  '(VITA) prepared returns Ct 75KLT100K',
#  '(VITA) prepared returns Ct All',
#  '(VITA) prepared returns Ct LT25K',
#  'Add child tax credit Amt 25KLT50K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Advance premium tax credit Amt 100KLT200K',
#  'Advance premium tax credit Amt 25KLT50K',
#  'Advance premium tax credit Amt 50KLT75K',
#  'Advance premium tax credit Amt 75KLT100K',
#  'Advance premium tax credit Amt All',
#  'Advance premium tax credit Amt LT25K',
#  'Advance premium tax credit Ct 100KLT200K',
#  'Advance premium tax credit Ct 25KLT50K',
#  'Advance premium tax credit Ct 50KLT75K',
#  'Advance premium tax credit Ct 75KLT100K',
#  'Advance premium tax credit Ct All',
#  'Advance premium tax credit Ct GE200K',
#  'Advance premium tax credit Ct LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Deductible points Amt 100KLT200K',
#  'Deductible points Amt 25KLT50K',
#  'Deductible points Amt 50KLT75K',
#  'Deductible points Amt 75KLT100K',
#  'Deductible points Amt All',
#  'Deductible points Amt GE200K',
#  'Deductible points Ct 100KLT200K',
#  'Deductible points Ct 25KLT50K',
#  'Deductible points Ct 50KLT75K',
#  'Deductible points Ct 75KLT100K',
#  'Deductible points Ct All',
#  'Deductible points Ct GE200K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct 50KLT75K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess advance premium tax credit repayment Amt 100KLT200K',
#  'Excess advance premium tax credit repayment Amt 25KLT50K',
#  'Excess advance premium tax credit repayment Amt 50KLT75K',
#  'Excess advance premium tax credit repayment Amt 75KLT100K',
#  'Excess advance premium tax credit repayment Amt All',
#  'Excess advance premium tax credit repayment Amt LT25K',
#  'Excess advance premium tax credit repayment Ct 100KLT200K',
#  'Excess advance premium tax credit repayment Ct 25KLT50K',
#  'Excess advance premium tax credit repayment Ct 50KLT75K',
#  'Excess advance premium tax credit repayment Ct 75KLT100K',
#  'Excess advance premium tax credit repayment Ct All',
#  'Excess advance premium tax credit repayment Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct 50KLT75K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'Health care individual responsibility payment Amt 100KLT200K',
#  'Health care individual responsibility payment Amt 25KLT50K',
#  'Health care individual responsibility payment Amt 50KLT75K',
#  'Health care individual responsibility payment Amt 75KLT100K',
#  'Health care individual responsibility payment Amt All',
#  'Health care individual responsibility payment Amt LT25K',
#  'Health care individual responsibility payment Ct 100KLT200K',
#  'Health care individual responsibility payment Ct 25KLT50K',
#  'Health care individual responsibility payment Ct 50KLT75K',
#  'Health care individual responsibility payment Ct 75KLT100K',
#  'Health care individual responsibility payment Ct All',
#  'Health care individual responsibility payment Ct GE200K',
#  'Health care individual responsibility payment Ct LT25K',
#  'Home mortgage interest paid Amt 100KLT200K',
#  'Home mortgage interest paid Amt 25KLT50K',
#  'Home mortgage interest paid Amt 50KLT75K',
#  'Home mortgage interest paid Amt 75KLT100K',
#  'Home mortgage interest paid Amt All',
#  'Home mortgage interest paid Amt GE200K',
#  'Home mortgage interest paid Amt LT25K',
#  'Home mortgage interest paid Ct 100KLT200K',
#  'Home mortgage interest paid Ct 25KLT50K',
#  'Home mortgage interest paid Ct 50KLT75K',
#  'Home mortgage interest paid Ct 75KLT100K',
#  'Home mortgage interest paid Ct All',
#  'Home mortgage interest paid Ct GE200K',
#  'Home mortgage interest paid Ct LT25K',
#  'Home mortgage interest paid from personal seller Amt 100KLT200K',
#  'Home mortgage interest paid from personal seller Amt 25KLT50K',
#  'Home mortgage interest paid from personal seller Amt 50KLT75K',
#  'Home mortgage interest paid from personal seller Amt 75KLT100K',
#  'Home mortgage interest paid from personal seller Amt All',
#  'Home mortgage interest paid from personal seller Amt GE200K',
#  'Home mortgage interest paid from personal seller Ct 100KLT200K',
#  'Home mortgage interest paid from personal seller Ct 25KLT50K',
#  'Home mortgage interest paid from personal seller Ct 50KLT75K',
#  'Home mortgage interest paid from personal seller Ct 75KLT100K',
#  'Home mortgage interest paid from personal seller Ct All',
#  'Home mortgage interest paid from personal seller Ct GE200K',
#  'Home mortgage interest paid from personal seller Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Individual retirement arrangement payments Amt 100KLT200K',
#  'Individual retirement arrangement payments Amt 25KLT50K',
#  'Individual retirement arrangement payments Amt 50KLT75K',
#  'Individual retirement arrangement payments Amt 75KLT100K',
#  'Individual retirement arrangement payments Amt All',
#  'Individual retirement arrangement payments Amt GE200K',
#  'Individual retirement arrangement payments Amt LT25K',
#  'Individual retirement arrangement payments Ct 100KLT200K',
#  'Individual retirement arrangement payments Ct 25KLT50K',
#  'Individual retirement arrangement payments Ct 50KLT75K',
#  'Individual retirement arrangement payments Ct 75KLT100K',
#  'Individual retirement arrangement payments Ct All',
#  'Individual retirement arrangement payments Ct GE200K',
#  'Individual retirement arrangement payments Ct LT25K',
#  'Investment interest paid Amt 100KLT200K',
#  'Investment interest paid Amt 50KLT75K',
#  'Investment interest paid Amt 75KLT100K',
#  'Investment interest paid Amt All',
#  'Investment interest paid Amt GE200K',
#  'Investment interest paid Ct 100KLT200K',
#  'Investment interest paid Ct 25KLT50K',
#  'Investment interest paid Ct 50KLT75K',
#  'Investment interest paid Ct 75KLT100K',
#  'Investment interest paid Ct All',
#  'Investment interest paid Ct GE200K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct 100KLT200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Net limited misc deduction Amt 100KLT200K',
#  'Net limited misc deduction Amt 25KLT50K',
#  'Net limited misc deduction Amt 50KLT75K',
#  'Net limited misc deduction Amt 75KLT100K',
#  'Net limited misc deduction Amt All',
#  'Net limited misc deduction Amt GE200K',
#  'Net limited misc deduction Amt LT25K',
#  'Net limited misc deduction Ct 100KLT200K',
#  'Net limited misc deduction Ct 25KLT50K',
#  'Net limited misc deduction Ct 50KLT75K',
#  'Net limited misc deduction Ct 75KLT100K',
#  'Net limited misc deduction Ct All',
#  'Net limited misc deduction Ct GE200K',
#  'Net limited misc deduction Ct LT25K',
#  'Net premium tax credit Amt 25KLT50K',
#  'Net premium tax credit Amt 50KLT75K',
#  'Net premium tax credit Amt All',
#  'Net premium tax credit Amt LT25K',
#  'Net premium tax credit Ct 25KLT50K',
#  'Net premium tax credit Ct 50KLT75K',
#  'Net premium tax credit Ct All',
#  'Net premium tax credit Ct LT25K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of elderly returns 100KLT200K',
#  'Number of elderly returns 25KLT50K',
#  'Number of elderly returns 50KLT75K',
#  'Number of elderly returns 75KLT100K',
#  'Number of elderly returns All',
#  'Number of elderly returns GE200K',
#  'Number of elderly returns LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of refund anticipation check returns 100KLT200K',
#  'Number of refund anticipation check returns 25KLT50K',
#  'Number of refund anticipation check returns 50KLT75K',
#  'Number of refund anticipation check returns 75KLT100K',
#  'Number of refund anticipation check returns All',
#  'Number of refund anticipation check returns GE200K',
#  'Number of refund anticipation check returns LT25K',
#  'Number of refund anticipation loan returns 25KLT50K',
#  'Number of refund anticipation loan returns All',
#  'Number of refund anticipation loan returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  'Number of volunteer prepared returns Tot 100KLT200K',
#  'Number of volunteer prepared returns Tot 25KLT50K',
#  'Number of volunteer prepared returns Tot 75KLT100K',
#  'Number of volunteer prepared returns Tot All',
#  'Number of volunteer prepared returns Tot LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Other non-limited misc deduction Amt 100KLT200K',
#  'Other non-limited misc deduction Amt 25KLT50K',
#  'Other non-limited misc deduction Amt All',
#  'Other non-limited misc deduction Amt GE200K',
#  'Other non-limited misc deduction Ct 100KLT200K',
#  'Other non-limited misc deduction Ct 25KLT50K',
#  'Other non-limited misc deduction Ct 50KLT75K',
#  'Other non-limited misc deduction Ct All',
#  'Other non-limited misc deduction Ct GE200K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Personal property taxes Amt 100KLT200K',
#  'Personal property taxes Amt 25KLT50K',
#  'Personal property taxes Amt 50KLT75K',
#  'Personal property taxes Amt 75KLT100K',
#  'Personal property taxes Amt All',
#  'Personal property taxes Amt GE200K',
#  'Personal property taxes Amt LT25K',
#  'Personal property taxes Ct 100KLT200K',
#  'Personal property taxes Ct 25KLT50K',
#  'Personal property taxes Ct 50KLT75K',
#  'Personal property taxes Ct 75KLT100K',
#  'Personal property taxes Ct All',
#  'Personal property taxes Ct GE200K',
#  'Personal property taxes Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Qualified mortgage insurance premiums Amt 100KLT200K',
#  'Qualified mortgage insurance premiums Amt 25KLT50K',
#  'Qualified mortgage insurance premiums Amt 50KLT75K',
#  'Qualified mortgage insurance premiums Amt 75KLT100K',
#  'Qualified mortgage insurance premiums Amt All',
#  'Qualified mortgage insurance premiums Amt LT25K',
#  'Qualified mortgage insurance premiums Ct 100KLT200K',
#  'Qualified mortgage insurance premiums Ct 25KLT50K',
#  'Qualified mortgage insurance premiums Ct 50KLT75K',
#  'Qualified mortgage insurance premiums Ct 75KLT100K',
#  'Qualified mortgage insurance premiums Ct All',
#  'Qualified mortgage insurance premiums Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Retirement savings contributions credit Amt 25KLT50K',
#  'Retirement savings contributions credit Amt 50KLT75K',
#  'Retirement savings contributions credit Amt All',
#  'Retirement savings contributions credit Amt LT25K',
#  'Retirement savings contributions credit Ct 25KLT50K',
#  'Retirement savings contributions credit Ct 50KLT75K',
#  'Retirement savings contributions credit Ct All',
#  'Retirement savings contributions credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employed (Keogh) retirement plans Amt 100KLT200K',
#  'Self-employed (Keogh) retirement plans Amt 25KLT50K',
#  'Self-employed (Keogh) retirement plans Amt 50KLT75K',
#  'Self-employed (Keogh) retirement plans Amt All',
#  'Self-employed (Keogh) retirement plans Amt GE200K',
#  'Self-employed (Keogh) retirement plans Ct 100KLT200K',
#  'Self-employed (Keogh) retirement plans Ct 25KLT50K',
#  'Self-employed (Keogh) retirement plans Ct 50KLT75K',
#  'Self-employed (Keogh) retirement plans Ct 75KLT100K',
#  'Self-employed (Keogh) retirement plans Ct All',
#  'Self-employed (Keogh) retirement plans Ct GE200K',
#  'Self-employed health insurance deduction Amt 100KLT200K',
#  'Self-employed health insurance deduction Amt 25KLT50K',
#  'Self-employed health insurance deduction Amt 50KLT75K',
#  'Self-employed health insurance deduction Amt 75KLT100K',
#  'Self-employed health insurance deduction Amt All',
#  'Self-employed health insurance deduction Amt GE200K',
#  'Self-employed health insurance deduction Amt LT25K',
#  'Self-employed health insurance deduction Ct 100KLT200K',
#  'Self-employed health insurance deduction Ct 25KLT50K',
#  'Self-employed health insurance deduction Ct 50KLT75K',
#  'Self-employed health insurance deduction Ct 75KLT100K',
#  'Self-employed health insurance deduction Ct All',
#  'Self-employed health insurance deduction Ct GE200K',
#  'Self-employed health insurance deduction Ct LT25K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt GE200K',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  'Taxable interest Ct 100KLT200K',
#  'Taxable interest Ct 25KLT50K',
#  'Taxable interest Ct 50KLT75K',
#  'Taxable interest Ct 75KLT100K',
#  'Taxable interest Ct All',
#  'Taxable interest Ct GE200K',
#  'Taxable interest Ct LT25K',
#  'Tot Add Medicare tax Amt 100KLT200K',
#  'Tot Add Medicare tax Amt 50KLT75K',
#  'Tot Add Medicare tax Amt All',
#  'Tot Add Medicare tax Amt GE200K',
#  'Tot Add Medicare tax Ct 100KLT200K',
#  'Tot Add Medicare tax Ct 25KLT50K',
#  'Tot Add Medicare tax Ct 50KLT75K',
#  'Tot Add Medicare tax Ct All',
#  'Tot Add Medicare tax Ct GE200K',
#  'Tot charitable contributions Amt 100KLT200K',
#  'Tot charitable contributions Amt 25KLT50K',
#  'Tot charitable contributions Amt 50KLT75K',
#  'Tot charitable contributions Amt 75KLT100K',
#  'Tot charitable contributions Amt All',
#  'Tot charitable contributions Amt GE200K',
#  'Tot charitable contributions Amt LT25K',
#  'Tot charitable contributions Ct 100KLT200K',
#  'Tot charitable contributions Ct 25KLT50K',
#  'Tot charitable contributions Ct 50KLT75K',
#  'Tot charitable contributions Ct 75KLT100K',
#  'Tot charitable contributions Ct All',
#  'Tot charitable contributions Ct GE200K',
#  'Tot charitable contributions Ct LT25K',
#  'Tot income Amt 100KLT200K',
#  'Tot income Amt 25KLT50K',
#  'Tot income Amt 50KLT75K',
#  'Tot income Amt 75KLT100K',
#  'Tot income Amt All',
#  'Tot income Amt GE200K',
#  'Tot income Amt LT25K',
#  'Tot income Ct 100KLT200K',
#  'Tot income Ct 25KLT50K',
#  'Tot income Ct 50KLT75K',
#  'Tot income Ct 75KLT100K',
#  'Tot income Ct All',
#  'Tot income Ct GE200K',
#  'Tot income Ct LT25K',
#  'Tot itemized deductions Amt 100KLT200K',
#  'Tot itemized deductions Amt 25KLT50K',
#  'Tot itemized deductions Amt 50KLT75K',
#  'Tot itemized deductions Amt 75KLT100K',
#  'Tot itemized deductions Amt All',
#  'Tot itemized deductions Amt GE200K',
#  'Tot itemized deductions Amt LT25K',
#  'Tot itemized deductions Amt of AGI 100KLT200K',
#  'Tot itemized deductions Amt of AGI 25KLT50K',
#  'Tot itemized deductions Amt of AGI 50KLT75K',
#  'Tot itemized deductions Amt of AGI 75KLT100K',
#  'Tot itemized deductions Amt of AGI All',
#  'Tot itemized deductions Amt of AGI GE200K',
#  'Tot itemized deductions Amt of AGI LT25K',
#  'Tot itemized deductions Ct 100KLT200K',
#  'Tot itemized deductions Ct 25KLT50K',
#  'Tot itemized deductions Ct 50KLT75K',
#  'Tot itemized deductions Ct 75KLT100K',
#  'Tot itemized deductions Ct All',
#  'Tot itemized deductions Ct GE200K',
#  'Tot itemized deductions Ct LT25K',
#  'Tot medical and dental expenses deduction Amt 100KLT200K',
#  'Tot medical and dental expenses deduction Amt 25KLT50K',
#  'Tot medical and dental expenses deduction Amt 50KLT75K',
#  'Tot medical and dental expenses deduction Amt 75KLT100K',
#  'Tot medical and dental expenses deduction Amt All',
#  'Tot medical and dental expenses deduction Amt GE200K',
#  'Tot medical and dental expenses deduction Amt LT25K',
#  'Tot medical and dental expenses deduction Ct 100KLT200K',
#  'Tot medical and dental expenses deduction Ct 25KLT50K',
#  'Tot medical and dental expenses deduction Ct 50KLT75K',
#  'Tot medical and dental expenses deduction Ct 75KLT100K',
#  'Tot medical and dental expenses deduction Ct All',
#  'Tot medical and dental expenses deduction Ct GE200K',
#  'Tot medical and dental expenses deduction Ct LT25K',
#  'Tot premium tax credit Amt 25KLT50K',
#  'Tot premium tax credit Amt 50KLT75K',
#  'Tot premium tax credit Amt 75KLT100K',
#  'Tot premium tax credit Amt All',
#  'Tot premium tax credit Amt LT25K',
#  'Tot premium tax credit Ct 25KLT50K',
#  'Tot premium tax credit Ct 50KLT75K',
#  'Tot premium tax credit Ct 75KLT100K',
#  'Tot premium tax credit Ct All',
#  'Tot premium tax credit Ct LT25K',
#  'Tot statuory adjustments Amt 100KLT200K',
#  'Tot statuory adjustments Amt 25KLT50K',
#  'Tot statuory adjustments Amt 50KLT75K',
#  'Tot statuory adjustments Amt 75KLT100K',
#  'Tot statuory adjustments Amt All',
#  'Tot statuory adjustments Amt GE200K',
#  'Tot statuory adjustments Amt LT25K',
#  'Tot statuory adjustments Ct 100KLT200K',
#  'Tot statuory adjustments Ct 25KLT50K',
#  'Tot statuory adjustments Ct 50KLT75K',
#  'Tot statuory adjustments Ct 75KLT100K',
#  'Tot statuory adjustments Ct All',
#  'Tot statuory adjustments Ct GE200K',
#  'Tot statuory adjustments Ct LT25K',
#  'Tot tax credits Amt 100KLT200K',
#  'Tot tax credits Amt 25KLT50K',
#  'Tot tax credits Amt 50KLT75K',
#  'Tot tax credits Amt 75KLT100K',
#  'Tot tax credits Amt All',
#  'Tot tax credits Amt GE200K',
#  'Tot tax credits Amt LT25K',
#  'Tot tax credits Ct 100KLT200K',
#  'Tot tax credits Ct 25KLT50K',
#  'Tot tax credits Ct 50KLT75K',
#  'Tot tax credits Ct 75KLT100K',
#  'Tot tax credits Ct All',
#  'Tot tax credits Ct GE200K',
#  'Tot tax credits Ct LT25K',
#  'Tot tax liability Amt 100KLT200K',
#  'Tot tax liability Amt 25KLT50K',
#  'Tot tax liability Amt 50KLT75K',
#  'Tot tax liability Amt 75KLT100K',
#  'Tot tax liability Amt All',
#  'Tot tax liability Amt GE200K',
#  'Tot tax liability Amt LT25K',
#  'Tot tax liability Ct 100KLT200K',
#  'Tot tax liability Ct 25KLT50K',
#  'Tot tax liability Ct 50KLT75K',
#  'Tot tax liability Ct 75KLT100K',
#  'Tot tax liability Ct All',
#  'Tot tax liability Ct GE200K',
#  'Tot tax liability Ct LT25K',
#  'Tot tax payments Amt 100KLT200K',
#  'Tot tax payments Amt 25KLT50K',
#  'Tot tax payments Amt 50KLT75K',
#  'Tot tax payments Amt 75KLT100K',
#  'Tot tax payments Amt All',
#  'Tot tax payments Amt GE200K',
#  'Tot tax payments Amt LT25K',
#  'Tot tax payments Ct 100KLT200K',
#  'Tot tax payments Ct 25KLT50K',
#  'Tot tax payments Ct 50KLT75K',
#  'Tot tax payments Ct 75KLT100K',
#  'Tot tax payments Ct All',
#  'Tot tax payments Ct GE200K',
#  'Tot tax payments Ct LT25K',
#  'Tot taxes paid Amt 100KLT200K',
#  'Tot taxes paid Amt 25KLT50K',
#  'Tot taxes paid Amt 50KLT75K',
#  'Tot taxes paid Amt 75KLT100K',
#  'Tot taxes paid Amt All',
#  'Tot taxes paid Amt GE200K',
#  'Tot taxes paid Amt LT25K',
#  'Tot taxes paid Ct 100KLT200K',
#  'Tot taxes paid Ct 25KLT50K',
#  'Tot taxes paid Ct 50KLT75K',
#  'Tot taxes paid Ct 75KLT100K',
#  'Tot taxes paid Ct All',
#  'Tot taxes paid Ct GE200K',
#  'Tot taxes paid Ct LT25K',
#  'Tuition and fees deduction Amt 100KLT200K',
#  ...]

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 1586 entries, year to SRC_Grades_Devices_Sent_Home_9:10:12
# dtypes: float64(1491), int64(3), uint8(92)
# memory usage: 5.4 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 547 entries, year to SRC_Grades_Devices_Sent_Home_9:10:12
# dtypes: float64(464), int64(3), uint8(80)
# memory usage: 1.7 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Data columns (total 548 columns):
# year                                                          int64
# closed_ind                                                    float64
# new_ind                                                       float64
# student_num                                                   float64
# lea_avg_student_num                                           float64
# st_avg_student_num                                            float64
# 09_Size                                                       float64
# 10_Size                                                       float64
# 11_Size                                                       float64
# 12_Size                                                       float64
# Biology_Size                                                  float64
# English II_Size                                               float64
# Math I_Size                                                   float64
# lea_total_expense_num                                         float64
# lea_salary_expense_pct                                        float64
# lea_services_expense_pct                                      float64
# lea_supplies_expense_pct                                      float64
# lea_instruct_equip_exp_pct                                    float64
# lea_other_expense_pct                                         float64
# lea_federal_perpupil_num                                      float64
# lea_local_perpupil_num                                        float64
# lea_state_perpupil_num                                        float64
# st_total_expense_num                                          float64
# st_other_expense_pct                                          float64
# SPG Score                                                     float64
# EVAAS Growth Score                                            float64
# NC Math 1 Score                                               float64
# English II Score                                              float64
# Biology Score                                                 float64
# ACT Score                                                     float64
# ACT WorkKeys Score                                            float64
# Passing NC Math 3                                             float64
# 4-Year Cohort Graduation Rate Score                           float64
# ACTMath_ACTBenchmark_All                                      float64
# ACTScience_ACTBenchmark_All                                   float64
# ACTWorkKeys_SilverPlus_All                                    float64
# ACTWriting_ACTBenchmark_All                                   float64
# EOCSubjects_CACR_All                                          float64
# GraduationRate_5yr_All                                        float64
# ACTCompositeScore_UNCMin_Female                               float64
# ACTEnglish_ACTBenchmark_Female                                float64
# ACTMath_ACTBenchmark_Female                                   float64
# ACTReading_ACTBenchmark_Female                                float64
# ACTScience_ACTBenchmark_Female                                float64
# ACTWorkKeys_SilverPlus_Female                                 float64
# EOCBiology_CACR_Female                                        float64
# EOCEnglish2_CACR_Female                                       float64
# GraduationRate_4yr_Female                                     float64
# GraduationRate_5yr_Female                                     float64
# ACTCompositeScore_UNCMin_Male                                 float64
# ACTMath_ACTBenchmark_Male                                     float64
# ACTScience_ACTBenchmark_Male                                  float64
# ACTWorkKeys_SilverPlus_Male                                   float64
# ACTWriting_ACTBenchmark_Male                                  float64
# EOCBiology_CACR_Male                                          float64
# EOCEnglish2_CACR_Male                                         float64
# EOCMathI_CACR_Male                                            float64
# GraduationRate_4yr_Male                                       float64
# GraduationRate_5yr_Male                                       float64
# ACTCompositeScore_UNCMin_AmericanIndian                       float64
# ACTMath_ACTBenchmark_AmericanIndian                           float64
# ACTSubtests_BenchmarksMet_AmericanIndian                      float64
# ACTWorkKeys_SilverPlus_AmericanIndian                         float64
# ACTWriting_ACTBenchmark_AmericanIndian                        float64
# EOCBiology_CACR_AmericanIndian                                float64
# EOCEnglish2_CACR_AmericanIndian                               float64
# EOCMathI_CACR_AmericanIndian                                  float64
# EOCSubjects_CACR_AmericanIndian                               float64
# GraduationRate_4yr_AmericanIndian                             float64
# GraduationRate_5yr_AmericanIndian                             float64
# ACTCompositeScore_UNCMin_Asian                                float64
# ACTSubtests_BenchmarksMet_Asian                               float64
# ACTWorkKeys_SilverPlus_Asian                                  float64
# ACTWriting_ACTBenchmark_Asian                                 float64
# EOCBiology_CACR_Asian                                         float64
# EOCEnglish2_CACR_Asian                                        float64
# EOCMathI_CACR_Asian                                           float64
# EOCSubjects_CACR_Asian                                        float64
# GraduationRate_4yr_Asian                                      float64
# GraduationRate_5yr_Asian                                      float64
# ACTCompositeScore_UNCMin_Black                                float64
# ACTEnglish_ACTBenchmark_Black                                 float64
# ACTMath_ACTBenchmark_Black                                    float64
# ACTReading_ACTBenchmark_Black                                 float64
# ACTScience_ACTBenchmark_Black                                 float64
# ACTSubtests_BenchmarksMet_Black                               float64
# ACTWorkKeys_SilverPlus_Black                                  float64
# ACTWriting_ACTBenchmark_Black                                 float64
# EOCBiology_CACR_Black                                         float64
# EOCEnglish2_CACR_Black                                        float64
# EOCMathI_CACR_Black                                           float64
# EOCSubjects_CACR_Black                                        float64
# GraduationRate_4yr_Black                                      float64
# GraduationRate_5yr_Black                                      float64
# ACTCompositeScore_UNCMin_Hispanic                             float64
# ACTEnglish_ACTBenchmark_Hispanic                              float64
# ACTMath_ACTBenchmark_Hispanic                                 float64
# ACTReading_ACTBenchmark_Hispanic                              float64
# ACTScience_ACTBenchmark_Hispanic                              float64
# ACTSubtests_BenchmarksMet_Hispanic                            float64
# ACTWorkKeys_SilverPlus_Hispanic                               float64
# ACTWriting_ACTBenchmark_Hispanic                              float64
# EOCBiology_CACR_Hispanic                                      float64
# EOCEnglish2_CACR_Hispanic                                     float64
# EOCMathI_CACR_Hispanic                                        float64
# EOCSubjects_CACR_Hispanic                                     float64
# GraduationRate_4yr_Hispanic                                   float64
# GraduationRate_5yr_Hispanic                                   float64
# ACTCompositeScore_UNCMin_TwoorMoreRaces                       float64
# ACTMath_ACTBenchmark_TwoorMoreRaces                           float64
# ACTReading_ACTBenchmark_TwoorMoreRaces                        float64
# ACTScience_ACTBenchmark_TwoorMoreRaces                        float64
# ACTSubtests_BenchmarksMet_TwoorMoreRaces                      float64
# ACTWorkKeys_SilverPlus_TwoorMoreRaces                         float64
# ACTWriting_ACTBenchmark_TwoorMoreRaces                        float64
# EOCBiology_CACR_TwoorMoreRaces                                float64
# EOCEnglish2_CACR_TwoorMoreRaces                               float64
# EOCMathI_CACR_TwoorMoreRaces                                  float64
# EOCSubjects_CACR_TwoorMoreRaces                               float64
# GraduationRate_4yr_TwoorMoreRaces                             float64
# GraduationRate_5yr_TwoorMoreRaces                             float64
# ACTCompositeScore_UNCMin_White                                float64
# ACTMath_ACTBenchmark_White                                    float64
# ACTScience_ACTBenchmark_White                                 float64
# ACTSubtests_BenchmarksMet_White                               float64
# ACTWorkKeys_SilverPlus_White                                  float64
# ACTWriting_ACTBenchmark_White                                 float64
# EOCBiology_CACR_White                                         float64
# EOCEnglish2_CACR_White                                        float64
# EOCMathI_CACR_White                                           float64
# EOCSubjects_CACR_White                                        float64
# GraduationRate_4yr_White                                      float64
# GraduationRate_5yr_White                                      float64
# ACTCompositeScore_UNCMin_EDS                                  float64
# ACTEnglish_ACTBenchmark_EDS                                   float64
# ACTMath_ACTBenchmark_EDS                                      float64
# ACTReading_ACTBenchmark_EDS                                   float64
# ACTScience_ACTBenchmark_EDS                                   float64
# ACTSubtests_BenchmarksMet_EDS                                 float64
# ACTWorkKeys_SilverPlus_EDS                                    float64
# ACTWriting_ACTBenchmark_EDS                                   float64
# EOCBiology_CACR_EDS                                           float64
# EOCEnglish2_CACR_EDS                                          float64
# EOCMathI_CACR_EDS                                             float64
# EOCSubjects_CACR_EDS                                          float64
# GraduationRate_4yr_EDS                                        float64
# GraduationRate_5yr_EDS                                        float64
# ACTCompositeScore_UNCMin_LEP                                  float64
# ACTEnglish_ACTBenchmark_LEP                                   float64
# ACTMath_ACTBenchmark_LEP                                      float64
# ACTReading_ACTBenchmark_LEP                                   float64
# ACTScience_ACTBenchmark_LEP                                   float64
# ACTSubtests_BenchmarksMet_LEP                                 float64
# ACTWorkKeys_SilverPlus_LEP                                    float64
# ACTWriting_ACTBenchmark_LEP                                   float64
# EOCBiology_CACR_LEP                                           float64
# EOCBiology_GLP_LEP                                            float64
# EOCEnglish2_CACR_LEP                                          float64
# EOCEnglish2_GLP_LEP                                           float64
# EOCMathI_CACR_LEP                                             float64
# EOCMathI_GLP_LEP                                              float64
# EOCSubjects_CACR_LEP                                          float64
# EOCSubjects_GLP_LEP                                           float64
# EOG/EOCSubjects_GLP_LEP                                       float64
# GraduationRate_4yr_LEP                                        float64
# GraduationRate_5yr_LEP                                        float64
# ACTCompositeScore_UNCMin_SWD                                  float64
# ACTEnglish_ACTBenchmark_SWD                                   float64
# ACTMath_ACTBenchmark_SWD                                      float64
# ACTReading_ACTBenchmark_SWD                                   float64
# ACTScience_ACTBenchmark_SWD                                   float64
# ACTSubtests_BenchmarksMet_SWD                                 float64
# ACTWorkKeys_SilverPlus_SWD                                    float64
# ACTWriting_ACTBenchmark_SWD                                   float64
# EOCBiology_CACR_SWD                                           float64
# EOCBiology_GLP_SWD                                            float64
# EOCEnglish2_CACR_SWD                                          float64
# EOCEnglish2_GLP_SWD                                           float64
# EOCMathI_CACR_SWD                                             float64
# EOCMathI_GLP_SWD                                              float64
# EOCSubjects_CACR_SWD                                          float64
# EOCSubjects_GLP_SWD                                           float64
# EOG/EOCSubjects_CACR_SWD                                      float64
# EOG/EOCSubjects_GLP_SWD                                       float64
# GraduationRate_4yr_SWD                                        float64
# GraduationRate_5yr_SWD                                        float64
# ACTCompositeScore_UNCMin_AIG                                  float64
# ACTMath_ACTBenchmark_AIG                                      float64
# ACTScience_ACTBenchmark_AIG                                   float64
# ACTSubtests_BenchmarksMet_AIG                                 float64
# ACTWorkKeys_SilverPlus_AIG                                    float64
# ACTWriting_ACTBenchmark_AIG                                   float64
# EOCBiology_CACR_AIG                                           float64
# EOCEnglish2_CACR_AIG                                          float64
# EOCMathI_CACR_AIG                                             float64
# EOCSubjects_CACR_AIG                                          float64
# GraduationRate_4yr_AIG                                        float64
# GraduationRate_5yr_AIG                                        float64
# ACT_pTarget_PctMet                                            float64
# ACTWorkKeys_pTarget_PctMet                                    float64
# CurrentYearEOC_pTarget_PctMet                                 float64
# MathGr10_pTarget_PctMet                                       float64
# ReadingGr10_pTarget_PctMet                                    float64
# SciGr11_pTarget_PctMet                                        float64
# TotalTargets_pTarget_PctMet                                   float64
# sat_avg_score_num                                             float64
# lea_sat_avg_score_num                                         float64
# st_sat_avg_score_num                                          float64
# nat_sat_avg_score_num                                         float64
# sat_participation_pct                                         float64
# lea_sat_participation_pct                                     float64
# nat_sat_participation_pct                                     float64
# ap_participation_pct                                          float64
# lea_ap_participation_pct                                      float64
# ap_pct_3_or_above                                             float64
# lea_ap_pct_3_or_above                                         float64
# total_specialized_courses                                     float64
# cte_courses                                                   float64
# univ_college_courses                                          float64
# lea_total_specialized_courses                                 float64
# lea_cte_courses                                               float64
# lea_univ_college_courses                                      float64
# st_total_specialized_courses                                  float64
# ALL_All Students (Total or Subtotal_ENROLL_sch_pct            float64
# ECODIS_Economically Disadvantaged_ENROLL_sch_pct              float64
# F_Female_ENROLL_sch_pct                                       float64
# M_Male_ENROLL_sch_pct                                         float64
# MB_Black_ENROLL_sch_pct                                       float64
# MW_White_ENROLL_sch_pct                                       float64
# avg_daily_attend_pct                                          float64
# crime_per_c_num                                               float64
# short_susp_per_c_num                                          float64
# long_susp_per_c_num                                           float64
# expelled_per_c_num                                            float64
# stud_internet_comp_num                                        float64
# lea_avg_daily_attend_pct                                      float64
# lea_crime_per_c_num                                           float64
# lea_short_susp_per_c_num                                      float64
# lea_long_susp_per_c_num                                       float64
# lea_expelled_per_c_num                                        float64
# lea_stud_internet_comp_num                                    float64
# st_avg_daily_attend_pct                                       float64
# st_crime_per_c_num                                            float64
# st_short_susp_per_c_num                                       float64
# digital_media_pct                                             float64
# avg_age_media_collection                                      float64
# books_per_student                                             float64
# lea_books_per_student                                         float64
# st_avg_age_media_collection                                   float64
# wap_num                                                       float64
# wap_per_classroom                                             float64
# lea_wap_num                                                   float64
# lea_wap_per_classroom                                         float64
# st_wap_num                                                    float64
# total_class_teacher_num                                       int64
# total_nbpts_num                                               int64
# flicensed_teach_pct                                           float64
# tchyrs_0thru3_pct                                             float64
# tchyrs_4thru10_pct                                            float64
# tchyrs_11plus_pct                                             float64
# nbpts_num                                                     float64
# advance_dgr_pct                                               float64
# _1yr_tchr_trnovr_pct                                          float64
# lateral_teach_pct                                             float64
# lea_flicensed_teach_pct                                       float64
# lea_tchyrs_0thru3_pct                                         float64
# lea_tchyrs_4thru10_pct                                        float64
# lea_tchyrs_11plus_pct                                         float64
# lea_nbpts_num                                                 float64
# lea_advance_dgr_pct                                           float64
# lea_1yr_tchr_trnovr_pct                                       float64
# lea_emer_prov_teach_pct                                       float64
# st_prin_female_pct                                            float64
# 0-3 Years_LEA_Exp_Pct_Prin                                    float64
# 10+ Years_LEA_Exp_Pct_Prin                                    float64
# 4-10 Years_LEA_Exp_Pct_Prin                                   float64
# Accomplished_TCHR_Standard 1_Pct                              float64
# Accomplished_TCHR_Standard 2_Pct                              float64
# Accomplished_TCHR_Standard 3_Pct                              float64
# Accomplished_TCHR_Standard 4_Pct                              float64
# Accomplished_TCHR_Standard 5_Pct                              float64
# Developing_TCHR_Standard 1_Pct                                float64
# Developing_TCHR_Standard 2_Pct                                float64
# Developing_TCHR_Standard 3_Pct                                float64
# Developing_TCHR_Standard 4_Pct                                float64
# Developing_TCHR_Standard 5_Pct                                float64
# Distinguished_TCHR_Standard 1_Pct                             float64
# Distinguished_TCHR_Standard 2_Pct                             float64
# Distinguished_TCHR_Standard 3_Pct                             float64
# Distinguished_TCHR_Standard 4_Pct                             float64
# Distinguished_TCHR_Standard 5_Pct                             float64
# Does Not Meet Expected Growth_TCHR_Student Growth_Pct         float64
# Exceeds Expected Growth_TCHR_Student Growth_Pct               float64
# Meets Expected Growth_TCHR_Student Growth_Pct                 float64
# Not Demostrated_TCHR_Standard 1_Pct                           float64
# Not Demostrated_TCHR_Standard 2_Pct                           float64
# Not Demostrated_TCHR_Standard 3_Pct                           float64
# Not Demostrated_TCHR_Standard 4_Pct                           float64
# Not Demostrated_TCHR_Standard 5_Pct                           float64
# Proficient_TCHR_Standard 1_Pct                                float64
# Proficient_TCHR_Standard 2_Pct                                float64
# Proficient_TCHR_Standard 3_Pct                                float64
# Proficient_TCHR_Standard 4_Pct                                float64
# Proficient_TCHR_Standard 5_Pct                                float64
# IndianPct                                                     float64
# AsianPct                                                      float64
# HispanicPct                                                   float64
# BlackPct                                                      float64
# WhitePct                                                      float64
# PacificIslandPct                                              float64
# TwoOrMorePct                                                  float64
# HispanicMalePct                                               float64
# BlackMalePct                                                  float64
# PacificIslandMalePct                                          float64
# TwoOrMoreMalePct                                              float64
# MinorityMalePct                                               float64
# HispanicFemalePct                                             float64
# BlackFemalePct                                                float64
# MinorityFemalePct                                             float64
# PacificIslandFemalePct                                        float64
# TwoOrMoreFemalePct                                            float64
# Gr_9_Pct_Prof                                                 float64
# pct_eds                                                       float64
# AAVC_Concentrator_Ct                                          float64
# AGNR_Concentrator_Ct                                          float64
# ARCH_Concentrator_Ct                                          float64
# BMA_Concentrator_Ct                                           float64
# HLTH_Concentrator_Ct                                          float64
# HOSP_Concentrator_Ct                                          float64
# INFO_Concentrator_Ct                                          float64
# MANU_Concentrator_Ct                                          float64
# MRKT_Concentrator_Ct                                          float64
# STEM_Concentrator_Ct                                          float64
# TRAN_Concentrator_Ct                                          float64
# Number_Industry_Recognized_Crede                              float64
# Year                                                          float64
# Violent Rate                                                  float64
# Murder Rate                                                   float64
# Rape Rate                                                     float64
# Robbery Rate                                                  float64
# MVT Rate                                                      float64
# Arson Rate                                                    float64
# (TCE) prepared returns Ct 100KLT200K                          float64
# (TCE) prepared returns Ct 25KLT50K                            float64
# (TCE) prepared returns Ct 75KLT100K                           float64
# (TCE) prepared returns Ct GE200K                              float64
# (VITA) prepared returns Ct 100KLT200K                         float64
# (VITA) prepared returns Ct 25KLT50K                           float64
# (VITA) prepared returns Ct 50KLT75K                           float64
# (VITA) prepared returns Ct GE200K                             float64
# Add child tax credit Amt 100KLT200K                           float64
# Add child tax credit Amt 75KLT100K                            float64
# Add child tax credit Amt GE200K                               float64
# Add child tax credit Ct 100KLT200K                            float64
# Add child tax credit Ct GE200K                                float64
# Advance premium tax credit Amt GE200K                         float64
# Alternative minimum tax Amt 25KLT50K                          float64
# Alternative minimum tax Amt 50KLT75K                          float64
# Alternative minimum tax Amt 75KLT100K                         float64
# Alternative minimum tax Amt LT25K                             float64
# Alternative minimum tax Ct 50KLT75K                           float64
# Alternative minimum tax Ct 75KLT100K                          float64
# Alternative minimum tax Ct LT25K                              float64
# Child tax credit Amt GE200K                                   float64
# Child tax credit Ct GE200K                                    float64
# Deductible points Amt LT25K                                   float64
# Deductible points Ct LT25K                                    float64
# Domestic production activities deduction Amt 100KLT200K       float64
# Domestic production activities deduction Amt 25KLT50K         float64
# Domestic production activities deduction Amt 50KLT75K         float64
# Domestic production activities deduction Amt 75KLT100K        float64
# Domestic production activities deduction Amt LT25K            float64
# Domestic production activities deduction Ct 100KLT200K        float64
# Domestic production activities deduction Ct 25KLT50K          float64
# Domestic production activities deduction Ct 50KLT75K          float64
# Domestic production activities deduction Ct 75KLT100K         float64
# Domestic production activities deduction Ct LT25K             float64
# Earned income credit Amt 100KLT200K                           float64
# Earned income credit Amt 50KLT75K                             float64
# Earned income credit Amt 75KLT100K                            float64
# Earned income credit Amt GE200K                               float64
# Earned income credit Ct 100KLT200K                            float64
# Earned income credit Ct 75KLT100K                             float64
# Earned income credit Ct GE200K                                float64
# Excess advance premium tax credit repayment Amt GE200K        float64
# Excess advance premium tax credit repayment Ct GE200K         float64
# Excess earned income credit (refundable) Amt 100KLT200K       float64
# Excess earned income credit (refundable) Amt 50KLT75K         float64
# Excess earned income credit (refundable) Amt 75KLT100K        float64
# Excess earned income credit (refundable) Amt GE200K           float64
# Excess earned income credit (refundable) Ct 100KLT200K        float64
# Excess earned income credit (refundable) Ct 75KLT100K         float64
# Excess earned income credit (refundable) Ct GE200K            float64
# Health care individual responsibility payment Amt GE200K      float64
# Home mortgage interest paid from personal seller Amt LT25K    float64
# Investment interest paid Amt 25KLT50K                         float64
# Investment interest paid Amt LT25K                            float64
# Investment interest paid Ct LT25K                             float64
# Net investment income tax Amt 100KLT200K                      float64
# Net investment income tax Amt 25KLT50K                        float64
# Net investment income tax Amt 50KLT75K                        float64
# Net investment income tax Amt 75KLT100K                       float64
# Net investment income tax Amt LT25K                           float64
# Net investment income tax Ct 25KLT50K                         float64
# Net investment income tax Ct 50KLT75K                         float64
# Net investment income tax Ct 75KLT100K                        float64
# Net investment income tax Ct LT25K                            float64
# Net premium tax credit Amt 100KLT200K                         float64
# Net premium tax credit Amt 75KLT100K                          float64
# Net premium tax credit Amt GE200K                             float64
# Net premium tax credit Ct 100KLT200K                          float64
# Net premium tax credit Ct 75KLT100K                           float64
# Net premium tax credit Ct GE200K                              float64
# Nonrefundable edu credit Amt GE200K                           float64
# Nonrefundable edu credit Ct GE200K                            float64
# Number of farm returns 100KLT200K                             float64
# Number of farm returns 25KLT50K                               float64
# Number of farm returns 50KLT75K                               float64
# Number of farm returns 75KLT100K                              float64
# Number of farm returns All                                    float64
# Number of farm returns GE200K                                 float64
# Number of farm returns LT25K                                  float64
# Number of refund anticipation loan returns 100KLT200K         float64
# Number of refund anticipation loan returns 50KLT75K           float64
# Number of refund anticipation loan returns 75KLT100K          float64
# Number of refund anticipation loan returns GE200K             float64
# Number of volunteer prepared returns Tot 50KLT75K             float64
# Number of volunteer prepared returns Tot GE200K               float64
# Other non-limited misc deduction Amt 50KLT75K                 float64
# Other non-limited misc deduction Amt 75KLT100K                float64
# Other non-limited misc deduction Amt LT25K                    float64
# Other non-limited misc deduction Ct 75KLT100K                 float64
# Other non-limited misc deduction Ct LT25K                     float64
# Partnership/S-corp net income (less loss) Amt LT25K           float64
# Qualified mortgage insurance premiums Amt GE200K              float64
# Qualified mortgage insurance premiums Ct GE200K               float64
# Refundable edu credit Amt GE200K                              float64
# Refundable edu credit Ct GE200K                               float64
# Residential energy tax credit Amt LT25K                       float64
# Residential energy tax credit Ct LT25K                        float64
# Retirement savings contributions credit Amt 100KLT200K        float64
# Retirement savings contributions credit Amt 75KLT100K         float64
# Retirement savings contributions credit Amt GE200K            float64
# Retirement savings contributions credit Ct 100KLT200K         float64
# Retirement savings contributions credit Ct 75KLT100K          float64
# Retirement savings contributions credit Ct GE200K             float64
# Self-employed (Keogh) retirement plans Amt 75KLT100K          float64
# Self-employed (Keogh) retirement plans Amt LT25K              float64
# Self-employed (Keogh) retirement plans Ct LT25K               float64
# Student loan interest deduction Amt GE200K                    float64
# Student loan interest deduction Ct GE200K                     float64
# Tot Add Medicare tax Amt 25KLT50K                             float64
# Tot Add Medicare tax Amt 75KLT100K                            float64
# Tot Add Medicare tax Amt LT25K                                float64
# Tot Add Medicare tax Ct 75KLT100K                             float64
# Tot Add Medicare tax Ct LT25K                                 float64
# Tot premium tax credit Amt 100KLT200K                         float64
# Tot premium tax credit Amt GE200K                             float64
# Tot premium tax credit Ct 100KLT200K                          float64
# Tot premium tax credit Ct GE200K                              float64
# Tuition and fees deduction Amt 75KLT100K                      float64
# Tuition and fees deduction Amt GE200K                         float64
# Tuition and fees deduction Ct GE200K                          float64
# volunteer prepared w Earned Income Credit 100KLT200K          float64
# volunteer prepared w Earned Income Credit 50KLT75K            float64
# volunteer prepared w Earned Income Credit 75KLT100K           float64
# volunteer prepared w Earned Income Credit GE200K              float64
# grade_range_cd_11-12                                          uint8
# grade_range_cd_11-13                                          uint8
# grade_range_cd_3-12                                           uint8
# grade_range_cd_6-12                                           uint8
# grade_range_cd_6-13                                           uint8
# grade_range_cd_7-12                                           uint8
# grade_range_cd_7-13                                           uint8
# grade_range_cd_8-12                                           uint8
# grade_range_cd_9-11                                           uint8
# grade_range_cd_9-12                                           uint8
# grade_range_cd_9-13                                           uint8
# grade_range_cd_9-9                                            uint8
# grade_range_cd_K-12                                           uint8
# grade_range_cd_PK-12                                          uint8
# grade_range_cd_PK-13                                          uint8
# calendar_type_txt_Regular School, Year-Round Calendar         uint8
# esea_status_P                                                 uint8
# Grad_project_status_Y                                         uint8
# SBE District_Northeast                                        uint8
# SBE District_Northwest                                        uint8
# SBE District_Piedmont-Triad                                   uint8
# SBE District_Sandhills                                        uint8
# SBE District_Southeast                                        uint8
# SBE District_Southwest                                        uint8
# SBE District_Western                                          uint8
# SPG Grade_A+NG                                                uint8
# SPG Grade_B                                                   uint8
# SPG Grade_C                                                   uint8
# SPG Grade_D                                                   uint8
# Reading SPG Grade_B                                           uint8
# Reading SPG Grade_C                                           uint8
# Reading SPG Grade_D                                           uint8
# Reading SPG Grade_F                                           uint8
# Math SPG Grade_B                                              uint8
# Math SPG Grade_C                                              uint8
# Math SPG Grade_D                                              uint8
# Math SPG Grade_F                                              uint8
# EVAAS Growth Status_Met                                       uint8
# EVAAS Growth Status_NotMet                                    uint8
# State Gap Compared_Y                                          uint8
# Byod_Yes                                                      uint8
# grades_BYOD_11:12                                             uint8
# grades_BYOD_11:12:13                                          uint8
# grades_BYOD_12                                                uint8
# grades_BYOD_6:7:8:9:10:11:12                                  uint8
# grades_BYOD_6:7:8:9:10:11:12:13                               uint8
# grades_BYOD_8:9:10:11:12                                      uint8
# grades_BYOD_9                                                 uint8
# grades_BYOD_9:10:11                                           uint8
# grades_BYOD_9:10:11:12                                        uint8
# grades_BYOD_9:10:11:12:13                                     uint8
# grades_BYOD_9:11:12                                           uint8
# grades_BYOD_PK:9:10:11:12                                     uint8
# _1_to_1_access_Yes                                            uint8
# grades_1_to_1_access_10:11:12                                 uint8
# grades_1_to_1_access_10:11:12:13                              uint8
# grades_1_to_1_access_11                                       uint8
# grades_1_to_1_access_11:12                                    uint8
# grades_1_to_1_access_11:12:13                                 uint8
# grades_1_to_1_access_6:07:08                                  uint8
# grades_1_to_1_access_6:7:8:9:10:11:12                         uint8
# grades_1_to_1_access_6:7:8:9:10:11:12:13                      uint8
# grades_1_to_1_access_9                                        uint8
# grades_1_to_1_access_9:10                                     uint8
# grades_1_to_1_access_9:10:11                                  uint8
# grades_1_to_1_access_9:10:11:12                               uint8
# grades_1_to_1_access_9:10:11:12:13                            uint8
# grades_1_to_1_access_9:11:12:13                               uint8
# SRC_devices_sent_home_Yes                                     uint8
# SRC_Grades_Devices_Sent_Home_10:11:12                         uint8
# SRC_Grades_Devices_Sent_Home_10:11:12:13                      uint8
# SRC_Grades_Devices_Sent_Home_6:07:08                          uint8
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12                 uint8
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13              uint8
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13                  uint8
# SRC_Grades_Devices_Sent_Home_9:10                             uint8
# SRC_Grades_Devices_Sent_Home_9:10:11                          uint8
# SRC_Grades_Devices_Sent_Home_9:10:11:12                       uint8
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13                    uint8
# SRC_Grades_Devices_Sent_Home_9:10:12                          uint8
# unit_code                                                     object
# dtypes: float64(464), int64(3), object(1), uint8(80)
# memory usage: 1.7+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.3
# Pandas Version: 0.24.2

# %%
print ('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2017/Machine Learning Datasets/PublicHighSchools2017_ML.csv
