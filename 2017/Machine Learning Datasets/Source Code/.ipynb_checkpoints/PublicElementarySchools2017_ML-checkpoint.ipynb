# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2017

#Location where copies of the raw data files will be read in from csv files.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2017'
#inputFileName = 'PublicHighSchools2017'
#inputFileName = 'PublicMiddleSchools2017'
inputFileName = 'PublicElementarySchools2017'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Columns: 2293 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2247), int64(3), object(43)
# memory usage: 22.2+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 2293 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2247), int64(3), object(43)
# memory usage: 22.2+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print ('Rows Updated / Imputed: ', rowsUpdated )
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 2082 entries, vphone_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2042), object(40)
# memory usage: 20.2+ MB
#
# Columns Deleted:  211

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 2079 entries, street_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2042), object(37)
# memory usage: 20.1+ MB
#
# Columns Deleted:  3

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 2079 entries, street_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(2042), object(37)
# memory usage: 20.1+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  37
# Continuous Columns:  2042
# Columns Accounted for:  2079

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 1516 entries, street_ad to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1479), object(37)
# memory usage: 14.7+ MB
#
# Columns Deleted:  563

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 1499 entries, category_cd to volunteer prepared w Earned Income Credit LT25K
# dtypes: float64(1479), object(20)
# memory usage: 14.5+ MB
#
# Columns Deleted:  17

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print ('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print ('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  20
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 1528 entries, student_num to SRC_Grades_Devices_Sent_Home_PK
# dtypes: float64(1479), uint8(49)
# memory usage: 14.4 MB
#
# New Columns Created Via One-Hot Encoding:  29

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 3                                              00_Size                     75
# 4                                              01_Size                     78
# 5                                              02_Size                     72
# 6                                              03_Size                     79
# 7                                              04_Size                     72
# 8                                              05_Size                    134
# 17                                           SPG Score                     35
# 18                                   Reading SPG Score                     38
# 19                                      Math SPG Score                     38
# 20                                  EVAAS Growth Score                     36
# 21                           Overall Achievement Score                     35
# 22                                       Reading Score                     38
# 23                                          Math Score                     38
# 24                                       Science Score                    121
# 25                            EOG/EOCSubjects_CACR_All                     35
# 26                             EOG/EOCSubjects_GLP_All                     35
# 27                                     EOGGr3_CACR_All                     60
# 28                                      EOGGr3_GLP_All                     60
# 29                                     EOGGr4_CACR_All                     64
# 30                                      EOGGr4_GLP_All                     64
# 31                                     EOGGr5_CACR_All                    126
# 32                                      EOGGr5_GLP_All                    126
# 33                                 EOGMathGr3_CACR_All                     61
# 34                                  EOGMathGr3_GLP_All                     61
# 35                               EOGMathGr3-8_CACR_All                     38
# 36                                EOGMathGr3-8_GLP_All                     38
# 37                                 EOGMathGr4_CACR_All                     65
# 38                                  EOGMathGr4_GLP_All                     65
# 39                                 EOGMathGr5_CACR_All                    129
# 40                                  EOGMathGr5_GLP_All                    129
# 41                              EOGReadingGr3_CACR_All                     61
# 42                               EOGReadingGr3_GLP_All                     61
# 43                            EOGReadingGr3-8_CACR_All                     38
# 44                             EOGReadingGr3-8_GLP_All                     38
# 45                              EOGReadingGr4_CACR_All                     65
# 46                               EOGReadingGr4_GLP_All                     65
# 47                              EOGReadingGr5_CACR_All                    129
# 48                               EOGReadingGr5_GLP_All                    129
# 49                              EOGScienceGr5_CACR_All                    129
# 50                               EOGScienceGr5_GLP_All                    129
# 51                            EOGScienceGr5&8_CACR_All                    124
# 52                             EOGScienceGr5&8_GLP_All                    124
# 53                                EOGSubjects_CACR_All                     38
# 54                                 EOGSubjects_GLP_All                     38
# 55                         EOG/EOCSubjects_CACR_Female                     35
# 56                          EOG/EOCSubjects_GLP_Female                     35
# 57                                  EOGGr3_CACR_Female                     60
# 58                                   EOGGr3_GLP_Female                     60
# 59                                  EOGGr4_CACR_Female                     64
# 60                                   EOGGr4_GLP_Female                     64
# 61                                  EOGGr5_CACR_Female                    126
# 62                                   EOGGr5_GLP_Female                    126
# 63                              EOGMathGr3_CACR_Female                     61
# 64                               EOGMathGr3_GLP_Female                     61
# 65                            EOGMathGr3-8_CACR_Female                     38
# 66                             EOGMathGr3-8_GLP_Female                     38
# 67                              EOGMathGr4_CACR_Female                     65
# 68                               EOGMathGr4_GLP_Female                     65
# 69                              EOGMathGr5_CACR_Female                    129
# 70                               EOGMathGr5_GLP_Female                    129
# 71                           EOGReadingGr3_CACR_Female                     61
# 72                            EOGReadingGr3_GLP_Female                     61
# 73                         EOGReadingGr3-8_CACR_Female                     38
# 74                          EOGReadingGr3-8_GLP_Female                     38
# 75                           EOGReadingGr4_CACR_Female                     65
# 76                            EOGReadingGr4_GLP_Female                     65
# 77                           EOGReadingGr5_CACR_Female                    129
# 78                            EOGReadingGr5_GLP_Female                    129
# 79                           EOGScienceGr5_CACR_Female                    129
# 80                            EOGScienceGr5_GLP_Female                    129
# 81                         EOGScienceGr5&8_CACR_Female                    124
# 82                          EOGScienceGr5&8_GLP_Female                    124
# 83                             EOGSubjects_CACR_Female                     38
# 84                              EOGSubjects_GLP_Female                     38
# 85                           EOG/EOCSubjects_CACR_Male                     35
# 86                            EOG/EOCSubjects_GLP_Male                     35
# 87                                    EOGGr3_CACR_Male                     60
# 88                                     EOGGr3_GLP_Male                     60
# 89                                    EOGGr4_CACR_Male                     64
# 90                                     EOGGr4_GLP_Male                     64
# 91                                    EOGGr5_CACR_Male                    126
# 92                                     EOGGr5_GLP_Male                    126
# 93                                EOGMathGr3_CACR_Male                     61
# 94                                 EOGMathGr3_GLP_Male                     61
# 95                              EOGMathGr3-8_CACR_Male                     38
# 96                               EOGMathGr3-8_GLP_Male                     38
# 97                                EOGMathGr4_CACR_Male                     65
# 98                                 EOGMathGr4_GLP_Male                     65
# 99                                EOGMathGr5_CACR_Male                    129
# 100                                EOGMathGr5_GLP_Male                    129
# 101                            EOGReadingGr3_CACR_Male                     61
# 102                             EOGReadingGr3_GLP_Male                     61
# 103                          EOGReadingGr3-8_CACR_Male                     38
# 104                           EOGReadingGr3-8_GLP_Male                     38
# 105                            EOGReadingGr4_CACR_Male                     65
# 106                             EOGReadingGr4_GLP_Male                     65
# 107                            EOGReadingGr5_CACR_Male                    129
# 108                             EOGReadingGr5_GLP_Male                    129
# 109                            EOGScienceGr5_CACR_Male                    129
# 110                             EOGScienceGr5_GLP_Male                    129
# 111                          EOGScienceGr5&8_CACR_Male                    124
# 112                           EOGScienceGr5&8_GLP_Male                    124
# 113                              EOGSubjects_CACR_Male                     38
# 114                               EOGSubjects_GLP_Male                     38
# 115                EOG/EOCSubjects_CACR_AmericanIndian                     35
# 116                 EOG/EOCSubjects_GLP_AmericanIndian                     35
# 117                         EOGGr3_CACR_AmericanIndian                     60
# 118                          EOGGr3_GLP_AmericanIndian                     60
# 119                         EOGGr4_CACR_AmericanIndian                     64
# 120                          EOGGr4_GLP_AmericanIndian                     64
# 121                         EOGGr5_CACR_AmericanIndian                    126
# 122                          EOGGr5_GLP_AmericanIndian                    126
# 123                     EOGMathGr3_CACR_AmericanIndian                     61
# 124                      EOGMathGr3_GLP_AmericanIndian                     61
# 125                   EOGMathGr3-8_CACR_AmericanIndian                     38
# 126                    EOGMathGr3-8_GLP_AmericanIndian                     38
# 127                     EOGMathGr4_CACR_AmericanIndian                     65
# 128                      EOGMathGr4_GLP_AmericanIndian                     65
# 129                     EOGMathGr5_CACR_AmericanIndian                    129
# 130                      EOGMathGr5_GLP_AmericanIndian                    129
# 131                  EOGReadingGr3_CACR_AmericanIndian                     61
# 132                   EOGReadingGr3_GLP_AmericanIndian                     61
# 133                EOGReadingGr3-8_CACR_AmericanIndian                     38
# 134                 EOGReadingGr3-8_GLP_AmericanIndian                     38
# 135                  EOGReadingGr4_CACR_AmericanIndian                     65
# 136                   EOGReadingGr4_GLP_AmericanIndian                     65
# 137                  EOGReadingGr5_CACR_AmericanIndian                    129
# 138                   EOGReadingGr5_GLP_AmericanIndian                    129
# 139                  EOGScienceGr5_CACR_AmericanIndian                    129
# 140                   EOGScienceGr5_GLP_AmericanIndian                    129
# 141                EOGScienceGr5&8_CACR_AmericanIndian                    124
# 142                 EOGScienceGr5&8_GLP_AmericanIndian                    124
# 143                    EOGSubjects_CACR_AmericanIndian                     38
# 144                     EOGSubjects_GLP_AmericanIndian                     38
# 145                         EOG/EOCSubjects_CACR_Asian                     35
# 146                          EOG/EOCSubjects_GLP_Asian                     35
# 147                                  EOGGr3_CACR_Asian                     60
# 148                                   EOGGr3_GLP_Asian                     60
# 149                                  EOGGr4_CACR_Asian                     64
# 150                                   EOGGr4_GLP_Asian                     64
# 151                                  EOGGr5_CACR_Asian                    126
# 152                                   EOGGr5_GLP_Asian                    126
# 153                              EOGMathGr3_CACR_Asian                     61
# 154                               EOGMathGr3_GLP_Asian                     61
# 155                            EOGMathGr3-8_CACR_Asian                     38
# 156                             EOGMathGr3-8_GLP_Asian                     38
# 157                              EOGMathGr4_CACR_Asian                     65
# 158                               EOGMathGr4_GLP_Asian                     65
# 159                              EOGMathGr5_CACR_Asian                    129
# 160                               EOGMathGr5_GLP_Asian                    129
# 161                           EOGReadingGr3_CACR_Asian                     61
# 162                            EOGReadingGr3_GLP_Asian                     61
# 163                         EOGReadingGr3-8_CACR_Asian                     38
# 164                          EOGReadingGr3-8_GLP_Asian                     38
# 165                           EOGReadingGr4_CACR_Asian                     65
# 166                            EOGReadingGr4_GLP_Asian                     65
# 167                           EOGReadingGr5_CACR_Asian                    129
# 168                            EOGReadingGr5_GLP_Asian                    129
# 169                           EOGScienceGr5_CACR_Asian                    129
# 170                            EOGScienceGr5_GLP_Asian                    129
# 171                         EOGScienceGr5&8_CACR_Asian                    124
# 172                          EOGScienceGr5&8_GLP_Asian                    124
# 173                             EOGSubjects_CACR_Asian                     38
# 174                              EOGSubjects_GLP_Asian                     38
# 175                         EOG/EOCSubjects_CACR_Black                     35
# 176                          EOG/EOCSubjects_GLP_Black                     35
# 177                                  EOGGr3_CACR_Black                     60
# 178                                   EOGGr3_GLP_Black                     60
# 179                                  EOGGr4_CACR_Black                     64
# 180                                   EOGGr4_GLP_Black                     64
# 181                                  EOGGr5_CACR_Black                    126
# 182                                   EOGGr5_GLP_Black                    126
# 183                              EOGMathGr3_CACR_Black                     61
# 184                               EOGMathGr3_GLP_Black                     61
# 185                            EOGMathGr3-8_CACR_Black                     38
# 186                             EOGMathGr3-8_GLP_Black                     38
# 187                              EOGMathGr4_CACR_Black                     65
# 188                               EOGMathGr4_GLP_Black                     65
# 189                              EOGMathGr5_CACR_Black                    129
# 190                               EOGMathGr5_GLP_Black                    129
# 191                           EOGReadingGr3_CACR_Black                     61
# 192                            EOGReadingGr3_GLP_Black                     61
# 193                         EOGReadingGr3-8_CACR_Black                     38
# 194                          EOGReadingGr3-8_GLP_Black                     38
# 195                           EOGReadingGr4_CACR_Black                     65
# 196                            EOGReadingGr4_GLP_Black                     65
# 197                           EOGReadingGr5_CACR_Black                    129
# 198                            EOGReadingGr5_GLP_Black                    129
# 199                           EOGScienceGr5_CACR_Black                    129
# 200                            EOGScienceGr5_GLP_Black                    129
# 201                         EOGScienceGr5&8_CACR_Black                    124
# 202                          EOGScienceGr5&8_GLP_Black                    124
# 203                             EOGSubjects_CACR_Black                     38
# 204                              EOGSubjects_GLP_Black                     38
# 205                      EOG/EOCSubjects_CACR_Hispanic                     35
# 206                       EOG/EOCSubjects_GLP_Hispanic                     35
# 207                               EOGGr3_CACR_Hispanic                     60
# 208                                EOGGr3_GLP_Hispanic                     60
# 209                               EOGGr4_CACR_Hispanic                     64
# 210                                EOGGr4_GLP_Hispanic                     64
# 211                               EOGGr5_CACR_Hispanic                    126
# 212                                EOGGr5_GLP_Hispanic                    126
# 213                           EOGMathGr3_CACR_Hispanic                     61
# 214                            EOGMathGr3_GLP_Hispanic                     61
# 215                         EOGMathGr3-8_CACR_Hispanic                     38
# 216                          EOGMathGr3-8_GLP_Hispanic                     38
# 217                           EOGMathGr4_CACR_Hispanic                     65
# 218                            EOGMathGr4_GLP_Hispanic                     65
# 219                           EOGMathGr5_CACR_Hispanic                    129
# 220                            EOGMathGr5_GLP_Hispanic                    129
# 221                        EOGReadingGr3_CACR_Hispanic                     61
# 222                         EOGReadingGr3_GLP_Hispanic                     61
# 223                      EOGReadingGr3-8_CACR_Hispanic                     38
# 224                       EOGReadingGr3-8_GLP_Hispanic                     38
# 225                        EOGReadingGr4_CACR_Hispanic                     65
# 226                         EOGReadingGr4_GLP_Hispanic                     65
# 227                        EOGReadingGr5_CACR_Hispanic                    129
# 228                         EOGReadingGr5_GLP_Hispanic                    129
# 229                        EOGScienceGr5_CACR_Hispanic                    129
# 230                         EOGScienceGr5_GLP_Hispanic                    129
# 231                      EOGScienceGr5&8_CACR_Hispanic                    124
# 232                       EOGScienceGr5&8_GLP_Hispanic                    124
# 233                          EOGSubjects_CACR_Hispanic                     38
# 234                           EOGSubjects_GLP_Hispanic                     38
# 235                EOG/EOCSubjects_CACR_TwoorMoreRaces                     35
# 236                 EOG/EOCSubjects_GLP_TwoorMoreRaces                     35
# 237                         EOGGr3_CACR_TwoorMoreRaces                     60
# 238                          EOGGr3_GLP_TwoorMoreRaces                     60
# 239                         EOGGr4_CACR_TwoorMoreRaces                     64
# 240                          EOGGr4_GLP_TwoorMoreRaces                     64
# 241                         EOGGr5_CACR_TwoorMoreRaces                    126
# 242                          EOGGr5_GLP_TwoorMoreRaces                    126
# 243                     EOGMathGr3_CACR_TwoorMoreRaces                     61
# 244                      EOGMathGr3_GLP_TwoorMoreRaces                     61
# 245                   EOGMathGr3-8_CACR_TwoorMoreRaces                     38
# 246                    EOGMathGr3-8_GLP_TwoorMoreRaces                     38
# 247                     EOGMathGr4_CACR_TwoorMoreRaces                     65
# 248                      EOGMathGr4_GLP_TwoorMoreRaces                     65
# 249                     EOGMathGr5_CACR_TwoorMoreRaces                    129
# 250                      EOGMathGr5_GLP_TwoorMoreRaces                    129
# 251                  EOGReadingGr3_CACR_TwoorMoreRaces                     61
# 252                   EOGReadingGr3_GLP_TwoorMoreRaces                     61
# 253                EOGReadingGr3-8_CACR_TwoorMoreRaces                     38
# 254                 EOGReadingGr3-8_GLP_TwoorMoreRaces                     38
# 255                  EOGReadingGr4_CACR_TwoorMoreRaces                     65
# 256                   EOGReadingGr4_GLP_TwoorMoreRaces                     65
# 257                  EOGReadingGr5_CACR_TwoorMoreRaces                    129
# 258                   EOGReadingGr5_GLP_TwoorMoreRaces                    129
# 259                  EOGScienceGr5_CACR_TwoorMoreRaces                    129
# 260                   EOGScienceGr5_GLP_TwoorMoreRaces                    129
# 261                EOGScienceGr5&8_CACR_TwoorMoreRaces                    124
# 262                 EOGScienceGr5&8_GLP_TwoorMoreRaces                    124
# 263                    EOGSubjects_CACR_TwoorMoreRaces                     38
# 264                     EOGSubjects_GLP_TwoorMoreRaces                     38
# 265                         EOG/EOCSubjects_CACR_White                     35
# 266                          EOG/EOCSubjects_GLP_White                     35
# 267                                  EOGGr3_CACR_White                     60
# 268                                   EOGGr3_GLP_White                     60
# 269                                  EOGGr4_CACR_White                     64
# 270                                   EOGGr4_GLP_White                     64
# 271                                  EOGGr5_CACR_White                    126
# 272                                   EOGGr5_GLP_White                    126
# 273                              EOGMathGr3_CACR_White                     61
# 274                               EOGMathGr3_GLP_White                     61
# 275                            EOGMathGr3-8_CACR_White                     38
# 276                             EOGMathGr3-8_GLP_White                     38
# 277                              EOGMathGr4_CACR_White                     65
# 278                               EOGMathGr4_GLP_White                     65
# 279                              EOGMathGr5_CACR_White                    129
# 280                               EOGMathGr5_GLP_White                    129
# 281                           EOGReadingGr3_CACR_White                     61
# 282                            EOGReadingGr3_GLP_White                     61
# 283                         EOGReadingGr3-8_CACR_White                     38
# 284                          EOGReadingGr3-8_GLP_White                     38
# 285                           EOGReadingGr4_CACR_White                     65
# 286                            EOGReadingGr4_GLP_White                     65
# 287                           EOGReadingGr5_CACR_White                    129
# 288                            EOGReadingGr5_GLP_White                    129
# 289                           EOGScienceGr5_CACR_White                    129
# 290                            EOGScienceGr5_GLP_White                    129
# 291                         EOGScienceGr5&8_CACR_White                    124
# 292                          EOGScienceGr5&8_GLP_White                    124
# 293                             EOGSubjects_CACR_White                     38
# 294                              EOGSubjects_GLP_White                     38
# 295                           EOG/EOCSubjects_CACR_EDS                     35
# 296                            EOG/EOCSubjects_GLP_EDS                     35
# 297                                    EOGGr3_CACR_EDS                     60
# 298                                     EOGGr3_GLP_EDS                     60
# 299                                    EOGGr4_CACR_EDS                     64
# 300                                     EOGGr4_GLP_EDS                     64
# 301                                    EOGGr5_CACR_EDS                    126
# 302                                     EOGGr5_GLP_EDS                    126
# 303                                EOGMathGr3_CACR_EDS                     61
# 304                                 EOGMathGr3_GLP_EDS                     61
# 305                              EOGMathGr3-8_CACR_EDS                     38
# 306                               EOGMathGr3-8_GLP_EDS                     38
# 307                                EOGMathGr4_CACR_EDS                     65
# 308                                 EOGMathGr4_GLP_EDS                     65
# 309                                EOGMathGr5_CACR_EDS                    129
# 310                                 EOGMathGr5_GLP_EDS                    129
# 311                             EOGReadingGr3_CACR_EDS                     61
# 312                              EOGReadingGr3_GLP_EDS                     61
# 313                           EOGReadingGr3-8_CACR_EDS                     38
# 314                            EOGReadingGr3-8_GLP_EDS                     38
# 315                             EOGReadingGr4_CACR_EDS                     65
# 316                              EOGReadingGr4_GLP_EDS                     65
# 317                             EOGReadingGr5_CACR_EDS                    129
# 318                              EOGReadingGr5_GLP_EDS                    129
# 319                             EOGScienceGr5_CACR_EDS                    129
# 320                              EOGScienceGr5_GLP_EDS                    129
# 321                           EOGScienceGr5&8_CACR_EDS                    124
# 322                            EOGScienceGr5&8_GLP_EDS                    124
# 323                               EOGSubjects_CACR_EDS                     38
# 324                                EOGSubjects_GLP_EDS                     38
# 325                           EOG/EOCSubjects_CACR_LEP                     35
# 326                            EOG/EOCSubjects_GLP_LEP                     35
# 327                                    EOGGr3_CACR_LEP                     60
# 328                                     EOGGr3_GLP_LEP                     60
# 329                                    EOGGr4_CACR_LEP                     64
# 330                                     EOGGr4_GLP_LEP                     64
# 331                                    EOGGr5_CACR_LEP                    126
# 332                                     EOGGr5_GLP_LEP                    126
# 333                                EOGMathGr3_CACR_LEP                     61
# 334                                 EOGMathGr3_GLP_LEP                     61
# 335                              EOGMathGr3-8_CACR_LEP                     38
# 336                               EOGMathGr3-8_GLP_LEP                     38
# 337                                EOGMathGr4_CACR_LEP                     65
# 338                                 EOGMathGr4_GLP_LEP                     65
# 339                                EOGMathGr5_CACR_LEP                    129
# 340                                 EOGMathGr5_GLP_LEP                    129
# 341                             EOGReadingGr3_CACR_LEP                     61
# 342                              EOGReadingGr3_GLP_LEP                     61
# 343                           EOGReadingGr3-8_CACR_LEP                     38
# 344                            EOGReadingGr3-8_GLP_LEP                     38
# 345                             EOGReadingGr4_CACR_LEP                     65
# 346                              EOGReadingGr4_GLP_LEP                     65
# 347                             EOGReadingGr5_CACR_LEP                    129
# 348                              EOGReadingGr5_GLP_LEP                    129
# 349                             EOGScienceGr5_CACR_LEP                    129
# 350                              EOGScienceGr5_GLP_LEP                    129
# 351                           EOGScienceGr5&8_CACR_LEP                    124
# 352                            EOGScienceGr5&8_GLP_LEP                    124
# 353                               EOGSubjects_CACR_LEP                     38
# 354                                EOGSubjects_GLP_LEP                     38
# 355                           EOG/EOCSubjects_CACR_SWD                     35
# 356                            EOG/EOCSubjects_GLP_SWD                     35
# 357                                    EOGGr3_CACR_SWD                     60
# 358                                     EOGGr3_GLP_SWD                     60
# 359                                    EOGGr4_CACR_SWD                     64
# 360                                     EOGGr4_GLP_SWD                     64
# 361                                    EOGGr5_CACR_SWD                    126
# 362                                     EOGGr5_GLP_SWD                    126
# 363                                EOGMathGr3_CACR_SWD                     61
# 364                                 EOGMathGr3_GLP_SWD                     61
# 365                              EOGMathGr3-8_CACR_SWD                     38
# 366                               EOGMathGr3-8_GLP_SWD                     38
# 367                                EOGMathGr4_CACR_SWD                     65
# 368                                 EOGMathGr4_GLP_SWD                     65
# 369                                EOGMathGr5_CACR_SWD                    129
# 370                                 EOGMathGr5_GLP_SWD                    129
# 371                             EOGReadingGr3_CACR_SWD                     61
# 372                              EOGReadingGr3_GLP_SWD                     61
# 373                           EOGReadingGr3-8_CACR_SWD                     38
# 374                            EOGReadingGr3-8_GLP_SWD                     38
# 375                             EOGReadingGr4_CACR_SWD                     65
# 376                              EOGReadingGr4_GLP_SWD                     65
# 377                             EOGReadingGr5_CACR_SWD                    129
# 378                              EOGReadingGr5_GLP_SWD                    129
# 379                             EOGScienceGr5_CACR_SWD                    129
# 380                              EOGScienceGr5_GLP_SWD                    129
# 381                           EOGScienceGr5&8_CACR_SWD                    124
# 382                            EOGScienceGr5&8_GLP_SWD                    124
# 383                               EOGSubjects_CACR_SWD                     38
# 384                                EOGSubjects_GLP_SWD                     38
# 385                           EOG/EOCSubjects_CACR_AIG                     35
# 386                            EOG/EOCSubjects_GLP_AIG                     35
# 387                                    EOGGr3_CACR_AIG                     60
# 388                                     EOGGr3_GLP_AIG                     60
# 389                                    EOGGr4_CACR_AIG                     64
# 390                                     EOGGr4_GLP_AIG                     64
# 391                                    EOGGr5_CACR_AIG                    126
# 392                                     EOGGr5_GLP_AIG                    126
# 393                                EOGMathGr3_CACR_AIG                     61
# 394                                 EOGMathGr3_GLP_AIG                     61
# 395                              EOGMathGr3-8_CACR_AIG                     38
# 396                               EOGMathGr3-8_GLP_AIG                     38
# 397                                EOGMathGr4_CACR_AIG                     65
# 398                                 EOGMathGr4_GLP_AIG                     65
# 399                                EOGMathGr5_CACR_AIG                    129
# 400                                 EOGMathGr5_GLP_AIG                    129
# 401                             EOGReadingGr3_CACR_AIG                     61
# 402                              EOGReadingGr3_GLP_AIG                     61
# 403                           EOGReadingGr3-8_CACR_AIG                     38
# 404                            EOGReadingGr3-8_GLP_AIG                     38
# 405                             EOGReadingGr4_CACR_AIG                     65
# 406                              EOGReadingGr4_GLP_AIG                     65
# 407                             EOGReadingGr5_CACR_AIG                    129
# 408                              EOGReadingGr5_GLP_AIG                    129
# 409                             EOGScienceGr5_CACR_AIG                    129
# 410                              EOGScienceGr5_GLP_AIG                    129
# 411                           EOGScienceGr5&8_CACR_AIG                    124
# 412                            EOGScienceGr5&8_GLP_AIG                    124
# 413                               EOGSubjects_CACR_AIG                     38
# 414                                EOGSubjects_GLP_AIG                     38
# 415                                        pct_GCE_ALL                     59
# 416                                     pct_PASSED_EOG                     88
# 417                                     pct_PASSED_LAA                    745
# 418                                       pct_PROMOTED                     61
# 419                                       pct_RETAINED                    741
# 420                           MathGr3-8_pTarget_PctMet                     39
# 421                        ReadingGr3-8_pTarget_PctMet                     39
# 422                            SciGr5&8_pTarget_PctMet                    167
# 423                        TotalTargets_pTarget_PctMet                     36
# 424                              lea_sat_avg_score_num                      4
# 425                          lea_sat_participation_pct                      4
# 426                           lea_ap_participation_pct                    133
# 427                              lea_ap_pct_3_or_above                     33
# 428                              lea_ib_pct_4_or_above                    717
# 433                             stud_internet_comp_num                      3
# 443                                  digital_media_pct                      4
# 444                           avg_age_media_collection                      3
# 445                                  books_per_student                      4
# 446                       lea_avg_age_media_collection                      3
# 447                              lea_books_per_student                      4
# 448                                            wap_num                      2
# 449                                  wap_per_classroom                      2
# 459                               _1yr_tchr_trnovr_pct                      6
# 460                                  lateral_teach_pct                    638
# 469                            lea_emer_prov_teach_pct                    414
# 470                              lea_lateral_teach_pct                     68
# 487                   Accomplished_TCHR_Standard 1_Pct                      2
# 488                   Accomplished_TCHR_Standard 2_Pct                      2
# 489                   Accomplished_TCHR_Standard 3_Pct                      2
# 490                   Accomplished_TCHR_Standard 4_Pct                      2
# 491                   Accomplished_TCHR_Standard 5_Pct                      2
# 492                     Developing_TCHR_Standard 1_Pct                      2
# 493                     Developing_TCHR_Standard 2_Pct                      2
# 494                     Developing_TCHR_Standard 3_Pct                      2
# 495                     Developing_TCHR_Standard 4_Pct                      2
# 496                     Developing_TCHR_Standard 5_Pct                      2
# 497                  Distinguished_TCHR_Standard 1_Pct                      2
# 498                  Distinguished_TCHR_Standard 2_Pct                      2
# 499                  Distinguished_TCHR_Standard 3_Pct                      2
# 500                  Distinguished_TCHR_Standard 4_Pct                      2
# 501                  Distinguished_TCHR_Standard 5_Pct                      2
# 502  Does Not Meet Expected Growth_TCHR_Student Gro...                      6
# 503    Exceeds Expected Growth_TCHR_Student Growth_Pct                      6
# 504      Meets Expected Growth_TCHR_Student Growth_Pct                      6
# 505                Not Demostrated_TCHR_Standard 1_Pct                      2
# 506                Not Demostrated_TCHR_Standard 2_Pct                      2
# 507                Not Demostrated_TCHR_Standard 3_Pct                      2
# 508                Not Demostrated_TCHR_Standard 4_Pct                      2
# 509                Not Demostrated_TCHR_Standard 5_Pct                      2
# 510                     Proficient_TCHR_Standard 1_Pct                      2
# 511                     Proficient_TCHR_Standard 2_Pct                      2
# 512                     Proficient_TCHR_Standard 3_Pct                      2
# 513                     Proficient_TCHR_Standard 4_Pct                      2
# 514                     Proficient_TCHR_Standard 5_Pct                      2
# 540                                               Year                    297
# 541                                       Violent Rate                    301
# 542                                        Murder Rate                    374
# 543                                          Rape Rate                    315
# 544                                       Robbery Rate                    328
# 545                                       Assault Rate                    308
# 546                                           MVT Rate                    297
# 547                                         Arson Rate                    323

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  277822  field correlations > 95%.
#                                                  Field1  \
# 0                                   lea_class_teach_num
# 1                                  st_tchyrs_0thru3_pct
# 2                                    st_class_teach_num
# 3                                          st_nbpts_num
# 4                                     Reading SPG Score
# 5                                        Math SPG Score
# 6                             Overall Achievement Score
# 7                                            Math Score
# 8                              EOG/EOCSubjects_CACR_All
# 9                               EOG/EOCSubjects_GLP_All
# 10                                 EOGMathGr3-8_GLP_All
# 11                                  EOGSubjects_GLP_All
# 12                           EOG/EOCSubjects_GLP_Female
# 13                               EOGSubjects_GLP_Female
# 14                             EOG/EOCSubjects_GLP_Male
# 15                                 EOGSubjects_GLP_Male
# 16                            Overall Achievement Score
# 17                                        Reading Score
# 18                              EOG/EOCSubjects_GLP_All
# 19                              EOGReadingGr3-8_GLP_All
# 20                                 EOGSubjects_CACR_All
# 21                                  EOGSubjects_GLP_All
# 22                           EOGReadingGr3-8_GLP_Female
# 23                               EOGSubjects_GLP_Female
# 24                             EOG/EOCSubjects_GLP_Male
# 25                             EOGReadingGr3-8_GLP_Male
# 26                                 EOGSubjects_GLP_Male
# 27                                           Math Score
# 28                              EOG/EOCSubjects_GLP_All
# 29                                EOGMathGr3-8_CACR_All
# 30                                 EOGMathGr3-8_GLP_All
# 31                                  EOGSubjects_GLP_All
# 32                              EOGMathGr3-8_GLP_Female
# 33                               EOGSubjects_GLP_Female
# 34                                EOGMathGr3-8_GLP_Male
# 35                                 EOGSubjects_GLP_Male
# 36                                        Reading Score
# 37                                           Math Score
# 38                             EOG/EOCSubjects_CACR_All
# 39                              EOG/EOCSubjects_GLP_All
# 40                                EOGMathGr3-8_CACR_All
# 41                                 EOGMathGr3-8_GLP_All
# 42                              EOGReadingGr3-8_GLP_All
# 43                                 EOGSubjects_CACR_All
# 44                                  EOGSubjects_GLP_All
# 45                          EOG/EOCSubjects_CACR_Female
# 46                           EOG/EOCSubjects_GLP_Female
# 47                              EOGSubjects_CACR_Female
# 48                               EOGSubjects_GLP_Female
# 49                            EOG/EOCSubjects_CACR_Male
# 50                             EOG/EOCSubjects_GLP_Male
# 51                                EOGSubjects_CACR_Male
# 52                                 EOGSubjects_GLP_Male
# 53                             EOG/EOCSubjects_CACR_All
# 54                              EOG/EOCSubjects_GLP_All
# 55                             EOGReadingGr3-8_CACR_All
# 56                              EOGReadingGr3-8_GLP_All
# 57                                 EOGSubjects_CACR_All
# 58                                  EOGSubjects_GLP_All
# 59                           EOG/EOCSubjects_GLP_Female
# 60                          EOGReadingGr3-8_CACR_Female
# 61                           EOGReadingGr3-8_GLP_Female
# 62                              EOGSubjects_CACR_Female
# 63                               EOGSubjects_GLP_Female
# 64                             EOG/EOCSubjects_GLP_Male
# 65                            EOGReadingGr3-8_CACR_Male
# 66                             EOGReadingGr3-8_GLP_Male
# 67                                EOGSubjects_CACR_Male
# 68                                 EOGSubjects_GLP_Male
# 69                             EOG/EOCSubjects_CACR_All
# 70                              EOG/EOCSubjects_GLP_All
# 71                                EOGMathGr3-8_CACR_All
# 72                                 EOGMathGr3-8_GLP_All
# 73                                 EOGSubjects_CACR_All
# 74                                  EOGSubjects_GLP_All
# 75                           EOG/EOCSubjects_GLP_Female
# 76                             EOGMathGr3-8_CACR_Female
# 77                              EOGMathGr3-8_GLP_Female
# 78                               EOGSubjects_GLP_Female
# 79                             EOG/EOCSubjects_GLP_Male
# 80                               EOGMathGr3-8_CACR_Male
# 81                                EOGMathGr3-8_GLP_Male
# 82                                EOGSubjects_CACR_Male
# 83                                 EOGSubjects_GLP_Male
# 84                                       EOGGr5_GLP_All
# 85                               EOGScienceGr5_CACR_All
# 86                                EOGScienceGr5_GLP_All
# 87                             EOGScienceGr5&8_CACR_All
# 88                              EOGScienceGr5&8_GLP_All
# 89                              EOG/EOCSubjects_GLP_All
# 90                                EOGMathGr3-8_CACR_All
# 91                                 EOGMathGr3-8_GLP_All
# 92                             EOGReadingGr3-8_CACR_All
# 93                              EOGReadingGr3-8_GLP_All
# 94                                 EOGSubjects_CACR_All
# 95                                  EOGSubjects_GLP_All
# 96                          EOG/EOCSubjects_CACR_Female
# 97                           EOG/EOCSubjects_GLP_Female
# 98                             EOGMathGr3-8_CACR_Female
# 99                              EOGSubjects_CACR_Female
# 100                              EOGSubjects_GLP_Female
# 101                           EOG/EOCSubjects_CACR_Male
# 102                            EOG/EOCSubjects_GLP_Male
# 103                              EOGMathGr3-8_CACR_Male
# 104                           EOGReadingGr3-8_CACR_Male
# 105                               EOGSubjects_CACR_Male
# 106                                EOGSubjects_GLP_Male
# 107                               EOGMathGr3-8_CACR_All
# 108                                EOGMathGr3-8_GLP_All
# 109                             EOGReadingGr3-8_GLP_All
# 110                                EOGSubjects_CACR_All
# 111                                 EOGSubjects_GLP_All
# 112                         EOG/EOCSubjects_CACR_Female
# 113                          EOG/EOCSubjects_GLP_Female
# 114                             EOGMathGr3-8_GLP_Female
# 115                          EOGReadingGr3-8_GLP_Female
# 116                             EOGSubjects_CACR_Female
# 117                              EOGSubjects_GLP_Female
# 118                           EOG/EOCSubjects_CACR_Male
# 119                            EOG/EOCSubjects_GLP_Male
# 120                               EOGMathGr3-8_GLP_Male
# 121                            EOGReadingGr3-8_GLP_Male
# 122                               EOGSubjects_CACR_Male
# 123                                EOGSubjects_GLP_Male
# 124                                      EOGGr3_GLP_All
# 125                                 EOGMathGr3_CACR_All
# 126                              EOGReadingGr3_CACR_All
# 127                               EOGReadingGr3_GLP_All
# 128                                  EOGGr3_CACR_Female
# 129                                    EOGGr3_CACR_Male
# 130                                 EOGMathGr3_CACR_All
# 131                                  EOGMathGr3_GLP_All
# 132                               EOGReadingGr3_GLP_All
# 133                                   EOGGr3_GLP_Female
# 134                                     EOGGr3_GLP_Male
# 135                                      EOGGr4_GLP_All
# 136                                 EOGMathGr4_CACR_All
# 137                                  EOGMathGr4_GLP_All
# 138                              EOGReadingGr4_CACR_All
# 139                                    EOGGr4_CACR_Male
# 140                                 EOGMathGr4_CACR_All
# 141                                  EOGMathGr4_GLP_All
# 142                               EOGReadingGr4_GLP_All
# 143                                     EOGGr4_GLP_Male
# 144                                      EOGGr5_GLP_All
# 145                                 EOGMathGr5_CACR_All
# 146                                  EOGMathGr5_GLP_All
# 147                               EOGReadingGr5_GLP_All
# 148                              EOGScienceGr5_CACR_All
# 149                                  EOGGr5_CACR_Female
# 150                                   EOGGr5_GLP_Female
# 151                                    EOGGr5_CACR_Male
# 152                                     EOGGr5_GLP_Male
# 153                                  EOGMathGr5_GLP_All
# 154                               EOGReadingGr5_GLP_All
# 155                               EOGScienceGr5_GLP_All
# 156                             EOGScienceGr5&8_GLP_All
# 157                                  EOGGr5_CACR_Female
# 158                                   EOGGr5_GLP_Female
# 159                                    EOGGr5_CACR_Male
# 160                                     EOGGr5_GLP_Male
# 161                                  EOGMathGr3_GLP_All
# 162                                EOGMathGr3-8_GLP_All
# 163                                EOGSubjects_CACR_All
# 164                                 EOGSubjects_GLP_All
# 165                         EOG/EOCSubjects_CACR_Female
# 166                            EOGMathGr3-8_CACR_Female
# 167                             EOGMathGr3-8_GLP_Female
# 168                             EOGSubjects_CACR_Female
# 169                              EOGSubjects_GLP_Female
# 170                           EOG/EOCSubjects_CACR_Male
# 171                            EOG/EOCSubjects_GLP_Male
# 172                              EOGMathGr3-8_CACR_Male
# 173                               EOGMathGr3-8_GLP_Male
# 174                               EOGSubjects_CACR_Male
# 175                                EOGSubjects_GLP_Male
# 176                                EOGSubjects_CACR_All
# 177                                 EOGSubjects_GLP_All
# 178                          EOG/EOCSubjects_GLP_Female
# 179                            EOGMathGr3-8_CACR_Female
# 180                             EOGMathGr3-8_GLP_Female
# 181                              EOGSubjects_GLP_Female
# 182                            EOG/EOCSubjects_GLP_Male
# 183                              EOGMathGr3-8_CACR_Male
# 184                               EOGMathGr3-8_GLP_Male
# 185                               EOGSubjects_CACR_Male
# 186                                EOGSubjects_GLP_Male
# 187                                  EOGMathGr4_GLP_All
# 188                                  EOGMathGr5_GLP_All
# 189                                   EOGGr5_GLP_Female
# 190                               EOGReadingGr3_GLP_All
# 191                                      pct_PASSED_EOG
# 192                             EOGReadingGr3-8_GLP_All
# 193                                EOGSubjects_CACR_All
# 194                         EOG/EOCSubjects_CACR_Female
# 195                         EOGReadingGr3-8_CACR_Female
# 196                          EOGReadingGr3-8_GLP_Female
# 197                             EOGSubjects_CACR_Female
# 198                           EOG/EOCSubjects_CACR_Male
# 199                           EOGReadingGr3-8_CACR_Male
# 200                            EOGReadingGr3-8_GLP_Male
# 201                               EOGSubjects_CACR_Male
# 202                                EOGSubjects_CACR_All
# 203                                 EOGSubjects_GLP_All
# 204                          EOG/EOCSubjects_GLP_Female
# 205                         EOGReadingGr3-8_CACR_Female
# 206                          EOGReadingGr3-8_GLP_Female
# 207                             EOGSubjects_CACR_Female
# 208                              EOGSubjects_GLP_Female
# 209                            EOG/EOCSubjects_GLP_Male
# 210                           EOGReadingGr3-8_CACR_Male
# 211                            EOGReadingGr3-8_GLP_Male
# 212                               EOGSubjects_CACR_Male
# 213                                EOGSubjects_GLP_Male
# 214                               EOGReadingGr4_GLP_All
# 215                               EOGReadingGr5_GLP_All
# 216                               EOGScienceGr5_GLP_All
# 217                            EOGScienceGr5&8_CACR_All
# 218                             EOGScienceGr5&8_GLP_All
# 219                            EOGScienceGr5&8_CACR_All
# 220                             EOGScienceGr5&8_GLP_All
# 221                             EOGScienceGr5&8_GLP_All
# 222                                 EOGSubjects_GLP_All
# 223                         EOG/EOCSubjects_CACR_Female
# 224                          EOG/EOCSubjects_GLP_Female
# 225                            EOGMathGr3-8_CACR_Female
# 226                         EOGReadingGr3-8_CACR_Female
# 227                          EOGReadingGr3-8_GLP_Female
# 228                             EOGSubjects_CACR_Female
# 229                              EOGSubjects_GLP_Female
# 230                           EOG/EOCSubjects_CACR_Male
# 231                            EOG/EOCSubjects_GLP_Male
# 232                              EOGMathGr3-8_CACR_Male
# 233                           EOGReadingGr3-8_CACR_Male
# 234                            EOGReadingGr3-8_GLP_Male
# 235                               EOGSubjects_CACR_Male
# 236                                EOGSubjects_GLP_Male
# 237                         EOG/EOCSubjects_CACR_Female
# 238                          EOG/EOCSubjects_GLP_Female
# 239                            EOGMathGr3-8_CACR_Female
# 240                             EOGMathGr3-8_GLP_Female
# 241                          EOGReadingGr3-8_GLP_Female
# 242                             EOGSubjects_CACR_Female
# 243                              EOGSubjects_GLP_Female
# 244                           EOG/EOCSubjects_CACR_Male
# 245                            EOG/EOCSubjects_GLP_Male
# 246                              EOGMathGr3-8_CACR_Male
# 247                               EOGMathGr3-8_GLP_Male
# 248                            EOGReadingGr3-8_GLP_Male
# 249                               EOGSubjects_CACR_Male
# 250                                EOGSubjects_GLP_Male
# 251                          EOG/EOCSubjects_GLP_Female
# 252                            EOGMathGr3-8_CACR_Female
# 253                         EOGReadingGr3-8_CACR_Female
# 254                             EOGSubjects_CACR_Female
# 255                              EOGSubjects_GLP_Female
# 256                            EOGMathGr3-8_CACR_Female
# 257                             EOGMathGr3-8_GLP_Female
# 258                          EOGReadingGr3-8_GLP_Female
# 259                             EOGSubjects_CACR_Female
# 260                              EOGSubjects_GLP_Female
# 261                                   EOGGr3_GLP_Female
# 262                                   EOGGr4_GLP_Female
# 263                                   EOGGr5_GLP_Female
# 264                               EOGMathGr3_GLP_Female
# 265                             EOGMathGr3-8_GLP_Female
# 266                             EOGSubjects_CACR_Female
# 267                              EOGSubjects_GLP_Female
# 268                             EOGSubjects_CACR_Female
# 269                              EOGSubjects_GLP_Female
# 270                               EOGMathGr4_GLP_Female
# 271                               EOGMathGr5_GLP_Female
# 272                            EOGReadingGr3_GLP_Female
# 273                          EOGReadingGr3-8_GLP_Female
# 274                             EOGSubjects_CACR_Female
# 275                             EOGSubjects_CACR_Female
# 276                              EOGSubjects_GLP_Female
# 277                            EOGReadingGr5_GLP_Female
# 278                            EOGScienceGr5_GLP_Female
# 279                         EOGScienceGr5&8_CACR_Female
# 280                          EOGScienceGr5&8_GLP_Female
# 281                          EOGScienceGr5&8_GLP_Female
# 282                              EOGSubjects_GLP_Female
# 283                            EOG/EOCSubjects_GLP_Male
# 284                              EOGMathGr3-8_CACR_Male
# 285                           EOGReadingGr3-8_CACR_Male
# 286                            EOGReadingGr3-8_GLP_Male
# 287                               EOGSubjects_CACR_Male
# 288                                EOGSubjects_GLP_Male
# 289                              EOGMathGr3-8_CACR_Male
# 290                               EOGMathGr3-8_GLP_Male
# 291                            EOGReadingGr3-8_GLP_Male
# 292                               EOGSubjects_CACR_Male
# 293                                EOGSubjects_GLP_Male
# 294                                     EOGGr3_GLP_Male
# 295                                     EOGGr4_GLP_Male
# 296                                     EOGGr5_GLP_Male
# 297                                 EOGMathGr3_GLP_Male
# 298                               EOGMathGr3-8_GLP_Male
# 299                               EOGSubjects_CACR_Male
# 300                                EOGSubjects_GLP_Male
# 301                               EOGSubjects_CACR_Male
# 302                                EOGSubjects_GLP_Male
# 303                                 EOGMathGr4_GLP_Male
# 304                                 EOGMathGr5_GLP_Male
# 305                              EOGReadingGr3_GLP_Male
# 306                            EOGReadingGr3-8_GLP_Male
# 307                               EOGSubjects_CACR_Male
# 308                               EOGSubjects_CACR_Male
# 309                                EOGSubjects_GLP_Male
# 310                              EOGReadingGr5_GLP_Male
# 311                              EOGScienceGr5_GLP_Male
# 312                           EOGScienceGr5&8_CACR_Male
# 313                            EOGScienceGr5&8_GLP_Male
# 314                            EOGScienceGr5&8_GLP_Male
# 315                                EOGSubjects_GLP_Male
# 316                  EOG/EOCSubjects_GLP_AmericanIndian
# 317                     EOGSubjects_CACR_AmericanIndian
# 318                      EOGSubjects_GLP_AmericanIndian
# 319                     EOGSubjects_CACR_AmericanIndian
# 320                      EOGSubjects_GLP_AmericanIndian
# 321                           EOGGr3_GLP_AmericanIndian
# 322                           EOGGr4_GLP_AmericanIndian
# 323                           EOGGr5_GLP_AmericanIndian
# 324                       EOGMathGr3_GLP_AmericanIndian
# 325                    EOGReadingGr3_GLP_AmericanIndian
# 326                     EOGMathGr3-8_GLP_AmericanIndian
# 327                  EOGReadingGr3-8_GLP_AmericanIndian
# 328                 EOGReadingGr3-8_CACR_AmericanIndian
# 329                  EOGReadingGr3-8_GLP_AmericanIndian
# 330                       EOGMathGr4_GLP_AmericanIndian
# 331                    EOGReadingGr4_GLP_AmericanIndian
# 332                       EOGMathGr5_GLP_AmericanIndian
# 333                    EOGReadingGr5_GLP_AmericanIndian
# 334                    EOGScienceGr5_GLP_AmericanIndian
# 335                    EOGReadingGr3_GLP_AmericanIndian
# 336                  EOGReadingGr3-8_GLP_AmericanIndian
# 337                    EOGReadingGr4_GLP_AmericanIndian
# 338                    EOGScienceGr5_GLP_AmericanIndian
# 339                    EOGScienceGr5_GLP_AmericanIndian
# 340                 EOGScienceGr5&8_CACR_AmericanIndian
# 341                  EOGScienceGr5&8_GLP_AmericanIndian
# 342                 EOGScienceGr5&8_CACR_AmericanIndian
# 343                  EOGScienceGr5&8_GLP_AmericanIndian
# 344                  EOGScienceGr5&8_GLP_AmericanIndian
# 345                      EOGSubjects_GLP_AmericanIndian
# 346                           EOG/EOCSubjects_GLP_Asian
# 347                              EOGSubjects_CACR_Asian
# 348                               EOGSubjects_GLP_Asian
# 349                              EOGSubjects_CACR_Asian
# 350                               EOGSubjects_GLP_Asian
# 351                                    EOGGr3_GLP_Asian
# 352                                    EOGGr4_GLP_Asian
# 353                                    EOGGr5_GLP_Asian
# 354                                EOGMathGr3_GLP_Asian
# 355                            EOGReadingGr3_CACR_Asian
# 356                             EOGReadingGr3_GLP_Asian
# 357                            EOGReadingGr3_CACR_Asian
# 358                             EOGReadingGr3_GLP_Asian
# 359                              EOGMathGr3-8_GLP_Asian
# 360                          EOGReadingGr3-8_CACR_Asian
# 361                           EOGReadingGr3-8_GLP_Asian
# 362                          EOGReadingGr3-8_CACR_Asian
# 363                           EOGReadingGr3-8_GLP_Asian
# 364                                EOGMathGr4_GLP_Asian
# 365                            EOGReadingGr4_CACR_Asian
# 366                             EOGReadingGr4_GLP_Asian
# 367                            EOGReadingGr4_CACR_Asian
# 368                             EOGReadingGr4_GLP_Asian
# 369                                EOGMathGr5_GLP_Asian
# 370                            EOGReadingGr5_CACR_Asian
# 371                             EOGReadingGr5_GLP_Asian
# 372                            EOGScienceGr5_CACR_Asian
# 373                             EOGScienceGr5_GLP_Asian
# 374                          EOGScienceGr5&8_CACR_Asian
# 375                           EOGScienceGr5&8_GLP_Asian
# 376                            EOGReadingGr5_CACR_Asian
# 377                             EOGReadingGr5_GLP_Asian
# 378                            EOGScienceGr5_CACR_Asian
# 379                             EOGScienceGr5_GLP_Asian
# 380                          EOGScienceGr5&8_CACR_Asian
# 381                           EOGScienceGr5&8_GLP_Asian
# 382                             EOGReadingGr3_GLP_Asian
# 383                           EOGReadingGr3-8_GLP_Asian
# 384                             EOGReadingGr4_GLP_Asian
# 385                             EOGReadingGr5_GLP_Asian
# 386                            EOGScienceGr5_CACR_Asian
# 387                             EOGScienceGr5_GLP_Asian
# 388                          EOGScienceGr5&8_CACR_Asian
# 389                           EOGScienceGr5&8_GLP_Asian
# 390                            EOGScienceGr5_CACR_Asian
# 391                             EOGScienceGr5_GLP_Asian
# 392                          EOGScienceGr5&8_CACR_Asian
# 393                           EOGScienceGr5&8_GLP_Asian
# 394                             EOGScienceGr5_GLP_Asian
# 395                          EOGScienceGr5&8_CACR_Asian
# 396                           EOGScienceGr5&8_GLP_Asian
# 397                          EOGScienceGr5&8_CACR_Asian
# 398                           EOGScienceGr5&8_GLP_Asian
# 399                           EOGScienceGr5&8_GLP_Asian
# 400                               EOGSubjects_GLP_Asian
# 401                           EOG/EOCSubjects_GLP_Black
# 402                              EOGSubjects_CACR_Black
# 403                               EOGSubjects_GLP_Black
# 404                              EOGSubjects_CACR_Black
# 405                               EOGSubjects_GLP_Black
# 406                                    EOGGr3_GLP_Black
# 407                                    EOGGr4_GLP_Black
# 408                                    EOGGr5_GLP_Black
# 409                                EOGMathGr3_GLP_Black
# 410                              EOGMathGr3-8_GLP_Black
# 411                                EOGMathGr4_GLP_Black
# 412                                EOGMathGr5_GLP_Black
# 413                             EOGReadingGr3_GLP_Black
# 414                           EOGReadingGr3-8_GLP_Black
# 415                             EOGReadingGr4_GLP_Black
# 416                             EOGScienceGr5_GLP_Black
# 417                          EOGScienceGr5&8_CACR_Black
# 418                           EOGScienceGr5&8_GLP_Black
# 419                          EOGScienceGr5&8_CACR_Black
# 420                           EOGScienceGr5&8_GLP_Black
# 421                           EOGScienceGr5&8_GLP_Black
# 422                               EOGSubjects_GLP_Black
# 423                        EOG/EOCSubjects_GLP_Hispanic
# 424                           EOGSubjects_CACR_Hispanic
# 425                            EOGSubjects_GLP_Hispanic
# 426                           EOGSubjects_CACR_Hispanic
# 427                            EOGSubjects_GLP_Hispanic
# 428                                 EOGGr3_GLP_Hispanic
# 429                                 EOGGr4_GLP_Hispanic
# 430                                 EOGGr5_GLP_Hispanic
# 431                             EOGMathGr3_GLP_Hispanic
# 432                           EOGMathGr3-8_GLP_Hispanic
# 433                             EOGMathGr4_GLP_Hispanic
# 434                             EOGMathGr5_GLP_Hispanic
# 435                          EOGScienceGr5_GLP_Hispanic
# 436                          EOGReadingGr3_GLP_Hispanic
# 437                          EOGReadingGr4_GLP_Hispanic
# 438                          EOGReadingGr5_GLP_Hispanic
# 439                          EOGScienceGr5_GLP_Hispanic
# 440                       EOGScienceGr5&8_CACR_Hispanic
# 441                        EOGScienceGr5&8_GLP_Hispanic
# 442                       EOGScienceGr5&8_CACR_Hispanic
# 443                        EOGScienceGr5&8_GLP_Hispanic
# 444                        EOGScienceGr5&8_GLP_Hispanic
# 445                            EOGSubjects_GLP_Hispanic
# 446                  EOG/EOCSubjects_GLP_TwoorMoreRaces
# 447                     EOGSubjects_CACR_TwoorMoreRaces
# 448                      EOGSubjects_GLP_TwoorMoreRaces
# 449                     EOGSubjects_CACR_TwoorMoreRaces
# 450                      EOGSubjects_GLP_TwoorMoreRaces
# 451                           EOGGr3_GLP_TwoorMoreRaces
# 452                           EOGGr4_GLP_TwoorMoreRaces
# 453                           EOGGr5_GLP_TwoorMoreRaces
# 454                       EOGMathGr3_GLP_TwoorMoreRaces
# 455                   EOGReadingGr3_CACR_TwoorMoreRaces
# 456                    EOGReadingGr3_GLP_TwoorMoreRaces
# 457                   EOGReadingGr3_CACR_TwoorMoreRaces
# 458                    EOGReadingGr3_GLP_TwoorMoreRaces
# 459                     EOGMathGr3-8_GLP_TwoorMoreRaces
# 460                  EOGReadingGr3-8_GLP_TwoorMoreRaces
# 461                       EOGMathGr4_GLP_TwoorMoreRaces
# 462                    EOGReadingGr4_GLP_TwoorMoreRaces
# 463                   EOGReadingGr4_CACR_TwoorMoreRaces
# 464                    EOGReadingGr4_GLP_TwoorMoreRaces
# 465                       EOGMathGr5_GLP_TwoorMoreRaces
# 466                   EOGReadingGr5_CACR_TwoorMoreRaces
# 467                    EOGReadingGr5_GLP_TwoorMoreRaces
# 468                    EOGScienceGr5_GLP_TwoorMoreRaces
# 469                   EOGReadingGr5_CACR_TwoorMoreRaces
# 470                    EOGReadingGr5_GLP_TwoorMoreRaces
# 471                   EOGScienceGr5_CACR_TwoorMoreRaces
# 472                    EOGScienceGr5_GLP_TwoorMoreRaces
# 473                  EOGScienceGr5&8_GLP_TwoorMoreRaces
# 474                    EOGReadingGr3_GLP_TwoorMoreRaces
# 475                  EOGReadingGr3-8_GLP_TwoorMoreRaces
# 476                    EOGReadingGr4_GLP_TwoorMoreRaces
# 477                    EOGReadingGr5_GLP_TwoorMoreRaces
# 478                   EOGScienceGr5_CACR_TwoorMoreRaces
# 479                    EOGScienceGr5_GLP_TwoorMoreRaces
# 480                 EOGScienceGr5&8_CACR_TwoorMoreRaces
# 481                   EOGScienceGr5_CACR_TwoorMoreRaces
# 482                    EOGScienceGr5_GLP_TwoorMoreRaces
# 483                 EOGScienceGr5&8_CACR_TwoorMoreRaces
# 484                  EOGScienceGr5&8_GLP_TwoorMoreRaces
# 485                    EOGScienceGr5_GLP_TwoorMoreRaces
# 486                 EOGScienceGr5&8_CACR_TwoorMoreRaces
# 487                  EOGScienceGr5&8_GLP_TwoorMoreRaces
# 488                 EOGScienceGr5&8_CACR_TwoorMoreRaces
# 489                  EOGScienceGr5&8_GLP_TwoorMoreRaces
# 490                  EOGScienceGr5&8_GLP_TwoorMoreRaces
# 491                      EOGSubjects_GLP_TwoorMoreRaces
# 492                           EOG/EOCSubjects_GLP_White
# 493                              EOGSubjects_CACR_White
# 494                               EOGSubjects_GLP_White
# 495                              EOGSubjects_CACR_White
# 496                               EOGSubjects_GLP_White
# 497                                    EOGGr3_GLP_White
# 498                                    EOGGr4_GLP_White
# 499                                    EOGGr5_GLP_White
# ...                                                 ...
# 277322               Unemployment compensation Ct LT25K
# 277323                     Tot taxes paid Amt 75KLT100K
# 277324                           Tot taxes paid Amt All
# 277325                        Tot taxes paid Amt GE200K
# 277326                         Tot taxes paid Amt LT25K
# 277327                     Tot taxes paid Ct 100KLT200K
# 277328                       Tot taxes paid Ct 25KLT50K
# 277329                       Tot taxes paid Ct 50KLT75K
# 277330                      Tot taxes paid Ct 75KLT100K
# 277331                            Tot taxes paid Ct All
# 277332                         Tot taxes paid Ct GE200K
# 277333                          Tot taxes paid Ct LT25K
# 277334          Tuition and fees deduction Amt 25KLT50K
# 277335          Tuition and fees deduction Amt 50KLT75K
# 277336               Tuition and fees deduction Amt All
# 277337             Tuition and fees deduction Amt LT25K
# 277338           Tuition and fees deduction Ct 25KLT50K
# 277339           Tuition and fees deduction Ct 50KLT75K
# 277340                Tuition and fees deduction Ct All
# 277341              Tuition and fees deduction Ct LT25K
# 277342         Unemployment compensation Amt 100KLT200K
# 277343           Unemployment compensation Amt 25KLT50K
# 277344           Unemployment compensation Amt 50KLT75K
# 277345          Unemployment compensation Amt 75KLT100K
# 277346                Unemployment compensation Amt All
# 277347              Unemployment compensation Amt LT25K
# 277348          Unemployment compensation Ct 100KLT200K
# 277349            Unemployment compensation Ct 25KLT50K
# 277350            Unemployment compensation Ct 50KLT75K
# 277351           Unemployment compensation Ct 75KLT100K
# 277352                 Unemployment compensation Ct All
# 277353                           Tot taxes paid Amt All
# 277354                        Tot taxes paid Amt GE200K
# 277355                         Tot taxes paid Amt LT25K
# 277356                     Tot taxes paid Ct 100KLT200K
# 277357                       Tot taxes paid Ct 25KLT50K
# 277358                       Tot taxes paid Ct 50KLT75K
# 277359                      Tot taxes paid Ct 75KLT100K
# 277360                            Tot taxes paid Ct All
# 277361                         Tot taxes paid Ct GE200K
# 277362                          Tot taxes paid Ct LT25K
# 277363        Tuition and fees deduction Amt 100KLT200K
# 277364          Tuition and fees deduction Amt 25KLT50K
# 277365          Tuition and fees deduction Amt 50KLT75K
# 277366               Tuition and fees deduction Amt All
# 277367             Tuition and fees deduction Amt LT25K
# 277368         Tuition and fees deduction Ct 100KLT200K
# 277369           Tuition and fees deduction Ct 25KLT50K
# 277370           Tuition and fees deduction Ct 50KLT75K
# 277371                Tuition and fees deduction Ct All
# 277372              Tuition and fees deduction Ct LT25K
# 277373         Unemployment compensation Amt 100KLT200K
# 277374           Unemployment compensation Amt 25KLT50K
# 277375           Unemployment compensation Amt 50KLT75K
# 277376          Unemployment compensation Amt 75KLT100K
# 277377                Unemployment compensation Amt All
# 277378          Unemployment compensation Ct 100KLT200K
# 277379            Unemployment compensation Ct 25KLT50K
# 277380            Unemployment compensation Ct 50KLT75K
# 277381           Unemployment compensation Ct 75KLT100K
# 277382                 Unemployment compensation Ct All
# 277383              Unemployment compensation Ct GE200K
# 277384  volunteer prepared w Earned Income Credit LT25K
# 277385                        Tot taxes paid Amt GE200K
# 277386                         Tot taxes paid Amt LT25K
# 277387                     Tot taxes paid Ct 100KLT200K
# 277388                       Tot taxes paid Ct 25KLT50K
# 277389                       Tot taxes paid Ct 50KLT75K
# 277390                      Tot taxes paid Ct 75KLT100K
# 277391                            Tot taxes paid Ct All
# 277392                         Tot taxes paid Ct GE200K
# 277393                          Tot taxes paid Ct LT25K
# 277394          Tuition and fees deduction Amt 25KLT50K
# 277395          Tuition and fees deduction Amt 50KLT75K
# 277396               Tuition and fees deduction Amt All
# 277397             Tuition and fees deduction Amt LT25K
# 277398           Tuition and fees deduction Ct 25KLT50K
# 277399           Tuition and fees deduction Ct 50KLT75K
# 277400                Tuition and fees deduction Ct All
# 277401              Tuition and fees deduction Ct LT25K
# 277402         Unemployment compensation Amt 100KLT200K
# 277403           Unemployment compensation Amt 25KLT50K
# 277404           Unemployment compensation Amt 50KLT75K
# 277405          Unemployment compensation Amt 75KLT100K
# 277406                Unemployment compensation Amt All
# 277407             Unemployment compensation Amt GE200K
# 277408          Unemployment compensation Ct 100KLT200K
# 277409            Unemployment compensation Ct 25KLT50K
# 277410            Unemployment compensation Ct 50KLT75K
# 277411           Unemployment compensation Ct 75KLT100K
# 277412                 Unemployment compensation Ct All
# 277413              Unemployment compensation Ct GE200K
# 277414                         Tot taxes paid Amt LT25K
# 277415                     Tot taxes paid Ct 100KLT200K
# 277416                       Tot taxes paid Ct 25KLT50K
# 277417                       Tot taxes paid Ct 50KLT75K
# 277418                      Tot taxes paid Ct 75KLT100K
# 277419                            Tot taxes paid Ct All
# 277420                         Tot taxes paid Ct GE200K
# 277421                          Tot taxes paid Ct LT25K
# 277422          Tuition and fees deduction Amt 25KLT50K
# 277423          Tuition and fees deduction Amt 50KLT75K
# 277424               Tuition and fees deduction Amt All
# 277425             Tuition and fees deduction Amt LT25K
# 277426           Tuition and fees deduction Ct 25KLT50K
# 277427           Tuition and fees deduction Ct 50KLT75K
# 277428                Tuition and fees deduction Ct All
# 277429              Tuition and fees deduction Ct LT25K
# 277430         Unemployment compensation Amt 100KLT200K
# 277431           Unemployment compensation Amt 25KLT50K
# 277432           Unemployment compensation Amt 50KLT75K
# 277433          Unemployment compensation Amt 75KLT100K
# 277434                Unemployment compensation Amt All
# 277435             Unemployment compensation Amt GE200K
# 277436          Unemployment compensation Ct 100KLT200K
# 277437            Unemployment compensation Ct 25KLT50K
# 277438            Unemployment compensation Ct 50KLT75K
# 277439           Unemployment compensation Ct 75KLT100K
# 277440                 Unemployment compensation Ct All
# 277441              Unemployment compensation Ct GE200K
# 277442                     Tot taxes paid Ct 100KLT200K
# 277443                       Tot taxes paid Ct 25KLT50K
# 277444                       Tot taxes paid Ct 50KLT75K
# 277445                      Tot taxes paid Ct 75KLT100K
# 277446                            Tot taxes paid Ct All
# 277447                         Tot taxes paid Ct GE200K
# 277448                          Tot taxes paid Ct LT25K
# 277449          Tuition and fees deduction Amt 25KLT50K
# 277450          Tuition and fees deduction Amt 50KLT75K
# 277451               Tuition and fees deduction Amt All
# 277452             Tuition and fees deduction Amt LT25K
# 277453           Tuition and fees deduction Ct 25KLT50K
# 277454           Tuition and fees deduction Ct 50KLT75K
# 277455                Tuition and fees deduction Ct All
# 277456              Tuition and fees deduction Ct LT25K
# 277457         Unemployment compensation Amt 100KLT200K
# 277458           Unemployment compensation Amt 25KLT50K
# 277459           Unemployment compensation Amt 50KLT75K
# 277460          Unemployment compensation Amt 75KLT100K
# 277461                Unemployment compensation Amt All
# 277462              Unemployment compensation Amt LT25K
# 277463          Unemployment compensation Ct 100KLT200K
# 277464            Unemployment compensation Ct 25KLT50K
# 277465            Unemployment compensation Ct 50KLT75K
# 277466           Unemployment compensation Ct 75KLT100K
# 277467                 Unemployment compensation Ct All
# 277468               Unemployment compensation Ct LT25K
# 277469                       Tot taxes paid Ct 25KLT50K
# 277470                       Tot taxes paid Ct 50KLT75K
# 277471                      Tot taxes paid Ct 75KLT100K
# 277472                            Tot taxes paid Ct All
# 277473                         Tot taxes paid Ct GE200K
# 277474                          Tot taxes paid Ct LT25K
# 277475        Tuition and fees deduction Amt 100KLT200K
# 277476          Tuition and fees deduction Amt 25KLT50K
# 277477          Tuition and fees deduction Amt 50KLT75K
# 277478               Tuition and fees deduction Amt All
# 277479             Tuition and fees deduction Amt LT25K
# 277480         Tuition and fees deduction Ct 100KLT200K
# 277481           Tuition and fees deduction Ct 25KLT50K
# 277482           Tuition and fees deduction Ct 50KLT75K
# 277483                Tuition and fees deduction Ct All
# 277484              Tuition and fees deduction Ct LT25K
# 277485         Unemployment compensation Amt 100KLT200K
# 277486          Unemployment compensation Amt 75KLT100K
# 277487                Unemployment compensation Amt All
# 277488             Unemployment compensation Amt GE200K
# 277489          Unemployment compensation Ct 100KLT200K
# 277490           Unemployment compensation Ct 75KLT100K
# 277491                 Unemployment compensation Ct All
# 277492              Unemployment compensation Ct GE200K
# 277493                       Tot taxes paid Ct 50KLT75K
# 277494                      Tot taxes paid Ct 75KLT100K
# 277495                            Tot taxes paid Ct All
# 277496                         Tot taxes paid Ct GE200K
# 277497                          Tot taxes paid Ct LT25K
# 277498          Tuition and fees deduction Amt 25KLT50K
# 277499          Tuition and fees deduction Amt 50KLT75K
# 277500               Tuition and fees deduction Amt All
# 277501             Tuition and fees deduction Amt LT25K
# 277502           Tuition and fees deduction Ct 25KLT50K
# 277503           Tuition and fees deduction Ct 50KLT75K
# 277504                Tuition and fees deduction Ct All
# 277505              Tuition and fees deduction Ct LT25K
# 277506           Unemployment compensation Amt 25KLT50K
# 277507           Unemployment compensation Amt 50KLT75K
# 277508          Unemployment compensation Amt 75KLT100K
# 277509                Unemployment compensation Amt All
# 277510              Unemployment compensation Amt LT25K
# 277511            Unemployment compensation Ct 25KLT50K
# 277512            Unemployment compensation Ct 50KLT75K
# 277513           Unemployment compensation Ct 75KLT100K
# 277514                 Unemployment compensation Ct All
# 277515               Unemployment compensation Ct LT25K
# 277516                      Tot taxes paid Ct 75KLT100K
# 277517                            Tot taxes paid Ct All
# 277518                         Tot taxes paid Ct GE200K
# 277519                          Tot taxes paid Ct LT25K
# 277520          Tuition and fees deduction Amt 25KLT50K
# 277521          Tuition and fees deduction Amt 50KLT75K
# 277522               Tuition and fees deduction Amt All
# 277523             Tuition and fees deduction Amt LT25K
# 277524           Tuition and fees deduction Ct 25KLT50K
# 277525           Tuition and fees deduction Ct 50KLT75K
# 277526                Tuition and fees deduction Ct All
# 277527              Tuition and fees deduction Ct LT25K
# 277528         Unemployment compensation Amt 100KLT200K
# 277529           Unemployment compensation Amt 25KLT50K
# 277530           Unemployment compensation Amt 50KLT75K
# 277531          Unemployment compensation Amt 75KLT100K
# 277532                Unemployment compensation Amt All
# 277533              Unemployment compensation Amt LT25K
# 277534          Unemployment compensation Ct 100KLT200K
# 277535            Unemployment compensation Ct 25KLT50K
# 277536            Unemployment compensation Ct 50KLT75K
# 277537           Unemployment compensation Ct 75KLT100K
# 277538                 Unemployment compensation Ct All
# 277539                            Tot taxes paid Ct All
# 277540                         Tot taxes paid Ct GE200K
# 277541                          Tot taxes paid Ct LT25K
# 277542        Tuition and fees deduction Amt 100KLT200K
# 277543          Tuition and fees deduction Amt 25KLT50K
# 277544          Tuition and fees deduction Amt 50KLT75K
# 277545               Tuition and fees deduction Amt All
# 277546             Tuition and fees deduction Amt LT25K
# 277547         Tuition and fees deduction Ct 100KLT200K
# 277548           Tuition and fees deduction Ct 25KLT50K
# 277549           Tuition and fees deduction Ct 50KLT75K
# 277550                Tuition and fees deduction Ct All
# 277551              Tuition and fees deduction Ct LT25K
# 277552         Unemployment compensation Amt 100KLT200K
# 277553           Unemployment compensation Amt 25KLT50K
# 277554           Unemployment compensation Amt 50KLT75K
# 277555          Unemployment compensation Amt 75KLT100K
# 277556                Unemployment compensation Amt All
# 277557          Unemployment compensation Ct 100KLT200K
# 277558            Unemployment compensation Ct 25KLT50K
# 277559            Unemployment compensation Ct 50KLT75K
# 277560           Unemployment compensation Ct 75KLT100K
# 277561                 Unemployment compensation Ct All
# 277562    volunteer prepared w Earned Income Credit All
# 277563  volunteer prepared w Earned Income Credit LT25K
# 277564                         Tot taxes paid Ct GE200K
# 277565                          Tot taxes paid Ct LT25K
# 277566        Tuition and fees deduction Amt 100KLT200K
# 277567          Tuition and fees deduction Amt 25KLT50K
# 277568          Tuition and fees deduction Amt 50KLT75K
# 277569               Tuition and fees deduction Amt All
# 277570             Tuition and fees deduction Amt LT25K
# 277571         Tuition and fees deduction Ct 100KLT200K
# 277572           Tuition and fees deduction Ct 25KLT50K
# 277573           Tuition and fees deduction Ct 50KLT75K
# 277574                Tuition and fees deduction Ct All
# 277575              Tuition and fees deduction Ct LT25K
# 277576         Unemployment compensation Amt 100KLT200K
# 277577           Unemployment compensation Amt 25KLT50K
# 277578           Unemployment compensation Amt 50KLT75K
# 277579          Unemployment compensation Amt 75KLT100K
# 277580                Unemployment compensation Amt All
# 277581             Unemployment compensation Amt GE200K
# 277582          Unemployment compensation Ct 100KLT200K
# 277583            Unemployment compensation Ct 25KLT50K
# 277584            Unemployment compensation Ct 50KLT75K
# 277585           Unemployment compensation Ct 75KLT100K
# 277586                 Unemployment compensation Ct All
# 277587              Unemployment compensation Ct GE200K
# 277588                          Tot taxes paid Ct LT25K
# 277589        Tuition and fees deduction Amt 100KLT200K
# 277590          Tuition and fees deduction Amt 25KLT50K
# 277591          Tuition and fees deduction Amt 50KLT75K
# 277592               Tuition and fees deduction Amt All
# 277593             Tuition and fees deduction Amt LT25K
# 277594         Tuition and fees deduction Ct 100KLT200K
# 277595           Tuition and fees deduction Ct 25KLT50K
# 277596           Tuition and fees deduction Ct 50KLT75K
# 277597                Tuition and fees deduction Ct All
# 277598              Tuition and fees deduction Ct LT25K
# 277599         Unemployment compensation Amt 100KLT200K
# 277600           Unemployment compensation Amt 25KLT50K
# 277601           Unemployment compensation Amt 50KLT75K
# 277602          Unemployment compensation Amt 75KLT100K
# 277603                Unemployment compensation Amt All
# 277604             Unemployment compensation Amt GE200K
# 277605          Unemployment compensation Ct 100KLT200K
# 277606            Unemployment compensation Ct 25KLT50K
# 277607            Unemployment compensation Ct 50KLT75K
# 277608           Unemployment compensation Ct 75KLT100K
# 277609                 Unemployment compensation Ct All
# 277610              Unemployment compensation Ct GE200K
# 277611          Tuition and fees deduction Amt 25KLT50K
# 277612          Tuition and fees deduction Amt 50KLT75K
# 277613               Tuition and fees deduction Amt All
# 277614             Tuition and fees deduction Amt LT25K
# 277615           Tuition and fees deduction Ct 25KLT50K
# 277616           Tuition and fees deduction Ct 50KLT75K
# 277617                Tuition and fees deduction Ct All
# 277618              Tuition and fees deduction Ct LT25K
# 277619           Unemployment compensation Amt 25KLT50K
# 277620           Unemployment compensation Amt 50KLT75K
# 277621          Unemployment compensation Amt 75KLT100K
# 277622                Unemployment compensation Amt All
# 277623              Unemployment compensation Amt LT25K
# 277624            Unemployment compensation Ct 25KLT50K
# 277625            Unemployment compensation Ct 50KLT75K
# 277626           Unemployment compensation Ct 75KLT100K
# 277627                 Unemployment compensation Ct All
# 277628               Unemployment compensation Ct LT25K
# 277629               Tuition and fees deduction Amt All
# 277630         Tuition and fees deduction Ct 100KLT200K
# 277631                Tuition and fees deduction Ct All
# ...
# 277604                           Tot taxes paid Ct GE200K     0.970399
# 277605                           Tot taxes paid Ct GE200K     0.992382
# 277606                           Tot taxes paid Ct GE200K     0.962737
# 277607                           Tot taxes paid Ct GE200K     0.966701
# 277608                           Tot taxes paid Ct GE200K     0.977154
# 277609                           Tot taxes paid Ct GE200K     0.968074
# 277610                           Tot taxes paid Ct GE200K     0.976951
# 277611                            Tot taxes paid Ct LT25K     0.982554
# 277612                            Tot taxes paid Ct LT25K     0.984283
# 277613                            Tot taxes paid Ct LT25K     0.972504
# 277614                            Tot taxes paid Ct LT25K     0.978925
# 277615                            Tot taxes paid Ct LT25K     0.979878
# 277616                            Tot taxes paid Ct LT25K     0.980436
# 277617                            Tot taxes paid Ct LT25K     0.970241
# 277618                            Tot taxes paid Ct LT25K     0.982282
# 277619                            Tot taxes paid Ct LT25K     0.991724
# 277620                            Tot taxes paid Ct LT25K     0.992995
# 277621                            Tot taxes paid Ct LT25K     0.973199
# 277622                            Tot taxes paid Ct LT25K     0.993772
# 277623                            Tot taxes paid Ct LT25K     0.977483
# 277624                            Tot taxes paid Ct LT25K     0.992894
# 277625                            Tot taxes paid Ct LT25K     0.992145
# 277626                            Tot taxes paid Ct LT25K     0.969072
# 277627                            Tot taxes paid Ct LT25K     0.993696
# 277628                            Tot taxes paid Ct LT25K     0.965767
# 277629          Tuition and fees deduction Amt 100KLT200K     0.968895
# 277630          Tuition and fees deduction Amt 100KLT200K     0.999793
# 277631          Tuition and fees deduction Amt 100KLT200K     0.973753
# 277632          Tuition and fees deduction Amt 100KLT200K     0.970012
# 277633          Tuition and fees deduction Amt 100KLT200K     0.958517
# 277634          Tuition and fees deduction Amt 100KLT200K     0.967697
# 277635          Tuition and fees deduction Amt 100KLT200K     0.963930
# 277636            Tuition and fees deduction Amt 25KLT50K     0.987374
# 277637            Tuition and fees deduction Amt 25KLT50K     0.989802
# 277638            Tuition and fees deduction Amt 25KLT50K     0.990341
# 277639            Tuition and fees deduction Amt 25KLT50K     0.999275
# 277640            Tuition and fees deduction Amt 25KLT50K     0.986468
# 277641            Tuition and fees deduction Amt 25KLT50K     0.987704
# 277642            Tuition and fees deduction Amt 25KLT50K     0.990845
# 277643            Tuition and fees deduction Amt 25KLT50K     0.968354
# 277644            Tuition and fees deduction Amt 25KLT50K     0.972747
# 277645            Tuition and fees deduction Amt 25KLT50K     0.970908
# 277646            Tuition and fees deduction Amt 25KLT50K     0.977191
# 277647            Tuition and fees deduction Amt 25KLT50K     0.972339
# 277648            Tuition and fees deduction Amt 25KLT50K     0.970861
# 277649            Tuition and fees deduction Amt 25KLT50K     0.970179
# 277650            Tuition and fees deduction Amt 25KLT50K     0.979056
# 277651            Tuition and fees deduction Amt 25KLT50K     0.956380
# 277652            Tuition and fees deduction Amt 50KLT75K     0.990974
# 277653            Tuition and fees deduction Amt 50KLT75K     0.989074
# 277654            Tuition and fees deduction Amt 50KLT75K     0.985778
# 277655            Tuition and fees deduction Amt 50KLT75K     0.999217
# 277656            Tuition and fees deduction Amt 50KLT75K     0.989835
# 277657            Tuition and fees deduction Amt 50KLT75K     0.990005
# 277658            Tuition and fees deduction Amt 50KLT75K     0.965836
# 277659            Tuition and fees deduction Amt 50KLT75K     0.981284
# 277660            Tuition and fees deduction Amt 50KLT75K     0.981554
# 277661            Tuition and fees deduction Amt 50KLT75K     0.977264
# 277662            Tuition and fees deduction Amt 50KLT75K     0.987555
# 277663            Tuition and fees deduction Amt 50KLT75K     0.950417
# 277664            Tuition and fees deduction Amt 50KLT75K     0.969961
# 277665            Tuition and fees deduction Amt 50KLT75K     0.981030
# 277666            Tuition and fees deduction Amt 50KLT75K     0.979109
# 277667            Tuition and fees deduction Amt 50KLT75K     0.974703
# 277668            Tuition and fees deduction Amt 50KLT75K     0.984010
# 277669           Tuition and fees deduction Amt 75KLT100K     0.993948
# 277670                 Tuition and fees deduction Amt All     0.995904
# 277671                 Tuition and fees deduction Amt All     0.971029
# 277672                 Tuition and fees deduction Amt All     0.989597
# 277673                 Tuition and fees deduction Amt All     0.993471
# 277674                 Tuition and fees deduction Amt All     0.999476
# 277675                 Tuition and fees deduction Amt All     0.996046
# 277676                 Tuition and fees deduction Amt All     0.969148
# 277677                 Tuition and fees deduction Amt All     0.959242
# 277678                 Tuition and fees deduction Amt All     0.964333
# 277679                 Tuition and fees deduction Amt All     0.983488
# 277680                 Tuition and fees deduction Amt All     0.971073
# 277681                 Tuition and fees deduction Amt All     0.971482
# 277682                 Tuition and fees deduction Amt All     0.963520
# 277683                 Tuition and fees deduction Amt All     0.961972
# 277684                 Tuition and fees deduction Amt All     0.984222
# 277685                 Tuition and fees deduction Amt All     0.969670
# 277686                 Tuition and fees deduction Amt All     0.958443
# 277687                 Tuition and fees deduction Amt All     0.960136
# 277688               Tuition and fees deduction Amt LT25K     0.988624
# 277689               Tuition and fees deduction Amt LT25K     0.989563
# 277690               Tuition and fees deduction Amt LT25K     0.993149
# 277691               Tuition and fees deduction Amt LT25K     0.999284
# 277692               Tuition and fees deduction Amt LT25K     0.962784
# 277693               Tuition and fees deduction Amt LT25K     0.966764
# 277694               Tuition and fees deduction Amt LT25K     0.975795
# 277695               Tuition and fees deduction Amt LT25K     0.971795
# 277696               Tuition and fees deduction Amt LT25K     0.953181
# 277697               Tuition and fees deduction Amt LT25K     0.967431
# 277698               Tuition and fees deduction Amt LT25K     0.964876
# 277699               Tuition and fees deduction Amt LT25K     0.975638
# 277700               Tuition and fees deduction Amt LT25K     0.972441
# 277701               Tuition and fees deduction Amt LT25K     0.954316
# 277702               Tuition and fees deduction Amt LT25K     0.959709
# 277703           Tuition and fees deduction Ct 100KLT200K     0.953399
# 277704           Tuition and fees deduction Ct 100KLT200K     0.975981
# 277705           Tuition and fees deduction Ct 100KLT200K     0.972580
# 277706           Tuition and fees deduction Ct 100KLT200K     0.961542
# 277707           Tuition and fees deduction Ct 100KLT200K     0.970456
# 277708           Tuition and fees deduction Ct 100KLT200K     0.966418
# 277709             Tuition and fees deduction Ct 25KLT50K     0.985645
# 277710             Tuition and fees deduction Ct 25KLT50K     0.988385
# 277711             Tuition and fees deduction Ct 25KLT50K     0.989837
# 277712             Tuition and fees deduction Ct 25KLT50K     0.966201
# 277713             Tuition and fees deduction Ct 25KLT50K     0.970229
# 277714             Tuition and fees deduction Ct 25KLT50K     0.972676
# 277715             Tuition and fees deduction Ct 25KLT50K     0.975350
# 277716             Tuition and fees deduction Ct 25KLT50K     0.970230
# 277717             Tuition and fees deduction Ct 25KLT50K     0.968277
# 277718             Tuition and fees deduction Ct 25KLT50K     0.971620
# 277719             Tuition and fees deduction Ct 25KLT50K     0.977155
# 277720             Tuition and fees deduction Ct 25KLT50K     0.951338
# 277721             Tuition and fees deduction Ct 25KLT50K     0.957397
# 277722             Tuition and fees deduction Ct 50KLT75K     0.993168
# 277723             Tuition and fees deduction Ct 50KLT75K     0.990776
# 277724             Tuition and fees deduction Ct 50KLT75K     0.969901
# 277725             Tuition and fees deduction Ct 50KLT75K     0.976680
# 277726             Tuition and fees deduction Ct 50KLT75K     0.977911
# 277727             Tuition and fees deduction Ct 50KLT75K     0.980303
# 277728             Tuition and fees deduction Ct 50KLT75K     0.984262
# 277729             Tuition and fees deduction Ct 50KLT75K     0.973393
# 277730             Tuition and fees deduction Ct 50KLT75K     0.977343
# 277731             Tuition and fees deduction Ct 50KLT75K     0.975498
# 277732             Tuition and fees deduction Ct 50KLT75K     0.978538
# 277733             Tuition and fees deduction Ct 50KLT75K     0.980790
# 277734                  Tuition and fees deduction Ct All     0.994193
# 277735                  Tuition and fees deduction Ct All     0.972710
# 277736                  Tuition and fees deduction Ct All     0.958045
# 277737                  Tuition and fees deduction Ct All     0.963276
# 277738                  Tuition and fees deduction Ct All     0.985963
# 277739                  Tuition and fees deduction Ct All     0.970379
# 277740                  Tuition and fees deduction Ct All     0.974610
# 277741                  Tuition and fees deduction Ct All     0.962277
# 277742                  Tuition and fees deduction Ct All     0.960903
# 277743                  Tuition and fees deduction Ct All     0.986665
# 277744                  Tuition and fees deduction Ct All     0.968548
# 277745                  Tuition and fees deduction Ct All     0.958534
# 277746                  Tuition and fees deduction Ct All     0.959320
# 277747                Tuition and fees deduction Ct LT25K     0.951800
# 277748                Tuition and fees deduction Ct LT25K     0.967342
# 277749                Tuition and fees deduction Ct LT25K     0.971236
# 277750                Tuition and fees deduction Ct LT25K     0.980474
# 277751                Tuition and fees deduction Ct LT25K     0.975977
# 277752                Tuition and fees deduction Ct LT25K     0.955182
# 277753                Tuition and fees deduction Ct LT25K     0.971888
# 277754                Tuition and fees deduction Ct LT25K     0.969529
# 277755                Tuition and fees deduction Ct LT25K     0.979845
# 277756                Tuition and fees deduction Ct LT25K     0.976610
# 277757                Tuition and fees deduction Ct LT25K     0.953747
# 277758                Tuition and fees deduction Ct LT25K     0.959531
# 277759           Unemployment compensation Amt 100KLT200K     0.971223
# 277760           Unemployment compensation Amt 100KLT200K     0.954707
# 277761           Unemployment compensation Amt 100KLT200K     0.983175
# 277762           Unemployment compensation Amt 100KLT200K     0.999629
# 277763           Unemployment compensation Amt 100KLT200K     0.970431
# 277764           Unemployment compensation Amt 100KLT200K     0.987842
# 277765             Unemployment compensation Amt 25KLT50K     0.993989
# 277766             Unemployment compensation Amt 25KLT50K     0.966831
# 277767             Unemployment compensation Amt 25KLT50K     0.997842
# 277768             Unemployment compensation Amt 25KLT50K     0.983068
# 277769             Unemployment compensation Amt 25KLT50K     0.997709
# 277770             Unemployment compensation Amt 25KLT50K     0.994152
# 277771             Unemployment compensation Amt 25KLT50K     0.961067
# 277772             Unemployment compensation Amt 25KLT50K     0.995746
# 277773             Unemployment compensation Amt 25KLT50K     0.967625
# 277774             Unemployment compensation Amt 50KLT75K     0.970495
# 277775             Unemployment compensation Amt 50KLT75K     0.996840
# 277776             Unemployment compensation Amt 50KLT75K     0.976256
# 277777             Unemployment compensation Amt 50KLT75K     0.951347
# 277778             Unemployment compensation Amt 50KLT75K     0.992710
# 277779             Unemployment compensation Amt 50KLT75K     0.998383
# 277780             Unemployment compensation Amt 50KLT75K     0.965527
# 277781             Unemployment compensation Amt 50KLT75K     0.994436
# 277782             Unemployment compensation Amt 50KLT75K     0.961085
# 277783            Unemployment compensation Amt 75KLT100K     0.976626
# 277784            Unemployment compensation Amt 75KLT100K     0.972278
# 277785            Unemployment compensation Amt 75KLT100K     0.971083
# 277786            Unemployment compensation Amt 75KLT100K     0.968673
# 277787            Unemployment compensation Amt 75KLT100K     0.998576
# 277788            Unemployment compensation Amt 75KLT100K     0.974146
# 277789                  Unemployment compensation Amt All     0.977022
# 277790                  Unemployment compensation Amt All     0.959631
# 277791                  Unemployment compensation Amt All     0.996634
# 277792                  Unemployment compensation Amt All     0.996258
# 277793                  Unemployment compensation Amt All     0.971980
# 277794                  Unemployment compensation Amt All     0.997775
# 277795                  Unemployment compensation Amt All     0.962351
# 277796               Unemployment compensation Amt GE200K     0.982940
# 277797               Unemployment compensation Amt GE200K     0.998014
# 277798                Unemployment compensation Amt LT25K     0.981481
# 277799                Unemployment compensation Amt LT25K     0.978487
# 277800                Unemployment compensation Amt LT25K     0.981001
# 277801                Unemployment compensation Amt LT25K     0.993201
# 277802            Unemployment compensation Ct 100KLT200K     0.971549
# 277803            Unemployment compensation Ct 100KLT200K     0.987988
# 277804              Unemployment compensation Ct 25KLT50K     0.995109
# 277805              Unemployment compensation Ct 25KLT50K     0.967661
# 277806              Unemployment compensation Ct 25KLT50K     0.998176
# 277807              Unemployment compensation Ct 25KLT50K     0.971712
# 277808              Unemployment compensation Ct 50KLT75K     0.965107
# 277809              Unemployment compensation Ct 50KLT75K     0.996608
# 277810              Unemployment compensation Ct 50KLT75K     0.967331
# 277811             Unemployment compensation Ct 75KLT100K     0.971244
# 277812                   Unemployment compensation Ct All     0.973655
# 277813  volunteer prepared w Earned Income Credit 25KL...     0.978934
# 277814  volunteer prepared w Earned Income Credit 25KL...     0.963061
# 277815      volunteer prepared w Earned Income Credit All     0.997754
# 277816                                      category_cd_E     1.000000
# 277817                                      category_cd_I     1.000000
# 277818  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 277819  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 277820                                  sna_pgm_type_cd_Y     1.000000
# 277821                                     SPG Grade_A+NG     0.964909
#
# [277822 rows x 3 columns]

# %%
print ('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  1157  highly correlated fields.
# ['Reading SPG Score',
#  'Math SPG Score',
#  'Overall Achievement Score',
#  'Reading Score',
#  'Math Score',
#  'EOG/EOCSubjects_CACR_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_CACR_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGReadingGr5_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_CACR_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_CACR_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_CACR_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_CACR_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_CACR_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr3_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGReadingGr3_GLP_Black',
#  'EOGReadingGr3-8_GLP_Black',
#  'EOGReadingGr4_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_CACR_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_CACR_Black',
#  'EOGSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_Hispanic',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGReadingGr3_GLP_Hispanic',
#  'EOGReadingGr4_GLP_Hispanic',
#  'EOGReadingGr5_GLP_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_CACR_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_CACR_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_CACR_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr3-8_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_CACR_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_CACR_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_CACR_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_CACR_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_CACR_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_CACR_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_CACR_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_CACR_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOGGr3_GLP_LEP',
#  'EOGGr5_GLP_LEP',
#  'EOGMathGr3_GLP_LEP',
#  'EOGMathGr3-8_GLP_LEP',
#  'EOGMathGr4_GLP_LEP',
#  'EOGMathGr5_GLP_LEP',
#  'EOGScienceGr5&8_CACR_LEP',
#  'EOGScienceGr5&8_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOGSubjects_GLP_LEP',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGMathGr4_GLP_SWD',
#  'EOGScienceGr5&8_CACR_SWD',
#  'EOGScienceGr5&8_GLP_SWD',
#  'EOGSubjects_CACR_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_CACR_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_CACR_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'ReadingGr3-8_pTarget_PctMet',
#  'TotalTargets_pTarget_PctMet',
#  'st_short_susp_per_c_num',
#  'st_long_susp_per_c_num',
#  'lateral_teach_pct',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'st_flicensed_teach_pct',
#  'st_tchyrs_0thru3_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_class_teach_num',
#  'st_nbpts_num',
#  'st_advance_dgr_pct',
#  'st_1yr_tchr_trnovr_pct',
#  'st_emer_prov_teach_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'Not Demostrated_TCHR_Standard 3_Pct',
#  'Not Demostrated_TCHR_Standard 5_Pct',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'HispanicMalePct',
#  'BlackMalePct',
#  'WhiteMalePct',
#  'MinorityMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'HispanicFemalePct',
#  'BlackFemalePct',
#  'WhiteFemalePct',
#  'MinorityFemalePct',
#  'Robbery Rate',
#  'Assault Rate',
#  '(TCE) prepared returns Ct 50KLT75K',
#  '(TCE) prepared returns Ct All',
#  '(TCE) prepared returns Ct LT25K',
#  '(VITA) prepared returns Ct 75KLT100K',
#  '(VITA) prepared returns Ct All',
#  '(VITA) prepared returns Ct LT25K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Advance premium tax credit Amt 100KLT200K',
#  'Advance premium tax credit Amt 25KLT50K',
#  'Advance premium tax credit Amt 50KLT75K',
#  'Advance premium tax credit Amt 75KLT100K',
#  'Advance premium tax credit Amt All',
#  'Advance premium tax credit Amt LT25K',
#  'Advance premium tax credit Ct 100KLT200K',
#  'Advance premium tax credit Ct 25KLT50K',
#  'Advance premium tax credit Ct 50KLT75K',
#  'Advance premium tax credit Ct 75KLT100K',
#  'Advance premium tax credit Ct All',
#  'Advance premium tax credit Ct GE200K',
#  'Advance premium tax credit Ct LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Deductible points Amt 100KLT200K',
#  'Deductible points Amt 25KLT50K',
#  'Deductible points Amt 50KLT75K',
#  'Deductible points Amt 75KLT100K',
#  'Deductible points Amt All',
#  'Deductible points Amt GE200K',
#  'Deductible points Ct 100KLT200K',
#  'Deductible points Ct 25KLT50K',
#  'Deductible points Ct 50KLT75K',
#  'Deductible points Ct 75KLT100K',
#  'Deductible points Ct All',
#  'Deductible points Ct GE200K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Ct 100KLT200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct 50KLT75K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess advance premium tax credit repayment Amt 100KLT200K',
#  'Excess advance premium tax credit repayment Amt 25KLT50K',
#  'Excess advance premium tax credit repayment Amt 50KLT75K',
#  'Excess advance premium tax credit repayment Amt 75KLT100K',
#  'Excess advance premium tax credit repayment Amt All',
#  'Excess advance premium tax credit repayment Amt LT25K',
#  'Excess advance premium tax credit repayment Ct 100KLT200K',
#  'Excess advance premium tax credit repayment Ct 25KLT50K',
#  'Excess advance premium tax credit repayment Ct 50KLT75K',
#  'Excess advance premium tax credit repayment Ct 75KLT100K',
#  'Excess advance premium tax credit repayment Ct All',
#  'Excess advance premium tax credit repayment Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct 50KLT75K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'Health care individual responsibility payment Amt 100KLT200K',
#  'Health care individual responsibility payment Amt 25KLT50K',
#  'Health care individual responsibility payment Amt 50KLT75K',
#  'Health care individual responsibility payment Amt 75KLT100K',
#  'Health care individual responsibility payment Amt All',
#  'Health care individual responsibility payment Amt LT25K',
#  'Health care individual responsibility payment Ct 100KLT200K',
#  'Health care individual responsibility payment Ct 25KLT50K',
#  'Health care individual responsibility payment Ct 50KLT75K',
#  'Health care individual responsibility payment Ct 75KLT100K',
#  'Health care individual responsibility payment Ct All',
#  'Health care individual responsibility payment Ct GE200K',
#  'Health care individual responsibility payment Ct LT25K',
#  'Home mortgage interest paid Amt 100KLT200K',
#  'Home mortgage interest paid Amt 25KLT50K',
#  'Home mortgage interest paid Amt 50KLT75K',
#  'Home mortgage interest paid Amt 75KLT100K',
#  'Home mortgage interest paid Amt All',
#  'Home mortgage interest paid Amt GE200K',
#  'Home mortgage interest paid Amt LT25K',
#  'Home mortgage interest paid Ct 100KLT200K',
#  'Home mortgage interest paid Ct 25KLT50K',
#  'Home mortgage interest paid Ct 50KLT75K',
#  'Home mortgage interest paid Ct 75KLT100K',
#  'Home mortgage interest paid Ct All',
#  'Home mortgage interest paid Ct GE200K',
#  'Home mortgage interest paid Ct LT25K',
#  'Home mortgage interest paid from personal seller Amt 100KLT200K',
#  'Home mortgage interest paid from personal seller Amt 25KLT50K',
#  'Home mortgage interest paid from personal seller Amt 50KLT75K',
#  'Home mortgage interest paid from personal seller Amt 75KLT100K',
#  'Home mortgage interest paid from personal seller Amt All',
#  'Home mortgage interest paid from personal seller Amt GE200K',
#  'Home mortgage interest paid from personal seller Ct 100KLT200K',
#  'Home mortgage interest paid from personal seller Ct 25KLT50K',
#  'Home mortgage interest paid from personal seller Ct 50KLT75K',
#  'Home mortgage interest paid from personal seller Ct 75KLT100K',
#  'Home mortgage interest paid from personal seller Ct All',
#  'Home mortgage interest paid from personal seller Ct GE200K',
#  'Home mortgage interest paid from personal seller Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Individual retirement arrangement payments Amt 100KLT200K',
#  'Individual retirement arrangement payments Amt 25KLT50K',
#  'Individual retirement arrangement payments Amt 50KLT75K',
#  'Individual retirement arrangement payments Amt 75KLT100K',
#  'Individual retirement arrangement payments Amt All',
#  'Individual retirement arrangement payments Amt GE200K',
#  'Individual retirement arrangement payments Amt LT25K',
#  'Individual retirement arrangement payments Ct 100KLT200K',
#  'Individual retirement arrangement payments Ct 25KLT50K',
#  'Individual retirement arrangement payments Ct 50KLT75K',
#  'Individual retirement arrangement payments Ct 75KLT100K',
#  'Individual retirement arrangement payments Ct All',
#  'Individual retirement arrangement payments Ct GE200K',
#  'Individual retirement arrangement payments Ct LT25K',
#  'Investment interest paid Amt 100KLT200K',
#  'Investment interest paid Amt 50KLT75K',
#  'Investment interest paid Amt 75KLT100K',
#  'Investment interest paid Amt All',
#  'Investment interest paid Amt GE200K',
#  'Investment interest paid Ct 100KLT200K',
#  'Investment interest paid Ct 25KLT50K',
#  'Investment interest paid Ct 50KLT75K',
#  'Investment interest paid Ct 75KLT100K',
#  'Investment interest paid Ct All',
#  'Investment interest paid Ct GE200K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct 100KLT200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Net limited misc deduction Amt 100KLT200K',
#  'Net limited misc deduction Amt 25KLT50K',
#  'Net limited misc deduction Amt 50KLT75K',
#  'Net limited misc deduction Amt 75KLT100K',
#  'Net limited misc deduction Amt All',
#  'Net limited misc deduction Amt GE200K',
#  'Net limited misc deduction Amt LT25K',
#  'Net limited misc deduction Ct 100KLT200K',
#  'Net limited misc deduction Ct 25KLT50K',
#  'Net limited misc deduction Ct 50KLT75K',
#  'Net limited misc deduction Ct 75KLT100K',
#  'Net limited misc deduction Ct All',
#  'Net limited misc deduction Ct GE200K',
#  'Net limited misc deduction Ct LT25K',
#  'Net premium tax credit Amt 25KLT50K',
#  'Net premium tax credit Amt 50KLT75K',
#  'Net premium tax credit Amt All',
#  'Net premium tax credit Amt LT25K',
#  'Net premium tax credit Ct 25KLT50K',
#  'Net premium tax credit Ct 50KLT75K',
#  'Net premium tax credit Ct All',
#  'Net premium tax credit Ct LT25K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of elderly returns 100KLT200K',
#  'Number of elderly returns 25KLT50K',
#  'Number of elderly returns 50KLT75K',
#  'Number of elderly returns 75KLT100K',
#  'Number of elderly returns All',
#  'Number of elderly returns GE200K',
#  'Number of elderly returns LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of refund anticipation check returns 100KLT200K',
#  'Number of refund anticipation check returns 25KLT50K',
#  'Number of refund anticipation check returns 50KLT75K',
#  'Number of refund anticipation check returns 75KLT100K',
#  'Number of refund anticipation check returns All',
#  'Number of refund anticipation check returns GE200K',
#  'Number of refund anticipation check returns LT25K',
#  'Number of refund anticipation loan returns 25KLT50K',
#  'Number of refund anticipation loan returns All',
#  'Number of refund anticipation loan returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  'Number of volunteer prepared returns Tot 100KLT200K',
#  'Number of volunteer prepared returns Tot 25KLT50K',
#  'Number of volunteer prepared returns Tot 75KLT100K',
#  'Number of volunteer prepared returns Tot All',
#  'Number of volunteer prepared returns Tot LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Other non-limited misc deduction Amt 100KLT200K',
#  'Other non-limited misc deduction Amt 25KLT50K',
#  'Other non-limited misc deduction Amt All',
#  'Other non-limited misc deduction Amt GE200K',
#  'Other non-limited misc deduction Ct 100KLT200K',
#  'Other non-limited misc deduction Ct 25KLT50K',
#  'Other non-limited misc deduction Ct 50KLT75K',
#  'Other non-limited misc deduction Ct All',
#  'Other non-limited misc deduction Ct GE200K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Personal property taxes Amt 100KLT200K',
#  'Personal property taxes Amt 25KLT50K',
#  'Personal property taxes Amt 50KLT75K',
#  'Personal property taxes Amt 75KLT100K',
#  'Personal property taxes Amt All',
#  'Personal property taxes Amt GE200K',
#  'Personal property taxes Amt LT25K',
#  'Personal property taxes Ct 100KLT200K',
#  'Personal property taxes Ct 25KLT50K',
#  'Personal property taxes Ct 50KLT75K',
#  'Personal property taxes Ct 75KLT100K',
#  'Personal property taxes Ct All',
#  'Personal property taxes Ct GE200K',
#  'Personal property taxes Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Qualified mortgage insurance premiums Amt 100KLT200K',
#  'Qualified mortgage insurance premiums Amt 25KLT50K',
#  'Qualified mortgage insurance premiums Amt 50KLT75K',
#  'Qualified mortgage insurance premiums Amt 75KLT100K',
#  'Qualified mortgage insurance premiums Amt All',
#  'Qualified mortgage insurance premiums Amt LT25K',
#  'Qualified mortgage insurance premiums Ct 100KLT200K',
#  'Qualified mortgage insurance premiums Ct 25KLT50K',
#  'Qualified mortgage insurance premiums Ct 50KLT75K',
#  'Qualified mortgage insurance premiums Ct 75KLT100K',
#  'Qualified mortgage insurance premiums Ct All',
#  'Qualified mortgage insurance premiums Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Retirement savings contributions credit Amt 25KLT50K',
#  'Retirement savings contributions credit Amt 50KLT75K',
#  'Retirement savings contributions credit Amt All',
#  'Retirement savings contributions credit Amt LT25K',
#  'Retirement savings contributions credit Ct 25KLT50K',
#  'Retirement savings contributions credit Ct 50KLT75K',
#  'Retirement savings contributions credit Ct All',
#  'Retirement savings contributions credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employed (Keogh) retirement plans Amt 100KLT200K',
#  'Self-employed (Keogh) retirement plans Amt 25KLT50K',
#  'Self-employed (Keogh) retirement plans Amt 50KLT75K',
#  'Self-employed (Keogh) retirement plans Amt All',
#  'Self-employed (Keogh) retirement plans Amt GE200K',
#  'Self-employed (Keogh) retirement plans Ct 100KLT200K',
#  'Self-employed (Keogh) retirement plans Ct 25KLT50K',
#  'Self-employed (Keogh) retirement plans Ct 50KLT75K',
#  'Self-employed (Keogh) retirement plans Ct 75KLT100K',
#  'Self-employed (Keogh) retirement plans Ct All',
#  'Self-employed (Keogh) retirement plans Ct GE200K',
#  'Self-employed health insurance deduction Amt 100KLT200K',
#  'Self-employed health insurance deduction Amt 25KLT50K',
#  'Self-employed health insurance deduction Amt 50KLT75K',
#  'Self-employed health insurance deduction Amt 75KLT100K',
#  'Self-employed health insurance deduction Amt All',
#  'Self-employed health insurance deduction Amt GE200K',
#  'Self-employed health insurance deduction Amt LT25K',
#  'Self-employed health insurance deduction Ct 100KLT200K',
#  'Self-employed health insurance deduction Ct 25KLT50K',
#  'Self-employed health insurance deduction Ct 50KLT75K',
#  'Self-employed health insurance deduction Ct 75KLT100K',
#  'Self-employed health insurance deduction Ct All',
#  'Self-employed health insurance deduction Ct GE200K',
#  'Self-employed health insurance deduction Ct LT25K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt GE200K',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  'Taxable interest Ct 100KLT200K',
#  'Taxable interest Ct 25KLT50K',
#  'Taxable interest Ct 50KLT75K',
#  'Taxable interest Ct 75KLT100K',
#  'Taxable interest Ct All',
#  'Taxable interest Ct GE200K',
#  'Taxable interest Ct LT25K',
#  'Tot Add Medicare tax Amt 100KLT200K',
#  'Tot Add Medicare tax Amt 50KLT75K',
#  'Tot Add Medicare tax Amt All',
#  'Tot Add Medicare tax Amt GE200K',
#  'Tot Add Medicare tax Ct 100KLT200K',
#  'Tot Add Medicare tax Ct 25KLT50K',
#  'Tot Add Medicare tax Ct 50KLT75K',
#  'Tot Add Medicare tax Ct All',
#  'Tot Add Medicare tax Ct GE200K',
#  'Tot charitable contributions Amt 100KLT200K',
#  'Tot charitable contributions Amt 25KLT50K',
#  'Tot charitable contributions Amt 50KLT75K',
#  'Tot charitable contributions Amt 75KLT100K',
#  'Tot charitable contributions Amt All',
#  'Tot charitable contributions Amt GE200K',
#  'Tot charitable contributions Amt LT25K',
#  'Tot charitable contributions Ct 100KLT200K',
#  'Tot charitable contributions Ct 25KLT50K',
#  'Tot charitable contributions Ct 50KLT75K',
#  'Tot charitable contributions Ct 75KLT100K',
#  'Tot charitable contributions Ct All',
#  'Tot charitable contributions Ct GE200K',
#  'Tot charitable contributions Ct LT25K',
#  'Tot income Amt 100KLT200K',
#  'Tot income Amt 25KLT50K',
#  'Tot income Amt 50KLT75K',
#  'Tot income Amt 75KLT100K',
#  'Tot income Amt All',
#  'Tot income Amt GE200K',
#  'Tot income Amt LT25K',
#  'Tot income Ct 100KLT200K',
#  ...]

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 1528 entries, student_num to SRC_Grades_Devices_Sent_Home_PK
# dtypes: float64(1479), uint8(49)
# memory usage: 14.4 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 371 entries, student_num to SRC_Grades_Devices_Sent_Home_PK
# dtypes: float64(330), uint8(41)
# memory usage: 3.3 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Data columns (total 372 columns):
# student_num                                                   float64
# lea_avg_student_num                                           float64
# st_avg_student_num                                            float64
# 00_Size                                                       float64
# 01_Size                                                       float64
# 02_Size                                                       float64
# 03_Size                                                       float64
# 04_Size                                                       float64
# 05_Size                                                       float64
# lea_total_expense_num                                         float64
# lea_salary_expense_pct                                        float64
# lea_services_expense_pct                                      float64
# lea_supplies_expense_pct                                      float64
# lea_instruct_equip_exp_pct                                    float64
# lea_federal_perpupil_num                                      float64
# lea_local_perpupil_num                                        float64
# lea_state_perpupil_num                                        float64
# SPG Score                                                     float64
# EVAAS Growth Score                                            float64
# Science Score                                                 float64
# EOGGr3_CACR_All                                               float64
# EOGGr4_CACR_All                                               float64
# EOGGr5_CACR_All                                               float64
# EOGReadingGr5_CACR_All                                        float64
# EOGGr4_CACR_Female                                            float64
# EOGMathGr3_CACR_Female                                        float64
# EOGMathGr4_CACR_Female                                        float64
# EOGMathGr5_CACR_Female                                        float64
# EOGReadingGr3_CACR_Female                                     float64
# EOGReadingGr4_CACR_Female                                     float64
# EOGReadingGr4_GLP_Female                                      float64
# EOGReadingGr5_CACR_Female                                     float64
# EOGScienceGr5_CACR_Female                                     float64
# EOGMathGr3_CACR_Male                                          float64
# EOGMathGr4_CACR_Male                                          float64
# EOGMathGr5_CACR_Male                                          float64
# EOGReadingGr3_CACR_Male                                       float64
# EOGReadingGr4_CACR_Male                                       float64
# EOGReadingGr4_GLP_Male                                        float64
# EOGReadingGr5_CACR_Male                                       float64
# EOGScienceGr5_CACR_Male                                       float64
# EOG/EOCSubjects_CACR_AmericanIndian                           float64
# EOGGr3_CACR_AmericanIndian                                    float64
# EOGGr4_CACR_AmericanIndian                                    float64
# EOGGr5_CACR_AmericanIndian                                    float64
# EOGMathGr3_CACR_AmericanIndian                                float64
# EOGMathGr3-8_CACR_AmericanIndian                              float64
# EOGMathGr4_CACR_AmericanIndian                                float64
# EOGMathGr5_CACR_AmericanIndian                                float64
# EOGReadingGr3_CACR_AmericanIndian                             float64
# EOGReadingGr4_CACR_AmericanIndian                             float64
# EOGReadingGr5_CACR_AmericanIndian                             float64
# EOGScienceGr5_CACR_AmericanIndian                             float64
# EOG/EOCSubjects_CACR_Asian                                    float64
# EOGGr3_CACR_Asian                                             float64
# EOGGr4_CACR_Asian                                             float64
# EOGGr5_CACR_Asian                                             float64
# EOGMathGr3_CACR_Asian                                         float64
# EOGMathGr3-8_CACR_Asian                                       float64
# EOGMathGr4_CACR_Asian                                         float64
# EOGMathGr5_CACR_Asian                                         float64
# EOG/EOCSubjects_CACR_Black                                    float64
# EOGGr3_CACR_Black                                             float64
# EOGGr4_CACR_Black                                             float64
# EOGGr5_CACR_Black                                             float64
# EOGMathGr3_CACR_Black                                         float64
# EOGMathGr3-8_CACR_Black                                       float64
# EOGMathGr4_CACR_Black                                         float64
# EOGMathGr5_CACR_Black                                         float64
# EOGReadingGr3_CACR_Black                                      float64
# EOGReadingGr3-8_CACR_Black                                    float64
# EOGReadingGr4_CACR_Black                                      float64
# EOGReadingGr5_CACR_Black                                      float64
# EOGReadingGr5_GLP_Black                                       float64
# EOGScienceGr5_CACR_Black                                      float64
# EOG/EOCSubjects_CACR_Hispanic                                 float64
# EOGGr3_CACR_Hispanic                                          float64
# EOGGr4_CACR_Hispanic                                          float64
# EOGGr5_CACR_Hispanic                                          float64
# EOGMathGr3_CACR_Hispanic                                      float64
# EOGMathGr3-8_CACR_Hispanic                                    float64
# EOGMathGr4_CACR_Hispanic                                      float64
# EOGMathGr5_CACR_Hispanic                                      float64
# EOGReadingGr3_CACR_Hispanic                                   float64
# EOGReadingGr3-8_CACR_Hispanic                                 float64
# EOGReadingGr3-8_GLP_Hispanic                                  float64
# EOGReadingGr4_CACR_Hispanic                                   float64
# EOGReadingGr5_CACR_Hispanic                                   float64
# EOGScienceGr5_CACR_Hispanic                                   float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                           float64
# EOGGr3_CACR_TwoorMoreRaces                                    float64
# EOGGr4_CACR_TwoorMoreRaces                                    float64
# EOGGr5_CACR_TwoorMoreRaces                                    float64
# EOGMathGr3_CACR_TwoorMoreRaces                                float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                              float64
# EOGMathGr4_CACR_TwoorMoreRaces                                float64
# EOGMathGr5_CACR_TwoorMoreRaces                                float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                           float64
# EOG/EOCSubjects_CACR_White                                    float64
# EOGGr3_CACR_White                                             float64
# EOGGr4_CACR_White                                             float64
# EOGGr5_CACR_White                                             float64
# EOGMathGr3_CACR_White                                         float64
# EOGMathGr3-8_CACR_White                                       float64
# EOGMathGr4_CACR_White                                         float64
# EOGMathGr5_CACR_White                                         float64
# EOGReadingGr3_CACR_White                                      float64
# EOGReadingGr3-8_CACR_White                                    float64
# EOGReadingGr4_CACR_White                                      float64
# EOGReadingGr5_CACR_White                                      float64
# EOG/EOCSubjects_CACR_EDS                                      float64
# EOGGr3_CACR_EDS                                               float64
# EOGGr4_CACR_EDS                                               float64
# EOGGr5_CACR_EDS                                               float64
# EOGMathGr3_CACR_EDS                                           float64
# EOGMathGr3_GLP_EDS                                            float64
# EOGMathGr3-8_CACR_EDS                                         float64
# EOGMathGr4_CACR_EDS                                           float64
# EOGMathGr5_CACR_EDS                                           float64
# EOGReadingGr3_CACR_EDS                                        float64
# EOGReadingGr3_GLP_EDS                                         float64
# EOGReadingGr3-8_CACR_EDS                                      float64
# EOGReadingGr4_CACR_EDS                                        float64
# EOGReadingGr4_GLP_EDS                                         float64
# EOGReadingGr5_CACR_EDS                                        float64
# EOGReadingGr5_GLP_EDS                                         float64
# EOGScienceGr5_CACR_EDS                                        float64
# EOG/EOCSubjects_CACR_LEP                                      float64
# EOG/EOCSubjects_GLP_LEP                                       float64
# EOGGr3_CACR_LEP                                               float64
# EOGGr4_CACR_LEP                                               float64
# EOGGr4_GLP_LEP                                                float64
# EOGGr5_CACR_LEP                                               float64
# EOGMathGr3_CACR_LEP                                           float64
# EOGMathGr3-8_CACR_LEP                                         float64
# EOGMathGr4_CACR_LEP                                           float64
# EOGMathGr5_CACR_LEP                                           float64
# EOGReadingGr3_CACR_LEP                                        float64
# EOGReadingGr3_GLP_LEP                                         float64
# EOGReadingGr3-8_CACR_LEP                                      float64
# EOGReadingGr3-8_GLP_LEP                                       float64
# EOGReadingGr4_CACR_LEP                                        float64
# EOGReadingGr4_GLP_LEP                                         float64
# EOGReadingGr5_CACR_LEP                                        float64
# EOGReadingGr5_GLP_LEP                                         float64
# EOGScienceGr5_CACR_LEP                                        float64
# EOGScienceGr5_GLP_LEP                                         float64
# EOG/EOCSubjects_CACR_SWD                                      float64
# EOGGr3_CACR_SWD                                               float64
# EOGGr3_GLP_SWD                                                float64
# EOGGr4_CACR_SWD                                               float64
# EOGGr4_GLP_SWD                                                float64
# EOGGr5_CACR_SWD                                               float64
# EOGGr5_GLP_SWD                                                float64
# EOGMathGr3_CACR_SWD                                           float64
# EOGMathGr3_GLP_SWD                                            float64
# EOGMathGr3-8_CACR_SWD                                         float64
# EOGMathGr3-8_GLP_SWD                                          float64
# EOGMathGr4_CACR_SWD                                           float64
# EOGMathGr5_CACR_SWD                                           float64
# EOGMathGr5_GLP_SWD                                            float64
# EOGReadingGr3_CACR_SWD                                        float64
# EOGReadingGr3_GLP_SWD                                         float64
# EOGReadingGr3-8_CACR_SWD                                      float64
# EOGReadingGr3-8_GLP_SWD                                       float64
# EOGReadingGr4_CACR_SWD                                        float64
# EOGReadingGr4_GLP_SWD                                         float64
# EOGReadingGr5_CACR_SWD                                        float64
# EOGReadingGr5_GLP_SWD                                         float64
# EOGScienceGr5_CACR_SWD                                        float64
# EOGScienceGr5_GLP_SWD                                         float64
# EOG/EOCSubjects_CACR_AIG                                      float64
# EOGGr3_CACR_AIG                                               float64
# EOGGr4_CACR_AIG                                               float64
# EOGGr5_CACR_AIG                                               float64
# EOGMathGr3_CACR_AIG                                           float64
# EOGMathGr3-8_CACR_AIG                                         float64
# EOGMathGr4_CACR_AIG                                           float64
# EOGMathGr5_CACR_AIG                                           float64
# pct_GCE_ALL                                                   float64
# pct_PASSED_LAA                                                float64
# pct_PROMOTED                                                  float64
# pct_RETAINED                                                  float64
# MathGr3-8_pTarget_PctMet                                      float64
# SciGr5&8_pTarget_PctMet                                       float64
# lea_sat_avg_score_num                                         float64
# lea_sat_participation_pct                                     float64
# lea_ap_participation_pct                                      float64
# lea_ap_pct_3_or_above                                         float64
# lea_ib_pct_4_or_above                                         float64
# avg_daily_attend_pct                                          float64
# crime_per_c_num                                               float64
# short_susp_per_c_num                                          float64
# long_susp_per_c_num                                           float64
# stud_internet_comp_num                                        float64
# lea_avg_daily_attend_pct                                      float64
# lea_crime_per_c_num                                           float64
# lea_short_susp_per_c_num                                      float64
# lea_long_susp_per_c_num                                       float64
# lea_stud_internet_comp_num                                    float64
# st_avg_daily_attend_pct                                       float64
# st_crime_per_c_num                                            float64
# digital_media_pct                                             float64
# avg_age_media_collection                                      float64
# books_per_student                                             float64
# lea_avg_age_media_collection                                  float64
# lea_books_per_student                                         float64
# wap_num                                                       float64
# wap_per_classroom                                             float64
# lea_wap_num                                                   float64
# lea_wap_per_classroom                                         float64
# flicensed_teach_pct                                           float64
# tchyrs_0thru3_pct                                             float64
# tchyrs_4thru10_pct                                            float64
# tchyrs_11plus_pct                                             float64
# class_teach_num                                               float64
# nbpts_num                                                     float64
# advance_dgr_pct                                               float64
# _1yr_tchr_trnovr_pct                                          float64
# lea_flicensed_teach_pct                                       float64
# lea_tchyrs_0thru3_pct                                         float64
# lea_tchyrs_4thru10_pct                                        float64
# lea_tchyrs_11plus_pct                                         float64
# lea_nbpts_num                                                 float64
# lea_advance_dgr_pct                                           float64
# lea_1yr_tchr_trnovr_pct                                       float64
# lea_emer_prov_teach_pct                                       float64
# st_tchyrs_11plus_pct                                          float64
# 0-3 Years_LEA_Exp_Pct_Prin                                    float64
# 10+ Years_LEA_Exp_Pct_Prin                                    float64
# 4-10 Years_LEA_Exp_Pct_Prin                                   float64
# Accomplished_TCHR_Standard 1_Pct                              float64
# Accomplished_TCHR_Standard 2_Pct                              float64
# Accomplished_TCHR_Standard 3_Pct                              float64
# Accomplished_TCHR_Standard 4_Pct                              float64
# Accomplished_TCHR_Standard 5_Pct                              float64
# Developing_TCHR_Standard 1_Pct                                float64
# Developing_TCHR_Standard 2_Pct                                float64
# Developing_TCHR_Standard 3_Pct                                float64
# Developing_TCHR_Standard 4_Pct                                float64
# Developing_TCHR_Standard 5_Pct                                float64
# Distinguished_TCHR_Standard 1_Pct                             float64
# Distinguished_TCHR_Standard 2_Pct                             float64
# Distinguished_TCHR_Standard 3_Pct                             float64
# Distinguished_TCHR_Standard 4_Pct                             float64
# Distinguished_TCHR_Standard 5_Pct                             float64
# Does Not Meet Expected Growth_TCHR_Student Growth_Pct         float64
# Exceeds Expected Growth_TCHR_Student Growth_Pct               float64
# Meets Expected Growth_TCHR_Student Growth_Pct                 float64
# Not Demostrated_TCHR_Standard 1_Pct                           float64
# Not Demostrated_TCHR_Standard 2_Pct                           float64
# Not Demostrated_TCHR_Standard 4_Pct                           float64
# Proficient_TCHR_Standard 1_Pct                                float64
# Proficient_TCHR_Standard 2_Pct                                float64
# Proficient_TCHR_Standard 3_Pct                                float64
# Proficient_TCHR_Standard 4_Pct                                float64
# Proficient_TCHR_Standard 5_Pct                                float64
# IndianPct                                                     float64
# AsianPct                                                      float64
# HispanicPct                                                   float64
# BlackPct                                                      float64
# WhitePct                                                      float64
# PacificIslandPct                                              float64
# TwoOrMorePct                                                  float64
# PacificIslandMalePct                                          float64
# TwoOrMoreMalePct                                              float64
# PacificIslandFemalePct                                        float64
# TwoOrMoreFemalePct                                            float64
# pct_eds                                                       float64
# Year                                                          float64
# Violent Rate                                                  float64
# Murder Rate                                                   float64
# Rape Rate                                                     float64
# MVT Rate                                                      float64
# Arson Rate                                                    float64
# (TCE) prepared returns Ct 100KLT200K                          float64
# (TCE) prepared returns Ct 25KLT50K                            float64
# (TCE) prepared returns Ct 75KLT100K                           float64
# (VITA) prepared returns Ct 100KLT200K                         float64
# (VITA) prepared returns Ct 25KLT50K                           float64
# (VITA) prepared returns Ct 50KLT75K                           float64
# Add child tax credit Amt 25KLT50K                             float64
# Add child tax credit Amt 75KLT100K                            float64
# Advance premium tax credit Amt GE200K                         float64
# Alternative minimum tax Amt 25KLT50K                          float64
# Alternative minimum tax Amt 50KLT75K                          float64
# Alternative minimum tax Amt 75KLT100K                         float64
# Alternative minimum tax Ct 50KLT75K                           float64
# Alternative minimum tax Ct 75KLT100K                          float64
# Deductible points Amt LT25K                                   float64
# Deductible points Ct LT25K                                    float64
# Domestic production activities deduction Amt 100KLT200K       float64
# Domestic production activities deduction Amt 25KLT50K         float64
# Domestic production activities deduction Amt 50KLT75K         float64
# Domestic production activities deduction Amt 75KLT100K        float64
# Domestic production activities deduction Amt LT25K            float64
# Domestic production activities deduction Ct 25KLT50K          float64
# Domestic production activities deduction Ct 50KLT75K          float64
# Domestic production activities deduction Ct 75KLT100K         float64
# Domestic production activities deduction Ct LT25K             float64
# Earned income credit Amt 50KLT75K                             float64
# Excess earned income credit (refundable) Amt 50KLT75K         float64
# Health care individual responsibility payment Amt GE200K      float64
# Home mortgage interest paid from personal seller Amt LT25K    float64
# Investment interest paid Amt 25KLT50K                         float64
# Investment interest paid Amt LT25K                            float64
# Investment interest paid Ct LT25K                             float64
# Net investment income tax Amt 100KLT200K                      float64
# Number of farm returns 100KLT200K                             float64
# Number of farm returns 25KLT50K                               float64
# Number of farm returns 50KLT75K                               float64
# Number of farm returns 75KLT100K                              float64
# Number of farm returns All                                    float64
# Number of farm returns GE200K                                 float64
# Number of farm returns LT25K                                  float64
# Number of refund anticipation loan returns 50KLT75K           float64
# Number of volunteer prepared returns Tot 50KLT75K             float64
# Other non-limited misc deduction Amt 50KLT75K                 float64
# Other non-limited misc deduction Amt 75KLT100K                float64
# Other non-limited misc deduction Amt LT25K                    float64
# Other non-limited misc deduction Ct 75KLT100K                 float64
# Other non-limited misc deduction Ct LT25K                     float64
# Partnership/S-corp net income (less loss) Amt LT25K           float64
# Residential energy tax credit Amt LT25K                       float64
# Residential energy tax credit Ct LT25K                        float64
# Self-employed (Keogh) retirement plans Amt 75KLT100K          float64
# Self-employed (Keogh) retirement plans Amt LT25K              float64
# Self-employed (Keogh) retirement plans Ct LT25K               float64
# Tot Add Medicare tax Amt 25KLT50K                             float64
# Tuition and fees deduction Amt 75KLT100K                      float64
# calendar_type_txt_Regular School, Year-Round Calendar         uint8
# esea_status_P                                                 uint8
# Grad_project_status_Y                                         uint8
# SBE District_Northeast                                        uint8
# SBE District_Northwest                                        uint8
# SBE District_Piedmont-Triad                                   uint8
# SBE District_Sandhills                                        uint8
# SBE District_Southeast                                        uint8
# SBE District_Southwest                                        uint8
# SBE District_Western                                          uint8
# SPG Grade_A+NG                                                uint8
# SPG Grade_B                                                   uint8
# SPG Grade_C                                                   uint8
# SPG Grade_D                                                   uint8
# SPG Grade_F                                                   uint8
# Reading SPG Grade_B                                           uint8
# Reading SPG Grade_C                                           uint8
# Reading SPG Grade_D                                           uint8
# Reading SPG Grade_F                                           uint8
# Math SPG Grade_B                                              uint8
# Math SPG Grade_C                                              uint8
# Math SPG Grade_D                                              uint8
# Math SPG Grade_F                                              uint8
# EVAAS Growth Status_Met                                       uint8
# EVAAS Growth Status_NotMet                                    uint8
# Byod_Yes                                                      uint8
# _1_to_1_access_Yes                                            uint8
# SRC_devices_sent_home_Yes                                     uint8
# SRC_Grades_Devices_Sent_Home_3                                uint8
# SRC_Grades_Devices_Sent_Home_3:04:05                          uint8
# SRC_Grades_Devices_Sent_Home_4:05                             uint8
# SRC_Grades_Devices_Sent_Home_4:05:06                          uint8
# SRC_Grades_Devices_Sent_Home_5                                uint8
# SRC_Grades_Devices_Sent_Home_6:07:08                          uint8
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12                 uint8
# SRC_Grades_Devices_Sent_Home_7                                uint8
# SRC_Grades_Devices_Sent_Home_8                                uint8
# SRC_Grades_Devices_Sent_Home_9:10:11:12                       uint8
# SRC_Grades_Devices_Sent_Home_K:1:2:3:4:5                      uint8
# SRC_Grades_Devices_Sent_Home_K:1:2:3:4:5:6:7:8                uint8
# SRC_Grades_Devices_Sent_Home_PK                               uint8
# unit_code                                                     object
# dtypes: float64(330), object(1), uint8(41)
# memory usage: 3.3+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.3
# Pandas Version: 0.24.2

# %%
print( 'Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2017/Machine Learning Datasets/PublicElementarySchools2017_ML.csv
