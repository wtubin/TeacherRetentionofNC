# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2017

#Location where copies of the raw data files will be read in from csv files.
dataDir = '../../../' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
inputFileName = 'PublicSchools' + str(schoolYear)
#inputFileName = 'PublicHighSchools' + str(schoolYear)
#inputFileName = 'PublicMiddleSchools' + str(schoolYear)
#inputFileName = 'PublicElementarySchools' + str(schoolYear)

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = '../../../' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
#Rename Lea_Name to District Name
schoolData.rename(columns={'Lea_Name': 'District Name'}, inplace=True)
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2642 entries, 0 to 2641
# Columns: 2304 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(2249), int64(3), object(52)
# memory usage: 46.4+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Columns: 2304 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(2249), int64(3), object(52)
# memory usage: 43.4+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#schoolData.info(verbose=True)
#schoolData[['unit_code','School Name','_1yr_tchr_trnovr_pct','lea_1yr_tchr_trnovr_pct','st_1yr_tchr_trnovr_pct']][schoolData['_1yr_tchr_trnovr_pct']<=0.0]

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
# schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
#                                               .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print ('Rows Updated / Imputed: ', rowsUpdated )
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T]#.value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Empty DataFrame
# Columns: [District Name, District Name]
# Index: []

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Columns: 2109 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(2060), object(49)
# memory usage: 39.7+ MB
#
# Columns Deleted:  195

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Columns: 2109 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(2060), object(49)
# memory usage: 39.7+ MB
#
# Columns Deleted:  0

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Columns: 2109 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(2060), object(49)
# memory usage: 39.7+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print( "Boolean Columns: ", sD_boolean.shape[1])
print( "Nominal Columns: ", sD_nominal.shape[1])
print( "Continuous Columns: ", sD_continuous.shape[1])
print( "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  49
# Continuous Columns:  2060
# Columns Accounted for:  2109

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Columns: 1589 entries, vphone_ad to Attrtion_Reason_OtherReasonsPerct
# dtypes: float64(1540), object(49)
# memory usage: 29.9+ MB
#
# Columns Deleted:  520

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Columns: 1563 entries, category_cd to Attrtion_Reason_OtherReasons
# dtypes: float64(1540), object(23)
# memory usage: 29.4+ MB
#
# Columns Deleted:  28

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print ('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print ('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  23
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Columns: 1599 entries, student_num to SRC_devices_sent_home_Yes
# dtypes: float64(1540), uint8(59)
# memory usage: 29.2 MB
#
# New Columns Created Via One-Hot Encoding:  36

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                           Variable Name  Number Missing Values
# 3                                               00_Size                   1153
# 4                                               01_Size                   1154
# 5                                               02_Size                   1152
# 6                                               03_Size                   1159
# 7                                               04_Size                   1149
# 8                                               05_Size                   1180
# 9                                           Math I_Size                   1428
# 18                                            SPG Score                    131
# 19                                    Reading SPG Score                    622
# 20                                       Math SPG Score                    622
# 21                                   EVAAS Growth Score                    143
# 22                            Overall Achievement Score                    131
# 23                                        Reading Score                    622
# 24                                           Math Score                    622
# 25                                        Science Score                    707
# 26                                      NC Math 1 Score                   1474
# 27                                    EOCMathI_CACR_All                   1434
# 28                                     EOCMathI_GLP_All                   1434
# 29                                 EOCSubjects_CACR_All                   1408
# 30                                  EOCSubjects_GLP_All                   1408
# 31                             EOG/EOCSubjects_CACR_All                     51
# 32                              EOG/EOCSubjects_GLP_All                     51
# 33                                      EOGGr3_CACR_All                   1128
# 34                                       EOGGr3_GLP_All                   1128
# 35                                      EOGGr4_CACR_All                   1126
# 36                                       EOGGr4_GLP_All                   1126
# 37                                      EOGGr5_CACR_All                   1153
# 38                                       EOGGr5_GLP_All                   1153
# 39                                  EOGMathGr3_CACR_All                   1135
# 40                                   EOGMathGr3_GLP_All                   1135
# 41                                EOGMathGr3-8_CACR_All                    559
# 42                                 EOGMathGr3-8_GLP_All                    559
# 43                                  EOGMathGr4_CACR_All                   1140
# 44                                   EOGMathGr4_GLP_All                   1140
# 45                                  EOGMathGr5_CACR_All                   1170
# 46                                   EOGMathGr5_GLP_All                   1170
# 47                               EOGReadingGr3_CACR_All                   1135
# 48                                EOGReadingGr3_GLP_All                   1135
# 49                             EOGReadingGr3-8_CACR_All                    559
# 50                              EOGReadingGr3-8_GLP_All                    559
# 51                               EOGReadingGr4_CACR_All                   1140
# 52                                EOGReadingGr4_GLP_All                   1140
# 53                               EOGReadingGr5_CACR_All                   1170
# 54                                EOGReadingGr5_GLP_All                   1170
# 55                               EOGScienceGr5_CACR_All                   1170
# 56                                EOGScienceGr5_GLP_All                   1170
# 57                             EOGScienceGr5&8_CACR_All                    666
# 58                              EOGScienceGr5&8_GLP_All                    666
# 59                                 EOGSubjects_CACR_All                    553
# 60                                  EOGSubjects_GLP_All                    553
# 61                                 EOCMathI_CACR_Female                   1434
# 62                                  EOCMathI_GLP_Female                   1434
# 63                              EOCSubjects_CACR_Female                   1408
# 64                               EOCSubjects_GLP_Female                   1408
# 65                          EOG/EOCSubjects_CACR_Female                     51
# 66                           EOG/EOCSubjects_GLP_Female                     51
# 67                                   EOGGr3_CACR_Female                   1128
# 68                                    EOGGr3_GLP_Female                   1128
# 69                                   EOGGr4_CACR_Female                   1126
# 70                                    EOGGr4_GLP_Female                   1126
# 71                                   EOGGr5_CACR_Female                   1153
# 72                                    EOGGr5_GLP_Female                   1153
# 73                               EOGMathGr3_CACR_Female                   1135
# 74                                EOGMathGr3_GLP_Female                   1135
# 75                             EOGMathGr3-8_CACR_Female                    559
# 76                              EOGMathGr3-8_GLP_Female                    559
# 77                               EOGMathGr4_CACR_Female                   1140
# 78                                EOGMathGr4_GLP_Female                   1140
# 79                               EOGMathGr5_CACR_Female                   1170
# 80                                EOGMathGr5_GLP_Female                   1170
# 81                            EOGReadingGr3_CACR_Female                   1135
# 82                             EOGReadingGr3_GLP_Female                   1135
# 83                          EOGReadingGr3-8_CACR_Female                    559
# 84                           EOGReadingGr3-8_GLP_Female                    559
# 85                            EOGReadingGr4_CACR_Female                   1140
# 86                             EOGReadingGr4_GLP_Female                   1140
# 87                            EOGReadingGr5_CACR_Female                   1170
# 88                             EOGReadingGr5_GLP_Female                   1170
# 89                            EOGScienceGr5_CACR_Female                   1170
# 90                             EOGScienceGr5_GLP_Female                   1170
# 91                          EOGScienceGr5&8_CACR_Female                    666
# 92                           EOGScienceGr5&8_GLP_Female                    666
# 93                              EOGSubjects_CACR_Female                    553
# 94                               EOGSubjects_GLP_Female                    553
# 95                                   EOCMathI_CACR_Male                   1434
# 96                                    EOCMathI_GLP_Male                   1434
# 97                                EOCSubjects_CACR_Male                   1408
# 98                                 EOCSubjects_GLP_Male                   1408
# 99                            EOG/EOCSubjects_CACR_Male                     51
# 100                            EOG/EOCSubjects_GLP_Male                     51
# 101                                    EOGGr3_CACR_Male                   1128
# 102                                     EOGGr3_GLP_Male                   1128
# 103                                    EOGGr4_CACR_Male                   1126
# 104                                     EOGGr4_GLP_Male                   1126
# 105                                    EOGGr5_CACR_Male                   1153
# 106                                     EOGGr5_GLP_Male                   1153
# 107                                EOGMathGr3_CACR_Male                   1135
# 108                                 EOGMathGr3_GLP_Male                   1135
# 109                              EOGMathGr3-8_CACR_Male                    559
# 110                               EOGMathGr3-8_GLP_Male                    559
# 111                                EOGMathGr4_CACR_Male                   1140
# 112                                 EOGMathGr4_GLP_Male                   1140
# 113                                EOGMathGr5_CACR_Male                   1170
# 114                                 EOGMathGr5_GLP_Male                   1170
# 115                             EOGReadingGr3_CACR_Male                   1135
# 116                              EOGReadingGr3_GLP_Male                   1135
# 117                           EOGReadingGr3-8_CACR_Male                    559
# 118                            EOGReadingGr3-8_GLP_Male                    559
# 119                             EOGReadingGr4_CACR_Male                   1140
# 120                              EOGReadingGr4_GLP_Male                   1140
# 121                             EOGReadingGr5_CACR_Male                   1170
# 122                              EOGReadingGr5_GLP_Male                   1170
# 123                             EOGScienceGr5_CACR_Male                   1170
# 124                              EOGScienceGr5_GLP_Male                   1170
# 125                           EOGScienceGr5&8_CACR_Male                    666
# 126                            EOGScienceGr5&8_GLP_Male                    666
# 127                               EOGSubjects_CACR_Male                    553
# 128                                EOGSubjects_GLP_Male                    553
# 129                        EOCMathI_CACR_AmericanIndian                   1434
# 130                         EOCMathI_GLP_AmericanIndian                   1434
# 131                     EOCSubjects_CACR_AmericanIndian                   1408
# 132                      EOCSubjects_GLP_AmericanIndian                   1408
# 133                 EOG/EOCSubjects_CACR_AmericanIndian                     51
# 134                  EOG/EOCSubjects_GLP_AmericanIndian                     51
# 135                          EOGGr3_CACR_AmericanIndian                   1128
# 136                           EOGGr3_GLP_AmericanIndian                   1128
# 137                          EOGGr4_CACR_AmericanIndian                   1126
# 138                           EOGGr4_GLP_AmericanIndian                   1126
# 139                          EOGGr5_CACR_AmericanIndian                   1153
# 140                           EOGGr5_GLP_AmericanIndian                   1153
# 141                      EOGMathGr3_CACR_AmericanIndian                   1135
# 142                       EOGMathGr3_GLP_AmericanIndian                   1135
# 143                    EOGMathGr3-8_CACR_AmericanIndian                    559
# 144                     EOGMathGr3-8_GLP_AmericanIndian                    559
# 145                      EOGMathGr4_CACR_AmericanIndian                   1140
# 146                       EOGMathGr4_GLP_AmericanIndian                   1140
# 147                      EOGMathGr5_CACR_AmericanIndian                   1170
# 148                       EOGMathGr5_GLP_AmericanIndian                   1170
# 149                   EOGReadingGr3_CACR_AmericanIndian                   1135
# 150                    EOGReadingGr3_GLP_AmericanIndian                   1135
# 151                 EOGReadingGr3-8_CACR_AmericanIndian                    559
# 152                  EOGReadingGr3-8_GLP_AmericanIndian                    559
# 153                   EOGReadingGr4_CACR_AmericanIndian                   1140
# 154                    EOGReadingGr4_GLP_AmericanIndian                   1140
# 155                   EOGReadingGr5_CACR_AmericanIndian                   1170
# 156                    EOGReadingGr5_GLP_AmericanIndian                   1170
# 157                   EOGScienceGr5_CACR_AmericanIndian                   1170
# 158                    EOGScienceGr5_GLP_AmericanIndian                   1170
# 159                 EOGScienceGr5&8_CACR_AmericanIndian                    666
# 160                  EOGScienceGr5&8_GLP_AmericanIndian                    666
# 161                     EOGSubjects_CACR_AmericanIndian                    553
# 162                      EOGSubjects_GLP_AmericanIndian                    553
# 163                                 EOCMathI_CACR_Asian                   1434
# 164                                  EOCMathI_GLP_Asian                   1434
# 165                              EOCSubjects_CACR_Asian                   1408
# 166                               EOCSubjects_GLP_Asian                   1408
# 167                          EOG/EOCSubjects_CACR_Asian                     51
# 168                           EOG/EOCSubjects_GLP_Asian                     51
# 169                                   EOGGr3_CACR_Asian                   1128
# 170                                    EOGGr3_GLP_Asian                   1128
# 171                                   EOGGr4_CACR_Asian                   1126
# 172                                    EOGGr4_GLP_Asian                   1126
# 173                                   EOGGr5_CACR_Asian                   1153
# 174                                    EOGGr5_GLP_Asian                   1153
# 175                               EOGMathGr3_CACR_Asian                   1135
# 176                                EOGMathGr3_GLP_Asian                   1135
# 177                             EOGMathGr3-8_CACR_Asian                    559
# 178                              EOGMathGr3-8_GLP_Asian                    559
# 179                               EOGMathGr4_CACR_Asian                   1140
# 180                                EOGMathGr4_GLP_Asian                   1140
# 181                               EOGMathGr5_CACR_Asian                   1170
# 182                                EOGMathGr5_GLP_Asian                   1170
# 183                            EOGReadingGr3_CACR_Asian                   1135
# 184                             EOGReadingGr3_GLP_Asian                   1135
# 185                          EOGReadingGr3-8_CACR_Asian                    559
# 186                           EOGReadingGr3-8_GLP_Asian                    559
# 187                            EOGReadingGr4_CACR_Asian                   1140
# 188                             EOGReadingGr4_GLP_Asian                   1140
# 189                            EOGReadingGr5_CACR_Asian                   1170
# 190                             EOGReadingGr5_GLP_Asian                   1170
# 191                            EOGScienceGr5_CACR_Asian                   1170
# 192                             EOGScienceGr5_GLP_Asian                   1170
# 193                          EOGScienceGr5&8_CACR_Asian                    666
# 194                           EOGScienceGr5&8_GLP_Asian                    666
# 195                              EOGSubjects_CACR_Asian                    553
# 196                               EOGSubjects_GLP_Asian                    553
# 197                                 EOCMathI_CACR_Black                   1434
# 198                                  EOCMathI_GLP_Black                   1434
# 199                              EOCSubjects_CACR_Black                   1408
# 200                               EOCSubjects_GLP_Black                   1408
# 201                          EOG/EOCSubjects_CACR_Black                     51
# 202                           EOG/EOCSubjects_GLP_Black                     51
# 203                                   EOGGr3_CACR_Black                   1128
# 204                                    EOGGr3_GLP_Black                   1128
# 205                                   EOGGr4_CACR_Black                   1126
# 206                                    EOGGr4_GLP_Black                   1126
# 207                                   EOGGr5_CACR_Black                   1153
# 208                                    EOGGr5_GLP_Black                   1153
# 209                               EOGMathGr3_CACR_Black                   1135
# 210                                EOGMathGr3_GLP_Black                   1135
# 211                             EOGMathGr3-8_CACR_Black                    559
# 212                              EOGMathGr3-8_GLP_Black                    559
# 213                               EOGMathGr4_CACR_Black                   1140
# 214                                EOGMathGr4_GLP_Black                   1140
# 215                               EOGMathGr5_CACR_Black                   1170
# 216                                EOGMathGr5_GLP_Black                   1170
# 217                            EOGReadingGr3_CACR_Black                   1135
# 218                             EOGReadingGr3_GLP_Black                   1135
# 219                          EOGReadingGr3-8_CACR_Black                    559
# 220                           EOGReadingGr3-8_GLP_Black                    559
# 221                            EOGReadingGr4_CACR_Black                   1140
# 222                             EOGReadingGr4_GLP_Black                   1140
# 223                            EOGReadingGr5_CACR_Black                   1170
# 224                             EOGReadingGr5_GLP_Black                   1170
# 225                            EOGScienceGr5_CACR_Black                   1170
# 226                             EOGScienceGr5_GLP_Black                   1170
# 227                          EOGScienceGr5&8_CACR_Black                    666
# 228                           EOGScienceGr5&8_GLP_Black                    666
# 229                              EOGSubjects_CACR_Black                    553
# 230                               EOGSubjects_GLP_Black                    553
# 231                              EOCMathI_CACR_Hispanic                   1434
# 232                               EOCMathI_GLP_Hispanic                   1434
# 233                           EOCSubjects_CACR_Hispanic                   1408
# 234                            EOCSubjects_GLP_Hispanic                   1408
# 235                       EOG/EOCSubjects_CACR_Hispanic                     51
# 236                        EOG/EOCSubjects_GLP_Hispanic                     51
# 237                                EOGGr3_CACR_Hispanic                   1128
# 238                                 EOGGr3_GLP_Hispanic                   1128
# 239                                EOGGr4_CACR_Hispanic                   1126
# 240                                 EOGGr4_GLP_Hispanic                   1126
# 241                                EOGGr5_CACR_Hispanic                   1153
# 242                                 EOGGr5_GLP_Hispanic                   1153
# 243                            EOGMathGr3_CACR_Hispanic                   1135
# 244                             EOGMathGr3_GLP_Hispanic                   1135
# 245                          EOGMathGr3-8_CACR_Hispanic                    559
# 246                           EOGMathGr3-8_GLP_Hispanic                    559
# 247                            EOGMathGr4_CACR_Hispanic                   1140
# 248                             EOGMathGr4_GLP_Hispanic                   1140
# 249                            EOGMathGr5_CACR_Hispanic                   1170
# 250                             EOGMathGr5_GLP_Hispanic                   1170
# 251                         EOGReadingGr3_CACR_Hispanic                   1135
# 252                          EOGReadingGr3_GLP_Hispanic                   1135
# 253                       EOGReadingGr3-8_CACR_Hispanic                    559
# 254                        EOGReadingGr3-8_GLP_Hispanic                    559
# 255                         EOGReadingGr4_CACR_Hispanic                   1140
# 256                          EOGReadingGr4_GLP_Hispanic                   1140
# 257                         EOGReadingGr5_CACR_Hispanic                   1170
# 258                          EOGReadingGr5_GLP_Hispanic                   1170
# 259                         EOGScienceGr5_CACR_Hispanic                   1170
# 260                          EOGScienceGr5_GLP_Hispanic                   1170
# 261                       EOGScienceGr5&8_CACR_Hispanic                    666
# 262                        EOGScienceGr5&8_GLP_Hispanic                    666
# 263                           EOGSubjects_CACR_Hispanic                    553
# 264                            EOGSubjects_GLP_Hispanic                    553
# 265                        EOCMathI_CACR_TwoorMoreRaces                   1434
# 266                         EOCMathI_GLP_TwoorMoreRaces                   1434
# 267                     EOCSubjects_CACR_TwoorMoreRaces                   1408
# 268                      EOCSubjects_GLP_TwoorMoreRaces                   1408
# 269                 EOG/EOCSubjects_CACR_TwoorMoreRaces                     51
# 270                  EOG/EOCSubjects_GLP_TwoorMoreRaces                     51
# 271                          EOGGr3_CACR_TwoorMoreRaces                   1128
# 272                           EOGGr3_GLP_TwoorMoreRaces                   1128
# 273                          EOGGr4_CACR_TwoorMoreRaces                   1126
# 274                           EOGGr4_GLP_TwoorMoreRaces                   1126
# 275                          EOGGr5_CACR_TwoorMoreRaces                   1153
# 276                           EOGGr5_GLP_TwoorMoreRaces                   1153
# 277                      EOGMathGr3_CACR_TwoorMoreRaces                   1135
# 278                       EOGMathGr3_GLP_TwoorMoreRaces                   1135
# 279                    EOGMathGr3-8_CACR_TwoorMoreRaces                    559
# 280                     EOGMathGr3-8_GLP_TwoorMoreRaces                    559
# 281                      EOGMathGr4_CACR_TwoorMoreRaces                   1140
# 282                       EOGMathGr4_GLP_TwoorMoreRaces                   1140
# 283                      EOGMathGr5_CACR_TwoorMoreRaces                   1170
# 284                       EOGMathGr5_GLP_TwoorMoreRaces                   1170
# 285                   EOGReadingGr3_CACR_TwoorMoreRaces                   1135
# 286                    EOGReadingGr3_GLP_TwoorMoreRaces                   1135
# 287                 EOGReadingGr3-8_CACR_TwoorMoreRaces                    559
# 288                  EOGReadingGr3-8_GLP_TwoorMoreRaces                    559
# 289                   EOGReadingGr4_CACR_TwoorMoreRaces                   1140
# 290                    EOGReadingGr4_GLP_TwoorMoreRaces                   1140
# 291                   EOGReadingGr5_CACR_TwoorMoreRaces                   1170
# 292                    EOGReadingGr5_GLP_TwoorMoreRaces                   1170
# 293                   EOGScienceGr5_CACR_TwoorMoreRaces                   1170
# 294                    EOGScienceGr5_GLP_TwoorMoreRaces                   1170
# 295                 EOGScienceGr5&8_CACR_TwoorMoreRaces                    666
# 296                  EOGScienceGr5&8_GLP_TwoorMoreRaces                    666
# 297                     EOGSubjects_CACR_TwoorMoreRaces                    553
# 298                      EOGSubjects_GLP_TwoorMoreRaces                    553
# 299                                 EOCMathI_CACR_White                   1434
# 300                                  EOCMathI_GLP_White                   1434
# 301                              EOCSubjects_CACR_White                   1408
# 302                               EOCSubjects_GLP_White                   1408
# 303                          EOG/EOCSubjects_CACR_White                     51
# 304                           EOG/EOCSubjects_GLP_White                     51
# 305                                   EOGGr3_CACR_White                   1128
# 306                                    EOGGr3_GLP_White                   1128
# 307                                   EOGGr4_CACR_White                   1126
# 308                                    EOGGr4_GLP_White                   1126
# 309                                   EOGGr5_CACR_White                   1153
# 310                                    EOGGr5_GLP_White                   1153
# 311                               EOGMathGr3_CACR_White                   1135
# 312                                EOGMathGr3_GLP_White                   1135
# 313                             EOGMathGr3-8_CACR_White                    559
# 314                              EOGMathGr3-8_GLP_White                    559
# 315                               EOGMathGr4_CACR_White                   1140
# 316                                EOGMathGr4_GLP_White                   1140
# 317                               EOGMathGr5_CACR_White                   1170
# 318                                EOGMathGr5_GLP_White                   1170
# 319                            EOGReadingGr3_CACR_White                   1135
# 320                             EOGReadingGr3_GLP_White                   1135
# 321                          EOGReadingGr3-8_CACR_White                    559
# 322                           EOGReadingGr3-8_GLP_White                    559
# 323                            EOGReadingGr4_CACR_White                   1140
# 324                             EOGReadingGr4_GLP_White                   1140
# 325                            EOGReadingGr5_CACR_White                   1170
# 326                             EOGReadingGr5_GLP_White                   1170
# 327                            EOGScienceGr5_CACR_White                   1170
# 328                             EOGScienceGr5_GLP_White                   1170
# 329                          EOGScienceGr5&8_CACR_White                    666
# 330                           EOGScienceGr5&8_GLP_White                    666
# 331                              EOGSubjects_CACR_White                    553
# 332                               EOGSubjects_GLP_White                    553
# 333                                   EOCMathI_CACR_EDS                   1434
# 334                                    EOCMathI_GLP_EDS                   1434
# 335                                EOCSubjects_CACR_EDS                   1408
# 336                                 EOCSubjects_GLP_EDS                   1408
# 337                            EOG/EOCSubjects_CACR_EDS                     51
# 338                             EOG/EOCSubjects_GLP_EDS                     51
# 339                                     EOGGr3_CACR_EDS                   1128
# 340                                      EOGGr3_GLP_EDS                   1128
# 341                                     EOGGr4_CACR_EDS                   1126
# 342                                      EOGGr4_GLP_EDS                   1126
# 343                                     EOGGr5_CACR_EDS                   1153
# 344                                      EOGGr5_GLP_EDS                   1153
# 345                                 EOGMathGr3_CACR_EDS                   1135
# 346                                  EOGMathGr3_GLP_EDS                   1135
# 347                               EOGMathGr3-8_CACR_EDS                    559
# 348                                EOGMathGr3-8_GLP_EDS                    559
# 349                                 EOGMathGr4_CACR_EDS                   1140
# 350                                  EOGMathGr4_GLP_EDS                   1140
# 351                                 EOGMathGr5_CACR_EDS                   1170
# 352                                  EOGMathGr5_GLP_EDS                   1170
# 353                              EOGReadingGr3_CACR_EDS                   1135
# 354                               EOGReadingGr3_GLP_EDS                   1135
# 355                            EOGReadingGr3-8_CACR_EDS                    559
# 356                             EOGReadingGr3-8_GLP_EDS                    559
# 357                              EOGReadingGr4_CACR_EDS                   1140
# 358                               EOGReadingGr4_GLP_EDS                   1140
# 359                              EOGReadingGr5_CACR_EDS                   1170
# 360                               EOGReadingGr5_GLP_EDS                   1170
# 361                              EOGScienceGr5_CACR_EDS                   1170
# 362                               EOGScienceGr5_GLP_EDS                   1170
# 363                            EOGScienceGr5&8_CACR_EDS                    666
# 364                             EOGScienceGr5&8_GLP_EDS                    666
# 365                                EOGSubjects_CACR_EDS                    553
# 366                                 EOGSubjects_GLP_EDS                    553
# 367                                   EOCMathI_CACR_LEP                   1434
# 368                                    EOCMathI_GLP_LEP                   1434
# 369                                EOCSubjects_CACR_LEP                   1408
# 370                                 EOCSubjects_GLP_LEP                   1408
# 371                            EOG/EOCSubjects_CACR_LEP                     51
# 372                             EOG/EOCSubjects_GLP_LEP                     51
# 373                                     EOGGr3_CACR_LEP                   1128
# 374                                      EOGGr3_GLP_LEP                   1128
# 375                                     EOGGr4_CACR_LEP                   1126
# 376                                      EOGGr4_GLP_LEP                   1126
# 377                                     EOGGr5_CACR_LEP                   1153
# 378                                      EOGGr5_GLP_LEP                   1153
# 379                                 EOGMathGr3_CACR_LEP                   1135
# 380                                  EOGMathGr3_GLP_LEP                   1135
# 381                               EOGMathGr3-8_CACR_LEP                    559
# 382                                EOGMathGr3-8_GLP_LEP                    559
# 383                                 EOGMathGr4_CACR_LEP                   1140
# 384                                  EOGMathGr4_GLP_LEP                   1140
# 385                                 EOGMathGr5_CACR_LEP                   1170
# 386                                  EOGMathGr5_GLP_LEP                   1170
# 387                              EOGReadingGr3_CACR_LEP                   1135
# 388                               EOGReadingGr3_GLP_LEP                   1135
# 389                            EOGReadingGr3-8_CACR_LEP                    559
# 390                             EOGReadingGr3-8_GLP_LEP                    559
# 391                              EOGReadingGr4_CACR_LEP                   1140
# 392                               EOGReadingGr4_GLP_LEP                   1140
# 393                              EOGReadingGr5_CACR_LEP                   1170
# 394                               EOGReadingGr5_GLP_LEP                   1170
# 395                              EOGScienceGr5_CACR_LEP                   1170
# 396                               EOGScienceGr5_GLP_LEP                   1170
# 397                            EOGScienceGr5&8_CACR_LEP                    666
# 398                             EOGScienceGr5&8_GLP_LEP                    666
# 399                                EOGSubjects_CACR_LEP                    553
# 400                                 EOGSubjects_GLP_LEP                    553
# 401                                   EOCMathI_CACR_SWD                   1434
# 402                                    EOCMathI_GLP_SWD                   1434
# 403                                EOCSubjects_CACR_SWD                   1408
# 404                                 EOCSubjects_GLP_SWD                   1408
# 405                            EOG/EOCSubjects_CACR_SWD                     51
# 406                             EOG/EOCSubjects_GLP_SWD                     51
# 407                                     EOGGr3_CACR_SWD                   1128
# 408                                      EOGGr3_GLP_SWD                   1128
# 409                                     EOGGr4_CACR_SWD                   1126
# 410                                      EOGGr4_GLP_SWD                   1126
# 411                                     EOGGr5_CACR_SWD                   1153
# 412                                      EOGGr5_GLP_SWD                   1153
# 413                                 EOGMathGr3_CACR_SWD                   1135
# 414                                  EOGMathGr3_GLP_SWD                   1135
# 415                               EOGMathGr3-8_CACR_SWD                    559
# 416                                EOGMathGr3-8_GLP_SWD                    559
# 417                                 EOGMathGr4_CACR_SWD                   1140
# 418                                  EOGMathGr4_GLP_SWD                   1140
# 419                                 EOGMathGr5_CACR_SWD                   1170
# 420                                  EOGMathGr5_GLP_SWD                   1170
# 421                              EOGReadingGr3_CACR_SWD                   1135
# 422                               EOGReadingGr3_GLP_SWD                   1135
# 423                            EOGReadingGr3-8_CACR_SWD                    559
# 424                             EOGReadingGr3-8_GLP_SWD                    559
# 425                              EOGReadingGr4_CACR_SWD                   1140
# 426                               EOGReadingGr4_GLP_SWD                   1140
# 427                              EOGReadingGr5_CACR_SWD                   1170
# 428                               EOGReadingGr5_GLP_SWD                   1170
# 429                              EOGScienceGr5_CACR_SWD                   1170
# 430                               EOGScienceGr5_GLP_SWD                   1170
# 431                            EOGScienceGr5&8_CACR_SWD                    666
# 432                             EOGScienceGr5&8_GLP_SWD                    666
# 433                                EOGSubjects_CACR_SWD                    553
# 434                                 EOGSubjects_GLP_SWD                    553
# 435                                   EOCMathI_CACR_AIG                   1434
# 436                                    EOCMathI_GLP_AIG                   1434
# 437                                EOCSubjects_CACR_AIG                   1408
# 438                                 EOCSubjects_GLP_AIG                   1408
# 439                            EOG/EOCSubjects_CACR_AIG                     51
# 440                             EOG/EOCSubjects_GLP_AIG                     51
# 441                                     EOGGr3_CACR_AIG                   1128
# 442                                      EOGGr3_GLP_AIG                   1128
# 443                                     EOGGr4_CACR_AIG                   1126
# 444                                      EOGGr4_GLP_AIG                   1126
# 445                                     EOGGr5_CACR_AIG                   1153
# 446                                      EOGGr5_GLP_AIG                   1153
# 447                                 EOGMathGr3_CACR_AIG                   1135
# 448                                  EOGMathGr3_GLP_AIG                   1135
# 449                               EOGMathGr3-8_CACR_AIG                    559
# 450                                EOGMathGr3-8_GLP_AIG                    559
# 451                                 EOGMathGr4_CACR_AIG                   1140
# 452                                  EOGMathGr4_GLP_AIG                   1140
# 453                                 EOGMathGr5_CACR_AIG                   1170
# 454                                  EOGMathGr5_GLP_AIG                   1170
# 455                              EOGReadingGr3_CACR_AIG                   1135
# 456                               EOGReadingGr3_GLP_AIG                   1135
# 457                            EOGReadingGr3-8_CACR_AIG                    559
# 458                             EOGReadingGr3-8_GLP_AIG                    559
# 459                              EOGReadingGr4_CACR_AIG                   1140
# 460                               EOGReadingGr4_GLP_AIG                   1140
# 461                              EOGReadingGr5_CACR_AIG                   1170
# 462                               EOGReadingGr5_GLP_AIG                   1170
# 463                              EOGScienceGr5_CACR_AIG                   1170
# 464                               EOGScienceGr5_GLP_AIG                   1170
# 465                            EOGScienceGr5&8_CACR_AIG                    666
# 466                             EOGScienceGr5&8_GLP_AIG                    666
# 467                                EOGSubjects_CACR_AIG                    553
# 468                                 EOGSubjects_GLP_AIG                    553
# 469                                         pct_GCE_ALL                   1104
# 470                                      pct_PASSED_EOG                   1166
# 471                                        pct_PROMOTED                   1136
# 472                            MathGr3-8_pTarget_PctMet                    589
# 473                         ReadingGr3-8_pTarget_PctMet                    589
# 474                             SciGr5&8_pTarget_PctMet                    755
# 475                         TotalTargets_pTarget_PctMet                     69
# 476                               lea_sat_avg_score_num                      6
# 477                           lea_sat_participation_pct                      6
# 478                            lea_ap_participation_pct                    263
# 479                               lea_ap_pct_3_or_above                     64
# 480                               lea_ib_pct_4_or_above                   1314
# 486                              stud_internet_comp_num                      8
# 498                                   digital_media_pct                    142
# 499                            avg_age_media_collection                    132
# 500                                   books_per_student                    147
# 501                        lea_avg_age_media_collection                    132
# 502                               lea_books_per_student                    147
# 503                                             wap_num                     18
# 504                                   wap_per_classroom                     18
# 507                                 flicensed_teach_pct                      2
# 508                                   tchyrs_0thru3_pct                      2
# 509                                  tchyrs_4thru10_pct                      2
# 510                                   tchyrs_11plus_pct                      2
# 511                                     class_teach_num                      2
# 512                                           nbpts_num                      2
# 513                                     advance_dgr_pct                      2
# 514                                _1yr_tchr_trnovr_pct                     23
# 515                                   lateral_teach_pct                    893
# 524                             lea_emer_prov_teach_pct                    970
# 525                               lea_lateral_teach_pct                    108
# 536                               0-3 Years_Exp_Pct_Tch                      2
# 537                               10+ Years_Exp_Pct_Tch                      2
# 538                              4-10 Years_Exp_Pct_Tch                      2
# 542                    Accomplished_TCHR_Standard 1_Pct                      9
# 543                    Accomplished_TCHR_Standard 2_Pct                      9
# 544                    Accomplished_TCHR_Standard 3_Pct                      9
# 545                    Accomplished_TCHR_Standard 4_Pct                      9
# 546                    Accomplished_TCHR_Standard 5_Pct                      9
# 547                      Developing_TCHR_Standard 1_Pct                      9
# 548                      Developing_TCHR_Standard 2_Pct                      9
# 549                      Developing_TCHR_Standard 3_Pct                      9
# 550                      Developing_TCHR_Standard 4_Pct                      9
# 551                      Developing_TCHR_Standard 5_Pct                      9
# 552                   Distinguished_TCHR_Standard 1_Pct                      9
# 553                   Distinguished_TCHR_Standard 2_Pct                      9
# 554                   Distinguished_TCHR_Standard 3_Pct                      9
# 555                   Distinguished_TCHR_Standard 4_Pct                      9
# 556                   Distinguished_TCHR_Standard 5_Pct                      9
# 557   Does Not Meet Expected Growth_TCHR_Student Gro...                     55
# 558     Exceeds Expected Growth_TCHR_Student Growth_Pct                     55
# 559       Meets Expected Growth_TCHR_Student Growth_Pct                     55
# 560                 Not Demostrated_TCHR_Standard 1_Pct                      9
# 561                 Not Demostrated_TCHR_Standard 2_Pct                      9
# 562                 Not Demostrated_TCHR_Standard 3_Pct                      9
# 563                 Not Demostrated_TCHR_Standard 4_Pct                      9
# 564                 Not Demostrated_TCHR_Standard 5_Pct                      9
# 565                      Proficient_TCHR_Standard 1_Pct                      9
# 566                      Proficient_TCHR_Standard 2_Pct                      9
# 567                      Proficient_TCHR_Standard 3_Pct                      9
# 568                      Proficient_TCHR_Standard 4_Pct                      9
# 569                      Proficient_TCHR_Standard 5_Pct                      9
# 595                                                Year                    603
# 596                             Crime_Rate_Violent_Rate                    609
# 597                              Crime_Rate_Murder_Rate                    747
# 598                                Crime_Rate_Rape_Rate                    636
# 599                             Crime_Rate_Robbery_Rate                    661
# 600                             Crime_Rate_Assault_Rate                    622
# 601                                 Crime_Rate_MVT_Rate                    603
# 602                               Crime_Rate_Arson_Rate                    652
# 1534                                            LEACode                    213
# 1535                    Attrtion_Reason_TeachersLeaving                    213
# 1536                    Attrtion_Reason_PersonalReasons                    239
# 1537                     Attrtion_Reason_InitiatedbyLEA                    825
# 1538                 Attrtion_Reason_BeyondControlofLEA                    234
# 1539                       Attrtion_Reason_OtherReasons                    278

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  280679  field correlations > 95%.
#                                                  Field1  \
# 0                                       class_teach_num
# 1                                   lea_class_teach_num
# 2                                    st_class_teach_num
# 3                                    st_advance_dgr_pct
# 4                                               01_Size
# 5                             Overall Achievement Score
# 6                                        Math SPG Score
# 7                                         Reading Score
# 8                                            Math Score
# 9                                  EOGMathGr3-8_GLP_All
# 10                             EOGReadingGr3-8_CACR_All
# 11                              EOGReadingGr3-8_GLP_All
# 12                                 EOGSubjects_CACR_All
# 13                                  EOGSubjects_GLP_All
# 14                              EOGMathGr3-8_GLP_Female
# 15                          EOGReadingGr3-8_CACR_Female
# 16                           EOGReadingGr3-8_GLP_Female
# 17                              EOGSubjects_CACR_Female
# 18                               EOGSubjects_GLP_Female
# 19                             EOGReadingGr3-8_GLP_Male
# 20                                EOGSubjects_CACR_Male
# 21                                 EOGSubjects_GLP_Male
# 22                                        Reading Score
# 23                                           Math Score
# 24                                EOGMathGr3-8_CACR_All
# 25                                 EOGMathGr3-8_GLP_All
# 26                              EOGReadingGr3-8_GLP_All
# 27                                 EOGSubjects_CACR_All
# 28                                  EOGSubjects_GLP_All
# 29                             EOGMathGr3-8_CACR_Female
# 30                              EOGMathGr3-8_GLP_Female
# 31                           EOGReadingGr3-8_GLP_Female
# 32                              EOGSubjects_CACR_Female
# 33                               EOGSubjects_GLP_Female
# 34                               EOGMathGr3-8_CACR_Male
# 35                                EOGMathGr3-8_GLP_Male
# 36                                EOGSubjects_CACR_Male
# 37                                 EOGSubjects_GLP_Male
# 38                                  EOGSubjects_GLP_EDS
# 39                                           Math Score
# 40                                EOGMathGr3-8_CACR_All
# 41                                 EOGMathGr3-8_GLP_All
# 42                             EOGReadingGr3-8_CACR_All
# 43                              EOGReadingGr3-8_GLP_All
# 44                                 EOGSubjects_CACR_All
# 45                                  EOGSubjects_GLP_All
# 46                             EOGMathGr3-8_CACR_Female
# 47                              EOGMathGr3-8_GLP_Female
# 48                          EOGReadingGr3-8_CACR_Female
# 49                           EOGReadingGr3-8_GLP_Female
# 50                              EOGSubjects_CACR_Female
# 51                               EOGSubjects_GLP_Female
# 52                            EOGReadingGr3-8_CACR_Male
# 53                             EOGReadingGr3-8_GLP_Male
# 54                                EOGSubjects_CACR_Male
# 55                                 EOGSubjects_GLP_Male
# 56                                EOGMathGr3-8_CACR_All
# 57                                 EOGMathGr3-8_GLP_All
# 58                              EOGReadingGr3-8_GLP_All
# 59                                 EOGSubjects_CACR_All
# 60                                  EOGSubjects_GLP_All
# 61                             EOGMathGr3-8_CACR_Female
# 62                              EOGMathGr3-8_GLP_Female
# 63                           EOGReadingGr3-8_GLP_Female
# 64                              EOGSubjects_CACR_Female
# 65                               EOGSubjects_GLP_Female
# 66                               EOGMathGr3-8_CACR_Male
# 67                                EOGMathGr3-8_GLP_Male
# 68                             EOGReadingGr3-8_GLP_Male
# 69                                EOGSubjects_CACR_Male
# 70                                 EOGSubjects_GLP_Male
# 71                                 EOGMathGr3-8_GLP_EDS
# 72                             EOGScienceGr5&8_CACR_All
# 73                              EOGScienceGr5&8_GLP_All
# 74                          EOGScienceGr5&8_CACR_Female
# 75                           EOGScienceGr5&8_GLP_Female
# 76                            EOGScienceGr5&8_CACR_Male
# 77                             EOGScienceGr5&8_GLP_Male
# 78                                    EOCMathI_CACR_All
# 79                                     EOCMathI_GLP_All
# 80                                 EOCSubjects_CACR_All
# 81                                  EOCSubjects_GLP_All
# 82                                     EOCMathI_GLP_All
# 83                                 EOCSubjects_CACR_All
# 84                                  EOCSubjects_GLP_All
# 85                                 EOCSubjects_CACR_All
# 86                                  EOCSubjects_GLP_All
# 87                                  EOCSubjects_GLP_All
# 88                              EOG/EOCSubjects_GLP_All
# 89                          EOG/EOCSubjects_CACR_Female
# 90                           EOG/EOCSubjects_GLP_Female
# 91                            EOG/EOCSubjects_CACR_Male
# 92                             EOG/EOCSubjects_GLP_Male
# 93                          EOG/EOCSubjects_CACR_Female
# 94                           EOG/EOCSubjects_GLP_Female
# 95                            EOG/EOCSubjects_CACR_Male
# 96                             EOG/EOCSubjects_GLP_Male
# 97                                       EOGGr3_GLP_All
# 98                                  EOGMathGr3_CACR_All
# 99                                   EOGMathGr3_GLP_All
# 100                              EOGReadingGr3_CACR_All
# 101                               EOGReadingGr3_GLP_All
# 102                                  EOGGr3_CACR_Female
# 103                                   EOGGr3_GLP_Female
# 104                              EOGMathGr3_CACR_Female
# 105                                    EOGGr3_CACR_Male
# 106                                     EOGGr3_GLP_Male
# 107                                EOGMathGr3_CACR_Male
# 108                                 EOGMathGr3_GLP_Male
# 109                             EOGReadingGr3_CACR_Male
# 110                              EOGReadingGr3_GLP_Male
# 111                                      pct_PASSED_EOG
# 112                                 EOGMathGr3_CACR_All
# 113                                  EOGMathGr3_GLP_All
# 114                              EOGReadingGr3_CACR_All
# 115                               EOGReadingGr3_GLP_All
# 116                                  EOGGr3_CACR_Female
# 117                                   EOGGr3_GLP_Female
# 118                               EOGMathGr3_GLP_Female
# 119                            EOGReadingGr3_GLP_Female
# 120                                    EOGGr3_CACR_Male
# 121                                     EOGGr3_GLP_Male
# 122                                EOGMathGr3_CACR_Male
# 123                                 EOGMathGr3_GLP_Male
# 124                              EOGReadingGr3_GLP_Male
# 125                                      EOGGr3_GLP_EDS
# 126                                      pct_PASSED_EOG
# 127                                        pct_PROMOTED
# 128                                      EOGGr4_GLP_All
# 129                                 EOGMathGr4_CACR_All
# 130                                  EOGMathGr4_GLP_All
# 131                              EOGReadingGr4_CACR_All
# 132                               EOGReadingGr4_GLP_All
# 133                                  EOGGr4_CACR_Female
# 134                                   EOGGr4_GLP_Female
# 135                              EOGMathGr4_CACR_Female
# 136                                    EOGGr4_CACR_Male
# 137                                     EOGGr4_GLP_Male
# 138                                EOGMathGr4_CACR_Male
# 139                                 EOGMathGr4_GLP_Male
# 140                             EOGReadingGr4_CACR_Male
# 141                              EOGReadingGr4_GLP_Male
# 142                                 EOGMathGr4_CACR_All
# 143                                  EOGMathGr4_GLP_All
# 144                              EOGReadingGr4_CACR_All
# 145                               EOGReadingGr4_GLP_All
# 146                                  EOGGr4_CACR_Female
# 147                                   EOGGr4_GLP_Female
# 148                               EOGMathGr4_GLP_Female
# 149                            EOGReadingGr4_GLP_Female
# 150                                    EOGGr4_CACR_Male
# 151                                     EOGGr4_GLP_Male
# 152                                EOGMathGr4_CACR_Male
# 153                                 EOGMathGr4_GLP_Male
# 154                              EOGReadingGr4_GLP_Male
# 155                                      EOGGr4_GLP_EDS
# 156                                      EOGGr5_GLP_All
# 157                                 EOGMathGr5_CACR_All
# 158                                  EOGMathGr5_GLP_All
# 159                              EOGReadingGr5_CACR_All
# 160                               EOGReadingGr5_GLP_All
# 161                              EOGScienceGr5_CACR_All
# 162                               EOGScienceGr5_GLP_All
# 163                                  EOGGr5_CACR_Female
# 164                                   EOGGr5_GLP_Female
# 165                              EOGMathGr5_CACR_Female
# 166                               EOGMathGr5_GLP_Female
# 167                            EOGReadingGr5_GLP_Female
# 168                           EOGScienceGr5_CACR_Female
# 169                                    EOGGr5_CACR_Male
# 170                                     EOGGr5_GLP_Male
# 171                                     EOGGr5_CACR_EDS
# 172                                      EOGGr5_GLP_EDS
# 173                                 EOGMathGr5_CACR_All
# 174                                  EOGMathGr5_GLP_All
# 175                              EOGReadingGr5_CACR_All
# 176                               EOGReadingGr5_GLP_All
# 177                              EOGScienceGr5_CACR_All
# 178                               EOGScienceGr5_GLP_All
# 179                                  EOGGr5_CACR_Female
# 180                                   EOGGr5_GLP_Female
# 181                               EOGMathGr5_GLP_Female
# 182                            EOGReadingGr5_GLP_Female
# 183                            EOGScienceGr5_GLP_Female
# 184                                    EOGGr5_CACR_Male
# 185                                     EOGGr5_GLP_Male
# 186                                 EOGMathGr5_GLP_Male
# 187                              EOGScienceGr5_GLP_Male
# 188                                     EOGGr5_CACR_EDS
# 189                                      EOGGr5_GLP_EDS
# 190                                  EOGMathGr3_GLP_All
# 191                              EOGReadingGr3_CACR_All
# 192                               EOGReadingGr3_GLP_All
# 193                                  EOGGr3_CACR_Female
# 194                                   EOGGr3_GLP_Female
# 195                              EOGMathGr3_CACR_Female
# 196                               EOGMathGr3_GLP_Female
# 197                                    EOGGr3_CACR_Male
# 198                                     EOGGr3_GLP_Male
# 199                                EOGMathGr3_CACR_Male
# 200                                 EOGMathGr3_GLP_Male
# 201                                      pct_PASSED_EOG
# 202                              EOGReadingGr3_CACR_All
# 203                               EOGReadingGr3_GLP_All
# 204                                  EOGGr3_CACR_Female
# 205                                   EOGGr3_GLP_Female
# 206                               EOGMathGr3_GLP_Female
# 207                                    EOGGr3_CACR_Male
# 208                                     EOGGr3_GLP_Male
# 209                                EOGMathGr3_CACR_Male
# 210                                 EOGMathGr3_GLP_Male
# 211                                      EOGGr3_GLP_EDS
# 212                                      pct_PASSED_EOG
# 213                                        pct_PROMOTED
# 214                                EOGMathGr3-8_GLP_All
# 215                            EOGReadingGr3-8_CACR_All
# 216                             EOGReadingGr3-8_GLP_All
# 217                                EOGSubjects_CACR_All
# 218                                 EOGSubjects_GLP_All
# 219                            EOGMathGr3-8_CACR_Female
# 220                             EOGMathGr3-8_GLP_Female
# 221                             EOGSubjects_CACR_Female
# 222                              EOGSubjects_GLP_Female
# 223                              EOGMathGr3-8_CACR_Male
# 224                               EOGMathGr3-8_GLP_Male
# 225                            EOGReadingGr3-8_GLP_Male
# 226                               EOGSubjects_CACR_Male
# 227                                EOGSubjects_GLP_Male
# 228                             EOGReadingGr3-8_GLP_All
# 229                                EOGSubjects_CACR_All
# 230                                 EOGSubjects_GLP_All
# 231                            EOGMathGr3-8_CACR_Female
# 232                             EOGMathGr3-8_GLP_Female
# 233                          EOGReadingGr3-8_GLP_Female
# 234                             EOGSubjects_CACR_Female
# 235                              EOGSubjects_GLP_Female
# 236                              EOGMathGr3-8_CACR_Male
# 237                               EOGMathGr3-8_GLP_Male
# 238                            EOGReadingGr3-8_GLP_Male
# 239                               EOGSubjects_CACR_Male
# 240                                EOGSubjects_GLP_Male
# 241                                EOGMathGr3-8_GLP_EDS
# 242                                 EOGSubjects_GLP_EDS
# 243                                  EOGMathGr4_GLP_All
# 244                              EOGReadingGr4_CACR_All
# 245                               EOGReadingGr4_GLP_All
# 246                                  EOGGr4_CACR_Female
# 247                                   EOGGr4_GLP_Female
# 248                              EOGMathGr4_CACR_Female
# 249                               EOGMathGr4_GLP_Female
# 250                                    EOGGr4_CACR_Male
# 251                                     EOGGr4_GLP_Male
# 252                                EOGMathGr4_CACR_Male
# 253                                 EOGMathGr4_GLP_Male
# 254                              EOGReadingGr4_CACR_All
# 255                               EOGReadingGr4_GLP_All
# 256                                  EOGGr4_CACR_Female
# 257                                   EOGGr4_GLP_Female
# 258                              EOGMathGr4_CACR_Female
# 259                               EOGMathGr4_GLP_Female
# 260                                    EOGGr4_CACR_Male
# 261                                     EOGGr4_GLP_Male
# 262                                EOGMathGr4_CACR_Male
# 263                                 EOGMathGr4_GLP_Male
# 264                              EOGReadingGr4_GLP_Male
# 265                                      EOGGr4_GLP_EDS
# 266                                  EOGMathGr5_GLP_All
# 267                              EOGReadingGr5_CACR_All
# 268                               EOGReadingGr5_GLP_All
# 269                              EOGScienceGr5_CACR_All
# 270                               EOGScienceGr5_GLP_All
# 271                                  EOGGr5_CACR_Female
# 272                                   EOGGr5_GLP_Female
# 273                              EOGMathGr5_CACR_Female
# 274                               EOGMathGr5_GLP_Female
# 275                                    EOGGr5_CACR_Male
# 276                                     EOGGr5_GLP_Male
# 277                                EOGMathGr5_CACR_Male
# 278                                 EOGMathGr5_GLP_Male
# 279                              EOGReadingGr5_CACR_All
# 280                               EOGReadingGr5_GLP_All
# 281                              EOGScienceGr5_CACR_All
# 282                               EOGScienceGr5_GLP_All
# 283                                  EOGGr5_CACR_Female
# 284                                   EOGGr5_GLP_Female
# 285                              EOGMathGr5_CACR_Female
# 286                               EOGMathGr5_GLP_Female
# 287                                    EOGGr5_CACR_Male
# 288                                     EOGGr5_GLP_Male
# 289                                EOGMathGr5_CACR_Male
# 290                                 EOGMathGr5_GLP_Male
# 291                                      EOGGr5_GLP_EDS
# 292                               EOGReadingGr3_GLP_All
# 293                                  EOGGr3_CACR_Female
# 294                                   EOGGr3_GLP_Female
# 295                           EOGReadingGr3_CACR_Female
# 296                            EOGReadingGr3_GLP_Female
# 297                                    EOGGr3_CACR_Male
# 298                                     EOGGr3_GLP_Male
# 299                             EOGReadingGr3_CACR_Male
# 300                              EOGReadingGr3_GLP_Male
# 301                                      pct_PASSED_EOG
# 302                                  EOGGr3_CACR_Female
# 303                                   EOGGr3_GLP_Female
# 304                            EOGReadingGr3_GLP_Female
# 305                                    EOGGr3_CACR_Male
# 306                                     EOGGr3_GLP_Male
# 307                             EOGReadingGr3_CACR_Male
# 308                              EOGReadingGr3_GLP_Male
# 309                                      pct_PASSED_EOG
# 310                                        pct_PROMOTED
# 311                             EOGReadingGr3-8_GLP_All
# 312                                EOGSubjects_CACR_All
# 313                                 EOGSubjects_GLP_All
# 314                         EOGReadingGr3-8_CACR_Female
# 315                          EOGReadingGr3-8_GLP_Female
# 316                             EOGSubjects_CACR_Female
# 317                              EOGSubjects_GLP_Female
# 318                           EOGReadingGr3-8_CACR_Male
# 319                            EOGReadingGr3-8_GLP_Male
# 320                               EOGSubjects_CACR_Male
# 321                                EOGSubjects_GLP_Male
# 322                                EOGSubjects_CACR_All
# 323                                 EOGSubjects_GLP_All
# 324                             EOGMathGr3-8_GLP_Female
# 325                         EOGReadingGr3-8_CACR_Female
# 326                          EOGReadingGr3-8_GLP_Female
# 327                             EOGSubjects_CACR_Female
# 328                              EOGSubjects_GLP_Female
# 329                               EOGMathGr3-8_GLP_Male
# 330                           EOGReadingGr3-8_CACR_Male
# 331                            EOGReadingGr3-8_GLP_Male
# 332                               EOGSubjects_CACR_Male
# 333                                EOGSubjects_GLP_Male
# 334                             EOGReadingGr3-8_GLP_EDS
# 335                               EOGReadingGr4_GLP_All
# 336                                  EOGGr4_CACR_Female
# 337                                   EOGGr4_GLP_Female
# 338                           EOGReadingGr4_CACR_Female
# 339                                    EOGGr4_CACR_Male
# 340                                     EOGGr4_GLP_Male
# 341                             EOGReadingGr4_CACR_Male
# 342                              EOGReadingGr4_GLP_Male
# 343                                  EOGGr4_CACR_Female
# 344                                   EOGGr4_GLP_Female
# 345                            EOGReadingGr4_GLP_Female
# 346                                    EOGGr4_CACR_Male
# 347                                     EOGGr4_GLP_Male
# 348                                 EOGMathGr4_GLP_Male
# 349                             EOGReadingGr4_CACR_Male
# 350                              EOGReadingGr4_GLP_Male
# 351                               EOGReadingGr5_GLP_All
# 352                                  EOGGr5_CACR_Female
# 353                                   EOGGr5_GLP_Female
# 354                           EOGReadingGr5_CACR_Female
# 355                            EOGReadingGr5_GLP_Female
# 356                                    EOGGr5_CACR_Male
# 357                                     EOGGr5_GLP_Male
# 358                             EOGReadingGr5_CACR_Male
# 359                              EOGScienceGr5_CACR_All
# 360                               EOGScienceGr5_GLP_All
# 361                                  EOGGr5_CACR_Female
# 362                                   EOGGr5_GLP_Female
# 363                            EOGReadingGr5_GLP_Female
# 364                                    EOGGr5_CACR_Male
# 365                                     EOGGr5_GLP_Male
# 366                              EOGReadingGr5_GLP_Male
# 367                               EOGScienceGr5_GLP_All
# 368                                  EOGGr5_CACR_Female
# 369                                   EOGGr5_GLP_Female
# 370                           EOGScienceGr5_CACR_Female
# 371                            EOGScienceGr5_GLP_Female
# 372                                    EOGGr5_CACR_Male
# 373                                     EOGGr5_GLP_Male
# 374                             EOGScienceGr5_CACR_Male
# 375                              EOGScienceGr5_GLP_Male
# 376                                  EOGGr5_CACR_Female
# 377                                   EOGGr5_GLP_Female
# 378                           EOGScienceGr5_CACR_Female
# 379                            EOGScienceGr5_GLP_Female
# 380                                    EOGGr5_CACR_Male
# 381                                     EOGGr5_GLP_Male
# 382                             EOGScienceGr5_CACR_Male
# 383                              EOGScienceGr5_GLP_Male
# 384                                      EOGGr5_GLP_EDS
# 385                             EOGScienceGr5&8_GLP_All
# 386                         EOGScienceGr5&8_CACR_Female
# 387                          EOGScienceGr5&8_GLP_Female
# 388                           EOGScienceGr5&8_CACR_Male
# 389                            EOGScienceGr5&8_GLP_Male
# 390                         EOGScienceGr5&8_CACR_Female
# 391                          EOGScienceGr5&8_GLP_Female
# 392                           EOGScienceGr5&8_CACR_Male
# 393                            EOGScienceGr5&8_GLP_Male
# 394                                 EOGSubjects_GLP_All
# 395                            EOGMathGr3-8_CACR_Female
# 396                             EOGMathGr3-8_GLP_Female
# 397                         EOGReadingGr3-8_CACR_Female
# 398                          EOGReadingGr3-8_GLP_Female
# 399                             EOGSubjects_CACR_Female
# 400                              EOGSubjects_GLP_Female
# 401                              EOGMathGr3-8_CACR_Male
# 402                               EOGMathGr3-8_GLP_Male
# 403                           EOGReadingGr3-8_CACR_Male
# 404                            EOGReadingGr3-8_GLP_Male
# 405                               EOGSubjects_CACR_Male
# 406                                EOGSubjects_GLP_Male
# 407                            EOGMathGr3-8_CACR_Female
# 408                             EOGMathGr3-8_GLP_Female
# 409                         EOGReadingGr3-8_CACR_Female
# 410                          EOGReadingGr3-8_GLP_Female
# 411                             EOGSubjects_CACR_Female
# 412                              EOGSubjects_GLP_Female
# 413                              EOGMathGr3-8_CACR_Male
# 414                               EOGMathGr3-8_GLP_Male
# 415                           EOGReadingGr3-8_CACR_Male
# 416                            EOGReadingGr3-8_GLP_Male
# 417                               EOGSubjects_CACR_Male
# 418                                EOGSubjects_GLP_Male
# 419                                EOGSubjects_CACR_EDS
# 420                                 EOGSubjects_GLP_EDS
# 421                                 EOCMathI_GLP_Female
# 422                             EOCSubjects_CACR_Female
# 423                              EOCSubjects_GLP_Female
# 424                             EOCSubjects_CACR_Female
# 425                              EOCSubjects_GLP_Female
# 426                              EOCSubjects_GLP_Female
# 427                          EOG/EOCSubjects_GLP_Female
# 428                                   EOGGr3_GLP_Female
# 429                              EOGMathGr3_CACR_Female
# 430                           EOGReadingGr3_CACR_Female
# 431                            EOGReadingGr3_GLP_Female
# 432                                    EOGGr3_CACR_Male
# 433                                     EOGGr3_GLP_Male
# 434                                      pct_PASSED_EOG
# 435                              EOGMathGr3_CACR_Female
# 436                               EOGMathGr3_GLP_Female
# 437                            EOGReadingGr3_GLP_Female
# 438                                    EOGGr3_CACR_Male
# 439                                     EOGGr3_GLP_Male
# 440                                      pct_PASSED_EOG
# 441                                        pct_PROMOTED
# 442                                   EOGGr4_GLP_Female
# 443                              EOGMathGr4_CACR_Female
# 444                               EOGMathGr4_GLP_Female
# 445                           EOGReadingGr4_CACR_Female
# 446                            EOGReadingGr4_GLP_Female
# 447                                    EOGGr4_CACR_Male
# 448                                     EOGGr4_GLP_Male
# 449                              EOGMathGr4_CACR_Female
# 450                               EOGMathGr4_GLP_Female
# 451                           EOGReadingGr4_CACR_Female
# 452                            EOGReadingGr4_GLP_Female
# 453                                     EOGGr4_GLP_Male
# 454                                   EOGGr5_GLP_Female
# 455                              EOGMathGr5_CACR_Female
# 456                               EOGMathGr5_GLP_Female
# 457                           EOGReadingGr5_CACR_Female
# 458                            EOGReadingGr5_GLP_Female
# 459                           EOGScienceGr5_CACR_Female
# 460                            EOGScienceGr5_GLP_Female
# 461                                    EOGGr5_CACR_Male
# 462                                     EOGGr5_GLP_Male
# 463                              EOGMathGr5_CACR_Female
# 464                               EOGMathGr5_GLP_Female
# 465                            EOGReadingGr5_GLP_Female
# 466                           EOGScienceGr5_CACR_Female
# 467                            EOGScienceGr5_GLP_Female
# 468                                    EOGGr5_CACR_Male
# 469                                     EOGGr5_GLP_Male
# 470                                      EOGGr5_GLP_EDS
# 471                               EOGMathGr3_GLP_Female
# 472                           EOGReadingGr3_CACR_Female
# 473                            EOGReadingGr3_GLP_Female
# 474                            EOGReadingGr3_GLP_Female
# 475                                 EOGMathGr3_GLP_Male
# 476                             EOGMathGr3-8_GLP_Female
# 477                          EOGReadingGr3-8_GLP_Female
# 478                             EOGSubjects_CACR_Female
# 479                              EOGSubjects_GLP_Female
# 480                              EOGMathGr3-8_CACR_Male
# 481                               EOGMathGr3-8_GLP_Male
# 482                               EOGSubjects_CACR_Male
# 483                                EOGSubjects_GLP_Male
# 484                          EOGReadingGr3-8_GLP_Female
# 485                             EOGSubjects_CACR_Female
# 486                              EOGSubjects_GLP_Female
# 487                              EOGMathGr3-8_CACR_Male
# 488                               EOGMathGr3-8_GLP_Male
# 489                               EOGSubjects_CACR_Male
# 490                                EOGSubjects_GLP_Male
# 491                               EOGMathGr4_GLP_Female
# 492                           EOGReadingGr4_CACR_Female
# 493                            EOGReadingGr4_GLP_Female
# 494                           EOGReadingGr4_CACR_Female
# 495                            EOGReadingGr4_GLP_Female
# 496                               EOGMathGr5_GLP_Female
# 497                            EOGReadingGr5_GLP_Female
# 498                           EOGScienceGr5_CACR_Female
# 499                            EOGScienceGr5_GLP_Female
# ...                                                 ...
# 280179          Tuition and fees deduction Amt 25KLT50K
# 280180          Tuition and fees deduction Amt 50KLT75K
# 280181               Tuition and fees deduction Amt All
# 280182             Tuition and fees deduction Amt LT25K
# 280183           Tuition and fees deduction Ct 25KLT50K
# 280184           Tuition and fees deduction Ct 50KLT75K
# 280185                Tuition and fees deduction Ct All
# 280186              Tuition and fees deduction Ct LT25K
# 280187         Unemployment compensation Amt 100KLT200K
# 280188           Unemployment compensation Amt 25KLT50K
# 280189           Unemployment compensation Amt 50KLT75K
# 280190          Unemployment compensation Amt 75KLT100K
# 280191                Unemployment compensation Amt All
# 280192             Unemployment compensation Amt GE200K
# 280193          Unemployment compensation Ct 100KLT200K
# 280194            Unemployment compensation Ct 25KLT50K
# 280195            Unemployment compensation Ct 50KLT75K
# 280196           Unemployment compensation Ct 75KLT100K
# 280197                 Unemployment compensation Ct All
# 280198              Unemployment compensation Ct GE200K
# 280199                  Attrtion_Reason_TeachersLeaving
# 280200                  Attrtion_Reason_PersonalReasons
# 280201                         Tot taxes paid Amt LT25K
# 280202                     Tot taxes paid Ct 100KLT200K
# 280203                       Tot taxes paid Ct 25KLT50K
# 280204                       Tot taxes paid Ct 50KLT75K
# 280205                      Tot taxes paid Ct 75KLT100K
# 280206                            Tot taxes paid Ct All
# 280207                         Tot taxes paid Ct GE200K
# 280208                          Tot taxes paid Ct LT25K
# 280209          Tuition and fees deduction Amt 25KLT50K
# 280210          Tuition and fees deduction Amt 50KLT75K
# 280211               Tuition and fees deduction Amt All
# 280212             Tuition and fees deduction Amt LT25K
# 280213           Tuition and fees deduction Ct 25KLT50K
# 280214           Tuition and fees deduction Ct 50KLT75K
# 280215                Tuition and fees deduction Ct All
# 280216              Tuition and fees deduction Ct LT25K
# 280217         Unemployment compensation Amt 100KLT200K
# 280218           Unemployment compensation Amt 25KLT50K
# 280219           Unemployment compensation Amt 50KLT75K
# 280220          Unemployment compensation Amt 75KLT100K
# 280221                Unemployment compensation Amt All
# 280222             Unemployment compensation Amt GE200K
# 280223          Unemployment compensation Ct 100KLT200K
# 280224            Unemployment compensation Ct 25KLT50K
# 280225            Unemployment compensation Ct 50KLT75K
# 280226           Unemployment compensation Ct 75KLT100K
# 280227                 Unemployment compensation Ct All
# 280228              Unemployment compensation Ct GE200K
# 280229                  Attrtion_Reason_PersonalReasons
# 280230               Attrtion_Reason_BeyondControlofLEA
# 280231                     Tot taxes paid Ct 100KLT200K
# 280232                       Tot taxes paid Ct 25KLT50K
# 280233                       Tot taxes paid Ct 50KLT75K
# 280234                      Tot taxes paid Ct 75KLT100K
# 280235                            Tot taxes paid Ct All
# 280236                         Tot taxes paid Ct GE200K
# 280237                          Tot taxes paid Ct LT25K
# 280238          Tuition and fees deduction Amt 25KLT50K
# 280239          Tuition and fees deduction Amt 50KLT75K
# 280240               Tuition and fees deduction Amt All
# 280241             Tuition and fees deduction Amt LT25K
# 280242           Tuition and fees deduction Ct 25KLT50K
# 280243           Tuition and fees deduction Ct 50KLT75K
# 280244                Tuition and fees deduction Ct All
# 280245              Tuition and fees deduction Ct LT25K
# 280246           Unemployment compensation Amt 25KLT50K
# 280247           Unemployment compensation Amt 50KLT75K
# 280248          Unemployment compensation Amt 75KLT100K
# 280249                Unemployment compensation Amt All
# 280250              Unemployment compensation Amt LT25K
# 280251          Unemployment compensation Ct 100KLT200K
# 280252            Unemployment compensation Ct 25KLT50K
# 280253            Unemployment compensation Ct 50KLT75K
# 280254           Unemployment compensation Ct 75KLT100K
# 280255                 Unemployment compensation Ct All
# 280256               Unemployment compensation Ct LT25K
# 280257                  Attrtion_Reason_TeachersLeaving
# 280258                  Attrtion_Reason_PersonalReasons
# 280259               Attrtion_Reason_BeyondControlofLEA
# 280260                       Tot taxes paid Ct 25KLT50K
# 280261                       Tot taxes paid Ct 50KLT75K
# 280262                      Tot taxes paid Ct 75KLT100K
# 280263                            Tot taxes paid Ct All
# 280264                         Tot taxes paid Ct GE200K
# 280265        Tuition and fees deduction Amt 100KLT200K
# 280266          Tuition and fees deduction Amt 25KLT50K
# 280267          Tuition and fees deduction Amt 50KLT75K
# 280268               Tuition and fees deduction Amt All
# 280269             Tuition and fees deduction Amt LT25K
# 280270         Tuition and fees deduction Ct 100KLT200K
# 280271           Tuition and fees deduction Ct 25KLT50K
# 280272           Tuition and fees deduction Ct 50KLT75K
# 280273                Tuition and fees deduction Ct All
# 280274              Tuition and fees deduction Ct LT25K
# 280275         Unemployment compensation Amt 100KLT200K
# 280276          Unemployment compensation Amt 75KLT100K
# 280277                Unemployment compensation Amt All
# 280278             Unemployment compensation Amt GE200K
# 280279          Unemployment compensation Ct 100KLT200K
# 280280           Unemployment compensation Ct 75KLT100K
# 280281                 Unemployment compensation Ct All
# 280282              Unemployment compensation Ct GE200K
# 280283                       Tot taxes paid Ct 50KLT75K
# 280284                      Tot taxes paid Ct 75KLT100K
# 280285                            Tot taxes paid Ct All
# 280286                         Tot taxes paid Ct GE200K
# 280287                          Tot taxes paid Ct LT25K
# 280288          Tuition and fees deduction Amt 25KLT50K
# 280289          Tuition and fees deduction Amt 50KLT75K
# 280290               Tuition and fees deduction Amt All
# 280291             Tuition and fees deduction Amt LT25K
# 280292           Tuition and fees deduction Ct 25KLT50K
# 280293           Tuition and fees deduction Ct 50KLT75K
# 280294                Tuition and fees deduction Ct All
# 280295              Tuition and fees deduction Ct LT25K
# 280296           Unemployment compensation Amt 25KLT50K
# 280297           Unemployment compensation Amt 50KLT75K
# 280298          Unemployment compensation Amt 75KLT100K
# 280299                Unemployment compensation Amt All
# 280300              Unemployment compensation Amt LT25K
# 280301            Unemployment compensation Ct 25KLT50K
# 280302            Unemployment compensation Ct 50KLT75K
# 280303           Unemployment compensation Ct 75KLT100K
# 280304                 Unemployment compensation Ct All
# 280305               Unemployment compensation Ct LT25K
# 280306                  Attrtion_Reason_TeachersLeaving
# 280307                  Attrtion_Reason_PersonalReasons
# 280308               Attrtion_Reason_BeyondControlofLEA
# 280309                      Tot taxes paid Ct 75KLT100K
# 280310                            Tot taxes paid Ct All
# 280311                         Tot taxes paid Ct GE200K
# 280312                          Tot taxes paid Ct LT25K
# 280313          Tuition and fees deduction Amt 25KLT50K
# 280314          Tuition and fees deduction Amt 50KLT75K
# 280315               Tuition and fees deduction Amt All
# 280316             Tuition and fees deduction Amt LT25K
# 280317           Tuition and fees deduction Ct 25KLT50K
# 280318           Tuition and fees deduction Ct 50KLT75K
# 280319                Tuition and fees deduction Ct All
# 280320              Tuition and fees deduction Ct LT25K
# 280321         Unemployment compensation Amt 100KLT200K
# 280322           Unemployment compensation Amt 25KLT50K
# 280323           Unemployment compensation Amt 50KLT75K
# 280324          Unemployment compensation Amt 75KLT100K
# 280325                Unemployment compensation Amt All
# 280326              Unemployment compensation Amt LT25K
# 280327          Unemployment compensation Ct 100KLT200K
# 280328            Unemployment compensation Ct 25KLT50K
# 280329            Unemployment compensation Ct 50KLT75K
# 280330           Unemployment compensation Ct 75KLT100K
# 280331                 Unemployment compensation Ct All
# 280332                  Attrtion_Reason_TeachersLeaving
# 280333                  Attrtion_Reason_PersonalReasons
# 280334                            Tot taxes paid Ct All
# 280335                         Tot taxes paid Ct GE200K
# 280336                          Tot taxes paid Ct LT25K
# 280337        Tuition and fees deduction Amt 100KLT200K
# 280338          Tuition and fees deduction Amt 25KLT50K
# 280339          Tuition and fees deduction Amt 50KLT75K
# 280340               Tuition and fees deduction Amt All
# 280341             Tuition and fees deduction Amt LT25K
# 280342         Tuition and fees deduction Ct 100KLT200K
# 280343           Tuition and fees deduction Ct 25KLT50K
# 280344           Tuition and fees deduction Ct 50KLT75K
# 280345                Tuition and fees deduction Ct All
# 280346              Tuition and fees deduction Ct LT25K
# 280347         Unemployment compensation Amt 100KLT200K
# 280348           Unemployment compensation Amt 25KLT50K
# 280349           Unemployment compensation Amt 50KLT75K
# 280350          Unemployment compensation Amt 75KLT100K
# 280351                Unemployment compensation Amt All
# 280352          Unemployment compensation Ct 100KLT200K
# 280353            Unemployment compensation Ct 25KLT50K
# 280354            Unemployment compensation Ct 50KLT75K
# 280355           Unemployment compensation Ct 75KLT100K
# 280356                 Unemployment compensation Ct All
# 280357    volunteer prepared w Earned Income Credit All
# 280358  volunteer prepared w Earned Income Credit LT25K
# 280359                  Attrtion_Reason_TeachersLeaving
# 280360                  Attrtion_Reason_PersonalReasons
# 280361                         Tot taxes paid Ct GE200K
# 280362                          Tot taxes paid Ct LT25K
# 280363        Tuition and fees deduction Amt 100KLT200K
# 280364          Tuition and fees deduction Amt 25KLT50K
# 280365          Tuition and fees deduction Amt 50KLT75K
# 280366               Tuition and fees deduction Amt All
# 280367             Tuition and fees deduction Amt LT25K
# 280368         Tuition and fees deduction Ct 100KLT200K
# 280369           Tuition and fees deduction Ct 25KLT50K
# 280370           Tuition and fees deduction Ct 50KLT75K
# 280371                Tuition and fees deduction Ct All
# 280372              Tuition and fees deduction Ct LT25K
# 280373         Unemployment compensation Amt 100KLT200K
# 280374           Unemployment compensation Amt 25KLT50K
# 280375           Unemployment compensation Amt 50KLT75K
# 280376          Unemployment compensation Amt 75KLT100K
# 280377                Unemployment compensation Amt All
# 280378          Unemployment compensation Ct 100KLT200K
# 280379            Unemployment compensation Ct 25KLT50K
# 280380            Unemployment compensation Ct 50KLT75K
# 280381           Unemployment compensation Ct 75KLT100K
# 280382                 Unemployment compensation Ct All
# 280383              Unemployment compensation Ct GE200K
# 280384                  Attrtion_Reason_TeachersLeaving
# 280385                  Attrtion_Reason_PersonalReasons
# 280386                          Tot taxes paid Ct LT25K
# 280387        Tuition and fees deduction Amt 100KLT200K
# 280388          Tuition and fees deduction Amt 25KLT50K
# 280389          Tuition and fees deduction Amt 50KLT75K
# 280390               Tuition and fees deduction Amt All
# 280391             Tuition and fees deduction Amt LT25K
# 280392         Tuition and fees deduction Ct 100KLT200K
# 280393           Tuition and fees deduction Ct 25KLT50K
# 280394           Tuition and fees deduction Ct 50KLT75K
# 280395                Tuition and fees deduction Ct All
# 280396              Tuition and fees deduction Ct LT25K
# 280397         Unemployment compensation Amt 100KLT200K
# 280398           Unemployment compensation Amt 25KLT50K
# 280399           Unemployment compensation Amt 50KLT75K
# 280400          Unemployment compensation Amt 75KLT100K
# 280401                Unemployment compensation Amt All
# 280402             Unemployment compensation Amt GE200K
# 280403          Unemployment compensation Ct 100KLT200K
# 280404            Unemployment compensation Ct 25KLT50K
# 280405            Unemployment compensation Ct 50KLT75K
# 280406           Unemployment compensation Ct 75KLT100K
# 280407                 Unemployment compensation Ct All
# 280408              Unemployment compensation Ct GE200K
# 280409                  Attrtion_Reason_PersonalReasons
# 280410          Tuition and fees deduction Amt 25KLT50K
# 280411          Tuition and fees deduction Amt 50KLT75K
# 280412               Tuition and fees deduction Amt All
# 280413             Tuition and fees deduction Amt LT25K
# 280414           Tuition and fees deduction Ct 25KLT50K
# 280415           Tuition and fees deduction Ct 50KLT75K
# 280416                Tuition and fees deduction Ct All
# 280417              Tuition and fees deduction Ct LT25K
# 280418           Unemployment compensation Amt 25KLT50K
# 280419           Unemployment compensation Amt 50KLT75K
# 280420          Unemployment compensation Amt 75KLT100K
# 280421                Unemployment compensation Amt All
# 280422              Unemployment compensation Amt LT25K
# 280423            Unemployment compensation Ct 25KLT50K
# 280424            Unemployment compensation Ct 50KLT75K
# 280425           Unemployment compensation Ct 75KLT100K
# 280426                 Unemployment compensation Ct All
# 280427               Unemployment compensation Ct LT25K
# 280428                  Attrtion_Reason_TeachersLeaving
# 280429                  Attrtion_Reason_PersonalReasons
# 280430               Attrtion_Reason_BeyondControlofLEA
# 280431               Tuition and fees deduction Amt All
# 280432         Tuition and fees deduction Ct 100KLT200K
# 280433                Tuition and fees deduction Ct All
# 280434         Unemployment compensation Amt 100KLT200K
# 280435          Unemployment compensation Amt 75KLT100K
# 280436          Unemployment compensation Ct 100KLT200K
# 280437           Unemployment compensation Ct 75KLT100K
# 280438          Tuition and fees deduction Amt 50KLT75K
# 280439               Tuition and fees deduction Amt All
# 280440             Tuition and fees deduction Amt LT25K
# 280441           Tuition and fees deduction Ct 25KLT50K
# 280442           Tuition and fees deduction Ct 50KLT75K
# 280443                Tuition and fees deduction Ct All
# 280444              Tuition and fees deduction Ct LT25K
# 280445           Unemployment compensation Amt 25KLT50K
# 280446           Unemployment compensation Amt 50KLT75K
# 280447          Unemployment compensation Amt 75KLT100K
# 280448                Unemployment compensation Amt All
# 280449            Unemployment compensation Ct 25KLT50K
# 280450            Unemployment compensation Ct 50KLT75K
# 280451           Unemployment compensation Ct 75KLT100K
# 280452                 Unemployment compensation Ct All
# 280453    volunteer prepared w Earned Income Credit All
# 280454  volunteer prepared w Earned Income Credit LT25K
# 280455                  Attrtion_Reason_TeachersLeaving
# 280456                  Attrtion_Reason_PersonalReasons
# 280457               Tuition and fees deduction Amt All
# 280458             Tuition and fees deduction Amt LT25K
# 280459           Tuition and fees deduction Ct 25KLT50K
# 280460           Tuition and fees deduction Ct 50KLT75K
# 280461                Tuition and fees deduction Ct All
# 280462              Tuition and fees deduction Ct LT25K
# 280463         Unemployment compensation Amt 100KLT200K
# 280464           Unemployment compensation Amt 25KLT50K
# 280465           Unemployment compensation Amt 50KLT75K
# 280466          Unemployment compensation Amt 75KLT100K
# 280467                Unemployment compensation Amt All
# 280468          Unemployment compensation Ct 100KLT200K
# 280469            Unemployment compensation Ct 25KLT50K
# 280470            Unemployment compensation Ct 50KLT75K
# 280471           Unemployment compensation Ct 75KLT100K
# 280472                 Unemployment compensation Ct All
# 280473                  Attrtion_Reason_TeachersLeaving
# 280474                  Attrtion_Reason_PersonalReasons
# 280475          Tuition and fees deduction Ct 75KLT100K
# 280476             Tuition and fees deduction Amt LT25K
# 280477         Tuition and fees deduction Ct 100KLT200K
# 280478           Tuition and fees deduction Ct 25KLT50K
# 280479           Tuition and fees deduction Ct 50KLT75K
# 280480                Tuition and fees deduction Ct All
# 280481              Tuition and fees deduction Ct LT25K
# 280482         Unemployment compensation Amt 100KLT200K
# 280483           Unemployment compensation Amt 25KLT50K
# 280484           Unemployment compensation Amt 50KLT75K
# 280485          Unemployment compensation Amt 75KLT100K
# 280486                Unemployment compensation Amt All
# 280487          Unemployment compensation Ct 100KLT200K
# 280488            Unemployment compensation Ct 25KLT50K
# ...
# 280461            Tuition and fees deduction Amt 50KLT75K     0.989567
# 280462            Tuition and fees deduction Amt 50KLT75K     0.989472
# 280463            Tuition and fees deduction Amt 50KLT75K     0.964744
# 280464            Tuition and fees deduction Amt 50KLT75K     0.980522
# 280465            Tuition and fees deduction Amt 50KLT75K     0.980427
# 280466            Tuition and fees deduction Amt 50KLT75K     0.976632
# 280467            Tuition and fees deduction Amt 50KLT75K     0.986713
# 280468            Tuition and fees deduction Amt 50KLT75K     0.969071
# 280469            Tuition and fees deduction Amt 50KLT75K     0.980568
# 280470            Tuition and fees deduction Amt 50KLT75K     0.978299
# 280471            Tuition and fees deduction Amt 50KLT75K     0.973911
# 280472            Tuition and fees deduction Amt 50KLT75K     0.983527
# 280473            Tuition and fees deduction Amt 50KLT75K     0.969517
# 280474            Tuition and fees deduction Amt 50KLT75K     0.973558
# 280475           Tuition and fees deduction Amt 75KLT100K     0.993531
# 280476                 Tuition and fees deduction Amt All     0.995656
# 280477                 Tuition and fees deduction Amt All     0.969952
# 280478                 Tuition and fees deduction Amt All     0.989746
# 280479                 Tuition and fees deduction Amt All     0.993232
# 280480                 Tuition and fees deduction Amt All     0.999446
# 280481                 Tuition and fees deduction Amt All     0.995913
# 280482                 Tuition and fees deduction Amt All     0.967371
# 280483                 Tuition and fees deduction Amt All     0.958402
# 280484                 Tuition and fees deduction Amt All     0.963291
# 280485                 Tuition and fees deduction Amt All     0.983314
# 280486                 Tuition and fees deduction Amt All     0.970174
# 280487                 Tuition and fees deduction Amt All     0.969939
# 280488                 Tuition and fees deduction Amt All     0.963067
# 280489                 Tuition and fees deduction Amt All     0.961192
# 280490                 Tuition and fees deduction Amt All     0.983924
# 280491                 Tuition and fees deduction Amt All     0.969213
# 280492                 Tuition and fees deduction Amt All     0.958790
# 280493                 Tuition and fees deduction Amt All     0.960082
# 280494                 Tuition and fees deduction Amt All     0.954538
# 280495                 Tuition and fees deduction Amt All     0.955609
# 280496               Tuition and fees deduction Amt LT25K     0.988619
# 280497               Tuition and fees deduction Amt LT25K     0.988790
# 280498               Tuition and fees deduction Amt LT25K     0.992667
# 280499               Tuition and fees deduction Amt LT25K     0.999266
# 280500               Tuition and fees deduction Amt LT25K     0.961384
# 280501               Tuition and fees deduction Amt LT25K     0.965130
# 280502               Tuition and fees deduction Amt LT25K     0.975123
# 280503               Tuition and fees deduction Amt LT25K     0.970284
# 280504               Tuition and fees deduction Amt LT25K     0.950010
# 280505               Tuition and fees deduction Amt LT25K     0.966566
# 280506               Tuition and fees deduction Amt LT25K     0.963457
# 280507               Tuition and fees deduction Amt LT25K     0.974860
# 280508               Tuition and fees deduction Amt LT25K     0.971542
# 280509               Tuition and fees deduction Amt LT25K     0.954984
# 280510               Tuition and fees deduction Amt LT25K     0.960193
# 280511               Tuition and fees deduction Amt LT25K     0.955990
# 280512               Tuition and fees deduction Amt LT25K     0.957514
# 280513           Tuition and fees deduction Ct 100KLT200K     0.952535
# 280514           Tuition and fees deduction Ct 100KLT200K     0.975282
# 280515           Tuition and fees deduction Ct 100KLT200K     0.972157
# 280516           Tuition and fees deduction Ct 100KLT200K     0.960797
# 280517           Tuition and fees deduction Ct 100KLT200K     0.970132
# 280518           Tuition and fees deduction Ct 100KLT200K     0.965522
# 280519             Tuition and fees deduction Ct 25KLT50K     0.985197
# 280520             Tuition and fees deduction Ct 25KLT50K     0.988435
# 280521             Tuition and fees deduction Ct 25KLT50K     0.989984
# 280522             Tuition and fees deduction Ct 25KLT50K     0.965784
# 280523             Tuition and fees deduction Ct 25KLT50K     0.970493
# 280524             Tuition and fees deduction Ct 25KLT50K     0.973185
# 280525             Tuition and fees deduction Ct 25KLT50K     0.975090
# 280526             Tuition and fees deduction Ct 25KLT50K     0.970360
# 280527             Tuition and fees deduction Ct 25KLT50K     0.968721
# 280528             Tuition and fees deduction Ct 25KLT50K     0.972203
# 280529             Tuition and fees deduction Ct 25KLT50K     0.977221
# 280530             Tuition and fees deduction Ct 25KLT50K     0.952163
# 280531             Tuition and fees deduction Ct 25KLT50K     0.957900
# 280532             Tuition and fees deduction Ct 25KLT50K     0.952771
# 280533             Tuition and fees deduction Ct 25KLT50K     0.954319
# 280534             Tuition and fees deduction Ct 50KLT75K     0.992959
# 280535             Tuition and fees deduction Ct 50KLT75K     0.990106
# 280536             Tuition and fees deduction Ct 50KLT75K     0.969270
# 280537             Tuition and fees deduction Ct 50KLT75K     0.975919
# 280538             Tuition and fees deduction Ct 50KLT75K     0.976864
# 280539             Tuition and fees deduction Ct 50KLT75K     0.979914
# 280540             Tuition and fees deduction Ct 50KLT75K     0.983506
# 280541             Tuition and fees deduction Ct 50KLT75K     0.972930
# 280542             Tuition and fees deduction Ct 50KLT75K     0.976884
# 280543             Tuition and fees deduction Ct 50KLT75K     0.974781
# 280544             Tuition and fees deduction Ct 50KLT75K     0.978043
# 280545             Tuition and fees deduction Ct 50KLT75K     0.980371
# 280546             Tuition and fees deduction Ct 50KLT75K     0.967220
# 280547             Tuition and fees deduction Ct 50KLT75K     0.970500
# 280548                  Tuition and fees deduction Ct All     0.993866
# 280549                  Tuition and fees deduction Ct All     0.971644
# 280550                  Tuition and fees deduction Ct All     0.957324
# 280551                  Tuition and fees deduction Ct All     0.962458
# 280552                  Tuition and fees deduction Ct All     0.985989
# 280553                  Tuition and fees deduction Ct All     0.969668
# 280554                  Tuition and fees deduction Ct All     0.973733
# 280555                  Tuition and fees deduction Ct All     0.961936
# 280556                  Tuition and fees deduction Ct All     0.960352
# 280557                  Tuition and fees deduction Ct All     0.986617
# 280558                  Tuition and fees deduction Ct All     0.968226
# 280559                  Tuition and fees deduction Ct All     0.958718
# 280560                  Tuition and fees deduction Ct All     0.959021
# 280561                  Tuition and fees deduction Ct All     0.954745
# 280562                  Tuition and fees deduction Ct All     0.955376
# 280563                Tuition and fees deduction Ct LT25K     0.966295
# 280564                Tuition and fees deduction Ct LT25K     0.970143
# 280565                Tuition and fees deduction Ct LT25K     0.980252
# 280566                Tuition and fees deduction Ct LT25K     0.974909
# 280567                Tuition and fees deduction Ct LT25K     0.952753
# 280568                Tuition and fees deduction Ct LT25K     0.971419
# 280569                Tuition and fees deduction Ct LT25K     0.968642
# 280570                Tuition and fees deduction Ct LT25K     0.979584
# 280571                Tuition and fees deduction Ct LT25K     0.976142
# 280572                Tuition and fees deduction Ct LT25K     0.954546
# 280573                Tuition and fees deduction Ct LT25K     0.960103
# 280574                Tuition and fees deduction Ct LT25K     0.961014
# 280575                Tuition and fees deduction Ct LT25K     0.962534
# 280576           Unemployment compensation Amt 100KLT200K     0.970538
# 280577           Unemployment compensation Amt 100KLT200K     0.954208
# 280578           Unemployment compensation Amt 100KLT200K     0.983629
# 280579           Unemployment compensation Amt 100KLT200K     0.999609
# 280580           Unemployment compensation Amt 100KLT200K     0.969284
# 280581           Unemployment compensation Amt 100KLT200K     0.987726
# 280582             Unemployment compensation Amt 25KLT50K     0.994229
# 280583             Unemployment compensation Amt 25KLT50K     0.966808
# 280584             Unemployment compensation Amt 25KLT50K     0.997902
# 280585             Unemployment compensation Amt 25KLT50K     0.982772
# 280586             Unemployment compensation Amt 25KLT50K     0.997785
# 280587             Unemployment compensation Amt 25KLT50K     0.994395
# 280588             Unemployment compensation Amt 25KLT50K     0.960874
# 280589             Unemployment compensation Amt 25KLT50K     0.995903
# 280590             Unemployment compensation Amt 25KLT50K     0.968136
# 280591             Unemployment compensation Amt 25KLT50K     0.975526
# 280592             Unemployment compensation Amt 25KLT50K     0.986296
# 280593             Unemployment compensation Amt 25KLT50K     0.976460
# 280594             Unemployment compensation Amt 50KLT75K     0.970348
# 280595             Unemployment compensation Amt 50KLT75K     0.996973
# 280596             Unemployment compensation Amt 50KLT75K     0.976911
# 280597             Unemployment compensation Amt 50KLT75K     0.950401
# 280598             Unemployment compensation Amt 50KLT75K     0.993191
# 280599             Unemployment compensation Amt 50KLT75K     0.998611
# 280600             Unemployment compensation Amt 50KLT75K     0.965257
# 280601             Unemployment compensation Amt 50KLT75K     0.994948
# 280602             Unemployment compensation Amt 50KLT75K     0.962974
# 280603             Unemployment compensation Amt 50KLT75K     0.961292
# 280604             Unemployment compensation Amt 50KLT75K     0.975091
# 280605             Unemployment compensation Amt 50KLT75K     0.962411
# 280606            Unemployment compensation Amt 75KLT100K     0.976599
# 280607            Unemployment compensation Amt 75KLT100K     0.971688
# 280608            Unemployment compensation Amt 75KLT100K     0.971431
# 280609            Unemployment compensation Amt 75KLT100K     0.968775
# 280610            Unemployment compensation Amt 75KLT100K     0.998622
# 280611            Unemployment compensation Amt 75KLT100K     0.974631
# 280612            Unemployment compensation Amt 75KLT100K     0.957256
# 280613            Unemployment compensation Amt 75KLT100K     0.963234
# 280614                  Unemployment compensation Amt All     0.976852
# 280615                  Unemployment compensation Amt All     0.959245
# 280616                  Unemployment compensation Amt All     0.996819
# 280617                  Unemployment compensation Amt All     0.996458
# 280618                  Unemployment compensation Amt All     0.971808
# 280619                  Unemployment compensation Amt All     0.997936
# 280620                  Unemployment compensation Amt All     0.963067
# 280621                  Unemployment compensation Amt All     0.973715
# 280622                  Unemployment compensation Amt All     0.984235
# 280623                  Unemployment compensation Amt All     0.970145
# 280624               Unemployment compensation Amt GE200K     0.983143
# 280625               Unemployment compensation Amt GE200K     0.998254
# 280626                Unemployment compensation Amt LT25K     0.981575
# 280627                Unemployment compensation Amt LT25K     0.978932
# 280628                Unemployment compensation Amt LT25K     0.981023
# 280629                Unemployment compensation Amt LT25K     0.993912
# 280630                Unemployment compensation Amt LT25K     0.950296
# 280631                Unemployment compensation Amt LT25K     0.961052
# 280632                Unemployment compensation Amt LT25K     0.958152
# 280633            Unemployment compensation Ct 100KLT200K     0.970491
# 280634            Unemployment compensation Ct 100KLT200K     0.987608
# 280635              Unemployment compensation Ct 25KLT50K     0.995325
# 280636              Unemployment compensation Ct 25KLT50K     0.967768
# 280637              Unemployment compensation Ct 25KLT50K     0.998287
# 280638              Unemployment compensation Ct 25KLT50K     0.972312
# 280639              Unemployment compensation Ct 25KLT50K     0.971512
# 280640              Unemployment compensation Ct 25KLT50K     0.982009
# 280641              Unemployment compensation Ct 25KLT50K     0.969882
# 280642              Unemployment compensation Ct 50KLT75K     0.964974
# 280643              Unemployment compensation Ct 50KLT75K     0.996792
# 280644              Unemployment compensation Ct 50KLT75K     0.968327
# 280645              Unemployment compensation Ct 50KLT75K     0.960542
# 280646              Unemployment compensation Ct 50KLT75K     0.973804
# 280647              Unemployment compensation Ct 50KLT75K     0.962000
# 280648             Unemployment compensation Ct 75KLT100K     0.971535
# 280649             Unemployment compensation Ct 75KLT100K     0.950878
# 280650             Unemployment compensation Ct 75KLT100K     0.957060
# 280651                   Unemployment compensation Ct All     0.973904
# 280652                   Unemployment compensation Ct All     0.970261
# 280653                   Unemployment compensation Ct All     0.980165
# 280654                   Unemployment compensation Ct All     0.965057
# 280655  volunteer prepared w Earned Income Credit 25KL...     0.978640
# 280656  volunteer prepared w Earned Income Credit 25KL...     0.962602
# 280657      volunteer prepared w Earned Income Credit All     0.997737
# 280658                    Attrtion_Reason_TeachersLeaving     0.995792
# 280659                    Attrtion_Reason_TeachersLeaving     0.981335
# 280660                    Attrtion_Reason_PersonalReasons     0.985415
# 280661                                      category_cd_E     1.000000
# 280662                                      category_cd_H     1.000000
# 280663                                      category_cd_I     1.000000
# 280664                                      category_cd_M     1.000000
# 280665                                      category_cd_T     1.000000
# 280666                  calendar_type_txt_Hospital School     1.000000
# 280667                  calendar_type_txt_Hospital School     1.000000
# 280668  calendar_type_txt_Magnet School, Traditional C...     1.000000
# 280669  calendar_type_txt_Magnet School, Year-Round Ca...     1.000000
# 280670  calendar_type_txt_Regular School, Traditional ...     1.000000
# 280671  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 280672  calendar_type_txt_Special Education, Tradition...     1.000000
# 280673  calendar_type_txt_Special Education, Tradition...     1.000000
# 280674  calendar_type_txt_Vocational Education, Tradit...     1.000000
# 280675  calendar_type_txt_Vocational Education, Tradit...     1.000000
# 280676                                  sna_pgm_type_cd_H     1.000000
# 280677                                  sna_pgm_type_cd_S     1.000000
# 280678                                  sna_pgm_type_cd_V     1.000000
#
# [280679 rows x 3 columns]

# %%
print ('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
to_drop
# Out:
# Dropping the following  1206  highly correlated fields.
# ['01_Size',
#  'Math SPG Score',
#  'Overall Achievement Score',
#  'Reading Score',
#  'Math Score',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_CACR_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_CACR_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_CACR_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_CACR_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_CACR_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_CACR_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_CACR_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr4_CACR_Female',
#  'EOGReadingGr4_GLP_Female',
#  'EOGReadingGr5_CACR_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_CACR_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_CACR_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_CACR_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_CACR_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_CACR_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr4_CACR_Male',
#  'EOGReadingGr4_GLP_Male',
#  'EOGReadingGr5_CACR_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_CACR_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_CACR_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr3_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGReadingGr3_GLP_Black',
#  'EOGReadingGr3-8_GLP_Black',
#  'EOGReadingGr4_GLP_Black',
#  'EOGReadingGr5_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_GLP_Black',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_Hispanic',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGReadingGr3_GLP_Hispanic',
#  'EOGReadingGr3-8_GLP_Hispanic',
#  'EOGReadingGr4_GLP_Hispanic',
#  'EOGReadingGr5_GLP_Hispanic',
#  'EOGScienceGr5_CACR_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_CACR_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr3-8_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_CACR_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_CACR_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_CACR_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_CACR_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_CACR_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_CACR_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_CACR_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_CACR_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_CACR_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_CACR_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_CACR_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGReadingGr4_GLP_EDS',
#  'EOGReadingGr5_GLP_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOGGr3_GLP_LEP',
#  'EOGGr5_GLP_LEP',
#  'EOGMathGr3_GLP_LEP',
#  'EOGMathGr3-8_GLP_LEP',
#  'EOGMathGr4_GLP_LEP',
#  'EOGMathGr5_GLP_LEP',
#  'EOGSubjects_GLP_LEP',
#  'EOCSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGGr3_GLP_SWD',
#  'EOGGr4_GLP_SWD',
#  'EOGGr5_GLP_SWD',
#  'EOGMathGr3-8_GLP_SWD',
#  'EOGMathGr4_GLP_SWD',
#  'EOGMathGr5_GLP_SWD',
#  'EOGReadingGr3_GLP_SWD',
#  'EOGScienceGr5_GLP_SWD',
#  'EOGScienceGr5&8_GLP_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'pct_PROMOTED',
#  'ReadingGr3-8_pTarget_PctMet',
#  'lea_avg_age_media_collection',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_class_teach_num',
#  'st_advance_dgr_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'Not Demostrated_TCHR_Standard 3_Pct',
#  'Not Demostrated_TCHR_Standard 5_Pct',
#  'MinorityPct',
#  'IndianMalePct',
#  'AsianMalePct',
#  'HispanicMalePct',
#  'BlackMalePct',
#  'WhiteMalePct',
#  'MinorityMalePct',
#  'IndianFemalePct',
#  'AsianFemalePct',
#  'HispanicFemalePct',
#  'BlackFemalePct',
#  'WhiteFemalePct',
#  'MinorityFemalePct',
#  'Crime_Rate_Assault_Rate',
#  '(TCE) prepared returns Ct 50KLT75K',
#  '(TCE) prepared returns Ct All',
#  '(TCE) prepared returns Ct LT25K',
#  '(VITA) prepared returns Ct 75KLT100K',
#  '(VITA) prepared returns Ct All',
#  '(VITA) prepared returns Ct LT25K',
#  'Add child tax credit Amt 50KLT75K',
#  'Add child tax credit Amt All',
#  'Add child tax credit Amt LT25K',
#  'Add child tax credit Ct 25KLT50K',
#  'Add child tax credit Ct 50KLT75K',
#  'Add child tax credit Ct 75KLT100K',
#  'Add child tax credit Ct All',
#  'Add child tax credit Ct LT25K',
#  'Adjusted gross income (AGI) 100KLT200K',
#  'Adjusted gross income (AGI) 25KLT50K',
#  'Adjusted gross income (AGI) 50KLT75K',
#  'Adjusted gross income (AGI) 75KLT100K',
#  'Adjusted gross income (AGI) All',
#  'Adjusted gross income (AGI) GE200K',
#  'Adjusted gross income (AGI) LT25K',
#  'Advance premium tax credit Amt 100KLT200K',
#  'Advance premium tax credit Amt 25KLT50K',
#  'Advance premium tax credit Amt 50KLT75K',
#  'Advance premium tax credit Amt 75KLT100K',
#  'Advance premium tax credit Amt All',
#  'Advance premium tax credit Amt LT25K',
#  'Advance premium tax credit Ct 100KLT200K',
#  'Advance premium tax credit Ct 25KLT50K',
#  'Advance premium tax credit Ct 50KLT75K',
#  'Advance premium tax credit Ct 75KLT100K',
#  'Advance premium tax credit Ct All',
#  'Advance premium tax credit Ct GE200K',
#  'Advance premium tax credit Ct LT25K',
#  'Alternative minimum tax Amt 100KLT200K',
#  'Alternative minimum tax Amt All',
#  'Alternative minimum tax Amt GE200K',
#  'Alternative minimum tax Ct 100KLT200K',
#  'Alternative minimum tax Ct 25KLT50K',
#  'Alternative minimum tax Ct All',
#  'Alternative minimum tax Ct GE200K',
#  'Business or professionnet income (less loss) Amt 100KLT200K',
#  'Business or professionnet income (less loss) Amt 25KLT50K',
#  'Business or professionnet income (less loss) Amt 50KLT75K',
#  'Business or professionnet income (less loss) Amt 75KLT100K',
#  'Business or professionnet income (less loss) Amt All',
#  'Business or professionnet income (less loss) Amt GE200K',
#  'Business or professionnet income (less loss) Amt LT25K',
#  'Business or professionnet income (less loss) Ct 100KLT200K',
#  'Business or professionnet income (less loss) Ct 25KLT50K',
#  'Business or professionnet income (less loss) Ct 50KLT75K',
#  'Business or professionnet income (less loss) Ct 75KLT100K',
#  'Business or professionnet income (less loss) Ct All',
#  'Business or professionnet income (less loss) Ct GE200K',
#  'Business or professionnet income (less loss) Ct LT25K',
#  'Child and dependent care credit Amt 100KLT200K',
#  'Child and dependent care credit Amt 25KLT50K',
#  'Child and dependent care credit Amt 50KLT75K',
#  'Child and dependent care credit Amt 75KLT100K',
#  'Child and dependent care credit Amt All',
#  'Child and dependent care credit Amt GE200K',
#  'Child and dependent care credit Amt LT25K',
#  'Child and dependent care credit Ct 100KLT200K',
#  'Child and dependent care credit Ct 25KLT50K',
#  'Child and dependent care credit Ct 50KLT75K',
#  'Child and dependent care credit Ct 75KLT100K',
#  'Child and dependent care credit Ct All',
#  'Child and dependent care credit Ct GE200K',
#  'Child and dependent care credit Ct LT25K',
#  'Child tax credit Amt 100KLT200K',
#  'Child tax credit Amt 25KLT50K',
#  'Child tax credit Amt 50KLT75K',
#  'Child tax credit Amt 75KLT100K',
#  'Child tax credit Amt All',
#  'Child tax credit Amt LT25K',
#  'Child tax credit Ct 100KLT200K',
#  'Child tax credit Ct 25KLT50K',
#  'Child tax credit Ct 50KLT75K',
#  'Child tax credit Ct 75KLT100K',
#  'Child tax credit Ct All',
#  'Child tax credit Ct LT25K',
#  'Deductible points Amt 100KLT200K',
#  'Deductible points Amt 25KLT50K',
#  'Deductible points Amt 50KLT75K',
#  'Deductible points Amt 75KLT100K',
#  'Deductible points Amt All',
#  'Deductible points Amt GE200K',
#  'Deductible points Ct 100KLT200K',
#  'Deductible points Ct 25KLT50K',
#  'Deductible points Ct 50KLT75K',
#  'Deductible points Ct 75KLT100K',
#  'Deductible points Ct All',
#  'Deductible points Ct GE200K',
#  'Domestic production activities deduction Amt All',
#  'Domestic production activities deduction Amt GE200K',
#  'Domestic production activities deduction Ct 100KLT200K',
#  'Domestic production activities deduction Ct All',
#  'Domestic production activities deduction Ct GE200K',
#  'Earned income credit Amt 25KLT50K',
#  'Earned income credit Amt All',
#  'Earned income credit Amt LT25K',
#  'Earned income credit Ct 25KLT50K',
#  'Earned income credit Ct 50KLT75K',
#  'Earned income credit Ct All',
#  'Earned income credit Ct LT25K',
#  'Educator expenses Amt 100KLT200K',
#  'Educator expenses Amt 25KLT50K',
#  'Educator expenses Amt 50KLT75K',
#  'Educator expenses Amt 75KLT100K',
#  'Educator expenses Amt All',
#  'Educator expenses Amt GE200K',
#  'Educator expenses Amt LT25K',
#  'Educator expenses Ct 100KLT200K',
#  'Educator expenses Ct 25KLT50K',
#  'Educator expenses Ct 50KLT75K',
#  'Educator expenses Ct 75KLT100K',
#  'Educator expenses Ct All',
#  'Educator expenses Ct GE200K',
#  'Educator expenses Ct LT25K',
#  'Excess advance premium tax credit repayment Amt 100KLT200K',
#  'Excess advance premium tax credit repayment Amt 25KLT50K',
#  'Excess advance premium tax credit repayment Amt 50KLT75K',
#  'Excess advance premium tax credit repayment Amt 75KLT100K',
#  'Excess advance premium tax credit repayment Amt All',
#  'Excess advance premium tax credit repayment Amt LT25K',
#  'Excess advance premium tax credit repayment Ct 100KLT200K',
#  'Excess advance premium tax credit repayment Ct 25KLT50K',
#  'Excess advance premium tax credit repayment Ct 50KLT75K',
#  'Excess advance premium tax credit repayment Ct 75KLT100K',
#  'Excess advance premium tax credit repayment Ct All',
#  'Excess advance premium tax credit repayment Ct LT25K',
#  'Excess earned income credit (refundable) Amt 25KLT50K',
#  'Excess earned income credit (refundable) Amt All',
#  'Excess earned income credit (refundable) Amt LT25K',
#  'Excess earned income credit (refundable) Ct 25KLT50K',
#  'Excess earned income credit (refundable) Ct 50KLT75K',
#  'Excess earned income credit (refundable) Ct All',
#  'Excess earned income credit (refundable) Ct LT25K',
#  'Foreign tax credit Amt 100KLT200K',
#  'Foreign tax credit Amt 25KLT50K',
#  'Foreign tax credit Amt 50KLT75K',
#  'Foreign tax credit Amt 75KLT100K',
#  'Foreign tax credit Amt All',
#  'Foreign tax credit Amt GE200K',
#  'Foreign tax credit Amt LT25K',
#  'Foreign tax credit Ct 100KLT200K',
#  'Foreign tax credit Ct 25KLT50K',
#  'Foreign tax credit Ct 50KLT75K',
#  'Foreign tax credit Ct 75KLT100K',
#  'Foreign tax credit Ct All',
#  'Foreign tax credit Ct GE200K',
#  'Foreign tax credit Ct LT25K',
#  'Health care individual responsibility payment Amt 100KLT200K',
#  'Health care individual responsibility payment Amt 25KLT50K',
#  'Health care individual responsibility payment Amt 50KLT75K',
#  'Health care individual responsibility payment Amt 75KLT100K',
#  'Health care individual responsibility payment Amt All',
#  'Health care individual responsibility payment Amt LT25K',
#  'Health care individual responsibility payment Ct 100KLT200K',
#  'Health care individual responsibility payment Ct 25KLT50K',
#  'Health care individual responsibility payment Ct 50KLT75K',
#  'Health care individual responsibility payment Ct 75KLT100K',
#  'Health care individual responsibility payment Ct All',
#  'Health care individual responsibility payment Ct GE200K',
#  'Health care individual responsibility payment Ct LT25K',
#  'Home mortgage interest paid Amt 100KLT200K',
#  'Home mortgage interest paid Amt 25KLT50K',
#  'Home mortgage interest paid Amt 50KLT75K',
#  'Home mortgage interest paid Amt 75KLT100K',
#  'Home mortgage interest paid Amt All',
#  'Home mortgage interest paid Amt GE200K',
#  'Home mortgage interest paid Amt LT25K',
#  'Home mortgage interest paid Ct 100KLT200K',
#  'Home mortgage interest paid Ct 25KLT50K',
#  'Home mortgage interest paid Ct 50KLT75K',
#  'Home mortgage interest paid Ct 75KLT100K',
#  'Home mortgage interest paid Ct All',
#  'Home mortgage interest paid Ct GE200K',
#  'Home mortgage interest paid Ct LT25K',
#  'Home mortgage interest paid from personal seller Amt 100KLT200K',
#  'Home mortgage interest paid from personal seller Amt 25KLT50K',
#  'Home mortgage interest paid from personal seller Amt 50KLT75K',
#  'Home mortgage interest paid from personal seller Amt 75KLT100K',
#  'Home mortgage interest paid from personal seller Amt All',
#  'Home mortgage interest paid from personal seller Amt GE200K',
#  'Home mortgage interest paid from personal seller Ct 100KLT200K',
#  'Home mortgage interest paid from personal seller Ct 25KLT50K',
#  'Home mortgage interest paid from personal seller Ct 50KLT75K',
#  'Home mortgage interest paid from personal seller Ct 75KLT100K',
#  'Home mortgage interest paid from personal seller Ct All',
#  'Home mortgage interest paid from personal seller Ct GE200K',
#  'Home mortgage interest paid from personal seller Ct LT25K',
#  'Income tax Amt 100KLT200K',
#  'Income tax Amt 25KLT50K',
#  'Income tax Amt 50KLT75K',
#  'Income tax Amt 75KLT100K',
#  'Income tax Amt All',
#  'Income tax Amt GE200K',
#  'Income tax Amt LT25K',
#  'Income tax Ct 100KLT200K',
#  'Income tax Ct 25KLT50K',
#  'Income tax Ct 50KLT75K',
#  'Income tax Ct 75KLT100K',
#  'Income tax Ct All',
#  'Income tax Ct GE200K',
#  'Income tax Ct LT25K',
#  'Income tax before credits Amt 100KLT200K',
#  'Income tax before credits Amt 25KLT50K',
#  'Income tax before credits Amt 50KLT75K',
#  'Income tax before credits Amt 75KLT100K',
#  'Income tax before credits Amt All',
#  'Income tax before credits Amt GE200K',
#  'Income tax before credits Amt LT25K',
#  'Income tax before credits Ct 100KLT200K',
#  'Income tax before credits Ct 25KLT50K',
#  'Income tax before credits Ct 50KLT75K',
#  'Income tax before credits Ct 75KLT100K',
#  'Income tax before credits Ct All',
#  'Income tax before credits Ct GE200K',
#  'Income tax before credits Ct LT25K',
#  'Individual retirement arrangement payments Amt 100KLT200K',
#  'Individual retirement arrangement payments Amt 25KLT50K',
#  'Individual retirement arrangement payments Amt 50KLT75K',
#  'Individual retirement arrangement payments Amt 75KLT100K',
#  'Individual retirement arrangement payments Amt All',
#  'Individual retirement arrangement payments Amt GE200K',
#  'Individual retirement arrangement payments Amt LT25K',
#  'Individual retirement arrangement payments Ct 100KLT200K',
#  'Individual retirement arrangement payments Ct 25KLT50K',
#  'Individual retirement arrangement payments Ct 50KLT75K',
#  'Individual retirement arrangement payments Ct 75KLT100K',
#  'Individual retirement arrangement payments Ct All',
#  'Individual retirement arrangement payments Ct GE200K',
#  'Individual retirement arrangement payments Ct LT25K',
#  'Investment interest paid Amt 100KLT200K',
#  'Investment interest paid Amt 50KLT75K',
#  'Investment interest paid Amt 75KLT100K',
#  'Investment interest paid Amt All',
#  'Investment interest paid Amt GE200K',
#  'Investment interest paid Ct 100KLT200K',
#  'Investment interest paid Ct 25KLT50K',
#  'Investment interest paid Ct 50KLT75K',
#  'Investment interest paid Ct 75KLT100K',
#  'Investment interest paid Ct All',
#  'Investment interest paid Ct GE200K',
#  'Net capital gain (less loss) in AGI Amt 100KLT200K',
#  'Net capital gain (less loss) in AGI Amt 25KLT50K',
#  'Net capital gain (less loss) in AGI Amt 50KLT75K',
#  'Net capital gain (less loss) in AGI Amt 75KLT100K',
#  'Net capital gain (less loss) in AGI Amt All',
#  'Net capital gain (less loss) in AGI Amt GE200K',
#  'Net capital gain (less loss) in AGI Amt LT25K',
#  'Net capital gain (less loss) in AGI Ct 100KLT200K',
#  'Net capital gain (less loss) in AGI Ct 25KLT50K',
#  'Net capital gain (less loss) in AGI Ct 50KLT75K',
#  'Net capital gain (less loss) in AGI Ct 75KLT100K',
#  'Net capital gain (less loss) in AGI Ct All',
#  'Net capital gain (less loss) in AGI Ct GE200K',
#  'Net capital gain (less loss) in AGI Ct LT25K',
#  'Net investment income tax Amt All',
#  'Net investment income tax Amt GE200K',
#  'Net investment income tax Ct 100KLT200K',
#  'Net investment income tax Ct All',
#  'Net investment income tax Ct GE200K',
#  'Net limited misc deduction Amt 100KLT200K',
#  'Net limited misc deduction Amt 25KLT50K',
#  'Net limited misc deduction Amt 50KLT75K',
#  'Net limited misc deduction Amt 75KLT100K',
#  'Net limited misc deduction Amt All',
#  'Net limited misc deduction Amt GE200K',
#  'Net limited misc deduction Amt LT25K',
#  'Net limited misc deduction Ct 100KLT200K',
#  'Net limited misc deduction Ct 25KLT50K',
#  'Net limited misc deduction Ct 50KLT75K',
#  'Net limited misc deduction Ct 75KLT100K',
#  'Net limited misc deduction Ct All',
#  'Net limited misc deduction Ct GE200K',
#  'Net limited misc deduction Ct LT25K',
#  'Net premium tax credit Amt 25KLT50K',
#  'Net premium tax credit Amt 50KLT75K',
#  'Net premium tax credit Amt All',
#  'Net premium tax credit Amt LT25K',
#  'Net premium tax credit Ct 25KLT50K',
#  'Net premium tax credit Ct 50KLT75K',
#  'Net premium tax credit Ct All',
#  'Net premium tax credit Ct LT25K',
#  'Nonrefundable edu credit Amt 100KLT200K',
#  'Nonrefundable edu credit Amt 25KLT50K',
#  'Nonrefundable edu credit Amt 50KLT75K',
#  'Nonrefundable edu credit Amt 75KLT100K',
#  'Nonrefundable edu credit Amt All',
#  'Nonrefundable edu credit Amt LT25K',
#  'Nonrefundable edu credit Ct 100KLT200K',
#  'Nonrefundable edu credit Ct 25KLT50K',
#  'Nonrefundable edu credit Ct 50KLT75K',
#  'Nonrefundable edu credit Ct 75KLT100K',
#  'Nonrefundable edu credit Ct All',
#  'Nonrefundable edu credit Ct LT25K',
#  'Number of dependents 100KLT200K',
#  'Number of dependents 25KLT50K',
#  'Number of dependents 50KLT75K',
#  'Number of dependents 75KLT100K',
#  'Number of dependents All',
#  'Number of dependents GE200K',
#  'Number of dependents LT25K',
#  'Number of elderly returns 100KLT200K',
#  'Number of elderly returns 25KLT50K',
#  'Number of elderly returns 50KLT75K',
#  'Number of elderly returns 75KLT100K',
#  'Number of elderly returns All',
#  'Number of elderly returns GE200K',
#  'Number of elderly returns LT25K',
#  'Number of exemptions 100KLT200K',
#  'Number of exemptions 25KLT50K',
#  'Number of exemptions 50KLT75K',
#  'Number of exemptions 75KLT100K',
#  'Number of exemptions All',
#  'Number of exemptions GE200K',
#  'Number of exemptions LT25K',
#  'Number of head of household returns 100KLT200K',
#  'Number of head of household returns 25KLT50K',
#  'Number of head of household returns 50KLT75K',
#  'Number of head of household returns 75KLT100K',
#  'Number of head of household returns All',
#  'Number of head of household returns GE200K',
#  'Number of head of household returns LT25K',
#  'Number of joint returns 100KLT200K',
#  'Number of joint returns 25KLT50K',
#  'Number of joint returns 50KLT75K',
#  'Number of joint returns 75KLT100K',
#  'Number of joint returns All',
#  'Number of joint returns GE200K',
#  'Number of joint returns LT25K',
#  'Number of refund anticipation check returns 100KLT200K',
#  'Number of refund anticipation check returns 25KLT50K',
#  'Number of refund anticipation check returns 50KLT75K',
#  'Number of refund anticipation check returns 75KLT100K',
#  'Number of refund anticipation check returns All',
#  'Number of refund anticipation check returns GE200K',
#  'Number of refund anticipation check returns LT25K',
#  'Number of refund anticipation loan returns 25KLT50K',
#  'Number of refund anticipation loan returns All',
#  'Number of refund anticipation loan returns LT25K',
#  'Number of returns 100KLT200K',
#  'Number of returns 25KLT50K',
#  'Number of returns 50KLT75K',
#  'Number of returns 75KLT100K',
#  'Number of returns All',
#  'Number of returns GE200K',
#  'Number of returns LT25K',
#  'Number of single returns 100KLT200K',
#  'Number of single returns 25KLT50K',
#  'Number of single returns 50KLT75K',
#  'Number of single returns 75KLT100K',
#  'Number of single returns All',
#  'Number of single returns GE200K',
#  'Number of single returns LT25K',
#  'Number of volunteer prepared returns Tot 100KLT200K',
#  'Number of volunteer prepared returns Tot 25KLT50K',
#  'Number of volunteer prepared returns Tot 75KLT100K',
#  'Number of volunteer prepared returns Tot All',
#  'Number of volunteer prepared returns Tot LT25K',
#  "Number with paid preparer's signature 100KLT200K",
#  "Number with paid preparer's signature 25KLT50K",
#  "Number with paid preparer's signature 50KLT75K",
#  "Number with paid preparer's signature 75KLT100K",
#  "Number with paid preparer's signature All",
#  "Number with paid preparer's signature GE200K",
#  "Number with paid preparer's signature LT25K",
#  'Ordinary dividends Amt 100KLT200K',
#  'Ordinary dividends Amt 25KLT50K',
#  'Ordinary dividends Amt 50KLT75K',
#  'Ordinary dividends Amt 75KLT100K',
#  'Ordinary dividends Amt All',
#  'Ordinary dividends Amt GE200K',
#  'Ordinary dividends Amt LT25K',
#  'Ordinary dividends Ct 100KLT200K',
#  'Ordinary dividends Ct 25KLT50K',
#  'Ordinary dividends Ct 50KLT75K',
#  'Ordinary dividends Ct 75KLT100K',
#  'Ordinary dividends Ct All',
#  'Ordinary dividends Ct GE200K',
#  'Ordinary dividends Ct LT25K',
#  'Other non-limited misc deduction Amt 100KLT200K',
#  'Other non-limited misc deduction Amt 25KLT50K',
#  'Other non-limited misc deduction Amt All',
#  'Other non-limited misc deduction Amt GE200K',
#  'Other non-limited misc deduction Ct 100KLT200K',
#  'Other non-limited misc deduction Ct 25KLT50K',
#  'Other non-limited misc deduction Ct 50KLT75K',
#  'Other non-limited misc deduction Ct All',
#  'Other non-limited misc deduction Ct GE200K',
#  'Overpayments refunded Amt 100KLT200K',
#  'Overpayments refunded Amt 25KLT50K',
#  'Overpayments refunded Amt 50KLT75K',
#  'Overpayments refunded Amt 75KLT100K',
#  'Overpayments refunded Amt All',
#  'Overpayments refunded Amt GE200K',
#  'Overpayments refunded Amt LT25K',
#  'Overpayments refunded Ct 100KLT200K',
#  'Overpayments refunded Ct 25KLT50K',
#  'Overpayments refunded Ct 50KLT75K',
#  'Overpayments refunded Ct 75KLT100K',
#  'Overpayments refunded Ct All',
#  'Overpayments refunded Ct GE200K',
#  'Overpayments refunded Ct LT25K',
#  'Partnership/S-corp net income (less loss) Amt 100KLT200K',
#  'Partnership/S-corp net income (less loss) Amt 25KLT50K',
#  'Partnership/S-corp net income (less loss) Amt 50KLT75K',
#  'Partnership/S-corp net income (less loss) Amt 75KLT100K',
#  'Partnership/S-corp net income (less loss) Amt All',
#  'Partnership/S-corp net income (less loss) Amt GE200K',
#  'Partnership/S-corp net income (less loss) Ct 100KLT200K',
#  'Partnership/S-corp net income (less loss) Ct 25KLT50K',
#  'Partnership/S-corp net income (less loss) Ct 50KLT75K',
#  'Partnership/S-corp net income (less loss) Ct 75KLT100K',
#  'Partnership/S-corp net income (less loss) Ct All',
#  'Partnership/S-corp net income (less loss) Ct GE200K',
#  'Partnership/S-corp net income (less loss) Ct LT25K',
#  'Pensions and annuities in AGI Amt 100KLT200K',
#  'Pensions and annuities in AGI Amt 25KLT50K',
#  'Pensions and annuities in AGI Amt 50KLT75K',
#  'Pensions and annuities in AGI Amt 75KLT100K',
#  'Pensions and annuities in AGI Amt All',
#  'Pensions and annuities in AGI Amt GE200K',
#  'Pensions and annuities in AGI Amt LT25K',
#  'Pensions and annuities in AGI Ct 100KLT200K',
#  'Pensions and annuities in AGI Ct 25KLT50K',
#  'Pensions and annuities in AGI Ct 50KLT75K',
#  'Pensions and annuities in AGI Ct 75KLT100K',
#  'Pensions and annuities in AGI Ct All',
#  'Pensions and annuities in AGI Ct GE200K',
#  'Pensions and annuities in AGI Ct LT25K',
#  'Personal property taxes Amt 100KLT200K',
#  'Personal property taxes Amt 25KLT50K',
#  'Personal property taxes Amt 50KLT75K',
#  'Personal property taxes Amt 75KLT100K',
#  'Personal property taxes Amt All',
#  'Personal property taxes Amt GE200K',
#  'Personal property taxes Amt LT25K',
#  'Personal property taxes Ct 100KLT200K',
#  'Personal property taxes Ct 25KLT50K',
#  'Personal property taxes Ct 50KLT75K',
#  'Personal property taxes Ct 75KLT100K',
#  'Personal property taxes Ct All',
#  'Personal property taxes Ct GE200K',
#  'Personal property taxes Ct LT25K',
#  'Qualified dividends Amt 100KLT200K',
#  'Qualified dividends Amt 25KLT50K',
#  'Qualified dividends Amt 50KLT75K',
#  'Qualified dividends Amt 75KLT100K',
#  'Qualified dividends Amt All',
#  'Qualified dividends Amt GE200K',
#  'Qualified dividends Amt LT25K',
#  'Qualified dividends Ct 100KLT200K',
#  'Qualified dividends Ct 25KLT50K',
#  'Qualified dividends Ct 50KLT75K',
#  'Qualified dividends Ct 75KLT100K',
#  'Qualified dividends Ct All',
#  'Qualified dividends Ct GE200K',
#  'Qualified dividends Ct LT25K',
#  'Qualified mortgage insurance premiums Amt 100KLT200K',
#  'Qualified mortgage insurance premiums Amt 25KLT50K',
#  'Qualified mortgage insurance premiums Amt 50KLT75K',
#  'Qualified mortgage insurance premiums Amt 75KLT100K',
#  'Qualified mortgage insurance premiums Amt All',
#  'Qualified mortgage insurance premiums Amt LT25K',
#  'Qualified mortgage insurance premiums Ct 100KLT200K',
#  'Qualified mortgage insurance premiums Ct 25KLT50K',
#  'Qualified mortgage insurance premiums Ct 50KLT75K',
#  'Qualified mortgage insurance premiums Ct 75KLT100K',
#  'Qualified mortgage insurance premiums Ct All',
#  'Qualified mortgage insurance premiums Ct LT25K',
#  'Real estate taxes Amt 100KLT200K',
#  'Real estate taxes Amt 25KLT50K',
#  'Real estate taxes Amt 50KLT75K',
#  'Real estate taxes Amt 75KLT100K',
#  'Real estate taxes Amt All',
#  'Real estate taxes Amt GE200K',
#  'Real estate taxes Amt LT25K',
#  'Real estate taxes Ct 100KLT200K',
#  'Real estate taxes Ct 25KLT50K',
#  'Real estate taxes Ct 50KLT75K',
#  'Real estate taxes Ct 75KLT100K',
#  'Real estate taxes Ct All',
#  'Real estate taxes Ct GE200K',
#  'Real estate taxes Ct LT25K',
#  'Refundable edu credit Amt 100KLT200K',
#  'Refundable edu credit Amt 25KLT50K',
#  'Refundable edu credit Amt 50KLT75K',
#  'Refundable edu credit Amt 75KLT100K',
#  'Refundable edu credit Amt All',
#  'Refundable edu credit Amt LT25K',
#  'Refundable edu credit Ct 100KLT200K',
#  'Refundable edu credit Ct 25KLT50K',
#  'Refundable edu credit Ct 50KLT75K',
#  'Refundable edu credit Ct 75KLT100K',
#  'Refundable edu credit Ct All',
#  'Refundable edu credit Ct LT25K',
#  'Residential energy tax credit Amt 100KLT200K',
#  'Residential energy tax credit Amt 25KLT50K',
#  'Residential energy tax credit Amt 50KLT75K',
#  'Residential energy tax credit Amt 75KLT100K',
#  'Residential energy tax credit Amt All',
#  'Residential energy tax credit Amt GE200K',
#  'Residential energy tax credit Ct 100KLT200K',
#  'Residential energy tax credit Ct 25KLT50K',
#  'Residential energy tax credit Ct 50KLT75K',
#  'Residential energy tax credit Ct 75KLT100K',
#  'Residential energy tax credit Ct All',
#  'Residential energy tax credit Ct GE200K',
#  'Retirement savings contributions credit Amt 25KLT50K',
#  'Retirement savings contributions credit Amt 50KLT75K',
#  'Retirement savings contributions credit Amt All',
#  'Retirement savings contributions credit Amt LT25K',
#  'Retirement savings contributions credit Ct 25KLT50K',
#  'Retirement savings contributions credit Ct 50KLT75K',
#  'Retirement savings contributions credit Ct All',
#  'Retirement savings contributions credit Ct LT25K',
#  'Salaries and wages in AGI Amt 100KLT200K',
#  'Salaries and wages in AGI Amt 25KLT50K',
#  'Salaries and wages in AGI Amt 50KLT75K',
#  'Salaries and wages in AGI Amt 75KLT100K',
#  'Salaries and wages in AGI Amt All',
#  'Salaries and wages in AGI Amt GE200K',
#  'Salaries and wages in AGI Amt LT25K',
#  'Salaries and wages in AGI Ct 100KLT200K',
#  'Salaries and wages in AGI Ct 25KLT50K',
#  'Salaries and wages in AGI Ct 50KLT75K',
#  'Salaries and wages in AGI Ct 75KLT100K',
#  'Salaries and wages in AGI Ct All',
#  'Salaries and wages in AGI Ct GE200K',
#  'Salaries and wages in AGI Ct LT25K',
#  'Self-employed (Keogh) retirement plans Amt 100KLT200K',
#  'Self-employed (Keogh) retirement plans Amt 25KLT50K',
#  'Self-employed (Keogh) retirement plans Amt 50KLT75K',
#  'Self-employed (Keogh) retirement plans Amt 75KLT100K',
#  'Self-employed (Keogh) retirement plans Amt All',
#  'Self-employed (Keogh) retirement plans Amt GE200K',
#  'Self-employed (Keogh) retirement plans Ct 100KLT200K',
#  'Self-employed (Keogh) retirement plans Ct 25KLT50K',
#  'Self-employed (Keogh) retirement plans Ct 50KLT75K',
#  'Self-employed (Keogh) retirement plans Ct 75KLT100K',
#  'Self-employed (Keogh) retirement plans Ct All',
#  'Self-employed (Keogh) retirement plans Ct GE200K',
#  'Self-employed health insurance deduction Amt 100KLT200K',
#  'Self-employed health insurance deduction Amt 25KLT50K',
#  'Self-employed health insurance deduction Amt 50KLT75K',
#  'Self-employed health insurance deduction Amt 75KLT100K',
#  'Self-employed health insurance deduction Amt All',
#  'Self-employed health insurance deduction Amt GE200K',
#  'Self-employed health insurance deduction Amt LT25K',
#  'Self-employed health insurance deduction Ct 100KLT200K',
#  'Self-employed health insurance deduction Ct 25KLT50K',
#  'Self-employed health insurance deduction Ct 50KLT75K',
#  'Self-employed health insurance deduction Ct 75KLT100K',
#  'Self-employed health insurance deduction Ct All',
#  'Self-employed health insurance deduction Ct GE200K',
#  'Self-employed health insurance deduction Ct LT25K',
#  'Self-employment tax Amt 100KLT200K',
#  'Self-employment tax Amt 25KLT50K',
#  'Self-employment tax Amt 50KLT75K',
#  'Self-employment tax Amt 75KLT100K',
#  'Self-employment tax Amt All',
#  'Self-employment tax Amt GE200K',
#  'Self-employment tax Amt LT25K',
#  'Self-employment tax Ct 100KLT200K',
#  'Self-employment tax Ct 25KLT50K',
#  'Self-employment tax Ct 50KLT75K',
#  'Self-employment tax Ct 75KLT100K',
#  'Self-employment tax Ct All',
#  'Self-employment tax Ct GE200K',
#  'Self-employment tax Ct LT25K',
#  'State and local general sales taxes Amt 100KLT200K',
#  'State and local general sales taxes Amt 25KLT50K',
#  'State and local general sales taxes Amt 50KLT75K',
#  'State and local general sales taxes Amt 75KLT100K',
#  'State and local general sales taxes Amt All',
#  'State and local general sales taxes Amt GE200K',
#  'State and local general sales taxes Amt LT25K',
#  'State and local general sales taxes Ct 100KLT200K',
#  'State and local general sales taxes Ct 25KLT50K',
#  'State and local general sales taxes Ct 50KLT75K',
#  'State and local general sales taxes Ct 75KLT100K',
#  'State and local general sales taxes Ct All',
#  'State and local general sales taxes Ct GE200K',
#  'State and local general sales taxes Ct LT25K',
#  'State and local income tax refunds Amt 100KLT200K',
#  'State and local income tax refunds Amt 25KLT50K',
#  'State and local income tax refunds Amt 50KLT75K',
#  'State and local income tax refunds Amt 75KLT100K',
#  'State and local income tax refunds Amt All',
#  'State and local income tax refunds Amt GE200K',
#  'State and local income tax refunds Amt LT25K',
#  'State and local income tax refunds Ct 100KLT200K',
#  'State and local income tax refunds Ct 25KLT50K',
#  'State and local income tax refunds Ct 50KLT75K',
#  'State and local income tax refunds Ct 75KLT100K',
#  'State and local income tax refunds Ct All',
#  'State and local income tax refunds Ct GE200K',
#  'State and local income tax refunds Ct LT25K',
#  'State and local income taxes Amt 100KLT200K',
#  'State and local income taxes Amt 25KLT50K',
#  'State and local income taxes Amt 50KLT75K',
#  'State and local income taxes Amt 75KLT100K',
#  'State and local income taxes Amt All',
#  'State and local income taxes Amt GE200K',
#  'State and local income taxes Amt LT25K',
#  'State and local income taxes Ct 100KLT200K',
#  'State and local income taxes Ct 25KLT50K',
#  'State and local income taxes Ct 50KLT75K',
#  'State and local income taxes Ct 75KLT100K',
#  'State and local income taxes Ct All',
#  'State and local income taxes Ct GE200K',
#  'State and local income taxes Ct LT25K',
#  'Student loan interest deduction Amt 100KLT200K',
#  'Student loan interest deduction Amt 25KLT50K',
#  'Student loan interest deduction Amt 50KLT75K',
#  'Student loan interest deduction Amt 75KLT100K',
#  'Student loan interest deduction Amt All',
#  'Student loan interest deduction Amt LT25K',
#  'Student loan interest deduction Ct 100KLT200K',
#  'Student loan interest deduction Ct 25KLT50K',
#  'Student loan interest deduction Ct 50KLT75K',
#  'Student loan interest deduction Ct 75KLT100K',
#  'Student loan interest deduction Ct All',
#  'Student loan interest deduction Ct LT25K',
#  'Tax due at time of filing Amt 100KLT200K',
#  'Tax due at time of filing Amt 25KLT50K',
#  'Tax due at time of filing Amt 50KLT75K',
#  'Tax due at time of filing Amt 75KLT100K',
#  'Tax due at time of filing Amt All',
#  'Tax due at time of filing Amt GE200K',
#  'Tax due at time of filing Amt LT25K',
#  'Tax due at time of filing Ct 100KLT200K',
#  'Tax due at time of filing Ct 25KLT50K',
#  'Tax due at time of filing Ct 50KLT75K',
#  'Tax due at time of filing Ct 75KLT100K',
#  'Tax due at time of filing Ct All',
#  'Tax due at time of filing Ct GE200K',
#  'Tax due at time of filing Ct LT25K',
#  'Taxable Social Security benefits Amt 100KLT200K',
#  'Taxable Social Security benefits Amt 25KLT50K',
#  'Taxable Social Security benefits Amt 50KLT75K',
#  'Taxable Social Security benefits Amt 75KLT100K',
#  'Taxable Social Security benefits Amt All',
#  'Taxable Social Security benefits Amt GE200K',
#  'Taxable Social Security benefits Amt LT25K',
#  'Taxable Social Security benefits Ct 100KLT200K',
#  'Taxable Social Security benefits Ct 25KLT50K',
#  'Taxable Social Security benefits Ct 50KLT75K',
#  'Taxable Social Security benefits Ct 75KLT100K',
#  'Taxable Social Security benefits Ct All',
#  'Taxable Social Security benefits Ct GE200K',
#  'Taxable Social Security benefits Ct LT25K',
#  'Taxable income Amt 100KLT200K',
#  'Taxable income Amt 25KLT50K',
#  'Taxable income Amt 50KLT75K',
#  'Taxable income Amt 75KLT100K',
#  'Taxable income Amt All',
#  'Taxable income Amt GE200K',
#  'Taxable income Amt LT25K',
#  'Taxable income Ct 100KLT200K',
#  'Taxable income Ct 25KLT50K',
#  'Taxable income Ct 50KLT75K',
#  'Taxable income Ct 75KLT100K',
#  'Taxable income Ct All',
#  'Taxable income Ct GE200K',
#  'Taxable income Ct LT25K',
#  'Taxable individual retirementarrangement distributions Amt 100KLT200K',
#  'Taxable individual retirementarrangement distributions Amt 25KLT50K',
#  'Taxable individual retirementarrangement distributions Amt 50KLT75K',
#  'Taxable individual retirementarrangement distributions Amt 75KLT100K',
#  'Taxable individual retirementarrangement distributions Amt All',
#  'Taxable individual retirementarrangement distributions Amt GE200K',
#  'Taxable individual retirementarrangement distributions Amt LT25K',
#  'Taxable individual retirementarrangement distributions Ct 100KLT200K',
#  'Taxable individual retirementarrangement distributions Ct 25KLT50K',
#  'Taxable individual retirementarrangement distributions Ct 50KLT75K',
#  'Taxable individual retirementarrangement distributions Ct 75KLT100K',
#  'Taxable individual retirementarrangement distributions Ct All',
#  'Taxable individual retirementarrangement distributions Ct GE200K',
#  'Taxable individual retirementarrangement distributions Ct LT25K',
#  'Taxable interest Amt 100KLT200K',
#  'Taxable interest Amt 25KLT50K',
#  'Taxable interest Amt 50KLT75K',
#  'Taxable interest Amt 75KLT100K',
#  'Taxable interest Amt All',
#  'Taxable interest Amt GE200K',
#  'Taxable interest Amt LT25K',
#  ...]

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Columns: 1599 entries, student_num to SRC_devices_sent_home_Yes
# dtypes: float64(1540), uint8(59)
# memory usage: 29.2 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Columns: 393 entries, student_num to SRC_devices_sent_home_Yes
# dtypes: float64(350), uint8(43)
# memory usage: 6.7 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 2 to 2641
# Data columns (total 394 columns):
# student_num                                                     float64
# lea_avg_student_num                                             float64
# st_avg_student_num                                              float64
# 00_Size                                                         float64
# 02_Size                                                         float64
# 03_Size                                                         float64
# 04_Size                                                         float64
# 05_Size                                                         float64
# Math I_Size                                                     float64
# lea_total_expense_num                                           float64
# lea_salary_expense_pct                                          float64
# lea_services_expense_pct                                        float64
# lea_supplies_expense_pct                                        float64
# lea_instruct_equip_exp_pct                                      float64
# lea_federal_perpupil_num                                        float64
# lea_local_perpupil_num                                          float64
# lea_state_perpupil_num                                          float64
# SPG Score                                                       float64
# Reading SPG Score                                               float64
# EVAAS Growth Score                                              float64
# Science Score                                                   float64
# NC Math 1 Score                                                 float64
# EOG/EOCSubjects_CACR_All                                        float64
# EOGGr3_CACR_All                                                 float64
# EOGGr4_CACR_All                                                 float64
# EOGGr5_CACR_All                                                 float64
# EOCMathI_CACR_Female                                            float64
# EOCMathI_CACR_Male                                              float64
# EOCMathI_CACR_AmericanIndian                                    float64
# EOCSubjects_CACR_AmericanIndian                                 float64
# EOG/EOCSubjects_CACR_AmericanIndian                             float64
# EOGGr3_CACR_AmericanIndian                                      float64
# EOGGr4_CACR_AmericanIndian                                      float64
# EOGGr5_CACR_AmericanIndian                                      float64
# EOGMathGr3_CACR_AmericanIndian                                  float64
# EOGMathGr3-8_CACR_AmericanIndian                                float64
# EOGMathGr4_CACR_AmericanIndian                                  float64
# EOGMathGr5_CACR_AmericanIndian                                  float64
# EOGReadingGr3_CACR_AmericanIndian                               float64
# EOGReadingGr3-8_CACR_AmericanIndian                             float64
# EOGReadingGr4_CACR_AmericanIndian                               float64
# EOGReadingGr5_CACR_AmericanIndian                               float64
# EOGReadingGr5_GLP_AmericanIndian                                float64
# EOGScienceGr5_CACR_AmericanIndian                               float64
# EOGScienceGr5&8_CACR_AmericanIndian                             float64
# EOGSubjects_CACR_AmericanIndian                                 float64
# EOCMathI_CACR_Asian                                             float64
# EOCSubjects_CACR_Asian                                          float64
# EOG/EOCSubjects_CACR_Asian                                      float64
# EOGGr3_CACR_Asian                                               float64
# EOGGr4_CACR_Asian                                               float64
# EOGGr5_CACR_Asian                                               float64
# EOGMathGr3_CACR_Asian                                           float64
# EOGMathGr3-8_CACR_Asian                                         float64
# EOGMathGr4_CACR_Asian                                           float64
# EOGMathGr5_CACR_Asian                                           float64
# EOGScienceGr5&8_CACR_Asian                                      float64
# EOGSubjects_CACR_Asian                                          float64
# EOCMathI_CACR_Black                                             float64
# EOCSubjects_CACR_Black                                          float64
# EOG/EOCSubjects_CACR_Black                                      float64
# EOGGr3_CACR_Black                                               float64
# EOGGr4_CACR_Black                                               float64
# EOGGr5_CACR_Black                                               float64
# EOGMathGr3_CACR_Black                                           float64
# EOGMathGr3-8_CACR_Black                                         float64
# EOGMathGr4_CACR_Black                                           float64
# EOGMathGr5_CACR_Black                                           float64
# EOGReadingGr3_CACR_Black                                        float64
# EOGReadingGr3-8_CACR_Black                                      float64
# EOGReadingGr4_CACR_Black                                        float64
# EOGReadingGr5_CACR_Black                                        float64
# EOGScienceGr5_CACR_Black                                        float64
# EOGScienceGr5&8_CACR_Black                                      float64
# EOGSubjects_CACR_Black                                          float64
# EOCMathI_CACR_Hispanic                                          float64
# EOCSubjects_CACR_Hispanic                                       float64
# EOG/EOCSubjects_CACR_Hispanic                                   float64
# EOGGr3_CACR_Hispanic                                            float64
# EOGGr4_CACR_Hispanic                                            float64
# EOGGr5_CACR_Hispanic                                            float64
# EOGMathGr3_CACR_Hispanic                                        float64
# EOGMathGr3-8_CACR_Hispanic                                      float64
# EOGMathGr4_CACR_Hispanic                                        float64
# EOGMathGr5_CACR_Hispanic                                        float64
# EOGReadingGr3_CACR_Hispanic                                     float64
# EOGReadingGr3-8_CACR_Hispanic                                   float64
# EOGReadingGr4_CACR_Hispanic                                     float64
# EOGReadingGr5_CACR_Hispanic                                     float64
# EOGScienceGr5&8_CACR_Hispanic                                   float64
# EOGSubjects_CACR_Hispanic                                       float64
# EOCMathI_CACR_TwoorMoreRaces                                    float64
# EOCSubjects_CACR_TwoorMoreRaces                                 float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                             float64
# EOGGr3_CACR_TwoorMoreRaces                                      float64
# EOGGr4_CACR_TwoorMoreRaces                                      float64
# EOGGr5_CACR_TwoorMoreRaces                                      float64
# EOGMathGr3_CACR_TwoorMoreRaces                                  float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                                float64
# EOGMathGr4_CACR_TwoorMoreRaces                                  float64
# EOGMathGr5_CACR_TwoorMoreRaces                                  float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                             float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                             float64
# EOGSubjects_CACR_TwoorMoreRaces                                 float64
# EOCMathI_CACR_White                                             float64
# EOG/EOCSubjects_CACR_White                                      float64
# EOGGr3_CACR_White                                               float64
# EOGGr4_CACR_White                                               float64
# EOGGr5_CACR_White                                               float64
# EOGMathGr3_CACR_White                                           float64
# EOGMathGr3-8_CACR_White                                         float64
# EOGMathGr4_CACR_White                                           float64
# EOGMathGr5_CACR_White                                           float64
# EOGScienceGr5&8_CACR_White                                      float64
# EOCMathI_CACR_EDS                                               float64
# EOG/EOCSubjects_CACR_EDS                                        float64
# EOGGr3_CACR_EDS                                                 float64
# EOGGr4_CACR_EDS                                                 float64
# EOGMathGr3_CACR_EDS                                             float64
# EOGMathGr3-8_CACR_EDS                                           float64
# EOGMathGr4_CACR_EDS                                             float64
# EOGMathGr5_CACR_EDS                                             float64
# EOGReadingGr3_CACR_EDS                                          float64
# EOGReadingGr3-8_CACR_EDS                                        float64
# EOGReadingGr4_CACR_EDS                                          float64
# EOGReadingGr5_CACR_EDS                                          float64
# EOGScienceGr5_CACR_EDS                                          float64
# EOGScienceGr5&8_CACR_EDS                                        float64
# EOCMathI_CACR_LEP                                               float64
# EOCMathI_GLP_LEP                                                float64
# EOCSubjects_CACR_LEP                                            float64
# EOCSubjects_GLP_LEP                                             float64
# EOG/EOCSubjects_CACR_LEP                                        float64
# EOG/EOCSubjects_GLP_LEP                                         float64
# EOGGr3_CACR_LEP                                                 float64
# EOGGr4_CACR_LEP                                                 float64
# EOGGr4_GLP_LEP                                                  float64
# EOGGr5_CACR_LEP                                                 float64
# EOGMathGr3_CACR_LEP                                             float64
# EOGMathGr3-8_CACR_LEP                                           float64
# EOGMathGr4_CACR_LEP                                             float64
# EOGMathGr5_CACR_LEP                                             float64
# EOGReadingGr3_CACR_LEP                                          float64
# EOGReadingGr3_GLP_LEP                                           float64
# EOGReadingGr3-8_CACR_LEP                                        float64
# EOGReadingGr3-8_GLP_LEP                                         float64
# EOGReadingGr4_CACR_LEP                                          float64
# EOGReadingGr4_GLP_LEP                                           float64
# EOGReadingGr5_CACR_LEP                                          float64
# EOGReadingGr5_GLP_LEP                                           float64
# EOGScienceGr5_CACR_LEP                                          float64
# EOGScienceGr5_GLP_LEP                                           float64
# EOGScienceGr5&8_CACR_LEP                                        float64
# EOGScienceGr5&8_GLP_LEP                                         float64
# EOGSubjects_CACR_LEP                                            float64
# EOCMathI_CACR_SWD                                               float64
# EOCMathI_GLP_SWD                                                float64
# EOCSubjects_CACR_SWD                                            float64
# EOG/EOCSubjects_CACR_SWD                                        float64
# EOGGr3_CACR_SWD                                                 float64
# EOGGr4_CACR_SWD                                                 float64
# EOGGr5_CACR_SWD                                                 float64
# EOGMathGr3_CACR_SWD                                             float64
# EOGMathGr3_GLP_SWD                                              float64
# EOGMathGr3-8_CACR_SWD                                           float64
# EOGMathGr4_CACR_SWD                                             float64
# EOGMathGr5_CACR_SWD                                             float64
# EOGReadingGr3_CACR_SWD                                          float64
# EOGReadingGr3-8_CACR_SWD                                        float64
# EOGReadingGr3-8_GLP_SWD                                         float64
# EOGReadingGr4_CACR_SWD                                          float64
# EOGReadingGr4_GLP_SWD                                           float64
# EOGReadingGr5_CACR_SWD                                          float64
# EOGReadingGr5_GLP_SWD                                           float64
# EOGScienceGr5_CACR_SWD                                          float64
# EOGScienceGr5&8_CACR_SWD                                        float64
# EOGSubjects_CACR_SWD                                            float64
# EOCMathI_CACR_AIG                                               float64
# EOCSubjects_CACR_AIG                                            float64
# EOG/EOCSubjects_CACR_AIG                                        float64
# EOGGr3_CACR_AIG                                                 float64
# EOGGr4_CACR_AIG                                                 float64
# EOGGr5_CACR_AIG                                                 float64
# EOGMathGr3_CACR_AIG                                             float64
# EOGMathGr3-8_CACR_AIG                                           float64
# EOGMathGr4_CACR_AIG                                             float64
# EOGMathGr5_CACR_AIG                                             float64
# EOGScienceGr5&8_CACR_AIG                                        float64
# EOGSubjects_CACR_AIG                                            float64
# pct_GCE_ALL                                                     float64
# MathGr3-8_pTarget_PctMet                                        float64
# SciGr5&8_pTarget_PctMet                                         float64
# TotalTargets_pTarget_PctMet                                     float64
# lea_sat_avg_score_num                                           float64
# lea_sat_participation_pct                                       float64
# lea_ap_participation_pct                                        float64
# lea_ap_pct_3_or_above                                           float64
# lea_ib_pct_4_or_above                                           float64
# avg_daily_attend_pct                                            float64
# crime_per_c_num                                                 float64
# short_susp_per_c_num                                            float64
# long_susp_per_c_num                                             float64
# expelled_per_c_num                                              float64
# stud_internet_comp_num                                          float64
# lea_avg_daily_attend_pct                                        float64
# lea_crime_per_c_num                                             float64
# lea_short_susp_per_c_num                                        float64
# lea_long_susp_per_c_num                                         float64
# lea_expelled_per_c_num                                          float64
# lea_stud_internet_comp_num                                      float64
# st_avg_daily_attend_pct                                         float64
# st_crime_per_c_num                                              float64
# st_short_susp_per_c_num                                         float64
# st_long_susp_per_c_num                                          float64
# st_expelled_per_c_num                                           float64
# digital_media_pct                                               float64
# avg_age_media_collection                                        float64
# books_per_student                                               float64
# lea_books_per_student                                           float64
# wap_num                                                         float64
# wap_per_classroom                                               float64
# lea_wap_num                                                     float64
# lea_wap_per_classroom                                           float64
# flicensed_teach_pct                                             float64
# tchyrs_0thru3_pct                                               float64
# tchyrs_4thru10_pct                                              float64
# tchyrs_11plus_pct                                               float64
# nbpts_num                                                       float64
# advance_dgr_pct                                                 float64
# _1yr_tchr_trnovr_pct                                            float64
# lateral_teach_pct                                               float64
# lea_flicensed_teach_pct                                         float64
# lea_tchyrs_0thru3_pct                                           float64
# lea_tchyrs_4thru10_pct                                          float64
# lea_tchyrs_11plus_pct                                           float64
# lea_nbpts_num                                                   float64
# lea_advance_dgr_pct                                             float64
# lea_1yr_tchr_trnovr_pct                                         float64
# lea_emer_prov_teach_pct                                         float64
# st_flicensed_teach_pct                                          float64
# st_tchyrs_0thru3_pct                                            float64
# st_tchyrs_11plus_pct                                            float64
# st_nbpts_num                                                    float64
# st_1yr_tchr_trnovr_pct                                          float64
# st_emer_prov_teach_pct                                          float64
# 0-3 Years_LEA_Exp_Pct_Prin                                      float64
# 10+ Years_LEA_Exp_Pct_Prin                                      float64
# 4-10 Years_LEA_Exp_Pct_Prin                                     float64
# Accomplished_TCHR_Standard 1_Pct                                float64
# Accomplished_TCHR_Standard 2_Pct                                float64
# Accomplished_TCHR_Standard 3_Pct                                float64
# Accomplished_TCHR_Standard 4_Pct                                float64
# Accomplished_TCHR_Standard 5_Pct                                float64
# Developing_TCHR_Standard 1_Pct                                  float64
# Developing_TCHR_Standard 2_Pct                                  float64
# Developing_TCHR_Standard 3_Pct                                  float64
# Developing_TCHR_Standard 4_Pct                                  float64
# Developing_TCHR_Standard 5_Pct                                  float64
# Distinguished_TCHR_Standard 1_Pct                               float64
# Distinguished_TCHR_Standard 2_Pct                               float64
# Distinguished_TCHR_Standard 3_Pct                               float64
# Distinguished_TCHR_Standard 4_Pct                               float64
# Distinguished_TCHR_Standard 5_Pct                               float64
# Does Not Meet Expected Growth_TCHR_Student Growth_Pct           float64
# Exceeds Expected Growth_TCHR_Student Growth_Pct                 float64
# Meets Expected Growth_TCHR_Student Growth_Pct                   float64
# Not Demostrated_TCHR_Standard 1_Pct                             float64
# Not Demostrated_TCHR_Standard 2_Pct                             float64
# Not Demostrated_TCHR_Standard 4_Pct                             float64
# Proficient_TCHR_Standard 1_Pct                                  float64
# Proficient_TCHR_Standard 2_Pct                                  float64
# Proficient_TCHR_Standard 3_Pct                                  float64
# Proficient_TCHR_Standard 4_Pct                                  float64
# Proficient_TCHR_Standard 5_Pct                                  float64
# IndianPct                                                       float64
# AsianPct                                                        float64
# HispanicPct                                                     float64
# BlackPct                                                        float64
# WhitePct                                                        float64
# PacificIslandPct                                                float64
# TwoOrMorePct                                                    float64
# PacificIslandMalePct                                            float64
# TwoOrMoreMalePct                                                float64
# PacificIslandFemalePct                                          float64
# TwoOrMoreFemalePct                                              float64
# pct_eds                                                         float64
# Year                                                            float64
# Crime_Rate_Violent_Rate                                         float64
# Crime_Rate_Murder_Rate                                          float64
# Crime_Rate_Rape_Rate                                            float64
# Crime_Rate_Robbery_Rate                                         float64
# Crime_Rate_MVT_Rate                                             float64
# Crime_Rate_Arson_Rate                                           float64
# (TCE) prepared returns Ct 100KLT200K                            float64
# (TCE) prepared returns Ct 25KLT50K                              float64
# (TCE) prepared returns Ct 75KLT100K                             float64
# (VITA) prepared returns Ct 100KLT200K                           float64
# (VITA) prepared returns Ct 25KLT50K                             float64
# (VITA) prepared returns Ct 50KLT75K                             float64
# Add child tax credit Amt 25KLT50K                               float64
# Add child tax credit Amt 75KLT100K                              float64
# Advance premium tax credit Amt GE200K                           float64
# Alternative minimum tax Amt 25KLT50K                            float64
# Alternative minimum tax Amt 50KLT75K                            float64
# Alternative minimum tax Amt 75KLT100K                           float64
# Alternative minimum tax Ct 50KLT75K                             float64
# Alternative minimum tax Ct 75KLT100K                            float64
# Deductible points Amt LT25K                                     float64
# Deductible points Ct LT25K                                      float64
# Domestic production activities deduction Amt 100KLT200K         float64
# Domestic production activities deduction Amt 25KLT50K           float64
# Domestic production activities deduction Amt 50KLT75K           float64
# Domestic production activities deduction Amt 75KLT100K          float64
# Domestic production activities deduction Amt LT25K              float64
# Domestic production activities deduction Ct 25KLT50K            float64
# Domestic production activities deduction Ct 50KLT75K            float64
# Domestic production activities deduction Ct 75KLT100K           float64
# Domestic production activities deduction Ct LT25K               float64
# Earned income credit Amt 50KLT75K                               float64
# Excess earned income credit (refundable) Amt 50KLT75K           float64
# Health care individual responsibility payment Amt GE200K        float64
# Home mortgage interest paid from personal seller Amt LT25K      float64
# Investment interest paid Amt 25KLT50K                           float64
# Investment interest paid Amt LT25K                              float64
# Investment interest paid Ct LT25K                               float64
# Net investment income tax Amt 100KLT200K                        float64
# Number of farm returns 100KLT200K                               float64
# Number of farm returns 25KLT50K                                 float64
# Number of farm returns 50KLT75K                                 float64
# Number of farm returns 75KLT100K                                float64
# Number of farm returns All                                      float64
# Number of farm returns GE200K                                   float64
# Number of farm returns LT25K                                    float64
# Number of refund anticipation loan returns 50KLT75K             float64
# Number of volunteer prepared returns Tot 50KLT75K               float64
# Other non-limited misc deduction Amt 50KLT75K                   float64
# Other non-limited misc deduction Amt 75KLT100K                  float64
# Other non-limited misc deduction Amt LT25K                      float64
# Other non-limited misc deduction Ct 75KLT100K                   float64
# Other non-limited misc deduction Ct LT25K                       float64
# Partnership/S-corp net income (less loss) Amt LT25K             float64
# Residential energy tax credit Amt LT25K                         float64
# Residential energy tax credit Ct LT25K                          float64
# Self-employed (Keogh) retirement plans Amt LT25K                float64
# Self-employed (Keogh) retirement plans Ct LT25K                 float64
# Tot Add Medicare tax Amt 25KLT50K                               float64
# Tuition and fees deduction Amt 75KLT100K                        float64
# LEACode                                                         float64
# Attrtion_Reason_InitiatedbyLEA                                  float64
# Attrtion_Reason_OtherReasons                                    float64
# category_cd_E                                                   uint8
# category_cd_H                                                   uint8
# category_cd_I                                                   uint8
# category_cd_M                                                   uint8
# calendar_type_txt_Hospital School                               uint8
# calendar_type_txt_Magnet School, Traditional Calendar           uint8
# calendar_type_txt_Magnet School, Year-Round Calendar            uint8
# calendar_type_txt_Regular School, Traditional Calendar          uint8
# calendar_type_txt_Regular School, Year-Round Calendar           uint8
# calendar_type_txt_Special Education, Traditional Calendar       uint8
# calendar_type_txt_Vocational Education, Traditional Calendar    uint8
# school_type_txt_Magnet School                                   uint8
# school_type_txt_Regular School                                  uint8
# calendar_only_txt_Year-Round Calendar                           uint8
# esea_status_P                                                   uint8
# Grad_project_status_Y                                           uint8
# SBE District_Northeast                                          uint8
# SBE District_Northwest                                          uint8
# SBE District_Piedmont-Triad                                     uint8
# SBE District_Sandhills                                          uint8
# SBE District_Southeast                                          uint8
# SBE District_Southwest                                          uint8
# SBE District_Western                                            uint8
# SPG Grade_A+NG                                                  uint8
# SPG Grade_B                                                     uint8
# SPG Grade_C                                                     uint8
# SPG Grade_D                                                     uint8
# SPG Grade_F                                                     uint8
# SPG Grade_I                                                     uint8
# Reading SPG Grade_B                                             uint8
# Reading SPG Grade_C                                             uint8
# Reading SPG Grade_D                                             uint8
# Reading SPG Grade_F                                             uint8
# Math SPG Grade_B                                                uint8
# Math SPG Grade_C                                                uint8
# Math SPG Grade_D                                                uint8
# Math SPG Grade_F                                                uint8
# EVAAS Growth Status_Met                                         uint8
# EVAAS Growth Status_NotMet                                      uint8
# State Gap Compared_Y                                            uint8
# Byod_Yes                                                        uint8
# _1_to_1_access_Yes                                              uint8
# SRC_devices_sent_home_Yes                                       uint8
# unit_code                                                       object
# dtypes: float64(350), object(1), uint8(43)
# memory usage: 6.7+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.1
# Pandas Version: 0.24.2

# %%
print ('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# ../../../2017/Machine Learning Datasets/PublicSchools2017_ML.csv
